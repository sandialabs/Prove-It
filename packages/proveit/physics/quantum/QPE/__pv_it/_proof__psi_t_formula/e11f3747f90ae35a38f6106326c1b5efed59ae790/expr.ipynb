# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Variable, k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd, VecSum
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Interval, Mult, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(t, one)
sub_expr2 = frac(sub_expr1, two)
expr = Equals(ScalarMult(frac(one, Exp(two, sub_expr2)), VecSum(index_or_indices = [k], summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), NumKet(k, sub_expr1)), domain = Interval(zero, subtract(Mult(two, two_pow_t), one)))), TensorProd(ScalarMult(frac(one, Exp(two, subtract(sub_expr2, frac(t, two)))), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), ket1))), Variable("_a", latex_format = r"{_{-}a}")))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right)\right) = \left(\left(\frac{1}{2^{\frac{t + 1}{2} - \frac{t}{2}}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes} {_{-}a}\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) = (((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes _a)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})), ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes _a)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: Operation
#    operator: 36
#    operands: 5
# 4. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes _a
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (1 / 2^{(t + 1) / 2}, Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. otimes
#    core type: Literal
#    sub-expressions:
# 7. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)), _a)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. 1 / 2^{(t + 1) / 2}
#    core type: Operation
#    operator: 78
#    operands: 12
# 9. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#    core type: Operation
#    operator: 13
#    operand: 17
# 10. (1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))
#     core type: Operation
#     operator: 36
#     operands: 15
# 11. _a
#     core type: Variable
#     sub-expressions:
# 12. (1, 2^{(t + 1) / 2})
#     core type: ExprTuple
#     sub-expressions: 81, 16
# 13. Sum
#     core type: Literal
#     sub-expressions:
# 14. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#     core type: ExprTuple
#     sub-expressions: 17
# 15. (1 / 2^{((t + 1) / 2) - (t / 2)}, |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 82
#     operands: 20
# 17. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 64
#     body: 22
# 18. 1 / 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 78
#     operands: 23
# 19. |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. (2, (t + 1) / 2)
#     core type: ExprTuple
#     sub-expressions: 84, 55
# 21. (k)
#     core type: ExprTuple
#     sub-expressions: 64
# 22. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 26
#     condition: 27
# 23. (1, 2^{((t + 1) / 2) - (t / 2)})
#     core type: ExprTuple
#     sub-expressions: 81, 28
# 24. +
#     core type: Literal
#     sub-expressions:
# 25. (|0〉, e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 36
#     operands: 31
# 27. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 82
#     operands: 34
# 29. |0〉
#     core type: Operation
#     operator: 51
#     operand: 53
# 30. e^{2 * pi * i * phase * 2^{t}} * |1〉
#     core type: Operation
#     operator: 36
#     operands: 37
# 31. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 64, 40
# 34. (2, ((t + 1) / 2) - (t / 2))
#     core type: ExprTuple
#     sub-expressions: 84, 41
# 35. (0)
#     core type: ExprTuple
#     sub-expressions: 53
# 36. *
#     core type: Literal
#     sub-expressions:
# 37. (e^{2 * pi * i * phase * 2^{t}}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 38. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 82
#     operands: 44
# 39. |k〉_{t + 1}
#     core type: Operation
#     operator: 45
#     operands: 46
# 40. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 47
#     operands: 48
# 41. ((t + 1) / 2) - (t / 2)
#     core type: Operation
#     operator: 76
#     operands: 49
# 42. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 82
#     operands: 50
# 43. |1〉
#     core type: Operation
#     operator: 51
#     operand: 81
# 44. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 57, 52
# 45. NUM_KET
#     core type: Literal
#     sub-expressions:
# 46. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 64, 67
# 47. Interval
#     core type: Literal
#     sub-expressions:
# 48. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 49. ((t + 1) / 2, -(t / 2))
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 50. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 51. KET
#     core type: Literal
#     sub-expressions:
# 52. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 72
#     operands: 59
# 53. 0
#     core type: Literal
#     sub-expressions:
# 54. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 76
#     operands: 60
# 55. (t + 1) / 2
#     core type: Operation
#     operator: 78
#     operands: 61
# 56. -(t / 2)
#     core type: Operation
#     operator: 74
#     operand: 68
# 57. e
#     core type: Literal
#     sub-expressions:
# 58. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 72
#     operands: 63
# 59. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 84, 69, 70, 71, 64
# 60. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 61. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 67, 84
# 62. (t / 2)
#     core type: ExprTuple
#     sub-expressions: 68
# 63. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 84, 69, 70, 71, 80
# 64. k
#     core type: Variable
#     sub-expressions:
# 65. 2 * 2^{t}
#     core type: Operation
#     operator: 72
#     operands: 73
# 66. -1
#     core type: Operation
#     operator: 74
#     operand: 81
# 67. t + 1
#     core type: Operation
#     operator: 76
#     operands: 77
# 68. t / 2
#     core type: Operation
#     operator: 78
#     operands: 79
# 69. pi
#     core type: Literal
#     sub-expressions:
# 70. i
#     core type: Literal
#     sub-expressions:
# 71. phase
#     core type: Literal
#     sub-expressions:
# 72. *
#     core type: Literal
#     sub-expressions:
# 73. (2, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 84, 80
# 74. -
#     core type: Literal
#     sub-expressions:
# 75. (1)
#     core type: ExprTuple
#     sub-expressions: 81
# 76. +
#     core type: Literal
#     sub-expressions:
# 77. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 85, 81
# 78. /
#     core type: Literal
#     sub-expressions:
# 79. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 85, 84
# 80. 2^{t}
#     core type: Operation
#     operator: 82
#     operands: 83
# 81. 1
#     core type: Literal
#     sub-expressions:
# 82. Exp
#     core type: Literal
#     sub-expressions:
# 83. (2, t)
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 84. 2
#     core type: Literal
#     sub-expressions:
# 85. t
#     core type: Variable
#     sub-expressions:
