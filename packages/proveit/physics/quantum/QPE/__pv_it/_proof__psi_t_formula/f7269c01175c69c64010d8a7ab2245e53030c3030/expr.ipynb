# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, t
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import And, Equals, Forall
from proveit.numbers import Add, Exp, Interval, Mult, NaturalPos, e, frac, i, one, pi, sqrt, subtract, two, zero
from proveit.physics.quantum import Ket, NumKet
from proveit.physics.quantum.QPE import SubIndexed, _phase, _psi, _psi_t_ket, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Add(t, one)
sub_expr3 = Exp(e, Mult(two, pi, i, _phase, k))
expr = And(Equals(SubIndexed(_psi, [one]), ScalarMult(frac(one, sqrt(two)), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, Ket(k)), domain = Interval(zero, one)))), Forall(instance_param_or_params = [t], instance_expr = Equals(SubIndexed(_psi, [sub_expr2]), ScalarMult(frac(one, Exp(two, frac(sub_expr2, two))), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, NumKet(k, sub_expr2)), domain = Interval(zero, subtract(Mult(two, two_pow_t), one))))), domain = NaturalPos, condition = Equals(_psi_t_ket, ScalarMult(frac(one, Exp(two, frac(t, two))), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, NumKet(k, t)), domain = Interval(zero, subtract(two_pow_t, one)))))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\lvert \psi_{1} \rangle = \left(\frac{1}{\sqrt{2}} \cdot \left(\sum_{k=0}^{1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right)\right)\right) \land \left[\forall_{t \in \mathbb{N}^+~|~\lvert \psi_{t} \rangle = \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)}~\left(\lvert \psi_{t + 1} \rangle = \left(\frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right)\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (|psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))) and [forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))))]
#    core type: Operation
#    operator: 19
#    operands: 1
# 1. (|psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))), forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. |psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))
#    core type: Operation
#    operator: 32
#    operands: 4
# 3. forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))))
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. (|psi_{1}>, (1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (t -> {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. |psi_{1}>
#    core type: Operation
#    operator: 47
#    operand: 121
# 8. (1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))
#    core type: Operation
#    operator: 83
#    operands: 10
# 9. t -> {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).
#    core type: Lambda
#    parameter: 120
#    body: 11
# 10. (1 / sqrt(2), Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. 1 / sqrt(2)
#     core type: Operation
#     operator: 81
#     operands: 16
# 13. Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)
#     core type: Operation
#     operator: 61
#     operand: 22
# 14. |psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))
#     core type: Operation
#     operator: 32
#     operands: 18
# 15. (t in NaturalPos) and (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 121, 21
# 17. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.)
#     core type: ExprTuple
#     sub-expressions: 22
# 18. (|psi_{t + 1}>, (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (t in NaturalPos, |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 21. sqrt(2)
#     core type: Operation
#     operator: 115
#     operands: 27
# 22. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.
#     core type: Lambda
#     parameter: 112
#     body: 28
# 23. |psi_{t + 1}>
#     core type: Operation
#     operator: 47
#     operand: 87
# 24. (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#     core type: Operation
#     operator: 83
#     operands: 30
# 25. t in NaturalPos
#     core type: Operation
#     operator: 85
#     operands: 31
# 26. |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: Operation
#     operator: 32
#     operands: 33
# 27. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 119, 34
# 28. {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.
#     core type: Conditional
#     value: 35
#     condition: 36
# 29. (t + 1)
#     core type: ExprTuple
#     sub-expressions: 87
# 30. (1 / 2^{(t + 1) / 2}, Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 31. (t, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 120, 39
# 32. =
#     core type: Literal
#     sub-expressions:
# 33. (|psi_{t}>, (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 34. 1 / 2
#     core type: Operation
#     operator: 81
#     operands: 42
# 35. e^{2 * pi * i * phase * k} * |k〉
#     core type: Operation
#     operator: 83
#     operands: 43
# 36. k in {0 .. 1}
#     core type: Operation
#     operator: 85
#     operands: 44
# 37. 1 / 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 81
#     operands: 45
# 38. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#     core type: Operation
#     operator: 61
#     operand: 53
# 39. NaturalPos
#     core type: Literal
#     sub-expressions:
# 40. |psi_{t}>
#     core type: Operation
#     operator: 47
#     operand: 120
# 41. (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 83
#     operands: 49
# 42. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 121, 119
# 43. (e^{2 * pi * i * phase * k}, |k〉)
#     core type: ExprTuple
#     sub-expressions: 89, 50
# 44. (k, {0 .. 1})
#     core type: ExprTuple
#     sub-expressions: 112, 51
# 45. (1, 2^{(t + 1) / 2})
#     core type: ExprTuple
#     sub-expressions: 121, 52
# 46. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#     core type: ExprTuple
#     sub-expressions: 53
# 47. psi
#     core type: Literal
#     sub-expressions:
# 48. (t)
#     core type: ExprTuple
#     sub-expressions: 120
# 49. (1 / 2^{t / 2}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 50. |k〉
#     core type: Operation
#     operator: 56
#     operand: 112
# 51. {0 .. 1}
#     core type: Operation
#     operator: 97
#     operands: 57
# 52. 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 115
#     operands: 58
# 53. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 112
#     body: 59
# 54. 1 / 2^{t / 2}
#     core type: Operation
#     operator: 81
#     operands: 60
# 55. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 61
#     operand: 67
# 56. KET
#     core type: Literal
#     sub-expressions:
# 57. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 102, 121
# 58. (2, (t + 1) / 2)
#     core type: ExprTuple
#     sub-expressions: 119, 63
# 59. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 64
#     condition: 65
# 60. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 121, 66
# 61. Sum
#     core type: Literal
#     sub-expressions:
# 62. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 67
# 63. (t + 1) / 2
#     core type: Operation
#     operator: 81
#     operands: 68
# 64. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 83
#     operands: 69
# 65. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 85
#     operands: 70
# 66. 2^{t / 2}
#     core type: Operation
#     operator: 115
#     operands: 71
# 67. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 112
#     body: 73
# 68. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 87, 119
# 69. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 89, 74
# 70. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 112, 75
# 71. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 119, 76
# 72. (k)
#     core type: ExprTuple
#     sub-expressions: 112
# 73. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 77
#     condition: 78
# 74. |k〉_{t + 1}
#     core type: Operation
#     operator: 95
#     operands: 79
# 75. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 97
#     operands: 80
# 76. t / 2
#     core type: Operation
#     operator: 81
#     operands: 82
# 77. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 83
#     operands: 84
# 78. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 85
#     operands: 86
# 79. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 112, 87
# 80. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 102, 88
# 81. /
#     core type: Literal
#     sub-expressions:
# 82. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 120, 119
# 83. *
#     core type: Literal
#     sub-expressions:
# 84. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 89, 90
# 85. in
#     core type: Literal
#     sub-expressions:
# 86. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 112, 91
# 87. t + 1
#     core type: Operation
#     operator: 107
#     operands: 92
# 88. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 107
#     operands: 93
# 89. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 115
#     operands: 94
# 90. |k〉_{t}
#     core type: Operation
#     operator: 95
#     operands: 96
# 91. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 97
#     operands: 98
# 92. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 120, 121
# 93. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 99, 114
# 94. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 100, 101
# 95. NUM_KET
#     core type: Literal
#     sub-expressions:
# 96. (k, t)
#     core type: ExprTuple
#     sub-expressions: 112, 120
# 97. Interval
#     core type: Literal
#     sub-expressions:
# 98. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 102, 103
# 99. 2 * 2^{t}
#     core type: Operation
#     operator: 105
#     operands: 104
# 100. e
#      core type: Literal
#      sub-expressions:
# 101. 2 * pi * i * phase * k
#      core type: Operation
#      operator: 105
#      operands: 106
# 102. 0
#      core type: Literal
#      sub-expressions:
# 103. 2^{t} - 1
#      core type: Operation
#      operator: 107
#      operands: 108
# 104. (2, 2^{t})
#      core type: ExprTuple
#      sub-expressions: 119, 113
# 105. *
#      core type: Literal
#      sub-expressions:
# 106. (2, pi, i, phase, k)
#      core type: ExprTuple
#      sub-expressions: 119, 109, 110, 111, 112
# 107. +
#      core type: Literal
#      sub-expressions:
# 108. (2^{t}, -1)
#      core type: ExprTuple
#      sub-expressions: 113, 114
# 109. pi
#      core type: Literal
#      sub-expressions:
# 110. i
#      core type: Literal
#      sub-expressions:
# 111. phase
#      core type: Literal
#      sub-expressions:
# 112. k
#      core type: Variable
#      sub-expressions:
# 113. 2^{t}
#      core type: Operation
#      operator: 115
#      operands: 116
# 114. -1
#      core type: Operation
#      operator: 117
#      operand: 121
# 115. Exp
#      core type: Literal
#      sub-expressions:
# 116. (2, t)
#      core type: ExprTuple
#      sub-expressions: 119, 120
# 117. -
#      core type: Literal
#      sub-expressions:
# 118. (1)
#      core type: ExprTuple
#      sub-expressions: 121
# 119. 2
#      core type: Literal
#      sub-expressions:
# 120. t
#      core type: Variable
#      sub-expressions:
# 121. 1
#      core type: Literal
#      sub-expressions:
