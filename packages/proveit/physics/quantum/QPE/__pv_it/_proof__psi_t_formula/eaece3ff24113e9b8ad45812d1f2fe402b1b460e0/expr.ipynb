# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd
from proveit.numbers import Add, Exp, Mult, Neg, e, frac, i, one, pi, sqrt, subtract, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = frac(one, sqrt(two))
sub_expr3 = ExprRange(sub_expr1, ScalarMult(sub_expr2, VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))), Add(Neg(t), one), zero).with_decreasing_order()
expr = ExprTuple(ScalarMult(sub_expr2, TensorProd(VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, two_pow_t, _phase)), ket1)), sub_expr3)), ScalarMult(frac(one, Exp(two, subtract(frac(Add(t, one), two), frac(t, two)))), TensorProd(VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), ket1)), sub_expr3)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\frac{1}{\sqrt{2}} \cdot \left(\left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right){\otimes} \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \ldots {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right)\right), \frac{1}{2^{\frac{t + 1}{2} - \frac{t}{2}}} \cdot \left(\left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \lvert 1 \rangle\right)\right){\otimes} \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \ldots {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((1 / sqrt(2)) * ((|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))), (1 / 2^{((t + 1) / 2) - (t / 2)}) * ((|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (1 / sqrt(2)) * ((|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: Operation
#    operator: 59
#    operands: 3
# 2. (1 / 2^{((t + 1) / 2) - (t / 2)}) * ((|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: Operation
#    operator: 59
#    operands: 4
# 3. (1 / sqrt(2), (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 35, 5
# 4. (1 / 2^{((t + 1) / 2) - (t / 2)}, (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#    core type: Operation
#    operator: 10
#    operands: 8
# 6. 1 / 2^{((t + 1) / 2) - (t / 2)}
#    core type: Operation
#    operator: 67
#    operands: 9
# 7. (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉),((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 12, 15
# 9. (1, 2^{((t + 1) / 2) - (t / 2)})
#    core type: ExprTuple
#    sub-expressions: 75, 13
# 10. otimes
#     core type: Literal
#     sub-expressions:
# 11. (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉),((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. |0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉)
#     core type: Operation
#     operator: 43
#     operands: 16
# 13. 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 82
#     operands: 17
# 14. |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: Operation
#     operator: 43
#     operands: 18
# 15. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 63
# 16. (|0〉, e^{2 * pi * i * 2^{t} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 50, 21
# 17. (2, ((t + 1) / 2) - (t / 2))
#     core type: ExprTuple
#     sub-expressions: 84, 22
# 18. (|0〉, e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 50, 23
# 19. _a -> ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))
#     core type: Lambda
#     parameter: 88
#     body: 24
# 20. -t + 1
#     core type: Operation
#     operator: 53
#     operands: 25
# 21. e^{2 * pi * i * 2^{t} * phase} * |1〉
#     core type: Operation
#     operator: 59
#     operands: 26
# 22. ((t + 1) / 2) - (t / 2)
#     core type: Operation
#     operator: 53
#     operands: 27
# 23. e^{2 * pi * i * phase * 2^{t}} * |1〉
#     core type: Operation
#     operator: 59
#     operands: 28
# 24. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 59
#     operands: 29
# 25. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 30, 75
# 26. (e^{2 * pi * i * 2^{t} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 31, 65
# 27. ((t + 1) / 2, -(t / 2))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 28. (e^{2 * pi * i * phase * 2^{t}}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 34, 65
# 29. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 30. -t
#     core type: Operation
#     operator: 86
#     operand: 72
# 31. e^{2 * pi * i * 2^{t} * phase}
#     core type: Operation
#     operator: 82
#     operands: 38
# 32. (t + 1) / 2
#     core type: Operation
#     operator: 67
#     operands: 39
# 33. -(t / 2)
#     core type: Operation
#     operator: 86
#     operand: 47
# 34. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 82
#     operands: 41
# 35. 1 / sqrt(2)
#     core type: Operation
#     operator: 67
#     operands: 42
# 36. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 43
#     operands: 44
# 37. (t)
#     core type: ExprTuple
#     sub-expressions: 72
# 38. (e, 2 * pi * i * 2^{t} * phase)
#     core type: ExprTuple
#     sub-expressions: 73, 45
# 39. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 46, 84
# 40. (t / 2)
#     core type: ExprTuple
#     sub-expressions: 47
# 41. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 73, 48
# 42. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 75, 49
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 45. 2 * pi * i * 2^{t} * phase
#     core type: Operation
#     operator: 76
#     operands: 52
# 46. t + 1
#     core type: Operation
#     operator: 53
#     operands: 54
# 47. t / 2
#     core type: Operation
#     operator: 67
#     operands: 55
# 48. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 76
#     operands: 56
# 49. sqrt(2)
#     core type: Operation
#     operator: 82
#     operands: 57
# 50. |0〉
#     core type: Operation
#     operator: 70
#     operand: 63
# 51. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 59
#     operands: 60
# 52. (2, pi, i, 2^{t}, phase)
#     core type: ExprTuple
#     sub-expressions: 84, 78, 79, 61, 81
# 53. +
#     core type: Literal
#     sub-expressions:
# 54. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 72, 75
# 55. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 72, 84
# 56. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 84, 78, 79, 81, 61
# 57. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 84, 62
# 58. (0)
#     core type: ExprTuple
#     sub-expressions: 63
# 59. *
#     core type: Literal
#     sub-expressions:
# 60. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 61. 2^{t}
#     core type: Operation
#     operator: 82
#     operands: 66
# 62. 1 / 2
#     core type: Operation
#     operator: 67
#     operands: 68
# 63. 0
#     core type: Literal
#     sub-expressions:
# 64. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 82
#     operands: 69
# 65. |1〉
#     core type: Operation
#     operator: 70
#     operand: 75
# 66. (2, t)
#     core type: ExprTuple
#     sub-expressions: 84, 72
# 67. /
#     core type: Literal
#     sub-expressions:
# 68. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 75, 84
# 69. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 70. KET
#     core type: Literal
#     sub-expressions:
# 71. (1)
#     core type: ExprTuple
#     sub-expressions: 75
# 72. t
#     core type: Variable
#     sub-expressions:
# 73. e
#     core type: Literal
#     sub-expressions:
# 74. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 76
#     operands: 77
# 75. 1
#     core type: Literal
#     sub-expressions:
# 76. *
#     core type: Literal
#     sub-expressions:
# 77. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 84, 78, 79, 80, 81
# 78. pi
#     core type: Literal
#     sub-expressions:
# 79. i
#     core type: Literal
#     sub-expressions:
# 80. 2^{-_a}
#     core type: Operation
#     operator: 82
#     operands: 83
# 81. phase
#     core type: Literal
#     sub-expressions:
# 82. Exp
#     core type: Literal
#     sub-expressions:
# 83. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 84. 2
#     core type: Literal
#     sub-expressions:
# 85. -_a
#     core type: Operation
#     operator: 86
#     operand: 88
# 86. -
#     core type: Literal
#     sub-expressions:
# 87. (_a)
#     core type: ExprTuple
#     sub-expressions: 88
# 88. _a
#     core type: Variable
#     sub-expressions:
