# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k
from proveit.linear_algebra import ScalarMult, VecAdd, VecSum
from proveit.logic import Equals
from proveit.numbers import Exp, Interval, Mult, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import Ket, ket0, ket1
from proveit.physics.quantum.QPE import _phase

# %%
# build up the expression from sub-expressions
sub_expr1 = frac(one, sqrt(two))
expr = Equals(ScalarMult(sub_expr1, VecSum(index_or_indices = [k], summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), Ket(k)), domain = Interval(zero, one))), ScalarMult(sub_expr1, VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, _phase)), ket1))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\frac{1}{\sqrt{2}} \cdot \left(\sum_{k=0}^{1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right)\right) = \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))) = ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase} * |1〉)))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)), (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase} * |1〉)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))
#    core type: Operation
#    operator: 28
#    operands: 5
# 4. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase} * |1〉))
#    core type: Operation
#    operator: 28
#    operands: 6
# 5. (1 / sqrt(2), Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉))
#    core type: ExprTuple
#    sub-expressions: 8, 7
# 6. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * phase} * |1〉))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)
#    core type: Operation
#    operator: 10
#    operand: 15
# 8. 1 / sqrt(2)
#    core type: Operation
#    operator: 32
#    operands: 12
# 9. |0〉 + (e^{2 * pi * i * phase} * |1〉)
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. Sum
#     core type: Literal
#     sub-expressions:
# 11. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 50, 16
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (|0〉, e^{2 * pi * i * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.
#     core type: Lambda
#     parameter: 57
#     body: 19
# 16. sqrt(2)
#     core type: Operation
#     operator: 40
#     operands: 20
# 17. |0〉
#     core type: Operation
#     operator: 42
#     operand: 49
# 18. e^{2 * pi * i * phase} * |1〉
#     core type: Operation
#     operator: 28
#     operands: 22
# 19. {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 1}.
#     core type: Conditional
#     value: 23
#     condition: 24
# 20. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 53, 25
# 21. (0)
#     core type: ExprTuple
#     sub-expressions: 49
# 22. (e^{2 * pi * i * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. e^{2 * pi * i * phase * k} * |k〉
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. k in {0 .. 1}
#     core type: Operation
#     operator: 30
#     operands: 31
# 25. 1 / 2
#     core type: Operation
#     operator: 32
#     operands: 33
# 26. e^{2 * pi * i * phase}
#     core type: Operation
#     operator: 40
#     operands: 34
# 27. |1〉
#     core type: Operation
#     operator: 42
#     operand: 50
# 28. *
#     core type: Literal
#     sub-expressions:
# 29. (e^{2 * pi * i * phase * k}, |k〉)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (k, {0 .. 1})
#     core type: ExprTuple
#     sub-expressions: 57, 38
# 32. /
#     core type: Literal
#     sub-expressions:
# 33. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 50, 53
# 34. (e, 2 * pi * i * phase)
#     core type: ExprTuple
#     sub-expressions: 47, 39
# 35. (1)
#     core type: ExprTuple
#     sub-expressions: 50
# 36. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. |k〉
#     core type: Operation
#     operator: 42
#     operand: 57
# 38. {0 .. 1}
#     core type: Operation
#     operator: 44
#     operands: 45
# 39. 2 * pi * i * phase
#     core type: Operation
#     operator: 51
#     operands: 46
# 40. Exp
#     core type: Literal
#     sub-expressions:
# 41. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 42. KET
#     core type: Literal
#     sub-expressions:
# 43. (k)
#     core type: ExprTuple
#     sub-expressions: 57
# 44. Interval
#     core type: Literal
#     sub-expressions:
# 45. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 46. (2, pi, i, phase)
#     core type: ExprTuple
#     sub-expressions: 53, 54, 55, 56
# 47. e
#     core type: Literal
#     sub-expressions:
# 48. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 51
#     operands: 52
# 49. 0
#     core type: Literal
#     sub-expressions:
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. *
#     core type: Literal
#     sub-expressions:
# 52. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 53, 54, 55, 56, 57
# 53. 2
#     core type: Literal
#     sub-expressions:
# 54. pi
#     core type: Literal
#     sub-expressions:
# 55. i
#     core type: Literal
#     sub-expressions:
# 56. phase
#     core type: Literal
#     sub-expressions:
# 57. k
#     core type: Variable
#     sub-expressions:
