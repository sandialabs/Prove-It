# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, k, t
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Exp, Interval, Mult, NaturalPos, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet
from proveit.physics.quantum.QPE import SubIndexed, _phase, _psi, _psi_t_ket, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Add(t, one)
sub_expr3 = Exp(e, Mult(two, pi, i, _phase, k))
expr = ExprTuple(Lambda(t, Conditional(Equals(SubIndexed(_psi, [sub_expr2]), ScalarMult(frac(one, Exp(two, frac(sub_expr2, two))), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, NumKet(k, sub_expr2)), domain = Interval(zero, subtract(Mult(two, two_pow_t), one))))), And(InSet(t, NaturalPos), Equals(_psi_t_ket, ScalarMult(frac(one, Exp(two, frac(t, two))), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, NumKet(k, t)), domain = Interval(zero, subtract(two_pow_t, one)))))))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(t \mapsto \left\{\lvert \psi_{t + 1} \rangle = \left(\frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right)\right) \textrm{ if } t \in \mathbb{N}^+ ,  \lvert \psi_{t} \rangle = \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (t -> {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. t -> {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).
#    core type: Lambda
#    parameter: 93
#    body: 2
# 2. {|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) if t in NaturalPos ,  |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. |psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))
#    core type: Operation
#    operator: 15
#    operands: 5
# 4. (t in NaturalPos) and (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (|psi_{t + 1}>, (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (t in NaturalPos, |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. |psi_{t + 1}>
#    core type: Operation
#    operator: 24
#    operand: 60
# 9. (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: Operation
#    operator: 56
#    operands: 13
# 10. t in NaturalPos
#     core type: Operation
#     operator: 58
#     operands: 14
# 11. |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (t + 1)
#     core type: ExprTuple
#     sub-expressions: 60
# 13. (1 / 2^{(t + 1) / 2}, Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. (t, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 93, 19
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (|psi_{t}>, (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. 1 / 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 54
#     operands: 22
# 18. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#     core type: Operation
#     operator: 34
#     operand: 28
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. |psi_{t}>
#     core type: Operation
#     operator: 24
#     operand: 93
# 21. (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 56
#     operands: 26
# 22. (1, 2^{(t + 1) / 2})
#     core type: ExprTuple
#     sub-expressions: 94, 27
# 23. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#     core type: ExprTuple
#     sub-expressions: 28
# 24. psi
#     core type: Literal
#     sub-expressions:
# 25. (t)
#     core type: ExprTuple
#     sub-expressions: 93
# 26. (1 / 2^{t / 2}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 88
#     operands: 31
# 28. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 85
#     body: 32
# 29. 1 / 2^{t / 2}
#     core type: Operation
#     operator: 54
#     operands: 33
# 30. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 34
#     operand: 40
# 31. (2, (t + 1) / 2)
#     core type: ExprTuple
#     sub-expressions: 92, 36
# 32. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 37
#     condition: 38
# 33. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 94, 39
# 34. Sum
#     core type: Literal
#     sub-expressions:
# 35. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 40
# 36. (t + 1) / 2
#     core type: Operation
#     operator: 54
#     operands: 41
# 37. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 56
#     operands: 42
# 38. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 58
#     operands: 43
# 39. 2^{t / 2}
#     core type: Operation
#     operator: 88
#     operands: 44
# 40. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 85
#     body: 46
# 41. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 60, 92
# 42. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 62, 47
# 43. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 85, 48
# 44. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 92, 49
# 45. (k)
#     core type: ExprTuple
#     sub-expressions: 85
# 46. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 50
#     condition: 51
# 47. |k〉_{t + 1}
#     core type: Operation
#     operator: 68
#     operands: 52
# 48. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 70
#     operands: 53
# 49. t / 2
#     core type: Operation
#     operator: 54
#     operands: 55
# 50. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 56
#     operands: 57
# 51. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 58
#     operands: 59
# 52. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 85, 60
# 53. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 75, 61
# 54. /
#     core type: Literal
#     sub-expressions:
# 55. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 93, 92
# 56. *
#     core type: Literal
#     sub-expressions:
# 57. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 58. in
#     core type: Literal
#     sub-expressions:
# 59. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 85, 64
# 60. t + 1
#     core type: Operation
#     operator: 80
#     operands: 65
# 61. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 80
#     operands: 66
# 62. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 88
#     operands: 67
# 63. |k〉_{t}
#     core type: Operation
#     operator: 68
#     operands: 69
# 64. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 70
#     operands: 71
# 65. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 93, 94
# 66. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 72, 87
# 67. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 68. NUM_KET
#     core type: Literal
#     sub-expressions:
# 69. (k, t)
#     core type: ExprTuple
#     sub-expressions: 85, 93
# 70. Interval
#     core type: Literal
#     sub-expressions:
# 71. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 72. 2 * 2^{t}
#     core type: Operation
#     operator: 78
#     operands: 77
# 73. e
#     core type: Literal
#     sub-expressions:
# 74. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 78
#     operands: 79
# 75. 0
#     core type: Literal
#     sub-expressions:
# 76. 2^{t} - 1
#     core type: Operation
#     operator: 80
#     operands: 81
# 77. (2, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 92, 86
# 78. *
#     core type: Literal
#     sub-expressions:
# 79. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 92, 82, 83, 84, 85
# 80. +
#     core type: Literal
#     sub-expressions:
# 81. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 86, 87
# 82. pi
#     core type: Literal
#     sub-expressions:
# 83. i
#     core type: Literal
#     sub-expressions:
# 84. phase
#     core type: Literal
#     sub-expressions:
# 85. k
#     core type: Variable
#     sub-expressions:
# 86. 2^{t}
#     core type: Operation
#     operator: 88
#     operands: 89
# 87. -1
#     core type: Operation
#     operator: 90
#     operand: 94
# 88. Exp
#     core type: Literal
#     sub-expressions:
# 89. (2, t)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 90. -
#     core type: Literal
#     sub-expressions:
# 91. (1)
#     core type: ExprTuple
#     sub-expressions: 94
# 92. 2
#     core type: Literal
#     sub-expressions:
# 93. t
#     core type: Variable
#     sub-expressions:
# 94. 1
#     core type: Literal
#     sub-expressions:
