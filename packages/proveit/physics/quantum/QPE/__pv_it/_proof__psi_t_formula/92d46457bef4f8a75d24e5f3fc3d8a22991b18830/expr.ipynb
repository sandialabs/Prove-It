# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd, VecSum
from proveit.numbers import Add, Exp, Interval, Mult, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Add(t, one)
sub_expr3 = Exp(e, Mult(two, pi, i, _phase, k))
sub_expr4 = frac(one, Exp(two, frac(sub_expr2, two)))
sub_expr5 = VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, NumKet(k, t)), domain = Interval(zero, subtract(two_pow_t, one)))
expr = ExprTuple(ScalarMult(sub_expr4, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, NumKet(k, sub_expr2)), domain = Interval(zero, subtract(Mult(two, two_pow_t), one)))), ScalarMult(sub_expr4, VecAdd(TensorProd(ket0, sub_expr5), ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), TensorProd(ket1, sub_expr5)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right), \frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\left(\lvert 0 \rangle {\otimes} \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right) + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \left(\lvert 1 \rangle {\otimes} \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})), (1 / 2^{(t + 1) / 2}) * ((|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: Operation
#    operator: 56
#    operands: 3
# 2. (1 / 2^{(t + 1) / 2}) * ((|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: Operation
#    operator: 56
#    operands: 4
# 3. (1 / 2^{(t + 1) / 2}, Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: ExprTuple
#    sub-expressions: 6, 5
# 4. (1 / 2^{(t + 1) / 2}, (|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#    core type: Operation
#    operator: 43
#    operand: 12
# 6. 1 / 2^{(t + 1) / 2}
#    core type: Operation
#    operator: 28
#    operands: 9
# 7. (|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#    core type: ExprTuple
#    sub-expressions: 12
# 9. (1, 2^{(t + 1) / 2})
#    core type: ExprTuple
#    sub-expressions: 88, 13
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 79
#     body: 16
# 13. 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 82
#     operands: 17
# 14. |0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 32
#     operands: 18
# 15. e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: Operation
#     operator: 56
#     operands: 19
# 16. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 20
#     condition: 21
# 17. (2, (t + 1) / 2)
#     core type: ExprTuple
#     sub-expressions: 86, 22
# 18. (|0〉, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 23, 38
# 19. (e^{2 * pi * i * phase * 2^{t}}, |1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 20. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 56
#     operands: 26
# 21. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 58
#     operands: 27
# 22. (t + 1) / 2
#     core type: Operation
#     operator: 28
#     operands: 29
# 23. |0〉
#     core type: Operation
#     operator: 42
#     operand: 70
# 24. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 82
#     operands: 31
# 25. |1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 32
#     operands: 33
# 26. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 60, 34
# 27. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 79, 35
# 28. /
#     core type: Literal
#     sub-expressions:
# 29. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 45, 86
# 30. (0)
#     core type: ExprTuple
#     sub-expressions: 70
# 31. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 68, 36
# 32. otimes
#     core type: Literal
#     sub-expressions:
# 33. (|1〉, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. |k〉_{t + 1}
#     core type: Operation
#     operator: 64
#     operands: 39
# 35. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 66
#     operands: 40
# 36. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 72
#     operands: 41
# 37. |1〉
#     core type: Operation
#     operator: 42
#     operand: 88
# 38. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 43
#     operand: 47
# 39. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 79, 45
# 40. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 70, 46
# 41. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 86, 76, 77, 78, 80
# 42. KET
#     core type: Literal
#     sub-expressions:
# 43. Sum
#     core type: Literal
#     sub-expressions:
# 44. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 47
# 45. t + 1
#     core type: Operation
#     operator: 74
#     operands: 48
# 46. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 74
#     operands: 49
# 47. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 79
#     body: 51
# 48. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 87, 88
# 49. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 52, 81
# 50. (k)
#     core type: ExprTuple
#     sub-expressions: 79
# 51. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 53
#     condition: 54
# 52. 2 * 2^{t}
#     core type: Operation
#     operator: 72
#     operands: 55
# 53. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 56
#     operands: 57
# 54. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 58
#     operands: 59
# 55. (2, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 86, 80
# 56. *
#     core type: Literal
#     sub-expressions:
# 57. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 58. in
#     core type: Literal
#     sub-expressions:
# 59. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 79, 62
# 60. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 82
#     operands: 63
# 61. |k〉_{t}
#     core type: Operation
#     operator: 64
#     operands: 65
# 62. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 66
#     operands: 67
# 63. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 64. NUM_KET
#     core type: Literal
#     sub-expressions:
# 65. (k, t)
#     core type: ExprTuple
#     sub-expressions: 79, 87
# 66. Interval
#     core type: Literal
#     sub-expressions:
# 67. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 68. e
#     core type: Literal
#     sub-expressions:
# 69. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 72
#     operands: 73
# 70. 0
#     core type: Literal
#     sub-expressions:
# 71. 2^{t} - 1
#     core type: Operation
#     operator: 74
#     operands: 75
# 72. *
#     core type: Literal
#     sub-expressions:
# 73. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 86, 76, 77, 78, 79
# 74. +
#     core type: Literal
#     sub-expressions:
# 75. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 76. pi
#     core type: Literal
#     sub-expressions:
# 77. i
#     core type: Literal
#     sub-expressions:
# 78. phase
#     core type: Literal
#     sub-expressions:
# 79. k
#     core type: Variable
#     sub-expressions:
# 80. 2^{t}
#     core type: Operation
#     operator: 82
#     operands: 83
# 81. -1
#     core type: Operation
#     operator: 84
#     operand: 88
# 82. Exp
#     core type: Literal
#     sub-expressions:
# 83. (2, t)
#     core type: ExprTuple
#     sub-expressions: 86, 87
# 84. -
#     core type: Literal
#     sub-expressions:
# 85. (1)
#     core type: ExprTuple
#     sub-expressions: 88
# 86. 2
#     core type: Literal
#     sub-expressions:
# 87. t
#     core type: Variable
#     sub-expressions:
# 88. 1
#     core type: Literal
#     sub-expressions:
