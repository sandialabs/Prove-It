# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd, VecSum
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Interval, Mult, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Add(t, one)
sub_expr3 = frac(t, two)
sub_expr4 = frac(sub_expr2, two)
sub_expr5 = Exp(e, Mult(two, pi, i, _phase, k))
expr = Equals(ScalarMult(frac(one, Exp(two, sub_expr4)), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr5, NumKet(k, sub_expr2)), domain = Interval(zero, subtract(Mult(two, two_pow_t), one)))), TensorProd(ScalarMult(frac(one, Exp(two, subtract(sub_expr4, sub_expr3))), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), ket1))), ScalarMult(frac(one, Exp(two, sub_expr3)), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr5, NumKet(k, t)), domain = Interval(zero, subtract(two_pow_t, one))))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\frac{1}{2^{\frac{t + 1}{2}}} \cdot \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right)\right) = \left(\left(\frac{1}{2^{\frac{t + 1}{2} - \frac{t}{2}}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes} \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) = (((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})), ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: Operation
#    operator: 57
#    operands: 5
# 4. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (1 / 2^{(t + 1) / 2}, Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. otimes
#    core type: Literal
#    sub-expressions:
# 7. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)), (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. 1 / 2^{(t + 1) / 2}
#    core type: Operation
#    operator: 86
#    operands: 12
# 9. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#    core type: Operation
#    operator: 28
#    operand: 17
# 10. (1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))
#     core type: Operation
#     operator: 57
#     operands: 14
# 11. (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 57
#     operands: 15
# 12. (1, 2^{(t + 1) / 2})
#     core type: ExprTuple
#     sub-expressions: 104, 16
# 13. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#     core type: ExprTuple
#     sub-expressions: 17
# 14. (1 / 2^{((t + 1) / 2) - (t / 2)}, |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. (1 / 2^{t / 2}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 16. 2^{(t + 1) / 2}
#     core type: Operation
#     operator: 98
#     operands: 22
# 17. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Lambda
#     parameter: 95
#     body: 23
# 18. 1 / 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 86
#     operands: 24
# 19. |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: Operation
#     operator: 25
#     operands: 26
# 20. 1 / 2^{t / 2}
#     core type: Operation
#     operator: 86
#     operands: 27
# 21. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 28
#     operand: 36
# 22. (2, (t + 1) / 2)
#     core type: ExprTuple
#     sub-expressions: 102, 62
# 23. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 30
#     condition: 31
# 24. (1, 2^{((t + 1) / 2) - (t / 2)})
#     core type: ExprTuple
#     sub-expressions: 104, 32
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (|0〉, e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 27. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 104, 35
# 28. Sum
#     core type: Literal
#     sub-expressions:
# 29. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 36
# 30. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 57
#     operands: 37
# 31. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 59
#     operands: 38
# 32. 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 98
#     operands: 39
# 33. |0〉
#     core type: Operation
#     operator: 56
#     operand: 82
# 34. e^{2 * pi * i * phase * 2^{t}} * |1〉
#     core type: Operation
#     operator: 57
#     operands: 41
# 35. 2^{t / 2}
#     core type: Operation
#     operator: 98
#     operands: 42
# 36. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 95
#     body: 44
# 37. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 65, 45
# 38. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 95, 46
# 39. (2, ((t + 1) / 2) - (t / 2))
#     core type: ExprTuple
#     sub-expressions: 102, 47
# 40. (0)
#     core type: ExprTuple
#     sub-expressions: 82
# 41. (e^{2 * pi * i * phase * 2^{t}}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 42. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 102, 79
# 43. (k)
#     core type: ExprTuple
#     sub-expressions: 95
# 44. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 50
#     condition: 51
# 45. |k〉_{t + 1}
#     core type: Operation
#     operator: 73
#     operands: 52
# 46. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 75
#     operands: 53
# 47. ((t + 1) / 2) - (t / 2)
#     core type: Operation
#     operator: 90
#     operands: 54
# 48. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 98
#     operands: 55
# 49. |1〉
#     core type: Operation
#     operator: 56
#     operand: 104
# 50. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 57
#     operands: 58
# 51. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 59
#     operands: 60
# 52. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 95, 78
# 53. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 82, 61
# 54. ((t + 1) / 2, -(t / 2))
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 55. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 80, 64
# 56. KET
#     core type: Literal
#     sub-expressions:
# 57. *
#     core type: Literal
#     sub-expressions:
# 58. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 59. in
#     core type: Literal
#     sub-expressions:
# 60. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 95, 67
# 61. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 90
#     operands: 68
# 62. (t + 1) / 2
#     core type: Operation
#     operator: 86
#     operands: 69
# 63. -(t / 2)
#     core type: Operation
#     operator: 100
#     operand: 79
# 64. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 88
#     operands: 71
# 65. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 98
#     operands: 72
# 66. |k〉_{t}
#     core type: Operation
#     operator: 73
#     operands: 74
# 67. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 75
#     operands: 76
# 68. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 77, 97
# 69. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 78, 102
# 70. (t / 2)
#     core type: ExprTuple
#     sub-expressions: 79
# 71. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 102, 92, 93, 94, 96
# 72. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 73. NUM_KET
#     core type: Literal
#     sub-expressions:
# 74. (k, t)
#     core type: ExprTuple
#     sub-expressions: 95, 103
# 75. Interval
#     core type: Literal
#     sub-expressions:
# 76. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 77. 2 * 2^{t}
#     core type: Operation
#     operator: 88
#     operands: 84
# 78. t + 1
#     core type: Operation
#     operator: 90
#     operands: 85
# 79. t / 2
#     core type: Operation
#     operator: 86
#     operands: 87
# 80. e
#     core type: Literal
#     sub-expressions:
# 81. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 88
#     operands: 89
# 82. 0
#     core type: Literal
#     sub-expressions:
# 83. 2^{t} - 1
#     core type: Operation
#     operator: 90
#     operands: 91
# 84. (2, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 102, 96
# 85. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 103, 104
# 86. /
#     core type: Literal
#     sub-expressions:
# 87. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 103, 102
# 88. *
#     core type: Literal
#     sub-expressions:
# 89. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 102, 92, 93, 94, 95
# 90. +
#     core type: Literal
#     sub-expressions:
# 91. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 96, 97
# 92. pi
#     core type: Literal
#     sub-expressions:
# 93. i
#     core type: Literal
#     sub-expressions:
# 94. phase
#     core type: Literal
#     sub-expressions:
# 95. k
#     core type: Variable
#     sub-expressions:
# 96. 2^{t}
#     core type: Operation
#     operator: 98
#     operands: 99
# 97. -1
#     core type: Operation
#     operator: 100
#     operand: 104
# 98. Exp
#     core type: Literal
#     sub-expressions:
# 99. (2, t)
#     core type: ExprTuple
#     sub-expressions: 102, 103
# 100. -
#      core type: Literal
#      sub-expressions:
# 101. (1)
#      core type: ExprTuple
#      sub-expressions: 104
# 102. 2
#      core type: Literal
#      sub-expressions:
# 103. t
#      core type: Variable
#      sub-expressions:
# 104. 1
#      core type: Literal
#      sub-expressions:
