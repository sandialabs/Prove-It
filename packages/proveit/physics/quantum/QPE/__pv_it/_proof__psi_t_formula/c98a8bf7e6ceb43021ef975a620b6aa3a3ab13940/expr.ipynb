# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecSum
from proveit.numbers import Exp, Interval, Mult, e, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket0
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = NumKet(k, t)
sub_expr3 = Exp(e, Mult(two, pi, i, _phase, k))
sub_expr4 = Interval(zero, subtract(two_pow_t, one))
expr = ExprTuple(VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, TensorProd(ket0, sub_expr2)), domain = sub_expr4), TensorProd(ket0, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, sub_expr2), domain = sub_expr4)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \left(\lvert 0 \rangle {\otimes} \lvert k \rangle_{t}\right)\right), \lvert 0 \rangle {\otimes} \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (|0〉 otimes |k〉_{t})), |0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (|0〉 otimes |k〉_{t}))
#    core type: Operation
#    operator: 8
#    operand: 5
# 2. |0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#    core type: Operation
#    operator: 18
#    operands: 4
# 3. (k -> {e^{2 * pi * i * phase * k} * (|0〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (|0〉, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#    core type: ExprTuple
#    sub-expressions: 24, 6
# 5. k -> {e^{2 * pi * i * phase * k} * (|0〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 46
#    body: 7
# 6. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#    core type: Operation
# ...
