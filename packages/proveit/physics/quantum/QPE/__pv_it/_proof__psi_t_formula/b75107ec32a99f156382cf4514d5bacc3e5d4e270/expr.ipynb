# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd, VecSum
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Interval, Mult, e, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Exp(e, Mult(two, pi, i, _phase, k))
sub_expr3 = VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr2, NumKet(k, t)), domain = Interval(zero, subtract(two_pow_t, one)))
expr = Equals(VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr2, NumKet(k, Add(t, one))), domain = Interval(zero, subtract(Mult(two, two_pow_t), one))), VecAdd(TensorProd(ket0, sub_expr3), ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), TensorProd(ket1, sub_expr3))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\sum_{k=0}^{\left(2 \cdot 2^{t}\right) - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right)\right) = \left(\left(\lvert 0 \rangle {\otimes} \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right) + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \left(\lvert 1 \rangle {\otimes} \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})) = ((|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}), (|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#    core type: Operation
#    operator: 34
#    operand: 8
# 4. (|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) + (e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (|0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#    core type: Lambda
#    parameter: 70
#    body: 11
# 9. |0〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#    core type: Operation
#    operator: 23
#    operands: 12
# 10. e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: Operation
#     operator: 47
#     operands: 13
# 11. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. (2 * 2^{t}) - 1}.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. (|0〉, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 16, 29
# 13. (e^{2 * pi * i * phase * 2^{t}}, |1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 47
#     operands: 19
# 15. k in {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 49
#     operands: 20
# 16. |0〉
#     core type: Operation
#     operator: 33
#     operand: 61
# 17. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 73
#     operands: 22
# 18. |1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 51, 25
# 20. (k, {0 .. (2 * 2^{t}) - 1})
#     core type: ExprTuple
#     sub-expressions: 70, 26
# 21. (0)
#     core type: ExprTuple
#     sub-expressions: 61
# 22. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 59, 27
# 23. otimes
#     core type: Literal
#     sub-expressions:
# 24. (|1〉, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. |k〉_{t + 1}
#     core type: Operation
#     operator: 55
#     operands: 30
# 26. {0 .. (2 * 2^{t}) - 1}
#     core type: Operation
#     operator: 57
#     operands: 31
# 27. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 63
#     operands: 32
# 28. |1〉
#     core type: Operation
#     operator: 33
#     operand: 79
# 29. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 34
#     operand: 38
# 30. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 70, 36
# 31. (0, (2 * 2^{t}) - 1)
#     core type: ExprTuple
#     sub-expressions: 61, 37
# 32. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 77, 67, 68, 69, 71
# 33. KET
#     core type: Literal
#     sub-expressions:
# 34. Sum
#     core type: Literal
#     sub-expressions:
# 35. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 38
# 36. t + 1
#     core type: Operation
#     operator: 65
#     operands: 39
# 37. (2 * 2^{t}) - 1
#     core type: Operation
#     operator: 65
#     operands: 40
# 38. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 70
#     body: 42
# 39. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 40. (2 * 2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 43, 72
# 41. (k)
#     core type: ExprTuple
#     sub-expressions: 70
# 42. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 44
#     condition: 45
# 43. 2 * 2^{t}
#     core type: Operation
#     operator: 63
#     operands: 46
# 44. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 47
#     operands: 48
# 45. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. (2, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 77, 71
# 47. *
#     core type: Literal
#     sub-expressions:
# 48. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 70, 53
# 51. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 73
#     operands: 54
# 52. |k〉_{t}
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 55. NUM_KET
#     core type: Literal
#     sub-expressions:
# 56. (k, t)
#     core type: ExprTuple
#     sub-expressions: 70, 78
# 57. Interval
#     core type: Literal
#     sub-expressions:
# 58. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 59. e
#     core type: Literal
#     sub-expressions:
# 60. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 63
#     operands: 64
# 61. 0
#     core type: Literal
#     sub-expressions:
# 62. 2^{t} - 1
#     core type: Operation
#     operator: 65
#     operands: 66
# 63. *
#     core type: Literal
#     sub-expressions:
# 64. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 77, 67, 68, 69, 70
# 65. +
#     core type: Literal
#     sub-expressions:
# 66. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 67. pi
#     core type: Literal
#     sub-expressions:
# 68. i
#     core type: Literal
#     sub-expressions:
# 69. phase
#     core type: Literal
#     sub-expressions:
# 70. k
#     core type: Variable
#     sub-expressions:
# 71. 2^{t}
#     core type: Operation
#     operator: 73
#     operands: 74
# 72. -1
#     core type: Operation
#     operator: 75
#     operand: 79
# 73. Exp
#     core type: Literal
#     sub-expressions:
# 74. (2, t)
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 75. -
#     core type: Literal
#     sub-expressions:
# 76. (1)
#     core type: ExprTuple
#     sub-expressions: 79
# 77. 2
#     core type: Literal
#     sub-expressions:
# 78. t
#     core type: Variable
#     sub-expressions:
# 79. 1
#     core type: Literal
#     sub-expressions:
