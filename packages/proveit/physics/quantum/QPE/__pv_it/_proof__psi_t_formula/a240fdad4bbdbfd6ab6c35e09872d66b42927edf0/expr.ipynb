# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.linear_algebra.ScalarMult.html">ScalarMult</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Variable, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd
from proveit.numbers import Add, Exp, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = frac(one, sqrt(two))
expr = ScalarMult(sub_expr2, TensorProd(VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, two_pow_t, _phase)), ket1)), ExprRange(sub_expr1, ScalarMult(sub_expr2, VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))), Add(Neg(t), one), zero).with_decreasing_order()))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \frac{1}{\sqrt{2}} \cdot \left(\left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right){\otimes} \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \ldots {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (1 / sqrt(2)) * ((|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: Operation
#    operator: 32
#    operands: 1
# 1. (1 / sqrt(2), (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 18, 2
# 2. (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. otimes
#    core type: Literal
#    sub-expressions:
# 4. (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉),((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. |0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉)
#    core type: Operation
#    operator: 23
#    operands: 7
# 6. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 36
# 7. (|0〉, e^{2 * pi * i * 2^{t} * phase} * |1〉)
#    core type: ExprTuple
#    sub-expressions: 27, 10
# 8. _a -> ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))
#    core type: Lambda
#    parameter: 61
#    body: 11
# 9. -t + 1
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. e^{2 * pi * i * 2^{t} * phase} * |1〉
#     core type: Operation
#     operator: 32
#     operands: 14
# 11. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 32
#     operands: 15
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 48
# 14. (e^{2 * pi * i * 2^{t} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 17, 38
# 15. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. -t
#     core type: Operation
#     operator: 59
#     operand: 45
# 17. e^{2 * pi * i * 2^{t} * phase}
#     core type: Operation
#     operator: 55
#     operands: 21
# 18. 1 / sqrt(2)
#     core type: Operation
#     operator: 40
#     operands: 22
# 19. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. (t)
#     core type: ExprTuple
#     sub-expressions: 45
# 21. (e, 2 * pi * i * 2^{t} * phase)
#     core type: ExprTuple
#     sub-expressions: 46, 25
# 22. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 48, 26
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. 2 * pi * i * 2^{t} * phase
#     core type: Operation
#     operator: 49
#     operands: 29
# 26. sqrt(2)
#     core type: Operation
#     operator: 55
#     operands: 30
# 27. |0〉
#     core type: Operation
#     operator: 43
#     operand: 36
# 28. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. (2, pi, i, 2^{t}, phase)
#     core type: ExprTuple
#     sub-expressions: 57, 51, 52, 34, 54
# 30. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 57, 35
# 31. (0)
#     core type: ExprTuple
#     sub-expressions: 36
# 32. *
#     core type: Literal
#     sub-expressions:
# 33. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. 2^{t}
#     core type: Operation
#     operator: 55
#     operands: 39
# 35. 1 / 2
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. 0
#     core type: Literal
#     sub-expressions:
# 37. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 55
#     operands: 42
# 38. |1〉
#     core type: Operation
#     operator: 43
#     operand: 48
# 39. (2, t)
#     core type: ExprTuple
#     sub-expressions: 57, 45
# 40. /
#     core type: Literal
#     sub-expressions:
# 41. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 48, 57
# 42. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. KET
#     core type: Literal
#     sub-expressions:
# 44. (1)
#     core type: ExprTuple
#     sub-expressions: 48
# 45. t
#     core type: Variable
#     sub-expressions:
# 46. e
#     core type: Literal
#     sub-expressions:
# 47. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 49
#     operands: 50
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. *
#     core type: Literal
#     sub-expressions:
# 50. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 57, 51, 52, 53, 54
# 51. pi
#     core type: Literal
#     sub-expressions:
# 52. i
#     core type: Literal
#     sub-expressions:
# 53. 2^{-_a}
#     core type: Operation
#     operator: 55
#     operands: 56
# 54. phase
#     core type: Literal
#     sub-expressions:
# 55. Exp
#     core type: Literal
#     sub-expressions:
# 56. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 57. 2
#     core type: Literal
#     sub-expressions:
# 58. -_a
#     core type: Operation
#     operator: 59
#     operand: 61
# 59. -
#     core type: Literal
#     sub-expressions:
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. _a
#     core type: Variable
#     sub-expressions:
