# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecSum
from proveit.numbers import Add, Exp, Interval, Mult, e, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Exp(e, Mult(two, pi, i, _phase, k))
sub_expr3 = Interval(zero, subtract(two_pow_t, one))
expr = ExprTuple(VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr2, NumKet(k, Add(t, one))), domain = sub_expr3), ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), TensorProd(ket1, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr2, NumKet(k, t)), domain = sub_expr3))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t + 1}\right), \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \left(\lvert 1 \rangle {\otimes} \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}), e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})
#    core type: Operation
#    operator: 19
#    operand: 5
# 2. e^{2 * pi * i * phase * 2^{t}} * (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: Operation
#    operator: 30
#    operands: 4
# 3. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (e^{2 * pi * i * phase * 2^{t}}, |1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. k -> {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 53
#    body: 8
# 6. e^{2 * pi * i * phase * 2^{t}}
#    core type: Operation
#    operator: 56
#    operands: 9
# 7. |1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. {e^{2 * pi * i * phase * k} * |k〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 12
#    condition: 28
# 9. (e, 2 * pi * i * phase * 2^{t})
#    core type: ExprTuple
#    sub-expressions: 42, 13
# 10. otimes
#     core type: Literal
#     sub-expressions:
# 11. (|1〉, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. e^{2 * pi * i * phase * k} * |k〉_{t + 1}
#     core type: Operation
#     operator: 30
#     operands: 16
# 13. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 46
#     operands: 17
# 14. |1〉
#     core type: Operation
#     operator: 18
#     operand: 62
# 15. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 19
#     operand: 22
# 16. (e^{2 * pi * i * phase * k}, |k〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 34, 21
# 17. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 60, 50, 51, 52, 54
# 18. KET
#     core type: Literal
#     sub-expressions:
# 19. Sum
#     core type: Literal
#     sub-expressions:
# 20. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 22
# 21. |k〉_{t + 1}
#     core type: Operation
#     operator: 38
#     operands: 23
# 22. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 53
#     body: 25
# 23. (k, t + 1)
#     core type: ExprTuple
#     sub-expressions: 53, 26
# 24. (k)
#     core type: ExprTuple
#     sub-expressions: 53
# 25. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 27
#     condition: 28
# 26. t + 1
#     core type: Operation
#     operator: 48
#     operands: 29
# 27. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 30. *
#     core type: Literal
#     sub-expressions:
# 31. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 53, 36
# 34. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 56
#     operands: 37
# 35. |k〉_{t}
#     core type: Operation
#     operator: 38
#     operands: 39
# 36. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 38. NUM_KET
#     core type: Literal
#     sub-expressions:
# 39. (k, t)
#     core type: ExprTuple
#     sub-expressions: 53, 61
# 40. Interval
#     core type: Literal
#     sub-expressions:
# 41. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. e
#     core type: Literal
#     sub-expressions:
# 43. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 46
#     operands: 47
# 44. 0
#     core type: Literal
#     sub-expressions:
# 45. 2^{t} - 1
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. *
#     core type: Literal
#     sub-expressions:
# 47. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 60, 50, 51, 52, 53
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 50. pi
#     core type: Literal
#     sub-expressions:
# 51. i
#     core type: Literal
#     sub-expressions:
# 52. phase
#     core type: Literal
#     sub-expressions:
# 53. k
#     core type: Variable
#     sub-expressions:
# 54. 2^{t}
#     core type: Operation
#     operator: 56
#     operands: 57
# 55. -1
#     core type: Operation
#     operator: 58
#     operand: 62
# 56. Exp
#     core type: Literal
#     sub-expressions:
# 57. (2, t)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 58. -
#     core type: Literal
#     sub-expressions:
# 59. (1)
#     core type: ExprTuple
#     sub-expressions: 62
# 60. 2
#     core type: Literal
#     sub-expressions:
# 61. t
#     core type: Variable
#     sub-expressions:
# 62. 1
#     core type: Literal
#     sub-expressions:
