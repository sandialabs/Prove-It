# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Variable, t
from proveit.core_expr_types import Len
from proveit.linear_algebra import ScalarMult, VecAdd
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = frac(one, sqrt(two))
expr = Equals(Len(operands = [ScalarMult(sub_expr2, VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, two_pow_t, _phase)), ket1))), ExprRange(sub_expr1, ScalarMult(sub_expr2, VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))), Add(Neg(t), one), zero)]), Add(one, t)).with_wrapping_at(1)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} |\left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right),\left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-\left(-t + 1\right)} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right), \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-\left(-t + 2\right)} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right), \ldots, \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{-0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right)\right)| \\  = \left(1 + t\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (1)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. |((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉)),((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))))| \\  = (1 + t)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉)),((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))))|, 1 + t)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉)),((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))))|
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. 1 + t
#    core type: Operation
#    operator: 15
#    operands: 7
# 5. length
#    core type: Literal
#    sub-expressions:
# 6. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉)),((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (1, t)
#    core type: ExprTuple
#    sub-expressions: 51, 55
# 8. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))
#    core type: Operation
#    operator: 35
#    operands: 10
# 9. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉)))
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 12
#    end_index: 39
# 10. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 21, 13
# 11. _a -> ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))
#     core type: Lambda
#     parameter: 66
#     body: 14
# 12. -t + 1
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. |0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉)
#     core type: Operation
#     operator: 26
#     operands: 17
# 14. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 35
#     operands: 18
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 19, 51
# 17. (|0〉, e^{2 * pi * i * 2^{t} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 30, 20
# 18. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. -t
#     core type: Operation
#     operator: 64
#     operand: 55
# 20. e^{2 * pi * i * 2^{t} * phase} * |1〉
#     core type: Operation
#     operator: 35
#     operands: 24
# 21. 1 / sqrt(2)
#     core type: Operation
#     operator: 43
#     operands: 25
# 22. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. (t)
#     core type: ExprTuple
#     sub-expressions: 55
# 24. (e^{2 * pi * i * 2^{t} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 28, 41
# 25. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 51, 29
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. e^{2 * pi * i * 2^{t} * phase}
#     core type: Operation
#     operator: 60
#     operands: 32
# 29. sqrt(2)
#     core type: Operation
#     operator: 60
#     operands: 33
# 30. |0〉
#     core type: Operation
#     operator: 46
#     operand: 39
# 31. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. (e, 2 * pi * i * 2^{t} * phase)
#     core type: ExprTuple
#     sub-expressions: 49, 37
# 33. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 62, 38
# 34. (0)
#     core type: ExprTuple
#     sub-expressions: 39
# 35. *
#     core type: Literal
#     sub-expressions:
# 36. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 37. 2 * pi * i * 2^{t} * phase
#     core type: Operation
#     operator: 53
#     operands: 42
# 38. 1 / 2
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. 0
#     core type: Literal
#     sub-expressions:
# 40. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 60
#     operands: 45
# 41. |1〉
#     core type: Operation
#     operator: 46
#     operand: 51
# 42. (2, pi, i, 2^{t}, phase)
#     core type: ExprTuple
#     sub-expressions: 62, 56, 57, 48, 59
# 43. /
#     core type: Literal
#     sub-expressions:
# 44. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 51, 62
# 45. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 46. KET
#     core type: Literal
#     sub-expressions:
# 47. (1)
#     core type: ExprTuple
#     sub-expressions: 51
# 48. 2^{t}
#     core type: Operation
#     operator: 60
#     operands: 52
# 49. e
#     core type: Literal
#     sub-expressions:
# 50. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. (2, t)
#     core type: ExprTuple
#     sub-expressions: 62, 55
# 53. *
#     core type: Literal
#     sub-expressions:
# 54. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 62, 56, 57, 58, 59
# 55. t
#     core type: Variable
#     sub-expressions:
# 56. pi
#     core type: Literal
#     sub-expressions:
# 57. i
#     core type: Literal
#     sub-expressions:
# 58. 2^{-_a}
#     core type: Operation
#     operator: 60
#     operands: 61
# 59. phase
#     core type: Literal
#     sub-expressions:
# 60. Exp
#     core type: Literal
#     sub-expressions:
# 61. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 62. 2
#     core type: Literal
#     sub-expressions:
# 63. -_a
#     core type: Operation
#     operator: 64
#     operand: 66
# 64. -
#     core type: Literal
#     sub-expressions:
# 65. (_a)
#     core type: ExprTuple
#     sub-expressions: 66
# 66. _a
#     core type: Variable
#     sub-expressions:
