# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, k, t
from proveit.linear_algebra import ScalarMult, TensorProd
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Exp, Interval, Mult, e, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(k, two_pow_t)
sub_expr2 = Interval(zero, subtract(two_pow_t, one))
sub_expr3 = InSet(k, sub_expr2)
sub_expr4 = ScalarMult(Exp(e, Mult(two, pi, i, _phase, sub_expr1)), NumKet(sub_expr1, Add(t, one)))
sub_expr5 = ScalarMult(Mult(Exp(e, Mult(two, pi, i, _phase, k)), Exp(e, Mult(two, pi, i, _phase, two_pow_t))), TensorProd(ket1, NumKet(k, t)))
expr = ExprTuple(Forall(instance_param_or_params = [k], instance_expr = Equals(sub_expr4, sub_expr5), domain = sub_expr2), Equals(Lambda(k, Conditional(sub_expr4, sub_expr3)), Lambda(k, Conditional(sub_expr5, sub_expr3))).with_wrapping_at(2))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\forall_{k \in \{0~\ldotp \ldotp~2^{t} - 1\}}~\left(\left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot \left(k + 2^{t}\right)} \cdot \lvert k + 2^{t} \rangle_{t + 1}\right) = \left(\left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}}\right) \cdot \left(\lvert 1 \rangle {\otimes} \lvert k \rangle_{t}\right)\right)\right), \begin{array}{c} \begin{array}{l} \left[k \mapsto \left\{\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot \left(k + 2^{t}\right)} \cdot \lvert k + 2^{t} \rangle_{t + 1} \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..\right] =  \\ \left[k \mapsto \left\{\left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}}\right) \cdot \left(\lvert 1 \rangle {\otimes} \lvert k \rangle_{t}\right) \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..\right] \end{array} \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1}) = ((e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t}))), [k -> {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1}) = ((e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t})))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. [k -> {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.]
#    core type: Operation
#    operator: 15
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (k -> {(e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1}) = ((e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t})) if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (k -> {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}., k -> {(e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. k -> {(e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1}) = ((e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t})) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 65
#    body: 9
# 7. k -> {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 65
#    body: 10
# 8. k -> {(e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 65
#    body: 12
# 9. {(e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1}) = ((e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t})) if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. {e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 19
#     condition: 14
# 11. (k)
#     core type: ExprTuple
#     sub-expressions: 65
# 12. {(e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 20
#     condition: 14
# 13. (e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1}) = ((e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t}))
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1}, (e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 65, 21
# 19. e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1}
#     core type: Operation
#     operator: 23
#     operands: 22
# 20. (e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}) * (|1〉 otimes |k〉_{t})
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. (e^{2 * pi * i * phase * (k + 2^{t})}, |k + 2^{t}〉_{t + 1})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 23. *
#     core type: Literal
#     sub-expressions:
# 24. (e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}, |1〉 otimes |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 27. e^{2 * pi * i * phase * (k + 2^{t})}
#     core type: Operation
#     operator: 70
#     operands: 33
# 28. |k + 2^{t}〉_{t + 1}
#     core type: Operation
#     operator: 51
#     operands: 34
# 29. e^{2 * pi * i * phase * k} * e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 63
#     operands: 35
# 30. |1〉 otimes |k〉_{t}
#     core type: Operation
#     operator: 36
#     operands: 37
# 31. 0
#     core type: Literal
#     sub-expressions:
# 32. 2^{t} - 1
#     core type: Operation
#     operator: 60
#     operands: 38
# 33. (e, 2 * pi * i * phase * (k + 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 57, 39
# 34. (k + 2^{t}, t + 1)
#     core type: ExprTuple
#     sub-expressions: 55, 40
# 35. (e^{2 * pi * i * phase * k}, e^{2 * pi * i * phase * 2^{t}})
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 36. otimes
#     core type: Literal
#     sub-expressions:
# 37. (|1〉, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 38. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 69, 45
# 39. 2 * pi * i * phase * (k + 2^{t})
#     core type: Operation
#     operator: 63
#     operands: 46
# 40. t + 1
#     core type: Operation
#     operator: 60
#     operands: 47
# 41. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 70
#     operands: 48
# 42. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 70
#     operands: 49
# 43. |1〉
#     core type: Operation
#     operator: 50
#     operand: 59
# 44. |k〉_{t}
#     core type: Operation
#     operator: 51
#     operands: 52
# 45. -1
#     core type: Operation
#     operator: 53
#     operand: 59
# 46. (2, pi, i, phase, k + 2^{t})
#     core type: ExprTuple
#     sub-expressions: 72, 66, 67, 68, 55
# 47. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 73, 59
# 48. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 57, 56
# 49. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 50. KET
#     core type: Literal
#     sub-expressions:
# 51. NUM_KET
#     core type: Literal
#     sub-expressions:
# 52. (k, t)
#     core type: ExprTuple
#     sub-expressions: 65, 73
# 53. -
#     core type: Literal
#     sub-expressions:
# 54. (1)
#     core type: ExprTuple
#     sub-expressions: 59
# 55. k + 2^{t}
#     core type: Operation
#     operator: 60
#     operands: 61
# 56. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 63
#     operands: 62
# 57. e
#     core type: Literal
#     sub-expressions:
# 58. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 63
#     operands: 64
# 59. 1
#     core type: Literal
#     sub-expressions:
# 60. +
#     core type: Literal
#     sub-expressions:
# 61. (k, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 65, 69
# 62. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 72, 66, 67, 68, 65
# 63. *
#     core type: Literal
#     sub-expressions:
# 64. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 72, 66, 67, 68, 69
# 65. k
#     core type: Variable
#     sub-expressions:
# 66. pi
#     core type: Literal
#     sub-expressions:
# 67. i
#     core type: Literal
#     sub-expressions:
# 68. phase
#     core type: Literal
#     sub-expressions:
# 69. 2^{t}
#     core type: Operation
#     operator: 70
#     operands: 71
# 70. Exp
#     core type: Literal
#     sub-expressions:
# 71. (2, t)
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 72. 2
#     core type: Literal
#     sub-expressions:
# 73. t
#     core type: Variable
#     sub-expressions:
