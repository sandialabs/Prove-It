# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Variable, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Mult, Neg, e, frac, i, one, pi, sqrt, subtract, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = ScalarMult(frac(one, Exp(two, subtract(frac(Add(t, one), two), frac(t, two)))), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), ket1)))
sub_expr3 = ExprRange(sub_expr1, ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))), Add(Neg(t), one), zero).with_decreasing_order()
expr = Equals(TensorProd(sub_expr2, TensorProd(sub_expr3)), TensorProd(sub_expr2, sub_expr3)).with_wrapping_at(1)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left(\left(\frac{1}{2^{\frac{t + 1}{2} - \frac{t}{2}}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes} \left(\left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \ldots {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right)\right)\right) \\  = \left(\left(\frac{1}{2^{\frac{t + 1}{2} - \frac{t}{2}}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \lvert 1 \rangle\right)\right)\right){\otimes} \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \ldots {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right)\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (1)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))) \\  = (((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))), ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))) otimes (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: Operation
#    operator: 9
#    operands: 5
# 4. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)))otimes ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#    core type: Operation
#    operator: 9
#    operands: 6
# 5. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 8, 7
# 6. ((1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)),((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 8, 12
# 7. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (1 / 2^{((t + 1) / 2) - (t / 2)}) * (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))
#    core type: Operation
#    operator: 45
#    operands: 11
# 9. otimes
#    core type: Literal
#    sub-expressions:
# 10. (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (1 / 2^{((t + 1) / 2) - (t / 2)}, |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 51
# 13. 1 / 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 63
#     operands: 17
# 14. |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: Operation
#     operator: 33
#     operands: 18
# 15. _a -> ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))
#     core type: Lambda
#     parameter: 82
#     body: 19
# 16. -t + 1
#     core type: Operation
#     operator: 61
#     operands: 20
# 17. (1, 2^{((t + 1) / 2) - (t / 2)})
#     core type: ExprTuple
#     sub-expressions: 68, 21
# 18. (|0〉, e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 38, 22
# 19. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 45
#     operands: 23
# 20. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 24, 68
# 21. 2^{((t + 1) / 2) - (t / 2)}
#     core type: Operation
#     operator: 76
#     operands: 25
# 22. e^{2 * pi * i * phase * 2^{t}} * |1〉
#     core type: Operation
#     operator: 45
#     operands: 26
# 23. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. -t
#     core type: Operation
#     operator: 80
#     operand: 69
# 25. (2, ((t + 1) / 2) - (t / 2))
#     core type: ExprTuple
#     sub-expressions: 78, 30
# 26. (e^{2 * pi * i * phase * 2^{t}}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 31, 53
# 27. 1 / sqrt(2)
#     core type: Operation
#     operator: 63
#     operands: 32
# 28. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. (t)
#     core type: ExprTuple
#     sub-expressions: 69
# 30. ((t + 1) / 2) - (t / 2)
#     core type: Operation
#     operator: 61
#     operands: 35
# 31. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 76
#     operands: 36
# 32. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 68, 37
# 33. +
#     core type: Literal
#     sub-expressions:
# 34. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. ((t + 1) / 2, -(t / 2))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 36. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 66, 42
# 37. sqrt(2)
#     core type: Operation
#     operator: 76
#     operands: 43
# 38. |0〉
#     core type: Operation
#     operator: 59
#     operand: 51
# 39. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 45
#     operands: 46
# 40. (t + 1) / 2
#     core type: Operation
#     operator: 63
#     operands: 47
# 41. -(t / 2)
#     core type: Operation
#     operator: 80
#     operand: 55
# 42. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 70
#     operands: 49
# 43. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 78, 50
# 44. (0)
#     core type: ExprTuple
#     sub-expressions: 51
# 45. *
#     core type: Literal
#     sub-expressions:
# 46. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 47. (t + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 54, 78
# 48. (t / 2)
#     core type: ExprTuple
#     sub-expressions: 55
# 49. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 78, 72, 73, 75, 56
# 50. 1 / 2
#     core type: Operation
#     operator: 63
#     operands: 57
# 51. 0
#     core type: Literal
#     sub-expressions:
# 52. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 76
#     operands: 58
# 53. |1〉
#     core type: Operation
#     operator: 59
#     operand: 68
# 54. t + 1
#     core type: Operation
#     operator: 61
#     operands: 62
# 55. t / 2
#     core type: Operation
#     operator: 63
#     operands: 64
# 56. 2^{t}
#     core type: Operation
#     operator: 76
#     operands: 65
# 57. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 68, 78
# 58. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 59. KET
#     core type: Literal
#     sub-expressions:
# 60. (1)
#     core type: ExprTuple
#     sub-expressions: 68
# 61. +
#     core type: Literal
#     sub-expressions:
# 62. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 69, 68
# 63. /
#     core type: Literal
#     sub-expressions:
# 64. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 69, 78
# 65. (2, t)
#     core type: ExprTuple
#     sub-expressions: 78, 69
# 66. e
#     core type: Literal
#     sub-expressions:
# 67. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 70
#     operands: 71
# 68. 1
#     core type: Literal
#     sub-expressions:
# 69. t
#     core type: Variable
#     sub-expressions:
# 70. *
#     core type: Literal
#     sub-expressions:
# 71. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 78, 72, 73, 74, 75
# 72. pi
#     core type: Literal
#     sub-expressions:
# 73. i
#     core type: Literal
#     sub-expressions:
# 74. 2^{-_a}
#     core type: Operation
#     operator: 76
#     operands: 77
# 75. phase
#     core type: Literal
#     sub-expressions:
# 76. Exp
#     core type: Literal
#     sub-expressions:
# 77. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 78. 2
#     core type: Literal
#     sub-expressions:
# 79. -_a
#     core type: Operation
#     operator: 80
#     operand: 82
# 80. -
#     core type: Literal
#     sub-expressions:
# 81. (_a)
#     core type: ExprTuple
#     sub-expressions: 82
# 82. _a
#     core type: Variable
#     sub-expressions:
