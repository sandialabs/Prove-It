# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd, VecSum
from proveit.logic import CartExp, InSet
from proveit.numbers import Complex, Exp, Interval, Mult, e, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, QubitSpace, ket0, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
expr = InSet(TensorProd(VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, _phase, two_pow_t)), ket1)), VecSum(index_or_indices = [k], summand = ScalarMult(Exp(e, Mult(two, pi, i, _phase, k)), NumKet(k, t)), domain = Interval(zero, subtract(two_pow_t, one)))), TensorProd(QubitSpace, CartExp(Complex, two_pow_t)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{t}} \cdot \lvert 1 \rangle\right)\right) {\otimes} \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right) \in \left(\mathbb{C}^{2} {\otimes} \mathbb{C}^{2^{t}}\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)) otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in (Complex^{2} otimes Complex^{2^{t}})
#    core type: Operation
#    operator: 34
#    operands: 1
# 1. ((|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)) otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), Complex^{2} otimes Complex^{2^{t}})
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)) otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. Complex^{2} otimes Complex^{2^{t}}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (|0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉), Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. otimes
#    core type: Literal
#    sub-expressions:
# 6. (Complex^{2}, Complex^{2^{t}})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. |0〉 + (e^{2 * pi * i * phase * 2^{t}} * |1〉)
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#    core type: Operation
#    operator: 13
#    operand: 20
# 9. Complex^{2}
#    core type: Operation
#    operator: 16
#    operands: 15
# 10. Complex^{2^{t}}
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (|0〉, e^{2 * pi * i * phase * 2^{t}} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 13. Sum
#     core type: Literal
#     sub-expressions:
# 14. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 20
# 15. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 21, 64
# 16. CartExp
#     core type: Literal
#     sub-expressions:
# 17. (Complex, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 21, 58
# 18. |0〉
#     core type: Operation
#     operator: 31
#     operand: 48
# 19. e^{2 * pi * i * phase * 2^{t}} * |1〉
#     core type: Operation
#     operator: 32
#     operands: 23
# 20. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 57
#     body: 25
# 21. Complex
#     core type: Literal
#     sub-expressions:
# 22. (0)
#     core type: ExprTuple
#     sub-expressions: 48
# 23. (e^{2 * pi * i * phase * 2^{t}}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. (k)
#     core type: ExprTuple
#     sub-expressions: 57
# 25. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 28
#     condition: 29
# 26. e^{2 * pi * i * phase * 2^{t}}
#     core type: Operation
#     operator: 60
#     operands: 30
# 27. |1〉
#     core type: Operation
#     operator: 31
#     operand: 66
# 28. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. (e, 2 * pi * i * phase * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 46, 36
# 31. KET
#     core type: Literal
#     sub-expressions:
# 32. *
#     core type: Literal
#     sub-expressions:
# 33. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 57, 39
# 36. 2 * pi * i * phase * 2^{t}
#     core type: Operation
#     operator: 50
#     operands: 40
# 37. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 60
#     operands: 41
# 38. |k〉_{t}
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. (2, pi, i, phase, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 64, 54, 55, 56, 58
# 41. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 42. NUM_KET
#     core type: Literal
#     sub-expressions:
# 43. (k, t)
#     core type: ExprTuple
#     sub-expressions: 57, 65
# 44. Interval
#     core type: Literal
#     sub-expressions:
# 45. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 46. e
#     core type: Literal
#     sub-expressions:
# 47. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. 0
#     core type: Literal
#     sub-expressions:
# 49. 2^{t} - 1
#     core type: Operation
#     operator: 52
#     operands: 53
# 50. *
#     core type: Literal
#     sub-expressions:
# 51. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 64, 54, 55, 56, 57
# 52. +
#     core type: Literal
#     sub-expressions:
# 53. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 54. pi
#     core type: Literal
#     sub-expressions:
# 55. i
#     core type: Literal
#     sub-expressions:
# 56. phase
#     core type: Literal
#     sub-expressions:
# 57. k
#     core type: Variable
#     sub-expressions:
# 58. 2^{t}
#     core type: Operation
#     operator: 60
#     operands: 61
# 59. -1
#     core type: Operation
#     operator: 62
#     operand: 66
# 60. Exp
#     core type: Literal
#     sub-expressions:
# 61. (2, t)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 62. -
#     core type: Literal
#     sub-expressions:
# 63. (1)
#     core type: ExprTuple
#     sub-expressions: 66
# 64. 2
#     core type: Literal
#     sub-expressions:
# 65. t
#     core type: Variable
#     sub-expressions:
# 66. 1
#     core type: Literal
#     sub-expressions:
