# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecSum
from proveit.logic import CartExp, Equals, Forall, Implies, InSet
from proveit.numbers import Complex, Exp, Interval, Mult, e, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumKet, QubitSpace, ket1
from proveit.physics.quantum.QPE import _phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = NumKet(k, t)
sub_expr3 = Exp(e, Mult(two, pi, i, _phase, k))
sub_expr4 = ScalarMult(sub_expr3, sub_expr2)
sub_expr5 = Interval(zero, subtract(two_pow_t, one))
expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(TensorProd(ket1, sub_expr4), TensorProd(QubitSpace, CartExp(Complex, two_pow_t))), domain = sub_expr5), Equals(TensorProd(ket1, VecSum(index_or_indices = sub_expr1, summand = sub_expr4, domain = sub_expr5)), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(sub_expr3, TensorProd(ket1, sub_expr2)), domain = sub_expr5)).with_wrapping_at(1)).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left[\forall_{k \in \{0~\ldotp \ldotp~2^{t} - 1\}}~\left(\left(\lvert 1 \rangle {\otimes} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right) \in \left(\mathbb{C}^{2} {\otimes} \mathbb{C}^{2^{t}}\right)\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(\lvert 1 \rangle {\otimes} \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle_{t}\right)\right)\right) \\  = \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \left(\lvert 1 \rangle {\otimes} \lvert k \rangle_{t}\right)\right)\right) \end{array} \end{array}\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{k in {0 .. 2^{t} - 1}} ((|1〉 otimes (e^{2 * pi * i * phase * k} * |k〉_{t})) in (Complex^{2} otimes Complex^{2^{t}}))] =>  \\ ((|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) \\  = (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t}))))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{k in {0 .. 2^{t} - 1}} ((|1〉 otimes (e^{2 * pi * i * phase * k} * |k〉_{t})) in (Complex^{2} otimes Complex^{2^{t}})), (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) \\  = (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t}))))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{k in {0 .. 2^{t} - 1}} ((|1〉 otimes (e^{2 * pi * i * phase * k} * |k〉_{t})) in (Complex^{2} otimes Complex^{2^{t}}))
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) \\  = (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t})))
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (k -> {(|1〉 otimes (e^{2 * pi * i * phase * k} * |k〉_{t})) in (Complex^{2} otimes Complex^{2^{t}}) if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (|1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t})))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. k -> {(|1〉 otimes (e^{2 * pi * i * phase * k} * |k〉_{t})) in (Complex^{2} otimes Complex^{2^{t}}) if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 67
#    body: 12
# 10. |1〉 otimes (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: Operation
#     operator: 43
#     operands: 13
# 11. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t}))
#     core type: Operation
#     operator: 19
#     operand: 17
# 12. {(|1〉 otimes (e^{2 * pi * i * phase * k} * |k〉_{t})) in (Complex^{2} otimes Complex^{2^{t}}) if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 15
#     condition: 34
# 13. (|1〉, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
#     core type: ExprTuple
#     sub-expressions: 48, 16
# 14. (k -> {e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 17
# 15. (|1〉 otimes (e^{2 * pi * i * phase * k} * |k〉_{t})) in (Complex^{2} otimes Complex^{2^{t}})
#     core type: Operation
#     operator: 41
#     operands: 18
# 16. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 19
#     operand: 24
# 17. k -> {e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 67
#     body: 21
# 18. (|1〉 otimes (e^{2 * pi * i * phase * k} * |k〉_{t}), Complex^{2} otimes Complex^{2^{t}})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. Sum
#     core type: Literal
#     sub-expressions:
# 20. (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 24
# 21. {e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t}) if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 25
#     condition: 34
# 22. |1〉 otimes (e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: Operation
#     operator: 43
#     operands: 26
# 23. Complex^{2} otimes Complex^{2^{t}}
#     core type: Operation
#     operator: 43
#     operands: 27
# 24. k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 67
#     body: 29
# 25. e^{2 * pi * i * phase * k} * (|1〉 otimes |k〉_{t})
#     core type: Operation
#     operator: 39
#     operands: 30
# 26. (|1〉, e^{2 * pi * i * phase * k} * |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 48, 33
# 27. (Complex^{2}, Complex^{2^{t}})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. (k)
#     core type: ExprTuple
#     sub-expressions: 67
# 29. {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 33
#     condition: 34
# 30. (e^{2 * pi * i * phase * k}, |1〉 otimes |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 46, 35
# 31. Complex^{2}
#     core type: Operation
#     operator: 37
#     operands: 36
# 32. Complex^{2^{t}}
#     core type: Operation
#     operator: 37
#     operands: 38
# 33. e^{2 * pi * i * phase * k} * |k〉_{t}
#     core type: Operation
#     operator: 39
#     operands: 40
# 34. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 41
#     operands: 42
# 35. |1〉 otimes |k〉_{t}
#     core type: Operation
#     operator: 43
#     operands: 44
# 36. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 45, 74
# 37. CartExp
#     core type: Literal
#     sub-expressions:
# 38. (Complex, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 45, 68
# 39. *
#     core type: Literal
#     sub-expressions:
# 40. (e^{2 * pi * i * phase * k}, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 46, 49
# 41. in
#     core type: Literal
#     sub-expressions:
# 42. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 67, 47
# 43. otimes
#     core type: Literal
#     sub-expressions:
# 44. (|1〉, |k〉_{t})
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 45. Complex
#     core type: Literal
#     sub-expressions:
# 46. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 70
#     operands: 50
# 47. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 51
#     operands: 52
# 48. |1〉
#     core type: Operation
#     operator: 53
#     operand: 76
# 49. |k〉_{t}
#     core type: Operation
#     operator: 54
#     operands: 55
# 50. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 51. Interval
#     core type: Literal
#     sub-expressions:
# 52. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 53. KET
#     core type: Literal
#     sub-expressions:
# 54. NUM_KET
#     core type: Literal
#     sub-expressions:
# 55. (k, t)
#     core type: ExprTuple
#     sub-expressions: 67, 75
# 56. e
#     core type: Literal
#     sub-expressions:
# 57. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 60
#     operands: 61
# 58. 0
#     core type: Literal
#     sub-expressions:
# 59. 2^{t} - 1
#     core type: Operation
#     operator: 62
#     operands: 63
# 60. *
#     core type: Literal
#     sub-expressions:
# 61. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 74, 64, 65, 66, 67
# 62. +
#     core type: Literal
#     sub-expressions:
# 63. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 64. pi
#     core type: Literal
#     sub-expressions:
# 65. i
#     core type: Literal
#     sub-expressions:
# 66. phase
#     core type: Literal
#     sub-expressions:
# 67. k
#     core type: Variable
#     sub-expressions:
# 68. 2^{t}
#     core type: Operation
#     operator: 70
#     operands: 71
# 69. -1
#     core type: Operation
#     operator: 72
#     operand: 76
# 70. Exp
#     core type: Literal
#     sub-expressions:
# 71. (2, t)
#     core type: ExprTuple
#     sub-expressions: 74, 75
# 72. -
#     core type: Literal
#     sub-expressions:
# 73. (1)
#     core type: ExprTuple
#     sub-expressions: 76
# 74. 2
#     core type: Literal
#     sub-expressions:
# 75. t
#     core type: Variable
#     sub-expressions:
# 76. 1
#     core type: Literal
#     sub-expressions:
