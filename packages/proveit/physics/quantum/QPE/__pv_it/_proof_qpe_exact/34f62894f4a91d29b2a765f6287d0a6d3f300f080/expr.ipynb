# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, U, Variable
from proveit.core_expr_types import Len
from proveit.linear_algebra import MatrixMult, ScalarMult
from proveit.logic import Equals, InSet
from proveit.numbers import Exp, Interval, IntervalCO, Mult, Real, e, four, i, one, pi, subtract, two, zero
from proveit.physics.quantum import var_ket_u
from proveit.physics.quantum.QPE import phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Equals(Len(operands = [InSet(phase, Real), InSet(Mult(two_pow_t, phase), Interval(zero, subtract(two_pow_t, one))), Equals(MatrixMult(U, var_ket_u), ScalarMult(Exp(e, Mult(two, pi, i, phase)), var_ket_u)), InSet(phase, IntervalCO(zero, one))]), Len(operands = [ExprRange(sub_expr1, sub_expr1, one, four)]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# |\left(\varphi \in \mathbb{R}, \left(2^{t} \cdot \varphi\right) \in \{0~\ldotp \ldotp~2^{t} - 1\}, \left(U \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \cdot \lvert u \rangle\right), \varphi \in \left[0,1\right)\right)| = |\left(1, 2, \ldots, 4\right)|

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. |(phase in Real, (2^{t} * phase) in {0 .. 2^{t} - 1}, (U . |u>) = (e^{2 * pi * i * phase} * |u>), phase in [0,1))| = |(1, 2, ..., 4)|
#    core type: Operation
#    operator: 14
#    operands: 1
# 1. (|(phase in Real, (2^{t} * phase) in {0 .. 2^{t} - 1}, (U . |u>) = (e^{2 * pi * i * phase} * |u>), phase in [0,1))|, |(1, 2, ..., 4)|)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. |(phase in Real, (2^{t} * phase) in {0 .. 2^{t} - 1}, (U . |u>) = (e^{2 * pi * i * phase} * |u>), phase in [0,1))|
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. |(1, 2, ..., 4)|
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (phase in Real, (2^{t} * phase) in {0 .. 2^{t} - 1}, (U . |u>) = (e^{2 * pi * i * phase} * |u>), phase in [0,1))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 5. length
#    core type: Literal
#    sub-expressions:
# 6. (1, 2, ..., 4)
#    core type: ExprTuple
#    sub-expressions: 11
# 7. phase in Real
#    core type: Operation
#    operator: 16
#    operands: 12
# 8. (2^{t} * phase) in {0 .. 2^{t} - 1}
#    core type: Operation
#    operator: 16
#    operands: 13
# 9. (U . |u>) = (e^{2 * pi * i * phase} * |u>)
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. phase in [0,1)
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. 1, 2, ..., 4
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 56
#     end_index: 19
# 12. (phase, Real)
#     core type: ExprTuple
#     sub-expressions: 60, 20
# 13. (2^{t} * phase, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (U . |u>, e^{2 * pi * i * phase} * |u>)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (phase, [0,1))
#     core type: ExprTuple
#     sub-expressions: 60, 25
# 18. _a -> _a
#     core type: Lambda
#     parameter: 36
#     body: 36
# 19. 4
#     core type: Literal
#     sub-expressions:
# 20. Real
#     core type: Literal
#     sub-expressions:
# 21. 2^{t} * phase
#     core type: Operation
#     operator: 53
#     operands: 27
# 22. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 28
#     operands: 29
# 23. U . |u>
#     core type: Operation
#     operator: 30
#     operands: 31
# 24. e^{2 * pi * i * phase} * |u>
#     core type: Operation
#     operator: 32
#     operands: 33
# 25. [0,1)
#     core type: Operation
#     operator: 34
#     operands: 35
# 26. (_a)
#     core type: ExprTuple
#     sub-expressions: 36
# 27. (2^{t}, phase)
#     core type: ExprTuple
#     sub-expressions: 45, 60
# 28. Interval
#     core type: Literal
#     sub-expressions:
# 29. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 41, 37
# 30. .
#     core type: Literal
#     sub-expressions:
# 31. (U, |u>)
#     core type: ExprTuple
#     sub-expressions: 38, 40
# 32. *
#     core type: Literal
#     sub-expressions:
# 33. (e^{2 * pi * i * phase}, |u>)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 34. IntervalCO
#     core type: Literal
#     sub-expressions:
# 35. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 41, 56
# 36. _a
#     core type: Variable
#     sub-expressions:
# 37. 2^{t} - 1
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. U
#     core type: Variable
#     sub-expressions:
# 39. e^{2 * pi * i * phase}
#     core type: Operation
#     operator: 49
#     operands: 44
# 40. |u>
#     core type: Variable
#     sub-expressions:
# 41. 0
#     core type: Literal
#     sub-expressions:
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 44. (e, 2 * pi * i * phase)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 45. 2^{t}
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. -1
#     core type: Operation
#     operator: 51
#     operand: 56
# 47. e
#     core type: Literal
#     sub-expressions:
# 48. 2 * pi * i * phase
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. Exp
#     core type: Literal
#     sub-expressions:
# 50. (2, t)
#     core type: ExprTuple
#     sub-expressions: 57, 55
# 51. -
#     core type: Literal
#     sub-expressions:
# 52. (1)
#     core type: ExprTuple
#     sub-expressions: 56
# 53. *
#     core type: Literal
#     sub-expressions:
# 54. (2, pi, i, phase)
#     core type: ExprTuple
#     sub-expressions: 57, 58, 59, 60
# 55. t
#     core type: Variable
#     sub-expressions:
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. 2
#     core type: Literal
#     sub-expressions:
# 58. pi
#     core type: Literal
#     sub-expressions:
# 59. i
#     core type: Literal
#     sub-expressions:
# 60. phase
#     core type: Variable
#     sub-expressions:
