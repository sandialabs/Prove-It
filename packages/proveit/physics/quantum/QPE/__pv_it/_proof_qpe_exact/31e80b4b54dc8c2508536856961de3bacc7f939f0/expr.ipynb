# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, U, s, t
from proveit.linear_algebra import MatrixMult, ScalarMult, Unitary
from proveit.logic import And, Equals, InSet
from proveit.numbers import Exp, Interval, Mult, NaturalPos, Real, e, i, one, pi, subtract, two, zero
from proveit.physics.quantum import normalized_var_ket_u, var_ket_u
from proveit.physics.quantum.QPE import phase, s_ket_domain, two_pow_s, two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(s, NaturalPos), InSet(t, NaturalPos), InSet(U, Unitary(two_pow_s)), InSet(var_ket_u, s_ket_domain), normalized_var_ket_u, And(InSet(phase, Real), InSet(Mult(two_pow_t, phase), Interval(zero, subtract(two_pow_t, one))), Equals(MatrixMult(U, var_ket_u), ScalarMult(Exp(e, Mult(two, pi, i, phase)), var_ket_u))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(s \in \mathbb{N}^+, t \in \mathbb{N}^+, U \in \textrm{U}\left(2^{s}\right), \lvert u \rangle \in \mathbb{C}^{2^{s}}, \left \|\lvert u \rangle\right \| = 1, \left(\varphi \in \mathbb{R}\right) \land \left(\left(2^{t} \cdot \varphi\right) \in \{0~\ldotp \ldotp~2^{t} - 1\}\right) \land \left(\left(U \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \cdot \lvert u \rangle\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (s in NaturalPos, t in NaturalPos, U in U(2^{s}), |u> in Complex^{2^{s}}, |||u>|| = 1, (phase in Real) and ((2^{t} * phase) in {0 .. 2^{t} - 1}) and ((U . |u>) = (e^{2 * pi * i * phase} * |u>)))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5, 6
# 1. s in NaturalPos
#    core type: Operation
#    operator: 28
#    operands: 7
# 2. t in NaturalPos
#    core type: Operation
#    operator: 28
#    operands: 8
# 3. U in U(2^{s})
#    core type: Operation
#    operator: 28
#    operands: 9
# 4. |u> in Complex^{2^{s}}
#    core type: Operation
#    operator: 28
#    operands: 10
# 5. |||u>|| = 1
#    core type: Operation
#    operator: 30
#    operands: 11
# 6. (phase in Real) and ((2^{t} * phase) in {0 .. 2^{t} - 1}) and ((U . |u>) = (e^{2 * pi * i * phase} * |u>))
#    core type: Operation
#    operator: 12
#    operands: 13
# 7. (s, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 47, 14
# 8. (t, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 66, 14
# 9. (U, U(2^{s}))
#    core type: ExprTuple
#    sub-expressions: 50, 15
# 10. (|u>, Complex^{2^{s}})
#     core type: ExprTuple
#     sub-expressions: 52, 16
# 11. (|||u>||, 1)
#     core type: ExprTuple
#     sub-expressions: 17, 67
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (phase in Real, (2^{t} * phase) in {0 .. 2^{t} - 1}, (U . |u>) = (e^{2 * pi * i * phase} * |u>))
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20
# 14. NaturalPos
#     core type: Literal
#     sub-expressions:
# 15. U(2^{s})
#     core type: Operation
#     operator: 21
#     operand: 33
# 16. Complex^{2^{s}}
#     core type: Operation
#     operator: 23
#     operands: 24
# 17. |||u>||
#     core type: Operation
#     operator: 25
#     operand: 52
# 18. phase in Real
#     core type: Operation
#     operator: 28
#     operands: 27
# 19. (2^{t} * phase) in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 28
#     operands: 29
# 20. (U . |u>) = (e^{2 * pi * i * phase} * |u>)
#     core type: Operation
#     operator: 30
#     operands: 31
# 21. U
#     core type: Literal
#     sub-expressions:
# 22. (2^{s})
#     core type: ExprTuple
#     sub-expressions: 33
# 23. CartExp
#     core type: Literal
#     sub-expressions:
# 24. (Complex, 2^{s})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 25. Abs
#     core type: Literal
#     sub-expressions:
# 26. (|u>)
#     core type: ExprTuple
#     sub-expressions: 52
# 27. (phase, Real)
#     core type: ExprTuple
#     sub-expressions: 71, 34
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. (2^{t} * phase, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 30. =
#     core type: Literal
#     sub-expressions:
# 31. (U . |u>, e^{2 * pi * i * phase} * |u>)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 32. Complex
#     core type: Literal
#     sub-expressions:
# 33. 2^{s}
#     core type: Operation
#     operator: 60
#     operands: 39
# 34. Real
#     core type: Literal
#     sub-expressions:
# 35. 2^{t} * phase
#     core type: Operation
#     operator: 64
#     operands: 40
# 36. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. U . |u>
#     core type: Operation
#     operator: 43
#     operands: 44
# 38. e^{2 * pi * i * phase} * |u>
#     core type: Operation
#     operator: 45
#     operands: 46
# 39. (2, s)
#     core type: ExprTuple
#     sub-expressions: 68, 47
# 40. (2^{t}, phase)
#     core type: ExprTuple
#     sub-expressions: 56, 71
# 41. Interval
#     core type: Literal
#     sub-expressions:
# 42. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 43. .
#     core type: Literal
#     sub-expressions:
# 44. (U, |u>)
#     core type: ExprTuple
#     sub-expressions: 50, 52
# 45. *
#     core type: Literal
#     sub-expressions:
# 46. (e^{2 * pi * i * phase}, |u>)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 47. s
#     core type: Variable
#     sub-expressions:
# 48. 0
#     core type: Literal
#     sub-expressions:
# 49. 2^{t} - 1
#     core type: Operation
#     operator: 53
#     operands: 54
# 50. U
#     core type: Variable
#     sub-expressions:
# 51. e^{2 * pi * i * phase}
#     core type: Operation
#     operator: 60
#     operands: 55
# 52. |u>
#     core type: Variable
#     sub-expressions:
# 53. +
#     core type: Literal
#     sub-expressions:
# 54. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 55. (e, 2 * pi * i * phase)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. 2^{t}
#     core type: Operation
#     operator: 60
#     operands: 61
# 57. -1
#     core type: Operation
#     operator: 62
#     operand: 67
# 58. e
#     core type: Literal
#     sub-expressions:
# 59. 2 * pi * i * phase
#     core type: Operation
#     operator: 64
#     operands: 65
# 60. Exp
#     core type: Literal
#     sub-expressions:
# 61. (2, t)
#     core type: ExprTuple
#     sub-expressions: 68, 66
# 62. -
#     core type: Literal
#     sub-expressions:
# 63. (1)
#     core type: ExprTuple
#     sub-expressions: 67
# 64. *
#     core type: Literal
#     sub-expressions:
# 65. (2, pi, i, phase)
#     core type: ExprTuple
#     sub-expressions: 68, 69, 70, 71
# 66. t
#     core type: Variable
#     sub-expressions:
# 67. 1
#     core type: Literal
#     sub-expressions:
# 68. 2
#     core type: Literal
#     sub-expressions:
# 69. pi
#     core type: Literal
#     sub-expressions:
# 70. i
#     core type: Literal
#     sub-expressions:
# 71. phase
#     core type: Variable
#     sub-expressions:
