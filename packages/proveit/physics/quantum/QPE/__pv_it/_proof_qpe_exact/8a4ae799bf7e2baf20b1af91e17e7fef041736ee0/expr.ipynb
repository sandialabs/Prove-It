# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import U
from proveit.linear_algebra import MatrixMult, ScalarMult
from proveit.logic import And, Equals, Implies, InSet
from proveit.numbers import Exp, Interval, IntervalCO, Mult, Real, e, i, one, pi, subtract, two, zero
from proveit.physics.quantum import var_ket_u
from proveit.physics.quantum.QPE import phase, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = InSet(phase, Real)
sub_expr2 = InSet(Mult(two_pow_t, phase), Interval(zero, subtract(two_pow_t, one)))
sub_expr3 = Equals(MatrixMult(U, var_ket_u), ScalarMult(Exp(e, Mult(two, pi, i, phase)), var_ket_u))
expr = Implies(And(sub_expr1, sub_expr2, sub_expr3), And(sub_expr1, sub_expr2, sub_expr3, InSet(phase, IntervalCO(zero, one))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(\varphi \in \mathbb{R}\right) \land \left(\left(2^{t} \cdot \varphi\right) \in \{0~\ldotp \ldotp~2^{t} - 1\}\right) \land \left(\left(U \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \cdot \lvert u \rangle\right)\right)\right) \Rightarrow \left(\left(\varphi \in \mathbb{R}\right) \land \left(\left(2^{t} \cdot \varphi\right) \in \{0~\ldotp \ldotp~2^{t} - 1\}\right) \land \left(\left(U \thinspace \lvert u \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi} \cdot \lvert u \rangle\right)\right) \land \left(\varphi \in \left[0,1\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((phase in Real) and ((2^{t} * phase) in {0 .. 2^{t} - 1}) and ((U . |u>) = (e^{2 * pi * i * phase} * |u>))) => ((phase in Real) and ((2^{t} * phase) in {0 .. 2^{t} - 1}) and ((U . |u>) = (e^{2 * pi * i * phase} * |u>)) and (phase in [0,1)))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. ((phase in Real) and ((2^{t} * phase) in {0 .. 2^{t} - 1}) and ((U . |u>) = (e^{2 * pi * i * phase} * |u>)), (phase in Real) and ((2^{t} * phase) in {0 .. 2^{t} - 1}) and ((U . |u>) = (e^{2 * pi * i * phase} * |u>)) and (phase in [0,1)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (phase in Real) and ((2^{t} * phase) in {0 .. 2^{t} - 1}) and ((U . |u>) = (e^{2 * pi * i * phase} * |u>))
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (phase in Real) and ((2^{t} * phase) in {0 .. 2^{t} - 1}) and ((U . |u>) = (e^{2 * pi * i * phase} * |u>)) and (phase in [0,1))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (phase in Real, (2^{t} * phase) in {0 .. 2^{t} - 1}, (U . |u>) = (e^{2 * pi * i * phase} * |u>))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (phase in Real, (2^{t} * phase) in {0 .. 2^{t} - 1}, (U . |u>) = (e^{2 * pi * i * phase} * |u>), phase in [0,1))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 8. phase in Real
#    core type: Operation
#    operator: 16
#    operands: 12
# 9. (2^{t} * phase) in {0 .. 2^{t} - 1}
#    core type: Operation
#    operator: 16
#    operands: 13
# 10. (U . |u>) = (e^{2 * pi * i * phase} * |u>)
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. phase in [0,1)
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. (phase, Real)
#     core type: ExprTuple
#     sub-expressions: 56, 18
# 13. (2^{t} * phase, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (U . |u>, e^{2 * pi * i * phase} * |u>)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (phase, [0,1))
#     core type: ExprTuple
#     sub-expressions: 56, 23
# 18. Real
#     core type: Literal
#     sub-expressions:
# 19. 2^{t} * phase
#     core type: Operation
#     operator: 49
#     operands: 24
# 20. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. U . |u>
#     core type: Operation
#     operator: 27
#     operands: 28
# 22. e^{2 * pi * i * phase} * |u>
#     core type: Operation
#     operator: 29
#     operands: 30
# 23. [0,1)
#     core type: Operation
#     operator: 31
#     operands: 32
# 24. (2^{t}, phase)
#     core type: ExprTuple
#     sub-expressions: 41, 56
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 37, 33
# 27. .
#     core type: Literal
#     sub-expressions:
# 28. (U, |u>)
#     core type: ExprTuple
#     sub-expressions: 34, 36
# 29. *
#     core type: Literal
#     sub-expressions:
# 30. (e^{2 * pi * i * phase}, |u>)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 31. IntervalCO
#     core type: Literal
#     sub-expressions:
# 32. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 37, 52
# 33. 2^{t} - 1
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. U
#     core type: Variable
#     sub-expressions:
# 35. e^{2 * pi * i * phase}
#     core type: Operation
#     operator: 45
#     operands: 40
# 36. |u>
#     core type: Variable
#     sub-expressions:
# 37. 0
#     core type: Literal
#     sub-expressions:
# 38. +
#     core type: Literal
#     sub-expressions:
# 39. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 40. (e, 2 * pi * i * phase)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 41. 2^{t}
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. -1
#     core type: Operation
#     operator: 47
#     operand: 52
# 43. e
#     core type: Literal
#     sub-expressions:
# 44. 2 * pi * i * phase
#     core type: Operation
#     operator: 49
#     operands: 50
# 45. Exp
#     core type: Literal
#     sub-expressions:
# 46. (2, t)
#     core type: ExprTuple
#     sub-expressions: 53, 51
# 47. -
#     core type: Literal
#     sub-expressions:
# 48. (1)
#     core type: ExprTuple
#     sub-expressions: 52
# 49. *
#     core type: Literal
#     sub-expressions:
# 50. (2, pi, i, phase)
#     core type: ExprTuple
#     sub-expressions: 53, 54, 55, 56
# 51. t
#     core type: Variable
#     sub-expressions:
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. 2
#     core type: Literal
#     sub-expressions:
# 54. pi
#     core type: Literal
#     sub-expressions:
# 55. i
#     core type: Literal
#     sub-expressions:
# 56. phase
#     core type: Variable
#     sub-expressions:
