# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Function, U, Variable, s, t
from proveit.linear_algebra import Unitary
from proveit.logic import Forall
from proveit.numbers import NaturalPos
from proveit.physics.quantum import normalized_var_ket_u, var_ket_u
from proveit.physics.quantum.QPE import phase, s_ket_domain, two_pow_s

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [s, t], instance_expr = Forall(instance_param_or_params = [U], instance_expr = Forall(instance_param_or_params = [var_ket_u], instance_expr = Forall(instance_param_or_params = [phase], instance_expr = Function(Variable("_b", latex_format = r"{_{-}b}"), [s, t, U, var_ket_u, phase])), domain = s_ket_domain, condition = normalized_var_ket_u), domain = Unitary(two_pow_s)), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{s, t \in \mathbb{N}^+}~\left[\forall_{U \in \textrm{U}\left(2^{s}\right)}~\left[\forall_{\lvert u \rangle \in \mathbb{C}^{2^{s}}~|~\left \|\lvert u \rangle\right \| = 1}~\left[\forall_{\varphi}~{_{-}b}\left(s, t, U, \lvert u \rangle, \varphi\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{s, t in NaturalPos} [forall_{U in U(2^{s})} [forall_{|u> in Complex^{2^{s}} | |||u>|| = 1} [forall_{phase} _b(s, t, U, |u>, phase)]]]
#    core type: Operation
#    operator: 28
#    operand: 2
# 1. ((s, t) -> {forall_{U in U(2^{s})} [forall_{|u> in Complex^{2^{s}} | |||u>|| = 1} [forall_{phase} _b(s, t, U, |u>, phase)]] if s in NaturalPos ,  t in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (s, t) -> {forall_{U in U(2^{s})} [forall_{|u> in Complex^{2^{s}} | |||u>|| = 1} [forall_{phase} _b(s, t, U, |u>, phase)]] if s in NaturalPos ,  t in NaturalPos.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (s, t)
#    core type: ExprTuple
#    sub-expressions: 59, 46
# 4. {forall_{U in U(2^{s})} [forall_{|u> in Complex^{2^{s}} | |||u>|| = 1} [forall_{phase} _b(s, t, U, |u>, phase)]] if s in NaturalPos ,  t in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{U in U(2^{s})} [forall_{|u> in Complex^{2^{s}} | |||u>|| = 1} [forall_{phase} _b(s, t, U, |u>, phase)]]
#    core type: Operation
#    operator: 28
#    operand: 9
# 6. (s in NaturalPos) and (t in NaturalPos)
#    core type: Operation
#    operator: 30
#    operands: 8
# 7. (U -> {forall_{|u> in Complex^{2^{s}} | |||u>|| = 1} [forall_{phase} _b(s, t, U, |u>, phase)] if U in U(2^{s}).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (s in NaturalPos, t in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. U -> {forall_{|u> in Complex^{2^{s}} | |||u>|| = 1} [forall_{phase} _b(s, t, U, |u>, phase)] if U in U(2^{s}).
#    core type: Lambda
#    parameter: 47
#    body: 13
# 10. s in NaturalPos
#     core type: Operation
#     operator: 37
#     operands: 14
# 11. t in NaturalPos
#     core type: Operation
#     operator: 37
#     operands: 15
# 12. (U)
#     core type: ExprTuple
#     sub-expressions: 47
# 13. {forall_{|u> in Complex^{2^{s}} | |||u>|| = 1} [forall_{phase} _b(s, t, U, |u>, phase)] if U in U(2^{s}).
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. (s, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 59, 18
# 15. (t, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 46, 18
# 16. forall_{|u> in Complex^{2^{s}} | |||u>|| = 1} [forall_{phase} _b(s, t, U, |u>, phase)]
#     core type: Operation
#     operator: 28
#     operand: 21
# 17. U in U(2^{s})
#     core type: Operation
#     operator: 37
#     operands: 20
# 18. NaturalPos
#     core type: Literal
#     sub-expressions:
# 19. (|u> -> {forall_{phase} _b(s, t, U, |u>, phase) if |u> in Complex^{2^{s}} ,  |||u>|| = 1.)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. (U, U(2^{s}))
#     core type: ExprTuple
#     sub-expressions: 47, 22
# 21. |u> -> {forall_{phase} _b(s, t, U, |u>, phase) if |u> in Complex^{2^{s}} ,  |||u>|| = 1.
#     core type: Lambda
#     parameter: 55
#     body: 23
# 22. U(2^{s})
#     core type: Operation
#     operator: 24
#     operand: 54
# 23. {forall_{phase} _b(s, t, U, |u>, phase) if |u> in Complex^{2^{s}} ,  |||u>|| = 1.
#     core type: Conditional
#     value: 26
#     condition: 27
# 24. U
#     core type: Literal
#     sub-expressions:
# 25. (2^{s})
#     core type: ExprTuple
#     sub-expressions: 54
# 26. forall_{phase} _b(s, t, U, |u>, phase)
#     core type: Operation
#     operator: 28
#     operand: 32
# 27. (|u> in Complex^{2^{s}}) and (|||u>|| = 1)
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. forall
#     core type: Literal
#     sub-expressions:
# 29. (phase -> _b(s, t, U, |u>, phase))
#     core type: ExprTuple
#     sub-expressions: 32
# 30. and
#     core type: Literal
#     sub-expressions:
# 31. (|u> in Complex^{2^{s}}, |||u>|| = 1)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. phase -> _b(s, t, U, |u>, phase)
#     core type: Lambda
#     parameter: 48
#     body: 36
# 33. |u> in Complex^{2^{s}}
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. |||u>|| = 1
#     core type: Operation
#     operator: 39
#     operands: 40
# 35. (phase)
#     core type: ExprTuple
#     sub-expressions: 48
# 36. _b(s, t, U, |u>, phase)
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (|u>, Complex^{2^{s}})
#     core type: ExprTuple
#     sub-expressions: 55, 43
# 39. =
#     core type: Literal
#     sub-expressions:
# 40. (|||u>||, 1)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. _b
#     core type: Variable
#     sub-expressions:
# 42. (s, t, U, |u>, phase)
#     core type: ExprTuple
#     sub-expressions: 59, 46, 47, 55, 48
# 43. Complex^{2^{s}}
#     core type: Operation
#     operator: 49
#     operands: 50
# 44. |||u>||
#     core type: Operation
#     operator: 51
#     operand: 55
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. t
#     core type: Variable
#     sub-expressions:
# 47. U
#     core type: Variable
#     sub-expressions:
# 48. phase
#     core type: Variable
#     sub-expressions:
# 49. CartExp
#     core type: Literal
#     sub-expressions:
# 50. (Complex, 2^{s})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. Abs
#     core type: Literal
#     sub-expressions:
# 52. (|u>)
#     core type: ExprTuple
#     sub-expressions: 55
# 53. Complex
#     core type: Literal
#     sub-expressions:
# 54. 2^{s}
#     core type: Operation
#     operator: 56
#     operands: 57
# 55. |u>
#     core type: Variable
#     sub-expressions:
# 56. Exp
#     core type: Literal
#     sub-expressions:
# 57. (2, s)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 58. 2
#     core type: Literal
#     sub-expressions:
# 59. s
#     core type: Variable
#     sub-expressions:
