# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Literal
from proveit._common_ import l
from proveit.number import Exp, Neg, frac, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Literal("delta", latexFormat = r"\delta", context = "proveit.physics.quantum.QPE"), Neg(frac(l, Exp(two, Literal("t", context = "proveit.physics.quantum.QPE")))))
# Out:
# expr: (delta, -(l / 2^{t}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\delta, -\frac{l}{2^{t}}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (delta, -(l / 2^{t}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. delta
#    core type: Literal
#    sub-expressions:
# 2. -(l / 2^{t})
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. -
#    core type: Literal
#    sub-expressions:
# 4. l / 2^{t}
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. /
#    core type: Literal
#    sub-expressions:
# 6. (l, 2^{t})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. l
#    core type: Variable
#    sub-expressions:
# 8. 2^{t}
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. Exp
#    core type: Literal
#    sub-expressions:
# 10. (2, t)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. t
#     core type: Literal
#     sub-expressions:
