# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Literal
from proveit.number import Mult, e, i, pi, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(e, Mult(two, pi, i, Literal("phase", latexFormat = r"\varphi", context = "proveit.physics.quantum.QPE")))
# Out:
# expr: (e, 2 * pi * i * phase)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(e, 2 \cdot \pi \cdot i \cdot \varphi\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (e, 2 * pi * i * phase)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. e
#    core type: Literal
#    sub-expressions:
# 2. 2 * pi * i * phase
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. *
#    core type: Literal
#    sub-expressions:
# 4. (2, pi, i, phase)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7, 8
# 5. 2
#    core type: Literal
#    sub-expressions:
# 6. pi
#    core type: Literal
#    sub-expressions:
# 7. i
#    core type: Literal
#    sub-expressions:
# 8. phase
#    core type: Literal
#    sub-expressions:
