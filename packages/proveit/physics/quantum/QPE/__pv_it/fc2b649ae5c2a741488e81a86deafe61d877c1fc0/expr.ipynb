# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Literal
from proveit._common_ import eps, l
from proveit.logic import Equals, InSet
from proveit.number import Interval, Neg
from proveit.physics.quantum.QPE import ModAdd
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Conditional(Prob(Equals(Literal("m", context = "proveit.physics.quantum.QPE"), ModAdd(Literal("b", context = "proveit.physics.quantum.QPE"), l)), Literal("m", context = "proveit.physics.quantum.QPE")), InSet(l, Interval(Neg(eps), eps)))
# Out:
# expr: {Pr_{m}[m = (b MOD_ADD l)] if l in {-eps...eps}.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{Pr_{m}[m = \left(b \oplus l\right)] \textrm{ if } l \in \{-\varepsilon \dots \varepsilon\}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {Pr_{m}[m = (b MOD_ADD l)] if l in {-eps...eps}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. Pr_{m}[m = (b MOD_ADD l)]
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. l in {-eps...eps}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. PROB
#    core type: Literal
#    sub-expressions:
# 4. (m = (b MOD_ADD l), m)
#    core type: ExprTuple
#    sub-expressions: 7, 13
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (l, {-eps...eps})
#    core type: ExprTuple
#    sub-expressions: 21, 8
# 7. m = (b MOD_ADD l)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. {-eps...eps}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (m, b MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. Interval
#     core type: Literal
#     sub-expressions:
# 12. (-eps, eps)
#     core type: ExprTuple
#     sub-expressions: 15, 19
# 13. m
# ...
