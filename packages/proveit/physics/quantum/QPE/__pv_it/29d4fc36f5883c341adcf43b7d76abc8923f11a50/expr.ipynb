# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import a, b
from proveit.logic import And, InSet
from proveit.number import Exp, GreaterEq, NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(GreaterEq(Exp(a, b), a), And(InSet(a, NaturalsPos), InSet(b, NaturalsPos))))
# Out:
# expr: (a, b) -> {a^{b} >= a if a in NaturalsPos ,  b in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{a^{b} \geq a \textrm{ if } a \in \mathbb{N}^+ ,  b \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b) -> {a^{b} >= a if a in NaturalsPos ,  b in NaturalsPos.
#    core type: Lambda
#    parameters: 12\n   body: 1
# 1. {a^{b} >= a if a in NaturalsPos ,  b in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. a^{b} >= a
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a in NaturalsPos) and (b in NaturalsPos)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. >=
#    core type: Literal
#    sub-expressions:
# 5. (a^{b}, a)
#    core type: ExprTuple
#    sub-expressions: 8, 16
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in NaturalsPos, b in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. a^{b}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. a in NaturalsPos
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. b in NaturalsPos
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. Exp
#     core type: Literal
#     sub-expressions:
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. (a, NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (b, NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. NaturalsPos
#     core type: Literal
#     sub-expressions:
