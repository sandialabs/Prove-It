# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, l
from proveit.numbers import Exp, Mult, Sum, e, frac, i, one, pi, subtract, two
from proveit.physics.quantum.QPE import _delta_b_floor, _m_domain, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = subtract(_delta_b_floor, frac(l, _two_pow_t))
sub_expr2 = Exp(e, Mult(two, pi, i, sub_expr1))
expr = ExprTuple(Sum(index_or_indices = [k], summand = Exp(sub_expr2, k), domain = _m_domain), frac(subtract(one, Exp(e, Mult(two, pi, i, sub_expr1, _two_pow_t))), subtract(one, sub_expr2)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\sum_{k = 0}^{2^{t} - 1} (\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\delta_{b_{\textit{f}}} - \frac{l}{2^{t}}\right)})^{k}, \frac{1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\delta_{b_{\textit{f}}} - \frac{l}{2^{t}}\right) \cdot 2^{t}}}{1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\delta_{b_{\textit{f}}} - \frac{l}{2^{t}}\right)}}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})^{k}, (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t})) * 2^{t}}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})^{k}
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t})) * 2^{t}}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#    core type: Operation
#    operator: 55
#    operands: 5
# 3. Sum
#    core type: Literal
#    sub-expressions:
# 4. (k -> {(e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t})) * 2^{t}}, 1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. k -> {(e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 22
#    body: 10
# 7. 1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t})) * 2^{t}}
#    core type: Operation
#    operator: 44
#    operands: 11
# 8. 1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}
#    core type: Operation
#    operator: 44
#    operands: 12
# 9. (k)
#    core type: ExprTuple
#    sub-expressions: 22
# 10. {(e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. (1, -e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t})) * 2^{t}})
#     core type: ExprTuple
#     sub-expressions: 46, 15
# 12. (1, -e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#     core type: ExprTuple
#     sub-expressions: 46, 16
# 13. (e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})^{k}
#     core type: Operation
#     operator: 59
#     operands: 17
# 14. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. -e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t})) * 2^{t}}
#     core type: Operation
#     operator: 51
#     operand: 24
# 16. -e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}
#     core type: Operation
#     operator: 51
#     operand: 25
# 17. (e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}, k)
#     core type: ExprTuple
#     sub-expressions: 25, 22
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. (e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t})) * 2^{t}})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. (e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#     core type: ExprTuple
#     sub-expressions: 25
# 22. k
#     core type: Variable
#     sub-expressions:
# 23. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t})) * 2^{t}}
#     core type: Operation
#     operator: 59
#     operands: 28
# 25. e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}
#     core type: Operation
#     operator: 59
#     operands: 29
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. (e, 2 * pi * i * (delta_{b_{f}} - (l / 2^{t})) * 2^{t})
#     core type: ExprTuple
#     sub-expressions: 33, 32
# 29. (e, 2 * pi * i * (delta_{b_{f}} - (l / 2^{t})))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. 0
#     core type: Literal
#     sub-expressions:
# 31. 2^{t} - 1
#     core type: Operation
#     operator: 44
#     operands: 35
# 32. 2 * pi * i * (delta_{b_{f}} - (l / 2^{t})) * 2^{t}
#     core type: Operation
#     operator: 37
#     operands: 36
# 33. e
#     core type: Literal
#     sub-expressions:
# 34. 2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))
#     core type: Operation
#     operator: 37
#     operands: 38
# 35. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 58, 39
# 36. (2, pi, i, delta_{b_{f}} - (l / 2^{t}), 2^{t})
#     core type: ExprTuple
#     sub-expressions: 61, 40, 41, 42, 58
# 37. *
#     core type: Literal
#     sub-expressions:
# 38. (2, pi, i, delta_{b_{f}} - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 61, 40, 41, 42
# 39. -1
#     core type: Operation
#     operator: 51
#     operand: 46
# 40. pi
#     core type: Literal
#     sub-expressions:
# 41. i
#     core type: Literal
#     sub-expressions:
# 42. delta_{b_{f}} - (l / 2^{t})
#     core type: Operation
#     operator: 44
#     operands: 45
# 43. (1)
#     core type: ExprTuple
#     sub-expressions: 46
# 44. +
#     core type: Literal
#     sub-expressions:
# 45. (delta_{b_{f}}, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. delta_{b_{f}}
#     core type: Operation
#     operator: 49
#     operand: 53
# 48. -(l / 2^{t})
#     core type: Operation
#     operator: 51
#     operand: 54
# 49. delta
#     core type: Literal
#     sub-expressions:
# 50. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 53
# 51. -
#     core type: Literal
#     sub-expressions:
# 52. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 54
# 53. b_{f}
#     core type: Literal
#     sub-expressions:
# 54. l / 2^{t}
#     core type: Operation
#     operator: 55
#     operands: 56
# 55. /
#     core type: Literal
#     sub-expressions:
# 56. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 57. l
#     core type: Variable
#     sub-expressions:
# 58. 2^{t}
#     core type: Operation
#     operator: 59
#     operands: 60
# 59. Exp
#     core type: Literal
#     sub-expressions:
# 60. (2, t)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 61. 2
#     core type: Literal
#     sub-expressions:
# 62. t
#     core type: Literal
#     sub-expressions:
