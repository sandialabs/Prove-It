# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Equals
from proveit.numbers import Exp, Mult, e, frac, i, one, pi, subtract, two
from proveit.physics.quantum.QPE import _delta_b_floor, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = subtract(one, Exp(e, Mult(two, pi, i, subtract(_delta_b_floor, frac(l, _two_pow_t)))))
expr = Equals(frac(subtract(one, Exp(e, Mult(two, pi, i, subtract(Mult(_delta_b_floor, _two_pow_t), l)))), sub_expr1), frac(subtract(one, Exp(e, Mult(two, pi, i, subtract(Mult(_two_pow_t, _delta_b_floor), l)))), sub_expr1))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \frac{1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\left(\delta_{b_{\textit{f}}} \cdot 2^{t}\right) - l\right)}}{1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\delta_{b_{\textit{f}}} - \frac{l}{2^{t}}\right)}} = \frac{1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\left(2^{t} \cdot \delta_{b_{\textit{f}}}\right) - l\right)}}{1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\delta_{b_{\textit{f}}} - \frac{l}{2^{t}}\right)}}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((1 - e^{2 * pi * i * ((delta_{b_{f}} * 2^{t}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})) = ((1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1 - e^{2 * pi * i * ((delta_{b_{f}} * 2^{t}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}), (1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1 - e^{2 * pi * i * ((delta_{b_{f}} * 2^{t}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#    core type: Operation
#    operator: 56
#    operands: 5
# 4. (1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#    core type: Operation
#    operator: 56
#    operands: 6
# 5. (1 - e^{2 * pi * i * ((delta_{b_{f}} * 2^{t}) - l)}, 1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#    core type: ExprTuple
#    sub-expressions: 7, 9
# 6. (1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}, 1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. 1 - e^{2 * pi * i * ((delta_{b_{f}} * 2^{t}) - l)}
#    core type: Operation
#    operator: 40
#    operands: 10
# 8. 1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}
#    core type: Operation
#    operator: 40
#    operands: 11
# 9. 1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}
#    core type: Operation
#    operator: 40
#    operands: 12
# 10. (1, -e^{2 * pi * i * ((delta_{b_{f}} * 2^{t}) - l)})
#     core type: ExprTuple
#     sub-expressions: 15, 13
# 11. (1, -e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)})
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. (1, -e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. -e^{2 * pi * i * ((delta_{b_{f}} * 2^{t}) - l)}
#     core type: Operation
#     operator: 50
#     operand: 20
# 14. -e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}
#     core type: Operation
#     operator: 50
#     operand: 21
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. -e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}
#     core type: Operation
#     operator: 50
#     operand: 22
# 17. (e^{2 * pi * i * ((delta_{b_{f}} * 2^{t}) - l)})
#     core type: ExprTuple
#     sub-expressions: 20
# 18. (e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)})
#     core type: ExprTuple
#     sub-expressions: 21
# 19. (e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#     core type: ExprTuple
#     sub-expressions: 22
# 20. e^{2 * pi * i * ((delta_{b_{f}} * 2^{t}) - l)}
#     core type: Operation
#     operator: 61
#     operands: 23
# 21. e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}
#     core type: Operation
#     operator: 61
#     operands: 24
# 22. e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}
#     core type: Operation
#     operator: 61
#     operands: 25
# 23. (e, 2 * pi * i * ((delta_{b_{f}} * 2^{t}) - l))
#     core type: ExprTuple
#     sub-expressions: 28, 26
# 24. (e, 2 * pi * i * ((2^{t} * delta_{b_{f}}) - l))
#     core type: ExprTuple
#     sub-expressions: 28, 27
# 25. (e, 2 * pi * i * (delta_{b_{f}} - (l / 2^{t})))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. 2 * pi * i * ((delta_{b_{f}} * 2^{t}) - l)
#     core type: Operation
#     operator: 47
#     operands: 30
# 27. 2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)
#     core type: Operation
#     operator: 47
#     operands: 31
# 28. e
#     core type: Literal
#     sub-expressions:
# 29. 2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))
#     core type: Operation
#     operator: 47
#     operands: 32
# 30. (2, pi, i, (delta_{b_{f}} * 2^{t}) - l)
#     core type: ExprTuple
#     sub-expressions: 63, 35, 36, 33
# 31. (2, pi, i, (2^{t} * delta_{b_{f}}) - l)
#     core type: ExprTuple
#     sub-expressions: 63, 35, 36, 34
# 32. (2, pi, i, delta_{b_{f}} - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 63, 35, 36, 37
# 33. (delta_{b_{f}} * 2^{t}) - l
#     core type: Operation
#     operator: 40
#     operands: 38
# 34. (2^{t} * delta_{b_{f}}) - l
#     core type: Operation
#     operator: 40
#     operands: 39
# 35. pi
#     core type: Literal
#     sub-expressions:
# 36. i
#     core type: Literal
#     sub-expressions:
# 37. delta_{b_{f}} - (l / 2^{t})
#     core type: Operation
#     operator: 40
#     operands: 41
# 38. (delta_{b_{f}} * 2^{t}, -l)
#     core type: ExprTuple
#     sub-expressions: 42, 44
# 39. (2^{t} * delta_{b_{f}}, -l)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. (delta_{b_{f}}, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 52, 45
# 42. delta_{b_{f}} * 2^{t}
#     core type: Operation
#     operator: 47
#     operands: 46
# 43. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. -l
#     core type: Operation
#     operator: 50
#     operand: 59
# 45. -(l / 2^{t})
#     core type: Operation
#     operator: 50
#     operand: 53
# 46. (delta_{b_{f}}, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 52, 60
# 47. *
#     core type: Literal
#     sub-expressions:
# 48. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 60, 52
# 49. (l)
#     core type: ExprTuple
#     sub-expressions: 59
# 50. -
#     core type: Literal
#     sub-expressions:
# 51. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 53
# 52. delta_{b_{f}}
#     core type: Operation
#     operator: 54
#     operand: 58
# 53. l / 2^{t}
#     core type: Operation
#     operator: 56
#     operands: 57
# 54. delta
#     core type: Literal
#     sub-expressions:
# 55. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 58
# 56. /
#     core type: Literal
#     sub-expressions:
# 57. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 58. b_{f}
#     core type: Literal
#     sub-expressions:
# 59. l
#     core type: Variable
#     sub-expressions:
# 60. 2^{t}
#     core type: Operation
#     operator: 61
#     operands: 62
# 61. Exp
#     core type: Literal
#     sub-expressions:
# 62. (2, t)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 63. 2
#     core type: Literal
#     sub-expressions:
# 64. t
#     core type: Literal
#     sub-expressions:
