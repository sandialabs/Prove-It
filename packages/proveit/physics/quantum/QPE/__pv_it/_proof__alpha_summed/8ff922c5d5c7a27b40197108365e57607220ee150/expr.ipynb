# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Variable, k
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Mult, Neg, Sum, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import _b_floor, _delta_b_floor, _m_domain, _rel_indexed_alpha, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = Equals(_rel_indexed_alpha, Mult(frac(one, _two_pow_t), Sum(index_or_indices = [k], summand = Exp(Exp(e, Mult(two, pi, i, Add(frac(_b_floor, _two_pow_t), _delta_b_floor, Neg(Variable("_a", latex_format = r"{_{-}a}"))))), k), domain = _m_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \alpha_{b_{\textit{f}} \oplus l} = \left(\frac{1}{2^{t}} \cdot \left(\sum_{k = 0}^{2^{t} - 1} (\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\frac{b_{\textit{f}}}{2^{t}} + \delta_{b_{\textit{f}}} - {_{-}a}\right)})^{k}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. alpha_{b_{f} MOD_ADD l} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k}))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (alpha_{b_{f} MOD_ADD l}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. alpha_{b_{f} MOD_ADD l}
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k})
#    core type: Operation
#    operator: 35
#    operands: 7
# 5. alpha
#    core type: Literal
#    sub-expressions:
# 6. (b_{f} MOD_ADD l)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. b_{f} MOD_ADD l
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. 1 / 2^{t}
#    core type: Operation
#    operator: 49
#    operands: 13
# 10. Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k}
#     core type: Operation
#     operator: 14
#     operand: 17
# 11. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 12. (b_{f}, l)
#     core type: ExprTuple
#     sub-expressions: 56, 16
# 13. (1, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 48, 55
# 14. Sum
#     core type: Literal
#     sub-expressions:
# 15. (k -> {(e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. l
#     core type: Variable
#     sub-expressions:
# 17. k -> {(e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 26
#     body: 19
# 18. (k)
#     core type: ExprTuple
#     sub-expressions: 26
# 19. {(e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 20
#     condition: 21
# 20. (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k}
#     core type: Operation
#     operator: 58
#     operands: 22
# 21. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)}, k)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)}
#     core type: Operation
#     operator: 58
#     operands: 28
# 26. k
#     core type: Variable
#     sub-expressions:
# 27. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. (e, 2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. Interval
#     core type: Literal
#     sub-expressions:
# 30. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. e
#     core type: Literal
#     sub-expressions:
# 32. 2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. 0
#     core type: Literal
#     sub-expressions:
# 34. 2^{t} - 1
#     core type: Operation
#     operator: 42
#     operands: 37
# 35. *
#     core type: Literal
#     sub-expressions:
# 36. (2, pi, i, (b_{f} / 2^{t}) + delta_{b_{f}} - _a)
#     core type: ExprTuple
#     sub-expressions: 60, 38, 39, 40
# 37. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 55, 41
# 38. pi
#     core type: Literal
#     sub-expressions:
# 39. i
#     core type: Literal
#     sub-expressions:
# 40. (b_{f} / 2^{t}) + delta_{b_{f}} - _a
#     core type: Operation
#     operator: 42
#     operands: 43
# 41. -1
#     core type: Operation
#     operator: 53
#     operand: 48
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. (b_{f} / 2^{t}, delta_{b_{f}}, -_a)
#     core type: ExprTuple
#     sub-expressions: 45, 46, 47
# 44. (1)
#     core type: ExprTuple
#     sub-expressions: 48
# 45. b_{f} / 2^{t}
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. delta_{b_{f}}
#     core type: Operation
#     operator: 51
#     operand: 56
# 47. -_a
#     core type: Operation
#     operator: 53
#     operand: 57
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. /
#     core type: Literal
#     sub-expressions:
# 50. (b_{f}, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 56, 55
# 51. delta
#     core type: Literal
#     sub-expressions:
# 52. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 56
# 53. -
#     core type: Literal
#     sub-expressions:
# 54. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 55. 2^{t}
#     core type: Operation
#     operator: 58
#     operands: 59
# 56. b_{f}
#     core type: Literal
#     sub-expressions:
# 57. _a
#     core type: Variable
#     sub-expressions:
# 58. Exp
#     core type: Literal
#     sub-expressions:
# 59. (2, t)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 60. 2
#     core type: Literal
#     sub-expressions:
# 61. t
#     core type: Literal
#     sub-expressions:
