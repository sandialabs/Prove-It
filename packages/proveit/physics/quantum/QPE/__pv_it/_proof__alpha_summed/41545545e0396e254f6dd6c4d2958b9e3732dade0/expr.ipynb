# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Variable, k
from proveit.numbers import Add, Exp, Mult, Neg, Sum, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import _b_floor, _delta_b_floor, _m_domain, _rel_indexed_alpha, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(_rel_indexed_alpha, Mult(frac(one, _two_pow_t), Sum(index_or_indices = [k], summand = Exp(Exp(e, Mult(two, pi, i, Add(frac(_b_floor, _two_pow_t), _delta_b_floor, Neg(Variable("_a", latex_format = r"{_{-}a}"))))), k), domain = _m_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\alpha_{b_{\textit{f}} \oplus l}, \frac{1}{2^{t}} \cdot \left(\sum_{k = 0}^{2^{t} - 1} (\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\frac{b_{\textit{f}}}{2^{t}} + \delta_{b_{\textit{f}}} - {_{-}a}\right)})^{k}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (alpha_{b_{f} MOD_ADD l}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. alpha_{b_{f} MOD_ADD l}
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k})
#    core type: Operation
#    operator: 33
#    operands: 5
# 3. alpha
#    core type: Literal
#    sub-expressions:
# 4. (b_{f} MOD_ADD l)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. b_{f} MOD_ADD l
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. 1 / 2^{t}
#    core type: Operation
#    operator: 47
#    operands: 11
# 8. Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k}
#    core type: Operation
#    operator: 12
#    operand: 15
# 9. MOD_ADD
#    core type: Literal
#    sub-expressions:
# 10. (b_{f}, l)
#     core type: ExprTuple
#     sub-expressions: 54, 14
# 11. (1, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 46, 53
# 12. Sum
#     core type: Literal
#     sub-expressions:
# 13. (k -> {(e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. l
#     core type: Variable
#     sub-expressions:
# 15. k -> {(e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 24
#     body: 17
# 16. (k)
#     core type: ExprTuple
#     sub-expressions: 24
# 17. {(e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 18
#     condition: 19
# 18. (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)})^{k}
#     core type: Operation
#     operator: 56
#     operands: 20
# 19. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)}, k)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)}
#     core type: Operation
#     operator: 56
#     operands: 26
# 24. k
#     core type: Variable
#     sub-expressions:
# 25. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. (e, 2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. Interval
#     core type: Literal
#     sub-expressions:
# 28. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. e
#     core type: Literal
#     sub-expressions:
# 30. 2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - _a)
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. 0
#     core type: Literal
#     sub-expressions:
# 32. 2^{t} - 1
#     core type: Operation
#     operator: 40
#     operands: 35
# 33. *
#     core type: Literal
#     sub-expressions:
# 34. (2, pi, i, (b_{f} / 2^{t}) + delta_{b_{f}} - _a)
#     core type: ExprTuple
#     sub-expressions: 58, 36, 37, 38
# 35. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 53, 39
# 36. pi
#     core type: Literal
#     sub-expressions:
# 37. i
#     core type: Literal
#     sub-expressions:
# 38. (b_{f} / 2^{t}) + delta_{b_{f}} - _a
#     core type: Operation
#     operator: 40
#     operands: 41
# 39. -1
#     core type: Operation
#     operator: 51
#     operand: 46
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. (b_{f} / 2^{t}, delta_{b_{f}}, -_a)
#     core type: ExprTuple
#     sub-expressions: 43, 44, 45
# 42. (1)
#     core type: ExprTuple
#     sub-expressions: 46
# 43. b_{f} / 2^{t}
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. delta_{b_{f}}
#     core type: Operation
#     operator: 49
#     operand: 54
# 45. -_a
#     core type: Operation
#     operator: 51
#     operand: 55
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. /
#     core type: Literal
#     sub-expressions:
# 48. (b_{f}, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 54, 53
# 49. delta
#     core type: Literal
#     sub-expressions:
# 50. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 54
# 51. -
#     core type: Literal
#     sub-expressions:
# 52. (_a)
#     core type: ExprTuple
#     sub-expressions: 55
# 53. 2^{t}
#     core type: Operation
#     operator: 56
#     operands: 57
# 54. b_{f}
#     core type: Literal
#     sub-expressions:
# 55. _a
#     core type: Variable
#     sub-expressions:
# 56. Exp
#     core type: Literal
#     sub-expressions:
# 57. (2, t)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 58. 2
#     core type: Literal
#     sub-expressions:
# 59. t
#     core type: Literal
#     sub-expressions:
