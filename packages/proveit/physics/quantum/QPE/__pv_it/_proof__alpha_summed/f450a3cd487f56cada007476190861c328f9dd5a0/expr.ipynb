# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k, l
from proveit.numbers import Add, Exp, Mult, Neg, Sum, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import _b_floor, _delta_b_floor, _m_domain, _rel_indexed_alpha, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(_rel_indexed_alpha, Mult(frac(one, _two_pow_t), Sum(index_or_indices = [k], summand = Exp(Exp(e, Mult(two, pi, i, Add(frac(_b_floor, _two_pow_t), _delta_b_floor, Neg(frac(Add(_b_floor, l), _two_pow_t))))), k), domain = _m_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\alpha_{b_{\textit{f}} \oplus l}, \frac{1}{2^{t}} \cdot \left(\sum_{k = 0}^{2^{t} - 1} (\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\frac{b_{\textit{f}}}{2^{t}} + \delta_{b_{\textit{f}}} - \frac{b_{\textit{f}} + l}{2^{t}}\right)})^{k}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (alpha_{b_{f} MOD_ADD l}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - ((b_{f} + l) / 2^{t}))})^{k}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. alpha_{b_{f} MOD_ADD l}
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - ((b_{f} + l) / 2^{t}))})^{k})
#    core type: Operation
#    operator: 31
#    operands: 5
# 3. alpha
#    core type: Literal
#    sub-expressions:
# 4. (b_{f} MOD_ADD l)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - ((b_{f} + l) / 2^{t}))})^{k})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. b_{f} MOD_ADD l
#    core type: Operation
#    operator: 9
#    operands: 55
# 7. 1 / 2^{t}
#    core type: Operation
#    operator: 50
#    operands: 10
# 8. Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - ((b_{f} + l) / 2^{t}))})^{k}
#    core type: Operation
#    operator: 11
#    operand: 13
# 9. MOD_ADD
#    core type: Literal
#    sub-expressions:
# 10. (1, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 43, 53
# 11. Sum
#     core type: Literal
#     sub-expressions:
# 12. (k -> {(e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - ((b_{f} + l) / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. k -> {(e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - ((b_{f} + l) / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 22
#     body: 15
# 14. (k)
#     core type: ExprTuple
#     sub-expressions: 22
# 15. {(e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - ((b_{f} + l) / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 16
#     condition: 17
# 16. (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - ((b_{f} + l) / 2^{t}))})^{k}
#     core type: Operation
#     operator: 56
#     operands: 18
# 17. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. (e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - ((b_{f} + l) / 2^{t}))}, k)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. e^{2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - ((b_{f} + l) / 2^{t}))}
#     core type: Operation
#     operator: 56
#     operands: 24
# 22. k
#     core type: Variable
#     sub-expressions:
# 23. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. (e, 2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - ((b_{f} + l) / 2^{t})))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. e
#     core type: Literal
#     sub-expressions:
# 28. 2 * pi * i * ((b_{f} / 2^{t}) + delta_{b_{f}} - ((b_{f} + l) / 2^{t}))
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. 0
#     core type: Literal
#     sub-expressions:
# 30. 2^{t} - 1
#     core type: Operation
#     operator: 54
#     operands: 33
# 31. *
#     core type: Literal
#     sub-expressions:
# 32. (2, pi, i, (b_{f} / 2^{t}) + delta_{b_{f}} - ((b_{f} + l) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 60, 34, 35, 36
# 33. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 53, 37
# 34. pi
#     core type: Literal
#     sub-expressions:
# 35. i
#     core type: Literal
#     sub-expressions:
# 36. (b_{f} / 2^{t}) + delta_{b_{f}} - ((b_{f} + l) / 2^{t})
#     core type: Operation
#     operator: 54
#     operands: 38
# 37. -1
#     core type: Operation
#     operator: 47
#     operand: 43
# 38. (b_{f} / 2^{t}, delta_{b_{f}}, -((b_{f} + l) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 40, 41, 42
# 39. (1)
#     core type: ExprTuple
#     sub-expressions: 43
# 40. b_{f} / 2^{t}
#     core type: Operation
#     operator: 50
#     operands: 44
# 41. delta_{b_{f}}
#     core type: Operation
#     operator: 45
#     operand: 58
# 42. -((b_{f} + l) / 2^{t})
#     core type: Operation
#     operator: 47
#     operand: 49
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. (b_{f}, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 58, 53
# 45. delta
#     core type: Literal
#     sub-expressions:
# 46. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 58
# 47. -
#     core type: Literal
#     sub-expressions:
# 48. ((b_{f} + l) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 49
# 49. (b_{f} + l) / 2^{t}
#     core type: Operation
#     operator: 50
#     operands: 51
# 50. /
#     core type: Literal
#     sub-expressions:
# 51. (b_{f} + l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 52. b_{f} + l
#     core type: Operation
#     operator: 54
#     operands: 55
# 53. 2^{t}
#     core type: Operation
#     operator: 56
#     operands: 57
# 54. +
#     core type: Literal
#     sub-expressions:
# 55. (b_{f}, l)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. Exp
#     core type: Literal
#     sub-expressions:
# 57. (2, t)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 58. b_{f}
#     core type: Literal
#     sub-expressions:
# 59. l
#     core type: Variable
#     sub-expressions:
# 60. 2
#     core type: Literal
#     sub-expressions:
# 61. t
#     core type: Literal
#     sub-expressions:
