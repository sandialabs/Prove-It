# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Variable
from proveit.core_expr_types import Len
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals
from proveit.numbers import Add, Interval, Mult, one, three
from proveit.physics.quantum import I
from proveit.physics.quantum.QFT import InverseFourierTransform
from proveit.physics.quantum.QPE import _Psi_ket, _ket_u, _psi__t_ket, _s, _t
from proveit.physics.quantum.circuits import Gate, Input, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, _s)
sub_expr3 = Interval(one, _t)
expr = Equals(Len(operands = [ExprRange(sub_expr1, MultiQubitElem(element = Input(state = TensorProd(_psi__t_ket, _ket_u), part = sub_expr1), targets = Interval(one, sub_expr2)), one, sub_expr2), ExprRange(sub_expr1, MultiQubitElem(element = Gate(operation = InverseFourierTransform(_t), part = sub_expr1), targets = sub_expr3), one, _t), ExprRange(sub_expr1, Gate(operation = I).with_implicit_representation(), one, _s), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = _Psi_ket, part = sub_expr1), targets = sub_expr3), one, _t), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = Interval(Add(_t, one), sub_expr2)), one, _s)]), Add(Mult(three, _t), Mult(three, _s))).with_wrapping_at(1)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} |\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~t + s~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{{\mathrm {FT}}^{\dag}_{t}~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{{\mathrm {FT}}^{\dag}_{t}~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{{\mathrm {FT}}^{\dag}_{t}~\mbox{part}~t~\mbox{on}~\{1~\ldotp \ldotp~t\}} & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, ..\left(s - 3\right) \times.., \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \Psi \rangle~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \Psi \rangle~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \Psi \rangle~\mbox{part}~t~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)| \\  = \left(\left(3 \cdot t\right) + \left(3 \cdot s\right)\right) \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (1)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. |([MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:t}, targets:{1 .. t}},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})| \\  = ((3 * t) + (3 * s))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|([MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:t}, targets:{1 .. t}},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})|, (3 * t) + (3 * s))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |([MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:t}, targets:{1 .. t}},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})|
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (3 * t) + (3 * s)
#    core type: Operation
#    operator: 65
#    operands: 7
# 5. length
#    core type: Literal
#    sub-expressions:
# 6. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:t}, targets:{1 .. t}},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12
# 7. (3 * t, 3 * s)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 8. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}}
#    core type: ExprRange
#    lambda_map: 15
#    start_index: 69
#    end_index: 60
# 9. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:t}, targets:{1 .. t}}
#    core type: ExprRange
#    lambda_map: 16
#    start_index: 69
#    end_index: 73
# 10. [GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 69
#     end_index: 70
# 11. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:t}, targets:{1 .. t}}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 69
#     end_index: 73
# 12. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 69
#     end_index: 70
# 13. 3 * t
#     core type: Operation
#     operator: 21
#     operands: 20
# 14. 3 * s
#     core type: Operation
#     operator: 21
#     operands: 22
# 15. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 58
#     body: 23
# 16. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 58
#     body: 24
# 17. _a -> [GATE]{operation:I}
#     core type: Lambda
#     parameter: 58
#     body: 25
# 18. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 58
#     body: 26
# 19. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 58
#     body: 28
# 20. (3, t)
#     core type: ExprTuple
#     sub-expressions: 29, 73
# 21. *
#     core type: Literal
#     sub-expressions:
# 22. (3, s)
#     core type: ExprTuple
#     sub-expressions: 29, 70
# 23. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 34
#     operands: 30
# 24. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 34
#     operands: 31
# 25. [GATE]{operation:I}
#     core type: Operation
#     operator: 47
#     operands: 32
# 26. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 34
#     operands: 33
# 27. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 28. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. 3
#     core type: Literal
#     sub-expressions:
# 30. {element:[INPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 36
#     targets: 37
# 31. {element:[GATE]{operation:FT^{dag}_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 38
#     targets: 41
# 32. {operation:I}
#     core type: NamedExprs
#     operation: 39
# 33. {element:[OUTPUT]{state:|Psi>, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 40
#     targets: 41
# 34. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 35. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 42
#     targets: 43
# 36. [INPUT]{state:(|psi_{t}> otimes |u>), part:_a}
#     core type: Operation
#     operator: 44
#     operands: 45
# 37. {1 .. t + s}
#     core type: Operation
#     operator: 53
#     operands: 46
# 38. [GATE]{operation:FT^{dag}_{t}, part:_a}
#     core type: Operation
#     operator: 47
#     operands: 48
# 39. I
#     core type: Literal
#     sub-expressions:
# 40. [OUTPUT]{state:|Psi>, part:_a}
#     core type: Operation
#     operator: 51
#     operands: 49
# 41. {1 .. t}
#     core type: Operation
#     operator: 53
#     operands: 50
# 42. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 51
#     operands: 52
# 43. {t + 1 .. t + s}
#     core type: Operation
#     operator: 53
#     operands: 54
# 44. INPUT
#     core type: Literal
#     sub-expressions:
# 45. {state:(|psi_{t}> otimes |u>), part:_a}
#     core type: NamedExprs
#     state: 55
#     part: 58
# 46. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 69, 60
# 47. GATE
#     core type: Literal
#     sub-expressions:
# 48. {operation:FT^{dag}_{t}, part:_a}
#     core type: NamedExprs
#     operation: 56
#     part: 58
# 49. {state:|Psi>, part:_a}
#     core type: NamedExprs
#     state: 57
#     part: 58
# 50. (1, t)
#     core type: ExprTuple
#     sub-expressions: 69, 73
# 51. OUTPUT
#     core type: Literal
#     sub-expressions:
# 52. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 68
#     part: 58
# 53. Interval
#     core type: Literal
#     sub-expressions:
# 54. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 55. |psi_{t}> otimes |u>
#     core type: Operation
#     operator: 61
#     operands: 62
# 56. FT^{dag}_{t}
#     core type: Operation
#     operator: 63
#     operand: 73
# 57. |Psi>
#     core type: Literal
#     sub-expressions:
# 58. _a
#     core type: Variable
#     sub-expressions:
# 59. t + 1
#     core type: Operation
#     operator: 65
#     operands: 64
# 60. t + s
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. otimes
#     core type: Literal
#     sub-expressions:
# 62. (|psi_{t}>, |u>)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 63. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 64. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 73, 69
# 65. +
#     core type: Literal
#     sub-expressions:
# 66. (t, s)
#     core type: ExprTuple
#     sub-expressions: 73, 70
# 67. |psi_{t}>
#     core type: Operation
#     operator: 71
#     operand: 73
# 68. |u>
#     core type: Literal
#     sub-expressions:
# 69. 1
#     core type: Literal
#     sub-expressions:
# 70. s
#     core type: Literal
#     sub-expressions:
# 71. psi
#     core type: Literal
#     sub-expressions:
# 72. (t)
#     core type: ExprTuple
#     sub-expressions: 73
# 73. t
#     core type: Literal
#     sub-expressions:
