# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable
from proveit.core_expr_types import Len
from proveit.linear_algebra import TensorProd
from proveit.numbers import Add, Interval, one, three
from proveit.physics.quantum import I
from proveit.physics.quantum.QFT import InverseFourierTransform
from proveit.physics.quantum.QPE import _Psi_ket, _ket_u, _psi__t_ket, _s, _t
from proveit.physics.quantum.circuits import Gate, Input, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, _s)
sub_expr3 = Add(_t, one)
sub_expr4 = Interval(one, _t)
sub_expr5 = MultiQubitElem(element = Input(state = TensorProd(_psi__t_ket, _ket_u), part = sub_expr1), targets = Interval(one, sub_expr2))
expr = ExprTuple(Len(operands = [[ExprRange(sub_expr1, sub_expr5, one, _t).with_wrapping_at(2,6), ExprRange(sub_expr1, sub_expr5, sub_expr3, sub_expr2).with_wrapping_at(2,6)], [ExprRange(sub_expr1, MultiQubitElem(element = Gate(operation = InverseFourierTransform(_t), part = sub_expr1), targets = sub_expr4), one, _t), ExprRange(sub_expr1, Gate(operation = I).with_implicit_representation(), one, _s)], [ExprRange(sub_expr1, MultiQubitElem(element = Output(state = _Psi_ket, part = sub_expr1), targets = sub_expr4), one, _t), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = Interval(sub_expr3, sub_expr2)), one, _s)]]), Len(operands = [ExprRange(sub_expr1, sub_expr1, one, three)]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(|\left(\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~t~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~t + 1~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~t + 2~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~t + s~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}\right), \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{{\mathrm {FT}}^{\dag}_{t}~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{{\mathrm {FT}}^{\dag}_{t}~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{{\mathrm {FT}}^{\dag}_{t}~\mbox{part}~t~\mbox{on}~\{1~\ldotp \ldotp~t\}} & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, ..\left(s - 3\right) \times.., \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}\right), \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \Psi \rangle~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \Psi \rangle~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \Psi \rangle~\mbox{part}~t~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)\right)|, |\left(1, 2, \ldots, 3\right)|\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (|(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:t}, targets:{1 .. t}},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))|, |(1, 2, ..., 3)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:t}, targets:{1 .. t}},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))|
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. |(1, 2, ..., 3)|
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (([MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:t}, targets:{1 .. t}},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. (1, 2, ..., 3)
#    core type: ExprTuple
#    sub-expressions: 9
# 6. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 7. ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:t}, targets:{1 .. t}},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 8. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 9. 1, 2, ..., 3
#    core type: ExprRange
#    lambda_map: 16
#    start_index: 68
#    end_index: 17
# 10. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}},  \\ [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:2}, targets:{1 .. t + s}}, ...,  \\ [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:t}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 68
#     end_index: 72
# 11. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}},  \\ [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ...,  \\ [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 58
#     end_index: 59
# 12. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:t}, targets:{1 .. t}}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 68
#     end_index: 72
# 13. [GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 68
#     end_index: 69
# 14. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:t}, targets:{1 .. t}}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 68
#     end_index: 72
# 15. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 68
#     end_index: 69
# 16. _a -> _a
#     core type: Lambda
#     parameter: 57
#     body: 57
# 17. 3
#     core type: Literal
#     sub-expressions:
# 18. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 57
#     body: 23
# 19. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 57
#     body: 24
# 20. _a -> [GATE]{operation:I}
#     core type: Lambda
#     parameter: 57
#     body: 25
# 21. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 57
#     body: 26
# 22. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 57
#     body: 28
# 23. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 33
#     operands: 29
# 24. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 33
#     operands: 30
# 25. [GATE]{operation:I}
#     core type: Operation
#     operator: 46
#     operands: 31
# 26. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 33
#     operands: 32
# 27. (_a)
#     core type: ExprTuple
#     sub-expressions: 57
# 28. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. {element:[INPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 35
#     targets: 36
# 30. {element:[GATE]{operation:FT^{dag}_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 37
#     targets: 40
# 31. {operation:I}
#     core type: NamedExprs
#     operation: 38
# 32. {element:[OUTPUT]{state:|Psi>, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 39
#     targets: 40
# 33. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 34. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 41
#     targets: 42
# 35. [INPUT]{state:(|psi_{t}> otimes |u>), part:_a}
#     core type: Operation
#     operator: 43
#     operands: 44
# 36. {1 .. t + s}
#     core type: Operation
#     operator: 52
#     operands: 45
# 37. [GATE]{operation:FT^{dag}_{t}, part:_a}
#     core type: Operation
#     operator: 46
#     operands: 47
# 38. I
#     core type: Literal
#     sub-expressions:
# 39. [OUTPUT]{state:|Psi>, part:_a}
#     core type: Operation
#     operator: 50
#     operands: 48
# 40. {1 .. t}
#     core type: Operation
#     operator: 52
#     operands: 49
# 41. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 50
#     operands: 51
# 42. {t + 1 .. t + s}
#     core type: Operation
#     operator: 52
#     operands: 53
# 43. INPUT
#     core type: Literal
#     sub-expressions:
# 44. {state:(|psi_{t}> otimes |u>), part:_a}
#     core type: NamedExprs
#     state: 54
#     part: 57
# 45. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 68, 59
# 46. GATE
#     core type: Literal
#     sub-expressions:
# 47. {operation:FT^{dag}_{t}, part:_a}
#     core type: NamedExprs
#     operation: 55
#     part: 57
# 48. {state:|Psi>, part:_a}
#     core type: NamedExprs
#     state: 56
#     part: 57
# 49. (1, t)
#     core type: ExprTuple
#     sub-expressions: 68, 72
# 50. OUTPUT
#     core type: Literal
#     sub-expressions:
# 51. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 67
#     part: 57
# 52. Interval
#     core type: Literal
#     sub-expressions:
# 53. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 54. |psi_{t}> otimes |u>
#     core type: Operation
#     operator: 60
#     operands: 61
# 55. FT^{dag}_{t}
#     core type: Operation
#     operator: 62
#     operand: 72
# 56. |Psi>
#     core type: Literal
#     sub-expressions:
# 57. _a
#     core type: Variable
#     sub-expressions:
# 58. t + 1
#     core type: Operation
#     operator: 64
#     operands: 63
# 59. t + s
#     core type: Operation
#     operator: 64
#     operands: 65
# 60. otimes
#     core type: Literal
#     sub-expressions:
# 61. (|psi_{t}>, |u>)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 62. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 63. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 72, 68
# 64. +
#     core type: Literal
#     sub-expressions:
# 65. (t, s)
#     core type: ExprTuple
#     sub-expressions: 72, 69
# 66. |psi_{t}>
#     core type: Operation
#     operator: 70
#     operand: 72
# 67. |u>
#     core type: Literal
#     sub-expressions:
# 68. 1
#     core type: Literal
#     sub-expressions:
# 69. s
#     core type: Literal
#     sub-expressions:
# 70. psi
#     core type: Literal
#     sub-expressions:
# 71. (t)
#     core type: ExprTuple
#     sub-expressions: 72
# 72. t
#     core type: Literal
#     sub-expressions:
