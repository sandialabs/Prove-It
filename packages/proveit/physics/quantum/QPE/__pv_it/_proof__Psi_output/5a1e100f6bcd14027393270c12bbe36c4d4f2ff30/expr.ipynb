# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, Variable
from proveit.linear_algebra import TensorProd
from proveit.numbers import Add, Interval, one
from proveit.physics.quantum import I
from proveit.physics.quantum.QFT import InverseFourierTransform
from proveit.physics.quantum.QPE import _Psi_ket, _ket_u, _psi__t_ket, _s, _t
from proveit.physics.quantum.circuits import Gate, Input, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, _s)
sub_expr3 = Interval(one, _t)
sub_expr4 = Lambda(sub_expr1, MultiQubitElem(element = Input(state = TensorProd(_psi__t_ket, _ket_u), part = sub_expr1), targets = Interval(one, sub_expr2)))
expr = ExprTuple(sub_expr4, sub_expr4, Lambda(sub_expr1, MultiQubitElem(element = Gate(operation = InverseFourierTransform(_t), part = sub_expr1), targets = sub_expr3)), Lambda(sub_expr1, Gate(operation = I).with_implicit_representation()), Lambda(sub_expr1, MultiQubitElem(element = Output(state = _Psi_ket, part = sub_expr1), targets = sub_expr3)), Lambda(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = Interval(Add(_t, one), sub_expr2))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left({_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{{\mathrm {FT}}^{\dag}_{t}~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t\}} & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \Psi \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{1~\ldotp \ldotp~t\}}
# } \end{array}, {_{-}a} \mapsto \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert u \rangle~\mbox{part}~{_{-}a}~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (_a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}, _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:_a}, targets:{1 .. t}}, _a -> [GATE]{operation:I}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:_a}, targets:{1 .. t}}, _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 1, 1, 2, 3, 4, 5
# 1. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#    core type: Lambda
#    parameter: 40
#    body: 6
# 2. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:_a}, targets:{1 .. t}}
#    core type: Lambda
#    parameter: 40
#    body: 7
# 3. _a -> [GATE]{operation:I}
#    core type: Lambda
#    parameter: 40
#    body: 8
# 4. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:_a}, targets:{1 .. t}}
#    core type: Lambda
#    parameter: 40
#    body: 9
# 5. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Lambda
#    parameter: 40
#    body: 11
# 6. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#    core type: Operation
#    operator: 16
#    operands: 12
# 7. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:FT^{dag}_{t}, part:_a}, targets:{1 .. t}}
#    core type: Operation
#    operator: 16
#    operands: 13
# 8. [GATE]{operation:I}
#    core type: Operation
#    operator: 29
#    operands: 14
# 9. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|Psi>, part:_a}, targets:{1 .. t}}
#    core type: Operation
#    operator: 16
#    operands: 15
# 10. (_a)
#     core type: ExprTuple
#     sub-expressions: 40
# 11. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. {element:[INPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 18
#     targets: 19
# 13. {element:[GATE]{operation:FT^{dag}_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 20
#     targets: 23
# 14. {operation:I}
#     core type: NamedExprs
#     operation: 21
# 15. {element:[OUTPUT]{state:|Psi>, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 22
#     targets: 23
# 16. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 17. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 24
#     targets: 25
# 18. [INPUT]{state:(|psi_{t}> otimes |u>), part:_a}
#     core type: Operation
#     operator: 26
#     operands: 27
# 19. {1 .. t + s}
#     core type: Operation
#     operator: 35
#     operands: 28
# 20. [GATE]{operation:FT^{dag}_{t}, part:_a}
#     core type: Operation
#     operator: 29
#     operands: 30
# 21. I
#     core type: Literal
#     sub-expressions:
# 22. [OUTPUT]{state:|Psi>, part:_a}
#     core type: Operation
#     operator: 33
#     operands: 31
# 23. {1 .. t}
#     core type: Operation
#     operator: 35
#     operands: 32
# 24. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 33
#     operands: 34
# 25. {t + 1 .. t + s}
#     core type: Operation
#     operator: 35
#     operands: 36
# 26. INPUT
#     core type: Literal
#     sub-expressions:
# 27. {state:(|psi_{t}> otimes |u>), part:_a}
#     core type: NamedExprs
#     state: 37
#     part: 40
# 28. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 51, 42
# 29. GATE
#     core type: Literal
#     sub-expressions:
# 30. {operation:FT^{dag}_{t}, part:_a}
#     core type: NamedExprs
#     operation: 38
#     part: 40
# 31. {state:|Psi>, part:_a}
#     core type: NamedExprs
#     state: 39
#     part: 40
# 32. (1, t)
#     core type: ExprTuple
#     sub-expressions: 51, 55
# 33. OUTPUT
#     core type: Literal
#     sub-expressions:
# 34. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 50
#     part: 40
# 35. Interval
#     core type: Literal
#     sub-expressions:
# 36. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 37. |psi_{t}> otimes |u>
#     core type: Operation
#     operator: 43
#     operands: 44
# 38. FT^{dag}_{t}
#     core type: Operation
#     operator: 45
#     operand: 55
# 39. |Psi>
#     core type: Literal
#     sub-expressions:
# 40. _a
#     core type: Variable
#     sub-expressions:
# 41. t + 1
#     core type: Operation
#     operator: 47
#     operands: 46
# 42. t + s
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. otimes
#     core type: Literal
#     sub-expressions:
# 44. (|psi_{t}>, |u>)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 45. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 46. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 55, 51
# 47. +
#     core type: Literal
#     sub-expressions:
# 48. (t, s)
#     core type: ExprTuple
#     sub-expressions: 55, 52
# 49. |psi_{t}>
#     core type: Operation
#     operator: 53
#     operand: 55
# 50. |u>
#     core type: Literal
#     sub-expressions:
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. s
#     core type: Literal
#     sub-expressions:
# 53. psi
#     core type: Literal
#     sub-expressions:
# 54. (t)
#     core type: ExprTuple
#     sub-expressions: 55
# 55. t
#     core type: Literal
#     sub-expressions:
