# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable
from proveit.core_expr_types import Len
from proveit.linear_algebra import TensorProd
from proveit.numbers import Add, Interval, Mult, one, three
from proveit.physics.quantum import ket_plus
from proveit.physics.quantum.QPE import QPE1, _U, _ket_u, _psi__t_ket, _s, _t
from proveit.physics.quantum.circuits import Gate, Input, MultiQubitElem, Output

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, one)
sub_expr3 = Add(_t, _s)
sub_expr4 = Interval(one, sub_expr3)
sub_expr5 = MultiQubitElem(element = Gate(operation = QPE1(_U, _t), part = sub_expr1), targets = sub_expr4)
sub_expr6 = MultiQubitElem(element = Output(state = TensorProd(_psi__t_ket, _ket_u), part = sub_expr1), targets = sub_expr4)
expr = ExprTuple(Len(operands = [ExprRange(sub_expr1, Input(state = ket_plus), one, _t), ExprRange(sub_expr1, MultiQubitElem(element = Input(state = _ket_u, part = sub_expr1), targets = Interval(sub_expr2, sub_expr3)), one, _s), ExprRange(sub_expr1, sub_expr5, one, _t), ExprRange(sub_expr1, sub_expr5, sub_expr2, sub_expr3), ExprRange(sub_expr1, sub_expr6, one, _t), ExprRange(sub_expr1, sub_expr6, sub_expr2, sub_expr3)]), Add(Mult(three, _t), Mult(three, _s)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(|\left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert + \rangle} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert + \rangle} & \qw
# } \end{array}, ..\left(t - 3\right) \times.., \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert + \rangle} & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & \qin{\lvert u \rangle~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}_1\left(U, t\right)~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}_1\left(U, t\right)~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}_1\left(U, t\right)~\mbox{part}~t~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}_1\left(U, t\right)~\mbox{part}~t + 1~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}_1\left(U, t\right)~\mbox{part}~t + 2~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{\textrm{QPE}_1\left(U, t\right)~\mbox{part}~t + s~\mbox{on}~\{1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~1~\mbox{on}~\{1~\ldotp \ldotp~t + s\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~2~\mbox{on}~\{1~\ldotp \ldotp~t + s\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~t~\mbox{on}~\{1~\ldotp \ldotp~t + s\}}
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~t + 1~\mbox{on}~\{1~\ldotp \ldotp~t + s\}}
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~t + 2~\mbox{on}~\{1~\ldotp \ldotp~t + s\}}
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qout{\lvert \psi_{t} \rangle {\otimes} \lvert u \rangle~\mbox{part}~t + s~\mbox{on}~\{1~\ldotp \ldotp~t + s\}}
# } \end{array}\right)|, \left(3 \cdot t\right) + \left(3 \cdot s\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (|([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:(t + s)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}})|, (3 * t) + (3 * s))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:(t + s)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}})|
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (3 * t) + (3 * s)
#    core type: Operation
#    operator: 60
#    operands: 5
# 3. length
#    core type: Literal
#    sub-expressions:
# 4. ([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:(t + s)}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9, 10, 11
# 5. (3 * t, 3 * s)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 6. [INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉}
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 62
#    end_index: 69
# 7. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#    core type: ExprRange
#    lambda_map: 15
#    start_index: 62
#    end_index: 66
# 8. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:t}, targets:{1 .. t + s}}
#    core type: ExprRange
#    lambda_map: 16
#    start_index: 62
#    end_index: 69
# 9. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:(t + s)}, targets:{1 .. t + s}}
#    core type: ExprRange
#    lambda_map: 16
#    start_index: 50
#    end_index: 54
# 10. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:t}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 62
#     end_index: 69
# 11. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:(t + s)}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 50
#     end_index: 54
# 12. 3 * t
#     core type: Operation
#     operator: 19
#     operands: 18
# 13. 3 * s
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. _a -> [INPUT]{state:|+〉}
#     core type: Lambda
#     parameter: 53
#     body: 21
# 15. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 53
#     body: 22
# 16. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 53
#     body: 23
# 17. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 53
#     body: 25
# 18. (3, t)
#     core type: ExprTuple
#     sub-expressions: 26, 69
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. (3, s)
#     core type: ExprTuple
#     sub-expressions: 26, 66
# 21. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 40
#     operands: 27
# 22. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 30
#     operands: 28
# 23. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE1(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 30
#     operands: 29
# 24. (_a)
#     core type: ExprTuple
#     sub-expressions: 53
# 25. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. 3
#     core type: Literal
#     sub-expressions:
# 27. {state:|+〉}
#     core type: NamedExprs
#     state: 32
# 28. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 33
#     targets: 34
# 29. {element:[GATE]{operation:QPE1(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 35
#     targets: 37
# 30. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 31. {element:[OUTPUT]{state:(|psi_{t}> otimes |u>), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 36
#     targets: 37
# 32. |+〉
#     core type: Operation
#     operator: 38
#     operand: 49
# 33. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 40
#     operands: 41
# 34. {t + 1 .. t + s}
#     core type: Operation
#     operator: 47
#     operands: 42
# 35. [GATE]{operation:QPE1(U, t), part:_a}
#     core type: Operation
#     operator: 43
#     operands: 44
# 36. [OUTPUT]{state:(|psi_{t}> otimes |u>), part:_a}
#     core type: Operation
#     operator: 45
#     operands: 46
# 37. {1 .. t + s}
#     core type: Operation
#     operator: 47
#     operands: 48
# 38. KET
#     core type: Literal
#     sub-expressions:
# 39. (+)
#     core type: ExprTuple
#     sub-expressions: 49
# 40. INPUT
#     core type: Literal
#     sub-expressions:
# 41. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 65
#     part: 53
# 42. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 50, 54
# 43. GATE
#     core type: Literal
#     sub-expressions:
# 44. {operation:QPE1(U, t), part:_a}
#     core type: NamedExprs
#     operation: 51
#     part: 53
# 45. OUTPUT
#     core type: Literal
#     sub-expressions:
# 46. {state:(|psi_{t}> otimes |u>), part:_a}
#     core type: NamedExprs
#     state: 52
#     part: 53
# 47. Interval
#     core type: Literal
#     sub-expressions:
# 48. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 62, 54
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. t + 1
#     core type: Operation
#     operator: 60
#     operands: 55
# 51. QPE1(U, t)
#     core type: Operation
#     operator: 56
#     operands: 57
# 52. |psi_{t}> otimes |u>
#     core type: Operation
#     operator: 58
#     operands: 59
# 53. _a
#     core type: Variable
#     sub-expressions:
# 54. t + s
#     core type: Operation
#     operator: 60
#     operands: 61
# 55. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 69, 62
# 56. QPE1
#     core type: Literal
#     sub-expressions:
# 57. (U, t)
#     core type: ExprTuple
#     sub-expressions: 63, 69
# 58. otimes
#     core type: Literal
#     sub-expressions:
# 59. (|psi_{t}>, |u>)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 60. +
#     core type: Literal
#     sub-expressions:
# 61. (t, s)
#     core type: ExprTuple
#     sub-expressions: 69, 66
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. U
#     core type: Literal
#     sub-expressions:
# 64. |psi_{t}>
#     core type: Operation
#     operator: 67
#     operand: 69
# 65. |u>
#     core type: Literal
#     sub-expressions:
# 66. s
#     core type: Literal
#     sub-expressions:
# 67. psi
#     core type: Literal
#     sub-expressions:
# 68. (t)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. t
#     core type: Literal
#     sub-expressions:
