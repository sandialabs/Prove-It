# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Literal
from proveit._common_ import l
from proveit.logic import And, InSet, NotEquals, NotInSet
from proveit.number import Add, Exp, Integers, Interval, Neg, frac, one, two, zero

# %%
# build up the expression from sub-expressions
subExpr1 = Exp(two, Add(Literal("t", context = "proveit.physics.quantum.QPE"), Neg(one)))
expr = Conditional(NotInSet(Add(Literal("delta", latexFormat = r"\delta", context = "proveit.physics.quantum.QPE"), Neg(frac(l, Exp(two, Literal("t", context = "proveit.physics.quantum.QPE"))))), Integers), And(InSet(l, Interval(Add(Neg(subExpr1), one), subExpr1)), NotEquals(l, zero)))
# Out:
# expr: {(delta - (l / 2^{t})) not-in Integers if l in {-2^{t - 1} + 1...2^{t - 1}} ,  l != 0.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(\delta - \frac{l}{2^{t}}\right) \notin \mathbb{Z} \textrm{ if } l \in \{-2^{t - 1} + 1 \dots 2^{t - 1}\} ,  l \neq 0\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(delta - (l / 2^{t})) not-in Integers if l in {-2^{t - 1} + 1...2^{t - 1}} ,  l != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (delta - (l / 2^{t})) not-in Integers
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (l in {-2^{t - 1} + 1...2^{t - 1}}) and (l != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. not-in
#    core type: Literal
#    sub-expressions:
# 4. (delta - (l / 2^{t}), Integers)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (l in {-2^{t - 1} + 1...2^{t - 1}}, l != 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. delta - (l / 2^{t})
#    core type: Operation
#    operator: 36
#    operands: 11
# 8. Integers
#    core type: Literal
#    sub-expressions:
# 9. l in {-2^{t - 1} + 1...2^{t - 1}}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. l != 0
#     core type: Operation
#     operator: 14
# ...
