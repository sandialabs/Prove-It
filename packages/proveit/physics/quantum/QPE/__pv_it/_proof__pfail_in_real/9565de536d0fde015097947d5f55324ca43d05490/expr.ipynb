# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, VertExprArray, m
from proveit.logic import And, Equals, InSet, TRUE
from proveit.numbers import Add, Interval, one
from proveit.physics.quantum import NumKet, Z, ket_plus
from proveit.physics.quantum.QPE import QPE, _U, _ket_u, _m_domain, _s, _s_wire, _t
from proveit.physics.quantum.circuits import Gate, Input, Measure, MultiQubitElem, Output, Qcircuit

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, one)
sub_expr3 = Add(_t, _s)
sub_expr4 = IndexedVar(m, one)
sub_expr5 = Interval(sub_expr2, sub_expr3)
sub_expr6 = MultiQubitElem(element = Gate(operation = QPE(_U, _t), part = sub_expr1), targets = Interval(one, sub_expr3))
sub_expr7 = InSet(sub_expr4, _m_domain)
sub_expr8 = Qcircuit(vert_expr_array = VertExprArray([ExprRange(sub_expr1, Input(state = ket_plus), one, _t), ExprRange(sub_expr1, MultiQubitElem(element = Input(state = _ket_u, part = sub_expr1), targets = sub_expr5), one, _s)], [ExprRange(sub_expr1, sub_expr6, one, _t), ExprRange(sub_expr1, sub_expr6, sub_expr2, sub_expr3)], [ExprRange(sub_expr1, Measure(basis = Z), one, _t), _s_wire], [ExprRange(sub_expr1, MultiQubitElem(element = Output(state = NumKet(sub_expr4, _t), part = sub_expr1), targets = Interval(one, _t)), one, _t), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = sub_expr5), one, _s)]))
expr = Equals(Conditional(sub_expr8, And(sub_expr7, TRUE)), Conditional(sub_expr8, sub_expr7)).with_wrapping_at(1)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left\{\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert + \rangle} & \multigate{4}{\textrm{QPE}\left(U, t\right)} & \meter & \multiqout{3}{\lvert m_{1} \rangle_{t}} \\
# \qin{\lvert + \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & \meter & \ghostqout{\lvert m_{1} \rangle_{t}} \\
# \qin{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} & \ghost{\textrm{QPE}\left(U, t\right)} & \measure{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} \qw & \ghostqout{\lvert m_{1} \rangle_{t}} \\
# \qin{\lvert + \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & \meter & \ghostqout{\lvert m_{1} \rangle_{t}} \\
# \qin{\lvert u \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & { /^{s} } \qw & \qout{\lvert u \rangle}
# } \end{array} \textrm{ if } m_{1} \in \{0~\ldotp \ldotp~2^{t} - 1\} ,  \top\right.. \\  = \left\{\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert + \rangle} & \multigate{4}{\textrm{QPE}\left(U, t\right)} & \meter & \multiqout{3}{\lvert m_{1} \rangle_{t}} \\
# \qin{\lvert + \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & \meter & \ghostqout{\lvert m_{1} \rangle_{t}} \\
# \qin{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} & \ghost{\textrm{QPE}\left(U, t\right)} & \measure{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} \qw & \ghostqout{\lvert m_{1} \rangle_{t}} \\
# \qin{\lvert + \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & \meter & \ghostqout{\lvert m_{1} \rangle_{t}} \\
# \qin{\lvert u \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & { /^{s} } \qw & \qout{\lvert u \rangle}
# } \end{array} \textrm{ if } m_{1} \in \{0~\ldotp \ldotp~2^{t} - 1\}\right.. \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (1)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))) if m_{1} in {0 .. 2^{t} - 1} ,  TRUE. \\  = {QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))) if m_{1} in {0 .. 2^{t} - 1}.
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))) if m_{1} in {0 .. 2^{t} - 1} ,  TRUE, QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))) if m_{1} in {0 .. 2^{t} - 1})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))) if m_{1} in {0 .. 2^{t} - 1} ,  TRUE.
#    core type: Conditional
#    value: 6
#    condition: 5
# 4. {QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))) if m_{1} in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 6
#    condition: 11
# 5. (m_{1} in {0 .. 2^{t} - 1}) and TRUE
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (m_{1} in {0 .. 2^{t} - 1}, TRUE)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. QCIRCUIT
#    core type: Literal
#    sub-expressions:
# 10. VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15, 16
# 11. m_{1} in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. TRUE
#     core type: Literal
#     sub-expressions:
# 13. ([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 14. ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 15. ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 16. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (m_{1}, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 99, 27
# 19. [INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 104
#     end_index: 100
# 20. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 104
#     end_index: 101
# 21. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 104
#     end_index: 100
# 22. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 88
#     end_index: 89
# 23. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 104
#     end_index: 100
# 24. [GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 104
#     end_index: 101
# 25. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 104
#     end_index: 100
# 26. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 104
#     end_index: 101
# 27. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 78
#     operands: 35
# 28. _a -> [INPUT]{state:|+〉}
#     core type: Lambda
#     parameter: 87
#     body: 36
# 29. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 87
#     body: 37
# 30. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 87
#     body: 38
# 31. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 87
#     body: 39
# 32. _a -> [GATE]{operation:I}
#     core type: Lambda
#     parameter: 87
#     body: 40
# 33. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 87
#     body: 41
# 34. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 87
#     body: 43
# 35. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 36. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 70
#     operands: 46
# 37. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 53
#     operands: 47
# 38. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 53
#     operands: 48
# 39. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 49
#     operands: 50
# 40. [GATE]{operation:I}
#     core type: Operation
#     operator: 71
#     operands: 51
# 41. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 53
#     operands: 52
# 42. (_a)
#     core type: ExprTuple
#     sub-expressions: 87
# 43. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 53
#     operands: 54
# 44. 0
#     core type: Literal
#     sub-expressions:
# 45. 2^{t} - 1
#     core type: Operation
#     operator: 96
#     operands: 55
# 46. {state:|+〉}
#     core type: NamedExprs
#     state: 56
# 47. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 57
#     targets: 65
# 48. {element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 58
#     targets: 59
# 49. MEASURE
#     core type: Literal
#     sub-expressions:
# 50. {basis:Z}
#     core type: NamedExprs
#     basis: 60
# 51. {operation:I}
#     core type: NamedExprs
#     operation: 61
# 52. {element:[OUTPUT]{state:|m_{1}〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 62
#     targets: 63
# 53. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 54. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 64
#     targets: 65
# 55. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 56. |+〉
#     core type: Operation
#     operator: 68
#     operand: 83
# 57. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 70
#     operands: 77
# 58. [GATE]{operation:QPE(U, t), part:_a}
#     core type: Operation
#     operator: 71
#     operands: 72
# 59. {1 .. t + s}
#     core type: Operation
#     operator: 78
#     operands: 73
# 60. Z
#     core type: Literal
#     sub-expressions:
# 61. I
#     core type: Literal
#     sub-expressions:
# 62. [OUTPUT]{state:|m_{1}〉_{t}, part:_a}
#     core type: Operation
#     operator: 76
#     operands: 74
# 63. {1 .. t}
#     core type: Operation
#     operator: 78
#     operands: 75
# 64. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 76
#     operands: 77
# 65. {t + 1 .. t + s}
#     core type: Operation
#     operator: 78
#     operands: 79
# 66. 2^{t}
#     core type: Operation
#     operator: 80
#     operands: 81
# 67. -1
#     core type: Operation
#     operator: 82
#     operand: 104
# 68. KET
#     core type: Literal
#     sub-expressions:
# 69. (+)
#     core type: ExprTuple
#     sub-expressions: 83
# 70. INPUT
#     core type: Literal
#     sub-expressions:
# 71. GATE
#     core type: Literal
#     sub-expressions:
# 72. {operation:QPE(U, t), part:_a}
#     core type: NamedExprs
#     operation: 84
#     part: 87
# 73. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 104, 89
# 74. {state:|m_{1}〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 85
#     part: 87
# 75. (1, t)
#     core type: ExprTuple
#     sub-expressions: 104, 100
# 76. OUTPUT
#     core type: Literal
#     sub-expressions:
# 77. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 86
#     part: 87
# 78. Interval
#     core type: Literal
#     sub-expressions:
# 79. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 88, 89
# 80. Exp
#     core type: Literal
#     sub-expressions:
# 81. (2, t)
#     core type: ExprTuple
#     sub-expressions: 90, 100
# 82. -
#     core type: Literal
#     sub-expressions:
# 83. +
#     core type: Literal
#     sub-expressions:
# 84. QPE(U, t)
#     core type: Operation
#     operator: 91
#     operands: 92
# 85. |m_{1}〉_{t}
#     core type: Operation
#     operator: 93
#     operands: 94
# 86. |u>
#     core type: Literal
#     sub-expressions:
# 87. _a
#     core type: Variable
#     sub-expressions:
# 88. t + 1
#     core type: Operation
#     operator: 96
#     operands: 95
# 89. t + s
#     core type: Operation
#     operator: 96
#     operands: 97
# 90. 2
#     core type: Literal
#     sub-expressions:
# 91. QPE
#     core type: Literal
#     sub-expressions:
# 92. (U, t)
#     core type: ExprTuple
#     sub-expressions: 98, 100
# 93. NUM_KET
#     core type: Literal
#     sub-expressions:
# 94. (m_{1}, t)
#     core type: ExprTuple
#     sub-expressions: 99, 100
# 95. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 100, 104
# 96. +
#     core type: Literal
#     sub-expressions:
# 97. (t, s)
#     core type: ExprTuple
#     sub-expressions: 100, 101
# 98. U
#     core type: Literal
#     sub-expressions:
# 99. m_{1}
#     core type: IndexedVar
# variable: 102
# index: 104
# 100. t
#      core type: Literal
#      sub-expressions:
# 101. s
#      core type: Literal
#      sub-expressions:
# 102. m
#      core type: Variable
#      sub-expressions:
# 103. (1)
#      core type: ExprTuple
#      sub-expressions: 104
# 104. 1
#      core type: Literal
#      sub-expressions:
