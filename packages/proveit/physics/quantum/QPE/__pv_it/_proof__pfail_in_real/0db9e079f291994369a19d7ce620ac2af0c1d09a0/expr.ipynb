# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, VertExprArray, m
from proveit.logic import InSet
from proveit.numbers import Add, Interval, one
from proveit.physics.quantum import NumKet, Z, ket_plus
from proveit.physics.quantum.QPE import QPE, _U, _ket_u, _m_domain, _s, _s_wire, _t
from proveit.physics.quantum.circuits import Gate, Input, Measure, MultiQubitElem, Output, Qcircuit

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(_t, one)
sub_expr3 = Add(_t, _s)
sub_expr4 = IndexedVar(m, one)
sub_expr5 = Interval(sub_expr2, sub_expr3)
sub_expr6 = MultiQubitElem(element = Gate(operation = QPE(_U, _t), part = sub_expr1), targets = Interval(one, sub_expr3))
expr = Conditional(Qcircuit(vert_expr_array = VertExprArray([ExprRange(sub_expr1, Input(state = ket_plus), one, _t), ExprRange(sub_expr1, MultiQubitElem(element = Input(state = _ket_u, part = sub_expr1), targets = sub_expr5), one, _s)], [ExprRange(sub_expr1, sub_expr6, one, _t), ExprRange(sub_expr1, sub_expr6, sub_expr2, sub_expr3)], [ExprRange(sub_expr1, Measure(basis = Z), one, _t), _s_wire], [ExprRange(sub_expr1, MultiQubitElem(element = Output(state = NumKet(sub_expr4, _t), part = sub_expr1), targets = Interval(one, _t)), one, _t), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = _ket_u, part = sub_expr1), targets = sub_expr5), one, _s)])), InSet(sub_expr4, _m_domain))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert + \rangle} & \multigate{4}{\textrm{QPE}\left(U, t\right)} & \meter & \multiqout{3}{\lvert m_{1} \rangle_{t}} \\
# \qin{\lvert + \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & \meter & \ghostqout{\lvert m_{1} \rangle_{t}} \\
# \qin{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} & \ghost{\textrm{QPE}\left(U, t\right)} & \measure{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} \qw & \ghostqout{\lvert m_{1} \rangle_{t}} \\
# \qin{\lvert + \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & \meter & \ghostqout{\lvert m_{1} \rangle_{t}} \\
# \qin{\lvert u \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & { /^{s} } \qw & \qout{\lvert u \rangle}
# } \end{array} \textrm{ if } m_{1} \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))) if m_{1} in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. m_{1} in {0 .. 2^{t} - 1}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. QCIRCUIT
#    core type: Literal
#    sub-expressions:
# 4. VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (m_{1}, {0 .. 2^{t} - 1})
#    core type: ExprTuple
#    sub-expressions: 91, 11
# 7. ([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 8. ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 9. ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I})
#    core type: ExprTuple
#    sub-expressions: 16, 17
# 10. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 11. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 73
#     operands: 20
# 12. [INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 96
#     end_index: 92
# 13. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 96
#     end_index: 93
# 14. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 96
#     end_index: 92
# 15. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 81
#     end_index: 82
# 16. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 96
#     end_index: 92
# 17. [GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 96
#     end_index: 93
# 18. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:t}, targets:{1 .. t}}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 96
#     end_index: 92
# 19. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 96
#     end_index: 93
# 20. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 21. _a -> [INPUT]{state:|+〉}
#     core type: Lambda
#     parameter: 80
#     body: 30
# 22. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 80
#     body: 31
# 23. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 80
#     body: 32
# 24. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 80
#     body: 33
# 25. _a -> [GATE]{operation:I}
#     core type: Lambda
#     parameter: 80
#     body: 34
# 26. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 80
#     body: 35
# 27. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 80
#     body: 37
# 28. 0
#     core type: Literal
#     sub-expressions:
# 29. 2^{t} - 1
#     core type: Operation
#     operator: 88
#     operands: 38
# 30. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 65
#     operands: 39
# 31. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 46
#     operands: 40
# 32. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 46
#     operands: 41
# 33. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 42
#     operands: 43
# 34. [GATE]{operation:I}
#     core type: Operation
#     operator: 66
#     operands: 44
# 35. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m_{1}〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 46
#     operands: 45
# 36. (_a)
#     core type: ExprTuple
#     sub-expressions: 80
# 37. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 46
#     operands: 47
# 38. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 39. {state:|+〉}
#     core type: NamedExprs
#     state: 50
# 40. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 51
#     targets: 59
# 41. {element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 52
#     targets: 53
# 42. MEASURE
#     core type: Literal
#     sub-expressions:
# 43. {basis:Z}
#     core type: NamedExprs
#     basis: 54
# 44. {operation:I}
#     core type: NamedExprs
#     operation: 55
# 45. {element:[OUTPUT]{state:|m_{1}〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 56
#     targets: 57
# 46. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 47. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 58
#     targets: 59
# 48. 2^{t}
#     core type: Operation
#     operator: 60
#     operands: 61
# 49. -1
#     core type: Operation
#     operator: 62
#     operand: 96
# 50. |+〉
#     core type: Operation
#     operator: 63
#     operand: 76
# 51. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 65
#     operands: 72
# 52. [GATE]{operation:QPE(U, t), part:_a}
#     core type: Operation
#     operator: 66
#     operands: 67
# 53. {1 .. t + s}
#     core type: Operation
#     operator: 73
#     operands: 68
# 54. Z
#     core type: Literal
#     sub-expressions:
# 55. I
#     core type: Literal
#     sub-expressions:
# 56. [OUTPUT]{state:|m_{1}〉_{t}, part:_a}
#     core type: Operation
#     operator: 71
#     operands: 69
# 57. {1 .. t}
#     core type: Operation
#     operator: 73
#     operands: 70
# 58. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 71
#     operands: 72
# 59. {t + 1 .. t + s}
#     core type: Operation
#     operator: 73
#     operands: 74
# 60. Exp
#     core type: Literal
#     sub-expressions:
# 61. (2, t)
#     core type: ExprTuple
#     sub-expressions: 75, 92
# 62. -
#     core type: Literal
#     sub-expressions:
# 63. KET
#     core type: Literal
#     sub-expressions:
# 64. (+)
#     core type: ExprTuple
#     sub-expressions: 76
# 65. INPUT
#     core type: Literal
#     sub-expressions:
# 66. GATE
#     core type: Literal
#     sub-expressions:
# 67. {operation:QPE(U, t), part:_a}
#     core type: NamedExprs
#     operation: 77
#     part: 80
# 68. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 96, 82
# 69. {state:|m_{1}〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 78
#     part: 80
# 70. (1, t)
#     core type: ExprTuple
#     sub-expressions: 96, 92
# 71. OUTPUT
#     core type: Literal
#     sub-expressions:
# 72. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 79
#     part: 80
# 73. Interval
#     core type: Literal
#     sub-expressions:
# 74. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 81, 82
# 75. 2
#     core type: Literal
#     sub-expressions:
# 76. +
#     core type: Literal
#     sub-expressions:
# 77. QPE(U, t)
#     core type: Operation
#     operator: 83
#     operands: 84
# 78. |m_{1}〉_{t}
#     core type: Operation
#     operator: 85
#     operands: 86
# 79. |u>
#     core type: Literal
#     sub-expressions:
# 80. _a
#     core type: Variable
#     sub-expressions:
# 81. t + 1
#     core type: Operation
#     operator: 88
#     operands: 87
# 82. t + s
#     core type: Operation
#     operator: 88
#     operands: 89
# 83. QPE
#     core type: Literal
#     sub-expressions:
# 84. (U, t)
#     core type: ExprTuple
#     sub-expressions: 90, 92
# 85. NUM_KET
#     core type: Literal
#     sub-expressions:
# 86. (m_{1}, t)
#     core type: ExprTuple
#     sub-expressions: 91, 92
# 87. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 92, 96
# 88. +
#     core type: Literal
#     sub-expressions:
# 89. (t, s)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 90. U
#     core type: Literal
#     sub-expressions:
# 91. m_{1}
#     core type: IndexedVar
# variable: 94
# index: 96
# 92. t
#     core type: Literal
#     sub-expressions:
# 93. s
#     core type: Literal
#     sub-expressions:
# 94. m
#     core type: Variable
#     sub-expressions:
# 95. (1)
#     core type: ExprTuple
#     sub-expressions: 96
# 96. 1
#     core type: Literal
#     sub-expressions:
