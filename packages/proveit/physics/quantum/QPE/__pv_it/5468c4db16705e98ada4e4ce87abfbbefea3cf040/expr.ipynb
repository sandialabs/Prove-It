# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.linalg.MatrixProd.html">MatrixProd</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Literal
from proveit.linalg import MatrixProd
from proveit.physics.quantum import Ket

# %%
# build up the expression from sub-expressions
expr = MatrixProd(Literal("U", context = "proveit.physics.quantum.QPE"), Ket(Literal("u", context = "proveit.physics.quantum.QPE")))
# Out:
# expr: U . |u〉

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# U \thinspace \lvert u \rangle

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. U . |u〉
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. .
#    core type: Literal
#    sub-expressions:
# 2. (U, |u〉)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. U
#    core type: Literal
#    sub-expressions:
# 4. |u〉
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. KET
#    core type: Literal
#    sub-expressions:
# 6. u
#    core type: Literal
#    sub-expressions:
