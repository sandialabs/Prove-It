# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, m
from proveit.logic import And, InSet
from proveit.numbers import LessEq, ModAbs, subtract
from proveit.physics.quantum.QPE import _b_floor, _e_value, _m_domain, _phase_est_circuit, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = Conditional(_phase_est_circuit, And(InSet(m, _m_domain), LessEq(ModAbs(subtract(m, _b_floor), _two_pow_t), _e_value)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert + \rangle} & \multigate{4}{\textrm{QPE}\left(U, t\right)} & \meter & \multiqout{3}{\lvert m \rangle_{t}} \\
# \qin{\lvert + \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & \meter & \ghostqout{\lvert m \rangle_{t}} \\
# \qin{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} & \ghost{\textrm{QPE}\left(U, t\right)} & \measure{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} \qw & \ghostqout{\lvert m \rangle_{t}} \\
# \qin{\lvert + \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & \meter & \ghostqout{\lvert m \rangle_{t}} \\
# \qin{\lvert u \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & { /^{s} } \qw & \qout{\lvert u \rangle}
# } \end{array} \textrm{ if } m \in \{0~\ldotp \ldotp~2^{t} - 1\} ,  \left|m - b_{\textit{f}}\right|_{\textup{mod}\thinspace 2^{t}} \leq \left(2^{t - n} - 1\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))) if m in {0 .. 2^{t} - 1} ,  |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (m in {0 .. 2^{t} - 1}) and (|m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1))
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. QCIRCUIT
#    core type: Literal
#    sub-expressions:
# 4. VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (m in {0 .. 2^{t} - 1}, |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 7. ([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 8. ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 15, 16
# 9. ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I})
#    core type: ExprTuple
#    sub-expressions: 17, 18
# 10. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 11. m in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 21
#     operands: 22
# 12. |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1)
#     core type: Operation
#     operator: 23
#     operands: 24
# 13. [INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 113
#     end_index: 114
# 14. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 113
#     end_index: 115
# 15. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 113
#     end_index: 114
# 16. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 94
#     end_index: 95
# 17. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 113
#     end_index: 114
# 18. [GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 113
#     end_index: 115
# 19. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 113
#     end_index: 114
# 20. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 113
#     end_index: 115
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (m, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 112, 32
# 23. <=
#     core type: Literal
#     sub-expressions:
# 24. (|m - b_{f}|_{mod 2^{t}}, 2^{t - n} - 1)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 25. _a -> [INPUT]{state:|+〉}
#     core type: Lambda
#     parameter: 93
#     body: 35
# 26. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 93
#     body: 36
# 27. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 93
#     body: 37
# 28. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 93
#     body: 38
# 29. _a -> [GATE]{operation:I}
#     core type: Lambda
#     parameter: 93
#     body: 39
# 30. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 93
#     body: 40
# 31. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 93
#     body: 42
# 32. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 83
#     operands: 43
# 33. |m - b_{f}|_{mod 2^{t}}
#     core type: Operation
#     operator: 44
#     operands: 45
# 34. 2^{t - n} - 1
#     core type: Operation
#     operator: 106
#     operands: 46
# 35. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 75
#     operands: 47
# 36. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 54
#     operands: 48
# 37. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 54
#     operands: 49
# 38. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 50
#     operands: 51
# 39. [GATE]{operation:I}
#     core type: Operation
#     operator: 76
#     operands: 52
# 40. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 54
#     operands: 53
# 41. (_a)
#     core type: ExprTuple
#     sub-expressions: 93
# 42. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 54
#     operands: 55
# 43. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 44. ModAbs
#     core type: Literal
#     sub-expressions:
# 45. (m - b_{f}, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 58, 85
# 46. (2^{t - n}, -1)
#     core type: ExprTuple
#     sub-expressions: 59, 86
# 47. {state:|+〉}
#     core type: NamedExprs
#     state: 60
# 48. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 61
#     targets: 69
# 49. {element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 62
#     targets: 63
# 50. MEASURE
#     core type: Literal
#     sub-expressions:
# 51. {basis:Z}
#     core type: NamedExprs
#     basis: 64
# 52. {operation:I}
#     core type: NamedExprs
#     operation: 65
# 53. {element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 66
#     targets: 67
# 54. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 55. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 68
#     targets: 69
# 56. 0
#     core type: Literal
#     sub-expressions:
# 57. 2^{t} - 1
#     core type: Operation
#     operator: 106
#     operands: 70
# 58. m - b_{f}
#     core type: Operation
#     operator: 106
#     operands: 71
# 59. 2^{t - n}
#     core type: Operation
#     operator: 96
#     operands: 72
# 60. |+〉
#     core type: Operation
#     operator: 73
#     operand: 89
# 61. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 75
#     operands: 82
# 62. [GATE]{operation:QPE(U, t), part:_a}
#     core type: Operation
#     operator: 76
#     operands: 77
# 63. {1 .. t + s}
#     core type: Operation
#     operator: 83
#     operands: 78
# 64. Z
#     core type: Literal
#     sub-expressions:
# 65. I
#     core type: Literal
#     sub-expressions:
# 66. [OUTPUT]{state:|m〉_{t}, part:_a}
#     core type: Operation
#     operator: 81
#     operands: 79
# 67. {1 .. t}
#     core type: Operation
#     operator: 83
#     operands: 80
# 68. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 81
#     operands: 82
# 69. {t + 1 .. t + s}
#     core type: Operation
#     operator: 83
#     operands: 84
# 70. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 85, 86
# 71. (m, -b_{f})
#     core type: ExprTuple
#     sub-expressions: 112, 87
# 72. (2, t - n)
#     core type: ExprTuple
#     sub-expressions: 108, 88
# 73. KET
#     core type: Literal
#     sub-expressions:
# 74. (+)
#     core type: ExprTuple
#     sub-expressions: 89
# 75. INPUT
#     core type: Literal
#     sub-expressions:
# 76. GATE
#     core type: Literal
#     sub-expressions:
# 77. {operation:QPE(U, t), part:_a}
#     core type: NamedExprs
#     operation: 90
#     part: 93
# 78. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 113, 95
# 79. {state:|m〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 91
#     part: 93
# 80. (1, t)
#     core type: ExprTuple
#     sub-expressions: 113, 114
# 81. OUTPUT
#     core type: Literal
#     sub-expressions:
# 82. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 92
#     part: 93
# 83. Interval
#     core type: Literal
#     sub-expressions:
# 84. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 94, 95
# 85. 2^{t}
#     core type: Operation
#     operator: 96
#     operands: 97
# 86. -1
#     core type: Operation
#     operator: 116
#     operand: 113
# 87. -b_{f}
#     core type: Operation
#     operator: 116
#     operand: 109
# 88. t - n
#     core type: Operation
#     operator: 106
#     operands: 100
# 89. +
#     core type: Literal
#     sub-expressions:
# 90. QPE(U, t)
#     core type: Operation
#     operator: 101
#     operands: 102
# 91. |m〉_{t}
#     core type: Operation
#     operator: 103
#     operands: 104
# 92. |u>
#     core type: Literal
#     sub-expressions:
# 93. _a
#     core type: Variable
#     sub-expressions:
# 94. t + 1
#     core type: Operation
#     operator: 106
#     operands: 105
# 95. t + s
#     core type: Operation
#     operator: 106
#     operands: 107
# 96. Exp
#     core type: Literal
#     sub-expressions:
# 97. (2, t)
#     core type: ExprTuple
#     sub-expressions: 108, 114
# 98. (1)
#     core type: ExprTuple
#     sub-expressions: 113
# 99. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 109
# 100. (t, -n)
#      core type: ExprTuple
#      sub-expressions: 114, 110
# 101. QPE
#      core type: Literal
#      sub-expressions:
# 102. (U, t)
#      core type: ExprTuple
#      sub-expressions: 111, 114
# 103. NUM_KET
#      core type: Literal
#      sub-expressions:
# 104. (m, t)
#      core type: ExprTuple
#      sub-expressions: 112, 114
# 105. (t, 1)
#      core type: ExprTuple
#      sub-expressions: 114, 113
# 106. +
#      core type: Literal
#      sub-expressions:
# 107. (t, s)
#      core type: ExprTuple
#      sub-expressions: 114, 115
# 108. 2
#      core type: Literal
#      sub-expressions:
# 109. b_{f}
#      core type: Literal
#      sub-expressions:
# 110. -n
#      core type: Operation
#      operator: 116
#      operand: 118
# 111. U
#      core type: Literal
#      sub-expressions:
# 112. m
#      core type: Variable
#      sub-expressions:
# 113. 1
#      core type: Literal
#      sub-expressions:
# 114. t
#      core type: Literal
#      sub-expressions:
# 115. s
#      core type: Literal
#      sub-expressions:
# 116. -
#      core type: Literal
#      sub-expressions:
# 117. (n)
#      core type: ExprTuple
#      sub-expressions: 118
# 118. n
#      core type: Literal
#      sub-expressions:
