# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Literal
from proveit._common_ import l
from proveit.logic import And, InSet
from proveit.number import Abs, GreaterEq, Integers, Reals, zero
from proveit.physics.quantum.QPE import SubIndexed

# %%
# build up the expression from sub-expressions
subExpr1 = Abs(SubIndexed(Literal("alpha", latexFormat = r"\alpha", context = "proveit.physics.quantum.QPE"), l))
expr = Lambda(l, Conditional(And(InSet(subExpr1, Reals), GreaterEq(subExpr1, zero)), InSet(l, Integers)))
# Out:
# expr: l -> {(|alpha_{l}| in Reals) and (|alpha_{l}| >= 0) if l in Integers.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# l \mapsto \left\{\left(\left|\alpha_{l}\right| \in \mathbb{R}\right) \land \left(\left|\alpha_{l}\right| \geq 0\right) \textrm{ if } l \in \mathbb{Z}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. l -> {(|alpha_{l}| in Reals) and (|alpha_{l}| >= 0) if l in Integers.
#    core type: Lambda
#    parameter: 22
#    body: 1
# 1. {(|alpha_{l}| in Reals) and (|alpha_{l}| >= 0) if l in Integers.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (|alpha_{l}| in Reals) and (|alpha_{l}| >= 0)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. l in Integers
#    core type: Operation
#    operator: 10
#    operands: 6
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (|alpha_{l}| in Reals, |alpha_{l}| >= 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (l, Integers)
#    core type: ExprTuple
#    sub-expressions: 22, 9
# 7. |alpha_{l}| in Reals
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. |alpha_{l}| >= 0
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. Integers
#    core type: Literal
#    sub-expressions:
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (|alpha_{l}|, Reals)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. >=
#     core type: Literal
#     sub-expressions:
# 13. (|alpha_{l}|, 0)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. Reals
#     core type: Literal
#     sub-expressions:
# 15. |alpha_{l}|
#     core type: Operation
#     operator: 17
#     operand: 18
# 16. 0
#     core type: Literal
#     sub-expressions:
# 17. Abs
#     core type: Literal
#     sub-expressions:
# 18. alpha_{l}
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 20. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. alpha
#     core type: Literal
#     sub-expressions:
# 22. l
#     core type: Variable
#     sub-expressions:
