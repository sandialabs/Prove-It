# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.LessEq.html">LessEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.numbers import Add, Exp, Mult, Neg, four, frac, greater_eq, one, subtract, three, two
from proveit.physics.quantum.QPE import _eps, _n, _t

# %%
# build up the expression from sub-expressions
sub_expr1 = frac(one, _eps)
sub_expr2 = subtract(Exp(two, subtract(_t, _n)), one)
expr = greater_eq(Add(one, Neg(frac(one, Mult(two, sub_expr2))), Neg(frac(one, Mult(four, Exp(sub_expr2, two))))), subtract(one, frac(Add(three, sub_expr1), Exp(Add(two, sub_expr1), two))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(1 - \frac{1}{2 \cdot \left(2^{t - n} - 1\right)} - \frac{1}{4 \cdot \left(2^{t - n} - 1\right)^{2}}\right) \geq \left(1 - \frac{3 + \frac{1}{\epsilon}}{\left(2 + \frac{1}{\epsilon}\right)^{2}}\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: reversed
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (1 - (1 / (2 * (2^{t - n} - 1))) - (1 / (4 * (2^{t - n} - 1)^{2}))) >= (1 - ((3 + (1 / eps)) / (2 + (1 / eps))^{2}))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=
#    core type: Literal
#    sub-expressions:
# 2. (1 - ((3 + (1 / eps)) / (2 + (1 / eps))^{2}), 1 - (1 / (2 * (2^{t - n} - 1))) - (1 / (4 * (2^{t - n} - 1)^{2})))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 1 - ((3 + (1 / eps)) / (2 + (1 / eps))^{2})
#    core type: Operation
#    operator: 48
#    operands: 5
# 4. 1 - (1 / (2 * (2^{t - n} - 1))) - (1 / (4 * (2^{t - n} - 1)^{2}))
#    core type: Operation
#    operator: 48
#    operands: 6
# 5. (1, -((3 + (1 / eps)) / (2 + (1 / eps))^{2}))
#    core type: ExprTuple
#    sub-expressions: 47, 7
# 6. (1, -(1 / (2 * (2^{t - n} - 1))), -(1 / (4 * (2^{t - n} - 1)^{2})))
#    core type: ExprTuple
#    sub-expressions: 47, 8, 9
# 7. -((3 + (1 / eps)) / (2 + (1 / eps))^{2})
#    core type: Operation
#    operator: 52
#    operand: 13
# 8. -(1 / (2 * (2^{t - n} - 1)))
#    core type: Operation
#    operator: 52
#    operand: 14
# 9. -(1 / (4 * (2^{t - n} - 1)^{2}))
#    core type: Operation
#    operator: 52
#    operand: 15
# 10. ((3 + (1 / eps)) / (2 + (1 / eps))^{2})
#     core type: ExprTuple
#     sub-expressions: 13
# 11. (1 / (2 * (2^{t - n} - 1)))
#     core type: ExprTuple
#     sub-expressions: 14
# 12. (1 / (4 * (2^{t - n} - 1)^{2}))
#     core type: ExprTuple
#     sub-expressions: 15
# 13. (3 + (1 / eps)) / (2 + (1 / eps))^{2}
#     core type: Operation
#     operator: 36
#     operands: 16
# 14. 1 / (2 * (2^{t - n} - 1))
#     core type: Operation
#     operator: 36
#     operands: 17
# 15. 1 / (4 * (2^{t - n} - 1)^{2})
#     core type: Operation
#     operator: 36
#     operands: 18
# 16. (3 + (1 / eps), (2 + (1 / eps))^{2})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. (1, 2 * (2^{t - n} - 1))
#     core type: ExprTuple
#     sub-expressions: 47, 21
# 18. (1, 4 * (2^{t - n} - 1)^{2})
#     core type: ExprTuple
#     sub-expressions: 47, 22
# 19. 3 + (1 / eps)
#     core type: Operation
#     operator: 48
#     operands: 23
# 20. (2 + (1 / eps))^{2}
#     core type: Operation
#     operator: 42
#     operands: 24
# 21. 2 * (2^{t - n} - 1)
#     core type: Operation
#     operator: 26
#     operands: 25
# 22. 4 * (2^{t - n} - 1)^{2}
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. (3, 1 / eps)
#     core type: ExprTuple
#     sub-expressions: 28, 34
# 24. (2 + (1 / eps), 2)
#     core type: ExprTuple
#     sub-expressions: 29, 45
# 25. (2, 2^{t - n} - 1)
#     core type: ExprTuple
#     sub-expressions: 45, 35
# 26. *
#     core type: Literal
#     sub-expressions:
# 27. (4, (2^{t - n} - 1)^{2})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. 3
#     core type: Literal
#     sub-expressions:
# 29. 2 + (1 / eps)
#     core type: Operation
#     operator: 48
#     operands: 32
# 30. 4
#     core type: Literal
#     sub-expressions:
# 31. (2^{t - n} - 1)^{2}
#     core type: Operation
#     operator: 42
#     operands: 33
# 32. (2, 1 / eps)
#     core type: ExprTuple
#     sub-expressions: 45, 34
# 33. (2^{t - n} - 1, 2)
#     core type: ExprTuple
#     sub-expressions: 35, 45
# 34. 1 / eps
#     core type: Operation
#     operator: 36
#     operands: 37
# 35. 2^{t - n} - 1
#     core type: Operation
#     operator: 48
#     operands: 38
# 36. /
#     core type: Literal
#     sub-expressions:
# 37. (1, eps)
#     core type: ExprTuple
#     sub-expressions: 47, 39
# 38. (2^{t - n}, -1)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 39. eps
#     core type: Literal
#     sub-expressions:
# 40. 2^{t - n}
#     core type: Operation
#     operator: 42
#     operands: 43
# 41. -1
#     core type: Operation
#     operator: 52
#     operand: 47
# 42. Exp
#     core type: Literal
#     sub-expressions:
# 43. (2, t - n)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 44. (1)
#     core type: ExprTuple
#     sub-expressions: 47
# 45. 2
#     core type: Literal
#     sub-expressions:
# 46. t - n
#     core type: Operation
#     operator: 48
#     operands: 49
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (t, -n)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 50. t
#     core type: Literal
#     sub-expressions:
# 51. -n
#     core type: Operation
#     operator: 52
#     operand: 54
# 52. -
#     core type: Literal
#     sub-expressions:
# 53. (n)
#     core type: ExprTuple
#     sub-expressions: 54
# 54. n
#     core type: Literal
#     sub-expressions:
