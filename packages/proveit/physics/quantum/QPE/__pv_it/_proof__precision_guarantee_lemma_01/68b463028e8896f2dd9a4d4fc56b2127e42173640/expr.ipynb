# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.LessEq.html">LessEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.numbers import Add, Exp, Mult, Neg, four, frac, greater_eq, one, subtract, three, two
from proveit.physics.quantum.QPE import _eps, _n, _t

# %%
# build up the expression from sub-expressions
sub_expr1 = subtract(Exp(two, subtract(_t, _n)), one)
expr = greater_eq(Add(one, Neg(frac(one, Mult(two, sub_expr1))), Neg(frac(one, Mult(four, Exp(sub_expr1, two))))), subtract(one, Mult(_eps, frac(Add(Mult(three, _eps), one), Exp(Add(Mult(two, _eps), one), two)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(1 - \frac{1}{2 \cdot \left(2^{t - n} - 1\right)} - \frac{1}{4 \cdot \left(2^{t - n} - 1\right)^{2}}\right) \geq \left(1 - \left(\epsilon \cdot \frac{\left(3 \cdot \epsilon\right) + 1}{\left(\left(2 \cdot \epsilon\right) + 1\right)^{2}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: reversed
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (1 - (1 / (2 * (2^{t - n} - 1))) - (1 / (4 * (2^{t - n} - 1)^{2}))) >= (1 - (eps * (((3 * eps) + 1) / ((2 * eps) + 1)^{2})))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=
#    core type: Literal
#    sub-expressions:
# 2. (1 - (eps * (((3 * eps) + 1) / ((2 * eps) + 1)^{2})), 1 - (1 / (2 * (2^{t - n} - 1))) - (1 / (4 * (2^{t - n} - 1)^{2})))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 1 - (eps * (((3 * eps) + 1) / ((2 * eps) + 1)^{2}))
#    core type: Operation
#    operator: 52
#    operands: 5
# 4. 1 - (1 / (2 * (2^{t - n} - 1))) - (1 / (4 * (2^{t - n} - 1)^{2}))
#    core type: Operation
#    operator: 52
#    operands: 6
# 5. (1, -(eps * (((3 * eps) + 1) / ((2 * eps) + 1)^{2})))
#    core type: ExprTuple
#    sub-expressions: 51, 7
# 6. (1, -(1 / (2 * (2^{t - n} - 1))), -(1 / (4 * (2^{t - n} - 1)^{2})))
#    core type: ExprTuple
#    sub-expressions: 51, 8, 9
# 7. -(eps * (((3 * eps) + 1) / ((2 * eps) + 1)^{2}))
#    core type: Operation
#    operator: 56
#    operand: 13
# 8. -(1 / (2 * (2^{t - n} - 1)))
#    core type: Operation
#    operator: 56
#    operand: 14
# 9. -(1 / (4 * (2^{t - n} - 1)^{2}))
#    core type: Operation
#    operator: 56
#    operand: 15
# 10. (eps * (((3 * eps) + 1) / ((2 * eps) + 1)^{2}))
#     core type: ExprTuple
#     sub-expressions: 13
# 11. (1 / (2 * (2^{t - n} - 1)))
#     core type: ExprTuple
#     sub-expressions: 14
# 12. (1 / (4 * (2^{t - n} - 1)^{2}))
#     core type: ExprTuple
#     sub-expressions: 15
# 13. eps * (((3 * eps) + 1) / ((2 * eps) + 1)^{2})
#     core type: Operation
#     operator: 43
#     operands: 16
# 14. 1 / (2 * (2^{t - n} - 1))
#     core type: Operation
#     operator: 22
#     operands: 17
# 15. 1 / (4 * (2^{t - n} - 1)^{2})
#     core type: Operation
#     operator: 22
#     operands: 18
# 16. (eps, ((3 * eps) + 1) / ((2 * eps) + 1)^{2})
#     core type: ExprTuple
#     sub-expressions: 48, 19
# 17. (1, 2 * (2^{t - n} - 1))
#     core type: ExprTuple
#     sub-expressions: 51, 20
# 18. (1, 4 * (2^{t - n} - 1)^{2})
#     core type: ExprTuple
#     sub-expressions: 51, 21
# 19. ((3 * eps) + 1) / ((2 * eps) + 1)^{2}
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. 2 * (2^{t - n} - 1)
#     core type: Operation
#     operator: 43
#     operands: 24
# 21. 4 * (2^{t - n} - 1)^{2}
#     core type: Operation
#     operator: 43
#     operands: 25
# 22. /
#     core type: Literal
#     sub-expressions:
# 23. ((3 * eps) + 1, ((2 * eps) + 1)^{2})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. (2, 2^{t - n} - 1)
#     core type: ExprTuple
#     sub-expressions: 49, 35
# 25. (4, (2^{t - n} - 1)^{2})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. (3 * eps) + 1
#     core type: Operation
#     operator: 52
#     operands: 30
# 27. ((2 * eps) + 1)^{2}
#     core type: Operation
#     operator: 45
#     operands: 31
# 28. 4
#     core type: Literal
#     sub-expressions:
# 29. (2^{t - n} - 1)^{2}
#     core type: Operation
#     operator: 45
#     operands: 32
# 30. (3 * eps, 1)
#     core type: ExprTuple
#     sub-expressions: 33, 51
# 31. ((2 * eps) + 1, 2)
#     core type: ExprTuple
#     sub-expressions: 34, 49
# 32. (2^{t - n} - 1, 2)
#     core type: ExprTuple
#     sub-expressions: 35, 49
# 33. 3 * eps
#     core type: Operation
#     operator: 43
#     operands: 36
# 34. (2 * eps) + 1
#     core type: Operation
#     operator: 52
#     operands: 37
# 35. 2^{t - n} - 1
#     core type: Operation
#     operator: 52
#     operands: 38
# 36. (3, eps)
#     core type: ExprTuple
#     sub-expressions: 39, 48
# 37. (2 * eps, 1)
#     core type: ExprTuple
#     sub-expressions: 40, 51
# 38. (2^{t - n}, -1)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 39. 3
#     core type: Literal
#     sub-expressions:
# 40. 2 * eps
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. 2^{t - n}
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. -1
#     core type: Operation
#     operator: 56
#     operand: 51
# 43. *
#     core type: Literal
#     sub-expressions:
# 44. (2, eps)
#     core type: ExprTuple
#     sub-expressions: 49, 48
# 45. Exp
#     core type: Literal
#     sub-expressions:
# 46. (2, t - n)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 47. (1)
#     core type: ExprTuple
#     sub-expressions: 51
# 48. eps
#     core type: Literal
#     sub-expressions:
# 49. 2
#     core type: Literal
#     sub-expressions:
# 50. t - n
#     core type: Operation
#     operator: 52
#     operands: 53
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. +
#     core type: Literal
#     sub-expressions:
# 53. (t, -n)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 54. t
#     core type: Literal
#     sub-expressions:
# 55. -n
#     core type: Operation
#     operator: 56
#     operand: 58
# 56. -
#     core type: Literal
#     sub-expressions:
# 57. (n)
#     core type: ExprTuple
#     sub-expressions: 58
# 58. n
#     core type: Literal
#     sub-expressions:
