# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import eps
from proveit.logic import InSet
from proveit.number import NaturalsPos, Reals
from proveit.physics.quantum.QPE import Psuccess

# %%
# build up the expression from sub-expressions
expr = Lambda(eps, Conditional(InSet(Psuccess(eps), Reals), InSet(eps, NaturalsPos)))
# Out:
# expr: eps -> {[Psuccess](eps) in Reals if eps in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \varepsilon \mapsto \left\{\left[P_{\rm success}\right]\left(\varepsilon\right) \in \mathbb{R} \textrm{ if } \varepsilon \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. eps -> {[Psuccess](eps) in Reals if eps in NaturalsPos.
#    core type: Lambda
#    parameter: 11
#    body: 1
# 1. {[Psuccess](eps) in Reals if eps in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. [Psuccess](eps) in Reals
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. eps in NaturalsPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. ([Psuccess](eps), Reals)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (eps, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 11, 9
# 7. [Psuccess](eps)
#    core type: Operation
#    operator: 10
#    operand: 11
# 8. Reals
#    core type: Literal
#    sub-expressions:
# 9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. Psuccess
#     core type: Literal
#     sub-expressions:
# 11. eps
#     core type: Variable
#     sub-expressions:
