# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Literal
from proveit._common_ import l
from proveit.number import Add, Exp, Mult, Neg, four, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(four, Exp(Add(l, Neg(Mult(Exp(two, Literal("t", context = "proveit.physics.quantum.QPE")), Literal("delta", latexFormat = r"\delta", context = "proveit.physics.quantum.QPE")))), two))
# Out:
# expr: (4, (l - (2^{t} * delta))^{2})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(4, \left(l - \left(2^{t} \cdot \delta\right)\right)^{2}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (4, (l - (2^{t} * delta))^{2})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 4
#    core type: Literal
#    sub-expressions:
# 2. (l - (2^{t} * delta))^{2}
#    core type: Operation
#    operator: 15
#    operands: 3
# 3. (l - (2^{t} * delta), 2)
#    core type: ExprTuple
#    sub-expressions: 4, 17
# 4. l - (2^{t} * delta)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (l, -(2^{t} * delta))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. l
#    core type: Variable
#    sub-expressions:
# 8. -(2^{t} * delta)
#    core type: Operation
#    operator: 9
#    operand: 10
# 9. -
#    core type: Literal
#    sub-expressions:
# 10. 2^{t} * delta
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. 2^{t}
#     core type: Operation
# ...
