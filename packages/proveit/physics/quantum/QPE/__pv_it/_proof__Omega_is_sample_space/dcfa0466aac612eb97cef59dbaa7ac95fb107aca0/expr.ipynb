# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Variable, VertExprArray, m
from proveit.logic import InSet
from proveit.numbers import Interval, one
from proveit.physics.quantum import NumKet, Z
from proveit.physics.quantum.QPE import _Psi_ket, _m_domain, _t
from proveit.physics.quantum.circuits import Input, Measure, MultiQubitElem, Output, Qcircuit

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Interval(one, _t)
expr = Conditional(Qcircuit(vert_expr_array = VertExprArray([ExprRange(sub_expr1, MultiQubitElem(element = Input(state = _Psi_ket, part = sub_expr1), targets = sub_expr2), one, _t)], [ExprRange(sub_expr1, Measure(basis = Z), one, _t)], [ExprRange(sub_expr1, MultiQubitElem(element = Output(state = NumKet(m, _t), part = sub_expr1), targets = sub_expr2), one, _t)])), InSet(m, _m_domain))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \multiqin{3}{\lvert \Psi \rangle} & \meter & \multiqout{3}{\lvert m \rangle_{t}} \\
# \ghostqin{\lvert \Psi \rangle} & \meter & \ghostqout{\lvert m \rangle_{t}} \\
# \ghostqin{\lvert \Psi \rangle} & \measure{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} \qw & \ghostqout{\lvert m \rangle_{t}} \\
# \ghostqin{\lvert \Psi \rangle} & \meter & \ghostqout{\lvert m \rangle_{t}}
# } \end{array} \textrm{ if } m \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:t}, targets:{1 .. t}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}}))) if m in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. QCIRCUIT(VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:t}, targets:{1 .. t}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}})))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. m in {0 .. 2^{t} - 1}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. QCIRCUIT
#    core type: Literal
#    sub-expressions:
# 4. VertExprArray(([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:t}, targets:{1 .. t}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}}))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (m, {0 .. 2^{t} - 1})
#    core type: ExprTuple
#    sub-expressions: 54, 10
# 7. ([MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:t}, targets:{1 .. t}})
#    core type: ExprTuple
#    sub-expressions: 11
# 8. ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z})
#    core type: ExprTuple
#    sub-expressions: 12
# 9. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}})
#    core type: ExprTuple
#    sub-expressions: 13
# 10. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 45
#     operands: 14
# 11. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:t}, targets:{1 .. t}}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 51
#     end_index: 55
# 12. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 51
#     end_index: 55
# 13. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 51
#     end_index: 55
# 14. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 50
#     body: 20
# 16. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 50
#     body: 21
# 17. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 50
#     body: 23
# 18. 0
#     core type: Literal
#     sub-expressions:
# 19. 2^{t} - 1
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|Psi>, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 29
#     operands: 26
# 21. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 27
#     operands: 28
# 22. (_a)
#     core type: ExprTuple
#     sub-expressions: 50
# 23. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. +
#     core type: Literal
#     sub-expressions:
# 25. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 26. {element:[INPUT]{state:|Psi>, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 33
#     targets: 36
# 27. MEASURE
#     core type: Literal
#     sub-expressions:
# 28. {basis:Z}
#     core type: NamedExprs
#     basis: 34
# 29. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 30. {element:[OUTPUT]{state:|m〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 35
#     targets: 36
# 31. 2^{t}
#     core type: Operation
#     operator: 37
#     operands: 38
# 32. -1
#     core type: Operation
#     operator: 39
#     operand: 51
# 33. [INPUT]{state:|Psi>, part:_a}
#     core type: Operation
#     operator: 41
#     operands: 42
# 34. Z
#     core type: Literal
#     sub-expressions:
# 35. [OUTPUT]{state:|m〉_{t}, part:_a}
#     core type: Operation
#     operator: 43
#     operands: 44
# 36. {1 .. t}
#     core type: Operation
#     operator: 45
#     operands: 46
# 37. Exp
#     core type: Literal
#     sub-expressions:
# 38. (2, t)
#     core type: ExprTuple
#     sub-expressions: 47, 55
# 39. -
#     core type: Literal
#     sub-expressions:
# 40. (1)
#     core type: ExprTuple
#     sub-expressions: 51
# 41. INPUT
#     core type: Literal
#     sub-expressions:
# 42. {state:|Psi>, part:_a}
#     core type: NamedExprs
#     state: 48
#     part: 50
# 43. OUTPUT
#     core type: Literal
#     sub-expressions:
# 44. {state:|m〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 49
#     part: 50
# 45. Interval
#     core type: Literal
#     sub-expressions:
# 46. (1, t)
#     core type: ExprTuple
#     sub-expressions: 51, 55
# 47. 2
#     core type: Literal
#     sub-expressions:
# 48. |Psi>
#     core type: Literal
#     sub-expressions:
# 49. |m〉_{t}
#     core type: Operation
#     operator: 52
#     operands: 53
# 50. _a
#     core type: Variable
#     sub-expressions:
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. NUM_KET
#     core type: Literal
#     sub-expressions:
# 53. (m, t)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 54. m
#     core type: Variable
#     sub-expressions:
# 55. t
#     core type: Literal
#     sub-expressions:
