# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#two_pow_tMinusOne_in_posnats">two_pow_tMinusOne_in_posnats</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum.QPE._theorems_ import two_pow_tMinusOne_in_posnats

# %%
# check that the built expression is the same as the stored expression
# %check_expr two_pow_tMinusOne_in_posnats
# Out:
# Passed sanity check: built 'two_pow_tMinusOne_in_posnats' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(two_pow_tMinusOne_in_posnats.latex())
# Out:
# \vdash 2^{t - 1} \in \mathbb{N}^+

# %%
# display the expression information
two_pow_tMinusOne_in_posnats.exprInfo()
# Out:
# 0. 2^{t - 1} in NaturalsPos
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (2^{t - 1}, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2^{t - 1}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 5. Exp
#    core type: Literal
#    sub-expressions:
# 6. (2, t - 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. 2
#    core type: Literal
#    sub-expressions:
# 8. t - 1
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. t
#     core type: Literal
#     sub-expressions:
# 12. -1
#     core type: Operation
#     operator: 13
#     operand: 14
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. 1
#     core type: Literal
#     sub-expressions:
