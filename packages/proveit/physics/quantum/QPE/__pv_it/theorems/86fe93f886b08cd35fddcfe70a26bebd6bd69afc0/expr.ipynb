# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import m
from proveit.logic import Forall
from proveit.numbers import Exp, LessEq, ModAbs, one, subtract, two
from proveit.physics.quantum.QPE import _b_floor, _m_domain, _n, _success_cond, _t, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [m], instance_expr = _success_cond, domain = _m_domain, condition = LessEq(ModAbs(subtract(m, _b_floor), _two_pow_t), subtract(Exp(two, subtract(_t, _n)), one)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m \in \{0~\ldotp \ldotp~2^{t} - 1\}~|~\left|m - b_{\textit{f}}\right|_{\textup{mod}\thinspace 2^{t}} \leq \left(2^{t - n} - 1\right)}~\left(\left|\frac{m}{2^{t}} - \varphi\right|_{\textup{mod}\thinspace 1} \leq 2^{-n}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m in {0 .. 2^{t} - 1} | |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1)} (|(m / 2^{t}) - phase|_{mod 1} <= 2^{-n})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (m -> {|(m / 2^{t}) - phase|_{mod 1} <= 2^{-n} if m in {0 .. 2^{t} - 1} ,  |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. m -> {|(m / 2^{t}) - phase|_{mod 1} <= 2^{-n} if m in {0 .. 2^{t} - 1} ,  |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1).
#    core type: Lambda
#    parameter: 46
#    body: 5
# 4. (m)
#    core type: ExprTuple
#    sub-expressions: 46
# 5. {|(m / 2^{t}) - phase|_{mod 1} <= 2^{-n} if m in {0 .. 2^{t} - 1} ,  |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. |(m / 2^{t}) - phase|_{mod 1} <= 2^{-n}
#    core type: Operation
#    operator: 19
#    operands: 8
# 7. (m in {0 .. 2^{t} - 1}) and (|m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1))
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (|(m / 2^{t}) - phase|_{mod 1}, 2^{-n})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (m in {0 .. 2^{t} - 1}, |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. |(m / 2^{t}) - phase|_{mod 1}
#     core type: Operation
#     operator: 28
#     operands: 15
# 12. 2^{-n}
#     core type: Operation
#     operator: 49
#     operands: 16
# 13. m in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1)
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. ((m / 2^{t}) - phase, 1)
#     core type: ExprTuple
#     sub-expressions: 21, 56
# 16. (2, -n)
#     core type: ExprTuple
#     sub-expressions: 55, 59
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (m, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 46, 22
# 19. <=
#     core type: Literal
#     sub-expressions:
# 20. (|m - b_{f}|_{mod 2^{t}}, 2^{t - n} - 1)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. (m / 2^{t}) - phase
#     core type: Operation
#     operator: 53
#     operands: 25
# 22. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. |m - b_{f}|_{mod 2^{t}}
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. 2^{t - n} - 1
#     core type: Operation
#     operator: 53
#     operands: 30
# 25. (m / 2^{t}, -phase)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 28. ModAbs
#     core type: Literal
#     sub-expressions:
# 29. (m - b_{f}, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 35, 44
# 30. (2^{t - n}, -1)
#     core type: ExprTuple
#     sub-expressions: 36, 45
# 31. m / 2^{t}
#     core type: Operation
#     operator: 37
#     operands: 38
# 32. -phase
#     core type: Operation
#     operator: 60
#     operand: 43
# 33. 0
#     core type: Literal
#     sub-expressions:
# 34. 2^{t} - 1
#     core type: Operation
#     operator: 53
#     operands: 40
# 35. m - b_{f}
#     core type: Operation
#     operator: 53
#     operands: 41
# 36. 2^{t - n}
#     core type: Operation
#     operator: 49
#     operands: 42
# 37. /
#     core type: Literal
#     sub-expressions:
# 38. (m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 46, 44
# 39. (phase)
#     core type: ExprTuple
#     sub-expressions: 43
# 40. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. (m, -b_{f})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 42. (2, t - n)
#     core type: ExprTuple
#     sub-expressions: 55, 48
# 43. phase
#     core type: Literal
#     sub-expressions:
# 44. 2^{t}
#     core type: Operation
#     operator: 49
#     operands: 50
# 45. -1
#     core type: Operation
#     operator: 60
#     operand: 56
# 46. m
#     core type: Variable
#     sub-expressions:
# 47. -b_{f}
#     core type: Operation
#     operator: 60
#     operand: 57
# 48. t - n
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. Exp
#     core type: Literal
#     sub-expressions:
# 50. (2, t)
#     core type: ExprTuple
#     sub-expressions: 55, 58
# 51. (1)
#     core type: ExprTuple
#     sub-expressions: 56
# 52. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 57
# 53. +
#     core type: Literal
#     sub-expressions:
# 54. (t, -n)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 55. 2
#     core type: Literal
#     sub-expressions:
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. b_{f}
#     core type: Literal
#     sub-expressions:
# 58. t
#     core type: Literal
#     sub-expressions:
# 59. -n
#     core type: Operation
#     operator: 60
#     operand: 62
# 60. -
#     core type: Literal
#     sub-expressions:
# 61. (n)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. n
#     core type: Literal
#     sub-expressions:
