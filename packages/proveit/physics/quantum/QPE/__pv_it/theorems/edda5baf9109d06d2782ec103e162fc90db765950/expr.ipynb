# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import e, l
from proveit.logic import And, Forall, Iff, InSet, Union
from proveit.numbers import ModAbs, greater
from proveit.physics.quantum.QPE import _e_domain, _full_domain, _neg_domain, _pos_domain, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = greater(ModAbs(l, _two_pow_t), e)
expr = Forall(instance_param_or_params = [e], instance_expr = Iff(And(InSet(l, Union(_neg_domain, _pos_domain)), sub_expr1), And(InSet(l, _full_domain), sub_expr1)).with_wrapping_at(1), domain = _e_domain).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{e \in \{1~\ldotp \ldotp~2^{t - 1} - 2\}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left(l \in \left(\{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\} \cup \{e + 1~\ldotp \ldotp~2^{t - 1}\}\right)\right) \land \left(\left|l\right|_{\textup{mod}\thinspace 2^{t}} > e\right)\right) \\  \Leftrightarrow \left(\left(l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\}\right) \land \left(\left|l\right|_{\textup{mod}\thinspace 2^{t}} > e\right)\right) \end{array} \end{array}\right)\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{e in {1 .. 2^{t - 1} - 2}} (((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (e -> {((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)) if e in {1 .. 2^{t - 1} - 2}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. e -> {((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)) if e in {1 .. 2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 55
#    body: 5
# 4. (e)
#    core type: ExprTuple
#    sub-expressions: 55
# 5. {((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)) if e in {1 .. 2^{t - 1} - 2}.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. e in {1 .. 2^{t - 1} - 2}
#    core type: Operation
#    operator: 23
#    operands: 10
# 8. <=>
#    core type: Literal
#    sub-expressions:
# 9. ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e), (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (e, {1 .. 2^{t - 1} - 2})
#     core type: ExprTuple
#     sub-expressions: 55, 13
# 11. (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)
#     core type: Operation
#     operator: 15
#     operands: 14
# 12. (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. {1 .. 2^{t - 1} - 2}
#     core type: Operation
#     operator: 43
#     operands: 17
# 14. (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}), |l|_{mod 2^{t}} > e)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (l in {-2^{t - 1} + 1 .. 2^{t - 1}}, |l|_{mod 2^{t}} > e)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. (1, 2^{t - 1} - 2)
#     core type: ExprTuple
#     sub-expressions: 66, 21
# 18. l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})
#     core type: Operation
#     operator: 23
#     operands: 22
# 19. l in {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. |l|_{mod 2^{t}} > e
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. 2^{t - 1} - 2
#     core type: Operation
#     operator: 60
#     operands: 27
# 22. (l, {-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 40, 28
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (l, {-2^{t - 1} + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 40, 29
# 25. <
#     core type: Literal
#     sub-expressions:
# 26. (e, |l|_{mod 2^{t}})
#     core type: ExprTuple
#     sub-expressions: 55, 30
# 27. (2^{t - 1}, -2)
#     core type: ExprTuple
#     sub-expressions: 54, 31
# 28. {-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 43
#     operands: 34
# 30. |l|_{mod 2^{t}}
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. -2
#     core type: Operation
#     operator: 64
#     operand: 58
# 32. union
#     core type: Literal
#     sub-expressions:
# 33. ({-2^{t - 1} + 1 .. -(e + 1)}, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 34. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 46, 54
# 35. ModAbs
#     core type: Literal
#     sub-expressions:
# 36. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 37. (2)
#     core type: ExprTuple
#     sub-expressions: 58
# 38. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 43
#     operands: 42
# 39. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. l
#     core type: Variable
#     sub-expressions:
# 41. 2^{t}
#     core type: Operation
#     operator: 56
#     operands: 45
# 42. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. Interval
#     core type: Literal
#     sub-expressions:
# 44. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 51, 54
# 45. (2, t)
#     core type: ExprTuple
#     sub-expressions: 58, 62
# 46. -2^{t - 1} + 1
#     core type: Operation
#     operator: 60
#     operands: 48
# 47. -(e + 1)
#     core type: Operation
#     operator: 64
#     operand: 51
# 48. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 50, 66
# 49. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 51
# 50. -2^{t - 1}
#     core type: Operation
#     operator: 64
#     operand: 54
# 51. e + 1
#     core type: Operation
#     operator: 60
#     operands: 53
# 52. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 54
# 53. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 55, 66
# 54. 2^{t - 1}
#     core type: Operation
#     operator: 56
#     operands: 57
# 55. e
#     core type: Variable
#     sub-expressions:
# 56. Exp
#     core type: Literal
#     sub-expressions:
# 57. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 58. 2
#     core type: Literal
#     sub-expressions:
# 59. t - 1
#     core type: Operation
#     operator: 60
#     operands: 61
# 60. +
#     core type: Literal
#     sub-expressions:
# 61. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 62. t
#     core type: Literal
#     sub-expressions:
# 63. -1
#     core type: Operation
#     operator: 64
#     operand: 66
# 64. -
#     core type: Literal
#     sub-expressions:
# 65. (1)
#     core type: ExprTuple
#     sub-expressions: 66
# 66. 1
#     core type: Literal
#     sub-expressions:
