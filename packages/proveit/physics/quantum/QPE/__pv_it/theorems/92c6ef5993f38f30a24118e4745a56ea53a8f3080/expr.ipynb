# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, m
from proveit.logic import Equals
from proveit.numbers import Exp, Mult, Sum, e, frac, i, one, pi, subtract, two
from proveit.physics.quantum.QPE import _alpha_m_mod_two_pow_t, _m_domain, _phase, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = Equals(_alpha_m_mod_two_pow_t, Mult(frac(one, _two_pow_t), Sum(index_or_indices = [k], summand = Exp(Exp(e, Mult(two, pi, i, subtract(_phase, frac(m, _two_pow_t)))), k), domain = _m_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \alpha_{m ~\textup{mod}~ 2^{t}} = \left(\frac{1}{2^{t}} \cdot \left(\sum_{k = 0}^{2^{t} - 1} (\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\varphi - \frac{m}{2^{t}}\right)})^{k}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (alpha_{m mod 2^{t}}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. alpha_{m mod 2^{t}}
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})
#    core type: Operation
#    operator: 33
#    operands: 7
# 5. alpha
#    core type: Literal
#    sub-expressions:
# 6. (m mod 2^{t})
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. m mod 2^{t}
#    core type: Operation
#    operator: 11
#    operands: 50
# 9. 1 / 2^{t}
#    core type: Operation
#    operator: 49
#    operands: 12
# 10. Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}
#     core type: Operation
#     operator: 13
#     operand: 15
# 11. mod
#     core type: Literal
#     sub-expressions:
# 12. (1, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 45, 52
# 13. Sum
#     core type: Literal
#     sub-expressions:
# 14. (k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 15
# 15. k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 24
#     body: 17
# 16. (k)
#     core type: ExprTuple
#     sub-expressions: 24
# 17. {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 18
#     condition: 19
# 18. (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}
#     core type: Operation
#     operator: 53
#     operands: 20
# 19. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (e^{2 * pi * i * (phase - (m / 2^{t}))}, k)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. e^{2 * pi * i * (phase - (m / 2^{t}))}
#     core type: Operation
#     operator: 53
#     operands: 26
# 24. k
#     core type: Variable
#     sub-expressions:
# 25. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. (e, 2 * pi * i * (phase - (m / 2^{t})))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. Interval
#     core type: Literal
#     sub-expressions:
# 28. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. e
#     core type: Literal
#     sub-expressions:
# 30. 2 * pi * i * (phase - (m / 2^{t}))
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. 0
#     core type: Literal
#     sub-expressions:
# 32. 2^{t} - 1
#     core type: Operation
#     operator: 40
#     operands: 35
# 33. *
#     core type: Literal
#     sub-expressions:
# 34. (2, pi, i, phase - (m / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 55, 36, 37, 38
# 35. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 52, 39
# 36. pi
#     core type: Literal
#     sub-expressions:
# 37. i
#     core type: Literal
#     sub-expressions:
# 38. phase - (m / 2^{t})
#     core type: Operation
#     operator: 40
#     operands: 41
# 39. -1
#     core type: Operation
#     operator: 46
#     operand: 45
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. (phase, -(m / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 42. (1)
#     core type: ExprTuple
#     sub-expressions: 45
# 43. phase
#     core type: Literal
#     sub-expressions:
# 44. -(m / 2^{t})
#     core type: Operation
#     operator: 46
#     operand: 48
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. -
#     core type: Literal
#     sub-expressions:
# 47. (m / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 48
# 48. m / 2^{t}
#     core type: Operation
#     operator: 49
#     operands: 50
# 49. /
#     core type: Literal
#     sub-expressions:
# 50. (m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 51. m
#     core type: Variable
#     sub-expressions:
# 52. 2^{t}
#     core type: Operation
#     operator: 53
#     operands: 54
# 53. Exp
#     core type: Literal
#     sub-expressions:
# 54. (2, t)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 55. 2
#     core type: Literal
#     sub-expressions:
# 56. t
#     core type: Literal
#     sub-expressions:
