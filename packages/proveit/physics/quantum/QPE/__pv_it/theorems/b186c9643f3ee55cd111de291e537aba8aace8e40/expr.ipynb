# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, l
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.numbers import Exp, Mult, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum.QPE import _delta_b_floor, _full_domain, _rel_indexed_alpha, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(_rel_indexed_alpha, Mult(frac(one, _two_pow_t), frac(subtract(one, Exp(e, Mult(two, pi, i, subtract(Mult(_two_pow_t, _delta_b_floor), l)))), subtract(one, Exp(e, Mult(two, pi, i, subtract(_delta_b_floor, frac(l, _two_pow_t)))))))), And(InSet(l, _full_domain), NotEquals(l, zero)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\alpha_{b_{\textit{f}} \oplus l} = \left(\frac{1}{2^{t}} \cdot \frac{1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\left(2^{t} \cdot \delta_{b_{\textit{f}}}\right) - l\right)}}{1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\delta_{b_{\textit{f}}} - \frac{l}{2^{t}}\right)}}\right) \textrm{ if } l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\} ,  l \neq 0\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {alpha_{b_{f} MOD_ADD l} = ((1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}))) if l in {-2^{t - 1} + 1 .. 2^{t - 1}} ,  l != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. alpha_{b_{f} MOD_ADD l} = ((1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (l != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (alpha_{b_{f} MOD_ADD l}, (1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. alpha_{b_{f} MOD_ADD l}
#    core type: Operation
#    operator: 11
#    operand: 18
# 8. (1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}))
#    core type: Operation
#    operator: 67
#    operands: 13
# 9. l in {-2^{t - 1} + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. l != 0
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. alpha
#     core type: Literal
#     sub-expressions:
# 12. (b_{f} MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 18
# 13. (1 / 2^{t}, (1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (l, {-2^{t - 1} + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 79, 21
# 16. !=
#     core type: Literal
#     sub-expressions:
# 17. (l, 0)
#     core type: ExprTuple
#     sub-expressions: 79, 22
# 18. b_{f} MOD_ADD l
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. 1 / 2^{t}
#     core type: Operation
#     operator: 76
#     operands: 25
# 20. (1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#     core type: Operation
#     operator: 76
#     operands: 26
# 21. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 27
#     operands: 28
# 22. 0
#     core type: Literal
#     sub-expressions:
# 23. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 24. (b_{f}, l)
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 25. (1, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 66, 80
# 26. (1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}, 1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. Interval
#     core type: Literal
#     sub-expressions:
# 28. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 31, 43
# 29. 1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}
#     core type: Operation
#     operator: 60
#     operands: 32
# 30. 1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}
#     core type: Operation
#     operator: 60
#     operands: 33
# 31. -2^{t - 1} + 1
#     core type: Operation
#     operator: 60
#     operands: 34
# 32. (1, -e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)})
#     core type: ExprTuple
#     sub-expressions: 66, 35
# 33. (1, -e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#     core type: ExprTuple
#     sub-expressions: 66, 36
# 34. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 37, 66
# 35. -e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}
#     core type: Operation
#     operator: 70
#     operand: 41
# 36. -e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}
#     core type: Operation
#     operator: 70
#     operand: 42
# 37. -2^{t - 1}
#     core type: Operation
#     operator: 70
#     operand: 43
# 38. (e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)})
#     core type: ExprTuple
#     sub-expressions: 41
# 39. (e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#     core type: ExprTuple
#     sub-expressions: 42
# 40. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 43
# 41. e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}
#     core type: Operation
#     operator: 81
#     operands: 44
# 42. e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}
#     core type: Operation
#     operator: 81
#     operands: 45
# 43. 2^{t - 1}
#     core type: Operation
#     operator: 81
#     operands: 46
# 44. (e, 2 * pi * i * ((2^{t} * delta_{b_{f}}) - l))
#     core type: ExprTuple
#     sub-expressions: 48, 47
# 45. (e, 2 * pi * i * (delta_{b_{f}} - (l / 2^{t})))
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 46. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 83, 50
# 47. 2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)
#     core type: Operation
#     operator: 67
#     operands: 51
# 48. e
#     core type: Literal
#     sub-expressions:
# 49. 2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))
#     core type: Operation
#     operator: 67
#     operands: 52
# 50. t - 1
#     core type: Operation
#     operator: 60
#     operands: 53
# 51. (2, pi, i, (2^{t} * delta_{b_{f}}) - l)
#     core type: ExprTuple
#     sub-expressions: 83, 55, 56, 54
# 52. (2, pi, i, delta_{b_{f}} - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 83, 55, 56, 57
# 53. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 84, 58
# 54. (2^{t} * delta_{b_{f}}) - l
#     core type: Operation
#     operator: 60
#     operands: 59
# 55. pi
#     core type: Literal
#     sub-expressions:
# 56. i
#     core type: Literal
#     sub-expressions:
# 57. delta_{b_{f}} - (l / 2^{t})
#     core type: Operation
#     operator: 60
#     operands: 61
# 58. -1
#     core type: Operation
#     operator: 70
#     operand: 66
# 59. (2^{t} * delta_{b_{f}}, -l)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 60. +
#     core type: Literal
#     sub-expressions:
# 61. (delta_{b_{f}}, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 72, 65
# 62. (1)
#     core type: ExprTuple
#     sub-expressions: 66
# 63. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 67
#     operands: 68
# 64. -l
#     core type: Operation
#     operator: 70
#     operand: 79
# 65. -(l / 2^{t})
#     core type: Operation
#     operator: 70
#     operand: 73
# 66. 1
#     core type: Literal
#     sub-expressions:
# 67. *
#     core type: Literal
#     sub-expressions:
# 68. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 80, 72
# 69. (l)
#     core type: ExprTuple
#     sub-expressions: 79
# 70. -
#     core type: Literal
#     sub-expressions:
# 71. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 73
# 72. delta_{b_{f}}
#     core type: Operation
#     operator: 74
#     operand: 78
# 73. l / 2^{t}
#     core type: Operation
#     operator: 76
#     operands: 77
# 74. delta
#     core type: Literal
#     sub-expressions:
# 75. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 78
# 76. /
#     core type: Literal
#     sub-expressions:
# 77. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 78. b_{f}
#     core type: Literal
#     sub-expressions:
# 79. l
#     core type: Variable
#     sub-expressions:
# 80. 2^{t}
#     core type: Operation
#     operator: 81
#     operands: 82
# 81. Exp
#     core type: Literal
#     sub-expressions:
# 82. (2, t)
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 83. 2
#     core type: Literal
#     sub-expressions:
# 84. t
#     core type: Literal
#     sub-expressions:
