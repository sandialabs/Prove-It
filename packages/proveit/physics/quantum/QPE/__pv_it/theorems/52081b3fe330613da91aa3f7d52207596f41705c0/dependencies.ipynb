# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#all_alpha_l_is_complex">all_alpha_l_is_complex</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/all_alpha_l_is_complex/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.physics.quantum.QPE import all_alpha_l_is_complex

# %%
# %dependencies all_alpha_l_is_complex
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon all_alpha_l_is_complex</h3>
