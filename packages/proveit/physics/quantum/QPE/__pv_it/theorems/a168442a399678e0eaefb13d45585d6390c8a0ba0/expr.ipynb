# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Forall, InSet
from proveit.numbers import Add, IntervalCO, Neg, frac, one, two
from proveit.physics.quantum.QPE import delta_, full_domain, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = frac(one, two)
expr = Forall([l], InSet(Add(delta_, Neg(frac(l, two_pow_t))), IntervalCO(Neg(sub_expr1), sub_expr1)), domains = [full_domain])
# Out:
# expr: forall_{l in {-2^{t - 1} + 1...2^{t - 1}}} ((delta - (l / 2^{t})) in [-(1 / 2),1 / 2))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{l \in \{-2^{t - 1} + 1 \dots 2^{t - 1}\}}~\left(\left(\delta - \frac{l}{2^{t}}\right) \in \left[-\frac{1}{2},\frac{1}{2}\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{l in {-2^{t - 1} + 1...2^{t - 1}}} ((delta - (l / 2^{t})) in [-(1 / 2),1 / 2))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. l -> {(delta - (l / 2^{t})) in [-(1 / 2),1 / 2) if l in {-2^{t - 1} + 1...2^{t - 1}}.
#    core type: Lambda
#    parameter: 28
#    body: 3
# 3. {(delta - (l / 2^{t})) in [-(1 / 2),1 / 2) if l in {-2^{t - 1} + 1...2^{t - 1}}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (delta - (l / 2^{t})) in [-(1 / 2),1 / 2)
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. l in {-2^{t - 1} + 1...2^{t - 1}}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (delta - (l / 2^{t}), [-(1 / 2),1 / 2))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (l, {-2^{t - 1} + 1...2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 28, 11
# 9. delta - (l / 2^{t})
#    core type: Operation
#    operator: 36
#    operands: 12
# 10. [-(1 / 2),1 / 2)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. {-2^{t - 1} + 1...2^{t - 1}}
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (delta, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 13. IntervalCO
#     core type: Literal
#     sub-expressions:
# 14. (-(1 / 2), 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 19, 22
# 15. Interval
#     core type: Literal
#     sub-expressions:
# 16. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 20, 30
# 17. delta
#     core type: Literal
#     sub-expressions:
# 18. -(l / 2^{t})
#     core type: Operation
#     operator: 40
#     operand: 21
# 19. -(1 / 2)
#     core type: Operation
#     operator: 40
#     operand: 22
# 20. -2^{t - 1} + 1
#     core type: Operation
#     operator: 36
#     operands: 23
# 21. l / 2^{t}
#     core type: Operation
#     operator: 25
#     operands: 24
# 22. 1 / 2
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 27, 41
# 24. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. /
#     core type: Literal
#     sub-expressions:
# 26. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 41, 34
# 27. -2^{t - 1}
#     core type: Operation
#     operator: 40
#     operand: 30
# 28. l
#     core type: Variable
#     sub-expressions:
# 29. 2^{t}
#     core type: Operation
#     operator: 32
#     operands: 31
# 30. 2^{t - 1}
#     core type: Operation
#     operator: 32
#     operands: 33
# 31. (2, t)
#     core type: ExprTuple
#     sub-expressions: 34, 38
# 32. Exp
#     core type: Literal
#     sub-expressions:
# 33. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 34. 2
#     core type: Literal
#     sub-expressions:
# 35. t - 1
#     core type: Operation
#     operator: 36
#     operands: 37
# 36. +
#     core type: Literal
#     sub-expressions:
# 37. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 38. t
#     core type: Literal
#     sub-expressions:
# 39. -1
#     core type: Operation
#     operator: 40
#     operand: 41
# 40. -
#     core type: Literal
#     sub-expressions:
# 41. 1
#     core type: Literal
#     sub-expressions:
