# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, e, l
from proveit.logic import Equals, InSet
from proveit.numbers import Abs, Add, Exp, Sum, two
from proveit.physics.quantum.QPE import Pfail, _e_domain, _neg_domain, _pos_domain, _rel_indexed_alpha

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = Exp(Abs(_rel_indexed_alpha), two)
expr = Conditional(Equals(Pfail(e), Add(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = _neg_domain), Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = _pos_domain))), InSet(e, _e_domain))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\left[P_{\rm fail}\right]\left(e\right) = \left(\left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right) + \left(\sum_{l = e + 1}^{2^{t - 1}} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right)\right) \textrm{ if } e \in \{1~\ldotp \ldotp~2^{t - 1} - 2\}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {[Pfail](e) = ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})) if e in {1 .. 2^{t - 1} - 2}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. [Pfail](e) = ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. e in {1 .. 2^{t - 1} - 2}
#    core type: Operation
#    operator: 32
#    operands: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ([Pfail](e), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (e, {1 .. 2^{t - 1} - 2})
#    core type: ExprTuple
#    sub-expressions: 57, 8
# 6. [Pfail](e)
#    core type: Operation
#    operator: 9
#    operand: 57
# 7. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})
#    core type: Operation
#    operator: 64
#    operands: 11
# 8. {1 .. 2^{t - 1} - 2}
#    core type: Operation
#    operator: 40
#    operands: 12
# 9. Pfail
#    core type: Literal
#    sub-expressions:
# 10. (e)
#     core type: ExprTuple
#     sub-expressions: 57
# 11. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}, Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. (1, 2^{t - 1} - 2)
#     core type: ExprTuple
#     sub-expressions: 70, 15
# 13. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 17
#     operand: 20
# 14. Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 17
#     operand: 21
# 15. 2^{t - 1} - 2
#     core type: Operation
#     operator: 64
#     operands: 19
# 16. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#     core type: ExprTuple
#     sub-expressions: 20
# 17. Sum
#     core type: Literal
#     sub-expressions:
# 18. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. (2^{t - 1}, -2)
#     core type: ExprTuple
#     sub-expressions: 56, 22
# 20. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Lambda
#     parameter: 59
#     body: 23
# 21. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 59
#     body: 25
# 22. -2
#     core type: Operation
#     operator: 68
#     operand: 62
# 23. {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 28
#     condition: 27
# 24. (l)
#     core type: ExprTuple
#     sub-expressions: 59
# 25. {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 28
#     condition: 29
# 26. (2)
#     core type: ExprTuple
#     sub-expressions: 62
# 27. l in {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 32
#     operands: 30
# 28. |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 60
#     operands: 31
# 29. l in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 59, 34
# 31. (|alpha_{b_{f} MOD_ADD l}|, 2)
#     core type: ExprTuple
#     sub-expressions: 35, 62
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (l, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 59, 36
# 34. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 40
#     operands: 37
# 35. |alpha_{b_{f} MOD_ADD l}|
#     core type: Operation
#     operator: 38
#     operand: 44
# 36. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 38. Abs
#     core type: Literal
#     sub-expressions:
# 39. (alpha_{b_{f} MOD_ADD l})
#     core type: ExprTuple
#     sub-expressions: 44
# 40. Interval
#     core type: Literal
#     sub-expressions:
# 41. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 50, 56
# 42. -2^{t - 1} + 1
#     core type: Operation
#     operator: 64
#     operands: 45
# 43. -(e + 1)
#     core type: Operation
#     operator: 68
#     operand: 50
# 44. alpha_{b_{f} MOD_ADD l}
#     core type: Operation
#     operator: 47
#     operand: 51
# 45. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 49, 70
# 46. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 50
# 47. alpha
#     core type: Literal
#     sub-expressions:
# 48. (b_{f} MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 51
# 49. -2^{t - 1}
#     core type: Operation
#     operator: 68
#     operand: 56
# 50. e + 1
#     core type: Operation
#     operator: 64
#     operands: 53
# 51. b_{f} MOD_ADD l
#     core type: Operation
#     operator: 54
#     operands: 55
# 52. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 56
# 53. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 57, 70
# 54. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 55. (b_{f}, l)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. 2^{t - 1}
#     core type: Operation
#     operator: 60
#     operands: 61
# 57. e
#     core type: Variable
#     sub-expressions:
# 58. b_{f}
#     core type: Literal
#     sub-expressions:
# 59. l
#     core type: Variable
#     sub-expressions:
# 60. Exp
#     core type: Literal
#     sub-expressions:
# 61. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 62. 2
#     core type: Literal
#     sub-expressions:
# 63. t - 1
#     core type: Operation
#     operator: 64
#     operands: 65
# 64. +
#     core type: Literal
#     sub-expressions:
# 65. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 66. t
#     core type: Literal
#     sub-expressions:
# 67. -1
#     core type: Operation
#     operator: 68
#     operand: 70
# 68. -
#     core type: Literal
#     sub-expressions:
# 69. (1)
#     core type: ExprTuple
#     sub-expressions: 70
# 70. 1
#     core type: Literal
#     sub-expressions:
