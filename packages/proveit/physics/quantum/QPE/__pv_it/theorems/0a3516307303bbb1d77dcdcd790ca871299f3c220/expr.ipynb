# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, e, l
from proveit.logic import And, Iff, InSet, Union
from proveit.numbers import ModAbs, greater
from proveit.physics.quantum.QPE import _e_domain, _full_domain, _neg_domain, _pos_domain, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = greater(ModAbs(l, _two_pow_t), e)
expr = ExprTuple(Lambda(e, Conditional(Iff(And(InSet(l, Union(_neg_domain, _pos_domain)), sub_expr1), And(InSet(l, _full_domain), sub_expr1)).with_wrapping_at(1), InSet(e, _e_domain))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(e \mapsto \left\{\begin{array}{c} \begin{array}{l} \left(\left(l \in \left(\{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\} \cup \{e + 1~\ldotp \ldotp~2^{t - 1}\}\right)\right) \land \left(\left|l\right|_{\textup{mod}\thinspace 2^{t}} > e\right)\right) \\  \Leftrightarrow \left(\left(l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\}\right) \land \left(\left|l\right|_{\textup{mod}\thinspace 2^{t}} > e\right)\right) \end{array} \end{array} \textrm{ if } e \in \{1~\ldotp \ldotp~2^{t - 1} - 2\}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (e -> {((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)) if e in {1 .. 2^{t - 1} - 2}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. e -> {((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)) if e in {1 .. 2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 53
#    body: 3
# 2. (e)
#    core type: ExprTuple
#    sub-expressions: 53
# 3. {((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)) if e in {1 .. 2^{t - 1} - 2}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. e in {1 .. 2^{t - 1} - 2}
#    core type: Operation
#    operator: 21
#    operands: 8
# 6. <=>
#    core type: Literal
#    sub-expressions:
# 7. ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e), (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (e, {1 .. 2^{t - 1} - 2})
#    core type: ExprTuple
#    sub-expressions: 53, 11
# 9. (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)
#    core type: Operation
#    operator: 13
#    operands: 12
# 10. (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. {1 .. 2^{t - 1} - 2}
#     core type: Operation
#     operator: 41
#     operands: 15
# 12. (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}), |l|_{mod 2^{t}} > e)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (l in {-2^{t - 1} + 1 .. 2^{t - 1}}, |l|_{mod 2^{t}} > e)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. (1, 2^{t - 1} - 2)
#     core type: ExprTuple
#     sub-expressions: 64, 19
# 16. l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})
#     core type: Operation
#     operator: 21
#     operands: 20
# 17. l in {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. |l|_{mod 2^{t}} > e
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. 2^{t - 1} - 2
#     core type: Operation
#     operator: 58
#     operands: 25
# 20. (l, {-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 38, 26
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (l, {-2^{t - 1} + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 38, 27
# 23. <
#     core type: Literal
#     sub-expressions:
# 24. (e, |l|_{mod 2^{t}})
#     core type: ExprTuple
#     sub-expressions: 53, 28
# 25. (2^{t - 1}, -2)
#     core type: ExprTuple
#     sub-expressions: 52, 29
# 26. {-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 41
#     operands: 32
# 28. |l|_{mod 2^{t}}
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. -2
#     core type: Operation
#     operator: 62
#     operand: 56
# 30. union
#     core type: Literal
#     sub-expressions:
# 31. ({-2^{t - 1} + 1 .. -(e + 1)}, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 32. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 44, 52
# 33. ModAbs
#     core type: Literal
#     sub-expressions:
# 34. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. (2)
#     core type: ExprTuple
#     sub-expressions: 56
# 36. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 41
#     operands: 40
# 37. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. l
#     core type: Variable
#     sub-expressions:
# 39. 2^{t}
#     core type: Operation
#     operator: 54
#     operands: 43
# 40. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. Interval
#     core type: Literal
#     sub-expressions:
# 42. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 49, 52
# 43. (2, t)
#     core type: ExprTuple
#     sub-expressions: 56, 60
# 44. -2^{t - 1} + 1
#     core type: Operation
#     operator: 58
#     operands: 46
# 45. -(e + 1)
#     core type: Operation
#     operator: 62
#     operand: 49
# 46. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 48, 64
# 47. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 49
# 48. -2^{t - 1}
#     core type: Operation
#     operator: 62
#     operand: 52
# 49. e + 1
#     core type: Operation
#     operator: 58
#     operands: 51
# 50. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 52
# 51. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 53, 64
# 52. 2^{t - 1}
#     core type: Operation
#     operator: 54
#     operands: 55
# 53. e
#     core type: Variable
#     sub-expressions:
# 54. Exp
#     core type: Literal
#     sub-expressions:
# 55. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 56. 2
#     core type: Literal
#     sub-expressions:
# 57. t - 1
#     core type: Operation
#     operator: 58
#     operands: 59
# 58. +
#     core type: Literal
#     sub-expressions:
# 59. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 60. t
#     core type: Literal
#     sub-expressions:
# 61. -1
#     core type: Operation
#     operator: 62
#     operand: 64
# 62. -
#     core type: Literal
#     sub-expressions:
# 63. (1)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. 1
#     core type: Literal
#     sub-expressions:
