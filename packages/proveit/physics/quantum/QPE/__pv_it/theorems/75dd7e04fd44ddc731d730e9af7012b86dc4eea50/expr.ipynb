# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, l
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Abs, IntervalOC, Mult, frac, pi, subtract, two, zero
from proveit.physics.quantum.QPE import _delta_b_floor, _full_domain, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(l, Conditional(InSet(Mult(pi, Abs(subtract(_delta_b_floor, frac(l, _two_pow_t)))), IntervalOC(zero, frac(pi, two))), And(InSet(l, _full_domain), NotEquals(l, zero)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(l \mapsto \left\{\left(\pi \cdot \left|\delta_{b_{\textit{f}}} - \frac{l}{2^{t}}\right|\right) \in \left(0,\frac{\pi}{2}\right] \textrm{ if } l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\} ,  l \neq 0\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (l -> {(pi * |delta_{b_{f}} - (l / 2^{t})|) in (0,pi / 2] if l in {-2^{t - 1} + 1 .. 2^{t - 1}} ,  l != 0.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. l -> {(pi * |delta_{b_{f}} - (l / 2^{t})|) in (0,pi / 2] if l in {-2^{t - 1} + 1 .. 2^{t - 1}} ,  l != 0.
#    core type: Lambda
#    parameter: 48
#    body: 3
# 2. (l)
#    core type: ExprTuple
#    sub-expressions: 48
# 3. {(pi * |delta_{b_{f}} - (l / 2^{t})|) in (0,pi / 2] if l in {-2^{t - 1} + 1 .. 2^{t - 1}} ,  l != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (pi * |delta_{b_{f}} - (l / 2^{t})|) in (0,pi / 2]
#    core type: Operation
#    operator: 17
#    operands: 6
# 5. (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (l != 0)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (pi * |delta_{b_{f}} - (l / 2^{t})|, (0,pi / 2])
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. pi * |delta_{b_{f}} - (l / 2^{t})|
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. (0,pi / 2]
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. l in {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. l != 0
#     core type: Operation
#     operator: 19
#     operands: 20
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (pi, |delta_{b_{f}} - (l / 2^{t})|)
#     core type: ExprTuple
#     sub-expressions: 31, 21
# 15. IntervalOC
#     core type: Literal
#     sub-expressions:
# 16. (0, pi / 2)
#     core type: ExprTuple
#     sub-expressions: 24, 22
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (l, {-2^{t - 1} + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 48, 23
# 19. !=
#     core type: Literal
#     sub-expressions:
# 20. (l, 0)
#     core type: ExprTuple
#     sub-expressions: 48, 24
# 21. |delta_{b_{f}} - (l / 2^{t})|
#     core type: Operation
#     operator: 25
#     operand: 30
# 22. pi / 2
#     core type: Operation
#     operator: 45
#     operands: 27
# 23. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. 0
#     core type: Literal
#     sub-expressions:
# 25. Abs
#     core type: Literal
#     sub-expressions:
# 26. (delta_{b_{f}} - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 30
# 27. (pi, 2)
#     core type: ExprTuple
#     sub-expressions: 31, 55
# 28. Interval
#     core type: Literal
#     sub-expressions:
# 29. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 32, 44
# 30. delta_{b_{f}} - (l / 2^{t})
#     core type: Operation
#     operator: 53
#     operands: 33
# 31. pi
#     core type: Literal
#     sub-expressions:
# 32. -2^{t - 1} + 1
#     core type: Operation
#     operator: 53
#     operands: 34
# 33. (delta_{b_{f}}, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 34. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 37, 60
# 35. delta_{b_{f}}
#     core type: Operation
#     operator: 38
#     operand: 42
# 36. -(l / 2^{t})
#     core type: Operation
#     operator: 58
#     operand: 43
# 37. -2^{t - 1}
#     core type: Operation
#     operator: 58
#     operand: 44
# 38. delta
#     core type: Literal
#     sub-expressions:
# 39. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 42
# 40. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 43
# 41. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 44
# 42. b_{f}
#     core type: Literal
#     sub-expressions:
# 43. l / 2^{t}
#     core type: Operation
#     operator: 45
#     operands: 46
# 44. 2^{t - 1}
#     core type: Operation
#     operator: 51
#     operands: 47
# 45. /
#     core type: Literal
#     sub-expressions:
# 46. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 47. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 55, 50
# 48. l
#     core type: Variable
#     sub-expressions:
# 49. 2^{t}
#     core type: Operation
#     operator: 51
#     operands: 52
# 50. t - 1
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. Exp
#     core type: Literal
#     sub-expressions:
# 52. (2, t)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. +
#     core type: Literal
#     sub-expressions:
# 54. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 55. 2
#     core type: Literal
#     sub-expressions:
# 56. t
#     core type: Literal
#     sub-expressions:
# 57. -1
#     core type: Operation
#     operator: 58
#     operand: 60
# 58. -
#     core type: Literal
#     sub-expressions:
# 59. (1)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. 1
#     core type: Literal
#     sub-expressions:
