# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, l
from proveit.logic import And, InSet
from proveit.numbers import GreaterEq, Integer, Real, zero
from proveit.physics.quantum.QPE import abs_alpha_l

# %%
# build up the expression from sub-expressions
expr = Lambda(l, Conditional(And(InSet(abs_alpha_l, Real), GreaterEq(abs_alpha_l, zero)), InSet(l, Integer)))
# Out:
# expr: l -> {(|alpha_{l}| in Real) and (|alpha_{l}| >= 0) if l in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# l \mapsto \left\{\left(\left|\alpha_{l}\right| \in \mathbb{R}\right) \land \left(\left|\alpha_{l}\right| \geq 0\right) \textrm{ if } l \in \mathbb{Z}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. l -> {(|alpha_{l}| in Real) and (|alpha_{l}| >= 0) if l in Integer.
#    core type: Lambda
#    parameter: 22
#    body: 1
# 1. {(|alpha_{l}| in Real) and (|alpha_{l}| >= 0) if l in Integer.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (|alpha_{l}| in Real) and (|alpha_{l}| >= 0)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. l in Integer
#    core type: Operation
#    operator: 10
#    operands: 6
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (|alpha_{l}| in Real, |alpha_{l}| >= 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (l, Integer)
#    core type: ExprTuple
#    sub-expressions: 22, 9
# 7. |alpha_{l}| in Real
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. |alpha_{l}| >= 0
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. Integer
#    core type: Literal
#    sub-expressions:
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (|alpha_{l}|, Real)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. >=
#     core type: Literal
#     sub-expressions:
# 13. (|alpha_{l}|, 0)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. Real
#     core type: Literal
#     sub-expressions:
# 15. |alpha_{l}|
#     core type: Operation
#     operator: 17
#     operand: 18
# 16. 0
#     core type: Literal
#     sub-expressions:
# 17. Abs
#     core type: Literal
#     sub-expressions:
# 18. alpha_{l}
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 20. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. alpha
#     core type: Literal
#     sub-expressions:
# 22. l
#     core type: Variable
#     sub-expressions:
