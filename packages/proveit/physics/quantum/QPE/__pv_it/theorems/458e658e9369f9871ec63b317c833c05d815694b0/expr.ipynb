# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Div.html">Div</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.numbers import Add, Exp, Mult, Neg, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = frac(Add(one, Neg(Exp(e, Mult(two, pi, i, Add(Mult(two_pow_t, delta_), Neg(l)))))), Add(one, Neg(Exp(e, Mult(two, pi, i, Add(delta_, Neg(frac(l, two_pow_t))))))))
# Out:
# expr: (1 - e^{2 * pi * i * ((2^{t} * delta) - l)}) / (1 - e^{2 * pi * i * (delta - (l / 2^{t}))})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \frac{1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\left(2^{t} \cdot \delta\right) - l\right)}}{1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\delta - \frac{l}{2^{t}}\right)}}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1 - e^{2 * pi * i * ((2^{t} * delta) - l)}) / (1 - e^{2 * pi * i * (delta - (l / 2^{t}))})
#    core type: Operation
#    operator: 33
#    operands: 1
# 1. (1 - e^{2 * pi * i * ((2^{t} * delta) - l)}, 1 - e^{2 * pi * i * (delta - (l / 2^{t}))})
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. 1 - e^{2 * pi * i * ((2^{t} * delta) - l)}
#    core type: Operation
#    operator: 23
#    operands: 4
# 3. 1 - e^{2 * pi * i * (delta - (l / 2^{t}))}
#    core type: Operation
#    operator: 23
#    operands: 5
# 4. (1, -e^{2 * pi * i * ((2^{t} * delta) - l)})
#    core type: ExprTuple
#    sub-expressions: 7, 6
# 5. (1, -e^{2 * pi * i * (delta - (l / 2^{t}))})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. -e^{2 * pi * i * ((2^{t} * delta) - l)}
#    core type: Operation
#    operator: 30
#    operand: 9
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. -e^{2 * pi * i * (delta - (l / 2^{t}))}
#    core type: Operation
#    operator: 30
#    operand: 10
# ...
