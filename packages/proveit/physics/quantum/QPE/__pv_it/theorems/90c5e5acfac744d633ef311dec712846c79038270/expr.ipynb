# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Add, Exp, Sum, four, frac, one, two
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _neg_domain, _pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = frac(one, Exp(_diff_l_scaled_delta_floor, two))
expr = ExprTuple(frac(one, four), Add(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = _neg_domain), Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = _pos_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\frac{1}{4}, \left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right) + \left(\sum_{l = e + 1}^{2^{t - 1}} \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (1 / 4, (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 1 / 4
#    core type: Operation
#    operator: 20
#    operands: 3
# 2. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 53
#    operands: 4
# 3. (1, 4)
#    core type: ExprTuple
#    sub-expressions: 65, 5
# 4. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}), Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. 4
#    core type: Literal
#    sub-expressions:
# 6. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#    core type: Operation
#    operator: 9
#    operand: 11
# 7. Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. (l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. Sum
#    core type: Literal
#    sub-expressions:
# 10. (l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Lambda
#     parameter: 39
#     body: 13
# 12. l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 39
#     body: 15
# 13. {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 17
#     condition: 16
# 14. (l)
#     core type: ExprTuple
#     sub-expressions: 39
# 15. {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 17
#     condition: 18
# 16. l in {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 22
#     operands: 19
# 17. 1 / (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. l in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 39, 24
# 20. /
#     core type: Literal
#     sub-expressions:
# 21. (1, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 65, 25
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (l, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 39, 26
# 24. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 29
#     operands: 27
# 25. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 55
#     operands: 28
# 26. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 33, 60
# 29. Interval
#     core type: Literal
#     sub-expressions:
# 30. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 38, 44
# 31. -2^{t - 1} + 1
#     core type: Operation
#     operator: 53
#     operands: 34
# 32. -(e + 1)
#     core type: Operation
#     operator: 63
#     operand: 38
# 33. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 53
#     operands: 36
# 34. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 37, 65
# 35. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 38
# 36. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 37. -2^{t - 1}
#     core type: Operation
#     operator: 63
#     operand: 44
# 38. e + 1
#     core type: Operation
#     operator: 53
#     operands: 42
# 39. l
#     core type: Variable
#     sub-expressions:
# 40. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 63
#     operand: 46
# 41. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 44
# 42. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 45, 65
# 43. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 46
# 44. 2^{t - 1}
#     core type: Operation
#     operator: 55
#     operands: 47
# 45. e
#     core type: Variable
#     sub-expressions:
# 46. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 48
#     operands: 49
# 47. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 60, 50
# 48. *
#     core type: Literal
#     sub-expressions:
# 49. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 50. t - 1
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. 2^{t}
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. delta_{b_{f}}
#     core type: Operation
#     operator: 57
#     operand: 62
# 53. +
#     core type: Literal
#     sub-expressions:
# 54. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 61, 59
# 55. Exp
#     core type: Literal
#     sub-expressions:
# 56. (2, t)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 57. delta
#     core type: Literal
#     sub-expressions:
# 58. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 62
# 59. -1
#     core type: Operation
#     operator: 63
#     operand: 65
# 60. 2
#     core type: Literal
#     sub-expressions:
# 61. t
#     core type: Literal
#     sub-expressions:
# 62. b_{f}
#     core type: Literal
#     sub-expressions:
# 63. -
#     core type: Literal
#     sub-expressions:
# 64. (1)
#     core type: ExprTuple
#     sub-expressions: 65
# 65. 1
#     core type: Literal
#     sub-expressions:
