# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, e, l
from proveit.logic import Equals, InSet
from proveit.numbers import Abs, Add, Exp, Sum, two
from proveit.physics.quantum.QPE import Pfail, _e_domain, _neg_domain, _pos_domain, _rel_indexed_alpha

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = Exp(Abs(_rel_indexed_alpha), two)
expr = Lambda(e, Conditional(Equals(Pfail(e), Add(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = _neg_domain), Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = _pos_domain))), InSet(e, _e_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# e \mapsto \left\{\left[P_{\rm fail}\right]\left(e\right) = \left(\left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right) + \left(\sum_{l = e + 1}^{2^{t - 1}} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right)\right) \textrm{ if } e \in \{1~\ldotp \ldotp~2^{t - 1} - 2\}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. e -> {[Pfail](e) = ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})) if e in {1 .. 2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 58
#    body: 1
# 1. {[Pfail](e) = ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})) if e in {1 .. 2^{t - 1} - 2}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. [Pfail](e) = ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. e in {1 .. 2^{t - 1} - 2}
#    core type: Operation
#    operator: 33
#    operands: 6
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. ([Pfail](e), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (e, {1 .. 2^{t - 1} - 2})
#    core type: ExprTuple
#    sub-expressions: 58, 9
# 7. [Pfail](e)
#    core type: Operation
#    operator: 10
#    operand: 58
# 8. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})
#    core type: Operation
#    operator: 65
#    operands: 12
# 9. {1 .. 2^{t - 1} - 2}
#    core type: Operation
#    operator: 41
#    operands: 13
# 10. Pfail
#     core type: Literal
#     sub-expressions:
# 11. (e)
#     core type: ExprTuple
#     sub-expressions: 58
# 12. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}, Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. (1, 2^{t - 1} - 2)
#     core type: ExprTuple
#     sub-expressions: 71, 16
# 14. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 18
#     operand: 21
# 15. Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 18
#     operand: 22
# 16. 2^{t - 1} - 2
#     core type: Operation
#     operator: 65
#     operands: 20
# 17. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#     core type: ExprTuple
#     sub-expressions: 21
# 18. Sum
#     core type: Literal
#     sub-expressions:
# 19. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 22
# 20. (2^{t - 1}, -2)
#     core type: ExprTuple
#     sub-expressions: 57, 23
# 21. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Lambda
#     parameter: 60
#     body: 24
# 22. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 60
#     body: 26
# 23. -2
#     core type: Operation
#     operator: 69
#     operand: 63
# 24. {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 29
#     condition: 28
# 25. (l)
#     core type: ExprTuple
#     sub-expressions: 60
# 26. {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 29
#     condition: 30
# 27. (2)
#     core type: ExprTuple
#     sub-expressions: 63
# 28. l in {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 33
#     operands: 31
# 29. |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 61
#     operands: 32
# 30. l in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 60, 35
# 32. (|alpha_{b_{f} MOD_ADD l}|, 2)
#     core type: ExprTuple
#     sub-expressions: 36, 63
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (l, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 60, 37
# 35. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 41
#     operands: 38
# 36. |alpha_{b_{f} MOD_ADD l}|
#     core type: Operation
#     operator: 39
#     operand: 45
# 37. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 39. Abs
#     core type: Literal
#     sub-expressions:
# 40. (alpha_{b_{f} MOD_ADD l})
#     core type: ExprTuple
#     sub-expressions: 45
# 41. Interval
#     core type: Literal
#     sub-expressions:
# 42. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 51, 57
# 43. -2^{t - 1} + 1
#     core type: Operation
#     operator: 65
#     operands: 46
# 44. -(e + 1)
#     core type: Operation
#     operator: 69
#     operand: 51
# 45. alpha_{b_{f} MOD_ADD l}
#     core type: Operation
#     operator: 48
#     operand: 52
# 46. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 50, 71
# 47. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 51
# 48. alpha
#     core type: Literal
#     sub-expressions:
# 49. (b_{f} MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 52
# 50. -2^{t - 1}
#     core type: Operation
#     operator: 69
#     operand: 57
# 51. e + 1
#     core type: Operation
#     operator: 65
#     operands: 54
# 52. b_{f} MOD_ADD l
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 57
# 54. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 58, 71
# 55. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 56. (b_{f}, l)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 57. 2^{t - 1}
#     core type: Operation
#     operator: 61
#     operands: 62
# 58. e
#     core type: Variable
#     sub-expressions:
# 59. b_{f}
#     core type: Literal
#     sub-expressions:
# 60. l
#     core type: Variable
#     sub-expressions:
# 61. Exp
#     core type: Literal
#     sub-expressions:
# 62. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 63. 2
#     core type: Literal
#     sub-expressions:
# 64. t - 1
#     core type: Operation
#     operator: 65
#     operands: 66
# 65. +
#     core type: Literal
#     sub-expressions:
# 66. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 67. t
#     core type: Literal
#     sub-expressions:
# 68. -1
#     core type: Operation
#     operator: 69
#     operand: 71
# 69. -
#     core type: Literal
#     sub-expressions:
# 70. (1)
#     core type: ExprTuple
#     sub-expressions: 71
# 71. 1
#     core type: Literal
#     sub-expressions:
