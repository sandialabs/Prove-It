# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, m
from proveit.logic import And, InSet
from proveit.numbers import Exp, LessEq, ModAbs, one, subtract, two
from proveit.physics.quantum.QPE import _b_floor, _m_domain, _n, _success_cond, _t, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = Conditional(_success_cond, And(InSet(m, _m_domain), LessEq(ModAbs(subtract(m, _b_floor), _two_pow_t), subtract(Exp(two, subtract(_t, _n)), one))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\left|\frac{m}{2^{t}} - \varphi\right|_{\textup{mod}\thinspace 1} \leq 2^{-n} \textrm{ if } m \in \{0~\ldotp \ldotp~2^{t} - 1\} ,  \left|m - b_{\textit{f}}\right|_{\textup{mod}\thinspace 2^{t}} \leq \left(2^{t - n} - 1\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {|(m / 2^{t}) - phase|_{mod 1} <= 2^{-n} if m in {0 .. 2^{t} - 1} ,  |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. |(m / 2^{t}) - phase|_{mod 1} <= 2^{-n}
#    core type: Operation
#    operator: 14
#    operands: 3
# 2. (m in {0 .. 2^{t} - 1}) and (|m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (|(m / 2^{t}) - phase|_{mod 1}, 2^{-n})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (m in {0 .. 2^{t} - 1}, |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. |(m / 2^{t}) - phase|_{mod 1}
#    core type: Operation
#    operator: 23
#    operands: 10
# 7. 2^{-n}
#    core type: Operation
#    operator: 44
#    operands: 11
# 8. m in {0 .. 2^{t} - 1}
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1)
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. ((m / 2^{t}) - phase, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 51
# 11. (2, -n)
#     core type: ExprTuple
#     sub-expressions: 50, 54
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (m, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 41, 17
# 14. <=
#     core type: Literal
#     sub-expressions:
# 15. (|m - b_{f}|_{mod 2^{t}}, 2^{t - n} - 1)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. (m / 2^{t}) - phase
#     core type: Operation
#     operator: 48
#     operands: 20
# 17. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. |m - b_{f}|_{mod 2^{t}}
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. 2^{t - n} - 1
#     core type: Operation
#     operator: 48
#     operands: 25
# 20. (m / 2^{t}, -phase)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 21. Interval
#     core type: Literal
#     sub-expressions:
# 22. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 23. ModAbs
#     core type: Literal
#     sub-expressions:
# 24. (m - b_{f}, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 30, 39
# 25. (2^{t - n}, -1)
#     core type: ExprTuple
#     sub-expressions: 31, 40
# 26. m / 2^{t}
#     core type: Operation
#     operator: 32
#     operands: 33
# 27. -phase
#     core type: Operation
#     operator: 55
#     operand: 38
# 28. 0
#     core type: Literal
#     sub-expressions:
# 29. 2^{t} - 1
#     core type: Operation
#     operator: 48
#     operands: 35
# 30. m - b_{f}
#     core type: Operation
#     operator: 48
#     operands: 36
# 31. 2^{t - n}
#     core type: Operation
#     operator: 44
#     operands: 37
# 32. /
#     core type: Literal
#     sub-expressions:
# 33. (m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 41, 39
# 34. (phase)
#     core type: ExprTuple
#     sub-expressions: 38
# 35. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. (m, -b_{f})
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 37. (2, t - n)
#     core type: ExprTuple
#     sub-expressions: 50, 43
# 38. phase
#     core type: Literal
#     sub-expressions:
# 39. 2^{t}
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. -1
#     core type: Operation
#     operator: 55
#     operand: 51
# 41. m
#     core type: Variable
#     sub-expressions:
# 42. -b_{f}
#     core type: Operation
#     operator: 55
#     operand: 52
# 43. t - n
#     core type: Operation
#     operator: 48
#     operands: 49
# 44. Exp
#     core type: Literal
#     sub-expressions:
# 45. (2, t)
#     core type: ExprTuple
#     sub-expressions: 50, 53
# 46. (1)
#     core type: ExprTuple
#     sub-expressions: 51
# 47. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 52
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (t, -n)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 50. 2
#     core type: Literal
#     sub-expressions:
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. b_{f}
#     core type: Literal
#     sub-expressions:
# 53. t
#     core type: Literal
#     sub-expressions:
# 54. -n
#     core type: Operation
#     operator: 55
#     operand: 57
# 55. -
#     core type: Literal
#     sub-expressions:
# 56. (n)
#     core type: ExprTuple
#     sub-expressions: 57
# 57. n
#     core type: Literal
#     sub-expressions:
