# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import eps, l
from proveit.logic import Equals, Forall
from proveit.numbers import GreaterEq, Interval, NaturalPos, Neg, Sum
from proveit.physics.quantum.QPE import ModAdd, Psuccess, b_, m_
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Forall([eps], GreaterEq(Psuccess(eps), Sum([l], Prob(Equals(m_, ModAdd(b_, l)), m_), domains = [Interval(Neg(eps), eps)])), domains = [NaturalPos])
# Out:
# expr: forall_{eps in NaturalPos} ([Psuccess](eps) >= (Sum_{l=-eps}^{eps} Pr_{m}[m = (b MOD_ADD l)]))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{\varepsilon \in \mathbb{N}^+}~\left(\left[P_{\rm success}\right]\left(\varepsilon\right) \geq \left(\sum_{l=-\varepsilon}^{\varepsilon} Pr_{m}[m = \left(b \oplus l\right)]\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{eps in NaturalPos} ([Psuccess](eps) >= (Sum_{l=-eps}^{eps} Pr_{m}[m = (b MOD_ADD l)]))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. eps -> {[Psuccess](eps) >= (Sum_{l=-eps}^{eps} Pr_{m}[m = (b MOD_ADD l)]) if eps in NaturalPos.
#    core type: Lambda
#    parameter: 34
#    body: 3
# 3. {[Psuccess](eps) >= (Sum_{l=-eps}^{eps} Pr_{m}[m = (b MOD_ADD l)]) if eps in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. [Psuccess](eps) >= (Sum_{l=-eps}^{eps} Pr_{m}[m = (b MOD_ADD l)])
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. eps in NaturalPos
#    core type: Operation
#    operator: 20
#    operands: 8
# 6. >=
#    core type: Literal
#    sub-expressions:
# 7. ([Psuccess](eps), Sum_{l=-eps}^{eps} Pr_{m}[m = (b MOD_ADD l)])
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (eps, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 34, 11
# ...
