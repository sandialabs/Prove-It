# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#exp2pi_i_modadd">exp2pi_i_modadd</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import exp2pi_i_modadd

# %%
# check that the built expression is the same as the stored expression
assert exp2pi_i_modadd.expr == stored_expr
assert exp2pi_i_modadd.expr._style_id == stored_expr._style_id
print("Passed sanity check: exp2pi_i_modadd matches stored_expr")
# Out:
# Passed sanity check: exp2pi_i_modadd matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(exp2pi_i_modadd.latex())
# Out:
# \vdash \forall_{a, b \in \mathbb{Z}}~\left(\mathsf{e}^{\frac{2 \cdot \pi \cdot \mathsf{i} \cdot \left(a \oplus b\right)}{2^{t}}} = \mathsf{e}^{\frac{2 \cdot \pi \cdot \mathsf{i} \cdot \left(a + b\right)}{2^{t}}}\right)

# %%
# display the expression information
exp2pi_i_modadd.expr_info()
# Out:
# 0. forall_{a, b in Integer} (e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}} if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 42\n   body: 3
# 3. {e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}} if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}}, e^{(2 * pi * i * (a + b)) / 2^{t}})
#    core type: ExprTuple
# ...
