# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#fail_ineq">fail_ineq</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import fail_ineq

# %%
# check that the built expression is the same as the stored expression
assert fail_ineq.expr == stored_expr
assert fail_ineq.expr._style_id == stored_expr._style_id
print("Passed sanity check: fail_ineq matches stored_expr")
# Out:
# Passed sanity check: fail_ineq matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(fail_ineq.latex())
# Out:
# \vdash \forall_{\varepsilon \in \{1 \dots 2^{t - 1} - 2\}}~\left(\left[P_{\rm fail}\right]\left(\varepsilon\right) \leq \left(\frac{1}{2} \cdot \left(\frac{1}{\varepsilon} + \frac{1}{\varepsilon^{2}}\right)\right)\right)

# %%
# display the expression information
fail_ineq.expr_info()
# Out:
# 0. forall_{eps in {1...2^{t - 1} - 2}} ([Pfail](eps) <= ((1 / 2) * ((1 / eps) + (1 / eps^{2}))))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. eps -> {[Pfail](eps) <= ((1 / 2) * ((1 / eps) + (1 / eps^{2}))) if eps in {1...2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 38
#    body: 3
# 3. {[Pfail](eps) <= ((1 / 2) * ((1 / eps) + (1 / eps^{2}))) if eps in {1...2^{t - 1} - 2}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. [Pfail](eps) <= ((1 / 2) * ((1 / eps) + (1 / eps^{2})))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. eps in {1...2^{t - 1} - 2}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. <=
#    core type: Literal
#    sub-expressions:
# 7. ([Pfail](eps), (1 / 2) * ((1 / eps) + (1 / eps^{2})))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (eps, {1...2^{t - 1} - 2})
#    core type: ExprTuple
#    sub-expressions: 38, 12
# 10. [Pfail](eps)
#     core type: Operation
#     operator: 13
#     operand: 38
# 11. (1 / 2) * ((1 / eps) + (1 / eps^{2}))
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. {1...2^{t - 1} - 2}
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. Pfail
#     core type: Literal
#     sub-expressions:
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (1 / 2, (1 / eps) + (1 / eps^{2}))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. Interval
#     core type: Literal
#     sub-expressions:
# 17. (1, 2^{t - 1} - 2)
#     core type: ExprTuple
#     sub-expressions: 43, 20
# 18. 1 / 2
#     core type: Operation
#     operator: 29
#     operands: 21
# 19. (1 / eps) + (1 / eps^{2})
#     core type: Operation
#     operator: 36
#     operands: 22
# 20. 2^{t - 1} - 2
#     core type: Operation
#     operator: 36
#     operands: 23
# 21. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 43, 39
# 22. (1 / eps, 1 / eps^{2})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. (2^{t - 1}, -2)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. 1 / eps
#     core type: Operation
#     operator: 29
#     operands: 28
# 25. 1 / eps^{2}
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. 2^{t - 1}
#     core type: Operation
#     operator: 34
#     operands: 31
# 27. -2
#     core type: Operation
#     operator: 42
#     operand: 39
# 28. (1, eps)
#     core type: ExprTuple
#     sub-expressions: 43, 38
# 29. /
#     core type: Literal
#     sub-expressions:
# 30. (1, eps^{2})
#     core type: ExprTuple
#     sub-expressions: 43, 32
# 31. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 39, 33
# 32. eps^{2}
#     core type: Operation
#     operator: 34
#     operands: 35
# 33. t - 1
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. Exp
#     core type: Literal
#     sub-expressions:
# 35. (eps, 2)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. +
#     core type: Literal
#     sub-expressions:
# 37. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. eps
#     core type: Variable
#     sub-expressions:
# 39. 2
#     core type: Literal
#     sub-expressions:
# 40. t
#     core type: Literal
#     sub-expressions:
# 41. -1
#     core type: Operation
#     operator: 42
#     operand: 43
# 42. -
#     core type: Literal
#     sub-expressions:
# 43. 1
#     core type: Literal
#     sub-expressions:
