# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, l
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Interval, Mult, Neg, Sum, e, frac, i, one, pi, two, zero
from proveit.physics.quantum.QPE import ModAdd, alpha_l, b_, phase_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = Equals(alpha_l, Mult(frac(one, two_pow_t), Sum([k], Mult(Exp(e, frac(Neg(Mult(two, pi, i, k, ModAdd(b_, l))), two_pow_t)), Exp(e, Mult(two, pi, i, phase_, k))), domains = [Interval(zero, Add(two_pow_t, Neg(one)))])))
# Out:
# expr: alpha_{l} = ((1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \alpha_{l} = \left(\frac{1}{2^{t}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{\frac{-\left(2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot \left(b \oplus l\right)\right)}{2^{t}}} \cdot \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k}\right)\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. alpha_{l} = ((1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k})))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (alpha_{l}, (1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k})))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. alpha_{l}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}))
#    core type: Operation
#    operator: 46
#    operands: 7
# 5. SUB_INDEXED
#    core type: Literal
#    sub-expressions:
# 6. (alpha, l)
#    core type: ExprTuple
#    sub-expressions: 8, 57
# 7. (1 / 2^{t}, Sum_{k=0}^{2^{t} - 1} e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. alpha
#    core type: Literal
#    sub-expressions:
# 9. 1 / 2^{t}
#    core type: Operation
#    operator: 32
#    operands: 11
# 10. Sum_{k=0}^{2^{t} - 1} e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. (1, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 45, 39
# 12. Sum
#     core type: Literal
#     sub-expressions:
# 13. k -> {e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k} if k in {0...2^{t} - 1}.
#     core type: Lambda
#     parameter: 52
#     body: 14
# 14. {e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k} if k in {0...2^{t} - 1}.
#     core type: Conditional
#     value: 15
#     condition: 16
# 15. e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 46
#     operands: 17
# 16. k in {0...2^{t} - 1}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}}, e^{2 * pi * i * phase * k})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (k, {0...2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 52, 22
# 20. e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}}
#     core type: Operation
#     operator: 42
#     operands: 23
# 21. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 42
#     operands: 24
# 22. {0...2^{t} - 1}
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. (e, (-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 28, 27
# 24. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 27. (-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. e
#     core type: Literal
#     sub-expressions:
# 29. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 46
#     operands: 34
# 30. 0
#     core type: Literal
#     sub-expressions:
# 31. 2^{t} - 1
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. /
#     core type: Literal
#     sub-expressions:
# 33. (-(2 * pi * i * k * (b MOD_ADD l)), 2^{t})
#     core type: ExprTuple
#     sub-expressions: 37, 39
# 34. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 49, 50, 51, 38, 52
# 35. +
#     core type: Literal
#     sub-expressions:
# 36. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 37. -(2 * pi * i * k * (b MOD_ADD l))
#     core type: Operation
#     operator: 44
#     operand: 41
# 38. phase
#     core type: Literal
#     sub-expressions:
# 39. 2^{t}
#     core type: Operation
#     operator: 42
#     operands: 43
# 40. -1
#     core type: Operation
#     operator: 44
#     operand: 45
# 41. 2 * pi * i * k * (b MOD_ADD l)
#     core type: Operation
#     operator: 46
#     operands: 47
# 42. Exp
#     core type: Literal
#     sub-expressions:
# 43. (2, t)
#     core type: ExprTuple
#     sub-expressions: 49, 48
# 44. -
#     core type: Literal
#     sub-expressions:
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. *
#     core type: Literal
#     sub-expressions:
# 47. (2, pi, i, k, b MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 49, 50, 51, 52, 53
# 48. t
#     core type: Literal
#     sub-expressions:
# 49. 2
#     core type: Literal
#     sub-expressions:
# 50. pi
#     core type: Literal
#     sub-expressions:
# 51. i
#     core type: Literal
#     sub-expressions:
# 52. k
#     core type: Variable
#     sub-expressions:
# 53. b MOD_ADD l
#     core type: Operation
#     operator: 54
#     operands: 55
# 54. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 55. (b, l)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 56. b
#     core type: Literal
#     sub-expressions:
# 57. l
#     core type: Variable
#     sub-expressions:
