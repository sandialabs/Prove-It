# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, l
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Abs, Exp, LessEq, Mult, four, frac, one, two, zero
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _full_domain, _rel_indexed_alpha

# %%
# build up the expression from sub-expressions
expr = Conditional(LessEq(Exp(Abs(_rel_indexed_alpha), two), frac(one, Mult(four, Exp(_diff_l_scaled_delta_floor, two)))), And(InSet(l, _full_domain), NotEquals(l, zero)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2} \leq \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} \textrm{ if } l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\} ,  l \neq 0\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {|alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. 2^{t - 1}} ,  l != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. |alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (l != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. <=
#    core type: Literal
#    sub-expressions:
# 4. (|alpha_{b_{f} MOD_ADD l}|^{2}, 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. |alpha_{b_{f} MOD_ADD l}|^{2}
#    core type: Operation
#    operator: 56
#    operands: 11
# 8. 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#    core type: Operation
#    operator: 12
# ...
