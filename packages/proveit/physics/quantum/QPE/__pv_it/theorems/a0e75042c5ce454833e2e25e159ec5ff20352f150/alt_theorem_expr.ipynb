# %% [markdown]
# Temporary notebook for <a class="ProveItLink" href="../../../_theorems_.ipynb#pos_domain_in_full_domain">pos_domain_in_full_domain</a> of type <a href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # a not-yet-official theorem from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import eps, l
from proveit.logic import Forall, InSet
from proveit.numbers import NaturalPos
from proveit.physics.quantum.QPE import full_domain, pos_domain

# %%
# build up the expression from sub-expressions
expr = Forall([eps], Forall([l], InSet(l, full_domain), domains = [pos_domain]), domains = [NaturalPos])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: pos_domain_in_full_domain matches stored_expr")

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())

# %%
# display the expression information
expr.expr_info()
