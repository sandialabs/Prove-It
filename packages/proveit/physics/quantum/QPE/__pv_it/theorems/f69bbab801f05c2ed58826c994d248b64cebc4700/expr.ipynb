# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, e, l
from proveit.logic import And, Forall, Iff, InSet, Union
from proveit.numbers import ModAbs, greater
from proveit.physics.quantum.QPE import _e_domain, _full_domain, _neg_domain, _pos_domain, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = greater(ModAbs(l, _two_pow_t), e)
expr = ExprTuple(Lambda(l, Forall(instance_param_or_params = [e], instance_expr = Iff(And(InSet(l, Union(_neg_domain, _pos_domain)), sub_expr1), And(InSet(l, _full_domain), sub_expr1)).with_wrapping_at(1), domain = _e_domain).with_wrapping()))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(l \mapsto \left[\begin{array}{l}\forall_{e \in \{1~\ldotp \ldotp~2^{t - 1} - 2\}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left(l \in \left(\{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\} \cup \{e + 1~\ldotp \ldotp~2^{t - 1}\}\right)\right) \land \left(\left|l\right|_{\textup{mod}\thinspace 2^{t}} > e\right)\right) \\  \Leftrightarrow \left(\left(l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\}\right) \land \left(\left|l\right|_{\textup{mod}\thinspace 2^{t}} > e\right)\right) \end{array} \end{array}\right)\end{array}\right]\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (l -> [forall_{e in {1 .. 2^{t - 1} - 2}} (((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)))])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. l -> [forall_{e in {1 .. 2^{t - 1} - 2}} (((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)))]
#    core type: Lambda
#    parameter: 43
#    body: 3
# 2. (l)
#    core type: ExprTuple
#    sub-expressions: 43
# 3. forall_{e in {1 .. 2^{t - 1} - 2}} (((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)))
#    core type: Operation
#    operator: 4
#    operand: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (e -> {((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)) if e in {1 .. 2^{t - 1} - 2}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. e -> {((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)) if e in {1 .. 2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 58
#    body: 8
# 7. (e)
#    core type: ExprTuple
#    sub-expressions: 58
# 8. {((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)) if e in {1 .. 2^{t - 1} - 2}.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e))
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. e in {1 .. 2^{t - 1} - 2}
#     core type: Operation
#     operator: 26
#     operands: 13
# 11. <=>
#     core type: Literal
#     sub-expressions:
# 12. ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e), (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. (e, {1 .. 2^{t - 1} - 2})
#     core type: ExprTuple
#     sub-expressions: 58, 16
# 14. (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)
#     core type: Operation
#     operator: 18
#     operands: 17
# 15. (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. {1 .. 2^{t - 1} - 2}
#     core type: Operation
#     operator: 46
#     operands: 20
# 17. (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}), |l|_{mod 2^{t}} > e)
#     core type: ExprTuple
#     sub-expressions: 21, 23
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. (l in {-2^{t - 1} + 1 .. 2^{t - 1}}, |l|_{mod 2^{t}} > e)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. (1, 2^{t - 1} - 2)
#     core type: ExprTuple
#     sub-expressions: 69, 24
# 21. l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})
#     core type: Operation
#     operator: 26
#     operands: 25
# 22. l in {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. |l|_{mod 2^{t}} > e
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. 2^{t - 1} - 2
#     core type: Operation
#     operator: 63
#     operands: 30
# 25. (l, {-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 43, 31
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (l, {-2^{t - 1} + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 43, 32
# 28. <
#     core type: Literal
#     sub-expressions:
# 29. (e, |l|_{mod 2^{t}})
#     core type: ExprTuple
#     sub-expressions: 58, 33
# 30. (2^{t - 1}, -2)
#     core type: ExprTuple
#     sub-expressions: 57, 34
# 31. {-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 46
#     operands: 37
# 33. |l|_{mod 2^{t}}
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. -2
#     core type: Operation
#     operator: 67
#     operand: 61
# 35. union
#     core type: Literal
#     sub-expressions:
# 36. ({-2^{t - 1} + 1 .. -(e + 1)}, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 37. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 49, 57
# 38. ModAbs
#     core type: Literal
#     sub-expressions:
# 39. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 40. (2)
#     core type: ExprTuple
#     sub-expressions: 61
# 41. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 46
#     operands: 45
# 42. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. l
#     core type: Variable
#     sub-expressions:
# 44. 2^{t}
#     core type: Operation
#     operator: 59
#     operands: 48
# 45. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 46. Interval
#     core type: Literal
#     sub-expressions:
# 47. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 54, 57
# 48. (2, t)
#     core type: ExprTuple
#     sub-expressions: 61, 65
# 49. -2^{t - 1} + 1
#     core type: Operation
#     operator: 63
#     operands: 51
# 50. -(e + 1)
#     core type: Operation
#     operator: 67
#     operand: 54
# 51. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 53, 69
# 52. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 54
# 53. -2^{t - 1}
#     core type: Operation
#     operator: 67
#     operand: 57
# 54. e + 1
#     core type: Operation
#     operator: 63
#     operands: 56
# 55. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 57
# 56. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 58, 69
# 57. 2^{t - 1}
#     core type: Operation
#     operator: 59
#     operands: 60
# 58. e
#     core type: Variable
#     sub-expressions:
# 59. Exp
#     core type: Literal
#     sub-expressions:
# 60. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 61. 2
#     core type: Literal
#     sub-expressions:
# 62. t - 1
#     core type: Operation
#     operator: 63
#     operands: 64
# 63. +
#     core type: Literal
#     sub-expressions:
# 64. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 65. t
#     core type: Literal
#     sub-expressions:
# 66. -1
#     core type: Operation
#     operator: 67
#     operand: 69
# 67. -
#     core type: Literal
#     sub-expressions:
# 68. (1)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. 1
#     core type: Literal
#     sub-expressions:
