# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.physics.quantum.circuits.Qcircuit.html">Qcircuit</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, U, Variable, VertExprArray, s, t
from proveit.numbers import Add, Interval, Mod, Mult, Round, one
from proveit.physics.quantum import I, NumKet, Z, ket_plus, var_ket_u
from proveit.physics.quantum.QPE import QPE, phase, two_pow_t
from proveit.physics.quantum.circuits import Gate, Input, Measure, MultiQubitElem, Output, Qcircuit

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Add(t, one)
sub_expr3 = Add(t, s)
sub_expr4 = Interval(sub_expr2, sub_expr3)
sub_expr5 = MultiQubitElem(element = Gate(operation = QPE(U, t), part = sub_expr1), targets = Interval(one, sub_expr3))
expr = Qcircuit(vert_expr_array = VertExprArray([ExprRange(sub_expr1, Input(state = ket_plus), one, t), ExprRange(sub_expr1, MultiQubitElem(element = Input(state = var_ket_u, part = sub_expr1), targets = sub_expr4), one, s)], [ExprRange(sub_expr1, sub_expr5, one, t), ExprRange(sub_expr1, sub_expr5, sub_expr2, sub_expr3)], [ExprRange(sub_expr1, Measure(basis = Z), one, t), ExprRange(sub_expr1, Gate(operation = I).with_implicit_representation(), one, s)], [ExprRange(sub_expr1, MultiQubitElem(element = Output(state = NumKet(Mod(Round(Mult(two_pow_t, phase)), two_pow_t), t), part = sub_expr1), targets = Interval(one, t)), one, t), ExprRange(sub_expr1, MultiQubitElem(element = Output(state = var_ket_u, part = sub_expr1), targets = sub_expr4), one, s)]))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# \qin{\lvert + \rangle} & \multigate{4}{\textrm{QPE}\left(U, t\right)} & \meter & \multiqout{3}{\lvert round\left(2^{t} \cdot \varphi\right) ~\textup{mod}~ 2^{t} \rangle_{t}} \\
# \qin{\lvert + \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & \meter & \ghostqout{\lvert round\left(2^{t} \cdot \varphi\right) ~\textup{mod}~ 2^{t} \rangle_{t}} \\
# \qin{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} & \ghost{\textrm{QPE}\left(U, t\right)} & \measure{\begin{array}{c}:\\ \left(t - 3\right) \times \\:\end{array}} \qw & \ghostqout{\lvert round\left(2^{t} \cdot \varphi\right) ~\textup{mod}~ 2^{t} \rangle_{t}} \\
# \qin{\lvert + \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & \meter & \ghostqout{\lvert round\left(2^{t} \cdot \varphi\right) ~\textup{mod}~ 2^{t} \rangle_{t}} \\
# \qin{\lvert u \rangle} & \ghost{\textrm{QPE}\left(U, t\right)} & { /^{s} } \qw & \qout{\lvert u \rangle}
# } \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: spacing
# description: change the spacing of a circuit using the format '@C=1em @R=.7em' where C is the column spacing and R is the row spacing
# default: @C=1em @R=.7em
# current value: @C=1em @R=.7em
# related methods: ()

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. QCIRCUIT
#    core type: Literal
#    sub-expressions:
# 2. VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}),  \\ ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}),  \\ ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}),  \\ ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. ([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 4. ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 5. ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 6. ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 7. [INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉}
#    core type: ExprRange
#    lambda_map: 15
#    start_index: 77
#    end_index: 92
# 8. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#    core type: ExprRange
#    lambda_map: 16
#    start_index: 77
#    end_index: 78
# 9. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}}
#    core type: ExprRange
#    lambda_map: 17
#    start_index: 77
#    end_index: 92
# 10. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 66
#     end_index: 67
# 11. [MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 77
#     end_index: 92
# 12. [GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 77
#     end_index: 78
# 13. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:t}, targets:{1 .. t}}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 77
#     end_index: 92
# 14. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 77
#     end_index: 78
# 15. _a -> [INPUT]{state:|+〉}
#     core type: Lambda
#     parameter: 65
#     body: 22
# 16. _a -> [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 65
#     body: 23
# 17. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Lambda
#     parameter: 65
#     body: 24
# 18. _a -> [MEASURE]{basis:Z}
#     core type: Lambda
#     parameter: 65
#     body: 25
# 19. _a -> [GATE]{operation:I}
#     core type: Lambda
#     parameter: 65
#     body: 26
# 20. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Lambda
#     parameter: 65
#     body: 27
# 21. _a -> [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 65
#     body: 29
# 22. [INPUT]{state:|+〉}
#     core type: Operation
#     operator: 51
#     operands: 30
# 23. [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 37
#     operands: 31
# 24. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: Operation
#     operator: 37
#     operands: 32
# 25. [MEASURE]{basis:Z}
#     core type: Operation
#     operator: 33
#     operands: 34
# 26. [GATE]{operation:I}
#     core type: Operation
#     operator: 52
#     operands: 35
# 27. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: Operation
#     operator: 37
#     operands: 36
# 28. (_a)
#     core type: ExprTuple
#     sub-expressions: 65
# 29. [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 37
#     operands: 38
# 30. {state:|+〉}
#     core type: NamedExprs
#     state: 39
# 31. {element:[INPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 40
#     targets: 48
# 32. {element:[GATE]{operation:QPE(U, t), part:_a}, targets:{1 .. t + s}}
#     core type: NamedExprs
#     element: 41
#     targets: 42
# 33. MEASURE
#     core type: Literal
#     sub-expressions:
# 34. {basis:Z}
#     core type: NamedExprs
#     basis: 43
# 35. {operation:I}
#     core type: NamedExprs
#     operation: 44
# 36. {element:[OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:_a}, targets:{1 .. t}}
#     core type: NamedExprs
#     element: 45
#     targets: 46
# 37. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 38. {element:[OUTPUT]{state:|u>, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 47
#     targets: 48
# 39. |+〉
#     core type: Operation
#     operator: 49
#     operand: 61
# 40. [INPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 51
#     operands: 58
# 41. [GATE]{operation:QPE(U, t), part:_a}
#     core type: Operation
#     operator: 52
#     operands: 53
# 42. {1 .. t + s}
#     core type: Operation
#     operator: 59
#     operands: 54
# 43. Z
#     core type: Literal
#     sub-expressions:
# 44. I
#     core type: Literal
#     sub-expressions:
# 45. [OUTPUT]{state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:_a}
#     core type: Operation
#     operator: 57
#     operands: 55
# 46. {1 .. t}
#     core type: Operation
#     operator: 59
#     operands: 56
# 47. [OUTPUT]{state:|u>, part:_a}
#     core type: Operation
#     operator: 57
#     operands: 58
# 48. {t + 1 .. t + s}
#     core type: Operation
#     operator: 59
#     operands: 60
# 49. KET
#     core type: Literal
#     sub-expressions:
# 50. (+)
#     core type: ExprTuple
#     sub-expressions: 61
# 51. INPUT
#     core type: Literal
#     sub-expressions:
# 52. GATE
#     core type: Literal
#     sub-expressions:
# 53. {operation:QPE(U, t), part:_a}
#     core type: NamedExprs
#     operation: 62
#     part: 65
# 54. (1, t + s)
#     core type: ExprTuple
#     sub-expressions: 77, 67
# 55. {state:|round(2^{t} * phase) mod 2^{t}〉_{t}, part:_a}
#     core type: NamedExprs
#     state: 63
#     part: 65
# 56. (1, t)
#     core type: ExprTuple
#     sub-expressions: 77, 92
# 57. OUTPUT
#     core type: Literal
#     sub-expressions:
# 58. {state:|u>, part:_a}
#     core type: NamedExprs
#     state: 64
#     part: 65
# 59. Interval
#     core type: Literal
#     sub-expressions:
# 60. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 61. +
#     core type: Literal
#     sub-expressions:
# 62. QPE(U, t)
#     core type: Operation
#     operator: 68
#     operands: 69
# 63. |round(2^{t} * phase) mod 2^{t}〉_{t}
#     core type: Operation
#     operator: 70
#     operands: 71
# 64. |u>
#     core type: Variable
#     sub-expressions:
# 65. _a
#     core type: Variable
#     sub-expressions:
# 66. t + 1
#     core type: Operation
#     operator: 73
#     operands: 72
# 67. t + s
#     core type: Operation
#     operator: 73
#     operands: 74
# 68. QPE
#     core type: Literal
#     sub-expressions:
# 69. (U, t)
#     core type: ExprTuple
#     sub-expressions: 75, 92
# 70. NUM_KET
#     core type: Literal
#     sub-expressions:
# 71. (round(2^{t} * phase) mod 2^{t}, t)
#     core type: ExprTuple
#     sub-expressions: 76, 92
# 72. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 92, 77
# 73. +
#     core type: Literal
#     sub-expressions:
# 74. (t, s)
#     core type: ExprTuple
#     sub-expressions: 92, 78
# 75. U
#     core type: Variable
#     sub-expressions:
# 76. round(2^{t} * phase) mod 2^{t}
#     core type: Operation
#     operator: 79
#     operands: 80
# 77. 1
#     core type: Literal
#     sub-expressions:
# 78. s
#     core type: Variable
#     sub-expressions:
# 79. mod
#     core type: Literal
#     sub-expressions:
# 80. (round(2^{t} * phase), 2^{t})
#     core type: ExprTuple
#     sub-expressions: 81, 87
# 81. round(2^{t} * phase)
#     core type: Operation
#     operator: 82
#     operand: 84
# 82. round
#     core type: Literal
#     sub-expressions:
# 83. (2^{t} * phase)
#     core type: ExprTuple
#     sub-expressions: 84
# 84. 2^{t} * phase
#     core type: Operation
#     operator: 85
#     operands: 86
# 85. *
#     core type: Literal
#     sub-expressions:
# 86. (2^{t}, phase)
#     core type: ExprTuple
#     sub-expressions: 87, 88
# 87. 2^{t}
#     core type: Operation
#     operator: 89
#     operands: 90
# 88. phase
#     core type: Variable
#     sub-expressions:
# 89. Exp
#     core type: Literal
#     sub-expressions:
# 90. (2, t)
#     core type: ExprTuple
#     sub-expressions: 91, 92
# 91. 2
#     core type: Literal
#     sub-expressions:
# 92. t
#     core type: Variable
#     sub-expressions:
