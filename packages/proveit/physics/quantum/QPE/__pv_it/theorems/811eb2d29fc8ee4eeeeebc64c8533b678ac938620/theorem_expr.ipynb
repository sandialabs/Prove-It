# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#mod_add_closure">mod_add_closure</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import mod_add_closure

# %%
# check that the built expression is the same as the stored expression
assert mod_add_closure.expr == stored_expr
assert mod_add_closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: mod_add_closure matches stored_expr")
# Out:
# Passed sanity check: mod_add_closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(mod_add_closure.latex())
# Out:
# \vdash \forall_{a, b \in \mathbb{Z}}~\left(\left(a \oplus b\right) \in \mathbb{Z}\right)

# %%
# display the expression information
mod_add_closure.expr_info()
# Out:
# 0. forall_{a, b in Integer} ((a MOD_ADD b) in Integer)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> {(a MOD_ADD b) in Integer if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 13\n   body: 3
# 3. {(a MOD_ADD b) in Integer if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (a MOD_ADD b) in Integer
#    core type: Operation
#    operator: 15
#    operands: 6
# 5. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a MOD_ADD b, Integer)
#    core type: ExprTuple
#    sub-expressions: 9, 19
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Integer, b in Integer)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. a MOD_ADD b
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. a in Integer
#     core type: Operation
#     operator: 15
# ...
