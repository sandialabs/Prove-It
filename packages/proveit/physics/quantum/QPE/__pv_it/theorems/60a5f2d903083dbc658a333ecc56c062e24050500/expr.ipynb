# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, k, m
from proveit.logic import Equals, InSet
from proveit.numbers import Exp, Integer, Mult, Neg, Sum, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import _alpha_m_mod_two_pow_t, _m_domain, _phase, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(m, Conditional(Equals(_alpha_m_mod_two_pow_t, Mult(frac(one, _two_pow_t), Sum(index_or_indices = [k], summand = Mult(Exp(e, Neg(frac(Mult(two, pi, i, k, m), _two_pow_t))), Exp(e, Mult(two, pi, i, _phase, k))), domain = _m_domain))), InSet(m, Integer))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(m \mapsto \left\{\alpha_{m ~\textup{mod}~ 2^{t}} = \left(\frac{1}{2^{t}} \cdot \left(\sum_{k = 0}^{2^{t} - 1} \left(\mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}} \cdot \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k}\right)\right)\right) \textrm{ if } m \in \mathbb{Z}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (m -> {alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))) if m in Integer.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. m -> {alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))) if m in Integer.
#    core type: Lambda
#    parameter: 64
#    body: 3
# 2. (m)
#    core type: ExprTuple
#    sub-expressions: 64
# 3. {alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))) if m in Integer.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. m in Integer
#    core type: Operation
#    operator: 29
#    operands: 8
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (alpha_{m mod 2^{t}}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (m, Integer)
#    core type: ExprTuple
#    sub-expressions: 64, 11
# 9. alpha_{m mod 2^{t}}
#    core type: Operation
#    operator: 12
#    operand: 15
# 10. (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
#     core type: Operation
#     operator: 57
#     operands: 14
# 11. Integer
#     core type: Literal
#     sub-expressions:
# 12. alpha
#     core type: Literal
#     sub-expressions:
# 13. (m mod 2^{t})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. m mod 2^{t}
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. 1 / 2^{t}
#     core type: Operation
#     operator: 50
#     operands: 20
# 17. Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})
#     core type: Operation
#     operator: 21
#     operand: 23
# 18. mod
#     core type: Literal
#     sub-expressions:
# 19. (m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 64, 55
# 20. (1, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 56, 55
# 21. Sum
#     core type: Literal
#     sub-expressions:
# 22. (k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 23
# 23. k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 63
#     body: 25
# 24. (k)
#     core type: ExprTuple
#     sub-expressions: 63
# 25. {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 26
#     condition: 27
# 26. e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 57
#     operands: 28
# 27. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. (e^{-((2 * pi * i * k * m) / 2^{t})}, e^{2 * pi * i * phase * k})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. in
#     core type: Literal
#     sub-expressions:
# 30. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 63, 33
# 31. e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 59
#     operands: 34
# 32. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 59
#     operands: 35
# 33. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. (e, -((2 * pi * i * k * m) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 39, 38
# 35. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. Interval
#     core type: Literal
#     sub-expressions:
# 37. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 38. -((2 * pi * i * k * m) / 2^{t})
#     core type: Operation
#     operator: 52
#     operand: 47
# 39. e
#     core type: Literal
#     sub-expressions:
# 40. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 57
#     operands: 44
# 41. 0
#     core type: Literal
#     sub-expressions:
# 42. 2^{t} - 1
#     core type: Operation
#     operator: 45
#     operands: 46
# 43. ((2 * pi * i * k * m) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 47
# 44. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 65, 61, 62, 48, 63
# 45. +
#     core type: Literal
#     sub-expressions:
# 46. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 55, 49
# 47. (2 * pi * i * k * m) / 2^{t}
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. phase
#     core type: Literal
#     sub-expressions:
# 49. -1
#     core type: Operation
#     operator: 52
#     operand: 56
# 50. /
#     core type: Literal
#     sub-expressions:
# 51. (2 * pi * i * k * m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. -
#     core type: Literal
#     sub-expressions:
# 53. (1)
#     core type: ExprTuple
#     sub-expressions: 56
# 54. 2 * pi * i * k * m
#     core type: Operation
#     operator: 57
#     operands: 58
# 55. 2^{t}
#     core type: Operation
#     operator: 59
#     operands: 60
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. *
#     core type: Literal
#     sub-expressions:
# 58. (2, pi, i, k, m)
#     core type: ExprTuple
#     sub-expressions: 65, 61, 62, 63, 64
# 59. Exp
#     core type: Literal
#     sub-expressions:
# 60. (2, t)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 61. pi
#     core type: Literal
#     sub-expressions:
# 62. i
#     core type: Literal
#     sub-expressions:
# 63. k
#     core type: Variable
#     sub-expressions:
# 64. m
#     core type: Variable
#     sub-expressions:
# 65. 2
#     core type: Literal
#     sub-expressions:
# 66. t
#     core type: Literal
#     sub-expressions:
