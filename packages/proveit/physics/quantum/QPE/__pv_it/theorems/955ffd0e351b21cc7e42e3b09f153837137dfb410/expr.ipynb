# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, eps
from proveit.numbers import Add, Exp, frac, one, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(frac(one, two), Add(frac(one, eps), frac(one, Exp(eps, two))))
# Out:
# expr: (1 / 2, (1 / eps) + (1 / eps^{2}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\frac{1}{2}, \frac{1}{\varepsilon} + \frac{1}{\varepsilon^{2}}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1 / 2, (1 / eps) + (1 / eps^{2}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 1 / 2
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. (1 / eps) + (1 / eps^{2})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (1, 2)
#    core type: ExprTuple
#    sub-expressions: 11, 16
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (1 / eps, 1 / eps^{2})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. 1 / eps
#    core type: Operation
#    operator: 9
#    operands: 8
# 7. 1 / eps^{2}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (1, eps)
#    core type: ExprTuple
#    sub-expressions: 11, 15
# 9. /
#    core type: Literal
#    sub-expressions:
# 10. (1, eps^{2})
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. eps^{2}
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. Exp
#     core type: Literal
#     sub-expressions:
# 14. (eps, 2)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. eps
#     core type: Variable
#     sub-expressions:
# 16. 2
#     core type: Literal
#     sub-expressions:
