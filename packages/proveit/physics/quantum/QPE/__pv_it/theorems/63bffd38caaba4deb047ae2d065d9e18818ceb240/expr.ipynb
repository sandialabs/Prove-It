# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Equals
from proveit.numbers import Exp, Mult, e, frac, i, one, pi, subtract, two
from proveit.physics.quantum.QPE import _delta_b_floor, _rel_indexed_alpha, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = Equals(_rel_indexed_alpha, Mult(frac(one, _two_pow_t), frac(subtract(one, Exp(e, Mult(two, pi, i, subtract(Mult(_two_pow_t, _delta_b_floor), l)))), subtract(one, Exp(e, Mult(two, pi, i, subtract(_delta_b_floor, frac(l, _two_pow_t))))))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \alpha_{b_{\textit{f}} \oplus l} = \left(\frac{1}{2^{t}} \cdot \frac{1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\left(2^{t} \cdot \delta_{b_{\textit{f}}}\right) - l\right)}}{1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\delta_{b_{\textit{f}}} - \frac{l}{2^{t}}\right)}}\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. alpha_{b_{f} MOD_ADD l} = ((1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (alpha_{b_{f} MOD_ADD l}, (1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. alpha_{b_{f} MOD_ADD l}
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}))
#    core type: Operation
#    operator: 43
#    operands: 7
# 5. alpha
#    core type: Literal
#    sub-expressions:
# 6. (b_{f} MOD_ADD l)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (1 / 2^{t}, (1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. b_{f} MOD_ADD l
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. 1 / 2^{t}
#    core type: Operation
#    operator: 52
#    operands: 13
# 10. (1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#     core type: Operation
#     operator: 52
#     operands: 14
# 11. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 12. (b_{f}, l)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 13. (1, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 20, 56
# 14. (1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}, 1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. 1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}
#     core type: Operation
#     operator: 38
#     operands: 17
# 16. 1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}
#     core type: Operation
#     operator: 38
#     operands: 18
# 17. (1, -e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)})
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 18. (1, -e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. -e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}
#     core type: Operation
#     operator: 46
#     operand: 24
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. -e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}
#     core type: Operation
#     operator: 46
#     operand: 25
# 22. (e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)})
#     core type: ExprTuple
#     sub-expressions: 24
# 23. (e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))})
#     core type: ExprTuple
#     sub-expressions: 25
# 24. e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}
#     core type: Operation
#     operator: 57
#     operands: 26
# 25. e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}
#     core type: Operation
#     operator: 57
#     operands: 27
# 26. (e, 2 * pi * i * ((2^{t} * delta_{b_{f}}) - l))
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 27. (e, 2 * pi * i * (delta_{b_{f}} - (l / 2^{t})))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. 2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)
#     core type: Operation
#     operator: 43
#     operands: 31
# 29. e
#     core type: Literal
#     sub-expressions:
# 30. 2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))
#     core type: Operation
#     operator: 43
#     operands: 32
# 31. (2, pi, i, (2^{t} * delta_{b_{f}}) - l)
#     core type: ExprTuple
#     sub-expressions: 59, 34, 35, 33
# 32. (2, pi, i, delta_{b_{f}} - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 59, 34, 35, 36
# 33. (2^{t} * delta_{b_{f}}) - l
#     core type: Operation
#     operator: 38
#     operands: 37
# 34. pi
#     core type: Literal
#     sub-expressions:
# 35. i
#     core type: Literal
#     sub-expressions:
# 36. delta_{b_{f}} - (l / 2^{t})
#     core type: Operation
#     operator: 38
#     operands: 39
# 37. (2^{t} * delta_{b_{f}}, -l)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. +
#     core type: Literal
#     sub-expressions:
# 39. (delta_{b_{f}}, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 48, 42
# 40. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. -l
#     core type: Operation
#     operator: 46
#     operand: 55
# 42. -(l / 2^{t})
#     core type: Operation
#     operator: 46
#     operand: 49
# 43. *
#     core type: Literal
#     sub-expressions:
# 44. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 56, 48
# 45. (l)
#     core type: ExprTuple
#     sub-expressions: 55
# 46. -
#     core type: Literal
#     sub-expressions:
# 47. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 49
# 48. delta_{b_{f}}
#     core type: Operation
#     operator: 50
#     operand: 54
# 49. l / 2^{t}
#     core type: Operation
#     operator: 52
#     operands: 53
# 50. delta
#     core type: Literal
#     sub-expressions:
# 51. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 54
# 52. /
#     core type: Literal
#     sub-expressions:
# 53. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 54. b_{f}
#     core type: Literal
#     sub-expressions:
# 55. l
#     core type: Variable
#     sub-expressions:
# 56. 2^{t}
#     core type: Operation
#     operator: 57
#     operands: 58
# 57. Exp
#     core type: Literal
#     sub-expressions:
# 58. (2, t)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 59. 2
#     core type: Literal
#     sub-expressions:
# 60. t
#     core type: Literal
#     sub-expressions:
