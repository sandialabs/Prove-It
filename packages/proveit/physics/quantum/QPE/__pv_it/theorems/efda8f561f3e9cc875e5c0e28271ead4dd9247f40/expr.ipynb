# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import e, l
from proveit.logic import Equals, Forall
from proveit.numbers import Abs, Add, Exp, Sum, two
from proveit.physics.quantum.QPE import Pfail, _e_domain, _neg_domain, _pos_domain, _rel_indexed_alpha

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = Exp(Abs(_rel_indexed_alpha), two)
expr = Forall(instance_param_or_params = [e], instance_expr = Equals(Pfail(e), Add(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = _neg_domain), Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = _pos_domain))), domain = _e_domain)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{e \in \{1~\ldotp \ldotp~2^{t - 1} - 2\}}~\left(\left[P_{\rm fail}\right]\left(e\right) = \left(\left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right) + \left(\sum_{l = e + 1}^{2^{t - 1}} \left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2}\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{e in {1 .. 2^{t - 1} - 2}} ([Pfail](e) = ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (e -> {[Pfail](e) = ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})) if e in {1 .. 2^{t - 1} - 2}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. e -> {[Pfail](e) = ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})) if e in {1 .. 2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 61
#    body: 4
# 4. {[Pfail](e) = ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})) if e in {1 .. 2^{t - 1} - 2}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. [Pfail](e) = ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. e in {1 .. 2^{t - 1} - 2}
#    core type: Operation
#    operator: 36
#    operands: 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. ([Pfail](e), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (e, {1 .. 2^{t - 1} - 2})
#    core type: ExprTuple
#    sub-expressions: 61, 12
# 10. [Pfail](e)
#     core type: Operation
#     operator: 13
#     operand: 61
# 11. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}) + (Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})
#     core type: Operation
#     operator: 68
#     operands: 15
# 12. {1 .. 2^{t - 1} - 2}
#     core type: Operation
#     operator: 44
#     operands: 16
# 13. Pfail
#     core type: Literal
#     sub-expressions:
# 14. (e)
#     core type: ExprTuple
#     sub-expressions: 61
# 15. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}, Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. (1, 2^{t - 1} - 2)
#     core type: ExprTuple
#     sub-expressions: 74, 19
# 17. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 21
#     operand: 24
# 18. Sum_{l = e + 1}^{2^{t - 1}} |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 21
#     operand: 25
# 19. 2^{t - 1} - 2
#     core type: Operation
#     operator: 68
#     operands: 23
# 20. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#     core type: ExprTuple
#     sub-expressions: 24
# 21. Sum
#     core type: Literal
#     sub-expressions:
# 22. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 25
# 23. (2^{t - 1}, -2)
#     core type: ExprTuple
#     sub-expressions: 60, 26
# 24. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Lambda
#     parameter: 63
#     body: 27
# 25. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 63
#     body: 29
# 26. -2
#     core type: Operation
#     operator: 72
#     operand: 66
# 27. {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 32
#     condition: 31
# 28. (l)
#     core type: ExprTuple
#     sub-expressions: 63
# 29. {|alpha_{b_{f} MOD_ADD l}|^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 32
#     condition: 33
# 30. (2)
#     core type: ExprTuple
#     sub-expressions: 66
# 31. l in {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 36
#     operands: 34
# 32. |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 64
#     operands: 35
# 33. l in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 63, 38
# 35. (|alpha_{b_{f} MOD_ADD l}|, 2)
#     core type: ExprTuple
#     sub-expressions: 39, 66
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (l, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 63, 40
# 38. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 44
#     operands: 41
# 39. |alpha_{b_{f} MOD_ADD l}|
#     core type: Operation
#     operator: 42
#     operand: 48
# 40. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 42. Abs
#     core type: Literal
#     sub-expressions:
# 43. (alpha_{b_{f} MOD_ADD l})
#     core type: ExprTuple
#     sub-expressions: 48
# 44. Interval
#     core type: Literal
#     sub-expressions:
# 45. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 54, 60
# 46. -2^{t - 1} + 1
#     core type: Operation
#     operator: 68
#     operands: 49
# 47. -(e + 1)
#     core type: Operation
#     operator: 72
#     operand: 54
# 48. alpha_{b_{f} MOD_ADD l}
#     core type: Operation
#     operator: 51
#     operand: 55
# 49. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 53, 74
# 50. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 54
# 51. alpha
#     core type: Literal
#     sub-expressions:
# 52. (b_{f} MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 55
# 53. -2^{t - 1}
#     core type: Operation
#     operator: 72
#     operand: 60
# 54. e + 1
#     core type: Operation
#     operator: 68
#     operands: 57
# 55. b_{f} MOD_ADD l
#     core type: Operation
#     operator: 58
#     operands: 59
# 56. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 60
# 57. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 61, 74
# 58. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 59. (b_{f}, l)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 60. 2^{t - 1}
#     core type: Operation
#     operator: 64
#     operands: 65
# 61. e
#     core type: Variable
#     sub-expressions:
# 62. b_{f}
#     core type: Literal
#     sub-expressions:
# 63. l
#     core type: Variable
#     sub-expressions:
# 64. Exp
#     core type: Literal
#     sub-expressions:
# 65. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 66. 2
#     core type: Literal
#     sub-expressions:
# 67. t - 1
#     core type: Operation
#     operator: 68
#     operands: 69
# 68. +
#     core type: Literal
#     sub-expressions:
# 69. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 70. t
#     core type: Literal
#     sub-expressions:
# 71. -1
#     core type: Operation
#     operator: 72
#     operand: 74
# 72. -
#     core type: Literal
#     sub-expressions:
# 73. (1)
#     core type: ExprTuple
#     sub-expressions: 74
# 74. 1
#     core type: Literal
#     sub-expressions:
