# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Forall, NotEquals
from proveit.numbers import Add, Exp, LessEq, Mult, Neg, four, frac, one, two, zero
from proveit.physics.quantum.QPE import alpha_l_sqrd, delta_, full_domain, two_pow_t

# %%
# build up the expression from sub-expressions
expr = Forall([l], LessEq(alpha_l_sqrd, frac(one, Mult(four, Exp(Add(l, Neg(Mult(two_pow_t, delta_))), two)))), domains = [full_domain], condition = NotEquals(l, zero))
# Out:
# expr: forall_{l in {-2^{t - 1} + 1...2^{t - 1}} | l != 0} (|alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{l \in \{-2^{t - 1} + 1 \dots 2^{t - 1}\}~|~l \neq 0}~\left(\left|\alpha_{l}\right|^{2} \leq \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{l in {-2^{t - 1} + 1...2^{t - 1}} | l != 0} (|alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2})))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. l -> {|alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2})) if l in {-2^{t - 1} + 1...2^{t - 1}} ,  l != 0.
#    core type: Lambda
#    parameter: 42
#    body: 3
# 3. {|alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2})) if l in {-2^{t - 1} + 1...2^{t - 1}} ,  l != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. |alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2}))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (l in {-2^{t - 1} + 1...2^{t - 1}}) and (l != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. <=
#    core type: Literal
#    sub-expressions:
# 7. (|alpha_{l}|^{2}, 1 / (4 * (l - (2^{t} * delta))^{2}))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (l in {-2^{t - 1} + 1...2^{t - 1}}, l != 0)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. |alpha_{l}|^{2}
#     core type: Operation
#     operator: 54
#     operands: 14
# 11. 1 / (4 * (l - (2^{t} * delta))^{2})
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. l in {-2^{t - 1} + 1...2^{t - 1}}
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. l != 0
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. (|alpha_{l}|, 2)
#     core type: ExprTuple
#     sub-expressions: 21, 58
# 15. /
#     core type: Literal
#     sub-expressions:
# 16. (1, 4 * (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 57, 22
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (l, {-2^{t - 1} + 1...2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 42, 23
# 19. !=
#     core type: Literal
#     sub-expressions:
# 20. (l, 0)
#     core type: ExprTuple
#     sub-expressions: 42, 24
# 21. |alpha_{l}|
#     core type: Operation
#     operator: 25
#     operand: 26
# 22. 4 * (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 47
#     operands: 27
# 23. {-2^{t - 1} + 1...2^{t - 1}}
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. 0
#     core type: Literal
#     sub-expressions:
# 25. Abs
#     core type: Literal
#     sub-expressions:
# 26. alpha_{l}
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. (4, (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 28. Interval
#     core type: Literal
#     sub-expressions:
# 29. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 34, 41
# 30. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 31. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 35, 42
# 32. 4
#     core type: Literal
#     sub-expressions:
# 33. (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 54
#     operands: 36
# 34. -2^{t - 1} + 1
#     core type: Operation
#     operator: 49
#     operands: 37
# 35. alpha
#     core type: Literal
#     sub-expressions:
# 36. (l - (2^{t} * delta), 2)
#     core type: ExprTuple
#     sub-expressions: 38, 58
# 37. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 39, 57
# 38. l - (2^{t} * delta)
#     core type: Operation
#     operator: 49
#     operands: 40
# 39. -2^{t - 1}
#     core type: Operation
#     operator: 56
#     operand: 41
# 40. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 41. 2^{t - 1}
#     core type: Operation
#     operator: 54
#     operands: 44
# 42. l
#     core type: Variable
#     sub-expressions:
# 43. -(2^{t} * delta)
#     core type: Operation
#     operator: 56
#     operand: 45
# 44. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 58, 46
# 45. 2^{t} * delta
#     core type: Operation
#     operator: 47
#     operands: 48
# 46. t - 1
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. *
#     core type: Literal
#     sub-expressions:
# 48. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 59, 53
# 51. 2^{t}
#     core type: Operation
#     operator: 54
#     operands: 55
# 52. delta
#     core type: Literal
#     sub-expressions:
# 53. -1
#     core type: Operation
#     operator: 56
#     operand: 57
# 54. Exp
#     core type: Literal
#     sub-expressions:
# 55. (2, t)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. -
#     core type: Literal
#     sub-expressions:
# 57. 1
#     core type: Literal
#     sub-expressions:
# 58. 2
#     core type: Literal
#     sub-expressions:
# 59. t
#     core type: Literal
#     sub-expressions:
