# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#all_abs_alpha_l_nonneg">all_abs_alpha_l_nonneg</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/all_abs_alpha_l_nonneg/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.physics.quantum.QPE import all_abs_alpha_l_nonneg

# %%
# %dependencies all_abs_alpha_l_nonneg
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon all_abs_alpha_l_nonneg</h3>
