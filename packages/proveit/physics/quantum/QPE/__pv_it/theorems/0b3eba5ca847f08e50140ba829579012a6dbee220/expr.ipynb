# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Forall, NotEquals
from proveit.numbers import Abs, Exp, LessEq, Mult, four, frac, one, two, zero
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _full_domain, _rel_indexed_alpha

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [l], instance_expr = LessEq(Exp(Abs(_rel_indexed_alpha), two), frac(one, Mult(four, Exp(_diff_l_scaled_delta_floor, two)))), domain = _full_domain, condition = NotEquals(l, zero))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\}~|~l \neq 0}~\left(\left|\alpha_{b_{\textit{f}} \oplus l}\right|^{2} \leq \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} | l != 0} (|alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (l -> {|alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. 2^{t - 1}} ,  l != 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {|alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. 2^{t - 1}} ,  l != 0.
#    core type: Lambda
#    parameter: 47
#    body: 5
# 4. (l)
#    core type: ExprTuple
#    sub-expressions: 47
# 5. {|alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})) if l in {-2^{t - 1} + 1 .. 2^{t - 1}} ,  l != 0.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. |alpha_{b_{f} MOD_ADD l}|^{2} <= (1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (l != 0)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. <=
#    core type: Literal
#    sub-expressions:
# 9. (|alpha_{b_{f} MOD_ADD l}|^{2}, 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. |alpha_{b_{f} MOD_ADD l}|^{2}
#     core type: Operation
#     operator: 61
#     operands: 16
# 13. 1 / (4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. l in {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. l != 0
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. (|alpha_{b_{f} MOD_ADD l}|, 2)
#     core type: ExprTuple
#     sub-expressions: 23, 67
# 17. /
#     core type: Literal
#     sub-expressions:
# 18. (1, 4 * (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 70, 24
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (l, {-2^{t - 1} + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 47, 25
# 21. !=
#     core type: Literal
#     sub-expressions:
# 22. (l, 0)
#     core type: ExprTuple
#     sub-expressions: 47, 26
# 23. |alpha_{b_{f} MOD_ADD l}|
#     core type: Operation
#     operator: 27
#     operand: 32
# 24. 4 * (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 54
#     operands: 29
# 25. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. 0
#     core type: Literal
#     sub-expressions:
# 27. Abs
#     core type: Literal
#     sub-expressions:
# 28. (alpha_{b_{f} MOD_ADD l})
#     core type: ExprTuple
#     sub-expressions: 32
# 29. (4, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. Interval
#     core type: Literal
#     sub-expressions:
# 31. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 35, 49
# 32. alpha_{b_{f} MOD_ADD l}
#     core type: Operation
#     operator: 36
#     operand: 40
# 33. 4
#     core type: Literal
#     sub-expressions:
# 34. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 61
#     operands: 38
# 35. -2^{t - 1} + 1
#     core type: Operation
#     operator: 56
#     operands: 39
# 36. alpha
#     core type: Literal
#     sub-expressions:
# 37. (b_{f} MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 40
# 38. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 41, 67
# 39. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 42, 70
# 40. b_{f} MOD_ADD l
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 56
#     operands: 45
# 42. -2^{t - 1}
#     core type: Operation
#     operator: 65
#     operand: 49
# 43. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 44. (b_{f}, l)
#     core type: ExprTuple
#     sub-expressions: 69, 47
# 45. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 46. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 49
# 47. l
#     core type: Variable
#     sub-expressions:
# 48. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 65
#     operand: 52
# 49. 2^{t - 1}
#     core type: Operation
#     operator: 61
#     operands: 51
# 50. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 52
# 51. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 67, 53
# 52. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 54
#     operands: 55
# 53. t - 1
#     core type: Operation
#     operator: 56
#     operands: 57
# 54. *
#     core type: Literal
#     sub-expressions:
# 55. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. +
#     core type: Literal
#     sub-expressions:
# 57. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 68, 60
# 58. 2^{t}
#     core type: Operation
#     operator: 61
#     operands: 62
# 59. delta_{b_{f}}
#     core type: Operation
#     operator: 63
#     operand: 69
# 60. -1
#     core type: Operation
#     operator: 65
#     operand: 70
# 61. Exp
#     core type: Literal
#     sub-expressions:
# 62. (2, t)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 63. delta
#     core type: Literal
#     sub-expressions:
# 64. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 69
# 65. -
#     core type: Literal
#     sub-expressions:
# 66. (1)
#     core type: ExprTuple
#     sub-expressions: 70
# 67. 2
#     core type: Literal
#     sub-expressions:
# 68. t
#     core type: Literal
#     sub-expressions:
# 69. b_{f}
#     core type: Literal
#     sub-expressions:
# 70. 1
#     core type: Literal
#     sub-expressions:
