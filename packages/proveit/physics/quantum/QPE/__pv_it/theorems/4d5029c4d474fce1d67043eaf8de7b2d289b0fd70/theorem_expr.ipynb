# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#neg_domain_in_full_domain">neg_domain_in_full_domain</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import neg_domain_in_full_domain

# %%
# check that the built expression is the same as the stored expression
assert neg_domain_in_full_domain.expr == stored_expr
assert neg_domain_in_full_domain.expr._style_id == stored_expr._style_id
print("Passed sanity check: neg_domain_in_full_domain matches stored_expr")
# Out:
# Passed sanity check: neg_domain_in_full_domain matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(neg_domain_in_full_domain.latex())
# Out:
# \vdash \forall_{\varepsilon \in \mathbb{N}^+}~\left[\forall_{l \in \{-2^{t - 1} + 1 \dots -\left(\varepsilon + 1\right)\}}~\left(l \in \{-2^{t - 1} + 1 \dots 2^{t - 1}\}\right)\right]

# %%
# display the expression information
neg_domain_in_full_domain.expr_info()
# Out:
# 0. forall_{eps in NaturalPos} [forall_{l in {-2^{t - 1} + 1...-(eps + 1)}} (l in {-2^{t - 1} + 1...2^{t - 1}})]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. eps -> {forall_{l in {-2^{t - 1} + 1...-(eps + 1)}} (l in {-2^{t - 1} + 1...2^{t - 1}}) if eps in NaturalPos.
#    core type: Lambda
#    parameter: 28
#    body: 2
# 2. {forall_{l in {-2^{t - 1} + 1...-(eps + 1)}} (l in {-2^{t - 1} + 1...2^{t - 1}}) if eps in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{l in {-2^{t - 1} + 1...-(eps + 1)}} (l in {-2^{t - 1} + 1...2^{t - 1}})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. eps in NaturalPos
#    core type: Operation
#    operator: 13
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. l -> {l in {-2^{t - 1} + 1...2^{t - 1}} if l in {-2^{t - 1} + 1...-(eps + 1)}.
#    core type: Lambda
#    parameter: 16
#    body: 8
# 7. (eps, NaturalPos)
#    core type: ExprTuple
# ...
