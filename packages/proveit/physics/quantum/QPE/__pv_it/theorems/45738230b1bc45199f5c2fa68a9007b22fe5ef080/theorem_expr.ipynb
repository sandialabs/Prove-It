# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#_fail_sum_prob_conds_equiv_lemma">_fail_sum_prob_conds_equiv_lemma</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import _fail_sum_prob_conds_equiv_lemma

# %%
# check that the built expression is the same as the stored expression
assert _fail_sum_prob_conds_equiv_lemma.expr == stored_expr
assert _fail_sum_prob_conds_equiv_lemma.expr._style_id == stored_expr._style_id
print("Passed sanity check: _fail_sum_prob_conds_equiv_lemma matches stored_expr")
# Out:
# Passed sanity check: _fail_sum_prob_conds_equiv_lemma matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{l}~\\
# \left[\begin{array}{l}\forall_{e \in \{1~\ldotp \ldotp~2^{t - 1} - 2\}}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left(l \in \left(\{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\} \cup \{e + 1~\ldotp \ldotp~2^{t - 1}\}\right)\right) \land \left(\left|l\right|_{\textup{mod}\thinspace 2^{t}} > e\right)\right) \\  \Leftrightarrow \left(\left(l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\}\right) \land \left(\left|l\right|_{\textup{mod}\thinspace 2^{t}} > e\right)\right) \end{array} \end{array}\right)\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{l} [forall_{e in {1 .. 2^{t - 1} - 2}} (((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)))]
#    core type: Operation
#    operator: 5
#    operand: 2
# 1. (l -> [forall_{e in {1 .. 2^{t - 1} - 2}} (((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. l -> [forall_{e in {1 .. 2^{t - 1} - 2}} (((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)))]
#    core type: Lambda
#    parameter: 44
#    body: 4
# 3. (l)
#    core type: ExprTuple
#    sub-expressions: 44
# ...
