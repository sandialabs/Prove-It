# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, m
from proveit.logic import Equals, Forall
from proveit.numbers import Exp, Mult, Neg, Sum, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import _alpha_m, _m_domain, _phase, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [m], instance_expr = Equals(_alpha_m, Mult(frac(one, _two_pow_t), Sum(index_or_indices = [k], summand = Mult(Exp(e, Neg(frac(Mult(two, pi, i, k, m), _two_pow_t))), Exp(e, Mult(two, pi, i, _phase, k))), domain = _m_domain))), domain = _m_domain)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m \in \{0~\ldotp \ldotp~2^{t} - 1\}}~\left(\alpha_{m} = \left(\frac{1}{2^{t}} \cdot \left(\sum_{k = 0}^{2^{t} - 1} \left(\mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}} \cdot \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k}\right)\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (m -> {alpha_{m} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))) if m in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. m -> {alpha_{m} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))) if m in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 61
#    body: 4
# 4. {alpha_{m} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))) if m in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. alpha_{m} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. m in {0 .. 2^{t} - 1}
#    core type: Operation
#    operator: 26
#    operands: 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (alpha_{m}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (m, {0 .. 2^{t} - 1})
#    core type: ExprTuple
#    sub-expressions: 61, 30
# 10. alpha_{m}
#     core type: Operation
#     operator: 12
#     operand: 61
# 11. (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
#     core type: Operation
#     operator: 54
#     operands: 14
# 12. alpha
#     core type: Literal
#     sub-expressions:
# 13. (m)
#     core type: ExprTuple
#     sub-expressions: 61
# 14. (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. 1 / 2^{t}
#     core type: Operation
#     operator: 47
#     operands: 17
# 16. Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})
#     core type: Operation
#     operator: 18
#     operand: 20
# 17. (1, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 53, 52
# 18. Sum
#     core type: Literal
#     sub-expressions:
# 19. (k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 20
# 20. k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 60
#     body: 22
# 21. (k)
#     core type: ExprTuple
#     sub-expressions: 60
# 22. {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 23
#     condition: 24
# 23. e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 54
#     operands: 25
# 24. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. (e^{-((2 * pi * i * k * m) / 2^{t})}, e^{2 * pi * i * phase * k})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 60, 30
# 28. e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 56
#     operands: 31
# 29. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 56
#     operands: 32
# 30. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. (e, -((2 * pi * i * k * m) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 36, 35
# 32. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. Interval
#     core type: Literal
#     sub-expressions:
# 34. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. -((2 * pi * i * k * m) / 2^{t})
#     core type: Operation
#     operator: 49
#     operand: 44
# 36. e
#     core type: Literal
#     sub-expressions:
# 37. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 54
#     operands: 41
# 38. 0
#     core type: Literal
#     sub-expressions:
# 39. 2^{t} - 1
#     core type: Operation
#     operator: 42
#     operands: 43
# 40. ((2 * pi * i * k * m) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 44
# 41. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 62, 58, 59, 45, 60
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 52, 46
# 44. (2 * pi * i * k * m) / 2^{t}
#     core type: Operation
#     operator: 47
#     operands: 48
# 45. phase
#     core type: Literal
#     sub-expressions:
# 46. -1
#     core type: Operation
#     operator: 49
#     operand: 53
# 47. /
#     core type: Literal
#     sub-expressions:
# 48. (2 * pi * i * k * m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. -
#     core type: Literal
#     sub-expressions:
# 50. (1)
#     core type: ExprTuple
#     sub-expressions: 53
# 51. 2 * pi * i * k * m
#     core type: Operation
#     operator: 54
#     operands: 55
# 52. 2^{t}
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. *
#     core type: Literal
#     sub-expressions:
# 55. (2, pi, i, k, m)
#     core type: ExprTuple
#     sub-expressions: 62, 58, 59, 60, 61
# 56. Exp
#     core type: Literal
#     sub-expressions:
# 57. (2, t)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 58. pi
#     core type: Literal
#     sub-expressions:
# 59. i
#     core type: Literal
#     sub-expressions:
# 60. k
#     core type: Variable
#     sub-expressions:
# 61. m
#     core type: Variable
#     sub-expressions:
# 62. 2
#     core type: Literal
#     sub-expressions:
# 63. t
#     core type: Literal
#     sub-expressions:
