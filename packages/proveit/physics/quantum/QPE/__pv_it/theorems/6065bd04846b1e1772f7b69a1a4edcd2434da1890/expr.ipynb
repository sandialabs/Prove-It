# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b
from proveit.numbers import Mult, i, pi, two
from proveit.physics.quantum.QPE import ModAdd, two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Mult(two, pi, i, ModAdd(a, b)), two_pow_t)
# Out:
# expr: (2 * pi * i * (a MOD_ADD b), 2^{t})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 \cdot \pi \cdot \mathsf{i} \cdot \left(a \oplus b\right), 2^{t}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2 * pi * i * (a MOD_ADD b), 2^{t})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 2 * pi * i * (a MOD_ADD b)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. 2^{t}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. *
#    core type: Literal
#    sub-expressions:
# 4. (2, pi, i, a MOD_ADD b)
#    core type: ExprTuple
#    sub-expressions: 10, 7, 8, 9
# 5. Exp
#    core type: Literal
#    sub-expressions:
# 6. (2, t)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 7. pi
#    core type: Literal
#    sub-expressions:
# 8. i
#    core type: Literal
#    sub-expressions:
# 9. a MOD_ADD b
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. 2
#     core type: Literal
#     sub-expressions:
# 11. t
#     core type: Literal
#     sub-expressions:
# 12. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 13. (a, b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
