# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#_alpha_summed">_alpha_summed</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import _alpha_summed

# %%
# check that the built expression is the same as the stored expression
assert _alpha_summed.expr == stored_expr
assert _alpha_summed.expr._style_id == stored_expr._style_id
print("Passed sanity check: _alpha_summed matches stored_expr")
# Out:
# Passed sanity check: _alpha_summed matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\}~|~l \neq 0}~\left(\alpha_{b_{\textit{f}} \oplus l} = \left(\frac{1}{2^{t}} \cdot \frac{1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\left(2^{t} \cdot \delta_{b_{\textit{f}}}\right) - l\right)}}{1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\delta_{b_{\textit{f}}} - \frac{l}{2^{t}}\right)}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} | l != 0} (alpha_{b_{f} MOD_ADD l} = ((1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}))))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (l -> {alpha_{b_{f} MOD_ADD l} = ((1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}))) if l in {-2^{t - 1} + 1 .. 2^{t - 1}} ,  l != 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {alpha_{b_{f} MOD_ADD l} = ((1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta_{b_{f}}) - l)}) / (1 - e^{2 * pi * i * (delta_{b_{f}} - (l / 2^{t}))}))) if l in {-2^{t - 1} + 1 .. 2^{t - 1}} ,  l != 0.
#    core type: Lambda
#    parameter: 83
#    body: 4
# ...
