# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Forall, NotEquals, NotInSet
from proveit.numbers import Add, Integer, Neg, frac, zero
from proveit.physics.quantum.QPE import delta_, full_domain, two_pow_t

# %%
# build up the expression from sub-expressions
expr = Forall([l], NotInSet(Add(delta_, Neg(frac(l, two_pow_t))), Integer), domains = [full_domain], condition = NotEquals(l, zero))
# Out:
# expr: forall_{l in {-2^{t - 1} + 1...2^{t - 1}} | l != 0} ((delta - (l / 2^{t})) not-in Integer)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{l \in \{-2^{t - 1} + 1 \dots 2^{t - 1}\}~|~l \neq 0}~\left(\left(\delta - \frac{l}{2^{t}}\right) \notin \mathbb{Z}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{l in {-2^{t - 1} + 1...2^{t - 1}} | l != 0} ((delta - (l / 2^{t})) not-in Integer)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. l -> {(delta - (l / 2^{t})) not-in Integer if l in {-2^{t - 1} + 1...2^{t - 1}} ,  l != 0.
#    core type: Lambda
#    parameter: 29
#    body: 3
# 3. {(delta - (l / 2^{t})) not-in Integer if l in {-2^{t - 1} + 1...2^{t - 1}} ,  l != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (delta - (l / 2^{t})) not-in Integer
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (l in {-2^{t - 1} + 1...2^{t - 1}}) and (l != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. not-in
#    core type: Literal
#    sub-expressions:
# 7. (delta - (l / 2^{t}), Integer)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (l in {-2^{t - 1} + 1...2^{t - 1}}, l != 0)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. delta - (l / 2^{t})
#     core type: Operation
#     operator: 39
#     operands: 14
# 11. Integer
#     core type: Literal
#     sub-expressions:
# 12. l in {-2^{t - 1} + 1...2^{t - 1}}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. l != 0
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (delta, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (l, {-2^{t - 1} + 1...2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 29, 21
# 17. !=
#     core type: Literal
#     sub-expressions:
# 18. (l, 0)
#     core type: ExprTuple
#     sub-expressions: 29, 22
# 19. delta
#     core type: Literal
#     sub-expressions:
# 20. -(l / 2^{t})
#     core type: Operation
#     operator: 43
#     operand: 23
# 21. {-2^{t - 1} + 1...2^{t - 1}}
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. 0
#     core type: Literal
#     sub-expressions:
# 23. l / 2^{t}
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. Interval
#     core type: Literal
#     sub-expressions:
# 25. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 28, 34
# 26. /
#     core type: Literal
#     sub-expressions:
# 27. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. -2^{t - 1} + 1
#     core type: Operation
#     operator: 39
#     operands: 31
# 29. l
#     core type: Variable
#     sub-expressions:
# 30. 2^{t}
#     core type: Operation
#     operator: 35
#     operands: 32
# 31. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 33, 44
# 32. (2, t)
#     core type: ExprTuple
#     sub-expressions: 37, 41
# 33. -2^{t - 1}
#     core type: Operation
#     operator: 43
#     operand: 34
# 34. 2^{t - 1}
#     core type: Operation
#     operator: 35
#     operands: 36
# 35. Exp
#     core type: Literal
#     sub-expressions:
# 36. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 37. 2
#     core type: Literal
#     sub-expressions:
# 38. t - 1
#     core type: Operation
#     operator: 39
#     operands: 40
# 39. +
#     core type: Literal
#     sub-expressions:
# 40. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 41. t
#     core type: Literal
#     sub-expressions:
# 42. -1
#     core type: Operation
#     operator: 43
#     operand: 44
# 43. -
#     core type: Literal
#     sub-expressions:
# 44. 1
#     core type: Literal
#     sub-expressions:
