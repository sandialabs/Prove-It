# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, m
from proveit.logic import And, InSet
from proveit.numbers import Exp, LessEq, ModAbs, one, subtract, two
from proveit.physics.quantum.QPE import _b_floor, _m_domain, _n, _success_cond, _t, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(m, Conditional(_success_cond, And(InSet(m, _m_domain), LessEq(ModAbs(subtract(m, _b_floor), _two_pow_t), subtract(Exp(two, subtract(_t, _n)), one))))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(m \mapsto \left\{\left|\frac{m}{2^{t}} - \varphi\right|_{\textup{mod}\thinspace 1} \leq 2^{-n} \textrm{ if } m \in \{0~\ldotp \ldotp~2^{t} - 1\} ,  \left|m - b_{\textit{f}}\right|_{\textup{mod}\thinspace 2^{t}} \leq \left(2^{t - n} - 1\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (m -> {|(m / 2^{t}) - phase|_{mod 1} <= 2^{-n} if m in {0 .. 2^{t} - 1} ,  |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. m -> {|(m / 2^{t}) - phase|_{mod 1} <= 2^{-n} if m in {0 .. 2^{t} - 1} ,  |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1).
#    core type: Lambda
#    parameter: 44
#    body: 3
# 2. (m)
#    core type: ExprTuple
#    sub-expressions: 44
# 3. {|(m / 2^{t}) - phase|_{mod 1} <= 2^{-n} if m in {0 .. 2^{t} - 1} ,  |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. |(m / 2^{t}) - phase|_{mod 1} <= 2^{-n}
#    core type: Operation
#    operator: 17
#    operands: 6
# 5. (m in {0 .. 2^{t} - 1}) and (|m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (|(m / 2^{t}) - phase|_{mod 1}, 2^{-n})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (m in {0 .. 2^{t} - 1}, |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. |(m / 2^{t}) - phase|_{mod 1}
#    core type: Operation
#    operator: 26
#    operands: 13
# 10. 2^{-n}
#     core type: Operation
#     operator: 47
#     operands: 14
# 11. m in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1)
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. ((m / 2^{t}) - phase, 1)
#     core type: ExprTuple
#     sub-expressions: 19, 54
# 14. (2, -n)
#     core type: ExprTuple
#     sub-expressions: 53, 57
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (m, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 44, 20
# 17. <=
#     core type: Literal
#     sub-expressions:
# 18. (|m - b_{f}|_{mod 2^{t}}, 2^{t - n} - 1)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. (m / 2^{t}) - phase
#     core type: Operation
#     operator: 51
#     operands: 23
# 20. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. |m - b_{f}|_{mod 2^{t}}
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. 2^{t - n} - 1
#     core type: Operation
#     operator: 51
#     operands: 28
# 23. (m / 2^{t}, -phase)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 24. Interval
#     core type: Literal
#     sub-expressions:
# 25. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 26. ModAbs
#     core type: Literal
#     sub-expressions:
# 27. (m - b_{f}, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 33, 42
# 28. (2^{t - n}, -1)
#     core type: ExprTuple
#     sub-expressions: 34, 43
# 29. m / 2^{t}
#     core type: Operation
#     operator: 35
#     operands: 36
# 30. -phase
#     core type: Operation
#     operator: 58
#     operand: 41
# 31. 0
#     core type: Literal
#     sub-expressions:
# 32. 2^{t} - 1
#     core type: Operation
#     operator: 51
#     operands: 38
# 33. m - b_{f}
#     core type: Operation
#     operator: 51
#     operands: 39
# 34. 2^{t - n}
#     core type: Operation
#     operator: 47
#     operands: 40
# 35. /
#     core type: Literal
#     sub-expressions:
# 36. (m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 44, 42
# 37. (phase)
#     core type: ExprTuple
#     sub-expressions: 41
# 38. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 39. (m, -b_{f})
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 40. (2, t - n)
#     core type: ExprTuple
#     sub-expressions: 53, 46
# 41. phase
#     core type: Literal
#     sub-expressions:
# 42. 2^{t}
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. -1
#     core type: Operation
#     operator: 58
#     operand: 54
# 44. m
#     core type: Variable
#     sub-expressions:
# 45. -b_{f}
#     core type: Operation
#     operator: 58
#     operand: 55
# 46. t - n
#     core type: Operation
#     operator: 51
#     operands: 52
# 47. Exp
#     core type: Literal
#     sub-expressions:
# 48. (2, t)
#     core type: ExprTuple
#     sub-expressions: 53, 56
# 49. (1)
#     core type: ExprTuple
#     sub-expressions: 54
# 50. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 55
# 51. +
#     core type: Literal
#     sub-expressions:
# 52. (t, -n)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 53. 2
#     core type: Literal
#     sub-expressions:
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. b_{f}
#     core type: Literal
#     sub-expressions:
# 56. t
#     core type: Literal
#     sub-expressions:
# 57. -n
#     core type: Operation
#     operator: 58
#     operand: 60
# 58. -
#     core type: Literal
#     sub-expressions:
# 59. (n)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. n
#     core type: Literal
#     sub-expressions:
