# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, k, m
from proveit.logic import Equals, InSet
from proveit.numbers import Exp, Integer, Mult, Neg, Sum, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import _alpha_m_mod_two_pow_t, _m_domain, _phase, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Conditional(Equals(_alpha_m_mod_two_pow_t, Mult(frac(one, _two_pow_t), Sum(index_or_indices = [k], summand = Mult(Exp(e, Neg(frac(Mult(two, pi, i, k, m), _two_pow_t))), Exp(e, Mult(two, pi, i, _phase, k))), domain = _m_domain))), InSet(m, Integer)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# m \mapsto \left\{\alpha_{m ~\textup{mod}~ 2^{t}} = \left(\frac{1}{2^{t}} \cdot \left(\sum_{k = 0}^{2^{t} - 1} \left(\mathsf{e}^{-\frac{2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot m}{2^{t}}} \cdot \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k}\right)\right)\right) \textrm{ if } m \in \mathbb{Z}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. m -> {alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))) if m in Integer.
#    core type: Lambda
#    parameter: 63
#    body: 2
# 1. (m)
#    core type: ExprTuple
#    sub-expressions: 63
# 2. {alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))) if m in Integer.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. m in Integer
#    core type: Operation
#    operator: 28
#    operands: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (alpha_{m mod 2^{t}}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (m, Integer)
#    core type: ExprTuple
#    sub-expressions: 63, 10
# 8. alpha_{m mod 2^{t}}
#    core type: Operation
#    operator: 11
#    operand: 14
# 9. (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
#    core type: Operation
#    operator: 56
#    operands: 13
# 10. Integer
#     core type: Literal
#     sub-expressions:
# 11. alpha
#     core type: Literal
#     sub-expressions:
# 12. (m mod 2^{t})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. m mod 2^{t}
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. 1 / 2^{t}
#     core type: Operation
#     operator: 49
#     operands: 19
# 16. Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})
#     core type: Operation
#     operator: 20
#     operand: 22
# 17. mod
#     core type: Literal
#     sub-expressions:
# 18. (m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 63, 54
# 19. (1, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 55, 54
# 20. Sum
#     core type: Literal
#     sub-expressions:
# 21. (k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 22
# 22. k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 62
#     body: 24
# 23. (k)
#     core type: ExprTuple
#     sub-expressions: 62
# 24. {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 25
#     condition: 26
# 25. e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 56
#     operands: 27
# 26. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. (e^{-((2 * pi * i * k * m) / 2^{t})}, e^{2 * pi * i * phase * k})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 62, 32
# 30. e^{-((2 * pi * i * k * m) / 2^{t})}
#     core type: Operation
#     operator: 58
#     operands: 33
# 31. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 58
#     operands: 34
# 32. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. (e, -((2 * pi * i * k * m) / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 38, 37
# 34. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. Interval
#     core type: Literal
#     sub-expressions:
# 36. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 37. -((2 * pi * i * k * m) / 2^{t})
#     core type: Operation
#     operator: 51
#     operand: 46
# 38. e
#     core type: Literal
#     sub-expressions:
# 39. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 56
#     operands: 43
# 40. 0
#     core type: Literal
#     sub-expressions:
# 41. 2^{t} - 1
#     core type: Operation
#     operator: 44
#     operands: 45
# 42. ((2 * pi * i * k * m) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 46
# 43. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 64, 60, 61, 47, 62
# 44. +
#     core type: Literal
#     sub-expressions:
# 45. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 54, 48
# 46. (2 * pi * i * k * m) / 2^{t}
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. phase
#     core type: Literal
#     sub-expressions:
# 48. -1
#     core type: Operation
#     operator: 51
#     operand: 55
# 49. /
#     core type: Literal
#     sub-expressions:
# 50. (2 * pi * i * k * m, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. -
#     core type: Literal
#     sub-expressions:
# 52. (1)
#     core type: ExprTuple
#     sub-expressions: 55
# 53. 2 * pi * i * k * m
#     core type: Operation
#     operator: 56
#     operands: 57
# 54. 2^{t}
#     core type: Operation
#     operator: 58
#     operands: 59
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. *
#     core type: Literal
#     sub-expressions:
# 57. (2, pi, i, k, m)
#     core type: ExprTuple
#     sub-expressions: 64, 60, 61, 62, 63
# 58. Exp
#     core type: Literal
#     sub-expressions:
# 59. (2, t)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 60. pi
#     core type: Literal
#     sub-expressions:
# 61. i
#     core type: Literal
#     sub-expressions:
# 62. k
#     core type: Variable
#     sub-expressions:
# 63. m
#     core type: Variable
#     sub-expressions:
# 64. 2
#     core type: Literal
#     sub-expressions:
# 65. t
#     core type: Literal
#     sub-expressions:
