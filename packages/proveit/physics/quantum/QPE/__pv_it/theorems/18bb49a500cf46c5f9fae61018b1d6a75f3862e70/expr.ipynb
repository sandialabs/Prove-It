# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import eps, l
from proveit.logic import Forall
from proveit.numbers import Add, LessEq, Sum
from proveit.physics.quantum.QPE import Pfail, alpha_l_sqrd, eps_domain, neg_domain, pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
expr = Forall([eps], LessEq(Pfail(eps), Add(Sum(sub_expr1, alpha_l_sqrd, domains = [neg_domain]), Sum(sub_expr1, alpha_l_sqrd, domains = [pos_domain]))), domains = [eps_domain])
# Out:
# expr: forall_{eps in {1...2^{t - 1} - 2}} ([Pfail](eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{\varepsilon \in \{1 \dots 2^{t - 1} - 2\}}~\left(\left[P_{\rm fail}\right]\left(\varepsilon\right) \leq \left(\left(\sum_{l=-2^{t - 1} + 1}^{-\left(\varepsilon + 1\right)} \left|\alpha_{l}\right|^{2}\right) + \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \left|\alpha_{l}\right|^{2}\right)\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{eps in {1...2^{t - 1} - 2}} ([Pfail](eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. eps -> {[Pfail](eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})) if eps in {1...2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 51
#    body: 3
# 3. {[Pfail](eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})) if eps in {1...2^{t - 1} - 2}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. [Pfail](eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. eps in {1...2^{t - 1} - 2}
#    core type: Operation
#    operator: 30
#    operands: 8
# ...
