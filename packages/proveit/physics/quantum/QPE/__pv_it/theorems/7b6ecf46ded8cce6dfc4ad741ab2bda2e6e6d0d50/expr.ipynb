# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Add, Mult, Neg, e, frac, i, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(e, Mult(two, pi, i, Add(delta_, Neg(frac(l, two_pow_t)))))
# Out:
# expr: (e, 2 * pi * i * (delta - (l / 2^{t})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\mathsf{e}, 2 \cdot \pi \cdot \mathsf{i} \cdot \left(\delta - \frac{l}{2^{t}}\right)\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (e, 2 * pi * i * (delta - (l / 2^{t})))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. e
#    core type: Literal
#    sub-expressions:
# 2. 2 * pi * i * (delta - (l / 2^{t}))
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. *
#    core type: Literal
#    sub-expressions:
# 4. (2, pi, i, delta - (l / 2^{t}))
#    core type: ExprTuple
#    sub-expressions: 20, 5, 6, 7
# 5. pi
#    core type: Literal
#    sub-expressions:
# 6. i
#    core type: Literal
#    sub-expressions:
# 7. delta - (l / 2^{t})
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (delta, -(l / 2^{t}))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. delta
#     core type: Literal
#     sub-expressions:
# 11. -(l / 2^{t})
#     core type: Operation
#     operator: 12
#     operand: 13
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. l / 2^{t}
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. /
#     core type: Literal
#     sub-expressions:
# 15. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. l
#     core type: Variable
#     sub-expressions:
# 17. 2^{t}
#     core type: Operation
#     operator: 18
#     operands: 19
# 18. Exp
#     core type: Literal
#     sub-expressions:
# 19. (2, t)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. 2
#     core type: Literal
#     sub-expressions:
# 21. t
#     core type: Literal
#     sub-expressions:
