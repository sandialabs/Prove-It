# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, l
from proveit.logic import Forall, Implies
from proveit.numbers import Exp, LessEq, Mult, Sum, frac, one, subtract, two
from proveit.physics.quantum.QPE import _delta_b_floor, _diff_l_scaled_delta_floor, _pos_domain, _two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
expr = Implies(Forall(instance_param_or_params = [k], instance_expr = LessEq(frac(one, Exp(subtract(k, Mult(_two_pow_t, _delta_b_floor)), two)), frac(one, Exp(subtract(k, one), two))), domain = _pos_domain), LessEq(Sum(index_or_indices = sub_expr1, summand = frac(one, Exp(_diff_l_scaled_delta_floor, two)), domain = _pos_domain), Sum(index_or_indices = sub_expr1, summand = frac(one, Exp(subtract(l, one), two)), domain = _pos_domain)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left[\forall_{k \in \{e + 1~\ldotp \ldotp~2^{t - 1}\}}~\left(\frac{1}{\left(k - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} \leq \frac{1}{\left(k - 1\right)^{2}}\right)\right] \Rightarrow \left(\left(\sum_{l = e + 1}^{2^{t - 1}} \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right) \leq \left(\sum_{l = e + 1}^{2^{t - 1}} \frac{1}{\left(l - 1\right)^{2}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{k in {e + 1 .. 2^{t - 1}}} ((1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}))] => ((Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) <= (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{k in {e + 1 .. 2^{t - 1}}} ((1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2})), (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) <= (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{k in {e + 1 .. 2^{t - 1}}} ((1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) <= (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))
#    core type: Operation
#    operator: 20
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (k -> {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}) if k in {e + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}), Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. k -> {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}) if k in {e + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 61
#    body: 12
# 9. Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#    core type: Operation
#    operator: 14
#    operand: 18
# 10. Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})
#     core type: Operation
#     operator: 14
#     operand: 19
# 11. (k)
#     core type: ExprTuple
#     sub-expressions: 61
# 12. {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}) if k in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 16
#     condition: 17
# 13. (l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 18
# 14. Sum
#     core type: Literal
#     sub-expressions:
# 15. (l -> {1 / (l - 1)^{2} if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 19
# 16. (1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2})
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. k in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 36
#     operands: 22
# 18. l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 63
#     body: 23
# 19. l -> {1 / (l - 1)^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 63
#     body: 25
# 20. <=
#     core type: Literal
#     sub-expressions:
# 21. (1 / (k - (2^{t} * delta_{b_{f}}))^{2}, 1 / (k - 1)^{2})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 22. (k, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 61, 42
# 23. {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 28
#     condition: 30
# 24. (l)
#     core type: ExprTuple
#     sub-expressions: 63
# 25. {1 / (l - 1)^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 29
#     condition: 30
# 26. 1 / (k - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 34
#     operands: 31
# 27. 1 / (k - 1)^{2}
#     core type: Operation
#     operator: 34
#     operands: 32
# 28. 1 / (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 34
#     operands: 33
# 29. 1 / (l - 1)^{2}
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. l in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 36
#     operands: 37
# 31. (1, (k - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 77, 38
# 32. (1, (k - 1)^{2})
#     core type: ExprTuple
#     sub-expressions: 77, 39
# 33. (1, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 77, 40
# 34. /
#     core type: Literal
#     sub-expressions:
# 35. (1, (l - 1)^{2})
#     core type: ExprTuple
#     sub-expressions: 77, 41
# 36. in
#     core type: Literal
#     sub-expressions:
# 37. (l, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 63, 42
# 38. (k - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 78
#     operands: 43
# 39. (k - 1)^{2}
#     core type: Operation
#     operator: 78
#     operands: 44
# 40. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 78
#     operands: 45
# 41. (l - 1)^{2}
#     core type: Operation
#     operator: 78
#     operands: 46
# 42. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. (k - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 49, 82
# 44. (k - 1, 2)
#     core type: ExprTuple
#     sub-expressions: 50, 82
# 45. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 51, 82
# 46. (l - 1, 2)
#     core type: ExprTuple
#     sub-expressions: 52, 82
# 47. Interval
#     core type: Literal
#     sub-expressions:
# 48. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 49. k - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 67
#     operands: 55
# 50. k - 1
#     core type: Operation
#     operator: 67
#     operands: 56
# 51. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 67
#     operands: 57
# 52. l - 1
#     core type: Operation
#     operator: 67
#     operands: 58
# 53. e + 1
#     core type: Operation
#     operator: 67
#     operands: 59
# 54. 2^{t - 1}
#     core type: Operation
#     operator: 78
#     operands: 60
# 55. (k, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 56. (k, -1)
#     core type: ExprTuple
#     sub-expressions: 61, 70
# 57. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 63, 62
# 58. (l, -1)
#     core type: ExprTuple
#     sub-expressions: 63, 70
# 59. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 64, 77
# 60. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 82, 65
# 61. k
#     core type: Variable
#     sub-expressions:
# 62. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 73
#     operand: 69
# 63. l
#     core type: Variable
#     sub-expressions:
# 64. e
#     core type: Variable
#     sub-expressions:
# 65. t - 1
#     core type: Operation
#     operator: 67
#     operands: 68
# 66. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 69
# 67. +
#     core type: Literal
#     sub-expressions:
# 68. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 83, 70
# 69. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 71
#     operands: 72
# 70. -1
#     core type: Operation
#     operator: 73
#     operand: 77
# 71. *
#     core type: Literal
#     sub-expressions:
# 72. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 73. -
#     core type: Literal
#     sub-expressions:
# 74. (1)
#     core type: ExprTuple
#     sub-expressions: 77
# 75. 2^{t}
#     core type: Operation
#     operator: 78
#     operands: 79
# 76. delta_{b_{f}}
#     core type: Operation
#     operator: 80
#     operand: 84
# 77. 1
#     core type: Literal
#     sub-expressions:
# 78. Exp
#     core type: Literal
#     sub-expressions:
# 79. (2, t)
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 80. delta
#     core type: Literal
#     sub-expressions:
# 81. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 84
# 82. 2
#     core type: Literal
#     sub-expressions:
# 83. t
#     core type: Literal
#     sub-expressions:
# 84. b_{f}
#     core type: Literal
#     sub-expressions:
