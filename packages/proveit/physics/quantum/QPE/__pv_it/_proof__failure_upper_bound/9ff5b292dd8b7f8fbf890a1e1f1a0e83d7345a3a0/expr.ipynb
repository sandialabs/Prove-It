# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Forall, Implies, InSet
from proveit.numbers import Exp, Real, Sum, frac, one, two
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _neg_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = frac(one, Exp(_diff_l_scaled_delta_floor, two))
expr = Implies(Forall(instance_param_or_params = sub_expr1, instance_expr = InSet(sub_expr2, Real), domain = _neg_domain), InSet(Sum(index_or_indices = sub_expr1, summand = sub_expr2, domain = _neg_domain), Real))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left[\forall_{l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\}}~\left(\frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} \in \mathbb{R}\right)\right] \Rightarrow \left(\left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right) \in \mathbb{R}\right)

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. [forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real)] => ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) in Real)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) in Real)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real)
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) in Real
#    core type: Operation
#    operator: 23
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (l -> {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}), Real)
#    core type: ExprTuple
#    sub-expressions: 9, 18
# 8. l -> {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Lambda
#    parameter: 36
#    body: 10
# 9. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#    core type: Operation
#    operator: 11
#    operand: 14
# 10. {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 13
#     condition: 20
# 11. Sum
#     core type: Literal
#     sub-expressions:
# 12. (l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. (1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real
#     core type: Operation
#     operator: 23
#     operands: 15
# 14. l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Lambda
#     parameter: 36
#     body: 17
# 15. (1 / (l - (2^{t} * delta_{b_{f}}))^{2}, Real)
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 16. (l)
#     core type: ExprTuple
#     sub-expressions: 36
# 17. {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 19
#     condition: 20
# 18. Real
#     core type: Literal
#     sub-expressions:
# 19. 1 / (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. l in {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. /
#     core type: Literal
#     sub-expressions:
# 22. (1, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 64, 25
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 36, 26
# 25. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 52
#     operands: 27
# 26. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 30, 58
# 28. Interval
#     core type: Literal
#     sub-expressions:
# 29. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 56
#     operands: 33
# 31. -2^{t - 1} + 1
#     core type: Operation
#     operator: 56
#     operands: 34
# 32. -(e + 1)
#     core type: Operation
#     operator: 62
#     operand: 39
# 33. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 38, 64
# 35. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 39
# 36. l
#     core type: Variable
#     sub-expressions:
# 37. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 62
#     operand: 43
# 38. -2^{t - 1}
#     core type: Operation
#     operator: 62
#     operand: 44
# 39. e + 1
#     core type: Operation
#     operator: 56
#     operands: 42
# 40. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 43
# 41. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 44
# 42. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 45, 64
# 43. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 46
#     operands: 47
# 44. 2^{t - 1}
#     core type: Operation
#     operator: 52
#     operands: 48
# 45. e
#     core type: Variable
#     sub-expressions:
# 46. *
#     core type: Literal
#     sub-expressions:
# 47. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 48. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 58, 51
# 49. 2^{t}
#     core type: Operation
#     operator: 52
#     operands: 53
# 50. delta_{b_{f}}
#     core type: Operation
#     operator: 54
#     operand: 59
# 51. t - 1
#     core type: Operation
#     operator: 56
#     operands: 57
# 52. Exp
#     core type: Literal
#     sub-expressions:
# 53. (2, t)
#     core type: ExprTuple
#     sub-expressions: 58, 60
# 54. delta
#     core type: Literal
#     sub-expressions:
# 55. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 59
# 56. +
#     core type: Literal
#     sub-expressions:
# 57. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 58. 2
#     core type: Literal
#     sub-expressions:
# 59. b_{f}
#     core type: Literal
#     sub-expressions:
# 60. t
#     core type: Literal
#     sub-expressions:
# 61. -1
#     core type: Operation
#     operator: 62
#     operand: 64
# 62. -
#     core type: Literal
#     sub-expressions:
# 63. (1)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. 1
#     core type: Literal
#     sub-expressions:
