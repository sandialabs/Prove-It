# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k
from proveit.logic import Forall
from proveit.numbers import Exp, LessEq, Mult, frac, one, subtract, two
from proveit.physics.quantum.QPE import _delta_b_floor, _pos_domain, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [k], instance_expr = LessEq(frac(one, Exp(subtract(k, Mult(_two_pow_t, _delta_b_floor)), two)), frac(one, Exp(subtract(k, one), two))), domain = _pos_domain)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{k \in \{e + 1~\ldotp \ldotp~2^{t - 1}\}}~\left(\frac{1}{\left(k - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} \leq \frac{1}{\left(k - 1\right)^{2}}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{k in {e + 1 .. 2^{t - 1}}} ((1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (k -> {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}) if k in {e + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. k -> {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}) if k in {e + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 37
#    body: 5
# 4. (k)
#    core type: ExprTuple
#    sub-expressions: 37
# 5. {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}) if k in {e + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2})
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. k in {e + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. <=
#    core type: Literal
#    sub-expressions:
# 9. (1 / (k - (2^{t} * delta_{b_{f}}))^{2}, 1 / (k - 1)^{2})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (k, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 37, 14
# 12. 1 / (k - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 16
#     operands: 15
# 13. 1 / (k - 1)^{2}
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. (1, (k - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 43, 20
# 16. /
#     core type: Literal
#     sub-expressions:
# 17. (1, (k - 1)^{2})
#     core type: ExprTuple
#     sub-expressions: 43, 21
# 18. Interval
#     core type: Literal
#     sub-expressions:
# 19. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. (k - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 48
#     operands: 24
# 21. (k - 1)^{2}
#     core type: Operation
#     operator: 48
#     operands: 25
# 22. e + 1
#     core type: Operation
#     operator: 34
#     operands: 26
# 23. 2^{t - 1}
#     core type: Operation
#     operator: 48
#     operands: 27
# 24. (k - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 28, 52
# 25. (k - 1, 2)
#     core type: ExprTuple
#     sub-expressions: 29, 52
# 26. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 30, 43
# 27. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 52, 31
# 28. k - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 34
#     operands: 32
# 29. k - 1
#     core type: Operation
#     operator: 34
#     operands: 33
# 30. e
#     core type: Variable
#     sub-expressions:
# 31. t - 1
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. (k, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 37, 36
# 33. (k, -1)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 53, 38
# 36. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 40
#     operand: 42
# 37. k
#     core type: Variable
#     sub-expressions:
# 38. -1
#     core type: Operation
#     operator: 40
#     operand: 43
# 39. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 42
# 40. -
#     core type: Literal
#     sub-expressions:
# 41. (1)
#     core type: ExprTuple
#     sub-expressions: 43
# 42. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 44
#     operands: 45
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. *
#     core type: Literal
#     sub-expressions:
# 45. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 46. 2^{t}
#     core type: Operation
#     operator: 48
#     operands: 49
# 47. delta_{b_{f}}
#     core type: Operation
#     operator: 50
#     operand: 54
# 48. Exp
#     core type: Literal
#     sub-expressions:
# 49. (2, t)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. delta
#     core type: Literal
#     sub-expressions:
# 51. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 54
# 52. 2
#     core type: Literal
#     sub-expressions:
# 53. t
#     core type: Literal
#     sub-expressions:
# 54. b_{f}
#     core type: Literal
#     sub-expressions:
