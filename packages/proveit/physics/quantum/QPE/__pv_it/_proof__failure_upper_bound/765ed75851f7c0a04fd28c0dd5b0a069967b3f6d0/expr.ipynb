# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Add, Exp, Mult, Sum, four, frac, one, two
from proveit.physics.quantum.QPE import _diff_l_scaled_delta_floor, _neg_domain, _pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = frac(one, four)
sub_expr3 = frac(one, Exp(_diff_l_scaled_delta_floor, two))
sub_expr4 = Sum(index_or_indices = sub_expr1, summand = sub_expr3, domain = _pos_domain)
expr = ExprTuple(Mult(sub_expr2, Add(Sum(index_or_indices = sub_expr1, summand = sub_expr3, domain = _neg_domain), sub_expr4)), Mult(sub_expr2, Add(Sum(index_or_indices = sub_expr1, summand = frac(one, Exp(l, two)), domain = _neg_domain), sub_expr4)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\frac{1}{4} \cdot \left(\left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right) + \left(\sum_{l = e + 1}^{2^{t - 1}} \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)\right), \frac{1}{4} \cdot \left(\left(\sum_{l = -2^{t - 1} + 1}^{-\left(e + 1\right)} \frac{1}{l^{2}}\right) + \left(\sum_{l = e + 1}^{2^{t - 1}} \frac{1}{\left(l - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}}\right)\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: Operation
#    operator: 62
#    operands: 3
# 2. (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: Operation
#    operator: 62
#    operands: 4
# 3. (1 / 4, (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: ExprTuple
#    sub-expressions: 6, 5
# 4. (1 / 4, (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 67
#    operands: 8
# 6. 1 / 4
#    core type: Operation
#    operator: 32
#    operands: 9
# 7. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: Operation
#    operator: 67
#    operands: 10
# 8. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}), Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
#    core type: ExprTuple
#    sub-expressions: 11, 14
# 9. (1, 4)
#    core type: ExprTuple
#    sub-expressions: 79, 12
# 10. (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}), Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 17
#     operand: 19
# 12. 4
#     core type: Literal
#     sub-expressions:
# 13. Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})
#     core type: Operation
#     operator: 17
#     operand: 20
# 14. Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: Operation
#     operator: 17
#     operand: 21
# 15. (l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#     core type: ExprTuple
#     sub-expressions: 19
# 16. (l -> {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
#     core type: ExprTuple
#     sub-expressions: 20
# 17. Sum
#     core type: Literal
#     sub-expressions:
# 18. (l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {e + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Lambda
#     parameter: 53
#     body: 22
# 20. l -> {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Lambda
#     parameter: 53
#     body: 23
# 21. l -> {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 53
#     body: 25
# 22. {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 28
#     condition: 27
# 23. {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
#     core type: Conditional
#     value: 26
#     condition: 27
# 24. (l)
#     core type: ExprTuple
#     sub-expressions: 53
# 25. {1 / (l - (2^{t} * delta_{b_{f}}))^{2} if l in {e + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 28
#     condition: 29
# 26. 1 / l^{2}
#     core type: Operation
#     operator: 32
#     operands: 30
# 27. l in {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 34
#     operands: 31
# 28. 1 / (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. l in {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. (1, l^{2})
#     core type: ExprTuple
#     sub-expressions: 79, 36
# 31. (l, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 53, 37
# 32. /
#     core type: Literal
#     sub-expressions:
# 33. (1, (l - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 79, 38
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (l, {e + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 53, 39
# 36. l^{2}
#     core type: Operation
#     operator: 69
#     operands: 40
# 37. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 43
#     operands: 41
# 38. (l - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 69
#     operands: 42
# 39. {e + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. (l, 2)
#     core type: ExprTuple
#     sub-expressions: 53, 74
# 41. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. (l - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 47, 74
# 43. Interval
#     core type: Literal
#     sub-expressions:
# 44. (e + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 52, 58
# 45. -2^{t - 1} + 1
#     core type: Operation
#     operator: 67
#     operands: 48
# 46. -(e + 1)
#     core type: Operation
#     operator: 77
#     operand: 52
# 47. l - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 67
#     operands: 50
# 48. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 51, 79
# 49. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 52
# 50. (l, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. -2^{t - 1}
#     core type: Operation
#     operator: 77
#     operand: 58
# 52. e + 1
#     core type: Operation
#     operator: 67
#     operands: 56
# 53. l
#     core type: Variable
#     sub-expressions:
# 54. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 77
#     operand: 60
# 55. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 58
# 56. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 59, 79
# 57. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 60
# 58. 2^{t - 1}
#     core type: Operation
#     operator: 69
#     operands: 61
# 59. e
#     core type: Variable
#     sub-expressions:
# 60. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 62
#     operands: 63
# 61. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 74, 64
# 62. *
#     core type: Literal
#     sub-expressions:
# 63. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 64. t - 1
#     core type: Operation
#     operator: 67
#     operands: 68
# 65. 2^{t}
#     core type: Operation
#     operator: 69
#     operands: 70
# 66. delta_{b_{f}}
#     core type: Operation
#     operator: 71
#     operand: 76
# 67. +
#     core type: Literal
#     sub-expressions:
# 68. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 75, 73
# 69. Exp
#     core type: Literal
#     sub-expressions:
# 70. (2, t)
#     core type: ExprTuple
#     sub-expressions: 74, 75
# 71. delta
#     core type: Literal
#     sub-expressions:
# 72. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 76
# 73. -1
#     core type: Operation
#     operator: 77
#     operand: 79
# 74. 2
#     core type: Literal
#     sub-expressions:
# 75. t
#     core type: Literal
#     sub-expressions:
# 76. b_{f}
#     core type: Literal
#     sub-expressions:
# 77. -
#     core type: Literal
#     sub-expressions:
# 78. (1)
#     core type: ExprTuple
#     sub-expressions: 79
# 79. 1
#     core type: Literal
#     sub-expressions:
