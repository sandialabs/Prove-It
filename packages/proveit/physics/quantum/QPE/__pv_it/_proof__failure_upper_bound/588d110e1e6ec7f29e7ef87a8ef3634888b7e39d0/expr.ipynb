# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k
from proveit.logic import Forall
from proveit.numbers import Exp, LessEq, Mult, frac, one, subtract, two
from proveit.physics.quantum.QPE import _delta_b_floor, _neg_domain, _two_pow_t

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [k], instance_expr = LessEq(frac(one, Exp(subtract(k, Mult(_two_pow_t, _delta_b_floor)), two)), frac(one, Exp(k, two))), domain = _neg_domain)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{k \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(e + 1\right)\}}~\left(\frac{1}{\left(k - \left(2^{t} \cdot \delta_{b_{\textit{f}}}\right)\right)^{2}} \leq \frac{1}{k^{2}}\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{k in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / k^{2}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (k -> {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / k^{2}) if k in {-2^{t - 1} + 1 .. -(e + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. k -> {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / k^{2}) if k in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Lambda
#    parameter: 34
#    body: 5
# 4. (k)
#    core type: ExprTuple
#    sub-expressions: 34
# 5. {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / k^{2}) if k in {-2^{t - 1} + 1 .. -(e + 1)}.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / k^{2})
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. k in {-2^{t - 1} + 1 .. -(e + 1)}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. <=
#    core type: Literal
#    sub-expressions:
# 9. (1 / (k - (2^{t} * delta_{b_{f}}))^{2}, 1 / k^{2})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (k, {-2^{t - 1} + 1 .. -(e + 1)})
#     core type: ExprTuple
#     sub-expressions: 34, 14
# 12. 1 / (k - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 16
#     operands: 15
# 13. 1 / k^{2}
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. {-2^{t - 1} + 1 .. -(e + 1)}
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. (1, (k - (2^{t} * delta_{b_{f}}))^{2})
#     core type: ExprTuple
#     sub-expressions: 58, 20
# 16. /
#     core type: Literal
#     sub-expressions:
# 17. (1, k^{2})
#     core type: ExprTuple
#     sub-expressions: 58, 21
# 18. Interval
#     core type: Literal
#     sub-expressions:
# 19. (-2^{t - 1} + 1, -(e + 1))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. (k - (2^{t} * delta_{b_{f}}))^{2}
#     core type: Operation
#     operator: 49
#     operands: 24
# 21. k^{2}
#     core type: Operation
#     operator: 49
#     operands: 25
# 22. -2^{t - 1} + 1
#     core type: Operation
#     operator: 44
#     operands: 26
# 23. -(e + 1)
#     core type: Operation
#     operator: 53
#     operand: 30
# 24. (k - (2^{t} * delta_{b_{f}}), 2)
#     core type: ExprTuple
#     sub-expressions: 28, 55
# 25. (k, 2)
#     core type: ExprTuple
#     sub-expressions: 34, 55
# 26. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 29, 58
# 27. (e + 1)
#     core type: ExprTuple
#     sub-expressions: 30
# 28. k - (2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 44
#     operands: 31
# 29. -2^{t - 1}
#     core type: Operation
#     operator: 53
#     operand: 36
# 30. e + 1
#     core type: Operation
#     operator: 44
#     operands: 33
# 31. (k, -(2^{t} * delta_{b_{f}}))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 36
# 33. (e, 1)
#     core type: ExprTuple
#     sub-expressions: 37, 58
# 34. k
#     core type: Variable
#     sub-expressions:
# 35. -(2^{t} * delta_{b_{f}})
#     core type: Operation
#     operator: 53
#     operand: 40
# 36. 2^{t - 1}
#     core type: Operation
#     operator: 49
#     operands: 39
# 37. e
#     core type: Variable
#     sub-expressions:
# 38. (2^{t} * delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 40
# 39. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 55, 41
# 40. 2^{t} * delta_{b_{f}}
#     core type: Operation
#     operator: 42
#     operands: 43
# 41. t - 1
#     core type: Operation
#     operator: 44
#     operands: 45
# 42. *
#     core type: Literal
#     sub-expressions:
# 43. (2^{t}, delta_{b_{f}})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 44. +
#     core type: Literal
#     sub-expressions:
# 45. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 56, 48
# 46. 2^{t}
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. delta_{b_{f}}
#     core type: Operation
#     operator: 51
#     operand: 57
# 48. -1
#     core type: Operation
#     operator: 53
#     operand: 58
# 49. Exp
#     core type: Literal
#     sub-expressions:
# 50. (2, t)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 51. delta
#     core type: Literal
#     sub-expressions:
# 52. (b_{f})
#     core type: ExprTuple
#     sub-expressions: 57
# 53. -
#     core type: Literal
#     sub-expressions:
# 54. (1)
#     core type: ExprTuple
#     sub-expressions: 58
# 55. 2
#     core type: Literal
#     sub-expressions:
# 56. t
#     core type: Literal
#     sub-expressions:
# 57. b_{f}
#     core type: Literal
#     sub-expressions:
# 58. 1
#     core type: Literal
#     sub-expressions:
