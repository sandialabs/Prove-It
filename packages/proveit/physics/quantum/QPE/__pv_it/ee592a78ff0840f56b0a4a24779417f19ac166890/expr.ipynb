# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#deltaDiffInInterval">deltaDiffInInterval</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum.QPE._theorems_ import deltaDiffInInterval

# %%
# check that the built expression is the same as the stored expression
# %check_expr deltaDiffInInterval
# Out:
# Passed sanity check: built 'deltaDiffInInterval' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(deltaDiffInInterval.latex())
# Out:
# \vdash \forall_{l \in \{-2^{t - 1} + 1 \dots 2^{t - 1}\}}~\left(\left(\delta - \frac{l}{2^{t}}\right) \in \left[-\frac{1}{2},\frac{1}{2}\right)\right)

# %%
# display the expression information
deltaDiffInInterval.exprInfo()
# Out:
# 0. forall_{l in {-2^{t - 1} + 1...2^{t - 1}}} ((delta - (l / 2^{t})) in [-(1 / 2),1 / 2))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. l -> {(delta - (l / 2^{t})) in [-(1 / 2),1 / 2) if l in {-2^{t - 1} + 1...2^{t - 1}}.
#    core type: Lambda
#    parameter: 28
#    body: 3
# 3. {(delta - (l / 2^{t})) in [-(1 / 2),1 / 2) if l in {-2^{t - 1} + 1...2^{t - 1}}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (delta - (l / 2^{t})) in [-(1 / 2),1 / 2)
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. l in {-2^{t - 1} + 1...2^{t - 1}}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (delta - (l / 2^{t}), [-(1 / 2),1 / 2))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (l, {-2^{t - 1} + 1...2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 28, 11
# 9. delta - (l / 2^{t})
# ...
