# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#phaseFromBest">phaseFromBest</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum.QPE._theorems_ import phaseFromBest

# %%
# check that the built expression is the same as the stored expression
# %check_expr phaseFromBest
# Out:
# Passed sanity check: built 'phaseFromBest' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(phaseFromBest.latex())
# Out:
# \vdash \varphi = \left(\frac{b}{2^{t}} + \delta\right)

# %%
# display the expression information
phaseFromBest.exprInfo()
# Out:
# 0. phase = ((b / 2^{t}) + delta)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (phase, (b / 2^{t}) + delta)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. phase
#    core type: Literal
#    sub-expressions:
# 4. (b / 2^{t}) + delta
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (b / 2^{t}, delta)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. b / 2^{t}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. delta
#    core type: Literal
#    sub-expressions:
# 9. /
#    core type: Literal
#    sub-expressions:
# 10. (b, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. b
#     core type: Literal
#     sub-expressions:
# 12. 2^{t}
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. Exp
#     core type: Literal
#     sub-expressions:
# 14. (2, t)
#     core type: ExprTuple
# ...
