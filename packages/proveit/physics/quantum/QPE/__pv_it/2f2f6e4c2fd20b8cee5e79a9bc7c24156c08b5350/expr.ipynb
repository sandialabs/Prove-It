# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.number.Mult.html">Mult</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Literal
from proveit._common_ import k, l
from proveit.number import Add, Exp, Interval, Mult, Neg, Sum, e, frac, i, one, pi, two, zero
from proveit.physics.quantum.QPE import ModAdd

# %%
# build up the expression from sub-expressions
subExpr1 = Exp(two, Literal("t", context = "proveit.physics.quantum.QPE"))
expr = Mult(frac(one, subExpr1), Sum([k], Mult(Exp(e, frac(Neg(Mult(two, pi, i, k, ModAdd(Literal("b", context = "proveit.physics.quantum.QPE"), l))), subExpr1)), Exp(e, Mult(two, pi, i, Literal("phase", latexFormat = r"\varphi", context = "proveit.physics.quantum.QPE"), k))), domain = Interval(zero, Add(subExpr1, Neg(one)))))
# Out:
# expr: (1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \frac{1}{2^{t}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(e^{\frac{-\left(2 \cdot \pi \cdot i \cdot k \cdot \left(b \oplus l\right)\right)}{2^{t}}} \cdot e^{2 \cdot \pi \cdot i \cdot \varphi \cdot k}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}))
#    core type: Operation
#    operator: 39
#    operands: 1
# 1. (1 / 2^{t}, Sum_{k=0}^{2^{t} - 1} e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k})
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. 1 / 2^{t}
#    core type: Operation
#    operator: 25
#    operands: 4
# 3. Sum_{k=0}^{2^{t} - 1} e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (1, 2^{t})
#    core type: ExprTuple
#    sub-expressions: 38, 32
# 5. Sum
#    core type: Literal
#    sub-expressions:
# 6. k -> {e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k} if k in {0...2^{t} - 1}.
#    core type: Lambda
#    parameter: 45
#    body: 7
# 7. {e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k} if k in {0...2^{t} - 1}.
# ...
