# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ConditionalSet, ExprRange, ExprTuple, U, Variable, s, t
from proveit.linear_algebra import MatrixExp
from proveit.logic import Equals, NotEquals, Set
from proveit.numbers import Add, Exp, Interval, Neg, one, two
from proveit.physics.quantum import CONTROL, I
from proveit.physics.quantum.circuits import Gate, MultiQubitElem

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr3 = Add(t, one)
sub_expr4 = Add(sub_expr2, t)
expr = ExprTuple(ExprRange(sub_expr1, ConditionalSet(Conditional(MultiQubitElem(element = CONTROL, targets = Set(sub_expr3)), Equals(sub_expr4, sub_expr1)), Conditional(Gate(operation = I).with_implicit_representation(), NotEquals(sub_expr4, sub_expr1))), one, t).with_case_simplification(), ExprRange(sub_expr1, MultiQubitElem(element = Gate(operation = MatrixExp(U, Exp(two, Neg(sub_expr2))), part = sub_expr1), targets = Interval(sub_expr3, Add(t, s))), one, s))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left\{\begin{array}{ccc}\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array} \textrm{ if } \left({_{-}b} + t\right) = 1 \\ \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} \textrm{ if } \left({_{-}b} + t\right) \neq 1\end{array}\right.., \left\{\begin{array}{ccc}\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array} \textrm{ if } \left({_{-}b} + t\right) = 2 \\ \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} \textrm{ if } \left({_{-}b} + t\right) \neq 2\end{array}\right.., \ldots, \left\{\begin{array}{ccc}\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array} \textrm{ if } \left({_{-}b} + t\right) = t \\ \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array} \textrm{ if } \left({_{-}b} + t\right) \neq t\end{array}\right..,\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-{_{-}b}}}~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-{_{-}b}}}~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{-{_{-}b}}}~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 1; [GATE]{operation:I} if (_b + t) != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 2; [GATE]{operation:I} if (_b + t) != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = t; [GATE]{operation:I} if (_b + t) != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 1; [GATE]{operation:I} if (_b + t) != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 2; [GATE]{operation:I} if (_b + t) != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = t; [GATE]{operation:I} if (_b + t) != t.
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 53
#    end_index: 52
# 2. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:s}, targets:{t + 1 .. t + s}}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 53
#    end_index: 44
# 3. _a -> {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a; [GATE]{operation:I} if (_b + t) != _a.
#    core type: Lambda
#    parameter: 35
#    body: 5
# 4. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Lambda
#    parameter: 35
#    body: 7
# 5. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a; [GATE]{operation:I} if (_b + t) != _a.
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. (_a)
#    core type: ExprTuple
#    sub-expressions: 35
# 7. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#    core type: Operation
#    operator: 22
#    operands: 10
# 8. CondSet
#    core type: Literal
#    sub-expressions:
# 9. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a, [GATE]{operation:I} if (_b + t) != _a)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. {element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 13
#     targets: 14
# 11. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a.
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. {[GATE]{operation:I} if (_b + t) != _a.
#     core type: Conditional
#     value: 17
#     condition: 18
# 13. [GATE]{operation:U^{2^{-_b}}, part:_a}
#     core type: Operation
#     operator: 25
#     operands: 19
# 14. {t + 1 .. t + s}
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}
#     core type: Operation
#     operator: 22
#     operands: 23
# 16. (_b + t) = _a
#     core type: Operation
#     operator: 24
#     operands: 28
# 17. [GATE]{operation:I}
#     core type: Operation
#     operator: 25
#     operands: 26
# 18. (_b + t) != _a
#     core type: Operation
#     operator: 27
#     operands: 28
# 19. {operation:U^{2^{-_b}}, part:_a}
#     core type: NamedExprs
#     operation: 29
#     part: 35
# 20. Interval
#     core type: Literal
#     sub-expressions:
# 21. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 45, 30
# 22. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 23. {element:CONTROL, targets:{t + 1}}
#     core type: NamedExprs
#     element: 31
#     targets: 32
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. GATE
#     core type: Literal
#     sub-expressions:
# 26. {operation:I}
#     core type: NamedExprs
#     operation: 33
# 27. !=
#     core type: Literal
#     sub-expressions:
# 28. (_b + t, _a)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 29. U^{2^{-_b}}
#     core type: Operation
#     operator: 36
#     operands: 37
# 30. t + s
#     core type: Operation
#     operator: 48
#     operands: 38
# 31. CONTROL
#     core type: Literal
#     sub-expressions:
# 32. {t + 1}
#     core type: Operation
#     operator: 39
#     operand: 45
# 33. I
#     core type: Literal
#     sub-expressions:
# 34. _b + t
#     core type: Operation
#     operator: 48
#     operands: 41
# 35. _a
#     core type: Variable
#     sub-expressions:
# 36. ExpM
#     core type: Literal
#     sub-expressions:
# 37. (U, 2^{-_b})
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 38. (t, s)
#     core type: ExprTuple
#     sub-expressions: 52, 44
# 39. Set
#     core type: Literal
#     sub-expressions:
# 40. (t + 1)
#     core type: ExprTuple
#     sub-expressions: 45
# 41. (_b, t)
#     core type: ExprTuple
#     sub-expressions: 56, 52
# 42. U
#     core type: Variable
#     sub-expressions:
# 43. 2^{-_b}
#     core type: Operation
#     operator: 46
#     operands: 47
# 44. s
#     core type: Variable
#     sub-expressions:
# 45. t + 1
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. Exp
#     core type: Literal
#     sub-expressions:
# 47. (2, -_b)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. 2
#     core type: Literal
#     sub-expressions:
# 51. -_b
#     core type: Operation
#     operator: 54
#     operand: 56
# 52. t
#     core type: Variable
#     sub-expressions:
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. -
#     core type: Literal
#     sub-expressions:
# 55. (_b)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. _b
#     core type: Variable
#     sub-expressions:
