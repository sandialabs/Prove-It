# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ConditionalSet, ExprRange, U, Variable, s, t
from proveit.linear_algebra import MatrixExp
from proveit.logic import Equals, NotEquals, Set
from proveit.numbers import Add, Exp, Interval, Neg, one, two, zero
from proveit.physics.quantum import CONTROL, I
from proveit.physics.quantum.circuits import Gate, MultiQubitElem

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr2 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr3 = Add(t, one)
sub_expr4 = Add(sub_expr1, t)
expr = ExprRange(sub_expr1, [ExprRange(sub_expr2, ConditionalSet(Conditional(MultiQubitElem(element = CONTROL, targets = Set(sub_expr3)), Equals(sub_expr4, sub_expr2)), Conditional(Gate(operation = I).with_implicit_representation(), NotEquals(sub_expr4, sub_expr2))), one, t).with_case_simplification(), ExprRange(sub_expr2, MultiQubitElem(element = Gate(operation = MatrixExp(U, Exp(two, Neg(sub_expr1))), part = sub_expr2), targets = Interval(sub_expr3, Add(t, s))), one, s)], Add(Neg(t), one), zero).with_decreasing_order().with_case_simplification()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{t - 1}}~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{t - 1}}~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{t - 1}}~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}\right), \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{t - 2}}~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{t - 2}}~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{t - 2}}~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}\right), \ldots, \left(\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \qw & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{CONTROL~\mbox{on}~\left\{t + 1\right\}} & \qw
# } \end{array},\begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{0}}~\mbox{part}~1~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{0}}~\mbox{part}~2~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}, \ldots, \begin{array}{c} \Qcircuit@C=1em @R=.7em{
# & & \gate{U^{2^{0}}~\mbox{part}~s~\mbox{on}~\{t + 1~\ldotp \ldotp~t + s\}} & \qw
# } \end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')
# style name: front_expansion
# description: The number of instances to display at the front of the range (e.g., before the ellipsis). Default is 2.
# default: 2
# current value: 2
# related methods: ('with_front_expansion', 'get_front_expansion')
# style name: back_expansion
# description: The number of instances to display at the back of the range (e.g., after the ellipsis). Default is 1.
# default: 1
# current value: 1
# related methods: ('with_back_expansion', 'get_back_expansion')
# style name: order
# description: The default order is 'increasing' (a_1 ... a_3) but to represent a 'decreasing' ExprRange (a_6 ... a_2) the order must be set to 'decreasing'
# default: increasing
# current value: decreasing
# related methods: ('with_decreasing_order', 'with_increasing_order')
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: case_simplify
# description: If 'True', simplify formatted instances that are ConditionalSets under proper index assumptions
# default: False
# current value: True
# related methods: ('with_case_simplification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, [GATE]{operation:I}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 1}}, part:s}, targets:{t + 1 .. t + s}}), ([GATE]{operation:I}, [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}, ..., [GATE]{operation:I},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{t - 2}}, part:s}, targets:{t + 1 .. t + s}}), ..., ([GATE]{operation:I}, [GATE]{operation:I}, ..., [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{0}}, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. _b -> ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 1; [GATE]{operation:I} if (_b + t) != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 2; [GATE]{operation:I} if (_b + t) != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = t; [GATE]{operation:I} if (_b + t) != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:s}, targets:{t + 1 .. t + s}})
#    core type: Lambda
#    parameter: 63
#    body: 4
# 2. -t + 1
#    core type: Operation
#    operator: 55
#    operands: 5
# 3. 0
#    core type: Literal
#    sub-expressions:
# 4. ({[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 1; [GATE]{operation:I} if (_b + t) != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 2; [GATE]{operation:I} if (_b + t) != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = t; [GATE]{operation:I} if (_b + t) != t.,[MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:s}, targets:{t + 1 .. t + s}})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (-t, 1)
#    core type: ExprTuple
#    sub-expressions: 8, 60
# 6. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 1; [GATE]{operation:I} if (_b + t) != 1., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = 2; [GATE]{operation:I} if (_b + t) != 2., ..., {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = t; [GATE]{operation:I} if (_b + t) != t.
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 60
#    end_index: 59
# 7. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:s}, targets:{t + 1 .. t + s}}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 60
#    end_index: 51
# 8. -t
#    core type: Operation
#    operator: 61
#    operand: 59
# 9. _a -> {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a; [GATE]{operation:I} if (_b + t) != _a.
#    core type: Lambda
#    parameter: 42
#    body: 12
# 10. _a -> [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Lambda
#     parameter: 42
#     body: 14
# 11. (t)
#     core type: ExprTuple
#     sub-expressions: 59
# 12. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a; [GATE]{operation:I} if (_b + t) != _a.
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (_a)
#     core type: ExprTuple
#     sub-expressions: 42
# 14. [MULTI_QUBIT_ELEM]{element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#     core type: Operation
#     operator: 29
#     operands: 17
# 15. CondSet
#     core type: Literal
#     sub-expressions:
# 16. ([MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a, [GATE]{operation:I} if (_b + t) != _a)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. {element:[GATE]{operation:U^{2^{-_b}}, part:_a}, targets:{t + 1 .. t + s}}
#     core type: NamedExprs
#     element: 20
#     targets: 21
# 18. {[MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}} if (_b + t) = _a.
#     core type: Conditional
#     value: 22
#     condition: 23
# 19. {[GATE]{operation:I} if (_b + t) != _a.
#     core type: Conditional
#     value: 24
#     condition: 25
# 20. [GATE]{operation:U^{2^{-_b}}, part:_a}
#     core type: Operation
#     operator: 32
#     operands: 26
# 21. {t + 1 .. t + s}
#     core type: Operation
#     operator: 27
#     operands: 28
# 22. [MULTI_QUBIT_ELEM]{element:CONTROL, targets:{t + 1}}
#     core type: Operation
#     operator: 29
#     operands: 30
# 23. (_b + t) = _a
#     core type: Operation
#     operator: 31
#     operands: 35
# 24. [GATE]{operation:I}
#     core type: Operation
#     operator: 32
#     operands: 33
# 25. (_b + t) != _a
#     core type: Operation
#     operator: 34
#     operands: 35
# 26. {operation:U^{2^{-_b}}, part:_a}
#     core type: NamedExprs
#     operation: 36
#     part: 42
# 27. Interval
#     core type: Literal
#     sub-expressions:
# 28. (t + 1, t + s)
#     core type: ExprTuple
#     sub-expressions: 52, 37
# 29. MULTI_QUBIT_ELEM
#     core type: Literal
#     sub-expressions:
# 30. {element:CONTROL, targets:{t + 1}}
#     core type: NamedExprs
#     element: 38
#     targets: 39
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. GATE
#     core type: Literal
#     sub-expressions:
# 33. {operation:I}
#     core type: NamedExprs
#     operation: 40
# 34. !=
#     core type: Literal
#     sub-expressions:
# 35. (_b + t, _a)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 36. U^{2^{-_b}}
#     core type: Operation
#     operator: 43
#     operands: 44
# 37. t + s
#     core type: Operation
#     operator: 55
#     operands: 45
# 38. CONTROL
#     core type: Literal
#     sub-expressions:
# 39. {t + 1}
#     core type: Operation
#     operator: 46
#     operand: 52
# 40. I
#     core type: Literal
#     sub-expressions:
# 41. _b + t
#     core type: Operation
#     operator: 55
#     operands: 48
# 42. _a
#     core type: Variable
#     sub-expressions:
# 43. ExpM
#     core type: Literal
#     sub-expressions:
# 44. (U, 2^{-_b})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 45. (t, s)
#     core type: ExprTuple
#     sub-expressions: 59, 51
# 46. Set
#     core type: Literal
#     sub-expressions:
# 47. (t + 1)
#     core type: ExprTuple
#     sub-expressions: 52
# 48. (_b, t)
#     core type: ExprTuple
#     sub-expressions: 63, 59
# 49. U
#     core type: Variable
#     sub-expressions:
# 50. 2^{-_b}
#     core type: Operation
#     operator: 53
#     operands: 54
# 51. s
#     core type: Variable
#     sub-expressions:
# 52. t + 1
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. Exp
#     core type: Literal
#     sub-expressions:
# 54. (2, -_b)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 55. +
#     core type: Literal
#     sub-expressions:
# 56. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 57. 2
#     core type: Literal
#     sub-expressions:
# 58. -_b
#     core type: Operation
#     operator: 61
#     operand: 63
# 59. t
#     core type: Variable
#     sub-expressions:
# 60. 1
#     core type: Literal
#     sub-expressions:
# 61. -
#     core type: Literal
#     sub-expressions:
# 62. (_b)
#     core type: ExprTuple
#     sub-expressions: 63
# 63. _b
#     core type: Variable
#     sub-expressions:
