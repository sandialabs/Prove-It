# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#psi_t">psi_t</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.physics.quantum.QPE.SubIndexed.html">SubIndexed</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import psi_t

# %%
# check that the built expression is the same as the stored expression
assert psi_t == stored_expr
assert psi_t._style_id == stored_expr._style_id
print("Passed sanity check: psi_t matches stored_expr")
# Out:
# Passed sanity check: psi_t matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(psi_t.latex())
# Out:
# \psi_{t}

# %%
# display the expression information
psi_t.expr_info()
# Out:
# 0. psi_{t}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. SUB_INDEXED
#    core type: Literal
#    sub-expressions:
# 2. (psi, t)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. psi
#    core type: Literal
#    sub-expressions:
# 4. t
#    core type: Literal
#    sub-expressions:
