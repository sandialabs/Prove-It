# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#alpha_">alpha_</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Literal.html">Literal</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import alpha_

# %%
# check that the built expression is the same as the stored expression
assert alpha_ == stored_expr
assert alpha_._style_id == stored_expr._style_id
print("Passed sanity check: alpha_ matches stored_expr")
# Out:
# Passed sanity check: alpha_ matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(alpha_.latex())
# Out:
# \alpha

# %%
# display the expression information
alpha_.expr_info()
# Out:
# 0. alpha
#    core type: Literal
#    sub-expressions:
