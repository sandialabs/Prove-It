# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#nonIntDeltaDiff">nonIntDeltaDiff</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum.QPE._theorems_ import nonIntDeltaDiff

# %%
# check that the built expression is the same as the stored expression
# %check_expr nonIntDeltaDiff
# Out:
# Passed sanity check: built 'nonIntDeltaDiff' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(nonIntDeltaDiff.latex())
# Out:
# \vdash \forall_{l \in \{-2^{t - 1} + 1 \dots 2^{t - 1}\}~|~l \neq 0}~\left(\left(\delta - \frac{l}{2^{t}}\right) \notin \mathbb{Z}\right)

# %%
# display the expression information
nonIntDeltaDiff.exprInfo()
# Out:
# 0. forall_{l in {-2^{t - 1} + 1...2^{t - 1}} | l != 0} ((delta - (l / 2^{t})) not-in Integers)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. l -> {(delta - (l / 2^{t})) not-in Integers if l in {-2^{t - 1} + 1...2^{t - 1}} ,  l != 0.
#    core type: Lambda
#    parameter: 29
#    body: 3
# 3. {(delta - (l / 2^{t})) not-in Integers if l in {-2^{t - 1} + 1...2^{t - 1}} ,  l != 0.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (delta - (l / 2^{t})) not-in Integers
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (l in {-2^{t - 1} + 1...2^{t - 1}}) and (l != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. not-in
#    core type: Literal
#    sub-expressions:
# 7. (delta - (l / 2^{t}), Integers)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (l in {-2^{t - 1} + 1...2^{t - 1}}, l != 0)
# ...
