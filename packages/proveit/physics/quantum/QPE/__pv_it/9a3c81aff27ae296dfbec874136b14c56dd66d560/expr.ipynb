# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#alpha_l_eval">alpha_l_eval</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum.QPE._theorems_ import alpha_l_eval

# %%
# check that the built expression is the same as the stored expression
# %check_expr alpha_l_eval
# Out:
# Passed sanity check: built 'alpha_l_eval' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(alpha_l_eval.latex())
# Out:
# \vdash \forall_{l \in \mathbb{Z}}~\left(\alpha_{l} = \left(\frac{1}{2^{t}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(e^{\frac{-\left(2 \cdot \pi \cdot i \cdot k \cdot \left(b \oplus l\right)\right)}{2^{t}}} \cdot e^{2 \cdot \pi \cdot i \cdot \varphi \cdot k}\right)\right)\right)\right)

# %%
# display the expression information
alpha_l_eval.exprInfo()
# Out:
# 0. forall_{l in Integers} (alpha_{l} = ((1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}))))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. l -> {alpha_{l} = ((1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}))) if l in Integers.
#    core type: Lambda
#    parameter: 64
#    body: 3
# 3. {alpha_{l} = ((1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}))) if l in Integers.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. alpha_{l} = ((1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k})))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. l in Integers
#    core type: Operation
#    operator: 25
#    operands: 8
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (alpha_{l}, (1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k})))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (l, Integers)
#    core type: ExprTuple
#    sub-expressions: 64, 11
# 9. alpha_{l}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. (1 / 2^{t}) * (Sum_{k=0}^{2^{t} - 1} (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}))
#     core type: Operation
#     operator: 53
#     operands: 14
# 11. Integers
#     core type: Literal
#     sub-expressions:
# 12. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 13. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 15, 64
# 14. (1 / 2^{t}, Sum_{k=0}^{2^{t} - 1} e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. alpha
#     core type: Literal
#     sub-expressions:
# 16. 1 / 2^{t}
#     core type: Operation
#     operator: 39
#     operands: 18
# 17. Sum_{k=0}^{2^{t} - 1} e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 19
#     operand: 20
# 18. (1, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 52, 46
# 19. Sum
#     core type: Literal
#     sub-expressions:
# 20. k -> {e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k} if k in {0...2^{t} - 1}.
#     core type: Lambda
#     parameter: 59
#     body: 21
# 21. {e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k} if k in {0...2^{t} - 1}.
#     core type: Conditional
#     value: 22
#     condition: 23
# 22. e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}} * e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 53
#     operands: 24
# 23. k in {0...2^{t} - 1}
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. (e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}}, e^{2 * pi * i * phase * k})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (k, {0...2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 59, 29
# 27. e^{(-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}}
#     core type: Operation
#     operator: 49
#     operands: 30
# 28. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 49
#     operands: 31
# 29. {0...2^{t} - 1}
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. (e, (-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 35, 34
# 31. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 32. Interval
#     core type: Literal
#     sub-expressions:
# 33. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. (-(2 * pi * i * k * (b MOD_ADD l))) / 2^{t}
#     core type: Operation
#     operator: 39
#     operands: 40
# 35. e
#     core type: Literal
#     sub-expressions:
# 36. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 53
#     operands: 41
# 37. 0
#     core type: Literal
#     sub-expressions:
# 38. 2^{t} - 1
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. /
#     core type: Literal
#     sub-expressions:
# 40. (-(2 * pi * i * k * (b MOD_ADD l)), 2^{t})
#     core type: ExprTuple
#     sub-expressions: 44, 46
# 41. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 56, 57, 58, 45, 59
# 42. +
#     core type: Literal
#     sub-expressions:
# 43. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 44. -(2 * pi * i * k * (b MOD_ADD l))
#     core type: Operation
#     operator: 51
#     operand: 48
# 45. phase
#     core type: Literal
#     sub-expressions:
# 46. 2^{t}
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. -1
#     core type: Operation
#     operator: 51
#     operand: 52
# 48. 2 * pi * i * k * (b MOD_ADD l)
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. Exp
#     core type: Literal
#     sub-expressions:
# 50. (2, t)
#     core type: ExprTuple
#     sub-expressions: 56, 55
# 51. -
#     core type: Literal
#     sub-expressions:
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. *
#     core type: Literal
#     sub-expressions:
# 54. (2, pi, i, k, b MOD_ADD l)
#     core type: ExprTuple
#     sub-expressions: 56, 57, 58, 59, 60
# 55. t
#     core type: Literal
#     sub-expressions:
# 56. 2
#     core type: Literal
#     sub-expressions:
# 57. pi
#     core type: Literal
#     sub-expressions:
# 58. i
#     core type: Literal
#     sub-expressions:
# 59. k
#     core type: Variable
#     sub-expressions:
# 60. b MOD_ADD l
#     core type: Operation
#     operator: 61
#     operands: 62
# 61. MOD_ADD
#     core type: Literal
#     sub-expressions:
# 62. (b, l)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 63. b
#     core type: Literal
#     sub-expressions:
# 64. l
#     core type: Variable
#     sub-expressions:
