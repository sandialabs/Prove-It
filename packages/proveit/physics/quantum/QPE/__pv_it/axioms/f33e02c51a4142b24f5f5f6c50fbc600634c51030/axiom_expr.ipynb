# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#alpha_def">alpha_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import alpha_def

# %%
# check that the built expression is the same as the stored expression
assert alpha_def.expr == stored_expr
assert alpha_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: alpha_def matches stored_expr")
# Out:
# Passed sanity check: alpha_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(alpha_def.latex())
# Out:
# \vdash \forall_{l \in \mathbb{Z}}~\left(\alpha_{l} = {_{t}}\langle b \oplus l \rvert\Psi \rangle\right)

# %%
# display the expression information
alpha_def.expr_info()
# Out:
# 0. forall_{l in Integer} (alpha_{l} = {t}_〈b MOD_ADD l|Psi〉)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. l -> {alpha_{l} = {t}_〈b MOD_ADD l|Psi〉 if l in Integer.
#    core type: Lambda
#    parameter: 29
#    body: 3
# 3. {alpha_{l} = {t}_〈b MOD_ADD l|Psi〉 if l in Integer.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. alpha_{l} = {t}_〈b MOD_ADD l|Psi〉
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. l in Integer
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (alpha_{l}, {t}_〈b MOD_ADD l|Psi〉)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (l, Integer)
#    core type: ExprTuple
#    sub-expressions: 29, 12
# 10. alpha_{l}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. {t}_〈b MOD_ADD l| . |Psi〉
# ...
