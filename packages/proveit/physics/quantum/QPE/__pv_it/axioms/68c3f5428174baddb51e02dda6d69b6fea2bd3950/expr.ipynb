# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, Lambda, Variable, t
from proveit.linear_algebra import ScalarMult, TensorProd, VecAdd
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Exp, Mult, NaturalPos, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import _phase, _psi_t_ket

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda(t, Conditional(Equals(_psi_t_ket, TensorProd(ExprRange(sub_expr1, ScalarMult(frac(one, sqrt(two)), VecAdd(ket0, ScalarMult(Exp(e, Mult(two, pi, i, Exp(two, Neg(sub_expr1)), _phase)), ket1))), Add(Neg(t), one), zero).with_decreasing_order())), InSet(t, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(t \mapsto \left\{\lvert \psi_{t} \rangle = \left(\left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 1} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{t - 2} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right) {\otimes}  \ldots {\otimes}  \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot 2^{0} \cdot \varphi} \cdot \lvert 1 \rangle\right)\right)\right)\right) \textrm{ if } t \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (t -> {|psi_{t}> = (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))) if t in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. t -> {|psi_{t}> = (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))) if t in NaturalPos.
#    core type: Lambda
#    parameter: 29
#    body: 2
# 2. {|psi_{t}> = (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))) if t in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. |psi_{t}> = (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. t in NaturalPos
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (|psi_{t}>, ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (t, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 29, 11
# 9. |psi_{t}>
#    core type: Operation
#    operator: 12
#    operand: 29
# 10. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. psi
#     core type: Literal
#     sub-expressions:
# 13. otimes
#     core type: Literal
#     sub-expressions:
# 14. (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
#     core type: ExprTuple
#     sub-expressions: 15
# 15. ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 38
# 16. _a -> ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)))
#     core type: Lambda
#     parameter: 61
#     body: 18
# 17. -t + 1
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: Operation
#     operator: 35
#     operands: 21
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (-t, 1)
#     core type: ExprTuple
#     sub-expressions: 22, 48
# 21. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. -t
#     core type: Operation
#     operator: 59
#     operand: 29
# 23. 1 / sqrt(2)
#     core type: Operation
#     operator: 41
#     operands: 26
# 24. |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. (t)
#     core type: ExprTuple
#     sub-expressions: 29
# 26. (1, sqrt(2))
#     core type: ExprTuple
#     sub-expressions: 48, 30
# 27. +
#     core type: Literal
#     sub-expressions:
# 28. (|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. t
#     core type: Variable
#     sub-expressions:
# 30. sqrt(2)
#     core type: Operation
#     operator: 55
#     operands: 33
# 31. |0〉
#     core type: Operation
#     operator: 44
#     operand: 38
# 32. e^{2 * pi * i * 2^{-_a} * phase} * |1〉
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 57, 37
# 34. (0)
#     core type: ExprTuple
#     sub-expressions: 38
# 35. *
#     core type: Literal
#     sub-expressions:
# 36. (e^{2 * pi * i * 2^{-_a} * phase}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 37. 1 / 2
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. 0
#     core type: Literal
#     sub-expressions:
# 39. e^{2 * pi * i * 2^{-_a} * phase}
#     core type: Operation
#     operator: 55
#     operands: 43
# 40. |1〉
#     core type: Operation
#     operator: 44
#     operand: 48
# 41. /
#     core type: Literal
#     sub-expressions:
# 42. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 48, 57
# 43. (e, 2 * pi * i * 2^{-_a} * phase)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 44. KET
#     core type: Literal
#     sub-expressions:
# 45. (1)
#     core type: ExprTuple
#     sub-expressions: 48
# 46. e
#     core type: Literal
#     sub-expressions:
# 47. 2 * pi * i * 2^{-_a} * phase
#     core type: Operation
#     operator: 49
#     operands: 50
# 48. 1
#     core type: Literal
#     sub-expressions:
# 49. *
#     core type: Literal
#     sub-expressions:
# 50. (2, pi, i, 2^{-_a}, phase)
#     core type: ExprTuple
#     sub-expressions: 57, 51, 52, 53, 54
# 51. pi
#     core type: Literal
#     sub-expressions:
# 52. i
#     core type: Literal
#     sub-expressions:
# 53. 2^{-_a}
#     core type: Operation
#     operator: 55
#     operands: 56
# 54. phase
#     core type: Literal
#     sub-expressions:
# 55. Exp
#     core type: Literal
#     sub-expressions:
# 56. (2, -_a)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 57. 2
#     core type: Literal
#     sub-expressions:
# 58. -_a
#     core type: Operation
#     operator: 59
#     operand: 61
# 59. -
#     core type: Literal
#     sub-expressions:
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. _a
#     core type: Variable
#     sub-expressions:
