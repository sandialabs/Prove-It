# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#PsiKetInQRegSpace">PsiKetInQRegSpace</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import PsiKetInQRegSpace

# %%
# check that the built expression is the same as the stored expression
assert PsiKetInQRegSpace.expr == stored_expr
assert PsiKetInQRegSpace.expr._style_id == stored_expr._style_id
print("Passed sanity check: PsiKetInQRegSpace matches stored_expr")
# Out:
# Passed sanity check: PsiKetInQRegSpace matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(PsiKetInQRegSpace.latex())
# Out:
# \vdash \lvert \Psi \rangle \in \left(\mathbb{C}^{2}\right)^{\otimes t}

# %%
# display the expression information
PsiKetInQRegSpace.expr_info()
# Out:
# 0. |Psi〉 in (Complex^{2})^{otimes t}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (|Psi〉, (Complex^{2})^{otimes t})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |Psi〉
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (Complex^{2})^{otimes t}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. KET
#    core type: Literal
#    sub-expressions:
# 6. Psi
#    core type: Literal
#    sub-expressions:
# 7. otimes
#    core type: Literal
#    sub-expressions:
# 8. ((Complex^{2}), t)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. (Complex^{2})
#    core type: ExprTuple
#    sub-expressions: 11
# 10. t
#     core type: Literal
#     sub-expressions:
# 11. Complex^{2}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# ...
