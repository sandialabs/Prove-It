# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#u_ket_register">u_ket_register</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.physics.quantum.QPE import u_ket_register

# %%
# %dependencies u_ket_register
# Out:
# <h3>No theorems/conjectures depend upon u_ket_register</h3>
