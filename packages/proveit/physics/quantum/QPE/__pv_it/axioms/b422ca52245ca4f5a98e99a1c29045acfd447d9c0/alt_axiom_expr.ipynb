# %% [markdown]
# Temporary notebook for <a class="ProveItLink" href="../../../_axioms_.ipynb#success_def">success_def</a> of type <a href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # a not-yet-official axiom from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import eps
from proveit.logic import Equals, Forall
from proveit.numbers import Add, LessEq, ModAbs, NaturalPos, Neg
from proveit.physics.quantum.QPE import Psuccess, b_, m_, two_pow_t
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Forall([eps], Equals(Psuccess(eps), Prob(LessEq(ModAbs(Add(m_, Neg(b_)), two_pow_t), eps), m_)), domains = [NaturalPos])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: success_def matches stored_expr")

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())

# %%
# display the expression information
expr.expr_info()
