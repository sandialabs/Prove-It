# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k
from proveit.linalg import TensorExp
from proveit.logic import Forall, InSet
from proveit.numbers import Complex, Exp, NaturalPos, two
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import psi_k

# %%
# build up the expression from sub-expressions
expr = Forall([k], InSet(Ket(psi_k), TensorExp([Exp(Complex, two)], k)), domains = [NaturalPos])
# Out:
# expr: forall_{k in NaturalPos} (|psi_{k}〉 in (Complex^{2})^{otimes k})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{k \in \mathbb{N}^+}~\left(\lvert \psi_{k} \rangle \in \left(\mathbb{C}^{2}\right)^{\otimes k}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{k in NaturalPos} (|psi_{k}〉 in (Complex^{2})^{otimes k})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. k -> {|psi_{k}〉 in (Complex^{2})^{otimes k} if k in NaturalPos.
#    core type: Lambda
#    parameter: 20
#    body: 3
# 3. {|psi_{k}〉 in (Complex^{2})^{otimes k} if k in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. |psi_{k}〉 in (Complex^{2})^{otimes k}
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. k in NaturalPos
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (|psi_{k}〉, (Complex^{2})^{otimes k})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (k, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 20, 11
# 9. |psi_{k}〉
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. (Complex^{2})^{otimes k}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. KET
#     core type: Literal
#     sub-expressions:
# 13. psi_{k}
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. otimes
#     core type: Literal
#     sub-expressions:
# 15. ((Complex^{2}), k)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 16. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 17. (psi, k)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 21
# 19. psi
#     core type: Literal
#     sub-expressions:
# 20. k
#     core type: Variable
#     sub-expressions:
# 21. Complex^{2}
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. Complex
#     core type: Literal
#     sub-expressions:
# 25. 2
#     core type: Literal
#     sub-expressions:
