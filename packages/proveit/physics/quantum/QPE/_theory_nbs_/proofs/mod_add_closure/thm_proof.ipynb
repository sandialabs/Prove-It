# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#mod_add_closure">mod_add_closure</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import a, b
from proveit.logic import InSet
from proveit.numbers import Add, Integer
from proveit.numbers.modular import mod_int_closure
from proveit.physics.quantum.QPE  import mod_add_def
from proveit.physics.quantum.QPE import two_pow_t
from proveit.physics.quantum.QPE import two_pow_t_is_nat_pos, two_pow_t_not_zero
theory = proveit.Theory() # the theorem's theory

# %%
# %proving mod_add_closure
# Out:
# mod_add_closure: forall_{a, b in Integer} ((a MOD_ADD b) in Integer)

# %%
defaults = mod_add_closure.conditions
# Out:
# defaults: (a in Integer, b in Integer)

# %%
mod_add_def
# Out:
# |- forall_{a, b in Integer} ((a MOD_ADD b) = ((a + b) mod  2^{t}))

# %%
mod_add_def_spec = mod_add_def.instantiate({a:a, b:b}, assumptions=defaults)
# Out:
# mod_add_def_spec: {a in Integer, b in Integer} |- (a MOD_ADD b) = ((a + b) mod  2^{t})

# %%
# 3/19/2020: consider adding a deduce_in_number_set method to the Mod class;
# that will allow a simplification of this manual part of the proof process
# although it won't shorten the eventual proof.

# %%
mod_int_closure
# Out:
# |- forall_{a, b in Integer | b != 0} ((a mod  b) in Integer)

# %%
two_pow_t_not_zero
# Out:
# |- 2^{t} != 0

# %%
two_pow_t_is_nat_pos
# Out:
# |- 2^{t} in NaturalPos

# %%
mod_int_closure_spec = mod_int_closure.instantiate({a:Add(a, b), b:two_pow_t}, assumptions=[InSet(a, Integer), InSet(b, Integer)])
# Out:
# mod_int_closure_spec: {a in Integer, b in Integer} |- ((a + b) mod  2^{t}) in Integer

# %%
mod_add_def_spec.sub_left_side_into(mod_int_closure_spec)
# Out:
# {a in Integer, b in Integer} |- (a MOD_ADD b) in Integer

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{a, b in Integer} ((a MOD_ADD b) in Integer)
# 1	instantiation	2, 3, 4	{a in Integer, b in Integer} |- (a MOD_ADD b) in Integer
# 	P(_a) : _a in Integer, x : a MOD_ADD b, y : (a + b) mod  2^{t}
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	instantiation	5, 6, 7, 8	{a in Integer, b in Integer} |- ((a + b) mod  2^{t}) in Integer
# 	a : a + b, b : 2^{t}
# 4	instantiation	9, 11, 12	{a in Integer, b in Integer} |- (a MOD_ADD b) = ((a + b) mod  2^{t})
# 	a : a, b : b
# 5	conjecture		|- forall_{a, b in Integer | b != 0} ((a mod  b) in Integer)
# 6	instantiation	10, 11, 12	{a in Integer, b in Integer} |- (a + b) in Integer
# 	a : a, b : b
# 7	instantiation	15, 13, 14	|- 2^{t} in Integer
# 	A : Natural, B : Integer, x : 2^{t}
# 8	conjecture		|- 2^{t} != 0
# 9	axiom		|- forall_{a, b in Integer} ((a MOD_ADD b) = ((a + b) mod  2^{t}))
# 	proveit.physics.quantum.QPE.mod_add_def
# 10	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 11	assumption		{a in Integer} |- a in Integer
# 12	assumption		{b in Integer} |- b in Integer
# 13	conjecture		|- Natural proper_subset Integer
# 14	instantiation	15, 16, 17	|- 2^{t} in Natural
# 	A : NaturalPos, B : Natural, x : 2^{t}
# 15	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 16	conjecture		|- NaturalPos proper_subset Natural
# 17	conjecture		|- 2^{t} in NaturalPos
