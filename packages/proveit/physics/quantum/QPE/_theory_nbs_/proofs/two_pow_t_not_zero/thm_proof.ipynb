# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#two_pow_t_not_zero">two_pow_t_not_zero</a> theorem
# ========

# %%
import proveit
from proveit import a, b
from proveit.numbers import two
from proveit.numbers.exponentiation import exp_not_eq_zero
from proveit.physics.quantum.QPE  import t_in_natural_pos
from proveit.physics.quantum.QPE import t_
theory = proveit.Theory() # the theorem's theory

# %%
# %proving two_pow_t_not_zero
# Out:
# two_pow_t_not_zero: 2^{t} != 0

# %%
t_in_natural_pos
# Out:
# |- t in NaturalPos

# %%
exp_not_eq_zero
# Out:
# |- forall_{a, b in Complex | a != 0} (a^{b} != 0)

# %%
exp_not_eq_zero_spec = exp_not_eq_zero.instantiate({a:two, b:t_})
# Out:
# two_pow_t_not_zero has been proven.  Now simply execute "%qed".
# exp_not_eq_zero_spec: |- 2^{t} != 0

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3, 4	|- 2^{t} != 0
# 	a : 2, b : t
# 1	conjecture		|- forall_{a, b in Complex | a != 0} (a^{b} != 0)
# 2	instantiation	19, 6, 5	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 3	instantiation	19, 6, 7	|- t in Complex
# 	A : Real, B : Complex, x : t
# 4	instantiation	8, 9	|- 2 != 0
# 	n : 2
# 5	instantiation	19, 11, 10	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 6	conjecture		|- Real proper_subset Complex
# 7	instantiation	19, 11, 12	|- t in Real
# 	A : Rational, B : Real, x : t
# 8	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 9	conjecture		|- 2 in NaturalPos
# 10	instantiation	19, 14, 13	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 11	conjecture		|- Rational proper_subset Real
# 12	instantiation	19, 14, 15	|- t in Rational
# 	A : Integer, B : Rational, x : t
# 13	instantiation	19, 17, 16	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 14	conjecture		|- Integer proper_subset Rational
# 15	instantiation	19, 17, 18	|- t in Integer
# 	A : Natural, B : Integer, x : t
# 16	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 17	conjecture		|- Natural proper_subset Integer
# 18	instantiation	19, 20, 21	|- t in Natural
# 	A : NaturalPos, B : Natural, x : t
# 19	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 20	conjecture		|- NaturalPos proper_subset Natural
# 21	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE.t_in_natural_pos
