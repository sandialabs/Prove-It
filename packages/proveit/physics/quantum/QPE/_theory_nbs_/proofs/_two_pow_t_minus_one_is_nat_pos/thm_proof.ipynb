# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_two_pow_t_minus_one_is_nat_pos">_two_pow_t_minus_one_is_nat_pos</a> theorem
# ========

# %%
import proveit
from proveit.numbers import one, subtract
from proveit.physics.quantum.QPE import _t
from proveit.physics.quantum.QPE import _t_in_natural_pos
theory = proveit.Theory() # the theorem's theory

# %%
# %proving _two_pow_t_minus_one_is_nat_pos
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="_two_pow_t_minus_one_is_nat_pos">_two_pow_t_minus_one_is_nat_pos:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/fdc5aaccce23f853b415834a94fd23eb3d98ce2b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/2ce5873ca249ee269a4dc170b72835640434f1e50/dependencies.ipynb">dependencies</a>)<br>
# _two_pow_t_minus_one_is_nat_pos may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos has been proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3	|- 2^{t - 1} in NaturalPos
# 	a : 2, b : t - 1
# 1	conjecture		|- forall_{a, b in Natural} (a^{b} in NaturalPos)
# 	proveit.numbers.exponentiation.exp_natpos_closure
# 2	conjecture		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 3	instantiation	4, 5, 6	|- (t - 1) in Natural
# 	a : t - 1
# 4	conjecture		|- forall_{a in Integer | a >= 0} (a in Natural)
# 	proveit.numbers.number_sets.integers.nonneg_int_is_natural
# 5	instantiation	7, 8, 9	|- (t - 1) in Integer
# 	a : t, b : -1
# 6	instantiation	10, 11	|- (t - 1) >= 0
# 	a : t, b : 1
# 7	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 8	instantiation	13, 12, 17	|- t in Integer
# 	A : NaturalPos, B : Integer, x : t
# 9	instantiation	13, 14, 15	|- (-1) in Integer
# 	A : IntegerNeg, B : Integer, x : -1
# 10	conjecture		|- forall_{a, b | a >= b} ((a - b) >= 0)
# 	proveit.numbers.addition.subtraction.nonneg_difference
# 11	instantiation	16, 17	|- t >= 1
# 	n : t
# 12	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 13	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 14	conjecture		|- IntegerNeg proper_subset Integer
# 	proveit.numbers.number_sets.integers.neg_int_within_int
# 15	instantiation	18, 19	|- (-1) in IntegerNeg
# 	a : 1
# 16	conjecture		|- forall_{n in NaturalPos} (n >= 1)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_lower_bound
# 17	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 18	conjecture		|- forall_{a in NaturalPos} ((-a) in IntegerNeg)
# 	proveit.numbers.negation.int_neg_closure
# 19	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
