# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_alpha_are_complex">_alpha_are_complex</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

from proveit import defaults
from proveit.logic import InSet
from proveit.numbers import Complex
from proveit.physics.quantum.QPE import (_alpha_m_def, _Psi_ket_is_normalized_vec, 
                                         _t_in_natural_pos, _two_pow_t_is_nat_pos)

# %%
# %proving _alpha_are_complex
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="_alpha_are_complex">_alpha_are_complex:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/eb5178402837bb8ca3c45bff2742a7517b41d5d90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/36527a47e8fcbdc1bc4babe0104999d7b4a385620/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _alpha_are_complex.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_are_complex/553d5598dac26513c310f953cbd1ba9111fc3e510/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_alpha_m_def
# Out:
# |- forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} = ({t}_〈m| . |Psi>))

# %%
alpha_m_defined = _alpha_m_def.instantiate()
# Out:
# <strong id="alpha_m_defined">alpha_m_defined:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_are_complex/9adccdb9d9131ba21104ad193c835362a79e02460/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/7ef73f638b7eceb945bc406413dceae5b95f80cf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_Psi_ket_is_normalized_vec
# Out:
# |- (|Psi> in Complex^{2^{t}}) and (|||Psi>|| = 1)

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._alpha_are_complex has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} in Complex)
# 1	instantiation	2, 3, 4	{m in {0 .. 2^{t} - 1}} |- alpha_{m} in Complex
# 	P(_a) : _a in Complex, x : alpha_{m}, y : {t}_〈m| . |Psi>
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	instantiation	5, 10, 11, 6, 7	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . |Psi>) in Complex
# 	H : Complex^{2^{t}}, X : Complex, A : {t}_〈m|, |psi> : |Psi>
# 4	instantiation	8, 19	{m in {0 .. 2^{t} - 1}} |- alpha_{m} = ({t}_〈m| . |Psi>)
# 	m : m
# 5	conjecture		|- forall_{H, X in_c HilbertSpaces} [forall_{A | [A] in LINMAP(H, X)} [forall_{|psi> in H} ((A . |psi>) in X)]]
# 	proveit.physics.quantum.algebra.qmult_op_ket_is_ket
# 6	instantiation	9, 10, 11, 12	{m in {0 .. 2^{t} - 1}} |- [{t}_〈m|] in LINMAP(Complex^{2^{t}}, Complex)
# 	H : Complex^{2^{t}}, X : Complex, A : {t}_〈m|
# 7	instantiation	13, 14	|- |Psi> in Complex^{2^{t}}
# 	A : |Psi> in Complex^{2^{t}}, B : |||Psi>|| = 1
# 8	axiom		|- forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} = ({t}_〈m| . |Psi>))
# 	proveit.physics.quantum.QPE._alpha_m_def
# 9	conjecture		|- forall_{H, X in_c HilbertSpaces} [forall_{A in LINMAP(H, X)} ([A] in LINMAP(H, X))]
# 	proveit.physics.quantum.algebra.qmult_op_is_linmap
# 10	instantiation	15, 16	|- Complex^{2^{t}} in_c HilbertSpaces
# 	n : 2^{t}
# 11	conjecture		|- Complex in_c HilbertSpaces
# 	proveit.linear_algebra.inner_products.complex_set_is_hilbert_space
# 12	instantiation	17, 18, 19	{m in {0 .. 2^{t} - 1}} |- {t}_〈m| in LINMAP(Complex^{2^{t}}, Complex)
# 	n : t, k : m
# 13	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 14	conjecture		|- (|Psi> in Complex^{2^{t}}) and (|||Psi>|| = 1)
# 	proveit.physics.quantum.QPE._Psi_ket_is_normalized_vec
# 15	conjecture		|- forall_{n in NaturalPos} (Complex^{n} in_c HilbertSpaces)
# 	proveit.linear_algebra.inner_products.complex_vec_set_is_hilbert_space
# 16	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
# 17	conjecture		|- forall_{n in NaturalPos} [forall_{k in {0 .. 2^{n} - 1}} ({n}_〈k| in LINMAP(Complex^{2^{n}}, Complex))]
# 	proveit.physics.quantum.algebra.num_bra_is_lin_map
# 18	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 19	assumption		{m in {0 .. 2^{t} - 1}} |- m in {0 .. 2^{t} - 1}
