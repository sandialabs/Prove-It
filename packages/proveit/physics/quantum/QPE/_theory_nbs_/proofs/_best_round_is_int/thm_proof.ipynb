# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_best_round_is_int">_best_round_is_int</a> theorem
# ========

# %%
import proveit
from proveit.logic import InSet
from proveit.numbers import Integer
from proveit.physics.quantum.QPE import _best_round_def
from proveit.physics.quantum.QPE import _phase_is_real, _two_pow_t_is_nat_pos
theory = proveit.Theory() # the theorem's theory

# %%
# %proving _best_round_is_int
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="_best_round_is_int">_best_round_is_int:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/c12acbee0bd507d9af1816764a5c0d2ddf91c1e60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/da6d29f420c18f1153bb6e0cdf0b1ce4715a17960/dependencies.ipynb">dependencies</a>)<br>

# %%
_best_round_def
# Out:
# |- b_{r} = round(2^{t} * phase)

# %%
_phase_is_real
# Out:
# |- phase in Real

# %%
_two_pow_t_is_nat_pos
# Out:
# |- 2^{t} in NaturalPos

# %%
InSet(_best_round_def.rhs, Integer).prove()
# Out:
# |- round(2^{t} * phase) in Integer

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._best_round_is_int has been proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3	|- b_{r} in Integer
# 	P(_a) : _a in Integer, x : b_{r}, y : round(2^{t} * phase)
# 1	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 2	instantiation	4, 5	|- round(2^{t} * phase) in Integer
# 	x : 2^{t} * phase
# 3	axiom		|- b_{r} = round(2^{t} * phase)
# 	proveit.physics.quantum.QPE._best_round_def
# 4	axiom		|- forall_{x in Real} (round(x) in Integer)
# 	proveit.numbers.rounding.round_is_an_int
# 5	instantiation	6, 7, 8	|- (2^{t} * phase) in Real
# 	a : 2^{t}, b : phase
# 6	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 7	instantiation	13, 9, 10	|- 2^{t} in Real
# 	A : Rational, B : Real, x : 2^{t}
# 8	conjecture		|- phase in Real
# 	proveit.physics.quantum.QPE._phase_is_real
# 9	conjecture		|- Rational proper_subset Real
# ...
