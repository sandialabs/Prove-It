# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_Psi_ket_is_normalized_vec">_Psi_ket_is_normalized_vec</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

from proveit import n, t
from proveit.physics.quantum.QFT import invFT_is_unitary
from proveit.physics.quantum.QPE import (
    _t, _t_in_natural_pos, _psi_t_ket_is_normalized_vec, _Psi_def)

# %%
# %proving _Psi_ket_is_normalized_vec
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="_Psi_ket_is_normalized_vec">_Psi_ket_is_normalized_vec:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/6f9b3505d2aeb564a9c904a3a8182d14c406ae7b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/45589a12a203a1c1fc25338e69651f49399dc8240/dependencies.ipynb">dependencies</a>)<br>

# %%
_psi_t_ket_is_normalized_vec.instantiate({t:_t})
# Out:
# |- (|psi_{t}> in Complex^{2^{t}}) and (|||psi_{t}>|| = 1)

# %%
_Psi_def
# Out:
# |- |Psi> = (FT^{dag}_{t} . |psi_{t}>)

# %%
invFT_is_unitary
# Out:
# |- forall_{n in NaturalPos} (FT^{dag}_{n} in U(2^{n}))

# %%
invFT_is_unitary.instantiate({n:_t})
# Out:
# |- FT^{dag}_{t} in U(2^{t})

# %%
_Psi_def.rhs.compute_norm(replacements=[_Psi_def.derive_reversed()])
# Out:
# |- |||Psi>|| = 1
# _Psi_ket_is_normalized_vec may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._Psi_ket_is_normalized_vec has been proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3	|- (|Psi> in Complex^{2^{t}}) and (|||Psi>|| = 1)
# 	A : |Psi> in Complex^{2^{t}}, B : |||Psi>|| = 1
# 1	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 2	instantiation	4, 7, 8, 5, 10*	|- |Psi> in Complex^{2^{t}}
# 	n : 2^{t}, U : FT^{dag}_{t}, |psi> : |psi_{t}>
# 3	instantiation	6, 7, 8, 9, 12, 10*	|- |||Psi>|| = 1
# 	n : 2^{t}, U : FT^{dag}_{t}, alpha : 1, |psi> : |psi_{t}>
# 4	conjecture		|- forall_{n in NaturalPos} [forall_{U in U(n)} [forall_{|psi> in Complex^{n}} ((U . |psi>) in Complex^{n})]]
# 	proveit.physics.quantum.algebra.state_space_preservation
# 5	instantiation	11, 12	|- |psi_{t}> in Complex^{2^{t}}
# 	A : |psi_{t}> in Complex^{2^{t}}, B : |||psi_{t}>|| = 1
# 6	conjecture		|- forall_{n in NaturalPos} [forall_{U in U(n)} [forall_{alpha in RealNonNeg} [forall_{|psi> in Complex^{n} | |||psi>|| = alpha} (||U . |psi>|| = alpha)]]]
# 	proveit.physics.quantum.algebra.normalization_preservation
# 7	instantiation	13, 14, 15	|- 2^{t} in NaturalPos
# 	a : 2, b : t
# 8	instantiation	16, 23	|- FT^{dag}_{t} in U(2^{t})
# 	n : t
# 9	instantiation	24, 17, 18	|- 1 in RealNonNeg
# 	A : RationalNonNeg, B : RealNonNeg, x : 1
# 10	instantiation	19, 20	|- (FT^{dag}_{t} . |psi_{t}>) = |Psi>
# 	x : |Psi>, y : FT^{dag}_{t} . |psi_{t}>
# 11	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 12	instantiation	21, 23	|- (|psi_{t}> in Complex^{2^{t}}) and (|||psi_{t}>|| = 1)
# 	t : t
# 13	conjecture		|- forall_{a, b in Natural} (a^{b} in NaturalPos)
# 	proveit.numbers.exponentiation.exp_natpos_closure
# 14	conjecture		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 15	instantiation	24, 22, 23	|- t in Natural
# 	A : NaturalPos, B : Natural, x : t
# 16	conjecture		|- forall_{n in NaturalPos} (FT^{dag}_{n} in U(2^{n}))
# 	proveit.physics.quantum.QFT.invFT_is_unitary
# 17	conjecture		|- RationalNonNeg proper_subset RealNonNeg
# 	proveit.numbers.number_sets.real_numbers.rational_nonneg_within_real_nonneg
# 18	instantiation	24, 25, 26	|- 1 in RationalNonNeg
# 	A : Natural, B : RationalNonNeg, x : 1
# 19	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 20	axiom		|- |Psi> = (FT^{dag}_{t} . |psi_{t}>)
# 	proveit.physics.quantum.QPE._Psi_def
# 21	conjecture		|- forall_{t in NaturalPos} ((|psi_{t}> in Complex^{2^{t}}) and (|||psi_{t}>|| = 1))
# 	proveit.physics.quantum.QPE._psi_t_ket_is_normalized_vec
# 22	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 23	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 24	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 25	conjecture		|- Natural proper_subset RationalNonNeg
# 	proveit.numbers.number_sets.rational_numbers.nat_within_rational_nonneg
# 26	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
