# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_delta_b_not_eq_scaledNonzeroInt">_delta_b_not_eq_scaledNonzeroInt</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import b, l, defaults
from proveit.logic import Forall, InSet, NotEquals, Set
from proveit.numbers import Integer, Mult
from proveit.physics.quantum.QPE import (
        _b_floor, _best_floor_is_int, _b_round,
        _best_round_def, _best_round_is_int, _delta_b,
        _delta_b_is_real, _scaled_delta_b_not_eq_nonzeroInt,
        _two_pow_t, _two_pow_t_is_nat_pos)

# %%
# %proving _delta_b_not_eq_scaledNonzeroInt
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="_delta_b_not_eq_scaledNonzeroInt">_delta_b_not_eq_scaledNonzeroInt:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/58814a4ea9e96d9eecce36756844dedba5878da40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/79da62ee40fb435190bdf7f6258f0c73120966d10/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _delta_b_not_eq_scaledNonzeroInt.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/86269d40e585e2eb6333037b5a3024092ebe10140/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_scaled_delta_b_not_eq_nonzeroInt
# Out:
# |- forall_{b in {b_{f}, b_{r}}, l in Integer | l != 0} ((2^{t} * delta_{b}) != l)

# %%
all_scaled_deltas_ne_ell_inst = (
        _scaled_delta_b_not_eq_nonzeroInt.instantiate())
# Out:
# <strong id="all_scaled_deltas_ne_ell_inst">all_scaled_deltas_ne_ell_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/7b8e14bfeec30fa2c83deb2740813fd8ea169a4c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/b38b045a9246dd5ac239f68f921874310f53aad00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_not_eq_scaledNonzeroInt/97a3bf9cce762ebe4e078dba2bf9a74e8df93fcd0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/a6859b38ede3e9f618b0086c26c104308d7bed700/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_two_pow_t_is_nat_pos
# Out:
# |- 2^{t} in NaturalPos

# %%
_delta_b_is_real
# Out:
# |- forall_{b in Integer} (delta_{b} in Real)

# %%
_best_round_is_int
# Out:
# |- b_{r} in Integer

# %%
_best_floor_is_int
# Out:
# |- b_{f} in Integer

# %%
all_b_in_best_set_are_int = (
        Forall(b, InSet(b, Integer),
               domain=Set(_b_floor, _b_round)).prove())
# Out:
# <strong id="all_b_in_best_set_are_int">all_b_in_best_set_are_int:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_not_eq_scaledNonzeroInt/4f3aefa235945d8d9581d53b3aea16c23e2976600/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_not_eq_scaledNonzeroInt/6b2d7875162d7ec534a9e0c577c028d646610f540/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
all_b_in_best_set_are_int.instantiate()
# Out:
# {b in {b_{f}, b_{r}}} |- b in Integer

# %%
_delta_b_is_real.instantiate()
# Out:
# {b in {b_{f}, b_{r}}} |- delta_{b} in Real

# %%
all_scaled_deltas_ne_ell_inst.divide_both_sides(_two_pow_t)
# Out:
# {b in {b_{f}, b_{r}}, l in Integer, l != 0} |- delta_{b} != (l / 2^{t})
# _delta_b_not_eq_scaledNonzeroInt may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._delta_b_not_eq_scaledNonzeroInt has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{b in {b_{f}, b_{r}}, l in Integer | l != 0} (delta_{b} != (l / 2^{t}))
# 1	instantiation	2, 33, 3, 4, 5, 6, 7*	{b in {b_{f}, b_{r}}, l in Integer, l != 0} |- delta_{b} != (l / 2^{t})
# 	a : 2^{t}, x : 2^{t} * delta_{b}, y : l
# 2	conjecture		|- forall_{a, x, y in Real | x != y, a != 0} ((x / a) != (y / a))
# 	proveit.numbers.division.div_neq_real
# 3	instantiation	8, 33, 28	{b in {b_{f}, b_{r}}} |- (2^{t} * delta_{b}) in Real
# 	a : 2^{t}, b : delta_{b}
# 4	instantiation	52, 39, 9	{l in Integer} |- l in Real
# 	A : Rational, B : Real, x : l
# 5	instantiation	10, 42, 16, 11	{b in {b_{f}, b_{r}}, l in Integer, l != 0} |- (2^{t} * delta_{b}) != l
# 	b : b, l : l
# 6	instantiation	12, 54	|- 2^{t} != 0
# 	n : 2^{t}
# 7	instantiation	13, 14, 15	{b in {b_{f}, b_{r}}} |- ((2^{t} * delta_{b}) / 2^{t}) = delta_{b}
# 	x : (2^{t} * delta_{b}) / 2^{t}, y : delta_{b} / 1, z : delta_{b}
# 8	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 9	instantiation	52, 45, 16	{l in Integer} |- l in Rational
# 	A : Integer, B : Rational, x : l
# 10	conjecture		|- forall_{b in {b_{f}, b_{r}}, l in Integer | l != 0} ((2^{t} * delta_{b}) != l)
# 	proveit.physics.quantum.QPE._scaled_delta_b_not_eq_nonzeroInt
# 11	assumption		{l != 0} |- l != 0
# 12	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 13	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 14	instantiation	17, 18, 19, 22, 20*	{b in {b_{f}, b_{r}}} |- ((2^{t} * delta_{b}) / 2^{t}) = (delta_{b} / 1)
# 	x : 2^{t}, z : 1, y : delta_{b}
# 15	instantiation	21, 22	{b in {b_{f}, b_{r}}} |- (delta_{b} / 1) = delta_{b}
# 	x : delta_{b}
# 16	assumption		{l in Integer} |- l in Integer
# 17	conjecture		|- forall_{x, z in ComplexNonZero} [forall_{y in Complex} (((x * y) / (x * z)) = (y / z))]
# 	proveit.numbers.division.frac_cancel_left
# 18	instantiation	52, 24, 23	|- 2^{t} in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t}
# 19	instantiation	52, 24, 25	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 20	instantiation	26, 27	|- (2^{t} * 1) = 2^{t}
# 	x : 2^{t}
# 21	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 22	instantiation	52, 32, 28	{b in {b_{f}, b_{r}}} |- delta_{b} in Complex
# 	A : Real, B : Complex, x : delta_{b}
# 23	instantiation	52, 30, 29	|- 2^{t} in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2^{t}
# 24	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 25	instantiation	52, 30, 31	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 26	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 27	instantiation	52, 32, 33	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 28	instantiation	34, 35	{b in {b_{f}, b_{r}}} |- delta_{b} in Real
# 	b : b
# 29	instantiation	52, 37, 36	|- 2^{t} in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2^{t}
# 30	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 31	instantiation	52, 37, 38	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 32	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 33	instantiation	52, 39, 40	|- 2^{t} in Real
# 	A : Rational, B : Real, x : 2^{t}
# 34	conjecture		|- forall_{b in Integer} (delta_{b} in Real)
# 	proveit.physics.quantum.QPE._delta_b_is_real
# 35	instantiation	41, 42	{b in {b_{f}, b_{r}}} |- b in Integer
# 	b : b
# 36	instantiation	52, 43, 54	|- 2^{t} in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2^{t}
# 37	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 38	instantiation	52, 43, 44	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 39	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 40	instantiation	52, 45, 46	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 41	instantiation	47, 48, 49, 50, 51	|- forall_{b in {b_{f}, b_{r}}} (b in Integer)
# 	n : 2, (a_{1}, ..., a_{2}) : (b_{f}, b_{r}), P(b) : b in Integer, x : b
# 42	assumption		{b in {b_{f}, b_{r}}} |- b in {b_{f}, b_{r}}
# 43	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 44	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 45	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 46	instantiation	52, 53, 54	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 47	conjecture		|- forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n}} [forall_{P | P(a_{1}), P(a_{2}), ..., P(a_{n})} [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)]]]
# 	proveit.logic.sets.enumeration.true_for_each_then_true_for_all
# 48	conjecture		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 49	instantiation	55	|- |(b_{f}, b_{r})| = |(1, ..., 2)|
# 	a : b_{f}, b : b_{r}
# 50	conjecture		|- b_{f} in Integer
# 	proveit.physics.quantum.QPE._best_floor_is_int
# 51	conjecture		|- b_{r} in Integer
# 	proveit.physics.quantum.QPE._best_round_is_int
# 52	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 53	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 54	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
# 55	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
