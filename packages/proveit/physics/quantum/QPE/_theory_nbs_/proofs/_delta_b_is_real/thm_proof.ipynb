# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_delta_b_is_real">_delta_b_is_real</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults
from proveit.logic import InSet
from proveit.numbers import Real
from proveit.physics.quantum.QPE import _phase_is_real, _two_pow_t_is_nat_pos

# %%
# %proving _delta_b_is_real
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="_delta_b_is_real">_delta_b_is_real:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/03b7c5116fb9501347e3e06936a08436606d37360/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/2fca217ab274374863326de79c58ca63972c3c250/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _delta_b_is_real.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_is_real/573f4cd331da201f507b04e9d621277df04961e90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
from proveit.physics.quantum.QPE import _delta_b_def
_delta_b_def
# Out:
# |- forall_{b in Integer} (delta_{b} = (phase - (b / 2^{t})))

# %%
_delta_b_def_inst = _delta_b_def.instantiate()
# Out:
# <strong id="_delta_b_def_inst">_delta_b_def_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/035e0ae7bd8c0fe127ee5d2062443d6c874adcdd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_is_real/e2b26862c448bb8607fa8d2f63ca6991075a4d860/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/f36aeb0fcc4a09d334de072cccaf2d807548c1580/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
InSet(_delta_b_def_inst.rhs, Real).prove()
# Out:
# {b in Integer} |- (phase - (b / 2^{t})) in Real

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._delta_b_is_real has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{b in Integer} (delta_{b} in Real)
# 1	instantiation	2, 3, 4	{b in Integer} |- delta_{b} in Real
# 	P(_a) : _a in Real, x : delta_{b}, y : phase - (b / 2^{t})
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	instantiation	5, 6, 7	{b in Integer} |- (phase - (b / 2^{t})) in Real
# 	a : phase, b : -(b / 2^{t})
# 4	instantiation	8, 19	{b in Integer} |- delta_{b} = (phase - (b / 2^{t}))
# 	b : b
# 5	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 6	conjecture		|- phase in Real
# 	proveit.physics.quantum.QPE._phase_is_real
# 7	instantiation	9, 10	{b in Integer} |- (-(b / 2^{t})) in Real
# 	a : b / 2^{t}
# 8	axiom		|- forall_{b in Integer} (delta_{b} = (phase - (b / 2^{t})))
# 	proveit.physics.quantum.QPE._delta_b_def
# 9	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 10	instantiation	11, 12, 13, 14	{b in Integer} |- (b / 2^{t}) in Real
# 	a : b, b : 2^{t}
# 11	conjecture		|- forall_{a, b in Real | b != 0} ((a / b) in Real)
# 	proveit.numbers.division.div_real_closure
# 12	instantiation	22, 16, 15	{b in Integer} |- b in Real
# 	A : Rational, B : Real, x : b
# 13	instantiation	22, 16, 17	|- 2^{t} in Real
# 	A : Rational, B : Real, x : 2^{t}
# 14	instantiation	18, 24	|- 2^{t} != 0
# 	n : 2^{t}
# 15	instantiation	22, 20, 19	{b in Integer} |- b in Rational
# 	A : Integer, B : Rational, x : b
# 16	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 17	instantiation	22, 20, 21	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 18	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 19	assumption		{b in Integer} |- b in Integer
# 20	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 21	instantiation	22, 23, 24	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 22	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 23	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 24	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
