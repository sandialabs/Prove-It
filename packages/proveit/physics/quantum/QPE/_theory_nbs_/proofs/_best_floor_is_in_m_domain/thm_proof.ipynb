# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_best_floor_is_in_m_domain">_best_floor_is_in_m_domain</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit.physics.quantum.QPE import (
    _b_floor,
    _best_floor_def, _phase_in_interval, _phase_is_real, _two_pow_t_is_nat_pos)

# %%
# %proving _best_floor_is_in_m_domain
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="_best_floor_is_in_m_domain">_best_floor_is_in_m_domain:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/2aecb9b59625fe2c3a892de198feef3214d1f9240/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/2038736f63fcc563688f1a1529f91166cbd483e20/dependencies.ipynb">dependencies</a>)<br>

# %%
_best_floor_def
# Out:
# |- b_{f} = floor(2^{t} * phase)

# %%
scaled_phase_floor = _best_floor_def.rhs
# Out:
# <strong id="scaled_phase_floor">scaled_phase_floor:</strong> <a class="ProveItLink" href="../../../__pv_it/axioms/f9fbe5ddb24723b1298f21be90320b95475d08c80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
scaled_phase = _best_floor_def.rhs.operand
# Out:
# <strong id="scaled_phase">scaled_phase:</strong> <a class="ProveItLink" href="../../../__pv_it/axioms/53fb19711fbef1d96169a35f6e09557e8a08d2160/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
from proveit.logic import InSet
from proveit.numbers import Integer
InSet(scaled_phase_floor, Integer).prove()
# Out:
# |- floor(2^{t} * phase) in Integer

# %%
_phase_in_interval
# Out:
# |- phase in [0,1)

# %%
_two_pow_t_is_nat_pos
# Out:
# |- 2^{t} in NaturalPos

# %%
_phase_upper_bound = _phase_in_interval.derive_element_upper_bound()
# Out:
# <strong id="_phase_upper_bound">_phase_upper_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_floor_is_in_m_domain/4fb3caad640e151d33b04938955c218400f1001f0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_floor_is_in_m_domain/dc9d1f7921c722a2710280fcb79a51993f569bbb0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_phase_lower_bound = _phase_in_interval.derive_element_lower_bound()
# Out:
# <strong id="_phase_lower_bound">_phase_lower_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_floor_is_in_m_domain/0064ba32a8b3370dc6147fa8654807c16d2ce8350/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_floor_is_in_m_domain/ae02d4d05b521fe54b74cf64571b99633b6f52db0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
scaled_phase_upper_bound = scaled_phase.deduce_bound([_phase_upper_bound])
# Out:
# <strong id="scaled_phase_upper_bound">scaled_phase_upper_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_floor_is_in_m_domain/2a6ac41ca07e467ab90ac7620ea94797a61298520/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_floor_is_in_m_domain/f41bcdc23bb3c17c3493341fc53cda67652196690/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
scaled_phase_lower_bound = (
    scaled_phase.deduce_bound(
        [_phase_lower_bound.with_styles(direction='reversed')]))
# Out:
# <strong id="scaled_phase_lower_bound">scaled_phase_lower_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_floor_is_in_m_domain/b908c2feed458e6b9e9f681a0632c81807e19ae90/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_floor_is_in_m_domain/a93f373f8606a751bc61a6548224221f337c76a60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
scaled_phase_floor.deduce_bound([scaled_phase_upper_bound])
# Out:
# |- floor(2^{t} * phase) <= (2^{t} - 1)

# %%
scaled_phase_floor.deduce_bound([scaled_phase_lower_bound])
# Out:
# |- floor(2^{t} * phase) >= 0

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._best_floor_is_in_m_domain has been proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3	|- b_{f} in {0 .. 2^{t} - 1}
# 	P(_a) : _a in {0 .. 2^{t} - 1}, x : b_{f}, y : floor(2^{t} * phase)
# 1	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 2	instantiation	4, 26, 5, 6, 7	|- floor(2^{t} * phase) in {0 .. 2^{t} - 1}
# 	a : 0, b : 2^{t} - 1, n : floor(2^{t} * phase)
# 3	axiom		|- b_{f} = floor(2^{t} * phase)
# 	proveit.physics.quantum.QPE._best_floor_def
# 4	conjecture		|- forall_{a, b, n in Integer | a <= n <= b} (n in {a .. b})
# 	proveit.numbers.number_sets.integers.in_interval
# 5	instantiation	8, 52, 9	|- (2^{t} - 1) in Integer
# 	a : 2^{t}, b : -1
# 6	instantiation	10, 19	|- floor(2^{t} * phase) in Integer
# 	x : 2^{t} * phase
# 7	instantiation	11, 12, 13	|- (0 <= floor(2^{t} * phase)) and (floor(2^{t} * phase) <= (2^{t} - 1))
# 	A : 0 <= floor(2^{t} * phase), B : floor(2^{t} * phase) <= (2^{t} - 1)
# 8	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 9	instantiation	14, 46	|- (-1) in Integer
# 	a : 1
# 10	axiom		|- forall_{x in Real} (floor(x) in Integer)
# 	proveit.numbers.rounding.floor_is_an_int
# 11	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 12	instantiation	15, 37, 19, 16, 17*	|- 0 <= floor(2^{t} * phase)
# 	x : 0, y : 2^{t} * phase
# 13	instantiation	18, 19, 52, 20	|- floor(2^{t} * phase) <= (2^{t} - 1)
# 	x : 2^{t} * phase, y : 2^{t}
# 14	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 15	conjecture		|- forall_{x, y in Real | x <= y} (floor(x) <= floor(y))
# 	proveit.numbers.rounding.floor_increasing_less_eq
# 16	instantiation	21, 45, 37, 29, 22, 23, 24*	|- 0 <= (2^{t} * phase)
# 	a : 2^{t}, x : 0, y : phase
# 17	instantiation	25, 26	|- floor(0) = 0
# 	x : 0
# 18	conjecture		|- forall_{x in Real, y in Integer | x < y} (floor(x) <= (y - 1))
# 	proveit.numbers.rounding.floor_of_real_below_int
# 19	instantiation	27, 45, 29	|- (2^{t} * phase) in Real
# 	a : 2^{t}, b : phase
# 20	instantiation	28, 45, 29, 38, 30, 34, 31*	|- (2^{t} * phase) < 2^{t}
# 	a : 2^{t}, x : phase, y : 1
# 21	conjecture		|- forall_{a, x, y in Real | x <= y, a >= 0} ((a * x) <= (a * y))
# 	proveit.numbers.multiplication.weak_bound_via_right_factor_bound
# 22	instantiation	32, 37, 38, 39	|- 0 <= phase
# 	a : 0, b : 1, x : phase
# 23	instantiation	33, 34	|- 0 <= 2^{t}
# 	x : 0, y : 2^{t}
# 24	instantiation	35, 41	|- (2^{t} * 0) = 0
# 	x : 2^{t}
# 25	conjecture		|- forall_{x in Integer} (floor(x) = x)
# 	proveit.numbers.rounding.floor_of_integer
# 26	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 27	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 28	conjecture		|- forall_{a, x, y in Real | x < y, a > 0} ((a * x) < (a * y))
# 	proveit.numbers.multiplication.strong_bound_via_right_factor_bound
# 29	conjecture		|- phase in Real
# 	proveit.physics.quantum.QPE._phase_is_real
# 30	instantiation	36, 37, 38, 39	|- phase < 1
# 	a : 0, b : 1, x : phase
# 31	instantiation	40, 41	|- (2^{t} * 1) = 2^{t}
# 	x : 2^{t}
# 32	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (a <= x)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_lower_bound
# 33	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 34	instantiation	42, 55	|- 2^{t} > 0
# 	n : 2^{t}
# 35	conjecture		|- forall_{x in Complex} ((x * 0) = 0)
# 	proveit.numbers.multiplication.mult_zero_right
# 36	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x < b)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_upper_bound
# 37	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 38	instantiation	53, 47, 43	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 39	axiom		|- phase in [0,1)
# 	proveit.physics.quantum.QPE._phase_in_interval
# 40	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 41	instantiation	53, 44, 45	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 42	conjecture		|- forall_{n in NaturalPos} (n > 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_is_pos
# 43	instantiation	53, 51, 46	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 44	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 45	instantiation	53, 47, 48	|- 2^{t} in Real
# 	A : Rational, B : Real, x : 2^{t}
# 46	instantiation	53, 49, 50	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 47	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 48	instantiation	53, 51, 52	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 49	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 50	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 51	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 52	instantiation	53, 54, 55	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 53	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 54	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 55	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
