# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_alpha_ideal_case">_alpha_ideal_case</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults
from proveit import k, m
from proveit.numbers import Exp
from proveit.physics.quantum.QPE import (
    _alpha_m_evaluation, _ideal_phase_cond, _t_in_natural_pos, _two_pow_t_is_nat_pos, _phase_is_real)

# %%
# %proving _alpha_ideal_case
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="_alpha_ideal_case">_alpha_ideal_case:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e7a1c3be185f23b3c2a3c390c2cffc8f681322150/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/c9d0edba0e46c2b60cff1bc7234a883ce5d1d01c0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = [_ideal_phase_cond]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_ideal_case/53b8cc723f072f5e4c38b609aa917a4a80fb84d20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_scaled_phase = _ideal_phase_cond.element
# Out:
# <strong id="_scaled_phase">_scaled_phase:</strong> <a class="ProveItLink" href="../../../__pv_it/common/1c68973a596c55e546d23e04abe144dd1f873b790/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# Keep the $2$ in $2 \pi i$ from combining with powers of $2$:

# %%
Exp.change_simplification_directives(factor_numeric_rational=True)

# %%
_alpha_m_evaluation
# Out:
# |- forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))))

# %% [markdown]
# Reduced through auto-simplification:

# %%
_alpha_ideal_01 = _alpha_m_evaluation.instantiate({m: _scaled_phase})
# Out:
# <strong id="_alpha_ideal_01">_alpha_ideal_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/fbdfe876e08a0cba83da0cf438e9fc744a30683c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_ideal_case/899457dbd6593387d05a8f58be6492e35d01d4da0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/0c578b359940001aca5868475b467854cfe2b7920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# _alpha_ideal_case may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._alpha_ideal_case has been proven.
# 	step type	requirements	statement
# 0	deduction	1	|- ((2^{t} * phase) in {0 .. 2^{t} - 1}) => (alpha_{2^{t} * phase} = 1)
# 1	instantiation	2, 3, 4*	{(2^{t} * phase) in {0 .. 2^{t} - 1}} |- alpha_{2^{t} * phase} = 1
# 	m : 2^{t} * phase
# 2	conjecture		|- forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))))
# 	proveit.physics.quantum.QPE._alpha_m_evaluation
# 3	assumption		{(2^{t} * phase) in {0 .. 2^{t} - 1}} |- (2^{t} * phase) in {0 .. 2^{t} - 1}
# 4	instantiation	131, 5, 6	|- ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k}))) = 1
# 	x : (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k})), y : (1 / 2^{t}) * 2^{t}, z : 1
# 5	instantiation	103, 7	|- ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k}))) = ((1 / 2^{t}) * 2^{t})
# 	f(_a) : (1 / 2^{t}) * _a, x : Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k}), y : 2^{t}
# 6	instantiation	140, 8, 9	|- ((1 / 2^{t}) * 2^{t}) = 1
# 	P(_a) : ((1 / 2^{t}) * 2^{t}) = _a, x : (1 / 1) * (1 / 1), y : 1
# 7	instantiation	131, 10, 11	|- (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k})) = 2^{t}
# 	x : Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k}), y : Sum_{k = 0}^{2^{t} - 1} 1, z : 2^{t}
# 8	instantiation	140, 12, 13	|- ((1 / 2^{t}) * 2^{t}) = ((1 / 1) * (1 / 1))
# 	P(_a) : _a = ((1 / 1) * (1 / 1)), x : (1 / (1 * 2^{t})) * ((2^{t} * 1) / 1), y : (1 / 2^{t}) * 2^{t}
# 9	instantiation	42, 14, 15, 16	|- ((1 / 1) * (1 / 1)) = 1
# 	a : (1 / 1) * (1 / 1), b : 1 * (1 / 1), c : 1 * 1, d : 1
# 10	instantiation	103, 17	|- (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k})) = (Sum_{k = 0}^{2^{t} - 1} 1)
# 	f(_a) : Sum_{k} _a(k), x(k) : {e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}., y(k) : {1 if k in {0 .. 2^{t} - 1}.
# 11	instantiation	18, 183, 184, 55, 19*	|- (Sum_{i = 0}^{2^{t} - 1} 1) = 2^{t}
# 	a : 0, b : 2^{t} - 1, x : 1
# 12	instantiation	20, 55, 107, 106	|- ((1 / (1 * 2^{t})) * ((2^{t} * 1) / 1)) = ((1 / 1) * (1 / 1))
# 	a : 1, d : 1, b : 1, c : 2^{t}, e : 1
# 13	instantiation	131, 21, 22	|- ((1 / (1 * 2^{t})) * ((2^{t} * 1) / 1)) = ((1 / 2^{t}) * 2^{t})
# 	x : (1 / (1 * 2^{t})) * ((2^{t} * 1) / 1), y : (1 / 2^{t}) * ((2^{t} * 1) / 1), z : (1 / 2^{t}) * 2^{t}
# 14	instantiation	103, 23	|- ((1 / 1) * (1 / 1)) = (1 * (1 / 1))
# 	f(_a) : _a * (1 / 1), x : 1 / 1, y : 1
# 15	instantiation	103, 23	|- (1 * (1 / 1)) = (1 * 1)
# 	f(_a) : 1 * _a, x : 1 / 1, y : 1
# 16	instantiation	119, 55	|- (1 * 1) = 1
# 	x : 1
# 17	modus ponens	24, 25	|- [k -> {e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {1 if k in {0 .. 2^{t} - 1}.]
# 18	conjecture		|- forall_{a, b in Integer} [forall_{x in Complex} ((Sum_{i = a}^{b} x) = ((b - a + 1) * x))]
# 	proveit.numbers.summation.trivial_sum
# 19	instantiation	131, 26, 109	|- (((2^{t} - 1) - 0 + 1) * 1) = 2^{t}
# 	x : ((2^{t} - 1) - 0 + 1) * 1, y : 2^{t} * 1, z : 2^{t}
# 20	conjecture		|- forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} (((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)))]
# 	proveit.numbers.division.mult_frac_cancel_denom_left
# 21	instantiation	103, 27	|- ((1 / (1 * 2^{t})) * ((2^{t} * 1) / 1)) = ((1 / 2^{t}) * ((2^{t} * 1) / 1))
# 	f(_a) : _a * ((2^{t} * 1) / 1), x : 1 / (1 * 2^{t}), y : 1 / 2^{t}
# 22	instantiation	103, 28	|- ((1 / 2^{t}) * ((2^{t} * 1) / 1)) = ((1 / 2^{t}) * 2^{t})
# 	f(_a) : (1 / 2^{t}) * _a, x : (2^{t} * 1) / 1, y : 2^{t}
# 23	instantiation	99, 55	|- (1 / 1) = 1
# 	x : 1
# 24	instantiation	29, 150	|- [forall_{k} ({e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}. = {1 if k in {0 .. 2^{t} - 1}.)] =>  \\ ([k -> {e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {1 if k in {0 .. 2^{t} - 1}.])
# 	i : 1, f(k) : {e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}., g(k) : {1 if k in {0 .. 2^{t} - 1}., a : (k), b : (k), c : (k)
# 25	generalization	30	|- forall_{k} ({e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}. = {1 if k in {0 .. 2^{t} - 1}.)
# 26	instantiation	103, 31	|- (((2^{t} - 1) - 0 + 1) * 1) = (2^{t} * 1)
# 	f(_a) : _a * 1, x : (2^{t} - 1) - 0 + 1, y : 2^{t}
# 27	instantiation	103, 32	|- (1 / (1 * 2^{t})) = (1 / 2^{t})
# 	f(_a) : 1 / _a, x : 1 * 2^{t}, y : 2^{t}
# 28	instantiation	131, 33, 34	|- ((2^{t} * 1) / 1) = 2^{t}
# 	x : (2^{t} * 1) / 1, y : 2^{t} / 1, z : 2^{t}
# 29	axiom		|- forall_{i in NaturalPos} [forall_{f, g} ([forall_{a_{1}, a_{2}, ..., a_{i}} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> f(b_{1}, b_{2}, ..., b_{i})] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> g(c_{1}, c_{2}, ..., c_{i})]))]
# 	proveit.core_expr_types.lambda_maps.lambda_substitution
# 30	instantiation	35, 36	|- {e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}. \\  = {1 if k in {0 .. 2^{t} - 1}.
# 	a : e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k}, b : 1, Q : k in {0 .. 2^{t} - 1}
# 31	instantiation	131, 37, 38	|- ((2^{t} - 1) - 0 + 1) = 2^{t}
# 	x : (2^{t} - 1) - 0 + 1, y : (2^{t} - 1) + 0 + 1, z : 2^{t}
# 32	instantiation	39, 126	|- (1 * 2^{t}) = 2^{t}
# 	x : 2^{t}
# 33	instantiation	103, 109	|- ((2^{t} * 1) / 1) = (2^{t} / 1)
# 	f(_a) : _a / 1, x : 2^{t} * 1, y : 2^{t}
# 34	instantiation	99, 126	|- (2^{t} / 1) = 2^{t}
# 	x : 2^{t}
# 35	axiom		|- forall_{a, b, Q | Q => (a = b)} ({a if Q. \\  = {b if Q.)
# 	proveit.core_expr_types.conditionals.conditional_substitution
# 36	deduction	40	|- (k in {0 .. 2^{t} - 1}) => ((e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k}) = 1)
# 37	instantiation	103, 41	|- ((2^{t} - 1) - 0 + 1) = ((2^{t} - 1) + 0 + 1)
# 	f(_a) : (2^{t} - 1) + _a + 1, x : -0, y : 0
# 38	instantiation	42, 43, 44, 45	|- ((2^{t} - 1) + 0 + 1) = 2^{t}
# 	a : (2^{t} - 1) + 0 + 1, b : 2^{t} - 1 + 0 + 1, c : 2^{t} - 1 + 1, d : 2^{t}
# 39	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 40	instantiation	131, 46, 47	{k in {0 .. 2^{t} - 1}} |- (e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k}) = 1
# 	x : e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k}, y : e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k}, z : 1
# 41	conjecture		|- (-0) = 0
# 	proveit.numbers.negation.negated_zero
# 42	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 43	instantiation	48, 153, 179, 154, 52, 49, 126, 53, 50, 55	|- ((2^{t} - 1) + 0 + 1) =  \\ (2^{t} - 1 + 0 + 1)
# 	i : 0, j : 2, k : 2, a : (), b : (2^{t}, -1), c : (0, 1)
# 44	instantiation	51, 179, 194, 52, 126, 53, 55	|- (2^{t} - 1 + 0 + 1) = (2^{t} - 1 + 1)
# 	i : 2, j : 1, a : (2^{t}, -1), b : (1)
# 45	instantiation	54, 55, 126, 56	|- (2^{t} - 1 + 1) = 2^{t}
# 	a : 1, b : 1, c : 2^{t}
# 46	instantiation	103, 57	{k in {0 .. 2^{t} - 1}} |- (e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k})
# 	f(_a) : [*]_a, x : (e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})}, e^{2 * pi * i * phase * k}), y : (e^{-(2 * pi * i * k * phase)}, e^{2 * pi * i * phase * k})
# 47	instantiation	58, 89, 59, 81, 60*	{k in {0 .. 2^{t} - 1}} |- (e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k}) = 1
# 	a : e, b : -(2 * pi * i * k * phase), c : 2 * pi * i * phase * k
# 48	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 49	instantiation	165	|- |(0, 1)| = |(1, ..., 2)|
# 	a : 0, b : 1
# 50	conjecture		|- 0 in Complex
# 	proveit.numbers.number_sets.complex_numbers.zero_is_complex
# 51	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}) = (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}))]
# 	proveit.numbers.addition.elim_zero_any
# 52	instantiation	165	|- |(2^{t}, -1)| = |(1, ..., 2)|
# 	a : 2^{t}, b : -1
# 53	instantiation	192, 169, 61	|- (-1) in Complex
# 	A : Real, B : Complex, x : -1
# 54	conjecture		|- forall_{a, b, c in Complex | a = b} ((c - a + b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_32
# 55	instantiation	192, 169, 62	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 56	instantiation	75	|- 1 = 1
# 	x : 1
# 57	instantiation	63, 64, 65, 66, 67, 68	{k in {0 .. 2^{t} - 1}} |- (e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})}, e^{2 * pi * i * phase * k}) = (e^{-(2 * pi * i * k * phase)}, e^{2 * pi * i * phase * k})
# 	i : 2, a : (e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})}, e^{2 * pi * i * phase * k}), b : (e^{-(2 * pi * i * k * phase)}, e^{2 * pi * i * phase * k})
# 58	conjecture		|- forall_{a in RealPos, b in Complex, c in Complex} ((a^{b} * a^{c}) = a^{b + c})
# 	proveit.numbers.exponentiation.product_of_complex_powers
# 59	instantiation	69, 108	{k in {0 .. 2^{t} - 1}} |- (-(2 * pi * i * k * phase)) in Complex
# 	a : 2 * pi * i * k * phase
# 60	instantiation	131, 70, 71	{k in {0 .. 2^{t} - 1}} |- e^{-(2 * pi * i * k * phase) + (2 * pi * i * phase * k)} = 1
# 	x : e^{-(2 * pi * i * k * phase) + (2 * pi * i * phase * k)}, y : e^{0}, z : 1
# 61	instantiation	192, 174, 72	|- (-1) in Real
# 	A : Rational, B : Real, x : -1
# 62	instantiation	192, 174, 73	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 63	conjecture		|- forall_{i in NaturalPos} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{i} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{i} = b_{i})} ((a_{1}, a_{2}, ..., a_{i}) = (b_{1}, b_{2}, ..., b_{i}))]
# 	proveit.core_expr_types.tuples.tuple_eq_via_elem_eq
# 64	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 65	instantiation	165	|- |(e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})}, e^{2 * pi * i * phase * k})| = |(1, ..., 2)|
# 	a : e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})}, b : e^{2 * pi * i * phase * k}
# 66	instantiation	165	|- |(e^{-(2 * pi * i * k * phase)}, e^{2 * pi * i * phase * k})| = |(1, ..., 2)|
# 	a : e^{-(2 * pi * i * k * phase)}, b : e^{2 * pi * i * phase * k}
# 67	instantiation	103, 74	{k in {0 .. 2^{t} - 1}} |- e^{-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})} = e^{-(2 * pi * i * k * phase)}
# 	f(_a) : e^{_a}, x : -((2 * pi * i * k * (2^{t} * phase)) / 2^{t}), y : -(2 * pi * i * k * phase)
# 68	instantiation	75	|- e^{2 * pi * i * phase * k} = e^{2 * pi * i * phase * k}
# 	x : e^{2 * pi * i * phase * k}
# 69	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 70	instantiation	103, 76	{k in {0 .. 2^{t} - 1}} |- e^{-(2 * pi * i * k * phase) + (2 * pi * i * phase * k)} = e^{0}
# 	f(_a) : e^{_a}, x : -(2 * pi * i * k * phase) + (2 * pi * i * phase * k), y : 0
# 71	instantiation	77, 78	|- e^{0} = 1
# 	a : e
# 72	instantiation	192, 177, 187	|- (-1) in Rational
# 	A : Integer, B : Rational, x : -1
# 73	instantiation	192, 177, 191	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 74	instantiation	103, 79	{k in {0 .. 2^{t} - 1}} |- (-((2 * pi * i * k * (2^{t} * phase)) / 2^{t})) = (-(2 * pi * i * k * phase))
# 	f(_a) : -_a, x : (2 * pi * i * k * (2^{t} * phase)) / 2^{t}, y : 2 * pi * i * k * phase
# 75	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 76	instantiation	80, 108, 81, 82	{k in {0 .. 2^{t} - 1}} |- (-(2 * pi * i * k * phase) + (2 * pi * i * phase * k)) = 0
# 	a : 2 * pi * i * k * phase, b : 2 * pi * i * phase * k
# 77	conjecture		|- forall_{a in Complex} (a^{0} = 1)
# 	proveit.numbers.exponentiation.exp_zero_eq_one
# 78	instantiation	192, 169, 83	|- e in Complex
# 	A : Real, B : Complex, x : e
# 79	instantiation	131, 84, 85	{k in {0 .. 2^{t} - 1}} |- ((2 * pi * i * k * (2^{t} * phase)) / 2^{t}) = (2 * pi * i * k * phase)
# 	x : (2 * pi * i * k * (2^{t} * phase)) / 2^{t}, y : (2 * pi * i * k * 2^{t} * phase) / 2^{t}, z : 2 * pi * i * k * phase
# 80	conjecture		|- forall_{a, b in Complex | a = b} ((-a + b) = 0)
# 	proveit.numbers.addition.subtraction.add_cancel_reverse
# 81	instantiation	140, 86, 87	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * phase * k) in Complex
# 	P(_a) : _a in Complex, x : (2 * pi) * (i * phase * k), y : 2 * pi * i * phase * k
# 82	instantiation	120, 144, 194, 153, 88, 154, 157, 158, 163, 164, 156	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * k * phase) =  \\ (2 * pi * i * phase * k)
# 	i : 3, j : 1, k : 0, a : (2, pi, i), b : (k), c : phase, d : ()
# 83	instantiation	192, 172, 89	|- e in Real
# 	A : RealPos, B : Real, x : e
# 84	instantiation	103, 90	{k in {0 .. 2^{t} - 1}} |- ((2 * pi * i * k * (2^{t} * phase)) / 2^{t}) = ((2 * pi * i * k * 2^{t} * phase) / 2^{t})
# 	f(_a) : _a / 2^{t}, x : 2 * pi * i * k * (2^{t} * phase), y : 2 * pi * i * k * 2^{t} * phase
# 85	instantiation	131, 91, 92	{k in {0 .. 2^{t} - 1}} |- ((2 * pi * i * k * 2^{t} * phase) / 2^{t}) = (2 * pi * i * k * phase)
# 	x : (2 * pi * i * k * 2^{t} * phase) / 2^{t}, y : (2 * pi * i * k * phase) / 1, z : 2 * pi * i * k * phase
# 86	instantiation	162, 143, 93	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * (i * phase * k)) in Complex
# 	a : 2 * pi, b : i * phase * k
# 87	instantiation	131, 94, 95	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * (i * phase * k)) = (2 * pi * i * phase * k)
# 	x : (2 * pi) * (i * phase * k), y : (2 * pi) * i * phase * k, z : 2 * pi * i * phase * k
# 88	instantiation	159	|- |(2, pi, i)| = |(1, 2, ..., 3)|
# 	a : 2, b : pi, c : i
# 89	conjecture		|- e in RealPos
# 	proveit.numbers.number_sets.real_numbers.e_is_real_pos
# 90	instantiation	152, 121, 179, 153, 122, 96, 154, 157, 158, 163, 164, 126, 156	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * k * (2^{t} * phase)) =  \\ (2 * pi * i * k * 2^{t} * phase)
# 	i : 4, j : 2, k : 0, a : (2, pi, i, k), b : (2^{t}, phase), c : ()
# 91	instantiation	131, 97, 98	{k in {0 .. 2^{t} - 1}} |- ((2 * pi * i * k * 2^{t} * phase) / 2^{t}) = ((2 * pi * i * k * phase) / 1)
# 	x : (2 * pi * i * k * 2^{t} * phase) / 2^{t}, y : (2^{t} * (2 * pi * i * k * phase)) / 2^{t}, z : (2 * pi * i * k * phase) / 1
# 92	instantiation	99, 108	{k in {0 .. 2^{t} - 1}} |- ((2 * pi * i * k * phase) / 1) = (2 * pi * i * k * phase)
# 	x : 2 * pi * i * k * phase
# 93	instantiation	140, 100, 101	{k in {0 .. 2^{t} - 1}} |- (i * phase * k) in Complex
# 	P(_a) : _a in Complex, x : (i * phase) * k, y : i * phase * k
# 94	instantiation	152, 194, 144, 153, 102, 154, 143, 163, 156, 164	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * (i * phase * k)) =  \\ ((2 * pi) * i * phase * k)
# 	i : 1, j : 3, k : 0, a : (2 * pi), b : (i, phase, k), c : ()
# 95	instantiation	152, 153, 179, 144, 154, 145, 102, 157, 158, 163, 156, 164	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * i * phase * k) =  \\ (2 * pi * i * phase * k)
# 	i : 0, j : 2, k : 3, a : (), b : (2, pi), c : (i, phase, k)
# 96	instantiation	165	|- |(2^{t}, phase)| = |(1, ..., 2)|
# 	a : 2^{t}, b : phase
# 97	instantiation	103, 104	{k in {0 .. 2^{t} - 1}} |- ((2 * pi * i * k * 2^{t} * phase) / 2^{t}) = ((2^{t} * (2 * pi * i * k * phase)) / 2^{t})
# 	f(_a) : _a / 2^{t}, x : 2 * pi * i * k * 2^{t} * phase, y : 2^{t} * (2 * pi * i * k * phase)
# 98	instantiation	105, 106, 107, 108, 109*	{k in {0 .. 2^{t} - 1}} |- ((2^{t} * (2 * pi * i * k * phase)) / 2^{t}) = ((2 * pi * i * k * phase) / 1)
# 	x : 2^{t}, z : 1, y : 2 * pi * i * k * phase
# 99	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 100	instantiation	162, 110, 164	{k in {0 .. 2^{t} - 1}} |- ((i * phase) * k) in Complex
# 	a : i * phase, b : k
# 101	instantiation	152, 153, 179, 194, 154, 111, 163, 156, 164	{k in {0 .. 2^{t} - 1}} |- ((i * phase) * k) =  \\ (i * phase * k)
# 	i : 0, j : 2, k : 1, a : (), b : (i, phase), c : (k)
# 102	instantiation	159	|- |(i, phase, k)| = |(1, 2, ..., 3)|
# 	a : i, b : phase, c : k
# 103	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 104	instantiation	131, 112, 113	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * k * 2^{t} * phase) = (2^{t} * (2 * pi * i * k * phase))
# 	x : 2 * pi * i * k * 2^{t} * phase, y : 2^{t} * 2 * pi * i * k * phase, z : 2^{t} * (2 * pi * i * k * phase)
# 105	conjecture		|- forall_{x, z in ComplexNonZero} [forall_{y in Complex} (((x * y) / (x * z)) = (y / z))]
# 	proveit.numbers.division.frac_cancel_left
# 106	instantiation	192, 115, 114	|- 2^{t} in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t}
# 107	instantiation	192, 115, 116	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 108	instantiation	140, 117, 118	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * k * phase) in Complex
# 	P(_a) : _a in Complex, x : (2 * pi) * (i * k * phase), y : 2 * pi * i * k * phase
# 109	instantiation	119, 126	|- (2^{t} * 1) = 2^{t}
# 	x : 2^{t}
# 110	instantiation	162, 163, 156	|- (i * phase) in Complex
# 	a : i, b : phase
# 111	instantiation	165	|- |(i, phase)| = |(1, ..., 2)|
# 	a : i, b : phase
# 112	instantiation	120, 153, 121, 194, 154, 122, 157, 158, 163, 164, 126, 156	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * k * 2^{t} * phase) =  \\ (2^{t} * 2 * pi * i * k * phase)
# 	i : 0, j : 4, k : 1, a : (), b : (2, pi, i, k), c : 2^{t}, d : (phase)
# 113	instantiation	123, 194, 124, 153, 125, 154, 126, 157, 158, 163, 164, 156	{k in {0 .. 2^{t} - 1}} |- (2^{t} * 2 * pi * i * k * phase) =  \\ (2^{t} * (2 * pi * i * k * phase))
# 	i : 1, j : 5, k : 0, a : (2^{t}), b : (2, pi, i, k, phase), c : ()
# 114	instantiation	192, 128, 127	|- 2^{t} in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2^{t}
# 115	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 116	instantiation	192, 128, 129	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 117	instantiation	162, 143, 130	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * (i * k * phase)) in Complex
# 	a : 2 * pi, b : i * k * phase
# 118	instantiation	131, 132, 133	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * (i * k * phase)) = (2 * pi * i * k * phase)
# 	x : (2 * pi) * (i * k * phase), y : (2 * pi) * i * k * phase, z : 2 * pi * i * k * phase
# 119	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 120	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j} * c* d_{1} *  d_{2} *  ... *  d_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i} * c* b_{1} *  b_{2} *  ... *  b_{j}* d_{1} *  d_{2} *  ... *  d_{k}))]
# 	proveit.numbers.multiplication.leftward_commutation
# 121	conjecture		|- 4 in Natural
# 	proveit.numbers.numerals.decimals.nat4
# 122	instantiation	134	|- |(2, pi, i, k)| = |(1, 2, ..., 4)|
# 	a : 2, b : pi, c : i, d : k
# 123	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} *  b_{2} *  ... *  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}))]
# 	proveit.numbers.multiplication.association
# 124	conjecture		|- 5 in Natural
# 	proveit.numbers.numerals.decimals.nat5
# 125	instantiation	135	|- |(2, pi, i, k, phase)| = |(1, 2, ..., 5)|
# 	a : 2, b : pi, c : i, d : k, e : phase
# 126	instantiation	192, 169, 136	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 127	instantiation	192, 138, 137	|- 2^{t} in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2^{t}
# 128	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 129	instantiation	192, 138, 139	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 130	instantiation	140, 141, 142	{k in {0 .. 2^{t} - 1}} |- (i * k * phase) in Complex
# 	P(_a) : _a in Complex, x : (i * k) * phase, y : i * k * phase
# 131	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 132	instantiation	152, 194, 144, 153, 146, 154, 143, 163, 164, 156	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * (i * k * phase)) =  \\ ((2 * pi) * i * k * phase)
# 	i : 1, j : 3, k : 0, a : (2 * pi), b : (i, k, phase), c : ()
# 133	instantiation	152, 153, 179, 144, 154, 145, 146, 157, 158, 163, 164, 156	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * i * k * phase) =  \\ (2 * pi * i * k * phase)
# 	i : 0, j : 2, k : 3, a : (), b : (2, pi), c : (i, k, phase)
# 134	conjecture		|- forall_{a, b, c, d} (|(a, b, c, d)| = |(1, 2, ..., 4)|)
# 	proveit.numbers.numerals.decimals.tuple_len_4_typical_eq
# 135	conjecture		|- forall_{a, b, c, d, e} (|(a, b, c, d, e)| = |(1, 2, ..., 5)|)
# 	proveit.numbers.numerals.decimals.tuple_len_5_typical_eq
# 136	instantiation	147, 148, 189	|- 2^{t} in Real
# 	A : NaturalPos, B : Real, x : 2^{t}
# 137	instantiation	192, 149, 189	|- 2^{t} in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2^{t}
# 138	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 139	instantiation	192, 149, 150	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 140	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 141	instantiation	162, 151, 156	{k in {0 .. 2^{t} - 1}} |- ((i * k) * phase) in Complex
# 	a : i * k, b : phase
# 142	instantiation	152, 153, 179, 194, 154, 155, 163, 164, 156	{k in {0 .. 2^{t} - 1}} |- ((i * k) * phase) =  \\ (i * k * phase)
# 	i : 0, j : 2, k : 1, a : (), b : (i, k), c : (phase)
# 143	instantiation	162, 157, 158	|- (2 * pi) in Complex
# 	a : 2, b : pi
# 144	conjecture		|- 3 in Natural
# 	proveit.numbers.numerals.decimals.nat3
# 145	instantiation	165	|- |(2, pi)| = |(1, ..., 2)|
# 	a : 2, b : pi
# 146	instantiation	159	|- |(i, k, phase)| = |(1, 2, ..., 3)|
# 	a : i, b : k, c : phase
# 147	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 148	instantiation	160, 161	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 149	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 150	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 151	instantiation	162, 163, 164	{k in {0 .. 2^{t} - 1}} |- (i * k) in Complex
# 	a : i, b : k
# 152	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} *  b_{2} *  ... *  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}* c_{1} *  c_{2} *  ... *  c_{k}))]
# 	proveit.numbers.multiplication.disassociation
# 153	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 154	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 155	instantiation	165	|- |(i, k)| = |(1, ..., 2)|
# 	a : i, b : k
# 156	instantiation	192, 169, 166	|- phase in Complex
# 	A : Real, B : Complex, x : phase
# 157	instantiation	192, 169, 167	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 158	instantiation	192, 169, 168	|- pi in Complex
# 	A : Real, B : Complex, x : pi
# 159	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, 2, ..., 3)|)
# 	proveit.numbers.numerals.decimals.tuple_len_3_typical_eq
# 160	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 161	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 162	conjecture		|- forall_{a, b in Complex} ((a * b) in Complex)
# 	proveit.numbers.multiplication.mult_complex_closure_bin
# 163	conjecture		|- i in Complex
# 	proveit.numbers.number_sets.complex_numbers.i_is_complex
# 164	instantiation	192, 169, 170	{k in {0 .. 2^{t} - 1}} |- k in Complex
# 	A : Real, B : Complex, x : k
# 165	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 166	conjecture		|- phase in Real
# 	proveit.physics.quantum.QPE._phase_is_real
# 167	instantiation	192, 174, 171	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 168	instantiation	192, 172, 173	|- pi in Real
# 	A : RealPos, B : Real, x : pi
# 169	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 170	instantiation	192, 174, 175	{k in {0 .. 2^{t} - 1}} |- k in Real
# 	A : Rational, B : Real, x : k
# 171	instantiation	192, 177, 176	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 172	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 173	conjecture		|- pi in RealPos
# 	proveit.numbers.number_sets.real_numbers.pi_is_real_pos
# 174	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 175	instantiation	192, 177, 178	{k in {0 .. 2^{t} - 1}} |- k in Rational
# 	A : Integer, B : Rational, x : k
# 176	instantiation	192, 193, 179	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 177	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 178	instantiation	192, 180, 181	{k in {0 .. 2^{t} - 1}} |- k in Integer
# 	A : {0 .. 2^{t} - 1}, B : Integer, x : k
# 179	conjecture		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 180	instantiation	182, 183, 184	|- {0 .. 2^{t} - 1} proper_subset Integer
# 	a : 0, b : 2^{t} - 1
# 181	assumption		{k in {0 .. 2^{t} - 1}} |- k in {0 .. 2^{t} - 1}
# 182	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 183	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 184	instantiation	185, 186, 187	|- (2^{t} - 1) in Integer
# 	a : 2^{t}, b : -1
# 185	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 186	instantiation	192, 188, 189	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 187	instantiation	190, 191	|- (-1) in Integer
# 	a : 1
# 188	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 189	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
# 190	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 191	instantiation	192, 193, 194	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 192	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 193	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 194	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
