# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_e_value_ge_two">_e_value_ge_two</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import a, b, x
from proveit.logic import InSet
from proveit.numbers import (zero, one, two, five, Add, Exp, frac, greater,
                             Integer, Neg, Real, RealPos, subtract)
# QPE common expressions
from proveit.physics.quantum.QPE import _t, _n
# QPE axioms
from proveit.physics.quantum.QPE import (
        _eps_in_interval, _n_in_natural_pos, _t_in_natural_pos, _t_req)

# %%
# %proving _e_value_ge_two
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="_e_value_ge_two">_e_value_ge_two:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/396def8ba7d11f0cfc66829313d1ccd83d6529830/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/1fd0a868af1d044898374bdb1a59bd4de9072ebc0/dependencies.ipynb">dependencies</a>)<br>

# %%
_t_in_natural_pos
# Out:
# |- t in NaturalPos

# %%
_n_in_natural_pos
# Out:
# |- n in NaturalPos

# %%
_eps_in_interval
# Out:
# |- eps in (0,1]

# %%
_t_req
# Out:
# |- t >= (n + ceil(log_2(2 + (1 / (2 * eps)))))

# %%
bound_01 = _t_req.right_add_both_sides(Neg(_n))
# Out:
# <strong id="bound_01">bound_01:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_ge_two/ef463982f9e89d4a4e73fcb99e3209035545f5a90/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_ge_two/f6a8143496d86e53edc18a9e18fff7eb5849f5fc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_eps_le_one = _eps_in_interval.derive_element_upper_bound()
# Out:
# <strong id="_eps_le_one">_eps_le_one:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_ge_two/ffc83ca6f10f62281ed42ffbfa9cfa41addb86520/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_ge_two/ff24096d2b1d72376aed268b9700cde0af9715870/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
bound_02 = bound_01.rhs.deduce_bound(_eps_le_one)
# Out:
# <strong id="bound_02">bound_02:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_ge_two/430cd6c558ed87844d85ec3f2922b5c707fcd2100/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_ge_two/294908053b32e19be21d1fb9394488a1da7300470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
bound_03 = bound_01.apply_transitivity(bound_02)
# Out:
# <strong id="bound_03">bound_03:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_ge_two/56484122fdb778f6a768278d53de292b8e325ddb0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_ge_two/746b90fb126fd4a996c0ece8dbe7ed161d991c550/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Note that ${\rm log}_2(x) > 1$ if $x > 2$:

# %%
bound_04 = bound_03.rhs.deduce_bound(greater(frac(five, two), two))
# Out:
# <strong id="bound_04">bound_04:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_ge_two/5fbc66599527efb40117f10ec88f110e2f7842120/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_ge_two/90392a83cdc72c595064ee4e8066e695b0ea82fe0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
bound_05 = bound_03.apply_transitivity(bound_04)
# Out:
# <strong id="bound_05">bound_05:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_ge_two/93bb4c12ea796a45f598dd97eef5e02130bf379a0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_ge_two/ae59de77dc5b720645ed666d3ae0cdafc9d58a9d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
bound_06 = Exp(two, subtract(_t, _n)).deduce_bound(bound_05)
# Out:
# <strong id="bound_06">bound_06:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_ge_two/7d61e7834623cebfb3e3765f6a4b18844ddade060/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_ge_two/4c83dbb32920c78b06151e0fc9b65886092ca6370/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# _e_value_ge_two may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._e_value_ge_two has been proven.
# 	step type	requirements	statement
# 0	instantiation	85, 110, 14, 1, 2, 3*, 4*	|- (2^{t - n} - 1) >= 2
# 	a : -2, x : 4, y : 2^{t - n} + 1
# 1	instantiation	109, 23, 239	|- (2^{t - n} + 1) in Real
# 	a : 2^{t - n}, b : 1
# 2	instantiation	52, 14, 23, 239, 5, 6	|- 4 <= (2^{t - n} + 1)
# 	a : 4, b : 2^{t - n}, c : 1
# 3	instantiation	7, 182, 8, 9	|- (4 - 2) = 2
# 	a : 2, b : 2, c : 4
# 4	instantiation	169, 10, 11	|- ((2^{t - n} + 1) - 2) = (2^{t - n} - 1)
# 	x : (2^{t - n} + 1) - 2, y : 2^{t - n} + 1 - 2, z : 2^{t - n} - 1
# 5	instantiation	12, 193, 53, 219, 54, 13*	|- 4 <= 2^{t - n}
# 	a : 2, x : 2, y : t - n
# 6	instantiation	181, 247	|- 1 >= 0
# 	n : 1
# 7	conjecture		|- forall_{a, b, c in Complex | (a + b) = c} ((c - b) = a)
# 	proveit.numbers.addition.subtraction.subtract_from_add
# 8	instantiation	245, 204, 14	|- 4 in Complex
# 	A : Real, B : Complex, x : 4
# 9	conjecture		|- (2 + 2) = 4
# 	proveit.numbers.numerals.decimals.add_2_2
# 10	instantiation	127, 128, 218, 247, 129, 15, 18, 196, 76	|- ((2^{t - n} + 1) - 2) =  \\ (2^{t - n} + 1 - 2)
# 	i : 0, j : 2, k : 1, a : (), b : (2^{t - n}, 1), c : (-2)
# 11	instantiation	16, 247, 218, 128, 17, 129, 18, 196, 76, 19*	|- (2^{t - n} + 1 - 2) =  \\ (2^{t - n} - 1)
# 	i : 1, j : 2, k : 0, a : (2^{t - n}), b : (1, -2), c : ()
# 12	conjecture		|- forall_{a, x, y in Real | a > 1, x <= y} (a^{x} <= a^{y})
# 	proveit.numbers.exponentiation.exp_monotonicity_large_base_less_eq
# 13	instantiation	62, 20, 21, 186	|- 2^{2} = 4
# 	a : 2^{2}, b : 2 *  ..0 ×.. *  2, c : 2 * 2, d : 4
# 14	instantiation	245, 241, 22	|- 4 in Real
# 	A : Rational, B : Real, x : 4
# 15	instantiation	194	|- |(2^{t - n}, 1)| = |(1, ..., 2)|
# 	a : 2^{t - n}, b : 1
# 16	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.association
# 17	instantiation	194	|- |(1, -2)| = |(1, ..., 2)|
# 	a : 1, b : -2
# 18	instantiation	245, 204, 23	|- 2^{t - n} in Complex
# 	A : Real, B : Complex, x : 2^{t - n}
# 19	instantiation	24, 196, 182, 68	|- (1 - 2) = (-1)
# 	a : 1, b : 1, c : 2
# 20	instantiation	25, 235, 182	|- 2^{2} = (2 *  ..0 ×.. *  2)
# 	n : 2, x : 2
# 21	instantiation	26, 218, 27, 28, 29	|- (2 *  ..0 ×.. *  2) =  \\ (2 * 2)
# 	n : 2, f(_b_{1}, ..., _b_{2}) : _b_{1} *  ... *  _b_{2}, x : (2, ..0 ×.., 2), y : (2, 2)
# 22	instantiation	245, 243, 30	|- 4 in Rational
# 	A : Integer, B : Rational, x : 4
# 23	instantiation	31, 193, 32	|- 2^{t - n} in Real
# 	a : 2, b : t - n
# 24	conjecture		|- forall_{a, b, c in Complex | (a + b) = c} ((b - c) = (-a))
# 	proveit.numbers.addition.subtraction.subtract_from_add_reversed
# 25	conjecture		|- forall_{n in NaturalPos} [forall_{x in Complex} (x^{n} = (x *  x *  ..(n - 3) ×.. *  x))]
# 	proveit.numbers.exponentiation.exp_nat_pos_expansion
# 26	conjecture		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1}, x_{2}, ..., x_{n}) = (y_{1}, y_{2}, ..., y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution_via_tuple
# 27	instantiation	33, 218	|- |(2, ..0 ×.., 2)| = |(1, ..., 2)|
# 	i : 2, f(_a) : 2
# 28	instantiation	194	|- |(2, 2)| = |(1, ..., 2)|
# 	a : 2, b : 2
# 29	instantiation	34	|- (2, ..0 ×.., 2) = (2, 2)
# 	x : 2
# 30	instantiation	245, 246, 35	|- 4 in Integer
# 	A : Natural, B : Integer, x : 4
# 31	conjecture		|- forall_{a in Real, b in Natural} (a^{b} in Real)
# 	proveit.numbers.exponentiation.exp_real_closure_nat_power
# 32	instantiation	36, 37, 38	|- (t - n) in Natural
# 	a : t - n
# 33	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), f(2), ..., f(i))| = |(1, 2, ..., i)|)]
# 	proveit.core_expr_types.tuples.range_from1_len_typical_eq
# 34	conjecture		|- forall_{x} ((x, ..0 ×.., x) = (x, x))
# 	proveit.numbers.numerals.decimals.reduce_2_repeats
# 35	conjecture		|- 4 in Natural
# 	proveit.numbers.numerals.decimals.nat4
# 36	conjecture		|- forall_{a in Integer | a >= 0} (a in Natural)
# 	proveit.numbers.number_sets.integers.nonneg_int_is_natural
# 37	instantiation	39, 40, 41	|- (t - n) in Integer
# 	a : t, b : -n
# 38	instantiation	42, 43	|- (t - n) >= 0
# 	a : t, b : n
# 39	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 40	instantiation	245, 44, 136	|- t in Integer
# 	A : NaturalPos, B : Integer, x : t
# 41	instantiation	245, 45, 46	|- (-n) in Integer
# 	A : IntegerNeg, B : Integer, x : -n
# 42	conjecture		|- forall_{a, b | a >= b} ((a - b) >= 0)
# 	proveit.numbers.addition.subtraction.nonneg_difference
# 43	instantiation	85, 89, 193, 47, 48, 49*, 50*	|- n <= t
# 	a : n - 2, x : 2, y : (t - n) + 2
# 44	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 45	conjecture		|- IntegerNeg proper_subset Integer
# 	proveit.numbers.number_sets.integers.neg_int_within_int
# 46	instantiation	51, 190	|- (-n) in IntegerNeg
# 	a : n
# 47	instantiation	109, 53, 193	|- ((t - n) + 2) in Real
# 	a : t - n, b : 2
# 48	instantiation	52, 193, 53, 54, 166	|- 2 <= ((t - n) + 2)
# 	a : 2, b : t - n, c : 2
# 49	instantiation	169, 55, 56	|- (2 + (n - 2)) = n
# 	x : 2 + (n - 2), y : 2 + n - 2, z : n
# 50	instantiation	169, 57, 58	|- (((t - n) + 2) + (n - 2)) = t
# 	x : ((t - n) + 2) + (n - 2), y : (t - n + 2) + (n - 2), z : t
# 51	conjecture		|- forall_{a in NaturalPos} ((-a) in IntegerNeg)
# 	proveit.numbers.negation.int_neg_closure
# 52	conjecture		|- forall_{a, b, c in Real | a <= b, 0 <= c} (a <= (b + c))
# 	proveit.numbers.ordering.less_eq_add_right
# 53	instantiation	109, 111, 154	|- (t - n) in Real
# 	a : t, b : -n
# 54	instantiation	69, 59, 60	|- 2 <= (t - n)
# 	x : 2, y : ceil(log_2(5 / 2)), z : t - n
# 55	instantiation	127, 247, 218, 128, 75, 129, 182, 133, 76	|- (2 + (n - 2)) =  \\ (2 + n - 2)
# 	i : 1, j : 2, k : 0, a : (2), b : (n, -2), c : ()
# 56	instantiation	132, 182, 133, 94	|- (2 + n - 2) = n
# 	a : 2, b : 2, c : n
# 57	instantiation	141, 61	|- (((t - n) + 2) + (n - 2)) = ((t - n + 2) + (n - 2))
# 	f(_a) : _a + (n - 2), x : (t - n) + 2, y : t - n + 2
# 58	instantiation	62, 63, 64, 65	|- ((t - n + 2) + (n - 2)) = t
# 	a : (t - n + 2) + (n - 2), b : t - n + 2 + (n - 2), c : t - n + 2 + n - 2, d : t
# 59	instantiation	66, 244, 83, 67, 68*	|- 2 <= ceil(log_2(5 / 2))
# 	x : 1, y : log_2(5 / 2)
# 60	instantiation	69, 70, 71	|- ceil(log_2(5 / 2)) <= (t - n)
# 	x : ceil(log_2(5 / 2)), y : ceil(log_2(2 + (1 / (2 * eps)))), z : t - n
# 61	instantiation	127, 128, 218, 247, 129, 93, 96, 131, 182	|- ((t - n) + 2) =  \\ (t - n + 2)
# 	i : 0, j : 2, k : 1, a : (), b : (t, -n), c : (2)
# 62	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 63	instantiation	127, 128, 73, 247, 129, 74, 96, 131, 182, 72	|- ((t - n + 2) + (n - 2)) =  \\ (t - n + 2 + (n - 2))
# 	i : 0, j : 3, k : 1, a : (), b : (t, -n, 2), c : (n - 2)
# 64	instantiation	127, 73, 218, 128, 74, 75, 129, 96, 131, 182, 133, 76	|- (t - n + 2 + (n - 2)) =  \\ (t - n + 2 + n - 2)
# 	i : 3, j : 2, k : 0, a : (t, -n, 2), b : (n, -2), c : ()
# 65	instantiation	169, 77, 78	|- (t - n + 2 + n - 2) = t
# 	x : t - n + 2 + n - 2, y : t - n + n, z : t
# 66	conjecture		|- forall_{x in Integer, y in Real | x < y} ((x + 1) <= ceil(y))
# 	proveit.numbers.rounding.ceil_of_real_above_int
# 67	instantiation	79, 227, 105, 80, 219, 81*	|- 1 < log_2(5 / 2)
# 	a : 2, x : 2, y : 5 / 2
# 68	conjecture		|- (1 + 1) = 2
# 	proveit.numbers.numerals.decimals.add_1_1
# 69	conjecture		|- forall_{x, y, z | x <= y, y <= z} (x <= z)
# 	proveit.numbers.ordering.transitivity_less_eq_less_eq
# 70	instantiation	82, 83, 200, 84	|- ceil(log_2(5 / 2)) <= ceil(log_2(2 + (1 / (2 * eps))))
# 	x : log_2(5 / 2), y : log_2(2 + (1 / (2 * eps)))
# 71	instantiation	85, 154, 86, 111, 87, 88*	|- ceil(log_2(2 + (1 / (2 * eps)))) <= (t - n)
# 	a : -n, x : n + ceil(log_2(2 + (1 / (2 * eps)))), y : t
# 72	instantiation	245, 204, 89	|- (n - 2) in Complex
# 	A : Real, B : Complex, x : n - 2
# 73	conjecture		|- 3 in Natural
# 	proveit.numbers.numerals.decimals.nat3
# 74	instantiation	90	|- |(t, -n, 2)| = |(1, 2, ..., 3)|
# 	a : t, b : -n, c : 2
# 75	instantiation	194	|- |(n, -2)| = |(1, ..., 2)|
# 	a : n, b : -2
# 76	instantiation	91, 182	|- (-2) in Complex
# 	a : 2
# 77	instantiation	92, 218, 247, 128, 93, 129, 96, 131, 182, 133, 94	|- (t - n + 2 + n - 2) = (t - n + n)
# 	i : 2, j : 1, k : 0, a : (t, -n), b : 2, c : (n), d : 2, e : ()
# 78	instantiation	95, 133, 96, 135	|- (t - n + n) = t
# 	a : n, b : n, c : t
# 79	conjecture		|- forall_{a, x, y in RealPos | x < y, a > 1} (log_a(x) < log_a(y))
# 	proveit.numbers.logarithms.log_increasing_less
# 80	instantiation	97, 193, 98, 99, 100, 101*, 102*	|- 2 < (5 / 2)
# 	a : 2, x : (1 / 2) * 0, y : (1 / 2) * 1
# 81	instantiation	103, 227	|- log_2(2) = 1
# 	a : 2
# 82	conjecture		|- forall_{x, y in Real | x <= y} (ceil(x) <= ceil(y))
# 	proveit.numbers.rounding.ceil_increasing_less_eq
# 83	instantiation	205, 227, 105, 207	|- log_2(5 / 2) in Real
# 	a : 2, b : 5 / 2
# 84	instantiation	104, 227, 105, 206, 106, 219	|- log_2(5 / 2) <= log_2(2 + (1 / (2 * eps)))
# 	a : 2, x : 5 / 2, y : 2 + (1 / (2 * eps))
# 85	conjecture		|- forall_{a, x, y in Real | x <= y} ((x + a) <= (y + a))
# 	proveit.numbers.addition.weak_bound_via_left_term_bound
# 86	instantiation	109, 174, 155	|- (n + ceil(log_2(2 + (1 / (2 * eps))))) in Real
# 	a : n, b : ceil(log_2(2 + (1 / (2 * eps))))
# 87	axiom		|- t >= (n + ceil(log_2(2 + (1 / (2 * eps)))))
# 	proveit.physics.quantum.QPE._t_req
# 88	instantiation	169, 107, 108	|- ((n + ceil(log_2(2 + (1 / (2 * eps))))) - n) = ceil(log_2(2 + (1 / (2 * eps))))
# 	x : (n + ceil(log_2(2 + (1 / (2 * eps))))) - n, y : n + ceil(log_2(2 + (1 / (2 * eps)))) - n, z : ceil(log_2(2 + (1 / (2 * eps))))
# 89	instantiation	109, 174, 110	|- (n - 2) in Real
# 	a : n, b : -2
# 90	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, 2, ..., 3)|)
# 	proveit.numbers.numerals.decimals.tuple_len_3_typical_eq
# 91	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 92	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex | b = d} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}))]
# 	proveit.numbers.addition.subtraction.add_cancel_general
# 93	instantiation	194	|- |(t, -n)| = |(1, ..., 2)|
# 	a : t, b : -n
# 94	instantiation	156	|- 2 = 2
# 	x : 2
# 95	conjecture		|- forall_{a, b, c in Complex | a = b} ((c - a + b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_32
# 96	instantiation	245, 204, 111	|- t in Complex
# 	A : Real, B : Complex, x : t
# 97	conjecture		|- forall_{a, x, y in Real | x < y} ((x + a) < (y + a))
# 	proveit.numbers.addition.strong_bound_via_left_term_bound
# 98	instantiation	112, 176, 238	|- ((1 / 2) * 0) in Real
# 	a : 1 / 2, b : 0
# 99	instantiation	245, 241, 113	|- ((1 / 2) * 1) in Real
# 	A : Rational, B : Real, x : (1 / 2) * 1
# 100	instantiation	114, 176, 238, 239, 115, 116	|- ((1 / 2) * 0) < ((1 / 2) * 1)
# 	a : 1 / 2, x : 0, y : 1
# 101	instantiation	169, 117, 118	|- (((1 / 2) * 0) + 2) = 2
# 	x : ((1 / 2) * 0) + 2, y : 0 + 2, z : 2
# 102	instantiation	169, 119, 120	|- (((1 / 2) * 1) + 2) = (5 / 2)
# 	x : ((1 / 2) * 1) + 2, y : (1 / 2) + 2, z : 5 / 2
# 103	conjecture		|- forall_{a in RealPos} (log_a(a) = 1)
# 	proveit.numbers.logarithms.log_eq_1
# 104	conjecture		|- forall_{a, x, y in RealPos | x <= y, a > 1} (log_a(x) <= log_a(y))
# 	proveit.numbers.logarithms.log_increasing_less_eq
# 105	instantiation	214, 121, 227, 122	|- (5 / 2) in RealPos
# 	a : 5, b : 2
# 106	instantiation	123, 193, 176, 124, 125, 126*	|- (5 / 2) <= (2 + (1 / (2 * eps)))
# 	a : 2, x : 1 / 2, y : 1 / (2 * eps)
# 107	instantiation	127, 128, 218, 247, 129, 130, 133, 134, 131	|- ((n + ceil(log_2(2 + (1 / (2 * eps))))) - n) =  \\ (n + ceil(log_2(2 + (1 / (2 * eps)))) - n)
# 	i : 0, j : 2, k : 1, a : (), b : (n, ceil(log_2(2 + (1 / (2 * eps))))), c : (-n)
# 108	instantiation	132, 133, 134, 135	|- (n + ceil(log_2(2 + (1 / (2 * eps)))) - n) = ceil(log_2(2 + (1 / (2 * eps))))
# 	a : n, b : n, c : ceil(log_2(2 + (1 / (2 * eps))))
# 109	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 110	instantiation	173, 193	|- (-2) in Real
# 	a : 2
# 111	instantiation	188, 189, 136	|- t in Real
# 	A : NaturalPos, B : Real, x : t
# 112	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 113	instantiation	137, 192, 242	|- ((1 / 2) * 1) in Rational
# 	a : 1 / 2, b : 1
# 114	conjecture		|- forall_{a, x, y in Real | x < y, a > 0} ((a * x) < (a * y))
# 	proveit.numbers.multiplication.strong_bound_via_right_factor_bound
# 115	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 116	instantiation	138, 202	|- (1 / 2) > 0
# 	q : 1 / 2
# 117	instantiation	141, 139	|- (((1 / 2) * 0) + 2) = (0 + 2)
# 	f(_a) : _a + 2, x : (1 / 2) * 0, y : 0
# 118	instantiation	140, 182	|- (0 + 2) = 2
# 	a : 2
# 119	instantiation	141, 142	|- (((1 / 2) * 1) + 2) = ((1 / 2) + 2)
# 	f(_a) : _a + 2, x : (1 / 2) * 1, y : 1 / 2
# 120	instantiation	150, 244, 209, 151*, 143*, 167*	|- ((1 / 2) + 2) = (5 / 2)
# 	a : 1, b : 2, c : 2, d : 1
# 121	instantiation	245, 229, 144	|- 5 in RealPos
# 	A : RationalPos, B : RealPos, x : 5
# 122	instantiation	145, 235	|- 2 != 0
# 	n : 2
# 123	conjecture		|- forall_{a, x, y in Real | x <= y} ((a + x) <= (a + y))
# 	proveit.numbers.addition.weak_bound_via_right_term_bound
# 124	instantiation	245, 146, 211	|- (1 / (2 * eps)) in Real
# 	A : RealPos, B : Real, x : 1 / (2 * eps)
# 125	instantiation	147, 148, 225, 227, 149	|- (1 / (2 * eps)) >= (1 / 2)
# 	a : 1, x : 2 * eps, y : 2
# 126	instantiation	150, 209, 244, 151*, 152*, 153*	|- (2 + (1 / 2)) = (5 / 2)
# 	a : 2, b : 1, c : 1, d : 2
# 127	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 128	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 129	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 130	instantiation	194	|- |(n, ceil(log_2(2 + (1 / (2 * eps)))))| = |(1, ..., 2)|
# 	a : n, b : ceil(log_2(2 + (1 / (2 * eps))))
# 131	instantiation	245, 204, 154	|- (-n) in Complex
# 	A : Real, B : Complex, x : -n
# 132	conjecture		|- forall_{a, b, c in Complex | a = b} ((a + c - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_13
# 133	instantiation	245, 204, 174	|- n in Complex
# 	A : Real, B : Complex, x : n
# 134	instantiation	245, 204, 155	|- ceil(log_2(2 + (1 / (2 * eps)))) in Complex
# 	A : Real, B : Complex, x : ceil(log_2(2 + (1 / (2 * eps))))
# 135	instantiation	156	|- n = n
# 	x : n
# 136	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 137	conjecture		|- forall_{a, b in Rational} ((a * b) in Rational)
# 	proveit.numbers.multiplication.mult_rational_closure_bin
# 138	conjecture		|- forall_{q in RationalPos} (q > 0)
# 	proveit.numbers.number_sets.rational_numbers.positive_if_in_rational_pos
# 139	instantiation	157, 158	|- ((1 / 2) * 0) = 0
# 	x : 1 / 2
# 140	conjecture		|- forall_{a in Complex} ((0 + a) = a)
# 	proveit.numbers.addition.elim_zero_left
# 141	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 142	instantiation	195, 158	|- ((1 / 2) * 1) = (1 / 2)
# 	x : 1 / 2
# 143	instantiation	169, 159, 160	|- ((1 * 1) + (2 * 2)) = 5
# 	x : (1 * 1) + (2 * 2), y : 1 + 4, z : 5
# 144	instantiation	245, 234, 161	|- 5 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 5
# 145	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 146	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 147	conjecture		|- forall_{a in RealNonNeg} [forall_{x, y in RealPos | x <= y} ((a / x) >= (a / y))]
# 	proveit.numbers.division.weak_div_from_denom_bound__all_pos
# 148	instantiation	245, 162, 163	|- 1 in RealNonNeg
# 	A : RationalNonNeg, B : RealNonNeg, x : 1
# 149	instantiation	164, 193, 232, 239, 165, 166, 167*	|- (2 * eps) <= 2
# 	a : 2, x : eps, y : 1
# 150	conjecture		|- forall_{a, b, c, d in Integer} (((a / b) + (c / d)) = (((a * d) + (b * c)) / (b * d)))
# 	proveit.numbers.addition.rational_pair_addition
# 151	instantiation	168, 182	|- (2 / 1) = 2
# 	x : 2
# 152	instantiation	169, 170, 171	|- ((2 * 2) + (1 * 1)) = 5
# 	x : (2 * 2) + (1 * 1), y : 4 + 1, z : 5
# 153	instantiation	172, 182	|- (1 * 2) = 2
# 	x : 2
# 154	instantiation	173, 174	|- (-n) in Real
# 	a : n
# 155	instantiation	245, 241, 175	|- ceil(log_2(2 + (1 / (2 * eps)))) in Real
# 	A : Rational, B : Real, x : ceil(log_2(2 + (1 / (2 * eps))))
# 156	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 157	conjecture		|- forall_{x in Complex} ((x * 0) = 0)
# 	proveit.numbers.multiplication.mult_zero_right
# 158	instantiation	245, 204, 176	|- (1 / 2) in Complex
# 	A : Real, B : Complex, x : 1 / 2
# 159	instantiation	183, 218, 177, 178, 187, 186	|- ((1 * 1) + (2 * 2)) =  \\ (1 + 4)
# 	n : 2, f(_a, _b) : _a + _b, x : (1 * 1, 2 * 2), y : (1, 4)
# 160	conjecture		|- (1 + 4) = 5
# 	proveit.numbers.numerals.decimals.add_1_4
# 161	conjecture		|- 5 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat5
# 162	conjecture		|- RationalNonNeg proper_subset RealNonNeg
# 	proveit.numbers.number_sets.real_numbers.rational_nonneg_within_real_nonneg
# 163	instantiation	245, 179, 247	|- 1 in RationalNonNeg
# 	A : Natural, B : RationalNonNeg, x : 1
# 164	conjecture		|- forall_{a, x, y in Real | x <= y, a >= 0} ((a * x) <= (a * y))
# 	proveit.numbers.multiplication.weak_bound_via_right_factor_bound
# 165	instantiation	180, 238, 239, 240	|- eps <= 1
# 	a : 0, b : 1, x : eps
# 166	instantiation	181, 218	|- 0 <= 2
# 	n : 2
# 167	instantiation	195, 182	|- (2 * 1) = 2
# 	x : 2
# 168	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 169	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 170	instantiation	183, 218, 184, 185, 186, 187	|- ((2 * 2) + (1 * 1)) =  \\ (4 + 1)
# 	n : 2, f(_a, _b) : _a + _b, x : (2 * 2, 1 * 1), y : (4, 1)
# 171	conjecture		|- (4 + 1) = 5
# 	proveit.numbers.numerals.decimals.add_4_1
# 172	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 173	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 174	instantiation	188, 189, 190	|- n in Real
# 	A : NaturalPos, B : Real, x : n
# 175	instantiation	245, 243, 191	|- ceil(log_2(2 + (1 / (2 * eps)))) in Rational
# 	A : Integer, B : Rational, x : ceil(log_2(2 + (1 / (2 * eps))))
# 176	instantiation	245, 241, 192	|- (1 / 2) in Real
# 	A : Rational, B : Real, x : 1 / 2
# 177	instantiation	194	|- |(1 * 1, 2 * 2)| = |(1, ..., 2)|
# 	a : 1 * 1, b : 2 * 2
# 178	instantiation	194	|- |(1, 4)| = |(1, ..., 2)|
# 	a : 1, b : 4
# 179	conjecture		|- Natural proper_subset RationalNonNeg
# 	proveit.numbers.number_sets.rational_numbers.nat_within_rational_nonneg
# 180	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (x <= b)]
# 	proveit.numbers.number_sets.real_numbers.interval_oc_upper_bound
# 181	conjecture		|- forall_{n in Natural} (n >= 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_lower_bound
# 182	instantiation	245, 204, 193	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 183	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 184	instantiation	194	|- |(2 * 2, 1 * 1)| = |(1, ..., 2)|
# 	a : 2 * 2, b : 1 * 1
# 185	instantiation	194	|- |(4, 1)| = |(1, ..., 2)|
# 	a : 4, b : 1
# 186	conjecture		|- (2 * 2) = 4
# 	proveit.numbers.numerals.decimals.mult_2_2
# 187	instantiation	195, 196	|- (1 * 1) = 1
# 	x : 1
# 188	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 189	instantiation	197, 198	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 190	axiom		|- n in NaturalPos
# 	proveit.physics.quantum.QPE._n_in_natural_pos
# 191	instantiation	199, 200	|- ceil(log_2(2 + (1 / (2 * eps)))) in Integer
# 	x : log_2(2 + (1 / (2 * eps)))
# 192	instantiation	245, 201, 202	|- (1 / 2) in Rational
# 	A : RationalPos, B : Rational, x : 1 / 2
# 193	instantiation	245, 241, 203	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 194	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 195	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 196	instantiation	245, 204, 239	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 197	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 198	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 199	axiom		|- forall_{x in Real} (ceil(x) in Integer)
# 	proveit.numbers.rounding.ceil_is_an_int
# 200	instantiation	205, 227, 206, 207	|- log_2(2 + (1 / (2 * eps))) in Real
# 	a : 2, b : 2 + (1 / (2 * eps))
# 201	conjecture		|- RationalPos proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.rational_pos_within_rational
# 202	instantiation	208, 220, 230	|- (1 / 2) in RationalPos
# 	a : 1, b : 2
# 203	instantiation	245, 243, 209	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 204	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 205	conjecture		|- forall_{a, b in RealPos | a != 1} (log_a(b) in Real)
# 	proveit.numbers.logarithms.log_real_pos_real_closure
# 206	instantiation	210, 227, 211	|- (2 + (1 / (2 * eps))) in RealPos
# 	a : 2, b : 1 / (2 * eps)
# 207	instantiation	212, 213	|- 2 != 1
# 	x : 1, y : 2
# 208	conjecture		|- forall_{a, b in RationalPos} ((a / b) in RationalPos)
# 	proveit.numbers.division.div_rational_pos_closure
# 209	instantiation	245, 246, 218	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 210	conjecture		|- forall_{a, b in RealPos} ((a + b) in RealPos)
# 	proveit.numbers.addition.add_real_pos_closure_bin
# 211	instantiation	214, 215, 225, 216	|- (1 / (2 * eps)) in RealPos
# 	a : 1, b : 2 * eps
# 212	theorem		|- forall_{x, y | x != y} (y != x)
# 	proveit.logic.equality.not_equals_symmetry
# 213	instantiation	217, 247, 218, 219	|- 1 != 2
# 	a : 1, b : 2
# 214	conjecture		|- forall_{a, b in RealPos | b != 0} ((a / b) in RealPos)
# 	proveit.numbers.division.div_real_pos_closure
# 215	instantiation	245, 229, 220	|- 1 in RealPos
# 	A : RationalPos, B : RealPos, x : 1
# 216	instantiation	221, 222	|- (2 * eps) != 0
# 	x : 2 * eps
# 217	conjecture		|- forall_{a, b in Natural | a < b} (a != b)
# 	proveit.numbers.ordering.less_is_not_eq_nat
# 218	conjecture		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 219	conjecture		|- 1 < 2
# 	proveit.numbers.numerals.decimals.less_1_2
# 220	instantiation	245, 234, 223	|- 1 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 1
# 221	conjecture		|- forall_{x in RealNonZero} (x != 0)
# 	proveit.numbers.number_sets.real_numbers.nonzero_if_in_real_nonzero
# 222	instantiation	245, 224, 225	|- (2 * eps) in RealNonZero
# 	A : RealPos, B : RealNonZero, x : 2 * eps
# 223	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 224	conjecture		|- RealPos proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real_nonzero
# 225	instantiation	226, 227, 228	|- (2 * eps) in RealPos
# 	a : 2, b : eps
# 226	conjecture		|- forall_{a, b in RealPos} ((a * b) in RealPos)
# 	proveit.numbers.multiplication.mult_real_pos_closure_bin
# 227	instantiation	245, 229, 230	|- 2 in RealPos
# 	A : RationalPos, B : RealPos, x : 2
# 228	instantiation	231, 232, 233	|- eps in RealPos
# 	a : eps
# 229	conjecture		|- RationalPos proper_subset RealPos
# 	proveit.numbers.number_sets.real_numbers.rational_pos_within_real_pos
# 230	instantiation	245, 234, 235	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 231	conjecture		|- forall_{a in Real | a > 0} (a in RealPos)
# 	proveit.numbers.number_sets.real_numbers.pos_real_is_real_pos
# 232	instantiation	236, 238, 239, 240	|- eps in Real
# 	a : 0, b : 1, x : eps
# 233	instantiation	237, 238, 239, 240	|- 0 < eps
# 	a : 0, b : 1, x : eps
# 234	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 235	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 236	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_oc__is__real
# 237	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (a < x)]
# 	proveit.numbers.number_sets.real_numbers.interval_oc_lower_bound
# 238	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 239	instantiation	245, 241, 242	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 240	axiom		|- eps in (0,1]
# 	proveit.physics.quantum.QPE._eps_in_interval
# 241	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 242	instantiation	245, 243, 244	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 243	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 244	instantiation	245, 246, 247	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 245	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 246	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 247	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
