# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_psi_t_ket_is_normalized_vec">_psi_t_ket_is_normalized_vec</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

from proveit import defaults
from proveit.logic import InSet
from proveit.numbers import Mult, Complex
from proveit.physics.quantum.QPE import _psi_t_def, _phase_is_real

# %%
# %proving _psi_t_ket_is_normalized_vec
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="_psi_t_ket_is_normalized_vec">_psi_t_ket_is_normalized_vec:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/69597cdddc096bf354ec5966375a5dcaab3ca1330/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/6da986179fe7649ea6ec2f7e6fd17a8f5a1c0bbe0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _psi_t_ket_is_normalized_vec.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_ket_is_normalized_vec/b224c91479a3b890185904715420afd2361984620/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# Keep the $2$ in $2 \pi i ...$ from combining with the other factors of $2$:

# %%
Mult.change_simplification_directives(combine_all_exponents=False)

# %%
psi_t_def_inst = _psi_t_def.instantiate()
# Out:
# <strong id="psi_t_def_inst">psi_t_def_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_ket_is_normalized_vec/3b2b244a456255e6f1b54fc7e6aa4dbb54eb3d3f0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/563650e734cfbeae20efdbfe15f272f48df74d250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
psi_t_def_inst.rhs.compute_norm(field=Complex, replacements=[psi_t_def_inst.derive_reversed()])
# Out:
# {t in NaturalPos} |- |||psi_{t}>|| = 1

# %%
domain = _psi_t_ket_is_normalized_vec.instance_expr.operands[0].domain
# Out:
# <strong id="domain">domain:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/159b10cef8a4d9569c7d0082018ceb562e82e0b20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
InSet(psi_t_def_inst.rhs, domain).prove()
# Out:
# {t in NaturalPos} |- (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))) in Complex^{2^{t}}

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._psi_t_ket_is_normalized_vec has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{t in NaturalPos} ((|psi_{t}> in Complex^{2^{t}}) and (|||psi_{t}>|| = 1))
# 1	instantiation	2, 3, 4	{t in NaturalPos} |- (|psi_{t}> in Complex^{2^{t}}) and (|||psi_{t}>|| = 1)
# 	A : |psi_{t}> in Complex^{2^{t}}, B : |||psi_{t}>|| = 1
# 2	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 3	instantiation	190, 5, 14	{t in NaturalPos} |- |psi_{t}> in Complex^{2^{t}}
# 	P(_b) : _b in Complex^{2^{t}}, x : |psi_{t}>, y : ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
# 4	instantiation	6, 328, 20, 7, 22, 23, 8, 9*	{t in NaturalPos} |- |||psi_{t}>|| = 1
# 	K : Complex, i : t, V : (Complex^{2}, Complex^{2}, ..(t - 3) ×.., Complex^{2}), a : (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
# 5	instantiation	244, 10, 11	{t in NaturalPos} |- (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))) in Complex^{2^{t}}
# 	A : Complex^{2} otimes  Complex^{2} otimes  ..(t - 3) ×.. otimes  Complex^{2}, B : Complex^{2^{t}}, x : ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
# 6	conjecture		|- forall_{K} [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c InnerProdSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i}) | (||a_{1}|| = 1) and  (||a_{2}|| = 1) and  ... and  (||a_{i}|| = 1)} (||a_{1} otimes  a_{2} otimes  ... otimes  a_{i}|| = 1)]]]
# 	proveit.linear_algebra.tensors.norm_preserving_tensor_prod
# 7	instantiation	31, 317, 318, 134, 46	{t in NaturalPos} |- (Complex^{2} in_c InnerProdSpaces(Complex)) and  (Complex^{2} in_c InnerProdSpaces(Complex)) and  ..(t - 3) ×.. and  (Complex^{2} in_c InnerProdSpaces(Complex))
# 	i : -t + 1, j : 0, A : Complex^{2} in_c InnerProdSpaces(Complex)
# 8	modus ponens	12, 13	{t in NaturalPos} |- (||(1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))|| = 1) and  (||(1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))|| = 1) and  ... and  (||(1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))|| = 1)
# 9	instantiation	211, 14	{t in NaturalPos} |- (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))) = |psi_{t}>
# 	x : |psi_{t}>, y : ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))
# 10	instantiation	15, 328, 16, 17, 18*	{t in NaturalPos} |- (Complex^{2} otimes  Complex^{2} otimes  ..(t - 3) ×.. otimes  Complex^{2}) subset_eq Complex^{2^{t}}
# 	K : Complex, m : t, n : (2, 2, ..(t - 3) ×.., 2)
# 11	instantiation	19, 328, 20, 21, 22, 23	{t in NaturalPos} |- (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))) in (Complex^{2} otimes  Complex^{2} otimes  ..(t - 3) ×.. otimes  Complex^{2})
# 	K : Complex, i : t, V : (Complex^{2}, Complex^{2}, ..(t - 3) ×.., Complex^{2}), a : (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
# 12	instantiation	45, 317, 318, 46	{t in NaturalPos} |- [forall_{_a in {-t + 1 .. 0}} (||(1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))|| = 1)] => ((||(1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))|| = 1) and  (||(1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))|| = 1) and  ... and  (||(1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))|| = 1))
# 	i : -t + 1, j : 0, P(_a) : ||(1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))|| = 1, k : _a
# 13	generalization	24	{t in NaturalPos} |- forall_{_a in {-t + 1 .. 0}} (||(1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))|| = 1)
# 14	instantiation	25, 328	{t in NaturalPos} |- |psi_{t}> = (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))
# 	t : t
# 15	conjecture		|- forall_{K} [forall_{m in NaturalPos} [forall_{n_{1}, n_{2}, ..., n_{m} in NaturalPos} ((K^{n_{1}} otimes  K^{n_{2}} otimes  ... otimes  K^{n_{m}}) subset_eq K^{n_{1} *  n_{2} *  ... *  n_{m}})]]
# 	proveit.linear_algebra.tensors.tensor_prod_of_cart_exps_within_cart_exp
# 16	instantiation	107, 26, 204, 33	{t in NaturalPos} |- |(2, 2, ..(t - 3) ×.., 2)| = |(1, 2, ..., t)|
# 	a : |(2, 2, ..(t - 3) ×.., 2)|, b : t, c : t, d : |(1, 2, ..., t)|
# 17	instantiation	31, 317, 318, 260, 46	{t in NaturalPos} |- (2 in NaturalPos) and  (2 in NaturalPos) and  ..(t - 3) ×.. and  (2 in NaturalPos)
# 	i : -t + 1, j : 0, A : 2 in NaturalPos
# 18	instantiation	27, 28, 297, 43, 29*, 43*	{t in NaturalPos} |- (2 *  2 *  ..(t - 3) ×.. *  2) = 2^{t}
# 	n : 0 - (-t + 1) + 1, x : 2
# 19	conjecture		|- forall_{K} [forall_{i in NaturalPos} [forall_{V_{1}, V_{2}, ..., V_{i} in_c VecSpaces(K)} [forall_{(a_{1} in V_{1}), (a_{2} in V_{2}), ..., (a_{i} in V_{i})} ((a_{1} otimes  a_{2} otimes  ... otimes  a_{i}) in (V_{1} otimes  V_{2} otimes  ... otimes  V_{i}))]]]
# 	proveit.linear_algebra.tensors.tensor_prod_is_in_tensor_prod_space
# 20	instantiation	107, 30, 204, 33	{t in NaturalPos} |- |(Complex^{2}, Complex^{2}, ..(t - 3) ×.., Complex^{2})| = |(1, 2, ..., t)|
# 	a : |(Complex^{2}, Complex^{2}, ..(t - 3) ×.., Complex^{2})|, b : t, c : t, d : |(1, 2, ..., t)|
# 21	instantiation	31, 317, 318, 130, 46	{t in NaturalPos} |- (Complex^{2} in_c VecSpaces(Complex)) and  (Complex^{2} in_c VecSpaces(Complex)) and  ..(t - 3) ×.. and  (Complex^{2} in_c VecSpaces(Complex))
# 	i : -t + 1, j : 0, A : Complex^{2} in_c VecSpaces(Complex)
# 22	instantiation	107, 32, 204, 33	{t in NaturalPos} |- |(((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))| = |(1, 2, ..., t)|
# 	a : |(((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉))))|, b : t, c : t, d : |(1, 2, ..., t)|
# 23	modus ponens	34, 35	{t in NaturalPos} |- (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))) in Complex^{2}) and  (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))) in Complex^{2}) and  ... and  (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))) in Complex^{2})
# 24	instantiation	253, 36, 37	{t in NaturalPos, _a in {-t + 1 .. 0}} |- ||(1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))|| = 1
# 	x : ||(1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))||, y : (1 / sqrt(2)) * sqrt((|||0〉||^{2} + |||1〉||^{2})), z : 1
# 25	axiom		|- forall_{t in NaturalPos} (|psi_{t}> = (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))))
# 	proveit.physics.quantum.QPE._psi_t_def
# 26	instantiation	261, 38, 43	{t in NaturalPos} |- |(2, 2, ..(t - 3) ×.., 2)| = t
# 	P(_b) : |(2, 2, ..(t - 3) ×.., 2)| = _b, x : 0 - (-t + 1) + 1, y : t
# 27	conjecture		|- forall_{n in NaturalPos} [forall_{x in Complex} ((x *  x *  ..(n - 3) ×.. *  x) = x^{n})]
# 	proveit.numbers.exponentiation.exp_nat_pos_rev
# 28	instantiation	149, 311, 278, 39, 279, 83, 325, 150	{t in NaturalPos} |- (0 - (-t + 1) + 1) in NaturalPos
# 	i : 2, j : 0, a : (0, -(-t + 1)), b : 1, c : ()
# 29	instantiation	211, 40	{t in NaturalPos} |- (2, 2, ..(t - 3) ×.., 2) = (2, 2, ..(t - 3) ×.., 2)
# 	x : (2, 2, ..(t - 3) ×.., 2), y : (2, 2, ..(t - 3) ×.., 2)
# 30	instantiation	261, 41, 43	{t in NaturalPos} |- |(Complex^{2}, Complex^{2}, ..(t - 3) ×.., Complex^{2})| = t
# 	P(_b) : |(Complex^{2}, Complex^{2}, ..(t - 3) ×.., Complex^{2})| = _b, x : 0 - (-t + 1) + 1, y : t
# 31	conjecture		|- forall_{i, j in Integer} [forall_{A | A, i <= (j + 1)} (A and  A and  ..(j - i - 2) ×.. and  A)]
# 	proveit.logic.booleans.conjunction.redundant_conjunction_general
# 32	instantiation	261, 42, 43	{t in NaturalPos} |- |(((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))))| = t
# 	P(_b) : |(((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))))| = _b, x : 0 - (-t + 1) + 1, y : t
# 33	instantiation	211, 44	{t in NaturalPos} |- t = |(1, 2, ..., t)|
# 	x : |(1, 2, ..., t)|, y : t
# 34	instantiation	45, 317, 318, 46	{t in NaturalPos} |- [forall_{_a in {-t + 1 .. 0}} (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2})] => ((((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))) in Complex^{2}) and  (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))) in Complex^{2}) and  ... and  (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))) in Complex^{2}))
# 	i : -t + 1, j : 0, P(_a) : ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2}, k : _a
# 35	generalization	47	{t in NaturalPos} |- forall_{_a in {-t + 1 .. 0}} (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2})
# 36	instantiation	102, 134, 67, 68, 48*, 49*	{t in NaturalPos, _a in {-t + 1 .. 0}} |- ||(1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))|| = ((1 / sqrt(2)) * sqrt((|||0〉||^{2} + |||1〉||^{2})))
# 	K : Complex, H : Complex^{2}, alpha : 1 / sqrt(2), x : |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
# 37	instantiation	253, 50, 51	|- ((1 / sqrt(2)) * sqrt((|||0〉||^{2} + |||1〉||^{2}))) = 1
# 	x : (1 / sqrt(2)) * sqrt((|||0〉||^{2} + |||1〉||^{2})), y : (1 / sqrt(2)) * sqrt(2), z : 1
# 38	instantiation	56, 57	{t in NaturalPos} |- |(2, 2, ..(t - 3) ×.., 2)| = (0 - (-t + 1) + 1)
# 	f(_a) : 2, i : -t + 1, j : 0
# 39	instantiation	290	|- |(0, -(-t + 1))| = |(1, ..., 2)|
# 	a : 0, b : -(-t + 1)
# 40	instantiation	52, 320, 53, 54, 55	{t in NaturalPos} |- (2, 2, ..(t - 3) ×.., 2) = (2, 2, ..(t - 3) ×.., 2)
# 	f(_a) : 2, a : -t, i : -t + 1, j : 0, k : 1, l : t
# 41	instantiation	56, 57	{t in NaturalPos} |- |(Complex^{2}, Complex^{2}, ..(t - 3) ×.., Complex^{2})| = (0 - (-t + 1) + 1)
# 	f(_a) : Complex^{2}, i : -t + 1, j : 0
# 42	instantiation	56, 57	{t in NaturalPos} |- |(((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 1)} * phase} * |1〉))), ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-(-t + 2)} * phase} * |1〉))), ..., ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-0} * phase} * |1〉))))| = (0 - (-t + 1) + 1)
# 	f(_a) : (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)), i : -t + 1, j : 0
# 43	instantiation	253, 58, 59	{t in NaturalPos} |- (0 - (-t + 1) + 1) = t
# 	x : 0 - (-t + 1) + 1, y : 0 + (t - 1) + 1, z : t
# 44	instantiation	60, 61	{t in NaturalPos} |- |(1, 2, ..., t)| = t
# 	i : t, f(_a) : _a
# 45	conjecture		|- forall_{i, j in Integer} [forall_{P | i <= (j + 1)} ([forall_{k in {i .. j}} P(k)] => (P(i) and  P(i + 1) and  ... and  P(j)))]
# 	proveit.logic.booleans.conjunction.conjunction_from_quantification
# 46	instantiation	178, 62, 63, 223, 64, 65*, 66*	{t in NaturalPos} |- (-t + 1) <= (0 + 1)
# 	a : -t + 1, x : 0, y : t
# 47	instantiation	129, 130, 67, 68	{t in NaturalPos, _a in {-t + 1 .. 0}} |- ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉))) in Complex^{2}
# 	K : Complex, V : Complex^{2}, a : 1 / sqrt(2), x : |0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)
# 48	instantiation	69, 70	|- |1 / sqrt(2)| = (1 / sqrt(2))
# 	x : 1 / sqrt(2)
# 49	instantiation	71, 130, 135, 97, 72, 73*	{t in NaturalPos, _a in {-t + 1 .. 0}} |- |||0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)|| = sqrt((|||0〉||^{2} + |||1〉||^{2}))
# 	K : Complex, V : Complex^{2}, a : |0〉, b : e^{2 * pi * i * 2^{-_a} * phase} * |1〉
# 50	instantiation	235, 74	|- ((1 / sqrt(2)) * sqrt((|||0〉||^{2} + |||1〉||^{2}))) = ((1 / sqrt(2)) * sqrt(2))
# 	f(_b) : (1 / sqrt(2)) * _b, x : sqrt((|||0〉||^{2} + |||1〉||^{2})), y : sqrt(2)
# 51	instantiation	261, 75, 76	|- ((1 / sqrt(2)) * sqrt(2)) = 1
# 	P(_b) : ((1 / sqrt(2)) * sqrt(2)) = _b, x : (1 / 1) * (1 / 1), y : 1
# 52	conjecture		|- forall_{f} [forall_{a in Integer} [forall_{i, j, k, l | ((j + 1) - i) in Natural, k = (i - a), l = (j - a)} ((f(i), f(i + 1), ..., f(j)) = (f(k + a), f((k + 1) + a), ..., f(l + a)))]]
# 	proveit.core_expr_types.tuples.shift_equivalence
# 53	instantiation	77, 78, 83	{t in NaturalPos} |- ((0 + 1) - (-t + 1)) in Natural
# 	a : 0 + 1, b : -(-t + 1)
# 54	instantiation	211, 79	{t in NaturalPos} |- 1 = ((-t + 1) - (-t))
# 	x : (-t + 1) - (-t), y : 1
# 55	instantiation	211, 80	{t in NaturalPos} |- t = (0 - (-t))
# 	x : 0 - (-t), y : t
# 56	conjecture		|- forall_{f, i, j | (j - i + 1) in Natural} (|(f(i), f(i + 1), ..., f(j))| = (j - i + 1))
# 	proveit.core_expr_types.tuples.range_len
# 57	instantiation	81, 265, 82, 278, 83, 325	{t in NaturalPos} |- (0 - (-t + 1) + 1) in Natural
# 	i : 3, a : (0, -(-t + 1), 1)
# 58	instantiation	235, 84	{t in NaturalPos} |- (0 - (-t + 1) + 1) = (0 + (t - 1) + 1)
# 	f(_a) : 0 + _a + 1, x : -(-t + 1), y : t - 1
# 59	instantiation	107, 85, 86, 87	{t in NaturalPos} |- (0 + (t - 1) + 1) = t
# 	a : 0 + (t - 1) + 1, b : 0 + t - 1 + 1, c : t - 1 + 1, d : t
# 60	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), f(2), ..., f(i))| = i)]
# 	proveit.core_expr_types.tuples.range_from1_len
# 61	instantiation	326, 111, 328	{t in NaturalPos} |- t in Natural
# 	A : NaturalPos, B : Natural, x : t
# 62	instantiation	326, 309, 88	{t in NaturalPos} |- (-t + 1) in Real
# 	A : Rational, B : Real, x : -t + 1
# 63	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 64	instantiation	89, 90	{t in NaturalPos} |- 0 <= t
# 	x : 0, y : t
# 65	instantiation	253, 91, 92	{t in NaturalPos} |- (0 + (-t + 1)) = (-t + 1)
# 	x : 0 + (-t + 1), y : 0 - t + 1, z : -t + 1
# 66	instantiation	107, 93, 123, 94	{t in NaturalPos} |- (t + (-t + 1)) = (0 + 1)
# 	a : t + (-t + 1), b : 1, c : 1, d : 0 + 1
# 67	instantiation	326, 306, 95	|- (1 / sqrt(2)) in Complex
# 	A : Real, B : Complex, x : 1 / sqrt(2)
# 68	instantiation	96, 130, 135, 97	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (|0〉 + (e^{2 * pi * i * 2^{-_a} * phase} * |1〉)) in Complex^{2}
# 	K : Complex, V : Complex^{2}, x : |0〉, y : e^{2 * pi * i * 2^{-_a} * phase} * |1〉
# 69	conjecture		|- forall_{x | x >= 0} (|x| = x)
# 	proveit.numbers.absolute_value.abs_non_neg_elim
# 70	instantiation	98, 99	|- 0 <= (1 / sqrt(2))
# 	x : 1 / sqrt(2)
# 71	conjecture		|- forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a, b in V | <a, b> = 0} (||a + b|| = sqrt((||a||^{2} + ||b||^{2})))]]
# 	proveit.linear_algebra.addition.norm_of_sum_of_orthogonal_pair
# 72	instantiation	261, 100, 101	{t in NaturalPos, _a in {-t + 1 .. 0}} |- <|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉> = 0
# 	P(_b) : <|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉> = _b, x : e^{2 * pi * i * 2^{-_a} * phase} * <|0〉, |1〉>, y : 0
# 73	instantiation	102, 134, 186, 136, 103*	{t in NaturalPos, _a in {-t + 1 .. 0}} |- ||e^{2 * pi * i * 2^{-_a} * phase} * |1〉|| = |||1〉||
# 	K : Complex, H : Complex^{2}, alpha : e^{2 * pi * i * 2^{-_a} * phase}, x : |1〉
# 74	instantiation	235, 104	|- sqrt((|||0〉||^{2} + |||1〉||^{2})) = sqrt(2)
# 	f(_b) : sqrt(_b), x : |||0〉||^{2} + |||1〉||^{2}, y : 2
# 75	instantiation	261, 105, 106	|- ((1 / sqrt(2)) * sqrt(2)) = ((1 / 1) * (1 / 1))
# 	P(_b) : _b = ((1 / 1) * (1 / 1)), x : (1 / (1 * sqrt(2))) * ((sqrt(2) * 1) / 1), y : (1 / sqrt(2)) * sqrt(2)
# 76	instantiation	107, 108, 109, 110	|- ((1 / 1) * (1 / 1)) = 1
# 	a : (1 / 1) * (1 / 1), b : 1 * (1 / 1), c : 1 * 1, d : 1
# 77	conjecture		|- forall_{a, b in Natural} ((a + b) in Natural)
# 	proveit.numbers.addition.add_nat_closure_bin
# 78	instantiation	326, 111, 112	|- (0 + 1) in Natural
# 	A : NaturalPos, B : Natural, x : 0 + 1
# 79	instantiation	253, 113, 114	{t in NaturalPos} |- ((-t + 1) - (-t)) = 1
# 	x : (-t + 1) - (-t), y : (-t + 1) + t, z : 1
# 80	instantiation	253, 115, 116	{t in NaturalPos} |- (0 - (-t)) = t
# 	x : 0 - (-t), y : 0 + t, z : t
# 81	conjecture		|- forall_{i in Natural} [forall_{a_{1}, a_{2}, ..., a_{i} in Natural} ((a_{1} +  a_{2} +  ... +  a_{i}) in Natural)]
# 	proveit.numbers.addition.add_nat_closure
# 82	instantiation	283	|- |(0, -(-t + 1), 1)| = |(1, 2, ..., 3)|
# 	a : 0, b : -(-t + 1), c : 1
# 83	instantiation	284, 117	{t in NaturalPos} |- (-(-t + 1)) in Natural
# 	a : -t + 1
# 84	instantiation	118, 201, 200, 153*	{t in NaturalPos} |- (-(-t + 1)) = (t - 1)
# 	a : -t, b : 1
# 85	instantiation	174, 325, 311, 119, 164, 203, 121, 200	{t in NaturalPos} |- (0 + (t - 1) + 1) =  \\ (0 + t - 1 + 1)
# 	i : 1, j : 2, k : 1, a : (0), b : (t, -1), c : (1)
# 86	instantiation	125, 278, 265, 279, 120, 203, 121, 200	{t in NaturalPos} |- (0 + t - 1 + 1) = (t - 1 + 1)
# 	i : 0, j : 3, a : (), b : (t, -1, 1)
# 87	instantiation	122, 200, 203, 123	{t in NaturalPos} |- (t - 1 + 1) = t
# 	a : 1, b : 1, c : t
# 88	instantiation	326, 312, 317	{t in NaturalPos} |- (-t + 1) in Rational
# 	A : Integer, B : Rational, x : -t + 1
# 89	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 90	instantiation	124, 328	{t in NaturalPos} |- t > 0
# 	n : t
# 91	instantiation	174, 325, 311, 278, 175, 279, 164, 201, 200	{t in NaturalPos} |- (0 + (-t + 1)) =  \\ (0 - t + 1)
# 	i : 1, j : 2, k : 0, a : (0), b : (-t, 1), c : ()
# 92	instantiation	125, 278, 311, 279, 175, 201, 200	{t in NaturalPos} |- (0 - t + 1) = (-t + 1)
# 	i : 0, j : 2, a : (), b : (-t, 1)
# 93	instantiation	253, 126, 127	{t in NaturalPos} |- (t + (-t + 1)) = 1
# 	x : t + (-t + 1), y : t - t + 1, z : 1
# 94	instantiation	211, 128	|- 1 = (0 + 1)
# 	x : 0 + 1, y : 1
# 95	instantiation	326, 299, 132	|- (1 / sqrt(2)) in Real
# 	A : RealPos, B : Real, x : 1 / sqrt(2)
# 96	conjecture		|- forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{x, y in V} ((x + y) in V)]]
# 	proveit.linear_algebra.addition.binary_closure
# 97	instantiation	129, 130, 186, 136	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (e^{2 * pi * i * 2^{-_a} * phase} * |1〉) in Complex^{2}
# 	K : Complex, V : Complex^{2}, a : e^{2 * pi * i * 2^{-_a} * phase}, x : |1〉
# 98	conjecture		|- forall_{x in RealNonNeg} (x >= 0)
# 	proveit.numbers.number_sets.real_numbers.nonneg_if_in_real_nonneg
# 99	instantiation	326, 131, 132	|- (1 / sqrt(2)) in RealNonNeg
# 	A : RealPos, B : RealNonNeg, x : 1 / sqrt(2)
# 100	instantiation	133, 134, 186, 135, 136	{t in NaturalPos, _a in {-t + 1 .. 0}} |- <|0〉, e^{2 * pi * i * 2^{-_a} * phase} * |1〉> = (e^{2 * pi * i * 2^{-_a} * phase} * <|0〉, |1〉>)
# 	K : Complex, H : Complex^{2}, a : e^{2 * pi * i * 2^{-_a} * phase}, x : |0〉, y : |1〉
# 101	instantiation	253, 137, 138	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (e^{2 * pi * i * 2^{-_a} * phase} * <|0〉, |1〉>) = 0
# 	x : e^{2 * pi * i * 2^{-_a} * phase} * <|0〉, |1〉>, y : e^{2 * pi * i * 2^{-_a} * phase} * 0, z : 0
# 102	conjecture		|- forall_{K} [forall_{H in_c InnerProdSpaces(K)} [forall_{alpha in K, x in H} (||alpha * x|| = (|alpha| * ||x||))]]
# 	proveit.linear_algebra.inner_products.scaled_norm
# 103	instantiation	253, 139, 140	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (|e^{2 * pi * i * 2^{-_a} * phase}| * |||1〉||) = |||1〉||
# 	x : |e^{2 * pi * i * 2^{-_a} * phase}| * |||1〉||, y : 1 * |||1〉||, z : |||1〉||
# 104	instantiation	253, 141, 142	|- (|||0〉||^{2} + |||1〉||^{2}) = 2
# 	x : |||0〉||^{2} + |||1〉||^{2}, y : 1 + 1, z : 2
# 105	instantiation	143, 200, 144, 145	|- ((1 / (1 * sqrt(2))) * ((sqrt(2) * 1) / 1)) = ((1 / 1) * (1 / 1))
# 	a : 1, d : 1, b : 1, c : sqrt(2), e : 1
# 106	instantiation	253, 146, 147	|- ((1 / (1 * sqrt(2))) * ((sqrt(2) * 1) / 1)) = ((1 / sqrt(2)) * sqrt(2))
# 	x : (1 / (1 * sqrt(2))) * ((sqrt(2) * 1) / 1), y : (1 / sqrt(2)) * ((sqrt(2) * 1) / 1), z : (1 / sqrt(2)) * sqrt(2)
# 107	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 108	instantiation	235, 148	|- ((1 / 1) * (1 / 1)) = (1 * (1 / 1))
# 	f(_b) : _b * (1 / 1), x : 1 / 1, y : 1
# 109	instantiation	235, 148	|- (1 * (1 / 1)) = (1 * 1)
# 	f(_b) : 1 * _b, x : 1 / 1, y : 1
# 110	instantiation	240, 200	|- (1 * 1) = 1
# 	x : 1
# 111	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 112	instantiation	149, 325, 278, 279, 150	|- (0 + 1) in NaturalPos
# 	i : 1, j : 0, a : (0), b : 1, c : ()
# 113	instantiation	235, 153	{t in NaturalPos} |- ((-t + 1) - (-t)) = ((-t + 1) + t)
# 	f(_a) : (-t + 1) + _a, x : -(-t), y : t
# 114	instantiation	253, 151, 152	{t in NaturalPos} |- ((-t + 1) + t) = 1
# 	x : (-t + 1) + t, y : -t + 1 + t, z : 1
# 115	instantiation	235, 153	{t in NaturalPos} |- (0 - (-t)) = (0 + t)
# 	f(_a) : 0 + _a, x : -(-t), y : t
# 116	instantiation	156, 203	{t in NaturalPos} |- (0 + t) = t
# 	a : t
# 117	instantiation	294, 317, 154	{t in NaturalPos} |- (-t + 1) in IntegerNonPos
# 	a : -t + 1
# 118	conjecture		|- forall_{a, b in Complex} ((-(a + b)) = (-a - b))
# 	proveit.numbers.negation.distribute_neg_through_binary_sum
# 119	instantiation	290	|- |(t, -1)| = |(1, ..., 2)|
# 	a : t, b : -1
# 120	instantiation	283	|- |(t, -1, 1)| = |(1, 2, ..., 3)|
# 	a : t, b : -1, c : 1
# 121	instantiation	303, 200	|- (-1) in Complex
# 	a : 1
# 122	conjecture		|- forall_{a, b, c in Complex | a = b} ((c - a + b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_32
# 123	instantiation	224	|- 1 = 1
# 	x : 1
# 124	conjecture		|- forall_{n in NaturalPos} (n > 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_is_pos
# 125	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}) = (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}))]
# 	proveit.numbers.addition.elim_zero_any
# 126	instantiation	174, 325, 311, 278, 175, 279, 203, 201, 200	{t in NaturalPos} |- (t + (-t + 1)) =  \\ (t - t + 1)
# 	i : 1, j : 2, k : 0, a : (t), b : (-t, 1), c : ()
# 127	instantiation	155, 203, 200, 204	{t in NaturalPos} |- (t - t + 1) = 1
# 	a : t, b : t, c : 1
# 128	instantiation	156, 200	|- (0 + 1) = 1
# 	a : 1
# 129	conjecture		|- forall_{K} [forall_{V in_c VecSpaces(K)} [forall_{a in K} [forall_{x in V} ((a * x) in V)]]]
# 	proveit.linear_algebra.scalar_multiplication.scalar_mult_closure
# 130	instantiation	157, 260	|- Complex^{2} in_c VecSpaces(Complex)
# 	n : 2
# 131	conjecture		|- RealPos proper_subset RealNonNeg
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real_nonneg
# 132	instantiation	158, 159, 206, 160	|- (1 / sqrt(2)) in RealPos
# 	a : 1, b : sqrt(2)
# 133	conjecture		|- forall_{K} [forall_{H in_c InnerProdSpaces(K)} [forall_{a in K} [forall_{x, y in H} (<x, a * y> = (a * <x, y>))]]]
# 	proveit.linear_algebra.inner_products.inner_prod_scalar_mult_right
# 134	instantiation	161, 260	|- Complex^{2} in_c InnerProdSpaces(Complex)
# 	n : 2
# 135	conjecture		|- |0〉 in Complex^{2}
# 	proveit.physics.quantum.algebra.ket_zero_in_qubit_space
# 136	conjecture		|- |1〉 in Complex^{2}
# 	proveit.physics.quantum.algebra.ket_one_in_qubit_space
# 137	instantiation	235, 162	|- (e^{2 * pi * i * 2^{-_a} * phase} * <|0〉, |1〉>) = (e^{2 * pi * i * 2^{-_a} * phase} * 0)
# 	f(_b) : e^{2 * pi * i * 2^{-_a} * phase} * _b, x : <|0〉, |1〉>, y : 0
# 138	instantiation	163, 186, 164, 165*	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (e^{2 * pi * i * 2^{-_a} * phase} * 0) = 0
# 	a : e^{2 * pi * i * 2^{-_a} * phase}, b : 0
# 139	instantiation	235, 166	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (|e^{2 * pi * i * 2^{-_a} * phase}| * |||1〉||) = (1 * |||1〉||)
# 	f(_b) : _b * |||1〉||, x : |e^{2 * pi * i * 2^{-_a} * phase}|, y : 1
# 140	instantiation	218, 167	|- (1 * |||1〉||) = |||1〉||
# 	x : |||1〉||
# 141	instantiation	253, 168, 169	|- (|||0〉||^{2} + |||1〉||^{2}) = (1 + 1)
# 	x : |||0〉||^{2} + |||1〉||^{2}, y : 1 + |||1〉||^{2}, z : 1 + 1
# 142	conjecture		|- (1 + 1) = 2
# 	proveit.numbers.numerals.decimals.add_1_1
# 143	conjecture		|- forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} (((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)))]
# 	proveit.numbers.division.mult_frac_cancel_denom_left
# 144	instantiation	326, 171, 170	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 145	instantiation	326, 171, 184	|- sqrt(2) in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : sqrt(2)
# 146	instantiation	235, 172	|- ((1 / (1 * sqrt(2))) * ((sqrt(2) * 1) / 1)) = ((1 / sqrt(2)) * ((sqrt(2) * 1) / 1))
# 	f(_b) : _b * ((sqrt(2) * 1) / 1), x : 1 / (1 * sqrt(2)), y : 1 / sqrt(2)
# 147	instantiation	235, 173	|- ((1 / sqrt(2)) * ((sqrt(2) * 1) / 1)) = ((1 / sqrt(2)) * sqrt(2))
# 	f(_b) : (1 / sqrt(2)) * _b, x : (sqrt(2) * 1) / 1, y : sqrt(2)
# 148	instantiation	220, 200	|- (1 / 1) = 1
# 	x : 1
# 149	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j} in Natural | b > 0} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) in NaturalPos)]
# 	proveit.numbers.addition.add_nat_pos_from_nonneg
# 150	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 151	instantiation	174, 278, 311, 325, 279, 175, 201, 200, 203	{t in NaturalPos} |- ((-t + 1) + t) =  \\ (-t + 1 + t)
# 	i : 0, j : 2, k : 1, a : (), b : (-t, 1), c : (t)
# 152	instantiation	176, 203, 200, 204	{t in NaturalPos} |- (-t + 1 + t) = 1
# 	a : t, b : t, c : 1
# 153	instantiation	177, 203	{t in NaturalPos} |- (-(-t)) = t
# 	x : t
# 154	instantiation	178, 222, 221, 223, 179, 180*, 181*	{t in NaturalPos} |- (-t + 1) <= 0
# 	a : -t, x : 1, y : t
# 155	conjecture		|- forall_{a, b, c in Complex | a = b} ((a - b + c) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_12
# 156	conjecture		|- forall_{a in Complex} ((0 + a) = a)
# 	proveit.numbers.addition.elim_zero_left
# 157	conjecture		|- forall_{n in NaturalPos} (Complex^{n} in_c VecSpaces(Complex))
# 	proveit.linear_algebra.complex_vec_set_is_vec_space
# 158	conjecture		|- forall_{a, b in RealPos | b != 0} ((a / b) in RealPos)
# 	proveit.numbers.division.div_real_pos_closure
# 159	instantiation	326, 246, 182	|- 1 in RealPos
# 	A : RationalPos, B : RealPos, x : 1
# 160	instantiation	183, 184	|- sqrt(2) != 0
# 	x : sqrt(2)
# 161	conjecture		|- forall_{n in NaturalPos} (Complex^{n} in_c InnerProdSpaces(Complex))
# 	proveit.linear_algebra.inner_products.complex_vec_set_is_inner_prod_space
# 162	conjecture		|- <|0〉, |1〉> = 0
# 	proveit.physics.quantum.algebra.ket_zero_and_one_have_zero_inner_prod
# 163	axiom		|- forall_{a, b in Complex} ((a * b) = (a * b))
# 	proveit.linear_algebra.scalar_multiplication.scalar_mult_extends_number_mult
# 164	conjecture		|- 0 in Complex
# 	proveit.numbers.number_sets.complex_numbers.zero_is_complex
# 165	instantiation	185, 186	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (e^{2 * pi * i * 2^{-_a} * phase} * 0) = 0
# 	x : e^{2 * pi * i * 2^{-_a} * phase}
# 166	instantiation	187, 188, 189*	{t in NaturalPos, _a in {-t + 1 .. 0}} |- |e^{2 * pi * i * 2^{-_a} * phase}| = 1
# 	theta : 2 * pi * 2^{-_a} * phase
# 167	instantiation	190, 200, 236	|- |||1〉|| in Complex
# 	P(_b) : _b in Complex, x : |||1〉||, y : 1
# 168	instantiation	235, 191	|- (|||0〉||^{2} + |||1〉||^{2}) = (1 + |||1〉||^{2})
# 	f(_b) : _b + |||1〉||^{2}, x : |||0〉||^{2}, y : 1
# 169	instantiation	235, 192	|- (1 + |||1〉||^{2}) = (1 + 1)
# 	f(_b) : 1 + _b, x : |||1〉||^{2}, y : 1
# 170	instantiation	326, 193, 194	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 171	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 172	instantiation	235, 195	|- (1 / (1 * sqrt(2))) = (1 / sqrt(2))
# 	f(_b) : 1 / _b, x : 1 * sqrt(2), y : sqrt(2)
# 173	instantiation	253, 196, 197	|- ((sqrt(2) * 1) / 1) = sqrt(2)
# 	x : (sqrt(2) * 1) / 1, y : sqrt(2) / 1, z : sqrt(2)
# 174	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 175	instantiation	290	|- |(-t, 1)| = |(1, ..., 2)|
# 	a : -t, b : 1
# 176	conjecture		|- forall_{a, b, c in Complex | a = b} ((-a + c + b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_31
# 177	conjecture		|- forall_{x in Complex} ((-(-x)) = x)
# 	proveit.numbers.negation.double_negation
# 178	conjecture		|- forall_{a, x, y in Real | x <= y} ((x + a) <= (y + a))
# 	proveit.numbers.addition.weak_bound_via_left_term_bound
# 179	instantiation	198, 328	{t in NaturalPos} |- t >= 1
# 	n : t
# 180	instantiation	199, 200, 201	{t in NaturalPos} |- (1 - t) = (-t + 1)
# 	a : 1, b : -t
# 181	instantiation	202, 203, 204	{t in NaturalPos} |- (t - t) = 0
# 	a : t, b : t
# 182	instantiation	326, 259, 239	|- 1 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 1
# 183	conjecture		|- forall_{x in RealNonZero} (x != 0)
# 	proveit.numbers.number_sets.real_numbers.nonzero_if_in_real_nonzero
# 184	instantiation	326, 205, 206	|- sqrt(2) in RealNonZero
# 	A : RealPos, B : RealNonZero, x : sqrt(2)
# 185	conjecture		|- forall_{x in Complex} ((x * 0) = 0)
# 	proveit.numbers.multiplication.mult_zero_right
# 186	instantiation	296, 207, 208	{t in NaturalPos, _a in {-t + 1 .. 0}} |- e^{2 * pi * i * 2^{-_a} * phase} in Complex
# 	a : e, b : 2 * pi * i * 2^{-_a} * phase
# 187	conjecture		|- forall_{theta in Real} (|e^{i * theta}| = 1)
# 	proveit.numbers.absolute_value.complex_unit_length
# 188	instantiation	261, 209, 210	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (2 * pi * 2^{-_a} * phase) in Real
# 	P(_b) : _b in Real, x : (2 * pi) * (2^{-_a} * phase), y : 2 * pi * 2^{-_a} * phase
# 189	instantiation	211, 212	{t in NaturalPos, _a in {-t + 1 .. 0}} |- e^{i * (2 * pi * 2^{-_a} * phase)} = e^{2 * pi * i * 2^{-_a} * phase}
# 	x : e^{2 * pi * i * 2^{-_a} * phase}, y : e^{i * (2 * pi * 2^{-_a} * phase)}
# 190	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 191	instantiation	253, 213, 215	|- |||0〉||^{2} = 1
# 	x : |||0〉||^{2}, y : 1^{2}, z : 1
# 192	instantiation	253, 214, 215	|- |||1〉||^{2} = 1
# 	x : |||1〉||^{2}, y : 1^{2}, z : 1
# 193	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 194	instantiation	326, 216, 217	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 195	instantiation	218, 241	|- (1 * sqrt(2)) = sqrt(2)
# 	x : sqrt(2)
# 196	instantiation	235, 219	|- ((sqrt(2) * 1) / 1) = (sqrt(2) / 1)
# 	f(_b) : _b / 1, x : sqrt(2) * 1, y : sqrt(2)
# 197	instantiation	220, 241	|- (sqrt(2) / 1) = sqrt(2)
# 	x : sqrt(2)
# 198	conjecture		|- forall_{n in NaturalPos} (n >= 1)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_lower_bound
# 199	conjecture		|- forall_{a, b in Complex} ((a + b) = (b + a))
# 	proveit.numbers.addition.commutation
# 200	instantiation	326, 306, 221	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 201	instantiation	326, 306, 222	{t in NaturalPos} |- (-t) in Complex
# 	A : Real, B : Complex, x : -t
# 202	conjecture		|- forall_{a, b in Complex | a = b} ((a - b) = 0)
# 	proveit.numbers.addition.subtraction.add_cancel_basic
# 203	instantiation	326, 306, 223	{t in NaturalPos} |- t in Complex
# 	A : Real, B : Complex, x : t
# 204	instantiation	224	|- t = t
# 	x : t
# 205	conjecture		|- RealPos proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real_nonzero
# 206	instantiation	225, 226	|- sqrt(2) in RealPos
# 	a : 2
# 207	instantiation	326, 306, 227	|- e in Complex
# 	A : Real, B : Complex, x : e
# 208	instantiation	261, 228, 229	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (2 * pi * i * 2^{-_a} * phase) in Complex
# 	P(_b) : _b in Complex, x : (2 * pi) * (i * 2^{-_a} * phase), y : 2 * pi * i * 2^{-_a} * phase
# 209	instantiation	292, 282, 230	{t in NaturalPos, _a in {-t + 1 .. 0}} |- ((2 * pi) * (2^{-_a} * phase)) in Real
# 	a : 2 * pi, b : 2^{-_a} * phase
# 210	instantiation	253, 231, 232	{t in NaturalPos, _a in {-t + 1 .. 0}} |- ((2 * pi) * (2^{-_a} * phase)) = (2 * pi * 2^{-_a} * phase)
# 	x : (2 * pi) * (2^{-_a} * phase), y : (2 * pi) * 2^{-_a} * phase, z : 2 * pi * 2^{-_a} * phase
# 211	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 212	instantiation	235, 233	{t in NaturalPos, _a in {-t + 1 .. 0}} |- e^{2 * pi * i * 2^{-_a} * phase} = e^{i * (2 * pi * 2^{-_a} * phase)}
# 	f(_b) : e^{_b}, x : 2 * pi * i * 2^{-_a} * phase, y : i * (2 * pi * 2^{-_a} * phase)
# 213	instantiation	235, 234	|- |||0〉||^{2} = 1^{2}
# 	f(_b) : _b^{2}, x : |||0〉||, y : 1
# 214	instantiation	235, 236	|- |||1〉||^{2} = 1^{2}
# 	f(_b) : _b^{2}, x : |||1〉||, y : 1
# 215	instantiation	237, 297	|- 1^{2} = 1
# 	x : 2
# 216	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 217	instantiation	326, 238, 239	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 218	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 219	instantiation	240, 241	|- (sqrt(2) * 1) = sqrt(2)
# 	x : sqrt(2)
# 220	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 221	instantiation	326, 309, 242	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 222	instantiation	326, 309, 243	{t in NaturalPos} |- (-t) in Real
# 	A : Rational, B : Real, x : -t
# 223	instantiation	244, 245, 328	{t in NaturalPos} |- t in Real
# 	A : NaturalPos, B : Real, x : t
# 224	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 225	conjecture		|- forall_{a in RealPos} (sqrt(a) in RealPos)
# 	proveit.numbers.exponentiation.sqrt_real_pos_closure
# 226	instantiation	326, 246, 247	|- 2 in RealPos
# 	A : RationalPos, B : RealPos, x : 2
# 227	instantiation	326, 299, 248	|- e in Real
# 	A : RealPos, B : Real, x : e
# 228	instantiation	287, 264, 249	{t in NaturalPos, _a in {-t + 1 .. 0}} |- ((2 * pi) * (i * 2^{-_a} * phase)) in Complex
# 	a : 2 * pi, b : i * 2^{-_a} * phase
# 229	instantiation	253, 250, 251	{t in NaturalPos, _a in {-t + 1 .. 0}} |- ((2 * pi) * (i * 2^{-_a} * phase)) = (2 * pi * i * 2^{-_a} * phase)
# 	x : (2 * pi) * (i * 2^{-_a} * phase), y : (2 * pi) * i * 2^{-_a} * phase, z : 2 * pi * i * 2^{-_a} * phase
# 230	instantiation	292, 252, 291	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (2^{-_a} * phase) in Real
# 	a : 2^{-_a}, b : phase
# 231	instantiation	277, 325, 311, 278, 271, 279, 264, 289, 281	{t in NaturalPos, _a in {-t + 1 .. 0}} |- ((2 * pi) * (2^{-_a} * phase)) =  \\ ((2 * pi) * 2^{-_a} * phase)
# 	i : 1, j : 2, k : 0, a : (2 * pi), b : (2^{-_a}, phase), c : ()
# 232	instantiation	277, 278, 311, 279, 270, 271, 297, 275, 289, 281	{t in NaturalPos, _a in {-t + 1 .. 0}} |- ((2 * pi) * 2^{-_a} * phase) =  \\ (2 * pi * 2^{-_a} * phase)
# 	i : 0, j : 2, k : 2, a : (), b : (2, pi), c : (2^{-_a}, phase)
# 233	instantiation	253, 254, 255	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (2 * pi * i * 2^{-_a} * phase) = (i * (2 * pi * 2^{-_a} * phase))
# 	x : 2 * pi * i * 2^{-_a} * phase, y : i * 2 * pi * 2^{-_a} * phase, z : i * (2 * pi * 2^{-_a} * phase)
# 234	conjecture		|- |||0〉|| = 1
# 	proveit.physics.quantum.algebra.ket_zero_norm
# 235	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 236	conjecture		|- |||1〉|| = 1
# 	proveit.physics.quantum.algebra.ket_one_norm
# 237	conjecture		|- forall_{x in Complex} (1^{x} = 1)
# 	proveit.numbers.exponentiation.exponentiated_one
# 238	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 239	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 240	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 241	instantiation	256, 297	|- sqrt(2) in Complex
# 	a : 2
# 242	instantiation	326, 312, 321	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 243	instantiation	326, 312, 320	{t in NaturalPos} |- (-t) in Rational
# 	A : Integer, B : Rational, x : -t
# 244	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 245	instantiation	257, 258	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 246	conjecture		|- RationalPos proper_subset RealPos
# 	proveit.numbers.number_sets.real_numbers.rational_pos_within_real_pos
# 247	instantiation	326, 259, 260	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 248	conjecture		|- e in RealPos
# 	proveit.numbers.number_sets.real_numbers.e_is_real_pos
# 249	instantiation	261, 262, 263	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (i * 2^{-_a} * phase) in Complex
# 	P(_b) : _b in Complex, x : (i * 2^{-_a}) * phase, y : i * 2^{-_a} * phase
# 250	instantiation	277, 325, 265, 278, 266, 279, 264, 288, 289, 281	{t in NaturalPos, _a in {-t + 1 .. 0}} |- ((2 * pi) * (i * 2^{-_a} * phase)) =  \\ ((2 * pi) * i * 2^{-_a} * phase)
# 	i : 1, j : 3, k : 0, a : (2 * pi), b : (i, 2^{-_a}, phase), c : ()
# 251	instantiation	277, 278, 311, 265, 279, 270, 266, 297, 275, 288, 289, 281	{t in NaturalPos, _a in {-t + 1 .. 0}} |- ((2 * pi) * i * 2^{-_a} * phase) =  \\ (2 * pi * i * 2^{-_a} * phase)
# 	i : 0, j : 2, k : 3, a : (), b : (2, pi), c : (i, 2^{-_a}, phase)
# 252	instantiation	267, 302, 268	{t in NaturalPos, _a in {-t + 1 .. 0}} |- 2^{-_a} in Real
# 	a : 2, b : -_a
# 253	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 254	instantiation	269, 278, 311, 279, 270, 271, 297, 275, 288, 289, 281	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (2 * pi * i * 2^{-_a} * phase) =  \\ (i * 2 * pi * 2^{-_a} * phase)
# 	i : 0, j : 2, k : 2, a : (), b : (2, pi), c : i, d : (2^{-_a}, phase)
# 255	instantiation	272, 325, 273, 278, 274, 279, 288, 297, 275, 289, 281	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (i * 2 * pi * 2^{-_a} * phase) =  \\ (i * (2 * pi * 2^{-_a} * phase))
# 	i : 1, j : 4, k : 0, a : (i), b : (2, pi, 2^{-_a}, phase), c : ()
# 256	conjecture		|- forall_{a in Complex} (sqrt(a) in Complex)
# 	proveit.numbers.exponentiation.sqrt_complex_closure
# 257	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 258	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 259	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 260	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 261	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 262	instantiation	287, 276, 281	{t in NaturalPos, _a in {-t + 1 .. 0}} |- ((i * 2^{-_a}) * phase) in Complex
# 	a : i * 2^{-_a}, b : phase
# 263	instantiation	277, 278, 311, 325, 279, 280, 288, 289, 281	{t in NaturalPos, _a in {-t + 1 .. 0}} |- ((i * 2^{-_a}) * phase) =  \\ (i * 2^{-_a} * phase)
# 	i : 0, j : 2, k : 1, a : (), b : (i, 2^{-_a}), c : (phase)
# 264	instantiation	326, 306, 282	|- (2 * pi) in Complex
# 	A : Real, B : Complex, x : 2 * pi
# 265	conjecture		|- 3 in Natural
# 	proveit.numbers.numerals.decimals.nat3
# 266	instantiation	283	|- |(i, 2^{-_a}, phase)| = |(1, 2, ..., 3)|
# 	a : i, b : 2^{-_a}, c : phase
# 267	conjecture		|- forall_{a in Real, b in Natural} (a^{b} in Real)
# 	proveit.numbers.exponentiation.exp_real_closure_nat_power
# 268	instantiation	284, 285	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (-_a) in Natural
# 	a : _a
# 269	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j} * c* d_{1} *  d_{2} *  ... *  d_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i} * c* b_{1} *  b_{2} *  ... *  b_{j}* d_{1} *  d_{2} *  ... *  d_{k}))]
# 	proveit.numbers.multiplication.leftward_commutation
# 270	instantiation	290	|- |(2, pi)| = |(1, ..., 2)|
# 	a : 2, b : pi
# 271	instantiation	290	|- |(2^{-_a}, phase)| = |(1, ..., 2)|
# 	a : 2^{-_a}, b : phase
# 272	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} *  b_{2} *  ... *  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}))]
# 	proveit.numbers.multiplication.association
# 273	conjecture		|- 4 in Natural
# 	proveit.numbers.numerals.decimals.nat4
# 274	instantiation	286	|- |(2, pi, 2^{-_a}, phase)| = |(1, 2, ..., 4)|
# 	a : 2, b : pi, c : 2^{-_a}, d : phase
# 275	instantiation	326, 306, 293	|- pi in Complex
# 	A : Real, B : Complex, x : pi
# 276	instantiation	287, 288, 289	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (i * 2^{-_a}) in Complex
# 	a : i, b : 2^{-_a}
# 277	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} *  b_{2} *  ... *  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}* c_{1} *  c_{2} *  ... *  c_{k}))]
# 	proveit.numbers.multiplication.disassociation
# 278	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 279	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 280	instantiation	290	|- |(i, 2^{-_a})| = |(1, ..., 2)|
# 	a : i, b : 2^{-_a}
# 281	instantiation	326, 306, 291	|- phase in Complex
# 	A : Real, B : Complex, x : phase
# 282	instantiation	292, 302, 293	|- (2 * pi) in Real
# 	a : 2, b : pi
# 283	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, 2, ..., 3)|)
# 	proveit.numbers.numerals.decimals.tuple_len_3_typical_eq
# 284	conjecture		|- forall_{a in IntegerNonPos} ((-a) in Natural)
# 	proveit.numbers.negation.nat_closure
# 285	instantiation	294, 313, 295	{t in NaturalPos, _a in {-t + 1 .. 0}} |- _a in IntegerNonPos
# 	a : _a
# 286	conjecture		|- forall_{a, b, c, d} (|(a, b, c, d)| = |(1, 2, ..., 4)|)
# 	proveit.numbers.numerals.decimals.tuple_len_4_typical_eq
# 287	conjecture		|- forall_{a, b in Complex} ((a * b) in Complex)
# 	proveit.numbers.multiplication.mult_complex_closure_bin
# 288	conjecture		|- i in Complex
# 	proveit.numbers.number_sets.complex_numbers.i_is_complex
# 289	instantiation	296, 297, 298	{t in NaturalPos, _a in {-t + 1 .. 0}} |- 2^{-_a} in Complex
# 	a : 2, b : -_a
# 290	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 291	conjecture		|- phase in Real
# 	proveit.physics.quantum.QPE._phase_is_real
# 292	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 293	instantiation	326, 299, 300	|- pi in Real
# 	A : RealPos, B : Real, x : pi
# 294	conjecture		|- forall_{a in Integer | a <= 0} (a in IntegerNonPos)
# 	proveit.numbers.number_sets.integers.nonpos_int_is_int_nonpos
# 295	instantiation	301, 317, 318, 315	{t in NaturalPos, _a in {-t + 1 .. 0}} |- _a <= 0
# 	a : -t + 1, b : 0, n : _a
# 296	conjecture		|- forall_{a, b in Complex} (a^{b} in Complex)
# 	proveit.numbers.exponentiation.exp_complex_closure
# 297	instantiation	326, 306, 302	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 298	instantiation	303, 304	{t in NaturalPos, _a in {-t + 1 .. 0}} |- (-_a) in Complex
# 	a : _a
# 299	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 300	conjecture		|- pi in RealPos
# 	proveit.numbers.number_sets.real_numbers.pi_is_real_pos
# 301	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n <= b)]
# 	proveit.numbers.number_sets.integers.interval_upper_bound
# 302	instantiation	326, 309, 305	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 303	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 304	instantiation	326, 306, 307	{t in NaturalPos, _a in {-t + 1 .. 0}} |- _a in Complex
# 	A : Real, B : Complex, x : _a
# 305	instantiation	326, 312, 308	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 306	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 307	instantiation	326, 309, 310	{t in NaturalPos, _a in {-t + 1 .. 0}} |- _a in Real
# 	A : Rational, B : Real, x : _a
# 308	instantiation	326, 324, 311	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 309	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 310	instantiation	326, 312, 313	{t in NaturalPos, _a in {-t + 1 .. 0}} |- _a in Rational
# 	A : Integer, B : Rational, x : _a
# 311	conjecture		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 312	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 313	instantiation	326, 314, 315	{t in NaturalPos, _a in {-t + 1 .. 0}} |- _a in Integer
# 	A : {-t + 1 .. 0}, B : Integer, x : _a
# 314	instantiation	316, 317, 318	{t in NaturalPos} |- {-t + 1 .. 0} proper_subset Integer
# 	a : -t + 1, b : 0
# 315	assumption		{_a in {-t + 1 .. 0}} |- _a in {-t + 1 .. 0}
# 316	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 317	instantiation	319, 320, 321	{t in NaturalPos} |- (-t + 1) in Integer
# 	a : -t, b : 1
# 318	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 319	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 320	instantiation	322, 323	{t in NaturalPos} |- (-t) in Integer
# 	a : t
# 321	instantiation	326, 324, 325	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 322	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 323	instantiation	326, 327, 328	{t in NaturalPos} |- t in Integer
# 	A : NaturalPos, B : Integer, x : t
# 324	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 325	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 326	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 327	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 328	assumption		{t in NaturalPos} |- t in NaturalPos
