# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_alpha_m_evaluation">_alpha_m_evaluation</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import k, l, m, n, t, defaults
from proveit.logic import InSet
from proveit.numbers import Mult
from proveit.physics.quantum.QPE import ( _m_domain, _t ) # QPE Common Expressions
from proveit.physics.quantum.QPE import (                 # QPE Axioms
    _alpha_m_def, _Psi_def )
from proveit.physics.quantum.QPE import (                 # QPE Theorems
    _phase_is_real, _psi_t_formula, _t_in_natural_pos )
from proveit.physics.quantum.QFT import invFT_on_matrix_elem

# %%
# %proving _alpha_m_evaluation
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="_alpha_m_evaluation">_alpha_m_evaluation:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/1973ff1b37f0d1edf492e28b66d82bc0f5a63a3e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/caf49173b3711e4a248a8274f0b087173d02bcf60/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _alpha_m_evaluation.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/553d5598dac26513c310f953cbd1ba9111fc3e510/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_alpha_m_def
# Out:
# |- forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} = ({t}_〈m| . |Psi>))

# %%
alpha_m_eq_01 = _alpha_m_def.instantiate()
# Out:
# <strong id="alpha_m_eq_01">alpha_m_eq_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/9adccdb9d9131ba21104ad193c835362a79e02460/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/7ef73f638b7eceb945bc406413dceae5b95f80cf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_Psi_def
# Out:
# |- |Psi> = (FT^{dag}_{t} . |psi_{t}>)

# %%
alpha_m_eq_02 = _Psi_def.sub_right_side_into(alpha_m_eq_01)
# Out:
# <strong id="alpha_m_eq_02">alpha_m_eq_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/ab51eddf4957b930414a7eed9ae5cf8c9e5deed80/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/033cd799473c4cdc43def70fba3942f96382d44f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_psi_t_formula
# Out:
# |- forall_{t in NaturalPos} (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))

# %%
# This instantiation requires we know that _t is in NaturalPos
psi_formula = _psi_t_formula.instantiate({t:_t})
# Out:
# <strong id="psi_formula">psi_formula:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/1a06aeefb574dc0cfa761002b4919338660499780/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/38c13344ce5f2bea1b766a9506da5b294db378e40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# Auto_simplification here pulls the constant coefficient
# out to the front of the bra-ket; for that auto-simplification
# factoring to work, however, we need the _phase_is_real theorem
# and the correct domain assumption for m.
alpha_m_eq_03 = psi_formula.sub_right_side_into(alpha_m_eq_02)
# Out:
# <strong id="alpha_m_eq_03">alpha_m_eq_03:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/04696ab163c75597bacad83822f341053bd7ae190/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/aab9802102c90c7d83dc490cc59403160aeb9ef40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
alpha_m_eq_04 = alpha_m_eq_03.inner_expr().rhs.operands[1].distribute(2)
# Out:
# <strong id="alpha_m_eq_04">alpha_m_eq_04:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/5c3205f87be0793f8397a199ccdbf4ad6ecca9520/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/94f12783feabc9770f5df255c445eb151d7e72840/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# for convenience and clarity we name the summation domain
k_domain = psi_formula.rhs.operands[1].domain
# Out:
# <strong id="k_domain">k_domain:</strong> <a class="ProveItLink" href="../../../__pv_it/common/0107914a254b4cba063b4849ea3d536e6979ec8c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
invFT_on_matrix_elem
# Out:
# |- forall_{n in NaturalPos} [forall_{k, l in {0 .. 2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}))]

# %%
matrix_elem = invFT_on_matrix_elem.instantiate(
    {n:_t, l:m}, assumptions=[InSet(k, k_domain), InSet(m, _m_domain)])
# Out:
# <strong id="matrix_elem">matrix_elem:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/df30aba3a535ce7eb8609d1347296ba1cd1680060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/bebbf1fc88eed6e2163d89d1b1d816b81b88d16c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/c019d655b17ea3d5ae40460ffa476136a76add270/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# We don't want to combine the two different exponentials through auto-simplification.
Mult.change_simplification_directives(combine_all_exponents=False)
alpha_m_eq_05 = (alpha_m_eq_04.inner_expr().rhs.operands[1]
               .summand.operands[1].substitute(matrix_elem))
# Out:
# <strong id="alpha_m_eq_05">alpha_m_eq_05:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/5496a3990751d94f3080dcab57504368ae15a12e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/117f77989ae224f6ce19547513b32827728802a00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# _alpha_m_evaluation may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._alpha_m_evaluation has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))))
# 1	instantiation	331, 2, 3	{m in {0 .. 2^{t} - 1}} |- alpha_{m} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))
# 	x : alpha_{m}, y : (1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), z : (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
# 2	instantiation	4, 5, 6	{m in {0 .. 2^{t} - 1}} |- alpha_{m} = ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	P : alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))), Q : alpha_{m} = ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 3	instantiation	7, 398, 8, 9, 10, 11	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))) =  \\ ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))
# 	n : 2, f(_a, _b) : _a * _b, x : ((1 / 2^{t / 2})^{2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), y : (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
# 4	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 5	instantiation	306, 12, 13	{m in {0 .. 2^{t} - 1}} |- alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))
# 	P(_a) : alpha_{m} = ((1 / 2^{t / 2}) * _a), x : {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), y : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
# 6	instantiation	341, 14, 15*, 16*, 17*	{m in {0 .. 2^{t} - 1}} |- (alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))) = (alpha_{m} = ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))))
# 	f(_a) : alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * _a(k)))), x(k) : {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}., y(k) : {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
# 7	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 8	instantiation	338	|- |((1 / 2^{t / 2})^{2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))| = |(1, ..., 2)|
# 	a : (1 / 2^{t / 2})^{2}, b : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
# 9	instantiation	338	|- |(1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))| = |(1, ..., 2)|
# 	a : 1 / 2^{t}, b : Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})
# 10	instantiation	107, 18	|- (1 / 2^{t / 2})^{2} = (1 / 2^{t})
# 	x : 1 / 2^{t}, y : (1 / 2^{t / 2})^{2}
# 11	instantiation	341, 19	{m in {0 .. 2^{t} - 1}} |- (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})) = (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
# 	f(_a) : Sum_{k} _a(k), x(k) : {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}., y(k) : {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
# 12	instantiation	306, 20, 21, 22*	{m in {0 .. 2^{t} - 1}} |- alpha_{m} = ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	P(_a) : alpha_{m} = ({t}_〈m| . (FT^{dag}_{t} . _a)), x : |psi_{t}>, y : (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 13	modus ponens	23, 152	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) \\  = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# 14	modus ponens	24, 25	{m in {0 .. 2^{t} - 1}} |- [k -> {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.]
# 15	instantiation	101, 366	{k in {0 .. 2^{t} - 1}} |- {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}. = ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})
# 	a : {t}_〈m| . FT^{dag}_{t} . |k〉_{t}, Q : k in {0 .. 2^{t} - 1}
# 16	instantiation	101, 366	{k in {0 .. 2^{t} - 1}} |- {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})
# 	a : (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}, Q : k in {0 .. 2^{t} - 1}
# 17	instantiation	331, 26, 27	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})))) = ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	x : (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))), y : (1 / 2^{t / 2}) * ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))), z : (1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 18	instantiation	196, 28, 29, 30	|- (1 / 2^{t}) = (1 / 2^{t / 2})^{2}
# 	a : 1 / 2^{t}, b : 2^{-t}, c : 2^{(-((1 / 2) * t)) * 2}, d : (1 / 2^{t / 2})^{2}
# 19	modus ponens	31, 32	{m in {0 .. 2^{t} - 1}} |- [k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.]
# 20	instantiation	306, 33, 34	{m in {0 .. 2^{t} - 1}} |- alpha_{m} = ({t}_〈m| . (FT^{dag}_{t} . |psi_{t}>))
# 	P(_a) : alpha_{m} = ({t}_〈m| . _a), x : |Psi>, y : FT^{dag}_{t} . |psi_{t}>
# 21	instantiation	35, 400	|- |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	t : t
# 22	instantiation	331, 36, 37	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	x : {t}_〈m| . (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), y : {t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), z : (1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 23	instantiation	38, 390, 398, 322, 210, 323, 39*	{m in {0 .. 2^{t} - 1}} |- (({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*) =>  \\ (({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) \\  = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))
# 	j : 1, m : 2, n : 0, A : ({t}_〈m|, FT^{dag}_{t}), C : (), f(k) : e^{2 * pi * i * phase * k} * |k〉_{t}, Q(k) : k in {0 .. 2^{t} - 1}, b : (k)
# 24	instantiation	140, 390	|- [forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))] =>  \\ ([k -> {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.])
# 	i : 1, f(k) : {t}_〈m| . FT^{dag}_{t} . |k〉_{t}, g(k) : (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}, Q(k) : k in {0 .. 2^{t} - 1}, a : (k), b : (k), c : (k)
# 25	generalization	40	{m in {0 .. 2^{t} - 1}} |- forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 26	instantiation	341, 41	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})))) = ((1 / 2^{t / 2}) * ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))))
# 	f(_a) : (1 / 2^{t / 2}) * _a, x : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})), y : (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 27	instantiation	331, 42, 43	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) * ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))) = ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	x : (1 / 2^{t / 2}) * ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))), y : (1 / 2^{t / 2}) * (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), z : (1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 28	instantiation	315, 257, 227, 228, 44*	|- (1 / 2^{t}) = 2^{-t}
# 	x : 1, y : 2^{t}
# 29	instantiation	341, 45	|- 2^{-t} = 2^{(-((1 / 2) * t)) * 2}
# 	f(_a) : 2^{_a}, x : -t, y : (-((1 / 2) * t)) * 2
# 30	instantiation	107, 46	|- 2^{(-((1 / 2) * t)) * 2} = (1 / 2^{t / 2})^{2}
# 	x : (1 / 2^{t / 2})^{2}, y : 2^{(-((1 / 2) * t)) * 2}
# 31	instantiation	121, 390	|- [forall_{k} ({e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. = {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.)] =>  \\ ([k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.])
# 	i : 1, f(k) : {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}., g(k) : {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}., a : (k), b : (k), c : (k)
# 32	generalization	47	{m in {0 .. 2^{t} - 1}} |- forall_{k} ({e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. = {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.)
# 33	instantiation	48, 356	{m in {0 .. 2^{t} - 1}} |- alpha_{m} = ({t}_〈m| . |Psi>)
# 	m : m
# 34	axiom		|- |Psi> = (FT^{dag}_{t} . |psi_{t}>)
# 	proveit.physics.quantum.QPE._Psi_def
# 35	conjecture		|- forall_{t in NaturalPos} (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	proveit.physics.quantum.QPE._psi_t_formula
# 36	instantiation	341, 49	|- ({t}_〈m| . (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
# 	f(_a) : {t}_〈m| . _a, x : FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), y : (1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 37	instantiation	331, 50, 51	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	x : {t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), y : (1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), z : (1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 38	conjecture		|- forall_{j in NaturalPos, m in Natural, n in Natural} [forall_{A_{1}, A_{2}, ..., A_{m}, C_{1}, C_{2}, ..., C_{n}, f, Q} (((A_{1} .  A_{2} .  ... .  A_{m} . [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*) =>  \\ ((A_{1} .  A_{2} .  ... .  A_{m} . [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]. C_{1} .  C_{2} .  ... .  C_{n}) \\  = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (A_{1} .  A_{2} .  ... .  A_{m} . f(b_{1}, b_{2}, ..., b_{j}). C_{1} .  C_{2} .  ... .  C_{n})]))]
# 	proveit.physics.quantum.algebra.qmult_distribution_over_summation
# 39	instantiation	331, 52, 53	{m in {0 .. 2^{t} - 1}} |- (Sum_{k=0}^{2^{t} - 1} ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}))) = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# 	x : Sum_{k=0}^{2^{t} - 1} ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})), y : Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})), z : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
# 40	instantiation	54, 400, 366, 356, 55*	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})
# 	n : t, k : k, l : m
# 41	instantiation	331, 56, 57	{m in {0 .. 2^{t} - 1}} |- (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))) = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	x : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})), y : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}), z : (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 42	instantiation	321, 403, 398, 322, 58, 323, 241, 60	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) * ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))) =  \\ ((1 / 2^{t / 2}) * (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	i : 1, j : 2, k : 0, a : (1 / 2^{t / 2}), b : (1 / 2^{t / 2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), c : ()
# 43	instantiation	179, 322, 398, 403, 323, 59, 241, 60, 61*	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) * (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))) =  \\ ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	i : 0, j : 2, k : 1, a : (), b : (1 / 2^{t / 2}, 1 / 2^{t / 2}), c : (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 44	instantiation	331, 62, 63	|- (1 * (2^{t})^{-1}) = 2^{-t}
# 	x : 1 * (2^{t})^{-1}, y : 1 * 2^{-t}, z : 2^{-t}
# 45	instantiation	107, 64	|- (-t) = ((-((1 / 2) * t)) * 2)
# 	x : (-((1 / 2) * t)) * 2, y : -t
# 46	instantiation	331, 65, 66	|- (1 / 2^{t / 2})^{2} = 2^{(-((1 / 2) * t)) * 2}
# 	x : (1 / 2^{t / 2})^{2}, y : (2^{-((1 / 2) * t)})^{2}, z : 2^{(-((1 / 2) * t)) * 2}
# 47	instantiation	138, 67	{m in {0 .. 2^{t} - 1}} |- {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. \\  = {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
# 	a : e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}, b : e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}, Q : k in {0 .. 2^{t} - 1}
# 48	axiom		|- forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} = ({t}_〈m| . |Psi>))
# 	proveit.physics.quantum.QPE._alpha_m_def
# 49	instantiation	196, 68, 69, 70	|- (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) = ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	a : FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), b : FT^{dag}_{t} . (1 / 2^{t / 2}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), c : (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), d : (1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 50	instantiation	331, 71, 72	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ((1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	x : {t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), y : {t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), z : (1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 51	instantiation	157, 158, 241, 73, 152, 74*	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	j : 3, a : 1 / 2^{t / 2}, B : ({t}_〈m|, FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 52	instantiation	341, 75, 76*, 77*	{m in {0 .. 2^{t} - 1}} |- (Sum_{k=0}^{2^{t} - 1} ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}))) = (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# 	f(_a) : Sum_{k=0}^{2^{t} - 1} _a(k), x(k) : {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}., y(k) : {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.
# 53	modus ponens	78, 79	{m in {0 .. 2^{t} - 1}} |- (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))) = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# 54	conjecture		|- forall_{n in NaturalPos} [forall_{k, l in {0 .. 2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}))]
# 	proveit.physics.quantum.QFT.invFT_on_matrix_elem
# 55	instantiation	80, 226, 227, 228	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- ((-(2 * pi * i * k * m)) / 2^{t}) = (-((2 * pi * i * k * m) / 2^{t}))
# 	x : 2 * pi * i * k * m, y : 2^{t}
# 56	instantiation	341, 81	{m in {0 .. 2^{t} - 1}} |- (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))) = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 	f(_a) : Sum_{k} _a(k), x(k) : {e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}., y(k) : {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
# 57	instantiation	331, 82, 83	{m in {0 .. 2^{t} - 1}} |- (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})) = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	x : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}), y : Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), z : (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 58	instantiation	338	|- |(1 / 2^{t / 2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))| = |(1, ..., 2)|
# 	a : 1 / 2^{t / 2}, b : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
# 59	instantiation	338	|- |(1 / 2^{t / 2}, 1 / 2^{t / 2})| = |(1, ..., 2)|
# 	a : 1 / 2^{t / 2}, b : 1 / 2^{t / 2}
# 60	modus ponens	84, 143	{m in {0 .. 2^{t} - 1}} |- (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})) in Complex
# 61	instantiation	85, 241, 390, 86*, 87*	|- ((1 / 2^{t / 2}) * (1 / 2^{t / 2})) = (1 / 2^{t / 2})^{2}
# 	a : 1 / 2^{t / 2}, m : 1, n : 1
# 62	instantiation	341, 88	|- (1 * (2^{t})^{-1}) = (1 * 2^{-t})
# 	f(_a) : 1 * _a, x : (2^{t})^{-1}, y : 2^{-t}
# 63	instantiation	290, 89	|- (1 * 2^{-t}) = 2^{-t}
# 	x : 2^{-t}
# 64	instantiation	90, 202, 361, 91*	|- ((-((1 / 2) * t)) * 2) = (-t)
# 	x : (1 / 2) * t, y : 2
# 65	instantiation	341, 92	|- (1 / 2^{t / 2})^{2} = (2^{-((1 / 2) * t)})^{2}
# 	f(_a) : _a^{2}, x : 1 / 2^{t / 2}, y : 2^{-((1 / 2) * t)}
# 66	instantiation	184, 361, 93, 370, 316	|- (2^{-((1 / 2) * t)})^{2} = 2^{(-((1 / 2) * t)) * 2}
# 	a : 2, b : -((1 / 2) * t), c : 2
# 67	deduction	94	{m in {0 .. 2^{t} - 1}} |- (k in {0 .. 2^{t} - 1}) => ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) = (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
# 68	instantiation	155, 241, 403, 322, 323, 95	|- (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) =  \\ (FT^{dag}_{t} . (1 / 2^{t / 2}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	alpha : 1 / 2^{t / 2}, l : 1, n : 0, A : (FT^{dag}_{t}), B : Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}), C : ()
# 69	instantiation	156, 403, 241, 95	|- (FT^{dag}_{t} . (1 / 2^{t / 2}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ ((1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	l : 1, n : 1, b : 1 / 2^{t / 2}, A : (FT^{dag}_{t}), C : (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 70	instantiation	157, 392, 241, 151, 95	|- ((1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	j : 2, a : 1 / 2^{t / 2}, B : (FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 71	instantiation	331, 96, 97	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	x : {t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), y : {t}_〈m| . (1 / 2^{t / 2}) . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), z : {t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 72	instantiation	156, 403, 398, 241, 151, 152	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ ((1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	l : 1, n : 2, b : 1 / 2^{t / 2}, A : ({t}_〈m|), C : (FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 73	instantiation	327	|- |({t}_〈m|, FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))| = |(1, 2, ..., 3)|
# 	a : {t}_〈m|, b : FT^{dag}_{t}, c : Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
# 74	instantiation	175, 241, 98	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) = ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	a : 1 / 2^{t / 2}, b : {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 75	modus ponens	99, 100	{m in {0 .. 2^{t} - 1}} |- [k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.]
# 76	instantiation	101, 366	{k in {0 .. 2^{t} - 1}} |- {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}. = ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 	a : {t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}), Q : k in {0 .. 2^{t} - 1}
# 77	instantiation	101, 366	{k in {0 .. 2^{t} - 1}} |- {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}. = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
# 	a : e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}), Q : k in {0 .. 2^{t} - 1}
# 78	instantiation	102, 390	|- [forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) in Complex)] =>  \\ ((Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))) = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))
# 	j : 1, f(k) : e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}), Q(k) : k in {0 .. 2^{t} - 1}, b : (k)
# 79	generalization	103	{m in {0 .. 2^{t} - 1}} |- forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) in Complex)
# 80	conjecture		|- forall_{x, y in Complex | y != 0} (((-x) / y) = (-(x / y)))
# 	proveit.numbers.division.neg_frac_neg_numerator
# 81	modus ponens	104, 105	{m in {0 .. 2^{t} - 1}} |- [k -> {e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.]
# 82	instantiation	341, 106	{m in {0 .. 2^{t} - 1}} |- (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})) = (Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	f(_a) : Sum(_a), x(k) : {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}., y(k) : {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.
# 83	instantiation	107, 108	{m in {0 .. 2^{t} - 1}} |- (Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))) = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	x : (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), y : Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 84	instantiation	109	|- [forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex)] => ((Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})) in Complex)
# 	f(k) : e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}, Q(k) : k in {0 .. 2^{t} - 1}, x : k
# 85	conjecture		|- forall_{a in Complex, m in NaturalPos, n in NaturalPos} ((a^{m} * a^{n}) = a^{m + n})
# 	proveit.numbers.exponentiation.product_of_posnat_powers
# 86	instantiation	360, 241	|- (1 / 2^{t / 2})^{1} = (1 / 2^{t / 2})
# 	x : 1 / 2^{t / 2}
# 87	conjecture		|- (1 + 1) = 2
# 	proveit.numbers.numerals.decimals.add_1_1
# 88	instantiation	184, 361, 354, 232, 316, 110*	|- (2^{t})^{-1} = 2^{-t}
# 	a : 2, b : t, c : -1
# 89	instantiation	278, 361, 111	|- 2^{-t} in Complex
# 	a : 2, b : -t
# 90	conjecture		|- forall_{x, y in Complex} (((-x) * y) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_left
# 91	instantiation	196, 112, 113, 127	|- (((1 / 2) * t) * 2) = t
# 	a : ((1 / 2) * t) * 2, b : (1 / 2) * t * 2, c : t * 1, d : t
# 92	instantiation	331, 114, 115	|- (1 / 2^{t / 2}) = 2^{-((1 / 2) * t)}
# 	x : 1 / 2^{t / 2}, y : 1 / 2^{(1 / 2) * t}, z : 2^{-((1 / 2) * t)}
# 93	instantiation	116, 221	|- (-((1 / 2) * t)) in Real
# 	a : (1 / 2) * t
# 94	instantiation	343, 238, 181	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) = (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})
# 	a : e^{2 * pi * i * phase * k}, b : e^{-((2 * pi * i * k * m) / 2^{t})}
# 95	instantiation	190, 261, 244, 187	|- (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*
# 	H : Complex^{2^{t}}, X : Complex^{2^{t}}, A : FT^{dag}_{t}, |psi> : Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
# 96	instantiation	155, 241, 403, 322, 323, 117	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) =  \\ ({t}_〈m| . (1 / 2^{t / 2}) . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	alpha : 1 / 2^{t / 2}, l : 1, n : 0, A : ({t}_〈m|), B : FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), C : ()
# 97	instantiation	150, 398, 392, 322, 206, 151, 323, 118	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . (1 / 2^{t / 2}) . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) =  \\ ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	l : 2, m : 2, n : 0, A : ({t}_〈m|, 1 / 2^{t / 2}), B : (FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), C : ()
# 98	instantiation	280, 119, 172	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in Complex
# 	P(_a) : _a in Complex, x : {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), y : ({t}_〈m| . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 99	instantiation	140, 390	|- [forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))] =>  \\ ([k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.])
# 	i : 1, f(k) : {t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}), g(k) : e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}), Q(k) : k in {0 .. 2^{t} - 1}, a : (k), b : (k), c : (k)
# 100	generalization	120	{m in {0 .. 2^{t} - 1}} |- forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# 101	conjecture		|- forall_{a, Q | Q} ({a if Q. = a)
# 	proveit.core_expr_types.conditionals.satisfied_condition_reduction
# 102	axiom		|- forall_{j in NaturalPos} [forall_{f, Q} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]))]
# 	proveit.linear_algebra.addition.scalar_sum_extends_number_sum
# 103	instantiation	335, 238, 176	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) in Complex
# 	a : e^{2 * pi * i * phase * k}, b : {t}_〈m| . FT^{dag}_{t} . |k〉_{t}
# 104	instantiation	121, 390	|- [forall_{k} ({e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}. = {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.)] =>  \\ ([k -> {e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.])
# 	i : 1, f(k) : {e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}., g(k) : {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}., a : (k), b : (k), c : (k)
# 105	generalization	122	{m in {0 .. 2^{t} - 1}} |- forall_{k} ({e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}. = {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.)
# 106	modus ponens	123, 124	{m in {0 .. 2^{t} - 1}} |- [k -> {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.]
# 107	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 108	instantiation	125, 323, 241	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))) =  \\ (Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	a : (1 / 2^{t / 2}), c : ()
# 109	conjecture		|- forall_{f, Q} ([forall_{x | Q(x)} (f(x) in Complex)] => ([Sum_{x | Q(x)} f(x)] in Complex))
# 	proveit.numbers.summation.summation_complex_closure
# 110	instantiation	126, 344, 257, 127*	|- (t * (-1)) = (-t)
# 	x : t, y : 1
# 111	instantiation	211, 344	|- (-t) in Complex
# 	a : t
# 112	instantiation	321, 322, 398, 403, 323, 234, 345, 344, 361	|- (((1 / 2) * t) * 2) =  \\ ((1 / 2) * t * 2)
# 	i : 0, j : 2, k : 1, a : (), b : (1 / 2, t), c : (2)
# 113	instantiation	331, 128, 129	|- ((1 / 2) * t * 2) = (t * 1)
# 	x : (1 / 2) * t * 2, y : t * 2 * (1 / 2), z : t * 1
# 114	instantiation	341, 282	|- (1 / 2^{t / 2}) = (1 / 2^{(1 / 2) * t})
# 	f(_a) : 1 / _a, x : 2^{t / 2}, y : 2^{(1 / 2) * t}
# 115	instantiation	315, 257, 130, 281, 131*	|- (1 / 2^{(1 / 2) * t}) = 2^{-((1 / 2) * t)}
# 	x : 1, y : 2^{(1 / 2) * t}
# 116	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 117	instantiation	280, 152, 132	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) in_c Q*
# 	P(_a) : _a in_c Q*, x : {t}_〈m| . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), y : {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 118	instantiation	280, 133, 134	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*
# 	P(_a) : _a in_c Q*, x : {t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), y : ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 119	instantiation	207, 261, 262, 208, 187	{m in {0 .. 2^{t} - 1}} |- (({t}_〈m| . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in Complex
# 	H : Complex^{2^{t}}, X : Complex, A : {t}_〈m| . FT^{dag}_{t}, |psi> : Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
# 120	instantiation	196, 135, 136, 137	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
# 	a : {t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}), b : {t}_〈m| . FT^{dag}_{t} . e^{2 * pi * i * phase * k} . |k〉_{t}, c : e^{2 * pi * i * phase * k} . {t}_〈m| . FT^{dag}_{t} . |k〉_{t}, d : e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})
# 121	axiom		|- forall_{i in NaturalPos} [forall_{f, g} ([forall_{a_{1}, a_{2}, ..., a_{i}} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> f(b_{1}, b_{2}, ..., b_{i})] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> g(c_{1}, c_{2}, ..., c_{i})]))]
# 	proveit.core_expr_types.lambda_maps.lambda_substitution
# 122	instantiation	138, 139	{m in {0 .. 2^{t} - 1}} |- {e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}. \\  = {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
# 	a : e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}), b : e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}, Q : k in {0 .. 2^{t} - 1}
# 123	instantiation	140, 390	|- [forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) = ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))] =>  \\ ([k -> {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.])
# 	i : 1, f(k) : e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}, g(k) : (1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}), Q(k) : k in {0 .. 2^{t} - 1}, a : (k), b : (k), c : (k)
# 124	generalization	141	{m in {0 .. 2^{t} - 1}} |- forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) = ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 125	modus ponens	142, 143	{m in {0 .. 2^{t} - 1}} |- forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})))
# 126	conjecture		|- forall_{x, y in Complex} ((x * (-y)) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_right
# 127	instantiation	273, 344	|- (t * 1) = t
# 	x : t
# 128	instantiation	144, 322, 398, 323, 145, 345, 344, 361	|- ((1 / 2) * t * 2) =  \\ (t * 2 * (1 / 2))
# 	i : 0, j : 2, k : 0, a : (), b : 1 / 2, c : (t, 2), d : ()
# 129	instantiation	331, 146, 147	|- (t * 2 * (1 / 2)) = (t * 1)
# 	x : t * 2 * (1 / 2), y : t * (2 * (1 / 2)), z : t * 1
# 130	instantiation	278, 361, 202	|- 2^{(1 / 2) * t} in Complex
# 	a : 2, b : (1 / 2) * t
# 131	instantiation	331, 148, 149	|- (1 * (2^{(1 / 2) * t})^{-1}) = 2^{-((1 / 2) * t)}
# 	x : 1 * (2^{(1 / 2) * t})^{-1}, y : 1 * 2^{-((1 / 2) * t)}, z : 2^{-((1 / 2) * t)}
# 132	instantiation	150, 403, 392, 322, 151, 323, 152	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) =  \\ ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	l : 1, m : 2, n : 0, A : ({t}_〈m|), B : (FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), C : ()
# 133	instantiation	190, 261, 262, 153, 187	{m in {0 .. 2^{t} - 1}} |- (({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*
# 	H : Complex^{2^{t}}, X : Complex, A : {t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}, |psi> : Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
# 134	instantiation	209, 158, 154	|- ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ (({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	m : 3, A : ({t}_〈m|, 1 / 2^{t / 2}, FT^{dag}_{t}), B : Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
# 135	instantiation	155, 238, 398, 322, 210, 323, 160	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) =  \\ ({t}_〈m| . FT^{dag}_{t} . e^{2 * pi * i * phase * k} . |k〉_{t})
# 	alpha : e^{2 * pi * i * phase * k}, l : 2, n : 0, A : ({t}_〈m|, FT^{dag}_{t}), B : |k〉_{t}, C : ()
# 136	instantiation	156, 398, 403, 238, 210, 160	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . FT^{dag}_{t} . e^{2 * pi * i * phase * k} . |k〉_{t}) =  \\ (e^{2 * pi * i * phase * k} . {t}_〈m| . FT^{dag}_{t} . |k〉_{t})
# 	l : 2, n : 1, b : e^{2 * pi * i * phase * k}, A : ({t}_〈m|, FT^{dag}_{t}), C : (|k〉_{t})
# 137	instantiation	157, 158, 238, 159, 160, 161*	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- (e^{2 * pi * i * phase * k} . {t}_〈m| . FT^{dag}_{t} . |k〉_{t}) =  \\ (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
# 	j : 3, a : e^{2 * pi * i * phase * k}, B : ({t}_〈m|, FT^{dag}_{t}, |k〉_{t})
# 138	axiom		|- forall_{a, b, Q | Q => (a = b)} ({a if Q. \\  = {b if Q.)
# 	proveit.core_expr_types.conditionals.conditional_substitution
# 139	deduction	162	{m in {0 .. 2^{t} - 1}} |- (k in {0 .. 2^{t} - 1}) => ((e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})) = (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 140	conjecture		|- forall_{i in NaturalPos} [forall_{f, g, Q} ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).]))]
# 	proveit.core_expr_types.lambda_maps.general_lambda_substitution
# 141	instantiation	331, 163, 164	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) = ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 	x : e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}, y : (1 / 2^{t / 2}) * e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}, z : (1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
# 142	instantiation	165, 403, 390, 322	|- [forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex)] =>  \\ [forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})))]
# 	i : 1, j : 1, k : 0, f(k) : e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}, Q(k) : k in {0 .. 2^{t} - 1}, b : (k)
# 143	generalization	166	{m in {0 .. 2^{t} - 1}} |- forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex)
# 144	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j}* d_{1} *  d_{2} *  ... *  d_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i}* c_{1} *  c_{2} *  ... *  c_{j} * b* d_{1} *  d_{2} *  ... *  d_{k}))]
# 	proveit.numbers.multiplication.rightward_commutation
# 145	instantiation	338	|- |(t, 2)| = |(1, ..., 2)|
# 	a : t, b : 2
# 146	instantiation	179, 403, 398, 322, 167, 323, 344, 361, 345	|- (t * 2 * (1 / 2)) =  \\ (t * (2 * (1 / 2)))
# 	i : 1, j : 2, k : 0, a : (t), b : (2, 1 / 2), c : ()
# 147	instantiation	341, 168	|- (t * (2 * (1 / 2))) = (t * 1)
# 	f(_a) : t * _a, x : 2 * (1 / 2), y : 1
# 148	instantiation	341, 169	|- (1 * (2^{(1 / 2) * t})^{-1}) = (1 * 2^{-((1 / 2) * t)})
# 	f(_a) : 1 * _a, x : (2^{(1 / 2) * t})^{-1}, y : 2^{-((1 / 2) * t)}
# 149	instantiation	290, 170	|- (1 * 2^{-((1 / 2) * t)}) = 2^{-((1 / 2) * t)}
# 	x : 2^{-((1 / 2) * t)}
# 150	conjecture		|- forall_{l in Natural, m in NaturalPos, n in Natural} [forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l} . (B_{1} .  B_{2} .  ... .  B_{m}). C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}))]
# 	proveit.physics.quantum.algebra.qmult_disassociation
# 151	instantiation	338	|- |(FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))| = |(1, ..., 2)|
# 	a : FT^{dag}_{t}, b : Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
# 152	instantiation	280, 171, 172	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*
# 	P(_a) : _a in_c Q*, x : {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), y : ({t}_〈m| . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 153	instantiation	260, 261, 262, 173	{m in {0 .. 2^{t} - 1}} |- [{t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}] in LINMAP(Complex^{2^{t}}, Complex)
# 	H : Complex^{2^{t}}, X : Complex, A : {t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}
# 154	instantiation	327	|- |({t}_〈m|, 1 / 2^{t / 2}, FT^{dag}_{t})| = |(1, 2, ..., 3)|
# 	a : {t}_〈m|, b : 1 / 2^{t / 2}, c : FT^{dag}_{t}
# 155	conjecture		|- forall_{alpha in Complex, l in Natural, n in Natural} [forall_{A_{1}, A_{2}, ..., A_{l}, B, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l} . B. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l} . (alpha * B). C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (A_{1} .  A_{2} .  ... .  A_{l} . alpha . B. C_{1} .  C_{2} .  ... .  C_{n}))]
# 	proveit.physics.quantum.algebra.scalar_mult_absorption
# 156	conjecture		|- forall_{l, n in Natural} [forall_{b in Complex} [forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))]]
# 	proveit.physics.quantum.algebra.qmult_pulling_scalar_out_front
# 157	conjecture		|- forall_{j in NaturalPos} [forall_{a in Complex} [forall_{B_{1}, B_{2}, ..., B_{j} | (B_{1} .  B_{2} .  ... .  B_{j}) in_c Q*} ((a. B_{1} .  B_{2} .  ... .  B_{j}) =  \\ (a * (B_{1} .  B_{2} .  ... .  B_{j})))]]
# 	proveit.physics.quantum.algebra.scalar_mult_factorization
# 158	conjecture		|- 3 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat3
# 159	instantiation	327	|- |({t}_〈m|, FT^{dag}_{t}, |k〉_{t})| = |(1, 2, ..., 3)|
# 	a : {t}_〈m|, b : FT^{dag}_{t}, c : |k〉_{t}
# 160	instantiation	280, 174, 192	{m in {0 .. 2^{t} - 1}, k in {0 .. 2^{t} - 1}} |- ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) in_c Q*
# 	P(_a) : _a in_c Q*, x : {t}_〈m| . FT^{dag}_{t} . |k〉_{t}, y : ({t}_〈m| . FT^{dag}_{t}) . |k〉_{t}
# ...
# 	P(_a) : _a in Complex, x : (2 * pi) * (i * phase * k), y : 2 * pi * i * phase * k
# 256	conjecture		|- forall_{n in NaturalPos} [forall_{k in {0 .. 2^{n} - 1}} (|k〉_{n} in Complex^{2^{n}})]
# 	proveit.physics.quantum.algebra.num_ket_in_register_space
# 257	instantiation	401, 369, 277	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 258	instantiation	278, 361, 279	|- 2^{t / 2} in Complex
# 	a : 2, b : t / 2
# 259	instantiation	280, 281, 282	|- 2^{t / 2} != 0
# 	P(_a) : _a != 0, x : 2^{t / 2}, y : 2^{(1 / 2) * t}
# 260	conjecture		|- forall_{H, X in_c HilbertSpaces} [forall_{A in LINMAP(H, X)} ([A] in LINMAP(H, X))]
# 	proveit.physics.quantum.algebra.qmult_op_is_linmap
# 261	instantiation	283, 301	|- Complex^{2^{t}} in_c HilbertSpaces
# 	n : 2^{t}
# 262	conjecture		|- Complex in_c HilbertSpaces
# 	proveit.linear_algebra.inner_products.complex_set_is_hilbert_space
# 263	instantiation	284, 400, 356	{m in {0 .. 2^{t} - 1}} |- {t}_〈m| in LINMAP(Complex^{2^{t}}, Complex)
# 	n : t, k : m
# 264	conjecture		|- forall_{m, n in NaturalPos} [forall_{M in Complex^{m x n}} ([M] in LINMAP(Complex^{n}, Complex^{m}))]
# 	proveit.physics.quantum.algebra.qmult_matrix_is_linmap
# 265	instantiation	362, 285, 286	|- FT^{dag}_{t} in Complex^{2^{t} x 2^{t}}
# 	A : U(2^{t}), B : Complex^{2^{t} x 2^{t}}, x : FT^{dag}_{t}
# 266	instantiation	306, 287, 288	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- (i * k * m) in Complex
# 	P(_a) : _a in Complex, x : (i * k) * m, y : i * k * m
# 267	instantiation	321, 403, 310, 322, 289, 323, 309, 336, 325, 305	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- ((2 * pi) * (i * k * m)) =  \\ ((2 * pi) * i * k * m)
# 	i : 1, j : 3, k : 0, a : (2 * pi), b : (i, k, m), c : ()
# 268	instantiation	321, 322, 398, 310, 323, 311, 289, 361, 326, 336, 325, 305	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- ((2 * pi) * i * k * m) =  \\ (2 * pi * i * k * m)
# 	i : 0, j : 2, k : 3, a : (), b : (2, pi), c : (i, k, m)
# 269	instantiation	401, 389, 386	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 270	instantiation	401, 388, 390	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 271	instantiation	290, 361	|- (1 * 2) = 2
# 	x : 2
# 272	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 273	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 274	instantiation	401, 349, 291	|- e in Real
# 	A : RealPos, B : Real, x : e
# 275	instantiation	335, 309, 292	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * (i * phase * k)) in Complex
# 	a : 2 * pi, b : i * phase * k
# 276	instantiation	331, 293, 294	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * (i * phase * k)) = (2 * pi * i * phase * k)
# 	x : (2 * pi) * (i * phase * k), y : (2 * pi) * i * phase * k, z : 2 * pi * i * phase * k
# 277	instantiation	401, 380, 295	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 278	conjecture		|- forall_{a, b in Complex} (a^{b} in Complex)
# 	proveit.numbers.exponentiation.exp_complex_closure
# 279	instantiation	296, 344, 361, 316	|- (t / 2) in Complex
# 	a : t, b : 2
# 280	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 281	instantiation	297, 368, 298	|- 2^{(1 / 2) * t} != 0
# 	a : 2, b : (1 / 2) * t
# 282	instantiation	341, 299	|- 2^{t / 2} = 2^{(1 / 2) * t}
# 	f(_a) : 2^{_a}, x : t / 2, y : (1 / 2) * t
# 283	conjecture		|- forall_{n in NaturalPos} (Complex^{n} in_c HilbertSpaces)
# 	proveit.linear_algebra.inner_products.complex_vec_set_is_hilbert_space
# 284	conjecture		|- forall_{n in NaturalPos} [forall_{k in {0 .. 2^{n} - 1}} ({n}_〈k| in LINMAP(Complex^{2^{n}}, Complex))]
# 	proveit.physics.quantum.algebra.num_bra_is_lin_map
# 285	instantiation	300, 301	|- U(2^{t}) subset_eq Complex^{2^{t} x 2^{t}}
# 	n : 2^{t}
# 286	instantiation	302, 400	|- FT^{dag}_{t} in U(2^{t})
# 	n : t
# 287	instantiation	335, 303, 305	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- ((i * k) * m) in Complex
# 	a : i * k, b : m
# 288	instantiation	321, 322, 398, 403, 323, 304, 336, 325, 305	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- ((i * k) * m) =  \\ (i * k * m)
# 	i : 0, j : 2, k : 1, a : (), b : (i, k), c : (m)
# 289	instantiation	327	|- |(i, k, m)| = |(1, 2, ..., 3)|
# 	a : i, b : k, c : m
# 290	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 291	conjecture		|- e in RealPos
# 	proveit.numbers.number_sets.real_numbers.e_is_real_pos
# 292	instantiation	306, 307, 308	{k in {0 .. 2^{t} - 1}} |- (i * phase * k) in Complex
# 	P(_a) : _a in Complex, x : (i * phase) * k, y : i * phase * k
# 293	instantiation	321, 403, 310, 322, 312, 323, 309, 336, 337, 325	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * (i * phase * k)) =  \\ ((2 * pi) * i * phase * k)
# 	i : 1, j : 3, k : 0, a : (2 * pi), b : (i, phase, k), c : ()
# 294	instantiation	321, 322, 398, 310, 323, 311, 312, 361, 326, 336, 337, 325	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * i * phase * k) =  \\ (2 * pi * i * phase * k)
# 	i : 0, j : 2, k : 3, a : (), b : (2, pi), c : (i, phase, k)
# 295	instantiation	401, 389, 397	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 296	conjecture		|- forall_{a, b in Complex | b != 0} ((a / b) in Complex)
# 	proveit.numbers.division.div_complex_closure
# 297	conjecture		|- forall_{a, b in RationalNonZero} (a^{b} != 0)
# 	proveit.numbers.exponentiation.exp_rational_non_zero__not_zero
# 298	instantiation	401, 313, 314	|- ((1 / 2) * t) in RationalNonZero
# 	A : RationalPos, B : RationalNonZero, x : (1 / 2) * t
# 299	instantiation	315, 344, 361, 316, 317*	|- (t / 2) = ((1 / 2) * t)
# 	x : t, y : 2
# 300	conjecture		|- forall_{n in NaturalPos} (U(n) subset_eq Complex^{n x n})
# 	proveit.linear_algebra.matrices.unitaries_are_matrices
# 301	instantiation	318, 398, 395	|- 2^{t} in NaturalPos
# 	a : 2, b : t
# 302	conjecture		|- forall_{n in NaturalPos} (FT^{dag}_{n} in U(2^{n}))
# 	proveit.physics.quantum.QFT.invFT_is_unitary
# 303	instantiation	335, 336, 325	{k in {0 .. 2^{t} - 1}} |- (i * k) in Complex
# 	a : i, b : k
# 304	instantiation	338	|- |(i, k)| = |(1, ..., 2)|
# 	a : i, b : k
# 305	instantiation	401, 369, 319	{m in {0 .. 2^{t} - 1}} |- m in Complex
# 	A : Real, B : Complex, x : m
# 306	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 307	instantiation	335, 320, 325	{k in {0 .. 2^{t} - 1}} |- ((i * phase) * k) in Complex
# 	a : i * phase, b : k
# 308	instantiation	321, 322, 398, 403, 323, 324, 336, 337, 325	{k in {0 .. 2^{t} - 1}} |- ((i * phase) * k) =  \\ (i * phase * k)
# 	i : 0, j : 2, k : 1, a : (), b : (i, phase), c : (k)
# 309	instantiation	335, 361, 326	|- (2 * pi) in Complex
# 	a : 2, b : pi
# 310	conjecture		|- 3 in Natural
# 	proveit.numbers.numerals.decimals.nat3
# 311	instantiation	338	|- |(2, pi)| = |(1, ..., 2)|
# 	a : 2, b : pi
# 312	instantiation	327	|- |(i, phase, k)| = |(1, 2, ..., 3)|
# 	a : i, b : phase, c : k
# 313	conjecture		|- RationalPos proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.rational_pos_within_rational_nonzero
# 314	instantiation	328, 374, 329	|- ((1 / 2) * t) in RationalPos
# 	a : 1 / 2, b : t
# 315	conjecture		|- forall_{x, y in Complex | y != 0} ((x / y) = (x * y^{-1}))
# 	proveit.numbers.division.div_as_mult
# 316	instantiation	330, 392	|- 2 != 0
# 	n : 2
# 317	instantiation	331, 332, 333	|- (t * 2^{-1}) = ((1 / 2) * t)
# 	x : t * 2^{-1}, y : t * (1 / 2), z : (1 / 2) * t
# 318	conjecture		|- forall_{a, b in Natural} (a^{b} in NaturalPos)
# 	proveit.numbers.exponentiation.exp_natpos_closure
# 319	instantiation	401, 380, 334	{m in {0 .. 2^{t} - 1}} |- m in Real
# 	A : Rational, B : Real, x : m
# 320	instantiation	335, 336, 337	|- (i * phase) in Complex
# 	a : i, b : phase
# 321	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} *  b_{2} *  ... *  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}* c_{1} *  c_{2} *  ... *  c_{k}))]
# 	proveit.numbers.multiplication.disassociation
# 322	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 323	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 324	instantiation	338	|- |(i, phase)| = |(1, ..., 2)|
# 	a : i, b : phase
# 325	instantiation	401, 369, 339	{k in {0 .. 2^{t} - 1}} |- k in Complex
# 	A : Real, B : Complex, x : k
# 326	instantiation	401, 369, 340	|- pi in Complex
# 	A : Real, B : Complex, x : pi
# 327	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, 2, ..., 3)|)
# 	proveit.numbers.numerals.decimals.tuple_len_3_typical_eq
# 328	conjecture		|- forall_{a, b in RationalPos} ((a * b) in RationalPos)
# 	proveit.numbers.multiplication.mult_rational_pos_closure_bin
# 329	instantiation	401, 391, 400	|- t in RationalPos
# 	A : NaturalPos, B : RationalPos, x : t
# 330	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 331	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 332	instantiation	341, 342	|- (t * 2^{-1}) = (t * (1 / 2))
# 	f(_a) : t * _a, x : 2^{-1}, y : 1 / 2
# 333	instantiation	343, 344, 345	|- (t * (1 / 2)) = ((1 / 2) * t)
# 	a : t, b : 1 / 2
# 334	instantiation	401, 389, 346	{m in {0 .. 2^{t} - 1}} |- m in Rational
# 	A : Integer, B : Rational, x : m
# 335	conjecture		|- forall_{a, b in Complex} ((a * b) in Complex)
# 	proveit.numbers.multiplication.mult_complex_closure_bin
# 336	conjecture		|- i in Complex
# 	proveit.numbers.number_sets.complex_numbers.i_is_complex
# 337	instantiation	401, 369, 347	|- phase in Complex
# 	A : Real, B : Complex, x : phase
# 338	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 339	instantiation	401, 380, 348	{k in {0 .. 2^{t} - 1}} |- k in Real
# 	A : Rational, B : Real, x : k
# 340	instantiation	401, 349, 350	|- pi in Real
# 	A : RealPos, B : Real, x : pi
# 341	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 342	instantiation	351, 352, 390, 353*	|- 2^{-1} = (1 / 2)
# 	a : 2, n : 1
# 343	conjecture		|- forall_{a, b in Complex} ((a * b) = (b * a))
# 	proveit.numbers.multiplication.commutation
# 344	instantiation	401, 369, 354	|- t in Complex
# 	A : Real, B : Complex, x : t
# 345	instantiation	401, 369, 355	|- (1 / 2) in Complex
# 	A : Real, B : Complex, x : 1 / 2
# 346	instantiation	401, 365, 356	{m in {0 .. 2^{t} - 1}} |- m in Integer
# 	A : {0 .. 2^{t} - 1}, B : Integer, x : m
# 347	conjecture		|- phase in Real
# 	proveit.physics.quantum.QPE._phase_is_real
# 348	instantiation	401, 389, 357	{k in {0 .. 2^{t} - 1}} |- k in Rational
# 	A : Integer, B : Rational, x : k
# 349	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 350	conjecture		|- pi in RealPos
# 	proveit.numbers.number_sets.real_numbers.pi_is_real_pos
# 351	conjecture		|- forall_{a in ComplexNonZero, n in NaturalPos} (a^{-n} = (1 / a^{n}))
# 	proveit.numbers.exponentiation.neg_power_as_div
# 352	instantiation	401, 358, 359	|- 2 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2
# 353	instantiation	360, 361	|- 2^{1} = 2
# 	x : 2
# 354	instantiation	362, 363, 400	|- t in Real
# 	A : NaturalPos, B : Real, x : t
# 355	instantiation	401, 380, 364	|- (1 / 2) in Real
# 	A : Rational, B : Real, x : 1 / 2
# 356	assumption		{m in {0 .. 2^{t} - 1}} |- m in {0 .. 2^{t} - 1}
# 357	instantiation	401, 365, 366	{k in {0 .. 2^{t} - 1}} |- k in Integer
# 	A : {0 .. 2^{t} - 1}, B : Integer, x : k
# 358	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 359	instantiation	401, 367, 368	|- 2 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2
# 360	conjecture		|- forall_{x in Complex} (x^{1} = x)
# 	proveit.numbers.exponentiation.complex_x_to_first_power_is_x
# 361	instantiation	401, 369, 370	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 362	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 363	instantiation	371, 372	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 364	instantiation	401, 373, 374	|- (1 / 2) in Rational
# 	A : RationalPos, B : Rational, x : 1 / 2
# 365	instantiation	375, 376, 377	|- {0 .. 2^{t} - 1} proper_subset Integer
# 	a : 0, b : 2^{t} - 1
# 366	assumption		{k in {0 .. 2^{t} - 1}} |- k in {0 .. 2^{t} - 1}
# 367	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 368	instantiation	401, 378, 379	|- 2 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2
# 369	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 370	instantiation	401, 380, 381	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 371	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 372	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 373	conjecture		|- RationalPos proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.rational_pos_within_rational
# 374	instantiation	382, 383, 384	|- (1 / 2) in RationalPos
# 	a : 1, b : 2
# 375	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 376	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 377	instantiation	385, 386, 387	|- (2^{t} - 1) in Integer
# 	a : 2^{t}, b : -1
# 378	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 379	instantiation	401, 388, 392	|- 2 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2
# 380	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 381	instantiation	401, 389, 394	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 382	conjecture		|- forall_{a, b in RationalPos} ((a / b) in RationalPos)
# 	proveit.numbers.division.div_rational_pos_closure
# 383	instantiation	401, 391, 390	|- 1 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 1
# 384	instantiation	401, 391, 392	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 385	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 386	instantiation	393, 394, 395	|- 2^{t} in Integer
# 	a : 2, b : t
# 387	instantiation	396, 397	|- (-1) in Integer
# 	a : 1
# 388	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 389	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 390	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 391	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 392	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 393	conjecture		|- forall_{a in Integer, b in Natural} (a^{b} in Integer)
# 	proveit.numbers.exponentiation.exp_int_closure
# 394	instantiation	401, 402, 398	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 395	instantiation	401, 399, 400	|- t in Natural
# 	A : NaturalPos, B : Natural, x : t
# 396	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 397	instantiation	401, 402, 403	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 398	conjecture		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 399	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 400	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 401	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 402	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 403	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
