# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#two_pow_t_minus_one_is_nat_pos">two_pow_t_minus_one_is_nat_pos</a> theorem
# ========

# %%
import proveit
from proveit.numbers import one, subtract
from proveit.physics.quantum.QPE import t_
from proveit.physics.quantum.QPE  import t_in_natural_pos
theory = proveit.Theory() # the theorem's theory

# %%
# %proving two_pow_t_minus_one_is_nat_pos
# Out:
# two_pow_t_minus_one_is_nat_pos: 2^{t - 1} in NaturalPos

# %%
# Recall that t (represented by the Literal t_)
# denotes the number of Qbits in the input register.
# Considered an axiom that t is a positive natural number
t_in_natural_pos
# Out:
# |- t in NaturalPos

# %%
subtract(t_, one).deduce_difference_in_natural()
# Out:
# |- (t - 1) in Natural

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3	|- 2^{t - 1} in NaturalPos
# 	a : 2, b : t - 1
# 1	conjecture		|- forall_{a in NaturalPos, b in Natural} (a^{b} in NaturalPos)
# 2	conjecture		|- 2 in NaturalPos
# 3	instantiation	4, 5, 6, 7	|- (t - 1) in Natural
# 	a : t, b : 1
# 4	conjecture		|- forall_{a, b in Integer | b <= a} ((a - b) in Natural)
# 5	instantiation	13, 9, 8	|- t in Integer
# 	A : Natural, B : Integer, x : t
# 6	instantiation	13, 9, 10	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 7	instantiation	11, 12	|- 1 <= t
# 	x : t, y : 1
# 8	instantiation	13, 14, 16	|- t in Natural
# 	A : NaturalPos, B : Natural, x : t
# 9	conjecture		|- Natural proper_subset Integer
# 10	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 11	theorem		|- forall_{x, y | x >= y} (y <= x)
# 	proveit.numbers.ordering.reverse_greater_eq
# 12	instantiation	15, 16	|- t >= 1
# 	n : t
# 13	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 14	conjecture		|- NaturalPos proper_subset Natural
# 15	conjecture		|- forall_{n in NaturalPos} (n >= 1)
# 16	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE.t_in_natural_pos
