# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_phase_is_real">_phase_is_real</a> theorem
# ========

# %%
import proveit
from proveit.physics.quantum.QPE import _phase_in_interval
theory = proveit.Theory() # the theorem's theory

# %%
# %proving _phase_is_real
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="_phase_is_real">_phase_is_real:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/6f97b342dd38550cb8024855d13745b7ac6dd4990/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/eb10bb1c4e919d952f82009c6c8c95a953f0b22b0/dependencies.ipynb">dependencies</a>)<br>
# _phase_is_real has been proven.  Now simply execute "%qed".

# %%
# axiomatically:
_phase_in_interval
# Out:
# |- phase in [0,1)

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._phase_is_real has been proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3, 4	|- phase in Real
# 	a : 0, b : 1, x : phase
# 1	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_co__is__real
# 2	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 3	instantiation	9, 5, 6	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 4	axiom		|- phase in [0,1)
# 	proveit.physics.quantum.QPE._phase_in_interval
# 5	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 6	instantiation	9, 7, 8	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 7	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 8	instantiation	9, 10, 11	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# ...
