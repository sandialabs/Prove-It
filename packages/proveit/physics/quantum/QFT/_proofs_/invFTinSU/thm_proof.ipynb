# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_.ipynb">physics</a>.<a class="ProveItLink" href="../../_theory_.ipynb">quantum</a>.<a class="ProveItLink" href="../_theory_.ipynb">QFT</a>.<a class="ProveItLink" href="../_theorems_.ipynb#invFTinSU">invFTinSU</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving invFTinSU
