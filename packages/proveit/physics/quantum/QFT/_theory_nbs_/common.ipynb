# %% [markdown]
# Common expressions for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.physics.quantum.QFT</a>
# ========

# %%
import proveit
# Automation is not needed when building common expressions:
# %common_expressions_notebook # Keep this at the top following 'import proveit'.

# %%
# %begin common
# Out:
# Defining common sub-expressions for theory 'proveit.physics.quantum.QFT'
# Subsequent end-of-cell assignments will define common sub-expressions
# %end_common will finalize the definitions

# %%
# %end common
# Out:
# Theory proveit.physics.quantum.QFT has no common expressions
