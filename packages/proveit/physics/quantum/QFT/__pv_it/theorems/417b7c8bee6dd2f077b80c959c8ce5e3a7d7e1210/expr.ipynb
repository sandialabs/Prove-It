# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QFT</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, j, k, n
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Exp, Interval, Mult, NaturalPos, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumBra, NumKet, Qmult
from proveit.physics.quantum.QFT import FourierTransform

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(two, n)
expr = Lambda(n, Conditional(Forall(instance_param_or_params = [j, k], instance_expr = Equals(Qmult(NumBra(k, n), FourierTransform(n), NumKet(j, n)), Qmult(frac(one, Exp(two, frac(n, two))), Exp(e, frac(Mult(two, pi, i, j, k), sub_expr1)))), domain = Interval(zero, subtract(sub_expr1, one))), InSet(n, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# n \mapsto \left\{\forall_{j, k \in \{0~\ldotp \ldotp~2^{n} - 1\}}~\left(\left({_{n}}\langle k \rvert \thinspace {\mathrm {FT}}_{n} \thinspace \lvert j \rangle_{n}\right) = \left(\frac{1}{2^{\frac{n}{2}}} \thinspace \mathsf{e}^{\frac{2 \cdot \pi \cdot \mathsf{i} \cdot j \cdot k}{2^{n}}}\right)\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. n -> {forall_{j, k in {0 .. 2^{n} - 1}} (({n}_〈k| . FT_{n} . |j〉_{n}) = ((1 / 2^{n / 2}) . e^{(2 * pi * i * j * k) / 2^{n}})) if n in NaturalPos.
#    core type: Lambda
#    parameter: 69
#    body: 1
# 1. {forall_{j, k in {0 .. 2^{n} - 1}} (({n}_〈k| . FT_{n} . |j〉_{n}) = ((1 / 2^{n / 2}) . e^{(2 * pi * i * j * k) / 2^{n}})) if n in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{j, k in {0 .. 2^{n} - 1}} (({n}_〈k| . FT_{n} . |j〉_{n}) = ((1 / 2^{n / 2}) . e^{(2 * pi * i * j * k) / 2^{n}}))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. n in NaturalPos
#    core type: Operation
#    operator: 25
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((j, k) -> {({n}_〈k| . FT_{n} . |j〉_{n}) = ((1 / 2^{n / 2}) . e^{(2 * pi * i * j * k) / 2^{n}}) if j in {0 .. 2^{n} - 1} ,  k in {0 .. 2^{n} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 69, 8
# 7. (j, k) -> {({n}_〈k| . FT_{n} . |j〉_{n}) = ((1 / 2^{n / 2}) . e^{(2 * pi * i * j * k) / 2^{n}}) if j in {0 .. 2^{n} - 1} ,  k in {0 .. 2^{n} - 1}.
#    core type: Lambda
#    parameters: 9\n   body: 10
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. (j, k)
#    core type: ExprTuple
#    sub-expressions: 66, 67
# 10. {({n}_〈k| . FT_{n} . |j〉_{n}) = ((1 / 2^{n / 2}) . e^{(2 * pi * i * j * k) / 2^{n}}) if j in {0 .. 2^{n} - 1} ,  k in {0 .. 2^{n} - 1}.
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. ({n}_〈k| . FT_{n} . |j〉_{n}) = ((1 / 2^{n / 2}) . e^{(2 * pi * i * j * k) / 2^{n}})
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (j in {0 .. 2^{n} - 1}) and (k in {0 .. 2^{n} - 1})
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. ({n}_〈k| . FT_{n} . |j〉_{n}, (1 / 2^{n / 2}) . e^{(2 * pi * i * j * k) / 2^{n}})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (j in {0 .. 2^{n} - 1}, k in {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. {n}_〈k| . FT_{n} . |j〉_{n}
#     core type: Operation
#     operator: 22
#     operands: 21
# 18. (1 / 2^{n / 2}) . e^{(2 * pi * i * j * k) / 2^{n}}
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. j in {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 25
#     operands: 24
# 20. k in {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. ({n}_〈k|, FT_{n}, |j〉_{n})
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29
# 22. .
#     core type: Literal
#     sub-expressions:
# 23. (1 / 2^{n / 2}, e^{(2 * pi * i * j * k) / 2^{n}})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 24. (j, {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 66, 32
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (k, {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 67, 32
# 27. {n}_〈k|
#     core type: Operation
#     operator: 33
#     operands: 34
# 28. FT_{n}
#     core type: Operation
#     operator: 35
#     operand: 69
# 29. |j〉_{n}
#     core type: Operation
#     operator: 37
#     operands: 38
# 30. 1 / 2^{n / 2}
#     core type: Operation
#     operator: 56
#     operands: 39
# 31. e^{(2 * pi * i * j * k) / 2^{n}}
#     core type: Operation
#     operator: 60
#     operands: 40
# 32. {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 41
#     operands: 42
# 33. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 34. (k, n)
#     core type: ExprTuple
#     sub-expressions: 67, 69
# 35. FT
#     core type: Literal
#     sub-expressions:
# 36. (n)
#     core type: ExprTuple
#     sub-expressions: 69
# 37. NUM_KET
#     core type: Literal
#     sub-expressions:
# 38. (j, n)
#     core type: ExprTuple
#     sub-expressions: 66, 69
# 39. (1, 2^{n / 2})
#     core type: ExprTuple
#     sub-expressions: 70, 43
# 40. (e, (2 * pi * i * j * k) / 2^{n})
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. Interval
#     core type: Literal
#     sub-expressions:
# 42. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. 2^{n / 2}
#     core type: Operation
#     operator: 60
#     operands: 48
# 44. e
#     core type: Literal
#     sub-expressions:
# 45. (2 * pi * i * j * k) / 2^{n}
#     core type: Operation
#     operator: 56
#     operands: 49
# 46. 0
#     core type: Literal
#     sub-expressions:
# 47. 2^{n} - 1
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. (2, n / 2)
#     core type: ExprTuple
#     sub-expressions: 68, 52
# 49. (2 * pi * i * j * k, 2^{n})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 50. +
#     core type: Literal
#     sub-expressions:
# 51. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. n / 2
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. 2 * pi * i * j * k
#     core type: Operation
#     operator: 58
#     operands: 59
# 54. 2^{n}
#     core type: Operation
#     operator: 60
#     operands: 61
# 55. -1
#     core type: Operation
#     operator: 62
#     operand: 70
# 56. /
#     core type: Literal
#     sub-expressions:
# 57. (n, 2)
#     core type: ExprTuple
#     sub-expressions: 69, 68
# 58. *
#     core type: Literal
#     sub-expressions:
# 59. (2, pi, i, j, k)
#     core type: ExprTuple
#     sub-expressions: 68, 64, 65, 66, 67
# 60. Exp
#     core type: Literal
#     sub-expressions:
# 61. (2, n)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 62. -
#     core type: Literal
#     sub-expressions:
# 63. (1)
#     core type: ExprTuple
#     sub-expressions: 70
# 64. pi
#     core type: Literal
#     sub-expressions:
# 65. i
#     core type: Literal
#     sub-expressions:
# 66. j
#     core type: Variable
#     sub-expressions:
# 67. k
#     core type: Variable
#     sub-expressions:
# 68. 2
#     core type: Literal
#     sub-expressions:
# 69. n
#     core type: Variable
#     sub-expressions:
# 70. 1
#     core type: Literal
#     sub-expressions:
