# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QFT</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, k, l, n
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Exp, Interval, Mult, NaturalPos, Neg, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumBra, NumKet, Qmult
from proveit.physics.quantum.QFT import InverseFourierTransform

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(two, n)
expr = Conditional(Forall(instance_param_or_params = [k, l], instance_expr = Equals(Qmult(NumBra(l, n), InverseFourierTransform(n), NumKet(k, n)), Mult(frac(one, Exp(two, frac(n, two))), Exp(e, frac(Neg(Mult(two, pi, i, k, l)), sub_expr1)))), domain = Interval(zero, subtract(sub_expr1, one))), InSet(n, NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{k, l \in \{0~\ldotp \ldotp~2^{n} - 1\}}~\left(\left({_{n}}\langle l \rvert \thinspace {\mathrm {FT}}^{\dag}_{n} \thinspace \lvert k \rangle_{n}\right) = \left(\frac{1}{2^{\frac{n}{2}}} \cdot \mathsf{e}^{\frac{-\left(2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot l\right)}{2^{n}}}\right)\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{k, l in {0 .. 2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})) if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{k, l in {0 .. 2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. n in NaturalPos
#    core type: Operation
#    operator: 24
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((k, l) -> {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 63, 7
# 6. (k, l) -> {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. (k, l)
#    core type: ExprTuple
#    sub-expressions: 70, 71
# 9. {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (k in {0 .. 2^{n} - 1}) and (l in {0 .. 2^{n} - 1})
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}, (1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (k in {0 .. 2^{n} - 1}, l in {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. {n}_〈l| . FT^{dag}_{n} . |k〉_{n}
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. (1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}
#     core type: Operation
#     operator: 65
#     operands: 22
# 18. k in {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 24
#     operands: 23
# 19. l in {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. .
#     core type: Literal
#     sub-expressions:
# 21. ({n}_〈l|, FT^{dag}_{n}, |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28
# 22. (1 / 2^{n / 2}, e^{(-(2 * pi * i * k * l)) / 2^{n}})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 23. (k, {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 70, 31
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (l, {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 71, 31
# 26. {n}_〈l|
#     core type: Operation
#     operator: 32
#     operands: 33
# 27. FT^{dag}_{n}
#     core type: Operation
#     operator: 34
#     operand: 63
# 28. |k〉_{n}
#     core type: Operation
#     operator: 36
#     operands: 37
# 29. 1 / 2^{n / 2}
#     core type: Operation
#     operator: 55
#     operands: 38
# 30. e^{(-(2 * pi * i * k * l)) / 2^{n}}
#     core type: Operation
#     operator: 58
#     operands: 39
# 31. {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 40
#     operands: 41
# 32. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 33. (l, n)
#     core type: ExprTuple
#     sub-expressions: 71, 63
# 34. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 35. (n)
#     core type: ExprTuple
#     sub-expressions: 63
# 36. NUM_KET
#     core type: Literal
#     sub-expressions:
# 37. (k, n)
#     core type: ExprTuple
#     sub-expressions: 70, 63
# 38. (1, 2^{n / 2})
#     core type: ExprTuple
#     sub-expressions: 64, 42
# 39. (e, (-(2 * pi * i * k * l)) / 2^{n})
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 40. Interval
#     core type: Literal
#     sub-expressions:
# 41. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. 2^{n / 2}
#     core type: Operation
#     operator: 58
#     operands: 47
# 43. e
#     core type: Literal
#     sub-expressions:
# 44. (-(2 * pi * i * k * l)) / 2^{n}
#     core type: Operation
#     operator: 55
#     operands: 48
# 45. 0
#     core type: Literal
#     sub-expressions:
# 46. 2^{n} - 1
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. (2, n / 2)
#     core type: ExprTuple
#     sub-expressions: 67, 51
# 48. (-(2 * pi * i * k * l), 2^{n})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. n / 2
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. -(2 * pi * i * k * l)
#     core type: Operation
#     operator: 60
#     operand: 62
# 53. 2^{n}
#     core type: Operation
#     operator: 58
#     operands: 59
# 54. -1
#     core type: Operation
#     operator: 60
#     operand: 64
# 55. /
#     core type: Literal
#     sub-expressions:
# 56. (n, 2)
#     core type: ExprTuple
#     sub-expressions: 63, 67
# 57. (2 * pi * i * k * l)
#     core type: ExprTuple
#     sub-expressions: 62
# 58. Exp
#     core type: Literal
#     sub-expressions:
# 59. (2, n)
#     core type: ExprTuple
#     sub-expressions: 67, 63
# 60. -
#     core type: Literal
#     sub-expressions:
# 61. (1)
#     core type: ExprTuple
#     sub-expressions: 64
# 62. 2 * pi * i * k * l
#     core type: Operation
#     operator: 65
#     operands: 66
# 63. n
#     core type: Variable
#     sub-expressions:
# 64. 1
#     core type: Literal
#     sub-expressions:
# 65. *
#     core type: Literal
#     sub-expressions:
# 66. (2, pi, i, k, l)
#     core type: ExprTuple
#     sub-expressions: 67, 68, 69, 70, 71
# 67. 2
#     core type: Literal
#     sub-expressions:
# 68. pi
#     core type: Literal
#     sub-expressions:
# 69. i
#     core type: Literal
#     sub-expressions:
# 70. k
#     core type: Variable
#     sub-expressions:
# 71. l
#     core type: Variable
#     sub-expressions:
