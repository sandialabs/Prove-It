# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QFT</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, k, l, n
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Exp, Interval, Mult, NaturalPos, Neg, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumBra, NumKet, Qmult
from proveit.physics.quantum.QFT import InverseFourierTransform

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(two, n)
expr = Lambda(n, Conditional(Forall(instance_param_or_params = [k, l], instance_expr = Equals(Qmult(NumBra(l, n), InverseFourierTransform(n), NumKet(k, n)), Mult(frac(one, Exp(two, frac(n, two))), Exp(e, frac(Neg(Mult(two, pi, i, k, l)), sub_expr1)))), domain = Interval(zero, subtract(sub_expr1, one))), InSet(n, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# n \mapsto \left\{\forall_{k, l \in \{0~\ldotp \ldotp~2^{n} - 1\}}~\left(\left({_{n}}\langle l \rvert \thinspace {\mathrm {FT}}^{\dag}_{n} \thinspace \lvert k \rangle_{n}\right) = \left(\frac{1}{2^{\frac{n}{2}}} \cdot \mathsf{e}^{\frac{-\left(2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot l\right)}{2^{n}}}\right)\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. n -> {forall_{k, l in {0 .. 2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})) if n in NaturalPos.
#    core type: Lambda
#    parameter: 64
#    body: 1
# 1. {forall_{k, l in {0 .. 2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})) if n in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{k, l in {0 .. 2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. n in NaturalPos
#    core type: Operation
#    operator: 25
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((k, l) -> {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 64, 8
# 7. (k, l) -> {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.
#    core type: Lambda
#    parameters: 9\n   body: 10
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. (k, l)
#    core type: ExprTuple
#    sub-expressions: 71, 72
# 10. {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (k in {0 .. 2^{n} - 1}) and (l in {0 .. 2^{n} - 1})
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}, (1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (k in {0 .. 2^{n} - 1}, l in {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. {n}_〈l| . FT^{dag}_{n} . |k〉_{n}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. (1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}
#     core type: Operation
#     operator: 66
#     operands: 23
# 19. k in {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 25
#     operands: 24
# 20. l in {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. .
#     core type: Literal
#     sub-expressions:
# 22. ({n}_〈l|, FT^{dag}_{n}, |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29
# 23. (1 / 2^{n / 2}, e^{(-(2 * pi * i * k * l)) / 2^{n}})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 24. (k, {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 71, 32
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (l, {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 72, 32
# 27. {n}_〈l|
#     core type: Operation
#     operator: 33
#     operands: 34
# 28. FT^{dag}_{n}
#     core type: Operation
#     operator: 35
#     operand: 64
# 29. |k〉_{n}
#     core type: Operation
#     operator: 37
#     operands: 38
# 30. 1 / 2^{n / 2}
#     core type: Operation
#     operator: 56
#     operands: 39
# 31. e^{(-(2 * pi * i * k * l)) / 2^{n}}
#     core type: Operation
#     operator: 59
#     operands: 40
# 32. {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 41
#     operands: 42
# 33. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 34. (l, n)
#     core type: ExprTuple
#     sub-expressions: 72, 64
# 35. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 36. (n)
#     core type: ExprTuple
#     sub-expressions: 64
# 37. NUM_KET
#     core type: Literal
#     sub-expressions:
# 38. (k, n)
#     core type: ExprTuple
#     sub-expressions: 71, 64
# 39. (1, 2^{n / 2})
#     core type: ExprTuple
#     sub-expressions: 65, 43
# 40. (e, (-(2 * pi * i * k * l)) / 2^{n})
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. Interval
#     core type: Literal
#     sub-expressions:
# 42. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. 2^{n / 2}
#     core type: Operation
#     operator: 59
#     operands: 48
# 44. e
#     core type: Literal
#     sub-expressions:
# 45. (-(2 * pi * i * k * l)) / 2^{n}
#     core type: Operation
#     operator: 56
#     operands: 49
# 46. 0
#     core type: Literal
#     sub-expressions:
# 47. 2^{n} - 1
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. (2, n / 2)
#     core type: ExprTuple
#     sub-expressions: 68, 52
# 49. (-(2 * pi * i * k * l), 2^{n})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 50. +
#     core type: Literal
#     sub-expressions:
# 51. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. n / 2
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. -(2 * pi * i * k * l)
#     core type: Operation
#     operator: 61
#     operand: 63
# 54. 2^{n}
#     core type: Operation
#     operator: 59
#     operands: 60
# 55. -1
#     core type: Operation
#     operator: 61
#     operand: 65
# 56. /
#     core type: Literal
#     sub-expressions:
# 57. (n, 2)
#     core type: ExprTuple
#     sub-expressions: 64, 68
# 58. (2 * pi * i * k * l)
#     core type: ExprTuple
#     sub-expressions: 63
# 59. Exp
#     core type: Literal
#     sub-expressions:
# 60. (2, n)
#     core type: ExprTuple
#     sub-expressions: 68, 64
# 61. -
#     core type: Literal
#     sub-expressions:
# 62. (1)
#     core type: ExprTuple
#     sub-expressions: 65
# 63. 2 * pi * i * k * l
#     core type: Operation
#     operator: 66
#     operands: 67
# 64. n
#     core type: Variable
#     sub-expressions:
# 65. 1
#     core type: Literal
#     sub-expressions:
# 66. *
#     core type: Literal
#     sub-expressions:
# 67. (2, pi, i, k, l)
#     core type: ExprTuple
#     sub-expressions: 68, 69, 70, 71, 72
# 68. 2
#     core type: Literal
#     sub-expressions:
# 69. pi
#     core type: Literal
#     sub-expressions:
# 70. i
#     core type: Literal
#     sub-expressions:
# 71. k
#     core type: Variable
#     sub-expressions:
# 72. l
#     core type: Variable
#     sub-expressions:
