# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QFT</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, k, l, n
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Exp, Interval, Mult, NaturalPos, Neg, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumBra, NumKet, Qmult
from proveit.physics.quantum.QFT import InverseFourierTransform

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(two, n)
expr = ExprTuple(Lambda(n, Conditional(Forall(instance_param_or_params = [k, l], instance_expr = Equals(Qmult(NumBra(l, n), InverseFourierTransform(n), NumKet(k, n)), Mult(frac(one, Exp(two, frac(n, two))), Exp(e, frac(Neg(Mult(two, pi, i, k, l)), sub_expr1)))), domain = Interval(zero, subtract(sub_expr1, one))), InSet(n, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(n \mapsto \left\{\forall_{k, l \in \{0~\ldotp \ldotp~2^{n} - 1\}}~\left(\left({_{n}}\langle l \rvert \thinspace {\mathrm {FT}}^{\dag}_{n} \thinspace \lvert k \rangle_{n}\right) = \left(\frac{1}{2^{\frac{n}{2}}} \cdot \mathsf{e}^{\frac{-\left(2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot l\right)}{2^{n}}}\right)\right) \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (n -> {forall_{k, l in {0 .. 2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{k, l in {0 .. 2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})) if n in NaturalPos.
#    core type: Lambda
#    parameter: 65
#    body: 2
# 2. {forall_{k, l in {0 .. 2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{k, l in {0 .. 2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. n in NaturalPos
#    core type: Operation
#    operator: 26
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((k, l) -> {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 65, 9
# 8. (k, l) -> {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (k, l)
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 11. {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (k in {0 .. 2^{n} - 1}) and (l in {0 .. 2^{n} - 1})
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}, (1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (k in {0 .. 2^{n} - 1}, l in {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. {n}_〈l| . FT^{dag}_{n} . |k〉_{n}
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. (1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}
#     core type: Operation
#     operator: 67
#     operands: 24
# 20. k in {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 26
#     operands: 25
# 21. l in {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. .
#     core type: Literal
#     sub-expressions:
# 23. ({n}_〈l|, FT^{dag}_{n}, |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30
# 24. (1 / 2^{n / 2}, e^{(-(2 * pi * i * k * l)) / 2^{n}})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 25. (k, {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 72, 33
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (l, {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 73, 33
# 28. {n}_〈l|
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. FT^{dag}_{n}
#     core type: Operation
#     operator: 36
#     operand: 65
# 30. |k〉_{n}
#     core type: Operation
#     operator: 38
#     operands: 39
# 31. 1 / 2^{n / 2}
#     core type: Operation
#     operator: 57
#     operands: 40
# 32. e^{(-(2 * pi * i * k * l)) / 2^{n}}
#     core type: Operation
#     operator: 60
#     operands: 41
# 33. {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 42
#     operands: 43
# 34. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 35. (l, n)
#     core type: ExprTuple
#     sub-expressions: 73, 65
# 36. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 37. (n)
#     core type: ExprTuple
#     sub-expressions: 65
# 38. NUM_KET
#     core type: Literal
#     sub-expressions:
# 39. (k, n)
#     core type: ExprTuple
#     sub-expressions: 72, 65
# 40. (1, 2^{n / 2})
#     core type: ExprTuple
#     sub-expressions: 66, 44
# 41. (e, (-(2 * pi * i * k * l)) / 2^{n})
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. Interval
#     core type: Literal
#     sub-expressions:
# 43. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 44. 2^{n / 2}
#     core type: Operation
#     operator: 60
#     operands: 49
# 45. e
#     core type: Literal
#     sub-expressions:
# 46. (-(2 * pi * i * k * l)) / 2^{n}
#     core type: Operation
#     operator: 57
#     operands: 50
# 47. 0
#     core type: Literal
#     sub-expressions:
# 48. 2^{n} - 1
#     core type: Operation
#     operator: 51
#     operands: 52
# 49. (2, n / 2)
#     core type: ExprTuple
#     sub-expressions: 69, 53
# 50. (-(2 * pi * i * k * l), 2^{n})
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 51. +
#     core type: Literal
#     sub-expressions:
# 52. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. n / 2
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. -(2 * pi * i * k * l)
#     core type: Operation
#     operator: 62
#     operand: 64
# 55. 2^{n}
#     core type: Operation
#     operator: 60
#     operands: 61
# 56. -1
#     core type: Operation
#     operator: 62
#     operand: 66
# 57. /
#     core type: Literal
#     sub-expressions:
# 58. (n, 2)
#     core type: ExprTuple
#     sub-expressions: 65, 69
# 59. (2 * pi * i * k * l)
#     core type: ExprTuple
#     sub-expressions: 64
# 60. Exp
#     core type: Literal
#     sub-expressions:
# 61. (2, n)
#     core type: ExprTuple
#     sub-expressions: 69, 65
# 62. -
#     core type: Literal
#     sub-expressions:
# 63. (1)
#     core type: ExprTuple
#     sub-expressions: 66
# 64. 2 * pi * i * k * l
#     core type: Operation
#     operator: 67
#     operands: 68
# 65. n
#     core type: Variable
#     sub-expressions:
# 66. 1
#     core type: Literal
#     sub-expressions:
# 67. *
#     core type: Literal
#     sub-expressions:
# 68. (2, pi, i, k, l)
#     core type: ExprTuple
#     sub-expressions: 69, 70, 71, 72, 73
# 69. 2
#     core type: Literal
#     sub-expressions:
# 70. pi
#     core type: Literal
#     sub-expressions:
# 71. i
#     core type: Literal
#     sub-expressions:
# 72. k
#     core type: Variable
#     sub-expressions:
# 73. l
#     core type: Variable
#     sub-expressions:
