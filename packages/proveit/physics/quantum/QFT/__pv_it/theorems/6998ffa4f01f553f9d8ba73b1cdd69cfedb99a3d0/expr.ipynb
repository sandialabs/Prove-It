# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QFT</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, k, l, n
from proveit.linalg import MatrixProd
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import RegisterBra, RegisterKet
from proveit.physics.quantum.QFT import InverseFourierTransform

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(two, n)
sub_expr2 = Interval(zero, Add(sub_expr1, Neg(one)))
expr = Conditional(Equals(MatrixProd(RegisterBra(l, n), InverseFourierTransform(n), RegisterKet(k, n)), Mult(frac(one, sqrt(sub_expr1)), Exp(e, frac(Neg(Mult(two, pi, i, k, l)), sub_expr1)))), And(InSet(k, sub_expr2), InSet(l, sub_expr2)))
# Out:
# expr: {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0...2^{n} - 1} ,  l in {0...2^{n} - 1}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left({_{n}}\langle l \rvert \thinspace {\mathrm {FT}}^{\dag}_{n} \thinspace \lvert k \rangle_{n}\right) = \left(\frac{1}{\sqrt{(2^{n})}} \cdot \mathsf{e}^{\frac{-\left(2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot l\right)}{2^{n}}}\right) \textrm{ if } k \in \{0 \dots 2^{n} - 1\} ,  l \in \{0 \dots 2^{n} - 1\}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0...2^{n} - 1} ,  l in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (k in {0...2^{n} - 1}) and (l in {0...2^{n} - 1})
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}, (1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (k in {0...2^{n} - 1}, l in {0...2^{n} - 1})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. {n}_〈l| . FT^{dag}_{n} . |k〉_{n}
#    core type: Operation
#    operator: 11
#    operands: 12
# ...
