# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QFT</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, l, n
from proveit.logic import Equals, Forall
from proveit.numbers import Exp, Interval, Mult, Neg, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumBra, NumKet, Qmult
from proveit.physics.quantum.QFT import InverseFourierTransform

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(two, n)
expr = Forall(instance_param_or_params = [k, l], instance_expr = Equals(Qmult(NumBra(l, n), InverseFourierTransform(n), NumKet(k, n)), Mult(frac(one, Exp(two, frac(n, two))), Exp(e, frac(Neg(Mult(two, pi, i, k, l)), sub_expr1)))), domain = Interval(zero, subtract(sub_expr1, one)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{k, l \in \{0~\ldotp \ldotp~2^{n} - 1\}}~\left(\left({_{n}}\langle l \rvert \thinspace {\mathrm {FT}}^{\dag}_{n} \thinspace \lvert k \rangle_{n}\right) = \left(\frac{1}{2^{\frac{n}{2}}} \cdot \mathsf{e}^{\frac{-\left(2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot l\right)}{2^{n}}}\right)\right)

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{k, l in {0 .. 2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((k, l) -> {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (k, l) -> {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (k, l)
#    core type: ExprTuple
#    sub-expressions: 66, 67
# 5. {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (k in {0 .. 2^{n} - 1}) and (l in {0 .. 2^{n} - 1})
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}, (1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (k in {0 .. 2^{n} - 1}, l in {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. {n}_〈l| . FT^{dag}_{n} . |k〉_{n}
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}
#     core type: Operation
#     operator: 61
#     operands: 18
# 14. k in {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 20
#     operands: 19
# 15. l in {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. .
#     core type: Literal
#     sub-expressions:
# 17. ({n}_〈l|, FT^{dag}_{n}, |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 18. (1 / 2^{n / 2}, e^{(-(2 * pi * i * k * l)) / 2^{n}})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 19. (k, {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 66, 27
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (l, {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 67, 27
# 22. {n}_〈l|
#     core type: Operation
#     operator: 28
#     operands: 29
# 23. FT^{dag}_{n}
#     core type: Operation
#     operator: 30
#     operand: 59
# 24. |k〉_{n}
#     core type: Operation
#     operator: 32
#     operands: 33
# 25. 1 / 2^{n / 2}
#     core type: Operation
#     operator: 51
#     operands: 34
# 26. e^{(-(2 * pi * i * k * l)) / 2^{n}}
#     core type: Operation
#     operator: 54
#     operands: 35
# 27. {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 36
#     operands: 37
# 28. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 29. (l, n)
#     core type: ExprTuple
#     sub-expressions: 67, 59
# 30. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 31. (n)
#     core type: ExprTuple
#     sub-expressions: 59
# 32. NUM_KET
#     core type: Literal
#     sub-expressions:
# 33. (k, n)
#     core type: ExprTuple
#     sub-expressions: 66, 59
# 34. (1, 2^{n / 2})
#     core type: ExprTuple
#     sub-expressions: 60, 38
# 35. (e, (-(2 * pi * i * k * l)) / 2^{n})
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. Interval
#     core type: Literal
#     sub-expressions:
# 37. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 38. 2^{n / 2}
#     core type: Operation
#     operator: 54
#     operands: 43
# 39. e
#     core type: Literal
#     sub-expressions:
# 40. (-(2 * pi * i * k * l)) / 2^{n}
#     core type: Operation
#     operator: 51
#     operands: 44
# 41. 0
#     core type: Literal
#     sub-expressions:
# 42. 2^{n} - 1
#     core type: Operation
#     operator: 45
#     operands: 46
# 43. (2, n / 2)
#     core type: ExprTuple
#     sub-expressions: 63, 47
# 44. (-(2 * pi * i * k * l), 2^{n})
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 45. +
#     core type: Literal
#     sub-expressions:
# 46. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 47. n / 2
#     core type: Operation
#     operator: 51
#     operands: 52
# 48. -(2 * pi * i * k * l)
#     core type: Operation
#     operator: 56
#     operand: 58
# 49. 2^{n}
#     core type: Operation
#     operator: 54
#     operands: 55
# 50. -1
#     core type: Operation
#     operator: 56
#     operand: 60
# 51. /
#     core type: Literal
#     sub-expressions:
# 52. (n, 2)
#     core type: ExprTuple
#     sub-expressions: 59, 63
# 53. (2 * pi * i * k * l)
#     core type: ExprTuple
#     sub-expressions: 58
# 54. Exp
#     core type: Literal
#     sub-expressions:
# 55. (2, n)
#     core type: ExprTuple
#     sub-expressions: 63, 59
# 56. -
#     core type: Literal
#     sub-expressions:
# 57. (1)
#     core type: ExprTuple
#     sub-expressions: 60
# 58. 2 * pi * i * k * l
#     core type: Operation
#     operator: 61
#     operands: 62
# 59. n
#     core type: Variable
#     sub-expressions:
# 60. 1
#     core type: Literal
#     sub-expressions:
# 61. *
#     core type: Literal
#     sub-expressions:
# 62. (2, pi, i, k, l)
#     core type: ExprTuple
#     sub-expressions: 63, 64, 65, 66, 67
# 63. 2
#     core type: Literal
#     sub-expressions:
# 64. pi
#     core type: Literal
#     sub-expressions:
# 65. i
#     core type: Literal
#     sub-expressions:
# 66. k
#     core type: Variable
#     sub-expressions:
# 67. l
#     core type: Variable
#     sub-expressions:
