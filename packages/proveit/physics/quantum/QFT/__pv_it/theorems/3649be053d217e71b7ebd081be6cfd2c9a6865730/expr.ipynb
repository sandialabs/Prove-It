# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QFT</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, k, l, n
from proveit.logic import And, Equals, InSet
from proveit.numbers import Exp, Interval, Mult, Neg, e, frac, i, one, pi, subtract, two, zero
from proveit.physics.quantum import NumBra, NumKet, Qmult
from proveit.physics.quantum.QFT import InverseFourierTransform

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(two, n)
sub_expr2 = Interval(zero, subtract(sub_expr1, one))
expr = ExprTuple(Lambda([k, l], Conditional(Equals(Qmult(NumBra(l, n), InverseFourierTransform(n), NumKet(k, n)), Mult(frac(one, Exp(two, frac(n, two))), Exp(e, frac(Neg(Mult(two, pi, i, k, l)), sub_expr1)))), And(InSet(k, sub_expr2), InSet(l, sub_expr2)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(k, l\right) \mapsto \left\{\left({_{n}}\langle l \rvert \thinspace {\mathrm {FT}}^{\dag}_{n} \thinspace \lvert k \rangle_{n}\right) = \left(\frac{1}{2^{\frac{n}{2}}} \cdot \mathsf{e}^{\frac{-\left(2 \cdot \pi \cdot \mathsf{i} \cdot k \cdot l\right)}{2^{n}}}\right) \textrm{ if } k \in \{0~\ldotp \ldotp~2^{n} - 1\} ,  l \in \{0~\ldotp \ldotp~2^{n} - 1\}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((k, l) -> {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (k, l) -> {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (k, l)
#    core type: ExprTuple
#    sub-expressions: 64, 65
# 3. {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0 .. 2^{n} - 1} ,  l in {0 .. 2^{n} - 1}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (k in {0 .. 2^{n} - 1}) and (l in {0 .. 2^{n} - 1})
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}, (1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (k in {0 .. 2^{n} - 1}, l in {0 .. 2^{n} - 1})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. {n}_〈l| . FT^{dag}_{n} . |k〉_{n}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}
#     core type: Operation
#     operator: 59
#     operands: 16
# 12. k in {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 18
#     operands: 17
# 13. l in {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. .
#     core type: Literal
#     sub-expressions:
# 15. ({n}_〈l|, FT^{dag}_{n}, |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22
# 16. (1 / 2^{n / 2}, e^{(-(2 * pi * i * k * l)) / 2^{n}})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 17. (k, {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 64, 25
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (l, {0 .. 2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 65, 25
# 20. {n}_〈l|
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. FT^{dag}_{n}
#     core type: Operation
#     operator: 28
#     operand: 57
# 22. |k〉_{n}
#     core type: Operation
#     operator: 30
#     operands: 31
# 23. 1 / 2^{n / 2}
#     core type: Operation
#     operator: 49
#     operands: 32
# 24. e^{(-(2 * pi * i * k * l)) / 2^{n}}
#     core type: Operation
#     operator: 52
#     operands: 33
# 25. {0 .. 2^{n} - 1}
#     core type: Operation
#     operator: 34
#     operands: 35
# 26. NUM_BRA
#     core type: Literal
#     sub-expressions:
# 27. (l, n)
#     core type: ExprTuple
#     sub-expressions: 65, 57
# 28. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 29. (n)
#     core type: ExprTuple
#     sub-expressions: 57
# 30. NUM_KET
#     core type: Literal
#     sub-expressions:
# 31. (k, n)
#     core type: ExprTuple
#     sub-expressions: 64, 57
# 32. (1, 2^{n / 2})
#     core type: ExprTuple
#     sub-expressions: 58, 36
# 33. (e, (-(2 * pi * i * k * l)) / 2^{n})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. Interval
#     core type: Literal
#     sub-expressions:
# 35. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. 2^{n / 2}
#     core type: Operation
#     operator: 52
#     operands: 41
# 37. e
#     core type: Literal
#     sub-expressions:
# 38. (-(2 * pi * i * k * l)) / 2^{n}
#     core type: Operation
#     operator: 49
#     operands: 42
# 39. 0
#     core type: Literal
#     sub-expressions:
# 40. 2^{n} - 1
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. (2, n / 2)
#     core type: ExprTuple
#     sub-expressions: 61, 45
# 42. (-(2 * pi * i * k * l), 2^{n})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 45. n / 2
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. -(2 * pi * i * k * l)
#     core type: Operation
#     operator: 54
#     operand: 56
# 47. 2^{n}
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. -1
#     core type: Operation
#     operator: 54
#     operand: 58
# 49. /
#     core type: Literal
#     sub-expressions:
# 50. (n, 2)
#     core type: ExprTuple
#     sub-expressions: 57, 61
# 51. (2 * pi * i * k * l)
#     core type: ExprTuple
#     sub-expressions: 56
# 52. Exp
#     core type: Literal
#     sub-expressions:
# 53. (2, n)
#     core type: ExprTuple
#     sub-expressions: 61, 57
# 54. -
#     core type: Literal
#     sub-expressions:
# 55. (1)
#     core type: ExprTuple
#     sub-expressions: 58
# 56. 2 * pi * i * k * l
#     core type: Operation
#     operator: 59
#     operands: 60
# 57. n
#     core type: Variable
#     sub-expressions:
# 58. 1
#     core type: Literal
#     sub-expressions:
# 59. *
#     core type: Literal
#     sub-expressions:
# 60. (2, pi, i, k, l)
#     core type: ExprTuple
#     sub-expressions: 61, 62, 63, 64, 65
# 61. 2
#     core type: Literal
#     sub-expressions:
# 62. pi
#     core type: Literal
#     sub-expressions:
# 63. i
#     core type: Literal
#     sub-expressions:
# 64. k
#     core type: Variable
#     sub-expressions:
# 65. l
#     core type: Variable
#     sub-expressions:
