# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QFT</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import k, l, n
from proveit.linalg import MatrixProd
from proveit.logic import Equals, Forall
from proveit.number import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import RegisterBra, RegisterKet
from proveit.physics.quantum.QFT import InverseFourierTransform

# %%
# build up the expression from sub-expressions
subExpr1 = Exp(two, n)
subExpr2 = Interval(zero, Add(subExpr1, Neg(one)))
expr = Forall([k, l], Equals(MatrixProd(RegisterBra(l, n), InverseFourierTransform(n), RegisterKet(k, n)), Mult(frac(one, sqrt(subExpr1)), Exp(e, frac(Neg(Mult(two, pi, i, k, l)), subExpr1)))), domains = [subExpr2, subExpr2])
# Out:
# expr: forall_{k in {0...2^{n} - 1}, l in {0...2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{k \in \{0 \dots 2^{n} - 1\}, l \in \{0 \dots 2^{n} - 1\}}~\left(\left({_{n}}\langle l \rvert \thinspace {\mathrm {FT}}^{\dag}_{n} \thinspace \lvert k \rangle_{n}\right) = \left(\frac{1}{\sqrt{(2^{n})}} \cdot e^{\frac{-\left(2 \cdot \pi \cdot i \cdot k \cdot l\right)}{2^{n}}}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{k in {0...2^{n} - 1}, l in {0...2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (k, l) -> {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0...2^{n} - 1} ,  l in {0...2^{n} - 1}.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (k, l)
#    core type: ExprTuple
#    sub-expressions: 62, 63
# 4. {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0...2^{n} - 1} ,  l in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (k in {0...2^{n} - 1}) and (l in {0...2^{n} - 1})
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}, (1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (k in {0...2^{n} - 1}, l in {0...2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. {n}_〈l| . FT^{dag}_{n} . |k〉_{n}
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}
#     core type: Operation
#     operator: 56
#     operands: 17
# 13. k in {0...2^{n} - 1}
#     core type: Operation
#     operator: 19
#     operands: 18
# 14. l in {0...2^{n} - 1}
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. .
#     core type: Literal
#     sub-expressions:
# 16. ({n}_〈l|, FT^{dag}_{n}, |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23
# 17. (1 / sqrt((2^{n})), e^{(-(2 * pi * i * k * l)) / 2^{n}})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 18. (k, {0...2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 62, 26
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (l, {0...2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 63, 26
# 21. {n}_〈l|
#     core type: Operation
#     operator: 27
#     operands: 28
# 22. FT^{dag}_{n}
#     core type: Operation
#     operator: 29
#     operand: 58
# 23. |k〉_{n}
#     core type: Operation
#     operator: 30
#     operands: 31
# 24. 1 / sqrt((2^{n}))
#     core type: Operation
#     operator: 49
#     operands: 32
# 25. e^{(-(2 * pi * i * k * l)) / 2^{n}}
#     core type: Operation
#     operator: 52
#     operands: 33
# 26. {0...2^{n} - 1}
#     core type: Operation
#     operator: 34
#     operands: 35
# 27. REGISTER_BRA
#     core type: Literal
#     sub-expressions:
# 28. (l, n)
#     core type: ExprTuple
#     sub-expressions: 63, 58
# 29. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 30. REGISTER_KET
#     core type: Literal
#     sub-expressions:
# 31. (k, n)
#     core type: ExprTuple
#     sub-expressions: 62, 58
# 32. (1, sqrt((2^{n})))
#     core type: ExprTuple
#     sub-expressions: 55, 36
# 33. (e, (-(2 * pi * i * k * l)) / 2^{n})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 34. Interval
#     core type: Literal
#     sub-expressions:
# 35. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. sqrt((2^{n}))
#     core type: Operation
#     operator: 52
#     operands: 41
# 37. e
#     core type: Literal
#     sub-expressions:
# 38. (-(2 * pi * i * k * l)) / 2^{n}
#     core type: Operation
#     operator: 49
#     operands: 42
# 39. 0
#     core type: Literal
#     sub-expressions:
# 40. 2^{n} - 1
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. (2^{n}, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 47, 45
# 42. (-(2 * pi * i * k * l), 2^{n})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 45. 1 / 2
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. -(2 * pi * i * k * l)
#     core type: Operation
#     operator: 54
#     operand: 51
# 47. 2^{n}
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. -1
#     core type: Operation
#     operator: 54
#     operand: 55
# 49. /
#     core type: Literal
#     sub-expressions:
# 50. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 55, 59
# 51. 2 * pi * i * k * l
#     core type: Operation
#     operator: 56
#     operands: 57
# 52. Exp
#     core type: Literal
#     sub-expressions:
# 53. (2, n)
#     core type: ExprTuple
#     sub-expressions: 59, 58
# 54. -
#     core type: Literal
#     sub-expressions:
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. *
#     core type: Literal
#     sub-expressions:
# 57. (2, pi, i, k, l)
#     core type: ExprTuple
#     sub-expressions: 59, 60, 61, 62, 63
# 58. n
#     core type: Variable
#     sub-expressions:
# 59. 2
#     core type: Literal
#     sub-expressions:
# 60. pi
#     core type: Literal
#     sub-expressions:
# 61. i
#     core type: Literal
#     sub-expressions:
# 62. k
#     core type: Variable
#     sub-expressions:
# 63. l
#     core type: Variable
#     sub-expressions:
