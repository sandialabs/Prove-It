# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QFT</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import k, l, n
from proveit.linalg import MatrixProd
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Exp, Interval, Mult, NaturalsPos, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import RegisterBra, RegisterKet
from proveit.physics.quantum.QFT import InverseFourierTransform

# %%
# build up the expression from sub-expressions
subExpr1 = Exp(two, n)
subExpr2 = Interval(zero, Add(subExpr1, Neg(one)))
expr = Conditional(Forall([k, l], Equals(MatrixProd(RegisterBra(l, n), InverseFourierTransform(n), RegisterKet(k, n)), Mult(frac(one, sqrt(subExpr1)), Exp(e, frac(Neg(Mult(two, pi, i, k, l)), subExpr1)))), domains = [subExpr2, subExpr2]), InSet(n, NaturalsPos))
# Out:
# expr: {forall_{k in {0...2^{n} - 1}, l in {0...2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{k \in \{0 \dots 2^{n} - 1\}, l \in \{0 \dots 2^{n} - 1\}}~\left(\left({_{n}}\langle l \rvert \thinspace {\mathrm {FT}}^{\dag}_{n} \thinspace \lvert k \rangle_{n}\right) = \left(\frac{1}{\sqrt{(2^{n})}} \cdot e^{\frac{-\left(2 \cdot \pi \cdot i \cdot k \cdot l\right)}{2^{n}}}\right)\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{k in {0...2^{n} - 1}, l in {0...2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})) if n in NaturalsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{k in {0...2^{n} - 1}, l in {0...2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. n in NaturalsPos
#    core type: Operation
#    operator: 23
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (k, l) -> {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0...2^{n} - 1} ,  l in {0...2^{n} - 1}.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 5. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 62, 8
# 6. (k, l)
#    core type: ExprTuple
#    sub-expressions: 66, 67
# ...
