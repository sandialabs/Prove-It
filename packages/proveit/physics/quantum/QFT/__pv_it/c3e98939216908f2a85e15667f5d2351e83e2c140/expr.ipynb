# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QFT</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import n
from proveit.linalg import SU
from proveit.logic import InSet
from proveit.number import Exp, NaturalsPos, two
from proveit.physics.quantum.QFT import InverseFourierTransform

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(InSet(InverseFourierTransform(n), SU(Exp(two, n))), InSet(n, NaturalsPos)))
# Out:
# expr: n -> {FT^{dag}_{n} in [SU](2^{n}) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{{\mathrm {FT}}^{\dag}_{n} \in \left[SU\right]\left(2^{n}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {FT^{dag}_{n} in [SU](2^{n}) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 16
#    body: 1
# 1. {FT^{dag}_{n} in [SU](2^{n}) if n in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. FT^{dag}_{n} in [SU](2^{n})
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. n in NaturalsPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (FT^{dag}_{n}, [SU](2^{n}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 16, 9
# 7. FT^{dag}_{n}
#    core type: Operation
#    operator: 10
#    operand: 16
# 8. [SU](2^{n})
#    core type: Operation
#    operator: 11
#    operand: 12
# 9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. FT^{dag}
#     core type: Literal
#     sub-expressions:
# 11. SU
#     core type: Literal
#     sub-expressions:
# 12. 2^{n}
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. Exp
#     core type: Literal
#     sub-expressions:
# 14. (2, n)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. n
#     core type: Variable
#     sub-expressions:
