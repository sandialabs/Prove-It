# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QFT</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import k, l, n
from proveit.linalg import MatrixProd
from proveit.logic import And, Equals, InSet
from proveit.number import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import RegisterBra, RegisterKet
from proveit.physics.quantum.QFT import InverseFourierTransform

# %%
# build up the expression from sub-expressions
subExpr1 = Exp(two, n)
subExpr2 = Interval(zero, Add(subExpr1, Neg(one)))
expr = Lambda([k, l], Conditional(Equals(MatrixProd(RegisterBra(l, n), InverseFourierTransform(n), RegisterKet(k, n)), Mult(frac(one, sqrt(subExpr1)), Exp(e, frac(Neg(Mult(two, pi, i, k, l)), subExpr1)))), And(InSet(k, subExpr2), InSet(l, subExpr2))))
# Out:
# expr: (k, l) -> {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0...2^{n} - 1} ,  l in {0...2^{n} - 1}.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(k, l\right) \mapsto \left\{\left({_{n}}\langle l \rvert \thinspace {\mathrm {FT}}^{\dag}_{n} \thinspace \lvert k \rangle_{n}\right) = \left(\frac{1}{\sqrt{(2^{n})}} \cdot e^{\frac{-\left(2 \cdot \pi \cdot i \cdot k \cdot l\right)}{2^{n}}}\right) \textrm{ if } k \in \{0 \dots 2^{n} - 1\} ,  l \in \{0 \dots 2^{n} - 1\}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (k, l) -> {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0...2^{n} - 1} ,  l in {0...2^{n} - 1}.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (k, l)
#    core type: ExprTuple
#    sub-expressions: 60, 61
# 2. {({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}) if k in {0...2^{n} - 1} ,  l in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (k in {0...2^{n} - 1}) and (l in {0...2^{n} - 1})
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ({n}_〈l| . FT^{dag}_{n} . |k〉_{n}, (1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
# ...
