# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#invFTonMatrixElem">invFTonMatrixElem</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum.QFT</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum.QFT._theorems_ import invFTonMatrixElem

# %%
# check that the built expression is the same as the stored expression
# %check_expr invFTonMatrixElem
# Out:
# Passed sanity check: built 'invFTonMatrixElem' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(invFTonMatrixElem.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{k \in \{0 \dots 2^{n} - 1\}, l \in \{0 \dots 2^{n} - 1\}}~\left(\left({_{n}}\langle l \rvert \thinspace {\mathrm {FT}}^{\dag}_{n} \thinspace \lvert k \rangle_{n}\right) = \left(\frac{1}{\sqrt{(2^{n})}} \cdot e^{\frac{-\left(2 \cdot \pi \cdot i \cdot k \cdot l\right)}{2^{n}}}\right)\right)\right]

# %%
# display the expression information
invFTonMatrixElem.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{k in {0...2^{n} - 1}, l in {0...2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{k in {0...2^{n} - 1}, l in {0...2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 64
#    body: 2
# 2. {forall_{k in {0...2^{n} - 1}, l in {0...2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}})) if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{k in {0...2^{n} - 1}, l in {0...2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / sqrt((2^{n}))) * e^{(-(2 * pi * i * k * l)) / 2^{n}}))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalsPos
#    core type: Operation
#    operator: 25
# ...
