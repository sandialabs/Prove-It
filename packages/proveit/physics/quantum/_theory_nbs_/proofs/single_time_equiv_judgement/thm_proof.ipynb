# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theorems.ipynb#single_time_equiv_judgement">single_time_equiv_judgement</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving single_time_equiv_judgement
# Out:
# single_time_equiv_judgement: forall_{h, k, m in NaturalPos} [forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}} ((( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
# ...
