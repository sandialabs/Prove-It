# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">physics</a>.<a class="ProveItLink" href="../_context_.ipynb">quantum</a>.<a class="ProveItLink" href="../_theorems_.ipynb#transformedQubitStateInQubitSpace">transformedQubitStateInQubitSpace</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving transformedQubitStateInQubitSpace presuming []
# Out:
# Beginning proof of transformedQubitStateInQubitSpace
# Recorded 'presuming' information
# Presuming previous theorems (applied transitively).
# transformedQubitStateInQubitSpace: forall_{x in Complexes^{2}} [forall_{U in [SU](2)} ((U . x) in Complexes^{2})]
