# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">physics</a>.<a class="ProveItLink" href="../_context_.ipynb">quantum</a>.<a class="ProveItLink" href="../_theorems_.ipynb#empty_multiQubitGate_reduction">empty_multiQubitGate_reduction</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving empty_multiQubitGate_reduction presuming []
