# %% [markdown]
# Demonstrations for context <a class="ProveItLink" href="_context_.ipynb">proveit.physics.quantum</a>
# ========

# %%
import proveit
proveit.defaults.automation = False # prevents proveit from calling automations that are currently broken
from proveit import ExprArray, ExprTuple, ExprRange, indexed_var
from proveit._common_ import A, B, C, D, E, F, G, K, M, U, a, b, h, i, j, k, m, n, p, q, r, s, t, u 
from proveit.logic import Equals
from proveit.logic.set_theory import Set
from proveit.number import Neg, zero, one, two, three, four, five, six, seven, eight, nine
from proveit.physics.quantum.circuit import Gate, Target, Circuit, Input, Output, MultiQubitGate, IdentityOp
from proveit.physics.quantum._common_ import H, X, Z, I, ket1, ket0, ketPlus, ketMinus, SPACE, CONTROL, CLASSICAL_CONTROL
# %begin demonstrations

# %%
Aih = indexed_var(A,(i,h))
# Out:
# Aih: A_{i,h}

# %%
Bij = indexed_var(B,(i,j))
# Out:
# Bij: B_{i,j}

# %%
Cik = indexed_var(C,(i,k))
# Out:
# Cik: C_{i,k}

# %%
Dth = indexed_var(D,(t,h))
# Out:
# Dth: D_{t,h}

# %%
Etj = indexed_var(E,(t,j))
# Out:
# Etj: E_{t,j}

# %%
Ftk = indexed_var(F,(t,k))
# Out:
# Ftk: F_{t,k}

# %%
Guh = indexed_var(G,(u,h))
# Out:
# Guh: G_{u,h}

# %%
Kuj = indexed_var(K,(u,j))
# Out:
# Kuj: K_{u,j}

# %%
Muk = indexed_var(M,(u,k))
# Out:
# Muk: M_{u,k}

# %%
Circuit(ExprRange(i, ExprTuple(ExprRange(h, Aih, one, m)), one, q),
         ExprTuple(ExprRange(h, Dth, one, m)),
         ExprRange(u, ExprTuple(ExprRange(h, Guh, one, m)), one, s))
# Out:
#  A_{1,1}  & ..A_{1,h}..  & A_{1,m}   \\
#    \colon  & \colon  & \colon   \\
#    A_{i,1}  & ..A_{i,h}..  & A_{i,m}   \\
#    \colon  & \colon  & \colon   \\
#    A_{q,1}  & ..A_{q,h}..  & A_{q,m}   \\
#    D_{t,1}  & ..D_{t,h}..  & D_{t,m}   \\
#    G_{1,1}  & ..G_{1,h}..  & G_{1,m}   \\
#    \colon  & \colon  & \colon   \\
#    G_{u,1}  & ..G_{u,h}..  & G_{u,m}   \\
#    \colon  & \colon  & \colon   \\
#    G_{s,1}  & ..G_{s,h}..  & G_{s,m}
# \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1,1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1,m}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i,h}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{q,1}} & \gate{\cdots} & \gate{A_{q,m}}   \\
#   & \gate{D_{t,1}} & \gate{\cdots} & \gate{D_{t,m}}   \\
#   & \gate{G_{1,1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{G_{1,m}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{G_{u,h}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{G_{s,1}} & \gate{\cdots} & \gate{G_{s,m}}
# }
#  A_{1,1}  & ..A_{1,h}..  & A_{1,m}   \\
#    \colon  & \colon  & \colon   \\
#    A_{i,1}  & ..A_{i,h}..  & A_{i,m}   \\
#    \colon  & \colon  & \colon   \\
#    A_{q,1}  & ..A_{q,h}..  & A_{q,m}   \\
#    D_{t,1}  & ..D_{t,h}..  & D_{t,m}   \\
#    G_{1,1}  & ..G_{1,h}..  & G_{1,m}   \\
#    \colon  & \colon  & \colon   \\
#    G_{u,1}  & ..G_{u,h}..  & G_{u,m}   \\
#    \colon  & \colon  & \colon   \\
#    G_{s,1}  & ..G_{s,h}..  & G_{s,m}

# %%
Circuit(ExprRange(i, ExprTuple(ExprRange(h, Aih, one, m), ExprRange(j, Bij, one, n), ExprRange(k, Cik, one, p)), one, q))
# Out:
#  A_{1,1}  & ..A_{1,h}..  & A_{1,m}  & B_{1,1}  & ..B_{1,j}..  & B_{1,n}  & C_{1,1}  & ..C_{1,k}..  & C_{1,p}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i,1}  & ..A_{i,h}..  & A_{i,m}  & B_{i,1}  & ..B_{i,j}..  & B_{i,n}  & C_{i,1}  & ..C_{i,k}..  & C_{i,p}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{q,1}  & ..A_{q,h}..  & A_{q,m}  & B_{q,1}  & ..B_{q,j}..  & B_{q,n}  & C_{q,1}  & ..C_{q,k}..  & C_{q,p}
# \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1,1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1,m}} \qwx[1] & \gate{B_{1,1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{B_{1,n}} \qwx[1] & \gate{C_{1,1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1,p}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i,h}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{B_{i,j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{C_{i,k}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{q,1}} & \gate{\cdots} & \gate{A_{q,m}} & \gate{B_{q,1}} & \gate{\cdots} & \gate{B_{q,n}} & \gate{C_{q,1}} & \gate{\cdots} & \gate{C_{q,p}}
# }
#  A_{1,1}  & ..A_{1,h}..  & A_{1,m}  & B_{1,1}  & ..B_{1,j}..  & B_{1,n}  & C_{1,1}  & ..C_{1,k}..  & C_{1,p}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i,1}  & ..A_{i,h}..  & A_{i,m}  & B_{i,1}  & ..B_{i,j}..  & B_{i,n}  & C_{i,1}  & ..C_{i,k}..  & C_{i,p}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{q,1}  & ..A_{q,h}..  & A_{q,m}  & B_{q,1}  & ..B_{q,j}..  & B_{q,n}  & C_{q,1}  & ..C_{q,k}..  & C_{q,p}

# %%
Circuit(ExprRange(i, ExprTuple(ExprRange(h, Aih, one, m), ExprRange(j, Bij, one, n), ExprRange(k, Cik, one, p)), one, q),
         ExprTuple(ExprRange(h, Dth, one, m), ExprRange(j, Etj, one, n), ExprRange(k, Ftk, one, p)),
         ExprRange(u, ExprTuple(ExprRange(h, Guh, one, m), ExprRange(j, Kuj, one, n), ExprRange(k, Muk, one, p)), one, s))
# Out:
#  A_{1,1}  & ..A_{1,h}..  & A_{1,m}  & B_{1,1}  & ..B_{1,j}..  & B_{1,n}  & C_{1,1}  & ..C_{1,k}..  & C_{1,p}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i,1}  & ..A_{i,h}..  & A_{i,m}  & B_{i,1}  & ..B_{i,j}..  & B_{i,n}  & C_{i,1}  & ..C_{i,k}..  & C_{i,p}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{q,1}  & ..A_{q,h}..  & A_{q,m}  & B_{q,1}  & ..B_{q,j}..  & B_{q,n}  & C_{q,1}  & ..C_{q,k}..  & C_{q,p}   \\
#    D_{t,1}  & ..D_{t,h}..  & D_{t,m}  & E_{t,1}  & ..E_{t,j}..  & E_{t,n}  & F_{t,1}  & ..F_{t,k}..  & F_{t,p}   \\
#    G_{1,1}  & ..G_{1,h}..  & G_{1,m}  & K_{1,1}  & ..K_{1,j}..  & K_{1,n}  & M_{1,1}  & ..M_{1,k}..  & M_{1,p}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    G_{u,1}  & ..G_{u,h}..  & G_{u,m}  & K_{u,1}  & ..K_{u,j}..  & K_{u,n}  & M_{u,1}  & ..M_{u,k}..  & M_{u,p}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    G_{s,1}  & ..G_{s,h}..  & G_{s,m}  & K_{s,1}  & ..K_{s,j}..  & K_{s,n}  & M_{s,1}  & ..M_{s,k}..  & M_{s,p}
# \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1,1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1,m}} \qwx[1] & \gate{B_{1,1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{B_{1,n}} \qwx[1] & \gate{C_{1,1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1,p}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i,h}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{B_{i,j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{C_{i,k}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{q,1}} & \gate{\cdots} & \gate{A_{q,m}} & \gate{B_{q,1}} & \gate{\cdots} & \gate{B_{q,n}} & \gate{C_{q,1}} & \gate{\cdots} & \gate{C_{q,p}}   \\
#   & \gate{D_{t,1}} & \gate{\cdots} & \gate{D_{t,m}} & \gate{E_{t,1}} & \gate{\cdots} & \gate{E_{t,n}} & \gate{F_{t,1}} & \gate{\cdots} & \gate{F_{t,p}}   \\
#   & \gate{G_{1,1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{G_{1,m}} \qwx[1] & \gate{K_{1,1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{K_{1,n}} \qwx[1] & \gate{M_{1,1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{M_{1,p}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{G_{u,h}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{K_{u,j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{M_{u,k}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{G_{s,1}} & \gate{\cdots} & \gate{G_{s,m}} & \gate{K_{s,1}} & \gate{\cdots} & \gate{K_{s,n}} & \gate{M_{s,1}} & \gate{\cdots} & \gate{M_{s,p}}
# }
#  A_{1,1}  & ..A_{1,h}..  & A_{1,m}  & B_{1,1}  & ..B_{1,j}..  & B_{1,n}  & C_{1,1}  & ..C_{1,k}..  & C_{1,p}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i,1}  & ..A_{i,h}..  & A_{i,m}  & B_{i,1}  & ..B_{i,j}..  & B_{i,n}  & C_{i,1}  & ..C_{i,k}..  & C_{i,p}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{q,1}  & ..A_{q,h}..  & A_{q,m}  & B_{q,1}  & ..B_{q,j}..  & B_{q,n}  & C_{q,1}  & ..C_{q,k}..  & C_{q,p}   \\
#    D_{t,1}  & ..D_{t,h}..  & D_{t,m}  & E_{t,1}  & ..E_{t,j}..  & E_{t,n}  & F_{t,1}  & ..F_{t,k}..  & F_{t,p}   \\
#    G_{1,1}  & ..G_{1,h}..  & G_{1,m}  & K_{1,1}  & ..K_{1,j}..  & K_{1,n}  & M_{1,1}  & ..M_{1,k}..  & M_{1,p}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    G_{u,1}  & ..G_{u,h}..  & G_{u,m}  & K_{u,1}  & ..K_{u,j}..  & K_{u,n}  & M_{u,1}  & ..M_{u,k}..  & M_{u,p}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    G_{s,1}  & ..G_{s,h}..  & G_{s,m}  & K_{s,1}  & ..K_{s,j}..  & K_{s,n}  & M_{s,1}  & ..M_{s,k}..  & M_{s,p}

# %%
Circuit(ExprTuple(Input(ket0), Gate(H), Output(ketPlus)), 
        ExprTuple(Input(ket1), MultiQubitGate(H, Set(two)), Output(ketMinus)))
# MultiQubitGate of a single gate - automatic equality reductions.
# Out:
#  [INPUT](|0〉)  & [GATE](H)  & [OUTPUT](|+〉)   \\
#    [INPUT](|1〉)  & H MULTI_QUBIT_GATE {2}  & [OUTPUT](|-〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \gate{H} & \rstick{\lvert + \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \rstick{\lvert - \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (H, {2})
# styles
# MULTI_QUBIT_GATE
# (H, {2})
# operands
# MULTI_QUBIT_GATE
# (H, {2})
# styles
# MULTI_QUBIT_GATE
# (H, {2})
#  [INPUT](|0〉)  & [GATE](H)  & [OUTPUT](|+〉)   \\
#    [INPUT](|1〉)  & H MULTI_QUBIT_GATE {2}  & [OUTPUT](|-〉)

# %%
#Circuit(ExprRange(i, Gate(ExprRange(j, Aij, one, n)), one, m))

# %%
# multigate block test
Circuit(ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two, three, four, six, seven)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two, three, four, six, seven)), 
                  Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two, three, four, six, seven)), Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(one, two, three, four, six, seven)), 
                  Output(ket1)),
        ExprTuple(Input(ket0), IdentityOp(), Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(one, two, three, four, six, seven)), 
                  Output(ket1)),
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(one, two, three, four, six, seven)), 
                  Output(ket1)))
# Out:
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \ctrl{1} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \ctrl{1} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{Z} \qwx[1] & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{X} \qwx[2] & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \qw & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{X} \qwx[1] & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{Z} & \rstick{\lvert 1 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2, 3, 4, 6, 7})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2, 3, 4, 6, 7})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2, 3, 4, 6, 7})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2, 3, 4, 6, 7})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2, 3, 4, 6, 7})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2, 3, 4, 6, 7})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2, 3, 4, 6, 7})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2, 3, 4, 6, 7})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2, 3, 4, 6, 7})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2, 3, 4, 6, 7})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2, 3, 4, 6, 7})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2, 3, 4, 6, 7})
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|1〉)

# %%
# multigate block test
Circuit(ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two, three, four)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two, three, four)), 
                  Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two, three, four)), Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(one, two, three, four)), 
                  Output(ket1)))
# Out:
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2, 3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4}  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \ctrl{1} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \multigate{2}{Z} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \ghost{Z} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \ghost{Z} & \rstick{\lvert 1 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2, 3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2, 3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2, 3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2, 3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2, 3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2, 3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2, 3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2, 3, 4})
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2, 3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4}  & [OUTPUT](|1〉)

# %%
# Single Qubit Gates

# %%
Circuit(ExprTuple(Input(ket0), Gate(H), Output(ketPlus)), 
        ExprTuple(Input(ket1), Gate(H), Output(ketMinus)))
# H gate (both inputs)
# Out:
#  [INPUT](|0〉)  & [GATE](H)  & [OUTPUT](|+〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & [OUTPUT](|-〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \gate{H} & \rstick{\lvert + \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \rstick{\lvert - \rangle} \qw
# }
#  [INPUT](|0〉)  & [GATE](H)  & [OUTPUT](|+〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & [OUTPUT](|-〉)

# %%
Circuit(ExprTuple(Input(ket0), Gate(X), Output(ket1)), 
        ExprTuple(Input(ket1), Gate(X), Output(ket0)))
# X gate (both inputs)
# Out:
#  [INPUT](|0〉)  & [GATE](X)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](X)  & [OUTPUT](|0〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \gate{X} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{X} & \rstick{\lvert 0 \rangle} \qw
# }
#  [INPUT](|0〉)  & [GATE](X)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](X)  & [OUTPUT](|0〉)

# %%
Circuit(ExprTuple(Input(ket0), Gate(Z), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(Z), Output(Neg(ket1))))
# Z gate (both inputs)
# Out:
#  [INPUT](|0〉)  & [GATE](Z)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](Z)  & [OUTPUT](-|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \gate{Z} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{Z} & \rstick{-\lvert 1 \rangle} \qw
# }
#  [INPUT](|0〉)  & [GATE](Z)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](Z)  & [OUTPUT](-|1〉)

# %%
#Two Qubit Gates

# %%
Circuit(ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(three, four)), Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(three, four)), 
                  Output(ket1))) 
#CZ gate - 0 qubit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \ctrl{1} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{Z} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \ctrl{1} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{Z} & \rstick{\lvert 1 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)

# %%
Circuit(ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(one, two)), Output(ket1)), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(three, four)), Output(ket1)), 
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(three, four)), 
                  Output(Neg(ket1)))) 
#CZ gate - 1 qubit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](-|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 1 \rangle} & \ctrl{1} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{Z} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \ctrl{1} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{Z} & \rstick{-\lvert 1 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
#  [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](-|1〉)

# %%
Circuit(ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(X, Set(one, two)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(three, four)), Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(three, four)), Output(ket1))) 
#CX gate - 0 qubit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \ctrl{1} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{X} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \ctrl{1} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{X} & \rstick{\lvert 1 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (X, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (X, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (X, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (X, {3, 4})
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)

# %%
Circuit(ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(one, two)), Output(ket1)), 
        ExprTuple(Input(ket0), MultiQubitGate(X, Set(one, two)), Output(ket1)), 
        ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(three, four)), Output(ket1)), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(three, four)), Output(ket0))) 
#CX gate - 1 qubit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 1 \rangle} & \ctrl{1} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{X} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \ctrl{1} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{X} & \rstick{\lvert 0 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (X, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (X, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (X, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (X, {3, 4})
#  [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)

# %%
Circuit(ExprTuple(Input(zero), MultiQubitGate(CLASSICAL_CONTROL, Set(one, two)), SPACE), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(zero), MultiQubitGate(CLASSICAL_CONTROL, Set(three, four)), SPACE), 
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(three, four)), 
                  Output(ket1))) 
#cZ gate - 0 classical bit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](0)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {1, 2} & SPACE   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](0)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {3, 4} & SPACE   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{0} & \control \cw \cwx[1] &   \\
#    \lstick{\lvert 0 \rangle} & \gate{Z} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{0} & \control \cw \cwx[1] &   \\
#    \lstick{\lvert 1 \rangle} & \gate{Z} & \rstick{\lvert 1 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
#  [INPUT](0)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {1, 2} & SPACE   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](0)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {3, 4} & SPACE   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)

# %%
Circuit(ExprTuple(Input(one), MultiQubitGate(CLASSICAL_CONTROL, Set(one, two)), SPACE), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(one), MultiQubitGate(CLASSICAL_CONTROL, Set(three, four)), SPACE), 
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(three, four)), 
                  Output(Neg(ket1))))
#cZ gate - 1 classical bit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](1)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {1, 2} & SPACE   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](1)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {3, 4} & SPACE   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](-|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{1} & \control \cw \cwx[1] &   \\
#    \lstick{\lvert 0 \rangle} & \gate{Z} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{1} & \control \cw \cwx[1] &   \\
#    \lstick{\lvert 1 \rangle} & \gate{Z} & \rstick{-\lvert 1 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
#  [INPUT](1)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {1, 2} & SPACE   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](1)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {3, 4} & SPACE   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](-|1〉)

# %%
Circuit(ExprTuple(Input(zero), MultiQubitGate(CLASSICAL_CONTROL, Set(one, two)), SPACE), 
        ExprTuple(Input(ket0), MultiQubitGate(X, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(zero), MultiQubitGate(CLASSICAL_CONTROL, Set(three, four)), SPACE), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(three, four)), 
                  Output(ket1))) 
#cX gate - 0 classical bit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](0)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {1, 2} & SPACE   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](0)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {3, 4} & SPACE   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{0} & \control \cw \cwx[1] &   \\
#    \lstick{\lvert 0 \rangle} & \gate{X} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{0} & \control \cw \cwx[1] &   \\
#    \lstick{\lvert 1 \rangle} & \gate{X} & \rstick{\lvert 1 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (X, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (X, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (X, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (X, {3, 4})
#  [INPUT](0)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {1, 2} & SPACE   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](0)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {3, 4} & SPACE   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)

# %%
Circuit(ExprTuple(Input(one), MultiQubitGate(CLASSICAL_CONTROL, Set(one, two)), SPACE), 
        ExprTuple(Input(ket0), MultiQubitGate(X, Set(one, two)), 
                  Output(ket1)), 
        ExprTuple(Input(one), MultiQubitGate(CLASSICAL_CONTROL, Set(three, four)), SPACE), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(three, four)), 
                  Output(ket0)))
#cX gate - 1 classical bit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](1)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {1, 2} & SPACE   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|1〉)   \\
#    [INPUT](1)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {3, 4} & SPACE   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{1} & \control \cw \cwx[1] &   \\
#    \lstick{\lvert 0 \rangle} & \gate{X} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{1} & \control \cw \cwx[1] &   \\
#    \lstick{\lvert 1 \rangle} & \gate{X} & \rstick{\lvert 0 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (X, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (X, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CLASSICAL\_CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (X, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (X, {3, 4})
#  [INPUT](1)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {1, 2} & SPACE   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|1〉)   \\
#    [INPUT](1)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {3, 4} & SPACE   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)

# %%
#NULL GATES

# %%
Circuit(ExprTuple(Input(ket0), Gate(H), Gate(H), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(H), Gate(H), Output(ket1)))
# Out:
#  [INPUT](|0〉)  & [GATE](H)  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & [GATE](H)  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \gate{H} & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \gate{H} & \rstick{\lvert 1 \rangle} \qw
# }
#  [INPUT](|0〉)  & [GATE](H)  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & [GATE](H)  & [OUTPUT](|1〉)

# %%
Circuit(ExprTuple(Input(ket0), Gate(X), Gate(X), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(X), Gate(X), Output(ket1)))
# Out:
#  [INPUT](|0〉)  & [GATE](X)  & [GATE](X)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](X)  & [GATE](X)  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \gate{X} & \gate{X} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{X} & \gate{X} & \rstick{\lvert 1 \rangle} \qw
# }
#  [INPUT](|0〉)  & [GATE](X)  & [GATE](X)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](X)  & [GATE](X)  & [OUTPUT](|1〉)

# %%
Circuit(ExprTuple(Input(ket0), Gate(Z), Gate(Z), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(Z), Gate(Z), Output(ket1)))
# Out:
#  [INPUT](|0〉)  & [GATE](Z)  & [GATE](Z)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](Z)  & [GATE](Z)  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \gate{Z} & \gate{Z} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{Z} & \gate{Z} & \rstick{\lvert 1 \rangle} \qw
# }
#  [INPUT](|0〉)  & [GATE](Z)  & [GATE](Z)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](Z)  & [GATE](Z)  & [OUTPUT](|1〉)

# %%
Circuit(ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two)), MultiQubitGate(CONTROL, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two)), MultiQubitGate(Z, Set(one, two)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(three, four)), MultiQubitGate(CONTROL, Set(three, four)), 
                  Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(three, four)), MultiQubitGate(Z, Set(three, four)), 
                  Output(ket1)),
        ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(five, six)), MultiQubitGate(CONTROL, Set(five, six)),
                  Output(ket1)),
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(five, six)), MultiQubitGate(Z, Set(five, six)),
                  Output(ket0)),
        ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(seven, eight)), MultiQubitGate(CONTROL, Set(seven, eight)), 
                  Output(ket1)), 
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(seven, eight)), MultiQubitGate(Z, Set(seven, eight)), 
                  Output(ket1))) 
# Double CZ gate
# Out:
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {5, 6}  & Z MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {7, 8}  & Z MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \ctrl{1} & \ctrl{1} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{Z} & \gate{Z} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \ctrl{1} & \ctrl{1} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{Z} & \gate{Z} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \ctrl{1} & \ctrl{1} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{Z} & \gate{Z} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \ctrl{1} & \ctrl{1} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{Z} & \gate{Z} & \rstick{\lvert 1 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (Z, {7, 8})
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {5, 6}  & Z MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {7, 8}  & Z MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)

# %%
Circuit(ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two)), MultiQubitGate(CONTROL, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(X, Set(one, two)), MultiQubitGate(X, Set(one, two)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(three, four)), MultiQubitGate(CONTROL, Set(three, four)), 
                  Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(three, four)), MultiQubitGate(X, Set(three, four)), 
                  Output(ket1)),
        ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(five, six)), MultiQubitGate(CONTROL, Set(five, six)),
                  Output(ket1)),
        ExprTuple(Input(ket0), MultiQubitGate(X, Set(five, six)), MultiQubitGate(X, Set(five, six)),
                  Output(ket0)),
        ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(seven, eight)), MultiQubitGate(CONTROL, Set(seven, eight)), 
                  Output(ket1)), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(seven, eight)), MultiQubitGate(X, Set(seven, eight)), 
                  Output(ket1))) 
# Double CX gate
# Out:
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {5, 6}  & X MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {7, 8}  & X MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \ctrl{1} & \ctrl{1} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{X} & \gate{X} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \ctrl{1} & \ctrl{1} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{X} & \gate{X} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \ctrl{1} & \ctrl{1} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{X} & \gate{X} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \ctrl{1} & \ctrl{1} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{X} & \gate{X} & \rstick{\lvert 1 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (X, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (X, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (X, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (X, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (X, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (X, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (X, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (X, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (X, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (X, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (X, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (X, {7, 8})
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {5, 6}  & X MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {7, 8}  & X MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)

# %%
Circuit(ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(U, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(three, four)), Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(U, Set(three, four)), 
                  Output(ket1))) 
#CU gate - 0 classical bit control for 1 and 0 qubit inputs (Always null regardless of what U is)
# Out:
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & U MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & U MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \ctrl{1} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{U} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \ctrl{1} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{U} & \rstick{\lvert 1 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (U, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (U, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (U, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (U, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (U, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (U, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (U, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (U, {3, 4})
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & U MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & U MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)

# %%
# CONGRUENCIES

# %%
Circuit(ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two)), Output(ket0)), 
    ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two)), 
              Output(ket0)), 
    ExprTuple(Input(ket0), MultiQubitGate(Z, Set(three, four)), Output(ket0)), 
    ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(three, four)), 
                Output(ket1)),
    ExprTuple(Input(ket1), MultiQubitGate(Z, Set(five, six)), Output(ket1)), 
    ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(five, six)), 
              Output(ket0)), 
    ExprTuple(Input(ket1), MultiQubitGate(Z, Set(seven, eight)), Output(Neg(ket1))), 
    ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(seven, eight)), 
              Output(ket1)))

#Congruent to a regular CZ gate
# Out:
#  [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](-|1〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \gate{Z} \qwx[1] & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \control \qw & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{Z} \qwx[1] & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \control \qw & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{Z} \qwx[1] & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \control \qw & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{Z} \qwx[1] & \rstick{-\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \control \qw & \rstick{\lvert 1 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
#  [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](-|1〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)

# %%
Circuit(ExprTuple(Input(ket0), IdentityOp(), MultiQubitGate(CONTROL, Set(one, two)), IdentityOp(), Output(ket0)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(Z, Set(one, two)), Gate(H), Output(ket0)),
        ExprTuple(Input(ket0), IdentityOp(), MultiQubitGate(CONTROL, Set(three, four)), IdentityOp(), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(Z, Set(three, four)), Gate(H), Output(ket1)),
        ExprTuple(Input(ket1), IdentityOp(), MultiQubitGate(CONTROL, Set(five, six)), IdentityOp(), Output(ket1)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(Z, Set(five, six)), Gate(H), Output(ket1)),
        ExprTuple(Input(ket1), IdentityOp(), MultiQubitGate(CONTROL, Set(seven, eight)), IdentityOp(), Output(ket1)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(Z, Set(seven, eight)), Gate(H), Output(ket0)))
# Congruent to a CX gate
# Out:
#  [INPUT](|0〉)  & --  & CONTROL MULTI_QUBIT_GATE {1, 2}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & --  & CONTROL MULTI_QUBIT_GATE {3, 4}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & --  & CONTROL MULTI_QUBIT_GATE {5, 6}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & --  & CONTROL MULTI_QUBIT_GATE {7, 8}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|0〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \qw & \ctrl{1} & \qw & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{H} & \gate{Z} & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \qw & \ctrl{1} & \qw & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \gate{Z} & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \qw & \ctrl{1} & \qw & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{H} & \gate{Z} & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \qw & \ctrl{1} & \qw & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \gate{Z} & \gate{H} & \rstick{\lvert 0 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (Z, {7, 8})
#  [INPUT](|0〉)  & --  & CONTROL MULTI_QUBIT_GATE {1, 2}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & --  & CONTROL MULTI_QUBIT_GATE {3, 4}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & --  & CONTROL MULTI_QUBIT_GATE {5, 6}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & --  & CONTROL MULTI_QUBIT_GATE {7, 8}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|0〉)

# %%
Circuit(ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(one, two)), Gate(H), Output(ket0)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(Z, Set(one, two)), Gate(H), Output(ket0)),
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(three, four)), Gate(H), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(Z, Set(three, four)), Gate(H), Output(ket1)),
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(five, six)), Gate(H), Output(ket1)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(Z, Set(five, six)), Gate(H), Output(ket1)),
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(seven, eight)), Gate(H), Output(ket1)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(Z, Set(seven, eight)), Gate(H), Output(ket0)))
# Intermediate step to show the congruence of a switched CX gate
# Out:
#  [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|0〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \gate{H} & \ctrl{1} & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{H} & \gate{Z} & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{H} & \ctrl{1} & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \gate{Z} & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \ctrl{1} & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{H} & \gate{Z} & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \ctrl{1} & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \gate{Z} & \gate{H} & \rstick{\lvert 0 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (Z, {7, 8})
#  [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|0〉)

# %%
Circuit(ExprTuple(Input(ket0), Gate(H), MultiQubitGate(Z, Set(one, two)), Gate(H), Output(ket0)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(one, two)), Gate(H), Output(ket0)),
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(Z, Set(three, four)), Gate(H), Output(ket1)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(three, four)), Gate(H), Output(ket1)),
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(Z, Set(five, six)), Gate(H), Output(ket1)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(five, six)), Gate(H), Output(ket0)),
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(Z, Set(seven, eight)), Gate(H), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(seven, eight)), Gate(H), Output(ket1)))
# using cell 24 we can show that this is equivalent to cell 26
# Out:
#  [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \gate{H} & \gate{Z} \qwx[1] & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{H} & \control \qw & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{H} & \gate{Z} \qwx[1] & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \control \qw & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \gate{Z} \qwx[1] & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{H} & \control \qw & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \gate{Z} \qwx[1] & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \control \qw & \gate{H} & \rstick{\lvert 1 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (Z, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (Z, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (Z, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (Z, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
#  [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|1〉)

# %%
Circuit(ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(one, two)), Gate(H), Output(ket0)), 
        ExprTuple(Input(ket0), IdentityOp(), MultiQubitGate(X, Set(one, two)), IdentityOp(), Output(ket0)),
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(three, four)), Gate(H), Output(ket0)), 
        ExprTuple(Input(ket1), IdentityOp(), MultiQubitGate(X, Set(three, four)), IdentityOp(), Output(ket1)),
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(five, six)), Gate(H), Output(ket1)), 
        ExprTuple(Input(ket0), IdentityOp(), MultiQubitGate(X, Set(five, six)), IdentityOp(), Output(ket1)),
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(seven, eight)), Gate(H), Output(ket1)), 
        ExprTuple(Input(ket1), IdentityOp(), MultiQubitGate(X, Set(seven, eight)), IdentityOp(), Output(ket0)))
# using cell 26, we apply instantiation to return to the X gates
# Out:
#  [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & --  & X MULTI_QUBIT_GATE {1, 2}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & --  & X MULTI_QUBIT_GATE {3, 4}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & --  & X MULTI_QUBIT_GATE {5, 6}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & --  & X MULTI_QUBIT_GATE {7, 8}  & --  & [OUTPUT](|0〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \gate{H} & \ctrl{1} & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \qw & \gate{X} & \qw & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{H} & \ctrl{1} & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \qw & \gate{X} & \qw & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \ctrl{1} & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \qw & \gate{X} & \qw & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \ctrl{1} & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \qw & \gate{X} & \qw & \rstick{\lvert 0 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (X, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (X, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (X, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (X, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (X, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (X, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (X, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (X, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (X, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (X, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (X, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (X, {7, 8})
#  [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & --  & X MULTI_QUBIT_GATE {1, 2}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & --  & X MULTI_QUBIT_GATE {3, 4}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & --  & X MULTI_QUBIT_GATE {5, 6}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & --  & X MULTI_QUBIT_GATE {7, 8}  & --  & [OUTPUT](|0〉)

# %%
Circuit(ExprTuple(Input(ket0), IdentityOp(), MultiQubitGate(X, Set(one, two)), IdentityOp(), Output(ket0)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(one, two)), Gate(H), Output(ket0)),
        ExprTuple(Input(ket0), IdentityOp(), MultiQubitGate(X, Set(three, four)), IdentityOp(), Output(ket1)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(three, four)), Gate(H), Output(ket1)),
        ExprTuple(Input(ket1), IdentityOp(), MultiQubitGate(X, Set(five, six)), IdentityOp(), Output(ket1)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(five, six)), Gate(H), Output(ket0)),
        ExprTuple(Input(ket1), IdentityOp(), MultiQubitGate(X, Set(seven, eight)), IdentityOp(), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(seven, eight)), Gate(H), Output(ket1)))
# using cell 27 we can show that cell 28 is congruent to this cell
# Out:
#  [INPUT](|0〉)  & --  & X MULTI_QUBIT_GATE {1, 2}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & --  & X MULTI_QUBIT_GATE {3, 4}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & --  & X MULTI_QUBIT_GATE {5, 6}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & --  & X MULTI_QUBIT_GATE {7, 8}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|1〉)
# \Qcircuit@C=1em @R=.7em{
#  \lstick{\lvert 0 \rangle} & \qw & \gate{X} \qwx[1] & \qw & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{H} & \control \qw & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \qw & \gate{X} \qwx[1] & \qw & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \control \qw & \gate{H} & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \qw & \gate{X} \qwx[1] & \qw & \rstick{\lvert 1 \rangle} \qw   \\
#    \lstick{\lvert 0 \rangle} & \gate{H} & \control \qw & \gate{H} & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \qw & \gate{X} \qwx[1] & \qw & \rstick{\lvert 0 \rangle} \qw   \\
#    \lstick{\lvert 1 \rangle} & \gate{H} & \control \qw & \gate{H} & \rstick{\lvert 1 \rangle} \qw
# }
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (X, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (X, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (X, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (X, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (X, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (X, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (X, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (X, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {1, 2})
# operands
# MULTI_QUBIT_GATE
# (X, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (X, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {3, 4})
# operands
# MULTI_QUBIT_GATE
# (X, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (X, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {5, 6})
# operands
# MULTI_QUBIT_GATE
# (X, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (X, {7, 8})
# operands
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
# styles
# MULTI_QUBIT_GATE
# (CONTROL, {7, 8})
#  [INPUT](|0〉)  & --  & X MULTI_QUBIT_GATE {1, 2}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & --  & X MULTI_QUBIT_GATE {3, 4}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & --  & X MULTI_QUBIT_GATE {5, 6}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & --  & X MULTI_QUBIT_GATE {7, 8}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|1〉)

# %%
# %end demonstrations
