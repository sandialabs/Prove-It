# %% [markdown]
# Demonstrations for context <a class="ProveItLink" href="_context_.ipynb">proveit.physics.quantum</a>
# ========

# %%
import proveit
#proveit.defaults.automation = False # prevents proveit from calling automations that are currently broken
from proveit import ExprArray, ExprTuple, ExprRange, IndexedVar, varRange
from proveit._common_ import A, B, C, D, E, F, G, K, M, Q, R, S, U, a, b, f, g, h, i, j, k, m, n, p, q, r, s, t, u, x, y 
from proveit.core_expr_types import Len
from proveit.core_expr_types.expr_array._common_ import Aij, Bij, Cij, Dij, Eij, Qij, Rij, Sij
from proveit.logic import Equals, Implies, InSet, Forall, And
from proveit.logic.set_theory import Set
from proveit.number import Add, Neg, zero, one, two, three, four, five, six, seven, eight, nine, Naturals, NaturalsPos, Complexes
from proveit.number.numeral.deci._theorems_ import posnat1, posnat4
from proveit.physics.quantum.circuit import Gate, Target, Circuit, Input, Output, MultiQubitGate, IdentityOp, CircuitEquiv
from proveit.physics.quantum._common_ import H, X, Z, I, ket1, ket0, ketPlus, ketMinus, SPACE, CONTROL, CLASSICAL_CONTROL
#from proveit.physics.quantum._axioms_ import substitution
from proveit.physics.quantum._theorems_ import single_time_equiv
# %begin demonstrations
# Out:
# _i_{1, 1} MULTI_QUBIT_GATE _d_{1, 1} _i_{1, k} MULTI_QUBIT_GATE _d_{1, k}
# _g_{1, 1} MULTI_QUBIT_GATE _c_{1, 1} _g_{1, h} MULTI_QUBIT_GATE _c_{1, h}
# _i_{1, 1} MULTI_QUBIT_GATE _d_{1, 1} _i_{1, k} MULTI_QUBIT_GATE _d_{1, k}
# _g_{1, 1} MULTI_QUBIT_GATE _c_{1, 1} _g_{1, h} MULTI_QUBIT_GATE _c_{1, h}
# _i_{1, 1} MULTI_QUBIT_GATE _d_{1, 1} _i_{1, _k} MULTI_QUBIT_GATE _d_{1, _k}
# _g_{1, 1} MULTI_QUBIT_GATE _c_{1, 1} _g_{1, _l} MULTI_QUBIT_GATE _c_{1, _l}
# _i_{1, 1} MULTI_QUBIT_GATE _d_{1, 1} _i_{1, _k} MULTI_QUBIT_GATE _d_{1, _k}
# _g_{1, 1} MULTI_QUBIT_GATE _c_{1, 1} _g_{1, _l} MULTI_QUBIT_GATE _c_{1, _l}
# A_{1, 1} MULTI_QUBIT_GATE R_{1, 1} A_{1, k} MULTI_QUBIT_GATE R_{1, k}
# C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1} C_{1, h} MULTI_QUBIT_GATE Q_{1, h}
# A_{1, 1} MULTI_QUBIT_GATE R_{1, 1} A_{1, k} MULTI_QUBIT_GATE R_{1, k}
# C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1} C_{1, h} MULTI_QUBIT_GATE Q_{1, h}

# %%
len(Set().operands)
# Out:
# 0

# %%
MultiQubitGate(X, Set(two)).auto_reduction()
# Out:
# |- X MULTI_QUBIT_GATE {2} = [GATE](X)

# %%
And().auto_reduction()
# Out:
# |- [and]() = TRUE

# %%
Circuit(ExprArray(ExprTuple(MultiQubitGate(X, Set(one))))).operands[0][0][0].__class__
# Out:
# proveit.physics.quantum.circuit.MultiQubitGate

# %%
single_time_equiv
# Out:
# |- forall_{h in NaturalsPos, k in NaturalsPos, m in NaturalsPos} [forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}} (( B_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    B_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    B_{m} MULTI_QUBIT_GATE S_{m} equiv  D_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    D_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    D_{m} MULTI_QUBIT_GATE S_{m}) =>  \\ ( A_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & A_{1, k} MULTI_QUBIT_GATE R_{1, k}  & B_{1} MULTI_QUBIT_GATE S_{1}  & C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE Q_{1, j}..  & C_{1, h} MULTI_QUBIT_GATE Q_{1, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & A_{i, k} MULTI_QUBIT_GATE R_{i, k}  & B_{i} MULTI_QUBIT_GATE S_{i}  & C_{i, 1} MULTI_QUBIT_GATE Q_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE Q_{i, j}..  & C_{i, h} MULTI_QUBIT_GATE Q_{i, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE R_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE R_{m, j}..  & A_{m, k} MULTI_QUBIT_GATE R_{m, k}  & B_{m} MULTI_QUBIT_GATE S_{m}  & C_{m, 1} MULTI_QUBIT_GATE Q_{m, 1}  & ..C_{m, j} MULTI_QUBIT_GATE Q_{m, j}..  & C_{m, h} MULTI_QUBIT_GATE Q_{m, h} equiv  A_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & A_{1, k} MULTI_QUBIT_GATE R_{1, k}  & D_{1} MULTI_QUBIT_GATE S_{1}  & C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE Q_{1, j}..  & C_{1, h} MULTI_QUBIT_GATE Q_{1, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & A_{i, k} MULTI_QUBIT_GATE R_{i, k}  & D_{i} MULTI_QUBIT_GATE S_{i}  & C_{i, 1} MULTI_QUBIT_GATE Q_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE Q_{i, j}..  & C_{i, h} MULTI_QUBIT_GATE Q_{i, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE R_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE R_{m, j}..  & A_{m, k} MULTI_QUBIT_GATE R_{m, k}  & D_{m} MULTI_QUBIT_GATE S_{m}  & C_{m, 1} MULTI_QUBIT_GATE Q_{m, 1}  & ..C_{m, j} MULTI_QUBIT_GATE Q_{m, j}..  & C_{m, h} MULTI_QUBIT_GATE Q_{m, h}))]

# %%
# 3 by 1 array, subbing Gate(z) - UNFLATTENED
single_time_equiv.instantiate({h: one, k: one, m: one,  
                              A: ExprTuple(H), 
                              B: ExprTuple(Z), 
                              C: ExprTuple(X), 
                              D: ExprTuple(Z), 
                              S: ExprTuple(Set(one)), 
                              R: ExprTuple(Set(one)),
                              Q: ExprTuple(Set(one)),
                             }, 
                             
                             assumptions=[CircuitEquiv(Circuit(ExprArray(ExprTuple(Gate(Z)))), 
                                                       Circuit(ExprArray(ExprTuple(Gate(Z))))),
                                         ]).rhs.rhs.operands[0][0][0].__class__
# Out:
# proveit.physics.quantum.circuit.Gate

# %%
# single_time_equiv.instantiate({h: one, k: one, m: one,  
#                               A: ExprTuple(Gate(H)), 
#                               B: ExprTuple(Gate(Z)), 
#                               C: ExprTuple(Gate(X)), 
#                               D: ExprTuple(Gate(Z)), 
#                               S: ExprTuple(Set(one)), 
#                               R: ExprTuple(Set(one)),
#                               Q: ExprTuple(Set(one)),
#                              }, 
                             
#                              assumptions=[CircuitEquiv(Circuit(ExprArray(ExprTuple(Gate(Z)))), 
#                                                        Circuit(ExprArray(ExprTuple(Gate(Z))))),
#                                          ])

# %%
MultiQubitGate(Gate(Z), Set(one)).latex()
# Out:
# '\\Qcircuit@C=1em @R=.7em{\n& \\gate{\\Qcircuit@C=1em @R=.7em{\n& \\gate{Z} \n}{\\Big \\{}\\left\\{1\\right\\}} \n}'

# %%
MultiQubitGate(Z, Set(one))
# Out:
# Z MULTI_QUBIT_GATE {1}

# %%
# 3 by 1 array, subbing Gate(z) - UNFLATTENED
print(single_time_equiv.instantiate({h: one, k: one, m: one,  
                              A: ExprTuple(Gate(H)), 
                              B: ExprTuple(Gate(Z)), 
                              C: ExprTuple(Gate(X)), 
                              D: ExprTuple(Gate(Z)), 
                              S: ExprTuple(Set()), 
                              R: ExprTuple(Set()),
                              Q: ExprTuple(Set()),
                             }, 
                             
                             assumptions=[CircuitEquiv(Circuit(ExprArray(ExprTuple(Gate(Z)))), 
                                                       Circuit(ExprArray(ExprTuple(Gate(Z))))),
                                         ]).latex())
# Out:
# \vdash \begin{array}{c} \left(\Qcircuit@C=1em @R=.7em{
# & SPACE
# } \cong \Qcircuit@C=1em @R=.7em{
# & SPACE
# }\right) \Rightarrow  \\ \left(\Qcircuit@C=1em @R=.7em{
# & SPACE & &
# } \cong \Qcircuit@C=1em @R=.7em{
# & SPACE & &
# }\right) \end{array}

# %%
print(Forall ((h, k, m), Forall((varRange(A, [one, one], [m, k]), varRange(B, one, m), 
                                                varRange(C, [one, one], [m, h]), varRange(D, one, m), 
                                                varRange(S, one, m), varRange(R, [one, one], [m, k]), 
                                                varRange(Q, [one, one], [m, h])), 
        
            CircuitEquiv(
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(IndexedVar(B, i), IndexedVar(S, i))), one, m))),
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(IndexedVar(D, i), IndexedVar(S, i))), one, m)))
            )
    ).wrapParams(), domain=NaturalsPos).withWrapping().latex())
# Out:
# \left[\forall_{ \scriptsize \begin{array}{c}
# A_{1, 1}, \ldots, A_{1, k}, \ldots\ldots, A_{m, 1}, \ldots, A_{m, k}, B_{1}, \ldots, B_{m}, \\
# C_{1, 1}, \ldots, C_{1, h}, \ldots\ldots, C_{m, 1}, \ldots, C_{m, h}, D_{1}, \ldots, D_{m}, \\
# S_{1}, \ldots, S_{m}, R_{1, 1}, \ldots, R_{1, k}, \ldots\ldots, R_{m, 1}, \ldots, R_{m, k}, \\
# Q_{1, 1}, \ldots, Q_{1, h}, \ldots\ldots, Q_{m, 1}, \ldots, Q_{m, h}\end{array}
# }~  \\
# \left(\Qcircuit@C=1em @R=.7em{
# & \gate{B_{1}{\Big \{}S_{1}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1]   \\
#   & \gate{B_{m}{\Big \{}S_{m}}
# } \cong \Qcircuit@C=1em @R=.7em{
# & \gate{D_{1}{\Big \{}S_{1}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1]   \\
#   & \gate{D_{m}{\Big \{}S_{m}}
# }\right)\right]
# \forall_{h \in \mathbb{N}^+, k \in \mathbb{N}^+, m \in \mathbb{N}^+}~ \left[\forall_{ \scriptsize \begin{array}{c}
# A_{1, 1}, \ldots, A_{1, k}, \ldots\ldots, A_{m, 1}, \ldots, A_{m, k}, B_{1}, \ldots, B_{m}, \\
# C_{1, 1}, \ldots, C_{1, h}, \ldots\ldots, C_{m, 1}, \ldots, C_{m, h}, D_{1}, \ldots, D_{m}, \\
# S_{1}, \ldots, S_{m}, R_{1, 1}, \ldots, R_{1, k}, \ldots\ldots, R_{m, 1}, \ldots, R_{m, k}, \\
# Q_{1, 1}, \ldots, Q_{1, h}, \ldots\ldots, Q_{m, 1}, \ldots, Q_{m, h}\end{array}
# }~  \\
# \left(\Qcircuit@C=1em @R=.7em{
# & \gate{B_{1}{\Big \{}S_{1}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1]   \\
#   & \gate{B_{m}{\Big \{}S_{m}}
# } \cong \Qcircuit@C=1em @R=.7em{
# & \gate{D_{1}{\Big \{}S_{1}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1]   \\
#   & \gate{D_{m}{\Big \{}S_{m}}
# }\right)\right]

# %%
Forall ((h, k, m), Forall((varRange(A, [one, one], [m, k]), varRange(B, one, m), 
                                                varRange(C, [one, one], [m, h]), varRange(D, one, m), 
                                                varRange(S, one, m), varRange(R, [one, one], [m, k]), 
                                                varRange(Q, [one, one], [m, h])), 
        
            CircuitEquiv(
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(IndexedVar(B, i), IndexedVar(S, i))), one, m))),
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(IndexedVar(D, i), IndexedVar(S, i))), one, m)))
            )
    ).wrapParams(), domain=NaturalsPos)
# Out:
# forall_{h in NaturalsPos, k in NaturalsPos, m in NaturalsPos} [forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}} ( B_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    B_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    B_{m} MULTI_QUBIT_GATE S_{m} equiv  D_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    D_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    D_{m} MULTI_QUBIT_GATE S_{m})]

# %%
Forall ((h, k, m), Forall((varRange(A, [one, one], [m, k]), varRange(B, one, m), 
                                                varRange(C, [one, one], [m, h]), varRange(D, one, m), 
                                                varRange(S, one, m), varRange(R, [one, one], [m, k]), 
                                                varRange(Q, [one, one], [m, h])), 
        
            CircuitEquiv(
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(IndexedVar(B, i), IndexedVar(S, i))), one, m))),
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(IndexedVar(D, i), IndexedVar(S, i))), one, m)))
            )
    ).wrapParams(), domain=NaturalsPos)
# Out:
# forall_{h in NaturalsPos, k in NaturalsPos, m in NaturalsPos} [forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}} ( B_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    B_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    B_{m} MULTI_QUBIT_GATE S_{m} equiv  D_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    D_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    D_{m} MULTI_QUBIT_GATE S_{m})]

# %%
Forall((varRange(A, [one, one], [m, k]), varRange(B, one, m), 
                                                varRange(C, [one, one], [m, h]), varRange(D, one, m), 
                                                varRange(S, one, m), varRange(R, [one, one], [m, k]), 
                                                varRange(Q, [one, one], [m, h])), 
        
            CircuitEquiv(
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(IndexedVar(B, i), IndexedVar(S, i))), one, m))),
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(IndexedVar(D, i), IndexedVar(S, i))), one, m)))
            )
    ).wrapParams()
# Out:
# forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}} ( B_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    B_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    B_{m} MULTI_QUBIT_GATE S_{m} equiv  D_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    D_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    D_{m} MULTI_QUBIT_GATE S_{m})

# %%
Forall ((h, k, m), Forall((varRange(A, [one, one], [m, k]), varRange(B, one, m), 
                                                varRange(C, [one, one], [m, h]), varRange(D, one, m), 
                                                varRange(S, one, m), varRange(R, [one, one], [m, k]), 
                                                varRange(Q, [one, one], [m, h])), 
        Implies(
            CircuitEquiv(
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(IndexedVar(B, i), IndexedVar(S, i))), one, m))),
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(IndexedVar(D, i), IndexedVar(S, i))), one, m)))
            ),
            CircuitEquiv(
                        Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Rij), one, k), 
                                            MultiQubitGate(IndexedVar(B, i), IndexedVar(S, i)),
                                            ExprRange(j, MultiQubitGate(Cij, Qij), one, h)), 
                                    one, m))),
                        Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Rij), one, k), 
                                            MultiQubitGate(IndexedVar(D, i), IndexedVar(S, i)),
                                            ExprRange(j, MultiQubitGate(Cij, Qij), one, h)), 
                                    one, m)))
            )
        ).withWrappingAt(2)
    ).wrapParams(), domain=NaturalsPos)
# Out:
# A_{1, 1} MULTI_QUBIT_GATE R_{1, 1} A_{1, k} MULTI_QUBIT_GATE R_{1, k}
# C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1} C_{1, h} MULTI_QUBIT_GATE Q_{1, h}
# A_{1, 1} MULTI_QUBIT_GATE R_{1, 1} A_{1, k} MULTI_QUBIT_GATE R_{1, k}
# C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1} C_{1, h} MULTI_QUBIT_GATE Q_{1, h}
# A_{1, 1} MULTI_QUBIT_GATE R_{1, 1} A_{1, k} MULTI_QUBIT_GATE R_{1, k}
# C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1} C_{1, h} MULTI_QUBIT_GATE Q_{1, h}
# A_{1, 1} MULTI_QUBIT_GATE R_{1, 1} A_{1, k} MULTI_QUBIT_GATE R_{1, k}
# C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1} C_{1, h} MULTI_QUBIT_GATE Q_{1, h}
# _i_{1, 1} MULTI_QUBIT_GATE _d_{1, 1} _i_{1, k} MULTI_QUBIT_GATE _d_{1, k}
# _g_{1, 1} MULTI_QUBIT_GATE _c_{1, 1} _g_{1, h} MULTI_QUBIT_GATE _c_{1, h}
# _i_{1, 1} MULTI_QUBIT_GATE _d_{1, 1} _i_{1, k} MULTI_QUBIT_GATE _d_{1, k}
# _g_{1, 1} MULTI_QUBIT_GATE _c_{1, 1} _g_{1, h} MULTI_QUBIT_GATE _c_{1, h}
# _i_{1, 1} MULTI_QUBIT_GATE _d_{1, 1} _i_{1, _k} MULTI_QUBIT_GATE _d_{1, _k}
# _g_{1, 1} MULTI_QUBIT_GATE _c_{1, 1} _g_{1, _l} MULTI_QUBIT_GATE _c_{1, _l}
# _i_{1, 1} MULTI_QUBIT_GATE _d_{1, 1} _i_{1, _k} MULTI_QUBIT_GATE _d_{1, _k}
# _g_{1, 1} MULTI_QUBIT_GATE _c_{1, 1} _g_{1, _l} MULTI_QUBIT_GATE _c_{1, _l}
# forall_{h in NaturalsPos, k in NaturalsPos, m in NaturalsPos} [forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}} (( B_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    B_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    B_{m} MULTI_QUBIT_GATE S_{m} equiv  D_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    D_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    D_{m} MULTI_QUBIT_GATE S_{m}) =>  \\ ( A_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & A_{1, k} MULTI_QUBIT_GATE R_{1, k}  & B_{1} MULTI_QUBIT_GATE S_{1}  & C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE Q_{1, j}..  & C_{1, h} MULTI_QUBIT_GATE Q_{1, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & A_{i, k} MULTI_QUBIT_GATE R_{i, k}  & B_{i} MULTI_QUBIT_GATE S_{i}  & C_{i, 1} MULTI_QUBIT_GATE Q_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE Q_{i, j}..  & C_{i, h} MULTI_QUBIT_GATE Q_{i, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE R_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE R_{m, j}..  & A_{m, k} MULTI_QUBIT_GATE R_{m, k}  & B_{m} MULTI_QUBIT_GATE S_{m}  & C_{m, 1} MULTI_QUBIT_GATE Q_{m, 1}  & ..C_{m, j} MULTI_QUBIT_GATE Q_{m, j}..  & C_{m, h} MULTI_QUBIT_GATE Q_{m, h} equiv  A_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & A_{1, k} MULTI_QUBIT_GATE R_{1, k}  & D_{1} MULTI_QUBIT_GATE S_{1}  & C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE Q_{1, j}..  & C_{1, h} MULTI_QUBIT_GATE Q_{1, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & A_{i, k} MULTI_QUBIT_GATE R_{i, k}  & D_{i} MULTI_QUBIT_GATE S_{i}  & C_{i, 1} MULTI_QUBIT_GATE Q_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE Q_{i, j}..  & C_{i, h} MULTI_QUBIT_GATE Q_{i, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE R_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE R_{m, j}..  & A_{m, k} MULTI_QUBIT_GATE R_{m, k}  & D_{m} MULTI_QUBIT_GATE S_{m}  & C_{m, 1} MULTI_QUBIT_GATE Q_{m, 1}  & ..C_{m, j} MULTI_QUBIT_GATE Q_{m, j}..  & C_{m, h} MULTI_QUBIT_GATE Q_{m, h}))]

# %%
lhs = Circuit(ExprArray(ExprTuple(MultiQubitGate(CONTROL, Set(one, two))), 
        ExprTuple(MultiQubitGate(Z, Set(one, two))), 
        ExprTuple(MultiQubitGate(CONTROL, Set(three, four))), 
        ExprTuple(MultiQubitGate(Z, Set(three, four)))))
# Out:
# lhs:  CONTROL MULTI_QUBIT_GATE {1, 2}   \\
#    Z MULTI_QUBIT_GATE {1, 2}   \\
#    CONTROL MULTI_QUBIT_GATE {3, 4}   \\
#    Z MULTI_QUBIT_GATE {3, 4}

# %%
rhs = Circuit(ExprArray(ExprTuple(MultiQubitGate(CONTROL, Set(one, two))), 
        ExprTuple(MultiQubitGate(Z, Set(one, two))), 
        ExprTuple(MultiQubitGate(CONTROL, Set(three, four))), 
        ExprTuple(MultiQubitGate(Z, Set(three, four)))))
# Out:
# rhs:  CONTROL MULTI_QUBIT_GATE {1, 2}   \\
#    Z MULTI_QUBIT_GATE {1, 2}   \\
#    CONTROL MULTI_QUBIT_GATE {3, 4}   \\
#    Z MULTI_QUBIT_GATE {3, 4}

# %%
#CircuitEquiv(lhs, rhs).prove(assumptions=[CircuitEquiv(lhs, rhs)])

# %%
big = Circuit(ExprArray(ExprTuple(Gate(H), MultiQubitGate(CONTROL, Set(one, two)), Gate(X)), 
        ExprTuple(Gate(H), MultiQubitGate(Z, Set(one, two)), 
                  Gate(X)), 
        ExprTuple(Gate(H), MultiQubitGate(CONTROL, Set(three, four)), Gate(X)), 
        ExprTuple(Gate(H), MultiQubitGate(Z, Set(three, four)), 
                  Gate(X))))
# Out:
# big:  [GATE](H)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [GATE](X)   \\
#    [GATE](H)  & Z MULTI_QUBIT_GATE {1, 2}  & [GATE](X)   \\
#    [GATE](H)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [GATE](X)   \\
#    [GATE](H)  & Z MULTI_QUBIT_GATE {3, 4}  & [GATE](X)

# %%
big_left = Circuit(ExprArray(ExprTuple(Gate(H)), 
        ExprTuple(Gate(H)), 
        ExprTuple(Gate(H)), 
        ExprTuple(Gate(H))))
# Out:
# big_left:  [GATE](H)   \\
#    [GATE](H)   \\
#    [GATE](H)   \\
#    [GATE](H)

# %%
big_right = Circuit(ExprArray(ExprTuple(Gate(X)), 
        ExprTuple(Gate(X)), 
        ExprTuple(Gate(X)), 
        ExprTuple(Gate(X))))
# Out:
# big_right:  [GATE](X)   \\
#    [GATE](X)   \\
#    [GATE](X)   \\
#    [GATE](X)

# %%
# # single variables, no ExprTuple, unflattened
# single_time_equiv.specialize({h: one, k: one, m: four, A: big_left, B: lhs, C: big_right, D: rhs, 
#                               R: [Set(), Set(), Set(), Set()], S:[Set(one, two), Set(one, two), Set(three, four), 
#                                                                   Set(three, four)], 
#                               Q: [Set(), Set(), Set(), Set()]}, assumptions=[CircuitEquiv(lhs, rhs)])

# %%
# # single variables, but flattened
# single_time_equiv.specialize({h: one, k: one, m: four, A: ExprTuple(Gate(H), Gate(H), Gate(H), Gate(H)), 
#                               B: ExprTuple(MultiQubitGate(CONTROL, Set(one, two)), MultiQubitGate(Z, Set(one, two)), 
#                                            MultiQubitGate(CONTROL, Set(three, four)), MultiQubitGate(Z, Set(three, four))), 
#                               C: ExprTuple(Gate(X), Gate(X), Gate(X), Gate(X)), 
#                               D: ExprTuple(MultiQubitGate(CONTROL, Set(one, two)), MultiQubitGate(Z, Set(one, two)), 
#                                            MultiQubitGate(CONTROL, Set(three, four)), MultiQubitGate(Z, Set(three, four))), 
#                               R: ExprTuple(Set(one), Set(two), Set(three), Set(four)), S:ExprTuple(Set(one, two), Set(one, two), 
#                                                                                     Set(three, four), Set(three, four)), 
#                               Q: ExprTuple(Set(one), Set(two), Set(three), Set(four))}, assumptions=[CircuitEquiv(lhs, rhs)])

# %%
# 3 by 4, subbing two controlled z gates
# single_time_equiv.specialize({h: one, k: one, m: four, 
#                               ExprTuple(ExprRange(i, ExprRange(j, Aij, one, k), one, m)): ExprTuple(Gate(H), Gate(H), 
#                                                                                                     Gate(H), Gate(H)), 
#                               ExprTuple(varRange(B, one, m)): ExprTuple(MultiQubitGate(CONTROL, Set(one, two)), 
#                                                                         MultiQubitGate(Z, Set(one, two)),
#                                                                         MultiQubitGate(CONTROL, Set(three, four)), 
#                                                                         MultiQubitGate(Z, Set(three, four))), 
#                               ExprTuple(varRange(C, [one, one], [m, h])): ExprTuple(Gate(X), Gate(X), Gate(X), Gate(X)), 
#                               ExprTuple(varRange(D, one, m)): ExprTuple(MultiQubitGate(CONTROL, Set(one, two)), 
#                                                                         MultiQubitGate(Z, Set(one, two)), 
#                                            MultiQubitGate(CONTROL, Set(three, four)), MultiQubitGate(Z, Set(three, four))), 
#                               ExprTuple(varRange(S, one, m)): ExprTuple(Set(one, two), Set(one, two), 
#                                                                         Set(three, four), Set(three, four)), 
#                               ExprTuple(varRange(R, [one, one], [m, k])): ExprTuple(Set(), Set(), Set(), Set()), 
#                               ExprTuple(varRange(Q, [one, one], [m, h])): ExprTuple(Set(), Set(), Set(), Set())}, 
#                              assumptions=[CircuitEquiv(lhs, rhs)])

# COUNTING TO 10 ERROR

# %%
from proveit.core_expr_types.tuples._theorems_ import singular_range_reduction
singular_range_reduction
# Out:
# |- forall_{f, i} ((f(i), ..f(a).., f(i)) = (f(i)))

# %%
single_time_equiv
# Out:
# |- forall_{h in NaturalsPos, k in NaturalsPos, m in NaturalsPos} [forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}} (( B_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    B_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    B_{m} MULTI_QUBIT_GATE S_{m} equiv  D_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    D_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    D_{m} MULTI_QUBIT_GATE S_{m}) =>  \\ ( A_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & A_{1, k} MULTI_QUBIT_GATE R_{1, k}  & B_{1} MULTI_QUBIT_GATE S_{1}  & C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE Q_{1, j}..  & C_{1, h} MULTI_QUBIT_GATE Q_{1, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & A_{i, k} MULTI_QUBIT_GATE R_{i, k}  & B_{i} MULTI_QUBIT_GATE S_{i}  & C_{i, 1} MULTI_QUBIT_GATE Q_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE Q_{i, j}..  & C_{i, h} MULTI_QUBIT_GATE Q_{i, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE R_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE R_{m, j}..  & A_{m, k} MULTI_QUBIT_GATE R_{m, k}  & B_{m} MULTI_QUBIT_GATE S_{m}  & C_{m, 1} MULTI_QUBIT_GATE Q_{m, 1}  & ..C_{m, j} MULTI_QUBIT_GATE Q_{m, j}..  & C_{m, h} MULTI_QUBIT_GATE Q_{m, h} equiv  A_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & A_{1, k} MULTI_QUBIT_GATE R_{1, k}  & D_{1} MULTI_QUBIT_GATE S_{1}  & C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE Q_{1, j}..  & C_{1, h} MULTI_QUBIT_GATE Q_{1, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & A_{i, k} MULTI_QUBIT_GATE R_{i, k}  & D_{i} MULTI_QUBIT_GATE S_{i}  & C_{i, 1} MULTI_QUBIT_GATE Q_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE Q_{i, j}..  & C_{i, h} MULTI_QUBIT_GATE Q_{i, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE R_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE R_{m, j}..  & A_{m, k} MULTI_QUBIT_GATE R_{m, k}  & D_{m} MULTI_QUBIT_GATE S_{m}  & C_{m, 1} MULTI_QUBIT_GATE Q_{m, 1}  & ..C_{m, j} MULTI_QUBIT_GATE Q_{m, j}..  & C_{m, h} MULTI_QUBIT_GATE Q_{m, h}))]

# %%
CircuitEquiv(
                    Circuit(ExprArray(ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(B, j), Set(Add(m, one), Add(m, k, two))), one, n)),
                            ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(D, j), Set(Add(m, one), Add(m, k, two))), one, n)))),
                    Circuit(ExprArray(ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(F, j), Set(Add(m, one), Add(m, k, two))), one, n)),
                            ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(G, j), Set(Add(m, one), Add(m, k, two))), one, n))))
            ).lhs
# Out:
# B_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} B_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
# D_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} D_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
# F_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} F_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
# G_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} G_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
#  B_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2}  & ..B_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}..  & B_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}   \\
#    D_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2}  & ..D_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}..  & D_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}

# %%
ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, n)), one, m).first().entries[0].first()
# Out:
# A_{1, 1} MULTI_QUBIT_GATE S_{1, 1}

# %%
ExprRange(j, Gate(Aij), one, n).first().subExpr(1).subExpr(1)
# Out:
# (i, 1)

# %%
ExprArray(ExprRange(i, ExprTuple(ExprRange(j, Gate(Aij), one, n)), one, m),
                     ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(B, j), Set(Add(m, one), Add(m, k, two))), one, n)),
        ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k),
                     ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(D, j), Set(Add(m, one), Add(m, k, two))), one, n)),
        ExprRange(i, ExprTuple(ExprRange(j, Gate(Eij), one, n)), one, p))
# Out:
# [GATE](A_{1, 1}) & ..[GATE](A_{1, j}).. & [GATE](A_{1, n})  \\
#   \colon & \colon & \colon  \\
#   [GATE](A_{i, 1}) & ..[GATE](A_{i, j}).. & [GATE](A_{i, n})  \\
#   \colon & \colon & \colon  \\
#   [GATE](A_{m, 1}) & ..[GATE](A_{m, j}).. & [GATE](A_{m, n})  \\
#   B_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} & ..B_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}.. & B_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}  \\
#   C_{1, 1} MULTI_QUBIT_GATE R_{1, 1} & ..C_{1, j} MULTI_QUBIT_GATE R_{1, j}.. & C_{1, n} MULTI_QUBIT_GATE R_{1, n}  \\
#   \colon & \colon & \colon  \\
#   C_{i, 1} MULTI_QUBIT_GATE R_{i, 1} & ..C_{i, j} MULTI_QUBIT_GATE R_{i, j}.. & C_{i, n} MULTI_QUBIT_GATE R_{i, n}  \\
#   \colon & \colon & \colon  \\
#   C_{k, 1} MULTI_QUBIT_GATE R_{k, 1} & ..C_{k, j} MULTI_QUBIT_GATE R_{k, j}.. & C_{k, n} MULTI_QUBIT_GATE R_{k, n}  \\
#   D_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} & ..D_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}.. & D_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}  \\
#   [GATE](E_{1, 1}) & ..[GATE](E_{1, j}).. & [GATE](E_{1, n})  \\
#   \colon & \colon & \colon  \\
#   [GATE](E_{i, 1}) & ..[GATE](E_{i, j}).. & [GATE](E_{i, n})  \\
#   \colon & \colon & \colon  \\
#   [GATE](E_{p, 1}) & ..[GATE](E_{p, j}).. & [GATE](E_{p, n})

# %%
Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, Gate(Aij), one, n)), one, m),
                     ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(B, j), Set(Add(m, one), Add(m, k, two))), one, n)),
        ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k),
                     ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(D, j), Set(Add(m, one), Add(m, k, two))), one, n)),
        ExprRange(i, ExprTuple(ExprRange(j, Gate(Eij), one, n)), one, p)))
# Out:
# [GATE](A_{1, 1}) [GATE](A_{1, n})
# B_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} B_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
# D_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} D_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
#  [GATE](A_{1, 1})  & ..[GATE](A_{1, j})..  & [GATE](A_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    [GATE](A_{i, 1})  & ..[GATE](A_{i, j})..  & [GATE](A_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    [GATE](A_{m, 1})  & ..[GATE](A_{m, j})..  & [GATE](A_{m, n})   \\
#    B_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2}  & ..B_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}..  & B_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}   \\
#    C_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & C_{1, n} MULTI_QUBIT_GATE R_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & C_{i, n} MULTI_QUBIT_GATE R_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{k, 1} MULTI_QUBIT_GATE R_{k, 1}  & ..C_{k, j} MULTI_QUBIT_GATE R_{k, j}..  & C_{k, n} MULTI_QUBIT_GATE R_{k, n}   \\
#    D_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2}  & ..D_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}..  & D_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}   \\
#    [GATE](E_{1, 1})  & ..[GATE](E_{1, j})..  & [GATE](E_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    [GATE](E_{i, 1})  & ..[GATE](E_{i, j})..  & [GATE](E_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    [GATE](E_{p, 1})  & ..[GATE](E_{p, j})..  & [GATE](E_{p, n})

# %%
Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, n)), one, m),
                     ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(B, j), Set(Add(m, one), Add(m, k, two))), one, n)),
        ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k),
                     ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(D, j), Set(Add(m, one), Add(m, k, two))), one, n)),
        ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Eij, Qij), one, n)), one, p)))
# Out:
# A_{1, 1} MULTI_QUBIT_GATE S_{1, 1} A_{1, n} MULTI_QUBIT_GATE S_{1, n}
# B_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} B_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
# D_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} D_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
#  A_{1, 1} MULTI_QUBIT_GATE S_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE S_{1, j}..  & A_{1, n} MULTI_QUBIT_GATE S_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE S_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE S_{i, j}..  & A_{i, n} MULTI_QUBIT_GATE S_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE S_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE S_{m, j}..  & A_{m, n} MULTI_QUBIT_GATE S_{m, n}   \\
#    B_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2}  & ..B_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}..  & B_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}   \\
#    C_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & C_{1, n} MULTI_QUBIT_GATE R_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & C_{i, n} MULTI_QUBIT_GATE R_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{k, 1} MULTI_QUBIT_GATE R_{k, 1}  & ..C_{k, j} MULTI_QUBIT_GATE R_{k, j}..  & C_{k, n} MULTI_QUBIT_GATE R_{k, n}   \\
#    D_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2}  & ..D_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}..  & D_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}   \\
#    E_{1, 1} MULTI_QUBIT_GATE Q_{1, 1}  & ..E_{1, j} MULTI_QUBIT_GATE Q_{1, j}..  & E_{1, n} MULTI_QUBIT_GATE Q_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    E_{i, 1} MULTI_QUBIT_GATE Q_{i, 1}  & ..E_{i, j} MULTI_QUBIT_GATE Q_{i, j}..  & E_{i, n} MULTI_QUBIT_GATE Q_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    E_{p, 1} MULTI_QUBIT_GATE Q_{p, 1}  & ..E_{p, j} MULTI_QUBIT_GATE Q_{p, j}..  & E_{p, n} MULTI_QUBIT_GATE Q_{p, n}

# %%
Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, n)), one, m),
                     ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(B, j), Set(two, four)), one, n)),
        ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k),
                     ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(D, j), Set(two, five)), one, n)),
        ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Eij, Qij), one, n)), one, p)))
# Out:
# A_{1, 1} MULTI_QUBIT_GATE S_{1, 1} A_{1, n} MULTI_QUBIT_GATE S_{1, n}
# B_{1} MULTI_QUBIT_GATE {2, 4} B_{n} MULTI_QUBIT_GATE {2, 4}
# D_{1} MULTI_QUBIT_GATE {2, 5} D_{n} MULTI_QUBIT_GATE {2, 5}
#  A_{1, 1} MULTI_QUBIT_GATE S_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE S_{1, j}..  & A_{1, n} MULTI_QUBIT_GATE S_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE S_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE S_{i, j}..  & A_{i, n} MULTI_QUBIT_GATE S_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE S_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE S_{m, j}..  & A_{m, n} MULTI_QUBIT_GATE S_{m, n}   \\
#    B_{1} MULTI_QUBIT_GATE {2, 4}  & ..B_{j} MULTI_QUBIT_GATE {2, 4}..  & B_{n} MULTI_QUBIT_GATE {2, 4}   \\
#    C_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & C_{1, n} MULTI_QUBIT_GATE R_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & C_{i, n} MULTI_QUBIT_GATE R_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{k, 1} MULTI_QUBIT_GATE R_{k, 1}  & ..C_{k, j} MULTI_QUBIT_GATE R_{k, j}..  & C_{k, n} MULTI_QUBIT_GATE R_{k, n}   \\
#    D_{1} MULTI_QUBIT_GATE {2, 5}  & ..D_{j} MULTI_QUBIT_GATE {2, 5}..  & D_{n} MULTI_QUBIT_GATE {2, 5}   \\
#    E_{1, 1} MULTI_QUBIT_GATE Q_{1, 1}  & ..E_{1, j} MULTI_QUBIT_GATE Q_{1, j}..  & E_{1, n} MULTI_QUBIT_GATE Q_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    E_{i, 1} MULTI_QUBIT_GATE Q_{i, 1}  & ..E_{i, j} MULTI_QUBIT_GATE Q_{i, j}..  & E_{i, n} MULTI_QUBIT_GATE Q_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    E_{p, 1} MULTI_QUBIT_GATE Q_{p, 1}  & ..E_{p, j} MULTI_QUBIT_GATE Q_{p, j}..  & E_{p, n} MULTI_QUBIT_GATE Q_{p, n}

# %%
        Implies(
            CircuitEquiv(
                    Circuit(ExprArray(ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(B, j), Set(Add(m, one), Add(m, k, two))), one, n)),
                            ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(D, j), Set(Add(m, one), Add(m, k, two))), one, n)))),
                    Circuit(ExprArray(ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(F, j), Set(Add(m, one), Add(m, k, two))), one, n)),
                            ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(G, j), Set(Add(m, one), Add(m, k, two))), one, n))))
            ),
            CircuitEquiv(
                    Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, n)), one, m),
                            ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(B, j), Set(Add(m, one), Add(m, k, two))), one, n)),
                            ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k),
                            ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(D, j), Set(Add(m, one), Add(m, k, two))), one, n)),
                            ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Eij, Qij), one, n)), one, p))),
                    Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, n)), one, m),
                            ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(F, j), Set(Add(m, one), Add(m, k, two))), one, n)),
                            ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k),
                            ExprTuple(ExprRange(j, MultiQubitGate(IndexedVar(G, j), Set(Add(m, one), Add(m, k, two))), one, n)),
                            ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Eij, Qij), one, n)), one, p))))
            )
# Out:
# B_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} B_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
# D_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} D_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
# F_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} F_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
# G_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} G_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
# A_{1, 1} MULTI_QUBIT_GATE S_{1, 1} A_{1, n} MULTI_QUBIT_GATE S_{1, n}
# B_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} B_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
# D_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} D_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
# A_{1, 1} MULTI_QUBIT_GATE S_{1, 1} A_{1, n} MULTI_QUBIT_GATE S_{1, n}
# F_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} F_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
# G_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2} G_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}
# ( B_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2}  & ..B_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}..  & B_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}   \\
#    D_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2}  & ..D_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}..  & D_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2} equiv  F_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2}  & ..F_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}..  & F_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}   \\
#    G_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2}  & ..G_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}..  & G_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}) => ( A_{1, 1} MULTI_QUBIT_GATE S_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE S_{1, j}..  & A_{1, n} MULTI_QUBIT_GATE S_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE S_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE S_{i, j}..  & A_{i, n} MULTI_QUBIT_GATE S_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE S_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE S_{m, j}..  & A_{m, n} MULTI_QUBIT_GATE S_{m, n}   \\
#    B_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2}  & ..B_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}..  & B_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}   \\
#    C_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & C_{1, n} MULTI_QUBIT_GATE R_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & C_{i, n} MULTI_QUBIT_GATE R_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{k, 1} MULTI_QUBIT_GATE R_{k, 1}  & ..C_{k, j} MULTI_QUBIT_GATE R_{k, j}..  & C_{k, n} MULTI_QUBIT_GATE R_{k, n}   \\
#    D_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2}  & ..D_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}..  & D_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}   \\
#    E_{1, 1} MULTI_QUBIT_GATE Q_{1, 1}  & ..E_{1, j} MULTI_QUBIT_GATE Q_{1, j}..  & E_{1, n} MULTI_QUBIT_GATE Q_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    E_{i, 1} MULTI_QUBIT_GATE Q_{i, 1}  & ..E_{i, j} MULTI_QUBIT_GATE Q_{i, j}..  & E_{i, n} MULTI_QUBIT_GATE Q_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    E_{p, 1} MULTI_QUBIT_GATE Q_{p, 1}  & ..E_{p, j} MULTI_QUBIT_GATE Q_{p, j}..  & E_{p, n} MULTI_QUBIT_GATE Q_{p, n} equiv  A_{1, 1} MULTI_QUBIT_GATE S_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE S_{1, j}..  & A_{1, n} MULTI_QUBIT_GATE S_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE S_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE S_{i, j}..  & A_{i, n} MULTI_QUBIT_GATE S_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE S_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE S_{m, j}..  & A_{m, n} MULTI_QUBIT_GATE S_{m, n}   \\
#    F_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2}  & ..F_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}..  & F_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}   \\
#    C_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & C_{1, n} MULTI_QUBIT_GATE R_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & C_{i, n} MULTI_QUBIT_GATE R_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{k, 1} MULTI_QUBIT_GATE R_{k, 1}  & ..C_{k, j} MULTI_QUBIT_GATE R_{k, j}..  & C_{k, n} MULTI_QUBIT_GATE R_{k, n}   \\
#    G_{1} MULTI_QUBIT_GATE {m + 1, m + k + 2}  & ..G_{j} MULTI_QUBIT_GATE {m + 1, m + k + 2}..  & G_{n} MULTI_QUBIT_GATE {m + 1, m + k + 2}   \\
#    E_{1, 1} MULTI_QUBIT_GATE Q_{1, 1}  & ..E_{1, j} MULTI_QUBIT_GATE Q_{1, j}..  & E_{1, n} MULTI_QUBIT_GATE Q_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    E_{i, 1} MULTI_QUBIT_GATE Q_{i, 1}  & ..E_{i, j} MULTI_QUBIT_GATE Q_{i, j}..  & E_{i, n} MULTI_QUBIT_GATE Q_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    E_{p, 1} MULTI_QUBIT_GATE Q_{p, 1}  & ..E_{p, j} MULTI_QUBIT_GATE Q_{p, j}..  & E_{p, n} MULTI_QUBIT_GATE Q_{p, n})

# %%
Circuit(ExprArray(ExprTuple(Gate(X), Output(ket0), Input(ket0), Gate(H)))).latex()
# Out:
# '\\Qcircuit@C=1em @R=.7em{\n& \\gate{X} & \\rstick{\\lvert 0 \\rangle} \\qw & \\lstick{\\lvert 0 \\rangle} & \\gate{H} \n}'

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), Gate(H), MultiQubitGate(X, Set(one, three)), Gate(H), Output(ketPlus)), 
        ExprTuple(Input(ket1), MultiQubitGate(H, Set(two, three)), MultiQubitGate(H, Set(two)), Gate(X), Output(ketMinus)),
       ExprTuple(Input(ket1), MultiQubitGate(H, Set(two, three)), MultiQubitGate(X, Set(one, three)), Gate(X), Output(ketMinus))))
# Out:
#  [INPUT](|0〉)  & [GATE](H)  & X MULTI_QUBIT_GATE {1, 3}  & [GATE](H)  & [OUTPUT](|+〉)   \\
#    [INPUT](|1〉)  & H MULTI_QUBIT_GATE {2, 3}  & H MULTI_QUBIT_GATE {2}  & [GATE](X)  & [OUTPUT](|-〉)   \\
#    [INPUT](|1〉)  & H MULTI_QUBIT_GATE {2, 3}  & X MULTI_QUBIT_GATE {1, 3}  & [GATE](X)  & [OUTPUT](|-〉)

# %%
Circuit(ExprArray(ExprTuple(ExprRange(j, Gate(IndexedVar(B, j)), one, n))))
# Out:
# [GATE](B_{1}) [GATE](B_{n})
#  [GATE](B_{1})  & ..[GATE](B_{j})..  & [GATE](B_{n})

# %%
CircuitEquiv(
                    Circuit(ExprArray(ExprTuple(ExprRange(j, Gate(IndexedVar(B, j)), one, n)))),
                    Circuit(ExprArray(ExprTuple(ExprRange(j, Gate(IndexedVar(D, j)), one, n)))))
# Out:
# [GATE](B_{1}) [GATE](B_{n})
# [GATE](D_{1}) [GATE](D_{n})
#  [GATE](B_{1})  & ..[GATE](B_{j})..  & [GATE](B_{n}) equiv  [GATE](D_{1})  & ..[GATE](D_{j})..  & [GATE](D_{n})

# %%
Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k)))
# Out:
# C_{1, 1} MULTI_QUBIT_GATE R_{1, 1} C_{1, n} MULTI_QUBIT_GATE R_{1, n}
#  C_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & C_{1, n} MULTI_QUBIT_GATE R_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & C_{i, n} MULTI_QUBIT_GATE R_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{k, 1} MULTI_QUBIT_GATE R_{k, 1}  & ..C_{k, j} MULTI_QUBIT_GATE R_{k, j}..  & C_{k, n} MULTI_QUBIT_GATE R_{k, n}

# %%
Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, n)), one, m),
                            ExprTuple(ExprRange(j, Gate(IndexedVar(B, j)), one, n)),
                            ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k)))
# Out:
# A_{1, 1} MULTI_QUBIT_GATE S_{1, 1} A_{1, n} MULTI_QUBIT_GATE S_{1, n}
# [GATE](B_{1}) [GATE](B_{n})
#  A_{1, 1} MULTI_QUBIT_GATE S_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE S_{1, j}..  & A_{1, n} MULTI_QUBIT_GATE S_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE S_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE S_{i, j}..  & A_{i, n} MULTI_QUBIT_GATE S_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE S_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE S_{m, j}..  & A_{m, n} MULTI_QUBIT_GATE S_{m, n}   \\
#    [GATE](B_{1})  & ..[GATE](B_{j})..  & [GATE](B_{n})   \\
#    C_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & C_{1, n} MULTI_QUBIT_GATE R_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & C_{i, n} MULTI_QUBIT_GATE R_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{k, 1} MULTI_QUBIT_GATE R_{k, 1}  & ..C_{k, j} MULTI_QUBIT_GATE R_{k, j}..  & C_{k, n} MULTI_QUBIT_GATE R_{k, n}

# %%
CircuitEquiv(
                    Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, n)), one, m),
                            ExprTuple(ExprRange(j, Gate(IndexedVar(B, j)), one, n)),
                            ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k))),
                    Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, n)), one, m),
                            ExprTuple(ExprRange(j, Gate(IndexedVar(D, j)), one, n)),
                            ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k)))
            )
# Out:
# A_{1, 1} MULTI_QUBIT_GATE S_{1, 1} A_{1, n} MULTI_QUBIT_GATE S_{1, n}
# [GATE](B_{1}) [GATE](B_{n})
# A_{1, 1} MULTI_QUBIT_GATE S_{1, 1} A_{1, n} MULTI_QUBIT_GATE S_{1, n}
# [GATE](D_{1}) [GATE](D_{n})
#  A_{1, 1} MULTI_QUBIT_GATE S_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE S_{1, j}..  & A_{1, n} MULTI_QUBIT_GATE S_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE S_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE S_{i, j}..  & A_{i, n} MULTI_QUBIT_GATE S_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE S_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE S_{m, j}..  & A_{m, n} MULTI_QUBIT_GATE S_{m, n}   \\
#    [GATE](B_{1})  & ..[GATE](B_{j})..  & [GATE](B_{n})   \\
#    C_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & C_{1, n} MULTI_QUBIT_GATE R_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & C_{i, n} MULTI_QUBIT_GATE R_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{k, 1} MULTI_QUBIT_GATE R_{k, 1}  & ..C_{k, j} MULTI_QUBIT_GATE R_{k, j}..  & C_{k, n} MULTI_QUBIT_GATE R_{k, n} equiv  A_{1, 1} MULTI_QUBIT_GATE S_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE S_{1, j}..  & A_{1, n} MULTI_QUBIT_GATE S_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE S_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE S_{i, j}..  & A_{i, n} MULTI_QUBIT_GATE S_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE S_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE S_{m, j}..  & A_{m, n} MULTI_QUBIT_GATE S_{m, n}   \\
#    [GATE](D_{1})  & ..[GATE](D_{j})..  & [GATE](D_{n})   \\
#    C_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & C_{1, n} MULTI_QUBIT_GATE R_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & C_{i, n} MULTI_QUBIT_GATE R_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    C_{k, 1} MULTI_QUBIT_GATE R_{k, 1}  & ..C_{k, j} MULTI_QUBIT_GATE R_{k, j}..  & C_{k, n} MULTI_QUBIT_GATE R_{k, n}

# %%
Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Rij), one, k), 
                                            MultiQubitGate(IndexedVar(B, i), IndexedVar(S, i)),
                               ExprRange(j, MultiQubitGate(Cij, Qij), one, h)), 
                                    one, m)))
# Out:
# A_{1, 1} MULTI_QUBIT_GATE R_{1, 1} A_{1, k} MULTI_QUBIT_GATE R_{1, k}
# C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1} C_{1, h} MULTI_QUBIT_GATE Q_{1, h}
#  A_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & A_{1, k} MULTI_QUBIT_GATE R_{1, k}  & B_{1} MULTI_QUBIT_GATE S_{1}  & C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE Q_{1, j}..  & C_{1, h} MULTI_QUBIT_GATE Q_{1, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & A_{i, k} MULTI_QUBIT_GATE R_{i, k}  & B_{i} MULTI_QUBIT_GATE S_{i}  & C_{i, 1} MULTI_QUBIT_GATE Q_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE Q_{i, j}..  & C_{i, h} MULTI_QUBIT_GATE Q_{i, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE R_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE R_{m, j}..  & A_{m, k} MULTI_QUBIT_GATE R_{m, k}  & B_{m} MULTI_QUBIT_GATE S_{m}  & C_{m, 1} MULTI_QUBIT_GATE Q_{m, 1}  & ..C_{m, j} MULTI_QUBIT_GATE Q_{m, j}..  & C_{m, h} MULTI_QUBIT_GATE Q_{m, h}

# %%
print(Implies(
            CircuitEquiv(
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(IndexedVar(B, i), IndexedVar(S, i))), one, m))),
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(IndexedVar(D, i), IndexedVar(S, i))), one, m)))
            ),
            CircuitEquiv(
                        Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Rij), one, k), 
                                            MultiQubitGate(IndexedVar(B, i), IndexedVar(S, i)),
                                            ExprRange(j, MultiQubitGate(Cij, Qij), one, h)), 
                                    one, m))),
                        Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Rij), one, k), 
                                            MultiQubitGate(IndexedVar(D, i), IndexedVar(S, i)),
                                            ExprRange(j, MultiQubitGate(Cij, Qij), one, h)), 
                                    one, m)))
            )
        ).withWrappingAt(1).latex())
# Out:
# A_{1, 1} MULTI_QUBIT_GATE R_{1, 1} A_{1, k} MULTI_QUBIT_GATE R_{1, k}
# C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1} C_{1, h} MULTI_QUBIT_GATE Q_{1, h}
# A_{1, 1} MULTI_QUBIT_GATE R_{1, 1} A_{1, k} MULTI_QUBIT_GATE R_{1, k}
# C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1} C_{1, h} MULTI_QUBIT_GATE Q_{1, h}
# \begin{array}{c} \left(\Qcircuit@C=1em @R=.7em{
# & \gate{B_{1}{\Big \{}S_{1}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1]   \\
#   & \gate{B_{m}{\Big \{}S_{m}}
# } \cong \Qcircuit@C=1em @R=.7em{
# & \gate{D_{1}{\Big \{}S_{1}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1]   \\
#   & \gate{D_{m}{\Big \{}S_{m}}
# }\right) \\  \Rightarrow \left(\Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{}R_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, k}{\Big \{}R_{1, k}} \qwx[1] & \gate{B_{1}{\Big \{}S_{1}} \qwx[1] & \gate{C_{1, 1}{\Big \{}Q_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1, h}{\Big \{}Q_{1, h}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{}R_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{C_{i, j}{\Big \{}Q_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{m, 1}{\Big \{}R_{m, 1}} & \gate{\cdots} & \gate{A_{m, k}{\Big \{}R_{m, k}} & \gate{B_{m}{\Big \{}S_{m}} & \gate{C_{m, 1}{\Big \{}Q_{m, 1}} & \gate{\cdots} & \gate{C_{m, h}{\Big \{}Q_{m, h}}
# } \cong \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{}R_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, k}{\Big \{}R_{1, k}} \qwx[1] & \gate{D_{1}{\Big \{}S_{1}} \qwx[1] & \gate{C_{1, 1}{\Big \{}Q_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1, h}{\Big \{}Q_{1, h}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{}R_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{C_{i, j}{\Big \{}Q_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{m, 1}{\Big \{}R_{m, 1}} & \gate{\cdots} & \gate{A_{m, k}{\Big \{}R_{m, k}} & \gate{D_{m}{\Big \{}S_{m}} & \gate{C_{m, 1}{\Big \{}Q_{m, 1}} & \gate{\cdots} & \gate{C_{m, h}{\Big \{}Q_{m, h}}
# }\right) \end{array}

# %%
Implies(
            CircuitEquiv(
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(IndexedVar(B, i), IndexedVar(S, i))), one, m))),
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(IndexedVar(D, i), IndexedVar(S, i))), one, m)))
            ),
            CircuitEquiv(
                        Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Rij), one, k), 
                                            MultiQubitGate(IndexedVar(B, i), IndexedVar(S, i)),
                                            ExprRange(j, MultiQubitGate(Cij, Qij), one, h)), 
                                    one, m))),
                        Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Rij), one, k), 
                                            MultiQubitGate(IndexedVar(D, i), IndexedVar(S, i)),
                                            ExprRange(j, MultiQubitGate(Cij, Qij), one, h)), 
                                    one, m)))
            )
        ).withWrappingAt(1)
# Out:
# A_{1, 1} MULTI_QUBIT_GATE R_{1, 1} A_{1, k} MULTI_QUBIT_GATE R_{1, k}
# C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1} C_{1, h} MULTI_QUBIT_GATE Q_{1, h}
# A_{1, 1} MULTI_QUBIT_GATE R_{1, 1} A_{1, k} MULTI_QUBIT_GATE R_{1, k}
# C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1} C_{1, h} MULTI_QUBIT_GATE Q_{1, h}
# ( B_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    B_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    B_{m} MULTI_QUBIT_GATE S_{m} equiv  D_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    D_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    D_{m} MULTI_QUBIT_GATE S_{m}) \\  => ( A_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & A_{1, k} MULTI_QUBIT_GATE R_{1, k}  & B_{1} MULTI_QUBIT_GATE S_{1}  & C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE Q_{1, j}..  & C_{1, h} MULTI_QUBIT_GATE Q_{1, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & A_{i, k} MULTI_QUBIT_GATE R_{i, k}  & B_{i} MULTI_QUBIT_GATE S_{i}  & C_{i, 1} MULTI_QUBIT_GATE Q_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE Q_{i, j}..  & C_{i, h} MULTI_QUBIT_GATE Q_{i, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE R_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE R_{m, j}..  & A_{m, k} MULTI_QUBIT_GATE R_{m, k}  & B_{m} MULTI_QUBIT_GATE S_{m}  & C_{m, 1} MULTI_QUBIT_GATE Q_{m, 1}  & ..C_{m, j} MULTI_QUBIT_GATE Q_{m, j}..  & C_{m, h} MULTI_QUBIT_GATE Q_{m, h} equiv  A_{1, 1} MULTI_QUBIT_GATE R_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE R_{1, j}..  & A_{1, k} MULTI_QUBIT_GATE R_{1, k}  & D_{1} MULTI_QUBIT_GATE S_{1}  & C_{1, 1} MULTI_QUBIT_GATE Q_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE Q_{1, j}..  & C_{1, h} MULTI_QUBIT_GATE Q_{1, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE R_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE R_{i, j}..  & A_{i, k} MULTI_QUBIT_GATE R_{i, k}  & D_{i} MULTI_QUBIT_GATE S_{i}  & C_{i, 1} MULTI_QUBIT_GATE Q_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE Q_{i, j}..  & C_{i, h} MULTI_QUBIT_GATE Q_{i, h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{m, 1} MULTI_QUBIT_GATE R_{m, 1}  & ..A_{m, j} MULTI_QUBIT_GATE R_{m, j}..  & A_{m, k} MULTI_QUBIT_GATE R_{m, k}  & D_{m} MULTI_QUBIT_GATE S_{m}  & C_{m, 1} MULTI_QUBIT_GATE Q_{m, 1}  & ..C_{m, j} MULTI_QUBIT_GATE Q_{m, j}..  & C_{m, h} MULTI_QUBIT_GATE Q_{m, h})

# %%
CircuitEquiv(Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, m)), one, q))),
                     Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, m)), one, q))))
# Out:
# A_{1, 1} MULTI_QUBIT_GATE S_{1, 1} A_{1, m} MULTI_QUBIT_GATE S_{1, m}
# A_{1, 1} MULTI_QUBIT_GATE S_{1, 1} A_{1, m} MULTI_QUBIT_GATE S_{1, m}
#  A_{1, 1} MULTI_QUBIT_GATE S_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE S_{1, j}..  & A_{1, m} MULTI_QUBIT_GATE S_{1, m}   \\
#    \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE S_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE S_{i, j}..  & A_{i, m} MULTI_QUBIT_GATE S_{i, m}   \\
#    \colon  & \colon  & \colon   \\
#    A_{q, 1} MULTI_QUBIT_GATE S_{q, 1}  & ..A_{q, j} MULTI_QUBIT_GATE S_{q, j}..  & A_{q, m} MULTI_QUBIT_GATE S_{q, m} equiv  A_{1, 1} MULTI_QUBIT_GATE S_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE S_{1, j}..  & A_{1, m} MULTI_QUBIT_GATE S_{1, m}   \\
#    \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE S_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE S_{i, j}..  & A_{i, m} MULTI_QUBIT_GATE S_{i, m}   \\
#    \colon  & \colon  & \colon   \\
#    A_{q, 1} MULTI_QUBIT_GATE S_{q, 1}  & ..A_{q, j} MULTI_QUBIT_GATE S_{q, j}..  & A_{q, m} MULTI_QUBIT_GATE S_{q, m}

# %%
print(CircuitEquiv(Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, m)), one, q))),
                   Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, m)), one, q)))).latex())
# Out:
# A_{1, 1} MULTI_QUBIT_GATE S_{1, 1} A_{1, m} MULTI_QUBIT_GATE S_{1, m}
# A_{1, 1} MULTI_QUBIT_GATE S_{1, 1} A_{1, m} MULTI_QUBIT_GATE S_{1, m}
# \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{}S_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, m}{\Big \{}S_{1, m}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{}S_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{q, 1}{\Big \{}S_{q, 1}} & \gate{\cdots} & \gate{A_{q, m}{\Big \{}S_{q, m}}
# } \cong \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{}S_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, m}{\Big \{}S_{1, m}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{}S_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{q, 1}{\Big \{}S_{q, 1}} & \gate{\cdots} & \gate{A_{q, m}{\Big \{}S_{q, m}}
# }

# %%
Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, m)), one, q),
        ExprTuple(ExprRange(i, MultiQubitGate(IndexedVar(B, i), IndexedVar(S, i)), one, m)),
        ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Sij), one, m)), one, s)))
# Out:
# A_{1, 1} MULTI_QUBIT_GATE S_{1, 1} A_{1, m} MULTI_QUBIT_GATE S_{1, m}
# B_{1} MULTI_QUBIT_GATE S_{1} B_{m} MULTI_QUBIT_GATE S_{m}
#  A_{1, 1} MULTI_QUBIT_GATE S_{1, 1}  & ..A_{1, j} MULTI_QUBIT_GATE S_{1, j}..  & A_{1, m} MULTI_QUBIT_GATE S_{1, m}   \\
#    \colon  & \colon  & \colon   \\
#    A_{i, 1} MULTI_QUBIT_GATE S_{i, 1}  & ..A_{i, j} MULTI_QUBIT_GATE S_{i, j}..  & A_{i, m} MULTI_QUBIT_GATE S_{i, m}   \\
#    \colon  & \colon  & \colon   \\
#    A_{q, 1} MULTI_QUBIT_GATE S_{q, 1}  & ..A_{q, j} MULTI_QUBIT_GATE S_{q, j}..  & A_{q, m} MULTI_QUBIT_GATE S_{q, m}   \\
#    B_{1} MULTI_QUBIT_GATE S_{1}  & ..B_{i} MULTI_QUBIT_GATE S_{i}..  & B_{m} MULTI_QUBIT_GATE S_{m}   \\
#    C_{1, 1} MULTI_QUBIT_GATE S_{1, 1}  & ..C_{1, j} MULTI_QUBIT_GATE S_{1, j}..  & C_{1, m} MULTI_QUBIT_GATE S_{1, m}   \\
#    \colon  & \colon  & \colon   \\
#    C_{i, 1} MULTI_QUBIT_GATE S_{i, 1}  & ..C_{i, j} MULTI_QUBIT_GATE S_{i, j}..  & C_{i, m} MULTI_QUBIT_GATE S_{i, m}   \\
#    \colon  & \colon  & \colon   \\
#    C_{s, 1} MULTI_QUBIT_GATE S_{s, 1}  & ..C_{s, j} MULTI_QUBIT_GATE S_{s, j}..  & C_{s, m} MULTI_QUBIT_GATE S_{s, m}

# %%
Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Bij, Sij), one, n)), one, m)))
# Out:
# B_{1, 1} MULTI_QUBIT_GATE S_{1, 1} B_{1, n} MULTI_QUBIT_GATE S_{1, n}
#  B_{1, 1} MULTI_QUBIT_GATE S_{1, 1}  & ..B_{1, j} MULTI_QUBIT_GATE S_{1, j}..  & B_{1, n} MULTI_QUBIT_GATE S_{1, n}   \\
#    \colon  & \colon  & \colon   \\
#    B_{i, 1} MULTI_QUBIT_GATE S_{i, 1}  & ..B_{i, j} MULTI_QUBIT_GATE S_{i, j}..  & B_{i, n} MULTI_QUBIT_GATE S_{i, n}   \\
#    \colon  & \colon  & \colon   \\
#    B_{m, 1} MULTI_QUBIT_GATE S_{m, 1}  & ..B_{m, j} MULTI_QUBIT_GATE S_{m, j}..  & B_{m, n} MULTI_QUBIT_GATE S_{m, n}

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), Gate(H), Output(ketPlus)), 
        ExprTuple(Input(ket1), MultiQubitGate(H, Set(two)), Output(ketMinus))))
# MultiQubitGate of a single gate - automatic equality reductions.
# Out:
#  [INPUT](|0〉)  & [GATE](H)  & [OUTPUT](|+〉)   \\
#    [INPUT](|1〉)  & H MULTI_QUBIT_GATE {2}  & [OUTPUT](|-〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), Gate(IdentityOp()), Output(ketPlus)), 
        ExprTuple(Input(ket1), Gate(), Output(ketMinus))))
# Empty gate reduction
# Out:
#  [INPUT](|0〉)  & --  & [OUTPUT](|+〉)   \\
#    [INPUT](|1〉)  & [GATE]()  & [OUTPUT](|-〉)

# %%
#Circuit(ExprRange(i, Gate(ExprRange(j, Aij, one, n)), one, m))

# %%
# multigate block test
Circuit(ExprArray(ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two, three, four, six, seven)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two, three, four, six, seven)), 
                  Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two, three, four, six, seven)), Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(one, two, three, four, six, seven)), 
                  Output(ket1)),
        ExprTuple(Input(ket0), Gate(IdentityOp()), Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(one, two, three, four, six, seven)), 
                  Output(ket1)),
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(one, two, three, four, six, seven)), 
                  Output(ket1))))
# Out:
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4, 6, 7}  & [OUTPUT](|1〉)

# %%
# multigate block test
Circuit(ExprArray(ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two, three, four)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two, three, four)), 
                  Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two, three, four)), Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(one, two, three, four)), 
                  Output(ket1))))
# Out:
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2, 3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {1, 2, 3, 4}  & [OUTPUT](|1〉)

# %%
# Single Qubit Gates

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), Gate(H), Output(ketPlus)), 
        ExprTuple(Input(ket1), Gate(H), Output(ketMinus))))
# H gate (both inputs)
# Out:
#  [INPUT](|0〉)  & [GATE](H)  & [OUTPUT](|+〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & [OUTPUT](|-〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), Gate(X), Output(ket1)), 
        ExprTuple(Input(ket1), Gate(X), Output(ket0))))
# X gate (both inputs)
# Out:
#  [INPUT](|0〉)  & [GATE](X)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](X)  & [OUTPUT](|0〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), Gate(Z), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(Z), Output(Neg(ket1)))))
# Z gate (both inputs)
# Out:
#  [INPUT](|0〉)  & [GATE](Z)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](Z)  & [OUTPUT](-|1〉)

# %%
#Two Qubit Gates

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(three, four)), Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(three, four)), 
                  Output(ket1))))
#CZ gate - 0 qubit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(one, two)), Output(ket1)), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(three, four)), Output(ket1)), 
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(three, four)), 
                  Output(Neg(ket1))))) 
#CZ gate - 1 qubit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](-|1〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(X, Set(one, two)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(three, four)), Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(three, four)), Output(ket1)))) 
#CX gate - 0 qubit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(one, two)), Output(ket1)), 
        ExprTuple(Input(ket0), MultiQubitGate(X, Set(one, two)), Output(ket1)), 
        ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(three, four)), Output(ket1)), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(three, four)), Output(ket0)))) 
#CX gate - 1 qubit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)

# %%
Circuit(ExprArray(ExprTuple(Input(zero), MultiQubitGate(CLASSICAL_CONTROL, Set(one, two)), SPACE), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(zero), MultiQubitGate(CLASSICAL_CONTROL, Set(three, four)), SPACE), 
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(three, four)), 
                  Output(ket1)))) 
#cZ gate - 0 classical bit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](0)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {1, 2} & SPACE   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](0)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {3, 4} & SPACE   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)

# %%
Circuit(ExprArray(ExprTuple(Input(one), MultiQubitGate(CLASSICAL_CONTROL, Set(one, two)), SPACE), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(one), MultiQubitGate(CLASSICAL_CONTROL, Set(three, four)), SPACE), 
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(three, four)), 
                  Output(Neg(ket1)))))
#cZ gate - 1 classical bit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](1)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {1, 2} & SPACE   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](1)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {3, 4} & SPACE   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](-|1〉)

# %%
Circuit(ExprArray(ExprTuple(Input(zero), MultiQubitGate(CLASSICAL_CONTROL, Set(one, two)), SPACE), 
        ExprTuple(Input(ket0), MultiQubitGate(X, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(zero), MultiQubitGate(CLASSICAL_CONTROL, Set(three, four)), SPACE), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(three, four)), 
                  Output(ket1)))) 
#cX gate - 0 classical bit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](0)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {1, 2} & SPACE   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](0)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {3, 4} & SPACE   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)

# %%
Circuit(ExprArray(ExprTuple(Input(one), MultiQubitGate(CLASSICAL_CONTROL, Set(one, two)), SPACE), 
        ExprTuple(Input(ket0), MultiQubitGate(X, Set(one, two)), 
                  Output(ket1)), 
        ExprTuple(Input(one), MultiQubitGate(CLASSICAL_CONTROL, Set(three, four)), SPACE), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(three, four)), 
                  Output(ket0))))
#cX gate - 1 classical bit control for 1 and 0 qubit inputs
# Out:
#  [INPUT](1)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {1, 2} & SPACE   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|1〉)   \\
#    [INPUT](1)  & CLASSICAL\_CONTROL MULTI_QUBIT_GATE {3, 4} & SPACE   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)

# %%
#NULL GATES

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), Gate(H), Gate(H), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(H), Gate(H), Output(ket1))))
# Out:
#  [INPUT](|0〉)  & [GATE](H)  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & [GATE](H)  & [OUTPUT](|1〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), Gate(X), Gate(X), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(X), Gate(X), Output(ket1))))
# Out:
#  [INPUT](|0〉)  & [GATE](X)  & [GATE](X)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](X)  & [GATE](X)  & [OUTPUT](|1〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), Gate(Z), Gate(Z), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(Z), Gate(Z), Output(ket1))))
# Out:
#  [INPUT](|0〉)  & [GATE](Z)  & [GATE](Z)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](Z)  & [GATE](Z)  & [OUTPUT](|1〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two)), MultiQubitGate(CONTROL, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two)), MultiQubitGate(Z, Set(one, two)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(three, four)), MultiQubitGate(CONTROL, Set(three, four)), 
                  Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(three, four)), MultiQubitGate(Z, Set(three, four)), 
                  Output(ket1)),
        ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(five, six)), MultiQubitGate(CONTROL, Set(five, six)),
                  Output(ket1)),
        ExprTuple(Input(ket0), MultiQubitGate(Z, Set(five, six)), MultiQubitGate(Z, Set(five, six)),
                  Output(ket0)),
        ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(seven, eight)), MultiQubitGate(CONTROL, Set(seven, eight)), 
                  Output(ket1)), 
        ExprTuple(Input(ket1), MultiQubitGate(Z, Set(seven, eight)), MultiQubitGate(Z, Set(seven, eight)), 
                  Output(ket1)))) 
# Double CZ gate
# Out:
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {3, 4}  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {5, 6}  & Z MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {7, 8}  & Z MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two)), MultiQubitGate(CONTROL, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(X, Set(one, two)), MultiQubitGate(X, Set(one, two)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(three, four)), MultiQubitGate(CONTROL, Set(three, four)), 
                  Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(three, four)), MultiQubitGate(X, Set(three, four)), 
                  Output(ket1)),
        ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(five, six)), MultiQubitGate(CONTROL, Set(five, six)),
                  Output(ket1)),
        ExprTuple(Input(ket0), MultiQubitGate(X, Set(five, six)), MultiQubitGate(X, Set(five, six)),
                  Output(ket0)),
        ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(seven, eight)), MultiQubitGate(CONTROL, Set(seven, eight)), 
                  Output(ket1)), 
        ExprTuple(Input(ket1), MultiQubitGate(X, Set(seven, eight)), MultiQubitGate(X, Set(seven, eight)), 
                  Output(ket1)))) 
# Double CX gate
# Out:
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {1, 2}  & X MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {3, 4}  & X MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & X MULTI_QUBIT_GATE {5, 6}  & X MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & X MULTI_QUBIT_GATE {7, 8}  & X MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two)), Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(U, Set(one, two)), 
                  Output(ket0)), 
        ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(three, four)), Output(ket0)), 
        ExprTuple(Input(ket1), MultiQubitGate(U, Set(three, four)), 
                  Output(ket1)))) 
#CU gate - 0 classical bit control for 1 and 0 qubit inputs (Always null regardless of what U is)
# Out:
#  [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & U MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & U MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)

# %%
# CONGRUENCIES

# %%
Circuit(ExprArray(
    ExprTuple(Input(ket0), MultiQubitGate(Z, Set(one, two)), Output(ket0)), 
    ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(one, two)), 
              Output(ket0)), 
    ExprTuple(Input(ket0), MultiQubitGate(Z, Set(three, four)), Output(ket0)), 
    ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(three, four)), 
                Output(ket1)),
    ExprTuple(Input(ket1), MultiQubitGate(Z, Set(five, six)), Output(ket1)), 
    ExprTuple(Input(ket0), MultiQubitGate(CONTROL, Set(five, six)), 
              Output(ket0)), 
    ExprTuple(Input(ket1), MultiQubitGate(Z, Set(seven, eight)), Output(Neg(ket1))), 
    ExprTuple(Input(ket1), MultiQubitGate(CONTROL, Set(seven, eight)), 
              Output(ket1))))

#Congruent to a regular CZ gate
# Out:
#  [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & Z MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & Z MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](-|1〉)   \\
#    [INPUT](|1〉)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [OUTPUT](|1〉)

# %%
Circuit(ExprArray(
        ExprTuple(Input(ket0), Gate(IdentityOp()), MultiQubitGate(CONTROL, Set(one, two)), Gate(IdentityOp()), Output(ket0)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(Z, Set(one, two)), Gate(H), Output(ket0)),
        ExprTuple(Input(ket0), Gate(IdentityOp()), MultiQubitGate(CONTROL, Set(three, four)), Gate(IdentityOp()), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(Z, Set(three, four)), Gate(H), Output(ket1)),
        ExprTuple(Input(ket1), Gate(IdentityOp()), MultiQubitGate(CONTROL, Set(five, six)), Gate(IdentityOp()), Output(ket1)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(Z, Set(five, six)), Gate(H), Output(ket1)),
        ExprTuple(Input(ket1), Gate(IdentityOp()), MultiQubitGate(CONTROL, Set(seven, eight)), Gate(IdentityOp()), Output(ket1)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(Z, Set(seven, eight)), Gate(H), Output(ket0))))
# Congruent to a CX gate
# Out:
#  [INPUT](|0〉)  & --  & CONTROL MULTI_QUBIT_GATE {1, 2}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & --  & CONTROL MULTI_QUBIT_GATE {3, 4}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & --  & CONTROL MULTI_QUBIT_GATE {5, 6}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & --  & CONTROL MULTI_QUBIT_GATE {7, 8}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|0〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(one, two)), Gate(H), Output(ket0)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(Z, Set(one, two)), Gate(H), Output(ket0)),
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(three, four)), Gate(H), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(Z, Set(three, four)), Gate(H), Output(ket1)),
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(five, six)), Gate(H), Output(ket1)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(Z, Set(five, six)), Gate(H), Output(ket1)),
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(seven, eight)), Gate(H), Output(ket1)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(Z, Set(seven, eight)), Gate(H), Output(ket0))))
# Intermediate step to show the congruence of a switched CX gate
# Out:
#  [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|0〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), Gate(H), MultiQubitGate(Z, Set(one, two)), Gate(H), Output(ket0)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(one, two)), Gate(H), Output(ket0)),
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(Z, Set(three, four)), Gate(H), Output(ket1)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(three, four)), Gate(H), Output(ket1)),
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(Z, Set(five, six)), Gate(H), Output(ket1)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(five, six)), Gate(H), Output(ket0)),
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(Z, Set(seven, eight)), Gate(H), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(seven, eight)), Gate(H), Output(ket1))))
# using cell 24 we can show that this is equivalent to cell 26
# Out:
#  [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & Z MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|1〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(one, two)), Gate(H), Output(ket0)), 
        ExprTuple(Input(ket0), Gate(IdentityOp()), MultiQubitGate(X, Set(one, two)), Gate(IdentityOp()), Output(ket0)),
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(three, four)), Gate(H), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(IdentityOp()), MultiQubitGate(X, Set(three, four)), Gate(IdentityOp()), Output(ket1)),
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(five, six)), Gate(H), Output(ket1)), 
        ExprTuple(Input(ket0), Gate(IdentityOp()), MultiQubitGate(X, Set(five, six)), Gate(IdentityOp()), Output(ket1)),
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(seven, eight)), Gate(H), Output(ket1)), 
        ExprTuple(Input(ket1), Gate(IdentityOp()), MultiQubitGate(X, Set(seven, eight)), Gate(IdentityOp()), Output(ket0))))
# using cell 26, we apply instantiation to return to the X gates
# Out:
#  [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & --  & X MULTI_QUBIT_GATE {1, 2}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & --  & X MULTI_QUBIT_GATE {3, 4}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & --  & X MULTI_QUBIT_GATE {5, 6}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & --  & X MULTI_QUBIT_GATE {7, 8}  & --  & [OUTPUT](|0〉)

# %%
Circuit(ExprArray(ExprTuple(Input(ket0), Gate(IdentityOp()), MultiQubitGate(X, Set(one, two)), Gate(IdentityOp()), Output(ket0)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(one, two)), Gate(H), Output(ket0)),
        ExprTuple(Input(ket0), Gate(IdentityOp()), MultiQubitGate(X, Set(three, four)), Gate(IdentityOp()), Output(ket1)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(three, four)), Gate(H), Output(ket1)),
        ExprTuple(Input(ket1), Gate(IdentityOp()), MultiQubitGate(X, Set(five, six)), Gate(IdentityOp()), Output(ket1)), 
        ExprTuple(Input(ket0), Gate(H), MultiQubitGate(CONTROL, Set(five, six)), Gate(H), Output(ket0)),
        ExprTuple(Input(ket1), Gate(IdentityOp()), MultiQubitGate(X, Set(seven, eight)), Gate(IdentityOp()), Output(ket0)), 
        ExprTuple(Input(ket1), Gate(H), MultiQubitGate(CONTROL, Set(seven, eight)), Gate(H), Output(ket1))))
# using cell 27 we can show that cell 28 is congruent to this cell
# Out:
#  [INPUT](|0〉)  & --  & X MULTI_QUBIT_GATE {1, 2}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {1, 2}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|0〉)  & --  & X MULTI_QUBIT_GATE {3, 4}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {3, 4}  & [GATE](H)  & [OUTPUT](|1〉)   \\
#    [INPUT](|1〉)  & --  & X MULTI_QUBIT_GATE {5, 6}  & --  & [OUTPUT](|1〉)   \\
#    [INPUT](|0〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {5, 6}  & [GATE](H)  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & --  & X MULTI_QUBIT_GATE {7, 8}  & --  & [OUTPUT](|0〉)   \\
#    [INPUT](|1〉)  & [GATE](H)  & CONTROL MULTI_QUBIT_GATE {7, 8}  & [GATE](H)  & [OUTPUT](|1〉)

# %%
# try:
#     Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, Aij, one, m)), one, q),
#          ExprTuple(ExprRange(j, Bij, one, m)),
#          ExprRange(i, ExprTuple(ExprRange(j, Cij, one, m)), one, s))).latex()
#     assert False, "Expected a TypeError error."
# except TypeError as e:
#     print("Expected error:", e)

# %%
# %end demonstrations
