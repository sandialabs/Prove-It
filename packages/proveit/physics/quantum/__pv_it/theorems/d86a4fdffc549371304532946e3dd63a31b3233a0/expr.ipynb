# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, Conditional, D, ExprArray, ExprRange, IndexedVar, Q, R, Variable, i, j, k, m, n
from proveit.core_expr_types.expr_arrays import Aij, Cij, Rij, S11_to_Smn, Sij
from proveit.logic import And, Forall, Implies, InSet
from proveit.numbers import NaturalPos, one
from proveit.physics.quantum import Gate
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr3 = [sub_expr1, sub_expr2]
sub_expr4 = [ExprRange(j, Gate(IndexedVar(B, j)), one, n)]
sub_expr5 = [ExprRange(j, Gate(IndexedVar(D, j)), one, n)]
sub_expr6 = ExprRange(i, [ExprRange(j, MultiQubitGate(Aij, Sij), one, n)], one, m)
sub_expr7 = ExprRange(i, [ExprRange(j, MultiQubitGate(Cij, Rij), one, n)], one, k)
expr = Conditional(Forall([ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(A, sub_expr3), one, n), one, m), ExprRange(sub_expr1, IndexedVar(B, sub_expr1), one, n), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(C, sub_expr3), one, n), one, k), ExprRange(sub_expr1, IndexedVar(D, sub_expr1), one, n), S11_to_Smn, ExprRange(sub_expr1, IndexedVar(Q, sub_expr1), one, n), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(R, sub_expr3), one, n), one, k)], Implies(CircuitEquiv(Circuit(ExprArray(sub_expr4)), Circuit(ExprArray(sub_expr5))), CircuitEquiv(Circuit(ExprArray(sub_expr6, sub_expr4, sub_expr7)), Circuit(ExprArray(sub_expr6, sub_expr5, sub_expr7)))).with_wrapping_at(2)).wrap_params(), And(InSet(k, NaturalPos), InSet(m, NaturalPos), InSet(n, NaturalPos)))
# Out:
# expr: {forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, n}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, n}...., A_{m, 1}, ..A_{m, _b}.., A_{m, n}, B_{1}, ..B_{_a}.., B_{n}, C_{1, 1}, ..C_{1, _b}.., C_{1, n}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, n}...., C_{k, 1}, ..C_{k, _b}.., C_{k, n}, D_{1}, ..D_{_a}.., D_{n}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}, Q_{1}, ..Q_{_a}.., Q_{n}, R_{1, 1}, ..R_{1, _b}.., R_{1, n}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, n}...., R_{k, 1}, ..R_{k, _b}.., R_{k, n}} (( Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n}) equiv  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})) =>  \\ ( MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}) equiv  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}))) if k in NaturalPos ,  m in NaturalPos ,  n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{ \scriptsize \begin{array}{c}
# A_{1, 1}, \ldots, A_{1, n}, \ldots\ldots, A_{m, 1}, \ldots, A_{m, n}, B_{1}, \ldots, B_{n}, \\
# C_{1, 1}, \ldots, C_{1, n}, \ldots\ldots, C_{k, 1}, \ldots, C_{k, n}, D_{1}, \ldots, D_{n}, \\
# S_{1, 1}, \ldots, S_{1, n}, \ldots\ldots, S_{m, 1}, \ldots, S_{m, n}, Q_{1}, \ldots, Q_{n}, \\
# R_{1, 1}, \ldots, R_{1, n}, \ldots\ldots, R_{k, 1}, \ldots, R_{k, n}\end{array}
# }~  \\
# \left(\begin{array}{c} \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1}} & \gate{\cdots} & \gate{B_{n}}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{1}} & \gate{\cdots} & \gate{D_{n}}
# } \hspace{2em}\right) \Rightarrow  \\ \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} S_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, n}{\Big \{} S_{1, n}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{} S_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{m, 1}{\Big \{} S_{m, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{m, n}{\Big \{} S_{m, n}} \qwx[1]   \\
#   & \gate{B_{1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{B_{n}} \qwx[1]   \\
#   & \gate{C_{1, 1}{\Big \{} R_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1, n}{\Big \{} R_{1, n}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{C_{i, j}{\Big \{} R_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{C_{k, 1}{\Big \{} R_{k, 1}} & \gate{\cdots} & \gate{C_{k, n}{\Big \{} R_{k, n}}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} S_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, n}{\Big \{} S_{1, n}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{} S_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{m, 1}{\Big \{} S_{m, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{m, n}{\Big \{} S_{m, n}} \qwx[1]   \\
#   & \gate{D_{1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{D_{n}} \qwx[1]   \\
#   & \gate{C_{1, 1}{\Big \{} R_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1, n}{\Big \{} R_{1, n}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{C_{i, j}{\Big \{} R_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{C_{k, 1}{\Big \{} R_{k, 1}} & \gate{\cdots} & \gate{C_{k, n}{\Big \{} R_{k, n}}
# } \hspace{2em}\right) \end{array}\right) \textrm{ if } k \in \mathbb{N}^+ ,  m \in \mathbb{N}^+ ,  n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, n}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, n}...., A_{m, 1}, ..A_{m, _b}.., A_{m, n}, B_{1}, ..B_{_a}.., B_{n}, C_{1, 1}, ..C_{1, _b}.., C_{1, n}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, n}...., C_{k, 1}, ..C_{k, _b}.., C_{k, n}, D_{1}, ..D_{_a}.., D_{n}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}, Q_{1}, ..Q_{_a}.., Q_{n}, R_{1, 1}, ..R_{1, _b}.., R_{1, n}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, n}...., R_{k, 1}, ..R_{k, _b}.., R_{k, n}} (( Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n}) equiv  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})) =>  \\ ( MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}) equiv  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}))) if k in NaturalPos ,  m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, n}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, n}...., A_{m, 1}, ..A_{m, _b}.., A_{m, n}, B_{1}, ..B_{_a}.., B_{n}, C_{1, 1}, ..C_{1, _b}.., C_{1, n}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, n}...., C_{k, 1}, ..C_{k, _b}.., C_{k, n}, D_{1}, ..D_{_a}.., D_{n}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}, Q_{1}, ..Q_{_a}.., Q_{n}, R_{1, 1}, ..R_{1, _b}.., R_{1, n}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, n}...., R_{k, 1}, ..R_{k, _b}.., R_{k, n}} (( Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n}) equiv  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})) =>  \\ ( MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}) equiv  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n})))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (k in NaturalPos) and (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (A_{1, 1}, ..A_{1, _b}.., A_{1, n}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, n}...., A_{m, 1}, ..A_{m, _b}.., A_{m, n}, B_{1}, ..B_{_a}.., B_{n}, C_{1, 1}, ..C_{1, _b}.., C_{1, n}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, n}...., C_{k, 1}, ..C_{k, _b}.., C_{k, n}, D_{1}, ..D_{_a}.., D_{n}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}, Q_{1}, ..Q_{_a}.., Q_{n}, R_{1, 1}, ..R_{1, _b}.., R_{1, n}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, n}...., R_{k, 1}, ..R_{k, _b}.., R_{k, n}) -> (( Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n}) equiv  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})) =>  \\ ( MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}) equiv  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n})))
#    core type: Lambda
#    parameters: 7\n   body: 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (k in NaturalPos, m in NaturalPos, n in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. (A_{1, 1}, ..A_{1, _b}.., A_{1, n}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, n}...., A_{m, 1}, ..A_{m, _b}.., A_{m, n}, B_{1}, ..B_{_a}.., B_{n}, C_{1, 1}, ..C_{1, _b}.., C_{1, n}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, n}...., C_{k, 1}, ..C_{k, _b}.., C_{k, n}, D_{1}, ..D_{_a}.., D_{n}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}, Q_{1}, ..Q_{_a}.., Q_{n}, R_{1, 1}, ..R_{1, _b}.., R_{1, n}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, n}...., R_{k, 1}, ..R_{k, _b}.., R_{k, n})
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15, 16, 17, 18
# 8. ( Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n}) equiv  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})) =>  \\ ( MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}) equiv  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}))
#    core type: Operation
#    operator: 19
#    operands: 20
# 9. k in NaturalPos
#    core type: Operation
#    operator: 23
#    operands: 21
# 10. m in NaturalPos
#     core type: Operation
#     operator: 23
#     operands: 22
# 11. n in NaturalPos
#     core type: Operation
#     operator: 23
#     operands: 24
# 12. A_{1, 1}, ..A_{1, _b}.., A_{1, n}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, n}...., A_{m, 1}, ..A_{m, _b}.., A_{m, n}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 93
#     end_index: 76
# 13. B_{1}, ..B_{_a}.., B_{n}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 93
#     end_index: 94
# 14. C_{1, 1}, ..C_{1, _b}.., C_{1, n}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, n}...., C_{k, 1}, ..C_{k, _b}.., C_{k, n}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 93
#     end_index: 79
# 15. D_{1}, ..D_{_a}.., D_{n}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 93
#     end_index: 94
# 16. S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 93
#     end_index: 76
# 17. Q_{1}, ..Q_{_a}.., Q_{n}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 93
#     end_index: 94
# 18. R_{1, 1}, ..R_{1, _b}.., R_{1, n}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, n}...., R_{k, 1}, ..R_{k, _b}.., R_{k, n}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 93
#     end_index: 79
# 19. =>
#     core type: Literal
#     sub-expressions:
# 20. ( Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n}) equiv  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n}),  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}) equiv  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 21. (k, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 79, 34
# 22. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 76, 34
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 94, 34
# 25. _a -> A_{_a, 1}, ..A_{_a, _b}.., A_{_a, n}
#     core type: Lambda
#     parameter: 68
#     body: 35
# 26. _a -> B_{_a}
#     core type: Lambda
#     parameter: 68
#     body: 36
# 27. _a -> C_{_a, 1}, ..C_{_a, _b}.., C_{_a, n}
#     core type: Lambda
#     parameter: 68
#     body: 37
# 28. _a -> D_{_a}
#     core type: Lambda
#     parameter: 68
#     body: 38
# 29. _a -> S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}
#     core type: Lambda
#     parameter: 68
#     body: 39
# 30. _a -> Q_{_a}
#     core type: Lambda
#     parameter: 68
#     body: 40
# 31. _a -> R_{_a, 1}, ..R_{_a, _b}.., R_{_a, n}
#     core type: Lambda
#     parameter: 68
#     body: 41
# 32.  Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n}) equiv  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})
#     core type: Operation
#     operator: 43
#     operands: 42
# 33.  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}) equiv  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n})
#     core type: Operation
#     operator: 43
#     operands: 44
# 34. NaturalPos
#     core type: Literal
#     sub-expressions:
# 35. A_{_a, 1}, ..A_{_a, _b}.., A_{_a, n}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 93
#     end_index: 94
# 36. B_{_a}
#     core type: IndexedVar
# variable: 95
# index: 68
# 37. C_{_a, 1}, ..C_{_a, _b}.., C_{_a, n}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 93
#     end_index: 94
# 38. D_{_a}
#     core type: IndexedVar
# variable: 97
# index: 68
# 39. S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 93
#     end_index: 94
# 40. Q_{_a}
#     core type: IndexedVar
# variable: 48
# index: 68
# 41. R_{_a, 1}, ..R_{_a, _b}.., R_{_a, n}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 93
#     end_index: 94
# 42. ( Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n}),  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n}))
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 43. equiv
#     core type: Literal
#     sub-expressions:
# 44. ( MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}),  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 45. _b -> A_{_a, _b}
#     core type: Lambda
#     parameter: 69
#     body: 54
# 46. _b -> C_{_a, _b}
#     core type: Lambda
#     parameter: 69
#     body: 55
# 47. _b -> S_{_a, _b}
#     core type: Lambda
#     parameter: 69
#     body: 56
# 48. Q
#     core type: Variable
#     sub-expressions:
# 49. _b -> R_{_a, _b}
#     core type: Lambda
#     parameter: 69
#     body: 57
# 50.  Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})
#     core type: Operation
#     operator: 61
#     operand: 64
# 51.  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})
#     core type: Operation
#     operator: 61
#     operand: 65
# 52.  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n})
#     core type: Operation
#     operator: 61
#     operand: 66
# 53.  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n})
#     core type: Operation
#     operator: 61
#     operand: 67
# 54. A_{_a, _b}
#     core type: IndexedVar
# variable: 106
# indices: 63
# 55. C_{_a, _b}
#     core type: IndexedVar
# variable: 108
# indices: 63
# 56. S_{_a, _b}
#     core type: IndexedVar
# variable: 107
# indices: 63
# 57. R_{_a, _b}
#     core type: IndexedVar
# variable: 109
# indices: 63
# 58. ((Gate(B_{1}) & ..Gate(B_{j}).. & Gate(B_{n})))
#     core type: ExprTuple
#     sub-expressions: 64
# 59. ((Gate(D_{1}) & ..Gate(D_{j}).. & Gate(D_{n})))
#     core type: ExprTuple
#     sub-expressions: 65
# 60. ((MultiQubitGate(A_{1, 1}, S_{1, 1}) & ..MultiQubitGate(A_{1, j}, S_{1, j}).. & MultiQubitGate(A_{1, n}, S_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, S_{i, 1}) & ..MultiQubitGate(A_{i, j}, S_{i, j}).. & MultiQubitGate(A_{i, n}, S_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, S_{m, 1}) & ..MultiQubitGate(A_{m, j}, S_{m, j}).. & MultiQubitGate(A_{m, n}, S_{m, n})  \\
#   Gate(B_{1}) & ..Gate(B_{j}).. & Gate(B_{n})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{k, 1}, R_{k, 1}) & ..MultiQubitGate(C_{k, j}, R_{k, j}).. & MultiQubitGate(C_{k, n}, R_{k, n})))
#     core type: ExprTuple
#     sub-expressions: 66
# 61. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 62. ((MultiQubitGate(A_{1, 1}, S_{1, 1}) & ..MultiQubitGate(A_{1, j}, S_{1, j}).. & MultiQubitGate(A_{1, n}, S_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, S_{i, 1}) & ..MultiQubitGate(A_{i, j}, S_{i, j}).. & MultiQubitGate(A_{i, n}, S_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, S_{m, 1}) & ..MultiQubitGate(A_{m, j}, S_{m, j}).. & MultiQubitGate(A_{m, n}, S_{m, n})  \\
#   Gate(D_{1}) & ..Gate(D_{j}).. & Gate(D_{n})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{k, 1}, R_{k, 1}) & ..MultiQubitGate(C_{k, j}, R_{k, j}).. & MultiQubitGate(C_{k, n}, R_{k, n})))
#     core type: ExprTuple
#     sub-expressions: 67
# 63. (_a, _b)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 64. Gate(B_{1}) & ..Gate(B_{j}).. & Gate(B_{n})
#     core type: ExprTuple
#     sub-expressions: 70
# 65. Gate(D_{1}) & ..Gate(D_{j}).. & Gate(D_{n})
#     core type: ExprTuple
#     sub-expressions: 72
# 66. MultiQubitGate(A_{1, 1}, S_{1, 1}) & ..MultiQubitGate(A_{1, j}, S_{1, j}).. & MultiQubitGate(A_{1, n}, S_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, S_{i, 1}) & ..MultiQubitGate(A_{i, j}, S_{i, j}).. & MultiQubitGate(A_{i, n}, S_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, S_{m, 1}) & ..MultiQubitGate(A_{m, j}, S_{m, j}).. & MultiQubitGate(A_{m, n}, S_{m, n})  \\
#   Gate(B_{1}) & ..Gate(B_{j}).. & Gate(B_{n})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{k, 1}, R_{k, 1}) & ..MultiQubitGate(C_{k, j}, R_{k, j}).. & MultiQubitGate(C_{k, n}, R_{k, n})
#     core type: ExprTuple
#     sub-expressions: 71, 70, 73
# 67. MultiQubitGate(A_{1, 1}, S_{1, 1}) & ..MultiQubitGate(A_{1, j}, S_{1, j}).. & MultiQubitGate(A_{1, n}, S_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, S_{i, 1}) & ..MultiQubitGate(A_{i, j}, S_{i, j}).. & MultiQubitGate(A_{i, n}, S_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, S_{m, 1}) & ..MultiQubitGate(A_{m, j}, S_{m, j}).. & MultiQubitGate(A_{m, n}, S_{m, n})  \\
#   Gate(D_{1}) & ..Gate(D_{j}).. & Gate(D_{n})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{k, 1}, R_{k, 1}) & ..MultiQubitGate(C_{k, j}, R_{k, j}).. & MultiQubitGate(C_{k, n}, R_{k, n})
#     core type: ExprTuple
#     sub-expressions: 71, 72, 73
# 68. _a
#     core type: Variable
#     sub-expressions:
# 69. _b
#     core type: Variable
#     sub-expressions:
# 70. (Gate(B_{1}), ..Gate(B_{j}).., Gate(B_{n}))
#     core type: ExprTuple
#     sub-expressions: 74
# 71. (MultiQubitGate(A_{1, 1}, S_{1, 1}), ..MultiQubitGate(A_{1, j}, S_{1, j}).., MultiQubitGate(A_{1, n}, S_{1, n})), ..(MultiQubitGate(A_{i, 1}, S_{i, 1}), ..MultiQubitGate(A_{i, j}, S_{i, j}).., MultiQubitGate(A_{i, n}, S_{i, n})).., (MultiQubitGate(A_{m, 1}, S_{m, 1}), ..MultiQubitGate(A_{m, j}, S_{m, j}).., MultiQubitGate(A_{m, n}, S_{m, n}))
#     core type: ExprRange
#     lambda_map: 75
#     start_index: 93
#     end_index: 76
# 72. (Gate(D_{1}), ..Gate(D_{j}).., Gate(D_{n}))
#     core type: ExprTuple
#     sub-expressions: 77
# 73. (MultiQubitGate(C_{1, 1}, R_{1, 1}), ..MultiQubitGate(C_{1, j}, R_{1, j}).., MultiQubitGate(C_{1, n}, R_{1, n})), ..(MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, n}, R_{i, n})).., (MultiQubitGate(C_{k, 1}, R_{k, 1}), ..MultiQubitGate(C_{k, j}, R_{k, j}).., MultiQubitGate(C_{k, n}, R_{k, n}))
#     core type: ExprRange
#     lambda_map: 78
#     start_index: 93
#     end_index: 79
# 74. Gate(B_{1}), ..Gate(B_{j}).., Gate(B_{n})
#     core type: ExprRange
#     lambda_map: 80
#     start_index: 93
#     end_index: 94
# 75. i -> (MultiQubitGate(A_{i, 1}, S_{i, 1}), ..MultiQubitGate(A_{i, j}, S_{i, j}).., MultiQubitGate(A_{i, n}, S_{i, n}))
#     core type: Lambda
#     parameter: 111
#     body: 81
# 76. m
#     core type: Variable
#     sub-expressions:
# 77. Gate(D_{1}), ..Gate(D_{j}).., Gate(D_{n})
#     core type: ExprRange
#     lambda_map: 82
#     start_index: 93
#     end_index: 94
# 78. i -> (MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, n}, R_{i, n}))
#     core type: Lambda
#     parameter: 111
#     body: 83
# 79. k
#     core type: Variable
#     sub-expressions:
# 80. j -> Gate(B_{j})
#     core type: Lambda
#     parameter: 112
#     body: 84
# 81. (MultiQubitGate(A_{i, 1}, S_{i, 1}), ..MultiQubitGate(A_{i, j}, S_{i, j}).., MultiQubitGate(A_{i, n}, S_{i, n}))
#     core type: ExprTuple
#     sub-expressions: 85
# 82. j -> Gate(D_{j})
#     core type: Lambda
#     parameter: 112
#     body: 86
# 83. (MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, n}, R_{i, n}))
#     core type: ExprTuple
#     sub-expressions: 87
# 84. Gate(B_{j})
#     core type: Operation
#     operator: 90
#     operand: 88
# 85. MultiQubitGate(A_{i, 1}, S_{i, 1}), ..MultiQubitGate(A_{i, j}, S_{i, j}).., MultiQubitGate(A_{i, n}, S_{i, n})
#     core type: ExprRange
#     lambda_map: 89
#     start_index: 93
#     end_index: 94
# 86. Gate(D_{j})
#     core type: Operation
#     operator: 90
#     operand: 91
# 87. MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, n}, R_{i, n})
#     core type: ExprRange
#     lambda_map: 92
#     start_index: 93
#     end_index: 94
# 88. B_{j}
#     core type: IndexedVar
# variable: 95
# index: 112
# 89. j -> MultiQubitGate(A_{i, j}, S_{i, j})
#     core type: Lambda
#     parameter: 112
#     body: 96
# 90. GATE
#     core type: Literal
#     sub-expressions:
# 91. D_{j}
#     core type: IndexedVar
# variable: 97
# index: 112
# 92. j -> MultiQubitGate(C_{i, j}, R_{i, j})
#     core type: Lambda
#     parameter: 112
#     body: 98
# 93. 1
#     core type: Literal
#     sub-expressions:
# 94. n
#     core type: Variable
#     sub-expressions:
# 95. B
#     core type: Variable
#     sub-expressions:
# 96. MultiQubitGate(A_{i, j}, S_{i, j})
#     core type: Operation
#     operator: 100
#     operands: 99
# 97. D
#     core type: Variable
#     sub-expressions:
# 98. MultiQubitGate(C_{i, j}, R_{i, j})
#     core type: Operation
#     operator: 100
#     operands: 101
# 99. (A_{i, j}, S_{i, j})
#     core type: ExprTuple
#     sub-expressions: 102, 103
# 100. MULTI_QUBIT_GATE
#      core type: Literal
#      sub-expressions:
# 101. (C_{i, j}, R_{i, j})
#      core type: ExprTuple
#      sub-expressions: 104, 105
# 102. A_{i, j}
#      core type: IndexedVar
# variable: 106
# indices: 110
# 103. S_{i, j}
#      core type: IndexedVar
# variable: 107
# indices: 110
# 104. C_{i, j}
#      core type: IndexedVar
# variable: 108
# indices: 110
# 105. R_{i, j}
#      core type: IndexedVar
# variable: 109
# indices: 110
# 106. A
#      core type: Variable
#      sub-expressions:
# 107. S
#      core type: Variable
#      sub-expressions:
# 108. C
#      core type: Variable
#      sub-expressions:
# 109. R
#      core type: Variable
#      sub-expressions:
# 110. (i, j)
#      core type: ExprTuple
#      sub-expressions: 111, 112
# 111. i
#      core type: Variable
#      sub-expressions:
# 112. j
#      core type: Variable
#      sub-expressions:
