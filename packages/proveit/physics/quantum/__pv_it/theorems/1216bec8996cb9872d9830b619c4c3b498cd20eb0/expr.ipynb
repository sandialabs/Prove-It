# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, D, ExprArray, ExprRange, IndexedVar, Lambda, Q, R, S, Variable, h, i, j, k, m
from proveit.core_expr_types.expr_arrays import Aij, Cij, Qij, Rij
from proveit.logic import And, Implies
from proveit.numbers import one
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr3 = [sub_expr1, sub_expr2]
sub_expr4 = IndexedVar(S, i)
sub_expr5 = MultiQubitGate(IndexedVar(B, i), sub_expr4)
sub_expr6 = MultiQubitGate(IndexedVar(D, i), sub_expr4)
sub_expr7 = ExprRange(j, MultiQubitGate(Aij, Rij), one, k)
sub_expr8 = ExprRange(j, MultiQubitGate(Cij, Qij), one, h)
expr = Lambda([ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(A, sub_expr3), one, k), one, m), ExprRange(sub_expr1, IndexedVar(B, sub_expr1), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(C, sub_expr3), one, h), one, m), ExprRange(sub_expr1, IndexedVar(D, sub_expr1), one, m), ExprRange(sub_expr1, IndexedVar(S, sub_expr1), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(R, sub_expr3), one, k), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(Q, sub_expr3), one, h), one, m)], Implies(And(CircuitEquiv(Circuit(ExprArray(ExprRange(i, [sub_expr5], one, m))), Circuit(ExprArray(ExprRange(i, [sub_expr6], one, m)))), Circuit(ExprArray(ExprRange(i, [sub_expr7, sub_expr5, sub_expr8], one, m)))), Circuit(ExprArray(ExprRange(i, [sub_expr7, sub_expr6, sub_expr8], one, m)))).with_wrapping_at(2))
# Out:
# expr: (A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}) -> ((( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})) and  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h})) =>  \\  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1, 1}, \ldots, A_{1, k}, \ldots\ldots, A_{m, 1}, \ldots, A_{m, k}, B_{1}, \ldots, B_{m}, C_{1, 1}, \ldots, C_{1, h}, \ldots\ldots, C_{m, 1}, \ldots, C_{m, h}, D_{1}, \ldots, D_{m}, S_{1}, \ldots, S_{m}, R_{1, 1}, \ldots, R_{1, k}, \ldots\ldots, R_{m, 1}, \ldots, R_{m, k}, Q_{1, 1}, \ldots, Q_{1, h}, \ldots\ldots, Q_{m, 1}, \ldots, Q_{m, h}\right) \mapsto \left(\begin{array}{c} \left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1}{\Big \{} S_{1}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1]   \\
#   & \gate{B_{m}{\Big \{} S_{m}}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{1}{\Big \{} S_{1}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1]   \\
#   & \gate{D_{m}{\Big \{} S_{m}}
# } \hspace{2em}\right) \land \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} R_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, k}{\Big \{} R_{1, k}} \qwx[1] & \gate{B_{1}{\Big \{} S_{1}} \qwx[1] & \gate{C_{1, 1}{\Big \{} Q_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1, h}{\Big \{} Q_{1, h}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{} R_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{C_{i, j}{\Big \{} Q_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{m, 1}{\Big \{} R_{m, 1}} & \gate{\cdots} & \gate{A_{m, k}{\Big \{} R_{m, k}} & \gate{B_{m}{\Big \{} S_{m}} & \gate{C_{m, 1}{\Big \{} Q_{m, 1}} & \gate{\cdots} & \gate{C_{m, h}{\Big \{} Q_{m, h}}
# } \hspace{2em}\right) \Rightarrow  \\ \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} R_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, k}{\Big \{} R_{1, k}} \qwx[1] & \gate{D_{1}{\Big \{} S_{1}} \qwx[1] & \gate{C_{1, 1}{\Big \{} Q_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1, h}{\Big \{} Q_{1, h}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{} R_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{C_{i, j}{\Big \{} Q_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{m, 1}{\Big \{} R_{m, 1}} & \gate{\cdots} & \gate{A_{m, k}{\Big \{} R_{m, k}} & \gate{D_{m}{\Big \{} S_{m}} & \gate{C_{m, 1}{\Big \{} Q_{m, 1}} & \gate{\cdots} & \gate{C_{m, h}{\Big \{} Q_{m, h}}
# } \hspace{2em} \end{array}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}) -> ((( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})) and  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h})) =>  \\  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}))
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h})
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7, 8, 9
# 2. (( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})) and  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h})) =>  \\  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h})
#    core type: Operation
#    operator: 10
#    operands: 11
# 3. A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 74
#    end_index: 66
# 4. B_{1}, ..B_{_a}.., B_{m}
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 74
#    end_index: 66
# 5. C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 74
#    end_index: 66
# 6. D_{1}, ..D_{_a}.., D_{m}
#    core type: ExprRange
#    lambda_map: 15
#    start_index: 74
#    end_index: 66
# 7. S_{1}, ..S_{_a}.., S_{m}
#    core type: ExprRange
#    lambda_map: 16
#    start_index: 74
#    end_index: 66
# 8. R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}
#    core type: ExprRange
#    lambda_map: 17
#    start_index: 74
#    end_index: 66
# 9. Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}
#    core type: ExprRange
#    lambda_map: 18
#    start_index: 74
#    end_index: 66
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})) and  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}),  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 12. _a -> A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}
#     core type: Lambda
#     parameter: 51
#     body: 21
# 13. _a -> B_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 22
# 14. _a -> C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}
#     core type: Lambda
#     parameter: 51
#     body: 23
# 15. _a -> D_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 24
# 16. _a -> S_{_a}
#     core type: Lambda
#     parameter: 51
#     body: 25
# 17. _a -> R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}
#     core type: Lambda
#     parameter: 51
#     body: 26
# 18. _a -> Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}
#     core type: Lambda
#     parameter: 51
#     body: 27
# 19. ( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})) and  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h})
#     core type: Operation
#     operator: 28
#     operands: 29
# 20.  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h})
#     core type: Operation
#     operator: 54
#     operand: 37
# 21. A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 74
#     end_index: 72
# 22. B_{_a}
#     core type: IndexedVar
# variable: 92
# index: 51
# 23. C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 74
#     end_index: 75
# 24. D_{_a}
#     core type: IndexedVar
# variable: 93
# index: 51
# 25. S_{_a}
#     core type: IndexedVar
# variable: 94
# index: 51
# 26. R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 74
#     end_index: 72
# 27. Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 74
#     end_index: 75
# 28. and
#     core type: Literal
#     sub-expressions:
# 29. ( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m}),  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 30. ((MultiQubitGate(A_{1, 1}, R_{1, 1}) & ..MultiQubitGate(A_{1, j}, R_{1, j}).. & MultiQubitGate(A_{1, k}, R_{1, k}) & MultiQubitGate(D_{1}, S_{1}) & MultiQubitGate(C_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(C_{1, j}, Q_{1, j}).. & MultiQubitGate(C_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, R_{i, 1}) & ..MultiQubitGate(A_{i, j}, R_{i, j}).. & MultiQubitGate(A_{i, k}, R_{i, k}) & MultiQubitGate(D_{i}, S_{i}) & MultiQubitGate(C_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(C_{i, j}, Q_{i, j}).. & MultiQubitGate(C_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, R_{m, 1}) & ..MultiQubitGate(A_{m, j}, R_{m, j}).. & MultiQubitGate(A_{m, k}, R_{m, k}) & MultiQubitGate(D_{m}, S_{m}) & MultiQubitGate(C_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(C_{m, j}, Q_{m, j}).. & MultiQubitGate(C_{m, h}, Q_{m, h})))
#     core type: ExprTuple
#     sub-expressions: 37
# 31. _b -> A_{_a, _b}
#     core type: Lambda
#     parameter: 52
#     body: 38
# 32. _b -> C_{_a, _b}
#     core type: Lambda
#     parameter: 52
#     body: 39
# 33. _b -> R_{_a, _b}
#     core type: Lambda
#     parameter: 52
#     body: 40
# 34. _b -> Q_{_a, _b}
#     core type: Lambda
#     parameter: 52
#     body: 41
# 35.  MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})
#     core type: Operation
#     operator: 42
#     operands: 43
# 36.  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h})
#     core type: Operation
#     operator: 54
#     operand: 49
# 37. MultiQubitGate(A_{1, 1}, R_{1, 1}) & ..MultiQubitGate(A_{1, j}, R_{1, j}).. & MultiQubitGate(A_{1, k}, R_{1, k}) & MultiQubitGate(D_{1}, S_{1}) & MultiQubitGate(C_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(C_{1, j}, Q_{1, j}).. & MultiQubitGate(C_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, R_{i, 1}) & ..MultiQubitGate(A_{i, j}, R_{i, j}).. & MultiQubitGate(A_{i, k}, R_{i, k}) & MultiQubitGate(D_{i}, S_{i}) & MultiQubitGate(C_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(C_{i, j}, Q_{i, j}).. & MultiQubitGate(C_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, R_{m, 1}) & ..MultiQubitGate(A_{m, j}, R_{m, j}).. & MultiQubitGate(A_{m, k}, R_{m, k}) & MultiQubitGate(D_{m}, S_{m}) & MultiQubitGate(C_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(C_{m, j}, Q_{m, j}).. & MultiQubitGate(C_{m, h}, Q_{m, h})
#     core type: ExprTuple
#     sub-expressions: 45
# 38. A_{_a, _b}
#     core type: IndexedVar
# variable: 95
# indices: 46
# 39. C_{_a, _b}
#     core type: IndexedVar
# variable: 97
# indices: 46
# 40. R_{_a, _b}
#     core type: IndexedVar
# variable: 96
# indices: 46
# 41. Q_{_a, _b}
#     core type: IndexedVar
# variable: 98
# indices: 46
# 42. equiv
#     core type: Literal
#     sub-expressions:
# 43. ( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}),  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m}))
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 44. ((MultiQubitGate(A_{1, 1}, R_{1, 1}) & ..MultiQubitGate(A_{1, j}, R_{1, j}).. & MultiQubitGate(A_{1, k}, R_{1, k}) & MultiQubitGate(B_{1}, S_{1}) & MultiQubitGate(C_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(C_{1, j}, Q_{1, j}).. & MultiQubitGate(C_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, R_{i, 1}) & ..MultiQubitGate(A_{i, j}, R_{i, j}).. & MultiQubitGate(A_{i, k}, R_{i, k}) & MultiQubitGate(B_{i}, S_{i}) & MultiQubitGate(C_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(C_{i, j}, Q_{i, j}).. & MultiQubitGate(C_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, R_{m, 1}) & ..MultiQubitGate(A_{m, j}, R_{m, j}).. & MultiQubitGate(A_{m, k}, R_{m, k}) & MultiQubitGate(B_{m}, S_{m}) & MultiQubitGate(C_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(C_{m, j}, Q_{m, j}).. & MultiQubitGate(C_{m, h}, Q_{m, h})))
#     core type: ExprTuple
#     sub-expressions: 49
# 45. (MultiQubitGate(A_{1, 1}, R_{1, 1}), ..MultiQubitGate(A_{1, j}, R_{1, j}).., MultiQubitGate(A_{1, k}, R_{1, k}), MultiQubitGate(D_{1}, S_{1}), MultiQubitGate(C_{1, 1}, Q_{1, 1}), ..MultiQubitGate(C_{1, j}, Q_{1, j}).., MultiQubitGate(C_{1, h}, Q_{1, h})), ..(MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k}), MultiQubitGate(D_{i}, S_{i}), MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h})).., (MultiQubitGate(A_{m, 1}, R_{m, 1}), ..MultiQubitGate(A_{m, j}, R_{m, j}).., MultiQubitGate(A_{m, k}, R_{m, k}), MultiQubitGate(D_{m}, S_{m}), MultiQubitGate(C_{m, 1}, Q_{m, 1}), ..MultiQubitGate(C_{m, j}, Q_{m, j}).., MultiQubitGate(C_{m, h}, Q_{m, h}))
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 74
#     end_index: 66
# 46. (_a, _b)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 47.  MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m})
#     core type: Operation
#     operator: 54
#     operand: 58
# 48.  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})
#     core type: Operation
#     operator: 54
#     operand: 59
# 49. MultiQubitGate(A_{1, 1}, R_{1, 1}) & ..MultiQubitGate(A_{1, j}, R_{1, j}).. & MultiQubitGate(A_{1, k}, R_{1, k}) & MultiQubitGate(B_{1}, S_{1}) & MultiQubitGate(C_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(C_{1, j}, Q_{1, j}).. & MultiQubitGate(C_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, R_{i, 1}) & ..MultiQubitGate(A_{i, j}, R_{i, j}).. & MultiQubitGate(A_{i, k}, R_{i, k}) & MultiQubitGate(B_{i}, S_{i}) & MultiQubitGate(C_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(C_{i, j}, Q_{i, j}).. & MultiQubitGate(C_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, R_{m, 1}) & ..MultiQubitGate(A_{m, j}, R_{m, j}).. & MultiQubitGate(A_{m, k}, R_{m, k}) & MultiQubitGate(B_{m}, S_{m}) & MultiQubitGate(C_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(C_{m, j}, Q_{m, j}).. & MultiQubitGate(C_{m, h}, Q_{m, h})
#     core type: ExprTuple
#     sub-expressions: 56
# 50. i -> (MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k}), MultiQubitGate(D_{i}, S_{i}), MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h}))
#     core type: Lambda
#     parameter: 100
#     body: 57
# 51. _a
#     core type: Variable
#     sub-expressions:
# 52. _b
#     core type: Variable
#     sub-expressions:
# 53. ((MultiQubitGate(B_{1}, S_{1})  \\
#   \colon  \\
#   MultiQubitGate(B_{i}, S_{i})  \\
#   \colon  \\
#   MultiQubitGate(B_{m}, S_{m})))
#     core type: ExprTuple
#     sub-expressions: 58
# 54. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 55. ((MultiQubitGate(D_{1}, S_{1})  \\
#   \colon  \\
#   MultiQubitGate(D_{i}, S_{i})  \\
#   \colon  \\
#   MultiQubitGate(D_{m}, S_{m})))
#     core type: ExprTuple
#     sub-expressions: 59
# 56. (MultiQubitGate(A_{1, 1}, R_{1, 1}), ..MultiQubitGate(A_{1, j}, R_{1, j}).., MultiQubitGate(A_{1, k}, R_{1, k}), MultiQubitGate(B_{1}, S_{1}), MultiQubitGate(C_{1, 1}, Q_{1, 1}), ..MultiQubitGate(C_{1, j}, Q_{1, j}).., MultiQubitGate(C_{1, h}, Q_{1, h})), ..(MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k}), MultiQubitGate(B_{i}, S_{i}), MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h})).., (MultiQubitGate(A_{m, 1}, R_{m, 1}), ..MultiQubitGate(A_{m, j}, R_{m, j}).., MultiQubitGate(A_{m, k}, R_{m, k}), MultiQubitGate(B_{m}, S_{m}), MultiQubitGate(C_{m, 1}, Q_{m, 1}), ..MultiQubitGate(C_{m, j}, Q_{m, j}).., MultiQubitGate(C_{m, h}, Q_{m, h}))
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 74
#     end_index: 66
# 57. (MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k}), MultiQubitGate(D_{i}, S_{i}), MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h}))
#     core type: ExprTuple
#     sub-expressions: 67, 77, 68
# 58. MultiQubitGate(B_{1}, S_{1})  \\
#   \colon  \\
#   MultiQubitGate(B_{i}, S_{i})  \\
#   \colon  \\
#   MultiQubitGate(B_{m}, S_{m})
#     core type: ExprTuple
#     sub-expressions: 61
# 59. MultiQubitGate(D_{1}, S_{1})  \\
#   \colon  \\
#   MultiQubitGate(D_{i}, S_{i})  \\
#   \colon  \\
#   MultiQubitGate(D_{m}, S_{m})
#     core type: ExprTuple
#     sub-expressions: 62
# 60. i -> (MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k}), MultiQubitGate(B_{i}, S_{i}), MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h}))
#     core type: Lambda
#     parameter: 100
#     body: 63
# 61. (MultiQubitGate(B_{1}, S_{1})), ..(MultiQubitGate(B_{i}, S_{i})).., (MultiQubitGate(B_{m}, S_{m}))
#     core type: ExprRange
#     lambda_map: 64
#     start_index: 74
#     end_index: 66
# 62. (MultiQubitGate(D_{1}, S_{1})), ..(MultiQubitGate(D_{i}, S_{i})).., (MultiQubitGate(D_{m}, S_{m}))
#     core type: ExprRange
#     lambda_map: 65
#     start_index: 74
#     end_index: 66
# 63. (MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k}), MultiQubitGate(B_{i}, S_{i}), MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h}))
#     core type: ExprTuple
#     sub-expressions: 67, 76, 68
# 64. i -> (MultiQubitGate(B_{i}, S_{i}))
#     core type: Lambda
#     parameter: 100
#     body: 69
# 65. i -> (MultiQubitGate(D_{i}, S_{i}))
#     core type: Lambda
#     parameter: 100
#     body: 70
# 66. m
#     core type: Variable
#     sub-expressions:
# 67. MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k})
#     core type: ExprRange
#     lambda_map: 71
#     start_index: 74
#     end_index: 72
# 68. MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h})
#     core type: ExprRange
#     lambda_map: 73
#     start_index: 74
#     end_index: 75
# 69. (MultiQubitGate(B_{i}, S_{i}))
#     core type: ExprTuple
#     sub-expressions: 76
# 70. (MultiQubitGate(D_{i}, S_{i}))
#     core type: ExprTuple
#     sub-expressions: 77
# 71. j -> MultiQubitGate(A_{i, j}, R_{i, j})
#     core type: Lambda
#     parameter: 101
#     body: 78
# 72. k
#     core type: Variable
#     sub-expressions:
# 73. j -> MultiQubitGate(C_{i, j}, Q_{i, j})
#     core type: Lambda
#     parameter: 101
#     body: 79
# 74. 1
#     core type: Literal
#     sub-expressions:
# 75. h
#     core type: Variable
#     sub-expressions:
# 76. MultiQubitGate(B_{i}, S_{i})
#     core type: Operation
#     operator: 83
#     operands: 80
# 77. MultiQubitGate(D_{i}, S_{i})
#     core type: Operation
#     operator: 83
#     operands: 81
# 78. MultiQubitGate(A_{i, j}, R_{i, j})
#     core type: Operation
#     operator: 83
#     operands: 82
# 79. MultiQubitGate(C_{i, j}, Q_{i, j})
#     core type: Operation
#     operator: 83
#     operands: 84
# 80. (B_{i}, S_{i})
#     core type: ExprTuple
#     sub-expressions: 85, 87
# 81. (D_{i}, S_{i})
#     core type: ExprTuple
#     sub-expressions: 86, 87
# 82. (A_{i, j}, R_{i, j})
#     core type: ExprTuple
#     sub-expressions: 88, 89
# 83. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 84. (C_{i, j}, Q_{i, j})
#     core type: ExprTuple
#     sub-expressions: 90, 91
# 85. B_{i}
#     core type: IndexedVar
# variable: 92
# index: 100
# 86. D_{i}
#     core type: IndexedVar
# variable: 93
# index: 100
# 87. S_{i}
#     core type: IndexedVar
# variable: 94
# index: 100
# 88. A_{i, j}
#     core type: IndexedVar
# variable: 95
# indices: 99
# 89. R_{i, j}
#     core type: IndexedVar
# variable: 96
# indices: 99
# 90. C_{i, j}
#     core type: IndexedVar
# variable: 97
# indices: 99
# 91. Q_{i, j}
#     core type: IndexedVar
# variable: 98
# indices: 99
# 92. B
#     core type: Variable
#     sub-expressions:
# 93. D
#     core type: Variable
#     sub-expressions:
# 94. S
#     core type: Variable
#     sub-expressions:
# 95. A
#     core type: Variable
#     sub-expressions:
# 96. R
#     core type: Variable
#     sub-expressions:
# 97. C
#     core type: Variable
#     sub-expressions:
# 98. Q
#     core type: Variable
#     sub-expressions:
# 99. (i, j)
#     core type: ExprTuple
#     sub-expressions: 100, 101
# 100. i
#      core type: Variable
#      sub-expressions:
# 101. j
#      core type: Variable
#      sub-expressions:
