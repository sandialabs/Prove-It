# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, D, ExprArray, ExprRange, ExprTuple, IndexedVar, i, j, k, m, n
from proveit.core_expr_types.expr_arrays import Aij, Cij, Rij, Sij
from proveit.numbers import one
from proveit.physics.quantum import Gate
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = [ExprRange(j, Gate(IndexedVar(B, j)), one, n)]
sub_expr2 = [ExprRange(j, Gate(IndexedVar(D, j)), one, n)]
sub_expr3 = ExprRange(i, [ExprRange(j, MultiQubitGate(Aij, Sij), one, n)], one, m)
sub_expr4 = ExprRange(i, [ExprRange(j, MultiQubitGate(Cij, Rij), one, n)], one, k)
expr = ExprTuple(CircuitEquiv(Circuit(ExprArray(sub_expr1)), Circuit(ExprArray(sub_expr2))), CircuitEquiv(Circuit(ExprArray(sub_expr3, sub_expr1, sub_expr4)), Circuit(ExprArray(sub_expr3, sub_expr2, sub_expr4))))
# Out:
# expr: ( Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n}) equiv  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n}),  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}) equiv  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1}} & \gate{\cdots} & \gate{B_{n}}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{1}} & \gate{\cdots} & \gate{D_{n}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} S_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, n}{\Big \{} S_{1, n}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{} S_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{m, 1}{\Big \{} S_{m, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{m, n}{\Big \{} S_{m, n}} \qwx[1]   \\
#   & \gate{B_{1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{B_{n}} \qwx[1]   \\
#   & \gate{C_{1, 1}{\Big \{} R_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1, n}{\Big \{} R_{1, n}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{C_{i, j}{\Big \{} R_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{C_{k, 1}{\Big \{} R_{k, 1}} & \gate{\cdots} & \gate{C_{k, n}{\Big \{} R_{k, n}}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} S_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, n}{\Big \{} S_{1, n}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{} S_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{m, 1}{\Big \{} S_{m, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{m, n}{\Big \{} S_{m, n}} \qwx[1]   \\
#   & \gate{D_{1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{D_{n}} \qwx[1]   \\
#   & \gate{C_{1, 1}{\Big \{} R_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1, n}{\Big \{} R_{1, n}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{C_{i, j}{\Big \{} R_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{C_{k, 1}{\Big \{} R_{k, 1}} & \gate{\cdots} & \gate{C_{k, n}{\Big \{} R_{k, n}}
# } \hspace{2em}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ( Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n}) equiv  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n}),  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}) equiv  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1.  Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n}) equiv  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})
#    core type: Operation
#    operator: 4
#    operands: 3
# 2.  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}) equiv  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ( Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n}),  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. equiv
#    core type: Literal
#    sub-expressions:
# 5. ( MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}),  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6.  Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})
#    core type: Operation
#    operator: 13
#    operand: 15
# 7.  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})
#    core type: Operation
#    operator: 13
#    operand: 16
# 8.  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n})
#    core type: Operation
#    operator: 13
#    operand: 17
# 9.  MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, S_{m, 1})  & ..MultiQubitGate(A_{m, j}, S_{m, j})..  & MultiQubitGate(A_{m, n}, S_{m, n})   \\
#    Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})   \\
#    MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, n}, R_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, n}, R_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(C_{k, 1}, R_{k, 1})  & ..MultiQubitGate(C_{k, j}, R_{k, j})..  & MultiQubitGate(C_{k, n}, R_{k, n})
#    core type: Operation
#    operator: 13
#    operand: 18
# 10. ((Gate(B_{1}) & ..Gate(B_{j}).. & Gate(B_{n})))
#     core type: ExprTuple
#     sub-expressions: 15
# 11. ((Gate(D_{1}) & ..Gate(D_{j}).. & Gate(D_{n})))
#     core type: ExprTuple
#     sub-expressions: 16
# 12. ((MultiQubitGate(A_{1, 1}, S_{1, 1}) & ..MultiQubitGate(A_{1, j}, S_{1, j}).. & MultiQubitGate(A_{1, n}, S_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, S_{i, 1}) & ..MultiQubitGate(A_{i, j}, S_{i, j}).. & MultiQubitGate(A_{i, n}, S_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, S_{m, 1}) & ..MultiQubitGate(A_{m, j}, S_{m, j}).. & MultiQubitGate(A_{m, n}, S_{m, n})  \\
#   Gate(B_{1}) & ..Gate(B_{j}).. & Gate(B_{n})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{k, 1}, R_{k, 1}) & ..MultiQubitGate(C_{k, j}, R_{k, j}).. & MultiQubitGate(C_{k, n}, R_{k, n})))
#     core type: ExprTuple
#     sub-expressions: 17
# 13. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 14. ((MultiQubitGate(A_{1, 1}, S_{1, 1}) & ..MultiQubitGate(A_{1, j}, S_{1, j}).. & MultiQubitGate(A_{1, n}, S_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, S_{i, 1}) & ..MultiQubitGate(A_{i, j}, S_{i, j}).. & MultiQubitGate(A_{i, n}, S_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, S_{m, 1}) & ..MultiQubitGate(A_{m, j}, S_{m, j}).. & MultiQubitGate(A_{m, n}, S_{m, n})  \\
#   Gate(D_{1}) & ..Gate(D_{j}).. & Gate(D_{n})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{k, 1}, R_{k, 1}) & ..MultiQubitGate(C_{k, j}, R_{k, j}).. & MultiQubitGate(C_{k, n}, R_{k, n})))
#     core type: ExprTuple
#     sub-expressions: 18
# 15. Gate(B_{1}) & ..Gate(B_{j}).. & Gate(B_{n})
#     core type: ExprTuple
#     sub-expressions: 19
# 16. Gate(D_{1}) & ..Gate(D_{j}).. & Gate(D_{n})
#     core type: ExprTuple
#     sub-expressions: 21
# 17. MultiQubitGate(A_{1, 1}, S_{1, 1}) & ..MultiQubitGate(A_{1, j}, S_{1, j}).. & MultiQubitGate(A_{1, n}, S_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, S_{i, 1}) & ..MultiQubitGate(A_{i, j}, S_{i, j}).. & MultiQubitGate(A_{i, n}, S_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, S_{m, 1}) & ..MultiQubitGate(A_{m, j}, S_{m, j}).. & MultiQubitGate(A_{m, n}, S_{m, n})  \\
#   Gate(B_{1}) & ..Gate(B_{j}).. & Gate(B_{n})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{k, 1}, R_{k, 1}) & ..MultiQubitGate(C_{k, j}, R_{k, j}).. & MultiQubitGate(C_{k, n}, R_{k, n})
#     core type: ExprTuple
#     sub-expressions: 20, 19, 22
# 18. MultiQubitGate(A_{1, 1}, S_{1, 1}) & ..MultiQubitGate(A_{1, j}, S_{1, j}).. & MultiQubitGate(A_{1, n}, S_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, S_{i, 1}) & ..MultiQubitGate(A_{i, j}, S_{i, j}).. & MultiQubitGate(A_{i, n}, S_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, S_{m, 1}) & ..MultiQubitGate(A_{m, j}, S_{m, j}).. & MultiQubitGate(A_{m, n}, S_{m, n})  \\
#   Gate(D_{1}) & ..Gate(D_{j}).. & Gate(D_{n})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{k, 1}, R_{k, 1}) & ..MultiQubitGate(C_{k, j}, R_{k, j}).. & MultiQubitGate(C_{k, n}, R_{k, n})
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22
# 19. (Gate(B_{1}), ..Gate(B_{j}).., Gate(B_{n}))
#     core type: ExprTuple
#     sub-expressions: 23
# 20. (MultiQubitGate(A_{1, 1}, S_{1, 1}), ..MultiQubitGate(A_{1, j}, S_{1, j}).., MultiQubitGate(A_{1, n}, S_{1, n})), ..(MultiQubitGate(A_{i, 1}, S_{i, 1}), ..MultiQubitGate(A_{i, j}, S_{i, j}).., MultiQubitGate(A_{i, n}, S_{i, n})).., (MultiQubitGate(A_{m, 1}, S_{m, 1}), ..MultiQubitGate(A_{m, j}, S_{m, j}).., MultiQubitGate(A_{m, n}, S_{m, n}))
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 42
#     end_index: 25
# 21. (Gate(D_{1}), ..Gate(D_{j}).., Gate(D_{n}))
#     core type: ExprTuple
#     sub-expressions: 26
# 22. (MultiQubitGate(C_{1, 1}, R_{1, 1}), ..MultiQubitGate(C_{1, j}, R_{1, j}).., MultiQubitGate(C_{1, n}, R_{1, n})), ..(MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, n}, R_{i, n})).., (MultiQubitGate(C_{k, 1}, R_{k, 1}), ..MultiQubitGate(C_{k, j}, R_{k, j}).., MultiQubitGate(C_{k, n}, R_{k, n}))
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 42
#     end_index: 28
# 23. Gate(B_{1}), ..Gate(B_{j}).., Gate(B_{n})
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 42
#     end_index: 43
# 24. i -> (MultiQubitGate(A_{i, 1}, S_{i, 1}), ..MultiQubitGate(A_{i, j}, S_{i, j}).., MultiQubitGate(A_{i, n}, S_{i, n}))
#     core type: Lambda
#     parameter: 60
#     body: 30
# 25. m
#     core type: Variable
#     sub-expressions:
# 26. Gate(D_{1}), ..Gate(D_{j}).., Gate(D_{n})
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 42
#     end_index: 43
# 27. i -> (MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, n}, R_{i, n}))
#     core type: Lambda
#     parameter: 60
#     body: 32
# 28. k
#     core type: Variable
#     sub-expressions:
# 29. j -> Gate(B_{j})
#     core type: Lambda
#     parameter: 61
#     body: 33
# 30. (MultiQubitGate(A_{i, 1}, S_{i, 1}), ..MultiQubitGate(A_{i, j}, S_{i, j}).., MultiQubitGate(A_{i, n}, S_{i, n}))
#     core type: ExprTuple
#     sub-expressions: 34
# 31. j -> Gate(D_{j})
#     core type: Lambda
#     parameter: 61
#     body: 35
# 32. (MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, n}, R_{i, n}))
#     core type: ExprTuple
#     sub-expressions: 36
# 33. Gate(B_{j})
#     core type: Operation
#     operator: 39
#     operand: 37
# 34. MultiQubitGate(A_{i, 1}, S_{i, 1}), ..MultiQubitGate(A_{i, j}, S_{i, j}).., MultiQubitGate(A_{i, n}, S_{i, n})
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 42
#     end_index: 43
# 35. Gate(D_{j})
#     core type: Operation
#     operator: 39
#     operand: 40
# 36. MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, n}, R_{i, n})
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 42
#     end_index: 43
# 37. B_{j}
#     core type: IndexedVar
# variable: 44
# index: 61
# 38. j -> MultiQubitGate(A_{i, j}, S_{i, j})
#     core type: Lambda
#     parameter: 61
#     body: 45
# 39. GATE
#     core type: Literal
#     sub-expressions:
# 40. D_{j}
#     core type: IndexedVar
# variable: 46
# index: 61
# 41. j -> MultiQubitGate(C_{i, j}, R_{i, j})
#     core type: Lambda
#     parameter: 61
#     body: 47
# 42. 1
#     core type: Literal
#     sub-expressions:
# 43. n
#     core type: Variable
#     sub-expressions:
# 44. B
#     core type: Variable
#     sub-expressions:
# 45. MultiQubitGate(A_{i, j}, S_{i, j})
#     core type: Operation
#     operator: 49
#     operands: 48
# 46. D
#     core type: Variable
#     sub-expressions:
# 47. MultiQubitGate(C_{i, j}, R_{i, j})
#     core type: Operation
#     operator: 49
#     operands: 50
# 48. (A_{i, j}, S_{i, j})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 50. (C_{i, j}, R_{i, j})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. A_{i, j}
#     core type: IndexedVar
# variable: 55
# indices: 59
# 52. S_{i, j}
#     core type: IndexedVar
# variable: 56
# indices: 59
# 53. C_{i, j}
#     core type: IndexedVar
# variable: 57
# indices: 59
# 54. R_{i, j}
#     core type: IndexedVar
# variable: 58
# indices: 59
# 55. A
#     core type: Variable
#     sub-expressions:
# 56. S
#     core type: Variable
#     sub-expressions:
# 57. C
#     core type: Variable
#     sub-expressions:
# 58. R
#     core type: Variable
#     sub-expressions:
# 59. (i, j)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 60. i
#     core type: Variable
#     sub-expressions:
# 61. j
#     core type: Variable
#     sub-expressions:
