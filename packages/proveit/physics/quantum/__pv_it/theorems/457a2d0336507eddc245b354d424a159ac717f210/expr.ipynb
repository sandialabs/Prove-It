# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import alpha, n, x
from proveit.linalg import ScalarProd, TensorExp
from proveit.logic import InSet
from proveit.physics.quantum import QubitSpace

# %%
# build up the expression from sub-expressions
expr = InSet(ScalarProd(alpha, x), TensorExp([QubitSpace], n))
# Out:
# expr: (alpha * x) in (Complex^{2})^{otimes n}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\alpha \thinspace x\right) \in \left(\mathbb{C}^{2}\right)^{\otimes n}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (alpha * x) in (Complex^{2})^{otimes n}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (alpha * x, (Complex^{2})^{otimes n})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. alpha * x
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (Complex^{2})^{otimes n}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (alpha, x)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. otimes
#    core type: Literal
#    sub-expressions:
# 8. ((Complex^{2}), n)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. alpha
#    core type: Variable
#    sub-expressions:
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 13
# 12. n
#     core type: Variable
#     sub-expressions:
# 13. Complex^{2}
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. Exp
#     core type: Literal
#     sub-expressions:
# 15. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. Complex
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
