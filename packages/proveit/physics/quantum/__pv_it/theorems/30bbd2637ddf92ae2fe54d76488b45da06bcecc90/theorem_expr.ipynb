# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#single_space_equiv">single_space_equiv</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum import single_space_equiv

# %%
# check that the built expression is the same as the stored expression
assert single_space_equiv.expr == stored_expr
assert single_space_equiv.expr._style_id == stored_expr._style_id
print("Passed sanity check: single_space_equiv matches stored_expr")
# Out:
# Passed sanity check: single_space_equiv matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(single_space_equiv.latex())
# Out:
# \vdash \forall_{k, m, n \in \mathbb{N}^+}~\left[\forall_{ \scriptsize \begin{array}{c}
# A_{1, 1}, \ldots, A_{1, n}, \ldots\ldots, A_{m, 1}, \ldots, A_{m, n}, B_{1}, \ldots, B_{n}, \\
# C_{1, 1}, \ldots, C_{1, n}, \ldots\ldots, C_{k, 1}, \ldots, C_{k, n}, D_{1}, \ldots, D_{n}, \\
# S_{1, 1}, \ldots, S_{1, n}, \ldots\ldots, S_{m, 1}, \ldots, S_{m, n}, Q_{1}, \ldots, Q_{n}, \\
# R_{1, 1}, \ldots, R_{1, n}, \ldots\ldots, R_{k, 1}, \ldots, R_{k, n}\end{array}
# }~  \\
# \left(\begin{array}{c} \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1}} & \gate{\cdots} & \gate{B_{n}}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{1}} & \gate{\cdots} & \gate{D_{n}}
# } \hspace{2em}\right) \Rightarrow  \\ \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} S_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, n}{\Big \{} S_{1, n}} \qwx[1]   \\
# ...

# %%
# display the expression information
single_space_equiv.expr_info()
# Out:
# 0. forall_{k, m, n in NaturalPos} [forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, n}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, n}...., A_{m, 1}, ..A_{m, _b}.., A_{m, n}, B_{1}, ..B_{_a}.., B_{n}, C_{1, 1}, ..C_{1, _b}.., C_{1, n}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, n}...., C_{k, 1}, ..C_{k, _b}.., C_{k, n}, D_{1}, ..D_{_a}.., D_{n}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}, Q_{1}, ..Q_{_a}.., Q_{n}, R_{1, 1}, ..R_{1, _b}.., R_{1, n}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, n}...., R_{k, 1}, ..R_{k, _b}.., R_{k, n}} (( Gate(B_{1})  & ..Gate(B_{j})..  & Gate(B_{n}) equiv  Gate(D_{1})  & ..Gate(D_{j})..  & Gate(D_{n})) =>  \\ ( MultiQubitGate(A_{1, 1}, S_{1, 1})  & ..MultiQubitGate(A_{1, j}, S_{1, j})..  & MultiQubitGate(A_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, S_{i, 1})  & ..MultiQubitGate(A_{i, j}, S_{i, j})..  & MultiQubitGate(A_{i, n}, S_{i, n})   \\
# ...
