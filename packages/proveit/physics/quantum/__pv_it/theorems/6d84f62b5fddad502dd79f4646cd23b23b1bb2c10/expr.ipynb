# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, ExprArray, ExprRange, IndexedVar, P, Q, R, Variable, g, h, i, j, k, m, n
from proveit.core_expr_types.expr_arrays import Aij, Bij, Cij, D11_to_Dmn, Dij, Pij, Qij, Rij, S11_to_Smn, Sij
from proveit.logic import And, Forall, Implies
from proveit.numbers import NaturalPos, one
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr3 = [sub_expr1, sub_expr2]
sub_expr4 = ExprRange(j, MultiQubitGate(Bij, Qij), one, h)
sub_expr5 = ExprRange(j, MultiQubitGate(Dij, Sij), one, n)
sub_expr6 = ExprRange(j, MultiQubitGate(Aij, Pij), one, g)
sub_expr7 = ExprRange(j, MultiQubitGate(Cij, Rij), one, k)
expr = Forall([g, h, k, m, n], Forall([ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(A, sub_expr3), one, g), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(B, sub_expr3), one, h), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(C, sub_expr3), one, k), one, m), D11_to_Dmn, ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(P, sub_expr3), one, g), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(Q, sub_expr3), one, h), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(R, sub_expr3), one, k), one, m), S11_to_Smn], Implies(And(CircuitEquiv(Circuit(ExprArray(ExprRange(i, [sub_expr4], one, m))), Circuit(ExprArray(ExprRange(i, [sub_expr5], one, m)))), Circuit(ExprArray(ExprRange(i, [sub_expr6, sub_expr4, sub_expr7], one, m)))), Circuit(ExprArray(ExprRange(i, [sub_expr6, sub_expr5, sub_expr7], one, m)))).with_wrapping_at(2)).wrap_params(), domains = [NaturalPos, NaturalPos, NaturalPos, NaturalPos, NaturalPos])
# Out:
# expr: forall_{g, h, k, m, n in NaturalPos} [forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}} ((( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})) =>  \\  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k}))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{g, h, k, m, n \in \mathbb{N}^+}~\left[\forall_{ \scriptsize \begin{array}{c}
# A_{1, 1}, \ldots, A_{1, g}, \ldots\ldots, A_{m, 1}, \ldots, A_{m, g}, B_{1, 1}, \ldots, B_{1, h}, \ldots\ldots, B_{m, 1}, \ldots, B_{m, h}, \\
# C_{1, 1}, \ldots, C_{1, k}, \ldots\ldots, C_{m, 1}, \ldots, C_{m, k}, D_{1, 1}, \ldots, D_{1, n}, \ldots\ldots, D_{m, 1}, \ldots, D_{m, n}, \\
# P_{1, 1}, \ldots, P_{1, g}, \ldots\ldots, P_{m, 1}, \ldots, P_{m, g}, Q_{1, 1}, \ldots, Q_{1, h}, \ldots\ldots, Q_{m, 1}, \ldots, Q_{m, h}, \\
# R_{1, 1}, \ldots, R_{1, k}, \ldots\ldots, R_{m, 1}, \ldots, R_{m, k}, S_{1, 1}, \ldots, S_{1, n}, \ldots\ldots, S_{m, 1}, \ldots, S_{m, n}\end{array}
# }~  \\
# \left(\begin{array}{c} \left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1, 1}{\Big \{} Q_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{B_{1, h}{\Big \{} Q_{1, h}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{B_{i, j}{\Big \{} Q_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{B_{m, 1}{\Big \{} Q_{m, 1}} & \gate{\cdots} & \gate{B_{m, h}{\Big \{} Q_{m, h}}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{1, 1}{\Big \{} S_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{D_{1, n}{\Big \{} S_{1, n}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{D_{i, j}{\Big \{} S_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{D_{m, 1}{\Big \{} S_{m, 1}} & \gate{\cdots} & \gate{D_{m, n}{\Big \{} S_{m, n}}
# } \hspace{2em}\right) \land \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} P_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, g}{\Big \{} P_{1, g}} \qwx[1] & \gate{B_{1, 1}{\Big \{} Q_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{B_{1, h}{\Big \{} Q_{1, h}} \qwx[1] & \gate{C_{1, 1}{\Big \{} R_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1, k}{\Big \{} R_{1, k}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{} P_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{B_{i, j}{\Big \{} Q_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{C_{i, j}{\Big \{} R_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{m, 1}{\Big \{} P_{m, 1}} & \gate{\cdots} & \gate{A_{m, g}{\Big \{} P_{m, g}} & \gate{B_{m, 1}{\Big \{} Q_{m, 1}} & \gate{\cdots} & \gate{B_{m, h}{\Big \{} Q_{m, h}} & \gate{C_{m, 1}{\Big \{} R_{m, 1}} & \gate{\cdots} & \gate{C_{m, k}{\Big \{} R_{m, k}}
# } \hspace{2em}\right) \Rightarrow  \\ \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} P_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, g}{\Big \{} P_{1, g}} \qwx[1] & \gate{D_{1, 1}{\Big \{} S_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{D_{1, n}{\Big \{} S_{1, n}} \qwx[1] & \gate{C_{1, 1}{\Big \{} R_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1, k}{\Big \{} R_{1, k}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{} P_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{D_{i, j}{\Big \{} S_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{C_{i, j}{\Big \{} R_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{m, 1}{\Big \{} P_{m, 1}} & \gate{\cdots} & \gate{A_{m, g}{\Big \{} P_{m, g}} & \gate{D_{m, 1}{\Big \{} S_{m, 1}} & \gate{\cdots} & \gate{D_{m, n}{\Big \{} S_{m, n}} & \gate{C_{m, 1}{\Big \{} R_{m, 1}} & \gate{\cdots} & \gate{C_{m, k}{\Big \{} R_{m, k}}
# } \hspace{2em} \end{array}\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{g, h, k, m, n in NaturalPos} [forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}} ((( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})) =>  \\  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k}))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (g, h, k, m, n) -> {forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}} ((( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})) =>  \\  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})) if g in NaturalPos ,  h in NaturalPos ,  k in NaturalPos ,  m in NaturalPos ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (g, h, k, m, n)
#    core type: ExprTuple
#    sub-expressions: 103, 111, 105, 97, 114
# 3. {forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}} ((( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})) =>  \\  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})) if g in NaturalPos ,  h in NaturalPos ,  k in NaturalPos ,  m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}} ((( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})) =>  \\  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k}))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (g in NaturalPos) and (h in NaturalPos) and (k in NaturalPos) and (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 51
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}) -> ((( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})) =>  \\  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k}))
#    core type: Lambda
#    parameters: 9\n   body: 10
# 8. (g in NaturalPos, h in NaturalPos, k in NaturalPos, m in NaturalPos, n in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14, 15
# 9. (A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n})
#    core type: ExprTuple
#    sub-expressions: 16, 17, 18, 19, 20, 21, 22, 23
# 10. (( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})) =>  \\  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})
#     core type: Operation
#     operator: 24
#     operands: 25
# 11. g in NaturalPos
#     core type: Operation
#     operator: 30
#     operands: 26
# 12. h in NaturalPos
#     core type: Operation
#     operator: 30
#     operands: 27
# 13. k in NaturalPos
#     core type: Operation
#     operator: 30
#     operands: 28
# 14. m in NaturalPos
#     core type: Operation
#     operator: 30
#     operands: 29
# 15. n in NaturalPos
#     core type: Operation
#     operator: 30
#     operands: 31
# 16. A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 113
#     end_index: 97
# 17. B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 113
#     end_index: 97
# 18. C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 113
#     end_index: 97
# 19. D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 113
#     end_index: 97
# 20. P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 113
#     end_index: 97
# 21. Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 113
#     end_index: 97
# 22. R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 113
#     end_index: 97
# 23. S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 113
#     end_index: 97
# 24. =>
#     core type: Literal
#     sub-expressions:
# 25. (( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k}),  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k}))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 26. (g, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 103, 42
# 27. (h, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 111, 42
# 28. (k, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 105, 42
# 29. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 97, 42
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 114, 42
# 32. _a -> A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}
#     core type: Lambda
#     parameter: 82
#     body: 43
# 33. _a -> B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}
#     core type: Lambda
#     parameter: 82
#     body: 44
# 34. _a -> C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}
#     core type: Lambda
#     parameter: 82
#     body: 45
# 35. _a -> D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}
#     core type: Lambda
#     parameter: 82
#     body: 46
# 36. _a -> P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}
#     core type: Lambda
#     parameter: 82
#     body: 47
# 37. _a -> Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}
#     core type: Lambda
#     parameter: 82
#     body: 48
# 38. _a -> R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}
#     core type: Lambda
#     parameter: 82
#     body: 49
# 39. _a -> S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}
#     core type: Lambda
#     parameter: 82
#     body: 50
# 40. ( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})
#     core type: Operation
#     operator: 51
#     operands: 52
# 41.  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})
#     core type: Operation
#     operator: 85
#     operand: 64
# 42. NaturalPos
#     core type: Literal
#     sub-expressions:
# 43. A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 113
#     end_index: 103
# 44. B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}
#     core type: ExprRange
#     lambda_map: 55
#     start_index: 113
#     end_index: 111
# 45. C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 113
#     end_index: 105
# 46. D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 113
#     end_index: 114
# 47. P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 113
#     end_index: 103
# 48. Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 113
#     end_index: 111
# 49. R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 113
#     end_index: 105
# 50. S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 113
#     end_index: 114
# 51. and
#     core type: Literal
#     sub-expressions:
# 52. ( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n}),  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k}))
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 53. ((MultiQubitGate(A_{1, 1}, P_{1, 1}) & ..MultiQubitGate(A_{1, j}, P_{1, j}).. & MultiQubitGate(A_{1, g}, P_{1, g}) & MultiQubitGate(D_{1, 1}, S_{1, 1}) & ..MultiQubitGate(D_{1, j}, S_{1, j}).. & MultiQubitGate(D_{1, n}, S_{1, n}) & MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, k}, R_{1, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, P_{i, 1}) & ..MultiQubitGate(A_{i, j}, P_{i, j}).. & MultiQubitGate(A_{i, g}, P_{i, g}) & MultiQubitGate(D_{i, 1}, S_{i, 1}) & ..MultiQubitGate(D_{i, j}, S_{i, j}).. & MultiQubitGate(D_{i, n}, S_{i, n}) & MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, k}, R_{i, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, P_{m, 1}) & ..MultiQubitGate(A_{m, j}, P_{m, j}).. & MultiQubitGate(A_{m, g}, P_{m, g}) & MultiQubitGate(D_{m, 1}, S_{m, 1}) & ..MultiQubitGate(D_{m, j}, S_{m, j}).. & MultiQubitGate(D_{m, n}, S_{m, n}) & MultiQubitGate(C_{m, 1}, R_{m, 1}) & ..MultiQubitGate(C_{m, j}, R_{m, j}).. & MultiQubitGate(C_{m, k}, R_{m, k})))
#     core type: ExprTuple
#     sub-expressions: 64
# 54. _b -> A_{_a, _b}
#     core type: Lambda
#     parameter: 83
#     body: 65
# 55. _b -> B_{_a, _b}
#     core type: Lambda
#     parameter: 83
#     body: 66
# 56. _b -> C_{_a, _b}
#     core type: Lambda
#     parameter: 83
#     body: 67
# 57. _b -> D_{_a, _b}
#     core type: Lambda
#     parameter: 83
#     body: 68
# 58. _b -> P_{_a, _b}
#     core type: Lambda
#     parameter: 83
#     body: 69
# 59. _b -> Q_{_a, _b}
#     core type: Lambda
#     parameter: 83
#     body: 70
# 60. _b -> R_{_a, _b}
#     core type: Lambda
#     parameter: 83
#     body: 71
# 61. _b -> S_{_a, _b}
#     core type: Lambda
#     parameter: 83
#     body: 72
# 62.  MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})
#     core type: Operation
#     operator: 73
#     operands: 74
# 63.  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})
#     core type: Operation
#     operator: 85
#     operand: 80
# 64. MultiQubitGate(A_{1, 1}, P_{1, 1}) & ..MultiQubitGate(A_{1, j}, P_{1, j}).. & MultiQubitGate(A_{1, g}, P_{1, g}) & MultiQubitGate(D_{1, 1}, S_{1, 1}) & ..MultiQubitGate(D_{1, j}, S_{1, j}).. & MultiQubitGate(D_{1, n}, S_{1, n}) & MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, k}, R_{1, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, P_{i, 1}) & ..MultiQubitGate(A_{i, j}, P_{i, j}).. & MultiQubitGate(A_{i, g}, P_{i, g}) & MultiQubitGate(D_{i, 1}, S_{i, 1}) & ..MultiQubitGate(D_{i, j}, S_{i, j}).. & MultiQubitGate(D_{i, n}, S_{i, n}) & MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, k}, R_{i, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, P_{m, 1}) & ..MultiQubitGate(A_{m, j}, P_{m, j}).. & MultiQubitGate(A_{m, g}, P_{m, g}) & MultiQubitGate(D_{m, 1}, S_{m, 1}) & ..MultiQubitGate(D_{m, j}, S_{m, j}).. & MultiQubitGate(D_{m, n}, S_{m, n}) & MultiQubitGate(C_{m, 1}, R_{m, 1}) & ..MultiQubitGate(C_{m, j}, R_{m, j}).. & MultiQubitGate(C_{m, k}, R_{m, k})
#     core type: ExprTuple
#     sub-expressions: 76
# 65. A_{_a, _b}
#     core type: IndexedVar
# variable: 126
# indices: 77
# 66. B_{_a, _b}
#     core type: IndexedVar
# variable: 134
# indices: 77
# 67. C_{_a, _b}
#     core type: IndexedVar
# variable: 128
# indices: 77
# 68. D_{_a, _b}
#     core type: IndexedVar
# variable: 136
# indices: 77
# 69. P_{_a, _b}
#     core type: IndexedVar
# variable: 127
# indices: 77
# 70. Q_{_a, _b}
#     core type: IndexedVar
# variable: 135
# indices: 77
# 71. R_{_a, _b}
#     core type: IndexedVar
# variable: 129
# indices: 77
# 72. S_{_a, _b}
#     core type: IndexedVar
# variable: 137
# indices: 77
# 73. equiv
#     core type: Literal
#     sub-expressions:
# 74. ( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}),  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n}))
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 75. ((MultiQubitGate(A_{1, 1}, P_{1, 1}) & ..MultiQubitGate(A_{1, j}, P_{1, j}).. & MultiQubitGate(A_{1, g}, P_{1, g}) & MultiQubitGate(B_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(B_{1, j}, Q_{1, j}).. & MultiQubitGate(B_{1, h}, Q_{1, h}) & MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, k}, R_{1, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, P_{i, 1}) & ..MultiQubitGate(A_{i, j}, P_{i, j}).. & MultiQubitGate(A_{i, g}, P_{i, g}) & MultiQubitGate(B_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(B_{i, j}, Q_{i, j}).. & MultiQubitGate(B_{i, h}, Q_{i, h}) & MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, k}, R_{i, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, P_{m, 1}) & ..MultiQubitGate(A_{m, j}, P_{m, j}).. & MultiQubitGate(A_{m, g}, P_{m, g}) & MultiQubitGate(B_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(B_{m, j}, Q_{m, j}).. & MultiQubitGate(B_{m, h}, Q_{m, h}) & MultiQubitGate(C_{m, 1}, R_{m, 1}) & ..MultiQubitGate(C_{m, j}, R_{m, j}).. & MultiQubitGate(C_{m, k}, R_{m, k})))
#     core type: ExprTuple
#     sub-expressions: 80
# 76. (MultiQubitGate(A_{1, 1}, P_{1, 1}), ..MultiQubitGate(A_{1, j}, P_{1, j}).., MultiQubitGate(A_{1, g}, P_{1, g}), MultiQubitGate(D_{1, 1}, S_{1, 1}), ..MultiQubitGate(D_{1, j}, S_{1, j}).., MultiQubitGate(D_{1, n}, S_{1, n}), MultiQubitGate(C_{1, 1}, R_{1, 1}), ..MultiQubitGate(C_{1, j}, R_{1, j}).., MultiQubitGate(C_{1, k}, R_{1, k})), ..(MultiQubitGate(A_{i, 1}, P_{i, 1}), ..MultiQubitGate(A_{i, j}, P_{i, j}).., MultiQubitGate(A_{i, g}, P_{i, g}), MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n}), MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, k}, R_{i, k})).., (MultiQubitGate(A_{m, 1}, P_{m, 1}), ..MultiQubitGate(A_{m, j}, P_{m, j}).., MultiQubitGate(A_{m, g}, P_{m, g}), MultiQubitGate(D_{m, 1}, S_{m, 1}), ..MultiQubitGate(D_{m, j}, S_{m, j}).., MultiQubitGate(D_{m, n}, S_{m, n}), MultiQubitGate(C_{m, 1}, R_{m, 1}), ..MultiQubitGate(C_{m, j}, R_{m, j}).., MultiQubitGate(C_{m, k}, R_{m, k}))
#     core type: ExprRange
#     lambda_map: 81
#     start_index: 113
#     end_index: 97
# 77. (_a, _b)
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 78.  MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})
#     core type: Operation
#     operator: 85
#     operand: 89
# 79.  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})
#     core type: Operation
#     operator: 85
#     operand: 90
# 80. MultiQubitGate(A_{1, 1}, P_{1, 1}) & ..MultiQubitGate(A_{1, j}, P_{1, j}).. & MultiQubitGate(A_{1, g}, P_{1, g}) & MultiQubitGate(B_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(B_{1, j}, Q_{1, j}).. & MultiQubitGate(B_{1, h}, Q_{1, h}) & MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, k}, R_{1, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, P_{i, 1}) & ..MultiQubitGate(A_{i, j}, P_{i, j}).. & MultiQubitGate(A_{i, g}, P_{i, g}) & MultiQubitGate(B_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(B_{i, j}, Q_{i, j}).. & MultiQubitGate(B_{i, h}, Q_{i, h}) & MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, k}, R_{i, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, P_{m, 1}) & ..MultiQubitGate(A_{m, j}, P_{m, j}).. & MultiQubitGate(A_{m, g}, P_{m, g}) & MultiQubitGate(B_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(B_{m, j}, Q_{m, j}).. & MultiQubitGate(B_{m, h}, Q_{m, h}) & MultiQubitGate(C_{m, 1}, R_{m, 1}) & ..MultiQubitGate(C_{m, j}, R_{m, j}).. & MultiQubitGate(C_{m, k}, R_{m, k})
#     core type: ExprTuple
#     sub-expressions: 87
# 81. i -> (MultiQubitGate(A_{i, 1}, P_{i, 1}), ..MultiQubitGate(A_{i, j}, P_{i, j}).., MultiQubitGate(A_{i, g}, P_{i, g}), MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n}), MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, k}, R_{i, k}))
#     core type: Lambda
#     parameter: 139
#     body: 88
# 82. _a
#     core type: Variable
#     sub-expressions:
# 83. _b
#     core type: Variable
#     sub-expressions:
# 84. ((MultiQubitGate(B_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(B_{1, j}, Q_{1, j}).. & MultiQubitGate(B_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(B_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(B_{i, j}, Q_{i, j}).. & MultiQubitGate(B_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(B_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(B_{m, j}, Q_{m, j}).. & MultiQubitGate(B_{m, h}, Q_{m, h})))
#     core type: ExprTuple
#     sub-expressions: 89
# 85. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 86. ((MultiQubitGate(D_{1, 1}, S_{1, 1}) & ..MultiQubitGate(D_{1, j}, S_{1, j}).. & MultiQubitGate(D_{1, n}, S_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(D_{i, 1}, S_{i, 1}) & ..MultiQubitGate(D_{i, j}, S_{i, j}).. & MultiQubitGate(D_{i, n}, S_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(D_{m, 1}, S_{m, 1}) & ..MultiQubitGate(D_{m, j}, S_{m, j}).. & MultiQubitGate(D_{m, n}, S_{m, n})))
#     core type: ExprTuple
#     sub-expressions: 90
# 87. (MultiQubitGate(A_{1, 1}, P_{1, 1}), ..MultiQubitGate(A_{1, j}, P_{1, j}).., MultiQubitGate(A_{1, g}, P_{1, g}), MultiQubitGate(B_{1, 1}, Q_{1, 1}), ..MultiQubitGate(B_{1, j}, Q_{1, j}).., MultiQubitGate(B_{1, h}, Q_{1, h}), MultiQubitGate(C_{1, 1}, R_{1, 1}), ..MultiQubitGate(C_{1, j}, R_{1, j}).., MultiQubitGate(C_{1, k}, R_{1, k})), ..(MultiQubitGate(A_{i, 1}, P_{i, 1}), ..MultiQubitGate(A_{i, j}, P_{i, j}).., MultiQubitGate(A_{i, g}, P_{i, g}), MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h}), MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, k}, R_{i, k})).., (MultiQubitGate(A_{m, 1}, P_{m, 1}), ..MultiQubitGate(A_{m, j}, P_{m, j}).., MultiQubitGate(A_{m, g}, P_{m, g}), MultiQubitGate(B_{m, 1}, Q_{m, 1}), ..MultiQubitGate(B_{m, j}, Q_{m, j}).., MultiQubitGate(B_{m, h}, Q_{m, h}), MultiQubitGate(C_{m, 1}, R_{m, 1}), ..MultiQubitGate(C_{m, j}, R_{m, j}).., MultiQubitGate(C_{m, k}, R_{m, k}))
#     core type: ExprRange
#     lambda_map: 91
#     start_index: 113
#     end_index: 97
# 88. (MultiQubitGate(A_{i, 1}, P_{i, 1}), ..MultiQubitGate(A_{i, j}, P_{i, j}).., MultiQubitGate(A_{i, g}, P_{i, g}), MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n}), MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, k}, R_{i, k}))
#     core type: ExprTuple
#     sub-expressions: 98, 107, 99
# 89. MultiQubitGate(B_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(B_{1, j}, Q_{1, j}).. & MultiQubitGate(B_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(B_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(B_{i, j}, Q_{i, j}).. & MultiQubitGate(B_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(B_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(B_{m, j}, Q_{m, j}).. & MultiQubitGate(B_{m, h}, Q_{m, h})
#     core type: ExprTuple
#     sub-expressions: 92
# 90. MultiQubitGate(D_{1, 1}, S_{1, 1}) & ..MultiQubitGate(D_{1, j}, S_{1, j}).. & MultiQubitGate(D_{1, n}, S_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(D_{i, 1}, S_{i, 1}) & ..MultiQubitGate(D_{i, j}, S_{i, j}).. & MultiQubitGate(D_{i, n}, S_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(D_{m, 1}, S_{m, 1}) & ..MultiQubitGate(D_{m, j}, S_{m, j}).. & MultiQubitGate(D_{m, n}, S_{m, n})
#     core type: ExprTuple
#     sub-expressions: 93
# 91. i -> (MultiQubitGate(A_{i, 1}, P_{i, 1}), ..MultiQubitGate(A_{i, j}, P_{i, j}).., MultiQubitGate(A_{i, g}, P_{i, g}), MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h}), MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, k}, R_{i, k}))
#     core type: Lambda
#     parameter: 139
#     body: 94
# 92. (MultiQubitGate(B_{1, 1}, Q_{1, 1}), ..MultiQubitGate(B_{1, j}, Q_{1, j}).., MultiQubitGate(B_{1, h}, Q_{1, h})), ..(MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h})).., (MultiQubitGate(B_{m, 1}, Q_{m, 1}), ..MultiQubitGate(B_{m, j}, Q_{m, j}).., MultiQubitGate(B_{m, h}, Q_{m, h}))
#     core type: ExprRange
#     lambda_map: 95
#     start_index: 113
#     end_index: 97
# 93. (MultiQubitGate(D_{1, 1}, S_{1, 1}), ..MultiQubitGate(D_{1, j}, S_{1, j}).., MultiQubitGate(D_{1, n}, S_{1, n})), ..(MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n})).., (MultiQubitGate(D_{m, 1}, S_{m, 1}), ..MultiQubitGate(D_{m, j}, S_{m, j}).., MultiQubitGate(D_{m, n}, S_{m, n}))
#     core type: ExprRange
#     lambda_map: 96
#     start_index: 113
#     end_index: 97
# 94. (MultiQubitGate(A_{i, 1}, P_{i, 1}), ..MultiQubitGate(A_{i, j}, P_{i, j}).., MultiQubitGate(A_{i, g}, P_{i, g}), MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h}), MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, k}, R_{i, k}))
#     core type: ExprTuple
#     sub-expressions: 98, 106, 99
# 95. i -> (MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h}))
#     core type: Lambda
#     parameter: 139
#     body: 100
# 96. i -> (MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n}))
#     core type: Lambda
#     parameter: 139
#     body: 101
# 97. m
#     core type: Variable
#     sub-expressions:
# 98. MultiQubitGate(A_{i, 1}, P_{i, 1}), ..MultiQubitGate(A_{i, j}, P_{i, j}).., MultiQubitGate(A_{i, g}, P_{i, g})
#     core type: ExprRange
#     lambda_map: 102
#     start_index: 113
#     end_index: 103
# 99. MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, k}, R_{i, k})
#     core type: ExprRange
#     lambda_map: 104
#     start_index: 113
#     end_index: 105
# 100. (MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h}))
#      core type: ExprTuple
#      sub-expressions: 106
# 101. (MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n}))
#      core type: ExprTuple
#      sub-expressions: 107
# 102. j -> MultiQubitGate(A_{i, j}, P_{i, j})
#      core type: Lambda
#      parameter: 140
#      body: 108
# 103. g
#      core type: Variable
#      sub-expressions:
# 104. j -> MultiQubitGate(C_{i, j}, R_{i, j})
#      core type: Lambda
#      parameter: 140
#      body: 109
# 105. k
#      core type: Variable
#      sub-expressions:
# 106. MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h})
#      core type: ExprRange
#      lambda_map: 110
#      start_index: 113
#      end_index: 111
# 107. MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n})
#      core type: ExprRange
#      lambda_map: 112
#      start_index: 113
#      end_index: 114
# 108. MultiQubitGate(A_{i, j}, P_{i, j})
#      core type: Operation
#      operator: 124
#      operands: 115
# 109. MultiQubitGate(C_{i, j}, R_{i, j})
#      core type: Operation
#      operator: 124
#      operands: 116
# 110. j -> MultiQubitGate(B_{i, j}, Q_{i, j})
#      core type: Lambda
#      parameter: 140
#      body: 117
# 111. h
#      core type: Variable
#      sub-expressions:
# 112. j -> MultiQubitGate(D_{i, j}, S_{i, j})
#      core type: Lambda
#      parameter: 140
#      body: 118
# 113. 1
#      core type: Literal
#      sub-expressions:
# 114. n
#      core type: Variable
#      sub-expressions:
# 115. (A_{i, j}, P_{i, j})
#      core type: ExprTuple
#      sub-expressions: 119, 120
# 116. (C_{i, j}, R_{i, j})
#      core type: ExprTuple
#      sub-expressions: 121, 122
# 117. MultiQubitGate(B_{i, j}, Q_{i, j})
#      core type: Operation
#      operator: 124
#      operands: 123
# 118. MultiQubitGate(D_{i, j}, S_{i, j})
#      core type: Operation
#      operator: 124
#      operands: 125
# 119. A_{i, j}
#      core type: IndexedVar
# variable: 126
# indices: 138
# 120. P_{i, j}
#      core type: IndexedVar
# variable: 127
# indices: 138
# 121. C_{i, j}
#      core type: IndexedVar
# variable: 128
# indices: 138
# 122. R_{i, j}
#      core type: IndexedVar
# variable: 129
# indices: 138
# 123. (B_{i, j}, Q_{i, j})
#      core type: ExprTuple
#      sub-expressions: 130, 131
# 124. MULTI_QUBIT_GATE
#      core type: Literal
#      sub-expressions:
# 125. (D_{i, j}, S_{i, j})
#      core type: ExprTuple
#      sub-expressions: 132, 133
# 126. A
#      core type: Variable
#      sub-expressions:
# 127. P
#      core type: Variable
#      sub-expressions:
# 128. C
#      core type: Variable
#      sub-expressions:
# 129. R
#      core type: Variable
#      sub-expressions:
# 130. B_{i, j}
#      core type: IndexedVar
# variable: 134
# indices: 138
# 131. Q_{i, j}
#      core type: IndexedVar
# variable: 135
# indices: 138
# 132. D_{i, j}
#      core type: IndexedVar
# variable: 136
# indices: 138
# 133. S_{i, j}
#      core type: IndexedVar
# variable: 137
# indices: 138
# 134. B
#      core type: Variable
#      sub-expressions:
# 135. Q
#      core type: Variable
#      sub-expressions:
# 136. D
#      core type: Variable
#      sub-expressions:
# 137. S
#      core type: Variable
#      sub-expressions:
# 138. (i, j)
#      core type: ExprTuple
#      sub-expressions: 139, 140
# 139. i
#      core type: Variable
#      sub-expressions:
# 140. j
#      core type: Variable
#      sub-expressions:
