# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, U
from proveit.logic import Equals, InSet, Set
from proveit.numbers import NaturalPos
from proveit.physics.quantum import Gate
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(MultiQubitGate(U, Set(A)), Gate(U)), InSet(A, NaturalPos))
# Out:
# expr: {MultiQubitGate(U, {A}) = Gate(U) if A in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{U{\Big \{} \left\{A\right\}}
# } \hspace{2em} = \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{U}
# } \hspace{2em} \textrm{ if } A \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {MultiQubitGate(U, {A}) = Gate(U) if A in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. MultiQubitGate(U, {A}) = Gate(U)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. A in NaturalPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (MultiQubitGate(U, {A}), Gate(U))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (A, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 16, 9
# 7. MultiQubitGate(U, {A})
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. Gate(U)
#    core type: Operation
#    operator: 12
#    operand: 13
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 11. (U, {A})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. GATE
#     core type: Literal
#     sub-expressions:
# 13. U
#     core type: Variable
#     sub-expressions:
# 14. {A}
#     core type: Operation
#     operator: 15
#     operand: 16
# 15. Set
#     core type: Literal
#     sub-expressions:
# 16. A
#     core type: Variable
#     sub-expressions:
