# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.circuit.Circuit.html">Circuit</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, ExprArray, ExprRange, IndexedVar, S, i, m
from proveit.numbers import one
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = Circuit(ExprArray(ExprRange(i, [MultiQubitGate(IndexedVar(B, i), IndexedVar(S, i))], one, m)))
# Out:
# expr:  MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1}{\Big \{} S_{1}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1]   \\
#   & \gate{B_{m}{\Big \{} S_{m}}
# } \hspace{2em}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0.  MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 2. ((MultiQubitGate(B_{1}, S_{1})  \\
#   \colon  \\
#   MultiQubitGate(B_{i}, S_{i})  \\
#   \colon  \\
#   MultiQubitGate(B_{m}, S_{m})))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. MultiQubitGate(B_{1}, S_{1})  \\
#   \colon  \\
#   MultiQubitGate(B_{i}, S_{i})  \\
#   \colon  \\
#   MultiQubitGate(B_{m}, S_{m})
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (MultiQubitGate(B_{1}, S_{1})), ..(MultiQubitGate(B_{i}, S_{i})).., (MultiQubitGate(B_{m}, S_{m}))
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 5. i -> (MultiQubitGate(B_{i}, S_{i}))
#    core type: Lambda
#    parameter: 16
#    body: 8
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. m
#    core type: Variable
#    sub-expressions:
# 8. (MultiQubitGate(B_{i}, S_{i}))
#    core type: ExprTuple
#    sub-expressions: 9
# 9. MultiQubitGate(B_{i}, S_{i})
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 11. (B_{i}, S_{i})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. B_{i}
#     core type: IndexedVar
# variable: 14
# index: 16
# 13. S_{i}
#     core type: IndexedVar
# variable: 15
# index: 16
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. S
#     core type: Variable
#     sub-expressions:
# 16. i
#     core type: Variable
#     sub-expressions:
