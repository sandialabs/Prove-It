# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, D, ExprArray, ExprRange, IndexedVar, Q, R, S, Variable, h, i, j, k, m
from proveit.core_expr_types.expr_arrays import Aij, Cij, Qij, Rij
from proveit.logic import Forall, Implies
from proveit.numbers import NaturalPos, one
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr3 = [sub_expr1, sub_expr2]
sub_expr4 = IndexedVar(S, i)
sub_expr5 = MultiQubitGate(IndexedVar(B, i), sub_expr4)
sub_expr6 = MultiQubitGate(IndexedVar(D, i), sub_expr4)
sub_expr7 = ExprRange(j, MultiQubitGate(Aij, Rij), one, k)
sub_expr8 = ExprRange(j, MultiQubitGate(Cij, Qij), one, h)
expr = Forall([h, k, m], Forall([ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(A, sub_expr3), one, k), one, m), ExprRange(sub_expr1, IndexedVar(B, sub_expr1), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(C, sub_expr3), one, h), one, m), ExprRange(sub_expr1, IndexedVar(D, sub_expr1), one, m), ExprRange(sub_expr1, IndexedVar(S, sub_expr1), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(R, sub_expr3), one, k), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(Q, sub_expr3), one, h), one, m)], Implies(CircuitEquiv(Circuit(ExprArray(ExprRange(i, [sub_expr5], one, m))), Circuit(ExprArray(ExprRange(i, [sub_expr6], one, m)))), CircuitEquiv(Circuit(ExprArray(ExprRange(i, [sub_expr7, sub_expr5, sub_expr8], one, m))), Circuit(ExprArray(ExprRange(i, [sub_expr7, sub_expr6, sub_expr8], one, m))))).with_wrapping_at(2)).wrap_params(), domains = [NaturalPos, NaturalPos, NaturalPos])
# Out:
# expr: forall_{h, k, m in NaturalPos} [forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}} (( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})) =>  \\ ( MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}) equiv  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h})))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{h, k, m \in \mathbb{N}^+}~\left[\forall_{ \scriptsize \begin{array}{c}
# A_{1, 1}, \ldots, A_{1, k}, \ldots\ldots, A_{m, 1}, \ldots, A_{m, k}, B_{1}, \ldots, B_{m}, \\
# C_{1, 1}, \ldots, C_{1, h}, \ldots\ldots, C_{m, 1}, \ldots, C_{m, h}, D_{1}, \ldots, D_{m}, \\
# S_{1}, \ldots, S_{m}, R_{1, 1}, \ldots, R_{1, k}, \ldots\ldots, R_{m, 1}, \ldots, R_{m, k}, \\
# Q_{1, 1}, \ldots, Q_{1, h}, \ldots\ldots, Q_{m, 1}, \ldots, Q_{m, h}\end{array}
# }~  \\
# \left(\begin{array}{c} \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1}{\Big \{} S_{1}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1]   \\
#   & \gate{B_{m}{\Big \{} S_{m}}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{1}{\Big \{} S_{1}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1]   \\
#   & \gate{D_{m}{\Big \{} S_{m}}
# } \hspace{2em}\right) \Rightarrow  \\ \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} R_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, k}{\Big \{} R_{1, k}} \qwx[1] & \gate{B_{1}{\Big \{} S_{1}} \qwx[1] & \gate{C_{1, 1}{\Big \{} Q_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1, h}{\Big \{} Q_{1, h}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{} R_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{C_{i, j}{\Big \{} Q_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{m, 1}{\Big \{} R_{m, 1}} & \gate{\cdots} & \gate{A_{m, k}{\Big \{} R_{m, k}} & \gate{B_{m}{\Big \{} S_{m}} & \gate{C_{m, 1}{\Big \{} Q_{m, 1}} & \gate{\cdots} & \gate{C_{m, h}{\Big \{} Q_{m, h}}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} R_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, k}{\Big \{} R_{1, k}} \qwx[1] & \gate{D_{1}{\Big \{} S_{1}} \qwx[1] & \gate{C_{1, 1}{\Big \{} Q_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1, h}{\Big \{} Q_{1, h}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{} R_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{C_{i, j}{\Big \{} Q_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{m, 1}{\Big \{} R_{m, 1}} & \gate{\cdots} & \gate{A_{m, k}{\Big \{} R_{m, k}} & \gate{D_{m}{\Big \{} S_{m}} & \gate{C_{m, 1}{\Big \{} Q_{m, 1}} & \gate{\cdots} & \gate{C_{m, h}{\Big \{} Q_{m, h}}
# } \hspace{2em}\right) \end{array}\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{h, k, m in NaturalPos} [forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}} (( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})) =>  \\ ( MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}) equiv  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h})))]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (h, k, m) -> {forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}} (( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})) =>  \\ ( MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}) equiv  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}))) if h in NaturalPos ,  k in NaturalPos ,  m in NaturalPos.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (h, k, m)
#    core type: ExprTuple
#    sub-expressions: 95, 91, 80
# 3. {forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}} (( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})) =>  \\ ( MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}) equiv  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}))) if h in NaturalPos ,  k in NaturalPos ,  m in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}} (( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})) =>  \\ ( MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}) equiv  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h})))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (h in NaturalPos) and (k in NaturalPos) and (m in NaturalPos)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}) -> (( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})) =>  \\ ( MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}) equiv  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h})))
#    core type: Lambda
#    parameters: 10\n   body: 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (h in NaturalPos, k in NaturalPos, m in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 10. (A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h})
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17, 18, 19, 20, 21
# 11. ( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})) =>  \\ ( MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}) equiv  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}))
#     core type: Operation
#     operator: 22
#     operands: 23
# 12. h in NaturalPos
#     core type: Operation
#     operator: 26
#     operands: 24
# 13. k in NaturalPos
#     core type: Operation
#     operator: 26
#     operands: 25
# 14. m in NaturalPos
#     core type: Operation
#     operator: 26
#     operands: 27
# 15. A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 94
#     end_index: 80
# 16. B_{1}, ..B_{_a}.., B_{m}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 94
#     end_index: 80
# 17. C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 94
#     end_index: 80
# 18. D_{1}, ..D_{_a}.., D_{m}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 94
#     end_index: 80
# 19. S_{1}, ..S_{_a}.., S_{m}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 94
#     end_index: 80
# 20. R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 94
#     end_index: 80
# 21. Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 94
#     end_index: 80
# 22. =>
#     core type: Literal
#     sub-expressions:
# 23. ( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m}),  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}) equiv  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 24. (h, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 95, 37
# 25. (k, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 91, 37
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 80, 37
# 28. _a -> A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}
#     core type: Lambda
#     parameter: 70
#     body: 38
# 29. _a -> B_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 39
# 30. _a -> C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}
#     core type: Lambda
#     parameter: 70
#     body: 40
# 31. _a -> D_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 41
# 32. _a -> S_{_a}
#     core type: Lambda
#     parameter: 70
#     body: 42
# 33. _a -> R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}
#     core type: Lambda
#     parameter: 70
#     body: 43
# 34. _a -> Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}
#     core type: Lambda
#     parameter: 70
#     body: 44
# 35.  MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}) equiv  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})
#     core type: Operation
#     operator: 46
#     operands: 45
# 36.  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}) equiv  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h})
#     core type: Operation
#     operator: 46
#     operands: 47
# 37. NaturalPos
#     core type: Literal
#     sub-expressions:
# 38. A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 94
#     end_index: 91
# 39. B_{_a}
#     core type: IndexedVar
# variable: 101
# index: 70
# 40. C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 94
#     end_index: 95
# 41. D_{_a}
#     core type: IndexedVar
# variable: 103
# index: 70
# 42. S_{_a}
#     core type: IndexedVar
# variable: 104
# index: 70
# 43. R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 94
#     end_index: 91
# 44. Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 94
#     end_index: 95
# 45. ( MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m}),  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m}))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 46. equiv
#     core type: Literal
#     sub-expressions:
# 47. ( MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}),  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h}))
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 48. _b -> A_{_a, _b}
#     core type: Lambda
#     parameter: 71
#     body: 56
# 49. _b -> C_{_a, _b}
#     core type: Lambda
#     parameter: 71
#     body: 57
# 50. _b -> R_{_a, _b}
#     core type: Lambda
#     parameter: 71
#     body: 58
# 51. _b -> Q_{_a, _b}
#     core type: Lambda
#     parameter: 71
#     body: 59
# 52.  MultiQubitGate(B_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(B_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(B_{m}, S_{m})
#     core type: Operation
#     operator: 63
#     operand: 66
# 53.  MultiQubitGate(D_{1}, S_{1})   \\
#    \colon   \\
#    MultiQubitGate(D_{i}, S_{i})   \\
#    \colon   \\
#    MultiQubitGate(D_{m}, S_{m})
#     core type: Operation
#     operator: 63
#     operand: 67
# 54.  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(B_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(B_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(B_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h})
#     core type: Operation
#     operator: 63
#     operand: 68
# 55.  MultiQubitGate(A_{1, 1}, R_{1, 1})  & ..MultiQubitGate(A_{1, j}, R_{1, j})..  & MultiQubitGate(A_{1, k}, R_{1, k})  & MultiQubitGate(D_{1}, S_{1})  & MultiQubitGate(C_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(C_{1, j}, Q_{1, j})..  & MultiQubitGate(C_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, R_{i, 1})  & ..MultiQubitGate(A_{i, j}, R_{i, j})..  & MultiQubitGate(A_{i, k}, R_{i, k})  & MultiQubitGate(D_{i}, S_{i})  & MultiQubitGate(C_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(C_{i, j}, Q_{i, j})..  & MultiQubitGate(C_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, R_{m, 1})  & ..MultiQubitGate(A_{m, j}, R_{m, j})..  & MultiQubitGate(A_{m, k}, R_{m, k})  & MultiQubitGate(D_{m}, S_{m})  & MultiQubitGate(C_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(C_{m, j}, Q_{m, j})..  & MultiQubitGate(C_{m, h}, Q_{m, h})
#     core type: Operation
#     operator: 63
#     operand: 69
# 56. A_{_a, _b}
#     core type: IndexedVar
# variable: 111
# indices: 65
# 57. C_{_a, _b}
#     core type: IndexedVar
# variable: 113
# indices: 65
# 58. R_{_a, _b}
#     core type: IndexedVar
# variable: 112
# indices: 65
# 59. Q_{_a, _b}
#     core type: IndexedVar
# variable: 114
# indices: 65
# 60. ((MultiQubitGate(B_{1}, S_{1})  \\
#   \colon  \\
#   MultiQubitGate(B_{i}, S_{i})  \\
#   \colon  \\
#   MultiQubitGate(B_{m}, S_{m})))
#     core type: ExprTuple
#     sub-expressions: 66
# 61. ((MultiQubitGate(D_{1}, S_{1})  \\
#   \colon  \\
#   MultiQubitGate(D_{i}, S_{i})  \\
#   \colon  \\
#   MultiQubitGate(D_{m}, S_{m})))
#     core type: ExprTuple
#     sub-expressions: 67
# 62. ((MultiQubitGate(A_{1, 1}, R_{1, 1}) & ..MultiQubitGate(A_{1, j}, R_{1, j}).. & MultiQubitGate(A_{1, k}, R_{1, k}) & MultiQubitGate(B_{1}, S_{1}) & MultiQubitGate(C_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(C_{1, j}, Q_{1, j}).. & MultiQubitGate(C_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, R_{i, 1}) & ..MultiQubitGate(A_{i, j}, R_{i, j}).. & MultiQubitGate(A_{i, k}, R_{i, k}) & MultiQubitGate(B_{i}, S_{i}) & MultiQubitGate(C_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(C_{i, j}, Q_{i, j}).. & MultiQubitGate(C_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, R_{m, 1}) & ..MultiQubitGate(A_{m, j}, R_{m, j}).. & MultiQubitGate(A_{m, k}, R_{m, k}) & MultiQubitGate(B_{m}, S_{m}) & MultiQubitGate(C_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(C_{m, j}, Q_{m, j}).. & MultiQubitGate(C_{m, h}, Q_{m, h})))
#     core type: ExprTuple
#     sub-expressions: 68
# 63. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 64. ((MultiQubitGate(A_{1, 1}, R_{1, 1}) & ..MultiQubitGate(A_{1, j}, R_{1, j}).. & MultiQubitGate(A_{1, k}, R_{1, k}) & MultiQubitGate(D_{1}, S_{1}) & MultiQubitGate(C_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(C_{1, j}, Q_{1, j}).. & MultiQubitGate(C_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, R_{i, 1}) & ..MultiQubitGate(A_{i, j}, R_{i, j}).. & MultiQubitGate(A_{i, k}, R_{i, k}) & MultiQubitGate(D_{i}, S_{i}) & MultiQubitGate(C_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(C_{i, j}, Q_{i, j}).. & MultiQubitGate(C_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, R_{m, 1}) & ..MultiQubitGate(A_{m, j}, R_{m, j}).. & MultiQubitGate(A_{m, k}, R_{m, k}) & MultiQubitGate(D_{m}, S_{m}) & MultiQubitGate(C_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(C_{m, j}, Q_{m, j}).. & MultiQubitGate(C_{m, h}, Q_{m, h})))
#     core type: ExprTuple
#     sub-expressions: 69
# 65. (_a, _b)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 66. MultiQubitGate(B_{1}, S_{1})  \\
#   \colon  \\
#   MultiQubitGate(B_{i}, S_{i})  \\
#   \colon  \\
#   MultiQubitGate(B_{m}, S_{m})
#     core type: ExprTuple
#     sub-expressions: 72
# 67. MultiQubitGate(D_{1}, S_{1})  \\
#   \colon  \\
#   MultiQubitGate(D_{i}, S_{i})  \\
#   \colon  \\
#   MultiQubitGate(D_{m}, S_{m})
#     core type: ExprTuple
#     sub-expressions: 73
# 68. MultiQubitGate(A_{1, 1}, R_{1, 1}) & ..MultiQubitGate(A_{1, j}, R_{1, j}).. & MultiQubitGate(A_{1, k}, R_{1, k}) & MultiQubitGate(B_{1}, S_{1}) & MultiQubitGate(C_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(C_{1, j}, Q_{1, j}).. & MultiQubitGate(C_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, R_{i, 1}) & ..MultiQubitGate(A_{i, j}, R_{i, j}).. & MultiQubitGate(A_{i, k}, R_{i, k}) & MultiQubitGate(B_{i}, S_{i}) & MultiQubitGate(C_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(C_{i, j}, Q_{i, j}).. & MultiQubitGate(C_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, R_{m, 1}) & ..MultiQubitGate(A_{m, j}, R_{m, j}).. & MultiQubitGate(A_{m, k}, R_{m, k}) & MultiQubitGate(B_{m}, S_{m}) & MultiQubitGate(C_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(C_{m, j}, Q_{m, j}).. & MultiQubitGate(C_{m, h}, Q_{m, h})
#     core type: ExprTuple
#     sub-expressions: 74
# 69. MultiQubitGate(A_{1, 1}, R_{1, 1}) & ..MultiQubitGate(A_{1, j}, R_{1, j}).. & MultiQubitGate(A_{1, k}, R_{1, k}) & MultiQubitGate(D_{1}, S_{1}) & MultiQubitGate(C_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(C_{1, j}, Q_{1, j}).. & MultiQubitGate(C_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, R_{i, 1}) & ..MultiQubitGate(A_{i, j}, R_{i, j}).. & MultiQubitGate(A_{i, k}, R_{i, k}) & MultiQubitGate(D_{i}, S_{i}) & MultiQubitGate(C_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(C_{i, j}, Q_{i, j}).. & MultiQubitGate(C_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, R_{m, 1}) & ..MultiQubitGate(A_{m, j}, R_{m, j}).. & MultiQubitGate(A_{m, k}, R_{m, k}) & MultiQubitGate(D_{m}, S_{m}) & MultiQubitGate(C_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(C_{m, j}, Q_{m, j}).. & MultiQubitGate(C_{m, h}, Q_{m, h})
#     core type: ExprTuple
#     sub-expressions: 75
# 70. _a
#     core type: Variable
#     sub-expressions:
# 71. _b
#     core type: Variable
#     sub-expressions:
# 72. (MultiQubitGate(B_{1}, S_{1})), ..(MultiQubitGate(B_{i}, S_{i})).., (MultiQubitGate(B_{m}, S_{m}))
#     core type: ExprRange
#     lambda_map: 76
#     start_index: 94
#     end_index: 80
# 73. (MultiQubitGate(D_{1}, S_{1})), ..(MultiQubitGate(D_{i}, S_{i})).., (MultiQubitGate(D_{m}, S_{m}))
#     core type: ExprRange
#     lambda_map: 77
#     start_index: 94
#     end_index: 80
# 74. (MultiQubitGate(A_{1, 1}, R_{1, 1}), ..MultiQubitGate(A_{1, j}, R_{1, j}).., MultiQubitGate(A_{1, k}, R_{1, k}), MultiQubitGate(B_{1}, S_{1}), MultiQubitGate(C_{1, 1}, Q_{1, 1}), ..MultiQubitGate(C_{1, j}, Q_{1, j}).., MultiQubitGate(C_{1, h}, Q_{1, h})), ..(MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k}), MultiQubitGate(B_{i}, S_{i}), MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h})).., (MultiQubitGate(A_{m, 1}, R_{m, 1}), ..MultiQubitGate(A_{m, j}, R_{m, j}).., MultiQubitGate(A_{m, k}, R_{m, k}), MultiQubitGate(B_{m}, S_{m}), MultiQubitGate(C_{m, 1}, Q_{m, 1}), ..MultiQubitGate(C_{m, j}, Q_{m, j}).., MultiQubitGate(C_{m, h}, Q_{m, h}))
#     core type: ExprRange
#     lambda_map: 78
#     start_index: 94
#     end_index: 80
# 75. (MultiQubitGate(A_{1, 1}, R_{1, 1}), ..MultiQubitGate(A_{1, j}, R_{1, j}).., MultiQubitGate(A_{1, k}, R_{1, k}), MultiQubitGate(D_{1}, S_{1}), MultiQubitGate(C_{1, 1}, Q_{1, 1}), ..MultiQubitGate(C_{1, j}, Q_{1, j}).., MultiQubitGate(C_{1, h}, Q_{1, h})), ..(MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k}), MultiQubitGate(D_{i}, S_{i}), MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h})).., (MultiQubitGate(A_{m, 1}, R_{m, 1}), ..MultiQubitGate(A_{m, j}, R_{m, j}).., MultiQubitGate(A_{m, k}, R_{m, k}), MultiQubitGate(D_{m}, S_{m}), MultiQubitGate(C_{m, 1}, Q_{m, 1}), ..MultiQubitGate(C_{m, j}, Q_{m, j}).., MultiQubitGate(C_{m, h}, Q_{m, h}))
#     core type: ExprRange
#     lambda_map: 79
#     start_index: 94
#     end_index: 80
# 76. i -> (MultiQubitGate(B_{i}, S_{i}))
#     core type: Lambda
#     parameter: 116
#     body: 81
# 77. i -> (MultiQubitGate(D_{i}, S_{i}))
#     core type: Lambda
#     parameter: 116
#     body: 82
# 78. i -> (MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k}), MultiQubitGate(B_{i}, S_{i}), MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h}))
#     core type: Lambda
#     parameter: 116
#     body: 83
# 79. i -> (MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k}), MultiQubitGate(D_{i}, S_{i}), MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h}))
#     core type: Lambda
#     parameter: 116
#     body: 84
# 80. m
#     core type: Variable
#     sub-expressions:
# 81. (MultiQubitGate(B_{i}, S_{i}))
#     core type: ExprTuple
#     sub-expressions: 85
# 82. (MultiQubitGate(D_{i}, S_{i}))
#     core type: ExprTuple
#     sub-expressions: 87
# 83. (MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k}), MultiQubitGate(B_{i}, S_{i}), MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h}))
#     core type: ExprTuple
#     sub-expressions: 86, 85, 88
# 84. (MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k}), MultiQubitGate(D_{i}, S_{i}), MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h}))
#     core type: ExprTuple
#     sub-expressions: 86, 87, 88
# 85. MultiQubitGate(B_{i}, S_{i})
#     core type: Operation
#     operator: 105
#     operands: 89
# 86. MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k})
#     core type: ExprRange
#     lambda_map: 90
#     start_index: 94
#     end_index: 91
# 87. MultiQubitGate(D_{i}, S_{i})
#     core type: Operation
#     operator: 105
#     operands: 92
# 88. MultiQubitGate(C_{i, 1}, Q_{i, 1}), ..MultiQubitGate(C_{i, j}, Q_{i, j}).., MultiQubitGate(C_{i, h}, Q_{i, h})
#     core type: ExprRange
#     lambda_map: 93
#     start_index: 94
#     end_index: 95
# 89. (B_{i}, S_{i})
#     core type: ExprTuple
#     sub-expressions: 96, 99
# 90. j -> MultiQubitGate(A_{i, j}, R_{i, j})
#     core type: Lambda
#     parameter: 117
#     body: 97
# 91. k
#     core type: Variable
#     sub-expressions:
# 92. (D_{i}, S_{i})
#     core type: ExprTuple
#     sub-expressions: 98, 99
# 93. j -> MultiQubitGate(C_{i, j}, Q_{i, j})
#     core type: Lambda
#     parameter: 117
#     body: 100
# 94. 1
#     core type: Literal
#     sub-expressions:
# 95. h
#     core type: Variable
#     sub-expressions:
# 96. B_{i}
#     core type: IndexedVar
# variable: 101
# index: 116
# 97. MultiQubitGate(A_{i, j}, R_{i, j})
#     core type: Operation
#     operator: 105
#     operands: 102
# 98. D_{i}
#     core type: IndexedVar
# variable: 103
# index: 116
# 99. S_{i}
#     core type: IndexedVar
# variable: 104
# index: 116
# 100. MultiQubitGate(C_{i, j}, Q_{i, j})
#      core type: Operation
#      operator: 105
#      operands: 106
# 101. B
#      core type: Variable
#      sub-expressions:
# 102. (A_{i, j}, R_{i, j})
#      core type: ExprTuple
#      sub-expressions: 107, 108
# 103. D
#      core type: Variable
#      sub-expressions:
# 104. S
#      core type: Variable
#      sub-expressions:
# 105. MULTI_QUBIT_GATE
#      core type: Literal
#      sub-expressions:
# 106. (C_{i, j}, Q_{i, j})
#      core type: ExprTuple
#      sub-expressions: 109, 110
# 107. A_{i, j}
#      core type: IndexedVar
# variable: 111
# indices: 115
# 108. R_{i, j}
#      core type: IndexedVar
# variable: 112
# indices: 115
# 109. C_{i, j}
#      core type: IndexedVar
# variable: 113
# indices: 115
# 110. Q_{i, j}
#      core type: IndexedVar
# variable: 114
# indices: 115
# 111. A
#      core type: Variable
#      sub-expressions:
# 112. R
#      core type: Variable
#      sub-expressions:
# 113. C
#      core type: Variable
#      sub-expressions:
# 114. Q
#      core type: Variable
#      sub-expressions:
# 115. (i, j)
#      core type: ExprTuple
#      sub-expressions: 116, 117
# 116. i
#      core type: Variable
#      sub-expressions:
# 117. j
#      core type: Variable
#      sub-expressions:
