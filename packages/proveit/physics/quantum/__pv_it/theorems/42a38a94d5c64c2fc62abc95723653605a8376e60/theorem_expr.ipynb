# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#double_space_equiv">double_space_equiv</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum import double_space_equiv

# %%
# check that the built expression is the same as the stored expression
assert double_space_equiv.expr == stored_expr
assert double_space_equiv.expr._style_id == stored_expr._style_id
print("Passed sanity check: double_space_equiv matches stored_expr")
# Out:
# Passed sanity check: double_space_equiv matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(double_space_equiv.latex())
# Out:
# \vdash \forall_{h, k, m, n \in \mathbb{N}^+}~\left[\forall_{ \scriptsize \begin{array}{c}
# A_{1, 1}, \ldots, A_{1, n}, \ldots\ldots, A_{m, 1}, \ldots, A_{m, n}, B_{1}, \ldots, B_{n}, \\
# C_{1, 1}, \ldots, C_{1, n}, \ldots\ldots, C_{k, 1}, \ldots, C_{k, n}, D_{1}, \ldots, D_{n}, \\
# E_{1, 1}, \ldots, E_{1, n}, \ldots\ldots, E_{h, 1}, \ldots, E_{h, n}, F_{1}, \ldots, F_{n}, \\
# G_{1}, \ldots, G_{n}, S_{1, 1}, \ldots, S_{1, n}, \ldots\ldots, S_{m, 1}, \ldots, S_{m, n}, \\
# Q_{1, 1}, \ldots, Q_{1, n}, \ldots\ldots, Q_{h, 1}, \ldots, Q_{h, n}, R_{1, 1}, \ldots, R_{1, n}, \ldots\ldots, R_{k, 1}, \ldots, R_{k, n}\end{array}
# }~  \\
# \left(\begin{array}{c} \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1}{\Big \{} \left\{m + 1, m + k + 2\right\}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{B_{n}{\Big \{} \left\{m + 1, m + k + 2\right\}} \qwx[1]   \\
# ...

# %%
# display the expression information
double_space_equiv.expr_info()
# Out:
# 0. forall_{h, k, m, n in NaturalPos} [forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, n}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, n}...., A_{m, 1}, ..A_{m, _b}.., A_{m, n}, B_{1}, ..B_{_a}.., B_{n}, C_{1, 1}, ..C_{1, _b}.., C_{1, n}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, n}...., C_{k, 1}, ..C_{k, _b}.., C_{k, n}, D_{1}, ..D_{_a}.., D_{n}, E_{1, 1}, ..E_{1, _b}.., E_{1, n}, ....E_{_a, 1}, ..E_{_a, _b}.., E_{_a, n}...., E_{h, 1}, ..E_{h, _b}.., E_{h, n}, F_{1}, ..F_{_a}.., F_{n}, G_{1}, ..G_{_a}.., G_{n}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, n}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, n}...., Q_{h, 1}, ..Q_{h, _b}.., Q_{h, n}, R_{1, 1}, ..R_{1, _b}.., R_{1, n}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, n}...., R_{k, 1}, ..R_{k, _b}.., R_{k, n}} (( MultiQubitGate(B_{1}, {m + 1, m + k + 2})  & ..MultiQubitGate(B_{j}, {m + 1, m + k + 2})..  & MultiQubitGate(B_{n}, {m + 1, m + k + 2})   \\
# ...
