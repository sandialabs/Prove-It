# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, D, ExprRange, ExprTuple, IndexedVar, Q, R, S, Variable, h, k, m
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr3 = [sub_expr1, sub_expr2]
expr = ExprTuple(ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(A, sub_expr3), one, k), one, m), ExprRange(sub_expr1, IndexedVar(B, sub_expr1), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(C, sub_expr3), one, h), one, m), ExprRange(sub_expr1, IndexedVar(D, sub_expr1), one, m), ExprRange(sub_expr1, IndexedVar(S, sub_expr1), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(R, sub_expr3), one, k), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(Q, sub_expr3), one, h), one, m))
# Out:
# expr: (A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1, 1}, \ldots, A_{1, k}, \ldots\ldots, A_{m, 1}, \ldots, A_{m, k}, B_{1}, \ldots, B_{m}, C_{1, 1}, \ldots, C_{1, h}, \ldots\ldots, C_{m, 1}, \ldots, C_{m, h}, D_{1}, \ldots, D_{m}, S_{1}, \ldots, S_{m}, R_{1, 1}, \ldots, R_{1, k}, \ldots\ldots, R_{m, 1}, \ldots, R_{m, k}, Q_{1, 1}, \ldots, Q_{1, h}, \ldots\ldots, Q_{m, 1}, \ldots, Q_{m, h}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}, B_{1}, ..B_{_a}.., B_{m}, C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h})
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5, 6, 7
# 1. A_{1, 1}, ..A_{1, _b}.., A_{1, k}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}...., A_{m, 1}, ..A_{m, _b}.., A_{m, k}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 31
#    end_index: 15
# 2. B_{1}, ..B_{_a}.., B_{m}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 31
#    end_index: 15
# 3. C_{1, 1}, ..C_{1, _b}.., C_{1, h}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}...., C_{m, 1}, ..C_{m, _b}.., C_{m, h}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 31
#    end_index: 15
# 4. D_{1}, ..D_{_a}.., D_{m}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 31
#    end_index: 15
# 5. S_{1}, ..S_{_a}.., S_{m}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 31
#    end_index: 15
# 6. R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 31
#    end_index: 15
# 7. Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 31
#    end_index: 15
# 8. _a -> A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}
#    core type: Lambda
#    parameter: 42
#    body: 16
# 9. _a -> B_{_a}
#    core type: Lambda
#    parameter: 42
#    body: 17
# 10. _a -> C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}
#     core type: Lambda
#     parameter: 42
#     body: 18
# 11. _a -> D_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 19
# 12. _a -> S_{_a}
#     core type: Lambda
#     parameter: 42
#     body: 20
# 13. _a -> R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}
#     core type: Lambda
#     parameter: 42
#     body: 21
# 14. _a -> Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}
#     core type: Lambda
#     parameter: 42
#     body: 22
# 15. m
#     core type: Variable
#     sub-expressions:
# 16. A_{_a, 1}, ..A_{_a, _b}.., A_{_a, k}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 31
#     end_index: 29
# 17. B_{_a}
#     core type: IndexedVar
# variable: 24
# index: 42
# 18. C_{_a, 1}, ..C_{_a, _b}.., C_{_a, h}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 31
#     end_index: 32
# 19. D_{_a}
#     core type: IndexedVar
# variable: 26
# index: 42
# 20. S_{_a}
#     core type: IndexedVar
# variable: 27
# index: 42
# 21. R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 31
#     end_index: 29
# 22. Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 31
#     end_index: 32
# 23. _b -> A_{_a, _b}
#     core type: Lambda
#     parameter: 43
#     body: 33
# 24. B
#     core type: Variable
#     sub-expressions:
# 25. _b -> C_{_a, _b}
#     core type: Lambda
#     parameter: 43
#     body: 34
# 26. D
#     core type: Variable
#     sub-expressions:
# 27. S
#     core type: Variable
#     sub-expressions:
# 28. _b -> R_{_a, _b}
#     core type: Lambda
#     parameter: 43
#     body: 35
# 29. k
#     core type: Variable
#     sub-expressions:
# 30. _b -> Q_{_a, _b}
#     core type: Lambda
#     parameter: 43
#     body: 36
# 31. 1
#     core type: Literal
#     sub-expressions:
# 32. h
#     core type: Variable
#     sub-expressions:
# 33. A_{_a, _b}
#     core type: IndexedVar
# variable: 37
# indices: 41
# 34. C_{_a, _b}
#     core type: IndexedVar
# variable: 38
# indices: 41
# 35. R_{_a, _b}
#     core type: IndexedVar
# variable: 39
# indices: 41
# 36. Q_{_a, _b}
#     core type: IndexedVar
# variable: 40
# indices: 41
# 37. A
#     core type: Variable
#     sub-expressions:
# 38. C
#     core type: Variable
#     sub-expressions:
# 39. R
#     core type: Variable
#     sub-expressions:
# 40. Q
#     core type: Variable
#     sub-expressions:
# 41. (_a, _b)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 42. _a
#     core type: Variable
#     sub-expressions:
# 43. _b
#     core type: Variable
#     sub-expressions:
