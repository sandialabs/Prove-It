# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, j
from proveit.core_expr_types.expr_arrays import Aij, Rij
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = Lambda(j, MultiQubitGate(Aij, Rij))
# Out:
# expr: j -> MultiQubitGate(A_{i, j}, R_{i, j})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# j \mapsto \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{i, j}{\Big \{} R_{i, j}}
# } \hspace{2em}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. j -> MultiQubitGate(A_{i, j}, R_{i, j})
#    core type: Lambda
#    parameter: 10
#    body: 1
# 1. MultiQubitGate(A_{i, j}, R_{i, j})
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 3. (A_{i, j}, R_{i, j})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. A_{i, j}
#    core type: IndexedVar
# variable: 6
# indices: 8
# 5. R_{i, j}
#    core type: IndexedVar
# variable: 7
# indices: 8
# 6. A
#    core type: Variable
#    sub-expressions:
# 7. R
#    core type: Variable
#    sub-expressions:
# 8. (i, j)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. i
#    core type: Variable
#    sub-expressions:
# 10. j
#     core type: Variable
#     sub-expressions:
