# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import IndexedVar, Variable, x
from proveit.logic import InSet
from proveit.physics.quantum import QubitSpace

# %%
# build up the expression from sub-expressions
expr = InSet(IndexedVar(x, Variable("_a", latex_format = r"{_{-}a}")), QubitSpace)
# Out:
# expr: x_{_a} in Complex^{2}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x_{{_{-}a}} \in \mathbb{C}^{2}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x_{_a} in Complex^{2}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (x_{_a}, Complex^{2})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. x_{_a}
#    core type: IndexedVar
# variable: 5
# index: 6
# 4. Complex^{2}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. x
#    core type: Variable
#    sub-expressions:
# 6. _a
#    core type: Variable
#    sub-expressions:
# 7. Exp
#    core type: Literal
#    sub-expressions:
# 8. (Complex, 2)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. Complex
#    core type: Literal
#    sub-expressions:
# 10. 2
#     core type: Literal
#     sub-expressions:
