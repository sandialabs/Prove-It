# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, ExprRange, IndexedVar, j, k, m, n
from proveit.logic import Set
from proveit.numbers import Add, one, two
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = ExprRange(j, MultiQubitGate(IndexedVar(B, j), Set(Add(m, one), Add(m, k, two))), one, n)
# Out:
# expr: MultiQubitGate(B_{1}, {m + 1, m + k + 2}), ..MultiQubitGate(B_{j}, {m + 1, m + k + 2}).., MultiQubitGate(B_{n}, {m + 1, m + k + 2})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1}{\Big \{} \left\{m + 1, m + k + 2\right\}}
# } \hspace{2em}, \ldots, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{n}{\Big \{} \left\{m + 1, m + k + 2\right\}}
# } \hspace{2em}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. MultiQubitGate(B_{1}, {m + 1, m + k + 2}), ..MultiQubitGate(B_{j}, {m + 1, m + k + 2}).., MultiQubitGate(B_{n}, {m + 1, m + k + 2})
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 17
#    end_index: 2
# 1. j -> MultiQubitGate(B_{j}, {m + 1, m + k + 2})
#    core type: Lambda
#    parameter: 9
#    body: 3
# 2. n
#    core type: Variable
#    sub-expressions:
# 3. MultiQubitGate(B_{j}, {m + 1, m + k + 2})
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 5. (B_{j}, {m + 1, m + k + 2})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. B_{j}
#    core type: IndexedVar
# variable: 8
# index: 9
# 7. {m + 1, m + k + 2}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. B
#    core type: Variable
#    sub-expressions:
# 9. j
#    core type: Variable
#    sub-expressions:
# 10. Set
#     core type: Literal
#     sub-expressions:
# 11. (m + 1, m + k + 2)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. m + 1
#     core type: Operation
#     operator: 15
#     operands: 14
# 13. m + k + 2
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (m, k, 2)
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. m
#     core type: Variable
#     sub-expressions:
# 19. k
#     core type: Variable
#     sub-expressions:
# 20. 2
#     core type: Literal
#     sub-expressions:
