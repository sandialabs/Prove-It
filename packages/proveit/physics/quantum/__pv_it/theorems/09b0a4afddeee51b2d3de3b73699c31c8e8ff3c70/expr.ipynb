# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, alpha, n, x
from proveit.linalg import ScalarProd, TensorExp
from proveit.logic import Forall, InSet
from proveit.numbers import Complex, NaturalPos
from proveit.physics.quantum import QubitSpace

# %%
# build up the expression from sub-expressions
sub_expr1 = TensorExp([QubitSpace], n)
expr = Lambda(n, Conditional(Forall([x], Forall([alpha], InSet(ScalarProd(alpha, x), sub_expr1), domains = [Complex]), domains = [sub_expr1]), InSet(n, NaturalPos)))
# Out:
# expr: n -> {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex} ((alpha * x) in (Complex^{2})^{otimes n})] if n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{x \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left[\forall_{\alpha \in \mathbb{C}}~\left(\left(\alpha \thinspace x\right) \in \left(\mathbb{C}^{2}\right)^{\otimes n}\right)\right] \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. n -> {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex} ((alpha * x) in (Complex^{2})^{otimes n})] if n in NaturalPos.
#    core type: Lambda
#    parameter: 28
#    body: 1
# 1. {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex} ((alpha * x) in (Complex^{2})^{otimes n})] if n in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex} ((alpha * x) in (Complex^{2})^{otimes n})]
#    core type: Operation
#    operator: 10
#    operand: 4
# 3. n in NaturalPos
#    core type: Operation
#    operator: 17
#    operands: 5
# 4. x -> {forall_{alpha in Complex} ((alpha * x) in (Complex^{2})^{otimes n}) if x in (Complex^{2})^{otimes n}.
#    core type: Lambda
#    parameter: 26
#    body: 6
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 28, 7
# 6. {forall_{alpha in Complex} ((alpha * x) in (Complex^{2})^{otimes n}) if x in (Complex^{2})^{otimes n}.
#    core type: Conditional
#    value: 8
#    condition: 9
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. forall_{alpha in Complex} ((alpha * x) in (Complex^{2})^{otimes n})
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. x in (Complex^{2})^{otimes n}
#    core type: Operation
#    operator: 17
#    operands: 12
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. alpha -> {(alpha * x) in (Complex^{2})^{otimes n} if alpha in Complex.
#     core type: Lambda
#     parameter: 25
#     body: 13
# 12. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 26, 20
# 13. {(alpha * x) in (Complex^{2})^{otimes n} if alpha in Complex.
#     core type: Conditional
#     value: 14
#     condition: 15
# 14. (alpha * x) in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 17
#     operands: 16
# 15. alpha in Complex
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (alpha * x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (alpha, Complex)
#     core type: ExprTuple
#     sub-expressions: 25, 32
# 19. alpha * x
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. *
#     core type: Literal
#     sub-expressions:
# 22. (alpha, x)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. otimes
#     core type: Literal
#     sub-expressions:
# 24. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. alpha
#     core type: Variable
#     sub-expressions:
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 29
# 28. n
#     core type: Variable
#     sub-expressions:
# 29. Complex^{2}
#     core type: Operation
#     operator: 30
#     operands: 31
# 30. Exp
#     core type: Literal
#     sub-expressions:
# 31. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. Complex
#     core type: Literal
#     sub-expressions:
# 33. 2
#     core type: Literal
#     sub-expressions:
