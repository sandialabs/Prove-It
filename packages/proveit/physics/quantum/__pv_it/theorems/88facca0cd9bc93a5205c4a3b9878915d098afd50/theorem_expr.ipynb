# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#input_gate_to_ket">input_gate_to_ket</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum import input_gate_to_ket

# %%
# check that the built expression is the same as the stored expression
assert input_gate_to_ket.expr == stored_expr
assert input_gate_to_ket.expr._style_id == stored_expr._style_id
print("Passed sanity check: input_gate_to_ket matches stored_expr")
# Out:
# Passed sanity check: input_gate_to_ket matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(input_gate_to_ket.latex())
# Out:
# \vdash \forall_{U}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{ Input(U)}
# } \hspace{2em} = \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{U}
# } \hspace{2em}\right)

# %%
# display the expression information
input_gate_to_ket.expr_info()
# Out:
# 0. forall_{U} (Gate(Input(U)) = Input(U))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. U -> (Gate(Input(U)) = Input(U))
#    core type: Lambda
#    parameter: 10
#    body: 3
# 3. Gate(Input(U)) = Input(U)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (Gate(Input(U)), Input(U))
#    core type: ExprTuple
#    sub-expressions: 6, 8
# 6. Gate(Input(U))
#    core type: Operation
#    operator: 7
#    operand: 8
# 7. GATE
#    core type: Literal
#    sub-expressions:
# 8. [INPUT](U)
#    core type: Operation
#    operator: 9
#    operand: 10
# 9. INPUT
#    core type: Literal
#    sub-expressions:
# 10. U
#     core type: Variable
#     sub-expressions:
