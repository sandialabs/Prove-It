# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, j, k
from proveit.core_expr_types.expr_arrays import Aij, Rij
from proveit.numbers import one
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = ExprRange(j, MultiQubitGate(Aij, Rij), one, k)
# Out:
# expr: MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{i, 1}{\Big \{} R_{i, 1}}
# } \hspace{2em}, \ldots, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{i, k}{\Big \{} R_{i, k}}
# } \hspace{2em}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. MultiQubitGate(A_{i, 1}, R_{i, 1}), ..MultiQubitGate(A_{i, j}, R_{i, j}).., MultiQubitGate(A_{i, k}, R_{i, k})
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. j -> MultiQubitGate(A_{i, j}, R_{i, j})
#    core type: Lambda
#    parameter: 13
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. k
#    core type: Variable
#    sub-expressions:
# 4. MultiQubitGate(A_{i, j}, R_{i, j})
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 6. (A_{i, j}, R_{i, j})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. A_{i, j}
#    core type: IndexedVar
# variable: 9
# indices: 11
# 8. R_{i, j}
#    core type: IndexedVar
# variable: 10
# indices: 11
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. R
#     core type: Variable
#     sub-expressions:
# 11. (i, j)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. i
#     core type: Variable
#     sub-expressions:
# 13. j
#     core type: Variable
#     sub-expressions:
