# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import n
from proveit.core_expr_types import x_1_to_n
from proveit.logic import Forall, InSet
from proveit.numbers import Add, NaturalPos
from proveit.physics.quantum import QubitSpace

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([x_1_to_n], InSet(Add(x_1_to_n), QubitSpace), domains = [QubitSpace]), domains = [NaturalPos])
# Out:
# expr: forall_{n in NaturalPos} [forall_{x_{1}, ..x_{_a}.., x_{n} in Complex^{2}} ((x_{1} + ..x_{_a}.. + x_{n}) in Complex^{2})]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{x_{1}, \ldots, x_{n} \in \mathbb{C}^{2}}~\left(\left(x_{1} + \ldots + x_{n}\right) \in \mathbb{C}^{2}\right)\right]

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{x_{1}, ..x_{_a}.., x_{n} in Complex^{2}} ((x_{1} + ..x_{_a}.. + x_{n}) in Complex^{2})]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{x_{1}, ..x_{_a}.., x_{n} in Complex^{2}} ((x_{1} + ..x_{_a}.. + x_{n}) in Complex^{2}) if n in NaturalPos.
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. {forall_{x_{1}, ..x_{_a}.., x_{n} in Complex^{2}} ((x_{1} + ..x_{_a}.. + x_{n}) in Complex^{2}) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x_{1}, ..x_{_a}.., x_{n} in Complex^{2}} ((x_{1} + ..x_{_a}.. + x_{n}) in Complex^{2})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalPos
#    core type: Operation
#    operator: 25
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x_{1}, ..x_{_a}.., x_{n}) -> {(x_{1} + ..x_{_a}.. + x_{n}) in Complex^{2} if (x_{1} in Complex^{2}) and ..(x_{_a} in Complex^{2}).. and (x_{n} in Complex^{2}).
#    core type: Lambda
#    parameters: 18\n   body: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 24, 9
# 8. {(x_{1} + ..x_{_a}.. + x_{n}) in Complex^{2} if (x_{1} in Complex^{2}) and ..(x_{_a} in Complex^{2}).. and (x_{n} in Complex^{2}).
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (x_{1} + ..x_{_a}.. + x_{n}) in Complex^{2}
#     core type: Operation
#     operator: 25
#     operands: 12
# 11. (x_{1} in Complex^{2}) and ..(x_{_a} in Complex^{2}).. and (x_{n} in Complex^{2})
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (x_{1} + ..x_{_a}.. + x_{n}, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 15, 28
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (x_{1} in Complex^{2}, ..x_{_a} in Complex^{2}.., x_{n} in Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 16
# 15. x_{1} + ..x_{_a}.. + x_{n}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (x_{1} in Complex^{2}), ..(x_{_a} in Complex^{2}).., (x_{n} in Complex^{2})
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 23
#     end_index: 24
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 20
# 19. _a -> (x_{_a} in Complex^{2})
#     core type: Lambda
#     parameter: 30
#     body: 21
# 20. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 23
#     end_index: 24
# 21. x_{_a} in Complex^{2}
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. _a -> x_{_a}
#     core type: Lambda
#     parameter: 30
#     body: 27
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. n
#     core type: Variable
#     sub-expressions:
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (x_{_a}, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. x_{_a}
#     core type: IndexedVar
# variable: 29
# index: 30
# 28. Complex^{2}
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. _a
#     core type: Variable
#     sub-expressions:
# 31. Exp
#     core type: Literal
#     sub-expressions:
# 32. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 33. Complex
#     core type: Literal
#     sub-expressions:
# 34. 2
#     core type: Literal
#     sub-expressions:
