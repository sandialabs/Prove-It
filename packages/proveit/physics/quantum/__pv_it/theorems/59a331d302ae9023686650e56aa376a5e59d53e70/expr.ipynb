# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, k, n
from proveit.linalg import TensorExp
from proveit.logic import InSet
from proveit.numbers import Add, Exp, Interval, Neg, one, two, zero
from proveit.physics.quantum import QubitSpace, RegisterKet

# %%
# build up the expression from sub-expressions
expr = Lambda(k, Conditional(InSet(RegisterKet(k, n), TensorExp([QubitSpace], n)), InSet(k, Interval(zero, Add(Exp(two, n), Neg(one))))))
# Out:
# expr: k -> {|k〉_{n} in (Complex^{2})^{otimes n} if k in {0...2^{n} - 1}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# k \mapsto \left\{\lvert k \rangle_{n} \in \left(\mathbb{C}^{2}\right)^{\otimes n} \textrm{ if } k \in \{0 \dots 2^{n} - 1\}\right..

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. k -> {|k〉_{n} in (Complex^{2})^{otimes n} if k in {0...2^{n} - 1}.
#    core type: Lambda
#    parameter: 16
#    body: 1
# 1. {|k〉_{n} in (Complex^{2})^{otimes n} if k in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. |k〉_{n} in (Complex^{2})^{otimes n}
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. k in {0...2^{n} - 1}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (|k〉_{n}, (Complex^{2})^{otimes n})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (k, {0...2^{n} - 1})
#    core type: ExprTuple
#    sub-expressions: 16, 9
# 7. |k〉_{n}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (Complex^{2})^{otimes n}
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. {0...2^{n} - 1}
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. REGISTER_KET
#     core type: Literal
#     sub-expressions:
# 11. (k, n)
# ...
