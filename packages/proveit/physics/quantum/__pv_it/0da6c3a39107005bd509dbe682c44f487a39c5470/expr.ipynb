# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import Psi, k, m, n
from proveit.linalg import TensorExp
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Complexes, Exp, Interval, NaturalsPos, Neg, Sum, one, two, zero
from proveit.physics.quantum import Ket, Meas
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
subExpr1 = Ket(Psi)
expr = Lambda(n, Conditional(Forall([Psi, m], Equals(Sum([k], Prob(Equals(m, k), m), domain = Interval(zero, Add(Exp(two, n), Neg(one)))), one), conditions = [InSet(subExpr1, TensorExp([Exp(Complexes, two)], n)), Equals(m, Meas(subExpr1))]), InSet(n, NaturalsPos)))
# Out:
# expr: n -> {forall_{Psi, m | |Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉)} ((Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{\Psi, m~|~\lvert \Psi \rangle \in \left(\mathbb{C}^{2}\right)^{\otimes n}, m = \mathcal{M}(\lvert \Psi \rangle)}~\left(\left(\sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]\right) = 1\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{Psi, m | |Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉)} ((Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 60
#    body: 1
# 1. {forall_{Psi, m | |Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉)} ((Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1) if n in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{Psi, m | |Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉)} ((Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. n in NaturalsPos
#    core type: Operation
#    operator: 33
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (Psi, m) -> {(Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1 if |Psi〉 in (Complexes^{2})^{otimes n} ,  m = MEAS(|Psi〉).
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 60, 9
# 7. (Psi, m)
# ...
