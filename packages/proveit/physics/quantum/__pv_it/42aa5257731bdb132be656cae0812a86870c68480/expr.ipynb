# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import n, x
from proveit.logic import And, InSet
from proveit.number import Complexes, Exp, one, two

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = And(ExprRange(subExpr1, InSet(IndexedVar(x, subExpr1), Exp(Complexes, two)), one, n))
# Out:
# expr: (x_{1} in Complexes^{2}) and ..(x_{_a} in Complexes^{2}).. and (x_{n} in Complexes^{2})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1} \in \mathbb{C}^{2}\right) \land \ldots \land \left(x_{n} \in \mathbb{C}^{2}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_{1} in Complexes^{2}) and ..(x_{_a} in Complexes^{2}).. and (x_{n} in Complexes^{2})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (x_{1} in Complexes^{2}, ..x_{_a} in Complexes^{2}.., x_{n} in Complexes^{2})
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x_{1} in Complexes^{2}), ..(x_{_a} in Complexes^{2}).., (x_{n} in Complexes^{2})
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. _a -> (x_{_a} in Complexes^{2})
#    core type: Lambda
#    parameter: 13
#    body: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. n
#    core type: Variable
#    sub-expressions:
# 7. x_{_a} in Complexes^{2}
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x_{_a}, Complexes^{2})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. x_{_a}
#     core type: IndexedVar
# variable: 12
# index: 13
# 11. Complexes^{2}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. _a
#     core type: Variable
#     sub-expressions:
# 14. Exp
#     core type: Literal
#     sub-expressions:
# 15. (Complexes, 2)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. Complexes
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
