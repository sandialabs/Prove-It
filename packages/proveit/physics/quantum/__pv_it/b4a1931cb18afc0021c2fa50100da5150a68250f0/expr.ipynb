# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import alpha, x
from proveit.linalg import ScalarProd
from proveit.logic import InSet
from proveit.number import Complexes, Exp, two

# %%
# build up the expression from sub-expressions
expr = InSet(ScalarProd(alpha, x), Exp(Complexes, two))
# Out:
# expr: (alpha * x) in Complexes^{2}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\alpha \thinspace x\right) \in \mathbb{C}^{2}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (alpha * x) in Complexes^{2}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (alpha * x, Complexes^{2})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. alpha * x
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. Complexes^{2}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (alpha, x)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. Exp
#    core type: Literal
#    sub-expressions:
# 8. (Complexes, 2)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. alpha
#    core type: Variable
#    sub-expressions:
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. Complexes
#     core type: Literal
#     sub-expressions:
# 12. 2
#     core type: Literal
#     sub-expressions:
