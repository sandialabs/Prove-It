# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#registerQubitBornRule">registerQubitBornRule</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum._theorems_ import registerQubitBornRule

# %%
# check that the built expression is the same as the stored expression
# %check_expr registerQubitBornRule
# Out:
# Passed sanity check: built 'registerQubitBornRule' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(registerQubitBornRule.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{k \in \{0 \dots 2^{n} - 1\}}~\left[\forall_{\Psi, m~|~\lvert \Psi \rangle \in \left(\mathbb{C}^{2}\right)^{\otimes n}, m = \mathcal{M}(\lvert \Psi \rangle)}~\left(Pr_{m}[m = k] = \left|{_{n}}\langle k \rvert \thinspace \lvert \Psi \rangle\right|^{2}\right)\right]\right]

# %%
# display the expression information
registerQubitBornRule.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{k in {0...2^{n} - 1}} [forall_{Psi, m | |Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉)} (Pr_{m}[m = k] = |{n}_〈k| . |Psi〉|^{2})]]
#    core type: Operation
#    operator: 11
#    operand: 1
# 1. n -> {forall_{k in {0...2^{n} - 1}} [forall_{Psi, m | |Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉)} (Pr_{m}[m = k] = |{n}_〈k| . |Psi〉|^{2})] if n in NaturalsPos.
#    core type: Lambda
#    parameter: 68
#    body: 2
# 2. {forall_{k in {0...2^{n} - 1}} [forall_{Psi, m | |Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉)} (Pr_{m}[m = k] = |{n}_〈k| . |Psi〉|^{2})] if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{k in {0...2^{n} - 1}} [forall_{Psi, m | |Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉)} (Pr_{m}[m = k] = |{n}_〈k| . |Psi〉|^{2})]
#    core type: Operation
#    operator: 11
#    operand: 5
# 4. n in NaturalsPos
#    core type: Operation
#    operator: 35
#    operands: 6
# ...
