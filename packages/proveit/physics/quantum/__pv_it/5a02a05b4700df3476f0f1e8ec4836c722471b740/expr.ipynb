# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Operation
from proveit._common_ import U, f, k, l, n
from proveit.linalg import MatrixProd, SU, ScalarProd
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Exp, Interval, Mult, NaturalsPos, Neg, Sum, one, two, zero
from proveit.physics.quantum import RegisterBra, RegisterKet

# %%
# build up the expression from sub-expressions
subExpr1 = [k]
subExpr2 = Operation(f, k)
subExpr3 = RegisterBra(l, n)
subExpr4 = RegisterKet(k, n)
subExpr5 = Exp(two, n)
subExpr6 = Interval(zero, Add(subExpr5, Neg(one)))
expr = Lambda(n, Conditional(Forall([U], Forall([l], Forall([f], Equals(MatrixProd(subExpr3, MatrixProd(U, Sum(subExpr1, ScalarProd(subExpr2, subExpr4), domain = subExpr6))), Sum(subExpr1, Mult(subExpr2, MatrixProd(subExpr3, U, subExpr4)), domain = subExpr6))), domain = subExpr6), domain = SU(subExpr5)), InSet(n, NaturalsPos)))
# Out:
# expr: n -> {forall_{U in [SU](2^{n})} [forall_{l in {0...2^{n} - 1}} [forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))]] if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{U \in \left[SU\right]\left(2^{n}\right)}~\left[\forall_{l \in \{0 \dots 2^{n} - 1\}}~\left[\forall_{f}~\left(\left({_{n}}\langle l \rvert \thinspace \left(U \thinspace \left(\sum_{k=0}^{2^{n} - 1} \left(\left[f\right]\left(k\right) \thinspace \lvert k \rangle_{n}\right)\right)\right)\right) = \left(\sum_{k=0}^{2^{n} - 1} \left(\left[f\right]\left(k\right) \cdot \left({_{n}}\langle l \rvert \thinspace U \thinspace \lvert k \rangle_{n}\right)\right)\right)\right)\right]\right] \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{U in [SU](2^{n})} [forall_{l in {0...2^{n} - 1}} [forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))]] if n in NaturalsPos.
#    core type: Lambda
#    parameter: 71
#    body: 1
# 1. {forall_{U in [SU](2^{n})} [forall_{l in {0...2^{n} - 1}} [forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))]] if n in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{U in [SU](2^{n})} [forall_{l in {0...2^{n} - 1}} [forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))]]
#    core type: Operation
#    operator: 17
#    operand: 4
# 3. n in NaturalsPos
#    core type: Operation
#    operator: 46
#    operands: 5
# ...
