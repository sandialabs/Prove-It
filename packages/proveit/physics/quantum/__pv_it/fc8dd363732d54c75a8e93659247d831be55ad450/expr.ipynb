# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Operation
from proveit._common_ import U, f, k, l, n
from proveit.linalg import MatrixProd, ScalarProd
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Exp, Interval, Mult, Neg, Sum, one, two, zero
from proveit.physics.quantum import RegisterBra, RegisterKet

# %%
# build up the expression from sub-expressions
subExpr1 = [k]
subExpr2 = Operation(f, k)
subExpr3 = RegisterBra(l, n)
subExpr4 = RegisterKet(k, n)
subExpr5 = Interval(zero, Add(Exp(two, n), Neg(one)))
expr = Lambda(l, Conditional(Forall([f], Equals(MatrixProd(subExpr3, MatrixProd(U, Sum(subExpr1, ScalarProd(subExpr2, subExpr4), domain = subExpr5))), Sum(subExpr1, Mult(subExpr2, MatrixProd(subExpr3, U, subExpr4)), domain = subExpr5))), InSet(l, subExpr5)))
# Out:
# expr: l -> {forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n})))) if l in {0...2^{n} - 1}.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# l \mapsto \left\{\forall_{f}~\left(\left({_{n}}\langle l \rvert \thinspace \left(U \thinspace \left(\sum_{k=0}^{2^{n} - 1} \left(\left[f\right]\left(k\right) \thinspace \lvert k \rangle_{n}\right)\right)\right)\right) = \left(\sum_{k=0}^{2^{n} - 1} \left(\left[f\right]\left(k\right) \cdot \left({_{n}}\langle l \rvert \thinspace U \thinspace \lvert k \rangle_{n}\right)\right)\right)\right) \textrm{ if } l \in \{0 \dots 2^{n} - 1\}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. l -> {forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n})))) if l in {0...2^{n} - 1}.
#    core type: Lambda
#    parameter: 40
#    body: 1
# 1. {forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n})))) if l in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. l in {0...2^{n} - 1}
#    core type: Operation
#    operator: 33
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. f -> (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))
#    core type: Lambda
#    parameter: 41
#    body: 7
# 6. (l, {0...2^{n} - 1})
#    core type: ExprTuple
#    sub-expressions: 40, 39
# 7. ({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n})))
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. ({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n}))), Sum_{k=0}^{2^{n} - 1} [f](k) * ({n}_〈l| . U . |k〉_{n}))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. {n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))
#     core type: Operation
#     operator: 25
#     operands: 12
# 11. Sum_{k=0}^{2^{n} - 1} [f](k) * ({n}_〈l| . U . |k〉_{n})
#     core type: Operation
#     operator: 21
#     operand: 13
# 12. ({n}_〈l|, U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))
#     core type: ExprTuple
#     sub-expressions: 29, 14
# 13. k -> {[f](k) * ({n}_〈l| . U . |k〉_{n}) if k in {0...2^{n} - 1}.
#     core type: Lambda
#     parameter: 46
#     body: 15
# 14. U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n}))
#     core type: Operation
#     operator: 25
#     operands: 16
# 15. {[f](k) * ({n}_〈l| . U . |k〉_{n}) if k in {0...2^{n} - 1}.
#     core type: Conditional
#     value: 17
#     condition: 28
# 16. (U, Sum_{k=0}^{2^{n} - 1} [f](k) * |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 30, 18
# 17. [f](k) * ({n}_〈l| . U . |k〉_{n})
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. Sum_{k=0}^{2^{n} - 1} [f](k) * |k〉_{n}
#     core type: Operation
#     operator: 21
#     operand: 22
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. ([f](k), {n}_〈l| . U . |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 37, 23
# 21. Sum
#     core type: Literal
#     sub-expressions:
# 22. k -> {[f](k) * |k〉_{n} if k in {0...2^{n} - 1}.
#     core type: Lambda
#     parameter: 46
#     body: 24
# 23. {n}_〈l| . U . |k〉_{n}
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. {[f](k) * |k〉_{n} if k in {0...2^{n} - 1}.
#     core type: Conditional
#     value: 27
#     condition: 28
# 25. .
#     core type: Literal
#     sub-expressions:
# 26. ({n}_〈l|, U, |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 29, 30, 38
# 27. [f](k) * |k〉_{n}
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. k in {0...2^{n} - 1}
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. {n}_〈l|
#     core type: Operation
#     operator: 35
#     operands: 36
# 30. U
#     core type: Variable
#     sub-expressions:
# 31. *
#     core type: Literal
#     sub-expressions:
# 32. ([f](k), |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (k, {0...2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 46, 39
# 35. REGISTER_BRA
#     core type: Literal
#     sub-expressions:
# 36. (l, n)
#     core type: ExprTuple
#     sub-expressions: 40, 58
# 37. [f](k)
#     core type: Operation
#     operator: 41
#     operand: 46
# 38. |k〉_{n}
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. {0...2^{n} - 1}
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. l
#     core type: Variable
#     sub-expressions:
# 41. f
#     core type: Variable
#     sub-expressions:
# 42. REGISTER_KET
#     core type: Literal
#     sub-expressions:
# 43. (k, n)
#     core type: ExprTuple
#     sub-expressions: 46, 58
# 44. Interval
#     core type: Literal
#     sub-expressions:
# 45. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 46. k
#     core type: Variable
#     sub-expressions:
# 47. 0
#     core type: Literal
#     sub-expressions:
# 48. 2^{n} - 1
#     core type: Operation
#     operator: 49
#     operands: 50
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 51. 2^{n}
#     core type: Operation
#     operator: 53
#     operands: 54
# 52. -1
#     core type: Operation
#     operator: 55
#     operand: 56
# 53. Exp
#     core type: Literal
#     sub-expressions:
# 54. (2, n)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 55. -
#     core type: Literal
#     sub-expressions:
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. 2
#     core type: Literal
#     sub-expressions:
# 58. n
#     core type: Variable
#     sub-expressions:
