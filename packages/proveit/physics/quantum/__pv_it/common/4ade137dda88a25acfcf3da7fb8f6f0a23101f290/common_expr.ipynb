# %% [markdown]
# Common <a class="ProveItLink" href="../../../_common_.ipynb#WIRE_DN">WIRE_DN</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Literal.html">Literal</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum import WIRE_DN

# %%
# check that the built expression is the same as the stored expression
assert WIRE_DN == stored_expr
assert WIRE_DN._style_id == stored_expr._style_id
print("Passed sanity check: WIRE_DN matches stored_expr")
# Out:
# Passed sanity check: WIRE_DN matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(WIRE_DN.latex())
# Out:
# WIRE\_DN

# %%
# display the expression information
WIRE_DN.expr_info()
# Out:
# 0. WIRE\_DN
#    core type: Literal
#    sub-expressions:
