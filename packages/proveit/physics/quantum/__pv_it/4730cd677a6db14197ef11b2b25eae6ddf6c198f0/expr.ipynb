# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import alpha, x
from proveit.linalg import ScalarProd
from proveit.logic import Forall, InSet
from proveit.number import Complexes, Exp, two

# %%
# build up the expression from sub-expressions
expr = Forall([alpha], InSet(ScalarProd(alpha, x), Exp(Complexes, two)), domain = Complexes)
# Out:
# expr: forall_{alpha in Complexes} ((alpha * x) in Complexes^{2})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{\alpha \in \mathbb{C}}~\left(\left(\alpha \thinspace x\right) \in \mathbb{C}^{2}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{alpha in Complexes} ((alpha * x) in Complexes^{2})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. alpha -> {(alpha * x) in Complexes^{2} if alpha in Complexes.
#    core type: Lambda
#    parameter: 15
#    body: 3
# 3. {(alpha * x) in Complexes^{2} if alpha in Complexes.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (alpha * x) in Complexes^{2}
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. alpha in Complexes
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (alpha * x, Complexes^{2})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (alpha, Complexes)
#    core type: ExprTuple
#    sub-expressions: 15, 17
# 9. alpha * x
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. Complexes^{2}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (alpha, x)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. Exp
#     core type: Literal
#     sub-expressions:
# 14. (Complexes, 2)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. alpha
#     core type: Variable
#     sub-expressions:
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. Complexes
#     core type: Literal
#     sub-expressions:
# 18. 2
#     core type: Literal
#     sub-expressions:
