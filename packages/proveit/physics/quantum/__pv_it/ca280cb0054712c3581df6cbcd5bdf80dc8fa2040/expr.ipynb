# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import Psi, k, n
from proveit.linalg import MatrixProd, TensorExp
from proveit.logic import InSet
from proveit.number import Complexes, Exp, two
from proveit.physics.quantum import Ket, RegisterBra

# %%
# build up the expression from sub-expressions
subExpr1 = Ket(Psi)
expr = Conditional(InSet(MatrixProd(RegisterBra(k, n), subExpr1), Complexes), InSet(subExpr1, TensorExp([Exp(Complexes, two)], n)))
# Out:
# expr: {{n}_〈k|Psi〉 in Complexes if |Psi〉 in (Complexes^{2})^{otimes n}.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{{_{n}}\langle k \rvert\Psi \rangle \in \mathbb{C} \textrm{ if } \lvert \Psi \rangle \in \left(\mathbb{C}^{2}\right)^{\otimes n}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {{n}_〈k|Psi〉 in Complexes if |Psi〉 in (Complexes^{2})^{otimes n}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. {n}_〈k|Psi〉 in Complexes
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. |Psi〉 in (Complexes^{2})^{otimes n}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ({n}_〈k|Psi〉, Complexes)
#    core type: ExprTuple
#    sub-expressions: 6, 24
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (|Psi〉, (Complexes^{2})^{otimes n})
#    core type: ExprTuple
#    sub-expressions: 13, 7
# 6. {n}_〈k| . |Psi〉
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (Complexes^{2})^{otimes n}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. .
#    core type: Literal
#    sub-expressions:
# 9. ({n}_〈k|, |Psi〉)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. otimes
#     core type: Literal
#     sub-expressions:
# 11. ((Complexes^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 14, 21
# 12. {n}_〈k|
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. |Psi〉
#     core type: Operation
#     operator: 17
#     operand: 18
# 14. (Complexes^{2})
#     core type: ExprTuple
#     sub-expressions: 19
# 15. REGISTER_BRA
#     core type: Literal
#     sub-expressions:
# 16. (k, n)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. KET
#     core type: Literal
#     sub-expressions:
# 18. Psi
#     core type: Variable
#     sub-expressions:
# 19. Complexes^{2}
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. k
#     core type: Variable
#     sub-expressions:
# 21. n
#     core type: Variable
#     sub-expressions:
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (Complexes, 2)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. Complexes
#     core type: Literal
#     sub-expressions:
# 25. 2
#     core type: Literal
#     sub-expressions:
