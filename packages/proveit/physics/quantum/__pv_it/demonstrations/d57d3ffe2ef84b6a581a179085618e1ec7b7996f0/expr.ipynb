# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.circuit.MultiQubitGate.html">MultiQubitGate</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Literal
from proveit.logic import Set
from proveit.numbers import three, two
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = MultiQubitGate(Literal("MEAS", theory = "proveit.physics.quantum"), Set(two, three))
# Out:
# expr: MultiQubitGate(MEAS, {2, 3})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & MEAS
# } \hspace{2em}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. MultiQubitGate(MEAS, {2, 3})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 2. (MEAS, {2, 3})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. MEAS
#    core type: Literal
#    sub-expressions:
# 4. {2, 3}
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. Set
#    core type: Literal
#    sub-expressions:
# 6. (2, 3)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. 2
#    core type: Literal
#    sub-expressions:
# 8. 3
#    core type: Literal
#    sub-expressions:
