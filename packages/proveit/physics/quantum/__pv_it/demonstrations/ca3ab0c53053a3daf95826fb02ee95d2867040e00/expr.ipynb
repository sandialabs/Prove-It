# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, i, j, m, n
from proveit.core_expr_types.expr_arrays import Dij, Sij
from proveit.numbers import one
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = ExprRange(i, [ExprRange(j, MultiQubitGate(Dij, Sij), one, n)], one, m)
# Out:
# expr: (MultiQubitGate(D_{1, 1}, S_{1, 1}), ..MultiQubitGate(D_{1, j}, S_{1, j}).., MultiQubitGate(D_{1, n}, S_{1, n})), ..(MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n})).., (MultiQubitGate(D_{m, 1}, S_{m, 1}), ..MultiQubitGate(D_{m, j}, S_{m, j}).., MultiQubitGate(D_{m, n}, S_{m, n}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{1, 1}{\Big \{} S_{1, 1}}
# } \hspace{2em}, \ldots, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{1, n}{\Big \{} S_{1, n}}
# } \hspace{2em}\right), \ldots, \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{m, 1}{\Big \{} S_{m, 1}}
# } \hspace{2em}, \ldots, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{m, n}{\Big \{} S_{m, n}}
# } \hspace{2em}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (MultiQubitGate(D_{1, 1}, S_{1, 1}), ..MultiQubitGate(D_{1, j}, S_{1, j}).., MultiQubitGate(D_{1, n}, S_{1, n})), ..(MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n})).., (MultiQubitGate(D_{m, 1}, S_{m, 1}), ..MultiQubitGate(D_{m, j}, S_{m, j}).., MultiQubitGate(D_{m, n}, S_{m, n}))
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 6
#    end_index: 2
# 1. i -> (MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n}))
#    core type: Lambda
#    parameter: 16
#    body: 3
# 2. m
#    core type: Variable
#    sub-expressions:
# 3. (MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n}))
#    core type: ExprTuple
#    sub-expressions: 4
# 4. MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n})
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 5. j -> MultiQubitGate(D_{i, j}, S_{i, j})
#    core type: Lambda
#    parameter: 17
#    body: 8
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. n
#    core type: Variable
#    sub-expressions:
# 8. MultiQubitGate(D_{i, j}, S_{i, j})
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 10. (D_{i, j}, S_{i, j})
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. D_{i, j}
#     core type: IndexedVar
# variable: 13
# indices: 15
# 12. S_{i, j}
#     core type: IndexedVar
# variable: 14
# indices: 15
# 13. D
#     core type: Variable
#     sub-expressions:
# 14. S
#     core type: Variable
#     sub-expressions:
# 15. (i, j)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. i
#     core type: Variable
#     sub-expressions:
# 17. j
#     core type: Variable
#     sub-expressions:
