# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.circuit.MultiQubitGate.html">MultiQubitGate</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, IndexedVar, R, a, i
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = [i, a]
expr = MultiQubitGate(IndexedVar(A, sub_expr1), IndexedVar(R, sub_expr1))
# Out:
# expr: MultiQubitGate(A_{i, a}, R_{i, a})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{i, a}{\Big \{} R_{i, a}}
# } \hspace{2em}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. MultiQubitGate(A_{i, a}, R_{i, a})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 2. (A_{i, a}, R_{i, a})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A_{i, a}
#    core type: IndexedVar
# variable: 5
# indices: 7
# 4. R_{i, a}
#    core type: IndexedVar
# variable: 6
# indices: 7
# 5. A
#    core type: Variable
#    sub-expressions:
# 6. R
#    core type: Variable
#    sub-expressions:
# 7. (i, a)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. i
#    core type: Variable
#    sub-expressions:
# 9. a
#    core type: Variable
#    sub-expressions:
