# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, i, j, m, n
from proveit.core_expr_types.expr_arrays import Aij
from proveit.numbers import one
from proveit.physics.quantum import Gate

# %%
# build up the expression from sub-expressions
expr = ExprRange(i, [ExprRange(j, Gate(Aij), one, n)], one, m)
# Out:
# expr: (Gate(A_{1, 1}), ..Gate(A_{1, j}).., Gate(A_{1, n})), ..(Gate(A_{i, 1}), ..Gate(A_{i, j}).., Gate(A_{i, n})).., (Gate(A_{m, 1}), ..Gate(A_{m, j}).., Gate(A_{m, n}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}}
# } \hspace{2em}, \ldots, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, n}}
# } \hspace{2em}\right), \ldots, \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{m, 1}}
# } \hspace{2em}, \ldots, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{m, n}}
# } \hspace{2em}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Gate(A_{1, 1}), ..Gate(A_{1, j}).., Gate(A_{1, n})), ..(Gate(A_{i, 1}), ..Gate(A_{i, j}).., Gate(A_{i, n})).., (Gate(A_{m, 1}), ..Gate(A_{m, j}).., Gate(A_{m, n}))
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 6
#    end_index: 2
# 1. i -> (Gate(A_{i, 1}), ..Gate(A_{i, j}).., Gate(A_{i, n}))
#    core type: Lambda
#    parameter: 13
#    body: 3
# 2. m
#    core type: Variable
#    sub-expressions:
# 3. (Gate(A_{i, 1}), ..Gate(A_{i, j}).., Gate(A_{i, n}))
#    core type: ExprTuple
#    sub-expressions: 4
# 4. Gate(A_{i, 1}), ..Gate(A_{i, j}).., Gate(A_{i, n})
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 5. j -> Gate(A_{i, j})
#    core type: Lambda
#    parameter: 14
#    body: 8
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. n
#    core type: Variable
#    sub-expressions:
# 8. Gate(A_{i, j})
#    core type: Operation
#    operator: 9
#    operand: 10
# 9. GATE
#    core type: Literal
#    sub-expressions:
# 10. A_{i, j}
#     core type: IndexedVar
# variable: 11
# indices: 12
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. (i, j)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. i
#     core type: Variable
#     sub-expressions:
# 14. j
#     core type: Variable
#     sub-expressions:
