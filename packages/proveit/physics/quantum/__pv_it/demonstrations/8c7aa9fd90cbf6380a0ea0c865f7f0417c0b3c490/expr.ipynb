# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import one, three, two
from proveit.physics.quantum import Gate, H, Input, Output, X, ket0, ket1, ket_minus, ket_plus
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(H)
sub_expr2 = Gate(X)
sub_expr3 = Input(ket1)
sub_expr4 = Output(ket_minus)
sub_expr5 = MultiQubitGate(X, Set(one, three))
sub_expr6 = MultiQubitGate(H, Set(two, three))
expr = ExprArray([Input(ket0), sub_expr1, sub_expr5, sub_expr1, Output(ket_plus)], [sub_expr3, sub_expr6, MultiQubitGate(H, Set(two)), sub_expr2, sub_expr4], [sub_expr3, sub_expr6, sub_expr5, sub_expr2, sub_expr4])
# Out:
# expr: Input(|0〉) & Gate(H) & MultiQubitGate(X, {1, 3}) & Gate(H) & Output(|+〉)  \\
#   Input(|1〉) & MultiQubitGate(H, {2, 3}) & MultiQubitGate(H, {2}) & Gate(X) & Output(|-〉)  \\
#   Input(|1〉) & MultiQubitGate(H, {2, 3}) & MultiQubitGate(X, {1, 3}) & Gate(X) & Output(|-〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {ccccc}
#  \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & X
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert + \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & H
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H{\Big \{} \left\{2\right\}}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{X}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert - \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & H
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & X
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{X}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert - \rangle} \qw
# } \hspace{2em} \end{array}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Input(|0〉) & Gate(H) & MultiQubitGate(X, {1, 3}) & Gate(H) & Output(|+〉)  \\
#   Input(|1〉) & MultiQubitGate(H, {2, 3}) & MultiQubitGate(H, {2}) & Gate(X) & Output(|-〉)  \\
#   Input(|1〉) & MultiQubitGate(H, {2, 3}) & MultiQubitGate(X, {1, 3}) & Gate(X) & Output(|-〉)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. (Input(|0〉), Gate(H), MultiQubitGate(X, {1, 3}), Gate(H), Output(|+〉))
#    core type: ExprTuple
#    sub-expressions: 4, 5, 10, 5, 6
# 2. (Input(|1〉), MultiQubitGate(H, {2, 3}), MultiQubitGate(H, {2}), Gate(X), Output(|-〉))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 7, 11, 12
# 3. (Input(|1〉), MultiQubitGate(H, {2, 3}), MultiQubitGate(X, {1, 3}), Gate(X), Output(|-〉))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12
# 4. [INPUT](|0〉)
#    core type: Operation
#    operator: 16
#    operand: 13
# 5. Gate(H)
#    core type: Operation
#    operator: 21
#    operand: 27
# 6. [OUTPUT](|+〉)
#    core type: Operation
#    operator: 22
#    operand: 14
# 7. MultiQubitGate(H, {2})
#    core type: Operation
#    operator: 19
#    operands: 15
# 8. [INPUT](|1〉)
#    core type: Operation
#    operator: 16
#    operand: 17
# 9. MultiQubitGate(H, {2, 3})
#    core type: Operation
#    operator: 19
#    operands: 18
# 10. MultiQubitGate(X, {1, 3})
#     core type: Operation
#     operator: 19
#     operands: 20
# 11. Gate(X)
#     core type: Operation
#     operator: 21
#     operand: 29
# 12. [OUTPUT](|-〉)
#     core type: Operation
#     operator: 22
#     operand: 23
# 13. |0〉
#     core type: Operation
#     operator: 31
#     operand: 24
# 14. |+〉
#     core type: Operation
#     operator: 31
#     operand: 25
# 15. (H, {2})
#     core type: ExprTuple
#     sub-expressions: 27, 26
# 16. INPUT
#     core type: Literal
#     sub-expressions:
# 17. |1〉
#     core type: Operation
#     operator: 31
#     operand: 37
# 18. (H, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 19. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 20. (X, {1, 3})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 21. GATE
#     core type: Literal
#     sub-expressions:
# 22. OUTPUT
#     core type: Literal
#     sub-expressions:
# 23. |-〉
#     core type: Operation
#     operator: 31
#     operand: 32
# 24. 0
#     core type: Literal
#     sub-expressions:
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. {2}
#     core type: Operation
#     operator: 34
#     operand: 36
# 27. H
#     core type: Literal
#     sub-expressions:
# 28. {2, 3}
#     core type: Operation
#     operator: 34
#     operands: 33
# 29. X
#     core type: Literal
#     sub-expressions:
# 30. {1, 3}
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. KET
#     core type: Literal
#     sub-expressions:
# 32. -
#     core type: Literal
#     sub-expressions:
# 33. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 36, 38
# 34. Set
#     core type: Literal
#     sub-expressions:
# 35. (1, 3)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 36. 2
#     core type: Literal
#     sub-expressions:
# 37. 1
#     core type: Literal
#     sub-expressions:
# 38. 3
#     core type: Literal
#     sub-expressions:
