# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, k, x
from proveit.core_expr_types import Len
from proveit.numbers import one, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(two, Len([ExprRange(k, ExprRange(x, [k, x], one, two), one, one)]))
# Out:
# expr: (2, |((1, 1), ..(1, x).., (1, 2), ....(k, 1), ..(k, x).., (k, 2)...., (1, 1), ..(1, x).., (1, 2))|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2, |\left(\left(1, 1\right), \ldots, \left(1, 2\right), \ldots\ldots, \left(1, 1\right), \ldots, \left(1, 2\right)\right)|\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2, |((1, 1), ..(1, x).., (1, 2), ....(k, 1), ..(k, x).., (k, 2)...., (1, 1), ..(1, x).., (1, 2))|)
#    core type: ExprTuple
#    sub-expressions: 10, 1
# 1. |((1, 1), ..(1, x).., (1, 2), ....(k, 1), ..(k, x).., (k, 2)...., (1, 1), ..(1, x).., (1, 2))|
#    core type: Operation
#    operator: 2
#    operand: 4
# 2. length
#    core type: Literal
#    sub-expressions:
# 3. (((1, 1), ..(1, x).., (1, 2), ....(k, 1), ..(k, x).., (k, 2)...., (1, 1), ..(1, x).., (1, 2)))
#    core type: ExprTuple
#    sub-expressions: 4
# 4. ((1, 1), ..(1, x).., (1, 2), ....(k, 1), ..(k, x).., (k, 2)...., (1, 1), ..(1, x).., (1, 2))
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (1, 1), ..(1, x).., (1, 2), ....(k, 1), ..(k, x).., (k, 2)...., (1, 1), ..(1, x).., (1, 2)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 9
#    end_index: 9
# 6. k -> (k, 1), ..(k, x).., (k, 2)
#    core type: Lambda
#    parameter: 12
#    body: 7
# 7. (k, 1), ..(k, x).., (k, 2)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 8. x -> (k, x)
#    core type: Lambda
#    parameter: 13
#    body: 11
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. 2
#     core type: Literal
#     sub-expressions:
# 11. (k, x)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. k
#     core type: Variable
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
