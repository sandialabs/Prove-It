# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import eight, five, four, one, seven, six, three, two
from proveit.physics.quantum import CONTROL, Input, Output, Z, ket0, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Input(ket0)
sub_expr2 = Set(one, two)
sub_expr3 = Output(ket0)
sub_expr4 = Set(three, four)
sub_expr5 = Input(ket1)
sub_expr6 = Output(ket1)
sub_expr7 = Set(five, six)
sub_expr8 = Set(seven, eight)
sub_expr9 = MultiQubitGate(CONTROL, sub_expr2)
sub_expr10 = MultiQubitGate(Z, sub_expr2)
sub_expr11 = MultiQubitGate(CONTROL, sub_expr4)
sub_expr12 = MultiQubitGate(Z, sub_expr4)
sub_expr13 = MultiQubitGate(CONTROL, sub_expr7)
sub_expr14 = MultiQubitGate(Z, sub_expr7)
sub_expr15 = MultiQubitGate(CONTROL, sub_expr8)
sub_expr16 = MultiQubitGate(Z, sub_expr8)
expr = ExprArray([sub_expr1, sub_expr9, sub_expr9, sub_expr3], [sub_expr1, sub_expr10, sub_expr10, sub_expr3], [sub_expr1, sub_expr11, sub_expr11, sub_expr3], [sub_expr5, sub_expr12, sub_expr12, sub_expr6], [sub_expr5, sub_expr13, sub_expr13, sub_expr6], [sub_expr1, sub_expr14, sub_expr14, sub_expr3], [sub_expr5, sub_expr15, sub_expr15, sub_expr6], [sub_expr5, sub_expr16, sub_expr16, sub_expr6])
# Out:
# expr: Input(|0〉) & MultiQubitGate(CONTROL, {1, 2}) & MultiQubitGate(CONTROL, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {1, 2}) & MultiQubitGate(Z, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {3, 4}) & MultiQubitGate(CONTROL, {3, 4}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {3, 4}) & MultiQubitGate(Z, {3, 4}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(CONTROL, {5, 6}) & MultiQubitGate(CONTROL, {5, 6}) & Output(|1〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {5, 6}) & MultiQubitGate(Z, {5, 6}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(CONTROL, {7, 8}) & MultiQubitGate(CONTROL, {7, 8}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {7, 8}) & MultiQubitGate(Z, {7, 8}) & Output(|1〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {cccc}
#  \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em} \end{array}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Input(|0〉) & MultiQubitGate(CONTROL, {1, 2}) & MultiQubitGate(CONTROL, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {1, 2}) & MultiQubitGate(Z, {1, 2}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {3, 4}) & MultiQubitGate(CONTROL, {3, 4}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {3, 4}) & MultiQubitGate(Z, {3, 4}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(CONTROL, {5, 6}) & MultiQubitGate(CONTROL, {5, 6}) & Output(|1〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {5, 6}) & MultiQubitGate(Z, {5, 6}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(CONTROL, {7, 8}) & MultiQubitGate(CONTROL, {7, 8}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {7, 8}) & MultiQubitGate(Z, {7, 8}) & Output(|1〉)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5, 6, 7, 8
# 1. (Input(|0〉), MultiQubitGate(CONTROL, {1, 2}), MultiQubitGate(CONTROL, {1, 2}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 14, 9, 9, 16
# 2. (Input(|0〉), MultiQubitGate(Z, {1, 2}), MultiQubitGate(Z, {1, 2}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 14, 10, 10, 16
# 3. (Input(|0〉), MultiQubitGate(CONTROL, {3, 4}), MultiQubitGate(CONTROL, {3, 4}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 14, 11, 11, 16
# 4. (Input(|1〉), MultiQubitGate(Z, {3, 4}), MultiQubitGate(Z, {3, 4}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 18, 12, 12, 20
# 5. (Input(|1〉), MultiQubitGate(CONTROL, {5, 6}), MultiQubitGate(CONTROL, {5, 6}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 18, 13, 13, 20
# 6. (Input(|0〉), MultiQubitGate(Z, {5, 6}), MultiQubitGate(Z, {5, 6}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 14, 15, 15, 16
# 7. (Input(|1〉), MultiQubitGate(CONTROL, {7, 8}), MultiQubitGate(CONTROL, {7, 8}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 18, 17, 17, 20
# 8. (Input(|1〉), MultiQubitGate(Z, {7, 8}), MultiQubitGate(Z, {7, 8}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 18, 19, 19, 20
# 9. MultiQubitGate(CONTROL, {1, 2})
#    core type: Operation
#    operator: 30
#    operands: 21
# 10. MultiQubitGate(Z, {1, 2})
#     core type: Operation
#     operator: 30
#     operands: 22
# 11. MultiQubitGate(CONTROL, {3, 4})
#     core type: Operation
#     operator: 30
#     operands: 23
# 12. MultiQubitGate(Z, {3, 4})
#     core type: Operation
#     operator: 30
#     operands: 24
# 13. MultiQubitGate(CONTROL, {5, 6})
#     core type: Operation
#     operator: 30
#     operands: 25
# 14. [INPUT](|0〉)
#     core type: Operation
#     operator: 29
#     operand: 27
# 15. MultiQubitGate(Z, {5, 6})
#     core type: Operation
#     operator: 30
#     operands: 26
# 16. [OUTPUT](|0〉)
#     core type: Operation
#     operator: 32
#     operand: 27
# 17. MultiQubitGate(CONTROL, {7, 8})
#     core type: Operation
#     operator: 30
#     operands: 28
# 18. [INPUT](|1〉)
#     core type: Operation
#     operator: 29
#     operand: 33
# 19. MultiQubitGate(Z, {7, 8})
#     core type: Operation
#     operator: 30
#     operands: 31
# 20. [OUTPUT](|1〉)
#     core type: Operation
#     operator: 32
#     operand: 33
# 21. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 38, 34
# 22. (Z, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 39, 34
# 23. (CONTROL, {3, 4})
#     core type: ExprTuple
#     sub-expressions: 38, 35
# 24. (Z, {3, 4})
#     core type: ExprTuple
#     sub-expressions: 39, 35
# 25. (CONTROL, {5, 6})
#     core type: ExprTuple
#     sub-expressions: 38, 36
# 26. (Z, {5, 6})
#     core type: ExprTuple
#     sub-expressions: 39, 36
# 27. |0〉
#     core type: Operation
#     operator: 41
#     operand: 37
# 28. (CONTROL, {7, 8})
#     core type: ExprTuple
#     sub-expressions: 38, 40
# 29. INPUT
#     core type: Literal
#     sub-expressions:
# 30. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 31. (Z, {7, 8})
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 32. OUTPUT
#     core type: Literal
#     sub-expressions:
# 33. |1〉
#     core type: Operation
#     operator: 41
#     operand: 47
# 34. {1, 2}
#     core type: Operation
#     operator: 45
#     operands: 42
# 35. {3, 4}
#     core type: Operation
#     operator: 45
#     operands: 43
# 36. {5, 6}
#     core type: Operation
#     operator: 45
#     operands: 44
# 37. 0
#     core type: Literal
#     sub-expressions:
# 38. CONTROL
#     core type: Literal
#     sub-expressions:
# 39. Z
#     core type: Literal
#     sub-expressions:
# 40. {7, 8}
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. KET
#     core type: Literal
#     sub-expressions:
# 42. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 43. (3, 4)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 44. (5, 6)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 45. Set
#     core type: Literal
#     sub-expressions:
# 46. (7, 8)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. 2
#     core type: Literal
#     sub-expressions:
# 49. 3
#     core type: Literal
#     sub-expressions:
# 50. 4
#     core type: Literal
#     sub-expressions:
# 51. 5
#     core type: Literal
#     sub-expressions:
# 52. 6
#     core type: Literal
#     sub-expressions:
# 53. 7
#     core type: Literal
#     sub-expressions:
# 54. 8
#     core type: Literal
#     sub-expressions:
