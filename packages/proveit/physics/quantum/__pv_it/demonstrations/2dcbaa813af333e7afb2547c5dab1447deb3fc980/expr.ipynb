# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Set
from proveit.numbers import Neg, eight, seven
from proveit.physics.quantum import Input, Output, Z, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Input(ket1), MultiQubitGate(Z, Set(seven, eight)), Output(Neg(ket1)))
# Out:
# expr: (Input(|1〉), MultiQubitGate(Z, {7, 8}), Output(-|1〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{-\lvert 1 \rangle} \qw
# } \hspace{2em}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Input(|1〉), MultiQubitGate(Z, {7, 8}), Output(-|1〉))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. [INPUT](|1〉)
#    core type: Operation
#    operator: 4
#    operand: 12
# 2. MultiQubitGate(Z, {7, 8})
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. [OUTPUT](-|1〉)
#    core type: Operation
#    operator: 7
#    operand: 8
# 4. INPUT
#    core type: Literal
#    sub-expressions:
# 5. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 6. (Z, {7, 8})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. OUTPUT
#    core type: Literal
#    sub-expressions:
# 8. -|1〉
#    core type: Operation
#    operator: 11
#    operand: 12
# 9. Z
#    core type: Literal
#    sub-expressions:
# 10. {7, 8}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. -
#     core type: Literal
#     sub-expressions:
# 12. |1〉
#     core type: Operation
#     operator: 15
#     operand: 16
# 13. Set
#     core type: Literal
#     sub-expressions:
# 14. (7, 8)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. KET
#     core type: Literal
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. 7
#     core type: Literal
#     sub-expressions:
# 18. 8
#     core type: Literal
#     sub-expressions:
