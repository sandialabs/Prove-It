# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Set
from proveit.numbers import eight, seven
from proveit.physics.quantum import Gate, I, Input, Output, X, ket0, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(I)
expr = ExprTuple(Input(ket1), sub_expr1, MultiQubitGate(X, Set(seven, eight)), sub_expr1, Output(ket0))
# Out:
# expr: (Input(|1〉), Gate(I), MultiQubitGate(X, {7, 8}), Gate(I), Output(|0〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{I}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & X
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{I}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Input(|1〉), Gate(I), MultiQubitGate(X, {7, 8}), Gate(I), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 1, 3, 2, 3, 4
# 1. [INPUT](|1〉)
#    core type: Operation
#    operator: 5
#    operand: 6
# 2. MultiQubitGate(X, {7, 8})
#    core type: Operation
#    operator: 7
#    operands: 8
# 3. Gate(I)
#    core type: Operation
#    operator: 9
#    operand: 10
# 4. [OUTPUT](|0〉)
#    core type: Operation
#    operator: 11
#    operand: 12
# 5. INPUT
#    core type: Literal
#    sub-expressions:
# 6. |1〉
#    core type: Operation
#    operator: 16
#    operand: 13
# 7. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 8. (X, {7, 8})
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 9. GATE
#    core type: Literal
#    sub-expressions:
# 10. --
#     core type: Literal
#     sub-expressions:
# 11. OUTPUT
#     core type: Literal
#     sub-expressions:
# 12. |0〉
#     core type: Operation
#     operator: 16
#     operand: 17
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. X
#     core type: Literal
#     sub-expressions:
# 15. {7, 8}
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. KET
#     core type: Literal
#     sub-expressions:
# 17. 0
#     core type: Literal
#     sub-expressions:
# 18. Set
#     core type: Literal
#     sub-expressions:
# 19. (7, 8)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. 7
#     core type: Literal
#     sub-expressions:
# 21. 8
#     core type: Literal
#     sub-expressions:
