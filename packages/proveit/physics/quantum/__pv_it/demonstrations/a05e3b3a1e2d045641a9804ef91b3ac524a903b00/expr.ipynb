# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, k, x
from proveit.core_expr_types import Len
from proveit.numbers import one
from proveit.physics.quantum import H

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([H]), Len([ExprRange(k, ExprRange(x, [k, x], one, one), one, one)]))
# Out:
# expr: (|(H)|, |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1))|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(H\right)|, |\left(\left(1, 1\right), \ldots, \left(1, 1\right), \ldots\ldots, \left(1, 1\right), \ldots, \left(1, 1\right)\right)|\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(H)|, |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1))|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(H)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1))|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((H))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. (((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1)))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (H)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. ((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. H
#    core type: Literal
#    sub-expressions:
# 9. (1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 13
#    end_index: 13
# 10. k -> (k, 1), ..(k, x).., (k, 1)
#     core type: Lambda
#     parameter: 15
#     body: 11
# 11. (k, 1), ..(k, x).., (k, 1)
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 13
#     end_index: 13
# 12. x -> (k, x)
#     core type: Lambda
#     parameter: 16
#     body: 14
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. (k, x)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. x
#     core type: Variable
#     sub-expressions:
