# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Set
from proveit.numbers import four, one, three
from proveit.physics.quantum import CLASSICAL_CONTROL, Input, SPACE
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Input(one), MultiQubitGate(CLASSICAL_CONTROL, Set(three, four)), SPACE)
# Out:
# expr: (Input(1), MultiQubitGate(CLASSICAL\_CONTROL, {3, 4}), SPACE)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{1}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \cw
# } \hspace{2em}, SPACE\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Input(1), MultiQubitGate(CLASSICAL\_CONTROL, {3, 4}), SPACE)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. [INPUT](1)
#    core type: Operation
#    operator: 4
#    operand: 5
# 2. MultiQubitGate(CLASSICAL\_CONTROL, {3, 4})
#    core type: Operation
#    operator: 6
#    operands: 7
# 3. SPACE
#    core type: Literal
#    sub-expressions:
# 4. INPUT
#    core type: Literal
#    sub-expressions:
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 7. (CLASSICAL\_CONTROL, {3, 4})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. CLASSICAL\_CONTROL
#    core type: Literal
#    sub-expressions:
# 9. {3, 4}
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. Set
#     core type: Literal
#     sub-expressions:
# 11. (3, 4)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. 3
#     core type: Literal
#     sub-expressions:
# 13. 4
#     core type: Literal
#     sub-expressions:
