# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import And, Implies, Set
from proveit.numbers import one
from proveit.physics.quantum import H, Input, Output, ket_psi
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv, IdentityOp, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one)
sub_expr2 = MultiQubitGate(H, sub_expr1)
sub_expr3 = MultiQubitGate(IdentityOp(explicit = True), sub_expr1)
sub_expr4 = MultiQubitGate(Input(ket_psi), sub_expr1)
sub_expr5 = MultiQubitGate(Output(ket_psi), sub_expr1)
expr = Implies(And(CircuitEquiv(Circuit(ExprArray([sub_expr2, sub_expr2])), Circuit(ExprArray([sub_expr3]))), Circuit(ExprArray([sub_expr4, sub_expr2, sub_expr2, sub_expr5]))), Circuit(ExprArray([sub_expr4, sub_expr3, sub_expr5]))).with_wrapping_at(2)
# Out:
# expr: (( MultiQubitGate(H, {1})  & MultiQubitGate(H, {1}) equiv  MultiQubitGate(I, {1})) and  MultiQubitGate(Input(|psi〉), {1})  & MultiQubitGate(H, {1})  & MultiQubitGate(H, {1})  & MultiQubitGate(Output(|psi〉), {1})) =>  \\  MultiQubitGate(Input(|psi〉), {1})  & MultiQubitGate(I, {1})  & MultiQubitGate(Output(|psi〉), {1})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H{\Big \{} \left\{1\right\}} & \gate{H{\Big \{} \left\{1\right\}}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{I{\Big \{} \left\{1\right\}}
# } \hspace{2em}\right) \land \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{Input(\lvert \psi \rangle){\Big \{} \left\{1\right\}} & \gate{H{\Big \{} \left\{1\right\}} & \gate{H{\Big \{} \left\{1\right\}} & \gate{Output(\lvert \psi \rangle){\Big \{} \left\{1\right\}}
# } \hspace{2em}\right) \Rightarrow  \\ \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{Input(\lvert \psi \rangle){\Big \{} \left\{1\right\}} & \gate{I{\Big \{} \left\{1\right\}} & \gate{Output(\lvert \psi \rangle){\Big \{} \left\{1\right\}}
# } \hspace{2em} \end{array}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (( MultiQubitGate(H, {1})  & MultiQubitGate(H, {1}) equiv  MultiQubitGate(I, {1})) and  MultiQubitGate(Input(|psi〉), {1})  & MultiQubitGate(H, {1})  & MultiQubitGate(H, {1})  & MultiQubitGate(Output(|psi〉), {1})) =>  \\  MultiQubitGate(Input(|psi〉), {1})  & MultiQubitGate(I, {1})  & MultiQubitGate(Output(|psi〉), {1})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (( MultiQubitGate(H, {1})  & MultiQubitGate(H, {1}) equiv  MultiQubitGate(I, {1})) and  MultiQubitGate(Input(|psi〉), {1})  & MultiQubitGate(H, {1})  & MultiQubitGate(H, {1})  & MultiQubitGate(Output(|psi〉), {1}),  MultiQubitGate(Input(|psi〉), {1})  & MultiQubitGate(I, {1})  & MultiQubitGate(Output(|psi〉), {1}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. ( MultiQubitGate(H, {1})  & MultiQubitGate(H, {1}) equiv  MultiQubitGate(I, {1})) and  MultiQubitGate(Input(|psi〉), {1})  & MultiQubitGate(H, {1})  & MultiQubitGate(H, {1})  & MultiQubitGate(Output(|psi〉), {1})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4.  MultiQubitGate(Input(|psi〉), {1})  & MultiQubitGate(I, {1})  & MultiQubitGate(Output(|psi〉), {1})
#    core type: Operation
#    operator: 19
#    operand: 10
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. ( MultiQubitGate(H, {1})  & MultiQubitGate(H, {1}) equiv  MultiQubitGate(I, {1}),  MultiQubitGate(Input(|psi〉), {1})  & MultiQubitGate(H, {1})  & MultiQubitGate(H, {1})  & MultiQubitGate(Output(|psi〉), {1}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. ((MultiQubitGate(Input(|psi〉), {1}) & MultiQubitGate(I, {1}) & MultiQubitGate(Output(|psi〉), {1})))
#    core type: ExprTuple
#    sub-expressions: 10
# 8.  MultiQubitGate(H, {1})  & MultiQubitGate(H, {1}) equiv  MultiQubitGate(I, {1})
#    core type: Operation
#    operator: 11
#    operands: 12
# 9.  MultiQubitGate(Input(|psi〉), {1})  & MultiQubitGate(H, {1})  & MultiQubitGate(H, {1})  & MultiQubitGate(Output(|psi〉), {1})
#    core type: Operation
#    operator: 19
#    operand: 17
# 10. MultiQubitGate(Input(|psi〉), {1}) & MultiQubitGate(I, {1}) & MultiQubitGate(Output(|psi〉), {1})
#     core type: ExprTuple
#     sub-expressions: 14
# 11. equiv
#     core type: Literal
#     sub-expressions:
# 12. ( MultiQubitGate(H, {1})  & MultiQubitGate(H, {1}),  MultiQubitGate(I, {1}))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. ((MultiQubitGate(Input(|psi〉), {1}) & MultiQubitGate(H, {1}) & MultiQubitGate(H, {1}) & MultiQubitGate(Output(|psi〉), {1})))
#     core type: ExprTuple
#     sub-expressions: 17
# 14. (MultiQubitGate(Input(|psi〉), {1}), MultiQubitGate(I, {1}), MultiQubitGate(Output(|psi〉), {1}))
#     core type: ExprTuple
#     sub-expressions: 24, 31, 25
# 15.  MultiQubitGate(H, {1})  & MultiQubitGate(H, {1})
#     core type: Operation
#     operator: 19
#     operand: 22
# 16.  MultiQubitGate(I, {1})
#     core type: Operation
#     operator: 19
#     operand: 23
# 17. MultiQubitGate(Input(|psi〉), {1}) & MultiQubitGate(H, {1}) & MultiQubitGate(H, {1}) & MultiQubitGate(Output(|psi〉), {1})
#     core type: ExprTuple
#     sub-expressions: 21
# 18. ((MultiQubitGate(H, {1}) & MultiQubitGate(H, {1})))
#     core type: ExprTuple
#     sub-expressions: 22
# 19. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 20. ((MultiQubitGate(I, {1})))
#     core type: ExprTuple
#     sub-expressions: 23
# 21. (MultiQubitGate(Input(|psi〉), {1}), MultiQubitGate(H, {1}), MultiQubitGate(H, {1}), MultiQubitGate(Output(|psi〉), {1}))
#     core type: ExprTuple
#     sub-expressions: 24, 30, 30, 25
# 22. MultiQubitGate(H, {1}) & MultiQubitGate(H, {1})
#     core type: ExprTuple
#     sub-expressions: 26
# 23. MultiQubitGate(I, {1})
#     core type: ExprTuple
#     sub-expressions: 27
# 24. MultiQubitGate(Input(|psi〉), {1})
#     core type: Operation
#     operator: 35
#     operands: 28
# 25. MultiQubitGate(Output(|psi〉), {1})
#     core type: Operation
#     operator: 35
#     operands: 29
# 26. (MultiQubitGate(H, {1}), MultiQubitGate(H, {1}))
#     core type: ExprTuple
#     sub-expressions: 30, 30
# 27. (MultiQubitGate(I, {1}))
#     core type: ExprTuple
#     sub-expressions: 31
# 28. (Input(|psi〉), {1})
#     core type: ExprTuple
#     sub-expressions: 32, 42
# 29. (Output(|psi〉), {1})
#     core type: ExprTuple
#     sub-expressions: 33, 42
# 30. MultiQubitGate(H, {1})
#     core type: Operation
#     operator: 35
#     operands: 34
# 31. MultiQubitGate(I, {1})
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. [INPUT](|psi〉)
#     core type: Operation
#     operator: 37
#     operand: 39
# 33. [OUTPUT](|psi〉)
#     core type: Operation
#     operator: 38
#     operand: 39
# 34. (H, {1})
#     core type: ExprTuple
#     sub-expressions: 40, 42
# 35. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 36. ([I], {1})
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 37. INPUT
#     core type: Literal
#     sub-expressions:
# 38. OUTPUT
#     core type: Literal
#     sub-expressions:
# 39. |psi〉
#     core type: Operation
#     operator: 43
#     operand: 44
# 40. H
#     core type: Literal
#     sub-expressions:
# 41. [I]
#     core type: Literal
#     sub-expressions:
# 42. {1}
#     core type: Operation
#     operator: 45
#     operand: 46
# 43. KET
#     core type: Literal
#     sub-expressions:
# 44. psi
#     core type: Literal
#     sub-expressions:
# 45. Set
#     core type: Literal
#     sub-expressions:
# 46. 1
#     core type: Literal
#     sub-expressions:
