# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, C, ExprArray, ExprRange, IndexedVar, P, Q, R, Variable, g, h, i, j, k, m, n
from proveit.core_expr_types.expr_arrays import Aij, Bij, Cij, D11_to_Dmn, Dij, Pij, Qij, Rij, S11_to_Smn, Sij
from proveit.logic import And, Forall, Implies
from proveit.numbers import one
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr3 = [sub_expr1, sub_expr2]
sub_expr4 = ExprRange(j, MultiQubitGate(Bij, Qij), one, h)
sub_expr5 = ExprRange(j, MultiQubitGate(Dij, Sij), one, n)
sub_expr6 = ExprRange(j, MultiQubitGate(Aij, Pij), one, g)
sub_expr7 = ExprRange(j, MultiQubitGate(Cij, Rij), one, k)
expr = Forall([ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(A, sub_expr3), one, g), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(B, sub_expr3), one, h), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(C, sub_expr3), one, k), one, m), D11_to_Dmn, ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(P, sub_expr3), one, g), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(Q, sub_expr3), one, h), one, m), ExprRange(sub_expr1, ExprRange(sub_expr2, IndexedVar(R, sub_expr3), one, k), one, m), S11_to_Smn], Implies(And(CircuitEquiv(Circuit(ExprArray(ExprRange(i, [sub_expr4], one, m))), Circuit(ExprArray(ExprRange(i, [sub_expr5], one, m)))), Circuit(ExprArray(ExprRange(i, [sub_expr6, sub_expr4, sub_expr7], one, m)))), Circuit(ExprArray(ExprRange(i, [sub_expr6, sub_expr5, sub_expr7], one, m)))).with_wrapping_at(2)).wrap_params()
# Out:
# expr: forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}} ((( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})) =>  \\  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{ \scriptsize \begin{array}{c}
# A_{1, 1}, \ldots, A_{1, g}, \ldots\ldots, A_{m, 1}, \ldots, A_{m, g}, B_{1, 1}, \ldots, B_{1, h}, \ldots\ldots, B_{m, 1}, \ldots, B_{m, h}, \\
# C_{1, 1}, \ldots, C_{1, k}, \ldots\ldots, C_{m, 1}, \ldots, C_{m, k}, D_{1, 1}, \ldots, D_{1, n}, \ldots\ldots, D_{m, 1}, \ldots, D_{m, n}, \\
# P_{1, 1}, \ldots, P_{1, g}, \ldots\ldots, P_{m, 1}, \ldots, P_{m, g}, Q_{1, 1}, \ldots, Q_{1, h}, \ldots\ldots, Q_{m, 1}, \ldots, Q_{m, h}, \\
# R_{1, 1}, \ldots, R_{1, k}, \ldots\ldots, R_{m, 1}, \ldots, R_{m, k}, S_{1, 1}, \ldots, S_{1, n}, \ldots\ldots, S_{m, 1}, \ldots, S_{m, n}\end{array}
# }~  \\
# \left(\begin{array}{c} \left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1, 1}{\Big \{} Q_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{B_{1, h}{\Big \{} Q_{1, h}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{B_{i, j}{\Big \{} Q_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{B_{m, 1}{\Big \{} Q_{m, 1}} & \gate{\cdots} & \gate{B_{m, h}{\Big \{} Q_{m, h}}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{1, 1}{\Big \{} S_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{D_{1, n}{\Big \{} S_{1, n}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{D_{i, j}{\Big \{} S_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{D_{m, 1}{\Big \{} S_{m, 1}} & \gate{\cdots} & \gate{D_{m, n}{\Big \{} S_{m, n}}
# } \hspace{2em}\right) \land \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} P_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, g}{\Big \{} P_{1, g}} \qwx[1] & \gate{B_{1, 1}{\Big \{} Q_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{B_{1, h}{\Big \{} Q_{1, h}} \qwx[1] & \gate{C_{1, 1}{\Big \{} R_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1, k}{\Big \{} R_{1, k}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{} P_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{B_{i, j}{\Big \{} Q_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{C_{i, j}{\Big \{} R_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{m, 1}{\Big \{} P_{m, 1}} & \gate{\cdots} & \gate{A_{m, g}{\Big \{} P_{m, g}} & \gate{B_{m, 1}{\Big \{} Q_{m, 1}} & \gate{\cdots} & \gate{B_{m, h}{\Big \{} Q_{m, h}} & \gate{C_{m, 1}{\Big \{} R_{m, 1}} & \gate{\cdots} & \gate{C_{m, k}{\Big \{} R_{m, k}}
# } \hspace{2em}\right) \Rightarrow  \\ \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}{\Big \{} P_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{A_{1, g}{\Big \{} P_{1, g}} \qwx[1] & \gate{D_{1, 1}{\Big \{} S_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{D_{1, n}{\Big \{} S_{1, n}} \qwx[1] & \gate{C_{1, 1}{\Big \{} R_{1, 1}} \qwx[1] & \gate{\cdots} \qwx[1] & \gate{C_{1, k}{\Big \{} R_{1, k}} \qwx[1]   \\
#   & \gate{\vdots} \qwx[1] & \gate{A_{i, j}{\Big \{} P_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{D_{i, j}{\Big \{} S_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{\vdots} \qwx[1] & \gate{C_{i, j}{\Big \{} R_{i, j}} \qwx[1] & \gate{\vdots} \qwx[1]   \\
#   & \gate{A_{m, 1}{\Big \{} P_{m, 1}} & \gate{\cdots} & \gate{A_{m, g}{\Big \{} P_{m, g}} & \gate{D_{m, 1}{\Big \{} S_{m, 1}} & \gate{\cdots} & \gate{D_{m, n}{\Big \{} S_{m, n}} & \gate{C_{m, 1}{\Big \{} R_{m, 1}} & \gate{\cdots} & \gate{C_{m, k}{\Big \{} R_{m, k}}
# } \hspace{2em} \end{array}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}} ((( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})) =>  \\  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}) -> ((( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})) =>  \\  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k}))
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}, B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}, C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}, D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}, P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}, Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}, R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}, S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n})
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7, 8, 9, 10, 11, 12
# 4. (( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})) =>  \\  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})
#    core type: Operation
#    operator: 13
#    operands: 14
# 5. A_{1, 1}, ..A_{1, _b}.., A_{1, g}, ....A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}...., A_{m, 1}, ..A_{m, _b}.., A_{m, g}
#    core type: ExprRange
#    lambda_map: 15
#    start_index: 95
#    end_index: 79
# 6. B_{1, 1}, ..B_{1, _b}.., B_{1, h}, ....B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}...., B_{m, 1}, ..B_{m, _b}.., B_{m, h}
#    core type: ExprRange
#    lambda_map: 16
#    start_index: 95
#    end_index: 79
# 7. C_{1, 1}, ..C_{1, _b}.., C_{1, k}, ....C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}...., C_{m, 1}, ..C_{m, _b}.., C_{m, k}
#    core type: ExprRange
#    lambda_map: 17
#    start_index: 95
#    end_index: 79
# 8. D_{1, 1}, ..D_{1, _b}.., D_{1, n}, ....D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}...., D_{m, 1}, ..D_{m, _b}.., D_{m, n}
#    core type: ExprRange
#    lambda_map: 18
#    start_index: 95
#    end_index: 79
# 9. P_{1, 1}, ..P_{1, _b}.., P_{1, g}, ....P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}...., P_{m, 1}, ..P_{m, _b}.., P_{m, g}
#    core type: ExprRange
#    lambda_map: 19
#    start_index: 95
#    end_index: 79
# 10. Q_{1, 1}, ..Q_{1, _b}.., Q_{1, h}, ....Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}...., Q_{m, 1}, ..Q_{m, _b}.., Q_{m, h}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 95
#     end_index: 79
# 11. R_{1, 1}, ..R_{1, _b}.., R_{1, k}, ....R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}...., R_{m, 1}, ..R_{m, _b}.., R_{m, k}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 95
#     end_index: 79
# 12. S_{1, 1}, ..S_{1, _b}.., S_{1, n}, ....S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}...., S_{m, 1}, ..S_{m, _b}.., S_{m, n}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 95
#     end_index: 79
# 13. =>
#     core type: Literal
#     sub-expressions:
# 14. (( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k}),  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k}))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 15. _a -> A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}
#     core type: Lambda
#     parameter: 64
#     body: 25
# 16. _a -> B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}
#     core type: Lambda
#     parameter: 64
#     body: 26
# 17. _a -> C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}
#     core type: Lambda
#     parameter: 64
#     body: 27
# 18. _a -> D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}
#     core type: Lambda
#     parameter: 64
#     body: 28
# 19. _a -> P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}
#     core type: Lambda
#     parameter: 64
#     body: 29
# 20. _a -> Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}
#     core type: Lambda
#     parameter: 64
#     body: 30
# 21. _a -> R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}
#     core type: Lambda
#     parameter: 64
#     body: 31
# 22. _a -> S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}
#     core type: Lambda
#     parameter: 64
#     body: 32
# 23. ( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})) and  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})
#     core type: Operation
#     operator: 33
#     operands: 34
# 24.  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})
#     core type: Operation
#     operator: 67
#     operand: 46
# 25. A_{_a, 1}, ..A_{_a, _b}.., A_{_a, g}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 95
#     end_index: 85
# 26. B_{_a, 1}, ..B_{_a, _b}.., B_{_a, h}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 95
#     end_index: 93
# 27. C_{_a, 1}, ..C_{_a, _b}.., C_{_a, k}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 95
#     end_index: 87
# 28. D_{_a, 1}, ..D_{_a, _b}.., D_{_a, n}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 95
#     end_index: 96
# 29. P_{_a, 1}, ..P_{_a, _b}.., P_{_a, g}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 95
#     end_index: 85
# 30. Q_{_a, 1}, ..Q_{_a, _b}.., Q_{_a, h}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 95
#     end_index: 93
# 31. R_{_a, 1}, ..R_{_a, _b}.., R_{_a, k}
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 95
#     end_index: 87
# 32. S_{_a, 1}, ..S_{_a, _b}.., S_{_a, n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 95
#     end_index: 96
# 33. and
#     core type: Literal
#     sub-expressions:
# 34. ( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n}),  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k}))
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 35. ((MultiQubitGate(A_{1, 1}, P_{1, 1}) & ..MultiQubitGate(A_{1, j}, P_{1, j}).. & MultiQubitGate(A_{1, g}, P_{1, g}) & MultiQubitGate(D_{1, 1}, S_{1, 1}) & ..MultiQubitGate(D_{1, j}, S_{1, j}).. & MultiQubitGate(D_{1, n}, S_{1, n}) & MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, k}, R_{1, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, P_{i, 1}) & ..MultiQubitGate(A_{i, j}, P_{i, j}).. & MultiQubitGate(A_{i, g}, P_{i, g}) & MultiQubitGate(D_{i, 1}, S_{i, 1}) & ..MultiQubitGate(D_{i, j}, S_{i, j}).. & MultiQubitGate(D_{i, n}, S_{i, n}) & MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, k}, R_{i, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, P_{m, 1}) & ..MultiQubitGate(A_{m, j}, P_{m, j}).. & MultiQubitGate(A_{m, g}, P_{m, g}) & MultiQubitGate(D_{m, 1}, S_{m, 1}) & ..MultiQubitGate(D_{m, j}, S_{m, j}).. & MultiQubitGate(D_{m, n}, S_{m, n}) & MultiQubitGate(C_{m, 1}, R_{m, 1}) & ..MultiQubitGate(C_{m, j}, R_{m, j}).. & MultiQubitGate(C_{m, k}, R_{m, k})))
#     core type: ExprTuple
#     sub-expressions: 46
# 36. _b -> A_{_a, _b}
#     core type: Lambda
#     parameter: 65
#     body: 47
# 37. _b -> B_{_a, _b}
#     core type: Lambda
#     parameter: 65
#     body: 48
# 38. _b -> C_{_a, _b}
#     core type: Lambda
#     parameter: 65
#     body: 49
# 39. _b -> D_{_a, _b}
#     core type: Lambda
#     parameter: 65
#     body: 50
# 40. _b -> P_{_a, _b}
#     core type: Lambda
#     parameter: 65
#     body: 51
# 41. _b -> Q_{_a, _b}
#     core type: Lambda
#     parameter: 65
#     body: 52
# 42. _b -> R_{_a, _b}
#     core type: Lambda
#     parameter: 65
#     body: 53
# 43. _b -> S_{_a, _b}
#     core type: Lambda
#     parameter: 65
#     body: 54
# 44.  MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}) equiv  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})
#     core type: Operation
#     operator: 55
#     operands: 56
# 45.  MultiQubitGate(A_{1, 1}, P_{1, 1})  & ..MultiQubitGate(A_{1, j}, P_{1, j})..  & MultiQubitGate(A_{1, g}, P_{1, g})  & MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})  & MultiQubitGate(C_{1, 1}, R_{1, 1})  & ..MultiQubitGate(C_{1, j}, R_{1, j})..  & MultiQubitGate(C_{1, k}, R_{1, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{i, 1}, P_{i, 1})  & ..MultiQubitGate(A_{i, j}, P_{i, j})..  & MultiQubitGate(A_{i, g}, P_{i, g})  & MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})  & MultiQubitGate(C_{i, 1}, R_{i, 1})  & ..MultiQubitGate(C_{i, j}, R_{i, j})..  & MultiQubitGate(C_{i, k}, R_{i, k})   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    MultiQubitGate(A_{m, 1}, P_{m, 1})  & ..MultiQubitGate(A_{m, j}, P_{m, j})..  & MultiQubitGate(A_{m, g}, P_{m, g})  & MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})  & MultiQubitGate(C_{m, 1}, R_{m, 1})  & ..MultiQubitGate(C_{m, j}, R_{m, j})..  & MultiQubitGate(C_{m, k}, R_{m, k})
#     core type: Operation
#     operator: 67
#     operand: 62
# 46. MultiQubitGate(A_{1, 1}, P_{1, 1}) & ..MultiQubitGate(A_{1, j}, P_{1, j}).. & MultiQubitGate(A_{1, g}, P_{1, g}) & MultiQubitGate(D_{1, 1}, S_{1, 1}) & ..MultiQubitGate(D_{1, j}, S_{1, j}).. & MultiQubitGate(D_{1, n}, S_{1, n}) & MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, k}, R_{1, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, P_{i, 1}) & ..MultiQubitGate(A_{i, j}, P_{i, j}).. & MultiQubitGate(A_{i, g}, P_{i, g}) & MultiQubitGate(D_{i, 1}, S_{i, 1}) & ..MultiQubitGate(D_{i, j}, S_{i, j}).. & MultiQubitGate(D_{i, n}, S_{i, n}) & MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, k}, R_{i, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, P_{m, 1}) & ..MultiQubitGate(A_{m, j}, P_{m, j}).. & MultiQubitGate(A_{m, g}, P_{m, g}) & MultiQubitGate(D_{m, 1}, S_{m, 1}) & ..MultiQubitGate(D_{m, j}, S_{m, j}).. & MultiQubitGate(D_{m, n}, S_{m, n}) & MultiQubitGate(C_{m, 1}, R_{m, 1}) & ..MultiQubitGate(C_{m, j}, R_{m, j}).. & MultiQubitGate(C_{m, k}, R_{m, k})
#     core type: ExprTuple
#     sub-expressions: 58
# 47. A_{_a, _b}
#     core type: IndexedVar
# variable: 108
# indices: 59
# 48. B_{_a, _b}
#     core type: IndexedVar
# variable: 116
# indices: 59
# 49. C_{_a, _b}
#     core type: IndexedVar
# variable: 110
# indices: 59
# 50. D_{_a, _b}
#     core type: IndexedVar
# variable: 118
# indices: 59
# 51. P_{_a, _b}
#     core type: IndexedVar
# variable: 109
# indices: 59
# 52. Q_{_a, _b}
#     core type: IndexedVar
# variable: 117
# indices: 59
# 53. R_{_a, _b}
#     core type: IndexedVar
# variable: 111
# indices: 59
# 54. S_{_a, _b}
#     core type: IndexedVar
# variable: 119
# indices: 59
# 55. equiv
#     core type: Literal
#     sub-expressions:
# 56. ( MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h}),  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n}))
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 57. ((MultiQubitGate(A_{1, 1}, P_{1, 1}) & ..MultiQubitGate(A_{1, j}, P_{1, j}).. & MultiQubitGate(A_{1, g}, P_{1, g}) & MultiQubitGate(B_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(B_{1, j}, Q_{1, j}).. & MultiQubitGate(B_{1, h}, Q_{1, h}) & MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, k}, R_{1, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, P_{i, 1}) & ..MultiQubitGate(A_{i, j}, P_{i, j}).. & MultiQubitGate(A_{i, g}, P_{i, g}) & MultiQubitGate(B_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(B_{i, j}, Q_{i, j}).. & MultiQubitGate(B_{i, h}, Q_{i, h}) & MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, k}, R_{i, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, P_{m, 1}) & ..MultiQubitGate(A_{m, j}, P_{m, j}).. & MultiQubitGate(A_{m, g}, P_{m, g}) & MultiQubitGate(B_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(B_{m, j}, Q_{m, j}).. & MultiQubitGate(B_{m, h}, Q_{m, h}) & MultiQubitGate(C_{m, 1}, R_{m, 1}) & ..MultiQubitGate(C_{m, j}, R_{m, j}).. & MultiQubitGate(C_{m, k}, R_{m, k})))
#     core type: ExprTuple
#     sub-expressions: 62
# 58. (MultiQubitGate(A_{1, 1}, P_{1, 1}), ..MultiQubitGate(A_{1, j}, P_{1, j}).., MultiQubitGate(A_{1, g}, P_{1, g}), MultiQubitGate(D_{1, 1}, S_{1, 1}), ..MultiQubitGate(D_{1, j}, S_{1, j}).., MultiQubitGate(D_{1, n}, S_{1, n}), MultiQubitGate(C_{1, 1}, R_{1, 1}), ..MultiQubitGate(C_{1, j}, R_{1, j}).., MultiQubitGate(C_{1, k}, R_{1, k})), ..(MultiQubitGate(A_{i, 1}, P_{i, 1}), ..MultiQubitGate(A_{i, j}, P_{i, j}).., MultiQubitGate(A_{i, g}, P_{i, g}), MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n}), MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, k}, R_{i, k})).., (MultiQubitGate(A_{m, 1}, P_{m, 1}), ..MultiQubitGate(A_{m, j}, P_{m, j}).., MultiQubitGate(A_{m, g}, P_{m, g}), MultiQubitGate(D_{m, 1}, S_{m, 1}), ..MultiQubitGate(D_{m, j}, S_{m, j}).., MultiQubitGate(D_{m, n}, S_{m, n}), MultiQubitGate(C_{m, 1}, R_{m, 1}), ..MultiQubitGate(C_{m, j}, R_{m, j}).., MultiQubitGate(C_{m, k}, R_{m, k}))
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 95
#     end_index: 79
# 59. (_a, _b)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 60.  MultiQubitGate(B_{1, 1}, Q_{1, 1})  & ..MultiQubitGate(B_{1, j}, Q_{1, j})..  & MultiQubitGate(B_{1, h}, Q_{1, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{i, 1}, Q_{i, 1})  & ..MultiQubitGate(B_{i, j}, Q_{i, j})..  & MultiQubitGate(B_{i, h}, Q_{i, h})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(B_{m, 1}, Q_{m, 1})  & ..MultiQubitGate(B_{m, j}, Q_{m, j})..  & MultiQubitGate(B_{m, h}, Q_{m, h})
#     core type: Operation
#     operator: 67
#     operand: 71
# 61.  MultiQubitGate(D_{1, 1}, S_{1, 1})  & ..MultiQubitGate(D_{1, j}, S_{1, j})..  & MultiQubitGate(D_{1, n}, S_{1, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{i, 1}, S_{i, 1})  & ..MultiQubitGate(D_{i, j}, S_{i, j})..  & MultiQubitGate(D_{i, n}, S_{i, n})   \\
#    \colon  & \colon  & \colon   \\
#    MultiQubitGate(D_{m, 1}, S_{m, 1})  & ..MultiQubitGate(D_{m, j}, S_{m, j})..  & MultiQubitGate(D_{m, n}, S_{m, n})
#     core type: Operation
#     operator: 67
#     operand: 72
# 62. MultiQubitGate(A_{1, 1}, P_{1, 1}) & ..MultiQubitGate(A_{1, j}, P_{1, j}).. & MultiQubitGate(A_{1, g}, P_{1, g}) & MultiQubitGate(B_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(B_{1, j}, Q_{1, j}).. & MultiQubitGate(B_{1, h}, Q_{1, h}) & MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, k}, R_{1, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{i, 1}, P_{i, 1}) & ..MultiQubitGate(A_{i, j}, P_{i, j}).. & MultiQubitGate(A_{i, g}, P_{i, g}) & MultiQubitGate(B_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(B_{i, j}, Q_{i, j}).. & MultiQubitGate(B_{i, h}, Q_{i, h}) & MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, k}, R_{i, k})  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   MultiQubitGate(A_{m, 1}, P_{m, 1}) & ..MultiQubitGate(A_{m, j}, P_{m, j}).. & MultiQubitGate(A_{m, g}, P_{m, g}) & MultiQubitGate(B_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(B_{m, j}, Q_{m, j}).. & MultiQubitGate(B_{m, h}, Q_{m, h}) & MultiQubitGate(C_{m, 1}, R_{m, 1}) & ..MultiQubitGate(C_{m, j}, R_{m, j}).. & MultiQubitGate(C_{m, k}, R_{m, k})
#     core type: ExprTuple
#     sub-expressions: 69
# 63. i -> (MultiQubitGate(A_{i, 1}, P_{i, 1}), ..MultiQubitGate(A_{i, j}, P_{i, j}).., MultiQubitGate(A_{i, g}, P_{i, g}), MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n}), MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, k}, R_{i, k}))
#     core type: Lambda
#     parameter: 121
#     body: 70
# 64. _a
#     core type: Variable
#     sub-expressions:
# 65. _b
#     core type: Variable
#     sub-expressions:
# 66. ((MultiQubitGate(B_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(B_{1, j}, Q_{1, j}).. & MultiQubitGate(B_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(B_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(B_{i, j}, Q_{i, j}).. & MultiQubitGate(B_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(B_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(B_{m, j}, Q_{m, j}).. & MultiQubitGate(B_{m, h}, Q_{m, h})))
#     core type: ExprTuple
#     sub-expressions: 71
# 67. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 68. ((MultiQubitGate(D_{1, 1}, S_{1, 1}) & ..MultiQubitGate(D_{1, j}, S_{1, j}).. & MultiQubitGate(D_{1, n}, S_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(D_{i, 1}, S_{i, 1}) & ..MultiQubitGate(D_{i, j}, S_{i, j}).. & MultiQubitGate(D_{i, n}, S_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(D_{m, 1}, S_{m, 1}) & ..MultiQubitGate(D_{m, j}, S_{m, j}).. & MultiQubitGate(D_{m, n}, S_{m, n})))
#     core type: ExprTuple
#     sub-expressions: 72
# 69. (MultiQubitGate(A_{1, 1}, P_{1, 1}), ..MultiQubitGate(A_{1, j}, P_{1, j}).., MultiQubitGate(A_{1, g}, P_{1, g}), MultiQubitGate(B_{1, 1}, Q_{1, 1}), ..MultiQubitGate(B_{1, j}, Q_{1, j}).., MultiQubitGate(B_{1, h}, Q_{1, h}), MultiQubitGate(C_{1, 1}, R_{1, 1}), ..MultiQubitGate(C_{1, j}, R_{1, j}).., MultiQubitGate(C_{1, k}, R_{1, k})), ..(MultiQubitGate(A_{i, 1}, P_{i, 1}), ..MultiQubitGate(A_{i, j}, P_{i, j}).., MultiQubitGate(A_{i, g}, P_{i, g}), MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h}), MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, k}, R_{i, k})).., (MultiQubitGate(A_{m, 1}, P_{m, 1}), ..MultiQubitGate(A_{m, j}, P_{m, j}).., MultiQubitGate(A_{m, g}, P_{m, g}), MultiQubitGate(B_{m, 1}, Q_{m, 1}), ..MultiQubitGate(B_{m, j}, Q_{m, j}).., MultiQubitGate(B_{m, h}, Q_{m, h}), MultiQubitGate(C_{m, 1}, R_{m, 1}), ..MultiQubitGate(C_{m, j}, R_{m, j}).., MultiQubitGate(C_{m, k}, R_{m, k}))
#     core type: ExprRange
#     lambda_map: 73
#     start_index: 95
#     end_index: 79
# 70. (MultiQubitGate(A_{i, 1}, P_{i, 1}), ..MultiQubitGate(A_{i, j}, P_{i, j}).., MultiQubitGate(A_{i, g}, P_{i, g}), MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n}), MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, k}, R_{i, k}))
#     core type: ExprTuple
#     sub-expressions: 80, 89, 81
# 71. MultiQubitGate(B_{1, 1}, Q_{1, 1}) & ..MultiQubitGate(B_{1, j}, Q_{1, j}).. & MultiQubitGate(B_{1, h}, Q_{1, h})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(B_{i, 1}, Q_{i, 1}) & ..MultiQubitGate(B_{i, j}, Q_{i, j}).. & MultiQubitGate(B_{i, h}, Q_{i, h})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(B_{m, 1}, Q_{m, 1}) & ..MultiQubitGate(B_{m, j}, Q_{m, j}).. & MultiQubitGate(B_{m, h}, Q_{m, h})
#     core type: ExprTuple
#     sub-expressions: 74
# 72. MultiQubitGate(D_{1, 1}, S_{1, 1}) & ..MultiQubitGate(D_{1, j}, S_{1, j}).. & MultiQubitGate(D_{1, n}, S_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(D_{i, 1}, S_{i, 1}) & ..MultiQubitGate(D_{i, j}, S_{i, j}).. & MultiQubitGate(D_{i, n}, S_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(D_{m, 1}, S_{m, 1}) & ..MultiQubitGate(D_{m, j}, S_{m, j}).. & MultiQubitGate(D_{m, n}, S_{m, n})
#     core type: ExprTuple
#     sub-expressions: 75
# 73. i -> (MultiQubitGate(A_{i, 1}, P_{i, 1}), ..MultiQubitGate(A_{i, j}, P_{i, j}).., MultiQubitGate(A_{i, g}, P_{i, g}), MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h}), MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, k}, R_{i, k}))
#     core type: Lambda
#     parameter: 121
#     body: 76
# 74. (MultiQubitGate(B_{1, 1}, Q_{1, 1}), ..MultiQubitGate(B_{1, j}, Q_{1, j}).., MultiQubitGate(B_{1, h}, Q_{1, h})), ..(MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h})).., (MultiQubitGate(B_{m, 1}, Q_{m, 1}), ..MultiQubitGate(B_{m, j}, Q_{m, j}).., MultiQubitGate(B_{m, h}, Q_{m, h}))
#     core type: ExprRange
#     lambda_map: 77
#     start_index: 95
#     end_index: 79
# 75. (MultiQubitGate(D_{1, 1}, S_{1, 1}), ..MultiQubitGate(D_{1, j}, S_{1, j}).., MultiQubitGate(D_{1, n}, S_{1, n})), ..(MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n})).., (MultiQubitGate(D_{m, 1}, S_{m, 1}), ..MultiQubitGate(D_{m, j}, S_{m, j}).., MultiQubitGate(D_{m, n}, S_{m, n}))
#     core type: ExprRange
#     lambda_map: 78
#     start_index: 95
#     end_index: 79
# 76. (MultiQubitGate(A_{i, 1}, P_{i, 1}), ..MultiQubitGate(A_{i, j}, P_{i, j}).., MultiQubitGate(A_{i, g}, P_{i, g}), MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h}), MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, k}, R_{i, k}))
#     core type: ExprTuple
#     sub-expressions: 80, 88, 81
# 77. i -> (MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h}))
#     core type: Lambda
#     parameter: 121
#     body: 82
# 78. i -> (MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n}))
#     core type: Lambda
#     parameter: 121
#     body: 83
# 79. m
#     core type: Variable
#     sub-expressions:
# 80. MultiQubitGate(A_{i, 1}, P_{i, 1}), ..MultiQubitGate(A_{i, j}, P_{i, j}).., MultiQubitGate(A_{i, g}, P_{i, g})
#     core type: ExprRange
#     lambda_map: 84
#     start_index: 95
#     end_index: 85
# 81. MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, k}, R_{i, k})
#     core type: ExprRange
#     lambda_map: 86
#     start_index: 95
#     end_index: 87
# 82. (MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h}))
#     core type: ExprTuple
#     sub-expressions: 88
# 83. (MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n}))
#     core type: ExprTuple
#     sub-expressions: 89
# 84. j -> MultiQubitGate(A_{i, j}, P_{i, j})
#     core type: Lambda
#     parameter: 122
#     body: 90
# 85. g
#     core type: Variable
#     sub-expressions:
# 86. j -> MultiQubitGate(C_{i, j}, R_{i, j})
#     core type: Lambda
#     parameter: 122
#     body: 91
# 87. k
#     core type: Variable
#     sub-expressions:
# 88. MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, j}, Q_{i, j}).., MultiQubitGate(B_{i, h}, Q_{i, h})
#     core type: ExprRange
#     lambda_map: 92
#     start_index: 95
#     end_index: 93
# 89. MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, j}, S_{i, j}).., MultiQubitGate(D_{i, n}, S_{i, n})
#     core type: ExprRange
#     lambda_map: 94
#     start_index: 95
#     end_index: 96
# 90. MultiQubitGate(A_{i, j}, P_{i, j})
#     core type: Operation
#     operator: 106
#     operands: 97
# 91. MultiQubitGate(C_{i, j}, R_{i, j})
#     core type: Operation
#     operator: 106
#     operands: 98
# 92. j -> MultiQubitGate(B_{i, j}, Q_{i, j})
#     core type: Lambda
#     parameter: 122
#     body: 99
# 93. h
#     core type: Variable
#     sub-expressions:
# 94. j -> MultiQubitGate(D_{i, j}, S_{i, j})
#     core type: Lambda
#     parameter: 122
#     body: 100
# 95. 1
#     core type: Literal
#     sub-expressions:
# 96. n
#     core type: Variable
#     sub-expressions:
# 97. (A_{i, j}, P_{i, j})
#     core type: ExprTuple
#     sub-expressions: 101, 102
# 98. (C_{i, j}, R_{i, j})
#     core type: ExprTuple
#     sub-expressions: 103, 104
# 99. MultiQubitGate(B_{i, j}, Q_{i, j})
#     core type: Operation
#     operator: 106
#     operands: 105
# 100. MultiQubitGate(D_{i, j}, S_{i, j})
#      core type: Operation
#      operator: 106
#      operands: 107
# 101. A_{i, j}
#      core type: IndexedVar
# variable: 108
# indices: 120
# 102. P_{i, j}
#      core type: IndexedVar
# variable: 109
# indices: 120
# 103. C_{i, j}
#      core type: IndexedVar
# variable: 110
# indices: 120
# 104. R_{i, j}
#      core type: IndexedVar
# variable: 111
# indices: 120
# 105. (B_{i, j}, Q_{i, j})
#      core type: ExprTuple
#      sub-expressions: 112, 113
# 106. MULTI_QUBIT_GATE
#      core type: Literal
#      sub-expressions:
# 107. (D_{i, j}, S_{i, j})
#      core type: ExprTuple
#      sub-expressions: 114, 115
# 108. A
#      core type: Variable
#      sub-expressions:
# 109. P
#      core type: Variable
#      sub-expressions:
# 110. C
#      core type: Variable
#      sub-expressions:
# 111. R
#      core type: Variable
#      sub-expressions:
# 112. B_{i, j}
#      core type: IndexedVar
# variable: 116
# indices: 120
# 113. Q_{i, j}
#      core type: IndexedVar
# variable: 117
# indices: 120
# 114. D_{i, j}
#      core type: IndexedVar
# variable: 118
# indices: 120
# 115. S_{i, j}
#      core type: IndexedVar
# variable: 119
# indices: 120
# 116. B
#      core type: Variable
#      sub-expressions:
# 117. Q
#      core type: Variable
#      sub-expressions:
# 118. D
#      core type: Variable
#      sub-expressions:
# 119. S
#      core type: Variable
#      sub-expressions:
# 120. (i, j)
#      core type: ExprTuple
#      sub-expressions: 121, 122
# 121. i
#      core type: Variable
#      sub-expressions:
# 122. j
#      core type: Variable
#      sub-expressions:
