# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import four, one, seven, six, three, two
from proveit.physics.quantum import CONTROL, Gate, I, Input, Output, X, Z, ket0, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Input(ket0)
sub_expr2 = Set(one, two, three, four, six, seven)
sub_expr3 = Output(ket0)
sub_expr4 = Input(ket1)
sub_expr5 = Output(ket1)
sub_expr6 = MultiQubitGate(Z, sub_expr2)
sub_expr7 = [sub_expr1, MultiQubitGate(CONTROL, sub_expr2), sub_expr3]
sub_expr8 = [sub_expr4, MultiQubitGate(X, sub_expr2), sub_expr5]
expr = ExprArray(sub_expr7, sub_expr7, [sub_expr1, sub_expr6, sub_expr3], sub_expr8, [sub_expr1, Gate(I), sub_expr3], sub_expr8, [sub_expr4, sub_expr6, sub_expr5])
# Out:
# expr: Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {1, 2, 3, 4, 6, 7}) & Output(|1〉)  \\
#   Input(|0〉) & Gate(I) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {1, 2, 3, 4, 6, 7}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {1, 2, 3, 4, 6, 7}) & Output(|1〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {ccc}
#  \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & X
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{I}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & X
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & Z
# } \hspace{2em} & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em} \end{array}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {1, 2, 3, 4, 6, 7}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {1, 2, 3, 4, 6, 7}) & Output(|1〉)  \\
#   Input(|0〉) & Gate(I) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {1, 2, 3, 4, 6, 7}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {1, 2, 3, 4, 6, 7}) & Output(|1〉)
#    core type: ExprTuple
#    sub-expressions: 1, 1, 2, 4, 3, 4, 5
# 1. (Input(|0〉), MultiQubitGate(CONTROL, {1, 2, 3, 4, 6, 7}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 7, 6, 9
# 2. (Input(|0〉), MultiQubitGate(Z, {1, 2, 3, 4, 6, 7}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 7, 12, 9
# 3. (Input(|0〉), Gate(I), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 4. (Input(|1〉), MultiQubitGate(X, {1, 2, 3, 4, 6, 7}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 11, 10, 13
# 5. (Input(|1〉), MultiQubitGate(Z, {1, 2, 3, 4, 6, 7}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 6. MultiQubitGate(CONTROL, {1, 2, 3, 4, 6, 7})
#    core type: Operation
#    operator: 20
#    operands: 14
# 7. [INPUT](|0〉)
#    core type: Operation
#    operator: 19
#    operand: 17
# 8. Gate(I)
#    core type: Operation
#    operator: 15
#    operand: 16
# 9. [OUTPUT](|0〉)
#    core type: Operation
#    operator: 22
#    operand: 17
# 10. MultiQubitGate(X, {1, 2, 3, 4, 6, 7})
#     core type: Operation
#     operator: 20
#     operands: 18
# 11. [INPUT](|1〉)
#     core type: Operation
#     operator: 19
#     operand: 23
# 12. MultiQubitGate(Z, {1, 2, 3, 4, 6, 7})
#     core type: Operation
#     operator: 20
#     operands: 21
# 13. [OUTPUT](|1〉)
#     core type: Operation
#     operator: 22
#     operand: 23
# 14. (CONTROL, {1, 2, 3, 4, 6, 7})
#     core type: ExprTuple
#     sub-expressions: 24, 28
# 15. GATE
#     core type: Literal
#     sub-expressions:
# 16. --
#     core type: Literal
#     sub-expressions:
# 17. |0〉
#     core type: Operation
#     operator: 29
#     operand: 25
# 18. (X, {1, 2, 3, 4, 6, 7})
#     core type: ExprTuple
#     sub-expressions: 26, 28
# 19. INPUT
#     core type: Literal
#     sub-expressions:
# 20. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 21. (Z, {1, 2, 3, 4, 6, 7})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 22. OUTPUT
#     core type: Literal
#     sub-expressions:
# 23. |1〉
#     core type: Operation
#     operator: 29
#     operand: 32
# 24. CONTROL
#     core type: Literal
#     sub-expressions:
# 25. 0
#     core type: Literal
#     sub-expressions:
# 26. X
#     core type: Literal
#     sub-expressions:
# 27. Z
#     core type: Literal
#     sub-expressions:
# 28. {1, 2, 3, 4, 6, 7}
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. KET
#     core type: Literal
#     sub-expressions:
# 30. Set
#     core type: Literal
#     sub-expressions:
# 31. (1, 2, 3, 4, 6, 7)
#     core type: ExprTuple
#     sub-expressions: 32, 33, 34, 35, 36, 37
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. 2
#     core type: Literal
#     sub-expressions:
# 34. 3
#     core type: Literal
#     sub-expressions:
# 35. 4
#     core type: Literal
#     sub-expressions:
# 36. 6
#     core type: Literal
#     sub-expressions:
# 37. 7
#     core type: Literal
#     sub-expressions:
