# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.physics.quantum import Gate, H, Input, Output, ket1

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(H)
expr = ExprTuple(Input(ket1), sub_expr1, sub_expr1, Output(ket1))
# Out:
# expr: (Input(|1〉), Gate(H), Gate(H), Output(|1〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 1 \rangle}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 1 \rangle} \qw
# } \hspace{2em}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Input(|1〉), Gate(H), Gate(H), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 2, 3
# 1. [INPUT](|1〉)
#    core type: Operation
#    operator: 4
#    operand: 8
# 2. Gate(H)
#    core type: Operation
#    operator: 5
#    operand: 6
# 3. [OUTPUT](|1〉)
#    core type: Operation
#    operator: 7
#    operand: 8
# 4. INPUT
#    core type: Literal
#    sub-expressions:
# 5. GATE
#    core type: Literal
#    sub-expressions:
# 6. H
#    core type: Literal
#    sub-expressions:
# 7. OUTPUT
#    core type: Literal
#    sub-expressions:
# 8. |1〉
#    core type: Operation
#    operator: 9
#    operand: 10
# 9. KET
#    core type: Literal
#    sub-expressions:
# 10. 1
#     core type: Literal
#     sub-expressions:
