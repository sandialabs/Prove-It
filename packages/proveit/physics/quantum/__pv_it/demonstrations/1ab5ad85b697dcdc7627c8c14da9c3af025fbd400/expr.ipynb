# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import D, ExprRange, IndexedVar, S, a, i
from proveit.numbers import one
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = [i, a]
expr = ExprRange(a, MultiQubitGate(IndexedVar(D, sub_expr1), IndexedVar(S, sub_expr1)), one, one)
# Out:
# expr: MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, a}, S_{i, a}).., MultiQubitGate(D_{i, 1}, S_{i, 1})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{i, 1}{\Big \{} S_{i, 1}}
# } \hspace{2em}, \ldots, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{D_{i, 1}{\Big \{} S_{i, 1}}
# } \hspace{2em}

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. MultiQubitGate(D_{i, 1}, S_{i, 1}), ..MultiQubitGate(D_{i, a}, S_{i, a}).., MultiQubitGate(D_{i, 1}, S_{i, 1})
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 2
# 1. a -> MultiQubitGate(D_{i, a}, S_{i, a})
#    core type: Lambda
#    parameter: 12
#    body: 3
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. MultiQubitGate(D_{i, a}, S_{i, a})
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 5. (D_{i, a}, S_{i, a})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. D_{i, a}
#    core type: IndexedVar
# variable: 8
# indices: 10
# 7. S_{i, a}
#    core type: IndexedVar
# variable: 9
# indices: 10
# 8. D
#    core type: Variable
#    sub-expressions:
# 9. S
#    core type: Variable
#    sub-expressions:
# 10. (i, a)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. i
#     core type: Variable
#     sub-expressions:
# 12. a
#     core type: Variable
#     sub-expressions:
