# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, U
from proveit.logic import Set
from proveit.numbers import one, two
from proveit.physics.quantum import Input, Output, ket0
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Input(ket0), MultiQubitGate(U, Set(one, two)), Output(ket0))
# Out:
# expr: (Input(|0〉), MultiQubitGate(U, {1, 2}), Output(|0〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & U
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}\right)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Input(|0〉), MultiQubitGate(U, {1, 2}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. [INPUT](|0〉)
#    core type: Operation
#    operator: 4
#    operand: 8
# 2. MultiQubitGate(U, {1, 2})
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. [OUTPUT](|0〉)
#    core type: Operation
#    operator: 7
#    operand: 8
# 4. INPUT
#    core type: Literal
#    sub-expressions:
# 5. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 6. (U, {1, 2})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. OUTPUT
#    core type: Literal
#    sub-expressions:
# 8. |0〉
#    core type: Operation
#    operator: 11
#    operand: 12
# 9. U
#    core type: Variable
#    sub-expressions:
# 10. {1, 2}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. KET
#     core type: Literal
#     sub-expressions:
# 12. 0
#     core type: Literal
#     sub-expressions:
# 13. Set
#     core type: Literal
#     sub-expressions:
# 14. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. 2
#     core type: Literal
#     sub-expressions:
