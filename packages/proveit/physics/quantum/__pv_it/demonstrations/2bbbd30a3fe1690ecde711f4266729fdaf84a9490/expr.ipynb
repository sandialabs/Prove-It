# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, D, ExprArray, ExprRange, IndexedVar, i, j, k, m, n, p
from proveit.core_expr_types.expr_arrays import Aij, Cij, Eij, Rij
from proveit.logic import Set
from proveit.numbers import Add, one, two
from proveit.physics.quantum import Gate
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(Add(m, one), Add(m, k, two))
expr = ExprArray(ExprRange(i, [ExprRange(j, Gate(Aij), one, n)], one, m), [ExprRange(j, MultiQubitGate(IndexedVar(B, j), sub_expr1), one, n)], ExprRange(i, [ExprRange(j, MultiQubitGate(Cij, Rij), one, n)], one, k), [ExprRange(j, MultiQubitGate(IndexedVar(D, j), sub_expr1), one, n)], ExprRange(i, [ExprRange(j, Gate(Eij), one, n)], one, p))
# Out:
# expr: Gate(A_{1, 1}) & ..Gate(A_{1, j}).. & Gate(A_{1, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(A_{i, 1}) & ..Gate(A_{i, j}).. & Gate(A_{i, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(A_{m, 1}) & ..Gate(A_{m, j}).. & Gate(A_{m, n})  \\
#   MultiQubitGate(B_{1}, {m + 1, m + k + 2}) & ..MultiQubitGate(B_{j}, {m + 1, m + k + 2}).. & MultiQubitGate(B_{n}, {m + 1, m + k + 2})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{k, 1}, R_{k, 1}) & ..MultiQubitGate(C_{k, j}, R_{k, j}).. & MultiQubitGate(C_{k, n}, R_{k, n})  \\
#   MultiQubitGate(D_{1}, {m + 1, m + k + 2}) & ..MultiQubitGate(D_{j}, {m + 1, m + k + 2}).. & MultiQubitGate(D_{n}, {m + 1, m + k + 2})  \\
# ...

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {ccc}
#  \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, 1}}
# } \hspace{2em} & \cdots & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{1, n}}
# } \hspace{2em}  \\
#   \vdots & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{i, j}}
# } \hspace{2em} & \vdots  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{m, 1}}
# } \hspace{2em} & \cdots & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{A_{m, n}}
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{1}{\Big \{} \left\{m + 1, m + k + 2\right\}}
# } \hspace{2em} & \cdots & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{n}{\Big \{} \left\{m + 1, m + k + 2\right\}}
# } \hspace{2em}  \\
#   \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{C_{1, 1}{\Big \{} R_{1, 1}}
# } \hspace{2em} & \cdots & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{C_{1, n}{\Big \{} R_{1, n}}
# } \hspace{2em}  \\
#   \vdots & \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{C_{i, j}{\Big \{} R_{i, j}}
# ...

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Gate(A_{1, 1}) & ..Gate(A_{1, j}).. & Gate(A_{1, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(A_{i, 1}) & ..Gate(A_{i, j}).. & Gate(A_{i, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(A_{m, 1}) & ..Gate(A_{m, j}).. & Gate(A_{m, n})  \\
#   MultiQubitGate(B_{1}, {m + 1, m + k + 2}) & ..MultiQubitGate(B_{j}, {m + 1, m + k + 2}).. & MultiQubitGate(B_{n}, {m + 1, m + k + 2})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{k, 1}, R_{k, 1}) & ..MultiQubitGate(C_{k, j}, R_{k, j}).. & MultiQubitGate(C_{k, n}, R_{k, n})  \\
#   MultiQubitGate(D_{1}, {m + 1, m + k + 2}) & ..MultiQubitGate(D_{j}, {m + 1, m + k + 2}).. & MultiQubitGate(D_{n}, {m + 1, m + k + 2})  \\
# ...
