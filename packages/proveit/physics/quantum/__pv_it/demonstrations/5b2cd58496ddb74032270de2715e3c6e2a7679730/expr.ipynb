# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, k, x
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = Equals(one, Len([ExprRange(k, ExprRange(x, [k, x], one, one), one, one)]))
# Out:
# expr: 1 = |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1))|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# 1 = |\left(\left(1, 1\right), \ldots, \left(1, 1\right), \ldots\ldots, \left(1, 1\right), \ldots, \left(1, 1\right)\right)|

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. 1 = |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1))|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (1, |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1))|)
#    core type: ExprTuple
#    sub-expressions: 11, 3
# 3. |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1))|
#    core type: Operation
#    operator: 4
#    operand: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. (((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1)))
#    core type: ExprTuple
#    sub-expressions: 6
# 6. ((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1))
#    core type: ExprTuple
#    sub-expressions: 7
# 7. (1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 11
#    end_index: 11
# 8. k -> (k, 1), ..(k, x).., (k, 1)
#    core type: Lambda
#    parameter: 13
#    body: 9
# 9. (k, 1), ..(k, x).., (k, 1)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 11
# 10. x -> (k, x)
#     core type: Lambda
#     parameter: 14
#     body: 12
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. (k, x)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. k
#     core type: Variable
#     sub-expressions:
# 14. x
#     core type: Variable
#     sub-expressions:
