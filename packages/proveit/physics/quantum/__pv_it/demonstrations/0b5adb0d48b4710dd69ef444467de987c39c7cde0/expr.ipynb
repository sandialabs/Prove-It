# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, k, x
from proveit.core_expr_types import Len
from proveit.logic import Equals, Set
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = Equals(Len([Set(one)]), Len([ExprRange(k, ExprRange(x, [k, x], one, one), one, one)]))
# Out:
# expr: |({1})| = |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1))|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(\left\{1\right\}\right)| = |\left(\left(1, 1\right), \ldots, \left(1, 1\right), \ldots\ldots, \left(1, 1\right), \ldots, \left(1, 1\right)\right)|

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |({1})| = |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1))|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|({1})|, |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1))|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |({1})|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1))|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (({1}))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. (((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1)))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. ({1})
#    core type: ExprTuple
#    sub-expressions: 10
# 9. ((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1))
#    core type: ExprTuple
#    sub-expressions: 11
# 10. {1}
#     core type: Operation
#     operator: 12
#     operand: 16
# 11. (1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (1, 1), ..(1, x).., (1, 1)
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 16
#     end_index: 16
# 12. Set
#     core type: Literal
#     sub-expressions:
# 13. k -> (k, 1), ..(k, x).., (k, 1)
#     core type: Lambda
#     parameter: 18
#     body: 14
# 14. (k, 1), ..(k, x).., (k, 1)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 16
# 15. x -> (k, x)
#     core type: Lambda
#     parameter: 19
#     body: 17
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. (k, x)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. k
#     core type: Variable
#     sub-expressions:
# 19. x
#     core type: Variable
#     sub-expressions:
