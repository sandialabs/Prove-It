# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#hadamard_on_zero">hadamard_on_zero</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum import hadamard_on_zero

# %%
# check that the built expression is the same as the stored expression
assert hadamard_on_zero.expr == stored_expr
assert hadamard_on_zero.expr._style_id == stored_expr._style_id
print("Passed sanity check: hadamard_on_zero matches stored_expr")
# Out:
# Passed sanity check: hadamard_on_zero matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(hadamard_on_zero.latex())
# Out:
# \vdash \left(H \thinspace \lvert 0 \rangle\right) = \lvert + \rangle

# %%
# display the expression information
hadamard_on_zero.expr_info()
# Out:
# 0. (H . |0〉) = |+〉
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (H . |0〉, |+〉)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. H . |0〉
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. |+〉
#    core type: Operation
#    operator: 10
#    operand: 7
# 5. .
#    core type: Literal
#    sub-expressions:
# 6. (H, |0〉)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. H
#    core type: Literal
#    sub-expressions:
# 9. |0〉
#    core type: Operation
#    operator: 10
#    operand: 11
# 10. KET
#     core type: Literal
#     sub-expressions:
# 11. 0
#     core type: Literal
#     sub-expressions:
