# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#ket_one_in_qubit_space">ket_one_in_qubit_space</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.physics.quantum import ket_one_in_qubit_space

# %%
# %dependencies ket_one_in_qubit_space
# Out:
# <h3>No theorems/conjectures depend upon ket_one_in_qubit_space</h3>
