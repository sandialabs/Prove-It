# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#expand_register_with_zero_ket">expand_register_with_zero_ket</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.physics.quantum import expand_register_with_zero_ket

# %%
# %dependencies expand_register_with_zero_ket
# Out:
# <h3>No theorems/conjectures depend upon expand_register_with_zero_ket</h3>
