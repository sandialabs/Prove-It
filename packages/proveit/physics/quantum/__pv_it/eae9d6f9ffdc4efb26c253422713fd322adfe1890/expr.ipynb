# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#transformedQubitStateInQubitSpace">transformedQubitStateInQubitSpace</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum._theorems_ import transformedQubitStateInQubitSpace

# %%
# check that the built expression is the same as the stored expression
# %check_expr transformedQubitStateInQubitSpace
# Out:
# Passed sanity check: built 'transformedQubitStateInQubitSpace' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(transformedQubitStateInQubitSpace.latex())
# Out:
# \vdash \forall_{x \in \mathbb{C}^{2}}~\left[\forall_{U \in \left[SU\right]\left(2\right)}~\left(\left(U \thinspace x\right) \in \mathbb{C}^{2}\right)\right]

# %%
# display the expression information
transformedQubitStateInQubitSpace.exprInfo()
# Out:
# 0. forall_{x in Complexes^{2}} [forall_{U in [SU](2)} ((U . x) in Complexes^{2})]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. x -> {forall_{U in [SU](2)} ((U . x) in Complexes^{2}) if x in Complexes^{2}.
#    core type: Lambda
#    parameter: 23
#    body: 2
# 2. {forall_{U in [SU](2)} ((U . x) in Complexes^{2}) if x in Complexes^{2}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{U in [SU](2)} ((U . x) in Complexes^{2})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. x in Complexes^{2}
#    core type: Operation
#    operator: 12
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. U -> {(U . x) in Complexes^{2} if U in [SU](2).
#    core type: Lambda
#    parameter: 22
#    body: 8
# 7. (x, Complexes^{2})
#    core type: ExprTuple
#    sub-expressions: 23, 15
# 8. {(U . x) in Complexes^{2} if U in [SU](2).
#    core type: Conditional
#    value: 9
#    condition: 10
# ...
