# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import Psi, k, n
from proveit.linalg import MatrixProd
from proveit.logic import InSet
from proveit.number import Complexes
from proveit.physics.quantum import Ket, RegisterBra

# %%
# build up the expression from sub-expressions
expr = InSet(MatrixProd(RegisterBra(k, n), Ket(Psi)), Complexes)
# Out:
# expr: {n}_〈k|Psi〉 in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# {_{n}}\langle k \rvert\Psi \rangle \in \mathbb{C}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {n}_〈k|Psi〉 in Complexes
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. ({n}_〈k|Psi〉, Complexes)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. {n}_〈k| . |Psi〉
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. Complexes
#    core type: Literal
#    sub-expressions:
# 5. .
#    core type: Literal
#    sub-expressions:
# 6. ({n}_〈k|, |Psi〉)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. {n}_〈k|
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. |Psi〉
#    core type: Operation
#    operator: 11
#    operand: 12
# 9. REGISTER_BRA
#    core type: Literal
#    sub-expressions:
# 10. (k, n)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. KET
#     core type: Literal
#     sub-expressions:
# 12. Psi
#     core type: Variable
#     sub-expressions:
# 13. k
#     core type: Variable
#     sub-expressions:
# 14. n
#     core type: Variable
#     sub-expressions:
