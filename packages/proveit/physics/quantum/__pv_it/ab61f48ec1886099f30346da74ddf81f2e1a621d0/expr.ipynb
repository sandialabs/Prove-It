# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit.core_expr_types._common_ import x_1_to_n
from proveit.logic import Forall, InSet
from proveit.number import Add, Complexes, Exp, two

# %%
# build up the expression from sub-expressions
subExpr1 = Exp(Complexes, two)
expr = Forall([x_1_to_n], InSet(Add(x_1_to_n), subExpr1), domain = subExpr1)
# Out:
# expr: forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes^{2}} ((x_{1} + ..x_{_a}.. + x_{n}) in Complexes^{2})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x_{1}, \ldots, x_{n} \in \mathbb{C}^{2}}~\left(\left(x_{1} + \ldots + x_{n}\right) \in \mathbb{C}^{2}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes^{2}} ((x_{1} + ..x_{_a}.. + x_{n}) in Complexes^{2})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x_{1}, ..x_{_a}.., x_{n}) -> {(x_{1} + ..x_{_a}.. + x_{n}) in Complexes^{2} if (x_{1} in Complexes^{2}) and ..(x_{_a} in Complexes^{2}).. and (x_{n} in Complexes^{2}).
#    core type: Lambda
#    parameter: 14
#    body: 3
# 3. {(x_{1} + ..x_{_a}.. + x_{n}) in Complexes^{2} if (x_{1} in Complexes^{2}) and ..(x_{_a} in Complexes^{2}).. and (x_{n} in Complexes^{2}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (x_{1} + ..x_{_a}.. + x_{n}) in Complexes^{2}
#    core type: Operation
#    operator: 19
#    operands: 6
# 5. (x_{1} in Complexes^{2}) and ..(x_{_a} in Complexes^{2}).. and (x_{n} in Complexes^{2})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x_{1} + ..x_{_a}.. + x_{n}, Complexes^{2})
#    core type: ExprTuple
#    sub-expressions: 9, 22
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x_{1} in Complexes^{2}, ..x_{_a} in Complexes^{2}.., x_{n} in Complexes^{2})
#    core type: ExprTuple
#    sub-expressions: 10
# 9. x_{1} + ..x_{_a}.. + x_{n}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x_{1} in Complexes^{2}), ..(x_{_a} in Complexes^{2}).., (x_{n} in Complexes^{2})
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 17
#     end_index: 18
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. _a -> (x_{_a} in Complexes^{2})
#     core type: Lambda
#     parameter: 24
#     body: 15
# 14. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 15. x_{_a} in Complexes^{2}
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. _a -> x_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 21
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. n
#     core type: Variable
#     sub-expressions:
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (x_{_a}, Complexes^{2})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. x_{_a}
#     core type: IndexedVar
# variable: 23
# index: 24
# 22. Complexes^{2}
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. _a
#     core type: Variable
#     sub-expressions:
# 25. Exp
#     core type: Literal
#     sub-expressions:
# 26. (Complexes, 2)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. Complexes
#     core type: Literal
#     sub-expressions:
# 28. 2
#     core type: Literal
#     sub-expressions:
