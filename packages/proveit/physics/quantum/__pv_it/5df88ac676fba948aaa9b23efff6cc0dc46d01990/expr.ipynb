# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import Psi, k, m, n
from proveit.linalg import MatrixProd, TensorExp
from proveit.logic import Equals, Forall, InSet
from proveit.number import Abs, Add, Complexes, Exp, Interval, Neg, one, two, zero
from proveit.physics.quantum import Ket, Meas, RegisterBra
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
subExpr1 = Ket(Psi)
expr = Conditional(Forall([Psi, m], Equals(Prob(Equals(m, k), m), Exp(Abs(MatrixProd(RegisterBra(k, n), subExpr1)), two)), conditions = [InSet(subExpr1, TensorExp([Exp(Complexes, two)], n)), Equals(m, Meas(subExpr1))]), InSet(k, Interval(zero, Add(Exp(two, n), Neg(one)))))
# Out:
# expr: {forall_{Psi, m | |Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉)} (Pr_{m}[m = k] = |{n}_〈k| . |Psi〉|^{2}) if k in {0...2^{n} - 1}.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{\Psi, m~|~\lvert \Psi \rangle \in \left(\mathbb{C}^{2}\right)^{\otimes n}, m = \mathcal{M}(\lvert \Psi \rangle)}~\left(Pr_{m}[m = k] = \left|{_{n}}\langle k \rvert \thinspace \lvert \Psi \rangle\right|^{2}\right) \textrm{ if } k \in \{0 \dots 2^{n} - 1\}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{Psi, m | |Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉)} (Pr_{m}[m = k] = |{n}_〈k| . |Psi〉|^{2}) if k in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{Psi, m | |Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉)} (Pr_{m}[m = k] = |{n}_〈k| . |Psi〉|^{2})
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. k in {0...2^{n} - 1}
#    core type: Operation
#    operator: 27
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (Psi, m) -> {Pr_{m}[m = k] = |{n}_〈k| . |Psi〉|^{2} if |Psi〉 in (Complexes^{2})^{otimes n} ,  m = MEAS(|Psi〉).
#    core type: Lambda
#    parameters: 6\n   body: 7
# 5. (k, {0...2^{n} - 1})
#    core type: ExprTuple
#    sub-expressions: 59, 8
# 6. (Psi, m)
#    core type: ExprTuple
#    sub-expressions: 56, 46
# 7. {Pr_{m}[m = k] = |{n}_〈k| . |Psi〉|^{2} if |Psi〉 in (Complexes^{2})^{otimes n} ,  m = MEAS(|Psi〉).
#    core type: Conditional
#    value: 9
# ...
