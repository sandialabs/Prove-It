# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.linalg.ScalarProd.html">ScalarProd</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Operation
from proveit._common_ import f, k, n
from proveit.linalg import ScalarProd
from proveit.physics.quantum import RegisterKet

# %%
# build up the expression from sub-expressions
expr = ScalarProd(Operation(f, k), RegisterKet(k, n))
# Out:
# expr: [f](k) * |k〉_{n}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[f\right]\left(k\right) \thinspace \lvert k \rangle_{n}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [f](k) * |k〉_{n}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. *
#    core type: Literal
#    sub-expressions:
# 2. ([f](k), |k〉_{n})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [f](k)
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. |k〉_{n}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. f
#    core type: Variable
#    sub-expressions:
# 6. REGISTER_KET
#    core type: Literal
#    sub-expressions:
# 7. (k, n)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. k
#    core type: Variable
#    sub-expressions:
# 9. n
#    core type: Variable
#    sub-expressions:
