# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import k, n
from proveit.linalg import TensorExp
from proveit.logic import Forall, InSet
from proveit.number import Add, Complexes, Exp, Interval, NaturalsPos, Neg, one, two, zero
from proveit.physics.quantum import RegisterKet

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([k], InSet(RegisterKet(k, n), TensorExp([Exp(Complexes, two)], n)), domain = Interval(zero, Add(Exp(two, n), Neg(one)))), InSet(n, NaturalsPos))
# Out:
# expr: {forall_{k in {0...2^{n} - 1}} (|k〉_{n} in (Complexes^{2})^{otimes n}) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{k \in \{0 \dots 2^{n} - 1\}}~\left(\lvert k \rangle_{n} \in \left(\mathbb{C}^{2}\right)^{\otimes n}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{k in {0...2^{n} - 1}} (|k〉_{n} in (Complexes^{2})^{otimes n}) if n in NaturalsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{k in {0...2^{n} - 1}} (|k〉_{n} in (Complexes^{2})^{otimes n})
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. n in NaturalsPos
#    core type: Operation
#    operator: 11
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. k -> {|k〉_{n} in (Complexes^{2})^{otimes n} if k in {0...2^{n} - 1}.
#    core type: Lambda
#    parameter: 22
#    body: 6
# 5. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 38, 7
# 6. {|k〉_{n} in (Complexes^{2})^{otimes n} if k in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 8
#    condition: 9
# 7. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 8. |k〉_{n} in (Complexes^{2})^{otimes n}
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. k in {0...2^{n} - 1}
#    core type: Operation
# ...
