# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.linalg.MatrixProd.html">MatrixProd</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Operation
from proveit._common_ import U, f, k, l, n
from proveit.linalg import MatrixProd, ScalarProd
from proveit.number import Add, Exp, Interval, Neg, Sum, one, two, zero
from proveit.physics.quantum import RegisterBra, RegisterKet

# %%
# build up the expression from sub-expressions
expr = MatrixProd(RegisterBra(l, n), MatrixProd(U, Sum([k], ScalarProd(Operation(f, k), RegisterKet(k, n)), domain = Interval(zero, Add(Exp(two, n), Neg(one))))))
# Out:
# expr: {n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# {_{n}}\langle l \rvert \thinspace \left(U \thinspace \left(\sum_{k=0}^{2^{n} - 1} \left(\left[f\right]\left(k\right) \thinspace \lvert k \rangle_{n}\right)\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))
#    core type: Operation
#    operator: 6
#    operands: 1
# 1. ({n}_〈l|, U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. {n}_〈l|
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n}))
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. REGISTER_BRA
#    core type: Literal
#    sub-expressions:
# 5. (l, n)
#    core type: ExprTuple
#    sub-expressions: 8, 40
# 6. .
#    core type: Literal
#    sub-expressions:
# 7. (U, Sum_{k=0}^{2^{n} - 1} [f](k) * |k〉_{n})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. l
#    core type: Variable
#    sub-expressions:
# 9. U
#    core type: Variable
#    sub-expressions:
# 10. Sum_{k=0}^{2^{n} - 1} [f](k) * |k〉_{n}
#     core type: Operation
#     operator: 11
#     operand: 12
# 11. Sum
#     core type: Literal
#     sub-expressions:
# ...
