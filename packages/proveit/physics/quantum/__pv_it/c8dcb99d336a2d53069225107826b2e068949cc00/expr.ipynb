# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#registerQubitComplexAmplitude">registerQubitComplexAmplitude</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum._theorems_ import registerQubitComplexAmplitude

# %%
# check that the built expression is the same as the stored expression
# %check_expr registerQubitComplexAmplitude
# Out:
# Passed sanity check: built 'registerQubitComplexAmplitude' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(registerQubitComplexAmplitude.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{k \in \{0 \dots 2^{n} - 1\}}~\left[\forall_{\Psi~|~\lvert \Psi \rangle \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left({_{n}}\langle k \rvert\Psi \rangle \in \mathbb{C}\right)\right]\right]

# %%
# display the expression information
registerQubitComplexAmplitude.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{k in {0...2^{n} - 1}} [forall_{Psi | |Psi〉 in (Complexes^{2})^{otimes n}} ({n}_〈k|Psi〉 in Complexes)]]
#    core type: Operation
#    operator: 11
#    operand: 1
# 1. n -> {forall_{k in {0...2^{n} - 1}} [forall_{Psi | |Psi〉 in (Complexes^{2})^{otimes n}} ({n}_〈k|Psi〉 in Complexes)] if n in NaturalsPos.
#    core type: Lambda
#    parameter: 47
#    body: 2
# 2. {forall_{k in {0...2^{n} - 1}} [forall_{Psi | |Psi〉 in (Complexes^{2})^{otimes n}} ({n}_〈k|Psi〉 in Complexes)] if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{k in {0...2^{n} - 1}} [forall_{Psi | |Psi〉 in (Complexes^{2})^{otimes n}} ({n}_〈k|Psi〉 in Complexes)]
#    core type: Operation
#    operator: 11
#    operand: 5
# 4. n in NaturalsPos
#    core type: Operation
#    operator: 21
#    operands: 6
# 5. k -> {forall_{Psi | |Psi〉 in (Complexes^{2})^{otimes n}} ({n}_〈k|Psi〉 in Complexes) if k in {0...2^{n} - 1}.
#    core type: Lambda
# ...
