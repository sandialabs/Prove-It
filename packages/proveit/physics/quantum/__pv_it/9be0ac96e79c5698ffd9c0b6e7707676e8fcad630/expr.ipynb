# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#registerBraOverSummedKet">registerBraOverSummedKet</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum._theorems_ import registerBraOverSummedKet

# %%
# check that the built expression is the same as the stored expression
# %check_expr registerBraOverSummedKet
# Out:
# Passed sanity check: built 'registerBraOverSummedKet' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(registerBraOverSummedKet.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{U \in \left[SU\right]\left(2^{n}\right)}~\left[\forall_{l \in \{0 \dots 2^{n} - 1\}}~\left[\forall_{f}~\left(\left({_{n}}\langle l \rvert \thinspace \left(U \thinspace \left(\sum_{k=0}^{2^{n} - 1} \left(\left[f\right]\left(k\right) \thinspace \lvert k \rangle_{n}\right)\right)\right)\right) = \left(\sum_{k=0}^{2^{n} - 1} \left(\left[f\right]\left(k\right) \cdot \left({_{n}}\langle l \rvert \thinspace U \thinspace \lvert k \rangle_{n}\right)\right)\right)\right)\right]\right]\right]

# %%
# display the expression information
registerBraOverSummedKet.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{U in [SU](2^{n})} [forall_{l in {0...2^{n} - 1}} [forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))]]]
#    core type: Operation
#    operator: 18
#    operand: 1
# 1. n -> {forall_{U in [SU](2^{n})} [forall_{l in {0...2^{n} - 1}} [forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))]] if n in NaturalsPos.
#    core type: Lambda
#    parameter: 72
#    body: 2
# 2. {forall_{U in [SU](2^{n})} [forall_{l in {0...2^{n} - 1}} [forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))]] if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# ...
