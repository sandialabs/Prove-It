# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import Psi, k, m, n
from proveit.linalg import TensorExp
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Complexes, Exp, Interval, Neg, Sum, one, two, zero
from proveit.physics.quantum import Ket, Meas
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
subExpr1 = Ket(Psi)
expr = Forall([Psi, m], Equals(Sum([k], Prob(Equals(m, k), m), domain = Interval(zero, Add(Exp(two, n), Neg(one)))), one), conditions = [InSet(subExpr1, TensorExp([Exp(Complexes, two)], n)), Equals(m, Meas(subExpr1))])
# Out:
# expr: forall_{Psi, m | |Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉)} ((Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{\Psi, m~|~\lvert \Psi \rangle \in \left(\mathbb{C}^{2}\right)^{\otimes n}, m = \mathcal{M}(\lvert \Psi \rangle)}~\left(\left(\sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]\right) = 1\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{Psi, m | |Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉)} ((Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (Psi, m) -> {(Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1 if |Psi〉 in (Complexes^{2})^{otimes n} ,  m = MEAS(|Psi〉).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (Psi, m)
#    core type: ExprTuple
#    sub-expressions: 32, 41
# 4. {(Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1 if |Psi〉 in (Complexes^{2})^{otimes n} ,  m = MEAS(|Psi〉).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1
#    core type: Operation
#    operator: 36
#    operands: 7
# 6. (|Psi〉 in (Complexes^{2})^{otimes n}) and (m = MEAS(|Psi〉))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k], 1)
#    core type: ExprTuple
#    sub-expressions: 10, 53
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (|Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]
#     core type: Operation
#     operator: 13
#     operand: 14
# 11. |Psi〉 in (Complexes^{2})^{otimes n}
#     core type: Operation
#     operator: 28
#     operands: 15
# 12. m = MEAS(|Psi〉)
#     core type: Operation
#     operator: 36
#     operands: 16
# 13. Sum
#     core type: Literal
#     sub-expressions:
# 14. k -> {Pr_{m}[m = k] if k in {0...2^{n} - 1}.
#     core type: Lambda
#     parameter: 42
#     body: 17
# 15. (|Psi〉, (Complexes^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 25, 18
# 16. (m, MEAS(|Psi〉))
#     core type: ExprTuple
#     sub-expressions: 41, 19
# 17. {Pr_{m}[m = k] if k in {0...2^{n} - 1}.
#     core type: Conditional
#     value: 20
#     condition: 21
# 18. (Complexes^{2})^{otimes n}
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. MEAS(|Psi〉)
#     core type: Operation
#     operator: 24
#     operand: 25
# 20. Pr_{m}[m = k]
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. k in {0...2^{n} - 1}
#     core type: Operation
#     operator: 28
#     operands: 29
# 22. otimes
#     core type: Literal
#     sub-expressions:
# 23. ((Complexes^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 30, 55
# 24. MEAS
#     core type: Literal
#     sub-expressions:
# 25. |Psi〉
#     core type: Operation
#     operator: 31
#     operand: 32
# 26. PROB
#     core type: Literal
#     sub-expressions:
# 27. (m = k, m)
#     core type: ExprTuple
#     sub-expressions: 33, 41
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. (k, {0...2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 42, 34
# 30. (Complexes^{2})
#     core type: ExprTuple
#     sub-expressions: 35
# 31. KET
#     core type: Literal
#     sub-expressions:
# 32. Psi
#     core type: Variable
#     sub-expressions:
# 33. m = k
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. {0...2^{n} - 1}
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. Complexes^{2}
#     core type: Operation
#     operator: 50
#     operands: 40
# 36. =
#     core type: Literal
#     sub-expressions:
# 37. (m, k)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 38. Interval
#     core type: Literal
#     sub-expressions:
# 39. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 40. (Complexes, 2)
#     core type: ExprTuple
#     sub-expressions: 45, 54
# 41. m
#     core type: Variable
#     sub-expressions:
# 42. k
#     core type: Variable
#     sub-expressions:
# 43. 0
#     core type: Literal
#     sub-expressions:
# 44. 2^{n} - 1
#     core type: Operation
#     operator: 46
#     operands: 47
# 45. Complexes
#     core type: Literal
#     sub-expressions:
# 46. +
#     core type: Literal
#     sub-expressions:
# 47. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 48. 2^{n}
#     core type: Operation
#     operator: 50
#     operands: 51
# 49. -1
#     core type: Operation
#     operator: 52
#     operand: 53
# 50. Exp
#     core type: Literal
#     sub-expressions:
# 51. (2, n)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. -
#     core type: Literal
#     sub-expressions:
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. 2
#     core type: Literal
#     sub-expressions:
# 55. n
#     core type: Variable
#     sub-expressions:
