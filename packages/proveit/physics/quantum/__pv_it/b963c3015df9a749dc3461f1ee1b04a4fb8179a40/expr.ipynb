# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.number.Sum.html">Sum</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Operation
from proveit._common_ import f, k, n
from proveit.linalg import ScalarProd
from proveit.number import Add, Exp, Interval, Neg, Sum, one, two, zero
from proveit.physics.quantum import RegisterKet

# %%
# build up the expression from sub-expressions
expr = Sum([k], ScalarProd(Operation(f, k), RegisterKet(k, n)), domain = Interval(zero, Add(Exp(two, n), Neg(one))))
# Out:
# expr: Sum_{k=0}^{2^{n} - 1} [f](k) * |k〉_{n}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \sum_{k=0}^{2^{n} - 1} \left[f\right]\left(k\right) \thinspace \lvert k \rangle_{n}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. Sum_{k=0}^{2^{n} - 1} [f](k) * |k〉_{n}
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. Sum
#    core type: Literal
#    sub-expressions:
# 2. k -> {[f](k) * |k〉_{n} if k in {0...2^{n} - 1}.
#    core type: Lambda
#    parameter: 18
#    body: 3
# 3. {[f](k) * |k〉_{n} if k in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. [f](k) * |k〉_{n}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. k in {0...2^{n} - 1}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. *
#    core type: Literal
#    sub-expressions:
# 7. ([f](k), |k〉_{n})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (k, {0...2^{n} - 1})
#    core type: ExprTuple
#    sub-expressions: 18, 12
# 10. [f](k)
#     core type: Operation
#     operator: 13
#     operand: 18
# 11. |k〉_{n}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. {0...2^{n} - 1}
# ...
