# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import n
from proveit.core_expr_types._common_ import x_1_to_n
from proveit.logic import Forall, InSet
from proveit.number import Add, Complexes, Exp, NaturalsPos, two

# %%
# build up the expression from sub-expressions
subExpr1 = Exp(Complexes, two)
expr = Conditional(Forall([x_1_to_n], InSet(Add(x_1_to_n), subExpr1), domain = subExpr1), InSet(n, NaturalsPos))
# Out:
# expr: {forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes^{2}} ((x_{1} + ..x_{_a}.. + x_{n}) in Complexes^{2}) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x_{1}, \ldots, x_{n} \in \mathbb{C}^{2}}~\left(\left(x_{1} + \ldots + x_{n}\right) \in \mathbb{C}^{2}\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes^{2}} ((x_{1} + ..x_{_a}.. + x_{n}) in Complexes^{2}) if n in NaturalsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x_{1}, ..x_{_a}.., x_{n} in Complexes^{2}} ((x_{1} + ..x_{_a}.. + x_{n}) in Complexes^{2})
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. n in NaturalsPos
#    core type: Operation
#    operator: 23
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x_{1}, ..x_{_a}.., x_{n}) -> {(x_{1} + ..x_{_a}.. + x_{n}) in Complexes^{2} if (x_{1} in Complexes^{2}) and ..(x_{_a} in Complexes^{2}).. and (x_{n} in Complexes^{2}).
#    core type: Lambda
#    parameter: 18
#    body: 6
# 5. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 22, 7
# 6. {(x_{1} + ..x_{_a}.. + x_{n}) in Complexes^{2} if (x_{1} in Complexes^{2}) and ..(x_{_a} in Complexes^{2}).. and (x_{n} in Complexes^{2}).
#    core type: Conditional
#    value: 8
#    condition: 9
# 7. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 8. (x_{1} + ..x_{_a}.. + x_{n}) in Complexes^{2}
#    core type: Operation
#    operator: 23
#    operands: 10
# 9. (x_{1} in Complexes^{2}) and ..(x_{_a} in Complexes^{2}).. and (x_{n} in Complexes^{2})
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x_{1} + ..x_{_a}.. + x_{n}, Complexes^{2})
#     core type: ExprTuple
#     sub-expressions: 13, 26
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (x_{1} in Complexes^{2}, ..x_{_a} in Complexes^{2}.., x_{n} in Complexes^{2})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. x_{1} + ..x_{_a}.. + x_{n}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (x_{1} in Complexes^{2}), ..(x_{_a} in Complexes^{2}).., (x_{n} in Complexes^{2})
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 21
#     end_index: 22
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 17. _a -> (x_{_a} in Complexes^{2})
#     core type: Lambda
#     parameter: 28
#     body: 19
# 18. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 19. x_{_a} in Complexes^{2}
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. _a -> x_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 25
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. n
#     core type: Variable
#     sub-expressions:
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (x_{_a}, Complexes^{2})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. x_{_a}
#     core type: IndexedVar
# variable: 27
# index: 28
# 26. Complexes^{2}
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. _a
#     core type: Variable
#     sub-expressions:
# 29. Exp
#     core type: Literal
#     sub-expressions:
# 30. (Complexes, 2)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 31. Complexes
#     core type: Literal
#     sub-expressions:
# 32. 2
#     core type: Literal
#     sub-expressions:
