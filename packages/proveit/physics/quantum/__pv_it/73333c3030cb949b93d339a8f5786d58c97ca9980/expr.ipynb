# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Operation
from proveit._common_ import U, f, k, l, n
from proveit.linalg import MatrixProd, SU, ScalarProd
from proveit.logic import Equals, Forall
from proveit.number import Add, Exp, Interval, Mult, Neg, Sum, one, two, zero
from proveit.physics.quantum import RegisterBra, RegisterKet

# %%
# build up the expression from sub-expressions
subExpr1 = [k]
subExpr2 = Operation(f, k)
subExpr3 = RegisterBra(l, n)
subExpr4 = RegisterKet(k, n)
subExpr5 = Exp(two, n)
subExpr6 = Interval(zero, Add(subExpr5, Neg(one)))
expr = Forall([U], Forall([l], Forall([f], Equals(MatrixProd(subExpr3, MatrixProd(U, Sum(subExpr1, ScalarProd(subExpr2, subExpr4), domain = subExpr6))), Sum(subExpr1, Mult(subExpr2, MatrixProd(subExpr3, U, subExpr4)), domain = subExpr6))), domain = subExpr6), domain = SU(subExpr5))
# Out:
# expr: forall_{U in [SU](2^{n})} [forall_{l in {0...2^{n} - 1}} [forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))]]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{U \in \left[SU\right]\left(2^{n}\right)}~\left[\forall_{l \in \{0 \dots 2^{n} - 1\}}~\left[\forall_{f}~\left(\left({_{n}}\langle l \rvert \thinspace \left(U \thinspace \left(\sum_{k=0}^{2^{n} - 1} \left(\left[f\right]\left(k\right) \thinspace \lvert k \rangle_{n}\right)\right)\right)\right) = \left(\sum_{k=0}^{2^{n} - 1} \left(\left[f\right]\left(k\right) \cdot \left({_{n}}\langle l \rvert \thinspace U \thinspace \lvert k \rangle_{n}\right)\right)\right)\right)\right]\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{U in [SU](2^{n})} [forall_{l in {0...2^{n} - 1}} [forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))]]
#    core type: Operation
#    operator: 12
#    operand: 1
# 1. U -> {forall_{l in {0...2^{n} - 1}} [forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))] if U in [SU](2^{n}).
#    core type: Lambda
#    parameter: 38
#    body: 2
# 2. {forall_{l in {0...2^{n} - 1}} [forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))] if U in [SU](2^{n}).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{l in {0...2^{n} - 1}} [forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))]
#    core type: Operation
#    operator: 12
#    operand: 5
# 4. U in [SU](2^{n})
#    core type: Operation
#    operator: 41
#    operands: 6
# 5. l -> {forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n})))) if l in {0...2^{n} - 1}.
#    core type: Lambda
#    parameter: 48
#    body: 7
# 6. (U, [SU](2^{n}))
#    core type: ExprTuple
#    sub-expressions: 38, 8
# 7. {forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n})))) if l in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 9
#    condition: 10
# 8. [SU](2^{n})
#    core type: Operation
#    operator: 11
#    operand: 59
# 9. forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. l in {0...2^{n} - 1}
#     core type: Operation
#     operator: 41
#     operands: 14
# 11. SU
#     core type: Literal
#     sub-expressions:
# 12. forall
#     core type: Literal
#     sub-expressions:
# 13. f -> (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))
#     core type: Lambda
#     parameter: 49
#     body: 15
# 14. (l, {0...2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 48, 47
# 15. ({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n})))
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. ({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n}))), Sum_{k=0}^{2^{n} - 1} [f](k) * ({n}_〈l| . U . |k〉_{n}))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. {n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))
#     core type: Operation
#     operator: 33
#     operands: 20
# 19. Sum_{k=0}^{2^{n} - 1} [f](k) * ({n}_〈l| . U . |k〉_{n})
#     core type: Operation
#     operator: 29
#     operand: 21
# 20. ({n}_〈l|, U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))
#     core type: ExprTuple
#     sub-expressions: 37, 22
# 21. k -> {[f](k) * ({n}_〈l| . U . |k〉_{n}) if k in {0...2^{n} - 1}.
#     core type: Lambda
#     parameter: 54
#     body: 23
# 22. U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n}))
#     core type: Operation
#     operator: 33
#     operands: 24
# 23. {[f](k) * ({n}_〈l| . U . |k〉_{n}) if k in {0...2^{n} - 1}.
#     core type: Conditional
#     value: 25
#     condition: 36
# 24. (U, Sum_{k=0}^{2^{n} - 1} [f](k) * |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 38, 26
# 25. [f](k) * ({n}_〈l| . U . |k〉_{n})
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. Sum_{k=0}^{2^{n} - 1} [f](k) * |k〉_{n}
#     core type: Operation
#     operator: 29
#     operand: 30
# 27. *
#     core type: Literal
#     sub-expressions:
# 28. ([f](k), {n}_〈l| . U . |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 45, 31
# 29. Sum
#     core type: Literal
#     sub-expressions:
# 30. k -> {[f](k) * |k〉_{n} if k in {0...2^{n} - 1}.
#     core type: Lambda
#     parameter: 54
#     body: 32
# 31. {n}_〈l| . U . |k〉_{n}
#     core type: Operation
#     operator: 33
#     operands: 34
# 32. {[f](k) * |k〉_{n} if k in {0...2^{n} - 1}.
#     core type: Conditional
#     value: 35
#     condition: 36
# 33. .
#     core type: Literal
#     sub-expressions:
# 34. ({n}_〈l|, U, |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 37, 38, 46
# 35. [f](k) * |k〉_{n}
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. k in {0...2^{n} - 1}
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. {n}_〈l|
#     core type: Operation
#     operator: 43
#     operands: 44
# 38. U
#     core type: Variable
#     sub-expressions:
# 39. *
#     core type: Literal
#     sub-expressions:
# 40. ([f](k), |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 41. in
#     core type: Literal
#     sub-expressions:
# 42. (k, {0...2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 54, 47
# 43. REGISTER_BRA
#     core type: Literal
#     sub-expressions:
# 44. (l, n)
#     core type: ExprTuple
#     sub-expressions: 48, 66
# 45. [f](k)
#     core type: Operation
#     operator: 49
#     operand: 54
# 46. |k〉_{n}
#     core type: Operation
#     operator: 50
#     operands: 51
# 47. {0...2^{n} - 1}
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. l
#     core type: Variable
#     sub-expressions:
# 49. f
#     core type: Variable
#     sub-expressions:
# 50. REGISTER_KET
#     core type: Literal
#     sub-expressions:
# 51. (k, n)
#     core type: ExprTuple
#     sub-expressions: 54, 66
# 52. Interval
#     core type: Literal
#     sub-expressions:
# 53. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 54. k
#     core type: Variable
#     sub-expressions:
# 55. 0
#     core type: Literal
#     sub-expressions:
# 56. 2^{n} - 1
#     core type: Operation
#     operator: 57
#     operands: 58
# 57. +
#     core type: Literal
#     sub-expressions:
# 58. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 59. 2^{n}
#     core type: Operation
#     operator: 61
#     operands: 62
# 60. -1
#     core type: Operation
#     operator: 63
#     operand: 64
# 61. Exp
#     core type: Literal
#     sub-expressions:
# 62. (2, n)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 63. -
#     core type: Literal
#     sub-expressions:
# 64. 1
#     core type: Literal
#     sub-expressions:
# 65. 2
#     core type: Literal
#     sub-expressions:
# 66. n
#     core type: Variable
#     sub-expressions:
