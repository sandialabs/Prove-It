# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import alpha, n, x
from proveit.linalg import ScalarProd, TensorExp
from proveit.number import Complexes, Exp, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(ScalarProd(alpha, x), TensorExp([Exp(Complexes, two)], n))
# Out:
# expr: (alpha * x, (Complexes^{2})^{otimes n})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\alpha \thinspace x, \left(\mathbb{C}^{2}\right)^{\otimes n}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (alpha * x, (Complexes^{2})^{otimes n})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. alpha * x
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (Complexes^{2})^{otimes n}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. *
#    core type: Literal
#    sub-expressions:
# 4. (alpha, x)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. otimes
#    core type: Literal
#    sub-expressions:
# 6. ((Complexes^{2}), n)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. alpha
#    core type: Variable
#    sub-expressions:
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. (Complexes^{2})
#    core type: ExprTuple
#    sub-expressions: 11
# 10. n
#     core type: Variable
#     sub-expressions:
# 11. Complexes^{2}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (Complexes, 2)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. Complexes
#     core type: Literal
#     sub-expressions:
# 15. 2
#     core type: Literal
#     sub-expressions:
