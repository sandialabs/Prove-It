# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import Psi, k, n
from proveit.linalg import MatrixProd, TensorExp
from proveit.logic import Forall, InSet
from proveit.number import Add, Complexes, Exp, Interval, Neg, one, two, zero
from proveit.physics.quantum import Ket, RegisterBra

# %%
# build up the expression from sub-expressions
subExpr1 = Ket(Psi)
expr = Lambda(k, Conditional(Forall([Psi], InSet(MatrixProd(RegisterBra(k, n), subExpr1), Complexes), condition = InSet(subExpr1, TensorExp([Exp(Complexes, two)], n))), InSet(k, Interval(zero, Add(Exp(two, n), Neg(one))))))
# Out:
# expr: k -> {forall_{Psi | |Psi〉 in (Complexes^{2})^{otimes n}} ({n}_〈k|Psi〉 in Complexes) if k in {0...2^{n} - 1}.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# k \mapsto \left\{\forall_{\Psi~|~\lvert \Psi \rangle \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left({_{n}}\langle k \rvert\Psi \rangle \in \mathbb{C}\right) \textrm{ if } k \in \{0 \dots 2^{n} - 1\}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. k -> {forall_{Psi | |Psi〉 in (Complexes^{2})^{otimes n}} ({n}_〈k|Psi〉 in Complexes) if k in {0...2^{n} - 1}.
#    core type: Lambda
#    parameter: 39
#    body: 1
# 1. {forall_{Psi | |Psi〉 in (Complexes^{2})^{otimes n}} ({n}_〈k|Psi〉 in Complexes) if k in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{Psi | |Psi〉 in (Complexes^{2})^{otimes n}} ({n}_〈k|Psi〉 in Complexes)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. k in {0...2^{n} - 1}
#    core type: Operation
#    operator: 14
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. Psi -> {{n}_〈k|Psi〉 in Complexes if |Psi〉 in (Complexes^{2})^{otimes n}.
#    core type: Lambda
#    parameter: 37
#    body: 7
# 6. (k, {0...2^{n} - 1})
#    core type: ExprTuple
#    sub-expressions: 39, 8
# 7. {{n}_〈k|Psi〉 in Complexes if |Psi〉 in (Complexes^{2})^{otimes n}.
#    core type: Conditional
#    value: 9
#    condition: 10
# 8. {0...2^{n} - 1}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. {n}_〈k|Psi〉 in Complexes
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. |Psi〉 in (Complexes^{2})^{otimes n}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. Interval
#     core type: Literal
#     sub-expressions:
# 12. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. ({n}_〈k|Psi〉, Complexes)
#     core type: ExprTuple
#     sub-expressions: 18, 43
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (|Psi〉, (Complexes^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 29, 19
# 16. 0
#     core type: Literal
#     sub-expressions:
# 17. 2^{n} - 1
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. {n}_〈k| . |Psi〉
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. (Complexes^{2})^{otimes n}
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 22. .
#     core type: Literal
#     sub-expressions:
# 23. ({n}_〈k|, |Psi〉)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 24. otimes
#     core type: Literal
#     sub-expressions:
# 25. ((Complexes^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 30, 40
# 26. 2^{n}
#     core type: Operation
#     operator: 41
#     operands: 31
# 27. -1
#     core type: Operation
#     operator: 32
#     operand: 33
# 28. {n}_〈k|
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. |Psi〉
#     core type: Operation
#     operator: 36
#     operand: 37
# 30. (Complexes^{2})
#     core type: ExprTuple
#     sub-expressions: 38
# 31. (2, n)
#     core type: ExprTuple
#     sub-expressions: 44, 40
# 32. -
#     core type: Literal
#     sub-expressions:
# 33. 1
#     core type: Literal
#     sub-expressions:
# 34. REGISTER_BRA
#     core type: Literal
#     sub-expressions:
# 35. (k, n)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. KET
#     core type: Literal
#     sub-expressions:
# 37. Psi
#     core type: Variable
#     sub-expressions:
# 38. Complexes^{2}
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. k
#     core type: Variable
#     sub-expressions:
# 40. n
#     core type: Variable
#     sub-expressions:
# 41. Exp
#     core type: Literal
#     sub-expressions:
# 42. (Complexes, 2)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 43. Complexes
#     core type: Literal
#     sub-expressions:
# 44. 2
#     core type: Literal
#     sub-expressions:
