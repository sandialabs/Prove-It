# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.linalg.MatrixProd.html">MatrixProd</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Operation
from proveit._common_ import U, f, k, n
from proveit.linalg import MatrixProd, ScalarProd
from proveit.number import Add, Exp, Interval, Neg, Sum, one, two, zero
from proveit.physics.quantum import RegisterKet

# %%
# build up the expression from sub-expressions
expr = MatrixProd(U, Sum([k], ScalarProd(Operation(f, k), RegisterKet(k, n)), domain = Interval(zero, Add(Exp(two, n), Neg(one)))))
# Out:
# expr: U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# U \thinspace \left(\sum_{k=0}^{2^{n} - 1} \left(\left[f\right]\left(k\right) \thinspace \lvert k \rangle_{n}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n}))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. .
#    core type: Literal
#    sub-expressions:
# 2. (U, Sum_{k=0}^{2^{n} - 1} [f](k) * |k〉_{n})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. U
#    core type: Variable
#    sub-expressions:
# 4. Sum_{k=0}^{2^{n} - 1} [f](k) * |k〉_{n}
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. Sum
#    core type: Literal
#    sub-expressions:
# 6. k -> {[f](k) * |k〉_{n} if k in {0...2^{n} - 1}.
#    core type: Lambda
#    parameter: 22
#    body: 7
# 7. {[f](k) * |k〉_{n} if k in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. [f](k) * |k〉_{n}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. k in {0...2^{n} - 1}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. ([f](k), |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (k, {0...2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 22, 16
# 14. [f](k)
#     core type: Operation
#     operator: 17
#     operand: 22
# 15. |k〉_{n}
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. {0...2^{n} - 1}
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. f
#     core type: Variable
#     sub-expressions:
# 18. REGISTER_KET
#     core type: Literal
#     sub-expressions:
# 19. (k, n)
#     core type: ExprTuple
#     sub-expressions: 22, 34
# 20. Interval
#     core type: Literal
#     sub-expressions:
# 21. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. k
#     core type: Variable
#     sub-expressions:
# 23. 0
#     core type: Literal
#     sub-expressions:
# 24. 2^{n} - 1
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. 2^{n}
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. -1
#     core type: Operation
#     operator: 31
#     operand: 32
# 29. Exp
#     core type: Literal
#     sub-expressions:
# 30. (2, n)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. -
#     core type: Literal
#     sub-expressions:
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. 2
#     core type: Literal
#     sub-expressions:
# 34. n
#     core type: Variable
#     sub-expressions:
