# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import Psi, k, n
from proveit.linalg import MatrixProd, TensorExp
from proveit.logic import Forall, InSet
from proveit.number import Add, Complexes, Exp, Interval, NaturalsPos, Neg, one, two, zero
from proveit.physics.quantum import Ket, RegisterBra

# %%
# build up the expression from sub-expressions
subExpr1 = Ket(Psi)
expr = Lambda(n, Conditional(Forall([k], Forall([Psi], InSet(MatrixProd(RegisterBra(k, n), subExpr1), Complexes), condition = InSet(subExpr1, TensorExp([Exp(Complexes, two)], n))), domain = Interval(zero, Add(Exp(two, n), Neg(one)))), InSet(n, NaturalsPos)))
# Out:
# expr: n -> {forall_{k in {0...2^{n} - 1}} [forall_{Psi | |Psi〉 in (Complexes^{2})^{otimes n}} ({n}_〈k|Psi〉 in Complexes)] if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{k \in \{0 \dots 2^{n} - 1\}}~\left[\forall_{\Psi~|~\lvert \Psi \rangle \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left({_{n}}\langle k \rvert\Psi \rangle \in \mathbb{C}\right)\right] \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{k in {0...2^{n} - 1}} [forall_{Psi | |Psi〉 in (Complexes^{2})^{otimes n}} ({n}_〈k|Psi〉 in Complexes)] if n in NaturalsPos.
#    core type: Lambda
#    parameter: 46
#    body: 1
# 1. {forall_{k in {0...2^{n} - 1}} [forall_{Psi | |Psi〉 in (Complexes^{2})^{otimes n}} ({n}_〈k|Psi〉 in Complexes)] if n in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{k in {0...2^{n} - 1}} [forall_{Psi | |Psi〉 in (Complexes^{2})^{otimes n}} ({n}_〈k|Psi〉 in Complexes)]
#    core type: Operation
#    operator: 10
#    operand: 4
# 3. n in NaturalsPos
#    core type: Operation
#    operator: 20
#    operands: 5
# 4. k -> {forall_{Psi | |Psi〉 in (Complexes^{2})^{otimes n}} ({n}_〈k|Psi〉 in Complexes) if k in {0...2^{n} - 1}.
#    core type: Lambda
#    parameter: 45
#    body: 6
# 5. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 46, 7
# ...
