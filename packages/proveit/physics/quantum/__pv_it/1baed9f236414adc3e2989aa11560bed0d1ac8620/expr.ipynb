# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Operation
from proveit._common_ import U, f, k, l, n
from proveit.linalg import MatrixProd, ScalarProd
from proveit.number import Add, Exp, Interval, Mult, Neg, Sum, one, two, zero
from proveit.physics.quantum import RegisterBra, RegisterKet

# %%
# build up the expression from sub-expressions
subExpr1 = [k]
subExpr2 = Operation(f, k)
subExpr3 = RegisterBra(l, n)
subExpr4 = RegisterKet(k, n)
subExpr5 = Interval(zero, Add(Exp(two, n), Neg(one)))
expr = ExprTuple(MatrixProd(subExpr3, MatrixProd(U, Sum(subExpr1, ScalarProd(subExpr2, subExpr4), domain = subExpr5))), Sum(subExpr1, Mult(subExpr2, MatrixProd(subExpr3, U, subExpr4)), domain = subExpr5))
# Out:
# expr: ({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n}))), Sum_{k=0}^{2^{n} - 1} [f](k) * ({n}_〈l| . U . |k〉_{n}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left({_{n}}\langle l \rvert \thinspace \left(U \thinspace \left(\sum_{k=0}^{2^{n} - 1} \left(\left[f\right]\left(k\right) \thinspace \lvert k \rangle_{n}\right)\right)\right), \sum_{k=0}^{2^{n} - 1} \left[f\right]\left(k\right) \cdot \left({_{n}}\langle l \rvert \thinspace U \thinspace \lvert k \rangle_{n}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n}))), Sum_{k=0}^{2^{n} - 1} [f](k) * ({n}_〈l| . U . |k〉_{n}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. {n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))
#    core type: Operation
#    operator: 16
#    operands: 3
# 2. Sum_{k=0}^{2^{n} - 1} [f](k) * ({n}_〈l| . U . |k〉_{n})
#    core type: Operation
#    operator: 12
#    operand: 4
# 3. ({n}_〈l|, U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))
#    core type: ExprTuple
#    sub-expressions: 20, 5
# 4. k -> {[f](k) * ({n}_〈l| . U . |k〉_{n}) if k in {0...2^{n} - 1}.
#    core type: Lambda
#    parameter: 37
#    body: 6
# 5. U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n}))
#    core type: Operation
#    operator: 16
#    operands: 7
# 6. {[f](k) * ({n}_〈l| . U . |k〉_{n}) if k in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 8
#    condition: 19
# 7. (U, Sum_{k=0}^{2^{n} - 1} [f](k) * |k〉_{n})
#    core type: ExprTuple
#    sub-expressions: 21, 9
# 8. [f](k) * ({n}_〈l| . U . |k〉_{n})
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. Sum_{k=0}^{2^{n} - 1} [f](k) * |k〉_{n}
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. ([f](k), {n}_〈l| . U . |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 28, 14
# 12. Sum
#     core type: Literal
#     sub-expressions:
# 13. k -> {[f](k) * |k〉_{n} if k in {0...2^{n} - 1}.
#     core type: Lambda
#     parameter: 37
#     body: 15
# 14. {n}_〈l| . U . |k〉_{n}
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. {[f](k) * |k〉_{n} if k in {0...2^{n} - 1}.
#     core type: Conditional
#     value: 18
#     condition: 19
# 16. .
#     core type: Literal
#     sub-expressions:
# 17. ({n}_〈l|, U, |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 20, 21, 29
# 18. [f](k) * |k〉_{n}
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. k in {0...2^{n} - 1}
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. {n}_〈l|
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. U
#     core type: Variable
#     sub-expressions:
# 22. *
#     core type: Literal
#     sub-expressions:
# 23. ([f](k), |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (k, {0...2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 37, 30
# 26. REGISTER_BRA
#     core type: Literal
#     sub-expressions:
# 27. (l, n)
#     core type: ExprTuple
#     sub-expressions: 31, 49
# 28. [f](k)
#     core type: Operation
#     operator: 32
#     operand: 37
# 29. |k〉_{n}
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. {0...2^{n} - 1}
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. l
#     core type: Variable
#     sub-expressions:
# 32. f
#     core type: Variable
#     sub-expressions:
# 33. REGISTER_KET
#     core type: Literal
#     sub-expressions:
# 34. (k, n)
#     core type: ExprTuple
#     sub-expressions: 37, 49
# 35. Interval
#     core type: Literal
#     sub-expressions:
# 36. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 37. k
#     core type: Variable
#     sub-expressions:
# 38. 0
#     core type: Literal
#     sub-expressions:
# 39. 2^{n} - 1
#     core type: Operation
#     operator: 40
#     operands: 41
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 42. 2^{n}
#     core type: Operation
#     operator: 44
#     operands: 45
# 43. -1
#     core type: Operation
#     operator: 46
#     operand: 47
# 44. Exp
#     core type: Literal
#     sub-expressions:
# 45. (2, n)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 46. -
#     core type: Literal
#     sub-expressions:
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. 2
#     core type: Literal
#     sub-expressions:
# 49. n
#     core type: Variable
#     sub-expressions:
