# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import Psi, k, m, n
from proveit.linalg import TensorExp
from proveit.logic import And, Equals, InSet
from proveit.number import Add, Complexes, Exp, Interval, Neg, Sum, one, two, zero
from proveit.physics.quantum import Ket, Meas
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
subExpr1 = Ket(Psi)
expr = Conditional(Equals(Sum([k], Prob(Equals(m, k), m), domain = Interval(zero, Add(Exp(two, n), Neg(one)))), one), And(InSet(subExpr1, TensorExp([Exp(Complexes, two)], n)), Equals(m, Meas(subExpr1))))
# Out:
# expr: {(Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1 if |Psi〉 in (Complexes^{2})^{otimes n} ,  m = MEAS(|Psi〉).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(\sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]\right) = 1 \textrm{ if } \lvert \Psi \rangle \in \left(\mathbb{C}^{2}\right)^{\otimes n} ,  m = \mathcal{M}(\lvert \Psi \rangle)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1 if |Psi〉 in (Complexes^{2})^{otimes n} ,  m = MEAS(|Psi〉).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]) = 1
#    core type: Operation
#    operator: 32
#    operands: 3
# 2. (|Psi〉 in (Complexes^{2})^{otimes n}) and (m = MEAS(|Psi〉))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k], 1)
#    core type: ExprTuple
#    sub-expressions: 6, 49
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (|Psi〉 in (Complexes^{2})^{otimes n}, m = MEAS(|Psi〉))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. Sum_{k=0}^{2^{n} - 1} Pr_{m}[m = k]
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. |Psi〉 in (Complexes^{2})^{otimes n}
#    core type: Operation
#    operator: 24
#    operands: 11
# 8. m = MEAS(|Psi〉)
#    core type: Operation
#    operator: 32
#    operands: 12
# 9. Sum
#    core type: Literal
# ...
