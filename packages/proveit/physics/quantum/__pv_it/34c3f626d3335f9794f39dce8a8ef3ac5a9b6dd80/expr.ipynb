# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, Operation
from proveit._common_ import U, f, k, l, n
from proveit.linalg import MatrixProd, ScalarProd
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Exp, Interval, Mult, Neg, Sum, one, two, zero
from proveit.physics.quantum import RegisterBra, RegisterKet

# %%
# build up the expression from sub-expressions
subExpr1 = [k]
subExpr2 = Operation(f, k)
subExpr3 = RegisterBra(l, n)
subExpr4 = RegisterKet(k, n)
subExpr5 = Interval(zero, Add(Exp(two, n), Neg(one)))
expr = Conditional(Forall([f], Equals(MatrixProd(subExpr3, MatrixProd(U, Sum(subExpr1, ScalarProd(subExpr2, subExpr4), domain = subExpr5))), Sum(subExpr1, Mult(subExpr2, MatrixProd(subExpr3, U, subExpr4)), domain = subExpr5))), InSet(l, subExpr5))
# Out:
# expr: {forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n})))) if l in {0...2^{n} - 1}.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{f}~\left(\left({_{n}}\langle l \rvert \thinspace \left(U \thinspace \left(\sum_{k=0}^{2^{n} - 1} \left(\left[f\right]\left(k\right) \thinspace \lvert k \rangle_{n}\right)\right)\right)\right) = \left(\sum_{k=0}^{2^{n} - 1} \left(\left[f\right]\left(k\right) \cdot \left({_{n}}\langle l \rvert \thinspace U \thinspace \lvert k \rangle_{n}\right)\right)\right)\right) \textrm{ if } l \in \{0 \dots 2^{n} - 1\}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n})))) if l in {0...2^{n} - 1}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{f} (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. l in {0...2^{n} - 1}
#    core type: Operation
#    operator: 32
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. f -> (({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n}))))
#    core type: Lambda
#    parameter: 40
#    body: 6
# 5. (l, {0...2^{n} - 1})
#    core type: ExprTuple
#    sub-expressions: 39, 38
# 6. ({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))) = (Sum_{k=0}^{2^{n} - 1} ([f](k) * ({n}_〈l| . U . |k〉_{n})))
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. ({n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n}))), Sum_{k=0}^{2^{n} - 1} [f](k) * ({n}_〈l| . U . |k〉_{n}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. {n}_〈l| . (U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))
#    core type: Operation
#    operator: 24
#    operands: 11
# 10. Sum_{k=0}^{2^{n} - 1} [f](k) * ({n}_〈l| . U . |k〉_{n})
#     core type: Operation
#     operator: 20
#     operand: 12
# 11. ({n}_〈l|, U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n})))
#     core type: ExprTuple
#     sub-expressions: 28, 13
# 12. k -> {[f](k) * ({n}_〈l| . U . |k〉_{n}) if k in {0...2^{n} - 1}.
#     core type: Lambda
#     parameter: 45
#     body: 14
# 13. U . (Sum_{k=0}^{2^{n} - 1} ([f](k) * |k〉_{n}))
#     core type: Operation
#     operator: 24
#     operands: 15
# 14. {[f](k) * ({n}_〈l| . U . |k〉_{n}) if k in {0...2^{n} - 1}.
#     core type: Conditional
#     value: 16
#     condition: 27
# 15. (U, Sum_{k=0}^{2^{n} - 1} [f](k) * |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 29, 17
# 16. [f](k) * ({n}_〈l| . U . |k〉_{n})
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. Sum_{k=0}^{2^{n} - 1} [f](k) * |k〉_{n}
#     core type: Operation
#     operator: 20
#     operand: 21
# 18. *
#     core type: Literal
#     sub-expressions:
# 19. ([f](k), {n}_〈l| . U . |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 36, 22
# 20. Sum
#     core type: Literal
#     sub-expressions:
# 21. k -> {[f](k) * |k〉_{n} if k in {0...2^{n} - 1}.
#     core type: Lambda
#     parameter: 45
#     body: 23
# 22. {n}_〈l| . U . |k〉_{n}
#     core type: Operation
#     operator: 24
#     operands: 25
# 23. {[f](k) * |k〉_{n} if k in {0...2^{n} - 1}.
#     core type: Conditional
#     value: 26
#     condition: 27
# 24. .
#     core type: Literal
#     sub-expressions:
# 25. ({n}_〈l|, U, |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 28, 29, 37
# 26. [f](k) * |k〉_{n}
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. k in {0...2^{n} - 1}
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. {n}_〈l|
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. U
#     core type: Variable
#     sub-expressions:
# 30. *
#     core type: Literal
#     sub-expressions:
# 31. ([f](k), |k〉_{n})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (k, {0...2^{n} - 1})
#     core type: ExprTuple
#     sub-expressions: 45, 38
# 34. REGISTER_BRA
#     core type: Literal
#     sub-expressions:
# 35. (l, n)
#     core type: ExprTuple
#     sub-expressions: 39, 57
# 36. [f](k)
#     core type: Operation
#     operator: 40
#     operand: 45
# 37. |k〉_{n}
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. {0...2^{n} - 1}
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. l
#     core type: Variable
#     sub-expressions:
# 40. f
#     core type: Variable
#     sub-expressions:
# 41. REGISTER_KET
#     core type: Literal
#     sub-expressions:
# 42. (k, n)
#     core type: ExprTuple
#     sub-expressions: 45, 57
# 43. Interval
#     core type: Literal
#     sub-expressions:
# 44. (0, 2^{n} - 1)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 45. k
#     core type: Variable
#     sub-expressions:
# 46. 0
#     core type: Literal
#     sub-expressions:
# 47. 2^{n} - 1
#     core type: Operation
#     operator: 48
#     operands: 49
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (2^{n}, -1)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 50. 2^{n}
#     core type: Operation
#     operator: 52
#     operands: 53
# 51. -1
#     core type: Operation
#     operator: 54
#     operand: 55
# 52. Exp
#     core type: Literal
#     sub-expressions:
# 53. (2, n)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 54. -
#     core type: Literal
#     sub-expressions:
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. 2
#     core type: Literal
#     sub-expressions:
# 57. n
#     core type: Variable
#     sub-expressions:
