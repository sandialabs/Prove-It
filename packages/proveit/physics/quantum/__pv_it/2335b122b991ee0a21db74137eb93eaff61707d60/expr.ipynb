# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#expandRegisterWithZeroKet">expandRegisterWithZeroKet</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.physics.quantum</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import the special expression
from proveit.physics.quantum._axioms_ import expandRegisterWithZeroKet

# %%
# check that the built expression is the same as the stored expression
# %check_expr expandRegisterWithZeroKet
# Out:
# Passed sanity check: built 'expandRegisterWithZeroKet' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expandRegisterWithZeroKet.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{k \in \{0 \dots 2^{n} - 1\}}~\left(\lvert k \rangle_{n + 1} = \left(\lvert k \rangle_{n} {\otimes} \lvert 0 \rangle\right)\right)\right]

# %%
# display the expression information
expandRegisterWithZeroKet.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{k in {0...2^{n} - 1}} (|k〉_{n + 1} = (|k〉_{n} otimes |0〉))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. n -> {forall_{k in {0...2^{n} - 1}} (|k〉_{n + 1} = (|k〉_{n} otimes |0〉)) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 43
#    body: 2
# 2. {forall_{k in {0...2^{n} - 1}} (|k〉_{n + 1} = (|k〉_{n} otimes |0〉)) if n in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{k in {0...2^{n} - 1}} (|k〉_{n + 1} = (|k〉_{n} otimes |0〉))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. n in NaturalsPos
#    core type: Operation
#    operator: 14
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. k -> {|k〉_{n + 1} = (|k〉_{n} otimes |0〉) if k in {0...2^{n} - 1}.
#    core type: Lambda
#    parameter: 35
#    body: 8
# 7. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 43, 9
# ...
