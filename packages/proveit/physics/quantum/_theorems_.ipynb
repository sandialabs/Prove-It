# %% [markdown]
# Theorems for context <a class="ProveItLink" href="_context_.ipynb">proveit.physics.quantum</a>
# ========

# %%
import proveit
# Automation is not needed when building theorem expressions:
proveit.defaults.automation = False # This will speed things up.
from proveit import Operation, indexed_var, ExprTuple, ExprRange, varRange, ExprArray
from proveit._common_ import alpha, A, B, C, D, E, F, G, P, Q, R, S, f, g, h, i, j, k, l, m, n, p, x, y, Psi, U, Px, Py
from proveit.logic import And, Equals, Forall, InSet, Implies
from proveit.logic._common_ import xIter1n
from proveit.logic.set_theory import Set
from proveit.number import zero, one, two, subtract, Abs, Add, Complexes, Exp, Mult, NaturalsPos, Sum
from proveit.number.sets import Interval 
from proveit.physics.quantum import Ket, Meas, QubitRegisterSpace, RegisterBra, RegisterKet # RegisterBra, RegisterSU, 
from proveit.physics.quantum._common_ import (
        H, invRoot2, ket0, ket1, ketPlus, QubitSpace)
from proveit.physics.quantum.circuit import MultiQubitGate, Gate, Circuit, CircuitEquiv
from proveit.core_expr_types.expr_array._common_ import Aij, Bij, Cij, Dij, Eij, Qij, Rij, Sij, B11_to_Bmn, D11_to_Dmn, S11_to_Smn
from proveit.statistics import Prob

# from proveit.physics.quantum.common import I, H, Hgate, CTRL_DN, WIRE_DN, WIRE_LINK, PASS, \
#     , QubitRegisterSpace, RegisterSU 
from proveit.linalg import MatrixProd, ScalarProd, SU
# the context is in the current directory:
context = proveit.Context('.') # adds context root to sys.path if necessary

# %% [markdown]
# ### *The following 3 cells require updates to Circuit class before they can proceed.<br/>These then affect a handful of theorems/expressions below that refer to the Circuits.*

# %%
# def controlledNgate(a, b, x, y):
#     return Circuit([[Input(a), PASS, CTRL_DN, Output(b)],
#                     [Input(x), MultiWire(n), Gate(U), Output(y)]])

# %%
# pregatedControlledNgate = Circuit([[Input(a), Gate(u), CTRL_DN, Output(b)],
#                                    [Input(x), MultiWire(n), Gate(U), Output(y)]])

# %%
# pregatedControlledNgateWithMerge = Circuit([[Input(c), MultiWire(k), PASS, WIRE_DN, PASS, PASS],
#                                             [Input(a), Gate(u), CTRL_DN, WIRE_LINK, MultiWire(Add(k, one)), Output(d)],
#                                             [Input(x), MultiWire(n), Gate(U), Output(y), PASS, PASS]])

# %%
# %begin theorems
# Out:
# Defining theorems for context 'proveit.physics.quantum'
# Subsequent end-of-cell assignments will define theorems
# '%end theorems' will finalize the definitions

# %%
ketPlusDistributed = Equals(ketPlus, Add(ScalarProd(invRoot2, ket0), ScalarProd(invRoot2, ket1)))
# Out:
# ketPlusDistributed: |+〉 = (((1 / sqrt(2)) * |0〉) + ((1 / sqrt(2)) * |1〉))

# %%
scaledQubitStateInQubitSpace = Forall(
        x,
        Forall(alpha,
               InSet(ScalarProd(alpha, x), QubitSpace),
               domain=Complexes),
        domain=QubitSpace)
# Out:
# scaledQubitStateInQubitSpace: forall_{x in Temporary_placeholder_for_undefined_proveit.number.sets.complex.Complexes^{2}} [forall_{alpha in Temporary_placeholder_for_undefined_proveit.number.sets.complex.Complexes} ((alpha * x) in Temporary_placeholder_for_undefined_proveit.number.sets.complex.Complexes^{2})]

# %%
transformedQubitStateInQubitSpace = Forall(
        x,
        Forall(U,
               InSet(MatrixProd(U, x), QubitSpace),
               domain=SU(two)),
        domain=QubitSpace)
# Out:
# transformedQubitStateInQubitSpace: forall_{x in Temporary_placeholder_for_undefined_proveit.number.sets.complex.Complexes^{2}} [forall_{U in [SU](2)} ((U . x) in Temporary_placeholder_for_undefined_proveit.number.sets.complex.Complexes^{2})]

# %%
# for use in reducing a MultiQubitGate to a gate within a Circuit.
unary_multiQubitGate_reduction = Forall(U, Forall(A, Equals(MultiQubitGate(U, Set(A)), Gate(U)), domain=NaturalsPos))
# Out:
# unary_multiQubitGate_reduction: forall_{U} [forall_{A in NaturalsPos} (U MULTI_QUBIT_GATE {A} = [GATE](U))]

# %%
single_time_equiv = Forall ((h, k, m), Forall((varRange(A, [one, one], [m, k]), varRange(B, one, m), 
                                                varRange(C, [one, one], [m, h]), varRange(D, one, m), 
                                                varRange(S, one, m), varRange(R, [one, one], [m, k]), 
                                                varRange(Q, [one, one], [m, h])), 
        Implies(
            CircuitEquiv(
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(indexed_var(B, i), indexed_var(S, i))), one, m))),
                        Circuit(ExprArray(ExprRange(i, ExprTuple(MultiQubitGate(indexed_var(D, i), indexed_var(S, i))), one, m)))
            ),
            CircuitEquiv(
                        Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Rij), one, k), 
                                            MultiQubitGate(indexed_var(B, i), indexed_var(S, i)),
                                            ExprRange(j, MultiQubitGate(Cij, Qij), one, h)), 
                                    one, m))),
                        Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Rij), one, k), 
                                            MultiQubitGate(indexed_var(D, i), indexed_var(S, i)),
                                            ExprRange(j, MultiQubitGate(Cij, Qij), one, h)), 
                                    one, m)))
            )
        ).withWrappingAt(2)
    ), domain=NaturalsPos)
# Out:
# B_{1} MULTI_QUBIT_GATE S_{1}  \\
#   \colon  \\
#   B_{i} MULTI_QUBIT_GATE S_{i}  \\
#   \colon  \\
#   B_{m} MULTI_QUBIT_GATE S_{m}
# D_{1} MULTI_QUBIT_GATE S_{1}  \\
#   \colon  \\
#   D_{i} MULTI_QUBIT_GATE S_{i}  \\
#   \colon  \\
#   D_{m} MULTI_QUBIT_GATE S_{m}
# A_{1,1} MULTI_QUBIT_GATE R_{1,1} & ..A_{1,j} MULTI_QUBIT_GATE R_{1,j}.. & A_{1,k} MULTI_QUBIT_GATE R_{1,k} & B_{1} MULTI_QUBIT_GATE S_{1} & C_{1,1} MULTI_QUBIT_GATE Q_{1,1} & ..C_{1,j} MULTI_QUBIT_GATE Q_{1,j}.. & C_{1,h} MULTI_QUBIT_GATE Q_{1,h}  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   A_{i,1} MULTI_QUBIT_GATE R_{i,1} & ..A_{i,j} MULTI_QUBIT_GATE R_{i,j}.. & A_{i,k} MULTI_QUBIT_GATE R_{i,k} & B_{i} MULTI_QUBIT_GATE S_{i} & C_{i,1} MULTI_QUBIT_GATE Q_{i,1} & ..C_{i,j} MULTI_QUBIT_GATE Q_{i,j}.. & C_{i,h} MULTI_QUBIT_GATE Q_{i,h}  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   A_{m,1} MULTI_QUBIT_GATE R_{m,1} & ..A_{m,j} MULTI_QUBIT_GATE R_{m,j}.. & A_{m,k} MULTI_QUBIT_GATE R_{m,k} & B_{m} MULTI_QUBIT_GATE S_{m} & C_{m,1} MULTI_QUBIT_GATE Q_{m,1} & ..C_{m,j} MULTI_QUBIT_GATE Q_{m,j}.. & C_{m,h} MULTI_QUBIT_GATE Q_{m,h}
# A_{1,1} MULTI_QUBIT_GATE R_{1,1} & ..A_{1,j} MULTI_QUBIT_GATE R_{1,j}.. & A_{1,k} MULTI_QUBIT_GATE R_{1,k} & D_{1} MULTI_QUBIT_GATE S_{1} & C_{1,1} MULTI_QUBIT_GATE Q_{1,1} & ..C_{1,j} MULTI_QUBIT_GATE Q_{1,j}.. & C_{1,h} MULTI_QUBIT_GATE Q_{1,h}  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   A_{i,1} MULTI_QUBIT_GATE R_{i,1} & ..A_{i,j} MULTI_QUBIT_GATE R_{i,j}.. & A_{i,k} MULTI_QUBIT_GATE R_{i,k} & D_{i} MULTI_QUBIT_GATE S_{i} & C_{i,1} MULTI_QUBIT_GATE Q_{i,1} & ..C_{i,j} MULTI_QUBIT_GATE Q_{i,j}.. & C_{i,h} MULTI_QUBIT_GATE Q_{i,h}  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   A_{m,1} MULTI_QUBIT_GATE R_{m,1} & ..A_{m,j} MULTI_QUBIT_GATE R_{m,j}.. & A_{m,k} MULTI_QUBIT_GATE R_{m,k} & D_{m} MULTI_QUBIT_GATE S_{m} & C_{m,1} MULTI_QUBIT_GATE Q_{m,1} & ..C_{m,j} MULTI_QUBIT_GATE Q_{m,j}.. & C_{m,h} MULTI_QUBIT_GATE Q_{m,h}
# ((B_{1} MULTI_QUBIT_GATE S_{1}), ..(B_{_c} MULTI_QUBIT_GATE S_{_c}).., (B_{m} MULTI_QUBIT_GATE S_{m}))
# ((D_{1} MULTI_QUBIT_GATE S_{1}), ..(D_{_c} MULTI_QUBIT_GATE S_{_c}).., (D_{m} MULTI_QUBIT_GATE S_{m}))
# ((A_{1,1} MULTI_QUBIT_GATE R_{1,1}, ..A_{1,_d} MULTI_QUBIT_GATE R_{1,_d}.., A_{1,k} MULTI_QUBIT_GATE R_{1,k}, B_{1} MULTI_QUBIT_GATE S_{1}, C_{1,1} MULTI_QUBIT_GATE Q_{1,1}, ..C_{1,_d} MULTI_QUBIT_GATE Q_{1,_d}.., C_{1,h} MULTI_QUBIT_GATE Q_{1,h}), ..(A_{_j,1} MULTI_QUBIT_GATE R_{_j,1}, ..A_{_j,_d} MULTI_QUBIT_GATE R_{_j,_d}.., A_{_j,k} MULTI_QUBIT_GATE R_{_j,k}, B_{_j} MULTI_QUBIT_GATE S_{_j}, C_{_j,1} MULTI_QUBIT_GATE Q_{_j,1}, ..C_{_j,_d} MULTI_QUBIT_GATE Q_{_j,_d}.., C_{_j,h} MULTI_QUBIT_GATE Q_{_j,h}).., (A_{m,1} MULTI_QUBIT_GATE R_{m,1}, ..A_{m,_d} MULTI_QUBIT_GATE R_{m,_d}.., A_{m,k} MULTI_QUBIT_GATE R_{m,k}, B_{m} MULTI_QUBIT_GATE S_{m}, C_{m,1} MULTI_QUBIT_GATE Q_{m,1}, ..C_{m,_d} MULTI_QUBIT_GATE Q_{m,_d}.., C_{m,h} MULTI_QUBIT_GATE Q_{m,h}))
# ((A_{1,1} MULTI_QUBIT_GATE R_{1,1}, ..A_{1,_d} MULTI_QUBIT_GATE R_{1,_d}.., A_{1,k} MULTI_QUBIT_GATE R_{1,k}, D_{1} MULTI_QUBIT_GATE S_{1}, C_{1,1} MULTI_QUBIT_GATE Q_{1,1}, ..C_{1,_d} MULTI_QUBIT_GATE Q_{1,_d}.., C_{1,h} MULTI_QUBIT_GATE Q_{1,h}), ..(A_{_j,1} MULTI_QUBIT_GATE R_{_j,1}, ..A_{_j,_d} MULTI_QUBIT_GATE R_{_j,_d}.., A_{_j,k} MULTI_QUBIT_GATE R_{_j,k}, D_{_j} MULTI_QUBIT_GATE S_{_j}, C_{_j,1} MULTI_QUBIT_GATE Q_{_j,1}, ..C_{_j,_d} MULTI_QUBIT_GATE Q_{_j,_d}.., C_{_j,h} MULTI_QUBIT_GATE Q_{_j,h}).., (A_{m,1} MULTI_QUBIT_GATE R_{m,1}, ..A_{m,_d} MULTI_QUBIT_GATE R_{m,_d}.., A_{m,k} MULTI_QUBIT_GATE R_{m,k}, D_{m} MULTI_QUBIT_GATE S_{m}, C_{m,1} MULTI_QUBIT_GATE Q_{m,1}, ..C_{m,_d} MULTI_QUBIT_GATE Q_{m,_d}.., C_{m,h} MULTI_QUBIT_GATE Q_{m,h}))
# ((_k_{1} MULTI_QUBIT_GATE _h_{1}), ..(_k_{_c} MULTI_QUBIT_GATE _h_{_c}).., (_k_{m} MULTI_QUBIT_GATE _h_{m}))
# ((_i_{1} MULTI_QUBIT_GATE _h_{1}), ..(_i_{_c} MULTI_QUBIT_GATE _h_{_c}).., (_i_{m} MULTI_QUBIT_GATE _h_{m}))
# ((_l_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._l_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _l_{1,k} MULTI_QUBIT_GATE _g_{1,k}, _k_{1} MULTI_QUBIT_GATE _h_{1}, _j_{1,1} MULTI_QUBIT_GATE _f_{1,1}, .._j_{1,_d} MULTI_QUBIT_GATE _f_{1,_d}.., _j_{1,h} MULTI_QUBIT_GATE _f_{1,h}), ..(_l_{_a,1} MULTI_QUBIT_GATE _g_{_a,1}, .._l_{_a,_d} MULTI_QUBIT_GATE _g_{_a,_d}.., _l_{_a,k} MULTI_QUBIT_GATE _g_{_a,k}, _k_{_a} MULTI_QUBIT_GATE _h_{_a}, _j_{_a,1} MULTI_QUBIT_GATE _f_{_a,1}, .._j_{_a,_d} MULTI_QUBIT_GATE _f_{_a,_d}.., _j_{_a,h} MULTI_QUBIT_GATE _f_{_a,h}).., (_l_{m,1} MULTI_QUBIT_GATE _g_{m,1}, .._l_{m,_d} MULTI_QUBIT_GATE _g_{m,_d}.., _l_{m,k} MULTI_QUBIT_GATE _g_{m,k}, _k_{m} MULTI_QUBIT_GATE _h_{m}, _j_{m,1} MULTI_QUBIT_GATE _f_{m,1}, .._j_{m,_d} MULTI_QUBIT_GATE _f_{m,_d}.., _j_{m,h} MULTI_QUBIT_GATE _f_{m,h}))
# ((_l_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._l_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _l_{1,k} MULTI_QUBIT_GATE _g_{1,k}, _i_{1} MULTI_QUBIT_GATE _h_{1}, _j_{1,1} MULTI_QUBIT_GATE _f_{1,1}, .._j_{1,_d} MULTI_QUBIT_GATE _f_{1,_d}.., _j_{1,h} MULTI_QUBIT_GATE _f_{1,h}), ..(_l_{_a,1} MULTI_QUBIT_GATE _g_{_a,1}, .._l_{_a,_d} MULTI_QUBIT_GATE _g_{_a,_d}.., _l_{_a,k} MULTI_QUBIT_GATE _g_{_a,k}, _i_{_a} MULTI_QUBIT_GATE _h_{_a}, _j_{_a,1} MULTI_QUBIT_GATE _f_{_a,1}, .._j_{_a,_d} MULTI_QUBIT_GATE _f_{_a,_d}.., _j_{_a,h} MULTI_QUBIT_GATE _f_{_a,h}).., (_l_{m,1} MULTI_QUBIT_GATE _g_{m,1}, .._l_{m,_d} MULTI_QUBIT_GATE _g_{m,_d}.., _l_{m,k} MULTI_QUBIT_GATE _g_{m,k}, _i_{m} MULTI_QUBIT_GATE _h_{m}, _j_{m,1} MULTI_QUBIT_GATE _f_{m,1}, .._j_{m,_d} MULTI_QUBIT_GATE _f_{m,_d}.., _j_{m,h} MULTI_QUBIT_GATE _f_{m,h}))
# ((_l_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._l_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _l_{1,k} MULTI_QUBIT_GATE _g_{1,k}, _k_{1} MULTI_QUBIT_GATE _h_{1}, _j_{1,1} MULTI_QUBIT_GATE _f_{1,1}, .._j_{1,_d} MULTI_QUBIT_GATE _f_{1,_d}.., _j_{1,h} MULTI_QUBIT_GATE _f_{1,h}), ..(_l_{_m,1} MULTI_QUBIT_GATE _g_{_m,1}, .._l_{_m,_d} MULTI_QUBIT_GATE _g_{_m,_d}.., _l_{_m,k} MULTI_QUBIT_GATE _g_{_m,k}, _k_{_m} MULTI_QUBIT_GATE _h_{_m}, _j_{_m,1} MULTI_QUBIT_GATE _f_{_m,1}, .._j_{_m,_d} MULTI_QUBIT_GATE _f_{_m,_d}.., _j_{_m,h} MULTI_QUBIT_GATE _f_{_m,h}).., (_l_{m,1} MULTI_QUBIT_GATE _g_{m,1}, .._l_{m,_d} MULTI_QUBIT_GATE _g_{m,_d}.., _l_{m,k} MULTI_QUBIT_GATE _g_{m,k}, _k_{m} MULTI_QUBIT_GATE _h_{m}, _j_{m,1} MULTI_QUBIT_GATE _f_{m,1}, .._j_{m,_d} MULTI_QUBIT_GATE _f_{m,_d}.., _j_{m,h} MULTI_QUBIT_GATE _f_{m,h}))
# ((_l_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._l_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _l_{1,k} MULTI_QUBIT_GATE _g_{1,k}, _i_{1} MULTI_QUBIT_GATE _h_{1}, _j_{1,1} MULTI_QUBIT_GATE _f_{1,1}, .._j_{1,_d} MULTI_QUBIT_GATE _f_{1,_d}.., _j_{1,h} MULTI_QUBIT_GATE _f_{1,h}), ..(_l_{_k,1} MULTI_QUBIT_GATE _g_{_k,1}, .._l_{_k,_d} MULTI_QUBIT_GATE _g_{_k,_d}.., _l_{_k,k} MULTI_QUBIT_GATE _g_{_k,k}, _i_{_k} MULTI_QUBIT_GATE _h_{_k}, _j_{_k,1} MULTI_QUBIT_GATE _f_{_k,1}, .._j_{_k,_d} MULTI_QUBIT_GATE _f_{_k,_d}.., _j_{_k,h} MULTI_QUBIT_GATE _f_{_k,h}).., (_l_{m,1} MULTI_QUBIT_GATE _g_{m,1}, .._l_{m,_d} MULTI_QUBIT_GATE _g_{m,_d}.., _l_{m,k} MULTI_QUBIT_GATE _g_{m,k}, _i_{m} MULTI_QUBIT_GATE _h_{m}, _j_{m,1} MULTI_QUBIT_GATE _f_{m,1}, .._j_{m,_d} MULTI_QUBIT_GATE _f_{m,_d}.., _j_{m,h} MULTI_QUBIT_GATE _f_{m,h}))
# ((_c_{1} MULTI_QUBIT_GATE _h_{1}), ..(_c_{_d} MULTI_QUBIT_GATE _h_{_d}).., (_c_{_j} MULTI_QUBIT_GATE _h_{_j}))
# ((_i_{1} MULTI_QUBIT_GATE _h_{1}), ..(_i_{_d} MULTI_QUBIT_GATE _h_{_d}).., (_i_{_j} MULTI_QUBIT_GATE _h_{_j}))
# ((_b_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._b_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _b_{1,_k} MULTI_QUBIT_GATE _g_{1,_k}, _c_{1} MULTI_QUBIT_GATE _h_{1}, _a_{1,1} MULTI_QUBIT_GATE _f_{1,1}, .._a_{1,_d} MULTI_QUBIT_GATE _f_{1,_d}.., _a_{1,_l} MULTI_QUBIT_GATE _f_{1,_l}), ..(_b_{_m,1} MULTI_QUBIT_GATE _g_{_m,1}, .._b_{_m,_d} MULTI_QUBIT_GATE _g_{_m,_d}.., _b_{_m,_k} MULTI_QUBIT_GATE _g_{_m,_k}, _c_{_m} MULTI_QUBIT_GATE _h_{_m}, _a_{_m,1} MULTI_QUBIT_GATE _f_{_m,1}, .._a_{_m,_d} MULTI_QUBIT_GATE _f_{_m,_d}.., _a_{_m,_l} MULTI_QUBIT_GATE _f_{_m,_l}).., (_b_{_j,1} MULTI_QUBIT_GATE _g_{_j,1}, .._b_{_j,_d} MULTI_QUBIT_GATE _g_{_j,_d}.., _b_{_j,_k} MULTI_QUBIT_GATE _g_{_j,_k}, _c_{_j} MULTI_QUBIT_GATE _h_{_j}, _a_{_j,1} MULTI_QUBIT_GATE _f_{_j,1}, .._a_{_j,_d} MULTI_QUBIT_GATE _f_{_j,_d}.., _a_{_j,_l} MULTI_QUBIT_GATE _f_{_j,_l}))
# ((_b_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._b_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _b_{1,_k} MULTI_QUBIT_GATE _g_{1,_k}, _i_{1} MULTI_QUBIT_GATE _h_{1}, _a_{1,1} MULTI_QUBIT_GATE _f_{1,1}, .._a_{1,_d} MULTI_QUBIT_GATE _f_{1,_d}.., _a_{1,_l} MULTI_QUBIT_GATE _f_{1,_l}), ..(_b_{_c,1} MULTI_QUBIT_GATE _g_{_c,1}, .._b_{_c,_d} MULTI_QUBIT_GATE _g_{_c,_d}.., _b_{_c,_k} MULTI_QUBIT_GATE _g_{_c,_k}, _i_{_c} MULTI_QUBIT_GATE _h_{_c}, _a_{_c,1} MULTI_QUBIT_GATE _f_{_c,1}, .._a_{_c,_d} MULTI_QUBIT_GATE _f_{_c,_d}.., _a_{_c,_l} MULTI_QUBIT_GATE _f_{_c,_l}).., (_b_{_j,1} MULTI_QUBIT_GATE _g_{_j,1}, .._b_{_j,_d} MULTI_QUBIT_GATE _g_{_j,_d}.., _b_{_j,_k} MULTI_QUBIT_GATE _g_{_j,_k}, _i_{_j} MULTI_QUBIT_GATE _h_{_j}, _a_{_j,1} MULTI_QUBIT_GATE _f_{_j,1}, .._a_{_j,_d} MULTI_QUBIT_GATE _f_{_j,_d}.., _a_{_j,_l} MULTI_QUBIT_GATE _f_{_j,_l}))
# ((_i_{1} MULTI_QUBIT_GATE _h_{1}), ..(_i_{_c} MULTI_QUBIT_GATE _h_{_c}).., (_i_{_j} MULTI_QUBIT_GATE _h_{_j}))
# ((_b_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._b_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _b_{1,_k} MULTI_QUBIT_GATE _g_{1,_k}, _c_{1} MULTI_QUBIT_GATE _h_{1}, _a_{1,1} MULTI_QUBIT_GATE _f_{1,1}, .._a_{1,_d} MULTI_QUBIT_GATE _f_{1,_d}.., _a_{1,_l} MULTI_QUBIT_GATE _f_{1,_l}), ..(_b_{_j,1} MULTI_QUBIT_GATE _g_{_j,1}, .._b_{_j,_d} MULTI_QUBIT_GATE _g_{_j,_d}.., _b_{_j,_k} MULTI_QUBIT_GATE _g_{_j,_k}, _c_{_j} MULTI_QUBIT_GATE _h_{_j}, _a_{_j,1} MULTI_QUBIT_GATE _f_{_j,1}, .._a_{_j,_d} MULTI_QUBIT_GATE _f_{_j,_d}.., _a_{_j,_l} MULTI_QUBIT_GATE _f_{_j,_l}).., (_b_{_j,1} MULTI_QUBIT_GATE _g_{_j,1}, .._b_{_j,_d} MULTI_QUBIT_GATE _g_{_j,_d}.., _b_{_j,_k} MULTI_QUBIT_GATE _g_{_j,_k}, _c_{_j} MULTI_QUBIT_GATE _h_{_j}, _a_{_j,1} MULTI_QUBIT_GATE _f_{_j,1}, .._a_{_j,_d} MULTI_QUBIT_GATE _f_{_j,_d}.., _a_{_j,_l} MULTI_QUBIT_GATE _f_{_j,_l}))
# ((_b_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._b_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _b_{1,_k} MULTI_QUBIT_GATE _g_{1,_k}, _i_{1} MULTI_QUBIT_GATE _h_{1}, _a_{1,1} MULTI_QUBIT_GATE _f_{1,1}, .._a_{1,_d} MULTI_QUBIT_GATE _f_{1,_d}.., _a_{1,_l} MULTI_QUBIT_GATE _f_{1,_l}), ..(_b_{_j,1} MULTI_QUBIT_GATE _g_{_j,1}, .._b_{_j,_d} MULTI_QUBIT_GATE _g_{_j,_d}.., _b_{_j,_k} MULTI_QUBIT_GATE _g_{_j,_k}, _i_{_j} MULTI_QUBIT_GATE _h_{_j}, _a_{_j,1} MULTI_QUBIT_GATE _f_{_j,1}, .._a_{_j,_d} MULTI_QUBIT_GATE _f_{_j,_d}.., _a_{_j,_l} MULTI_QUBIT_GATE _f_{_j,_l}).., (_b_{_j,1} MULTI_QUBIT_GATE _g_{_j,1}, .._b_{_j,_d} MULTI_QUBIT_GATE _g_{_j,_d}.., _b_{_j,_k} MULTI_QUBIT_GATE _g_{_j,_k}, _i_{_j} MULTI_QUBIT_GATE _h_{_j}, _a_{_j,1} MULTI_QUBIT_GATE _f_{_j,1}, .._a_{_j,_d} MULTI_QUBIT_GATE _f_{_j,_d}.., _a_{_j,_l} MULTI_QUBIT_GATE _f_{_j,_l}))
# ((_n_{1} MULTI_QUBIT_GATE _h_{1}), ..(_n_{_d} MULTI_QUBIT_GATE _h_{_d}).., (_n_{_j} MULTI_QUBIT_GATE _h_{_j}))
# ((_i_{1} MULTI_QUBIT_GATE _h_{1}), ..(_i_{_c} MULTI_QUBIT_GATE _h_{_c}).., (_i_{_j} MULTI_QUBIT_GATE _h_{_j}))
# ((_o_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._o_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _o_{1,_k} MULTI_QUBIT_GATE _g_{1,_k}, _n_{1} MULTI_QUBIT_GATE _h_{1}, _m_{1,1} MULTI_QUBIT_GATE _f_{1,1}, .._m_{1,_d} MULTI_QUBIT_GATE _f_{1,_d}.., _m_{1,_l} MULTI_QUBIT_GATE _f_{1,_l}), ..(_o_{_j,1} MULTI_QUBIT_GATE _g_{_j,1}, .._o_{_j,_d} MULTI_QUBIT_GATE _g_{_j,_d}.., _o_{_j,_k} MULTI_QUBIT_GATE _g_{_j,_k}, _n_{_j} MULTI_QUBIT_GATE _h_{_j}, _m_{_j,1} MULTI_QUBIT_GATE _f_{_j,1}, .._m_{_j,_d} MULTI_QUBIT_GATE _f_{_j,_d}.., _m_{_j,_l} MULTI_QUBIT_GATE _f_{_j,_l}).., (_o_{_j,1} MULTI_QUBIT_GATE _g_{_j,1}, .._o_{_j,_d} MULTI_QUBIT_GATE _g_{_j,_d}.., _o_{_j,_k} MULTI_QUBIT_GATE _g_{_j,_k}, _n_{_j} MULTI_QUBIT_GATE _h_{_j}, _m_{_j,1} MULTI_QUBIT_GATE _f_{_j,1}, .._m_{_j,_d} MULTI_QUBIT_GATE _f_{_j,_d}.., _m_{_j,_l} MULTI_QUBIT_GATE _f_{_j,_l}))
# ((_o_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._o_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _o_{1,_k} MULTI_QUBIT_GATE _g_{1,_k}, _i_{1} MULTI_QUBIT_GATE _h_{1}, _m_{1,1} MULTI_QUBIT_GATE _f_{1,1}, .._m_{1,_d} MULTI_QUBIT_GATE _f_{1,_d}.., _m_{1,_l} MULTI_QUBIT_GATE _f_{1,_l}), ..(_o_{_j,1} MULTI_QUBIT_GATE _g_{_j,1}, .._o_{_j,_d} MULTI_QUBIT_GATE _g_{_j,_d}.., _o_{_j,_k} MULTI_QUBIT_GATE _g_{_j,_k}, _i_{_j} MULTI_QUBIT_GATE _h_{_j}, _m_{_j,1} MULTI_QUBIT_GATE _f_{_j,1}, .._m_{_j,_d} MULTI_QUBIT_GATE _f_{_j,_d}.., _m_{_j,_l} MULTI_QUBIT_GATE _f_{_j,_l}).., (_o_{_j,1} MULTI_QUBIT_GATE _g_{_j,1}, .._o_{_j,_d} MULTI_QUBIT_GATE _g_{_j,_d}.., _o_{_j,_k} MULTI_QUBIT_GATE _g_{_j,_k}, _i_{_j} MULTI_QUBIT_GATE _h_{_j}, _m_{_j,1} MULTI_QUBIT_GATE _f_{_j,1}, .._m_{_j,_d} MULTI_QUBIT_GATE _f_{_j,_d}.., _m_{_j,_l} MULTI_QUBIT_GATE _f_{_j,_l}))
# ((_n_{1} MULTI_QUBIT_GATE _h_{1}), ..(_n_{_c} MULTI_QUBIT_GATE _h_{_c}).., (_n_{_j} MULTI_QUBIT_GATE _h_{_j}))
# single_time_equiv: forall_{h in NaturalsPos, k in NaturalsPos, m in NaturalsPos} [forall_{A_{1,1}, ..A_{1,_b}.., A_{1,k}, ....A_{_a,1}, ..A_{_a,_b}.., A_{_a,k}...., A_{m,1}, ..A_{m,_b}.., A_{m,k}, B_{1}, ..B_{_a}.., B_{m}, C_{1,1}, ..C_{1,_b}.., C_{1,h}, ....C_{_a,1}, ..C_{_a,_b}.., C_{_a,h}...., C_{m,1}, ..C_{m,_b}.., C_{m,h}, D_{1}, ..D_{_a}.., D_{m}, S_{1}, ..S_{_a}.., S_{m}, R_{1,1}, ..R_{1,_b}.., R_{1,k}, ....R_{_a,1}, ..R_{_a,_b}.., R_{_a,k}...., R_{m,1}, ..R_{m,_b}.., R_{m,k}, Q_{1,1}, ..Q_{1,_b}.., Q_{1,h}, ....Q_{_a,1}, ..Q_{_a,_b}.., Q_{_a,h}...., Q_{m,1}, ..Q_{m,_b}.., Q_{m,h}} (( B_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    B_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    B_{m} MULTI_QUBIT_GATE S_{m} equiv  D_{1} MULTI_QUBIT_GATE S_{1}   \\
#    \colon   \\
#    D_{i} MULTI_QUBIT_GATE S_{i}   \\
#    \colon   \\
#    D_{m} MULTI_QUBIT_GATE S_{m}) =>  \\ ( A_{1,1} MULTI_QUBIT_GATE R_{1,1}  & ..A_{1,j} MULTI_QUBIT_GATE R_{1,j}..  & A_{1,k} MULTI_QUBIT_GATE R_{1,k}  & B_{1} MULTI_QUBIT_GATE S_{1}  & C_{1,1} MULTI_QUBIT_GATE Q_{1,1}  & ..C_{1,j} MULTI_QUBIT_GATE Q_{1,j}..  & C_{1,h} MULTI_QUBIT_GATE Q_{1,h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i,1} MULTI_QUBIT_GATE R_{i,1}  & ..A_{i,j} MULTI_QUBIT_GATE R_{i,j}..  & A_{i,k} MULTI_QUBIT_GATE R_{i,k}  & B_{i} MULTI_QUBIT_GATE S_{i}  & C_{i,1} MULTI_QUBIT_GATE Q_{i,1}  & ..C_{i,j} MULTI_QUBIT_GATE Q_{i,j}..  & C_{i,h} MULTI_QUBIT_GATE Q_{i,h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{m,1} MULTI_QUBIT_GATE R_{m,1}  & ..A_{m,j} MULTI_QUBIT_GATE R_{m,j}..  & A_{m,k} MULTI_QUBIT_GATE R_{m,k}  & B_{m} MULTI_QUBIT_GATE S_{m}  & C_{m,1} MULTI_QUBIT_GATE Q_{m,1}  & ..C_{m,j} MULTI_QUBIT_GATE Q_{m,j}..  & C_{m,h} MULTI_QUBIT_GATE Q_{m,h} equiv  A_{1,1} MULTI_QUBIT_GATE R_{1,1}  & ..A_{1,j} MULTI_QUBIT_GATE R_{1,j}..  & A_{1,k} MULTI_QUBIT_GATE R_{1,k}  & D_{1} MULTI_QUBIT_GATE S_{1}  & C_{1,1} MULTI_QUBIT_GATE Q_{1,1}  & ..C_{1,j} MULTI_QUBIT_GATE Q_{1,j}..  & C_{1,h} MULTI_QUBIT_GATE Q_{1,h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i,1} MULTI_QUBIT_GATE R_{i,1}  & ..A_{i,j} MULTI_QUBIT_GATE R_{i,j}..  & A_{i,k} MULTI_QUBIT_GATE R_{i,k}  & D_{i} MULTI_QUBIT_GATE S_{i}  & C_{i,1} MULTI_QUBIT_GATE Q_{i,1}  & ..C_{i,j} MULTI_QUBIT_GATE Q_{i,j}..  & C_{i,h} MULTI_QUBIT_GATE Q_{i,h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{m,1} MULTI_QUBIT_GATE R_{m,1}  & ..A_{m,j} MULTI_QUBIT_GATE R_{m,j}..  & A_{m,k} MULTI_QUBIT_GATE R_{m,k}  & D_{m} MULTI_QUBIT_GATE S_{m}  & C_{m,1} MULTI_QUBIT_GATE Q_{m,1}  & ..C_{m,j} MULTI_QUBIT_GATE Q_{m,j}..  & C_{m,h} MULTI_QUBIT_GATE Q_{m,h}))]

# %%
time_equiv = Forall ((h, k, m, n), Forall((varRange(A, [one, one], [m, k]), B11_to_Bmn, 
                                                varRange(C, [one, one], [m, h]), D11_to_Dmn, 
                                                S11_to_Smn, varRange(R, [one, one], [m, k]), 
                                                varRange(Q, [one, one], [m, h])), 
        Implies(
            CircuitEquiv(
                        Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Bij, Sij), one, n)), one, m))),
                        Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Dij, Sij), one, n)), one, m)))
            ),
            CircuitEquiv(
                        Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Rij), one, k), 
                                            ExprRange(j, MultiQubitGate(Bij, Sij), one, n),
                                            ExprRange(j, MultiQubitGate(Cij, Qij), one, h)), 
                                    one, m))),
                        Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Rij), one, k), 
                                            ExprRange(j, MultiQubitGate(Dij, Sij), one, n),
                                            ExprRange(j, MultiQubitGate(Cij, Qij), one, h)), 
                                    one, m)))
            )
        ).withWrappingAt(2)
    ), domain=NaturalsPos)
# Out:
# B_{1,1} MULTI_QUBIT_GATE S_{1,1} & ..B_{1,j} MULTI_QUBIT_GATE S_{1,j}.. & B_{1,n} MULTI_QUBIT_GATE S_{1,n}  \\
#   \colon & \colon & \colon  \\
#   B_{i,1} MULTI_QUBIT_GATE S_{i,1} & ..B_{i,j} MULTI_QUBIT_GATE S_{i,j}.. & B_{i,n} MULTI_QUBIT_GATE S_{i,n}  \\
#   \colon & \colon & \colon  \\
#   B_{m,1} MULTI_QUBIT_GATE S_{m,1} & ..B_{m,j} MULTI_QUBIT_GATE S_{m,j}.. & B_{m,n} MULTI_QUBIT_GATE S_{m,n}
# D_{1,1} MULTI_QUBIT_GATE S_{1,1} & ..D_{1,j} MULTI_QUBIT_GATE S_{1,j}.. & D_{1,n} MULTI_QUBIT_GATE S_{1,n}  \\
#   \colon & \colon & \colon  \\
#   D_{i,1} MULTI_QUBIT_GATE S_{i,1} & ..D_{i,j} MULTI_QUBIT_GATE S_{i,j}.. & D_{i,n} MULTI_QUBIT_GATE S_{i,n}  \\
#   \colon & \colon & \colon  \\
#   D_{m,1} MULTI_QUBIT_GATE S_{m,1} & ..D_{m,j} MULTI_QUBIT_GATE S_{m,j}.. & D_{m,n} MULTI_QUBIT_GATE S_{m,n}
# A_{1,1} MULTI_QUBIT_GATE R_{1,1} & ..A_{1,j} MULTI_QUBIT_GATE R_{1,j}.. & A_{1,k} MULTI_QUBIT_GATE R_{1,k} & B_{1,1} MULTI_QUBIT_GATE S_{1,1} & ..B_{1,j} MULTI_QUBIT_GATE S_{1,j}.. & B_{1,n} MULTI_QUBIT_GATE S_{1,n} & C_{1,1} MULTI_QUBIT_GATE Q_{1,1} & ..C_{1,j} MULTI_QUBIT_GATE Q_{1,j}.. & C_{1,h} MULTI_QUBIT_GATE Q_{1,h}  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   A_{i,1} MULTI_QUBIT_GATE R_{i,1} & ..A_{i,j} MULTI_QUBIT_GATE R_{i,j}.. & A_{i,k} MULTI_QUBIT_GATE R_{i,k} & B_{i,1} MULTI_QUBIT_GATE S_{i,1} & ..B_{i,j} MULTI_QUBIT_GATE S_{i,j}.. & B_{i,n} MULTI_QUBIT_GATE S_{i,n} & C_{i,1} MULTI_QUBIT_GATE Q_{i,1} & ..C_{i,j} MULTI_QUBIT_GATE Q_{i,j}.. & C_{i,h} MULTI_QUBIT_GATE Q_{i,h}  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   A_{m,1} MULTI_QUBIT_GATE R_{m,1} & ..A_{m,j} MULTI_QUBIT_GATE R_{m,j}.. & A_{m,k} MULTI_QUBIT_GATE R_{m,k} & B_{m,1} MULTI_QUBIT_GATE S_{m,1} & ..B_{m,j} MULTI_QUBIT_GATE S_{m,j}.. & B_{m,n} MULTI_QUBIT_GATE S_{m,n} & C_{m,1} MULTI_QUBIT_GATE Q_{m,1} & ..C_{m,j} MULTI_QUBIT_GATE Q_{m,j}.. & C_{m,h} MULTI_QUBIT_GATE Q_{m,h}
# A_{1,1} MULTI_QUBIT_GATE R_{1,1} & ..A_{1,j} MULTI_QUBIT_GATE R_{1,j}.. & A_{1,k} MULTI_QUBIT_GATE R_{1,k} & D_{1,1} MULTI_QUBIT_GATE S_{1,1} & ..D_{1,j} MULTI_QUBIT_GATE S_{1,j}.. & D_{1,n} MULTI_QUBIT_GATE S_{1,n} & C_{1,1} MULTI_QUBIT_GATE Q_{1,1} & ..C_{1,j} MULTI_QUBIT_GATE Q_{1,j}.. & C_{1,h} MULTI_QUBIT_GATE Q_{1,h}  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   A_{i,1} MULTI_QUBIT_GATE R_{i,1} & ..A_{i,j} MULTI_QUBIT_GATE R_{i,j}.. & A_{i,k} MULTI_QUBIT_GATE R_{i,k} & D_{i,1} MULTI_QUBIT_GATE S_{i,1} & ..D_{i,j} MULTI_QUBIT_GATE S_{i,j}.. & D_{i,n} MULTI_QUBIT_GATE S_{i,n} & C_{i,1} MULTI_QUBIT_GATE Q_{i,1} & ..C_{i,j} MULTI_QUBIT_GATE Q_{i,j}.. & C_{i,h} MULTI_QUBIT_GATE Q_{i,h}  \\
#   \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon & \colon  \\
#   A_{m,1} MULTI_QUBIT_GATE R_{m,1} & ..A_{m,j} MULTI_QUBIT_GATE R_{m,j}.. & A_{m,k} MULTI_QUBIT_GATE R_{m,k} & D_{m,1} MULTI_QUBIT_GATE S_{m,1} & ..D_{m,j} MULTI_QUBIT_GATE S_{m,j}.. & D_{m,n} MULTI_QUBIT_GATE S_{m,n} & C_{m,1} MULTI_QUBIT_GATE Q_{m,1} & ..C_{m,j} MULTI_QUBIT_GATE Q_{m,j}.. & C_{m,h} MULTI_QUBIT_GATE Q_{m,h}
# ((B_{1,1} MULTI_QUBIT_GATE S_{1,1}, ..B_{1,_d} MULTI_QUBIT_GATE S_{1,_d}.., B_{1,n} MULTI_QUBIT_GATE S_{1,n}), ..(B_{_e,1} MULTI_QUBIT_GATE S_{_e,1}, ..B_{_e,_d} MULTI_QUBIT_GATE S_{_e,_d}.., B_{_e,n} MULTI_QUBIT_GATE S_{_e,n}).., (B_{m,1} MULTI_QUBIT_GATE S_{m,1}, ..B_{m,_d} MULTI_QUBIT_GATE S_{m,_d}.., B_{m,n} MULTI_QUBIT_GATE S_{m,n}))
# ((D_{1,1} MULTI_QUBIT_GATE S_{1,1}, ..D_{1,_d} MULTI_QUBIT_GATE S_{1,_d}.., D_{1,n} MULTI_QUBIT_GATE S_{1,n}), ..(D_{_e,1} MULTI_QUBIT_GATE S_{_e,1}, ..D_{_e,_d} MULTI_QUBIT_GATE S_{_e,_d}.., D_{_e,n} MULTI_QUBIT_GATE S_{_e,n}).., (D_{m,1} MULTI_QUBIT_GATE S_{m,1}, ..D_{m,_d} MULTI_QUBIT_GATE S_{m,_d}.., D_{m,n} MULTI_QUBIT_GATE S_{m,n}))
# ((A_{1,1} MULTI_QUBIT_GATE R_{1,1}, ..A_{1,_d} MULTI_QUBIT_GATE R_{1,_d}.., A_{1,k} MULTI_QUBIT_GATE R_{1,k}, B_{1,1} MULTI_QUBIT_GATE S_{1,1}, ..B_{1,_d} MULTI_QUBIT_GATE S_{1,_d}.., B_{1,n} MULTI_QUBIT_GATE S_{1,n}, C_{1,1} MULTI_QUBIT_GATE Q_{1,1}, ..C_{1,_d} MULTI_QUBIT_GATE Q_{1,_d}.., C_{1,h} MULTI_QUBIT_GATE Q_{1,h}), ..(A_{_k,1} MULTI_QUBIT_GATE R_{_k,1}, ..A_{_k,_d} MULTI_QUBIT_GATE R_{_k,_d}.., A_{_k,k} MULTI_QUBIT_GATE R_{_k,k}, B_{_k,1} MULTI_QUBIT_GATE S_{_k,1}, ..B_{_k,_d} MULTI_QUBIT_GATE S_{_k,_d}.., B_{_k,n} MULTI_QUBIT_GATE S_{_k,n}, C_{_k,1} MULTI_QUBIT_GATE Q_{_k,1}, ..C_{_k,_d} MULTI_QUBIT_GATE Q_{_k,_d}.., C_{_k,h} MULTI_QUBIT_GATE Q_{_k,h}).., (A_{m,1} MULTI_QUBIT_GATE R_{m,1}, ..A_{m,_d} MULTI_QUBIT_GATE R_{m,_d}.., A_{m,k} MULTI_QUBIT_GATE R_{m,k}, B_{m,1} MULTI_QUBIT_GATE S_{m,1}, ..B_{m,_d} MULTI_QUBIT_GATE S_{m,_d}.., B_{m,n} MULTI_QUBIT_GATE S_{m,n}, C_{m,1} MULTI_QUBIT_GATE Q_{m,1}, ..C_{m,_d} MULTI_QUBIT_GATE Q_{m,_d}.., C_{m,h} MULTI_QUBIT_GATE Q_{m,h}))
# ((A_{1,1} MULTI_QUBIT_GATE R_{1,1}, ..A_{1,_d} MULTI_QUBIT_GATE R_{1,_d}.., A_{1,k} MULTI_QUBIT_GATE R_{1,k}, D_{1,1} MULTI_QUBIT_GATE S_{1,1}, ..D_{1,_d} MULTI_QUBIT_GATE S_{1,_d}.., D_{1,n} MULTI_QUBIT_GATE S_{1,n}, C_{1,1} MULTI_QUBIT_GATE Q_{1,1}, ..C_{1,_d} MULTI_QUBIT_GATE Q_{1,_d}.., C_{1,h} MULTI_QUBIT_GATE Q_{1,h}), ..(A_{_k,1} MULTI_QUBIT_GATE R_{_k,1}, ..A_{_k,_d} MULTI_QUBIT_GATE R_{_k,_d}.., A_{_k,k} MULTI_QUBIT_GATE R_{_k,k}, D_{_k,1} MULTI_QUBIT_GATE S_{_k,1}, ..D_{_k,_d} MULTI_QUBIT_GATE S_{_k,_d}.., D_{_k,n} MULTI_QUBIT_GATE S_{_k,n}, C_{_k,1} MULTI_QUBIT_GATE Q_{_k,1}, ..C_{_k,_d} MULTI_QUBIT_GATE Q_{_k,_d}.., C_{_k,h} MULTI_QUBIT_GATE Q_{_k,h}).., (A_{m,1} MULTI_QUBIT_GATE R_{m,1}, ..A_{m,_d} MULTI_QUBIT_GATE R_{m,_d}.., A_{m,k} MULTI_QUBIT_GATE R_{m,k}, D_{m,1} MULTI_QUBIT_GATE S_{m,1}, ..D_{m,_d} MULTI_QUBIT_GATE S_{m,_d}.., D_{m,n} MULTI_QUBIT_GATE S_{m,n}, C_{m,1} MULTI_QUBIT_GATE Q_{m,1}, ..C_{m,_d} MULTI_QUBIT_GATE Q_{m,_d}.., C_{m,h} MULTI_QUBIT_GATE Q_{m,h}))
# ((_l_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._l_{1,_d} MULTI_QUBIT_GATE _i_{1,_d}.., _l_{1,n} MULTI_QUBIT_GATE _i_{1,n}), ..(_l_{_e,1} MULTI_QUBIT_GATE _i_{_e,1}, .._l_{_e,_d} MULTI_QUBIT_GATE _i_{_e,_d}.., _l_{_e,n} MULTI_QUBIT_GATE _i_{_e,n}).., (_l_{m,1} MULTI_QUBIT_GATE _i_{m,1}, .._l_{m,_d} MULTI_QUBIT_GATE _i_{m,_d}.., _l_{m,n} MULTI_QUBIT_GATE _i_{m,n}))
# ((_j_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._j_{1,_d} MULTI_QUBIT_GATE _i_{1,_d}.., _j_{1,n} MULTI_QUBIT_GATE _i_{1,n}), ..(_j_{_e,1} MULTI_QUBIT_GATE _i_{_e,1}, .._j_{_e,_d} MULTI_QUBIT_GATE _i_{_e,_d}.., _j_{_e,n} MULTI_QUBIT_GATE _i_{_e,n}).., (_j_{m,1} MULTI_QUBIT_GATE _i_{m,1}, .._j_{m,_d} MULTI_QUBIT_GATE _i_{m,_d}.., _j_{m,n} MULTI_QUBIT_GATE _i_{m,n}))
# ((_m_{1,1} MULTI_QUBIT_GATE _h_{1,1}, .._m_{1,_d} MULTI_QUBIT_GATE _h_{1,_d}.., _m_{1,k} MULTI_QUBIT_GATE _h_{1,k}, _l_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._l_{1,_d} MULTI_QUBIT_GATE _i_{1,_d}.., _l_{1,n} MULTI_QUBIT_GATE _i_{1,n}, _k_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._k_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _k_{1,h} MULTI_QUBIT_GATE _g_{1,h}), ..(_m_{_a,1} MULTI_QUBIT_GATE _h_{_a,1}, .._m_{_a,_d} MULTI_QUBIT_GATE _h_{_a,_d}.., _m_{_a,k} MULTI_QUBIT_GATE _h_{_a,k}, _l_{_a,1} MULTI_QUBIT_GATE _i_{_a,1}, .._l_{_a,_d} MULTI_QUBIT_GATE _i_{_a,_d}.., _l_{_a,n} MULTI_QUBIT_GATE _i_{_a,n}, _k_{_a,1} MULTI_QUBIT_GATE _g_{_a,1}, .._k_{_a,_d} MULTI_QUBIT_GATE _g_{_a,_d}.., _k_{_a,h} MULTI_QUBIT_GATE _g_{_a,h}).., (_m_{m,1} MULTI_QUBIT_GATE _h_{m,1}, .._m_{m,_d} MULTI_QUBIT_GATE _h_{m,_d}.., _m_{m,k} MULTI_QUBIT_GATE _h_{m,k}, _l_{m,1} MULTI_QUBIT_GATE _i_{m,1}, .._l_{m,_d} MULTI_QUBIT_GATE _i_{m,_d}.., _l_{m,n} MULTI_QUBIT_GATE _i_{m,n}, _k_{m,1} MULTI_QUBIT_GATE _g_{m,1}, .._k_{m,_d} MULTI_QUBIT_GATE _g_{m,_d}.., _k_{m,h} MULTI_QUBIT_GATE _g_{m,h}))
# ((_m_{1,1} MULTI_QUBIT_GATE _h_{1,1}, .._m_{1,_d} MULTI_QUBIT_GATE _h_{1,_d}.., _m_{1,k} MULTI_QUBIT_GATE _h_{1,k}, _j_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._j_{1,_d} MULTI_QUBIT_GATE _i_{1,_d}.., _j_{1,n} MULTI_QUBIT_GATE _i_{1,n}, _k_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._k_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _k_{1,h} MULTI_QUBIT_GATE _g_{1,h}), ..(_m_{_a,1} MULTI_QUBIT_GATE _h_{_a,1}, .._m_{_a,_d} MULTI_QUBIT_GATE _h_{_a,_d}.., _m_{_a,k} MULTI_QUBIT_GATE _h_{_a,k}, _j_{_a,1} MULTI_QUBIT_GATE _i_{_a,1}, .._j_{_a,_d} MULTI_QUBIT_GATE _i_{_a,_d}.., _j_{_a,n} MULTI_QUBIT_GATE _i_{_a,n}, _k_{_a,1} MULTI_QUBIT_GATE _g_{_a,1}, .._k_{_a,_d} MULTI_QUBIT_GATE _g_{_a,_d}.., _k_{_a,h} MULTI_QUBIT_GATE _g_{_a,h}).., (_m_{m,1} MULTI_QUBIT_GATE _h_{m,1}, .._m_{m,_d} MULTI_QUBIT_GATE _h_{m,_d}.., _m_{m,k} MULTI_QUBIT_GATE _h_{m,k}, _j_{m,1} MULTI_QUBIT_GATE _i_{m,1}, .._j_{m,_d} MULTI_QUBIT_GATE _i_{m,_d}.., _j_{m,n} MULTI_QUBIT_GATE _i_{m,n}, _k_{m,1} MULTI_QUBIT_GATE _g_{m,1}, .._k_{m,_d} MULTI_QUBIT_GATE _g_{m,_d}.., _k_{m,h} MULTI_QUBIT_GATE _g_{m,h}))
# ((_m_{1,1} MULTI_QUBIT_GATE _h_{1,1}, .._m_{1,_d} MULTI_QUBIT_GATE _h_{1,_d}.., _m_{1,k} MULTI_QUBIT_GATE _h_{1,k}, _l_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._l_{1,_d} MULTI_QUBIT_GATE _i_{1,_d}.., _l_{1,n} MULTI_QUBIT_GATE _i_{1,n}, _k_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._k_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _k_{1,h} MULTI_QUBIT_GATE _g_{1,h}), ..(_m_{_n,1} MULTI_QUBIT_GATE _h_{_n,1}, .._m_{_n,_d} MULTI_QUBIT_GATE _h_{_n,_d}.., _m_{_n,k} MULTI_QUBIT_GATE _h_{_n,k}, _l_{_n,1} MULTI_QUBIT_GATE _i_{_n,1}, .._l_{_n,_d} MULTI_QUBIT_GATE _i_{_n,_d}.., _l_{_n,n} MULTI_QUBIT_GATE _i_{_n,n}, _k_{_n,1} MULTI_QUBIT_GATE _g_{_n,1}, .._k_{_n,_d} MULTI_QUBIT_GATE _g_{_n,_d}.., _k_{_n,h} MULTI_QUBIT_GATE _g_{_n,h}).., (_m_{m,1} MULTI_QUBIT_GATE _h_{m,1}, .._m_{m,_d} MULTI_QUBIT_GATE _h_{m,_d}.., _m_{m,k} MULTI_QUBIT_GATE _h_{m,k}, _l_{m,1} MULTI_QUBIT_GATE _i_{m,1}, .._l_{m,_d} MULTI_QUBIT_GATE _i_{m,_d}.., _l_{m,n} MULTI_QUBIT_GATE _i_{m,n}, _k_{m,1} MULTI_QUBIT_GATE _g_{m,1}, .._k_{m,_d} MULTI_QUBIT_GATE _g_{m,_d}.., _k_{m,h} MULTI_QUBIT_GATE _g_{m,h}))
# ((_m_{1,1} MULTI_QUBIT_GATE _h_{1,1}, .._m_{1,_d} MULTI_QUBIT_GATE _h_{1,_d}.., _m_{1,k} MULTI_QUBIT_GATE _h_{1,k}, _j_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._j_{1,_d} MULTI_QUBIT_GATE _i_{1,_d}.., _j_{1,n} MULTI_QUBIT_GATE _i_{1,n}, _k_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._k_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _k_{1,h} MULTI_QUBIT_GATE _g_{1,h}), ..(_m_{_l,1} MULTI_QUBIT_GATE _h_{_l,1}, .._m_{_l,_d} MULTI_QUBIT_GATE _h_{_l,_d}.., _m_{_l,k} MULTI_QUBIT_GATE _h_{_l,k}, _j_{_l,1} MULTI_QUBIT_GATE _i_{_l,1}, .._j_{_l,_d} MULTI_QUBIT_GATE _i_{_l,_d}.., _j_{_l,n} MULTI_QUBIT_GATE _i_{_l,n}, _k_{_l,1} MULTI_QUBIT_GATE _g_{_l,1}, .._k_{_l,_d} MULTI_QUBIT_GATE _g_{_l,_d}.., _k_{_l,h} MULTI_QUBIT_GATE _g_{_l,h}).., (_m_{m,1} MULTI_QUBIT_GATE _h_{m,1}, .._m_{m,_d} MULTI_QUBIT_GATE _h_{m,_d}.., _m_{m,k} MULTI_QUBIT_GATE _h_{m,k}, _j_{m,1} MULTI_QUBIT_GATE _i_{m,1}, .._j_{m,_d} MULTI_QUBIT_GATE _i_{m,_d}.., _j_{m,n} MULTI_QUBIT_GATE _i_{m,n}, _k_{m,1} MULTI_QUBIT_GATE _g_{m,1}, .._k_{m,_d} MULTI_QUBIT_GATE _g_{m,_d}.., _k_{m,h} MULTI_QUBIT_GATE _g_{m,h}))
# ((_b_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._b_{1,_f} MULTI_QUBIT_GATE _i_{1,_f}.., _b_{1,_j} MULTI_QUBIT_GATE _i_{1,_j}), ..(_b_{_e,1} MULTI_QUBIT_GATE _i_{_e,1}, .._b_{_e,_f} MULTI_QUBIT_GATE _i_{_e,_f}.., _b_{_e,_j} MULTI_QUBIT_GATE _i_{_e,_j}).., (_b_{_k,1} MULTI_QUBIT_GATE _i_{_k,1}, .._b_{_k,_f} MULTI_QUBIT_GATE _i_{_k,_f}.., _b_{_k,_j} MULTI_QUBIT_GATE _i_{_k,_j}))
# ((_a_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._a_{1,_f} MULTI_QUBIT_GATE _i_{1,_f}.., _a_{1,_j} MULTI_QUBIT_GATE _i_{1,_j}), ..(_a_{_e,1} MULTI_QUBIT_GATE _i_{_e,1}, .._a_{_e,_f} MULTI_QUBIT_GATE _i_{_e,_f}.., _a_{_e,_j} MULTI_QUBIT_GATE _i_{_e,_j}).., (_a_{_k,1} MULTI_QUBIT_GATE _i_{_k,1}, .._a_{_k,_f} MULTI_QUBIT_GATE _i_{_k,_f}.., _a_{_k,_j} MULTI_QUBIT_GATE _i_{_k,_j}))
# ((_d_{1,1} MULTI_QUBIT_GATE _h_{1,1}, .._d_{1,_e} MULTI_QUBIT_GATE _h_{1,_e}.., _d_{1,_l} MULTI_QUBIT_GATE _h_{1,_l}, _b_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._b_{1,_e} MULTI_QUBIT_GATE _i_{1,_e}.., _b_{1,_j} MULTI_QUBIT_GATE _i_{1,_j}, _c_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._c_{1,_e} MULTI_QUBIT_GATE _g_{1,_e}.., _c_{1,_m} MULTI_QUBIT_GATE _g_{1,_m}), ..(_d_{_n,1} MULTI_QUBIT_GATE _h_{_n,1}, .._d_{_n,_e} MULTI_QUBIT_GATE _h_{_n,_e}.., _d_{_n,_l} MULTI_QUBIT_GATE _h_{_n,_l}, _b_{_n,1} MULTI_QUBIT_GATE _i_{_n,1}, .._b_{_n,_e} MULTI_QUBIT_GATE _i_{_n,_e}.., _b_{_n,_j} MULTI_QUBIT_GATE _i_{_n,_j}, _c_{_n,1} MULTI_QUBIT_GATE _g_{_n,1}, .._c_{_n,_e} MULTI_QUBIT_GATE _g_{_n,_e}.., _c_{_n,_m} MULTI_QUBIT_GATE _g_{_n,_m}).., (_d_{_k,1} MULTI_QUBIT_GATE _h_{_k,1}, .._d_{_k,_e} MULTI_QUBIT_GATE _h_{_k,_e}.., _d_{_k,_l} MULTI_QUBIT_GATE _h_{_k,_l}, _b_{_k,1} MULTI_QUBIT_GATE _i_{_k,1}, .._b_{_k,_e} MULTI_QUBIT_GATE _i_{_k,_e}.., _b_{_k,_j} MULTI_QUBIT_GATE _i_{_k,_j}, _c_{_k,1} MULTI_QUBIT_GATE _g_{_k,1}, .._c_{_k,_e} MULTI_QUBIT_GATE _g_{_k,_e}.., _c_{_k,_m} MULTI_QUBIT_GATE _g_{_k,_m}))
# ((_d_{1,1} MULTI_QUBIT_GATE _h_{1,1}, .._d_{1,_e} MULTI_QUBIT_GATE _h_{1,_e}.., _d_{1,_l} MULTI_QUBIT_GATE _h_{1,_l}, _a_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._a_{1,_e} MULTI_QUBIT_GATE _i_{1,_e}.., _a_{1,_j} MULTI_QUBIT_GATE _i_{1,_j}, _c_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._c_{1,_e} MULTI_QUBIT_GATE _g_{1,_e}.., _c_{1,_m} MULTI_QUBIT_GATE _g_{1,_m}), ..(_d_{_b,1} MULTI_QUBIT_GATE _h_{_b,1}, .._d_{_b,_e} MULTI_QUBIT_GATE _h_{_b,_e}.., _d_{_b,_l} MULTI_QUBIT_GATE _h_{_b,_l}, _a_{_b,1} MULTI_QUBIT_GATE _i_{_b,1}, .._a_{_b,_e} MULTI_QUBIT_GATE _i_{_b,_e}.., _a_{_b,_j} MULTI_QUBIT_GATE _i_{_b,_j}, _c_{_b,1} MULTI_QUBIT_GATE _g_{_b,1}, .._c_{_b,_e} MULTI_QUBIT_GATE _g_{_b,_e}.., _c_{_b,_m} MULTI_QUBIT_GATE _g_{_b,_m}).., (_d_{_k,1} MULTI_QUBIT_GATE _h_{_k,1}, .._d_{_k,_e} MULTI_QUBIT_GATE _h_{_k,_e}.., _d_{_k,_l} MULTI_QUBIT_GATE _h_{_k,_l}, _a_{_k,1} MULTI_QUBIT_GATE _i_{_k,1}, .._a_{_k,_e} MULTI_QUBIT_GATE _i_{_k,_e}.., _a_{_k,_j} MULTI_QUBIT_GATE _i_{_k,_j}, _c_{_k,1} MULTI_QUBIT_GATE _g_{_k,1}, .._c_{_k,_e} MULTI_QUBIT_GATE _g_{_k,_e}.., _c_{_k,_m} MULTI_QUBIT_GATE _g_{_k,_m}))
# ((_d_{1,1} MULTI_QUBIT_GATE _h_{1,1}, .._d_{1,_e} MULTI_QUBIT_GATE _h_{1,_e}.., _d_{1,_l} MULTI_QUBIT_GATE _h_{1,_l}, _b_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._b_{1,_d} MULTI_QUBIT_GATE _i_{1,_d}.., _b_{1,_j} MULTI_QUBIT_GATE _i_{1,_j}, _c_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._c_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _c_{1,_m} MULTI_QUBIT_GATE _g_{1,_m}), ..(_d_{_k,1} MULTI_QUBIT_GATE _h_{_k,1}, .._d_{_k,_e} MULTI_QUBIT_GATE _h_{_k,_e}.., _d_{_k,_l} MULTI_QUBIT_GATE _h_{_k,_l}, _b_{_k,1} MULTI_QUBIT_GATE _i_{_k,1}, .._b_{_k,_d} MULTI_QUBIT_GATE _i_{_k,_d}.., _b_{_k,_j} MULTI_QUBIT_GATE _i_{_k,_j}, _c_{_k,1} MULTI_QUBIT_GATE _g_{_k,1}, .._c_{_k,_d} MULTI_QUBIT_GATE _g_{_k,_d}.., _c_{_k,_m} MULTI_QUBIT_GATE _g_{_k,_m}).., (_d_{_k,1} MULTI_QUBIT_GATE _h_{_k,1}, .._d_{_k,_e} MULTI_QUBIT_GATE _h_{_k,_e}.., _d_{_k,_l} MULTI_QUBIT_GATE _h_{_k,_l}, _b_{_k,1} MULTI_QUBIT_GATE _i_{_k,1}, .._b_{_k,_d} MULTI_QUBIT_GATE _i_{_k,_d}.., _b_{_k,_j} MULTI_QUBIT_GATE _i_{_k,_j}, _c_{_k,1} MULTI_QUBIT_GATE _g_{_k,1}, .._c_{_k,_d} MULTI_QUBIT_GATE _g_{_k,_d}.., _c_{_k,_m} MULTI_QUBIT_GATE _g_{_k,_m}))
# ((_d_{1,1} MULTI_QUBIT_GATE _h_{1,1}, .._d_{1,_e} MULTI_QUBIT_GATE _h_{1,_e}.., _d_{1,_l} MULTI_QUBIT_GATE _h_{1,_l}, _a_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._a_{1,_d} MULTI_QUBIT_GATE _i_{1,_d}.., _a_{1,_j} MULTI_QUBIT_GATE _i_{1,_j}, _c_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._c_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _c_{1,_m} MULTI_QUBIT_GATE _g_{1,_m}), ..(_d_{_k,1} MULTI_QUBIT_GATE _h_{_k,1}, .._d_{_k,_e} MULTI_QUBIT_GATE _h_{_k,_e}.., _d_{_k,_l} MULTI_QUBIT_GATE _h_{_k,_l}, _a_{_k,1} MULTI_QUBIT_GATE _i_{_k,1}, .._a_{_k,_d} MULTI_QUBIT_GATE _i_{_k,_d}.., _a_{_k,_j} MULTI_QUBIT_GATE _i_{_k,_j}, _c_{_k,1} MULTI_QUBIT_GATE _g_{_k,1}, .._c_{_k,_d} MULTI_QUBIT_GATE _g_{_k,_d}.., _c_{_k,_m} MULTI_QUBIT_GATE _g_{_k,_m}).., (_d_{_k,1} MULTI_QUBIT_GATE _h_{_k,1}, .._d_{_k,_e} MULTI_QUBIT_GATE _h_{_k,_e}.., _d_{_k,_l} MULTI_QUBIT_GATE _h_{_k,_l}, _a_{_k,1} MULTI_QUBIT_GATE _i_{_k,1}, .._a_{_k,_d} MULTI_QUBIT_GATE _i_{_k,_d}.., _a_{_k,_j} MULTI_QUBIT_GATE _i_{_k,_j}, _c_{_k,1} MULTI_QUBIT_GATE _g_{_k,1}, .._c_{_k,_d} MULTI_QUBIT_GATE _g_{_k,_d}.., _c_{_k,_m} MULTI_QUBIT_GATE _g_{_k,_m}))
# ((_p_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._p_{1,_f} MULTI_QUBIT_GATE _i_{1,_f}.., _p_{1,_j} MULTI_QUBIT_GATE _i_{1,_j}), ..(_p_{_e,1} MULTI_QUBIT_GATE _i_{_e,1}, .._p_{_e,_f} MULTI_QUBIT_GATE _i_{_e,_f}.., _p_{_e,_j} MULTI_QUBIT_GATE _i_{_e,_j}).., (_p_{_k,1} MULTI_QUBIT_GATE _i_{_k,1}, .._p_{_k,_f} MULTI_QUBIT_GATE _i_{_k,_f}.., _p_{_k,_j} MULTI_QUBIT_GATE _i_{_k,_j}))
# ((_n_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._n_{1,_f} MULTI_QUBIT_GATE _i_{1,_f}.., _n_{1,_j} MULTI_QUBIT_GATE _i_{1,_j}), ..(_n_{_e,1} MULTI_QUBIT_GATE _i_{_e,1}, .._n_{_e,_f} MULTI_QUBIT_GATE _i_{_e,_f}.., _n_{_e,_j} MULTI_QUBIT_GATE _i_{_e,_j}).., (_n_{_k,1} MULTI_QUBIT_GATE _i_{_k,1}, .._n_{_k,_f} MULTI_QUBIT_GATE _i_{_k,_f}.., _n_{_k,_j} MULTI_QUBIT_GATE _i_{_k,_j}))
# ((_q_{1,1} MULTI_QUBIT_GATE _h_{1,1}, .._q_{1,_e} MULTI_QUBIT_GATE _h_{1,_e}.., _q_{1,_l} MULTI_QUBIT_GATE _h_{1,_l}, _p_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._p_{1,_d} MULTI_QUBIT_GATE _i_{1,_d}.., _p_{1,_j} MULTI_QUBIT_GATE _i_{1,_j}, _o_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._o_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _o_{1,_m} MULTI_QUBIT_GATE _g_{1,_m}), ..(_q_{_k,1} MULTI_QUBIT_GATE _h_{_k,1}, .._q_{_k,_e} MULTI_QUBIT_GATE _h_{_k,_e}.., _q_{_k,_l} MULTI_QUBIT_GATE _h_{_k,_l}, _p_{_k,1} MULTI_QUBIT_GATE _i_{_k,1}, .._p_{_k,_d} MULTI_QUBIT_GATE _i_{_k,_d}.., _p_{_k,_j} MULTI_QUBIT_GATE _i_{_k,_j}, _o_{_k,1} MULTI_QUBIT_GATE _g_{_k,1}, .._o_{_k,_d} MULTI_QUBIT_GATE _g_{_k,_d}.., _o_{_k,_m} MULTI_QUBIT_GATE _g_{_k,_m}).., (_q_{_k,1} MULTI_QUBIT_GATE _h_{_k,1}, .._q_{_k,_e} MULTI_QUBIT_GATE _h_{_k,_e}.., _q_{_k,_l} MULTI_QUBIT_GATE _h_{_k,_l}, _p_{_k,1} MULTI_QUBIT_GATE _i_{_k,1}, .._p_{_k,_d} MULTI_QUBIT_GATE _i_{_k,_d}.., _p_{_k,_j} MULTI_QUBIT_GATE _i_{_k,_j}, _o_{_k,1} MULTI_QUBIT_GATE _g_{_k,1}, .._o_{_k,_d} MULTI_QUBIT_GATE _g_{_k,_d}.., _o_{_k,_m} MULTI_QUBIT_GATE _g_{_k,_m}))
# ((_q_{1,1} MULTI_QUBIT_GATE _h_{1,1}, .._q_{1,_e} MULTI_QUBIT_GATE _h_{1,_e}.., _q_{1,_l} MULTI_QUBIT_GATE _h_{1,_l}, _n_{1,1} MULTI_QUBIT_GATE _i_{1,1}, .._n_{1,_d} MULTI_QUBIT_GATE _i_{1,_d}.., _n_{1,_j} MULTI_QUBIT_GATE _i_{1,_j}, _o_{1,1} MULTI_QUBIT_GATE _g_{1,1}, .._o_{1,_d} MULTI_QUBIT_GATE _g_{1,_d}.., _o_{1,_m} MULTI_QUBIT_GATE _g_{1,_m}), ..(_q_{_k,1} MULTI_QUBIT_GATE _h_{_k,1}, .._q_{_k,_e} MULTI_QUBIT_GATE _h_{_k,_e}.., _q_{_k,_l} MULTI_QUBIT_GATE _h_{_k,_l}, _n_{_k,1} MULTI_QUBIT_GATE _i_{_k,1}, .._n_{_k,_d} MULTI_QUBIT_GATE _i_{_k,_d}.., _n_{_k,_j} MULTI_QUBIT_GATE _i_{_k,_j}, _o_{_k,1} MULTI_QUBIT_GATE _g_{_k,1}, .._o_{_k,_d} MULTI_QUBIT_GATE _g_{_k,_d}.., _o_{_k,_m} MULTI_QUBIT_GATE _g_{_k,_m}).., (_q_{_k,1} MULTI_QUBIT_GATE _h_{_k,1}, .._q_{_k,_e} MULTI_QUBIT_GATE _h_{_k,_e}.., _q_{_k,_l} MULTI_QUBIT_GATE _h_{_k,_l}, _n_{_k,1} MULTI_QUBIT_GATE _i_{_k,1}, .._n_{_k,_d} MULTI_QUBIT_GATE _i_{_k,_d}.., _n_{_k,_j} MULTI_QUBIT_GATE _i_{_k,_j}, _o_{_k,1} MULTI_QUBIT_GATE _g_{_k,1}, .._o_{_k,_d} MULTI_QUBIT_GATE _g_{_k,_d}.., _o_{_k,_m} MULTI_QUBIT_GATE _g_{_k,_m}))
# time_equiv: forall_{h in NaturalsPos, k in NaturalsPos, m in NaturalsPos, n in NaturalsPos} [forall_{A_{1,1}, ..A_{1,_b}.., A_{1,k}, ....A_{_a,1}, ..A_{_a,_b}.., A_{_a,k}...., A_{m,1}, ..A_{m,_b}.., A_{m,k}, B_{1,1}, ..B_{1,_b}.., B_{1,n}, ....B_{_a,1}, ..B_{_a,_b}.., B_{_a,n}...., B_{m,1}, ..B_{m,_b}.., B_{m,n}, C_{1,1}, ..C_{1,_b}.., C_{1,h}, ....C_{_a,1}, ..C_{_a,_b}.., C_{_a,h}...., C_{m,1}, ..C_{m,_b}.., C_{m,h}, D_{1,1}, ..D_{1,_b}.., D_{1,n}, ....D_{_a,1}, ..D_{_a,_b}.., D_{_a,n}...., D_{m,1}, ..D_{m,_b}.., D_{m,n}, S_{1,1}, ..S_{1,_b}.., S_{1,n}, ....S_{_a,1}, ..S_{_a,_b}.., S_{_a,n}...., S_{m,1}, ..S_{m,_b}.., S_{m,n}, R_{1,1}, ..R_{1,_b}.., R_{1,k}, ....R_{_a,1}, ..R_{_a,_b}.., R_{_a,k}...., R_{m,1}, ..R_{m,_b}.., R_{m,k}, Q_{1,1}, ..Q_{1,_b}.., Q_{1,h}, ....Q_{_a,1}, ..Q_{_a,_b}.., Q_{_a,h}...., Q_{m,1}, ..Q_{m,_b}.., Q_{m,h}} (( B_{1,1} MULTI_QUBIT_GATE S_{1,1}  & ..B_{1,j} MULTI_QUBIT_GATE S_{1,j}..  & B_{1,n} MULTI_QUBIT_GATE S_{1,n}   \\
#    \colon  & \colon  & \colon   \\
#    B_{i,1} MULTI_QUBIT_GATE S_{i,1}  & ..B_{i,j} MULTI_QUBIT_GATE S_{i,j}..  & B_{i,n} MULTI_QUBIT_GATE S_{i,n}   \\
#    \colon  & \colon  & \colon   \\
#    B_{m,1} MULTI_QUBIT_GATE S_{m,1}  & ..B_{m,j} MULTI_QUBIT_GATE S_{m,j}..  & B_{m,n} MULTI_QUBIT_GATE S_{m,n} equiv  D_{1,1} MULTI_QUBIT_GATE S_{1,1}  & ..D_{1,j} MULTI_QUBIT_GATE S_{1,j}..  & D_{1,n} MULTI_QUBIT_GATE S_{1,n}   \\
#    \colon  & \colon  & \colon   \\
#    D_{i,1} MULTI_QUBIT_GATE S_{i,1}  & ..D_{i,j} MULTI_QUBIT_GATE S_{i,j}..  & D_{i,n} MULTI_QUBIT_GATE S_{i,n}   \\
#    \colon  & \colon  & \colon   \\
#    D_{m,1} MULTI_QUBIT_GATE S_{m,1}  & ..D_{m,j} MULTI_QUBIT_GATE S_{m,j}..  & D_{m,n} MULTI_QUBIT_GATE S_{m,n}) =>  \\ ( A_{1,1} MULTI_QUBIT_GATE R_{1,1}  & ..A_{1,j} MULTI_QUBIT_GATE R_{1,j}..  & A_{1,k} MULTI_QUBIT_GATE R_{1,k}  & B_{1,1} MULTI_QUBIT_GATE S_{1,1}  & ..B_{1,j} MULTI_QUBIT_GATE S_{1,j}..  & B_{1,n} MULTI_QUBIT_GATE S_{1,n}  & C_{1,1} MULTI_QUBIT_GATE Q_{1,1}  & ..C_{1,j} MULTI_QUBIT_GATE Q_{1,j}..  & C_{1,h} MULTI_QUBIT_GATE Q_{1,h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i,1} MULTI_QUBIT_GATE R_{i,1}  & ..A_{i,j} MULTI_QUBIT_GATE R_{i,j}..  & A_{i,k} MULTI_QUBIT_GATE R_{i,k}  & B_{i,1} MULTI_QUBIT_GATE S_{i,1}  & ..B_{i,j} MULTI_QUBIT_GATE S_{i,j}..  & B_{i,n} MULTI_QUBIT_GATE S_{i,n}  & C_{i,1} MULTI_QUBIT_GATE Q_{i,1}  & ..C_{i,j} MULTI_QUBIT_GATE Q_{i,j}..  & C_{i,h} MULTI_QUBIT_GATE Q_{i,h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{m,1} MULTI_QUBIT_GATE R_{m,1}  & ..A_{m,j} MULTI_QUBIT_GATE R_{m,j}..  & A_{m,k} MULTI_QUBIT_GATE R_{m,k}  & B_{m,1} MULTI_QUBIT_GATE S_{m,1}  & ..B_{m,j} MULTI_QUBIT_GATE S_{m,j}..  & B_{m,n} MULTI_QUBIT_GATE S_{m,n}  & C_{m,1} MULTI_QUBIT_GATE Q_{m,1}  & ..C_{m,j} MULTI_QUBIT_GATE Q_{m,j}..  & C_{m,h} MULTI_QUBIT_GATE Q_{m,h} equiv  A_{1,1} MULTI_QUBIT_GATE R_{1,1}  & ..A_{1,j} MULTI_QUBIT_GATE R_{1,j}..  & A_{1,k} MULTI_QUBIT_GATE R_{1,k}  & D_{1,1} MULTI_QUBIT_GATE S_{1,1}  & ..D_{1,j} MULTI_QUBIT_GATE S_{1,j}..  & D_{1,n} MULTI_QUBIT_GATE S_{1,n}  & C_{1,1} MULTI_QUBIT_GATE Q_{1,1}  & ..C_{1,j} MULTI_QUBIT_GATE Q_{1,j}..  & C_{1,h} MULTI_QUBIT_GATE Q_{1,h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{i,1} MULTI_QUBIT_GATE R_{i,1}  & ..A_{i,j} MULTI_QUBIT_GATE R_{i,j}..  & A_{i,k} MULTI_QUBIT_GATE R_{i,k}  & D_{i,1} MULTI_QUBIT_GATE S_{i,1}  & ..D_{i,j} MULTI_QUBIT_GATE S_{i,j}..  & D_{i,n} MULTI_QUBIT_GATE S_{i,n}  & C_{i,1} MULTI_QUBIT_GATE Q_{i,1}  & ..C_{i,j} MULTI_QUBIT_GATE Q_{i,j}..  & C_{i,h} MULTI_QUBIT_GATE Q_{i,h}   \\
#    \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon  & \colon   \\
#    A_{m,1} MULTI_QUBIT_GATE R_{m,1}  & ..A_{m,j} MULTI_QUBIT_GATE R_{m,j}..  & A_{m,k} MULTI_QUBIT_GATE R_{m,k}  & D_{m,1} MULTI_QUBIT_GATE S_{m,1}  & ..D_{m,j} MULTI_QUBIT_GATE S_{m,j}..  & D_{m,n} MULTI_QUBIT_GATE S_{m,n}  & C_{m,1} MULTI_QUBIT_GATE Q_{m,1}  & ..C_{m,j} MULTI_QUBIT_GATE Q_{m,j}..  & C_{m,h} MULTI_QUBIT_GATE Q_{m,h}))]

# %%
single_space_equiv = Forall((k, m, n), Forall((varRange(A, [one, one], [m, n]), varRange(B, one, n),
                                              varRange(C, [one, one], [k, n]), varRange(D, one, n),
                                              S11_to_Smn, varRange(Q, one, n), 
                                              varRange(R, [one, one], [k, n])),
        Implies(
            CircuitEquiv(
                    Circuit(ExprTuple(ExprRange(j, Gate(indexed_var(B, j)), one, n))),
                    Circuit(ExprTuple(ExprRange(j, Gate(indexed_var(D, j)), one, n)))
            ),
            CircuitEquiv(
                    Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, n)), one, m),
                            ExprTuple(ExprRange(j, Gate(indexed_var(B, j)), one, n)),
                            ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k))),
                    Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, n)), one, m),
                            ExprTuple(ExprRange(j, Gate(indexed_var(D, j)), one, n)),
                            ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k)))
            )
        ).withWrappingAt(2)
    ), domain=NaturalsPos)
# Out:
# ([GATE](B_{1}), ..[GATE](B_{j}).., [GATE](B_{n}))
# ([GATE](D_{1}), ..[GATE](D_{j}).., [GATE](D_{n}))
# A_{1,1} MULTI_QUBIT_GATE S_{1,1} & ..A_{1,j} MULTI_QUBIT_GATE S_{1,j}.. & A_{1,n} MULTI_QUBIT_GATE S_{1,n}  \\
#   \colon & \colon & \colon  \\
#   A_{i,1} MULTI_QUBIT_GATE S_{i,1} & ..A_{i,j} MULTI_QUBIT_GATE S_{i,j}.. & A_{i,n} MULTI_QUBIT_GATE S_{i,n}  \\
#   \colon & \colon & \colon  \\
#   A_{m,1} MULTI_QUBIT_GATE S_{m,1} & ..A_{m,j} MULTI_QUBIT_GATE S_{m,j}.. & A_{m,n} MULTI_QUBIT_GATE S_{m,n}  \\
#   [GATE](B_{1}) & ..[GATE](B_{j}).. & [GATE](B_{n})  \\
#   C_{1,1} MULTI_QUBIT_GATE R_{1,1} & ..C_{1,j} MULTI_QUBIT_GATE R_{1,j}.. & C_{1,n} MULTI_QUBIT_GATE R_{1,n}  \\
#   \colon & \colon & \colon  \\
#   C_{i,1} MULTI_QUBIT_GATE R_{i,1} & ..C_{i,j} MULTI_QUBIT_GATE R_{i,j}.. & C_{i,n} MULTI_QUBIT_GATE R_{i,n}  \\
#   \colon & \colon & \colon  \\
#   C_{k,1} MULTI_QUBIT_GATE R_{k,1} & ..C_{k,j} MULTI_QUBIT_GATE R_{k,j}.. & C_{k,n} MULTI_QUBIT_GATE R_{k,n}
# A_{1,1} MULTI_QUBIT_GATE S_{1,1} & ..A_{1,j} MULTI_QUBIT_GATE S_{1,j}.. & A_{1,n} MULTI_QUBIT_GATE S_{1,n}  \\
#   \colon & \colon & \colon  \\
#   A_{i,1} MULTI_QUBIT_GATE S_{i,1} & ..A_{i,j} MULTI_QUBIT_GATE S_{i,j}.. & A_{i,n} MULTI_QUBIT_GATE S_{i,n}  \\
#   \colon & \colon & \colon  \\
#   A_{m,1} MULTI_QUBIT_GATE S_{m,1} & ..A_{m,j} MULTI_QUBIT_GATE S_{m,j}.. & A_{m,n} MULTI_QUBIT_GATE S_{m,n}  \\
#   [GATE](D_{1}) & ..[GATE](D_{j}).. & [GATE](D_{n})  \\
#   C_{1,1} MULTI_QUBIT_GATE R_{1,1} & ..C_{1,j} MULTI_QUBIT_GATE R_{1,j}.. & C_{1,n} MULTI_QUBIT_GATE R_{1,n}  \\
#   \colon & \colon & \colon  \\
#   C_{i,1} MULTI_QUBIT_GATE R_{i,1} & ..C_{i,j} MULTI_QUBIT_GATE R_{i,j}.. & C_{i,n} MULTI_QUBIT_GATE R_{i,n}  \\
#   \colon & \colon & \colon  \\
#   C_{k,1} MULTI_QUBIT_GATE R_{k,1} & ..C_{k,j} MULTI_QUBIT_GATE R_{k,j}.. & C_{k,n} MULTI_QUBIT_GATE R_{k,n}
# ([GATE](B_{1}), ..[GATE](B_{_b}).., [GATE](B_{n}))
# ([GATE](D_{1}), ..[GATE](D_{_b}).., [GATE](D_{n}))
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\operation\operation.py in _extractInitArgs(cls, operator_or_operators, operand_or_operands, obj)
#     218         try:
# --> 219             arg_vals = [extract_init_arg_value_fn(arg) for arg in args]
#     220             if varargs is not None:
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\operation\operation.py in <listcomp>(.0)
#     218         try:
# --> 219             arg_vals = [extract_init_arg_value_fn(arg) for arg in args]
#     220             if varargs is not None:
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\operation\operation.py in <lambda>(arg)
#     213                 lambda arg : cls.extractInitArgValue(arg, operator_or_operators,
# --> 214                                                      operand_or_operands)
#     215         else:
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\operation\operation.py in extractInitArgValue(cls, argName, operator_or_operators, operand_or_operands)
#     144         '''
# --> 145         raise NotImplementedError("'extractInitArgValue' must be appropriately implemented if __init__ arguments do not fall into a simple 'default' scenario")
#     146
#
# NotImplementedError: 'extractInitArgValue' must be appropriately implemented if __init__ arguments do not fall into a simple 'default' scenario
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-12-85a7fc03689d> in <module>
#      16                             ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k)))
#      17             )
# ---> 18         ).withWrappingAt(2)
#      19     ), domain=NaturalsPos)
#      20 proveit.magics.Assignments(['single_space_equiv'], [single_space_equiv])
#
# c:\users\joaqu\prove-it\packages\proveit\logic\boolean\quantification\universal\forall.py in __init__(self, instanceParamOrParams, instanceExpr, domain, domains, condition, conditions, _lambda_map)
#      26                 condition=condition, conditions=conditions,
#      27                 #nestMultiIvars=True, _lambda_map=_lambda_map)
# ---> 28                 nestMultiIvars=False, _lambda_map=_lambda_map)
#      29
#      30     def sideEffects(self, knownTruth):
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\operation\operation_over_instances.py in __init__(self, operator, instanceParamOrParams, instanceExpr, domain, domains, condition, conditions, nestMultiIvars, styles, _lambda_map)
#     264             lambda_map = OperationOverInstances._createOperand(instanceParamOrParams,
#     265                                                                instanceExpr,
# --> 266                                                                conditions)
#     267
#     268         self.instanceExpr = instanceExpr
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\operation\operation_over_instances.py in _createOperand(instanceParamOrParams, instanceExpr, conditions)
#     308     def _createOperand(instanceParamOrParams, instanceExpr, conditions):
#     309         if len(conditions) == 0:
# --> 310             return Lambda(instanceParamOrParams, instanceExpr)
#     311         else:
#     312             conditional =  Conditional(instanceExpr, conditions)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\lambda_expr\lambda_expr.py in __init__(self, parameter_or_parameters, body, _generic_expr)
#     171             try:
#     172                 defaults.automation = False
# --> 173                 genericExpr = self._generic_version()
#     174             finally:
#     175                 defaults.automation = prev_automation
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\lambda_expr\lambda_expr.py in _generic_version(self)
#     266                 generic_parameters = generic_parameters.replaced(
#     267                         relabel_map, assumptions=tuple())
# --> 268                 generic_body = self.body._generic_version()
#     269                 generic_body = generic_body.replaced(
#     270                         relabel_map, assumptions=tuple())
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in _generic_version(self)
#     178         # Get the generic versions of the sub-expressions.
#     179         generic_sub_expressions = tuple(sub_expr._generic_version()
# --> 180                                         for sub_expr in self._subExpressions)
#     181         # Get the styles of the sub expressions.
#     182         sub_expression_styles = tuple(sub_expr._styleData
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in <genexpr>(.0)
#     178         # Get the generic versions of the sub-expressions.
#     179         generic_sub_expressions = tuple(sub_expr._generic_version()
# --> 180                                         for sub_expr in self._subExpressions)
#     181         # Get the styles of the sub expressions.
#     182         sub_expression_styles = tuple(sub_expr._styleData
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in _generic_version(self)
#     178         # Get the generic versions of the sub-expressions.
#     179         generic_sub_expressions = tuple(sub_expr._generic_version()
# --> 180                                         for sub_expr in self._subExpressions)
#     181         # Get the styles of the sub expressions.
#     182         sub_expression_styles = tuple(sub_expr._styleData
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in <genexpr>(.0)
#     178         # Get the generic versions of the sub-expressions.
#     179         generic_sub_expressions = tuple(sub_expr._generic_version()
# --> 180                                         for sub_expr in self._subExpressions)
#     181         # Get the styles of the sub expressions.
#     182         sub_expression_styles = tuple(sub_expr._styleData
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in _generic_version(self)
#     178         # Get the generic versions of the sub-expressions.
#     179         generic_sub_expressions = tuple(sub_expr._generic_version()
# --> 180                                         for sub_expr in self._subExpressions)
#     181         # Get the styles of the sub expressions.
#     182         sub_expression_styles = tuple(sub_expr._styleData
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in <genexpr>(.0)
#     178         # Get the generic versions of the sub-expressions.
#     179         generic_sub_expressions = tuple(sub_expr._generic_version()
# --> 180                                         for sub_expr in self._subExpressions)
#     181         # Get the styles of the sub expressions.
#     182         sub_expression_styles = tuple(sub_expr._styleData
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in _generic_version(self)
#     178         # Get the generic versions of the sub-expressions.
#     179         generic_sub_expressions = tuple(sub_expr._generic_version()
# --> 180                                         for sub_expr in self._subExpressions)
#     181         # Get the styles of the sub expressions.
#     182         sub_expression_styles = tuple(sub_expr._styleData
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in <genexpr>(.0)
#     178         # Get the generic versions of the sub-expressions.
#     179         generic_sub_expressions = tuple(sub_expr._generic_version()
# --> 180                                         for sub_expr in self._subExpressions)
#     181         # Get the styles of the sub expressions.
#     182         sub_expression_styles = tuple(sub_expr._styleData
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in _generic_version(self)
#     196         self._genericExpr = self.__class__._checked_make(
#     197                 self._meaningData._coreInfo, dict(self._styleData.styles),
# --> 198                 generic_sub_expressions)
#     199         return self._genericExpr
#     200
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\expr.py in _checked_make(cls, coreInfo, styles, subExpressions, genericExpr)
#     389             made = cls._make(coreInfo, styles, subExpressions, genericExpr)
#     390         else:
# --> 391             made = cls._make(coreInfo, styles, subExpressions)
#     392         assert made._coreInfo == coreInfo, (
#     393                 "%s vs %s"%(made._coreInfo, coreInfo))
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\operation\operation.py in _make(operationClass, coreInfo, styles, subExpressions)
#     288         args = []
#     289         kw_args = dict()
# --> 290         for arg in operationClass._extractInitArgs(operator_or_operators, operand_or_operands):
#     291             if isinstance(arg, Expression):
#     292                 args.append(arg)
#
# c:\users\joaqu\prove-it\packages\proveit\_core_\expression\operation\operation.py in _extractInitArgs(cls, operator_or_operators, operand_or_operands, obj)
#     268                         "Operation of type %s if it does not fall into "
#     269                         "one of the default cases for 'extractInitArgs'"
# --> 270                         %str(cls))
#     271
#     272     @classmethod
#
# NotImplementedError: Must implement 'extractInitArgValue' for the Operation of type <class 'proveit.physics.quantum.circuit.Circuit'> if it does not fall into one of the default cases for 'extractInitArgs'

# %%
double_space_equiv = Forall((h, k, m, n), Forall((varRange(A, [one, one], [m, n]), varRange(B, one, n),
                                              varRange(C, [one, one], [k, n]), varRange(D, one, n), 
                                              varRange(E, [one, one], [h, n]), varRange(F, one, n), 
                                              varRange(G, one, n), 
                                              S11_to_Smn, varRange(Q, [one, one], [h, n]), 
                                              varRange(R, [one, one], [k, n])),
        Implies(
            CircuitEquiv(
                    Circuit(ExprArray(ExprTuple(ExprRange(j, MultiQubitGate(indexed_var(B, j), Set(Add(m, one), Add(m, k, two))), one, n)),
                            ExprTuple(ExprRange(j, MultiQubitGate(indexed_var(D, j), Set(Add(m, one), Add(m, k, two))), one, n)))),
                    Circuit(ExprArray(ExprTuple(ExprRange(j, MultiQubitGate(indexed_var(F, j), Set(Add(m, one), Add(m, k, two))), one, n)),
                            ExprTuple(ExprRange(j, MultiQubitGate(indexed_var(G, j), Set(Add(m, one), Add(m, k, two))), one, n))))
            ),
            CircuitEquiv(
                    Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, n)), one, m),
                            ExprTuple(ExprRange(j, MultiQubitGate(indexed_var(B, j), Set(Add(m, one), Add(m, k, two))), one, n)),
                            ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k),
                            ExprTuple(ExprRange(j, MultiQubitGate(indexed_var(D, j), Set(Add(m, one), Add(m, k, two))), one, n)),
                            ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Eij, Qij), one, n)), one, h))),
                    Circuit(ExprArray(ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Aij, Sij), one, n)), one, m),
                            ExprTuple(ExprRange(j, MultiQubitGate(indexed_var(F, j), Set(Add(m, one), Add(m, k, two))), one, n)),
                            ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Cij, Rij), one, n)), one, k),
                            ExprTuple(ExprRange(j, MultiQubitGate(indexed_var(G, j), Set(Add(m, one), Add(m, k, two))), one, n)),
                            ExprRange(i, ExprTuple(ExprRange(j, MultiQubitGate(Eij, Qij), one, n)), one, h))))
            ).withWrappingAt(2)
    ), domain=NaturalsPos)

# %%
# need to form an Iter to replace xEtc here
# summedQubitStateInQubitSpace = Forall(xEtc, InSet(Add(xEtc), QubitSpace), domain=QubitSpace)
summedQubitStateInQubitSpace = Forall(
    n,
    Forall(
        xIter1n,
        InSet(Add(xIter1n), QubitSpace),
        domain=QubitSpace),
    domain=NaturalsPos)

# %%
scaledQubitRegisterStateInQubitRegisterSpace = Forall(
        n,
        Forall(x,
               Forall(alpha, InSet(ScalarProd(alpha, x), QubitRegisterSpace(n)),
                      domain=Complexes),
               domain=QubitRegisterSpace(n)),
        domain=NaturalsPos)

# %%
registerKetInQubitRegisterSpace = Forall(
        n,
        Forall(k, InSet(RegisterKet(k, n), QubitRegisterSpace(n)),
               domain = Interval(zero, subtract(Exp(two, n), one))),
        domain=NaturalsPos)

# %%
# TOOK REALLY LONG TO RUN... MORE TESTING NEEDED
#registerQubitComplexAmplitude = Forall(
 #       n,
  #      Forall(k,
   #            Forall(Psi,
    #                  InSet(MatrixProd(RegisterBra(k, n), Ket(Psi)), Complexes),
     #                 conditions = [InSet(Ket(Psi), QubitRegisterSpace(n))]),
      #         domain=Interval(zero, subtract(Exp(two, n),one))),
       # domain=NaturalsPos)

# %%
# TOOK REALLY LONG TO RUN... MORE TESTING NEEDED
# registerQubitBornRule = Forall(
  #      n,
   #     Forall(k,
    #           Forall((Psi, m),
     #                 Equals(Prob(Equals(m, k), m),
      #                       Exp(Abs(MatrixProd(RegisterBra(k, n), Ket(Psi))), two)),
       #               conditions = [InSet(Ket(Psi), QubitRegisterSpace(n)), Equals(m, Meas(Ket(Psi)))]),
        #       domain=Interval(zero, subtract(Exp(two, n), one))),
        #domain=NaturalsPos)

# %%
registerQubitAllProbs = Forall(
        n,
        Forall((Psi, m),
               Equals(Sum(k, Prob(Equals(m, k), m),
                                domain=Interval(zero, subtract(Exp(two, n), one))),
                      one),
               conditions = [InSet(Ket(Psi), QubitRegisterSpace(n)), Equals(m, Meas(Ket(Psi)))]),
        domain=NaturalsPos)

# %%
## This one requires pregatedControlledNgate, defined at the top of this page,
## but that pregatedControlledNgate requires the Circuit class
# pregatedControlledNgateEquiv = Forall(
#         n,
#         Forall(U,
#                Forall(u,
#                       Forall((a, b),
#                              Forall((x, y),
#                                     Equals(pregatedControlledNgate,
#                                            controlledNgate(MatrixProd(u, a), b, x, y)),
#                                     domain=QubitRegisterSpace(n)),
#                              domain=QubitSpace),
#                       domain=SU(two)),
#                domain=RegisterSU(n)),
#         domain=NaturalsPos)

# %%
## This one requires controlledNgate, defined at the top of this page,
## but that controlledNgate requires the Circuit class
# controlledNgateEquiv = Forall(
#         n,
#         Forall(U,
#                Forall((a, b, c),
#                       Forall((x, y, z),
#                              Iff(Equals(controlledNgate(a, b, x, y),
#                                         controlledNgate(a, c, x, z)),
#                                  Equals(TensorProd(b, y), TensorProd(c, z))),
#                              domain=QubitRegisterSpace(n)),
#                       domain=QubitSpace),
#                domain=RegisterSU(n)),
#         domain=NaturalsPos)

# %%
## This one requires controlledNgate, defined at the top of this page,
## but that controlledNgate requires the Circuit class
# superpositionControlledNgate = Forall(
#         n,
#         Forall(U,
#                Forall((a, b, c, d),
#                       Forall((x, y),
#                              Implies(And(controlledNgate(a, c, x, y),
#                                          controlledNgate(b, d, x, y)),
#                                      controlledNgate(Add(a, b), Add(c, d), x, y)),
#                              domain=QubitRegisterSpace(n)),
#                       domain=QubitSpace),
#                domain=RegisterSU(n)),
#         domain=NaturalsPos)

# %%
## This one requires pregatedControlledNgate, defined at the top of this page,
## but that pregatedControlledNgate requires the Circuit class
# pregatedControlledNgateMerger = Forall(
#     (n, k),
#     Forall(U,
#            Forall(u,
#                   Forall((a, b),
#                          Forall(c,
#                                 Forall(d,
#                                        Forall((x, y),
#                                               Implies(pregatedControlledNgate,
#                                                       Implies(pregatedControlledNgateWithMerge,
#                                                               Equals(d, TensorProd(c, b)))),
#                                               domain=QubitRegisterSpace(n)),
#                                        domain=QubitRegisterSpace(Add(k, one))),
#                                 domain=QubitRegisterSpace(k)),
#                          domain=QubitSpace),
#                   domain=SU(two)),
#            domain=RegisterSU(n)),
#     domain=NaturalsPos)

# %%
# TOOK REALLY LONG TO RUN... MORE TESTING NEEDED
#registerBraOverSummedKet = Forall(
 #   n,
  #  Forall(U,
   #        Forall(l,
    #              Forall(f,
     #                    Equals(MatrixProd(RegisterBra(l, n),
      #                                     MatrixProd(U, Sum(k, ScalarProd(Operation(f, k), RegisterKet(k, n)),
       #                                                      domain=Interval(zero, subtract(Exp(two, n), one))))),
        #                        Sum(k, Mult(Operation(f, k),
         #                                   MatrixProd(RegisterBra(l, n), U, RegisterKet(k, n))),
          #                          domain=Interval(zero, subtract(Exp(two, n), one))))),
           #       domain=Interval(zero, subtract(Exp(two, n), one))),
           #domain=SU(Exp(two, n))),
    #domain=NaturalsPos)

# %%
# %end theorems
