# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">algebra</a>.<a class="ProveItLink" href="../../theorems.ipynb#matrix_simultaneous_diagonalization_as_outer_prods">matrix_simultaneous_diagonalization_as_outer_prods</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving matrix_simultaneous_diagonalization_as_outer_prods
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="matrix_simultaneous_diagonalization_as_outer_prods">matrix_simultaneous_diagonalization_as_outer_prods:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/6b39b077f9e1e40874683fbd29e3a50b64f48f2c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/9dc7b2557595829391dbb6b4ceadab5c380ae7770/dependencies.ipynb">dependencies</a>)<br>
