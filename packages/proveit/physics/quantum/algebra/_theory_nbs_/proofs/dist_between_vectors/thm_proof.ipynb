# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">algebra</a>.<a class="ProveItLink" href="../../theorems.ipynb#dist_between_vectors">dist_between_vectors</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

from proveit import defaults, K, V, H, x, y
from proveit.numbers import Complex
from proveit.linear_algebra import Hspace, VecNeg, VecAdd
from proveit.linear_algebra.inner_products import qnorm_def, qinner_prod_conj_sym
from proveit.linear_algebra.negation import neg_closure
from proveit.linear_algebra.addition import binary_closure
from proveit.physics.quantum import var_ket_u, var_ket_v

# %%
# %proving dist_between_vectors

# %%
dist_between_vectors

# %%
defaults.assumptions = dist_between_vectors.all_conditions()

# %%
qnorm_def

# %%
neg_closure
neg_closure.instantiate({K:Complex,V:Hspace,x:var_ket_v})

# %%
binary_closure
binary_closure.instantiate({K:Complex,V:Hspace,x:var_ket_u,y:VecNeg(var_ket_v)})

# %%
# Adj(var_ket_v).with_styles(notation='dirac')

# %%
expr1 = qnorm_def.instantiate({K:Complex, H:Hspace,x:VecAdd(var_ket_u,VecNeg(var_ket_v))})

# %%
expr2= expr1.inner_expr().rhs.base.operands[1].operands[0].with_styles(notation='dirac')

# %%
expr3= expr2.inner_expr().rhs.base.operands[2].operands[0].with_styles(notation='dirac')

# %%
qinner_prod_conj_sym

# %%
q11 = qinner_prod_conj_sym.instantiate({K:Complex, H:Hspace, x: var_ket_v, y:var_ket_u})

# %%
q12 = q11.sub_right_side_into(expr3)

# %%
# %qed
