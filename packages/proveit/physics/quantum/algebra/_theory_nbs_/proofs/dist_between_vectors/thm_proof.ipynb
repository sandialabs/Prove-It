# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">algebra</a>.<a class="ProveItLink" href="../../theorems.ipynb#dist_between_vectors">dist_between_vectors</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

from proveit import defaults, Variable, Literal, ExprRange, ExprArray, ExprTuple, display_provers
# Prepare this notebook for defining the theorems of a theory:
# %theorems_notebook # Keep this at the top following 'import proveit'.
from proveit import a, b, c, d, e, k, l, m, n, r, s, t, u, U, eps, K, x, y, V, H
from proveit.logic import (
    Implies, And, Or, Equals, Forall, Exists, Set, InSet, InClass, NotEquals, NotInSet,
    SubsetEq, Difference, Set, SetOfAll, Disjoint, Bijections, CartExp)
from proveit.numbers import (
    zero, one, two, three, four, pi, i,
    Abs, Add, Complex, Div, Exp, exp, exp2pi_i, sqrd, frac, greater, greater_eq,
    Integer, IntegerNonZero, IntegerNeg, Interval, IntervalCC, IntervalCO,
    number_ordering, Conjugate,
    IntervalOC, IntervalOO, Less, LessEq, Mod, ModAbs, Round, Mult, Natural,
    NaturalPos, Neg, Real, RealNonNeg, sqrd, sqrt, subtract, Sum)

from proveit.physics.quantum import Qmult, Bra, Ket

from proveit.physics.quantum import (
    psi, bra0, ket0, bra1, ket1, ket_psi, bra_psi, varphi, bra_varphi, ket_varphi, var_ket_u, var_ket_v,var_ket_psi)
from proveit.physics.quantum import Bra, Meas, NumBra, NumKet, Qmult, QubitRegisterSpace
from proveit.physics.quantum import inv_root2, ket0, ket1, normalized_var_ket_u, var_ket_u 
from proveit.linear_algebra import Norm, Hspace, HilbertSpaces,VecAdd,VecNeg,complex_vec_set_is_vec_space,Adj,VecSpaces, InnerProd
from proveit.linear_algebra.addition import binary_closure

from proveit.linear_algebra.inner_products import hilbert_space_is_inner_prod_space, inner_prod_vec_neg_left, inner_prod_vec_neg_right, hilbert_space_def, qnorm_def, qinner_prod_conj_sym
from proveit.numbers.numerals.decimals import nat1
from proveit.linear_algebra.negation import neg_closure
from proveit.linear_algebra.addition import binary_closure

# %%
# %proving dist_between_vectors

# %%
dist_between_vectors

# %%
defaults.assumptions = dist_between_vectors.all_conditions()

# %%
hilbert_space_def
qnorm_def

# %%
neg_closure
neg_closure.instantiate({K:Complex,V:Hspace,x:var_ket_v})

# %%
binary_closure
binary_closure.instantiate({K:Complex,V:Hspace,x:var_ket_u,y:VecNeg(var_ket_v)})

# %%
# Adj(var_ket_v).with_styles(notation='dirac')

# %%
expr1 = qnorm_def.instantiate({K:Complex, H:Hspace,x:VecAdd(var_ket_u,VecNeg(var_ket_v))})

# %%
expr2= expr1.inner_expr().rhs.base.operands[1].operands[0].with_styles(notation='dirac')

# %%
expr3= expr2.inner_expr().rhs.base.operands[2].operands[0].with_styles(notation='dirac')

# %%
qinner_prod_conj_sym

# %%
q11 = qinner_prod_conj_sym.instantiate({K:Complex, H:Hspace, x: var_ket_v, y:var_ket_u})

# %%
q12 = q11.sub_right_side_into(expr3)

# %%
# %qed
