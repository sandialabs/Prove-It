# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">algebra</a>.<a class="ProveItLink" href="../../theorems.ipynb#ket_self_projection">ket_self_projection</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit.linear_algebra.inner_products import norm_def
from proveit.physics.quantum.algebra import bra_def
from proveit.physics.quantum import psi, varphi,ket_psi
from proveit.linear_algebra import Hspace
from proveit import x,K,H
from proveit.numbers import Complex
from proveit.logic import InSet
from proveit import defaults

# %%
# %proving ket_self_projection
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="ket_self_projection">ket_self_projection:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/9400d6f06310b58cb589089a40090c5ead434ed10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/16e9eceeea23e9cfbb4bbbd995ddb2934d0c5d120/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions=ket_self_projection.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_ket_self_projection/1e256e3ab22b9cb3f251f227f24282ed298b523a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
lhs=ket_self_projection.instance_expr.instance_expr.lhs
# Out:
# <strong id="lhs">lhs:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/adc190346700d50c3f0ec4029b2354b7ed8d19d80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
bra_def
# Out:
# |- forall_{H in_c HilbertSpaces} [forall_{varphi | |varphi〉 in H} (〈varphi| = [|psi> -> {<|psi>, |varphi〉> if |psi> in H.])]

# %%
bra_def_inst=bra_def.instantiate({varphi:psi})
# Out:
# <strong id="bra_def_inst">bra_def_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../linear_algebra/inner_products/__pv_it/theorems/cc1a1fdbe030158429b482f8c4631f162e8f59980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/1e90b1aed1987dd6b7d171045c568aaf86fa4f340/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_ket_self_projection/63f0473c4824a34f28bc1f6815026ca351d5796f0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_ket_self_projection/9ffda1ce6289482167091b06f65738e7b518205e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
lhs.projection()
# Out:
# {H in_c HilbertSpaces, |psi〉 in H} |- (〈psi| . |psi〉) = <|psi〉, |psi〉>

# %%
bra_def_inst.substitution(lhs)
# Out:
# {H in_c HilbertSpaces, |psi〉 in H} |- (〈psi| . |psi〉) = ([|psi> -> {<|psi>, |psi〉> if |psi> in H.] . |psi〉)

# %%
norm_def
# Out:
# |- forall_{K} [forall_{H in_c InnerProdSpaces(K)} [forall_{x in H} (||x|| = sqrt(<x, x>))]]

# %%
norm_def_inst=norm_def.instantiate({x:ket_psi,K:Complex,H:Hspace})
# Out:
# <strong id="norm_def_inst">norm_def_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../linear_algebra/inner_products/__pv_it/theorems/cc1a1fdbe030158429b482f8c4631f162e8f59980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/1e90b1aed1987dd6b7d171045c568aaf86fa4f340/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_ket_self_projection/ad85491f0455c5c7d8ba8da264d4ee9348a661400/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_ket_self_projection/0b628c1b46d859be253e047199962c63fa8d0a440/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# wmw: TODO: handle this automatically
from proveit.numbers import deduce_number_set
deduce_number_set(norm_def_inst.rhs)
# Out:
# {H in_c HilbertSpaces, |psi〉 in H} |- sqrt(<|psi〉, |psi〉>) in Complex

# %%
eq = norm_def_inst.square_both_sides()
# Out:
# <strong id="eq">eq:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../linear_algebra/inner_products/__pv_it/theorems/cc1a1fdbe030158429b482f8c4631f162e8f59980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/1e90b1aed1987dd6b7d171045c568aaf86fa4f340/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_ket_self_projection/33e849a1595167e6d48972a93d8cd373c06dc9890/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_ket_self_projection/dc66e3c04202fc4b0fd46933c2d88a88c0a235870/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# ket_self_projection may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.algebra.ket_self_projection has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{H in_c HilbertSpaces} [forall_{psi | |psi〉 in H} ((〈psi| . |psi〉) = |||psi〉||^{2})]
# 1	instantiation	70, 2, 3	{H in_c HilbertSpaces, |psi〉 in H} |- (〈psi| . |psi〉) = |||psi〉||^{2}
# 	x : 〈psi| . |psi〉, y : <|psi〉, |psi〉>, z : |||psi〉||^{2}
# 2	instantiation	47, 4, 5, 6*	{H in_c HilbertSpaces, |psi〉 in H} |- (〈psi| . |psi〉) = <|psi〉, |psi〉>
# 	P(_a) : (〈psi| . |psi〉) = _a(|psi〉), x : [〈psi|], y(|psi>) : {<|psi>, |psi〉> if |psi> in H.
# 3	instantiation	7, 8	{H in_c HilbertSpaces, |psi〉 in H} |- <|psi〉, |psi〉> = |||psi〉||^{2}
# 	x : |||psi〉||^{2}, y : <|psi〉, |psi〉>
# 4	instantiation	9, 45, 10, 11, 46	{H in_c HilbertSpaces, |psi〉 in H} |- (〈psi| . |psi〉) = [〈psi|](|psi〉)
# 	H : H, X : Complex, A : 〈psi|, |psi> : |psi〉
# 5	instantiation	12, 45, 46	{H in_c HilbertSpaces, |psi〉 in H} |- [〈psi|] = [|psi> -> {<|psi>, |psi〉> if |psi> in H.]
# 	H : H, varphi : psi
# 6	instantiation	13, 46	{|psi〉 in H} |- {<|psi〉, |psi〉> if |psi〉 in H. = <|psi〉, |psi〉>
# 	a : <|psi〉, |psi〉>, Q : |psi〉 in H
# 7	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 8	instantiation	14, 86, 15, 19, 20, 16*	{H in_c HilbertSpaces, |psi〉 in H} |- |||psi〉||^{2} = <|psi〉, |psi〉>
# 	a : 2, x : |||psi〉||, y : sqrt(<|psi〉, |psi〉>)
# 9	axiom		|- forall_{H, X in_c HilbertSpaces} [forall_{A | [A] in LINMAP(H, X)} [forall_{|psi> in H} ((A . |psi>) = [A](|psi>))]]
# 	proveit.physics.quantum.algebra.qmult_op_ket
# 10	conjecture		|- Complex in_c HilbertSpaces
# 	proveit.linear_algebra.inner_products.complex_set_is_hilbert_space
# 11	instantiation	17, 45, 46	{H in_c HilbertSpaces, |psi〉 in H} |- [〈psi|] in LINMAP(H, Complex)
# 	H : H, varphi : psi
# 12	conjecture		|- forall_{H in_c HilbertSpaces} [forall_{varphi | |varphi〉 in H} ([〈varphi|] = [|psi> -> {<|psi>, |varphi〉> if |psi> in H.])]
# 	proveit.physics.quantum.algebra.qmult_of_bra_as_map
# 13	conjecture		|- forall_{a, Q | Q} ({a if Q. = a)
# 	proveit.core_expr_types.conditionals.satisfied_condition_reduction
# 14	theorem		|- forall_{a, x, y in Complex | x = y} (x^{a} = y^{a})
# 	proveit.numbers.exponentiation.exp_eq
# 15	instantiation	18, 19, 20	{H in_c HilbertSpaces, |psi〉 in H} |- |||psi〉|| in Complex
# 	P(_a) : _a in Complex, x : |||psi〉||, y : sqrt(<|psi〉, |psi〉>)
# 16	instantiation	21, 40, 22, 29, 23*	{H in_c HilbertSpaces, |psi〉 in H} |- (sqrt(<|psi〉, |psi〉>))^{2} = <|psi〉, |psi〉>
# 	a : <|psi〉, |psi〉>, b : 1 / 2, c : 2
# 17	conjecture		|- forall_{H in_c HilbertSpaces} [forall_{varphi | |varphi〉 in H} ([〈varphi|] in LINMAP(H, Complex))]
# 	proveit.physics.quantum.algebra.qmult_bra_is_linmap
# 18	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 19	instantiation	24, 40	{H in_c HilbertSpaces, |psi〉 in H} |- sqrt(<|psi〉, |psi〉>) in Complex
# 	a : <|psi〉, |psi〉>
# 20	instantiation	25, 26, 46	{H in_c HilbertSpaces, |psi〉 in H} |- |||psi〉|| = sqrt(<|psi〉, |psi〉>)
# 	K : Complex, H : H, x : |psi〉
# 21	conjecture		|- forall_{a in Complex, b in RealPos, c in RealPos} ((a^{b})^{c} = a^{b * c})
# 	proveit.numbers.exponentiation.pos_power_of_pos_power
# 22	instantiation	27, 28, 29, 30	|- (1 / 2) in RealPos
# 	a : 1, b : 2
# 23	instantiation	70, 31, 32	{H in_c HilbertSpaces, |psi〉 in H} |- <|psi〉, |psi〉>^{(1 / 2) * 2} = <|psi〉, |psi〉>
# 	x : <|psi〉, |psi〉>^{(1 / 2) * 2}, y : <|psi〉, |psi〉>^{1}, z : <|psi〉, |psi〉>
# 24	conjecture		|- forall_{a in Complex} (sqrt(a) in Complex)
# 	proveit.numbers.exponentiation.sqrt_complex_closure
# 25	axiom		|- forall_{K} [forall_{H in_c InnerProdSpaces(K)} [forall_{x in H} (||x|| = sqrt(<x, x>))]]
# 	proveit.linear_algebra.inner_products.norm_def
# 26	instantiation	33, 45	{H in_c HilbertSpaces} |- H in_c InnerProdSpaces(Complex)
# 	H : H
# 27	conjecture		|- forall_{a, b in RealPos | b != 0} ((a / b) in RealPos)
# 	proveit.numbers.division.div_real_pos_closure
# 28	instantiation	95, 35, 34	|- 1 in RealPos
# 	A : RationalPos, B : RealPos, x : 1
# 29	instantiation	95, 35, 36	|- 2 in RealPos
# 	A : RationalPos, B : RealPos, x : 2
# 30	instantiation	37, 84	|- 2 != 0
# 	n : 2
# 31	instantiation	78, 38	|- <|psi〉, |psi〉>^{(1 / 2) * 2} = <|psi〉, |psi〉>^{1}
# 	f(_a) : <|psi〉, |psi〉>^{_a}, x : (1 / 2) * 2, y : 1
# 32	instantiation	39, 40	{H in_c HilbertSpaces, |psi〉 in H} |- <|psi〉, |psi〉>^{1} = <|psi〉, |psi〉>
# 	x : <|psi〉, |psi〉>
# 33	theorem		|- forall_{H in_c HilbertSpaces} (H in_c InnerProdSpaces(Complex))
# 	proveit.linear_algebra.inner_products.hilbert_space_is_inner_prod_space
# 34	instantiation	95, 41, 82	|- 1 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 1
# 35	conjecture		|- RationalPos proper_subset RealPos
# 	proveit.numbers.number_sets.real_numbers.rational_pos_within_real_pos
# 36	instantiation	95, 41, 84	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 37	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 38	instantiation	47, 42, 43	|- ((1 / 2) * 2) = 1
# 	P(_a) : ((1 / 2) * 2) = _a, x : (1 / 1) * (1 / 1), y : 1
# 39	conjecture		|- forall_{x in Complex} (x^{1} = x)
# 	proveit.numbers.exponentiation.complex_x_to_first_power_is_x
# 40	instantiation	44, 45, 46	{H in_c HilbertSpaces, |psi〉 in H} |- <|psi〉, |psi〉> in Complex
# 	H : H, x : |psi〉, y : |psi〉
# 41	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 42	instantiation	47, 48, 49	|- ((1 / 2) * 2) = ((1 / 1) * (1 / 1))
# 	P(_a) : _a = ((1 / 1) * (1 / 1)), x : (1 / (1 * 2)) * ((2 * 1) / 1), y : (1 / 2) * 2
# 43	instantiation	50, 51, 52, 53	|- ((1 / 1) * (1 / 1)) = 1
# 	a : (1 / 1) * (1 / 1), b : 1 * (1 / 1), c : 1 * 1, d : 1
# 44	theorem		|- forall_{H in_c HilbertSpaces} [forall_{x, y in H} (<x, y> in Complex)]
# 	proveit.linear_algebra.inner_products.inner_prod_complex_membership
# 45	assumption		{H in_c HilbertSpaces} |- H in_c HilbertSpaces
# 46	assumption		{|psi〉 in H} |- |psi〉 in H
# 47	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 48	instantiation	54, 65, 55, 56	|- ((1 / (1 * 2)) * ((2 * 1) / 1)) = ((1 / 1) * (1 / 1))
# 	a : 1, d : 1, b : 1, c : 2, e : 1
# 49	instantiation	70, 57, 58	|- ((1 / (1 * 2)) * ((2 * 1) / 1)) = ((1 / 2) * 2)
# 	x : (1 / (1 * 2)) * ((2 * 1) / 1), y : (1 / 2) * ((2 * 1) / 1), z : (1 / 2) * 2
# 50	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 51	instantiation	78, 59	|- ((1 / 1) * (1 / 1)) = (1 * (1 / 1))
# 	f(_a) : _a * (1 / 1), x : 1 / 1, y : 1
# 52	instantiation	78, 59	|- (1 * (1 / 1)) = (1 * 1)
# 	f(_a) : 1 * _a, x : 1 / 1, y : 1
# 53	instantiation	85, 65	|- (1 * 1) = 1
# 	x : 1
# 54	conjecture		|- forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} (((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)))]
# 	proveit.numbers.division.mult_frac_cancel_denom_left
# 55	instantiation	95, 61, 60	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 56	instantiation	95, 61, 62	|- 2 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2
# 57	instantiation	78, 63	|- ((1 / (1 * 2)) * ((2 * 1) / 1)) = ((1 / 2) * ((2 * 1) / 1))
# 	f(_a) : _a * ((2 * 1) / 1), x : 1 / (1 * 2), y : 1 / 2
# 58	instantiation	78, 64	|- ((1 / 2) * ((2 * 1) / 1)) = ((1 / 2) * 2)
# 	f(_a) : (1 / 2) * _a, x : (2 * 1) / 1, y : 2
# 59	instantiation	80, 65	|- (1 / 1) = 1
# 	x : 1
# 60	instantiation	95, 67, 66	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 61	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 62	instantiation	95, 67, 68	|- 2 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2
# 63	instantiation	78, 69	|- (1 / (1 * 2)) = (1 / 2)
# 	f(_a) : 1 / _a, x : 1 * 2, y : 2
# 64	instantiation	70, 71, 72	|- ((2 * 1) / 1) = 2
# 	x : (2 * 1) / 1, y : 2 / 1, z : 2
# 65	instantiation	95, 88, 73	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 66	instantiation	95, 75, 74	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 67	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 68	instantiation	95, 75, 76	|- 2 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2
# 69	instantiation	77, 86	|- (1 * 2) = 2
# 	x : 2
# 70	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 71	instantiation	78, 79	|- ((2 * 1) / 1) = (2 / 1)
# 	f(_a) : _a / 1, x : 2 * 1, y : 2
# 72	instantiation	80, 86	|- (2 / 1) = 2
# 	x : 2
# 73	instantiation	95, 91, 81	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 74	instantiation	95, 83, 82	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 75	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 76	instantiation	95, 83, 84	|- 2 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2
# 77	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 78	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 79	instantiation	85, 86	|- (2 * 1) = 2
# 	x : 2
# 80	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 81	instantiation	95, 93, 87	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 82	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 83	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 84	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 85	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 86	instantiation	95, 88, 89	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 87	instantiation	95, 96, 90	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 88	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 89	instantiation	95, 91, 92	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 90	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 91	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 92	instantiation	95, 93, 94	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 93	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 94	instantiation	95, 96, 97	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 95	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 96	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 97	conjecture		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
