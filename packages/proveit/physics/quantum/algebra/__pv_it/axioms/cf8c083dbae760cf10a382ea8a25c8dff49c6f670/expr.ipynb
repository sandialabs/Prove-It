# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, X, Y
from proveit.linear_algebra import HilbertSpaces, Hspace, LinMap
from proveit.logic import Exists, Forall, InClass, InSet, Set
from proveit.numbers import Complex
from proveit.physics.quantum import Qmult, QmultCodomain

# %%
# build up the expression from sub-expressions
sub_expr1 = LinMap(Hspace, X)
expr = Forall(instance_param_or_params = [A, B], instance_expr = Exists(instance_param_or_params = [Hspace, X, Y], instance_expr = InSet([Qmult(A), Qmult(B)], Set([sub_expr1, Hspace], [X, LinMap(Hspace, Complex)], [LinMap(X, Y), sub_expr1], [Complex, QmultCodomain], [QmultCodomain, Complex])), domain = HilbertSpaces), condition = InClass(Qmult(A, B), QmultCodomain))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{A, B~|~\left(A \thinspace B\right) \underset{{\scriptscriptstyle c}}{\in} \mathcal{Q^*}}~\left[\exists_{\mathcal{H}, X, Y \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}}~\left(\left(\left[A\right], \left[B\right]\right) \in \left\{\left(\mathcal{L}\left(\mathcal{H}, X\right), \mathcal{H}\right), \left(X, \mathcal{L}\left(\mathcal{H}, \mathbb{C}\right)\right), \left(\mathcal{L}\left(X, Y\right), \mathcal{L}\left(\mathcal{H}, X\right)\right), \left(\mathbb{C}, \mathcal{Q^*}\right), \left(\mathcal{Q^*}, \mathbb{C}\right)\right\}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{A, B | (A . B) in_c Q*} [exists_{H, X, Y in_c HilbertSpaces} (([A], [B]) in {(LINMAP(H, X), H), (X, LINMAP(H, Complex)), (LINMAP(X, Y), LINMAP(H, X)), (Complex, Q*), (Q*, Complex)})]
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A, B) -> {exists_{H, X, Y in_c HilbertSpaces} (([A], [B]) in {(LINMAP(H, X), H), (X, LINMAP(H, Complex)), (LINMAP(X, Y), LINMAP(H, X)), (Complex, Q*), (Q*, Complex)}) if (A . B) in_c Q*.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A, B) -> {exists_{H, X, Y in_c HilbertSpaces} (([A], [B]) in {(LINMAP(H, X), H), (X, LINMAP(H, Complex)), (LINMAP(X, Y), LINMAP(H, X)), (Complex, Q*), (Q*, Complex)}) if (A . B) in_c Q*.
#    core type: Lambda
#    parameters: 14\n   body: 4
# 4. {exists_{H, X, Y in_c HilbertSpaces} (([A], [B]) in {(LINMAP(H, X), H), (X, LINMAP(H, Complex)), (LINMAP(X, Y), LINMAP(H, X)), (Complex, Q*), (Q*, Complex)}) if (A . B) in_c Q*.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. exists_{H, X, Y in_c HilbertSpaces} (([A], [B]) in {(LINMAP(H, X), H), (X, LINMAP(H, Complex)), (LINMAP(X, Y), LINMAP(H, X)), (Complex, Q*), (Q*, Complex)})
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (A . B) in_c Q*
#    core type: Operation
#    operator: 32
#    operands: 9
# 7. exists
#    core type: Literal
#    sub-expressions:
# 8. ((H, X, Y) -> {([A], [B]) in {(LINMAP(H, X), H), (X, LINMAP(H, Complex)), (LINMAP(X, Y), LINMAP(H, X)), (Complex, Q*), (Q*, Complex)} if H in_c HilbertSpaces ,  X in_c HilbertSpaces ,  Y in_c HilbertSpaces.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (A . B, Q*)
#    core type: ExprTuple
#    sub-expressions: 11, 48
# 10. (H, X, Y) -> {([A], [B]) in {(LINMAP(H, X), H), (X, LINMAP(H, Complex)), (LINMAP(X, Y), LINMAP(H, X)), (Complex, Q*), (Q*, Complex)} if H in_c HilbertSpaces ,  X in_c HilbertSpaces ,  Y in_c HilbertSpaces.
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. A . B
#     core type: Operation
#     operator: 35
#     operands: 14
# 12. (H, X, Y)
#     core type: ExprTuple
#     sub-expressions: 55, 56, 54
# 13. {([A], [B]) in {(LINMAP(H, X), H), (X, LINMAP(H, Complex)), (LINMAP(X, Y), LINMAP(H, X)), (Complex, Q*), (Q*, Complex)} if H in_c HilbertSpaces ,  X in_c HilbertSpaces ,  Y in_c HilbertSpaces.
#     core type: Conditional
#     value: 15
#     condition: 16
# 14. (A, B)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 15. ([A], [B]) in {(LINMAP(H, X), H), (X, LINMAP(H, Complex)), (LINMAP(X, Y), LINMAP(H, X)), (Complex, Q*), (Q*, Complex)}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (H in_c HilbertSpaces) and (X in_c HilbertSpaces) and (Y in_c HilbertSpaces)
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (([A], [B]), {(LINMAP(H, X), H), (X, LINMAP(H, Complex)), (LINMAP(X, Y), LINMAP(H, X)), (Complex, Q*), (Q*, Complex)})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (H in_c HilbertSpaces, X in_c HilbertSpaces, Y in_c HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25
# 21. ([A], [B])
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 22. {(LINMAP(H, X), H), (X, LINMAP(H, Complex)), (LINMAP(X, Y), LINMAP(H, X)), (Complex, Q*), (Q*, Complex)}
#     core type: Operation
#     operator: 28
#     operands: 29
# 23. H in_c HilbertSpaces
#     core type: Operation
#     operator: 32
#     operands: 30
# 24. X in_c HilbertSpaces
#     core type: Operation
#     operator: 32
#     operands: 31
# 25. Y in_c HilbertSpaces
#     core type: Operation
#     operator: 32
#     operands: 33
# 26. [A]
#     core type: Operation
#     operator: 35
#     operand: 43
# 27. [B]
#     core type: Operation
#     operator: 35
#     operand: 44
# 28. Set
#     core type: Literal
#     sub-expressions:
# 29. ((LINMAP(H, X), H), (X, LINMAP(H, Complex)), (LINMAP(X, Y), LINMAP(H, X)), (Complex, Q*), (Q*, Complex))
#     core type: ExprTuple
#     sub-expressions: 37, 38, 39, 40, 41
# 30. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 55, 42
# 31. (X, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 56, 42
# 32. in_c
#     core type: Literal
#     sub-expressions:
# 33. (Y, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 54, 42
# 34. (A)
#     core type: ExprTuple
#     sub-expressions: 43
# 35. .
#     core type: Literal
#     sub-expressions:
# 36. (B)
#     core type: ExprTuple
#     sub-expressions: 44
# 37. (LINMAP(H, X), H)
#     core type: ExprTuple
#     sub-expressions: 47, 55
# 38. (X, LINMAP(H, Complex))
#     core type: ExprTuple
#     sub-expressions: 56, 45
# 39. (LINMAP(X, Y), LINMAP(H, X))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 40. (Complex, Q*)
#     core type: ExprTuple
#     sub-expressions: 53, 48
# 41. (Q*, Complex)
#     core type: ExprTuple
#     sub-expressions: 48, 53
# 42. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 43. A
#     core type: Variable
#     sub-expressions:
# 44. B
#     core type: Variable
#     sub-expressions:
# 45. LINMAP(H, Complex)
#     core type: Operation
#     operator: 51
#     operands: 49
# 46. LINMAP(X, Y)
#     core type: Operation
#     operator: 51
#     operands: 50
# 47. LINMAP(H, X)
#     core type: Operation
#     operator: 51
#     operands: 52
# 48. Q*
#     core type: Literal
#     sub-expressions:
# 49. (H, Complex)
#     core type: ExprTuple
#     sub-expressions: 55, 53
# 50. (X, Y)
#     core type: ExprTuple
#     sub-expressions: 56, 54
# 51. LINMAP
#     core type: Literal
#     sub-expressions:
# 52. (H, X)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. Complex
#     core type: Literal
#     sub-expressions:
# 54. Y
#     core type: Variable
#     sub-expressions:
# 55. H
#     core type: Variable
#     sub-expressions:
# 56. X
#     core type: Variable
#     sub-expressions:
