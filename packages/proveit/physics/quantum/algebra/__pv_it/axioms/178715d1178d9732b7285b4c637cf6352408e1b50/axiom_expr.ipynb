# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#qmult_of_matrix">qmult_of_matrix</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.algebra import qmult_of_matrix

# %%
# check that the built expression is the same as the stored expression
assert qmult_of_matrix.expr == stored_expr
assert qmult_of_matrix.expr._style_id == stored_expr._style_id
print("Passed sanity check: qmult_of_matrix matches stored_expr")
# Out:
# Passed sanity check: qmult_of_matrix matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{m, n \in \mathbb{N}^+}~\left[\forall_{M \in \mathbb{C}^{m \times n}}~\left(\left[M\right] = \left[x \mapsto \left\{M \thinspace x \textrm{ if } x \in \mathbb{C}^{n}\right..\right]\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{m, n in NaturalPos} [forall_{M in Complex^{m x n}} ([M] = [x -> {M . x if x in Complex^{n}.])]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((m, n) -> {forall_{M in Complex^{m x n}} ([M] = [x -> {M . x if x in Complex^{n}.]) if m in NaturalPos ,  n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (m, n) -> {forall_{M in Complex^{m x n}} ([M] = [x -> {M . x if x in Complex^{n}.]) if m in NaturalPos ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (m, n)
#    core type: ExprTuple
#    sub-expressions: 34, 45
# 4. {forall_{M in Complex^{m x n}} ([M] = [x -> {M . x if x in Complex^{n}.]) if m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{M in Complex^{m x n}} ([M] = [x -> {M . x if x in Complex^{n}.])
#    core type: Operation
#    operator: 7
#    operand: 11
# 6. (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 9
# ...
