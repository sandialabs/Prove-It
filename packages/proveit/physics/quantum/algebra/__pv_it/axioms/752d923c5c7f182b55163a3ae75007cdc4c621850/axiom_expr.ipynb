# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#qmult_op_ket">qmult_op_ket</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.algebra import qmult_op_ket

# %%
# check that the built expression is the same as the stored expression
assert qmult_op_ket.expr == stored_expr
assert qmult_op_ket.expr._style_id == stored_expr._style_id
print("Passed sanity check: qmult_op_ket matches stored_expr")
# Out:
# Passed sanity check: qmult_op_ket matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{\mathcal{H}, X \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}}~\left[\forall_{A~|~\left[A\right] \in \mathcal{L}\left(\mathcal{H}, X\right)}~\left[\forall_{\lvert \psi \rangle \in \mathcal{H}}~\left(\left(A \thinspace \lvert \psi \rangle\right) = \left[A\right]\left(\lvert \psi \rangle\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{H, X in_c HilbertSpaces} [forall_{A | [A] in LINMAP(H, X)} [forall_{|psi> in H} ((A . |psi>) = [A](|psi>))]]
#    core type: Operation
#    operator: 19
#    operand: 2
# 1. ((H, X) -> {forall_{A | [A] in LINMAP(H, X)} [forall_{|psi> in H} ((A . |psi>) = [A](|psi>))] if H in_c HilbertSpaces ,  X in_c HilbertSpaces.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (H, X) -> {forall_{A | [A] in LINMAP(H, X)} [forall_{|psi> in H} ((A . |psi>) = [A](|psi>))] if H in_c HilbertSpaces ,  X in_c HilbertSpaces.
#    core type: Lambda
#    parameters: 26\n   body: 3
# 3. {forall_{A | [A] in LINMAP(H, X)} [forall_{|psi> in H} ((A . |psi>) = [A](|psi>))] if H in_c HilbertSpaces ,  X in_c HilbertSpaces.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A | [A] in LINMAP(H, X)} [forall_{|psi> in H} ((A . |psi>) = [A](|psi>))]
#    core type: Operation
#    operator: 19
#    operand: 9
# 5. (H in_c HilbertSpaces) and (X in_c HilbertSpaces)
# ...
