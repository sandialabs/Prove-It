# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, v_1_to_n, v_i
from proveit.linear_algebra import Adj, Commutator, MatrixSpace, OrthoNormBases, ScalarMult, VecSum, VecZero
from proveit.logic import And, CartExp, Equals, Exists, Iff, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = MatrixSpace(field = Complex, rows = n, columns = n)
sub_expr3 = Interval(one, n)
sub_expr4 = Qmult(Ket(v_i), Bra(v_i))
expr = Lambda([A, B], Conditional(Iff(Equals(Commutator(A, B), VecZero(sub_expr2)), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr4), domain = sub_expr3))).with_wrapping_at(2), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n), OrthoNormBases(CartExp(Complex, n)))).with_wrapping()).with_wrapping_at(2), And(InSet(A, sub_expr2), InSet(B, sub_expr2), Equals(Adj(A), A), Equals(Adj(B), B))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{\begin{array}{c} \begin{array}{l} \left(\left[A, B\right] = \vec{0}\left(\mathbb{C}^{n \times n}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{v_{1}, v_{2}, \ldots, v_{n}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array}\right)\end{array}\right]\end{array}\right] \end{array} \end{array} \textrm{ if } A \in \mathbb{C}^{n \times n} ,  B \in \mathbb{C}^{n \times n} ,  A^{\dagger} = A ,  B^{\dagger} = B\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (A, B) -> {([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in Complex^{n x n} ,  B in Complex^{n x n} ,  A* = A ,  B* = B.
#    core type: Lambda
#    parameters: 25\n   body: 1
# 1. {([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in Complex^{n x n} ,  B in Complex^{n x n} ,  A* = A ,  B* = B.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. ([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A in Complex^{n x n}) and (B in Complex^{n x n}) and (A* = A) and (B* = B)
#    core type: Operation
#    operator: 58
#    operands: 6
# 4. <=>
#    core type: Literal
#    sub-expressions:
# 5. ([A, B] = 0(Complex^{n x n}), exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))])
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (A in Complex^{n x n}, B in Complex^{n x n}, A* = A, B* = B)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 7. [A, B] = 0(Complex^{n x n})
#    core type: Operation
#    operator: 69
#    operands: 13
# 8. exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]
#    core type: Operation
#    operator: 37
#    operand: 21
# 9. A in Complex^{n x n}
#    core type: Operation
#    operator: 99
#    operands: 15
# 10. B in Complex^{n x n}
#     core type: Operation
#     operator: 99
#     operands: 16
# 11. A* = A
#     core type: Operation
#     operator: 69
#     operands: 17
# 12. B* = B
#     core type: Operation
#     operator: 69
#     operands: 18
# 13. ([A, B], 0(Complex^{n x n}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 14. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).)
#     core type: ExprTuple
#     sub-expressions: 21
# 15. (A, Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 73, 32
# 16. (B, Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 75, 32
# 17. (A*, A)
#     core type: ExprTuple
#     sub-expressions: 22, 73
# 18. (B*, B)
#     core type: ExprTuple
#     sub-expressions: 23, 75
# 19. [A, B]
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. 0(Complex^{n x n})
#     core type: Operation
#     operator: 26
#     operand: 32
# 21. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).
#     core type: Lambda
#     parameters: 46\n    body: 28
# 22. A*
#     core type: Operation
#     operator: 30
#     operand: 73
# 23. B*
#     core type: Operation
#     operator: 30
#     operand: 75
# 24. commutator
#     core type: Literal
#     sub-expressions:
# 25. (A, B)
#     core type: ExprTuple
#     sub-expressions: 73, 75
# 26. 0
#     core type: Literal
#     sub-expressions:
# 27. (Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 32
# 28. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 33
#     condition: 34
# 29. (A)
#     core type: ExprTuple
#     sub-expressions: 73
# 30. Adj
#     core type: Literal
#     sub-expressions:
# 31. (B)
#     core type: ExprTuple
#     sub-expressions: 75
# 32. Complex^{n x n}
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))
#     core type: Operation
#     operator: 37
#     operand: 40
# 34. {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 99
#     operands: 39
# 35. MSpace
#     core type: Literal
#     sub-expressions:
# 36. {field:Complex, rows:n, columns:n}
#     core type: NamedExprs
#     field: 88
#     rows: 114
#     columns: 114
# 37. exists
#     core type: Literal
#     sub-expressions:
# 38. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 40
# 39. ({v_{1}, v_{2}, ..., v_{n}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 40. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Lambda
#     parameters: 43\n    body: 44
# 41. {v_{1}, v_{2}, ..., v_{n}}
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 47
#     operand: 54
# 43. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 44. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 51
#     condition: 52
# 45. Set
#     core type: Literal
#     sub-expressions:
# 46. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 53
# 47. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 48. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 54
# 49. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 55
#     start_index: 113
#     end_index: 114
# 50. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 113
#     end_index: 114
# 51. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 58
#     operands: 57
# 52. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 58
#     operands: 59
# 53. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 113
#     end_index: 114
# 54. Complex^{n}
#     core type: Operation
#     operator: 61
#     operands: 62
# 55. _a -> a_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 86
# 56. _a -> b_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 87
# 57. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 58. and
#     core type: Literal
#     sub-expressions:
# 59. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 60. _a -> v_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 67
# 61. CartExp
#     core type: Literal
#     sub-expressions:
# 62. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 88, 114
# 63. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 69
#     operands: 68
# 64. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 69
#     operands: 70
# 65. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 71
#     start_index: 113
#     end_index: 114
# 66. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 72
#     start_index: 113
#     end_index: 114
# 67. v_{_a}
#     core type: IndexedVar
# variable: 119
# index: 95
# 68. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 69. =
#     core type: Literal
#     sub-expressions:
# 70. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 71. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 95
#     body: 77
# 72. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 95
#     body: 78
# 73. A
#     core type: Variable
#     sub-expressions:
# 74. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 80
#     operand: 84
# 75. B
#     core type: Variable
#     sub-expressions:
# 76. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 80
#     operand: 85
# 77. a_{_a} in Complex
#     core type: Operation
#     operator: 99
#     operands: 82
# 78. b_{_a} in Complex
#     core type: Operation
#     operator: 99
#     operands: 83
# 79. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 84
# 80. Sum
#     core type: Literal
#     sub-expressions:
# 81. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 85
# 82. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 86, 88
# 83. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 87, 88
# 84. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 121
#     body: 89
# 85. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 121
#     body: 90
# 86. a_{_a}
#     core type: IndexedVar
# variable: 105
# index: 95
# 87. b_{_a}
#     core type: IndexedVar
# variable: 106
# index: 95
# 88. Complex
#     core type: Literal
#     sub-expressions:
# 89. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 92
#     condition: 94
# 90. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 93
#     condition: 94
# 91. (_a)
#     core type: ExprTuple
#     sub-expressions: 95
# 92. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 97
#     operands: 96
# 93. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 97
#     operands: 98
# 94. i in {1 .. n}
#     core type: Operation
#     operator: 99
#     operands: 100
# 95. _a
#     core type: Variable
#     sub-expressions:
# 96. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 101, 103
# 97. *
#     core type: Literal
#     sub-expressions:
# 98. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 102, 103
# 99. in
#     core type: Literal
#     sub-expressions:
# 100. (i, {1 .. n})
#      core type: ExprTuple
#      sub-expressions: 121, 104
# 101. a_{i}
#      core type: IndexedVar
# variable: 105
# index: 121
# 102. b_{i}
#      core type: IndexedVar
# variable: 106
# index: 121
# 103. |v_{i}〉 . 〈v_{i}|
#      core type: Operation
#      operator: 107
#      operands: 108
# 104. {1 .. n}
#      core type: Operation
#      operator: 109
#      operands: 110
# 105. a
#      core type: Variable
#      sub-expressions:
# 106. b
#      core type: Variable
#      sub-expressions:
# 107. .
#      core type: Literal
#      sub-expressions:
# 108. (|v_{i}〉, 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 111, 112
# 109. Interval
#      core type: Literal
#      sub-expressions:
# 110. (1, n)
#      core type: ExprTuple
#      sub-expressions: 113, 114
# 111. |v_{i}〉
#      core type: Operation
#      operator: 115
#      operand: 118
# 112. 〈v_{i}|
#      core type: Operation
#      operator: 116
#      operand: 118
# 113. 1
#      core type: Literal
#      sub-expressions:
# 114. n
#      core type: Variable
#      sub-expressions:
# 115. KET
#      core type: Literal
#      sub-expressions:
# 116. BRA
#      core type: Literal
#      sub-expressions:
# 117. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 118
# 118. v_{i}
#      core type: IndexedVar
# variable: 119
# index: 121
# 119. v
#      core type: Variable
#      sub-expressions:
# 120. (i)
#      core type: ExprTuple
#      sub-expressions: 121
# 121. i
#      core type: Variable
#      sub-expressions:
