# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import X, i, n
from proveit.core_expr_types import x_1_to_n, x_i
from proveit.linear_algebra import HilbertSpaces, Hspace, OrthoNormBases, OrthoProj, VecSum
from proveit.logic import Equals, Forall, InSet, SubsetEq
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import x_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [Hspace], instance_expr = Forall(instance_param_or_params = [X], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(OrthoProj(Hspace, X), VecSum(index_or_indices = [i], summand = Qmult(Ket(x_i), Bra(x_i)), domain = Interval(one, n))), condition = InSet(x_1_to_n_kets, OrthoNormBases(Hspace))).with_wrapping(), domain = NaturalPos), condition = SubsetEq(X, Hspace)), domain = HilbertSpaces)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{\mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}}~\left[\forall_{X~|~X \subseteq \mathcal{H}}~\left[\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{\lvert x_{1} \rangle, \lvert x_{2} \rangle, \ldots, \lvert x_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left(\textrm{OrthoProj}\left(\mathcal{H}, X\right) = \left(\sum_{i=1}^{n} \left(\lvert x_{i} \rangle \thinspace \langle x_{i} \rvert\right)\right)\right)\end{array}\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{H in_c HilbertSpaces} [forall_{X | X subset_eq H} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]]]
#    core type: Operation
#    operator: 23
#    operand: 2
# 1. (H -> {forall_{X | X subset_eq H} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]] if H in_c HilbertSpaces.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. H -> {forall_{X | X subset_eq H} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]] if H in_c HilbertSpaces.
#    core type: Lambda
#    parameter: 52
#    body: 3
# 3. {forall_{X | X subset_eq H} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]] if H in_c HilbertSpaces.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{X | X subset_eq H} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]]
#    core type: Operation
#    operator: 23
#    operand: 9
# 5. H in_c HilbertSpaces
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (X -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in_c
#    core type: Literal
#    sub-expressions:
# 8. (H, HilbertSpaces)
#    core type: ExprTuple
#    sub-expressions: 52, 10
# 9. X -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.
#    core type: Lambda
#    parameter: 49
#    body: 12
# 10. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 11. (X)
#     core type: ExprTuple
#     sub-expressions: 49
# 12. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]
#     core type: Operation
#     operator: 23
#     operand: 18
# 14. X subset_eq H
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. subset_eq
#     core type: Literal
#     sub-expressions:
# 17. (X, H)
#     core type: ExprTuple
#     sub-expressions: 49, 52
# 18. n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#     core type: Lambda
#     parameter: 75
#     body: 20
# 19. (n)
#     core type: ExprTuple
#     sub-expressions: 75
# 20. {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#     core type: Conditional
#     value: 21
#     condition: 22
# 21. forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))
#     core type: Operation
#     operator: 23
#     operand: 26
# 22. n in NaturalPos
#     core type: Operation
#     operator: 60
#     operands: 25
# 23. forall
#     core type: Literal
#     sub-expressions:
# 24. ((x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 26
# 25. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 75, 27
# 26. (x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 28\n    body: 29
# 27. NaturalPos
#     core type: Literal
#     sub-expressions:
# 28. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 30
# 29. {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Conditional
#     value: 31
#     condition: 32
# 30. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 74
#     end_index: 75
# 31. OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)
#     core type: Operation
#     operator: 60
#     operands: 36
# 33. _a -> x_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 66
# 34. =
#     core type: Literal
#     sub-expressions:
# 35. (OrthoProj(H, X), Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 36. ({|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 37. OrthoProj(H, X)
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)
#     core type: Operation
#     operator: 43
#     operand: 50
# 39. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}
#     core type: Operation
#     operator: 45
#     operands: 46
# 40. O.N.Bases(H)
#     core type: Operation
#     operator: 47
#     operand: 52
# 41. OrthoProj
#     core type: Literal
#     sub-expressions:
# 42. (H, X)
#     core type: ExprTuple
#     sub-expressions: 52, 49
# 43. Sum
#     core type: Literal
#     sub-expressions:
# 44. (i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 50
# 45. Set
#     core type: Literal
#     sub-expressions:
# 46. (|x_{1}〉, |x_{2}〉, ..., |x_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 51
# 47. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 48. (H)
#     core type: ExprTuple
#     sub-expressions: 52
# 49. X
#     core type: Variable
#     sub-expressions:
# 50. i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 79
#     body: 53
# 51. |x_{1}〉, |x_{2}〉, ..., |x_{n}〉
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 74
#     end_index: 75
# 52. H
#     core type: Variable
#     sub-expressions:
# 53. {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 55
#     condition: 56
# 54. _a -> |x_{_a}〉
#     core type: Lambda
#     parameter: 76
#     body: 57
# 55. |x_{i}〉 . 〈x_{i}|
#     core type: Operation
#     operator: 58
#     operands: 59
# 56. i in {1 .. n}
#     core type: Operation
#     operator: 60
#     operands: 61
# 57. |x_{_a}〉
#     core type: Operation
#     operator: 67
#     operand: 66
# 58. .
#     core type: Literal
#     sub-expressions:
# 59. (|x_{i}〉, 〈x_{i}|)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 60. in
#     core type: Literal
#     sub-expressions:
# 61. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 79, 65
# 62. (x_{_a})
#     core type: ExprTuple
#     sub-expressions: 66
# 63. |x_{i}〉
#     core type: Operation
#     operator: 67
#     operand: 73
# 64. 〈x_{i}|
#     core type: Operation
#     operator: 68
#     operand: 73
# 65. {1 .. n}
#     core type: Operation
#     operator: 70
#     operands: 71
# 66. x_{_a}
#     core type: IndexedVar
# variable: 77
# index: 76
# 67. KET
#     core type: Literal
#     sub-expressions:
# 68. BRA
#     core type: Literal
#     sub-expressions:
# 69. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 73
# 70. Interval
#     core type: Literal
#     sub-expressions:
# 71. (1, n)
#     core type: ExprTuple
#     sub-expressions: 74, 75
# 72. (_a)
#     core type: ExprTuple
#     sub-expressions: 76
# 73. x_{i}
#     core type: IndexedVar
# variable: 77
# index: 79
# 74. 1
#     core type: Literal
#     sub-expressions:
# 75. n
#     core type: Variable
#     sub-expressions:
# 76. _a
#     core type: Variable
#     sub-expressions:
# 77. x
#     core type: Variable
#     sub-expressions:
# 78. (i)
#     core type: ExprTuple
#     sub-expressions: 79
# 79. i
#     core type: Variable
#     sub-expressions:
