# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, v_1_to_n, v_i
from proveit.linear_algebra import Adj, Commutator, Hspace, LinMap, OrthoNormBases, ScalarMult, VecSum, VecZero
from proveit.logic import And, Equals, Exists, Iff, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = LinMap(Hspace, Hspace)
sub_expr3 = Interval(one, n)
sub_expr4 = Qmult(Ket(v_i), Bra(v_i))
expr = Lambda([A, B], Conditional(Iff(Equals(Commutator(A, B), VecZero(sub_expr2)), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr4), domain = sub_expr3))).with_wrapping_at(2), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), And(InSet(A, sub_expr2), InSet(B, sub_expr2), Equals(Adj(A), A), Equals(Adj(B), B))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(A, B\right) \mapsto \left\{\begin{array}{c} \begin{array}{l} \left(\left[A, B\right] = \vec{0}\left(\mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{v_{1}, v_{2}, \ldots, v_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array}\right)\end{array}\right]\end{array}\right] \end{array} \end{array} \textrm{ if } A \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right) ,  B \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right) ,  A^{\dagger} = A ,  B^{\dagger} = B\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (A, B) -> {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.
#    core type: Lambda
#    parameters: 25\n   body: 1
# 1. {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. ([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A in LINMAP(H, H)) and (B in LINMAP(H, H)) and (A* = A) and (B* = B)
#    core type: Operation
#    operator: 58
#    operands: 6
# 4. <=>
#    core type: Literal
#    sub-expressions:
# 5. ([A, B] = 0(LINMAP(H, H)), exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))])
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (A in LINMAP(H, H), B in LINMAP(H, H), A* = A, B* = B)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 7. [A, B] = 0(LINMAP(H, H))
#    core type: Operation
#    operator: 67
#    operands: 13
# 8. exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]
#    core type: Operation
#    operator: 37
#    operand: 21
# 9. A in LINMAP(H, H)
#    core type: Operation
#    operator: 97
#    operands: 15
# 10. B in LINMAP(H, H)
#     core type: Operation
#     operator: 97
#     operands: 16
# 11. A* = A
#     core type: Operation
#     operator: 67
#     operands: 17
# 12. B* = B
#     core type: Operation
#     operator: 67
#     operands: 18
# 13. ([A, B], 0(LINMAP(H, H)))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 14. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 21
# 15. (A, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 71, 32
# 16. (B, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 73, 32
# 17. (A*, A)
#     core type: ExprTuple
#     sub-expressions: 22, 71
# 18. (B*, B)
#     core type: ExprTuple
#     sub-expressions: 23, 73
# 19. [A, B]
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. 0(LINMAP(H, H))
#     core type: Operation
#     operator: 26
#     operand: 32
# 21. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 46\n    body: 28
# 22. A*
#     core type: Operation
#     operator: 30
#     operand: 71
# 23. B*
#     core type: Operation
#     operator: 30
#     operand: 73
# 24. commutator
#     core type: Literal
#     sub-expressions:
# 25. (A, B)
#     core type: ExprTuple
#     sub-expressions: 71, 73
# 26. 0
#     core type: Literal
#     sub-expressions:
# 27. (LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 32
# 28. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 33
#     condition: 34
# 29. (A)
#     core type: ExprTuple
#     sub-expressions: 71
# 30. Adj
#     core type: Literal
#     sub-expressions:
# 31. (B)
#     core type: ExprTuple
#     sub-expressions: 73
# 32. LINMAP(H, H)
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))
#     core type: Operation
#     operator: 37
#     operand: 40
# 34. {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 97
#     operands: 39
# 35. LINMAP
#     core type: Literal
#     sub-expressions:
# 36. (H, H)
#     core type: ExprTuple
#     sub-expressions: 54, 54
# 37. exists
#     core type: Literal
#     sub-expressions:
# 38. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 40
# 39. ({v_{1}, v_{2}, ..., v_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 40. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Lambda
#     parameters: 43\n    body: 44
# 41. {v_{1}, v_{2}, ..., v_{n}}
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. O.N.Bases(H)
#     core type: Operation
#     operator: 47
#     operand: 54
# 43. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 44. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 51
#     condition: 52
# 45. Set
#     core type: Literal
#     sub-expressions:
# 46. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 53
# 47. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 48. (H)
#     core type: ExprTuple
#     sub-expressions: 54
# 49. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 55
#     start_index: 111
#     end_index: 112
# 50. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 111
#     end_index: 112
# 51. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 58
#     operands: 57
# 52. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 58
#     operands: 59
# 53. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 111
#     end_index: 112
# 54. H
#     core type: Variable
#     sub-expressions:
# 55. _a -> a_{_a}
#     core type: Lambda
#     parameter: 93
#     body: 84
# 56. _a -> b_{_a}
#     core type: Lambda
#     parameter: 93
#     body: 85
# 57. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 58. and
#     core type: Literal
#     sub-expressions:
# 59. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 60. _a -> v_{_a}
#     core type: Lambda
#     parameter: 93
#     body: 65
# 61. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 67
#     operands: 66
# 62. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 67
#     operands: 68
# 63. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 111
#     end_index: 112
# 64. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 111
#     end_index: 112
# 65. v_{_a}
#     core type: IndexedVar
# variable: 117
# index: 93
# 66. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 67. =
#     core type: Literal
#     sub-expressions:
# 68. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 69. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 93
#     body: 75
# 70. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 93
#     body: 76
# 71. A
#     core type: Variable
#     sub-expressions:
# 72. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 78
#     operand: 82
# 73. B
#     core type: Variable
#     sub-expressions:
# 74. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 78
#     operand: 83
# 75. a_{_a} in Complex
#     core type: Operation
#     operator: 97
#     operands: 80
# 76. b_{_a} in Complex
#     core type: Operation
#     operator: 97
#     operands: 81
# 77. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 82
# 78. Sum
#     core type: Literal
#     sub-expressions:
# 79. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 83
# 80. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 84, 86
# 81. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 85, 86
# 82. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 119
#     body: 87
# 83. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 119
#     body: 88
# 84. a_{_a}
#     core type: IndexedVar
# variable: 103
# index: 93
# 85. b_{_a}
#     core type: IndexedVar
# variable: 104
# index: 93
# 86. Complex
#     core type: Literal
#     sub-expressions:
# 87. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 90
#     condition: 92
# 88. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 91
#     condition: 92
# 89. (_a)
#     core type: ExprTuple
#     sub-expressions: 93
# 90. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 95
#     operands: 94
# 91. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 95
#     operands: 96
# 92. i in {1 .. n}
#     core type: Operation
#     operator: 97
#     operands: 98
# 93. _a
#     core type: Variable
#     sub-expressions:
# 94. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 99, 101
# 95. *
#     core type: Literal
#     sub-expressions:
# 96. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 100, 101
# 97. in
#     core type: Literal
#     sub-expressions:
# 98. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 119, 102
# 99. a_{i}
#     core type: IndexedVar
# variable: 103
# index: 119
# 100. b_{i}
#      core type: IndexedVar
# variable: 104
# index: 119
# 101. |v_{i}〉 . 〈v_{i}|
#      core type: Operation
#      operator: 105
#      operands: 106
# 102. {1 .. n}
#      core type: Operation
#      operator: 107
#      operands: 108
# 103. a
#      core type: Variable
#      sub-expressions:
# 104. b
#      core type: Variable
#      sub-expressions:
# 105. .
#      core type: Literal
#      sub-expressions:
# 106. (|v_{i}〉, 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 109, 110
# 107. Interval
#      core type: Literal
#      sub-expressions:
# 108. (1, n)
#      core type: ExprTuple
#      sub-expressions: 111, 112
# 109. |v_{i}〉
#      core type: Operation
#      operator: 113
#      operand: 116
# 110. 〈v_{i}|
#      core type: Operation
#      operator: 114
#      operand: 116
# 111. 1
#      core type: Literal
#      sub-expressions:
# 112. n
#      core type: Variable
#      sub-expressions:
# 113. KET
#      core type: Literal
#      sub-expressions:
# 114. BRA
#      core type: Literal
#      sub-expressions:
# 115. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 116
# 116. v_{i}
#      core type: IndexedVar
# variable: 117
# index: 119
# 117. v
#      core type: Variable
#      sub-expressions:
# 118. (i)
#      core type: ExprTuple
#      sub-expressions: 119
# 119. i
#      core type: Variable
#      sub-expressions:
