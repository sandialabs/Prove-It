# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, i, n
from proveit.core_expr_types import v_1_to_n, v_i, w_1_to_n, w_i
from proveit.linear_algebra import OrthoNormBases, Unitary, VecSum
from proveit.logic import CartExp, Forall, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = OrthoNormBases(CartExp(Complex, n))
expr = ExprTuple(Lambda(n, Conditional(Forall(instance_param_or_params = [v_1_to_n, w_1_to_n], instance_expr = InSet(VecSum(index_or_indices = [i], summand = Qmult(Ket(v_i), Bra(w_i)), domain = Interval(one, n)), Unitary(n)), conditions = [InSet(Set(v_1_to_n_kets), sub_expr1), InSet(Set(w_1_to_n_kets), sub_expr1)]).with_wrapping(), InSet(n, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(n \mapsto \left\{\begin{array}{l}\forall_{v_{1}, v_{2}, \ldots, v_{n}, w_{1}, w_{2}, \ldots, w_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right), \left\{\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left(\left(\sum_{i=1}^{n} \left(\lvert v_{i} \rangle \thinspace \langle w_{i} \rvert\right)\right) \in \textrm{U}\left(n\right)\right)\end{array} \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (n -> {forall_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} ((Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n)) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} ((Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n)) if n in NaturalPos.
#    core type: Lambda
#    parameter: 70
#    body: 2
# 2. {forall_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} ((Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n)) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} ((Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. n in NaturalPos
#    core type: Operation
#    operator: 47
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {(Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 70, 9
# 8. (v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {(Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (v_{1}, v_{2}, ..., v_{n},w_{1}, w_{2}, ..., w_{n})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. {(Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 69
#     end_index: 70
# 13. w_{1}, w_{2}, ..., w_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 69
#     end_index: 70
# 14. (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n)
#     core type: Operation
#     operator: 47
#     operands: 18
# 15. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})) and ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. _a -> v_{_a}
#     core type: Lambda
#     parameter: 83
#     body: 78
# 17. _a -> w_{_a}
#     core type: Lambda
#     parameter: 83
#     body: 79
# 18. (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|), U(n))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)
#     core type: Operation
#     operator: 25
#     operand: 31
# 22. U(n)
#     core type: Operation
#     operator: 27
#     operand: 70
# 23. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 47
#     operands: 29
# 24. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 47
#     operands: 30
# 25. Sum
#     core type: Literal
#     sub-expressions:
# 26. (i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 31
# 27. U
#     core type: Literal
#     sub-expressions:
# 28. (n)
#     core type: ExprTuple
#     sub-expressions: 70
# 29. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 32, 34
# 30. ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 77
#     body: 35
# 32. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 50
#     operand: 42
# 33. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}
#     core type: Operation
#     operator: 50
#     operand: 43
# 34. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 38
#     operand: 44
# 35. {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 40
#     condition: 41
# 36. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 42
# 37. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 43
# 38. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 39. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 44
# 40. |v_{i}〉 . 〈w_{i}|
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. i in {1 .. n}
#     core type: Operation
#     operator: 47
#     operands: 48
# 42. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 50
#     operands: 49
# 43. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 50
#     operands: 51
# 44. Complex^{n}
#     core type: Operation
#     operator: 52
#     operands: 53
# 45. .
#     core type: Literal
#     sub-expressions:
# 46. (|v_{i}〉, 〈w_{i}|)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 47. in
#     core type: Literal
#     sub-expressions:
# 48. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 77, 56
# 49. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 57
# 50. Set
#     core type: Literal
#     sub-expressions:
# 51. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 58
# 52. CartExp
#     core type: Literal
#     sub-expressions:
# 53. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 59, 70
# 54. |v_{i}〉
#     core type: Operation
#     operator: 75
#     operand: 67
# 55. 〈w_{i}|
#     core type: Operation
#     operator: 61
#     operand: 68
# 56. {1 .. n}
#     core type: Operation
#     operator: 63
#     operands: 64
# 57. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 65
#     start_index: 69
#     end_index: 70
# 58. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 66
#     start_index: 69
#     end_index: 70
# 59. Complex
#     core type: Literal
#     sub-expressions:
# 60. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 67
# 61. BRA
#     core type: Literal
#     sub-expressions:
# 62. (w_{i})
#     core type: ExprTuple
#     sub-expressions: 68
# 63. Interval
#     core type: Literal
#     sub-expressions:
# 64. (1, n)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 65. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 83
#     body: 71
# 66. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 83
#     body: 72
# 67. v_{i}
#     core type: IndexedVar
# variable: 80
# index: 77
# 68. w_{i}
#     core type: IndexedVar
# variable: 81
# index: 77
# 69. 1
#     core type: Literal
#     sub-expressions:
# 70. n
#     core type: Variable
#     sub-expressions:
# 71. |v_{_a}〉
#     core type: Operation
#     operator: 75
#     operand: 78
# 72. |w_{_a}〉
#     core type: Operation
#     operator: 75
#     operand: 79
# 73. (i)
#     core type: ExprTuple
#     sub-expressions: 77
# 74. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 78
# 75. KET
#     core type: Literal
#     sub-expressions:
# 76. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 79
# 77. i
#     core type: Variable
#     sub-expressions:
# 78. v_{_a}
#     core type: IndexedVar
# variable: 80
# index: 83
# 79. w_{_a}
#     core type: IndexedVar
# variable: 81
# index: 83
# 80. v
#     core type: Variable
#     sub-expressions:
# 81. w
#     core type: Variable
#     sub-expressions:
# 82. (_a)
#     core type: ExprTuple
#     sub-expressions: 83
# 83. _a
#     core type: Variable
#     sub-expressions:
