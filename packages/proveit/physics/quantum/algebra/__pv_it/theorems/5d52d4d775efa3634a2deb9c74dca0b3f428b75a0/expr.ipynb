# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, i, lambda_, m, n
from proveit.core_expr_types import a_1_to_m, a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import OrthoNormBases, ScalarMult, TensorProd, VecSum
from proveit.logic import CartExp, Equals, Exists, Forall, InSet, Set
from proveit.numbers import Complex, Interval, Min, RealNonNeg, one
from proveit.physics.quantum import Ket, Qmult, var_ket_psi
from proveit.physics.quantum.algebra import a_1_to_m_kets, b_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
sub_expr3 = CartExp(Complex, n)
sub_expr4 = CartExp(Complex, m)
expr = Forall(instance_param_or_params = [var_ket_psi], instance_expr = Exists(instance_param_or_params = [a_1_to_m], instance_expr = Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(var_ket_psi, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, Qmult(Ket(a_i), Ket(b_i))), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n_kets), OrthoNormBases(sub_expr3))).with_wrapping(), condition = InSet(Set(a_1_to_m_kets), OrthoNormBases(sub_expr4))).with_wrapping(), domain = TensorProd(sub_expr4, sub_expr3)).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{\lvert \psi \rangle \in \mathbb{C}^{m} {\otimes} \mathbb{C}^{n}}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{m}~|~\left\{\left\{\lvert a_{1} \rangle, \lvert a_{2} \rangle, \ldots, \lvert a_{m} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{m}\right)}~\\
# \left[\begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{\left\{\lvert b_{1} \rangle, \lvert b_{2} \rangle, \ldots, \lvert b_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(\lvert \psi \rangle = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(\lvert a_{i} \rangle \thinspace \lvert b_{i} \rangle\right)\right)\right)\right)\end{array}\right]\end{array}\right]\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{|psi> in Complex^{m} otimes Complex^{n}} [exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]]]
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (|psi> -> {exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]] if |psi> in (Complex^{m} otimes Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. |psi> -> {exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]] if |psi> in (Complex^{m} otimes Complex^{n}).
#    core type: Lambda
#    parameter: 66
#    body: 5
# 4. (|psi>)
#    core type: ExprTuple
#    sub-expressions: 66
# 5. {exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]] if |psi> in (Complex^{m} otimes Complex^{n}).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]]
#    core type: Operation
#    operator: 35
#    operand: 10
# 7. |psi> in (Complex^{m} otimes Complex^{n})
#    core type: Operation
#    operator: 89
#    operands: 9
# 8. ((a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))] if {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m}).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (|psi>, Complex^{m} otimes Complex^{n})
#    core type: ExprTuple
#    sub-expressions: 66, 11
# 10. (a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))] if {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m}).
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. Complex^{m} otimes Complex^{n}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 16
# 13. {exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))] if {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m}).
#     core type: Conditional
#     value: 17
#     condition: 18
# 14. otimes
#     core type: Literal
#     sub-expressions:
# 15. (Complex^{m}, Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 33, 54
# 16. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 103
#     end_index: 112
# 17. exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]
#     core type: Operation
#     operator: 35
#     operand: 22
# 18. {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})
#     core type: Operation
#     operator: 89
#     operands: 21
# 19. _a -> a_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 71
# 20. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).)
#     core type: ExprTuple
#     sub-expressions: 22
# 21. ({{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}}, O.N.Bases(Complex^{m}))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Lambda
#     parameters: 25\n    body: 26
# 23. {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}}
#     core type: Operation
#     operator: 61
#     operand: 32
# 24. O.N.Bases(Complex^{m})
#     core type: Operation
#     operator: 47
#     operand: 33
# 25. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 29
# 26. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 30
#     condition: 31
# 27. ({|a_{1}〉, |a_{2}〉, ..., |a_{m}〉})
#     core type: ExprTuple
#     sub-expressions: 32
# 28. (Complex^{m})
#     core type: ExprTuple
#     sub-expressions: 33
# 29. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 103
#     end_index: 113
# 30. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))
#     core type: Operation
#     operator: 35
#     operand: 40
# 31. {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 89
#     operands: 37
# 32. {|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}
#     core type: Operation
#     operator: 61
#     operands: 38
# 33. Complex^{m}
#     core type: Operation
#     operator: 63
#     operands: 39
# 34. _a -> b_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 86
# 35. exists
#     core type: Literal
#     sub-expressions:
# 36. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 40
# 37. ({{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 38. (|a_{1}〉, |a_{2}〉, ..., |a_{m}〉)
#     core type: ExprTuple
#     sub-expressions: 43
# 39. (Complex, m)
#     core type: ExprTuple
#     sub-expressions: 70, 112
# 40. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 44\n    body: 45
# 41. {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}}
#     core type: Operation
#     operator: 61
#     operand: 53
# 42. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 47
#     operand: 54
# 43. |a_{1}〉, |a_{2}〉, ..., |a_{m}〉
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 103
#     end_index: 112
# 44. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 50
# 45. {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 51
#     condition: 52
# 46. ({|b_{1}〉, |b_{2}〉, ..., |b_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 53
# 47. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 48. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 54
# 49. _a -> |a_{_a}〉
#     core type: Lambda
#     parameter: 95
#     body: 55
# 50. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 103
#     end_index: 104
# 51. |psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#     core type: Operation
#     operator: 57
#     operands: 58
# 52. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 59
#     operands: 60
# 53. {|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}
#     core type: Operation
#     operator: 61
#     operands: 62
# 54. Complex^{n}
#     core type: Operation
#     operator: 63
#     operands: 64
# 55. |a_{_a}〉
#     core type: Operation
#     operator: 106
#     operand: 71
# 56. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 84
# 57. =
#     core type: Literal
#     sub-expressions:
# 58. (|psi>, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 59. and
#     core type: Literal
#     sub-expressions:
# 60. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 68
# 61. Set
#     core type: Literal
#     sub-expressions:
# 62. (|b_{1}〉, |b_{2}〉, ..., |b_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 69
# 63. CartExp
#     core type: Literal
#     sub-expressions:
# 64. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 70, 113
# 65. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 71
# 66. |psi>
#     core type: Variable
#     sub-expressions:
# 67. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))
#     core type: Operation
#     operator: 72
#     operand: 76
# 68. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 74
#     start_index: 103
#     end_index: 104
# 69. |b_{1}〉, |b_{2}〉, ..., |b_{n}〉
#     core type: ExprRange
#     lambda_map: 75
#     start_index: 103
#     end_index: 113
# 70. Complex
#     core type: Literal
#     sub-expressions:
# 71. a_{_a}
#     core type: IndexedVar
# variable: 114
# index: 95
# 72. Sum
#     core type: Literal
#     sub-expressions:
# 73. (i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 76
# 74. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 95
#     body: 77
# 75. _a -> |b_{_a}〉
#     core type: Lambda
#     parameter: 95
#     body: 78
# 76. i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 117
#     body: 79
# 77. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 89
#     operands: 80
# 78. |b_{_a}〉
#     core type: Operation
#     operator: 106
#     operand: 86
# 79. {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 82
#     condition: 83
# 80. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 81. (b_{_a})
#     core type: ExprTuple
#     sub-expressions: 86
# 82. lambda_{i} * (|a_{i}〉 . |b_{i}〉)
#     core type: Operation
#     operator: 87
#     operands: 88
# 83. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 89
#     operands: 90
# 84. lambda_{_a}
#     core type: IndexedVar
# variable: 96
# index: 95
# 85. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 86. b_{_a}
#     core type: IndexedVar
# variable: 115
# index: 95
# 87. *
#     core type: Literal
#     sub-expressions:
# 88. (lambda_{i}, |a_{i}〉 . |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 89. in
#     core type: Literal
#     sub-expressions:
# 90. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 117, 94
# 91. (_a)
#     core type: ExprTuple
#     sub-expressions: 95
# 92. lambda_{i}
#     core type: IndexedVar
# variable: 96
# index: 117
# 93. |a_{i}〉 . |b_{i}〉
#     core type: Operation
#     operator: 97
#     operands: 98
# 94. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 99
#     operands: 100
# 95. _a
#     core type: Variable
#     sub-expressions:
# 96. lambda
#     core type: Variable
#     sub-expressions:
# 97. .
#     core type: Literal
#     sub-expressions:
# 98. (|a_{i}〉, |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 101, 102
# 99. Interval
#     core type: Literal
#     sub-expressions:
# 100. (1, Min(m, n))
#      core type: ExprTuple
#      sub-expressions: 103, 104
# 101. |a_{i}〉
#      core type: Operation
#      operator: 106
#      operand: 110
# 102. |b_{i}〉
#      core type: Operation
#      operator: 106
#      operand: 111
# 103. 1
#      core type: Literal
#      sub-expressions:
# 104. Min(m, n)
#      core type: Operation
#      operator: 108
#      operands: 109
# 105. (a_{i})
#      core type: ExprTuple
#      sub-expressions: 110
# 106. KET
#      core type: Literal
#      sub-expressions:
# 107. (b_{i})
#      core type: ExprTuple
#      sub-expressions: 111
# 108. Min
#      core type: Literal
#      sub-expressions:
# 109. (m, n)
#      core type: ExprTuple
#      sub-expressions: 112, 113
# 110. a_{i}
#      core type: IndexedVar
# variable: 114
# index: 117
# 111. b_{i}
#      core type: IndexedVar
# variable: 115
# index: 117
# 112. m
#      core type: Variable
#      sub-expressions:
# 113. n
#      core type: Variable
#      sub-expressions:
# 114. a
#      core type: Variable
#      sub-expressions:
# 115. b
#      core type: Variable
#      sub-expressions:
# 116. (i)
#      core type: ExprTuple
#      sub-expressions: 117
# 117. i
#      core type: Variable
#      sub-expressions:
