# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, V, W, i, j, m, n
from proveit.core_expr_types import v_1_to_m, v_i, w_1_to_n, w_j
from proveit.linear_algebra import OrthoNormBases, VecSum
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_m_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [v_1_to_m], instance_expr = Forall(instance_param_or_params = [w_1_to_n], instance_expr = Equals(A, VecSum(index_or_indices = [i], summand = VecSum(index_or_indices = [j], summand = Qmult(Bra(w_j), A, Ket(v_i), Ket(w_j), Bra(v_i)), domain = Interval(one, n)), domain = Interval(one, m))), condition = InSet(w_1_to_n_kets, OrthoNormBases(W))).with_wrapping(), condition = InSet(v_1_to_m_kets, OrthoNormBases(V))).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{v_{1}, v_{2}, \ldots, v_{m}~|~\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{m} \rangle\right\} \in \textrm{O.N.Bases}\left(V\right)}~\\
# \left[\begin{array}{l}\forall_{w_{1}, w_{2}, \ldots, w_{n}~|~\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(W\right)}~\\
# \left(A = \left(\sum_{i=1}^{m} \left(\sum_{j=1}^{n} \left(\langle w_{j} \rvert \thinspace A \thinspace \lvert v_{i} \rangle \thinspace \lvert w_{j} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]
#    core type: Operation
#    operator: 9
#    operand: 2
# 1. ((v_{1}, v_{2}, ..., v_{m}) -> {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (v_{1}, v_{2}, ..., v_{m}) -> {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (v_{1}, v_{2}, ..., v_{m})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).
#    core type: Conditional
#    value: 6
#    condition: 7
# 5. v_{1}, v_{2}, ..., v_{m}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 80
#    end_index: 60
# 6. forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))
#    core type: Operation
#    operator: 9
#    operand: 12
# 7. {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)
#    core type: Operation
#    operator: 64
#    operands: 11
# 8. _a -> v_{_a}
#    core type: Lambda
#    parameter: 61
#    body: 42
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. ((w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. ({|v_{1}〉, |v_{2}〉, ..., |v_{m}〉}, O.N.Bases(V))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. (w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#     core type: Lambda
#     parameters: 15\n    body: 16
# 13. {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉}
#     core type: Operation
#     operator: 34
#     operands: 17
# 14. O.N.Bases(V)
#     core type: Operation
#     operator: 36
#     operand: 23
# 15. (w_{1}, w_{2}, ..., w_{n})
#     core type: ExprTuple
#     sub-expressions: 19
# 16. {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#     core type: Conditional
#     value: 20
#     condition: 21
# 17. (|v_{1}〉, |v_{2}〉, ..., |v_{m}〉)
#     core type: ExprTuple
#     sub-expressions: 22
# 18. (V)
#     core type: ExprTuple
#     sub-expressions: 23
# 19. w_{1}, w_{2}, ..., w_{n}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 80
#     end_index: 81
# 20. A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)
#     core type: Operation
#     operator: 64
#     operands: 27
# 22. |v_{1}〉, |v_{2}〉, ..., |v_{m}〉
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 80
#     end_index: 60
# 23. V
#     core type: Variable
#     sub-expressions:
# 24. _a -> w_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 54
# 25. =
#     core type: Literal
#     sub-expressions:
# 26. (A, Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 67, 29
# 27. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}, O.N.Bases(W))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 61
#     body: 32
# 29. Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 48
#     operand: 39
# 30. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. O.N.Bases(W)
#     core type: Operation
#     operator: 36
#     operand: 41
# 32. |v_{_a}〉
#     core type: Operation
#     operator: 72
#     operand: 42
# 33. (i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 39
# 34. Set
#     core type: Literal
#     sub-expressions:
# 35. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 40
# 36. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 37. (W)
#     core type: ExprTuple
#     sub-expressions: 41
# 38. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 42
# 39. i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Lambda
#     parameter: 87
#     body: 43
# 40. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 80
#     end_index: 81
# 41. W
#     core type: Variable
#     sub-expressions:
# 42. v_{_a}
#     core type: IndexedVar
# variable: 84
# index: 61
# 43. {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Conditional
#     value: 45
#     condition: 46
# 44. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 61
#     body: 47
# 45. Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 48
#     operand: 52
# 46. i in {1 .. m}
#     core type: Operation
#     operator: 64
#     operands: 50
# 47. |w_{_a}〉
#     core type: Operation
#     operator: 72
#     operand: 54
# 48. Sum
#     core type: Literal
#     sub-expressions:
# 49. (j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 52
# 50. (i, {1 .. m})
#     core type: ExprTuple
#     sub-expressions: 87, 53
# 51. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 54
# 52. j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Lambda
#     parameter: 86
#     body: 55
# 53. {1 .. m}
#     core type: Operation
#     operator: 76
#     operands: 56
# 54. w_{_a}
#     core type: IndexedVar
# variable: 82
# index: 61
# 55. {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Conditional
#     value: 58
#     condition: 59
# 56. (1, m)
#     core type: ExprTuple
#     sub-expressions: 80, 60
# 57. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 58. 〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 62
#     operands: 63
# 59. j in {1 .. n}
#     core type: Operation
#     operator: 64
#     operands: 65
# 60. m
#     core type: Variable
#     sub-expressions:
# 61. _a
#     core type: Variable
#     sub-expressions:
# 62. .
#     core type: Literal
#     sub-expressions:
# 63. (〈w_{j}|, A, |v_{i}〉, |w_{j}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 66, 67, 68, 69, 70
# 64. in
#     core type: Literal
#     sub-expressions:
# 65. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 86, 71
# 66. 〈w_{j}|
#     core type: Operation
#     operator: 74
#     operand: 78
# 67. A
#     core type: Variable
#     sub-expressions:
# 68. |v_{i}〉
#     core type: Operation
#     operator: 72
#     operand: 79
# 69. |w_{j}〉
#     core type: Operation
#     operator: 72
#     operand: 78
# 70. 〈v_{i}|
#     core type: Operation
#     operator: 74
#     operand: 79
# 71. {1 .. n}
#     core type: Operation
#     operator: 76
#     operands: 77
# 72. KET
#     core type: Literal
#     sub-expressions:
# 73. (w_{j})
#     core type: ExprTuple
#     sub-expressions: 78
# 74. BRA
#     core type: Literal
#     sub-expressions:
# 75. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 79
# 76. Interval
#     core type: Literal
#     sub-expressions:
# 77. (1, n)
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 78. w_{j}
#     core type: IndexedVar
# variable: 82
# index: 86
# 79. v_{i}
#     core type: IndexedVar
# variable: 84
# index: 87
# 80. 1
#     core type: Literal
#     sub-expressions:
# 81. n
#     core type: Variable
#     sub-expressions:
# 82. w
#     core type: Variable
#     sub-expressions:
# 83. (j)
#     core type: ExprTuple
#     sub-expressions: 86
# 84. v
#     core type: Variable
#     sub-expressions:
# 85. (i)
#     core type: ExprTuple
#     sub-expressions: 87
# 86. j
#     core type: Variable
#     sub-expressions:
# 87. i
#     core type: Variable
#     sub-expressions:
