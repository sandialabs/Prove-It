# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, X, i, n
from proveit.core_expr_types import x_1_to_n, x_i
from proveit.linear_algebra import HilbertSpaces, Hspace, OrthoNormBases, OrthoProj, VecSum
from proveit.logic import Equals, Forall, InClass, InSet, SubsetEq
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import x_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [X], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(OrthoProj(Hspace, X), VecSum(index_or_indices = [i], summand = Qmult(Ket(x_i), Bra(x_i)), domain = Interval(one, n))), condition = InSet(x_1_to_n_kets, OrthoNormBases(X))).with_wrapping(), domain = NaturalPos), condition = SubsetEq(X, Hspace)), InClass(Hspace, HilbertSpaces))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{X~|~X \subseteq \mathcal{H}}~\left[\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{\lvert x_{1} \rangle, \lvert x_{2} \rangle, \ldots, \lvert x_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(X\right)}~\\
# \left(\textrm{OrthoProj}\left(\mathcal{H}, X\right) = \left(\sum_{i=1}^{n} \left(\lvert x_{i} \rangle \thinspace \langle x_{i} \rvert\right)\right)\right)\end{array}\right]\right] \textrm{ if } \mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{X | X subset_eq H} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]] if H in_c HilbertSpaces.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{X | X subset_eq H} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]]
#    core type: Operation
#    operator: 19
#    operand: 6
# 2. H in_c HilbertSpaces
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (X -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. in_c
#    core type: Literal
#    sub-expressions:
# 5. (H, HilbertSpaces)
#    core type: ExprTuple
#    sub-expressions: 45, 7
# 6. X -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.
#    core type: Lambda
#    parameter: 48
#    body: 8
# 7. HilbertSpaces
#    core type: Literal
#    sub-expressions:
# 8. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]
#    core type: Operation
#    operator: 19
#    operand: 14
# 10. X subset_eq H
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. subset_eq
#     core type: Literal
#     sub-expressions:
# 13. (X, H)
#     core type: ExprTuple
#     sub-expressions: 48, 45
# 14. n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#     core type: Lambda
#     parameter: 71
#     body: 16
# 15. (n)
#     core type: ExprTuple
#     sub-expressions: 71
# 16. {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#     core type: Conditional
#     value: 17
#     condition: 18
# 17. forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))
#     core type: Operation
#     operator: 19
#     operand: 22
# 18. n in NaturalPos
#     core type: Operation
#     operator: 56
#     operands: 21
# 19. forall
#     core type: Literal
#     sub-expressions:
# 20. ((x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).)
#     core type: ExprTuple
#     sub-expressions: 22
# 21. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 71, 23
# 22. (x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).
#     core type: Lambda
#     parameters: 24\n    body: 25
# 23. NaturalPos
#     core type: Literal
#     sub-expressions:
# 24. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 26
# 25. {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).
#     core type: Conditional
#     value: 27
#     condition: 28
# 26. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 70
#     end_index: 71
# 27. OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)
#     core type: Operation
#     operator: 56
#     operands: 32
# 29. _a -> x_{_a}
#     core type: Lambda
#     parameter: 72
#     body: 62
# 30. =
#     core type: Literal
#     sub-expressions:
# 31. (OrthoProj(H, X), Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. ({|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}, O.N.Bases(X))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. OrthoProj(H, X)
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)
#     core type: Operation
#     operator: 39
#     operand: 46
# 35. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}
#     core type: Operation
#     operator: 41
#     operands: 42
# 36. O.N.Bases(X)
#     core type: Operation
#     operator: 43
#     operand: 48
# 37. OrthoProj
#     core type: Literal
#     sub-expressions:
# 38. (H, X)
#     core type: ExprTuple
#     sub-expressions: 45, 48
# 39. Sum
#     core type: Literal
#     sub-expressions:
# 40. (i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 46
# 41. Set
#     core type: Literal
#     sub-expressions:
# 42. (|x_{1}〉, |x_{2}〉, ..., |x_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 47
# 43. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 44. (X)
#     core type: ExprTuple
#     sub-expressions: 48
# 45. H
#     core type: Variable
#     sub-expressions:
# 46. i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 75
#     body: 49
# 47. |x_{1}〉, |x_{2}〉, ..., |x_{n}〉
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 70
#     end_index: 71
# 48. X
#     core type: Variable
#     sub-expressions:
# 49. {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 51
#     condition: 52
# 50. _a -> |x_{_a}〉
#     core type: Lambda
#     parameter: 72
#     body: 53
# 51. |x_{i}〉 . 〈x_{i}|
#     core type: Operation
#     operator: 54
#     operands: 55
# 52. i in {1 .. n}
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. |x_{_a}〉
#     core type: Operation
#     operator: 63
#     operand: 62
# 54. .
#     core type: Literal
#     sub-expressions:
# 55. (|x_{i}〉, 〈x_{i}|)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 56. in
#     core type: Literal
#     sub-expressions:
# 57. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 75, 61
# 58. (x_{_a})
#     core type: ExprTuple
#     sub-expressions: 62
# 59. |x_{i}〉
#     core type: Operation
#     operator: 63
#     operand: 69
# 60. 〈x_{i}|
#     core type: Operation
#     operator: 64
#     operand: 69
# 61. {1 .. n}
#     core type: Operation
#     operator: 66
#     operands: 67
# 62. x_{_a}
#     core type: IndexedVar
# variable: 73
# index: 72
# 63. KET
#     core type: Literal
#     sub-expressions:
# 64. BRA
#     core type: Literal
#     sub-expressions:
# 65. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 69
# 66. Interval
#     core type: Literal
#     sub-expressions:
# 67. (1, n)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 68. (_a)
#     core type: ExprTuple
#     sub-expressions: 72
# 69. x_{i}
#     core type: IndexedVar
# variable: 73
# index: 75
# 70. 1
#     core type: Literal
#     sub-expressions:
# 71. n
#     core type: Variable
#     sub-expressions:
# 72. _a
#     core type: Variable
#     sub-expressions:
# 73. x
#     core type: Variable
#     sub-expressions:
# 74. (i)
#     core type: ExprTuple
#     sub-expressions: 75
# 75. i
#     core type: Variable
#     sub-expressions:
