# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprTuple, Lambda, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, v_1_to_n, v_i
from proveit.linear_algebra import Hspace, OrthoNormBases, ScalarMult, VecSum
from proveit.logic import And, Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Interval(one, n)
sub_expr3 = Qmult(Ket(v_i), Bra(v_i))
expr = ExprTuple(Lambda([v_1_to_n], Conditional(Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr3), domain = sub_expr2)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr3), domain = sub_expr2))).with_wrapping_at(2), domain = Complex).with_wrapping(), InSet(Set(v_1_to_n), OrthoNormBases(Hspace)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(v_{1}, v_{2}, \ldots, v_{n}\right) \mapsto \left\{\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array}\right)\end{array} \textrm{ if } \left\{v_{1}, v_{2}, \ldots, v_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).
#    core type: Lambda
#    parameters: 14\n   body: 2
# 2. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)
#    core type: Operation
#    operator: 65
#    operands: 7
# 5. exists
#    core type: Literal
#    sub-expressions:
# 6. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. ({v_{1}, v_{2}, ..., v_{n}}, O.N.Bases(H))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 9. {v_{1}, v_{2}, ..., v_{n}}
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. O.N.Bases(H)
#     core type: Operation
#     operator: 15
#     operand: 22
# 11. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 12. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 19
#     condition: 20
# 13. Set
#     core type: Literal
#     sub-expressions:
# 14. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 21
# 15. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 16. (H)
#     core type: ExprTuple
#     sub-expressions: 22
# 17. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 79
#     end_index: 80
# 18. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 79
#     end_index: 80
# 19. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 26
#     operands: 25
# 20. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 79
#     end_index: 80
# 22. H
#     core type: Variable
#     sub-expressions:
# 23. _a -> a_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 52
# 24. _a -> b_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 53
# 25. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. _a -> v_{_a}
#     core type: Lambda
#     parameter: 61
#     body: 33
# 29. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 35
#     operands: 34
# 30. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 79
#     end_index: 80
# 32. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 79
#     end_index: 80
# 33. v_{_a}
#     core type: IndexedVar
# variable: 85
# index: 61
# 34. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 35. =
#     core type: Literal
#     sub-expressions:
# 36. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 37. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 61
#     body: 43
# 38. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 61
#     body: 44
# 39. A
#     core type: Variable
#     sub-expressions:
# 40. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 46
#     operand: 50
# 41. B
#     core type: Variable
#     sub-expressions:
# 42. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 46
#     operand: 51
# 43. a_{_a} in Complex
#     core type: Operation
#     operator: 65
#     operands: 48
# 44. b_{_a} in Complex
#     core type: Operation
#     operator: 65
#     operands: 49
# 45. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 50
# 46. Sum
#     core type: Literal
#     sub-expressions:
# 47. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 51
# 48. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 52, 54
# 49. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 50. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 87
#     body: 55
# 51. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 87
#     body: 56
# 52. a_{_a}
#     core type: IndexedVar
# variable: 71
# index: 61
# 53. b_{_a}
#     core type: IndexedVar
# variable: 72
# index: 61
# 54. Complex
#     core type: Literal
#     sub-expressions:
# 55. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 58
#     condition: 60
# 56. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 59
#     condition: 60
# 57. (_a)
#     core type: ExprTuple
#     sub-expressions: 61
# 58. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 63
#     operands: 62
# 59. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 63
#     operands: 64
# 60. i in {1 .. n}
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. _a
#     core type: Variable
#     sub-expressions:
# 62. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 67, 69
# 63. *
#     core type: Literal
#     sub-expressions:
# 64. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 65. in
#     core type: Literal
#     sub-expressions:
# 66. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 87, 70
# 67. a_{i}
#     core type: IndexedVar
# variable: 71
# index: 87
# 68. b_{i}
#     core type: IndexedVar
# variable: 72
# index: 87
# 69. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 73
#     operands: 74
# 70. {1 .. n}
#     core type: Operation
#     operator: 75
#     operands: 76
# 71. a
#     core type: Variable
#     sub-expressions:
# 72. b
#     core type: Variable
#     sub-expressions:
# 73. .
#     core type: Literal
#     sub-expressions:
# 74. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 75. Interval
#     core type: Literal
#     sub-expressions:
# 76. (1, n)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 77. |v_{i}〉
#     core type: Operation
#     operator: 81
#     operand: 84
# 78. 〈v_{i}|
#     core type: Operation
#     operator: 82
#     operand: 84
# 79. 1
#     core type: Literal
#     sub-expressions:
# 80. n
#     core type: Variable
#     sub-expressions:
# 81. KET
#     core type: Literal
#     sub-expressions:
# 82. BRA
#     core type: Literal
#     sub-expressions:
# 83. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 84
# 84. v_{i}
#     core type: IndexedVar
# variable: 85
# index: 87
# 85. v
#     core type: Variable
#     sub-expressions:
# 86. (i)
#     core type: ExprTuple
#     sub-expressions: 87
# 87. i
#     core type: Variable
#     sub-expressions:
