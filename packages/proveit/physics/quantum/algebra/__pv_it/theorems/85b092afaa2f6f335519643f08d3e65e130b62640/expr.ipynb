# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, X, i, n
from proveit.core_expr_types import x_1_to_n, x_i
from proveit.linear_algebra import Hspace, OrthoNormBases, OrthoProj, VecSum
from proveit.logic import Equals, Forall, InSet, SubsetEq
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import x_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(X, Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(OrthoProj(Hspace, X), VecSum(index_or_indices = [i], summand = Qmult(Ket(x_i), Bra(x_i)), domain = Interval(one, n))), condition = InSet(x_1_to_n_kets, OrthoNormBases(Hspace))).with_wrapping(), domain = NaturalPos), SubsetEq(X, Hspace))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(X \mapsto \left\{\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{\lvert x_{1} \rangle, \lvert x_{2} \rangle, \ldots, \lvert x_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left(\textrm{OrthoProj}\left(\mathcal{H}, X\right) = \left(\sum_{i=1}^{n} \left(\lvert x_{i} \rangle \thinspace \langle x_{i} \rvert\right)\right)\right)\end{array}\right] \textrm{ if } X \subseteq \mathcal{H}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (X -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. X -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.
#    core type: Lambda
#    parameter: 40
#    body: 3
# 2. (X)
#    core type: ExprTuple
#    sub-expressions: 40
# 3. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]
#    core type: Operation
#    operator: 14
#    operand: 9
# 5. X subset_eq H
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. subset_eq
#    core type: Literal
#    sub-expressions:
# 8. (X, H)
#    core type: ExprTuple
#    sub-expressions: 40, 43
# 9. n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 66
#    body: 11
# 10. (n)
#     core type: ExprTuple
#     sub-expressions: 66
# 11. {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))
#     core type: Operation
#     operator: 14
#     operand: 17
# 13. n in NaturalPos
#     core type: Operation
#     operator: 51
#     operands: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. ((x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 66, 18
# 17. (x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 19\n    body: 20
# 18. NaturalPos
#     core type: Literal
#     sub-expressions:
# 19. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 21
# 20. {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Conditional
#     value: 22
#     condition: 23
# 21. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 65
#     end_index: 66
# 22. OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)
#     core type: Operation
#     operator: 51
#     operands: 27
# 24. _a -> x_{_a}
#     core type: Lambda
#     parameter: 67
#     body: 57
# 25. =
#     core type: Literal
#     sub-expressions:
# 26. (OrthoProj(H, X), Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. ({|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. OrthoProj(H, X)
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)
#     core type: Operation
#     operator: 34
#     operand: 41
# 30. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}
#     core type: Operation
#     operator: 36
#     operands: 37
# 31. O.N.Bases(H)
#     core type: Operation
#     operator: 38
#     operand: 43
# 32. OrthoProj
#     core type: Literal
#     sub-expressions:
# 33. (H, X)
#     core type: ExprTuple
#     sub-expressions: 43, 40
# 34. Sum
#     core type: Literal
#     sub-expressions:
# 35. (i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 41
# 36. Set
#     core type: Literal
#     sub-expressions:
# 37. (|x_{1}〉, |x_{2}〉, ..., |x_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 42
# 38. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 39. (H)
#     core type: ExprTuple
#     sub-expressions: 43
# 40. X
#     core type: Variable
#     sub-expressions:
# 41. i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 70
#     body: 44
# 42. |x_{1}〉, |x_{2}〉, ..., |x_{n}〉
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 65
#     end_index: 66
# 43. H
#     core type: Variable
#     sub-expressions:
# 44. {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 46
#     condition: 47
# 45. _a -> |x_{_a}〉
#     core type: Lambda
#     parameter: 67
#     body: 48
# 46. |x_{i}〉 . 〈x_{i}|
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. i in {1 .. n}
#     core type: Operation
#     operator: 51
#     operands: 52
# 48. |x_{_a}〉
#     core type: Operation
#     operator: 58
#     operand: 57
# 49. .
#     core type: Literal
#     sub-expressions:
# 50. (|x_{i}〉, 〈x_{i}|)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 70, 56
# 53. (x_{_a})
#     core type: ExprTuple
#     sub-expressions: 57
# 54. |x_{i}〉
#     core type: Operation
#     operator: 58
#     operand: 64
# 55. 〈x_{i}|
#     core type: Operation
#     operator: 59
#     operand: 64
# 56. {1 .. n}
#     core type: Operation
#     operator: 61
#     operands: 62
# 57. x_{_a}
#     core type: IndexedVar
# variable: 68
# index: 67
# 58. KET
#     core type: Literal
#     sub-expressions:
# 59. BRA
#     core type: Literal
#     sub-expressions:
# 60. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 64
# 61. Interval
#     core type: Literal
#     sub-expressions:
# 62. (1, n)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 63. (_a)
#     core type: ExprTuple
#     sub-expressions: 67
# 64. x_{i}
#     core type: IndexedVar
# variable: 68
# index: 70
# 65. 1
#     core type: Literal
#     sub-expressions:
# 66. n
#     core type: Variable
#     sub-expressions:
# 67. _a
#     core type: Variable
#     sub-expressions:
# 68. x
#     core type: Variable
#     sub-expressions:
# 69. (i)
#     core type: ExprTuple
#     sub-expressions: 70
# 70. i
#     core type: Variable
#     sub-expressions:
