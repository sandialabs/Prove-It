# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, v_1_to_n, v_i
from proveit.linear_algebra import Adj, MatrixSpace, OrthoNormBases, ScalarMult, VecSum
from proveit.logic import CartExp, Equals, Exists, Iff, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = Conditional(Iff(Equals(Qmult(sub_expr1, M), Qmult(M, sub_expr1)), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, Qmult(Ket(v_i), Bra(v_i))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n_kets), OrthoNormBases(CartExp(Complex, n)))).with_wrapping()).with_wrapping_at(2), InSet(M, MatrixSpace(field = Complex, rows = n, columns = n)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \thinspace M\right) = \left(M \thinspace M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array} \textrm{ if } M \in \mathbb{C}^{n \times n}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in Complex^{n x n}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. ((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. M in Complex^{n x n}
#    core type: Operation
#    operator: 73
#    operands: 5
# 3. <=>
#    core type: Literal
#    sub-expressions:
# 4. ((M* . M) = (M . M*), exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))])
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (M, Complex^{n x n})
#    core type: ExprTuple
#    sub-expressions: 52, 8
# 6. (M* . M) = (M . M*)
#    core type: Operation
#    operator: 44
#    operands: 9
# 7. exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]
#    core type: Operation
#    operator: 27
#    operand: 15
# 8. Complex^{n x n}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. (M* . M, M . M*)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 10. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).)
#     core type: ExprTuple
#     sub-expressions: 15
# 11. MSpace
#     core type: Literal
#     sub-expressions:
# 12. {field:Complex, rows:n, columns:n}
#     core type: NamedExprs
#     field: 69
#     rows: 88
#     columns: 88
# 13. M* . M
#     core type: Operation
#     operator: 81
#     operands: 16
# 14. M . M*
#     core type: Operation
#     operator: 81
#     operands: 17
# 15. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Lambda
#     parameters: 18\n    body: 19
# 16. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 20, 52
# 17. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 52, 20
# 18. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 21
# 19. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 22
#     condition: 23
# 20. M*
#     core type: Operation
#     operator: 24
#     operand: 52
# 21. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 87
#     end_index: 88
# 22. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 27
#     operand: 30
# 23. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 73
#     operands: 29
# 24. Adj
#     core type: Literal
#     sub-expressions:
# 25. (M)
#     core type: ExprTuple
#     sub-expressions: 52
# 26. _a -> v_{_a}
#     core type: Lambda
#     parameter: 79
#     body: 70
# 27. exists
#     core type: Literal
#     sub-expressions:
# 28. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 30
# 29. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 33\n    body: 34
# 31. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 48
#     operand: 41
# 32. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 36
#     operand: 42
# 33. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 34. {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 39
#     condition: 40
# 35. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 41
# 36. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 37. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 42
# 38. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 87
#     end_index: 88
# 39. M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 46
#     operands: 47
# 41. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 48
#     operands: 49
# 42. Complex^{n}
#     core type: Operation
#     operator: 50
#     operands: 51
# 43. _a -> a_{_a}
#     core type: Lambda
#     parameter: 79
#     body: 68
# 44. =
#     core type: Literal
#     sub-expressions:
# 45. (M, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 46. and
#     core type: Literal
#     sub-expressions:
# 47. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 54
# 48. Set
#     core type: Literal
#     sub-expressions:
# 49. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 55
# 50. CartExp
#     core type: Literal
#     sub-expressions:
# 51. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 69, 88
# 52. M
#     core type: Variable
#     sub-expressions:
# 53. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 56
#     operand: 60
# 54. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 87
#     end_index: 88
# 55. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 87
#     end_index: 88
# 56. Sum
#     core type: Literal
#     sub-expressions:
# 57. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 60
# 58. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 79
#     body: 61
# 59. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 79
#     body: 62
# 60. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 95
#     body: 63
# 61. a_{_a} in Complex
#     core type: Operation
#     operator: 73
#     operands: 64
# 62. |v_{_a}〉
#     core type: Operation
#     operator: 89
#     operand: 70
# 63. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 66
#     condition: 67
# 64. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 65. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 70
# 66. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 71
#     operands: 72
# 67. i in {1 .. n}
#     core type: Operation
#     operator: 73
#     operands: 74
# 68. a_{_a}
#     core type: IndexedVar
# variable: 80
# index: 79
# 69. Complex
#     core type: Literal
#     sub-expressions:
# 70. v_{_a}
#     core type: IndexedVar
# variable: 93
# index: 79
# 71. *
#     core type: Literal
#     sub-expressions:
# 72. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 76, 77
# 73. in
#     core type: Literal
#     sub-expressions:
# 74. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 95, 78
# 75. (_a)
#     core type: ExprTuple
#     sub-expressions: 79
# 76. a_{i}
#     core type: IndexedVar
# variable: 80
# index: 95
# 77. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 81
#     operands: 82
# 78. {1 .. n}
#     core type: Operation
#     operator: 83
#     operands: 84
# 79. _a
#     core type: Variable
#     sub-expressions:
# 80. a
#     core type: Variable
#     sub-expressions:
# 81. .
#     core type: Literal
#     sub-expressions:
# 82. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 85, 86
# 83. Interval
#     core type: Literal
#     sub-expressions:
# 84. (1, n)
#     core type: ExprTuple
#     sub-expressions: 87, 88
# 85. |v_{i}〉
#     core type: Operation
#     operator: 89
#     operand: 92
# 86. 〈v_{i}|
#     core type: Operation
#     operator: 90
#     operand: 92
# 87. 1
#     core type: Literal
#     sub-expressions:
# 88. n
#     core type: Variable
#     sub-expressions:
# 89. KET
#     core type: Literal
#     sub-expressions:
# 90. BRA
#     core type: Literal
#     sub-expressions:
# 91. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 92
# 92. v_{i}
#     core type: IndexedVar
# variable: 93
# index: 95
# 93. v
#     core type: Variable
#     sub-expressions:
# 94. (i)
#     core type: ExprTuple
#     sub-expressions: 95
# 95. i
#     core type: Variable
#     sub-expressions:
