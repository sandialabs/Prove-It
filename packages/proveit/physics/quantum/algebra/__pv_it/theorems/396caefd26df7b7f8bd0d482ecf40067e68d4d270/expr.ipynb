# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, i, n
from proveit.core_expr_types import x_1_to_n, x_i
from proveit.linear_algebra import HilbertSpaces, Hspace, Identity, OrthoNormBases, VecSum
from proveit.logic import Equals, Forall, InClass, InSet
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import x_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(Hspace, Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(VecSum(index_or_indices = [i], summand = Qmult(Ket(x_i), Bra(x_i)), domain = Interval(one, n)), Identity(Hspace)), condition = InSet(x_1_to_n_kets, OrthoNormBases(Hspace))).with_wrapping(), domain = NaturalPos), InClass(Hspace, HilbertSpaces))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\mathcal{H} \mapsto \left\{\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{\lvert x_{1} \rangle, \lvert x_{2} \rangle, \ldots, \lvert x_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left(\left(\sum_{i=1}^{n} \left(\lvert x_{i} \rangle \thinspace \langle x_{i} \rvert\right)\right) = I_{\mathcal{H}}\right)\end{array}\right] \textrm{ if } \mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (H -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)] if H in_c HilbertSpaces.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. H -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)] if H in_c HilbertSpaces.
#    core type: Lambda
#    parameter: 41
#    body: 2
# 2. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)] if H in_c HilbertSpaces.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)]
#    core type: Operation
#    operator: 14
#    operand: 8
# 4. H in_c HilbertSpaces
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in_c
#    core type: Literal
#    sub-expressions:
# 7. (H, HilbertSpaces)
#    core type: ExprTuple
#    sub-expressions: 41, 9
# 8. n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H) if n in NaturalPos.
#    core type: Lambda
#    parameter: 64
#    body: 11
# 9. HilbertSpaces
#    core type: Literal
#    sub-expressions:
# 10. (n)
#     core type: ExprTuple
#     sub-expressions: 64
# 11. {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H) if n in NaturalPos.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)
#     core type: Operation
#     operator: 14
#     operand: 17
# 13. n in NaturalPos
#     core type: Operation
#     operator: 49
#     operands: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. ((x_{1}, x_{2}, ..., x_{n}) -> {(Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 64, 18
# 17. (x_{1}, x_{2}, ..., x_{n}) -> {(Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 19\n    body: 20
# 18. NaturalPos
#     core type: Literal
#     sub-expressions:
# 19. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 21
# 20. {(Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Conditional
#     value: 22
#     condition: 23
# 21. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 63
#     end_index: 64
# 22. (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)
#     core type: Operation
#     operator: 49
#     operands: 27
# 24. _a -> x_{_a}
#     core type: Lambda
#     parameter: 65
#     body: 55
# 25. =
#     core type: Literal
#     sub-expressions:
# 26. (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|), I_H)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. ({|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)
#     core type: Operation
#     operator: 32
#     operand: 39
# 29. I_H
#     core type: Operation
#     operator: 34
#     operand: 41
# 30. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. O.N.Bases(H)
#     core type: Operation
#     operator: 37
#     operand: 41
# 32. Sum
#     core type: Literal
#     sub-expressions:
# 33. (i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 39
# 34. I
#     core type: Literal
#     sub-expressions:
# 35. Set
#     core type: Literal
#     sub-expressions:
# 36. (|x_{1}〉, |x_{2}〉, ..., |x_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 40
# 37. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 38. (H)
#     core type: ExprTuple
#     sub-expressions: 41
# 39. i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 68
#     body: 42
# 40. |x_{1}〉, |x_{2}〉, ..., |x_{n}〉
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 63
#     end_index: 64
# 41. H
#     core type: Variable
#     sub-expressions:
# 42. {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 44
#     condition: 45
# 43. _a -> |x_{_a}〉
#     core type: Lambda
#     parameter: 65
#     body: 46
# 44. |x_{i}〉 . 〈x_{i}|
#     core type: Operation
#     operator: 47
#     operands: 48
# 45. i in {1 .. n}
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. |x_{_a}〉
#     core type: Operation
#     operator: 56
#     operand: 55
# 47. .
#     core type: Literal
#     sub-expressions:
# 48. (|x_{i}〉, 〈x_{i}|)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 68, 54
# 51. (x_{_a})
#     core type: ExprTuple
#     sub-expressions: 55
# 52. |x_{i}〉
#     core type: Operation
#     operator: 56
#     operand: 62
# 53. 〈x_{i}|
#     core type: Operation
#     operator: 57
#     operand: 62
# 54. {1 .. n}
#     core type: Operation
#     operator: 59
#     operands: 60
# 55. x_{_a}
#     core type: IndexedVar
# variable: 66
# index: 65
# 56. KET
#     core type: Literal
#     sub-expressions:
# 57. BRA
#     core type: Literal
#     sub-expressions:
# 58. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 62
# 59. Interval
#     core type: Literal
#     sub-expressions:
# 60. (1, n)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 61. (_a)
#     core type: ExprTuple
#     sub-expressions: 65
# 62. x_{i}
#     core type: IndexedVar
# variable: 66
# index: 68
# 63. 1
#     core type: Literal
#     sub-expressions:
# 64. n
#     core type: Variable
#     sub-expressions:
# 65. _a
#     core type: Variable
#     sub-expressions:
# 66. x
#     core type: Variable
#     sub-expressions:
# 67. (i)
#     core type: ExprTuple
#     sub-expressions: 68
# 68. i
#     core type: Variable
#     sub-expressions:
