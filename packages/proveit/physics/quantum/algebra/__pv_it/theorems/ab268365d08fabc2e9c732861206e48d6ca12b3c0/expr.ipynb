# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, i, lambda_, m, n
from proveit.core_expr_types import a_1_to_m, a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import OrthoNormBases, ScalarMult, VecSum
from proveit.logic import CartExp, Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, Min, RealNonNeg, one
from proveit.physics.quantum import Ket, Qmult, var_ket_psi
from proveit.physics.quantum.algebra import a_1_to_m_kets, b_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
expr = Exists(instance_param_or_params = [a_1_to_m], instance_expr = Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(var_ket_psi, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, Qmult(Ket(a_i), Ket(b_i))), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n_kets), OrthoNormBases(CartExp(Complex, n)))).with_wrapping(), condition = InSet(Set(a_1_to_m_kets), OrthoNormBases(CartExp(Complex, m)))).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{m}~|~\left\{\left\{\lvert a_{1} \rangle, \lvert a_{2} \rangle, \ldots, \lvert a_{m} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{m}\right)}~\\
# \left[\begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{\left\{\lvert b_{1} \rangle, \lvert b_{2} \rangle, \ldots, \lvert b_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(\lvert \psi \rangle = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(\lvert a_{i} \rangle \thinspace \lvert b_{i} \rangle\right)\right)\right)\right)\end{array}\right]\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]]
#    core type: Operation
#    operator: 24
#    operand: 2
# 1. ((a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))] if {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m}).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))] if {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m}).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a_{1}, a_{2}, ..., a_{m})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. {exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))] if {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m}).
#    core type: Conditional
#    value: 6
#    condition: 7
# 5. a_{1}, a_{2}, ..., a_{m}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 92
#    end_index: 101
# 6. exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]
#    core type: Operation
#    operator: 24
#    operand: 11
# 7. {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})
#    core type: Operation
#    operator: 78
#    operands: 10
# 8. _a -> a_{_a}
#    core type: Lambda
#    parameter: 84
#    body: 60
# 9. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. ({{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}}, O.N.Bases(Complex^{m}))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Lambda
#     parameters: 14\n    body: 15
# 12. {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}}
#     core type: Operation
#     operator: 50
#     operand: 21
# 13. O.N.Bases(Complex^{m})
#     core type: Operation
#     operator: 36
#     operand: 22
# 14. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 15. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 19
#     condition: 20
# 16. ({|a_{1}〉, |a_{2}〉, ..., |a_{m}〉})
#     core type: ExprTuple
#     sub-expressions: 21
# 17. (Complex^{m})
#     core type: ExprTuple
#     sub-expressions: 22
# 18. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 92
#     end_index: 102
# 19. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))
#     core type: Operation
#     operator: 24
#     operand: 29
# 20. {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 78
#     operands: 26
# 21. {|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}
#     core type: Operation
#     operator: 50
#     operands: 27
# 22. Complex^{m}
#     core type: Operation
#     operator: 52
#     operands: 28
# 23. _a -> b_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 75
# 24. exists
#     core type: Literal
#     sub-expressions:
# 25. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 29
# 26. ({{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 27. (|a_{1}〉, |a_{2}〉, ..., |a_{m}〉)
#     core type: ExprTuple
#     sub-expressions: 32
# 28. (Complex, m)
#     core type: ExprTuple
#     sub-expressions: 59, 101
# 29. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 33\n    body: 34
# 30. {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}}
#     core type: Operation
#     operator: 50
#     operand: 42
# 31. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 36
#     operand: 43
# 32. |a_{1}〉, |a_{2}〉, ..., |a_{m}〉
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 92
#     end_index: 101
# 33. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 39
# 34. {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 40
#     condition: 41
# 35. ({|b_{1}〉, |b_{2}〉, ..., |b_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 42
# 36. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 37. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 43
# 38. _a -> |a_{_a}〉
#     core type: Lambda
#     parameter: 84
#     body: 44
# 39. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 92
#     end_index: 93
# 40. |psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#     core type: Operation
#     operator: 46
#     operands: 47
# 41. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 48
#     operands: 49
# 42. {|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}
#     core type: Operation
#     operator: 50
#     operands: 51
# 43. Complex^{n}
#     core type: Operation
#     operator: 52
#     operands: 53
# 44. |a_{_a}〉
#     core type: Operation
#     operator: 95
#     operand: 60
# 45. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 73
# 46. =
#     core type: Literal
#     sub-expressions:
# 47. (|psi>, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 48. and
#     core type: Literal
#     sub-expressions:
# 49. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 57
# 50. Set
#     core type: Literal
#     sub-expressions:
# 51. (|b_{1}〉, |b_{2}〉, ..., |b_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 58
# 52. CartExp
#     core type: Literal
#     sub-expressions:
# 53. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 59, 102
# 54. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 60
# 55. |psi>
#     core type: Variable
#     sub-expressions:
# 56. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))
#     core type: Operation
#     operator: 61
#     operand: 65
# 57. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 92
#     end_index: 93
# 58. |b_{1}〉, |b_{2}〉, ..., |b_{n}〉
#     core type: ExprRange
#     lambda_map: 64
#     start_index: 92
#     end_index: 102
# 59. Complex
#     core type: Literal
#     sub-expressions:
# 60. a_{_a}
#     core type: IndexedVar
# variable: 103
# index: 84
# 61. Sum
#     core type: Literal
#     sub-expressions:
# 62. (i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 65
# 63. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 84
#     body: 66
# 64. _a -> |b_{_a}〉
#     core type: Lambda
#     parameter: 84
#     body: 67
# 65. i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 106
#     body: 68
# 66. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 78
#     operands: 69
# 67. |b_{_a}〉
#     core type: Operation
#     operator: 95
#     operand: 75
# 68. {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 71
#     condition: 72
# 69. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 70. (b_{_a})
#     core type: ExprTuple
#     sub-expressions: 75
# 71. lambda_{i} * (|a_{i}〉 . |b_{i}〉)
#     core type: Operation
#     operator: 76
#     operands: 77
# 72. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 78
#     operands: 79
# 73. lambda_{_a}
#     core type: IndexedVar
# variable: 85
# index: 84
# 74. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 75. b_{_a}
#     core type: IndexedVar
# variable: 104
# index: 84
# 76. *
#     core type: Literal
#     sub-expressions:
# 77. (lambda_{i}, |a_{i}〉 . |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 81, 82
# 78. in
#     core type: Literal
#     sub-expressions:
# 79. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 106, 83
# 80. (_a)
#     core type: ExprTuple
#     sub-expressions: 84
# 81. lambda_{i}
#     core type: IndexedVar
# variable: 85
# index: 106
# 82. |a_{i}〉 . |b_{i}〉
#     core type: Operation
#     operator: 86
#     operands: 87
# 83. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 88
#     operands: 89
# 84. _a
#     core type: Variable
#     sub-expressions:
# 85. lambda
#     core type: Variable
#     sub-expressions:
# 86. .
#     core type: Literal
#     sub-expressions:
# 87. (|a_{i}〉, |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 90, 91
# 88. Interval
#     core type: Literal
#     sub-expressions:
# 89. (1, Min(m, n))
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 90. |a_{i}〉
#     core type: Operation
#     operator: 95
#     operand: 99
# 91. |b_{i}〉
#     core type: Operation
#     operator: 95
#     operand: 100
# 92. 1
#     core type: Literal
#     sub-expressions:
# 93. Min(m, n)
#     core type: Operation
#     operator: 97
#     operands: 98
# 94. (a_{i})
#     core type: ExprTuple
#     sub-expressions: 99
# 95. KET
#     core type: Literal
#     sub-expressions:
# 96. (b_{i})
#     core type: ExprTuple
#     sub-expressions: 100
# 97. Min
#     core type: Literal
#     sub-expressions:
# 98. (m, n)
#     core type: ExprTuple
#     sub-expressions: 101, 102
# 99. a_{i}
#     core type: IndexedVar
# variable: 103
# index: 106
# 100. b_{i}
#      core type: IndexedVar
# variable: 104
# index: 106
# 101. m
#      core type: Variable
#      sub-expressions:
# 102. n
#      core type: Variable
#      sub-expressions:
# 103. a
#      core type: Variable
#      sub-expressions:
# 104. b
#      core type: Variable
#      sub-expressions:
# 105. (i)
#      core type: ExprTuple
#      sub-expressions: 106
# 106. i
#      core type: Variable
#      sub-expressions:
