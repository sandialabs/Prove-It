# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, X, i, n
from proveit.core_expr_types import x_1_to_n, x_i
from proveit.linear_algebra import Hspace, OrthoNormBases, OrthoProj, VecSum
from proveit.logic import Equals, Forall, InSet, SubsetEq
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import x_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Lambda(X, Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(OrthoProj(Hspace, X), VecSum(index_or_indices = [i], summand = Qmult(Ket(x_i), Bra(x_i)), domain = Interval(one, n))), condition = InSet(x_1_to_n_kets, OrthoNormBases(X))).with_wrapping(), domain = NaturalPos), SubsetEq(X, Hspace)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# X \mapsto \left\{\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{\lvert x_{1} \rangle, \lvert x_{2} \rangle, \ldots, \lvert x_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(X\right)}~\\
# \left(\textrm{OrthoProj}\left(\mathcal{H}, X\right) = \left(\sum_{i=1}^{n} \left(\lvert x_{i} \rangle \thinspace \langle x_{i} \rvert\right)\right)\right)\end{array}\right] \textrm{ if } X \subseteq \mathcal{H}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. X -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.
#    core type: Lambda
#    parameter: 41
#    body: 1
# 1. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]
#    core type: Operation
#    operator: 12
#    operand: 7
# 3. X subset_eq H
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. subset_eq
#    core type: Literal
#    sub-expressions:
# 6. (X, H)
#    core type: ExprTuple
#    sub-expressions: 41, 38
# 7. n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 64
#    body: 9
# 8. (n)
#    core type: ExprTuple
#    sub-expressions: 64
# 9. {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))
#     core type: Operation
#     operator: 12
#     operand: 15
# 11. n in NaturalPos
#     core type: Operation
#     operator: 49
#     operands: 14
# 12. forall
#     core type: Literal
#     sub-expressions:
# 13. ((x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 64, 16
# 15. (x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).
#     core type: Lambda
#     parameters: 17\n    body: 18
# 16. NaturalPos
#     core type: Literal
#     sub-expressions:
# 17. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 19
# 18. {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).
#     core type: Conditional
#     value: 20
#     condition: 21
# 19. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 63
#     end_index: 64
# 20. OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)
#     core type: Operation
#     operator: 49
#     operands: 25
# 22. _a -> x_{_a}
#     core type: Lambda
#     parameter: 65
#     body: 55
# 23. =
#     core type: Literal
#     sub-expressions:
# 24. (OrthoProj(H, X), Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. ({|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}, O.N.Bases(X))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. OrthoProj(H, X)
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)
#     core type: Operation
#     operator: 32
#     operand: 39
# 28. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. O.N.Bases(X)
#     core type: Operation
#     operator: 36
#     operand: 41
# 30. OrthoProj
#     core type: Literal
#     sub-expressions:
# 31. (H, X)
#     core type: ExprTuple
#     sub-expressions: 38, 41
# 32. Sum
#     core type: Literal
#     sub-expressions:
# 33. (i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 39
# 34. Set
#     core type: Literal
#     sub-expressions:
# 35. (|x_{1}〉, |x_{2}〉, ..., |x_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 40
# 36. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 37. (X)
#     core type: ExprTuple
#     sub-expressions: 41
# 38. H
#     core type: Variable
#     sub-expressions:
# 39. i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 68
#     body: 42
# 40. |x_{1}〉, |x_{2}〉, ..., |x_{n}〉
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 63
#     end_index: 64
# 41. X
#     core type: Variable
#     sub-expressions:
# 42. {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 44
#     condition: 45
# 43. _a -> |x_{_a}〉
#     core type: Lambda
#     parameter: 65
#     body: 46
# 44. |x_{i}〉 . 〈x_{i}|
#     core type: Operation
#     operator: 47
#     operands: 48
# 45. i in {1 .. n}
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. |x_{_a}〉
#     core type: Operation
#     operator: 56
#     operand: 55
# 47. .
#     core type: Literal
#     sub-expressions:
# 48. (|x_{i}〉, 〈x_{i}|)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 68, 54
# 51. (x_{_a})
#     core type: ExprTuple
#     sub-expressions: 55
# 52. |x_{i}〉
#     core type: Operation
#     operator: 56
#     operand: 62
# 53. 〈x_{i}|
#     core type: Operation
#     operator: 57
#     operand: 62
# 54. {1 .. n}
#     core type: Operation
#     operator: 59
#     operands: 60
# 55. x_{_a}
#     core type: IndexedVar
# variable: 66
# index: 65
# 56. KET
#     core type: Literal
#     sub-expressions:
# 57. BRA
#     core type: Literal
#     sub-expressions:
# 58. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 62
# 59. Interval
#     core type: Literal
#     sub-expressions:
# 60. (1, n)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 61. (_a)
#     core type: ExprTuple
#     sub-expressions: 65
# 62. x_{i}
#     core type: IndexedVar
# variable: 66
# index: 68
# 63. 1
#     core type: Literal
#     sub-expressions:
# 64. n
#     core type: Variable
#     sub-expressions:
# 65. _a
#     core type: Variable
#     sub-expressions:
# 66. x
#     core type: Variable
#     sub-expressions:
# 67. (i)
#     core type: ExprTuple
#     sub-expressions: 68
# 68. i
#     core type: Variable
#     sub-expressions:
