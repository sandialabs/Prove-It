# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b, l, n
from proveit.core_expr_types import A_1_to_l, C_1_to_n
from proveit.logic import Equals, Forall, InClass
from proveit.numbers import Complex, Natural
from proveit.physics.quantum import Qmult, QmultCodomain

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [l, n], instance_expr = Forall(instance_param_or_params = [b], instance_expr = Forall(instance_param_or_params = [A_1_to_l, C_1_to_n], instance_expr = Equals(Qmult(A_1_to_l, b, C_1_to_n), Qmult(b, A_1_to_l, C_1_to_n)).with_wrapping_at(2), condition = InClass(Qmult(A_1_to_l, C_1_to_n), QmultCodomain)), domain = Complex), domain = Natural)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{l, n \in \mathbb{N}}~\left[\forall_{b \in \mathbb{C}}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{l}, C_{1}, C_{2}, \ldots, C_{n}~|~\left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) \underset{{\scriptscriptstyle c}}{\in} \mathcal{Q^*}}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l} \thinspace b\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) =  \\ \left(b\thinspace A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) \end{array} \end{array}\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{l, n in Natural} [forall_{b in Complex} [forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))]]
#    core type: Operation
#    operator: 20
#    operand: 2
# 1. ((l, n) -> {forall_{b in Complex} [forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))] if l in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (l, n) -> {forall_{b in Complex} [forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))] if l in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (l, n)
#    core type: ExprTuple
#    sub-expressions: 45, 48
# 4. {forall_{b in Complex} [forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))] if l in Natural ,  n in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{b in Complex} [forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))]
#    core type: Operation
#    operator: 20
#    operand: 10
# 6. (l in Natural) and (n in Natural)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (b -> {forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})) if b in Complex.)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (l in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. b -> {forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})) if b in Complex.
#     core type: Lambda
#     parameter: 41
#     body: 14
# 11. l in Natural
#     core type: Operation
#     operator: 22
#     operands: 15
# 12. n in Natural
#     core type: Operation
#     operator: 22
#     operands: 16
# 13. (b)
#     core type: ExprTuple
#     sub-expressions: 41
# 14. {forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})) if b in Complex.
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 45, 19
# 16. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 48, 19
# 17. forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))
#     core type: Operation
#     operator: 20
#     operand: 24
# 18. b in Complex
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. Natural
#     core type: Literal
#     sub-expressions:
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n}) -> {(A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) if (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*.)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 41, 25
# 24. (A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n}) -> {(A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) if (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*.
#     core type: Lambda
#     parameters: 40\n    body: 26
# 25. Complex
#     core type: Literal
#     sub-expressions:
# 26. {(A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) if (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*.
#     core type: Conditional
#     value: 27
#     condition: 28
# 27. (A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. =
#     core type: Literal
#     sub-expressions:
# 30. (A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}, b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. in_c
#     core type: Literal
#     sub-expressions:
# 32. (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}, Q*)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. A_{1} .  A_{2} .  ... .  A_{l} . b. C_{1} .  C_{2} .  ... .  C_{n}
#     core type: Operation
#     operator: 39
#     operands: 37
# 34. b. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}
#     core type: Operation
#     operator: 39
#     operands: 38
# 35. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. Q*
#     core type: Literal
#     sub-expressions:
# 37. (A_{1}, A_{2}, ..., A_{l}, b,C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 42, 41, 43
# 38. (b,A_{1}, A_{2}, ..., A_{l},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 41, 42, 43
# 39. .
#     core type: Literal
#     sub-expressions:
# 40. (A_{1}, A_{2}, ..., A_{l},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 41. b
#     core type: Variable
#     sub-expressions:
# 42. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 47
#     end_index: 45
# 43. C_{1}, C_{2}, ..., C_{n}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 47
#     end_index: 48
# 44. _a -> A_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 49
# 45. l
#     core type: Variable
#     sub-expressions:
# 46. _a -> C_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 50
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. n
#     core type: Variable
#     sub-expressions:
# 49. A_{_a}
#     core type: IndexedVar
# variable: 51
# index: 54
# 50. C_{_a}
#     core type: IndexedVar
# variable: 52
# index: 54
# 51. A
#     core type: Variable
#     sub-expressions:
# 52. C
#     core type: Variable
#     sub-expressions:
# 53. (_a)
#     core type: ExprTuple
#     sub-expressions: 54
# 54. _a
#     core type: Variable
#     sub-expressions:
