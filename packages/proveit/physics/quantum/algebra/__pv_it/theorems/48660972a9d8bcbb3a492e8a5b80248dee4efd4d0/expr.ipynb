# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprTuple, Lambda, V, W, i, j, m, n
from proveit.core_expr_types import v_1_to_m, v_i, w_1_to_n, w_j
from proveit.linear_algebra import OrthoNormBases, VecSum
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_m_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([v_1_to_m], Conditional(Forall(instance_param_or_params = [w_1_to_n], instance_expr = Equals(A, VecSum(index_or_indices = [i], summand = VecSum(index_or_indices = [j], summand = Qmult(Bra(w_j), A, Ket(v_i), Ket(w_j), Bra(v_i)), domain = Interval(one, n)), domain = Interval(one, m))), condition = InSet(w_1_to_n_kets, OrthoNormBases(W))).with_wrapping(), InSet(v_1_to_m_kets, OrthoNormBases(V)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(v_{1}, v_{2}, \ldots, v_{m}\right) \mapsto \left\{\begin{array}{l}\forall_{w_{1}, w_{2}, \ldots, w_{n}~|~\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(W\right)}~\\
# \left(A = \left(\sum_{i=1}^{m} \left(\sum_{j=1}^{n} \left(\langle w_{j} \rvert \thinspace A \thinspace \lvert v_{i} \rangle \thinspace \lvert w_{j} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array} \textrm{ if } \left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{m} \rangle\right\} \in \textrm{O.N.Bases}\left(V\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((v_{1}, v_{2}, ..., v_{m}) -> {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (v_{1}, v_{2}, ..., v_{m}) -> {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (v_{1}, v_{2}, ..., v_{m})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).
#    core type: Conditional
#    value: 5
#    condition: 6
# 4. v_{1}, v_{2}, ..., v_{m}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 79
#    end_index: 59
# 5. forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))
#    core type: Operation
#    operator: 8
#    operand: 11
# 6. {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)
#    core type: Operation
#    operator: 63
#    operands: 10
# 7. _a -> v_{_a}
#    core type: Lambda
#    parameter: 60
#    body: 41
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. ((w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. ({|v_{1}〉, |v_{2}〉, ..., |v_{m}〉}, O.N.Bases(V))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. (w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#     core type: Lambda
#     parameters: 14\n    body: 15
# 12. {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉}
#     core type: Operation
#     operator: 33
#     operands: 16
# 13. O.N.Bases(V)
#     core type: Operation
#     operator: 35
#     operand: 22
# 14. (w_{1}, w_{2}, ..., w_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 15. {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#     core type: Conditional
#     value: 19
#     condition: 20
# 16. (|v_{1}〉, |v_{2}〉, ..., |v_{m}〉)
#     core type: ExprTuple
#     sub-expressions: 21
# 17. (V)
#     core type: ExprTuple
#     sub-expressions: 22
# 18. w_{1}, w_{2}, ..., w_{n}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 79
#     end_index: 80
# 19. A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)
#     core type: Operation
#     operator: 63
#     operands: 26
# 21. |v_{1}〉, |v_{2}〉, ..., |v_{m}〉
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 79
#     end_index: 59
# 22. V
#     core type: Variable
#     sub-expressions:
# 23. _a -> w_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 53
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (A, Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 66, 28
# 26. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}, O.N.Bases(W))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 60
#     body: 31
# 28. Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 47
#     operand: 38
# 29. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. O.N.Bases(W)
#     core type: Operation
#     operator: 35
#     operand: 40
# 31. |v_{_a}〉
#     core type: Operation
#     operator: 71
#     operand: 41
# 32. (i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 38
# 33. Set
#     core type: Literal
#     sub-expressions:
# 34. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 39
# 35. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 36. (W)
#     core type: ExprTuple
#     sub-expressions: 40
# 37. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 41
# 38. i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Lambda
#     parameter: 86
#     body: 42
# 39. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 79
#     end_index: 80
# 40. W
#     core type: Variable
#     sub-expressions:
# 41. v_{_a}
#     core type: IndexedVar
# variable: 83
# index: 60
# 42. {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Conditional
#     value: 44
#     condition: 45
# 43. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 60
#     body: 46
# 44. Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 47
#     operand: 51
# 45. i in {1 .. m}
#     core type: Operation
#     operator: 63
#     operands: 49
# 46. |w_{_a}〉
#     core type: Operation
#     operator: 71
#     operand: 53
# 47. Sum
#     core type: Literal
#     sub-expressions:
# 48. (j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 51
# 49. (i, {1 .. m})
#     core type: ExprTuple
#     sub-expressions: 86, 52
# 50. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 53
# 51. j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Lambda
#     parameter: 85
#     body: 54
# 52. {1 .. m}
#     core type: Operation
#     operator: 75
#     operands: 55
# 53. w_{_a}
#     core type: IndexedVar
# variable: 81
# index: 60
# 54. {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Conditional
#     value: 57
#     condition: 58
# 55. (1, m)
#     core type: ExprTuple
#     sub-expressions: 79, 59
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 57. 〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 61
#     operands: 62
# 58. j in {1 .. n}
#     core type: Operation
#     operator: 63
#     operands: 64
# 59. m
#     core type: Variable
#     sub-expressions:
# 60. _a
#     core type: Variable
#     sub-expressions:
# 61. .
#     core type: Literal
#     sub-expressions:
# 62. (〈w_{j}|, A, |v_{i}〉, |w_{j}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 65, 66, 67, 68, 69
# 63. in
#     core type: Literal
#     sub-expressions:
# 64. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 85, 70
# 65. 〈w_{j}|
#     core type: Operation
#     operator: 73
#     operand: 77
# 66. A
#     core type: Variable
#     sub-expressions:
# 67. |v_{i}〉
#     core type: Operation
#     operator: 71
#     operand: 78
# 68. |w_{j}〉
#     core type: Operation
#     operator: 71
#     operand: 77
# 69. 〈v_{i}|
#     core type: Operation
#     operator: 73
#     operand: 78
# 70. {1 .. n}
#     core type: Operation
#     operator: 75
#     operands: 76
# 71. KET
#     core type: Literal
#     sub-expressions:
# 72. (w_{j})
#     core type: ExprTuple
#     sub-expressions: 77
# 73. BRA
#     core type: Literal
#     sub-expressions:
# 74. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 78
# 75. Interval
#     core type: Literal
#     sub-expressions:
# 76. (1, n)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 77. w_{j}
#     core type: IndexedVar
# variable: 81
# index: 85
# 78. v_{i}
#     core type: IndexedVar
# variable: 83
# index: 86
# 79. 1
#     core type: Literal
#     sub-expressions:
# 80. n
#     core type: Variable
#     sub-expressions:
# 81. w
#     core type: Variable
#     sub-expressions:
# 82. (j)
#     core type: ExprTuple
#     sub-expressions: 85
# 83. v
#     core type: Variable
#     sub-expressions:
# 84. (i)
#     core type: ExprTuple
#     sub-expressions: 86
# 85. j
#     core type: Variable
#     sub-expressions:
# 86. i
#     core type: Variable
#     sub-expressions:
