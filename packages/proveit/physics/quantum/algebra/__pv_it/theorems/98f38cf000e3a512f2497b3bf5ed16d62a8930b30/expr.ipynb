# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Function, IndexedVar, Lambda, Variable, a, f, i, n
from proveit.core_expr_types import a_1_to_n, a_i, v_i
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import And, Equals, Forall, Functions, InSet
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [i]
sub_expr3 = Interval(one, n)
sub_expr4 = Qmult(Ket(v_i), Bra(v_i))
expr = Lambda([a_1_to_n], Conditional(Forall(instance_param_or_params = [f], instance_expr = Equals(Function(f, [VecSum(index_or_indices = sub_expr2, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)]), VecSum(index_or_indices = sub_expr2, summand = ScalarMult(Function(f, [a_i]), sub_expr4), domain = sub_expr3)), domain = Functions(Complex, Complex)), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, n))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(a_{1}, a_{2}, \ldots, a_{n}\right) \mapsto \left\{\forall_{f \in \left[\mathbb{C} \rightarrow \mathbb{C}\right]}~\left(f\left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right) = \left(\sum_{i=1}^{n} \left(f\left(a_{i}\right) \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \textrm{ if } \left(a_{1} \in \mathbb{C}\right) \land  \left(a_{2} \in \mathbb{C}\right) \land  \ldots \land  \left(a_{n} \in \mathbb{C}\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (a_{1}, a_{2}, ..., a_{n}) -> {forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a_{1}, a_{2}, ..., a_{n})
#    core type: ExprTuple
#    sub-expressions: 3
# 2. {forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#    core type: Conditional
#    value: 4
#    condition: 5
# 3. a_{1}, a_{2}, ..., a_{n}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 62
#    end_index: 63
# 4. forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))
#    core type: Operation
#    operator: 7
#    operand: 11
# 5. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. _a -> a_{_a}
#    core type: Lambda
#    parameter: 35
#    body: 26
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. (f -> {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 12
# 11. f -> {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].
#     core type: Lambda
#     parameter: 50
#     body: 14
# 12. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 62
#     end_index: 63
# 13. (f)
#     core type: ExprTuple
#     sub-expressions: 50
# 14. {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].
#     core type: Conditional
#     value: 16
#     condition: 17
# 15. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 35
#     body: 18
# 16. f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. f in [Complex -> Complex]
#     core type: Operation
#     operator: 48
#     operands: 21
# 18. a_{_a} in Complex
#     core type: Operation
#     operator: 48
#     operands: 22
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. (f, [Complex -> Complex])
#     core type: ExprTuple
#     sub-expressions: 50, 25
# 22. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 26, 34
# 23. f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 50
#     operand: 32
# 24. Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 36
#     operand: 33
# 25. [Complex -> Complex]
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. a_{_a}
#     core type: IndexedVar
# variable: 59
# index: 35
# 27. (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 32
# 28. (i -> {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 33
# 29. Functions
#     core type: Literal
#     sub-expressions:
# 30. (Complex, Complex)
#     core type: ExprTuple
#     sub-expressions: 34, 34
# 31. (_a)
#     core type: ExprTuple
#     sub-expressions: 35
# 32. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 36
#     operand: 39
# 33. i -> {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 70
#     body: 38
# 34. Complex
#     core type: Literal
#     sub-expressions:
# 35. _a
#     core type: Variable
#     sub-expressions:
# 36. Sum
#     core type: Literal
#     sub-expressions:
# 37. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 39
# 38. {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 40
#     condition: 44
# 39. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 70
#     body: 41
# 40. f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 46
#     operands: 42
# 41. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 43
#     condition: 44
# 42. (f(a_{i}), |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 45, 52
# 43. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 46
#     operands: 47
# 44. i in {1 .. n}
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. f(a_{i})
#     core type: Operation
#     operator: 50
#     operand: 54
# 46. *
#     core type: Literal
#     sub-expressions:
# 47. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 54, 52
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 70, 53
# 50. f
#     core type: Variable
#     sub-expressions:
# 51. (a_{i})
#     core type: ExprTuple
#     sub-expressions: 54
# 52. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 55
#     operands: 56
# 53. {1 .. n}
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. a_{i}
#     core type: IndexedVar
# variable: 59
# index: 70
# 55. .
#     core type: Literal
#     sub-expressions:
# 56. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 57. Interval
#     core type: Literal
#     sub-expressions:
# 58. (1, n)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 59. a
#     core type: Variable
#     sub-expressions:
# 60. |v_{i}〉
#     core type: Operation
#     operator: 64
#     operand: 67
# 61. 〈v_{i}|
#     core type: Operation
#     operator: 65
#     operand: 67
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. n
#     core type: Variable
#     sub-expressions:
# 64. KET
#     core type: Literal
#     sub-expressions:
# 65. BRA
#     core type: Literal
#     sub-expressions:
# 66. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 67
# 67. v_{i}
#     core type: IndexedVar
# variable: 68
# index: 70
# 68. v
#     core type: Variable
#     sub-expressions:
# 69. (i)
#     core type: ExprTuple
#     sub-expressions: 70
# 70. i
#     core type: Variable
#     sub-expressions:
