# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, W, i, j, m, n
from proveit.core_expr_types import v_i, w_j
from proveit.linear_algebra import OrthoNormBases, VecSum
from proveit.logic import Equals, InSet
from proveit.numbers import Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import w_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(A, VecSum(index_or_indices = [i], summand = VecSum(index_or_indices = [j], summand = Qmult(Bra(w_j), A, Ket(v_i), Ket(w_j), Bra(v_i)), domain = Interval(one, n)), domain = Interval(one, m))), InSet(w_1_to_n_kets, OrthoNormBases(W)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{A = \left(\sum_{i=1}^{m} \left(\sum_{j=1}^{n} \left(\langle w_{j} \rvert \thinspace A \thinspace \lvert v_{i} \rangle \thinspace \lvert w_{j} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right) \textrm{ if } \left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(W\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)
#    core type: Operation
#    operator: 38
#    operands: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (A, Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#    core type: ExprTuple
#    sub-expressions: 41, 6
# 5. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}, O.N.Bases(W))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))
#    core type: Operation
#    operator: 22
#    operand: 14
# 7. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. O.N.Bases(W)
#    core type: Operation
#    operator: 12
#    operand: 16
# 9. (i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.)
#    core type: ExprTuple
#    sub-expressions: 14
# 10. Set
#     core type: Literal
#     sub-expressions:
# 11. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 13. (W)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Lambda
#     parameter: 61
#     body: 17
# 15. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 54
#     end_index: 55
# 16. W
#     core type: Variable
#     sub-expressions:
# 17. {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Conditional
#     value: 19
#     condition: 20
# 18. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 35
#     body: 21
# 19. Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 22
#     operand: 26
# 20. i in {1 .. m}
#     core type: Operation
#     operator: 38
#     operands: 24
# 21. |w_{_a}〉
#     core type: Operation
#     operator: 46
#     operand: 28
# 22. Sum
#     core type: Literal
#     sub-expressions:
# 23. (j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 26
# 24. (i, {1 .. m})
#     core type: ExprTuple
#     sub-expressions: 61, 27
# 25. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 28
# 26. j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Lambda
#     parameter: 60
#     body: 29
# 27. {1 .. m}
#     core type: Operation
#     operator: 50
#     operands: 30
# 28. w_{_a}
#     core type: IndexedVar
# variable: 56
# index: 35
# 29. {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Conditional
#     value: 32
#     condition: 33
# 30. (1, m)
#     core type: ExprTuple
#     sub-expressions: 54, 34
# 31. (_a)
#     core type: ExprTuple
#     sub-expressions: 35
# 32. 〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. j in {1 .. n}
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. m
#     core type: Variable
#     sub-expressions:
# 35. _a
#     core type: Variable
#     sub-expressions:
# 36. .
#     core type: Literal
#     sub-expressions:
# 37. (〈w_{j}|, A, |v_{i}〉, |w_{j}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 40, 41, 42, 43, 44
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 60, 45
# 40. 〈w_{j}|
#     core type: Operation
#     operator: 48
#     operand: 52
# 41. A
#     core type: Variable
#     sub-expressions:
# 42. |v_{i}〉
#     core type: Operation
#     operator: 46
#     operand: 53
# 43. |w_{j}〉
#     core type: Operation
#     operator: 46
#     operand: 52
# 44. 〈v_{i}|
#     core type: Operation
#     operator: 48
#     operand: 53
# 45. {1 .. n}
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. KET
#     core type: Literal
#     sub-expressions:
# 47. (w_{j})
#     core type: ExprTuple
#     sub-expressions: 52
# 48. BRA
#     core type: Literal
#     sub-expressions:
# 49. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 53
# 50. Interval
#     core type: Literal
#     sub-expressions:
# 51. (1, n)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. w_{j}
#     core type: IndexedVar
# variable: 56
# index: 60
# 53. v_{i}
#     core type: IndexedVar
# variable: 58
# index: 61
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. n
#     core type: Variable
#     sub-expressions:
# 56. w
#     core type: Variable
#     sub-expressions:
# 57. (j)
#     core type: ExprTuple
#     sub-expressions: 60
# 58. v
#     core type: Variable
#     sub-expressions:
# 59. (i)
#     core type: ExprTuple
#     sub-expressions: 61
# 60. j
#     core type: Variable
#     sub-expressions:
# 61. i
#     core type: Variable
#     sub-expressions:
