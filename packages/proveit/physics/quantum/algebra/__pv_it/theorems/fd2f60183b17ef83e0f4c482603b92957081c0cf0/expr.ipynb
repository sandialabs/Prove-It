# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, V, W, i, j, m, n
from proveit.core_expr_types import v_1_to_m, v_i, w_1_to_n, w_j
from proveit.linear_algebra import HilbertSpaces, LinMap, OrthoNormBases, VecSum
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_m_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [V, W], instance_expr = Forall(instance_param_or_params = [A], instance_expr = Forall(instance_param_or_params = [m, n], instance_expr = Forall(instance_param_or_params = [v_1_to_m], instance_expr = Forall(instance_param_or_params = [w_1_to_n], instance_expr = Equals(A, VecSum(index_or_indices = [i], summand = VecSum(index_or_indices = [j], summand = Qmult(Bra(w_j), A, Ket(v_i), Ket(w_j), Bra(v_i)), domain = Interval(one, n)), domain = Interval(one, m))), condition = InSet(w_1_to_n_kets, OrthoNormBases(W))).with_wrapping(), condition = InSet(v_1_to_m_kets, OrthoNormBases(V))).with_wrapping(), domain = NaturalPos), domain = LinMap(V, W)), domain = HilbertSpaces)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{V, W \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}}~\left[\forall_{A \in \mathcal{L}\left(V, W\right)}~\left[\forall_{m, n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{v_{1}, v_{2}, \ldots, v_{m}~|~\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{m} \rangle\right\} \in \textrm{O.N.Bases}\left(V\right)}~\\
# \left[\begin{array}{l}\forall_{w_{1}, w_{2}, \ldots, w_{n}~|~\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(W\right)}~\\
# \left(A = \left(\sum_{i=1}^{m} \left(\sum_{j=1}^{n} \left(\langle w_{j} \rvert \thinspace A \thinspace \lvert v_{i} \rangle \thinspace \lvert w_{j} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}\right]\end{array}\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{V, W in_c HilbertSpaces} [forall_{A in LINMAP(V, W)} [forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]]]]
#    core type: Operation
#    operator: 44
#    operand: 2
# 1. ((V, W) -> {forall_{A in LINMAP(V, W)} [forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]]] if V in_c HilbertSpaces ,  W in_c HilbertSpaces.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (V, W) -> {forall_{A in LINMAP(V, W)} [forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]]] if V in_c HilbertSpaces ,  W in_c HilbertSpaces.
#    core type: Lambda
#    parameters: 26\n   body: 3
# 3. {forall_{A in LINMAP(V, W)} [forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]]] if V in_c HilbertSpaces ,  W in_c HilbertSpaces.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A in LINMAP(V, W)} [forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]]]
#    core type: Operation
#    operator: 44
#    operand: 8
# 5. (V in_c HilbertSpaces) and (W in_c HilbertSpaces)
#    core type: Operation
#    operator: 30
#    operands: 7
# 6. (A -> {forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]] if A in LINMAP(V, W).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (V in_c HilbertSpaces, W in_c HilbertSpaces)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. A -> {forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]] if A in LINMAP(V, W).
#    core type: Lambda
#    parameter: 102
#    body: 12
# 9. V in_c HilbertSpaces
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. W in_c HilbertSpaces
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (A)
#     core type: ExprTuple
#     sub-expressions: 102
# 12. {forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]] if A in LINMAP(V, W).
#     core type: Conditional
#     value: 16
#     condition: 17
# 13. (V, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 58, 18
# 14. in_c
#     core type: Literal
#     sub-expressions:
# 15. (W, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 76, 18
# 16. forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]]
#     core type: Operation
#     operator: 44
#     operand: 21
# 17. A in LINMAP(V, W)
#     core type: Operation
#     operator: 99
#     operands: 20
# 18. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 19. ((m, n) -> {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. (A, LINMAP(V, W))
#     core type: ExprTuple
#     sub-expressions: 102, 22
# 21. (m, n) -> {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.
#     core type: Lambda
#     parameters: 23\n    body: 24
# 22. LINMAP(V, W)
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. (m, n)
#     core type: ExprTuple
#     sub-expressions: 95, 116
# 24. {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.
#     core type: Conditional
#     value: 27
#     condition: 28
# 25. LINMAP
#     core type: Literal
#     sub-expressions:
# 26. (V, W)
#     core type: ExprTuple
#     sub-expressions: 58, 76
# 27. forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]
#     core type: Operation
#     operator: 44
#     operand: 32
# 28. (m in NaturalPos) and (n in NaturalPos)
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. ((v_{1}, v_{2}, ..., v_{m}) -> {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).)
#     core type: ExprTuple
#     sub-expressions: 32
# 30. and
#     core type: Literal
#     sub-expressions:
# 31. (m in NaturalPos, n in NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. (v_{1}, v_{2}, ..., v_{m}) -> {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).
#     core type: Lambda
#     parameters: 35\n    body: 36
# 33. m in NaturalPos
#     core type: Operation
#     operator: 99
#     operands: 37
# 34. n in NaturalPos
#     core type: Operation
#     operator: 99
#     operands: 38
# 35. (v_{1}, v_{2}, ..., v_{m})
#     core type: ExprTuple
#     sub-expressions: 39
# 36. {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).
#     core type: Conditional
#     value: 40
#     condition: 41
# 37. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 95, 42
# 38. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 116, 42
# 39. v_{1}, v_{2}, ..., v_{m}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 115
#     end_index: 95
# 40. forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 44
#     operand: 47
# 41. {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)
#     core type: Operation
#     operator: 99
#     operands: 46
# 42. NaturalPos
#     core type: Literal
#     sub-expressions:
# 43. _a -> v_{_a}
#     core type: Lambda
#     parameter: 96
#     body: 77
# 44. forall
#     core type: Literal
#     sub-expressions:
# 45. ((w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).)
#     core type: ExprTuple
#     sub-expressions: 47
# 46. ({|v_{1}〉, |v_{2}〉, ..., |v_{m}〉}, O.N.Bases(V))
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 47. (w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#     core type: Lambda
#     parameters: 50\n    body: 51
# 48. {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉}
#     core type: Operation
#     operator: 69
#     operands: 52
# 49. O.N.Bases(V)
#     core type: Operation
#     operator: 71
#     operand: 58
# 50. (w_{1}, w_{2}, ..., w_{n})
#     core type: ExprTuple
#     sub-expressions: 54
# 51. {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#     core type: Conditional
#     value: 55
#     condition: 56
# 52. (|v_{1}〉, |v_{2}〉, ..., |v_{m}〉)
#     core type: ExprTuple
#     sub-expressions: 57
# 53. (V)
#     core type: ExprTuple
#     sub-expressions: 58
# 54. w_{1}, w_{2}, ..., w_{n}
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 115
#     end_index: 116
# 55. A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 60
#     operands: 61
# 56. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)
#     core type: Operation
#     operator: 99
#     operands: 62
# 57. |v_{1}〉, |v_{2}〉, ..., |v_{m}〉
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 115
#     end_index: 95
# 58. V
#     core type: Variable
#     sub-expressions:
# 59. _a -> w_{_a}
#     core type: Lambda
#     parameter: 96
#     body: 89
# 60. =
#     core type: Literal
#     sub-expressions:
# 61. (A, Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 102, 64
# 62. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}, O.N.Bases(W))
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 63. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 96
#     body: 67
# 64. Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 83
#     operand: 74
# 65. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 69
#     operands: 70
# 66. O.N.Bases(W)
#     core type: Operation
#     operator: 71
#     operand: 76
# 67. |v_{_a}〉
#     core type: Operation
#     operator: 107
#     operand: 77
# 68. (i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 74
# 69. Set
#     core type: Literal
#     sub-expressions:
# 70. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 75
# 71. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 72. (W)
#     core type: ExprTuple
#     sub-expressions: 76
# 73. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 77
# 74. i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Lambda
#     parameter: 122
#     body: 78
# 75. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 79
#     start_index: 115
#     end_index: 116
# 76. W
#     core type: Variable
#     sub-expressions:
# 77. v_{_a}
#     core type: IndexedVar
# variable: 119
# index: 96
# 78. {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Conditional
#     value: 80
#     condition: 81
# 79. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 96
#     body: 82
# 80. Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 83
#     operand: 87
# 81. i in {1 .. m}
#     core type: Operation
#     operator: 99
#     operands: 85
# 82. |w_{_a}〉
#     core type: Operation
#     operator: 107
#     operand: 89
# 83. Sum
#     core type: Literal
#     sub-expressions:
# 84. (j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 87
# 85. (i, {1 .. m})
#     core type: ExprTuple
#     sub-expressions: 122, 88
# 86. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 89
# 87. j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Lambda
#     parameter: 121
#     body: 90
# 88. {1 .. m}
#     core type: Operation
#     operator: 111
#     operands: 91
# 89. w_{_a}
#     core type: IndexedVar
# variable: 117
# index: 96
# 90. {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Conditional
#     value: 93
#     condition: 94
# 91. (1, m)
#     core type: ExprTuple
#     sub-expressions: 115, 95
# 92. (_a)
#     core type: ExprTuple
#     sub-expressions: 96
# 93. 〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 97
#     operands: 98
# 94. j in {1 .. n}
#     core type: Operation
#     operator: 99
#     operands: 100
# 95. m
#     core type: Variable
#     sub-expressions:
# 96. _a
#     core type: Variable
#     sub-expressions:
# 97. .
#     core type: Literal
#     sub-expressions:
# 98. (〈w_{j}|, A, |v_{i}〉, |w_{j}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 101, 102, 103, 104, 105
# 99. in
#     core type: Literal
#     sub-expressions:
# 100. (j, {1 .. n})
#      core type: ExprTuple
#      sub-expressions: 121, 106
# 101. 〈w_{j}|
#      core type: Operation
#      operator: 109
#      operand: 113
# 102. A
#      core type: Variable
#      sub-expressions:
# 103. |v_{i}〉
#      core type: Operation
#      operator: 107
#      operand: 114
# 104. |w_{j}〉
#      core type: Operation
#      operator: 107
#      operand: 113
# 105. 〈v_{i}|
#      core type: Operation
#      operator: 109
#      operand: 114
# 106. {1 .. n}
#      core type: Operation
#      operator: 111
#      operands: 112
# 107. KET
#      core type: Literal
#      sub-expressions:
# 108. (w_{j})
#      core type: ExprTuple
#      sub-expressions: 113
# 109. BRA
#      core type: Literal
#      sub-expressions:
# 110. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 114
# 111. Interval
#      core type: Literal
#      sub-expressions:
# 112. (1, n)
#      core type: ExprTuple
#      sub-expressions: 115, 116
# 113. w_{j}
#      core type: IndexedVar
# variable: 117
# index: 121
# 114. v_{i}
#      core type: IndexedVar
# variable: 119
# index: 122
# 115. 1
#      core type: Literal
#      sub-expressions:
# 116. n
#      core type: Variable
#      sub-expressions:
# 117. w
#      core type: Variable
#      sub-expressions:
# 118. (j)
#      core type: ExprTuple
#      sub-expressions: 121
# 119. v
#      core type: Variable
#      sub-expressions:
# 120. (i)
#      core type: ExprTuple
#      sub-expressions: 122
# 121. j
#      core type: Variable
#      sub-expressions:
# 122. i
#      core type: Variable
#      sub-expressions:
