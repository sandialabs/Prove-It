# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, j, l, n
from proveit.core_expr_types import A_1_to_l, C_1_to_n, b_1_to_j
from proveit.logic import And, Equals, Forall, InClass, InSet
from proveit.numbers import Complex, Natural
from proveit.physics.quantum import Qmult, QmultCodomain

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([j, l, n], Conditional(Forall(instance_param_or_params = [b_1_to_j], instance_expr = Forall(instance_param_or_params = [A_1_to_l, C_1_to_n], instance_expr = Equals(Qmult(A_1_to_l, b_1_to_j, C_1_to_n), Qmult(b_1_to_j, A_1_to_l, C_1_to_n)).with_wrapping_at(2), condition = InClass(Qmult(A_1_to_l, C_1_to_n), QmultCodomain)), domain = Complex), And(InSet(j, Natural), InSet(l, Natural), InSet(n, Natural)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(j, l, n\right) \mapsto \left\{\forall_{b_{1}, b_{2}, \ldots, b_{j} \in \mathbb{C}}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{l}, C_{1}, C_{2}, \ldots, C_{n}~|~\left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) \underset{{\scriptscriptstyle c}}{\in} \mathcal{Q^*}}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\thinspace b_{1} \thinspace  b_{2} \thinspace  \ldots \thinspace  b_{j}\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) =  \\ \left(b_{1} \thinspace  b_{2} \thinspace  \ldots \thinspace  b_{j}\thinspace A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) \end{array} \end{array}\right)\right] \textrm{ if } j \in \mathbb{N} ,  l \in \mathbb{N} ,  n \in \mathbb{N}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((j, l, n) -> {forall_{b_{1}, b_{2}, ..., b_{j} in Complex} [forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))] if j in Natural ,  l in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (j, l, n) -> {forall_{b_{1}, b_{2}, ..., b_{j} in Complex} [forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))] if j in Natural ,  l in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (j, l, n)
#    core type: ExprTuple
#    sub-expressions: 50, 52, 55
# 3. {forall_{b_{1}, b_{2}, ..., b_{j} in Complex} [forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))] if j in Natural ,  l in Natural ,  n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{b_{1}, b_{2}, ..., b_{j} in Complex} [forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))]
#    core type: Operation
#    operator: 20
#    operand: 8
# 5. (j in Natural) and (l in Natural) and (n in Natural)
#    core type: Operation
#    operator: 22
#    operands: 7
# 6. ((b_{1}, b_{2}, ..., b_{j}) -> {forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})) if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (j in Natural, l in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 8. (b_{1}, b_{2}, ..., b_{j}) -> {forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})) if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).
#    core type: Lambda
#    parameters: 12\n   body: 13
# 9. j in Natural
#    core type: Operation
#    operator: 35
#    operands: 14
# 10. l in Natural
#     core type: Operation
#     operator: 35
#     operands: 15
# 11. n in Natural
#     core type: Operation
#     operator: 35
#     operands: 16
# 12. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 46
# 13. {forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})) if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).
#     core type: Conditional
#     value: 17
#     condition: 18
# 14. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 50, 19
# 15. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 52, 19
# 16. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 55, 19
# 17. forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))
#     core type: Operation
#     operator: 20
#     operand: 24
# 18. (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex)
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. Natural
#     core type: Literal
#     sub-expressions:
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. ((A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n}) -> {(A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) if (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*.)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. ((b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex))
#     core type: ExprTuple
#     sub-expressions: 25
# 24. (A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n}) -> {(A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) if (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*.
#     core type: Lambda
#     parameters: 45\n    body: 26
# 25. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 54
#     end_index: 50
# 26. {(A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) if (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*.
#     core type: Conditional
#     value: 28
#     condition: 29
# 27. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 63
#     body: 30
# 28. (A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. b_{_a} in Complex
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}, b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 33. in_c
#     core type: Literal
#     sub-expressions:
# 34. (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}, Q*)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 56, 41
# 37. A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}
#     core type: Operation
#     operator: 44
#     operands: 42
# 38. b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}
#     core type: Operation
#     operator: 44
#     operands: 43
# 39. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. Q*
#     core type: Literal
#     sub-expressions:
# 41. Complex
#     core type: Literal
#     sub-expressions:
# 42. (A_{1}, A_{2}, ..., A_{l},b_{1}, b_{2}, ..., b_{j},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 47, 46, 48
# 43. (b_{1}, b_{2}, ..., b_{j},A_{1}, A_{2}, ..., A_{l},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 46, 47, 48
# 44. .
#     core type: Literal
#     sub-expressions:
# 45. (A_{1}, A_{2}, ..., A_{l},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 46. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 54
#     end_index: 50
# 47. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 54
#     end_index: 52
# 48. C_{1}, C_{2}, ..., C_{n}
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 54
#     end_index: 55
# 49. _a -> b_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 56
# 50. j
#     core type: Variable
#     sub-expressions:
# 51. _a -> A_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 57
# 52. l
#     core type: Variable
#     sub-expressions:
# 53. _a -> C_{_a}
#     core type: Lambda
#     parameter: 63
#     body: 58
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. n
#     core type: Variable
#     sub-expressions:
# 56. b_{_a}
#     core type: IndexedVar
# variable: 59
# index: 63
# 57. A_{_a}
#     core type: IndexedVar
# variable: 60
# index: 63
# 58. C_{_a}
#     core type: IndexedVar
# variable: 61
# index: 63
# 59. b
#     core type: Variable
#     sub-expressions:
# 60. A
#     core type: Variable
#     sub-expressions:
# 61. C
#     core type: Variable
#     sub-expressions:
# 62. (_a)
#     core type: ExprTuple
#     sub-expressions: 63
# 63. _a
#     core type: Variable
#     sub-expressions:
