# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, v_1_to_n, v_i
from proveit.linear_algebra import Hspace, OrthoNormBases, ScalarMult, VecSum
from proveit.logic import Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, Qmult(Ket(v_i), Bra(v_i))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n_kets), OrthoNormBases(Hspace))).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]
#    core type: Operation
#    operator: 9
#    operand: 2
# 1. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (v_{1}, v_{2}, ..., v_{n})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#    core type: Conditional
#    value: 6
#    condition: 7
# 5. v_{1}, v_{2}, ..., v_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 67
#    end_index: 68
# 6. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))
#    core type: Operation
#    operator: 9
#    operand: 12
# 7. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)
#    core type: Operation
#    operator: 53
#    operands: 11
# 8. _a -> v_{_a}
#    core type: Lambda
#    parameter: 59
#    body: 50
# 9. exists
#    core type: Literal
#    sub-expressions:
# 10. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 15\n    body: 16
# 13. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 30
#     operand: 23
# 14. O.N.Bases(H)
#     core type: Operation
#     operator: 18
#     operand: 24
# 15. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 20
# 16. {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 21
#     condition: 22
# 17. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 23
# 18. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 19. (H)
#     core type: ExprTuple
#     sub-expressions: 24
# 20. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 67
#     end_index: 68
# 21. M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 28
#     operands: 29
# 23. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 30
#     operands: 31
# 24. H
#     core type: Variable
#     sub-expressions:
# 25. _a -> a_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 48
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. (M, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 28. and
#     core type: Literal
#     sub-expressions:
# 29. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 34
# 30. Set
#     core type: Literal
#     sub-expressions:
# 31. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 35
# 32. M
#     core type: Variable
#     sub-expressions:
# 33. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 36
#     operand: 40
# 34. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 67
#     end_index: 68
# 35. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 67
#     end_index: 68
# 36. Sum
#     core type: Literal
#     sub-expressions:
# 37. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 40
# 38. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 59
#     body: 41
# 39. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 59
#     body: 42
# 40. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 75
#     body: 43
# 41. a_{_a} in Complex
#     core type: Operation
#     operator: 53
#     operands: 44
# 42. |v_{_a}〉
#     core type: Operation
#     operator: 69
#     operand: 50
# 43. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 46
#     condition: 47
# 44. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 45. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 50
# 46. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 51
#     operands: 52
# 47. i in {1 .. n}
#     core type: Operation
#     operator: 53
#     operands: 54
# 48. a_{_a}
#     core type: IndexedVar
# variable: 60
# index: 59
# 49. Complex
#     core type: Literal
#     sub-expressions:
# 50. v_{_a}
#     core type: IndexedVar
# variable: 73
# index: 59
# 51. *
#     core type: Literal
#     sub-expressions:
# 52. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 53. in
#     core type: Literal
#     sub-expressions:
# 54. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 75, 58
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 56. a_{i}
#     core type: IndexedVar
# variable: 60
# index: 75
# 57. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 61
#     operands: 62
# 58. {1 .. n}
#     core type: Operation
#     operator: 63
#     operands: 64
# 59. _a
#     core type: Variable
#     sub-expressions:
# 60. a
#     core type: Variable
#     sub-expressions:
# 61. .
#     core type: Literal
#     sub-expressions:
# 62. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 63. Interval
#     core type: Literal
#     sub-expressions:
# 64. (1, n)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 65. |v_{i}〉
#     core type: Operation
#     operator: 69
#     operand: 72
# 66. 〈v_{i}|
#     core type: Operation
#     operator: 70
#     operand: 72
# 67. 1
#     core type: Literal
#     sub-expressions:
# 68. n
#     core type: Variable
#     sub-expressions:
# 69. KET
#     core type: Literal
#     sub-expressions:
# 70. BRA
#     core type: Literal
#     sub-expressions:
# 71. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 72
# 72. v_{i}
#     core type: IndexedVar
# variable: 73
# index: 75
# 73. v
#     core type: Variable
#     sub-expressions:
# 74. (i)
#     core type: ExprTuple
#     sub-expressions: 75
# 75. i
#     core type: Variable
#     sub-expressions:
