# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, v_1_to_n, v_i
from proveit.linear_algebra import Adj, Dim, HilbertSpaces, Hspace, LinMap, OrthoNormBases, ScalarMult, VecSum
from proveit.logic import Equals, Exists, Forall, Iff, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = Forall(instance_param_or_params = [Hspace], instance_expr = Forall(instance_param_or_params = [M], instance_expr = Iff(Equals(Qmult(sub_expr1, M), Qmult(M, sub_expr1)), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, Qmult(Ket(v_i), Bra(v_i))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n_kets), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), domain = LinMap(Hspace, Hspace)), domain = HilbertSpaces, condition = Equals(Dim(Hspace), n)).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{\mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(\mathcal{H}\right) = n}~\\
# \left[\forall_{M \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \thinspace M\right) = \left(M \thinspace M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right)\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]])]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (H -> {forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. H -> {forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Lambda
#    parameter: 60
#    body: 3
# 3. {forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]])
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (H in_c HilbertSpaces) and (Dim(H) = n)
#    core type: Operation
#    operator: 64
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (M -> {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in LINMAP(H, H).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (H in_c HilbertSpaces, Dim(H) = n)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. M -> {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in LINMAP(H, H).
#    core type: Lambda
#    parameter: 68
#    body: 12
# 10. H in_c HilbertSpaces
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. Dim(H) = n
#     core type: Operation
#     operator: 62
#     operands: 15
# 12. {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in LINMAP(H, H).
#     core type: Conditional
#     value: 16
#     condition: 17
# 13. in_c
#     core type: Literal
#     sub-expressions:
# 14. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 60, 18
# 15. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 19, 104
# 16. ((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. M in LINMAP(H, H)
#     core type: Operation
#     operator: 89
#     operands: 22
# 18. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 19. Dim(H)
#     core type: Operation
#     operator: 23
#     operand: 60
# 20. <=>
#     core type: Literal
#     sub-expressions:
# 21. ((M* . M) = (M . M*), exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))])
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. (M, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 68, 26
# 23. Dim
#     core type: Literal
#     sub-expressions:
# 24. (M* . M) = (M . M*)
#     core type: Operation
#     operator: 62
#     operands: 27
# 25. exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]
#     core type: Operation
#     operator: 45
#     operand: 33
# 26. LINMAP(H, H)
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. (M* . M, M . M*)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 33
# 29. LINMAP
#     core type: Literal
#     sub-expressions:
# 30. (H, H)
#     core type: ExprTuple
#     sub-expressions: 60, 60
# 31. M* . M
#     core type: Operation
#     operator: 97
#     operands: 34
# 32. M . M*
#     core type: Operation
#     operator: 97
#     operands: 35
# 33. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 36\n    body: 37
# 34. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 38, 68
# 35. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 68, 38
# 36. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 39
# 37. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#     core type: Conditional
#     value: 40
#     condition: 41
# 38. M*
#     core type: Operation
#     operator: 42
#     operand: 68
# 39. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 103
#     end_index: 104
# 40. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 45
#     operand: 48
# 41. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)
#     core type: Operation
#     operator: 89
#     operands: 47
# 42. Adj
#     core type: Literal
#     sub-expressions:
# 43. (M)
#     core type: ExprTuple
#     sub-expressions: 68
# 44. _a -> v_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 86
# 45. exists
#     core type: Literal
#     sub-expressions:
# 46. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 48
# 47. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 48. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 51\n    body: 52
# 49. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 66
#     operand: 59
# 50. O.N.Bases(H)
#     core type: Operation
#     operator: 54
#     operand: 60
# 51. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 56
# 52. {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 57
#     condition: 58
# 53. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 59
# 54. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 55. (H)
#     core type: ExprTuple
#     sub-expressions: 60
# 56. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 103
#     end_index: 104
# 57. M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 62
#     operands: 63
# 58. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 64
#     operands: 65
# 59. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 66
#     operands: 67
# 60. H
#     core type: Variable
#     sub-expressions:
# 61. _a -> a_{_a}
#     core type: Lambda
#     parameter: 95
#     body: 84
# 62. =
#     core type: Literal
#     sub-expressions:
# 63. (M, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 64. and
#     core type: Literal
#     sub-expressions:
# 65. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 70
# 66. Set
#     core type: Literal
#     sub-expressions:
# 67. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 71
# 68. M
#     core type: Variable
#     sub-expressions:
# 69. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 72
#     operand: 76
# 70. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 74
#     start_index: 103
#     end_index: 104
# 71. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 75
#     start_index: 103
#     end_index: 104
# 72. Sum
#     core type: Literal
#     sub-expressions:
# 73. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 76
# 74. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 95
#     body: 77
# 75. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 95
#     body: 78
# 76. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 111
#     body: 79
# 77. a_{_a} in Complex
#     core type: Operation
#     operator: 89
#     operands: 80
# 78. |v_{_a}〉
#     core type: Operation
#     operator: 105
#     operand: 86
# 79. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 82
#     condition: 83
# 80. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 81. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 86
# 82. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 87
#     operands: 88
# 83. i in {1 .. n}
#     core type: Operation
#     operator: 89
#     operands: 90
# 84. a_{_a}
#     core type: IndexedVar
# variable: 96
# index: 95
# 85. Complex
#     core type: Literal
#     sub-expressions:
# 86. v_{_a}
#     core type: IndexedVar
# variable: 109
# index: 95
# 87. *
#     core type: Literal
#     sub-expressions:
# 88. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 89. in
#     core type: Literal
#     sub-expressions:
# 90. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 111, 94
# 91. (_a)
#     core type: ExprTuple
#     sub-expressions: 95
# 92. a_{i}
#     core type: IndexedVar
# variable: 96
# index: 111
# 93. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 97
#     operands: 98
# 94. {1 .. n}
#     core type: Operation
#     operator: 99
#     operands: 100
# 95. _a
#     core type: Variable
#     sub-expressions:
# 96. a
#     core type: Variable
#     sub-expressions:
# 97. .
#     core type: Literal
#     sub-expressions:
# 98. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 101, 102
# 99. Interval
#     core type: Literal
#     sub-expressions:
# 100. (1, n)
#      core type: ExprTuple
#      sub-expressions: 103, 104
# 101. |v_{i}〉
#      core type: Operation
#      operator: 105
#      operand: 108
# 102. 〈v_{i}|
#      core type: Operation
#      operator: 106
#      operand: 108
# 103. 1
#      core type: Literal
#      sub-expressions:
# 104. n
#      core type: Variable
#      sub-expressions:
# 105. KET
#      core type: Literal
#      sub-expressions:
# 106. BRA
#      core type: Literal
#      sub-expressions:
# 107. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 108
# 108. v_{i}
#      core type: IndexedVar
# variable: 109
# index: 111
# 109. v
#      core type: Variable
#      sub-expressions:
# 110. (i)
#      core type: ExprTuple
#      sub-expressions: 111
# 111. i
#      core type: Variable
#      sub-expressions:
