# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, U, i, j, n
from proveit.core_expr_types import v_1_to_n, v_i, v_j
from proveit.linear_algebra import Adj, MatrixSpace, OrthoNormBases, Unitary
from proveit.logic import CartExp, Equals, Forall, Implies, InSet, Set
from proveit.numbers import Complex, Interval, KroneckerDelta, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [v_1_to_n], instance_expr = Implies(Forall(instance_param_or_params = [i, j], instance_expr = Equals(Qmult(Bra(v_i), Adj(U), U, Ket(v_j)), KroneckerDelta(i, j)), domain = Interval(one, n)), InSet(U, Unitary(n))), condition = InSet(Set(v_1_to_n_kets), OrthoNormBases(CartExp(Complex, n)))).with_wrapping(), InSet(U, MatrixSpace(field = Complex, rows = n, columns = n)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left(\left[\forall_{i, j \in \{1~\ldotp \ldotp~n\}}~\left(\left(\langle v_{i} \rvert \thinspace U^{\dagger} \thinspace U \thinspace \lvert v_{j} \rangle\right) = \delta_{i, j}\right)\right] \Rightarrow \left(U \in \textrm{U}\left(n\right)\right)\right)\end{array} \textrm{ if } U \in \mathbb{C}^{n \times n}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n))) if U in Complex^{n x n}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)))
#    core type: Operation
#    operator: 22
#    operand: 5
# 2. U in Complex^{n x n}
#    core type: Operation
#    operator: 58
#    operands: 4
# 3. ((v_{1}, v_{2}, ..., v_{n}) -> {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (U, Complex^{n x n})
#    core type: ExprTuple
#    sub-expressions: 76, 6
# 5. (v_{1}, v_{2}, ..., v_{n}) -> {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. Complex^{n x n}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (v_{1}, v_{2}, ..., v_{n})
#    core type: ExprTuple
#    sub-expressions: 11
# 8. {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Conditional
#    value: 12
#    condition: 13
# 9. MSpace
#    core type: Literal
#    sub-expressions:
# 10. {field:Complex, rows:n, columns:n}
#     core type: NamedExprs
#     field: 42
#     rows: 79
#     columns: 79
# 11. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 78
#     end_index: 79
# 12. [forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n))
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 58
#     operands: 17
# 14. _a -> v_{_a}
#     core type: Lambda
#     parameter: 80
#     body: 65
# 15. =>
#     core type: Literal
#     sub-expressions:
# 16. (forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j}), U in U(n))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})
#     core type: Operation
#     operator: 22
#     operand: 28
# 19. U in U(n)
#     core type: Operation
#     operator: 58
#     operands: 24
# 20. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 35
#     operand: 30
# 21. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 26
#     operand: 31
# 22. forall
#     core type: Literal
#     sub-expressions:
# 23. ((i, j) -> {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 28
# 24. (U, U(n))
#     core type: ExprTuple
#     sub-expressions: 76, 29
# 25. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 30
# 26. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 27. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 31
# 28. (i, j) -> {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.
#     core type: Lambda
#     parameters: 56\n    body: 32
# 29. U(n)
#     core type: Operation
#     operator: 33
#     operand: 79
# 30. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. Complex^{n}
#     core type: Operation
#     operator: 37
#     operands: 38
# 32. {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.
#     core type: Conditional
#     value: 39
#     condition: 40
# 33. U
#     core type: Literal
#     sub-expressions:
# 34. (n)
#     core type: ExprTuple
#     sub-expressions: 79
# 35. Set
#     core type: Literal
#     sub-expressions:
# 36. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 41
# 37. CartExp
#     core type: Literal
#     sub-expressions:
# 38. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 42, 79
# 39. (〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j}
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. (i in {1 .. n}) and (j in {1 .. n})
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 78
#     end_index: 79
# 42. Complex
#     core type: Literal
#     sub-expressions:
# 43. =
#     core type: Literal
#     sub-expressions:
# 44. (〈v_{i}| . U* . U . |v_{j}〉, delta_{i, j})
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 45. and
#     core type: Literal
#     sub-expressions:
# 46. (i in {1 .. n}, j in {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 47. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 80
#     body: 52
# 48. 〈v_{i}| . U* . U . |v_{j}〉
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. delta_{i, j}
#     core type: Operation
#     operator: 55
#     operands: 56
# 50. i in {1 .. n}
#     core type: Operation
#     operator: 58
#     operands: 57
# 51. j in {1 .. n}
#     core type: Operation
#     operator: 58
#     operands: 59
# 52. |v_{_a}〉
#     core type: Operation
#     operator: 70
#     operand: 65
# 53. .
#     core type: Literal
#     sub-expressions:
# 54. (〈v_{i}|, U*, U, |v_{j}〉)
#     core type: ExprTuple
#     sub-expressions: 61, 62, 76, 63
# 55. Kdelta
#     core type: Literal
#     sub-expressions:
# 56. (i, j)
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 57. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 84, 64
# 58. in
#     core type: Literal
#     sub-expressions:
# 59. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 85, 64
# 60. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 65
# 61. 〈v_{i}|
#     core type: Operation
#     operator: 66
#     operand: 75
# 62. U*
#     core type: Operation
#     operator: 68
#     operand: 76
# 63. |v_{j}〉
#     core type: Operation
#     operator: 70
#     operand: 77
# 64. {1 .. n}
#     core type: Operation
#     operator: 72
#     operands: 73
# 65. v_{_a}
#     core type: IndexedVar
# variable: 82
# index: 80
# 66. BRA
#     core type: Literal
#     sub-expressions:
# 67. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 75
# 68. Adj
#     core type: Literal
#     sub-expressions:
# 69. (U)
#     core type: ExprTuple
#     sub-expressions: 76
# 70. KET
#     core type: Literal
#     sub-expressions:
# 71. (v_{j})
#     core type: ExprTuple
#     sub-expressions: 77
# 72. Interval
#     core type: Literal
#     sub-expressions:
# 73. (1, n)
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 74. (_a)
#     core type: ExprTuple
#     sub-expressions: 80
# 75. v_{i}
#     core type: IndexedVar
# variable: 82
# index: 84
# 76. U
#     core type: Variable
#     sub-expressions:
# 77. v_{j}
#     core type: IndexedVar
# variable: 82
# index: 85
# 78. 1
#     core type: Literal
#     sub-expressions:
# 79. n
#     core type: Variable
#     sub-expressions:
# 80. _a
#     core type: Variable
#     sub-expressions:
# 81. (i)
#     core type: ExprTuple
#     sub-expressions: 84
# 82. v
#     core type: Variable
#     sub-expressions:
# 83. (j)
#     core type: ExprTuple
#     sub-expressions: 85
# 84. i
#     core type: Variable
#     sub-expressions:
# 85. j
#     core type: Variable
#     sub-expressions:
