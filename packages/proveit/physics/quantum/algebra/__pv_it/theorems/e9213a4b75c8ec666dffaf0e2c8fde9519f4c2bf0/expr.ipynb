# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, U, i, j, n
from proveit.core_expr_types import v_1_to_n, v_i, v_j
from proveit.linear_algebra import Adj, OrthoNormBases, Unitary
from proveit.logic import CartExp, Equals, Forall, Implies, InSet, Set
from proveit.numbers import Complex, Interval, KroneckerDelta, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([v_1_to_n], Conditional(Implies(Forall(instance_param_or_params = [i, j], instance_expr = Equals(Qmult(Bra(v_i), Adj(U), U, Ket(v_j)), KroneckerDelta(i, j)), domain = Interval(one, n)), InSet(U, Unitary(n))), InSet(Set(v_1_to_n_kets), OrthoNormBases(CartExp(Complex, n))))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(v_{1}, v_{2}, \ldots, v_{n}\right) \mapsto \left\{\left[\forall_{i, j \in \{1~\ldotp \ldotp~n\}}~\left(\left(\langle v_{i} \rvert \thinspace U^{\dagger} \thinspace U \thinspace \lvert v_{j} \rangle\right) = \delta_{i, j}\right)\right] \Rightarrow \left(U \in \textrm{U}\left(n\right)\right) \textrm{ if } \left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((v_{1}, v_{2}, ..., v_{n}) -> {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (v_{1}, v_{2}, ..., v_{n}) -> {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (v_{1}, v_{2}, ..., v_{n})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Conditional
#    value: 5
#    condition: 6
# 4. v_{1}, v_{2}, ..., v_{n}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 71
#    end_index: 72
# 5. [forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n))
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#    core type: Operation
#    operator: 51
#    operands: 10
# 7. _a -> v_{_a}
#    core type: Lambda
#    parameter: 73
#    body: 58
# 8. =>
#    core type: Literal
#    sub-expressions:
# 9. (forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j}), U in U(n))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})
#     core type: Operation
#     operator: 15
#     operand: 21
# 12. U in U(n)
#     core type: Operation
#     operator: 51
#     operands: 17
# 13. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 28
#     operand: 23
# 14. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 19
#     operand: 24
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. ((i, j) -> {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 21
# 17. (U, U(n))
#     core type: ExprTuple
#     sub-expressions: 69, 22
# 18. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 23
# 19. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 20. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. (i, j) -> {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.
#     core type: Lambda
#     parameters: 49\n    body: 25
# 22. U(n)
#     core type: Operation
#     operator: 26
#     operand: 72
# 23. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. Complex^{n}
#     core type: Operation
#     operator: 30
#     operands: 31
# 25. {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.
#     core type: Conditional
#     value: 32
#     condition: 33
# 26. U
#     core type: Literal
#     sub-expressions:
# 27. (n)
#     core type: ExprTuple
#     sub-expressions: 72
# 28. Set
#     core type: Literal
#     sub-expressions:
# 29. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 34
# 30. CartExp
#     core type: Literal
#     sub-expressions:
# 31. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 35, 72
# 32. (〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j}
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. (i in {1 .. n}) and (j in {1 .. n})
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 71
#     end_index: 72
# 35. Complex
#     core type: Literal
#     sub-expressions:
# 36. =
#     core type: Literal
#     sub-expressions:
# 37. (〈v_{i}| . U* . U . |v_{j}〉, delta_{i, j})
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 38. and
#     core type: Literal
#     sub-expressions:
# 39. (i in {1 .. n}, j in {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 40. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 73
#     body: 45
# 41. 〈v_{i}| . U* . U . |v_{j}〉
#     core type: Operation
#     operator: 46
#     operands: 47
# 42. delta_{i, j}
#     core type: Operation
#     operator: 48
#     operands: 49
# 43. i in {1 .. n}
#     core type: Operation
#     operator: 51
#     operands: 50
# 44. j in {1 .. n}
#     core type: Operation
#     operator: 51
#     operands: 52
# 45. |v_{_a}〉
#     core type: Operation
#     operator: 63
#     operand: 58
# 46. .
#     core type: Literal
#     sub-expressions:
# 47. (〈v_{i}|, U*, U, |v_{j}〉)
#     core type: ExprTuple
#     sub-expressions: 54, 55, 69, 56
# 48. Kdelta
#     core type: Literal
#     sub-expressions:
# 49. (i, j)
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 50. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 77, 57
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 78, 57
# 53. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 58
# 54. 〈v_{i}|
#     core type: Operation
#     operator: 59
#     operand: 68
# 55. U*
#     core type: Operation
#     operator: 61
#     operand: 69
# 56. |v_{j}〉
#     core type: Operation
#     operator: 63
#     operand: 70
# 57. {1 .. n}
#     core type: Operation
#     operator: 65
#     operands: 66
# 58. v_{_a}
#     core type: IndexedVar
# variable: 75
# index: 73
# 59. BRA
#     core type: Literal
#     sub-expressions:
# 60. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 68
# 61. Adj
#     core type: Literal
#     sub-expressions:
# 62. (U)
#     core type: ExprTuple
#     sub-expressions: 69
# 63. KET
#     core type: Literal
#     sub-expressions:
# 64. (v_{j})
#     core type: ExprTuple
#     sub-expressions: 70
# 65. Interval
#     core type: Literal
#     sub-expressions:
# 66. (1, n)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 67. (_a)
#     core type: ExprTuple
#     sub-expressions: 73
# 68. v_{i}
#     core type: IndexedVar
# variable: 75
# index: 77
# 69. U
#     core type: Variable
#     sub-expressions:
# 70. v_{j}
#     core type: IndexedVar
# variable: 75
# index: 78
# 71. 1
#     core type: Literal
#     sub-expressions:
# 72. n
#     core type: Variable
#     sub-expressions:
# 73. _a
#     core type: Variable
#     sub-expressions:
# 74. (i)
#     core type: ExprTuple
#     sub-expressions: 77
# 75. v
#     core type: Variable
#     sub-expressions:
# 76. (j)
#     core type: ExprTuple
#     sub-expressions: 78
# 77. i
#     core type: Variable
#     sub-expressions:
# 78. j
#     core type: Variable
#     sub-expressions:
