# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import U, i, j, n
from proveit.core_expr_types import v_1_to_n, v_i, v_j
from proveit.linear_algebra import Adj, OrthoNormBases, Unitary
from proveit.logic import CartExp, Equals, Forall, Implies, InSet, Set
from proveit.numbers import Complex, Interval, KroneckerDelta, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [v_1_to_n], instance_expr = Implies(Forall(instance_param_or_params = [i, j], instance_expr = Equals(Qmult(Bra(v_i), Adj(U), U, Ket(v_j)), KroneckerDelta(i, j)), domain = Interval(one, n)), InSet(U, Unitary(n))), condition = InSet(Set(v_1_to_n_kets), OrthoNormBases(CartExp(Complex, n)))).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left(\left[\forall_{i, j \in \{1~\ldotp \ldotp~n\}}~\left(\left(\langle v_{i} \rvert \thinspace U^{\dagger} \thinspace U \thinspace \lvert v_{j} \rangle\right) = \delta_{i, j}\right)\right] \Rightarrow \left(U \in \textrm{U}\left(n\right)\right)\right)\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)))
#    core type: Operation
#    operator: 16
#    operand: 2
# 1. ((v_{1}, v_{2}, ..., v_{n}) -> {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (v_{1}, v_{2}, ..., v_{n}) -> {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (v_{1}, v_{2}, ..., v_{n})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Conditional
#    value: 6
#    condition: 7
# 5. v_{1}, v_{2}, ..., v_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 72
#    end_index: 73
# 6. [forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n))
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#    core type: Operation
#    operator: 52
#    operands: 11
# 8. _a -> v_{_a}
#    core type: Lambda
#    parameter: 74
#    body: 59
# 9. =>
#    core type: Literal
#    sub-expressions:
# 10. (forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j}), U in U(n))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})
#     core type: Operation
#     operator: 16
#     operand: 22
# 13. U in U(n)
#     core type: Operation
#     operator: 52
#     operands: 18
# 14. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 29
#     operand: 24
# 15. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 20
#     operand: 25
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. ((i, j) -> {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 22
# 18. (U, U(n))
#     core type: ExprTuple
#     sub-expressions: 70, 23
# 19. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 24
# 20. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 21. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 25
# 22. (i, j) -> {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.
#     core type: Lambda
#     parameters: 50\n    body: 26
# 23. U(n)
#     core type: Operation
#     operator: 27
#     operand: 73
# 24. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. Complex^{n}
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.
#     core type: Conditional
#     value: 33
#     condition: 34
# 27. U
#     core type: Literal
#     sub-expressions:
# 28. (n)
#     core type: ExprTuple
#     sub-expressions: 73
# 29. Set
#     core type: Literal
#     sub-expressions:
# 30. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 35
# 31. CartExp
#     core type: Literal
#     sub-expressions:
# 32. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 36, 73
# 33. (〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j}
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. (i in {1 .. n}) and (j in {1 .. n})
#     core type: Operation
#     operator: 39
#     operands: 40
# 35. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 72
#     end_index: 73
# 36. Complex
#     core type: Literal
#     sub-expressions:
# 37. =
#     core type: Literal
#     sub-expressions:
# 38. (〈v_{i}| . U* . U . |v_{j}〉, delta_{i, j})
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 39. and
#     core type: Literal
#     sub-expressions:
# 40. (i in {1 .. n}, j in {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 74
#     body: 46
# 42. 〈v_{i}| . U* . U . |v_{j}〉
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. delta_{i, j}
#     core type: Operation
#     operator: 49
#     operands: 50
# 44. i in {1 .. n}
#     core type: Operation
#     operator: 52
#     operands: 51
# 45. j in {1 .. n}
#     core type: Operation
#     operator: 52
#     operands: 53
# 46. |v_{_a}〉
#     core type: Operation
#     operator: 64
#     operand: 59
# 47. .
#     core type: Literal
#     sub-expressions:
# 48. (〈v_{i}|, U*, U, |v_{j}〉)
#     core type: ExprTuple
#     sub-expressions: 55, 56, 70, 57
# 49. Kdelta
#     core type: Literal
#     sub-expressions:
# 50. (i, j)
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 51. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 78, 58
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 79, 58
# 54. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 59
# 55. 〈v_{i}|
#     core type: Operation
#     operator: 60
#     operand: 69
# 56. U*
#     core type: Operation
#     operator: 62
#     operand: 70
# 57. |v_{j}〉
#     core type: Operation
#     operator: 64
#     operand: 71
# 58. {1 .. n}
#     core type: Operation
#     operator: 66
#     operands: 67
# 59. v_{_a}
#     core type: IndexedVar
# variable: 76
# index: 74
# 60. BRA
#     core type: Literal
#     sub-expressions:
# 61. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 69
# 62. Adj
#     core type: Literal
#     sub-expressions:
# 63. (U)
#     core type: ExprTuple
#     sub-expressions: 70
# 64. KET
#     core type: Literal
#     sub-expressions:
# 65. (v_{j})
#     core type: ExprTuple
#     sub-expressions: 71
# 66. Interval
#     core type: Literal
#     sub-expressions:
# 67. (1, n)
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 68. (_a)
#     core type: ExprTuple
#     sub-expressions: 74
# 69. v_{i}
#     core type: IndexedVar
# variable: 76
# index: 78
# 70. U
#     core type: Variable
#     sub-expressions:
# 71. v_{j}
#     core type: IndexedVar
# variable: 76
# index: 79
# 72. 1
#     core type: Literal
#     sub-expressions:
# 73. n
#     core type: Variable
#     sub-expressions:
# 74. _a
#     core type: Variable
#     sub-expressions:
# 75. (i)
#     core type: ExprTuple
#     sub-expressions: 78
# 76. v
#     core type: Variable
#     sub-expressions:
# 77. (j)
#     core type: ExprTuple
#     sub-expressions: 79
# 78. i
#     core type: Variable
#     sub-expressions:
# 79. j
#     core type: Variable
#     sub-expressions:
