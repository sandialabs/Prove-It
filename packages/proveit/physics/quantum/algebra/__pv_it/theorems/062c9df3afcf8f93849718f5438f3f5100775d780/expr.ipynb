# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, X, i, n
from proveit.core_expr_types import x_1_to_n, x_i
from proveit.linear_algebra import HilbertSpaces, Hspace, OrthoNormBases, OrthoProj, VecSum
from proveit.logic import Equals, Forall, InClass, InSet, SubsetEq
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import x_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Lambda(Hspace, Conditional(Forall(instance_param_or_params = [X], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(OrthoProj(Hspace, X), VecSum(index_or_indices = [i], summand = Qmult(Ket(x_i), Bra(x_i)), domain = Interval(one, n))), condition = InSet(x_1_to_n_kets, OrthoNormBases(Hspace))).with_wrapping(), domain = NaturalPos), condition = SubsetEq(X, Hspace)), InClass(Hspace, HilbertSpaces)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \mathcal{H} \mapsto \left\{\forall_{X~|~X \subseteq \mathcal{H}}~\left[\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{\lvert x_{1} \rangle, \lvert x_{2} \rangle, \ldots, \lvert x_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left(\textrm{OrthoProj}\left(\mathcal{H}, X\right) = \left(\sum_{i=1}^{n} \left(\lvert x_{i} \rangle \thinspace \langle x_{i} \rvert\right)\right)\right)\end{array}\right]\right] \textrm{ if } \mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. H -> {forall_{X | X subset_eq H} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]] if H in_c HilbertSpaces.
#    core type: Lambda
#    parameter: 50
#    body: 1
# 1. {forall_{X | X subset_eq H} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]] if H in_c HilbertSpaces.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{X | X subset_eq H} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]]
#    core type: Operation
#    operator: 21
#    operand: 7
# 3. H in_c HilbertSpaces
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (X -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. in_c
#    core type: Literal
#    sub-expressions:
# 6. (H, HilbertSpaces)
#    core type: ExprTuple
#    sub-expressions: 50, 8
# 7. X -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.
#    core type: Lambda
#    parameter: 47
#    body: 10
# 8. HilbertSpaces
#    core type: Literal
#    sub-expressions:
# 9. (X)
#    core type: ExprTuple
#    sub-expressions: 47
# 10. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]
#     core type: Operation
#     operator: 21
#     operand: 16
# 12. X subset_eq H
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. subset_eq
#     core type: Literal
#     sub-expressions:
# 15. (X, H)
#     core type: ExprTuple
#     sub-expressions: 47, 50
# 16. n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#     core type: Lambda
#     parameter: 73
#     body: 18
# 17. (n)
#     core type: ExprTuple
#     sub-expressions: 73
# 18. {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#     core type: Conditional
#     value: 19
#     condition: 20
# 19. forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))
#     core type: Operation
#     operator: 21
#     operand: 24
# 20. n in NaturalPos
#     core type: Operation
#     operator: 58
#     operands: 23
# 21. forall
#     core type: Literal
#     sub-expressions:
# 22. ((x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 73, 25
# 24. (x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 26\n    body: 27
# 25. NaturalPos
#     core type: Literal
#     sub-expressions:
# 26. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 28
# 27. {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Conditional
#     value: 29
#     condition: 30
# 28. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 72
#     end_index: 73
# 29. OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)
#     core type: Operation
#     operator: 58
#     operands: 34
# 31. _a -> x_{_a}
#     core type: Lambda
#     parameter: 74
#     body: 64
# 32. =
#     core type: Literal
#     sub-expressions:
# 33. (OrthoProj(H, X), Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 34. ({|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. OrthoProj(H, X)
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)
#     core type: Operation
#     operator: 41
#     operand: 48
# 37. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}
#     core type: Operation
#     operator: 43
#     operands: 44
# 38. O.N.Bases(H)
#     core type: Operation
#     operator: 45
#     operand: 50
# 39. OrthoProj
#     core type: Literal
#     sub-expressions:
# 40. (H, X)
#     core type: ExprTuple
#     sub-expressions: 50, 47
# 41. Sum
#     core type: Literal
#     sub-expressions:
# 42. (i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 48
# 43. Set
#     core type: Literal
#     sub-expressions:
# 44. (|x_{1}〉, |x_{2}〉, ..., |x_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 49
# 45. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 46. (H)
#     core type: ExprTuple
#     sub-expressions: 50
# 47. X
#     core type: Variable
#     sub-expressions:
# 48. i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 77
#     body: 51
# 49. |x_{1}〉, |x_{2}〉, ..., |x_{n}〉
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 72
#     end_index: 73
# 50. H
#     core type: Variable
#     sub-expressions:
# 51. {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 53
#     condition: 54
# 52. _a -> |x_{_a}〉
#     core type: Lambda
#     parameter: 74
#     body: 55
# 53. |x_{i}〉 . 〈x_{i}|
#     core type: Operation
#     operator: 56
#     operands: 57
# 54. i in {1 .. n}
#     core type: Operation
#     operator: 58
#     operands: 59
# 55. |x_{_a}〉
#     core type: Operation
#     operator: 65
#     operand: 64
# 56. .
#     core type: Literal
#     sub-expressions:
# 57. (|x_{i}〉, 〈x_{i}|)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 58. in
#     core type: Literal
#     sub-expressions:
# 59. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 77, 63
# 60. (x_{_a})
#     core type: ExprTuple
#     sub-expressions: 64
# 61. |x_{i}〉
#     core type: Operation
#     operator: 65
#     operand: 71
# 62. 〈x_{i}|
#     core type: Operation
#     operator: 66
#     operand: 71
# 63. {1 .. n}
#     core type: Operation
#     operator: 68
#     operands: 69
# 64. x_{_a}
#     core type: IndexedVar
# variable: 75
# index: 74
# 65. KET
#     core type: Literal
#     sub-expressions:
# 66. BRA
#     core type: Literal
#     sub-expressions:
# 67. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 71
# 68. Interval
#     core type: Literal
#     sub-expressions:
# 69. (1, n)
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 70. (_a)
#     core type: ExprTuple
#     sub-expressions: 74
# 71. x_{i}
#     core type: IndexedVar
# variable: 75
# index: 77
# 72. 1
#     core type: Literal
#     sub-expressions:
# 73. n
#     core type: Variable
#     sub-expressions:
# 74. _a
#     core type: Variable
#     sub-expressions:
# 75. x
#     core type: Variable
#     sub-expressions:
# 76. (i)
#     core type: ExprTuple
#     sub-expressions: 77
# 77. i
#     core type: Variable
#     sub-expressions:
