# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#prepend_num_ket_with_one_ket">prepend_num_ket_with_one_ket</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.algebra import prepend_num_ket_with_one_ket

# %%
# check that the built expression is the same as the stored expression
assert prepend_num_ket_with_one_ket.expr == stored_expr
assert prepend_num_ket_with_one_ket.expr._style_id == stored_expr._style_id
print("Passed sanity check: prepend_num_ket_with_one_ket matches stored_expr")
# Out:
# Passed sanity check: prepend_num_ket_with_one_ket matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{k \in \{0~\ldotp \ldotp~2^{n} - 1\}}~\left(\lvert 2^{n} + k \rangle_{n + 1} = \left(\lvert 1 \rangle {\otimes} \lvert k \rangle_{n}\right)\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{k in {0 .. 2^{n} - 1}} (|2^{n} + k〉_{n + 1} = (|1〉 otimes |k〉_{n}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (n -> {forall_{k in {0 .. 2^{n} - 1}} (|2^{n} + k〉_{n + 1} = (|1〉 otimes |k〉_{n})) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{k in {0 .. 2^{n} - 1}} (|2^{n} + k〉_{n + 1} = (|1〉 otimes |k〉_{n})) if n in NaturalPos.
#    core type: Lambda
#    parameter: 49
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 49
# 4. {forall_{k in {0 .. 2^{n} - 1}} (|2^{n} + k〉_{n + 1} = (|1〉 otimes |k〉_{n})) if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{k in {0 .. 2^{n} - 1}} (|2^{n} + k〉_{n + 1} = (|1〉 otimes |k〉_{n}))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. n in NaturalPos
#    core type: Operation
#    operator: 18
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# ...
