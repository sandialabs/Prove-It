# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, v_1_to_n, v_i
from proveit.linear_algebra import Adj, Dim, HilbertSpaces, Hspace, LinMap, OrthoNormBases, ScalarMult, VecSum
from proveit.logic import Equals, Exists, Forall, Iff, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [Hspace], instance_expr = Forall(instance_param_or_params = [M], instance_expr = Iff(Equals(Qmult(sub_expr1, M), Qmult(M, sub_expr1)), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, Qmult(Ket(v_i), Bra(v_i))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n_kets), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), domain = LinMap(Hspace, Hspace)), domain = HilbertSpaces, condition = Equals(Dim(Hspace), n)).with_wrapping(), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{\mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(\mathcal{H}\right) = n}~\\
# \left[\forall_{M \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \thinspace M\right) = \left(M \thinspace M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right)\right]\end{array}\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]])]]
#    core type: Operation
#    operator: 14
#    operand: 2
# 1. (n -> {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]])] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]])] if n in NaturalPos.
#    core type: Lambda
#    parameter: 112
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 112
# 4. {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]])] if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]])]
#    core type: Operation
#    operator: 14
#    operand: 9
# 6. n in NaturalPos
#    core type: Operation
#    operator: 97
#    operands: 8
# 7. (H -> {forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 112, 10
# 9. H -> {forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Lambda
#    parameter: 68
#    body: 11
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. {forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]])
#     core type: Operation
#     operator: 14
#     operand: 17
# 13. (H in_c HilbertSpaces) and (Dim(H) = n)
#     core type: Operation
#     operator: 72
#     operands: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. (M -> {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in LINMAP(H, H).)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. (H in_c HilbertSpaces, Dim(H) = n)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. M -> {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in LINMAP(H, H).
#     core type: Lambda
#     parameter: 76
#     body: 20
# 18. H in_c HilbertSpaces
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. Dim(H) = n
#     core type: Operation
#     operator: 70
#     operands: 23
# 20. {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in LINMAP(H, H).
#     core type: Conditional
#     value: 24
#     condition: 25
# 21. in_c
#     core type: Literal
#     sub-expressions:
# 22. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 68, 26
# 23. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 27, 112
# 24. ((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. M in LINMAP(H, H)
#     core type: Operation
#     operator: 97
#     operands: 30
# 26. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 27. Dim(H)
#     core type: Operation
#     operator: 31
#     operand: 68
# 28. <=>
#     core type: Literal
#     sub-expressions:
# 29. ((M* . M) = (M . M*), exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))])
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. (M, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 76, 34
# 31. Dim
#     core type: Literal
#     sub-expressions:
# 32. (M* . M) = (M . M*)
#     core type: Operation
#     operator: 70
#     operands: 35
# 33. exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]
#     core type: Operation
#     operator: 53
#     operand: 41
# 34. LINMAP(H, H)
#     core type: Operation
#     operator: 37
#     operands: 38
# 35. (M* . M, M . M*)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 41
# 37. LINMAP
#     core type: Literal
#     sub-expressions:
# 38. (H, H)
#     core type: ExprTuple
#     sub-expressions: 68, 68
# 39. M* . M
#     core type: Operation
#     operator: 105
#     operands: 42
# 40. M . M*
#     core type: Operation
#     operator: 105
#     operands: 43
# 41. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 44\n    body: 45
# 42. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 46, 76
# 43. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 76, 46
# 44. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 47
# 45. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#     core type: Conditional
#     value: 48
#     condition: 49
# 46. M*
#     core type: Operation
#     operator: 50
#     operand: 76
# 47. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 111
#     end_index: 112
# 48. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 53
#     operand: 56
# 49. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)
#     core type: Operation
#     operator: 97
#     operands: 55
# 50. Adj
#     core type: Literal
#     sub-expressions:
# 51. (M)
#     core type: ExprTuple
#     sub-expressions: 76
# 52. _a -> v_{_a}
#     core type: Lambda
#     parameter: 103
#     body: 94
# 53. exists
#     core type: Literal
#     sub-expressions:
# 54. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 56
# 55. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 56. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 59\n    body: 60
# 57. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 74
#     operand: 67
# 58. O.N.Bases(H)
#     core type: Operation
#     operator: 62
#     operand: 68
# 59. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 64
# 60. {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 65
#     condition: 66
# 61. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 67
# 62. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 63. (H)
#     core type: ExprTuple
#     sub-expressions: 68
# 64. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 111
#     end_index: 112
# 65. M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 70
#     operands: 71
# 66. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 72
#     operands: 73
# 67. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 74
#     operands: 75
# 68. H
#     core type: Variable
#     sub-expressions:
# 69. _a -> a_{_a}
#     core type: Lambda
#     parameter: 103
#     body: 92
# 70. =
#     core type: Literal
#     sub-expressions:
# 71. (M, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 76, 77
# 72. and
#     core type: Literal
#     sub-expressions:
# 73. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 78
# 74. Set
#     core type: Literal
#     sub-expressions:
# 75. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 79
# 76. M
#     core type: Variable
#     sub-expressions:
# 77. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 80
#     operand: 84
# 78. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 82
#     start_index: 111
#     end_index: 112
# 79. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 83
#     start_index: 111
#     end_index: 112
# 80. Sum
#     core type: Literal
#     sub-expressions:
# 81. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 84
# 82. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 103
#     body: 85
# 83. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 103
#     body: 86
# 84. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 119
#     body: 87
# 85. a_{_a} in Complex
#     core type: Operation
#     operator: 97
#     operands: 88
# 86. |v_{_a}〉
#     core type: Operation
#     operator: 113
#     operand: 94
# 87. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 90
#     condition: 91
# 88. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 89. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 94
# 90. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 95
#     operands: 96
# 91. i in {1 .. n}
#     core type: Operation
#     operator: 97
#     operands: 98
# 92. a_{_a}
#     core type: IndexedVar
# variable: 104
# index: 103
# 93. Complex
#     core type: Literal
#     sub-expressions:
# 94. v_{_a}
#     core type: IndexedVar
# variable: 117
# index: 103
# 95. *
#     core type: Literal
#     sub-expressions:
# 96. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 100, 101
# 97. in
#     core type: Literal
#     sub-expressions:
# 98. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 119, 102
# 99. (_a)
#     core type: ExprTuple
#     sub-expressions: 103
# 100. a_{i}
#      core type: IndexedVar
# variable: 104
# index: 119
# 101. |v_{i}〉 . 〈v_{i}|
#      core type: Operation
#      operator: 105
#      operands: 106
# 102. {1 .. n}
#      core type: Operation
#      operator: 107
#      operands: 108
# 103. _a
#      core type: Variable
#      sub-expressions:
# 104. a
#      core type: Variable
#      sub-expressions:
# 105. .
#      core type: Literal
#      sub-expressions:
# 106. (|v_{i}〉, 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 109, 110
# 107. Interval
#      core type: Literal
#      sub-expressions:
# 108. (1, n)
#      core type: ExprTuple
#      sub-expressions: 111, 112
# 109. |v_{i}〉
#      core type: Operation
#      operator: 113
#      operand: 116
# 110. 〈v_{i}|
#      core type: Operation
#      operator: 114
#      operand: 116
# 111. 1
#      core type: Literal
#      sub-expressions:
# 112. n
#      core type: Variable
#      sub-expressions:
# 113. KET
#      core type: Literal
#      sub-expressions:
# 114. BRA
#      core type: Literal
#      sub-expressions:
# 115. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 116
# 116. v_{i}
#      core type: IndexedVar
# variable: 117
# index: 119
# 117. v
#      core type: Variable
#      sub-expressions:
# 118. (i)
#      core type: ExprTuple
#      sub-expressions: 119
# 119. i
#      core type: Variable
#      sub-expressions:
