# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, i, lambda_, m, n
from proveit.core_expr_types import a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import OrthoNormBases, ScalarMult, VecSum
from proveit.logic import CartExp, Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, Min, RealNonNeg, one
from proveit.physics.quantum import Ket, Qmult, var_ket_psi
from proveit.physics.quantum.algebra import b_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
expr = Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(var_ket_psi, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, Qmult(Ket(a_i), Ket(b_i))), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n_kets), OrthoNormBases(CartExp(Complex, n)))).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{\left\{\lvert b_{1} \rangle, \lvert b_{2} \rangle, \ldots, \lvert b_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(\lvert \psi \rangle = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(\lvert a_{i} \rangle \thinspace \lvert b_{i} \rangle\right)\right)\right)\right)\end{array}\right]\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]
#    core type: Operation
#    operator: 9
#    operand: 2
# 1. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (b_{1}, b_{2}, ..., b_{n})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Conditional
#    value: 6
#    condition: 7
# 5. b_{1}, b_{2}, ..., b_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 70
#    end_index: 80
# 6. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))
#    core type: Operation
#    operator: 9
#    operand: 12
# 7. {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})
#    core type: Operation
#    operator: 56
#    operands: 11
# 8. _a -> b_{_a}
#    core type: Lambda
#    parameter: 62
#    body: 53
# 9. exists
#    core type: Literal
#    sub-expressions:
# 10. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. ({{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 15\n    body: 16
# 13. {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}}
#     core type: Operation
#     operator: 30
#     operand: 23
# 14. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 18
#     operand: 24
# 15. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 20
# 16. {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 21
#     condition: 22
# 17. ({|b_{1}〉, |b_{2}〉, ..., |b_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 23
# 18. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 19. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 24
# 20. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 70
#     end_index: 71
# 21. |psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 28
#     operands: 29
# 23. {|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}
#     core type: Operation
#     operator: 30
#     operands: 31
# 24. Complex^{n}
#     core type: Operation
#     operator: 32
#     operands: 33
# 25. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 62
#     body: 51
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. (|psi>, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 28. and
#     core type: Literal
#     sub-expressions:
# 29. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 36
# 30. Set
#     core type: Literal
#     sub-expressions:
# 31. (|b_{1}〉, |b_{2}〉, ..., |b_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 37
# 32. CartExp
#     core type: Literal
#     sub-expressions:
# 33. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 38, 80
# 34. |psi>
#     core type: Variable
#     sub-expressions:
# 35. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))
#     core type: Operation
#     operator: 39
#     operand: 43
# 36. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 70
#     end_index: 71
# 37. |b_{1}〉, |b_{2}〉, ..., |b_{n}〉
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 70
#     end_index: 80
# 38. Complex
#     core type: Literal
#     sub-expressions:
# 39. Sum
#     core type: Literal
#     sub-expressions:
# 40. (i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 43
# 41. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 62
#     body: 44
# 42. _a -> |b_{_a}〉
#     core type: Lambda
#     parameter: 62
#     body: 45
# 43. i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 84
#     body: 46
# 44. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 56
#     operands: 47
# 45. |b_{_a}〉
#     core type: Operation
#     operator: 73
#     operand: 53
# 46. {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 49
#     condition: 50
# 47. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 48. (b_{_a})
#     core type: ExprTuple
#     sub-expressions: 53
# 49. lambda_{i} * (|a_{i}〉 . |b_{i}〉)
#     core type: Operation
#     operator: 54
#     operands: 55
# 50. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 56
#     operands: 57
# 51. lambda_{_a}
#     core type: IndexedVar
# variable: 63
# index: 62
# 52. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 53. b_{_a}
#     core type: IndexedVar
# variable: 82
# index: 62
# 54. *
#     core type: Literal
#     sub-expressions:
# 55. (lambda_{i}, |a_{i}〉 . |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 56. in
#     core type: Literal
#     sub-expressions:
# 57. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 84, 61
# 58. (_a)
#     core type: ExprTuple
#     sub-expressions: 62
# 59. lambda_{i}
#     core type: IndexedVar
# variable: 63
# index: 84
# 60. |a_{i}〉 . |b_{i}〉
#     core type: Operation
#     operator: 64
#     operands: 65
# 61. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 66
#     operands: 67
# 62. _a
#     core type: Variable
#     sub-expressions:
# 63. lambda
#     core type: Variable
#     sub-expressions:
# 64. .
#     core type: Literal
#     sub-expressions:
# 65. (|a_{i}〉, |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 66. Interval
#     core type: Literal
#     sub-expressions:
# 67. (1, Min(m, n))
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 68. |a_{i}〉
#     core type: Operation
#     operator: 73
#     operand: 77
# 69. |b_{i}〉
#     core type: Operation
#     operator: 73
#     operand: 78
# 70. 1
#     core type: Literal
#     sub-expressions:
# 71. Min(m, n)
#     core type: Operation
#     operator: 75
#     operands: 76
# 72. (a_{i})
#     core type: ExprTuple
#     sub-expressions: 77
# 73. KET
#     core type: Literal
#     sub-expressions:
# 74. (b_{i})
#     core type: ExprTuple
#     sub-expressions: 78
# 75. Min
#     core type: Literal
#     sub-expressions:
# 76. (m, n)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 77. a_{i}
#     core type: IndexedVar
# variable: 81
# index: 84
# 78. b_{i}
#     core type: IndexedVar
# variable: 82
# index: 84
# 79. m
#     core type: Variable
#     sub-expressions:
# 80. n
#     core type: Variable
#     sub-expressions:
# 81. a
#     core type: Variable
#     sub-expressions:
# 82. b
#     core type: Variable
#     sub-expressions:
# 83. (i)
#     core type: ExprTuple
#     sub-expressions: 84
# 84. i
#     core type: Variable
#     sub-expressions:
