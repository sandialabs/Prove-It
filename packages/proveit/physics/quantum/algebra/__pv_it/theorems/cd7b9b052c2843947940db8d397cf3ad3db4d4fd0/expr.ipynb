# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, v_1_to_n, v_i
from proveit.linear_algebra import Adj, Commutator, Dim, HilbertSpaces, Hspace, LinMap, OrthoNormBases, ScalarMult, VecSum, VecZero
from proveit.logic import And, Equals, Exists, Forall, Iff, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = LinMap(Hspace, Hspace)
sub_expr3 = Interval(one, n)
sub_expr4 = Qmult(Ket(v_i), Bra(v_i))
expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [Hspace], instance_expr = Forall(instance_param_or_params = [A, B], instance_expr = Iff(Equals(Commutator(A, B), VecZero(sub_expr2)), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr4), domain = sub_expr3))).with_wrapping_at(2), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), domain = sub_expr2, conditions = [Equals(Adj(A), A), Equals(Adj(B), B)]).with_wrapping(), domain = HilbertSpaces, condition = Equals(Dim(Hspace), n)).with_wrapping(), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{\mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(\mathcal{H}\right) = n}~\\
# \left[\begin{array}{l}\forall_{A, B \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)~|~A^{\dagger} = A, B^{\dagger} = B}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left[A, B\right] = \vec{0}\left(\mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{v_{1}, v_{2}, \ldots, v_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array}\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right)\end{array}\right]\end{array}\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]])]]
#    core type: Operation
#    operator: 14
#    operand: 2
# 1. (n -> {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]])] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]])] if n in NaturalPos.
#    core type: Lambda
#    parameter: 137
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 137
# 4. {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]])] if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]])]
#    core type: Operation
#    operator: 14
#    operand: 9
# 6. n in NaturalPos
#    core type: Operation
#    operator: 122
#    operands: 8
# 7. (H -> {forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 137, 10
# 9. H -> {forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Lambda
#    parameter: 79
#    body: 11
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. {forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]])
#     core type: Operation
#     operator: 14
#     operand: 17
# 13. (H in_c HilbertSpaces) and (Dim(H) = n)
#     core type: Operation
#     operator: 83
#     operands: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. ((A, B) -> {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. (H in_c HilbertSpaces, Dim(H) = n)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. (A, B) -> {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.
#     core type: Lambda
#     parameters: 50\n    body: 20
# 18. H in_c HilbertSpaces
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. Dim(H) = n
#     core type: Operation
#     operator: 92
#     operands: 23
# 20. {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.
#     core type: Conditional
#     value: 24
#     condition: 25
# 21. in_c
#     core type: Literal
#     sub-expressions:
# 22. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 79, 26
# 23. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 27, 137
# 24. ([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. (A in LINMAP(H, H)) and (B in LINMAP(H, H)) and (A* = A) and (B* = B)
#     core type: Operation
#     operator: 83
#     operands: 30
# 26. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 27. Dim(H)
#     core type: Operation
#     operator: 31
#     operand: 79
# 28. <=>
#     core type: Literal
#     sub-expressions:
# 29. ([A, B] = 0(LINMAP(H, H)), exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))])
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. (A in LINMAP(H, H), B in LINMAP(H, H), A* = A, B* = B)
#     core type: ExprTuple
#     sub-expressions: 34, 35, 36, 37
# 31. Dim
#     core type: Literal
#     sub-expressions:
# 32. [A, B] = 0(LINMAP(H, H))
#     core type: Operation
#     operator: 92
#     operands: 38
# 33. exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]
#     core type: Operation
#     operator: 62
#     operand: 46
# 34. A in LINMAP(H, H)
#     core type: Operation
#     operator: 122
#     operands: 40
# 35. B in LINMAP(H, H)
#     core type: Operation
#     operator: 122
#     operands: 41
# 36. A* = A
#     core type: Operation
#     operator: 92
#     operands: 42
# 37. B* = B
#     core type: Operation
#     operator: 92
#     operands: 43
# 38. ([A, B], 0(LINMAP(H, H)))
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 39. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 46
# 40. (A, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 96, 57
# 41. (B, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 98, 57
# 42. (A*, A)
#     core type: ExprTuple
#     sub-expressions: 47, 96
# 43. (B*, B)
#     core type: ExprTuple
#     sub-expressions: 48, 98
# 44. [A, B]
#     core type: Operation
#     operator: 49
#     operands: 50
# 45. 0(LINMAP(H, H))
#     core type: Operation
#     operator: 51
#     operand: 57
# 46. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 71\n    body: 53
# 47. A*
#     core type: Operation
#     operator: 55
#     operand: 96
# 48. B*
#     core type: Operation
#     operator: 55
#     operand: 98
# 49. commutator
#     core type: Literal
#     sub-expressions:
# 50. (A, B)
#     core type: ExprTuple
#     sub-expressions: 96, 98
# 51. 0
#     core type: Literal
#     sub-expressions:
# 52. (LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 57
# 53. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 58
#     condition: 59
# 54. (A)
#     core type: ExprTuple
#     sub-expressions: 96
# 55. Adj
#     core type: Literal
#     sub-expressions:
# 56. (B)
#     core type: ExprTuple
#     sub-expressions: 98
# 57. LINMAP(H, H)
#     core type: Operation
#     operator: 60
#     operands: 61
# 58. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))
#     core type: Operation
#     operator: 62
#     operand: 65
# 59. {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 122
#     operands: 64
# 60. LINMAP
#     core type: Literal
#     sub-expressions:
# 61. (H, H)
#     core type: ExprTuple
#     sub-expressions: 79, 79
# 62. exists
#     core type: Literal
#     sub-expressions:
# 63. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 65
# 64. ({v_{1}, v_{2}, ..., v_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 65. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Lambda
#     parameters: 68\n    body: 69
# 66. {v_{1}, v_{2}, ..., v_{n}}
#     core type: Operation
#     operator: 70
#     operands: 71
# 67. O.N.Bases(H)
#     core type: Operation
#     operator: 72
#     operand: 79
# 68. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 74, 75
# 69. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 76
#     condition: 77
# 70. Set
#     core type: Literal
#     sub-expressions:
# 71. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 78
# 72. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 73. (H)
#     core type: ExprTuple
#     sub-expressions: 79
# 74. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 80
#     start_index: 136
#     end_index: 137
# 75. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 81
#     start_index: 136
#     end_index: 137
# 76. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 83
#     operands: 82
# 77. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 83
#     operands: 84
# 78. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 85
#     start_index: 136
#     end_index: 137
# 79. H
#     core type: Variable
#     sub-expressions:
# 80. _a -> a_{_a}
#     core type: Lambda
#     parameter: 118
#     body: 109
# 81. _a -> b_{_a}
#     core type: Lambda
#     parameter: 118
#     body: 110
# 82. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: ExprTuple
#     sub-expressions: 86, 87
# 83. and
#     core type: Literal
#     sub-expressions:
# 84. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 88, 89
# 85. _a -> v_{_a}
#     core type: Lambda
#     parameter: 118
#     body: 90
# 86. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 92
#     operands: 91
# 87. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 92
#     operands: 93
# 88. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 94
#     start_index: 136
#     end_index: 137
# 89. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 95
#     start_index: 136
#     end_index: 137
# 90. v_{_a}
#     core type: IndexedVar
# variable: 142
# index: 118
# 91. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 96, 97
# 92. =
#     core type: Literal
#     sub-expressions:
# 93. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 98, 99
# 94. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 118
#     body: 100
# 95. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 118
#     body: 101
# 96. A
#     core type: Variable
#     sub-expressions:
# 97. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 103
#     operand: 107
# 98. B
#     core type: Variable
#     sub-expressions:
# 99. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 103
#     operand: 108
# 100. a_{_a} in Complex
#      core type: Operation
#      operator: 122
#      operands: 105
# 101. b_{_a} in Complex
#      core type: Operation
#      operator: 122
#      operands: 106
# 102. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#      core type: ExprTuple
#      sub-expressions: 107
# 103. Sum
#      core type: Literal
#      sub-expressions:
# 104. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#      core type: ExprTuple
#      sub-expressions: 108
# 105. (a_{_a}, Complex)
#      core type: ExprTuple
#      sub-expressions: 109, 111
# 106. (b_{_a}, Complex)
#      core type: ExprTuple
#      sub-expressions: 110, 111
# 107. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#      core type: Lambda
#      parameter: 144
#      body: 112
# 108. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#      core type: Lambda
#      parameter: 144
#      body: 113
# 109. a_{_a}
#      core type: IndexedVar
# variable: 128
# index: 118
# 110. b_{_a}
#      core type: IndexedVar
# variable: 129
# index: 118
# 111. Complex
#      core type: Literal
#      sub-expressions:
# 112. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#      core type: Conditional
#      value: 115
#      condition: 117
# 113. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#      core type: Conditional
#      value: 116
#      condition: 117
# 114. (_a)
#      core type: ExprTuple
#      sub-expressions: 118
# 115. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#      core type: Operation
#      operator: 120
#      operands: 119
# 116. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#      core type: Operation
#      operator: 120
#      operands: 121
# 117. i in {1 .. n}
#      core type: Operation
#      operator: 122
#      operands: 123
# 118. _a
#      core type: Variable
#      sub-expressions:
# 119. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 124, 126
# 120. *
#      core type: Literal
#      sub-expressions:
# 121. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 125, 126
# 122. in
#      core type: Literal
#      sub-expressions:
# 123. (i, {1 .. n})
#      core type: ExprTuple
#      sub-expressions: 144, 127
# 124. a_{i}
#      core type: IndexedVar
# variable: 128
# index: 144
# 125. b_{i}
#      core type: IndexedVar
# variable: 129
# index: 144
# 126. |v_{i}〉 . 〈v_{i}|
#      core type: Operation
#      operator: 130
#      operands: 131
# 127. {1 .. n}
#      core type: Operation
#      operator: 132
#      operands: 133
# 128. a
#      core type: Variable
#      sub-expressions:
# 129. b
#      core type: Variable
#      sub-expressions:
# 130. .
#      core type: Literal
#      sub-expressions:
# 131. (|v_{i}〉, 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 134, 135
# 132. Interval
#      core type: Literal
#      sub-expressions:
# 133. (1, n)
#      core type: ExprTuple
#      sub-expressions: 136, 137
# 134. |v_{i}〉
#      core type: Operation
#      operator: 138
#      operand: 141
# 135. 〈v_{i}|
#      core type: Operation
#      operator: 139
#      operand: 141
# 136. 1
#      core type: Literal
#      sub-expressions:
# 137. n
#      core type: Variable
#      sub-expressions:
# 138. KET
#      core type: Literal
#      sub-expressions:
# 139. BRA
#      core type: Literal
#      sub-expressions:
# 140. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 141
# 141. v_{i}
#      core type: IndexedVar
# variable: 142
# index: 144
# 142. v
#      core type: Variable
#      sub-expressions:
# 143. (i)
#      core type: ExprTuple
#      sub-expressions: 144
# 144. i
#      core type: Variable
#      sub-expressions:
