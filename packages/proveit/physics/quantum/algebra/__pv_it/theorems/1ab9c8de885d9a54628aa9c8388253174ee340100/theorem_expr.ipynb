# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#scalar_mult_factorization">scalar_mult_factorization</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.algebra import scalar_mult_factorization

# %%
# check that the built expression is the same as the stored expression
assert scalar_mult_factorization.expr == stored_expr
assert scalar_mult_factorization.expr._style_id == stored_expr._style_id
print("Passed sanity check: scalar_mult_factorization matches stored_expr")
# Out:
# Passed sanity check: scalar_mult_factorization matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{j \in \mathbb{N}^+}~\left[\forall_{a \in \mathbb{C}}~\left[\forall_{B_{1}, B_{2}, \ldots, B_{j}~|~\left(B_{1} \thinspace  B_{2} \thinspace  \ldots \thinspace  B_{j}\right) \underset{{\scriptscriptstyle c}}{\in} \mathcal{Q^*}}~\left(\begin{array}{c} \begin{array}{l} \left(a\thinspace B_{1} \thinspace  B_{2} \thinspace  \ldots \thinspace  B_{j}\right) =  \\ \left(a \cdot \left(B_{1} \thinspace  B_{2} \thinspace  \ldots \thinspace  B_{j}\right)\right) \end{array} \end{array}\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{j in NaturalPos} [forall_{a in Complex} [forall_{B_{1}, B_{2}, ..., B_{j} | (B_{1} .  B_{2} .  ... .  B_{j}) in_c Q*} ((a. B_{1} .  B_{2} .  ... .  B_{j}) =  \\ (a * (B_{1} .  B_{2} .  ... .  B_{j})))]]
#    core type: Operation
#    operator: 15
#    operand: 2
# 1. (j -> {forall_{a in Complex} [forall_{B_{1}, B_{2}, ..., B_{j} | (B_{1} .  B_{2} .  ... .  B_{j}) in_c Q*} ((a. B_{1} .  B_{2} .  ... .  B_{j}) =  \\ (a * (B_{1} .  B_{2} .  ... .  B_{j})))] if j in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. j -> {forall_{a in Complex} [forall_{B_{1}, B_{2}, ..., B_{j} | (B_{1} .  B_{2} .  ... .  B_{j}) in_c Q*} ((a. B_{1} .  B_{2} .  ... .  B_{j}) =  \\ (a * (B_{1} .  B_{2} .  ... .  B_{j})))] if j in NaturalPos.
#    core type: Lambda
#    parameter: 41
#    body: 4
# 3. (j)
#    core type: ExprTuple
#    sub-expressions: 41
# ...
