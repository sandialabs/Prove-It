# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, U, i, n
from proveit.core_expr_types import v_1_to_n, v_i, w_1_to_n, w_i
from proveit.linear_algebra import OrthoNormBases, Unitary, VecSum
from proveit.logic import CartExp, Equals, Exists, Forall, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = OrthoNormBases(CartExp(Complex, n))
expr = ExprTuple(Lambda(n, Conditional(Forall(instance_param_or_params = [U], instance_expr = Exists(instance_param_or_params = [v_1_to_n, w_1_to_n], instance_expr = Equals(U, VecSum(index_or_indices = [i], summand = Qmult(Ket(v_i), Bra(w_i)), domain = Interval(one, n))), conditions = [InSet(Set(v_1_to_n_kets), sub_expr1), InSet(Set(w_1_to_n_kets), sub_expr1)]).with_wrapping(), domain = Unitary(n)), InSet(n, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(n \mapsto \left\{\forall_{U \in \textrm{U}\left(n\right)}~\left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}, w_{1}, w_{2}, \ldots, w_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right), \left\{\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left(U = \left(\sum_{i=1}^{n} \left(\lvert v_{i} \rangle \thinspace \langle w_{i} \rvert\right)\right)\right)\end{array}\right] \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (n -> {forall_{U in U(n)} [exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)))] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{U in U(n)} [exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)))] if n in NaturalPos.
#    core type: Lambda
#    parameter: 80
#    body: 2
# 2. {forall_{U in U(n)} [exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)))] if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{U in U(n)} [exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)))]
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. n in NaturalPos
#    core type: Operation
#    operator: 57
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (U -> {exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))) if U in U(n).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 80, 9
# 8. U -> {exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))) if U in U(n).
#    core type: Lambda
#    parameter: 33
#    body: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (U)
#     core type: ExprTuple
#     sub-expressions: 33
# 11. {exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))) if U in U(n).
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)))
#     core type: Operation
#     operator: 14
#     operand: 17
# 13. U in U(n)
#     core type: Operation
#     operator: 57
#     operands: 16
# 14. exists
#     core type: Literal
#     sub-expressions:
# 15. ((v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. (U, U(n))
#     core type: ExprTuple
#     sub-expressions: 33, 18
# 17. (v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Lambda
#     parameters: 19\n    body: 20
# 18. U(n)
#     core type: Operation
#     operator: 21
#     operand: 80
# 19. (v_{1}, v_{2}, ..., v_{n},w_{1}, w_{2}, ..., w_{n})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 25
#     condition: 26
# 21. U
#     core type: Literal
#     sub-expressions:
# 22. (n)
#     core type: ExprTuple
#     sub-expressions: 80
# 23. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 79
#     end_index: 80
# 24. w_{1}, w_{2}, ..., w_{n}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 79
#     end_index: 80
# 25. U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})) and ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. _a -> v_{_a}
#     core type: Lambda
#     parameter: 93
#     body: 88
# 28. _a -> w_{_a}
#     core type: Lambda
#     parameter: 93
#     body: 89
# 29. =
#     core type: Literal
#     sub-expressions:
# 30. (U, Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. and
#     core type: Literal
#     sub-expressions:
# 32. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. U
#     core type: Variable
#     sub-expressions:
# 34. Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)
#     core type: Operation
#     operator: 37
#     operand: 41
# 35. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 57
#     operands: 39
# 36. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 57
#     operands: 40
# 37. Sum
#     core type: Literal
#     sub-expressions:
# 38. (i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 41
# 39. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 42, 44
# 40. ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 41. i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 87
#     body: 45
# 42. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 60
#     operand: 52
# 43. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}
#     core type: Operation
#     operator: 60
#     operand: 53
# 44. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 48
#     operand: 54
# 45. {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 50
#     condition: 51
# 46. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 52
# 47. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 53
# 48. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 49. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 54
# 50. |v_{i}〉 . 〈w_{i}|
#     core type: Operation
#     operator: 55
#     operands: 56
# 51. i in {1 .. n}
#     core type: Operation
#     operator: 57
#     operands: 58
# 52. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 60
#     operands: 59
# 53. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 60
#     operands: 61
# 54. Complex^{n}
#     core type: Operation
#     operator: 62
#     operands: 63
# 55. .
#     core type: Literal
#     sub-expressions:
# 56. (|v_{i}〉, 〈w_{i}|)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 57. in
#     core type: Literal
#     sub-expressions:
# 58. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 87, 66
# 59. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 67
# 60. Set
#     core type: Literal
#     sub-expressions:
# 61. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 68
# 62. CartExp
#     core type: Literal
#     sub-expressions:
# 63. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 69, 80
# 64. |v_{i}〉
#     core type: Operation
#     operator: 85
#     operand: 77
# 65. 〈w_{i}|
#     core type: Operation
#     operator: 71
#     operand: 78
# 66. {1 .. n}
#     core type: Operation
#     operator: 73
#     operands: 74
# 67. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 75
#     start_index: 79
#     end_index: 80
# 68. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 76
#     start_index: 79
#     end_index: 80
# 69. Complex
#     core type: Literal
#     sub-expressions:
# 70. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 77
# 71. BRA
#     core type: Literal
#     sub-expressions:
# 72. (w_{i})
#     core type: ExprTuple
#     sub-expressions: 78
# 73. Interval
#     core type: Literal
#     sub-expressions:
# 74. (1, n)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 75. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 93
#     body: 81
# 76. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 93
#     body: 82
# 77. v_{i}
#     core type: IndexedVar
# variable: 90
# index: 87
# 78. w_{i}
#     core type: IndexedVar
# variable: 91
# index: 87
# 79. 1
#     core type: Literal
#     sub-expressions:
# 80. n
#     core type: Variable
#     sub-expressions:
# 81. |v_{_a}〉
#     core type: Operation
#     operator: 85
#     operand: 88
# 82. |w_{_a}〉
#     core type: Operation
#     operator: 85
#     operand: 89
# 83. (i)
#     core type: ExprTuple
#     sub-expressions: 87
# 84. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 88
# 85. KET
#     core type: Literal
#     sub-expressions:
# 86. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 89
# 87. i
#     core type: Variable
#     sub-expressions:
# 88. v_{_a}
#     core type: IndexedVar
# variable: 90
# index: 93
# 89. w_{_a}
#     core type: IndexedVar
# variable: 91
# index: 93
# 90. v
#     core type: Variable
#     sub-expressions:
# 91. w
#     core type: Variable
#     sub-expressions:
# 92. (_a)
#     core type: ExprTuple
#     sub-expressions: 93
# 93. _a
#     core type: Variable
#     sub-expressions:
