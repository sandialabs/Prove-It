# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, i, n
from proveit.core_expr_types import v_1_to_n, v_i, w_1_to_n, w_i
from proveit.linear_algebra import OrthoNormBases, Unitary, VecSum
from proveit.logic import And, CartExp, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = OrthoNormBases(CartExp(Complex, n))
expr = ExprTuple(Lambda([v_1_to_n, w_1_to_n], Conditional(InSet(VecSum(index_or_indices = [i], summand = Qmult(Ket(v_i), Bra(w_i)), domain = Interval(one, n)), Unitary(n)), And(InSet(Set(v_1_to_n_kets), sub_expr1), InSet(Set(w_1_to_n_kets), sub_expr1)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(v_{1}, v_{2}, \ldots, v_{n}, w_{1}, w_{2}, \ldots, w_{n}\right) \mapsto \left\{\left(\sum_{i=1}^{n} \left(\lvert v_{i} \rangle \thinspace \langle w_{i} \rvert\right)\right) \in \textrm{U}\left(n\right) \textrm{ if } \left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right) ,  \left\{\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {(Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {(Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (v_{1}, v_{2}, ..., v_{n},w_{1}, w_{2}, ..., w_{n})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. {(Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Conditional
#    value: 6
#    condition: 7
# 4. v_{1}, v_{2}, ..., v_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 61
#    end_index: 62
# 5. w_{1}, w_{2}, ..., w_{n}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 61
#    end_index: 62
# 6. (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n)
#    core type: Operation
#    operator: 39
#    operands: 10
# 7. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})) and ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. _a -> v_{_a}
#    core type: Lambda
#    parameter: 75
#    body: 70
# 9. _a -> w_{_a}
#    core type: Lambda
#    parameter: 75
#    body: 71
# 10. (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|), U(n))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)
#     core type: Operation
#     operator: 17
#     operand: 23
# 14. U(n)
#     core type: Operation
#     operator: 19
#     operand: 62
# 15. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 39
#     operands: 21
# 16. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 39
#     operands: 22
# 17. Sum
#     core type: Literal
#     sub-expressions:
# 18. (i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 23
# 19. U
#     core type: Literal
#     sub-expressions:
# 20. (n)
#     core type: ExprTuple
#     sub-expressions: 62
# 21. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 24, 26
# 22. ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 69
#     body: 27
# 24. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 42
#     operand: 34
# 25. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}
#     core type: Operation
#     operator: 42
#     operand: 35
# 26. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 30
#     operand: 36
# 27. {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 32
#     condition: 33
# 28. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 34
# 29. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 35
# 30. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 31. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 36
# 32. |v_{i}〉 . 〈w_{i}|
#     core type: Operation
#     operator: 37
#     operands: 38
# 33. i in {1 .. n}
#     core type: Operation
#     operator: 39
#     operands: 40
# 34. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 42
#     operands: 41
# 35. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 42
#     operands: 43
# 36. Complex^{n}
#     core type: Operation
#     operator: 44
#     operands: 45
# 37. .
#     core type: Literal
#     sub-expressions:
# 38. (|v_{i}〉, 〈w_{i}|)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 69, 48
# 41. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 49
# 42. Set
#     core type: Literal
#     sub-expressions:
# 43. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 50
# 44. CartExp
#     core type: Literal
#     sub-expressions:
# 45. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 51, 62
# 46. |v_{i}〉
#     core type: Operation
#     operator: 67
#     operand: 59
# 47. 〈w_{i}|
#     core type: Operation
#     operator: 53
#     operand: 60
# 48. {1 .. n}
#     core type: Operation
#     operator: 55
#     operands: 56
# 49. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 61
#     end_index: 62
# 50. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 61
#     end_index: 62
# 51. Complex
#     core type: Literal
#     sub-expressions:
# 52. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 59
# 53. BRA
#     core type: Literal
#     sub-expressions:
# 54. (w_{i})
#     core type: ExprTuple
#     sub-expressions: 60
# 55. Interval
#     core type: Literal
#     sub-expressions:
# 56. (1, n)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 57. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 75
#     body: 63
# 58. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 75
#     body: 64
# 59. v_{i}
#     core type: IndexedVar
# variable: 72
# index: 69
# 60. w_{i}
#     core type: IndexedVar
# variable: 73
# index: 69
# 61. 1
#     core type: Literal
#     sub-expressions:
# 62. n
#     core type: Variable
#     sub-expressions:
# 63. |v_{_a}〉
#     core type: Operation
#     operator: 67
#     operand: 70
# 64. |w_{_a}〉
#     core type: Operation
#     operator: 67
#     operand: 71
# 65. (i)
#     core type: ExprTuple
#     sub-expressions: 69
# 66. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 70
# 67. KET
#     core type: Literal
#     sub-expressions:
# 68. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 71
# 69. i
#     core type: Variable
#     sub-expressions:
# 70. v_{_a}
#     core type: IndexedVar
# variable: 72
# index: 75
# 71. w_{_a}
#     core type: IndexedVar
# variable: 73
# index: 75
# 72. v
#     core type: Variable
#     sub-expressions:
# 73. w
#     core type: Variable
#     sub-expressions:
# 74. (_a)
#     core type: ExprTuple
#     sub-expressions: 75
# 75. _a
#     core type: Variable
#     sub-expressions:
