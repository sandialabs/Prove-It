# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, a, b, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, v_i
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [i]
sub_expr3 = Interval(one, n)
sub_expr4 = Qmult(Ket(v_i), Bra(v_i))
expr = ExprTuple(Lambda([a_1_to_n, b_1_to_n], Conditional(And(Equals(A, VecSum(index_or_indices = sub_expr2, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)), Equals(B, VecSum(index_or_indices = sub_expr2, summand = ScalarMult(b_i, sub_expr4), domain = sub_expr3))).with_wrapping_at(2), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, n), ExprRange(sub_expr1, InSet(IndexedVar(b, sub_expr1), Complex), one, n)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n}\right) \mapsto \left\{\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array} \textrm{ if } \left(a_{1} \in \mathbb{C}\right) ,  \left(a_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(a_{n} \in \mathbb{C}\right), \left(b_{1} \in \mathbb{C}\right) ,  \left(b_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(b_{n} \in \mathbb{C}\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#    core type: Conditional
#    value: 6
#    condition: 7
# 4. a_{1}, a_{2}, ..., a_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 62
#    end_index: 63
# 5. b_{1}, b_{2}, ..., b_{n}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 62
#    end_index: 63
# 6. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. _a -> a_{_a}
#    core type: Lambda
#    parameter: 44
#    body: 35
# 9. _a -> b_{_a}
#    core type: Lambda
#    parameter: 44
#    body: 36
# 10. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 18
#     operands: 17
# 14. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 62
#     end_index: 63
# 16. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 62
#     end_index: 63
# 17. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 20. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 44
#     body: 26
# 21. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 44
#     body: 27
# 22. A
#     core type: Variable
#     sub-expressions:
# 23. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 29
#     operand: 33
# 24. B
#     core type: Variable
#     sub-expressions:
# 25. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 29
#     operand: 34
# 26. a_{_a} in Complex
#     core type: Operation
#     operator: 48
#     operands: 31
# 27. b_{_a} in Complex
#     core type: Operation
#     operator: 48
#     operands: 32
# 28. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 33
# 29. Sum
#     core type: Literal
#     sub-expressions:
# 30. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 34
# 31. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 35, 37
# 32. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 70
#     body: 38
# 34. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 70
#     body: 39
# 35. a_{_a}
#     core type: IndexedVar
# variable: 54
# index: 44
# 36. b_{_a}
#     core type: IndexedVar
# variable: 55
# index: 44
# 37. Complex
#     core type: Literal
#     sub-expressions:
# 38. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 41
#     condition: 43
# 39. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 42
#     condition: 43
# 40. (_a)
#     core type: ExprTuple
#     sub-expressions: 44
# 41. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 46
#     operands: 45
# 42. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. i in {1 .. n}
#     core type: Operation
#     operator: 48
#     operands: 49
# 44. _a
#     core type: Variable
#     sub-expressions:
# 45. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 50, 52
# 46. *
#     core type: Literal
#     sub-expressions:
# 47. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 70, 53
# 50. a_{i}
#     core type: IndexedVar
# variable: 54
# index: 70
# 51. b_{i}
#     core type: IndexedVar
# variable: 55
# index: 70
# 52. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 56
#     operands: 57
# 53. {1 .. n}
#     core type: Operation
#     operator: 58
#     operands: 59
# 54. a
#     core type: Variable
#     sub-expressions:
# 55. b
#     core type: Variable
#     sub-expressions:
# 56. .
#     core type: Literal
#     sub-expressions:
# 57. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 58. Interval
#     core type: Literal
#     sub-expressions:
# 59. (1, n)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 60. |v_{i}〉
#     core type: Operation
#     operator: 64
#     operand: 67
# 61. 〈v_{i}|
#     core type: Operation
#     operator: 65
#     operand: 67
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. n
#     core type: Variable
#     sub-expressions:
# 64. KET
#     core type: Literal
#     sub-expressions:
# 65. BRA
#     core type: Literal
#     sub-expressions:
# 66. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 67
# 67. v_{i}
#     core type: IndexedVar
# variable: 68
# index: 70
# 68. v
#     core type: Variable
#     sub-expressions:
# 69. (i)
#     core type: ExprTuple
#     sub-expressions: 70
# 70. i
#     core type: Variable
#     sub-expressions:
