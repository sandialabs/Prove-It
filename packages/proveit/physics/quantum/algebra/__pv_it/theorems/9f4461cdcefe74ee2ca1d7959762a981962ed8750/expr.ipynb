# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, i, lambda_, m, n
from proveit.core_expr_types import a_1_to_m, a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import OrthoNormBases, ScalarMult, TensorProd, VecSum
from proveit.logic import And, CartExp, Equals, Exists, Forall, InSet, Set
from proveit.numbers import Complex, Interval, Min, NaturalPos, RealNonNeg, one
from proveit.physics.quantum import Ket, Qmult, var_ket_psi
from proveit.physics.quantum.algebra import a_1_to_m_kets, b_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
sub_expr3 = CartExp(Complex, n)
sub_expr4 = CartExp(Complex, m)
expr = Lambda([m, n], Conditional(Forall(instance_param_or_params = [var_ket_psi], instance_expr = Exists(instance_param_or_params = [a_1_to_m], instance_expr = Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(var_ket_psi, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, Qmult(Ket(a_i), Ket(b_i))), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n_kets), OrthoNormBases(sub_expr3))).with_wrapping(), condition = InSet(Set(a_1_to_m_kets), OrthoNormBases(sub_expr4))).with_wrapping(), domain = TensorProd(sub_expr4, sub_expr3)).with_wrapping(), And(InSet(m, NaturalPos), InSet(n, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(m, n\right) \mapsto \left\{\begin{array}{l}\forall_{\lvert \psi \rangle \in \mathbb{C}^{m} {\otimes} \mathbb{C}^{n}}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{m}~|~\left\{\left\{\lvert a_{1} \rangle, \lvert a_{2} \rangle, \ldots, \lvert a_{m} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{m}\right)}~\\
# \left[\begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{\left\{\lvert b_{1} \rangle, \lvert b_{2} \rangle, \ldots, \lvert b_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(\lvert \psi \rangle = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(\lvert a_{i} \rangle \thinspace \lvert b_{i} \rangle\right)\right)\right)\right)\end{array}\right]\end{array}\right]\end{array}\right]\end{array} \textrm{ if } m \in \mathbb{N}^+ ,  n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (m, n) -> {forall_{|psi> in Complex^{m} otimes Complex^{n}} [exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]]] if m in NaturalPos ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 118\n   body: 1
# 1. {forall_{|psi> in Complex^{m} otimes Complex^{n}} [exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]]] if m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{|psi> in Complex^{m} otimes Complex^{n}} [exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]]]
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 68
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (|psi> -> {exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]] if |psi> in (Complex^{m} otimes Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (m in NaturalPos, n in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. |psi> -> {exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]] if |psi> in (Complex^{m} otimes Complex^{n}).
#    core type: Lambda
#    parameter: 75
#    body: 11
# 8. m in NaturalPos
#    core type: Operation
#    operator: 98
#    operands: 12
# 9. n in NaturalPos
#    core type: Operation
#    operator: 98
#    operands: 13
# 10. (|psi>)
#     core type: ExprTuple
#     sub-expressions: 75
# 11. {exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]] if |psi> in (Complex^{m} otimes Complex^{n}).
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 121, 16
# 13. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 122, 16
# 14. exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]]
#     core type: Operation
#     operator: 44
#     operand: 19
# 15. |psi> in (Complex^{m} otimes Complex^{n})
#     core type: Operation
#     operator: 98
#     operands: 18
# 16. NaturalPos
#     core type: Literal
#     sub-expressions:
# 17. ((a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))] if {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m}).)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. (|psi>, Complex^{m} otimes Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 75, 20
# 19. (a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))] if {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m}).
#     core type: Lambda
#     parameters: 21\n    body: 22
# 20. Complex^{m} otimes Complex^{n}
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. (a_{1}, a_{2}, ..., a_{m})
#     core type: ExprTuple
#     sub-expressions: 25
# 22. {exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))] if {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m}).
#     core type: Conditional
#     value: 26
#     condition: 27
# 23. otimes
#     core type: Literal
#     sub-expressions:
# 24. (Complex^{m}, Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 42, 63
# 25. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 112
#     end_index: 121
# 26. exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]
#     core type: Operation
#     operator: 44
#     operand: 31
# 27. {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})
#     core type: Operation
#     operator: 98
#     operands: 30
# 28. _a -> a_{_a}
#     core type: Lambda
#     parameter: 104
#     body: 80
# 29. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).)
#     core type: ExprTuple
#     sub-expressions: 31
# 30. ({{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}}, O.N.Bases(Complex^{m}))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 31. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Lambda
#     parameters: 34\n    body: 35
# 32. {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}}
#     core type: Operation
#     operator: 70
#     operand: 41
# 33. O.N.Bases(Complex^{m})
#     core type: Operation
#     operator: 56
#     operand: 42
# 34. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 35. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 39
#     condition: 40
# 36. ({|a_{1}〉, |a_{2}〉, ..., |a_{m}〉})
#     core type: ExprTuple
#     sub-expressions: 41
# 37. (Complex^{m})
#     core type: ExprTuple
#     sub-expressions: 42
# 38. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 112
#     end_index: 122
# 39. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))
#     core type: Operation
#     operator: 44
#     operand: 49
# 40. {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 98
#     operands: 46
# 41. {|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}
#     core type: Operation
#     operator: 70
#     operands: 47
# 42. Complex^{m}
#     core type: Operation
#     operator: 72
#     operands: 48
# 43. _a -> b_{_a}
#     core type: Lambda
#     parameter: 104
#     body: 95
# 44. exists
#     core type: Literal
#     sub-expressions:
# 45. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 49
# 46. ({{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 47. (|a_{1}〉, |a_{2}〉, ..., |a_{m}〉)
#     core type: ExprTuple
#     sub-expressions: 52
# 48. (Complex, m)
#     core type: ExprTuple
#     sub-expressions: 79, 121
# 49. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 53\n    body: 54
# 50. {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}}
#     core type: Operation
#     operator: 70
#     operand: 62
# 51. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 56
#     operand: 63
# 52. |a_{1}〉, |a_{2}〉, ..., |a_{m}〉
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 112
#     end_index: 121
# 53. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 59
# 54. {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 60
#     condition: 61
# 55. ({|b_{1}〉, |b_{2}〉, ..., |b_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 62
# 56. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 57. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 63
# 58. _a -> |a_{_a}〉
#     core type: Lambda
#     parameter: 104
#     body: 64
# 59. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 65
#     start_index: 112
#     end_index: 113
# 60. |psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#     core type: Operation
#     operator: 66
#     operands: 67
# 61. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 68
#     operands: 69
# 62. {|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}
#     core type: Operation
#     operator: 70
#     operands: 71
# 63. Complex^{n}
#     core type: Operation
#     operator: 72
#     operands: 73
# 64. |a_{_a}〉
#     core type: Operation
#     operator: 115
#     operand: 80
# 65. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 104
#     body: 93
# 66. =
#     core type: Literal
#     sub-expressions:
# 67. (|psi>, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 68. and
#     core type: Literal
#     sub-expressions:
# 69. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 77
# 70. Set
#     core type: Literal
#     sub-expressions:
# 71. (|b_{1}〉, |b_{2}〉, ..., |b_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 78
# 72. CartExp
#     core type: Literal
#     sub-expressions:
# 73. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 79, 122
# 74. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 80
# 75. |psi>
#     core type: Variable
#     sub-expressions:
# 76. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))
#     core type: Operation
#     operator: 81
#     operand: 85
# 77. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 83
#     start_index: 112
#     end_index: 113
# 78. |b_{1}〉, |b_{2}〉, ..., |b_{n}〉
#     core type: ExprRange
#     lambda_map: 84
#     start_index: 112
#     end_index: 122
# 79. Complex
#     core type: Literal
#     sub-expressions:
# 80. a_{_a}
#     core type: IndexedVar
# variable: 123
# index: 104
# 81. Sum
#     core type: Literal
#     sub-expressions:
# 82. (i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 85
# 83. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 104
#     body: 86
# 84. _a -> |b_{_a}〉
#     core type: Lambda
#     parameter: 104
#     body: 87
# 85. i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 126
#     body: 88
# 86. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 98
#     operands: 89
# 87. |b_{_a}〉
#     core type: Operation
#     operator: 115
#     operand: 95
# 88. {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 91
#     condition: 92
# 89. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 93, 94
# 90. (b_{_a})
#     core type: ExprTuple
#     sub-expressions: 95
# 91. lambda_{i} * (|a_{i}〉 . |b_{i}〉)
#     core type: Operation
#     operator: 96
#     operands: 97
# 92. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 98
#     operands: 99
# 93. lambda_{_a}
#     core type: IndexedVar
# variable: 105
# index: 104
# 94. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 95. b_{_a}
#     core type: IndexedVar
# variable: 124
# index: 104
# 96. *
#     core type: Literal
#     sub-expressions:
# 97. (lambda_{i}, |a_{i}〉 . |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 101, 102
# 98. in
#     core type: Literal
#     sub-expressions:
# 99. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 126, 103
# 100. (_a)
#      core type: ExprTuple
#      sub-expressions: 104
# 101. lambda_{i}
#      core type: IndexedVar
# variable: 105
# index: 126
# 102. |a_{i}〉 . |b_{i}〉
#      core type: Operation
#      operator: 106
#      operands: 107
# 103. {1 .. Min(m, n)}
#      core type: Operation
#      operator: 108
#      operands: 109
# 104. _a
#      core type: Variable
#      sub-expressions:
# 105. lambda
#      core type: Variable
#      sub-expressions:
# 106. .
#      core type: Literal
#      sub-expressions:
# 107. (|a_{i}〉, |b_{i}〉)
#      core type: ExprTuple
#      sub-expressions: 110, 111
# 108. Interval
#      core type: Literal
#      sub-expressions:
# 109. (1, Min(m, n))
#      core type: ExprTuple
#      sub-expressions: 112, 113
# 110. |a_{i}〉
#      core type: Operation
#      operator: 115
#      operand: 119
# 111. |b_{i}〉
#      core type: Operation
#      operator: 115
#      operand: 120
# 112. 1
#      core type: Literal
#      sub-expressions:
# 113. Min(m, n)
#      core type: Operation
#      operator: 117
#      operands: 118
# 114. (a_{i})
#      core type: ExprTuple
#      sub-expressions: 119
# 115. KET
#      core type: Literal
#      sub-expressions:
# 116. (b_{i})
#      core type: ExprTuple
#      sub-expressions: 120
# 117. Min
#      core type: Literal
#      sub-expressions:
# 118. (m, n)
#      core type: ExprTuple
#      sub-expressions: 121, 122
# 119. a_{i}
#      core type: IndexedVar
# variable: 123
# index: 126
# 120. b_{i}
#      core type: IndexedVar
# variable: 124
# index: 126
# 121. m
#      core type: Variable
#      sub-expressions:
# 122. n
#      core type: Variable
#      sub-expressions:
# 123. a
#      core type: Variable
#      sub-expressions:
# 124. b
#      core type: Variable
#      sub-expressions:
# 125. (i)
#      core type: ExprTuple
#      sub-expressions: 126
# 126. i
#      core type: Variable
#      sub-expressions:
