# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Iff.html">Iff</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, v_1_to_n, v_i
from proveit.linear_algebra import Commutator, MatrixSpace, OrthoNormBases, ScalarMult, VecSum, VecZero
from proveit.logic import And, CartExp, Equals, Exists, Iff, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Interval(one, n)
sub_expr3 = Qmult(Ket(v_i), Bra(v_i))
expr = Iff(Equals(Commutator(A, B), VecZero(MatrixSpace(field = Complex, rows = n, columns = n))), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr3), domain = sub_expr2)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr3), domain = sub_expr2))).with_wrapping_at(2), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n), OrthoNormBases(CartExp(Complex, n)))).with_wrapping()).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left(\left[A, B\right] = \vec{0}\left(\mathbb{C}^{n \times n}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{v_{1}, v_{2}, \ldots, v_{n}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array}\right)\end{array}\right]\end{array}\right] \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=>
#    core type: Literal
#    sub-expressions:
# 2. ([A, B] = 0(Complex^{n x n}), exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [A, B] = 0(Complex^{n x n})
#    core type: Operation
#    operator: 52
#    operands: 5
# 4. exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]
#    core type: Operation
#    operator: 20
#    operand: 9
# 5. ([A, B], 0(Complex^{n x n}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. [A, B]
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. 0(Complex^{n x n})
#    core type: Operation
#    operator: 12
#    operand: 15
# 9. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 29\n   body: 14
# 10. commutator
#     core type: Literal
#     sub-expressions:
# 11. (A, B)
#     core type: ExprTuple
#     sub-expressions: 56, 58
# 12. 0
#     core type: Literal
#     sub-expressions:
# 13. (Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 16
#     condition: 17
# 15. Complex^{n x n}
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))
#     core type: Operation
#     operator: 20
#     operand: 23
# 17. {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 82
#     operands: 22
# 18. MSpace
#     core type: Literal
#     sub-expressions:
# 19. {field:Complex, rows:n, columns:n}
#     core type: NamedExprs
#     field: 71
#     rows: 97
#     columns: 97
# 20. exists
#     core type: Literal
#     sub-expressions:
# 21. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. ({v_{1}, v_{2}, ..., v_{n}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Lambda
#     parameters: 26\n    body: 27
# 24. {v_{1}, v_{2}, ..., v_{n}}
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 30
#     operand: 37
# 26. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 27. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 34
#     condition: 35
# 28. Set
#     core type: Literal
#     sub-expressions:
# 29. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 36
# 30. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 31. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 37
# 32. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 96
#     end_index: 97
# 33. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 96
#     end_index: 97
# 34. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 41
#     operands: 40
# 35. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 41
#     operands: 42
# 36. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 96
#     end_index: 97
# 37. Complex^{n}
#     core type: Operation
#     operator: 44
#     operands: 45
# 38. _a -> a_{_a}
#     core type: Lambda
#     parameter: 78
#     body: 69
# 39. _a -> b_{_a}
#     core type: Lambda
#     parameter: 78
#     body: 70
# 40. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 41. and
#     core type: Literal
#     sub-expressions:
# 42. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 43. _a -> v_{_a}
#     core type: Lambda
#     parameter: 78
#     body: 50
# 44. CartExp
#     core type: Literal
#     sub-expressions:
# 45. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 71, 97
# 46. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 52
#     operands: 51
# 47. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 96
#     end_index: 97
# 49. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 55
#     start_index: 96
#     end_index: 97
# 50. v_{_a}
#     core type: IndexedVar
# variable: 102
# index: 78
# 51. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 52. =
#     core type: Literal
#     sub-expressions:
# 53. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 54. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 78
#     body: 60
# 55. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 78
#     body: 61
# 56. A
#     core type: Variable
#     sub-expressions:
# 57. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 63
#     operand: 67
# 58. B
#     core type: Variable
#     sub-expressions:
# 59. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 63
#     operand: 68
# 60. a_{_a} in Complex
#     core type: Operation
#     operator: 82
#     operands: 65
# 61. b_{_a} in Complex
#     core type: Operation
#     operator: 82
#     operands: 66
# 62. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 67
# 63. Sum
#     core type: Literal
#     sub-expressions:
# 64. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 68
# 65. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 69, 71
# 66. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 67. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 104
#     body: 72
# 68. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 104
#     body: 73
# 69. a_{_a}
#     core type: IndexedVar
# variable: 88
# index: 78
# 70. b_{_a}
#     core type: IndexedVar
# variable: 89
# index: 78
# 71. Complex
#     core type: Literal
#     sub-expressions:
# 72. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 75
#     condition: 77
# 73. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 76
#     condition: 77
# 74. (_a)
#     core type: ExprTuple
#     sub-expressions: 78
# 75. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 80
#     operands: 79
# 76. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 80
#     operands: 81
# 77. i in {1 .. n}
#     core type: Operation
#     operator: 82
#     operands: 83
# 78. _a
#     core type: Variable
#     sub-expressions:
# 79. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 84, 86
# 80. *
#     core type: Literal
#     sub-expressions:
# 81. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 85, 86
# 82. in
#     core type: Literal
#     sub-expressions:
# 83. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 104, 87
# 84. a_{i}
#     core type: IndexedVar
# variable: 88
# index: 104
# 85. b_{i}
#     core type: IndexedVar
# variable: 89
# index: 104
# 86. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 90
#     operands: 91
# 87. {1 .. n}
#     core type: Operation
#     operator: 92
#     operands: 93
# 88. a
#     core type: Variable
#     sub-expressions:
# 89. b
#     core type: Variable
#     sub-expressions:
# 90. .
#     core type: Literal
#     sub-expressions:
# 91. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 94, 95
# 92. Interval
#     core type: Literal
#     sub-expressions:
# 93. (1, n)
#     core type: ExprTuple
#     sub-expressions: 96, 97
# 94. |v_{i}〉
#     core type: Operation
#     operator: 98
#     operand: 101
# 95. 〈v_{i}|
#     core type: Operation
#     operator: 99
#     operand: 101
# 96. 1
#     core type: Literal
#     sub-expressions:
# 97. n
#     core type: Variable
#     sub-expressions:
# 98. KET
#     core type: Literal
#     sub-expressions:
# 99. BRA
#     core type: Literal
#     sub-expressions:
# 100. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 101
# 101. v_{i}
#      core type: IndexedVar
# variable: 102
# index: 104
# 102. v
#      core type: Variable
#      sub-expressions:
# 103. (i)
#      core type: ExprTuple
#      sub-expressions: 104
# 104. i
#      core type: Variable
#      sub-expressions:
