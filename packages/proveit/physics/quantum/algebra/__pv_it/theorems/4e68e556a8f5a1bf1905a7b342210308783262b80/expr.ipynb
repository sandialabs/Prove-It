# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, X, i, n
from proveit.core_expr_types import x_1_to_n, x_i
from proveit.linear_algebra import HilbertSpaces, Hspace, OrthoNormBases, OrthoProj, VecSum
from proveit.logic import Equals, Forall, InClass, InSet, SubsetEq
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import x_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(Hspace, Conditional(Forall(instance_param_or_params = [X], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(OrthoProj(Hspace, X), VecSum(index_or_indices = [i], summand = Qmult(Ket(x_i), Bra(x_i)), domain = Interval(one, n))), condition = InSet(x_1_to_n_kets, OrthoNormBases(Hspace))).with_wrapping(), domain = NaturalPos), condition = SubsetEq(X, Hspace)), InClass(Hspace, HilbertSpaces))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\mathcal{H} \mapsto \left\{\forall_{X~|~X \subseteq \mathcal{H}}~\left[\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{\lvert x_{1} \rangle, \lvert x_{2} \rangle, \ldots, \lvert x_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left(\textrm{OrthoProj}\left(\mathcal{H}, X\right) = \left(\sum_{i=1}^{n} \left(\lvert x_{i} \rangle \thinspace \langle x_{i} \rvert\right)\right)\right)\end{array}\right]\right] \textrm{ if } \mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (H -> {forall_{X | X subset_eq H} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]] if H in_c HilbertSpaces.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. H -> {forall_{X | X subset_eq H} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]] if H in_c HilbertSpaces.
#    core type: Lambda
#    parameter: 51
#    body: 2
# 2. {forall_{X | X subset_eq H} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]] if H in_c HilbertSpaces.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{X | X subset_eq H} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]]
#    core type: Operation
#    operator: 22
#    operand: 8
# 4. H in_c HilbertSpaces
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (X -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in_c
#    core type: Literal
#    sub-expressions:
# 7. (H, HilbertSpaces)
#    core type: ExprTuple
#    sub-expressions: 51, 9
# 8. X -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.
#    core type: Lambda
#    parameter: 48
#    body: 11
# 9. HilbertSpaces
#    core type: Literal
#    sub-expressions:
# 10. (X)
#     core type: ExprTuple
#     sub-expressions: 48
# 11. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]
#     core type: Operation
#     operator: 22
#     operand: 17
# 13. X subset_eq H
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.)
#     core type: ExprTuple
#     sub-expressions: 17
# 15. subset_eq
#     core type: Literal
#     sub-expressions:
# 16. (X, H)
#     core type: ExprTuple
#     sub-expressions: 48, 51
# 17. n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#     core type: Lambda
#     parameter: 74
#     body: 19
# 18. (n)
#     core type: ExprTuple
#     sub-expressions: 74
# 19. {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#     core type: Conditional
#     value: 20
#     condition: 21
# 20. forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))
#     core type: Operation
#     operator: 22
#     operand: 25
# 21. n in NaturalPos
#     core type: Operation
#     operator: 59
#     operands: 24
# 22. forall
#     core type: Literal
#     sub-expressions:
# 23. ((x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 25
# 24. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 74, 26
# 25. (x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 27\n    body: 28
# 26. NaturalPos
#     core type: Literal
#     sub-expressions:
# 27. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 29
# 28. {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Conditional
#     value: 30
#     condition: 31
# 29. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 73
#     end_index: 74
# 30. OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)
#     core type: Operation
#     operator: 59
#     operands: 35
# 32. _a -> x_{_a}
#     core type: Lambda
#     parameter: 75
#     body: 65
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. (OrthoProj(H, X), Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 35. ({|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. OrthoProj(H, X)
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)
#     core type: Operation
#     operator: 42
#     operand: 49
# 38. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}
#     core type: Operation
#     operator: 44
#     operands: 45
# 39. O.N.Bases(H)
#     core type: Operation
#     operator: 46
#     operand: 51
# 40. OrthoProj
#     core type: Literal
#     sub-expressions:
# 41. (H, X)
#     core type: ExprTuple
#     sub-expressions: 51, 48
# 42. Sum
#     core type: Literal
#     sub-expressions:
# 43. (i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 49
# 44. Set
#     core type: Literal
#     sub-expressions:
# 45. (|x_{1}〉, |x_{2}〉, ..., |x_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 50
# 46. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 47. (H)
#     core type: ExprTuple
#     sub-expressions: 51
# 48. X
#     core type: Variable
#     sub-expressions:
# 49. i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 78
#     body: 52
# 50. |x_{1}〉, |x_{2}〉, ..., |x_{n}〉
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 73
#     end_index: 74
# 51. H
#     core type: Variable
#     sub-expressions:
# 52. {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 54
#     condition: 55
# 53. _a -> |x_{_a}〉
#     core type: Lambda
#     parameter: 75
#     body: 56
# 54. |x_{i}〉 . 〈x_{i}|
#     core type: Operation
#     operator: 57
#     operands: 58
# 55. i in {1 .. n}
#     core type: Operation
#     operator: 59
#     operands: 60
# 56. |x_{_a}〉
#     core type: Operation
#     operator: 66
#     operand: 65
# 57. .
#     core type: Literal
#     sub-expressions:
# 58. (|x_{i}〉, 〈x_{i}|)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 59. in
#     core type: Literal
#     sub-expressions:
# 60. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 78, 64
# 61. (x_{_a})
#     core type: ExprTuple
#     sub-expressions: 65
# 62. |x_{i}〉
#     core type: Operation
#     operator: 66
#     operand: 72
# 63. 〈x_{i}|
#     core type: Operation
#     operator: 67
#     operand: 72
# 64. {1 .. n}
#     core type: Operation
#     operator: 69
#     operands: 70
# 65. x_{_a}
#     core type: IndexedVar
# variable: 76
# index: 75
# 66. KET
#     core type: Literal
#     sub-expressions:
# 67. BRA
#     core type: Literal
#     sub-expressions:
# 68. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 72
# 69. Interval
#     core type: Literal
#     sub-expressions:
# 70. (1, n)
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 71. (_a)
#     core type: ExprTuple
#     sub-expressions: 75
# 72. x_{i}
#     core type: IndexedVar
# variable: 76
# index: 78
# 73. 1
#     core type: Literal
#     sub-expressions:
# 74. n
#     core type: Variable
#     sub-expressions:
# 75. _a
#     core type: Variable
#     sub-expressions:
# 76. x
#     core type: Variable
#     sub-expressions:
# 77. (i)
#     core type: ExprTuple
#     sub-expressions: 78
# 78. i
#     core type: Variable
#     sub-expressions:
