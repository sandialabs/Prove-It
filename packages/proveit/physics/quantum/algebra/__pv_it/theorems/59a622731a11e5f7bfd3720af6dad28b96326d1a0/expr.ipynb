# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Iff.html">Iff</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, v_1_to_n, v_i
from proveit.linear_algebra import Commutator, Hspace, LinMap, OrthoNormBases, ScalarMult, VecSum, VecZero
from proveit.logic import And, Equals, Exists, Iff, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Interval(one, n)
sub_expr3 = Qmult(Ket(v_i), Bra(v_i))
expr = Iff(Equals(Commutator(A, B), VecZero(LinMap(Hspace, Hspace))), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr3), domain = sub_expr2)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr3), domain = sub_expr2))).with_wrapping_at(2), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left(\left[A, B\right] = \vec{0}\left(\mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{v_{1}, v_{2}, \ldots, v_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array}\right)\end{array}\right]\end{array}\right] \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=>
#    core type: Literal
#    sub-expressions:
# 2. ([A, B] = 0(LINMAP(H, H)), exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [A, B] = 0(LINMAP(H, H))
#    core type: Operation
#    operator: 50
#    operands: 5
# 4. exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]
#    core type: Operation
#    operator: 20
#    operand: 9
# 5. ([A, B], 0(LINMAP(H, H)))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. [A, B]
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. 0(LINMAP(H, H))
#    core type: Operation
#    operator: 12
#    operand: 15
# 9. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).
#    core type: Lambda
#    parameters: 29\n   body: 14
# 10. commutator
#     core type: Literal
#     sub-expressions:
# 11. (A, B)
#     core type: ExprTuple
#     sub-expressions: 54, 56
# 12. 0
#     core type: Literal
#     sub-expressions:
# 13. (LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 15
# 14. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 16
#     condition: 17
# 15. LINMAP(H, H)
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))
#     core type: Operation
#     operator: 20
#     operand: 23
# 17. {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 80
#     operands: 22
# 18. LINMAP
#     core type: Literal
#     sub-expressions:
# 19. (H, H)
#     core type: ExprTuple
#     sub-expressions: 37, 37
# 20. exists
#     core type: Literal
#     sub-expressions:
# 21. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. ({v_{1}, v_{2}, ..., v_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Lambda
#     parameters: 26\n    body: 27
# 24. {v_{1}, v_{2}, ..., v_{n}}
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. O.N.Bases(H)
#     core type: Operation
#     operator: 30
#     operand: 37
# 26. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 27. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 34
#     condition: 35
# 28. Set
#     core type: Literal
#     sub-expressions:
# 29. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 36
# 30. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 31. (H)
#     core type: ExprTuple
#     sub-expressions: 37
# 32. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 94
#     end_index: 95
# 33. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 94
#     end_index: 95
# 34. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 41
#     operands: 40
# 35. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 41
#     operands: 42
# 36. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 94
#     end_index: 95
# 37. H
#     core type: Variable
#     sub-expressions:
# 38. _a -> a_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 67
# 39. _a -> b_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 68
# 40. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. and
#     core type: Literal
#     sub-expressions:
# 42. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. _a -> v_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 48
# 44. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 50
#     operands: 49
# 45. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 94
#     end_index: 95
# 47. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 94
#     end_index: 95
# 48. v_{_a}
#     core type: IndexedVar
# variable: 100
# index: 76
# 49. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 50. =
#     core type: Literal
#     sub-expressions:
# 51. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 52. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 76
#     body: 58
# 53. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 76
#     body: 59
# 54. A
#     core type: Variable
#     sub-expressions:
# 55. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 61
#     operand: 65
# 56. B
#     core type: Variable
#     sub-expressions:
# 57. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 61
#     operand: 66
# 58. a_{_a} in Complex
#     core type: Operation
#     operator: 80
#     operands: 63
# 59. b_{_a} in Complex
#     core type: Operation
#     operator: 80
#     operands: 64
# 60. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 65
# 61. Sum
#     core type: Literal
#     sub-expressions:
# 62. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 66
# 63. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 67, 69
# 64. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 65. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 102
#     body: 70
# 66. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 102
#     body: 71
# 67. a_{_a}
#     core type: IndexedVar
# variable: 86
# index: 76
# 68. b_{_a}
#     core type: IndexedVar
# variable: 87
# index: 76
# 69. Complex
#     core type: Literal
#     sub-expressions:
# 70. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 73
#     condition: 75
# 71. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 74
#     condition: 75
# 72. (_a)
#     core type: ExprTuple
#     sub-expressions: 76
# 73. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 78
#     operands: 77
# 74. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 78
#     operands: 79
# 75. i in {1 .. n}
#     core type: Operation
#     operator: 80
#     operands: 81
# 76. _a
#     core type: Variable
#     sub-expressions:
# 77. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 82, 84
# 78. *
#     core type: Literal
#     sub-expressions:
# 79. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 80. in
#     core type: Literal
#     sub-expressions:
# 81. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 102, 85
# 82. a_{i}
#     core type: IndexedVar
# variable: 86
# index: 102
# 83. b_{i}
#     core type: IndexedVar
# variable: 87
# index: 102
# 84. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 88
#     operands: 89
# 85. {1 .. n}
#     core type: Operation
#     operator: 90
#     operands: 91
# 86. a
#     core type: Variable
#     sub-expressions:
# 87. b
#     core type: Variable
#     sub-expressions:
# 88. .
#     core type: Literal
#     sub-expressions:
# 89. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 90. Interval
#     core type: Literal
#     sub-expressions:
# 91. (1, n)
#     core type: ExprTuple
#     sub-expressions: 94, 95
# 92. |v_{i}〉
#     core type: Operation
#     operator: 96
#     operand: 99
# 93. 〈v_{i}|
#     core type: Operation
#     operator: 97
#     operand: 99
# 94. 1
#     core type: Literal
#     sub-expressions:
# 95. n
#     core type: Variable
#     sub-expressions:
# 96. KET
#     core type: Literal
#     sub-expressions:
# 97. BRA
#     core type: Literal
#     sub-expressions:
# 98. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 99
# 99. v_{i}
#     core type: IndexedVar
# variable: 100
# index: 102
# 100. v
#      core type: Variable
#      sub-expressions:
# 101. (i)
#      core type: ExprTuple
#      sub-expressions: 102
# 102. i
#      core type: Variable
#      sub-expressions:
