# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprTuple, Lambda, V, W, i, j, m, n
from proveit.core_expr_types import v_1_to_m, v_i, w_1_to_n, w_j
from proveit.linear_algebra import OrthoNormBases, VecSum
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_m_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([m, n], Conditional(Forall(instance_param_or_params = [v_1_to_m], instance_expr = Forall(instance_param_or_params = [w_1_to_n], instance_expr = Equals(A, VecSum(index_or_indices = [i], summand = VecSum(index_or_indices = [j], summand = Qmult(Bra(w_j), A, Ket(v_i), Ket(w_j), Bra(v_i)), domain = Interval(one, n)), domain = Interval(one, m))), condition = InSet(w_1_to_n_kets, OrthoNormBases(W))).with_wrapping(), condition = InSet(v_1_to_m_kets, OrthoNormBases(V))).with_wrapping(), And(InSet(m, NaturalPos), InSet(n, NaturalPos)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(m, n\right) \mapsto \left\{\begin{array}{l}\forall_{v_{1}, v_{2}, \ldots, v_{m}~|~\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{m} \rangle\right\} \in \textrm{O.N.Bases}\left(V\right)}~\\
# \left[\begin{array}{l}\forall_{w_{1}, w_{2}, \ldots, w_{n}~|~\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(W\right)}~\\
# \left(A = \left(\sum_{i=1}^{m} \left(\sum_{j=1}^{n} \left(\langle w_{j} \rvert \thinspace A \thinspace \lvert v_{i} \rangle \thinspace \lvert w_{j} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}\right]\end{array} \textrm{ if } m \in \mathbb{N}^+ ,  n \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((m, n) -> {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (m, n) -> {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (m, n)
#    core type: ExprTuple
#    sub-expressions: 72, 93
# 3. {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]
#    core type: Operation
#    operator: 21
#    operand: 9
# 5. (m in NaturalPos) and (n in NaturalPos)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. ((v_{1}, v_{2}, ..., v_{m}) -> {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (m in NaturalPos, n in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (v_{1}, v_{2}, ..., v_{m}) -> {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).
#    core type: Lambda
#    parameters: 12\n   body: 13
# 10. m in NaturalPos
#     core type: Operation
#     operator: 76
#     operands: 14
# 11. n in NaturalPos
#     core type: Operation
#     operator: 76
#     operands: 15
# 12. (v_{1}, v_{2}, ..., v_{m})
#     core type: ExprTuple
#     sub-expressions: 16
# 13. {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).
#     core type: Conditional
#     value: 17
#     condition: 18
# 14. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 72, 19
# 15. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 93, 19
# 16. v_{1}, v_{2}, ..., v_{m}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 92
#     end_index: 72
# 17. forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 21
#     operand: 24
# 18. {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)
#     core type: Operation
#     operator: 76
#     operands: 23
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. _a -> v_{_a}
#     core type: Lambda
#     parameter: 73
#     body: 54
# 21. forall
#     core type: Literal
#     sub-expressions:
# 22. ((w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. ({|v_{1}〉, |v_{2}〉, ..., |v_{m}〉}, O.N.Bases(V))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. (w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#     core type: Lambda
#     parameters: 27\n    body: 28
# 25. {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉}
#     core type: Operation
#     operator: 46
#     operands: 29
# 26. O.N.Bases(V)
#     core type: Operation
#     operator: 48
#     operand: 35
# 27. (w_{1}, w_{2}, ..., w_{n})
#     core type: ExprTuple
#     sub-expressions: 31
# 28. {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#     core type: Conditional
#     value: 32
#     condition: 33
# 29. (|v_{1}〉, |v_{2}〉, ..., |v_{m}〉)
#     core type: ExprTuple
#     sub-expressions: 34
# 30. (V)
#     core type: ExprTuple
#     sub-expressions: 35
# 31. w_{1}, w_{2}, ..., w_{n}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 92
#     end_index: 93
# 32. A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 37
#     operands: 38
# 33. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)
#     core type: Operation
#     operator: 76
#     operands: 39
# 34. |v_{1}〉, |v_{2}〉, ..., |v_{m}〉
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 92
#     end_index: 72
# 35. V
#     core type: Variable
#     sub-expressions:
# 36. _a -> w_{_a}
#     core type: Lambda
#     parameter: 73
#     body: 66
# 37. =
#     core type: Literal
#     sub-expressions:
# 38. (A, Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 79, 41
# 39. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}, O.N.Bases(W))
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 40. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 73
#     body: 44
# 41. Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 60
#     operand: 51
# 42. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. O.N.Bases(W)
#     core type: Operation
#     operator: 48
#     operand: 53
# 44. |v_{_a}〉
#     core type: Operation
#     operator: 84
#     operand: 54
# 45. (i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 51
# 46. Set
#     core type: Literal
#     sub-expressions:
# 47. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 52
# 48. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 49. (W)
#     core type: ExprTuple
#     sub-expressions: 53
# 50. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 54
# 51. i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Lambda
#     parameter: 99
#     body: 55
# 52. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 92
#     end_index: 93
# 53. W
#     core type: Variable
#     sub-expressions:
# 54. v_{_a}
#     core type: IndexedVar
# variable: 96
# index: 73
# 55. {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Conditional
#     value: 57
#     condition: 58
# 56. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 73
#     body: 59
# 57. Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 60
#     operand: 64
# 58. i in {1 .. m}
#     core type: Operation
#     operator: 76
#     operands: 62
# 59. |w_{_a}〉
#     core type: Operation
#     operator: 84
#     operand: 66
# 60. Sum
#     core type: Literal
#     sub-expressions:
# 61. (j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 64
# 62. (i, {1 .. m})
#     core type: ExprTuple
#     sub-expressions: 99, 65
# 63. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 66
# 64. j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Lambda
#     parameter: 98
#     body: 67
# 65. {1 .. m}
#     core type: Operation
#     operator: 88
#     operands: 68
# 66. w_{_a}
#     core type: IndexedVar
# variable: 94
# index: 73
# 67. {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Conditional
#     value: 70
#     condition: 71
# 68. (1, m)
#     core type: ExprTuple
#     sub-expressions: 92, 72
# 69. (_a)
#     core type: ExprTuple
#     sub-expressions: 73
# 70. 〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 74
#     operands: 75
# 71. j in {1 .. n}
#     core type: Operation
#     operator: 76
#     operands: 77
# 72. m
#     core type: Variable
#     sub-expressions:
# 73. _a
#     core type: Variable
#     sub-expressions:
# 74. .
#     core type: Literal
#     sub-expressions:
# 75. (〈w_{j}|, A, |v_{i}〉, |w_{j}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 78, 79, 80, 81, 82
# 76. in
#     core type: Literal
#     sub-expressions:
# 77. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 98, 83
# 78. 〈w_{j}|
#     core type: Operation
#     operator: 86
#     operand: 90
# 79. A
#     core type: Variable
#     sub-expressions:
# 80. |v_{i}〉
#     core type: Operation
#     operator: 84
#     operand: 91
# 81. |w_{j}〉
#     core type: Operation
#     operator: 84
#     operand: 90
# 82. 〈v_{i}|
#     core type: Operation
#     operator: 86
#     operand: 91
# 83. {1 .. n}
#     core type: Operation
#     operator: 88
#     operands: 89
# 84. KET
#     core type: Literal
#     sub-expressions:
# 85. (w_{j})
#     core type: ExprTuple
#     sub-expressions: 90
# 86. BRA
#     core type: Literal
#     sub-expressions:
# 87. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 91
# 88. Interval
#     core type: Literal
#     sub-expressions:
# 89. (1, n)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 90. w_{j}
#     core type: IndexedVar
# variable: 94
# index: 98
# 91. v_{i}
#     core type: IndexedVar
# variable: 96
# index: 99
# 92. 1
#     core type: Literal
#     sub-expressions:
# 93. n
#     core type: Variable
#     sub-expressions:
# 94. w
#     core type: Variable
#     sub-expressions:
# 95. (j)
#     core type: ExprTuple
#     sub-expressions: 98
# 96. v
#     core type: Variable
#     sub-expressions:
# 97. (i)
#     core type: ExprTuple
#     sub-expressions: 99
# 98. j
#     core type: Variable
#     sub-expressions:
# 99. i
#     core type: Variable
#     sub-expressions:
