# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, ExprTuple, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, v_1_to_n, v_i
from proveit.linear_algebra import Commutator, Hspace, LinMap, OrthoNormBases, ScalarMult, VecSum, VecZero
from proveit.logic import And, Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Interval(one, n)
sub_expr3 = Qmult(Ket(v_i), Bra(v_i))
expr = ExprTuple(Equals(Commutator(A, B), VecZero(LinMap(Hspace, Hspace))), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr3), domain = sub_expr2)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr3), domain = sub_expr2))).with_wrapping_at(2), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n), OrthoNormBases(Hspace))).with_wrapping())
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left[A, B\right] = \vec{0}\left(\mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)\right), \begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{v_{1}, v_{2}, \ldots, v_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array}\right)\end{array}\right]\end{array}\right)

# %%
stored_expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ([A, B] = 0(LINMAP(H, H)), exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. [A, B] = 0(LINMAP(H, H))
#    core type: Operation
#    operator: 48
#    operands: 3
# 2. exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]
#    core type: Operation
#    operator: 18
#    operand: 7
# 3. ([A, B], 0(LINMAP(H, H)))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. [A, B]
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. 0(LINMAP(H, H))
#    core type: Operation
#    operator: 10
#    operand: 13
# 7. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).
#    core type: Lambda
#    parameters: 27\n   body: 12
# 8. commutator
#    core type: Literal
#    sub-expressions:
# 9. (A, B)
#    core type: ExprTuple
#    sub-expressions: 52, 54
# 10. 0
#     core type: Literal
#     sub-expressions:
# 11. (LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 13
# 12. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. LINMAP(H, H)
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))
#     core type: Operation
#     operator: 18
#     operand: 21
# 15. {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 78
#     operands: 20
# 16. LINMAP
#     core type: Literal
#     sub-expressions:
# 17. (H, H)
#     core type: ExprTuple
#     sub-expressions: 35, 35
# 18. exists
#     core type: Literal
#     sub-expressions:
# 19. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. ({v_{1}, v_{2}, ..., v_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Lambda
#     parameters: 24\n    body: 25
# 22. {v_{1}, v_{2}, ..., v_{n}}
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. O.N.Bases(H)
#     core type: Operation
#     operator: 28
#     operand: 35
# 24. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 25. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 32
#     condition: 33
# 26. Set
#     core type: Literal
#     sub-expressions:
# 27. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 34
# 28. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 29. (H)
#     core type: ExprTuple
#     sub-expressions: 35
# 30. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 92
#     end_index: 93
# 31. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 92
#     end_index: 93
# 32. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 39
#     operands: 38
# 33. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 39
#     operands: 40
# 34. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 92
#     end_index: 93
# 35. H
#     core type: Variable
#     sub-expressions:
# 36. _a -> a_{_a}
#     core type: Lambda
#     parameter: 74
#     body: 65
# 37. _a -> b_{_a}
#     core type: Lambda
#     parameter: 74
#     body: 66
# 38. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 39. and
#     core type: Literal
#     sub-expressions:
# 40. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. _a -> v_{_a}
#     core type: Lambda
#     parameter: 74
#     body: 46
# 42. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 48
#     operands: 47
# 43. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 48
#     operands: 49
# 44. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 92
#     end_index: 93
# 45. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 92
#     end_index: 93
# 46. v_{_a}
#     core type: IndexedVar
# variable: 98
# index: 74
# 47. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 48. =
#     core type: Literal
#     sub-expressions:
# 49. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 50. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 74
#     body: 56
# 51. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 74
#     body: 57
# 52. A
#     core type: Variable
#     sub-expressions:
# 53. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 59
#     operand: 63
# 54. B
#     core type: Variable
#     sub-expressions:
# 55. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 59
#     operand: 64
# 56. a_{_a} in Complex
#     core type: Operation
#     operator: 78
#     operands: 61
# 57. b_{_a} in Complex
#     core type: Operation
#     operator: 78
#     operands: 62
# 58. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 63
# 59. Sum
#     core type: Literal
#     sub-expressions:
# 60. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 64
# 61. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 65, 67
# 62. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 63. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 100
#     body: 68
# 64. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 100
#     body: 69
# 65. a_{_a}
#     core type: IndexedVar
# variable: 84
# index: 74
# 66. b_{_a}
#     core type: IndexedVar
# variable: 85
# index: 74
# 67. Complex
#     core type: Literal
#     sub-expressions:
# 68. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 71
#     condition: 73
# 69. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 72
#     condition: 73
# 70. (_a)
#     core type: ExprTuple
#     sub-expressions: 74
# 71. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 76
#     operands: 75
# 72. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 76
#     operands: 77
# 73. i in {1 .. n}
#     core type: Operation
#     operator: 78
#     operands: 79
# 74. _a
#     core type: Variable
#     sub-expressions:
# 75. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 80, 82
# 76. *
#     core type: Literal
#     sub-expressions:
# 77. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 81, 82
# 78. in
#     core type: Literal
#     sub-expressions:
# 79. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 100, 83
# 80. a_{i}
#     core type: IndexedVar
# variable: 84
# index: 100
# 81. b_{i}
#     core type: IndexedVar
# variable: 85
# index: 100
# 82. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 86
#     operands: 87
# 83. {1 .. n}
#     core type: Operation
#     operator: 88
#     operands: 89
# 84. a
#     core type: Variable
#     sub-expressions:
# 85. b
#     core type: Variable
#     sub-expressions:
# 86. .
#     core type: Literal
#     sub-expressions:
# 87. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 90, 91
# 88. Interval
#     core type: Literal
#     sub-expressions:
# 89. (1, n)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 90. |v_{i}〉
#     core type: Operation
#     operator: 94
#     operand: 97
# 91. 〈v_{i}|
#     core type: Operation
#     operator: 95
#     operand: 97
# 92. 1
#     core type: Literal
#     sub-expressions:
# 93. n
#     core type: Variable
#     sub-expressions:
# 94. KET
#     core type: Literal
#     sub-expressions:
# 95. BRA
#     core type: Literal
#     sub-expressions:
# 96. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 97
# 97. v_{i}
#     core type: IndexedVar
# variable: 98
# index: 100
# 98. v
#     core type: Variable
#     sub-expressions:
# 99. (i)
#     core type: ExprTuple
#     sub-expressions: 100
# 100. i
#      core type: Variable
#      sub-expressions:
