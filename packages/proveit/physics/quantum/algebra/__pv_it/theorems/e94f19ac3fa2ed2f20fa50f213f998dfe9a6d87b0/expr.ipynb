# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, U, i, j, n
from proveit.core_expr_types import v_1_to_n, v_i, v_j
from proveit.linear_algebra import Adj, OrthoNormBases, Unitary
from proveit.logic import CartExp, Equals, Forall, Implies, InSet, Set
from proveit.numbers import Complex, Interval, KroneckerDelta, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Lambda([v_1_to_n], Conditional(Implies(Forall(instance_param_or_params = [i, j], instance_expr = Equals(Qmult(Bra(v_i), Adj(U), U, Ket(v_j)), KroneckerDelta(i, j)), domain = Interval(one, n)), InSet(U, Unitary(n))), InSet(Set(v_1_to_n_kets), OrthoNormBases(CartExp(Complex, n)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(v_{1}, v_{2}, \ldots, v_{n}\right) \mapsto \left\{\left[\forall_{i, j \in \{1~\ldotp \ldotp~n\}}~\left(\left(\langle v_{i} \rvert \thinspace U^{\dagger} \thinspace U \thinspace \lvert v_{j} \rangle\right) = \delta_{i, j}\right)\right] \Rightarrow \left(U \in \textrm{U}\left(n\right)\right) \textrm{ if } \left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (v_{1}, v_{2}, ..., v_{n}) -> {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (v_{1}, v_{2}, ..., v_{n})
#    core type: ExprTuple
#    sub-expressions: 3
# 2. {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 3. v_{1}, v_{2}, ..., v_{n}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 70
#    end_index: 71
# 4. [forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n))
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#    core type: Operation
#    operator: 50
#    operands: 9
# 6. _a -> v_{_a}
#    core type: Lambda
#    parameter: 72
#    body: 57
# 7. =>
#    core type: Literal
#    sub-expressions:
# 8. (forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j}), U in U(n))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})
#     core type: Operation
#     operator: 14
#     operand: 20
# 11. U in U(n)
#     core type: Operation
#     operator: 50
#     operands: 16
# 12. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 27
#     operand: 22
# 13. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 18
#     operand: 23
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. ((i, j) -> {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 20
# 16. (U, U(n))
#     core type: ExprTuple
#     sub-expressions: 68, 21
# 17. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 22
# 18. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 19. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 23
# 20. (i, j) -> {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.
#     core type: Lambda
#     parameters: 48\n    body: 24
# 21. U(n)
#     core type: Operation
#     operator: 25
#     operand: 71
# 22. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. Complex^{n}
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.
#     core type: Conditional
#     value: 31
#     condition: 32
# 25. U
#     core type: Literal
#     sub-expressions:
# 26. (n)
#     core type: ExprTuple
#     sub-expressions: 71
# 27. Set
#     core type: Literal
#     sub-expressions:
# 28. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 33
# 29. CartExp
#     core type: Literal
#     sub-expressions:
# 30. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 34, 71
# 31. (〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j}
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. (i in {1 .. n}) and (j in {1 .. n})
#     core type: Operation
#     operator: 37
#     operands: 38
# 33. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 70
#     end_index: 71
# 34. Complex
#     core type: Literal
#     sub-expressions:
# 35. =
#     core type: Literal
#     sub-expressions:
# 36. (〈v_{i}| . U* . U . |v_{j}〉, delta_{i, j})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 37. and
#     core type: Literal
#     sub-expressions:
# 38. (i in {1 .. n}, j in {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 39. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 72
#     body: 44
# 40. 〈v_{i}| . U* . U . |v_{j}〉
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. delta_{i, j}
#     core type: Operation
#     operator: 47
#     operands: 48
# 42. i in {1 .. n}
#     core type: Operation
#     operator: 50
#     operands: 49
# 43. j in {1 .. n}
#     core type: Operation
#     operator: 50
#     operands: 51
# 44. |v_{_a}〉
#     core type: Operation
#     operator: 62
#     operand: 57
# 45. .
#     core type: Literal
#     sub-expressions:
# 46. (〈v_{i}|, U*, U, |v_{j}〉)
#     core type: ExprTuple
#     sub-expressions: 53, 54, 68, 55
# 47. Kdelta
#     core type: Literal
#     sub-expressions:
# 48. (i, j)
#     core type: ExprTuple
#     sub-expressions: 76, 77
# 49. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 76, 56
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 77, 56
# 52. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 57
# 53. 〈v_{i}|
#     core type: Operation
#     operator: 58
#     operand: 67
# 54. U*
#     core type: Operation
#     operator: 60
#     operand: 68
# 55. |v_{j}〉
#     core type: Operation
#     operator: 62
#     operand: 69
# 56. {1 .. n}
#     core type: Operation
#     operator: 64
#     operands: 65
# 57. v_{_a}
#     core type: IndexedVar
# variable: 74
# index: 72
# 58. BRA
#     core type: Literal
#     sub-expressions:
# 59. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 67
# 60. Adj
#     core type: Literal
#     sub-expressions:
# 61. (U)
#     core type: ExprTuple
#     sub-expressions: 68
# 62. KET
#     core type: Literal
#     sub-expressions:
# 63. (v_{j})
#     core type: ExprTuple
#     sub-expressions: 69
# 64. Interval
#     core type: Literal
#     sub-expressions:
# 65. (1, n)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 66. (_a)
#     core type: ExprTuple
#     sub-expressions: 72
# 67. v_{i}
#     core type: IndexedVar
# variable: 74
# index: 76
# 68. U
#     core type: Variable
#     sub-expressions:
# 69. v_{j}
#     core type: IndexedVar
# variable: 74
# index: 77
# 70. 1
#     core type: Literal
#     sub-expressions:
# 71. n
#     core type: Variable
#     sub-expressions:
# 72. _a
#     core type: Variable
#     sub-expressions:
# 73. (i)
#     core type: ExprTuple
#     sub-expressions: 76
# 74. v
#     core type: Variable
#     sub-expressions:
# 75. (j)
#     core type: ExprTuple
#     sub-expressions: 77
# 76. i
#     core type: Variable
#     sub-expressions:
# 77. j
#     core type: Variable
#     sub-expressions:
