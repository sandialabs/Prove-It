# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, i, lambda_, m, n
from proveit.core_expr_types import a_1_to_m, a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import OrthoNormBases, ScalarMult, TensorProd, VecSum
from proveit.logic import CartExp, Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, Min, RealNonNeg, one
from proveit.physics.quantum import Ket, Qmult, var_ket_psi
from proveit.physics.quantum.algebra import a_1_to_m_kets, b_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
sub_expr3 = CartExp(Complex, n)
sub_expr4 = CartExp(Complex, m)
expr = Conditional(Exists(instance_param_or_params = [a_1_to_m], instance_expr = Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(var_ket_psi, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, Qmult(Ket(a_i), Ket(b_i))), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n_kets), OrthoNormBases(sub_expr3))).with_wrapping(), condition = InSet(Set(a_1_to_m_kets), OrthoNormBases(sub_expr4))).with_wrapping(), InSet(var_ket_psi, TensorProd(sub_expr4, sub_expr3)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{m}~|~\left\{\left\{\lvert a_{1} \rangle, \lvert a_{2} \rangle, \ldots, \lvert a_{m} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{m}\right)}~\\
# \left[\begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{\left\{\lvert b_{1} \rangle, \lvert b_{2} \rangle, \ldots, \lvert b_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(\lvert \psi \rangle = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(\lvert a_{i} \rangle \thinspace \lvert b_{i} \rangle\right)\right)\right)\right)\end{array}\right]\end{array}\right]\end{array} \textrm{ if } \lvert \psi \rangle \in \left(\mathbb{C}^{m} {\otimes} \mathbb{C}^{n}\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]] if |psi> in (Complex^{m} otimes Complex^{n}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. exists_{a_{1}, a_{2}, ..., a_{m} | {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})} [exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]]
#    core type: Operation
#    operator: 30
#    operand: 5
# 2. |psi> in (Complex^{m} otimes Complex^{n})
#    core type: Operation
#    operator: 84
#    operands: 4
# 3. ((a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))] if {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m}).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (|psi>, Complex^{m} otimes Complex^{n})
#    core type: ExprTuple
#    sub-expressions: 61, 6
# 5. (a_{1}, a_{2}, ..., a_{m}) -> {exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))] if {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m}).
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. Complex^{m} otimes Complex^{n}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (a_{1}, a_{2}, ..., a_{m})
#    core type: ExprTuple
#    sub-expressions: 11
# 8. {exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))] if {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m}).
#    core type: Conditional
#    value: 12
#    condition: 13
# 9. otimes
#    core type: Literal
#    sub-expressions:
# 10. (Complex^{m}, Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 28, 49
# 11. a_{1}, a_{2}, ..., a_{m}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 98
#     end_index: 107
# 12. exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]
#     core type: Operation
#     operator: 30
#     operand: 17
# 13. {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})
#     core type: Operation
#     operator: 84
#     operands: 16
# 14. _a -> a_{_a}
#     core type: Lambda
#     parameter: 90
#     body: 66
# 15. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. ({{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}}, O.N.Bases(Complex^{m}))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Lambda
#     parameters: 20\n    body: 21
# 18. {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}}
#     core type: Operation
#     operator: 56
#     operand: 27
# 19. O.N.Bases(Complex^{m})
#     core type: Operation
#     operator: 42
#     operand: 28
# 20. (b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 25
#     condition: 26
# 22. ({|a_{1}〉, |a_{2}〉, ..., |a_{m}〉})
#     core type: ExprTuple
#     sub-expressions: 27
# 23. (Complex^{m})
#     core type: ExprTuple
#     sub-expressions: 28
# 24. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 98
#     end_index: 108
# 25. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))
#     core type: Operation
#     operator: 30
#     operand: 35
# 26. {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 84
#     operands: 32
# 27. {|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}
#     core type: Operation
#     operator: 56
#     operands: 33
# 28. Complex^{m}
#     core type: Operation
#     operator: 58
#     operands: 34
# 29. _a -> b_{_a}
#     core type: Lambda
#     parameter: 90
#     body: 81
# 30. exists
#     core type: Literal
#     sub-expressions:
# 31. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 35
# 32. ({{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. (|a_{1}〉, |a_{2}〉, ..., |a_{m}〉)
#     core type: ExprTuple
#     sub-expressions: 38
# 34. (Complex, m)
#     core type: ExprTuple
#     sub-expressions: 65, 107
# 35. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 39\n    body: 40
# 36. {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}}
#     core type: Operation
#     operator: 56
#     operand: 48
# 37. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 42
#     operand: 49
# 38. |a_{1}〉, |a_{2}〉, ..., |a_{m}〉
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 98
#     end_index: 107
# 39. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 45
# 40. {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 46
#     condition: 47
# 41. ({|b_{1}〉, |b_{2}〉, ..., |b_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 48
# 42. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 43. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 49
# 44. _a -> |a_{_a}〉
#     core type: Lambda
#     parameter: 90
#     body: 50
# 45. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 98
#     end_index: 99
# 46. |psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#     core type: Operation
#     operator: 52
#     operands: 53
# 47. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 54
#     operands: 55
# 48. {|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}
#     core type: Operation
#     operator: 56
#     operands: 57
# 49. Complex^{n}
#     core type: Operation
#     operator: 58
#     operands: 59
# 50. |a_{_a}〉
#     core type: Operation
#     operator: 101
#     operand: 66
# 51. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 90
#     body: 79
# 52. =
#     core type: Literal
#     sub-expressions:
# 53. (|psi>, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 54. and
#     core type: Literal
#     sub-expressions:
# 55. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 63
# 56. Set
#     core type: Literal
#     sub-expressions:
# 57. (|b_{1}〉, |b_{2}〉, ..., |b_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 64
# 58. CartExp
#     core type: Literal
#     sub-expressions:
# 59. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 65, 108
# 60. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 66
# 61. |psi>
#     core type: Variable
#     sub-expressions:
# 62. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))
#     core type: Operation
#     operator: 67
#     operand: 71
# 63. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 98
#     end_index: 99
# 64. |b_{1}〉, |b_{2}〉, ..., |b_{n}〉
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 98
#     end_index: 108
# 65. Complex
#     core type: Literal
#     sub-expressions:
# 66. a_{_a}
#     core type: IndexedVar
# variable: 109
# index: 90
# 67. Sum
#     core type: Literal
#     sub-expressions:
# 68. (i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 71
# 69. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 90
#     body: 72
# 70. _a -> |b_{_a}〉
#     core type: Lambda
#     parameter: 90
#     body: 73
# 71. i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 112
#     body: 74
# 72. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 84
#     operands: 75
# 73. |b_{_a}〉
#     core type: Operation
#     operator: 101
#     operand: 81
# 74. {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 77
#     condition: 78
# 75. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 76. (b_{_a})
#     core type: ExprTuple
#     sub-expressions: 81
# 77. lambda_{i} * (|a_{i}〉 . |b_{i}〉)
#     core type: Operation
#     operator: 82
#     operands: 83
# 78. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 84
#     operands: 85
# 79. lambda_{_a}
#     core type: IndexedVar
# variable: 91
# index: 90
# 80. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 81. b_{_a}
#     core type: IndexedVar
# variable: 110
# index: 90
# 82. *
#     core type: Literal
#     sub-expressions:
# 83. (lambda_{i}, |a_{i}〉 . |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 87, 88
# 84. in
#     core type: Literal
#     sub-expressions:
# 85. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 112, 89
# 86. (_a)
#     core type: ExprTuple
#     sub-expressions: 90
# 87. lambda_{i}
#     core type: IndexedVar
# variable: 91
# index: 112
# 88. |a_{i}〉 . |b_{i}〉
#     core type: Operation
#     operator: 92
#     operands: 93
# 89. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 94
#     operands: 95
# 90. _a
#     core type: Variable
#     sub-expressions:
# 91. lambda
#     core type: Variable
#     sub-expressions:
# 92. .
#     core type: Literal
#     sub-expressions:
# 93. (|a_{i}〉, |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 96, 97
# 94. Interval
#     core type: Literal
#     sub-expressions:
# 95. (1, Min(m, n))
#     core type: ExprTuple
#     sub-expressions: 98, 99
# 96. |a_{i}〉
#     core type: Operation
#     operator: 101
#     operand: 105
# 97. |b_{i}〉
#     core type: Operation
#     operator: 101
#     operand: 106
# 98. 1
#     core type: Literal
#     sub-expressions:
# 99. Min(m, n)
#     core type: Operation
#     operator: 103
#     operands: 104
# 100. (a_{i})
#      core type: ExprTuple
#      sub-expressions: 105
# 101. KET
#      core type: Literal
#      sub-expressions:
# 102. (b_{i})
#      core type: ExprTuple
#      sub-expressions: 106
# 103. Min
#      core type: Literal
#      sub-expressions:
# 104. (m, n)
#      core type: ExprTuple
#      sub-expressions: 107, 108
# 105. a_{i}
#      core type: IndexedVar
# variable: 109
# index: 112
# 106. b_{i}
#      core type: IndexedVar
# variable: 110
# index: 112
# 107. m
#      core type: Variable
#      sub-expressions:
# 108. n
#      core type: Variable
#      sub-expressions:
# 109. a
#      core type: Variable
#      sub-expressions:
# 110. b
#      core type: Variable
#      sub-expressions:
# 111. (i)
#      core type: ExprTuple
#      sub-expressions: 112
# 112. i
#      core type: Variable
#      sub-expressions:
