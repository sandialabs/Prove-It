# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, U, i, j, n
from proveit.core_expr_types import v_1_to_n, v_i, v_j
from proveit.linear_algebra import Adj, MatrixSpace, OrthoNormBases, Unitary
from proveit.logic import CartExp, Equals, Forall, Implies, InSet, Set
from proveit.numbers import Complex, Interval, KroneckerDelta, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Lambda(U, Conditional(Forall(instance_param_or_params = [v_1_to_n], instance_expr = Implies(Forall(instance_param_or_params = [i, j], instance_expr = Equals(Qmult(Bra(v_i), Adj(U), U, Ket(v_j)), KroneckerDelta(i, j)), domain = Interval(one, n)), InSet(U, Unitary(n))), condition = InSet(Set(v_1_to_n_kets), OrthoNormBases(CartExp(Complex, n)))).with_wrapping(), InSet(U, MatrixSpace(field = Complex, rows = n, columns = n))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# U \mapsto \left\{\begin{array}{l}\forall_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left(\left[\forall_{i, j \in \{1~\ldotp \ldotp~n\}}~\left(\left(\langle v_{i} \rvert \thinspace U^{\dagger} \thinspace U \thinspace \lvert v_{j} \rangle\right) = \delta_{i, j}\right)\right] \Rightarrow \left(U \in \textrm{U}\left(n\right)\right)\right)\end{array} \textrm{ if } U \in \mathbb{C}^{n \times n}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. U -> {forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n))) if U in Complex^{n x n}.
#    core type: Lambda
#    parameter: 77
#    body: 1
# 1. {forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n))) if U in Complex^{n x n}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)))
#    core type: Operation
#    operator: 23
#    operand: 6
# 3. U in Complex^{n x n}
#    core type: Operation
#    operator: 59
#    operands: 5
# 4. ((v_{1}, v_{2}, ..., v_{n}) -> {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (U, Complex^{n x n})
#    core type: ExprTuple
#    sub-expressions: 77, 7
# 6. (v_{1}, v_{2}, ..., v_{n}) -> {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. Complex^{n x n}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (v_{1}, v_{2}, ..., v_{n})
#    core type: ExprTuple
#    sub-expressions: 12
# 9. {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. MSpace
#     core type: Literal
#     sub-expressions:
# 11. {field:Complex, rows:n, columns:n}
#     core type: NamedExprs
#     field: 43
#     rows: 80
#     columns: 80
# 12. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 79
#     end_index: 80
# 13. [forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n))
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 59
#     operands: 18
# 15. _a -> v_{_a}
#     core type: Lambda
#     parameter: 81
#     body: 66
# 16. =>
#     core type: Literal
#     sub-expressions:
# 17. (forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j}), U in U(n))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})
#     core type: Operation
#     operator: 23
#     operand: 29
# 20. U in U(n)
#     core type: Operation
#     operator: 59
#     operands: 25
# 21. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 36
#     operand: 31
# 22. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 27
#     operand: 32
# 23. forall
#     core type: Literal
#     sub-expressions:
# 24. ((i, j) -> {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 29
# 25. (U, U(n))
#     core type: ExprTuple
#     sub-expressions: 77, 30
# 26. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 31
# 27. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 28. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 32
# 29. (i, j) -> {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.
#     core type: Lambda
#     parameters: 57\n    body: 33
# 30. U(n)
#     core type: Operation
#     operator: 34
#     operand: 80
# 31. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. Complex^{n}
#     core type: Operation
#     operator: 38
#     operands: 39
# 33. {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.
#     core type: Conditional
#     value: 40
#     condition: 41
# 34. U
#     core type: Literal
#     sub-expressions:
# 35. (n)
#     core type: ExprTuple
#     sub-expressions: 80
# 36. Set
#     core type: Literal
#     sub-expressions:
# 37. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 42
# 38. CartExp
#     core type: Literal
#     sub-expressions:
# 39. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 43, 80
# 40. (〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j}
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. (i in {1 .. n}) and (j in {1 .. n})
#     core type: Operation
#     operator: 46
#     operands: 47
# 42. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 79
#     end_index: 80
# 43. Complex
#     core type: Literal
#     sub-expressions:
# 44. =
#     core type: Literal
#     sub-expressions:
# 45. (〈v_{i}| . U* . U . |v_{j}〉, delta_{i, j})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 46. and
#     core type: Literal
#     sub-expressions:
# 47. (i in {1 .. n}, j in {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 48. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 81
#     body: 53
# 49. 〈v_{i}| . U* . U . |v_{j}〉
#     core type: Operation
#     operator: 54
#     operands: 55
# 50. delta_{i, j}
#     core type: Operation
#     operator: 56
#     operands: 57
# 51. i in {1 .. n}
#     core type: Operation
#     operator: 59
#     operands: 58
# 52. j in {1 .. n}
#     core type: Operation
#     operator: 59
#     operands: 60
# 53. |v_{_a}〉
#     core type: Operation
#     operator: 71
#     operand: 66
# 54. .
#     core type: Literal
#     sub-expressions:
# 55. (〈v_{i}|, U*, U, |v_{j}〉)
#     core type: ExprTuple
#     sub-expressions: 62, 63, 77, 64
# 56. Kdelta
#     core type: Literal
#     sub-expressions:
# 57. (i, j)
#     core type: ExprTuple
#     sub-expressions: 85, 86
# 58. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 85, 65
# 59. in
#     core type: Literal
#     sub-expressions:
# 60. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 86, 65
# 61. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 66
# 62. 〈v_{i}|
#     core type: Operation
#     operator: 67
#     operand: 76
# 63. U*
#     core type: Operation
#     operator: 69
#     operand: 77
# 64. |v_{j}〉
#     core type: Operation
#     operator: 71
#     operand: 78
# 65. {1 .. n}
#     core type: Operation
#     operator: 73
#     operands: 74
# 66. v_{_a}
#     core type: IndexedVar
# variable: 83
# index: 81
# 67. BRA
#     core type: Literal
#     sub-expressions:
# 68. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 76
# 69. Adj
#     core type: Literal
#     sub-expressions:
# 70. (U)
#     core type: ExprTuple
#     sub-expressions: 77
# 71. KET
#     core type: Literal
#     sub-expressions:
# 72. (v_{j})
#     core type: ExprTuple
#     sub-expressions: 78
# 73. Interval
#     core type: Literal
#     sub-expressions:
# 74. (1, n)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 75. (_a)
#     core type: ExprTuple
#     sub-expressions: 81
# 76. v_{i}
#     core type: IndexedVar
# variable: 83
# index: 85
# 77. U
#     core type: Variable
#     sub-expressions:
# 78. v_{j}
#     core type: IndexedVar
# variable: 83
# index: 86
# 79. 1
#     core type: Literal
#     sub-expressions:
# 80. n
#     core type: Variable
#     sub-expressions:
# 81. _a
#     core type: Variable
#     sub-expressions:
# 82. (i)
#     core type: ExprTuple
#     sub-expressions: 85
# 83. v
#     core type: Variable
#     sub-expressions:
# 84. (j)
#     core type: ExprTuple
#     sub-expressions: 86
# 85. i
#     core type: Variable
#     sub-expressions:
# 86. j
#     core type: Variable
#     sub-expressions:
