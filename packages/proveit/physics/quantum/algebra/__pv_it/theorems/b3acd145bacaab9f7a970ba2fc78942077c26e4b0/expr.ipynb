# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, v_i
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import Equals, Exists
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, Qmult(Ket(v_i), Bra(v_i))), domain = Interval(one, n))), domain = Complex).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. exists
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a_{1}, a_{2}, ..., a_{n})
#    core type: ExprTuple
#    sub-expressions: 6
# 5. {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#    core type: Conditional
#    value: 7
#    condition: 8
# 6. a_{1}, a_{2}, ..., a_{n}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 44
#    end_index: 45
# 7. M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. _a -> a_{_a}
#    core type: Lambda
#    parameter: 36
#    body: 26
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (M, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 16
# 14. M
#     core type: Variable
#     sub-expressions:
# 15. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 17
#     operand: 20
# 16. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 44
#     end_index: 45
# 17. Sum
#     core type: Literal
#     sub-expressions:
# 18. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 36
#     body: 21
# 20. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 52
#     body: 22
# 21. a_{_a} in Complex
#     core type: Operation
#     operator: 30
#     operands: 23
# 22. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 24
#     condition: 25
# 23. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. i in {1 .. n}
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. a_{_a}
#     core type: IndexedVar
# variable: 37
# index: 36
# 27. Complex
#     core type: Literal
#     sub-expressions:
# 28. *
#     core type: Literal
#     sub-expressions:
# 29. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 52, 35
# 32. (_a)
#     core type: ExprTuple
#     sub-expressions: 36
# 33. a_{i}
#     core type: IndexedVar
# variable: 37
# index: 52
# 34. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. {1 .. n}
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. _a
#     core type: Variable
#     sub-expressions:
# 37. a
#     core type: Variable
#     sub-expressions:
# 38. .
#     core type: Literal
#     sub-expressions:
# 39. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 40. Interval
#     core type: Literal
#     sub-expressions:
# 41. (1, n)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. |v_{i}〉
#     core type: Operation
#     operator: 46
#     operand: 49
# 43. 〈v_{i}|
#     core type: Operation
#     operator: 47
#     operand: 49
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. n
#     core type: Variable
#     sub-expressions:
# 46. KET
#     core type: Literal
#     sub-expressions:
# 47. BRA
#     core type: Literal
#     sub-expressions:
# 48. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 49
# 49. v_{i}
#     core type: IndexedVar
# variable: 50
# index: 52
# 50. v
#     core type: Variable
#     sub-expressions:
# 51. (i)
#     core type: ExprTuple
#     sub-expressions: 52
# 52. i
#     core type: Variable
#     sub-expressions:
