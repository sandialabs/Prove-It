# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Function, IndexedVar, Variable, a, f, i, n
from proveit.core_expr_types import a_i, v_i
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import And, Equals, Forall, Functions, InSet
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [i]
sub_expr3 = Interval(one, n)
sub_expr4 = Qmult(Ket(v_i), Bra(v_i))
expr = Conditional(Forall(instance_param_or_params = [f], instance_expr = Equals(Function(f, [VecSum(index_or_indices = sub_expr2, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)]), VecSum(index_or_indices = sub_expr2, summand = ScalarMult(Function(f, [a_i]), sub_expr4), domain = sub_expr3)), domain = Functions(Complex, Complex)), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, n)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{f \in \left[\mathbb{C} \rightarrow \mathbb{C}\right]}~\left(f\left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right) = \left(\sum_{i=1}^{n} \left(f\left(a_{i}\right) \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \textrm{ if } \left(a_{1} \in \mathbb{C}\right) \land  \left(a_{2} \in \mathbb{C}\right) \land  \ldots \land  \left(a_{n} \in \mathbb{C}\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (f -> {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. f -> {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].
#    core type: Lambda
#    parameter: 46
#    body: 10
# 8. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 58
#    end_index: 59
# 9. (f)
#    core type: ExprTuple
#    sub-expressions: 46
# 10. {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].
#     core type: Conditional
#     value: 12
#     condition: 13
# 11. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 31
#     body: 14
# 12. f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. f in [Complex -> Complex]
#     core type: Operation
#     operator: 44
#     operands: 17
# 14. a_{_a} in Complex
#     core type: Operation
#     operator: 44
#     operands: 18
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. (f, [Complex -> Complex])
#     core type: ExprTuple
#     sub-expressions: 46, 21
# 18. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 22, 30
# 19. f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 46
#     operand: 28
# 20. Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 32
#     operand: 29
# 21. [Complex -> Complex]
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. a_{_a}
#     core type: IndexedVar
# variable: 55
# index: 31
# 23. (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 28
# 24. (i -> {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 29
# 25. Functions
#     core type: Literal
#     sub-expressions:
# 26. (Complex, Complex)
#     core type: ExprTuple
#     sub-expressions: 30, 30
# 27. (_a)
#     core type: ExprTuple
#     sub-expressions: 31
# 28. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 32
#     operand: 35
# 29. i -> {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 66
#     body: 34
# 30. Complex
#     core type: Literal
#     sub-expressions:
# 31. _a
#     core type: Variable
#     sub-expressions:
# 32. Sum
#     core type: Literal
#     sub-expressions:
# 33. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 35
# 34. {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 36
#     condition: 40
# 35. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 66
#     body: 37
# 36. f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 42
#     operands: 38
# 37. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 39
#     condition: 40
# 38. (f(a_{i}), |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 41, 48
# 39. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 42
#     operands: 43
# 40. i in {1 .. n}
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. f(a_{i})
#     core type: Operation
#     operator: 46
#     operand: 50
# 42. *
#     core type: Literal
#     sub-expressions:
# 43. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 50, 48
# 44. in
#     core type: Literal
#     sub-expressions:
# 45. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 66, 49
# 46. f
#     core type: Variable
#     sub-expressions:
# 47. (a_{i})
#     core type: ExprTuple
#     sub-expressions: 50
# 48. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 51
#     operands: 52
# 49. {1 .. n}
#     core type: Operation
#     operator: 53
#     operands: 54
# 50. a_{i}
#     core type: IndexedVar
# variable: 55
# index: 66
# 51. .
#     core type: Literal
#     sub-expressions:
# 52. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 53. Interval
#     core type: Literal
#     sub-expressions:
# 54. (1, n)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 55. a
#     core type: Variable
#     sub-expressions:
# 56. |v_{i}〉
#     core type: Operation
#     operator: 60
#     operand: 63
# 57. 〈v_{i}|
#     core type: Operation
#     operator: 61
#     operand: 63
# 58. 1
#     core type: Literal
#     sub-expressions:
# 59. n
#     core type: Variable
#     sub-expressions:
# 60. KET
#     core type: Literal
#     sub-expressions:
# 61. BRA
#     core type: Literal
#     sub-expressions:
# 62. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 63
# 63. v_{i}
#     core type: IndexedVar
# variable: 64
# index: 66
# 64. v
#     core type: Variable
#     sub-expressions:
# 65. (i)
#     core type: ExprTuple
#     sub-expressions: 66
# 66. i
#     core type: Variable
#     sub-expressions:
