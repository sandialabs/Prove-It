# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, U, i, n
from proveit.core_expr_types import v_1_to_n, v_i, w_1_to_n, w_i
from proveit.linear_algebra import OrthoNormBases, VecSum
from proveit.logic import And, CartExp, Equals, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = OrthoNormBases(CartExp(Complex, n))
expr = ExprTuple(Lambda([v_1_to_n, w_1_to_n], Conditional(Equals(U, VecSum(index_or_indices = [i], summand = Qmult(Ket(v_i), Bra(w_i)), domain = Interval(one, n))), And(InSet(Set(v_1_to_n_kets), sub_expr1), InSet(Set(w_1_to_n_kets), sub_expr1)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(v_{1}, v_{2}, \ldots, v_{n}, w_{1}, w_{2}, \ldots, w_{n}\right) \mapsto \left\{U = \left(\sum_{i=1}^{n} \left(\lvert v_{i} \rangle \thinspace \langle w_{i} \rvert\right)\right) \textrm{ if } \left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right) ,  \left\{\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (v_{1}, v_{2}, ..., v_{n},w_{1}, w_{2}, ..., w_{n})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Conditional
#    value: 6
#    condition: 7
# 4. v_{1}, v_{2}, ..., v_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 60
#    end_index: 61
# 5. w_{1}, w_{2}, ..., w_{n}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 60
#    end_index: 61
# 6. U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})) and ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. _a -> v_{_a}
#    core type: Lambda
#    parameter: 74
#    body: 69
# 9. _a -> w_{_a}
#    core type: Lambda
#    parameter: 74
#    body: 70
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (U, Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. U
#     core type: Variable
#     sub-expressions:
# 15. Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)
#     core type: Operation
#     operator: 18
#     operand: 22
# 16. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 38
#     operands: 20
# 17. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 38
#     operands: 21
# 18. Sum
#     core type: Literal
#     sub-expressions:
# 19. (i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 22
# 20. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 23, 25
# 21. ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 68
#     body: 26
# 23. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 41
#     operand: 33
# 24. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}
#     core type: Operation
#     operator: 41
#     operand: 34
# 25. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 29
#     operand: 35
# 26. {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 31
#     condition: 32
# 27. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 33
# 28. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 34
# 29. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 30. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 35
# 31. |v_{i}〉 . 〈w_{i}|
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. i in {1 .. n}
#     core type: Operation
#     operator: 38
#     operands: 39
# 33. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 41
#     operands: 40
# 34. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 41
#     operands: 42
# 35. Complex^{n}
#     core type: Operation
#     operator: 43
#     operands: 44
# 36. .
#     core type: Literal
#     sub-expressions:
# 37. (|v_{i}〉, 〈w_{i}|)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 68, 47
# 40. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 48
# 41. Set
#     core type: Literal
#     sub-expressions:
# 42. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 49
# 43. CartExp
#     core type: Literal
#     sub-expressions:
# 44. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 50, 61
# 45. |v_{i}〉
#     core type: Operation
#     operator: 66
#     operand: 58
# 46. 〈w_{i}|
#     core type: Operation
#     operator: 52
#     operand: 59
# 47. {1 .. n}
#     core type: Operation
#     operator: 54
#     operands: 55
# 48. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 60
#     end_index: 61
# 49. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 60
#     end_index: 61
# 50. Complex
#     core type: Literal
#     sub-expressions:
# 51. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 58
# 52. BRA
#     core type: Literal
#     sub-expressions:
# 53. (w_{i})
#     core type: ExprTuple
#     sub-expressions: 59
# 54. Interval
#     core type: Literal
#     sub-expressions:
# 55. (1, n)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 56. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 74
#     body: 62
# 57. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 74
#     body: 63
# 58. v_{i}
#     core type: IndexedVar
# variable: 71
# index: 68
# 59. w_{i}
#     core type: IndexedVar
# variable: 72
# index: 68
# 60. 1
#     core type: Literal
#     sub-expressions:
# 61. n
#     core type: Variable
#     sub-expressions:
# 62. |v_{_a}〉
#     core type: Operation
#     operator: 66
#     operand: 69
# 63. |w_{_a}〉
#     core type: Operation
#     operator: 66
#     operand: 70
# 64. (i)
#     core type: ExprTuple
#     sub-expressions: 68
# 65. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 69
# 66. KET
#     core type: Literal
#     sub-expressions:
# 67. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 70
# 68. i
#     core type: Variable
#     sub-expressions:
# 69. v_{_a}
#     core type: IndexedVar
# variable: 71
# index: 74
# 70. w_{_a}
#     core type: IndexedVar
# variable: 72
# index: 74
# 71. v
#     core type: Variable
#     sub-expressions:
# 72. w
#     core type: Variable
#     sub-expressions:
# 73. (_a)
#     core type: ExprTuple
#     sub-expressions: 74
# 74. _a
#     core type: Variable
#     sub-expressions:
