# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, j, l, n
from proveit.core_expr_types import A_1_to_l, C_1_to_n, b_1_to_j
from proveit.logic import And, Equals, Forall, InClass, InSet
from proveit.numbers import Complex, Natural
from proveit.physics.quantum import Qmult, QmultCodomain

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [b_1_to_j], instance_expr = Forall(instance_param_or_params = [A_1_to_l, C_1_to_n], instance_expr = Equals(Qmult(A_1_to_l, b_1_to_j, C_1_to_n), Qmult(b_1_to_j, A_1_to_l, C_1_to_n)).with_wrapping_at(2), condition = InClass(Qmult(A_1_to_l, C_1_to_n), QmultCodomain)), domain = Complex), And(InSet(j, Natural), InSet(l, Natural), InSet(n, Natural)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{b_{1}, b_{2}, \ldots, b_{j} \in \mathbb{C}}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{l}, C_{1}, C_{2}, \ldots, C_{n}~|~\left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) \underset{{\scriptscriptstyle c}}{\in} \mathcal{Q^*}}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\thinspace b_{1} \thinspace  b_{2} \thinspace  \ldots \thinspace  b_{j}\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) =  \\ \left(b_{1} \thinspace  b_{2} \thinspace  \ldots \thinspace  b_{j}\thinspace A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) \end{array} \end{array}\right)\right] \textrm{ if } j \in \mathbb{N} ,  l \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{b_{1}, b_{2}, ..., b_{j} in Complex} [forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))] if j in Natural ,  l in Natural ,  n in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{b_{1}, b_{2}, ..., b_{j} in Complex} [forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))]
#    core type: Operation
#    operator: 17
#    operand: 5
# 2. (j in Natural) and (l in Natural) and (n in Natural)
#    core type: Operation
#    operator: 19
#    operands: 4
# 3. ((b_{1}, b_{2}, ..., b_{j}) -> {forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})) if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (j in Natural, l in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 5. (b_{1}, b_{2}, ..., b_{j}) -> {forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})) if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).
#    core type: Lambda
#    parameters: 9\n   body: 10
# 6. j in Natural
#    core type: Operation
#    operator: 32
#    operands: 11
# 7. l in Natural
#    core type: Operation
#    operator: 32
#    operands: 12
# 8. n in Natural
#    core type: Operation
#    operator: 32
#    operands: 13
# 9. (b_{1}, b_{2}, ..., b_{j})
#    core type: ExprTuple
#    sub-expressions: 43
# 10. {forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})) if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).
#     core type: Conditional
#     value: 14
#     condition: 15
# 11. (j, Natural)
#     core type: ExprTuple
#     sub-expressions: 47, 16
# 12. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 49, 16
# 13. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 52, 16
# 14. forall_{A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}))
#     core type: Operation
#     operator: 17
#     operand: 21
# 15. (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex)
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. Natural
#     core type: Literal
#     sub-expressions:
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. ((A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n}) -> {(A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) if (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*.)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. ((b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex))
#     core type: ExprTuple
#     sub-expressions: 22
# 21. (A_{1}, A_{2}, ..., A_{l}, C_{1}, C_{2}, ..., C_{n}) -> {(A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) if (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*.
#     core type: Lambda
#     parameters: 42\n    body: 23
# 22. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 51
#     end_index: 47
# 23. {(A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) if (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*.
#     core type: Conditional
#     value: 25
#     condition: 26
# 24. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 60
#     body: 27
# 25. (A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. b_{_a} in Complex
#     core type: Operation
#     operator: 32
#     operands: 33
# 28. =
#     core type: Literal
#     sub-expressions:
# 29. (A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}, b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n})
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 30. in_c
#     core type: Literal
#     sub-expressions:
# 31. (A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}, Q*)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 53, 38
# 34. A_{1} .  A_{2} .  ... .  A_{l}. b_{1} .  b_{2} .  ... .  b_{j}. C_{1} .  C_{2} .  ... .  C_{n}
#     core type: Operation
#     operator: 41
#     operands: 39
# 35. b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}
#     core type: Operation
#     operator: 41
#     operands: 40
# 36. A_{1} .  A_{2} .  ... .  A_{l}. C_{1} .  C_{2} .  ... .  C_{n}
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. Q*
#     core type: Literal
#     sub-expressions:
# 38. Complex
#     core type: Literal
#     sub-expressions:
# 39. (A_{1}, A_{2}, ..., A_{l},b_{1}, b_{2}, ..., b_{j},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 44, 43, 45
# 40. (b_{1}, b_{2}, ..., b_{j},A_{1}, A_{2}, ..., A_{l},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 43, 44, 45
# 41. .
#     core type: Literal
#     sub-expressions:
# 42. (A_{1}, A_{2}, ..., A_{l},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 43. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 46
#     start_index: 51
#     end_index: 47
# 44. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 51
#     end_index: 49
# 45. C_{1}, C_{2}, ..., C_{n}
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 51
#     end_index: 52
# 46. _a -> b_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 53
# 47. j
#     core type: Variable
#     sub-expressions:
# 48. _a -> A_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 54
# 49. l
#     core type: Variable
#     sub-expressions:
# 50. _a -> C_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 55
# 51. 1
#     core type: Literal
#     sub-expressions:
# 52. n
#     core type: Variable
#     sub-expressions:
# 53. b_{_a}
#     core type: IndexedVar
# variable: 56
# index: 60
# 54. A_{_a}
#     core type: IndexedVar
# variable: 57
# index: 60
# 55. C_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 56. b
#     core type: Variable
#     sub-expressions:
# 57. A
#     core type: Variable
#     sub-expressions:
# 58. C
#     core type: Variable
#     sub-expressions:
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. _a
#     core type: Variable
#     sub-expressions:
