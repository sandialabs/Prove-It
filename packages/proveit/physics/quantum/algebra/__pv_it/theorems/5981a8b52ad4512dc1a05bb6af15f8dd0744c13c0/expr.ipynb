# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, i, lambda_, m, n
from proveit.core_expr_types import a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import OrthoNormBases, ScalarMult, VecSum
from proveit.logic import CartExp, Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, Min, RealNonNeg, one
from proveit.physics.quantum import Ket, Qmult, var_ket_psi
from proveit.physics.quantum.algebra import b_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
expr = Lambda([b_1_to_n], Conditional(Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(var_ket_psi, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, Qmult(Ket(a_i), Ket(b_i))), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), InSet(Set(b_1_to_n_kets), OrthoNormBases(CartExp(Complex, n)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(b_{1}, b_{2}, \ldots, b_{n}\right) \mapsto \left\{\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(\lvert \psi \rangle = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(\lvert a_{i} \rangle \thinspace \lvert b_{i} \rangle\right)\right)\right)\right)\end{array} \textrm{ if } \left\{\left\{\lvert b_{1} \rangle, \lvert b_{2} \rangle, \ldots, \lvert b_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (b_{1}, b_{2}, ..., b_{n})
#    core type: ExprTuple
#    sub-expressions: 3
# 2. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 3. b_{1}, b_{2}, ..., b_{n}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 68
#    end_index: 78
# 4. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))
#    core type: Operation
#    operator: 7
#    operand: 10
# 5. {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})
#    core type: Operation
#    operator: 54
#    operands: 9
# 6. _a -> b_{_a}
#    core type: Lambda
#    parameter: 60
#    body: 51
# 7. exists
#    core type: Literal
#    sub-expressions:
# 8. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. ({{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}}, O.N.Bases(Complex^{n}))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 13\n    body: 14
# 11. {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}}
#     core type: Operation
#     operator: 28
#     operand: 21
# 12. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 16
#     operand: 22
# 13. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 18
# 14. {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 19
#     condition: 20
# 15. ({|b_{1}〉, |b_{2}〉, ..., |b_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 21
# 16. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 17. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 22
# 18. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 68
#     end_index: 69
# 19. |psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. {|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}
#     core type: Operation
#     operator: 28
#     operands: 29
# 22. Complex^{n}
#     core type: Operation
#     operator: 30
#     operands: 31
# 23. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 49
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (|psi>, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 34
# 28. Set
#     core type: Literal
#     sub-expressions:
# 29. (|b_{1}〉, |b_{2}〉, ..., |b_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 35
# 30. CartExp
#     core type: Literal
#     sub-expressions:
# 31. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 36, 78
# 32. |psi>
#     core type: Variable
#     sub-expressions:
# 33. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))
#     core type: Operation
#     operator: 37
#     operand: 41
# 34. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 68
#     end_index: 69
# 35. |b_{1}〉, |b_{2}〉, ..., |b_{n}〉
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 68
#     end_index: 78
# 36. Complex
#     core type: Literal
#     sub-expressions:
# 37. Sum
#     core type: Literal
#     sub-expressions:
# 38. (i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 41
# 39. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 60
#     body: 42
# 40. _a -> |b_{_a}〉
#     core type: Lambda
#     parameter: 60
#     body: 43
# 41. i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 82
#     body: 44
# 42. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 54
#     operands: 45
# 43. |b_{_a}〉
#     core type: Operation
#     operator: 71
#     operand: 51
# 44. {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 47
#     condition: 48
# 45. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 46. (b_{_a})
#     core type: ExprTuple
#     sub-expressions: 51
# 47. lambda_{i} * (|a_{i}〉 . |b_{i}〉)
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 54
#     operands: 55
# 49. lambda_{_a}
#     core type: IndexedVar
# variable: 61
# index: 60
# 50. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 51. b_{_a}
#     core type: IndexedVar
# variable: 80
# index: 60
# 52. *
#     core type: Literal
#     sub-expressions:
# 53. (lambda_{i}, |a_{i}〉 . |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 54. in
#     core type: Literal
#     sub-expressions:
# 55. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 82, 59
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 57. lambda_{i}
#     core type: IndexedVar
# variable: 61
# index: 82
# 58. |a_{i}〉 . |b_{i}〉
#     core type: Operation
#     operator: 62
#     operands: 63
# 59. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 64
#     operands: 65
# 60. _a
#     core type: Variable
#     sub-expressions:
# 61. lambda
#     core type: Variable
#     sub-expressions:
# 62. .
#     core type: Literal
#     sub-expressions:
# 63. (|a_{i}〉, |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 64. Interval
#     core type: Literal
#     sub-expressions:
# 65. (1, Min(m, n))
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 66. |a_{i}〉
#     core type: Operation
#     operator: 71
#     operand: 75
# 67. |b_{i}〉
#     core type: Operation
#     operator: 71
#     operand: 76
# 68. 1
#     core type: Literal
#     sub-expressions:
# 69. Min(m, n)
#     core type: Operation
#     operator: 73
#     operands: 74
# 70. (a_{i})
#     core type: ExprTuple
#     sub-expressions: 75
# 71. KET
#     core type: Literal
#     sub-expressions:
# 72. (b_{i})
#     core type: ExprTuple
#     sub-expressions: 76
# 73. Min
#     core type: Literal
#     sub-expressions:
# 74. (m, n)
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 75. a_{i}
#     core type: IndexedVar
# variable: 79
# index: 82
# 76. b_{i}
#     core type: IndexedVar
# variable: 80
# index: 82
# 77. m
#     core type: Variable
#     sub-expressions:
# 78. n
#     core type: Variable
#     sub-expressions:
# 79. a
#     core type: Variable
#     sub-expressions:
# 80. b
#     core type: Variable
#     sub-expressions:
# 81. (i)
#     core type: ExprTuple
#     sub-expressions: 82
# 82. i
#     core type: Variable
#     sub-expressions:
