# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, v_1_to_n, v_i
from proveit.linear_algebra import Adj, Commutator, Dim, HilbertSpaces, Hspace, LinMap, OrthoNormBases, ScalarMult, VecSum, VecZero
from proveit.logic import And, Equals, Exists, Forall, Iff, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = LinMap(Hspace, Hspace)
sub_expr3 = Interval(one, n)
sub_expr4 = Qmult(Ket(v_i), Bra(v_i))
expr = Conditional(Forall(instance_param_or_params = [Hspace], instance_expr = Forall(instance_param_or_params = [A, B], instance_expr = Iff(Equals(Commutator(A, B), VecZero(sub_expr2)), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr4), domain = sub_expr3))).with_wrapping_at(2), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), domain = sub_expr2, conditions = [Equals(Adj(A), A), Equals(Adj(B), B)]).with_wrapping(), domain = HilbertSpaces, condition = Equals(Dim(Hspace), n)).with_wrapping(), InSet(n, NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{\mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(\mathcal{H}\right) = n}~\\
# \left[\begin{array}{l}\forall_{A, B \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)~|~A^{\dagger} = A, B^{\dagger} = B}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left[A, B\right] = \vec{0}\left(\mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{v_{1}, v_{2}, \ldots, v_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array}\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right)\end{array}\right]\end{array} \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]])] if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]])]
#    core type: Operation
#    operator: 10
#    operand: 5
# 2. n in NaturalPos
#    core type: Operation
#    operator: 118
#    operands: 4
# 3. (H -> {forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 133, 6
# 5. H -> {forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Lambda
#    parameter: 75
#    body: 7
# 6. NaturalPos
#    core type: Literal
#    sub-expressions:
# 7. {forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{A, B in LINMAP(H, H) | A* = A, B* = B} (([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]])
#    core type: Operation
#    operator: 10
#    operand: 13
# 9. (H in_c HilbertSpaces) and (Dim(H) = n)
#    core type: Operation
#    operator: 79
#    operands: 12
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. ((A, B) -> {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (H in_c HilbertSpaces, Dim(H) = n)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. (A, B) -> {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.
#     core type: Lambda
#     parameters: 46\n    body: 16
# 14. H in_c HilbertSpaces
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. Dim(H) = n
#     core type: Operation
#     operator: 88
#     operands: 19
# 16. {([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in LINMAP(H, H) ,  B in LINMAP(H, H) ,  A* = A ,  B* = B.
#     core type: Conditional
#     value: 20
#     condition: 21
# 17. in_c
#     core type: Literal
#     sub-expressions:
# 18. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 75, 22
# 19. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 23, 133
# 20. ([A, B] = 0(LINMAP(H, H))) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. (A in LINMAP(H, H)) and (B in LINMAP(H, H)) and (A* = A) and (B* = B)
#     core type: Operation
#     operator: 79
#     operands: 26
# 22. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 23. Dim(H)
#     core type: Operation
#     operator: 27
#     operand: 75
# 24. <=>
#     core type: Literal
#     sub-expressions:
# 25. ([A, B] = 0(LINMAP(H, H)), exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))])
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. (A in LINMAP(H, H), B in LINMAP(H, H), A* = A, B* = B)
#     core type: ExprTuple
#     sub-expressions: 30, 31, 32, 33
# 27. Dim
#     core type: Literal
#     sub-expressions:
# 28. [A, B] = 0(LINMAP(H, H))
#     core type: Operation
#     operator: 88
#     operands: 34
# 29. exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]
#     core type: Operation
#     operator: 58
#     operand: 42
# 30. A in LINMAP(H, H)
#     core type: Operation
#     operator: 118
#     operands: 36
# 31. B in LINMAP(H, H)
#     core type: Operation
#     operator: 118
#     operands: 37
# 32. A* = A
#     core type: Operation
#     operator: 88
#     operands: 38
# 33. B* = B
#     core type: Operation
#     operator: 88
#     operands: 39
# 34. ([A, B], 0(LINMAP(H, H)))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 35. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 42
# 36. (A, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 92, 53
# 37. (B, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 94, 53
# 38. (A*, A)
#     core type: ExprTuple
#     sub-expressions: 43, 92
# 39. (B*, B)
#     core type: ExprTuple
#     sub-expressions: 44, 94
# 40. [A, B]
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. 0(LINMAP(H, H))
#     core type: Operation
#     operator: 47
#     operand: 53
# 42. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 67\n    body: 49
# 43. A*
#     core type: Operation
#     operator: 51
#     operand: 92
# 44. B*
#     core type: Operation
#     operator: 51
#     operand: 94
# 45. commutator
#     core type: Literal
#     sub-expressions:
# 46. (A, B)
#     core type: ExprTuple
#     sub-expressions: 92, 94
# 47. 0
#     core type: Literal
#     sub-expressions:
# 48. (LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 53
# 49. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).
#     core type: Conditional
#     value: 54
#     condition: 55
# 50. (A)
#     core type: ExprTuple
#     sub-expressions: 92
# 51. Adj
#     core type: Literal
#     sub-expressions:
# 52. (B)
#     core type: ExprTuple
#     sub-expressions: 94
# 53. LINMAP(H, H)
#     core type: Operation
#     operator: 56
#     operands: 57
# 54. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))
#     core type: Operation
#     operator: 58
#     operand: 61
# 55. {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)
#     core type: Operation
#     operator: 118
#     operands: 60
# 56. LINMAP
#     core type: Literal
#     sub-expressions:
# 57. (H, H)
#     core type: ExprTuple
#     sub-expressions: 75, 75
# 58. exists
#     core type: Literal
#     sub-expressions:
# 59. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 61
# 60. ({v_{1}, v_{2}, ..., v_{n}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 61. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Lambda
#     parameters: 64\n    body: 65
# 62. {v_{1}, v_{2}, ..., v_{n}}
#     core type: Operation
#     operator: 66
#     operands: 67
# 63. O.N.Bases(H)
#     core type: Operation
#     operator: 68
#     operand: 75
# 64. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 65. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 72
#     condition: 73
# 66. Set
#     core type: Literal
#     sub-expressions:
# 67. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 74
# 68. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 69. (H)
#     core type: ExprTuple
#     sub-expressions: 75
# 70. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 76
#     start_index: 132
#     end_index: 133
# 71. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 77
#     start_index: 132
#     end_index: 133
# 72. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 79
#     operands: 78
# 73. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 79
#     operands: 80
# 74. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 81
#     start_index: 132
#     end_index: 133
# 75. H
#     core type: Variable
#     sub-expressions:
# 76. _a -> a_{_a}
#     core type: Lambda
#     parameter: 114
#     body: 105
# 77. _a -> b_{_a}
#     core type: Lambda
#     parameter: 114
#     body: 106
# 78. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 79. and
#     core type: Literal
#     sub-expressions:
# 80. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 81. _a -> v_{_a}
#     core type: Lambda
#     parameter: 114
#     body: 86
# 82. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 88
#     operands: 87
# 83. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 88
#     operands: 89
# 84. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 90
#     start_index: 132
#     end_index: 133
# 85. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 91
#     start_index: 132
#     end_index: 133
# 86. v_{_a}
#     core type: IndexedVar
# variable: 138
# index: 114
# 87. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 88. =
#     core type: Literal
#     sub-expressions:
# 89. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 94, 95
# 90. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 114
#     body: 96
# 91. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 114
#     body: 97
# 92. A
#     core type: Variable
#     sub-expressions:
# 93. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 99
#     operand: 103
# 94. B
#     core type: Variable
#     sub-expressions:
# 95. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 99
#     operand: 104
# 96. a_{_a} in Complex
#     core type: Operation
#     operator: 118
#     operands: 101
# 97. b_{_a} in Complex
#     core type: Operation
#     operator: 118
#     operands: 102
# 98. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 103
# 99. Sum
#     core type: Literal
#     sub-expressions:
# 100. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#      core type: ExprTuple
#      sub-expressions: 104
# 101. (a_{_a}, Complex)
#      core type: ExprTuple
#      sub-expressions: 105, 107
# 102. (b_{_a}, Complex)
#      core type: ExprTuple
#      sub-expressions: 106, 107
# 103. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#      core type: Lambda
#      parameter: 140
#      body: 108
# 104. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#      core type: Lambda
#      parameter: 140
#      body: 109
# 105. a_{_a}
#      core type: IndexedVar
# variable: 124
# index: 114
# 106. b_{_a}
#      core type: IndexedVar
# variable: 125
# index: 114
# 107. Complex
#      core type: Literal
#      sub-expressions:
# 108. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#      core type: Conditional
#      value: 111
#      condition: 113
# 109. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#      core type: Conditional
#      value: 112
#      condition: 113
# 110. (_a)
#      core type: ExprTuple
#      sub-expressions: 114
# 111. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#      core type: Operation
#      operator: 116
#      operands: 115
# 112. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#      core type: Operation
#      operator: 116
#      operands: 117
# 113. i in {1 .. n}
#      core type: Operation
#      operator: 118
#      operands: 119
# 114. _a
#      core type: Variable
#      sub-expressions:
# 115. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 120, 122
# 116. *
#      core type: Literal
#      sub-expressions:
# 117. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 121, 122
# 118. in
#      core type: Literal
#      sub-expressions:
# 119. (i, {1 .. n})
#      core type: ExprTuple
#      sub-expressions: 140, 123
# 120. a_{i}
#      core type: IndexedVar
# variable: 124
# index: 140
# 121. b_{i}
#      core type: IndexedVar
# variable: 125
# index: 140
# 122. |v_{i}〉 . 〈v_{i}|
#      core type: Operation
#      operator: 126
#      operands: 127
# 123. {1 .. n}
#      core type: Operation
#      operator: 128
#      operands: 129
# 124. a
#      core type: Variable
#      sub-expressions:
# 125. b
#      core type: Variable
#      sub-expressions:
# 126. .
#      core type: Literal
#      sub-expressions:
# 127. (|v_{i}〉, 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 130, 131
# 128. Interval
#      core type: Literal
#      sub-expressions:
# 129. (1, n)
#      core type: ExprTuple
#      sub-expressions: 132, 133
# 130. |v_{i}〉
#      core type: Operation
#      operator: 134
#      operand: 137
# 131. 〈v_{i}|
#      core type: Operation
#      operator: 135
#      operand: 137
# 132. 1
#      core type: Literal
#      sub-expressions:
# 133. n
#      core type: Variable
#      sub-expressions:
# 134. KET
#      core type: Literal
#      sub-expressions:
# 135. BRA
#      core type: Literal
#      sub-expressions:
# 136. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 137
# 137. v_{i}
#      core type: IndexedVar
# variable: 138
# index: 140
# 138. v
#      core type: Variable
#      sub-expressions:
# 139. (i)
#      core type: ExprTuple
#      sub-expressions: 140
# 140. i
#      core type: Variable
#      sub-expressions:
