# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#qmult_complex_op_closure">qmult_complex_op_closure</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.algebra import qmult_complex_op_closure

# %%
# check that the built expression is the same as the stored expression
assert qmult_complex_op_closure.expr == stored_expr
assert qmult_complex_op_closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: qmult_complex_op_closure matches stored_expr")
# Out:
# Passed sanity check: qmult_complex_op_closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{c \in \mathbb{C}}~\left[\forall_{\mathcal{H}, X \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}}~\left[\forall_{A~|~\left[A\right] \in \mathcal{L}\left(\mathcal{H}, X\right)}~\left(\left(c \thinspace A\right) \in \mathcal{L}\left(\mathcal{H}, X\right)\right)\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{c in Complex} [forall_{H, X in_c HilbertSpaces} [forall_{A | [A] in LINMAP(H, X)} ((c . A) in LINMAP(H, X))]]
#    core type: Operation
#    operator: 14
#    operand: 2
# 1. (c -> {forall_{H, X in_c HilbertSpaces} [forall_{A | [A] in LINMAP(H, X)} ((c . A) in LINMAP(H, X))] if c in Complex.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. c -> {forall_{H, X in_c HilbertSpaces} [forall_{A | [A] in LINMAP(H, X)} ((c . A) in LINMAP(H, X))] if c in Complex.
#    core type: Lambda
#    parameter: 39
#    body: 4
# 3. (c)
#    core type: ExprTuple
#    sub-expressions: 39
# 4. {forall_{H, X in_c HilbertSpaces} [forall_{A | [A] in LINMAP(H, X)} ((c . A) in LINMAP(H, X))] if c in Complex.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{H, X in_c HilbertSpaces} [forall_{A | [A] in LINMAP(H, X)} ((c . A) in LINMAP(H, X))]
#    core type: Operation
#    operator: 14
#    operand: 9
# 6. c in Complex
#    core type: Operation
#    operator: 29
# ...
