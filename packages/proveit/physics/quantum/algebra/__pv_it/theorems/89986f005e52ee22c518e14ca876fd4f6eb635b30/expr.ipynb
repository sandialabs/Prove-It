# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, v_1_to_n, v_i
from proveit.linear_algebra import Adj, Commutator, MatrixSpace, OrthoNormBases, ScalarMult, VecSum, VecZero
from proveit.logic import And, CartExp, Equals, Exists, Forall, Iff, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = MatrixSpace(field = Complex, rows = n, columns = n)
sub_expr3 = Interval(one, n)
sub_expr4 = Qmult(Ket(v_i), Bra(v_i))
expr = Conditional(Forall(instance_param_or_params = [A, B], instance_expr = Iff(Equals(Commutator(A, B), VecZero(sub_expr2)), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr4), domain = sub_expr3))).with_wrapping_at(2), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n), OrthoNormBases(CartExp(Complex, n)))).with_wrapping()).with_wrapping_at(2), domain = sub_expr2, conditions = [Equals(Adj(A), A), Equals(Adj(B), B)]).with_wrapping(), InSet(n, NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{A, B \in \mathbb{C}^{n \times n}~|~A^{\dagger} = A, B^{\dagger} = B}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left[A, B\right] = \vec{0}\left(\mathbb{C}^{n \times n}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{v_{1}, v_{2}, \ldots, v_{n}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array}\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right)\end{array} \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{A, B in Complex^{n x n} | A* = A, B* = B} (([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]) if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A, B in Complex^{n x n} | A* = A, B* = B} (([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]])
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. n in NaturalPos
#    core type: Operation
#    operator: 106
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((A, B) -> {([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in Complex^{n x n} ,  B in Complex^{n x n} ,  A* = A ,  B* = B.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 121, 7
# 6. (A, B) -> {([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in Complex^{n x n} ,  B in Complex^{n x n} ,  A* = A ,  B* = B.
#    core type: Lambda
#    parameters: 32\n   body: 8
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. {([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in Complex^{n x n} ,  B in Complex^{n x n} ,  A* = A ,  B* = B.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. ([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (A in Complex^{n x n}) and (B in Complex^{n x n}) and (A* = A) and (B* = B)
#     core type: Operation
#     operator: 65
#     operands: 13
# 11. <=>
#     core type: Literal
#     sub-expressions:
# 12. ([A, B] = 0(Complex^{n x n}), exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))])
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. (A in Complex^{n x n}, B in Complex^{n x n}, A* = A, B* = B)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18, 19
# 14. [A, B] = 0(Complex^{n x n})
#     core type: Operation
#     operator: 76
#     operands: 20
# 15. exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]
#     core type: Operation
#     operator: 44
#     operand: 28
# 16. A in Complex^{n x n}
#     core type: Operation
#     operator: 106
#     operands: 22
# 17. B in Complex^{n x n}
#     core type: Operation
#     operator: 106
#     operands: 23
# 18. A* = A
#     core type: Operation
#     operator: 76
#     operands: 24
# 19. B* = B
#     core type: Operation
#     operator: 76
#     operands: 25
# 20. ([A, B], 0(Complex^{n x n}))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 21. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).)
#     core type: ExprTuple
#     sub-expressions: 28
# 22. (A, Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 80, 39
# 23. (B, Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 82, 39
# 24. (A*, A)
#     core type: ExprTuple
#     sub-expressions: 29, 80
# 25. (B*, B)
#     core type: ExprTuple
#     sub-expressions: 30, 82
# 26. [A, B]
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. 0(Complex^{n x n})
#     core type: Operation
#     operator: 33
#     operand: 39
# 28. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).
#     core type: Lambda
#     parameters: 53\n    body: 35
# 29. A*
#     core type: Operation
#     operator: 37
#     operand: 80
# 30. B*
#     core type: Operation
#     operator: 37
#     operand: 82
# 31. commutator
#     core type: Literal
#     sub-expressions:
# 32. (A, B)
#     core type: ExprTuple
#     sub-expressions: 80, 82
# 33. 0
#     core type: Literal
#     sub-expressions:
# 34. (Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 39
# 35. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 40
#     condition: 41
# 36. (A)
#     core type: ExprTuple
#     sub-expressions: 80
# 37. Adj
#     core type: Literal
#     sub-expressions:
# 38. (B)
#     core type: ExprTuple
#     sub-expressions: 82
# 39. Complex^{n x n}
#     core type: Operation
#     operator: 42
#     operands: 43
# 40. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))
#     core type: Operation
#     operator: 44
#     operand: 47
# 41. {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 106
#     operands: 46
# 42. MSpace
#     core type: Literal
#     sub-expressions:
# 43. {field:Complex, rows:n, columns:n}
#     core type: NamedExprs
#     field: 95
#     rows: 121
#     columns: 121
# 44. exists
#     core type: Literal
#     sub-expressions:
# 45. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 47
# 46. ({v_{1}, v_{2}, ..., v_{n}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 47. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Lambda
#     parameters: 50\n    body: 51
# 48. {v_{1}, v_{2}, ..., v_{n}}
#     core type: Operation
#     operator: 52
#     operands: 53
# 49. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 54
#     operand: 61
# 50. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 51. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 58
#     condition: 59
# 52. Set
#     core type: Literal
#     sub-expressions:
# 53. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 60
# 54. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 55. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 61
# 56. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 62
#     start_index: 120
#     end_index: 121
# 57. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 120
#     end_index: 121
# 58. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 65
#     operands: 64
# 59. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 65
#     operands: 66
# 60. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 67
#     start_index: 120
#     end_index: 121
# 61. Complex^{n}
#     core type: Operation
#     operator: 68
#     operands: 69
# 62. _a -> a_{_a}
#     core type: Lambda
#     parameter: 102
#     body: 93
# 63. _a -> b_{_a}
#     core type: Lambda
#     parameter: 102
#     body: 94
# 64. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 65. and
#     core type: Literal
#     sub-expressions:
# 66. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 67. _a -> v_{_a}
#     core type: Lambda
#     parameter: 102
#     body: 74
# 68. CartExp
#     core type: Literal
#     sub-expressions:
# 69. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 95, 121
# 70. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 76
#     operands: 75
# 71. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 76
#     operands: 77
# 72. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 78
#     start_index: 120
#     end_index: 121
# 73. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 79
#     start_index: 120
#     end_index: 121
# 74. v_{_a}
#     core type: IndexedVar
# variable: 126
# index: 102
# 75. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 76. =
#     core type: Literal
#     sub-expressions:
# 77. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 78. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 102
#     body: 84
# 79. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 102
#     body: 85
# 80. A
#     core type: Variable
#     sub-expressions:
# 81. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 87
#     operand: 91
# 82. B
#     core type: Variable
#     sub-expressions:
# 83. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 87
#     operand: 92
# 84. a_{_a} in Complex
#     core type: Operation
#     operator: 106
#     operands: 89
# 85. b_{_a} in Complex
#     core type: Operation
#     operator: 106
#     operands: 90
# 86. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 91
# 87. Sum
#     core type: Literal
#     sub-expressions:
# 88. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 92
# 89. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 93, 95
# 90. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 94, 95
# 91. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 128
#     body: 96
# 92. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 128
#     body: 97
# 93. a_{_a}
#     core type: IndexedVar
# variable: 112
# index: 102
# 94. b_{_a}
#     core type: IndexedVar
# variable: 113
# index: 102
# 95. Complex
#     core type: Literal
#     sub-expressions:
# 96. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 99
#     condition: 101
# 97. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 100
#     condition: 101
# 98. (_a)
#     core type: ExprTuple
#     sub-expressions: 102
# 99. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 104
#     operands: 103
# 100. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#      core type: Operation
#      operator: 104
#      operands: 105
# 101. i in {1 .. n}
#      core type: Operation
#      operator: 106
#      operands: 107
# 102. _a
#      core type: Variable
#      sub-expressions:
# 103. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 108, 110
# 104. *
#      core type: Literal
#      sub-expressions:
# 105. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 109, 110
# 106. in
#      core type: Literal
#      sub-expressions:
# 107. (i, {1 .. n})
#      core type: ExprTuple
#      sub-expressions: 128, 111
# 108. a_{i}
#      core type: IndexedVar
# variable: 112
# index: 128
# 109. b_{i}
#      core type: IndexedVar
# variable: 113
# index: 128
# 110. |v_{i}〉 . 〈v_{i}|
#      core type: Operation
#      operator: 114
#      operands: 115
# 111. {1 .. n}
#      core type: Operation
#      operator: 116
#      operands: 117
# 112. a
#      core type: Variable
#      sub-expressions:
# 113. b
#      core type: Variable
#      sub-expressions:
# 114. .
#      core type: Literal
#      sub-expressions:
# 115. (|v_{i}〉, 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 118, 119
# 116. Interval
#      core type: Literal
#      sub-expressions:
# 117. (1, n)
#      core type: ExprTuple
#      sub-expressions: 120, 121
# 118. |v_{i}〉
#      core type: Operation
#      operator: 122
#      operand: 125
# 119. 〈v_{i}|
#      core type: Operation
#      operator: 123
#      operand: 125
# 120. 1
#      core type: Literal
#      sub-expressions:
# 121. n
#      core type: Variable
#      sub-expressions:
# 122. KET
#      core type: Literal
#      sub-expressions:
# 123. BRA
#      core type: Literal
#      sub-expressions:
# 124. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 125
# 125. v_{i}
#      core type: IndexedVar
# variable: 126
# index: 128
# 126. v
#      core type: Variable
#      sub-expressions:
# 127. (i)
#      core type: ExprTuple
#      sub-expressions: 128
# 128. i
#      core type: Variable
#      sub-expressions:
