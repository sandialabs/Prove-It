# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import X, i, n
from proveit.core_expr_types import x_1_to_n, x_i
from proveit.linear_algebra import Hspace, OrthoNormBases, OrthoProj, VecSum
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import x_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(OrthoProj(Hspace, X), VecSum(index_or_indices = [i], summand = Qmult(Ket(x_i), Bra(x_i)), domain = Interval(one, n))), condition = InSet(x_1_to_n_kets, OrthoNormBases(X))).with_wrapping(), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{\lvert x_{1} \rangle, \lvert x_{2} \rangle, \ldots, \lvert x_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(X\right)}~\\
# \left(\textrm{OrthoProj}\left(\mathcal{H}, X\right) = \left(\sum_{i=1}^{n} \left(\lvert x_{i} \rangle \thinspace \langle x_{i} \rvert\right)\right)\right)\end{array}\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 59
#    body: 4
# 3. (n)
#    core type: ExprTuple
#    sub-expressions: 59
# 4. {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. n in NaturalPos
#    core type: Operation
#    operator: 44
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 59, 11
# 10. (x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).
#     core type: Lambda
#     parameters: 12\n    body: 13
# 11. NaturalPos
#     core type: Literal
#     sub-expressions:
# 12. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).
#     core type: Conditional
#     value: 15
#     condition: 16
# 14. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 58
#     end_index: 59
# 15. OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)
#     core type: Operation
#     operator: 44
#     operands: 20
# 17. _a -> x_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 50
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (OrthoProj(H, X), Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. ({|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}, O.N.Bases(X))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. OrthoProj(H, X)
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)
#     core type: Operation
#     operator: 27
#     operand: 34
# 23. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. O.N.Bases(X)
#     core type: Operation
#     operator: 31
#     operand: 36
# 25. OrthoProj
#     core type: Literal
#     sub-expressions:
# 26. (H, X)
#     core type: ExprTuple
#     sub-expressions: 33, 36
# 27. Sum
#     core type: Literal
#     sub-expressions:
# 28. (i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 34
# 29. Set
#     core type: Literal
#     sub-expressions:
# 30. (|x_{1}〉, |x_{2}〉, ..., |x_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 35
# 31. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 32. (X)
#     core type: ExprTuple
#     sub-expressions: 36
# 33. H
#     core type: Variable
#     sub-expressions:
# 34. i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 63
#     body: 37
# 35. |x_{1}〉, |x_{2}〉, ..., |x_{n}〉
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 58
#     end_index: 59
# 36. X
#     core type: Variable
#     sub-expressions:
# 37. {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 39
#     condition: 40
# 38. _a -> |x_{_a}〉
#     core type: Lambda
#     parameter: 60
#     body: 41
# 39. |x_{i}〉 . 〈x_{i}|
#     core type: Operation
#     operator: 42
#     operands: 43
# 40. i in {1 .. n}
#     core type: Operation
#     operator: 44
#     operands: 45
# 41. |x_{_a}〉
#     core type: Operation
#     operator: 51
#     operand: 50
# 42. .
#     core type: Literal
#     sub-expressions:
# 43. (|x_{i}〉, 〈x_{i}|)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 44. in
#     core type: Literal
#     sub-expressions:
# 45. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 63, 49
# 46. (x_{_a})
#     core type: ExprTuple
#     sub-expressions: 50
# 47. |x_{i}〉
#     core type: Operation
#     operator: 51
#     operand: 57
# 48. 〈x_{i}|
#     core type: Operation
#     operator: 52
#     operand: 57
# 49. {1 .. n}
#     core type: Operation
#     operator: 54
#     operands: 55
# 50. x_{_a}
#     core type: IndexedVar
# variable: 61
# index: 60
# 51. KET
#     core type: Literal
#     sub-expressions:
# 52. BRA
#     core type: Literal
#     sub-expressions:
# 53. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 57
# 54. Interval
#     core type: Literal
#     sub-expressions:
# 55. (1, n)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 57. x_{i}
#     core type: IndexedVar
# variable: 61
# index: 63
# 58. 1
#     core type: Literal
#     sub-expressions:
# 59. n
#     core type: Variable
#     sub-expressions:
# 60. _a
#     core type: Variable
#     sub-expressions:
# 61. x
#     core type: Variable
#     sub-expressions:
# 62. (i)
#     core type: ExprTuple
#     sub-expressions: 63
# 63. i
#     core type: Variable
#     sub-expressions:
