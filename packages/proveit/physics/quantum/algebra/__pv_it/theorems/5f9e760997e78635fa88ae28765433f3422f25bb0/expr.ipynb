# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, i, n
from proveit.core_expr_types import v_1_to_n, v_i, w_1_to_n, w_i
from proveit.linear_algebra import OrthoNormBases, Unitary, VecSum
from proveit.logic import CartExp, Forall, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = OrthoNormBases(CartExp(Complex, n))
expr = Lambda(n, Conditional(Forall(instance_param_or_params = [v_1_to_n, w_1_to_n], instance_expr = InSet(VecSum(index_or_indices = [i], summand = Qmult(Ket(v_i), Bra(w_i)), domain = Interval(one, n)), Unitary(n)), conditions = [InSet(Set(v_1_to_n_kets), sub_expr1), InSet(Set(w_1_to_n_kets), sub_expr1)]).with_wrapping(), InSet(n, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# n \mapsto \left\{\begin{array}{l}\forall_{v_{1}, v_{2}, \ldots, v_{n}, w_{1}, w_{2}, \ldots, w_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right), \left\{\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left(\left(\sum_{i=1}^{n} \left(\lvert v_{i} \rangle \thinspace \langle w_{i} \rvert\right)\right) \in \textrm{U}\left(n\right)\right)\end{array} \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. n -> {forall_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} ((Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n)) if n in NaturalPos.
#    core type: Lambda
#    parameter: 69
#    body: 1
# 1. {forall_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} ((Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n)) if n in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} ((Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. n in NaturalPos
#    core type: Operation
#    operator: 46
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {(Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 69, 8
# 7. (v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {(Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 9\n   body: 10
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. (v_{1}, v_{2}, ..., v_{n},w_{1}, w_{2}, ..., w_{n})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. {(Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 68
#     end_index: 69
# 12. w_{1}, w_{2}, ..., w_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 68
#     end_index: 69
# 13. (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n)
#     core type: Operation
#     operator: 46
#     operands: 17
# 14. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})) and ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. _a -> v_{_a}
#     core type: Lambda
#     parameter: 82
#     body: 77
# 16. _a -> w_{_a}
#     core type: Lambda
#     parameter: 82
#     body: 78
# 17. (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|), U(n))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)
#     core type: Operation
#     operator: 24
#     operand: 30
# 21. U(n)
#     core type: Operation
#     operator: 26
#     operand: 69
# 22. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 46
#     operands: 28
# 23. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 46
#     operands: 29
# 24. Sum
#     core type: Literal
#     sub-expressions:
# 25. (i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 30
# 26. U
#     core type: Literal
#     sub-expressions:
# 27. (n)
#     core type: ExprTuple
#     sub-expressions: 69
# 28. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 31, 33
# 29. ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 76
#     body: 34
# 31. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 49
#     operand: 41
# 32. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}
#     core type: Operation
#     operator: 49
#     operand: 42
# 33. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 37
#     operand: 43
# 34. {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 39
#     condition: 40
# 35. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 41
# 36. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 42
# 37. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 38. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 43
# 39. |v_{i}〉 . 〈w_{i}|
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. i in {1 .. n}
#     core type: Operation
#     operator: 46
#     operands: 47
# 41. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 49
#     operands: 48
# 42. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 49
#     operands: 50
# 43. Complex^{n}
#     core type: Operation
#     operator: 51
#     operands: 52
# 44. .
#     core type: Literal
#     sub-expressions:
# 45. (|v_{i}〉, 〈w_{i}|)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 76, 55
# 48. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 56
# 49. Set
#     core type: Literal
#     sub-expressions:
# 50. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 57
# 51. CartExp
#     core type: Literal
#     sub-expressions:
# 52. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 58, 69
# 53. |v_{i}〉
#     core type: Operation
#     operator: 74
#     operand: 66
# 54. 〈w_{i}|
#     core type: Operation
#     operator: 60
#     operand: 67
# 55. {1 .. n}
#     core type: Operation
#     operator: 62
#     operands: 63
# 56. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 64
#     start_index: 68
#     end_index: 69
# 57. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 65
#     start_index: 68
#     end_index: 69
# 58. Complex
#     core type: Literal
#     sub-expressions:
# 59. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 66
# 60. BRA
#     core type: Literal
#     sub-expressions:
# 61. (w_{i})
#     core type: ExprTuple
#     sub-expressions: 67
# 62. Interval
#     core type: Literal
#     sub-expressions:
# 63. (1, n)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 64. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 82
#     body: 70
# 65. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 82
#     body: 71
# 66. v_{i}
#     core type: IndexedVar
# variable: 79
# index: 76
# 67. w_{i}
#     core type: IndexedVar
# variable: 80
# index: 76
# 68. 1
#     core type: Literal
#     sub-expressions:
# 69. n
#     core type: Variable
#     sub-expressions:
# 70. |v_{_a}〉
#     core type: Operation
#     operator: 74
#     operand: 77
# 71. |w_{_a}〉
#     core type: Operation
#     operator: 74
#     operand: 78
# 72. (i)
#     core type: ExprTuple
#     sub-expressions: 76
# 73. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 77
# 74. KET
#     core type: Literal
#     sub-expressions:
# 75. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 78
# 76. i
#     core type: Variable
#     sub-expressions:
# 77. v_{_a}
#     core type: IndexedVar
# variable: 79
# index: 82
# 78. w_{_a}
#     core type: IndexedVar
# variable: 80
# index: 82
# 79. v
#     core type: Variable
#     sub-expressions:
# 80. w
#     core type: Variable
#     sub-expressions:
# 81. (_a)
#     core type: ExprTuple
#     sub-expressions: 82
# 82. _a
#     core type: Variable
#     sub-expressions:
