# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, Conditional, ExprRange, IndexedVar, Variable, i, m, n
from proveit.core_expr_types import A_1_to_m, B_1_to_i, C_1_to_n
from proveit.linear_algebra import VecAdd
from proveit.logic import And, Equals, Forall, Implies, InClass, InSet
from proveit.numbers import Natural, NaturalPos, one
from proveit.physics.quantum import Qmult, QmultCodomain

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr2 = Qmult(A_1_to_m, VecAdd(B_1_to_i), C_1_to_n)
expr = Conditional(Forall(instance_param_or_params = [A_1_to_m, B_1_to_i, C_1_to_n], instance_expr = Implies(InClass(sub_expr2, QmultCodomain), Equals(sub_expr2, VecAdd(ExprRange(sub_expr1, Qmult(A_1_to_m, IndexedVar(B, sub_expr1), C_1_to_n), one, i))).with_wrapping_at(2)).with_wrapping_at(2)), And(InSet(i, NaturalPos), InSet(m, Natural), InSet(n, Natural)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{A_{1}, A_{2}, \ldots, A_{m}, B_{1}, B_{2}, \ldots, B_{i}, C_{1}, C_{2}, \ldots, C_{n}}~\left(\begin{array}{c} \begin{array}{l} \left(\left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{m} \thinspace \left(B_{1} +  B_{2} +  \ldots +  B_{i}\right)\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) \underset{{\scriptscriptstyle c}}{\in} \mathcal{Q^*}\right) \Rightarrow  \\ \left(\begin{array}{c} \begin{array}{l} \left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{m} \thinspace \left(B_{1} +  B_{2} +  \ldots +  B_{i}\right)\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) =  \\ \left(\left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{m} \thinspace B_{1}\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) +  \left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{m} \thinspace B_{2}\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) +  \ldots +  \left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{m} \thinspace B_{i}\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right)\right) \end{array} \end{array}\right) \end{array} \end{array}\right) \textrm{ if } i \in \mathbb{N}^+ ,  m \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{i}, C_{1}, C_{2}, ..., C_{n}} (((A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*) =>  \\ ((A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}) =  \\ ((A_{1} .  A_{2} .  ... .  A_{m} . B_{1}. C_{1} .  C_{2} .  ... .  C_{n}) +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{2}. C_{1} .  C_{2} .  ... .  C_{n}) +  ... +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{i}. C_{1} .  C_{2} .  ... .  C_{n})))) if i in NaturalPos ,  m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{i}, C_{1}, C_{2}, ..., C_{n}} (((A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*) =>  \\ ((A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}) =  \\ ((A_{1} .  A_{2} .  ... .  A_{m} . B_{1}. C_{1} .  C_{2} .  ... .  C_{n}) +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{2}. C_{1} .  C_{2} .  ... .  C_{n}) +  ... +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{i}. C_{1} .  C_{2} .  ... .  C_{n}))))
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (i in NaturalPos) and (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{i}, C_{1}, C_{2}, ..., C_{n}) -> (((A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*) =>  \\ ((A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}) =  \\ ((A_{1} .  A_{2} .  ... .  A_{m} . B_{1}. C_{1} .  C_{2} .  ... .  C_{n}) +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{2}. C_{1} .  C_{2} .  ... .  C_{n}) +  ... +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{i}. C_{1} .  C_{2} .  ... .  C_{n})))))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (i in NaturalPos, m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. (A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{i}, C_{1}, C_{2}, ..., C_{n}) -> (((A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*) =>  \\ ((A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}) =  \\ ((A_{1} .  A_{2} .  ... .  A_{m} . B_{1}. C_{1} .  C_{2} .  ... .  C_{n}) +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{2}. C_{1} .  C_{2} .  ... .  C_{n}) +  ... +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{i}. C_{1} .  C_{2} .  ... .  C_{n}))))
#    core type: Lambda
#    parameters: 11\n   body: 12
# 8. i in NaturalPos
#    core type: Operation
#    operator: 15
#    operands: 13
# 9. m in Natural
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. n in Natural
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. (A_{1}, A_{2}, ..., A_{m},B_{1}, B_{2}, ..., B_{i},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 44, 37, 46
# 12. ((A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*) =>  \\ ((A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}) =  \\ ((A_{1} .  A_{2} .  ... .  A_{m} . B_{1}. C_{1} .  C_{2} .  ... .  C_{n}) +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{2}. C_{1} .  C_{2} .  ... .  C_{n}) +  ... +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{i}. C_{1} .  C_{2} .  ... .  C_{n})))
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. (i, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 40, 19
# 14. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 48, 20
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 53, 20
# 17. =>
#     core type: Literal
#     sub-expressions:
# 18. ((A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*, (A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}) =  \\ ((A_{1} .  A_{2} .  ... .  A_{m} . B_{1}. C_{1} .  C_{2} .  ... .  C_{n}) +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{2}. C_{1} .  C_{2} .  ... .  C_{n}) +  ... +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{i}. C_{1} .  C_{2} .  ... .  C_{n})))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. Natural
#     core type: Literal
#     sub-expressions:
# 21. (A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. (A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}) =  \\ ((A_{1} .  A_{2} .  ... .  A_{m} . B_{1}. C_{1} .  C_{2} .  ... .  C_{n}) +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{2}. C_{1} .  C_{2} .  ... .  C_{n}) +  ... +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{i}. C_{1} .  C_{2} .  ... .  C_{n}))
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. in_c
#     core type: Literal
#     sub-expressions:
# 24. (A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}, Q*)
#     core type: ExprTuple
#     sub-expressions: 28, 27
# 25. =
#     core type: Literal
#     sub-expressions:
# 26. (A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}, (A_{1} .  A_{2} .  ... .  A_{m} . B_{1}. C_{1} .  C_{2} .  ... .  C_{n}) +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{2}. C_{1} .  C_{2} .  ... .  C_{n}) +  ... +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{i}. C_{1} .  C_{2} .  ... .  C_{n}))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. Q*
#     core type: Literal
#     sub-expressions:
# 28. A_{1} .  A_{2} .  ... .  A_{m} . (B_{1} +  B_{2} +  ... +  B_{i}). C_{1} .  C_{2} .  ... .  C_{n}
#     core type: Operation
#     operator: 41
#     operands: 30
# 29. (A_{1} .  A_{2} .  ... .  A_{m} . B_{1}. C_{1} .  C_{2} .  ... .  C_{n}) +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{2}. C_{1} .  C_{2} .  ... .  C_{n}) +  ... +  (A_{1} .  A_{2} .  ... .  A_{m} . B_{i}. C_{1} .  C_{2} .  ... .  C_{n})
#     core type: Operation
#     operator: 34
#     operands: 31
# 30. (A_{1}, A_{2}, ..., A_{m}, B_{1} +  B_{2} +  ... +  B_{i},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 44, 32, 46
# 31. ((A_{1} .  A_{2} .  ... .  A_{m} . B_{1}. C_{1} .  C_{2} .  ... .  C_{n}), (A_{1} .  A_{2} .  ... .  A_{m} . B_{2}. C_{1} .  C_{2} .  ... .  C_{n}), ..., (A_{1} .  A_{2} .  ... .  A_{m} . B_{i}. C_{1} .  C_{2} .  ... .  C_{n}))
#     core type: ExprTuple
#     sub-expressions: 33
# 32. B_{1} +  B_{2} +  ... +  B_{i}
#     core type: Operation
#     operator: 34
#     operands: 35
# 33. (A_{1} .  A_{2} .  ... .  A_{m} . B_{1}. C_{1} .  C_{2} .  ... .  C_{n}), (A_{1} .  A_{2} .  ... .  A_{m} . B_{2}. C_{1} .  C_{2} .  ... .  C_{n}), ..., (A_{1} .  A_{2} .  ... .  A_{m} . B_{i}. C_{1} .  C_{2} .  ... .  C_{n})
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 52
#     end_index: 40
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. (B_{1}, B_{2}, ..., B_{i})
#     core type: ExprTuple
#     sub-expressions: 37
# 36. _b -> (A_{1} .  A_{2} .  ... .  A_{m} . B_{_b}. C_{1} .  C_{2} .  ... .  C_{n})
#     core type: Lambda
#     parameter: 55
#     body: 38
# 37. B_{1}, B_{2}, ..., B_{i}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 52
#     end_index: 40
# 38. A_{1} .  A_{2} .  ... .  A_{m} . B_{_b}. C_{1} .  C_{2} .  ... .  C_{n}
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. _a -> B_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 43
# 40. i
#     core type: Variable
#     sub-expressions:
# 41. .
#     core type: Literal
#     sub-expressions:
# 42. (A_{1}, A_{2}, ..., A_{m}, B_{_b},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 44, 45, 46
# 43. B_{_a}
#     core type: IndexedVar
# variable: 49
# index: 60
# 44. A_{1}, A_{2}, ..., A_{m}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 52
#     end_index: 48
# 45. B_{_b}
#     core type: IndexedVar
# variable: 49
# index: 55
# 46. C_{1}, C_{2}, ..., C_{n}
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 52
#     end_index: 53
# 47. _a -> A_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 54
# 48. m
#     core type: Variable
#     sub-expressions:
# 49. B
#     core type: Variable
#     sub-expressions:
# 50. (_b)
#     core type: ExprTuple
#     sub-expressions: 55
# 51. _a -> C_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 56
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. n
#     core type: Variable
#     sub-expressions:
# 54. A_{_a}
#     core type: IndexedVar
# variable: 57
# index: 60
# 55. _b
#     core type: Variable
#     sub-expressions:
# 56. C_{_a}
#     core type: IndexedVar
# variable: 58
# index: 60
# 57. A
#     core type: Variable
#     sub-expressions:
# 58. C
#     core type: Variable
#     sub-expressions:
# 59. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 60. _a
#     core type: Variable
#     sub-expressions:
