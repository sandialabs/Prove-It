# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, X, i, n
from proveit.core_expr_types import x_1_to_n, x_i
from proveit.linear_algebra import Hspace, OrthoNormBases, OrthoProj, VecSum
from proveit.logic import Equals, Forall, InSet, SubsetEq
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import x_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(X, Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(OrthoProj(Hspace, X), VecSum(index_or_indices = [i], summand = Qmult(Ket(x_i), Bra(x_i)), domain = Interval(one, n))), condition = InSet(x_1_to_n_kets, OrthoNormBases(X))).with_wrapping(), domain = NaturalPos), SubsetEq(X, Hspace))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(X \mapsto \left\{\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{\lvert x_{1} \rangle, \lvert x_{2} \rangle, \ldots, \lvert x_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(X\right)}~\\
# \left(\textrm{OrthoProj}\left(\mathcal{H}, X\right) = \left(\sum_{i=1}^{n} \left(\lvert x_{i} \rangle \thinspace \langle x_{i} \rvert\right)\right)\right)\end{array}\right] \textrm{ if } X \subseteq \mathcal{H}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (X -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. X -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.
#    core type: Lambda
#    parameter: 42
#    body: 2
# 2. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))] if X subset_eq H.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))]
#    core type: Operation
#    operator: 13
#    operand: 8
# 4. X subset_eq H
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. subset_eq
#    core type: Literal
#    sub-expressions:
# 7. (X, H)
#    core type: ExprTuple
#    sub-expressions: 42, 39
# 8. n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 65
#    body: 10
# 9. (n)
#    core type: ExprTuple
#    sub-expressions: 65
# 10. {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))
#     core type: Operation
#     operator: 13
#     operand: 16
# 12. n in NaturalPos
#     core type: Operation
#     operator: 50
#     operands: 15
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. ((x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 65, 17
# 16. (x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).
#     core type: Lambda
#     parameters: 18\n    body: 19
# 17. NaturalPos
#     core type: Literal
#     sub-expressions:
# 18. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 20
# 19. {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).
#     core type: Conditional
#     value: 21
#     condition: 22
# 20. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 64
#     end_index: 65
# 21. OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)
#     core type: Operation
#     operator: 50
#     operands: 26
# 23. _a -> x_{_a}
#     core type: Lambda
#     parameter: 66
#     body: 56
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (OrthoProj(H, X), Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. ({|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}, O.N.Bases(X))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. OrthoProj(H, X)
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)
#     core type: Operation
#     operator: 33
#     operand: 40
# 29. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}
#     core type: Operation
#     operator: 35
#     operands: 36
# 30. O.N.Bases(X)
#     core type: Operation
#     operator: 37
#     operand: 42
# 31. OrthoProj
#     core type: Literal
#     sub-expressions:
# 32. (H, X)
#     core type: ExprTuple
#     sub-expressions: 39, 42
# 33. Sum
#     core type: Literal
#     sub-expressions:
# 34. (i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 40
# 35. Set
#     core type: Literal
#     sub-expressions:
# 36. (|x_{1}〉, |x_{2}〉, ..., |x_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 41
# 37. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 38. (X)
#     core type: ExprTuple
#     sub-expressions: 42
# 39. H
#     core type: Variable
#     sub-expressions:
# 40. i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 69
#     body: 43
# 41. |x_{1}〉, |x_{2}〉, ..., |x_{n}〉
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 64
#     end_index: 65
# 42. X
#     core type: Variable
#     sub-expressions:
# 43. {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 45
#     condition: 46
# 44. _a -> |x_{_a}〉
#     core type: Lambda
#     parameter: 66
#     body: 47
# 45. |x_{i}〉 . 〈x_{i}|
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. i in {1 .. n}
#     core type: Operation
#     operator: 50
#     operands: 51
# 47. |x_{_a}〉
#     core type: Operation
#     operator: 57
#     operand: 56
# 48. .
#     core type: Literal
#     sub-expressions:
# 49. (|x_{i}〉, 〈x_{i}|)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 69, 55
# 52. (x_{_a})
#     core type: ExprTuple
#     sub-expressions: 56
# 53. |x_{i}〉
#     core type: Operation
#     operator: 57
#     operand: 63
# 54. 〈x_{i}|
#     core type: Operation
#     operator: 58
#     operand: 63
# 55. {1 .. n}
#     core type: Operation
#     operator: 60
#     operands: 61
# 56. x_{_a}
#     core type: IndexedVar
# variable: 67
# index: 66
# 57. KET
#     core type: Literal
#     sub-expressions:
# 58. BRA
#     core type: Literal
#     sub-expressions:
# 59. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 63
# 60. Interval
#     core type: Literal
#     sub-expressions:
# 61. (1, n)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 62. (_a)
#     core type: ExprTuple
#     sub-expressions: 66
# 63. x_{i}
#     core type: IndexedVar
# variable: 67
# index: 69
# 64. 1
#     core type: Literal
#     sub-expressions:
# 65. n
#     core type: Variable
#     sub-expressions:
# 66. _a
#     core type: Variable
#     sub-expressions:
# 67. x
#     core type: Variable
#     sub-expressions:
# 68. (i)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. i
#     core type: Variable
#     sub-expressions:
