# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, j, l
from proveit.core_expr_types import A_1_to_l, b_1_to_j
from proveit.logic import And, Equals, Forall, InClass, InSet
from proveit.numbers import Complex, Mult, Natural, NaturalPos
from proveit.physics.quantum import Qmult, QmultCodomain

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([j, l], Conditional(Forall(instance_param_or_params = [b_1_to_j], instance_expr = Forall(instance_param_or_params = [A_1_to_l], instance_expr = Equals(Qmult(b_1_to_j, A_1_to_l), Qmult(Mult(b_1_to_j), A_1_to_l)).with_wrapping_at(2), condition = InClass(Qmult(A_1_to_l), QmultCodomain)), domain = Complex), And(InSet(j, NaturalPos), InSet(l, Natural)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(j, l\right) \mapsto \left\{\forall_{b_{1}, b_{2}, \ldots, b_{j} \in \mathbb{C}}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{l}~|~\left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\right) \underset{{\scriptscriptstyle c}}{\in} \mathcal{Q^*}}~\left(\begin{array}{c} \begin{array}{l} \left(b_{1} \thinspace  b_{2} \thinspace  \ldots \thinspace  b_{j}\thinspace A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\right) =  \\ \left(\left(b_{1} \cdot  b_{2} \cdot  \ldots \cdot  b_{j}\right)\thinspace A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\right) \end{array} \end{array}\right)\right] \textrm{ if } j \in \mathbb{N}^+ ,  l \in \mathbb{N}\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((j, l) -> {forall_{b_{1}, b_{2}, ..., b_{j} in Complex} [forall_{A_{1}, A_{2}, ..., A_{l} | (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*} ((b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}))] if j in NaturalPos ,  l in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (j, l) -> {forall_{b_{1}, b_{2}, ..., b_{j} in Complex} [forall_{A_{1}, A_{2}, ..., A_{l} | (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*} ((b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}))] if j in NaturalPos ,  l in Natural.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (j, l)
#    core type: ExprTuple
#    sub-expressions: 54, 49
# 3. {forall_{b_{1}, b_{2}, ..., b_{j} in Complex} [forall_{A_{1}, A_{2}, ..., A_{l} | (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*} ((b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}))] if j in NaturalPos ,  l in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{b_{1}, b_{2}, ..., b_{j} in Complex} [forall_{A_{1}, A_{2}, ..., A_{l} | (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*} ((b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}))]
#    core type: Operation
#    operator: 18
#    operand: 8
# 5. (j in NaturalPos) and (l in Natural)
#    core type: Operation
#    operator: 20
#    operands: 7
# 6. ((b_{1}, b_{2}, ..., b_{j}) -> {forall_{A_{1}, A_{2}, ..., A_{l} | (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*} ((b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l})) if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (j in NaturalPos, l in Natural)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (b_{1}, b_{2}, ..., b_{j}) -> {forall_{A_{1}, A_{2}, ..., A_{l} | (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*} ((b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l})) if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).
#    core type: Lambda
#    parameters: 47\n   body: 11
# 9. j in NaturalPos
#    core type: Operation
#    operator: 33
#    operands: 12
# 10. l in Natural
#     core type: Operation
#     operator: 33
#     operands: 13
# 11. {forall_{A_{1}, A_{2}, ..., A_{l} | (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*} ((b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l})) if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. (j, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 54, 16
# 13. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 49, 17
# 14. forall_{A_{1}, A_{2}, ..., A_{l} | (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*} ((b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}))
#     core type: Operation
#     operator: 18
#     operand: 22
# 15. (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex)
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. NaturalPos
#     core type: Literal
#     sub-expressions:
# 17. Natural
#     core type: Literal
#     sub-expressions:
# 18. forall
#     core type: Literal
#     sub-expressions:
# 19. ((A_{1}, A_{2}, ..., A_{l}) -> {(b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}) if (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*.)
#     core type: ExprTuple
#     sub-expressions: 22
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. ((b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex))
#     core type: ExprTuple
#     sub-expressions: 23
# 22. (A_{1}, A_{2}, ..., A_{l}) -> {(b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}) if (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*.
#     core type: Lambda
#     parameters: 43\n    body: 24
# 23. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 53
#     end_index: 54
# 24. {(b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}) if (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*.
#     core type: Conditional
#     value: 26
#     condition: 27
# 25. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 59
#     body: 28
# 26. (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l})
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. b_{_a} in Complex
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. =
#     core type: Literal
#     sub-expressions:
# 30. (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}, (b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l})
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 31. in_c
#     core type: Literal
#     sub-expressions:
# 32. (A_{1} .  A_{2} .  ... .  A_{l}, Q*)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 56, 39
# 35. b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}
#     core type: Operation
#     operator: 42
#     operands: 40
# 36. (b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}
#     core type: Operation
#     operator: 42
#     operands: 41
# 37. A_{1} .  A_{2} .  ... .  A_{l}
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. Q*
#     core type: Literal
#     sub-expressions:
# 39. Complex
#     core type: Literal
#     sub-expressions:
# 40. (b_{1}, b_{2}, ..., b_{j},A_{1}, A_{2}, ..., A_{l})
#     core type: ExprTuple
#     sub-expressions: 50, 45
# 41. (b_{1} *  b_{2} *  ... *  b_{j},A_{1}, A_{2}, ..., A_{l})
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. .
#     core type: Literal
#     sub-expressions:
# 43. (A_{1}, A_{2}, ..., A_{l})
#     core type: ExprTuple
#     sub-expressions: 45
# 44. b_{1} *  b_{2} *  ... *  b_{j}
#     core type: Operation
#     operator: 46
#     operands: 47
# 45. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 53
#     end_index: 49
# 46. *
#     core type: Literal
#     sub-expressions:
# 47. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 50
# 48. _a -> A_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 51
# 49. l
#     core type: Variable
#     sub-expressions:
# 50. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 53
#     end_index: 54
# 51. A_{_a}
#     core type: IndexedVar
# variable: 55
# index: 59
# 52. _a -> b_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 56
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. j
#     core type: Variable
#     sub-expressions:
# 55. A
#     core type: Variable
#     sub-expressions:
# 56. b_{_a}
#     core type: IndexedVar
# variable: 57
# index: 59
# 57. b
#     core type: Variable
#     sub-expressions:
# 58. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 59. _a
#     core type: Variable
#     sub-expressions:
