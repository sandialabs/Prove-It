# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, v_i
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import And, Equals, Exists
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Interval(one, n)
sub_expr3 = Qmult(Ket(v_i), Bra(v_i))
expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr3), domain = sub_expr2)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr3), domain = sub_expr2))).with_wrapping_at(2), domain = Complex).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array}\right)\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. exists
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#    core type: Conditional
#    value: 8
#    condition: 9
# 6. a_{1}, a_{2}, ..., a_{n}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 64
#    end_index: 65
# 7. b_{1}, b_{2}, ..., b_{n}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 64
#    end_index: 65
# 8. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. _a -> a_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 37
# 11. _a -> b_{_a}
#     core type: Lambda
#     parameter: 46
#     body: 38
# 12. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 20
#     operands: 19
# 16. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 64
#     end_index: 65
# 18. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 64
#     end_index: 65
# 19. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 22. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 46
#     body: 28
# 23. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 46
#     body: 29
# 24. A
#     core type: Variable
#     sub-expressions:
# 25. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 31
#     operand: 35
# 26. B
#     core type: Variable
#     sub-expressions:
# 27. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 31
#     operand: 36
# 28. a_{_a} in Complex
#     core type: Operation
#     operator: 50
#     operands: 33
# 29. b_{_a} in Complex
#     core type: Operation
#     operator: 50
#     operands: 34
# 30. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 35
# 31. Sum
#     core type: Literal
#     sub-expressions:
# 32. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 36
# 33. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 37, 39
# 34. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 72
#     body: 40
# 36. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 72
#     body: 41
# 37. a_{_a}
#     core type: IndexedVar
# variable: 56
# index: 46
# 38. b_{_a}
#     core type: IndexedVar
# variable: 57
# index: 46
# 39. Complex
#     core type: Literal
#     sub-expressions:
# 40. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 43
#     condition: 45
# 41. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 44
#     condition: 45
# 42. (_a)
#     core type: ExprTuple
#     sub-expressions: 46
# 43. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 48
#     operands: 47
# 44. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. i in {1 .. n}
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. _a
#     core type: Variable
#     sub-expressions:
# 47. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 52, 54
# 48. *
#     core type: Literal
#     sub-expressions:
# 49. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 72, 55
# 52. a_{i}
#     core type: IndexedVar
# variable: 56
# index: 72
# 53. b_{i}
#     core type: IndexedVar
# variable: 57
# index: 72
# 54. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 58
#     operands: 59
# 55. {1 .. n}
#     core type: Operation
#     operator: 60
#     operands: 61
# 56. a
#     core type: Variable
#     sub-expressions:
# 57. b
#     core type: Variable
#     sub-expressions:
# 58. .
#     core type: Literal
#     sub-expressions:
# 59. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 60. Interval
#     core type: Literal
#     sub-expressions:
# 61. (1, n)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 62. |v_{i}〉
#     core type: Operation
#     operator: 66
#     operand: 69
# 63. 〈v_{i}|
#     core type: Operation
#     operator: 67
#     operand: 69
# 64. 1
#     core type: Literal
#     sub-expressions:
# 65. n
#     core type: Variable
#     sub-expressions:
# 66. KET
#     core type: Literal
#     sub-expressions:
# 67. BRA
#     core type: Literal
#     sub-expressions:
# 68. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 69
# 69. v_{i}
#     core type: IndexedVar
# variable: 70
# index: 72
# 70. v
#     core type: Variable
#     sub-expressions:
# 71. (i)
#     core type: ExprTuple
#     sub-expressions: 72
# 72. i
#     core type: Variable
#     sub-expressions:
