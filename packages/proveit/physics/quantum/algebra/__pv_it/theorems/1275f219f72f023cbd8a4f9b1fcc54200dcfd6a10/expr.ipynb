# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, i, lambda_, m, n
from proveit.core_expr_types import a_i, b_1_to_n, b_i, lambda_i
from proveit.linear_algebra import OrthoNormBases, ScalarMult, VecSum
from proveit.logic import CartExp, Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, Min, RealNonNeg, one
from proveit.physics.quantum import Ket, Qmult, var_ket_psi
from proveit.physics.quantum.algebra import a_1_to_m_kets, b_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = Min(m, n)
expr = Conditional(Exists(instance_param_or_params = [b_1_to_n], instance_expr = Exists(instance_param_or_params = [ExprRange(sub_expr1, IndexedVar(lambda_, sub_expr1), one, sub_expr2)], instance_expr = Equals(var_ket_psi, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, Qmult(Ket(a_i), Ket(b_i))), domain = Interval(one, sub_expr2))), domain = RealNonNeg).with_wrapping(), condition = InSet(Set(b_1_to_n_kets), OrthoNormBases(CartExp(Complex, n)))).with_wrapping(), InSet(Set(a_1_to_m_kets), OrthoNormBases(CartExp(Complex, m))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\exists_{b_{1}, b_{2}, \ldots, b_{n}~|~\left\{\left\{\lvert b_{1} \rangle, \lvert b_{2} \rangle, \ldots, \lvert b_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left[\begin{array}{l}\exists_{\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}}~\\
# \left(\lvert \psi \rangle = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(\lvert a_{i} \rangle \thinspace \lvert b_{i} \rangle\right)\right)\right)\right)\end{array}\right]\end{array} \textrm{ if } \left\{\left\{\lvert a_{1} \rangle, \lvert a_{2} \rangle, \ldots, \lvert a_{m} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{m}\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))] if {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. exists_{b_{1}, b_{2}, ..., b_{n} | {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))]
#    core type: Operation
#    operator: 18
#    operand: 5
# 2. {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}} in O.N.Bases(Complex^{m})
#    core type: Operation
#    operator: 72
#    operands: 4
# 3. ((b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. ({{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}}, O.N.Bases(Complex^{m}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (b_{1}, b_{2}, ..., b_{n}) -> {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 8\n   body: 9
# 6. {{|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}}
#    core type: Operation
#    operator: 44
#    operand: 15
# 7. O.N.Bases(Complex^{m})
#    core type: Operation
#    operator: 30
#    operand: 16
# 8. (b_{1}, b_{2}, ..., b_{n})
#    core type: ExprTuple
#    sub-expressions: 12
# 9. {exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))) if {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. ({|a_{1}〉, |a_{2}〉, ..., |a_{m}〉})
#     core type: ExprTuple
#     sub-expressions: 15
# 11. (Complex^{m})
#     core type: ExprTuple
#     sub-expressions: 16
# 12. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 86
#     end_index: 96
# 13. exists_{lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)} in RealNonNeg} (|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))))
#     core type: Operation
#     operator: 18
#     operand: 23
# 14. {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 72
#     operands: 20
# 15. {|a_{1}〉, |a_{2}〉, ..., |a_{m}〉}
#     core type: Operation
#     operator: 44
#     operands: 21
# 16. Complex^{m}
#     core type: Operation
#     operator: 46
#     operands: 22
# 17. _a -> b_{_a}
#     core type: Lambda
#     parameter: 78
#     body: 69
# 18. exists
#     core type: Literal
#     sub-expressions:
# 19. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#     core type: ExprTuple
#     sub-expressions: 23
# 20. ({{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 21. (|a_{1}〉, |a_{2}〉, ..., |a_{m}〉)
#     core type: ExprTuple
#     sub-expressions: 26
# 22. (Complex, m)
#     core type: ExprTuple
#     sub-expressions: 53, 95
# 23. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Lambda
#     parameters: 27\n    body: 28
# 24. {{|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}}
#     core type: Operation
#     operator: 44
#     operand: 36
# 25. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 30
#     operand: 37
# 26. |a_{1}〉, |a_{2}〉, ..., |a_{m}〉
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 86
#     end_index: 95
# 27. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 33
# 28. {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#     core type: Conditional
#     value: 34
#     condition: 35
# 29. ({|b_{1}〉, |b_{2}〉, ..., |b_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 36
# 30. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 31. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 37
# 32. _a -> |a_{_a}〉
#     core type: Lambda
#     parameter: 78
#     body: 38
# 33. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#     core type: ExprRange
#     lambda_map: 39
#     start_index: 86
#     end_index: 87
# 34. |psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#     core type: Operation
#     operator: 40
#     operands: 41
# 35. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#     core type: Operation
#     operator: 42
#     operands: 43
# 36. {|b_{1}〉, |b_{2}〉, ..., |b_{n}〉}
#     core type: Operation
#     operator: 44
#     operands: 45
# 37. Complex^{n}
#     core type: Operation
#     operator: 46
#     operands: 47
# 38. |a_{_a}〉
#     core type: Operation
#     operator: 89
#     operand: 54
# 39. _a -> lambda_{_a}
#     core type: Lambda
#     parameter: 78
#     body: 67
# 40. =
#     core type: Literal
#     sub-expressions:
# 41. (|psi>, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 42. and
#     core type: Literal
#     sub-expressions:
# 43. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 51
# 44. Set
#     core type: Literal
#     sub-expressions:
# 45. (|b_{1}〉, |b_{2}〉, ..., |b_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 52
# 46. CartExp
#     core type: Literal
#     sub-expressions:
# 47. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 53, 96
# 48. (a_{_a})
#     core type: ExprTuple
#     sub-expressions: 54
# 49. |psi>
#     core type: Variable
#     sub-expressions:
# 50. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))
#     core type: Operation
#     operator: 55
#     operand: 59
# 51. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 86
#     end_index: 87
# 52. |b_{1}〉, |b_{2}〉, ..., |b_{n}〉
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 86
#     end_index: 96
# 53. Complex
#     core type: Literal
#     sub-expressions:
# 54. a_{_a}
#     core type: IndexedVar
# variable: 97
# index: 78
# 55. Sum
#     core type: Literal
#     sub-expressions:
# 56. (i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 59
# 57. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 78
#     body: 60
# 58. _a -> |b_{_a}〉
#     core type: Lambda
#     parameter: 78
#     body: 61
# 59. i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 100
#     body: 62
# 60. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 72
#     operands: 63
# 61. |b_{_a}〉
#     core type: Operation
#     operator: 89
#     operand: 69
# 62. {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 65
#     condition: 66
# 63. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 64. (b_{_a})
#     core type: ExprTuple
#     sub-expressions: 69
# 65. lambda_{i} * (|a_{i}〉 . |b_{i}〉)
#     core type: Operation
#     operator: 70
#     operands: 71
# 66. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 72
#     operands: 73
# 67. lambda_{_a}
#     core type: IndexedVar
# variable: 79
# index: 78
# 68. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 69. b_{_a}
#     core type: IndexedVar
# variable: 98
# index: 78
# 70. *
#     core type: Literal
#     sub-expressions:
# 71. (lambda_{i}, |a_{i}〉 . |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 72. in
#     core type: Literal
#     sub-expressions:
# 73. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 100, 77
# 74. (_a)
#     core type: ExprTuple
#     sub-expressions: 78
# 75. lambda_{i}
#     core type: IndexedVar
# variable: 79
# index: 100
# 76. |a_{i}〉 . |b_{i}〉
#     core type: Operation
#     operator: 80
#     operands: 81
# 77. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 82
#     operands: 83
# 78. _a
#     core type: Variable
#     sub-expressions:
# 79. lambda
#     core type: Variable
#     sub-expressions:
# 80. .
#     core type: Literal
#     sub-expressions:
# 81. (|a_{i}〉, |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 82. Interval
#     core type: Literal
#     sub-expressions:
# 83. (1, Min(m, n))
#     core type: ExprTuple
#     sub-expressions: 86, 87
# 84. |a_{i}〉
#     core type: Operation
#     operator: 89
#     operand: 93
# 85. |b_{i}〉
#     core type: Operation
#     operator: 89
#     operand: 94
# 86. 1
#     core type: Literal
#     sub-expressions:
# 87. Min(m, n)
#     core type: Operation
#     operator: 91
#     operands: 92
# 88. (a_{i})
#     core type: ExprTuple
#     sub-expressions: 93
# 89. KET
#     core type: Literal
#     sub-expressions:
# 90. (b_{i})
#     core type: ExprTuple
#     sub-expressions: 94
# 91. Min
#     core type: Literal
#     sub-expressions:
# 92. (m, n)
#     core type: ExprTuple
#     sub-expressions: 95, 96
# 93. a_{i}
#     core type: IndexedVar
# variable: 97
# index: 100
# 94. b_{i}
#     core type: IndexedVar
# variable: 98
# index: 100
# 95. m
#     core type: Variable
#     sub-expressions:
# 96. n
#     core type: Variable
#     sub-expressions:
# 97. a
#     core type: Variable
#     sub-expressions:
# 98. b
#     core type: Variable
#     sub-expressions:
# 99. (i)
#     core type: ExprTuple
#     sub-expressions: 100
# 100. i
#      core type: Variable
#      sub-expressions:
