# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, v_1_to_n, v_i
from proveit.linear_algebra import Adj, Dim, HilbertSpaces, Hspace, LinMap, OrthoNormBases, ScalarMult, VecSum
from proveit.logic import And, Equals, Exists, Forall, Iff, InClass, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = Conditional(Forall(instance_param_or_params = [M], instance_expr = Iff(Equals(Qmult(sub_expr1, M), Qmult(M, sub_expr1)), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, Qmult(Ket(v_i), Bra(v_i))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n_kets), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), domain = LinMap(Hspace, Hspace)), And(InClass(Hspace, HilbertSpaces), Equals(Dim(Hspace), n)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{M \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \thinspace M\right) = \left(M \thinspace M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right) \textrm{ if } \mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces} ,  \textrm{Dim}\left(\mathcal{H}\right) = n\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]])
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (H in_c HilbertSpaces) and (Dim(H) = n)
#    core type: Operation
#    operator: 61
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (M -> {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in LINMAP(H, H).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (H in_c HilbertSpaces, Dim(H) = n)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. M -> {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in LINMAP(H, H).
#    core type: Lambda
#    parameter: 65
#    body: 9
# 7. H in_c HilbertSpaces
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. Dim(H) = n
#    core type: Operation
#    operator: 59
#    operands: 12
# 9. {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in LINMAP(H, H).
#    core type: Conditional
#    value: 13
#    condition: 14
# 10. in_c
#     core type: Literal
#     sub-expressions:
# 11. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 57, 15
# 12. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 16, 101
# 13. ((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. M in LINMAP(H, H)
#     core type: Operation
#     operator: 86
#     operands: 19
# 15. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 16. Dim(H)
#     core type: Operation
#     operator: 20
#     operand: 57
# 17. <=>
#     core type: Literal
#     sub-expressions:
# 18. ((M* . M) = (M . M*), exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))])
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. (M, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 65, 23
# 20. Dim
#     core type: Literal
#     sub-expressions:
# 21. (M* . M) = (M . M*)
#     core type: Operation
#     operator: 59
#     operands: 24
# 22. exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]
#     core type: Operation
#     operator: 42
#     operand: 30
# 23. LINMAP(H, H)
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. (M* . M, M . M*)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 30
# 26. LINMAP
#     core type: Literal
#     sub-expressions:
# 27. (H, H)
#     core type: ExprTuple
#     sub-expressions: 57, 57
# 28. M* . M
#     core type: Operation
#     operator: 94
#     operands: 31
# 29. M . M*
#     core type: Operation
#     operator: 94
#     operands: 32
# 30. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 33\n    body: 34
# 31. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 35, 65
# 32. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 65, 35
# 33. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 36
# 34. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#     core type: Conditional
#     value: 37
#     condition: 38
# 35. M*
#     core type: Operation
#     operator: 39
#     operand: 65
# 36. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 100
#     end_index: 101
# 37. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 42
#     operand: 45
# 38. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)
#     core type: Operation
#     operator: 86
#     operands: 44
# 39. Adj
#     core type: Literal
#     sub-expressions:
# 40. (M)
#     core type: ExprTuple
#     sub-expressions: 65
# 41. _a -> v_{_a}
#     core type: Lambda
#     parameter: 92
#     body: 83
# 42. exists
#     core type: Literal
#     sub-expressions:
# 43. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 45
# 44. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 45. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 48\n    body: 49
# 46. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 63
#     operand: 56
# 47. O.N.Bases(H)
#     core type: Operation
#     operator: 51
#     operand: 57
# 48. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 53
# 49. {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 54
#     condition: 55
# 50. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 56
# 51. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 52. (H)
#     core type: ExprTuple
#     sub-expressions: 57
# 53. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 100
#     end_index: 101
# 54. M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 59
#     operands: 60
# 55. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 61
#     operands: 62
# 56. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 63
#     operands: 64
# 57. H
#     core type: Variable
#     sub-expressions:
# 58. _a -> a_{_a}
#     core type: Lambda
#     parameter: 92
#     body: 81
# 59. =
#     core type: Literal
#     sub-expressions:
# 60. (M, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 61. and
#     core type: Literal
#     sub-expressions:
# 62. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 67
# 63. Set
#     core type: Literal
#     sub-expressions:
# 64. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 68
# 65. M
#     core type: Variable
#     sub-expressions:
# 66. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 69
#     operand: 73
# 67. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 71
#     start_index: 100
#     end_index: 101
# 68. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 72
#     start_index: 100
#     end_index: 101
# 69. Sum
#     core type: Literal
#     sub-expressions:
# 70. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 73
# 71. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 92
#     body: 74
# 72. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 92
#     body: 75
# 73. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 108
#     body: 76
# 74. a_{_a} in Complex
#     core type: Operation
#     operator: 86
#     operands: 77
# 75. |v_{_a}〉
#     core type: Operation
#     operator: 102
#     operand: 83
# 76. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 79
#     condition: 80
# 77. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 81, 82
# 78. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 83
# 79. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 84
#     operands: 85
# 80. i in {1 .. n}
#     core type: Operation
#     operator: 86
#     operands: 87
# 81. a_{_a}
#     core type: IndexedVar
# variable: 93
# index: 92
# 82. Complex
#     core type: Literal
#     sub-expressions:
# 83. v_{_a}
#     core type: IndexedVar
# variable: 106
# index: 92
# 84. *
#     core type: Literal
#     sub-expressions:
# 85. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 89, 90
# 86. in
#     core type: Literal
#     sub-expressions:
# 87. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 108, 91
# 88. (_a)
#     core type: ExprTuple
#     sub-expressions: 92
# 89. a_{i}
#     core type: IndexedVar
# variable: 93
# index: 108
# 90. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 94
#     operands: 95
# 91. {1 .. n}
#     core type: Operation
#     operator: 96
#     operands: 97
# 92. _a
#     core type: Variable
#     sub-expressions:
# 93. a
#     core type: Variable
#     sub-expressions:
# 94. .
#     core type: Literal
#     sub-expressions:
# 95. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 98, 99
# 96. Interval
#     core type: Literal
#     sub-expressions:
# 97. (1, n)
#     core type: ExprTuple
#     sub-expressions: 100, 101
# 98. |v_{i}〉
#     core type: Operation
#     operator: 102
#     operand: 105
# 99. 〈v_{i}|
#     core type: Operation
#     operator: 103
#     operand: 105
# 100. 1
#      core type: Literal
#      sub-expressions:
# 101. n
#      core type: Variable
#      sub-expressions:
# 102. KET
#      core type: Literal
#      sub-expressions:
# 103. BRA
#      core type: Literal
#      sub-expressions:
# 104. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 105
# 105. v_{i}
#      core type: IndexedVar
# variable: 106
# index: 108
# 106. v
#      core type: Variable
#      sub-expressions:
# 107. (i)
#      core type: ExprTuple
#      sub-expressions: 108
# 108. i
#      core type: Variable
#      sub-expressions:
