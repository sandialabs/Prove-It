# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, v_1_to_n, v_i
from proveit.linear_algebra import Adj, Commutator, MatrixSpace, OrthoNormBases, ScalarMult, VecSum, VecZero
from proveit.logic import And, CartExp, Equals, Exists, Forall, Iff, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = MatrixSpace(field = Complex, rows = n, columns = n)
sub_expr3 = Interval(one, n)
sub_expr4 = Qmult(Ket(v_i), Bra(v_i))
expr = Lambda(n, Conditional(Forall(instance_param_or_params = [A, B], instance_expr = Iff(Equals(Commutator(A, B), VecZero(sub_expr2)), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr4), domain = sub_expr3))).with_wrapping_at(2), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n), OrthoNormBases(CartExp(Complex, n)))).with_wrapping()).with_wrapping_at(2), domain = sub_expr2, conditions = [Equals(Adj(A), A), Equals(Adj(B), B)]).with_wrapping(), InSet(n, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# n \mapsto \left\{\begin{array}{l}\forall_{A, B \in \mathbb{C}^{n \times n}~|~A^{\dagger} = A, B^{\dagger} = B}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left[A, B\right] = \vec{0}\left(\mathbb{C}^{n \times n}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{v_{1}, v_{2}, \ldots, v_{n}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array}\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right)\end{array} \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. n -> {forall_{A, B in Complex^{n x n} | A* = A, B* = B} (([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 123
#    body: 2
# 1. (n)
#    core type: ExprTuple
#    sub-expressions: 123
# 2. {forall_{A, B in Complex^{n x n} | A* = A, B* = B} (([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A, B in Complex^{n x n} | A* = A, B* = B} (([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]])
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. n in NaturalPos
#    core type: Operation
#    operator: 108
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((A, B) -> {([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in Complex^{n x n} ,  B in Complex^{n x n} ,  A* = A ,  B* = B.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 123, 9
# 8. (A, B) -> {([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in Complex^{n x n} ,  B in Complex^{n x n} ,  A* = A ,  B* = B.
#    core type: Lambda
#    parameters: 34\n   body: 10
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. {([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in Complex^{n x n} ,  B in Complex^{n x n} ,  A* = A ,  B* = B.
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. ([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (A in Complex^{n x n}) and (B in Complex^{n x n}) and (A* = A) and (B* = B)
#     core type: Operation
#     operator: 67
#     operands: 15
# 13. <=>
#     core type: Literal
#     sub-expressions:
# 14. ([A, B] = 0(Complex^{n x n}), exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))])
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. (A in Complex^{n x n}, B in Complex^{n x n}, A* = A, B* = B)
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20, 21
# 16. [A, B] = 0(Complex^{n x n})
#     core type: Operation
#     operator: 78
#     operands: 22
# 17. exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]
#     core type: Operation
#     operator: 46
#     operand: 30
# 18. A in Complex^{n x n}
#     core type: Operation
#     operator: 108
#     operands: 24
# 19. B in Complex^{n x n}
#     core type: Operation
#     operator: 108
#     operands: 25
# 20. A* = A
#     core type: Operation
#     operator: 78
#     operands: 26
# 21. B* = B
#     core type: Operation
#     operator: 78
#     operands: 27
# 22. ([A, B], 0(Complex^{n x n}))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 23. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).)
#     core type: ExprTuple
#     sub-expressions: 30
# 24. (A, Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 82, 41
# 25. (B, Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 84, 41
# 26. (A*, A)
#     core type: ExprTuple
#     sub-expressions: 31, 82
# 27. (B*, B)
#     core type: ExprTuple
#     sub-expressions: 32, 84
# 28. [A, B]
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. 0(Complex^{n x n})
#     core type: Operation
#     operator: 35
#     operand: 41
# 30. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).
#     core type: Lambda
#     parameters: 55\n    body: 37
# 31. A*
#     core type: Operation
#     operator: 39
#     operand: 82
# 32. B*
#     core type: Operation
#     operator: 39
#     operand: 84
# 33. commutator
#     core type: Literal
#     sub-expressions:
# 34. (A, B)
#     core type: ExprTuple
#     sub-expressions: 82, 84
# 35. 0
#     core type: Literal
#     sub-expressions:
# 36. (Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 41
# 37. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 42
#     condition: 43
# 38. (A)
#     core type: ExprTuple
#     sub-expressions: 82
# 39. Adj
#     core type: Literal
#     sub-expressions:
# 40. (B)
#     core type: ExprTuple
#     sub-expressions: 84
# 41. Complex^{n x n}
#     core type: Operation
#     operator: 44
#     operands: 45
# 42. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))
#     core type: Operation
#     operator: 46
#     operand: 49
# 43. {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 108
#     operands: 48
# 44. MSpace
#     core type: Literal
#     sub-expressions:
# 45. {field:Complex, rows:n, columns:n}
#     core type: NamedExprs
#     field: 97
#     rows: 123
#     columns: 123
# 46. exists
#     core type: Literal
#     sub-expressions:
# 47. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 49
# 48. ({v_{1}, v_{2}, ..., v_{n}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 49. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Lambda
#     parameters: 52\n    body: 53
# 50. {v_{1}, v_{2}, ..., v_{n}}
#     core type: Operation
#     operator: 54
#     operands: 55
# 51. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 56
#     operand: 63
# 52. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 53. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 60
#     condition: 61
# 54. Set
#     core type: Literal
#     sub-expressions:
# 55. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 62
# 56. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 57. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 63
# 58. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 64
#     start_index: 122
#     end_index: 123
# 59. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 65
#     start_index: 122
#     end_index: 123
# 60. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 67
#     operands: 66
# 61. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 67
#     operands: 68
# 62. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 122
#     end_index: 123
# 63. Complex^{n}
#     core type: Operation
#     operator: 70
#     operands: 71
# 64. _a -> a_{_a}
#     core type: Lambda
#     parameter: 104
#     body: 95
# 65. _a -> b_{_a}
#     core type: Lambda
#     parameter: 104
#     body: 96
# 66. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 67. and
#     core type: Literal
#     sub-expressions:
# 68. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 74, 75
# 69. _a -> v_{_a}
#     core type: Lambda
#     parameter: 104
#     body: 76
# 70. CartExp
#     core type: Literal
#     sub-expressions:
# 71. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 97, 123
# 72. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 78
#     operands: 77
# 73. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 78
#     operands: 79
# 74. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 80
#     start_index: 122
#     end_index: 123
# 75. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 81
#     start_index: 122
#     end_index: 123
# 76. v_{_a}
#     core type: IndexedVar
# variable: 128
# index: 104
# 77. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 78. =
#     core type: Literal
#     sub-expressions:
# 79. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 80. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 104
#     body: 86
# 81. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 104
#     body: 87
# 82. A
#     core type: Variable
#     sub-expressions:
# 83. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 89
#     operand: 93
# 84. B
#     core type: Variable
#     sub-expressions:
# 85. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 89
#     operand: 94
# 86. a_{_a} in Complex
#     core type: Operation
#     operator: 108
#     operands: 91
# 87. b_{_a} in Complex
#     core type: Operation
#     operator: 108
#     operands: 92
# 88. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 93
# 89. Sum
#     core type: Literal
#     sub-expressions:
# 90. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 94
# 91. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 95, 97
# 92. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 96, 97
# 93. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 130
#     body: 98
# 94. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 130
#     body: 99
# 95. a_{_a}
#     core type: IndexedVar
# variable: 114
# index: 104
# 96. b_{_a}
#     core type: IndexedVar
# variable: 115
# index: 104
# 97. Complex
#     core type: Literal
#     sub-expressions:
# 98. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 101
#     condition: 103
# 99. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 102
#     condition: 103
# 100. (_a)
#      core type: ExprTuple
#      sub-expressions: 104
# 101. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#      core type: Operation
#      operator: 106
#      operands: 105
# 102. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#      core type: Operation
#      operator: 106
#      operands: 107
# 103. i in {1 .. n}
#      core type: Operation
#      operator: 108
#      operands: 109
# 104. _a
#      core type: Variable
#      sub-expressions:
# 105. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 110, 112
# 106. *
#      core type: Literal
#      sub-expressions:
# 107. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 111, 112
# 108. in
#      core type: Literal
#      sub-expressions:
# 109. (i, {1 .. n})
#      core type: ExprTuple
#      sub-expressions: 130, 113
# 110. a_{i}
#      core type: IndexedVar
# variable: 114
# index: 130
# 111. b_{i}
#      core type: IndexedVar
# variable: 115
# index: 130
# 112. |v_{i}〉 . 〈v_{i}|
#      core type: Operation
#      operator: 116
#      operands: 117
# 113. {1 .. n}
#      core type: Operation
#      operator: 118
#      operands: 119
# 114. a
#      core type: Variable
#      sub-expressions:
# 115. b
#      core type: Variable
#      sub-expressions:
# 116. .
#      core type: Literal
#      sub-expressions:
# 117. (|v_{i}〉, 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 120, 121
# 118. Interval
#      core type: Literal
#      sub-expressions:
# 119. (1, n)
#      core type: ExprTuple
#      sub-expressions: 122, 123
# 120. |v_{i}〉
#      core type: Operation
#      operator: 124
#      operand: 127
# 121. 〈v_{i}|
#      core type: Operation
#      operator: 125
#      operand: 127
# 122. 1
#      core type: Literal
#      sub-expressions:
# 123. n
#      core type: Variable
#      sub-expressions:
# 124. KET
#      core type: Literal
#      sub-expressions:
# 125. BRA
#      core type: Literal
#      sub-expressions:
# 126. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 127
# 127. v_{i}
#      core type: IndexedVar
# variable: 128
# index: 130
# 128. v
#      core type: Variable
#      sub-expressions:
# 129. (i)
#      core type: ExprTuple
#      sub-expressions: 130
# 130. i
#      core type: Variable
#      sub-expressions:
