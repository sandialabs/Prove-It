# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import U, i, n
from proveit.core_expr_types import v_1_to_n, v_i, w_1_to_n, w_i
from proveit.linear_algebra import OrthoNormBases, VecSum
from proveit.logic import CartExp, Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = OrthoNormBases(CartExp(Complex, n))
expr = Exists(instance_param_or_params = [v_1_to_n, w_1_to_n], instance_expr = Equals(U, VecSum(index_or_indices = [i], summand = Qmult(Ket(v_i), Bra(w_i)), domain = Interval(one, n))), conditions = [InSet(Set(v_1_to_n_kets), sub_expr1), InSet(Set(w_1_to_n_kets), sub_expr1)]).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}, w_{1}, w_{2}, \ldots, w_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right), \left\{\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left(U = \left(\sum_{i=1}^{n} \left(\lvert v_{i} \rangle \thinspace \langle w_{i} \rvert\right)\right)\right)\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. exists
#    core type: Literal
#    sub-expressions:
# 2. ((v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (v_{1}, v_{2}, ..., v_{n},w_{1}, w_{2}, ..., w_{n})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Conditional
#    value: 8
#    condition: 9
# 6. v_{1}, v_{2}, ..., v_{n}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 62
#    end_index: 63
# 7. w_{1}, w_{2}, ..., w_{n}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 62
#    end_index: 63
# 8. U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})) and ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. _a -> v_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 71
# 11. _a -> w_{_a}
#     core type: Lambda
#     parameter: 76
#     body: 72
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (U, Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. U
#     core type: Variable
#     sub-expressions:
# 17. Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)
#     core type: Operation
#     operator: 20
#     operand: 24
# 18. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 40
#     operands: 22
# 19. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 40
#     operands: 23
# 20. Sum
#     core type: Literal
#     sub-expressions:
# 21. (i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 25, 27
# 23. ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 70
#     body: 28
# 25. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 43
#     operand: 35
# 26. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}
#     core type: Operation
#     operator: 43
#     operand: 36
# 27. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 31
#     operand: 37
# 28. {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 33
#     condition: 34
# 29. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 35
# 30. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 36
# 31. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 32. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 37
# 33. |v_{i}〉 . 〈w_{i}|
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. i in {1 .. n}
#     core type: Operation
#     operator: 40
#     operands: 41
# 35. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 43
#     operands: 42
# 36. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 43
#     operands: 44
# 37. Complex^{n}
#     core type: Operation
#     operator: 45
#     operands: 46
# 38. .
#     core type: Literal
#     sub-expressions:
# 39. (|v_{i}〉, 〈w_{i}|)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 70, 49
# 42. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 50
# 43. Set
#     core type: Literal
#     sub-expressions:
# 44. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 51
# 45. CartExp
#     core type: Literal
#     sub-expressions:
# 46. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 52, 63
# 47. |v_{i}〉
#     core type: Operation
#     operator: 68
#     operand: 60
# 48. 〈w_{i}|
#     core type: Operation
#     operator: 54
#     operand: 61
# 49. {1 .. n}
#     core type: Operation
#     operator: 56
#     operands: 57
# 50. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 58
#     start_index: 62
#     end_index: 63
# 51. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 62
#     end_index: 63
# 52. Complex
#     core type: Literal
#     sub-expressions:
# 53. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 60
# 54. BRA
#     core type: Literal
#     sub-expressions:
# 55. (w_{i})
#     core type: ExprTuple
#     sub-expressions: 61
# 56. Interval
#     core type: Literal
#     sub-expressions:
# 57. (1, n)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 58. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 76
#     body: 64
# 59. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 76
#     body: 65
# 60. v_{i}
#     core type: IndexedVar
# variable: 73
# index: 70
# 61. w_{i}
#     core type: IndexedVar
# variable: 74
# index: 70
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. n
#     core type: Variable
#     sub-expressions:
# 64. |v_{_a}〉
#     core type: Operation
#     operator: 68
#     operand: 71
# 65. |w_{_a}〉
#     core type: Operation
#     operator: 68
#     operand: 72
# 66. (i)
#     core type: ExprTuple
#     sub-expressions: 70
# 67. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 71
# 68. KET
#     core type: Literal
#     sub-expressions:
# 69. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 72
# 70. i
#     core type: Variable
#     sub-expressions:
# 71. v_{_a}
#     core type: IndexedVar
# variable: 73
# index: 76
# 72. w_{_a}
#     core type: IndexedVar
# variable: 74
# index: 76
# 73. v
#     core type: Variable
#     sub-expressions:
# 74. w
#     core type: Variable
#     sub-expressions:
# 75. (_a)
#     core type: ExprTuple
#     sub-expressions: 76
# 76. _a
#     core type: Variable
#     sub-expressions:
