# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Function, Lambda, f, i, n
from proveit.core_expr_types import a_1_to_n, a_i, v_1_to_n, v_i
from proveit.linear_algebra import Dim, HilbertSpaces, Hspace, OrthoNormBases, ScalarMult, VecSum
from proveit.logic import Equals, Forall, Functions, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Interval(one, n)
sub_expr3 = Qmult(Ket(v_i), Bra(v_i))
expr = Lambda(n, Conditional(Forall(instance_param_or_params = [Hspace], instance_expr = Forall(instance_param_or_params = [v_1_to_n], instance_expr = Forall(instance_param_or_params = [a_1_to_n], instance_expr = Forall(instance_param_or_params = [f], instance_expr = Equals(Function(f, [VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr3), domain = sub_expr2)]), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(Function(f, [a_i]), sub_expr3), domain = sub_expr2)), domain = Functions(Complex, Complex)), domain = Complex), condition = InSet(Set(v_1_to_n_kets), OrthoNormBases(Hspace))).with_wrapping(), domain = HilbertSpaces, condition = Equals(Dim(Hspace), n)).with_wrapping(), InSet(n, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# n \mapsto \left\{\begin{array}{l}\forall_{\mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(\mathcal{H}\right) = n}~\\
# \left[\begin{array}{l}\forall_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\forall_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\left[\forall_{f \in \left[\mathbb{C} \rightarrow \mathbb{C}\right]}~\left(f\left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right) = \left(\sum_{i=1}^{n} \left(f\left(a_{i}\right) \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\right]\right]\end{array}\right]\end{array} \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. n -> {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))]]] if n in NaturalPos.
#    core type: Lambda
#    parameter: 108
#    body: 2
# 1. (n)
#    core type: ExprTuple
#    sub-expressions: 108
# 2. {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))]]] if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))]]]
#    core type: Operation
#    operator: 45
#    operand: 7
# 4. n in NaturalPos
#    core type: Operation
#    operator: 93
#    operands: 6
# 5. (H -> {forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))]] if H in_c HilbertSpaces ,  Dim(H) = n.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 108, 8
# 7. H -> {forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))]] if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Lambda
#    parameter: 43
#    body: 9
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. {forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))]] if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))]]
#     core type: Operation
#     operator: 45
#     operand: 14
# 11. (H in_c HilbertSpaces) and (Dim(H) = n)
#     core type: Operation
#     operator: 47
#     operands: 13
# 12. ((v_{1}, v_{2}, ..., v_{n}) -> {forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))] if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. (H in_c HilbertSpaces, Dim(H) = n)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. (v_{1}, v_{2}, ..., v_{n}) -> {forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))] if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 17\n    body: 18
# 15. H in_c HilbertSpaces
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. Dim(H) = n
#     core type: Operation
#     operator: 62
#     operands: 21
# 17. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 22
# 18. {forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))] if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#     core type: Conditional
#     value: 23
#     condition: 24
# 19. in_c
#     core type: Literal
#     sub-expressions:
# 20. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 43, 25
# 21. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 26, 108
# 22. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 107
#     end_index: 108
# 23. forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))]
#     core type: Operation
#     operator: 45
#     operand: 31
# 24. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)
#     core type: Operation
#     operator: 93
#     operands: 29
# 25. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 26. Dim(H)
#     core type: Operation
#     operator: 30
#     operand: 43
# 27. _a -> v_{_a}
#     core type: Lambda
#     parameter: 80
#     body: 71
# 28. ((a_{1}, a_{2}, ..., a_{n}) -> {forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 31
# 29. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. Dim
#     core type: Literal
#     sub-expressions:
# 31. (a_{1}, a_{2}, ..., a_{n}) -> {forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 34\n    body: 35
# 32. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 49
#     operand: 42
# 33. O.N.Bases(H)
#     core type: Operation
#     operator: 37
#     operand: 43
# 34. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 39
# 35. {forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 40
#     condition: 41
# 36. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 42
# 37. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 38. (H)
#     core type: ExprTuple
#     sub-expressions: 43
# 39. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 107
#     end_index: 108
# 40. forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 45
#     operand: 51
# 41. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 47
#     operands: 48
# 42. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 49
#     operands: 50
# 43. H
#     core type: Variable
#     sub-expressions:
# 44. _a -> a_{_a}
#     core type: Lambda
#     parameter: 80
#     body: 70
# 45. forall
#     core type: Literal
#     sub-expressions:
# 46. (f -> {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].)
#     core type: ExprTuple
#     sub-expressions: 51
# 47. and
#     core type: Literal
#     sub-expressions:
# 48. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 52
# 49. Set
#     core type: Literal
#     sub-expressions:
# 50. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 53
# 51. f -> {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].
#     core type: Lambda
#     parameter: 95
#     body: 55
# 52. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 56
#     start_index: 107
#     end_index: 108
# 53. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 107
#     end_index: 108
# 54. (f)
#     core type: ExprTuple
#     sub-expressions: 95
# 55. {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].
#     core type: Conditional
#     value: 58
#     condition: 59
# 56. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 80
#     body: 60
# 57. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 80
#     body: 61
# 58. f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 62
#     operands: 63
# 59. f in [Complex -> Complex]
#     core type: Operation
#     operator: 93
#     operands: 64
# 60. a_{_a} in Complex
#     core type: Operation
#     operator: 93
#     operands: 65
# 61. |v_{_a}〉
#     core type: Operation
#     operator: 109
#     operand: 71
# 62. =
#     core type: Literal
#     sub-expressions:
# 63. (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 64. (f, [Complex -> Complex])
#     core type: ExprTuple
#     sub-expressions: 95, 69
# 65. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 70, 79
# 66. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 71
# 67. f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 95
#     operand: 77
# 68. Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 81
#     operand: 78
# 69. [Complex -> Complex]
#     core type: Operation
#     operator: 74
#     operands: 75
# 70. a_{_a}
#     core type: IndexedVar
# variable: 104
# index: 80
# 71. v_{_a}
#     core type: IndexedVar
# variable: 113
# index: 80
# 72. (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 77
# 73. (i -> {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 78
# 74. Functions
#     core type: Literal
#     sub-expressions:
# 75. (Complex, Complex)
#     core type: ExprTuple
#     sub-expressions: 79, 79
# 76. (_a)
#     core type: ExprTuple
#     sub-expressions: 80
# 77. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 81
#     operand: 84
# 78. i -> {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 115
#     body: 83
# 79. Complex
#     core type: Literal
#     sub-expressions:
# 80. _a
#     core type: Variable
#     sub-expressions:
# 81. Sum
#     core type: Literal
#     sub-expressions:
# 82. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 84
# 83. {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 85
#     condition: 89
# 84. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 115
#     body: 86
# 85. f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 91
#     operands: 87
# 86. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 88
#     condition: 89
# 87. (f(a_{i}), |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 90, 97
# 88. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 91
#     operands: 92
# 89. i in {1 .. n}
#     core type: Operation
#     operator: 93
#     operands: 94
# 90. f(a_{i})
#     core type: Operation
#     operator: 95
#     operand: 99
# 91. *
#     core type: Literal
#     sub-expressions:
# 92. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 99, 97
# 93. in
#     core type: Literal
#     sub-expressions:
# 94. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 115, 98
# 95. f
#     core type: Variable
#     sub-expressions:
# 96. (a_{i})
#     core type: ExprTuple
#     sub-expressions: 99
# 97. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 100
#     operands: 101
# 98. {1 .. n}
#     core type: Operation
#     operator: 102
#     operands: 103
# 99. a_{i}
#     core type: IndexedVar
# variable: 104
# index: 115
# 100. .
#      core type: Literal
#      sub-expressions:
# 101. (|v_{i}〉, 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 105, 106
# 102. Interval
#      core type: Literal
#      sub-expressions:
# 103. (1, n)
#      core type: ExprTuple
#      sub-expressions: 107, 108
# 104. a
#      core type: Variable
#      sub-expressions:
# 105. |v_{i}〉
#      core type: Operation
#      operator: 109
#      operand: 112
# 106. 〈v_{i}|
#      core type: Operation
#      operator: 110
#      operand: 112
# 107. 1
#      core type: Literal
#      sub-expressions:
# 108. n
#      core type: Variable
#      sub-expressions:
# 109. KET
#      core type: Literal
#      sub-expressions:
# 110. BRA
#      core type: Literal
#      sub-expressions:
# 111. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 112
# 112. v_{i}
#      core type: IndexedVar
# variable: 113
# index: 115
# 113. v
#      core type: Variable
#      sub-expressions:
# 114. (i)
#      core type: ExprTuple
#      sub-expressions: 115
# 115. i
#      core type: Variable
#      sub-expressions:
