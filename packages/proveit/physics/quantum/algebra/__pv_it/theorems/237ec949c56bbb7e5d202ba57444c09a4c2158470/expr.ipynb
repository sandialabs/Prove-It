# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, U, i, j, n
from proveit.core_expr_types import v_i, v_j
from proveit.linear_algebra import Adj, OrthoNormBases, Unitary
from proveit.logic import CartExp, Equals, Forall, Implies, InSet, Set
from proveit.numbers import Complex, Interval, KroneckerDelta, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Conditional(Implies(Forall(instance_param_or_params = [i, j], instance_expr = Equals(Qmult(Bra(v_i), Adj(U), U, Ket(v_j)), KroneckerDelta(i, j)), domain = Interval(one, n)), InSet(U, Unitary(n))), InSet(Set(v_1_to_n_kets), OrthoNormBases(CartExp(Complex, n))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\left[\forall_{i, j \in \{1~\ldotp \ldotp~n\}}~\left(\left(\langle v_{i} \rvert \thinspace U^{\dagger} \thinspace U \thinspace \lvert v_{j} \rangle\right) = \delta_{i, j}\right)\right] \Rightarrow \left(U \in \textrm{U}\left(n\right)\right) \textrm{ if } \left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. [forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#    core type: Operation
#    operator: 46
#    operands: 5
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j}), U in U(n))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})
#    core type: Operation
#    operator: 10
#    operand: 16
# 7. U in U(n)
#    core type: Operation
#    operator: 46
#    operands: 12
# 8. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#    core type: Operation
#    operator: 23
#    operand: 18
# 9. O.N.Bases(Complex^{n})
#    core type: Operation
#    operator: 14
#    operand: 19
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. ((i, j) -> {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 16
# 12. (U, U(n))
#     core type: ExprTuple
#     sub-expressions: 64, 17
# 13. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 18
# 14. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 15. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 19
# 16. (i, j) -> {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.
#     core type: Lambda
#     parameters: 44\n    body: 20
# 17. U(n)
#     core type: Operation
#     operator: 21
#     operand: 67
# 18. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. Complex^{n}
#     core type: Operation
#     operator: 25
#     operands: 26
# 20. {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.
#     core type: Conditional
#     value: 27
#     condition: 28
# 21. U
#     core type: Literal
#     sub-expressions:
# 22. (n)
#     core type: ExprTuple
#     sub-expressions: 67
# 23. Set
#     core type: Literal
#     sub-expressions:
# 24. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 29
# 25. CartExp
#     core type: Literal
#     sub-expressions:
# 26. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 30, 67
# 27. (〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j}
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. (i in {1 .. n}) and (j in {1 .. n})
#     core type: Operation
#     operator: 33
#     operands: 34
# 29. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 66
#     end_index: 67
# 30. Complex
#     core type: Literal
#     sub-expressions:
# 31. =
#     core type: Literal
#     sub-expressions:
# 32. (〈v_{i}| . U* . U . |v_{j}〉, delta_{i, j})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. and
#     core type: Literal
#     sub-expressions:
# 34. (i in {1 .. n}, j in {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 35. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 68
#     body: 40
# 36. 〈v_{i}| . U* . U . |v_{j}〉
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. delta_{i, j}
#     core type: Operation
#     operator: 43
#     operands: 44
# 38. i in {1 .. n}
#     core type: Operation
#     operator: 46
#     operands: 45
# 39. j in {1 .. n}
#     core type: Operation
#     operator: 46
#     operands: 47
# 40. |v_{_a}〉
#     core type: Operation
#     operator: 58
#     operand: 53
# 41. .
#     core type: Literal
#     sub-expressions:
# 42. (〈v_{i}|, U*, U, |v_{j}〉)
#     core type: ExprTuple
#     sub-expressions: 49, 50, 64, 51
# 43. Kdelta
#     core type: Literal
#     sub-expressions:
# 44. (i, j)
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 45. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 72, 52
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 73, 52
# 48. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 53
# 49. 〈v_{i}|
#     core type: Operation
#     operator: 54
#     operand: 63
# 50. U*
#     core type: Operation
#     operator: 56
#     operand: 64
# 51. |v_{j}〉
#     core type: Operation
#     operator: 58
#     operand: 65
# 52. {1 .. n}
#     core type: Operation
#     operator: 60
#     operands: 61
# 53. v_{_a}
#     core type: IndexedVar
# variable: 70
# index: 68
# 54. BRA
#     core type: Literal
#     sub-expressions:
# 55. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 63
# 56. Adj
#     core type: Literal
#     sub-expressions:
# 57. (U)
#     core type: ExprTuple
#     sub-expressions: 64
# 58. KET
#     core type: Literal
#     sub-expressions:
# 59. (v_{j})
#     core type: ExprTuple
#     sub-expressions: 65
# 60. Interval
#     core type: Literal
#     sub-expressions:
# 61. (1, n)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 62. (_a)
#     core type: ExprTuple
#     sub-expressions: 68
# 63. v_{i}
#     core type: IndexedVar
# variable: 70
# index: 72
# 64. U
#     core type: Variable
#     sub-expressions:
# 65. v_{j}
#     core type: IndexedVar
# variable: 70
# index: 73
# 66. 1
#     core type: Literal
#     sub-expressions:
# 67. n
#     core type: Variable
#     sub-expressions:
# 68. _a
#     core type: Variable
#     sub-expressions:
# 69. (i)
#     core type: ExprTuple
#     sub-expressions: 72
# 70. v
#     core type: Variable
#     sub-expressions:
# 71. (j)
#     core type: ExprTuple
#     sub-expressions: 73
# 72. i
#     core type: Variable
#     sub-expressions:
# 73. j
#     core type: Variable
#     sub-expressions:
