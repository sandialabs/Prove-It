# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Function, Lambda, f, i, n
from proveit.core_expr_types import a_1_to_n, a_i, v_1_to_n, v_i
from proveit.linear_algebra import Hspace, OrthoNormBases, ScalarMult, VecSum
from proveit.logic import Equals, Forall, Functions, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Interval(one, n)
sub_expr3 = Qmult(Ket(v_i), Bra(v_i))
expr = ExprTuple(Lambda([v_1_to_n], Conditional(Forall(instance_param_or_params = [a_1_to_n], instance_expr = Forall(instance_param_or_params = [f], instance_expr = Equals(Function(f, [VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr3), domain = sub_expr2)]), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(Function(f, [a_i]), sub_expr3), domain = sub_expr2)), domain = Functions(Complex, Complex)), domain = Complex), InSet(Set(v_1_to_n_kets), OrthoNormBases(Hspace)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(v_{1}, v_{2}, \ldots, v_{n}\right) \mapsto \left\{\forall_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\left[\forall_{f \in \left[\mathbb{C} \rightarrow \mathbb{C}\right]}~\left(f\left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right) = \left(\sum_{i=1}^{n} \left(f\left(a_{i}\right) \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\right] \textrm{ if } \left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((v_{1}, v_{2}, ..., v_{n}) -> {forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))] if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (v_{1}, v_{2}, ..., v_{n}) -> {forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))] if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (v_{1}, v_{2}, ..., v_{n})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. {forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))] if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#    core type: Conditional
#    value: 5
#    condition: 6
# 4. v_{1}, v_{2}, ..., v_{n}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 86
#    end_index: 87
# 5. forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))]
#    core type: Operation
#    operator: 24
#    operand: 10
# 6. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)
#    core type: Operation
#    operator: 72
#    operands: 9
# 7. _a -> v_{_a}
#    core type: Lambda
#    parameter: 59
#    body: 50
# 8. ((a_{1}, a_{2}, ..., a_{n}) -> {forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(H))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (a_{1}, a_{2}, ..., a_{n}) -> {forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 13\n    body: 14
# 11. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 28
#     operand: 21
# 12. O.N.Bases(H)
#     core type: Operation
#     operator: 16
#     operand: 22
# 13. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 18
# 14. {forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 19
#     condition: 20
# 15. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 21
# 16. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 17. (H)
#     core type: ExprTuple
#     sub-expressions: 22
# 18. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 86
#     end_index: 87
# 19. forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 24
#     operand: 30
# 20. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 28
#     operands: 29
# 22. H
#     core type: Variable
#     sub-expressions:
# 23. _a -> a_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 49
# 24. forall
#     core type: Literal
#     sub-expressions:
# 25. (f -> {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].)
#     core type: ExprTuple
#     sub-expressions: 30
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 31
# 28. Set
#     core type: Literal
#     sub-expressions:
# 29. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 32
# 30. f -> {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].
#     core type: Lambda
#     parameter: 74
#     body: 34
# 31. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 86
#     end_index: 87
# 32. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 86
#     end_index: 87
# 33. (f)
#     core type: ExprTuple
#     sub-expressions: 74
# 34. {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].
#     core type: Conditional
#     value: 37
#     condition: 38
# 35. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 59
#     body: 39
# 36. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 59
#     body: 40
# 37. f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. f in [Complex -> Complex]
#     core type: Operation
#     operator: 72
#     operands: 43
# 39. a_{_a} in Complex
#     core type: Operation
#     operator: 72
#     operands: 44
# 40. |v_{_a}〉
#     core type: Operation
#     operator: 88
#     operand: 50
# 41. =
#     core type: Literal
#     sub-expressions:
# 42. (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. (f, [Complex -> Complex])
#     core type: ExprTuple
#     sub-expressions: 74, 48
# 44. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 49, 58
# 45. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 50
# 46. f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 74
#     operand: 56
# 47. Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 60
#     operand: 57
# 48. [Complex -> Complex]
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. a_{_a}
#     core type: IndexedVar
# variable: 83
# index: 59
# 50. v_{_a}
#     core type: IndexedVar
# variable: 92
# index: 59
# 51. (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 56
# 52. (i -> {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 57
# 53. Functions
#     core type: Literal
#     sub-expressions:
# 54. (Complex, Complex)
#     core type: ExprTuple
#     sub-expressions: 58, 58
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 56. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 60
#     operand: 63
# 57. i -> {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 94
#     body: 62
# 58. Complex
#     core type: Literal
#     sub-expressions:
# 59. _a
#     core type: Variable
#     sub-expressions:
# 60. Sum
#     core type: Literal
#     sub-expressions:
# 61. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 63
# 62. {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 64
#     condition: 68
# 63. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 94
#     body: 65
# 64. f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 70
#     operands: 66
# 65. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 67
#     condition: 68
# 66. (f(a_{i}), |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 69, 76
# 67. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 70
#     operands: 71
# 68. i in {1 .. n}
#     core type: Operation
#     operator: 72
#     operands: 73
# 69. f(a_{i})
#     core type: Operation
#     operator: 74
#     operand: 78
# 70. *
#     core type: Literal
#     sub-expressions:
# 71. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 78, 76
# 72. in
#     core type: Literal
#     sub-expressions:
# 73. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 94, 77
# 74. f
#     core type: Variable
#     sub-expressions:
# 75. (a_{i})
#     core type: ExprTuple
#     sub-expressions: 78
# 76. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 79
#     operands: 80
# 77. {1 .. n}
#     core type: Operation
#     operator: 81
#     operands: 82
# 78. a_{i}
#     core type: IndexedVar
# variable: 83
# index: 94
# 79. .
#     core type: Literal
#     sub-expressions:
# 80. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 84, 85
# 81. Interval
#     core type: Literal
#     sub-expressions:
# 82. (1, n)
#     core type: ExprTuple
#     sub-expressions: 86, 87
# 83. a
#     core type: Variable
#     sub-expressions:
# 84. |v_{i}〉
#     core type: Operation
#     operator: 88
#     operand: 91
# 85. 〈v_{i}|
#     core type: Operation
#     operator: 89
#     operand: 91
# 86. 1
#     core type: Literal
#     sub-expressions:
# 87. n
#     core type: Variable
#     sub-expressions:
# 88. KET
#     core type: Literal
#     sub-expressions:
# 89. BRA
#     core type: Literal
#     sub-expressions:
# 90. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 91
# 91. v_{i}
#     core type: IndexedVar
# variable: 92
# index: 94
# 92. v
#     core type: Variable
#     sub-expressions:
# 93. (i)
#     core type: ExprTuple
#     sub-expressions: 94
# 94. i
#     core type: Variable
#     sub-expressions:
