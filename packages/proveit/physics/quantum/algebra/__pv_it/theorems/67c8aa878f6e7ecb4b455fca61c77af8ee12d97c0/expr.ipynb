# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, j, l
from proveit.core_expr_types import A_1_to_l, b_1_to_j
from proveit.logic import And, Equals, Forall, InClass, InSet
from proveit.numbers import Complex, Mult, Natural, NaturalPos
from proveit.physics.quantum import Qmult, QmultCodomain

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [b_1_to_j], instance_expr = Forall(instance_param_or_params = [A_1_to_l], instance_expr = Equals(Qmult(b_1_to_j, A_1_to_l), Qmult(Mult(b_1_to_j), A_1_to_l)).with_wrapping_at(2), condition = InClass(Qmult(A_1_to_l), QmultCodomain)), domain = Complex), And(InSet(j, NaturalPos), InSet(l, Natural)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{b_{1}, b_{2}, \ldots, b_{j} \in \mathbb{C}}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{l}~|~\left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\right) \underset{{\scriptscriptstyle c}}{\in} \mathcal{Q^*}}~\left(\begin{array}{c} \begin{array}{l} \left(b_{1} \thinspace  b_{2} \thinspace  \ldots \thinspace  b_{j}\thinspace A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\right) =  \\ \left(\left(b_{1} \cdot  b_{2} \cdot  \ldots \cdot  b_{j}\right)\thinspace A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\right) \end{array} \end{array}\right)\right] \textrm{ if } j \in \mathbb{N}^+ ,  l \in \mathbb{N}\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{b_{1}, b_{2}, ..., b_{j} in Complex} [forall_{A_{1}, A_{2}, ..., A_{l} | (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*} ((b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}))] if j in NaturalPos ,  l in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{b_{1}, b_{2}, ..., b_{j} in Complex} [forall_{A_{1}, A_{2}, ..., A_{l} | (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*} ((b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}))]
#    core type: Operation
#    operator: 15
#    operand: 5
# 2. (j in NaturalPos) and (l in Natural)
#    core type: Operation
#    operator: 17
#    operands: 4
# 3. ((b_{1}, b_{2}, ..., b_{j}) -> {forall_{A_{1}, A_{2}, ..., A_{l} | (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*} ((b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l})) if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (j in NaturalPos, l in Natural)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (b_{1}, b_{2}, ..., b_{j}) -> {forall_{A_{1}, A_{2}, ..., A_{l} | (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*} ((b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l})) if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).
#    core type: Lambda
#    parameters: 44\n   body: 8
# 6. j in NaturalPos
#    core type: Operation
#    operator: 30
#    operands: 9
# 7. l in Natural
#    core type: Operation
#    operator: 30
#    operands: 10
# 8. {forall_{A_{1}, A_{2}, ..., A_{l} | (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*} ((b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l})) if (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex).
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. (j, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 51, 13
# 10. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 46, 14
# 11. forall_{A_{1}, A_{2}, ..., A_{l} | (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*} ((b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}))
#     core type: Operation
#     operator: 15
#     operand: 19
# 12. (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{j} in Complex)
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. NaturalPos
#     core type: Literal
#     sub-expressions:
# 14. Natural
#     core type: Literal
#     sub-expressions:
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. ((A_{1}, A_{2}, ..., A_{l}) -> {(b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}) if (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*.)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. ((b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex))
#     core type: ExprTuple
#     sub-expressions: 20
# 19. (A_{1}, A_{2}, ..., A_{l}) -> {(b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}) if (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*.
#     core type: Lambda
#     parameters: 40\n    body: 21
# 20. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{j} in Complex)
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 50
#     end_index: 51
# 21. {(b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}) if (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*.
#     core type: Conditional
#     value: 23
#     condition: 24
# 22. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 56
#     body: 25
# 23. (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}) =  \\ ((b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l})
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. (A_{1} .  A_{2} .  ... .  A_{l}) in_c Q*
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. b_{_a} in Complex
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. (b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}, (b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 28. in_c
#     core type: Literal
#     sub-expressions:
# 29. (A_{1} .  A_{2} .  ... .  A_{l}, Q*)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 53, 36
# 32. b_{1} .  b_{2} .  ... .  b_{j}. A_{1} .  A_{2} .  ... .  A_{l}
#     core type: Operation
#     operator: 39
#     operands: 37
# 33. (b_{1} *  b_{2} *  ... *  b_{j}). A_{1} .  A_{2} .  ... .  A_{l}
#     core type: Operation
#     operator: 39
#     operands: 38
# 34. A_{1} .  A_{2} .  ... .  A_{l}
#     core type: Operation
#     operator: 39
#     operands: 40
# 35. Q*
#     core type: Literal
#     sub-expressions:
# 36. Complex
#     core type: Literal
#     sub-expressions:
# 37. (b_{1}, b_{2}, ..., b_{j},A_{1}, A_{2}, ..., A_{l})
#     core type: ExprTuple
#     sub-expressions: 47, 42
# 38. (b_{1} *  b_{2} *  ... *  b_{j},A_{1}, A_{2}, ..., A_{l})
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 39. .
#     core type: Literal
#     sub-expressions:
# 40. (A_{1}, A_{2}, ..., A_{l})
#     core type: ExprTuple
#     sub-expressions: 42
# 41. b_{1} *  b_{2} *  ... *  b_{j}
#     core type: Operation
#     operator: 43
#     operands: 44
# 42. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 50
#     end_index: 46
# 43. *
#     core type: Literal
#     sub-expressions:
# 44. (b_{1}, b_{2}, ..., b_{j})
#     core type: ExprTuple
#     sub-expressions: 47
# 45. _a -> A_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 48
# 46. l
#     core type: Variable
#     sub-expressions:
# 47. b_{1}, b_{2}, ..., b_{j}
#     core type: ExprRange
#     lambda_map: 49
#     start_index: 50
#     end_index: 51
# 48. A_{_a}
#     core type: IndexedVar
# variable: 52
# index: 56
# 49. _a -> b_{_a}
#     core type: Lambda
#     parameter: 56
#     body: 53
# 50. 1
#     core type: Literal
#     sub-expressions:
# 51. j
#     core type: Variable
#     sub-expressions:
# 52. A
#     core type: Variable
#     sub-expressions:
# 53. b_{_a}
#     core type: IndexedVar
# variable: 54
# index: 56
# 54. b
#     core type: Variable
#     sub-expressions:
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. _a
#     core type: Variable
#     sub-expressions:
