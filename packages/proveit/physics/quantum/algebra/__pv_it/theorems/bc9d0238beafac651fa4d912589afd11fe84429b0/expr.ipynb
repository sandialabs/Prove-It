# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, n
from proveit.core_expr_types import v_1_to_n, v_i, w_1_to_n, w_i
from proveit.linear_algebra import OrthoNormBases, Unitary, VecSum
from proveit.logic import CartExp, Forall, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = OrthoNormBases(CartExp(Complex, n))
expr = Forall(instance_param_or_params = [v_1_to_n, w_1_to_n], instance_expr = InSet(VecSum(index_or_indices = [i], summand = Qmult(Ket(v_i), Bra(w_i)), domain = Interval(one, n)), Unitary(n)), conditions = [InSet(Set(v_1_to_n_kets), sub_expr1), InSet(Set(w_1_to_n_kets), sub_expr1)]).with_wrapping()
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{l}\forall_{v_{1}, v_{2}, \ldots, v_{n}, w_{1}, w_{2}, \ldots, w_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right), \left\{\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left(\left(\sum_{i=1}^{n} \left(\lvert v_{i} \rangle \thinspace \langle w_{i} \rvert\right)\right) \in \textrm{U}\left(n\right)\right)\end{array}

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: True
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} ((Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {(Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {(Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (v_{1}, v_{2}, ..., v_{n},w_{1}, w_{2}, ..., w_{n})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. {(Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Conditional
#    value: 8
#    condition: 9
# 6. v_{1}, v_{2}, ..., v_{n}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 63
#    end_index: 64
# 7. w_{1}, w_{2}, ..., w_{n}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 63
#    end_index: 64
# 8. (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n)
#    core type: Operation
#    operator: 41
#    operands: 12
# 9. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})) and ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. _a -> v_{_a}
#     core type: Lambda
#     parameter: 77
#     body: 72
# 11. _a -> w_{_a}
#     core type: Lambda
#     parameter: 77
#     body: 73
# 12. (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|), U(n))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)
#     core type: Operation
#     operator: 19
#     operand: 25
# 16. U(n)
#     core type: Operation
#     operator: 21
#     operand: 64
# 17. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 41
#     operands: 23
# 18. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 41
#     operands: 24
# 19. Sum
#     core type: Literal
#     sub-expressions:
# 20. (i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 25
# 21. U
#     core type: Literal
#     sub-expressions:
# 22. (n)
#     core type: ExprTuple
#     sub-expressions: 64
# 23. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 26, 28
# 24. ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 71
#     body: 29
# 26. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 44
#     operand: 36
# 27. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}
#     core type: Operation
#     operator: 44
#     operand: 37
# 28. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 32
#     operand: 38
# 29. {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 34
#     condition: 35
# 30. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 36
# 31. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 37
# 32. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 33. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 34. |v_{i}〉 . 〈w_{i}|
#     core type: Operation
#     operator: 39
#     operands: 40
# 35. i in {1 .. n}
#     core type: Operation
#     operator: 41
#     operands: 42
# 36. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 44
#     operands: 43
# 37. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 44
#     operands: 45
# 38. Complex^{n}
#     core type: Operation
#     operator: 46
#     operands: 47
# 39. .
#     core type: Literal
#     sub-expressions:
# 40. (|v_{i}〉, 〈w_{i}|)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 41. in
#     core type: Literal
#     sub-expressions:
# 42. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 71, 50
# 43. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 51
# 44. Set
#     core type: Literal
#     sub-expressions:
# 45. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 52
# 46. CartExp
#     core type: Literal
#     sub-expressions:
# 47. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 53, 64
# 48. |v_{i}〉
#     core type: Operation
#     operator: 69
#     operand: 61
# 49. 〈w_{i}|
#     core type: Operation
#     operator: 55
#     operand: 62
# 50. {1 .. n}
#     core type: Operation
#     operator: 57
#     operands: 58
# 51. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 59
#     start_index: 63
#     end_index: 64
# 52. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 60
#     start_index: 63
#     end_index: 64
# 53. Complex
#     core type: Literal
#     sub-expressions:
# 54. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 61
# 55. BRA
#     core type: Literal
#     sub-expressions:
# 56. (w_{i})
#     core type: ExprTuple
#     sub-expressions: 62
# 57. Interval
#     core type: Literal
#     sub-expressions:
# 58. (1, n)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 59. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 77
#     body: 65
# 60. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 77
#     body: 66
# 61. v_{i}
#     core type: IndexedVar
# variable: 74
# index: 71
# 62. w_{i}
#     core type: IndexedVar
# variable: 75
# index: 71
# 63. 1
#     core type: Literal
#     sub-expressions:
# 64. n
#     core type: Variable
#     sub-expressions:
# 65. |v_{_a}〉
#     core type: Operation
#     operator: 69
#     operand: 72
# 66. |w_{_a}〉
#     core type: Operation
#     operator: 69
#     operand: 73
# 67. (i)
#     core type: ExprTuple
#     sub-expressions: 71
# 68. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 72
# 69. KET
#     core type: Literal
#     sub-expressions:
# 70. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 73
# 71. i
#     core type: Variable
#     sub-expressions:
# 72. v_{_a}
#     core type: IndexedVar
# variable: 74
# index: 77
# 73. w_{_a}
#     core type: IndexedVar
# variable: 75
# index: 77
# 74. v
#     core type: Variable
#     sub-expressions:
# 75. w
#     core type: Variable
#     sub-expressions:
# 76. (_a)
#     core type: ExprTuple
#     sub-expressions: 77
# 77. _a
#     core type: Variable
#     sub-expressions:
