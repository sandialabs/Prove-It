# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, v_1_to_n, v_i
from proveit.linear_algebra import Adj, MatrixSpace, OrthoNormBases, ScalarMult, VecSum
from proveit.logic import CartExp, Equals, Exists, Forall, Iff, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = ExprTuple(Lambda(n, Conditional(Forall(instance_param_or_params = [M], instance_expr = Iff(Equals(Qmult(sub_expr1, M), Qmult(M, sub_expr1)), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, Qmult(Ket(v_i), Bra(v_i))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n_kets), OrthoNormBases(CartExp(Complex, n)))).with_wrapping()).with_wrapping_at(2), domain = MatrixSpace(field = Complex, rows = n, columns = n)), InSet(n, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(n \mapsto \left\{\forall_{M \in \mathbb{C}^{n \times n}}~\left(\begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \thinspace M\right) = \left(M \thinspace M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right) \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (n -> {forall_{M in Complex^{n x n}} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{M in Complex^{n x n}} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 99
#    body: 3
# 2. (n)
#    core type: ExprTuple
#    sub-expressions: 99
# 3. {forall_{M in Complex^{n x n}} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{M in Complex^{n x n}} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]])
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in NaturalPos
#    core type: Operation
#    operator: 84
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (M -> {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in Complex^{n x n}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 99, 10
# 9. M -> {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in Complex^{n x n}.
#    core type: Lambda
#    parameter: 63
#    body: 11
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in Complex^{n x n}.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. ((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. M in Complex^{n x n}
#     core type: Operation
#     operator: 84
#     operands: 16
# 14. <=>
#     core type: Literal
#     sub-expressions:
# 15. ((M* . M) = (M . M*), exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))])
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. (M, Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 63, 19
# 17. (M* . M) = (M . M*)
#     core type: Operation
#     operator: 55
#     operands: 20
# 18. exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]
#     core type: Operation
#     operator: 38
#     operand: 26
# 19. Complex^{n x n}
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. (M* . M, M . M*)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 21. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).)
#     core type: ExprTuple
#     sub-expressions: 26
# 22. MSpace
#     core type: Literal
#     sub-expressions:
# 23. {field:Complex, rows:n, columns:n}
#     core type: NamedExprs
#     field: 80
#     rows: 99
#     columns: 99
# 24. M* . M
#     core type: Operation
#     operator: 92
#     operands: 27
# 25. M . M*
#     core type: Operation
#     operator: 92
#     operands: 28
# 26. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Lambda
#     parameters: 29\n    body: 30
# 27. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 31, 63
# 28. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 63, 31
# 29. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 32
# 30. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 33
#     condition: 34
# 31. M*
#     core type: Operation
#     operator: 35
#     operand: 63
# 32. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 98
#     end_index: 99
# 33. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 38
#     operand: 41
# 34. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 84
#     operands: 40
# 35. Adj
#     core type: Literal
#     sub-expressions:
# 36. (M)
#     core type: ExprTuple
#     sub-expressions: 63
# 37. _a -> v_{_a}
#     core type: Lambda
#     parameter: 90
#     body: 81
# 38. exists
#     core type: Literal
#     sub-expressions:
# 39. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 41
# 40. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 41. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 44\n    body: 45
# 42. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 59
#     operand: 52
# 43. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 47
#     operand: 53
# 44. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 49
# 45. {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 50
#     condition: 51
# 46. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 52
# 47. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 48. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 53
# 49. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 54
#     start_index: 98
#     end_index: 99
# 50. M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 55
#     operands: 56
# 51. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 57
#     operands: 58
# 52. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 59
#     operands: 60
# 53. Complex^{n}
#     core type: Operation
#     operator: 61
#     operands: 62
# 54. _a -> a_{_a}
#     core type: Lambda
#     parameter: 90
#     body: 79
# 55. =
#     core type: Literal
#     sub-expressions:
# 56. (M, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 57. and
#     core type: Literal
#     sub-expressions:
# 58. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 65
# 59. Set
#     core type: Literal
#     sub-expressions:
# 60. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 66
# 61. CartExp
#     core type: Literal
#     sub-expressions:
# 62. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 80, 99
# 63. M
#     core type: Variable
#     sub-expressions:
# 64. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 67
#     operand: 71
# 65. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 98
#     end_index: 99
# 66. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 98
#     end_index: 99
# 67. Sum
#     core type: Literal
#     sub-expressions:
# 68. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 71
# 69. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 90
#     body: 72
# 70. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 90
#     body: 73
# 71. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 106
#     body: 74
# 72. a_{_a} in Complex
#     core type: Operation
#     operator: 84
#     operands: 75
# 73. |v_{_a}〉
#     core type: Operation
#     operator: 100
#     operand: 81
# 74. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 77
#     condition: 78
# 75. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 76. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 81
# 77. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 82
#     operands: 83
# 78. i in {1 .. n}
#     core type: Operation
#     operator: 84
#     operands: 85
# 79. a_{_a}
#     core type: IndexedVar
# variable: 91
# index: 90
# 80. Complex
#     core type: Literal
#     sub-expressions:
# 81. v_{_a}
#     core type: IndexedVar
# variable: 104
# index: 90
# 82. *
#     core type: Literal
#     sub-expressions:
# 83. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 87, 88
# 84. in
#     core type: Literal
#     sub-expressions:
# 85. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 106, 89
# 86. (_a)
#     core type: ExprTuple
#     sub-expressions: 90
# 87. a_{i}
#     core type: IndexedVar
# variable: 91
# index: 106
# 88. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 92
#     operands: 93
# 89. {1 .. n}
#     core type: Operation
#     operator: 94
#     operands: 95
# 90. _a
#     core type: Variable
#     sub-expressions:
# 91. a
#     core type: Variable
#     sub-expressions:
# 92. .
#     core type: Literal
#     sub-expressions:
# 93. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 96, 97
# 94. Interval
#     core type: Literal
#     sub-expressions:
# 95. (1, n)
#     core type: ExprTuple
#     sub-expressions: 98, 99
# 96. |v_{i}〉
#     core type: Operation
#     operator: 100
#     operand: 103
# 97. 〈v_{i}|
#     core type: Operation
#     operator: 101
#     operand: 103
# 98. 1
#     core type: Literal
#     sub-expressions:
# 99. n
#     core type: Variable
#     sub-expressions:
# 100. KET
#      core type: Literal
#      sub-expressions:
# 101. BRA
#      core type: Literal
#      sub-expressions:
# 102. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 103
# 103. v_{i}
#      core type: IndexedVar
# variable: 104
# index: 106
# 104. v
#      core type: Variable
#      sub-expressions:
# 105. (i)
#      core type: ExprTuple
#      sub-expressions: 106
# 106. i
#      core type: Variable
#      sub-expressions:
