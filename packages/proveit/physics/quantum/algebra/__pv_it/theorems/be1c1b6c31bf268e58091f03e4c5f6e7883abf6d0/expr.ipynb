# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, X, i, n
from proveit.core_expr_types import x_1_to_n, x_i
from proveit.linear_algebra import Hspace, OrthoNormBases, OrthoProj, VecSum
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import x_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(OrthoProj(Hspace, X), VecSum(index_or_indices = [i], summand = Qmult(Ket(x_i), Bra(x_i)), domain = Interval(one, n))), condition = InSet(x_1_to_n_kets, OrthoNormBases(X))).with_wrapping(), InSet(n, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(n \mapsto \left\{\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{\lvert x_{1} \rangle, \lvert x_{2} \rangle, \ldots, \lvert x_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(X\right)}~\\
# \left(\textrm{OrthoProj}\left(\mathcal{H}, X\right) = \left(\sum_{i=1}^{n} \left(\lvert x_{i} \rangle \thinspace \langle x_{i} \rvert\right)\right)\right)\end{array} \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 58
#    body: 3
# 2. (n)
#    core type: ExprTuple
#    sub-expressions: 58
# 3. {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in NaturalPos
#    core type: Operation
#    operator: 43
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 58, 10
# 9. (x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 13
# 12. {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X).
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 57
#     end_index: 58
# 14. OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(X)
#     core type: Operation
#     operator: 43
#     operands: 19
# 16. _a -> x_{_a}
#     core type: Lambda
#     parameter: 59
#     body: 49
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (OrthoProj(H, X), Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. ({|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}, O.N.Bases(X))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. OrthoProj(H, X)
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)
#     core type: Operation
#     operator: 26
#     operand: 33
# 22. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}
#     core type: Operation
#     operator: 28
#     operands: 29
# 23. O.N.Bases(X)
#     core type: Operation
#     operator: 30
#     operand: 35
# 24. OrthoProj
#     core type: Literal
#     sub-expressions:
# 25. (H, X)
#     core type: ExprTuple
#     sub-expressions: 32, 35
# 26. Sum
#     core type: Literal
#     sub-expressions:
# 27. (i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 33
# 28. Set
#     core type: Literal
#     sub-expressions:
# 29. (|x_{1}〉, |x_{2}〉, ..., |x_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 34
# 30. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 31. (X)
#     core type: ExprTuple
#     sub-expressions: 35
# 32. H
#     core type: Variable
#     sub-expressions:
# 33. i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 62
#     body: 36
# 34. |x_{1}〉, |x_{2}〉, ..., |x_{n}〉
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 57
#     end_index: 58
# 35. X
#     core type: Variable
#     sub-expressions:
# 36. {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 38
#     condition: 39
# 37. _a -> |x_{_a}〉
#     core type: Lambda
#     parameter: 59
#     body: 40
# 38. |x_{i}〉 . 〈x_{i}|
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. i in {1 .. n}
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. |x_{_a}〉
#     core type: Operation
#     operator: 50
#     operand: 49
# 41. .
#     core type: Literal
#     sub-expressions:
# 42. (|x_{i}〉, 〈x_{i}|)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 62, 48
# 45. (x_{_a})
#     core type: ExprTuple
#     sub-expressions: 49
# 46. |x_{i}〉
#     core type: Operation
#     operator: 50
#     operand: 56
# 47. 〈x_{i}|
#     core type: Operation
#     operator: 51
#     operand: 56
# 48. {1 .. n}
#     core type: Operation
#     operator: 53
#     operands: 54
# 49. x_{_a}
#     core type: IndexedVar
# variable: 60
# index: 59
# 50. KET
#     core type: Literal
#     sub-expressions:
# 51. BRA
#     core type: Literal
#     sub-expressions:
# 52. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 56
# 53. Interval
#     core type: Literal
#     sub-expressions:
# 54. (1, n)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 55. (_a)
#     core type: ExprTuple
#     sub-expressions: 59
# 56. x_{i}
#     core type: IndexedVar
# variable: 60
# index: 62
# 57. 1
#     core type: Literal
#     sub-expressions:
# 58. n
#     core type: Variable
#     sub-expressions:
# 59. _a
#     core type: Variable
#     sub-expressions:
# 60. x
#     core type: Variable
#     sub-expressions:
# 61. (i)
#     core type: ExprTuple
#     sub-expressions: 62
# 62. i
#     core type: Variable
#     sub-expressions:
