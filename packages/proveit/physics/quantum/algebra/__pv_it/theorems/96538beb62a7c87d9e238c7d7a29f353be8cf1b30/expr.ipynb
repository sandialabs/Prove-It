# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, Lambda, V, W, i, j, m, n
from proveit.core_expr_types import v_1_to_m, v_i, w_1_to_n, w_j
from proveit.linear_algebra import HilbertSpaces, LinMap, OrthoNormBases, VecSum
from proveit.logic import And, Equals, Forall, InClass, InSet
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_m_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Lambda([V, W], Conditional(Forall(instance_param_or_params = [A], instance_expr = Forall(instance_param_or_params = [m, n], instance_expr = Forall(instance_param_or_params = [v_1_to_m], instance_expr = Forall(instance_param_or_params = [w_1_to_n], instance_expr = Equals(A, VecSum(index_or_indices = [i], summand = VecSum(index_or_indices = [j], summand = Qmult(Bra(w_j), A, Ket(v_i), Ket(w_j), Bra(v_i)), domain = Interval(one, n)), domain = Interval(one, m))), condition = InSet(w_1_to_n_kets, OrthoNormBases(W))).with_wrapping(), condition = InSet(v_1_to_m_kets, OrthoNormBases(V))).with_wrapping(), domain = NaturalPos), domain = LinMap(V, W)), And(InClass(V, HilbertSpaces), InClass(W, HilbertSpaces))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(V, W\right) \mapsto \left\{\forall_{A \in \mathcal{L}\left(V, W\right)}~\left[\forall_{m, n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{v_{1}, v_{2}, \ldots, v_{m}~|~\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{m} \rangle\right\} \in \textrm{O.N.Bases}\left(V\right)}~\\
# \left[\begin{array}{l}\forall_{w_{1}, w_{2}, \ldots, w_{n}~|~\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(W\right)}~\\
# \left(A = \left(\sum_{i=1}^{m} \left(\sum_{j=1}^{n} \left(\langle w_{j} \rvert \thinspace A \thinspace \lvert v_{i} \rangle \thinspace \lvert w_{j} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}\right]\end{array}\right]\right] \textrm{ if } V \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces} ,  W \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (V, W) -> {forall_{A in LINMAP(V, W)} [forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]]] if V in_c HilbertSpaces ,  W in_c HilbertSpaces.
#    core type: Lambda
#    parameters: 24\n   body: 1
# 1. {forall_{A in LINMAP(V, W)} [forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]]] if V in_c HilbertSpaces ,  W in_c HilbertSpaces.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{A in LINMAP(V, W)} [forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]]]
#    core type: Operation
#    operator: 42
#    operand: 6
# 3. (V in_c HilbertSpaces) and (W in_c HilbertSpaces)
#    core type: Operation
#    operator: 28
#    operands: 5
# 4. (A -> {forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]] if A in LINMAP(V, W).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (V in_c HilbertSpaces, W in_c HilbertSpaces)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. A -> {forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]] if A in LINMAP(V, W).
#    core type: Lambda
#    parameter: 100
#    body: 10
# 7. V in_c HilbertSpaces
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. W in_c HilbertSpaces
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. (A)
#    core type: ExprTuple
#    sub-expressions: 100
# 10. {forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]] if A in LINMAP(V, W).
#     core type: Conditional
#     value: 14
#     condition: 15
# 11. (V, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 56, 16
# 12. in_c
#     core type: Literal
#     sub-expressions:
# 13. (W, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 74, 16
# 14. forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]]
#     core type: Operation
#     operator: 42
#     operand: 19
# 15. A in LINMAP(V, W)
#     core type: Operation
#     operator: 97
#     operands: 18
# 16. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 17. ((m, n) -> {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. (A, LINMAP(V, W))
#     core type: ExprTuple
#     sub-expressions: 100, 20
# 19. (m, n) -> {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.
#     core type: Lambda
#     parameters: 21\n    body: 22
# 20. LINMAP(V, W)
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. (m, n)
#     core type: ExprTuple
#     sub-expressions: 93, 114
# 22. {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.
#     core type: Conditional
#     value: 25
#     condition: 26
# 23. LINMAP
#     core type: Literal
#     sub-expressions:
# 24. (V, W)
#     core type: ExprTuple
#     sub-expressions: 56, 74
# 25. forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]
#     core type: Operation
#     operator: 42
#     operand: 30
# 26. (m in NaturalPos) and (n in NaturalPos)
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. ((v_{1}, v_{2}, ..., v_{m}) -> {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).)
#     core type: ExprTuple
#     sub-expressions: 30
# 28. and
#     core type: Literal
#     sub-expressions:
# 29. (m in NaturalPos, n in NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. (v_{1}, v_{2}, ..., v_{m}) -> {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).
#     core type: Lambda
#     parameters: 33\n    body: 34
# 31. m in NaturalPos
#     core type: Operation
#     operator: 97
#     operands: 35
# 32. n in NaturalPos
#     core type: Operation
#     operator: 97
#     operands: 36
# 33. (v_{1}, v_{2}, ..., v_{m})
#     core type: ExprTuple
#     sub-expressions: 37
# 34. {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).
#     core type: Conditional
#     value: 38
#     condition: 39
# 35. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 93, 40
# 36. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 114, 40
# 37. v_{1}, v_{2}, ..., v_{m}
#     core type: ExprRange
#     lambda_map: 41
#     start_index: 113
#     end_index: 93
# 38. forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 42
#     operand: 45
# 39. {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)
#     core type: Operation
#     operator: 97
#     operands: 44
# 40. NaturalPos
#     core type: Literal
#     sub-expressions:
# 41. _a -> v_{_a}
#     core type: Lambda
#     parameter: 94
#     body: 75
# 42. forall
#     core type: Literal
#     sub-expressions:
# 43. ((w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).)
#     core type: ExprTuple
#     sub-expressions: 45
# 44. ({|v_{1}〉, |v_{2}〉, ..., |v_{m}〉}, O.N.Bases(V))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 45. (w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#     core type: Lambda
#     parameters: 48\n    body: 49
# 46. {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉}
#     core type: Operation
#     operator: 67
#     operands: 50
# 47. O.N.Bases(V)
#     core type: Operation
#     operator: 69
#     operand: 56
# 48. (w_{1}, w_{2}, ..., w_{n})
#     core type: ExprTuple
#     sub-expressions: 52
# 49. {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#     core type: Conditional
#     value: 53
#     condition: 54
# 50. (|v_{1}〉, |v_{2}〉, ..., |v_{m}〉)
#     core type: ExprTuple
#     sub-expressions: 55
# 51. (V)
#     core type: ExprTuple
#     sub-expressions: 56
# 52. w_{1}, w_{2}, ..., w_{n}
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 113
#     end_index: 114
# 53. A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 58
#     operands: 59
# 54. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)
#     core type: Operation
#     operator: 97
#     operands: 60
# 55. |v_{1}〉, |v_{2}〉, ..., |v_{m}〉
#     core type: ExprRange
#     lambda_map: 61
#     start_index: 113
#     end_index: 93
# 56. V
#     core type: Variable
#     sub-expressions:
# 57. _a -> w_{_a}
#     core type: Lambda
#     parameter: 94
#     body: 87
# 58. =
#     core type: Literal
#     sub-expressions:
# 59. (A, Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 100, 62
# 60. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}, O.N.Bases(W))
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 61. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 94
#     body: 65
# 62. Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 81
#     operand: 72
# 63. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 67
#     operands: 68
# 64. O.N.Bases(W)
#     core type: Operation
#     operator: 69
#     operand: 74
# 65. |v_{_a}〉
#     core type: Operation
#     operator: 105
#     operand: 75
# 66. (i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 72
# 67. Set
#     core type: Literal
#     sub-expressions:
# 68. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 73
# 69. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 70. (W)
#     core type: ExprTuple
#     sub-expressions: 74
# 71. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 75
# 72. i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Lambda
#     parameter: 120
#     body: 76
# 73. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 77
#     start_index: 113
#     end_index: 114
# 74. W
#     core type: Variable
#     sub-expressions:
# 75. v_{_a}
#     core type: IndexedVar
# variable: 117
# index: 94
# 76. {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Conditional
#     value: 78
#     condition: 79
# 77. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 94
#     body: 80
# 78. Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 81
#     operand: 85
# 79. i in {1 .. m}
#     core type: Operation
#     operator: 97
#     operands: 83
# 80. |w_{_a}〉
#     core type: Operation
#     operator: 105
#     operand: 87
# 81. Sum
#     core type: Literal
#     sub-expressions:
# 82. (j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 85
# 83. (i, {1 .. m})
#     core type: ExprTuple
#     sub-expressions: 120, 86
# 84. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 87
# 85. j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Lambda
#     parameter: 119
#     body: 88
# 86. {1 .. m}
#     core type: Operation
#     operator: 109
#     operands: 89
# 87. w_{_a}
#     core type: IndexedVar
# variable: 115
# index: 94
# 88. {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Conditional
#     value: 91
#     condition: 92
# 89. (1, m)
#     core type: ExprTuple
#     sub-expressions: 113, 93
# 90. (_a)
#     core type: ExprTuple
#     sub-expressions: 94
# 91. 〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 95
#     operands: 96
# 92. j in {1 .. n}
#     core type: Operation
#     operator: 97
#     operands: 98
# 93. m
#     core type: Variable
#     sub-expressions:
# 94. _a
#     core type: Variable
#     sub-expressions:
# 95. .
#     core type: Literal
#     sub-expressions:
# 96. (〈w_{j}|, A, |v_{i}〉, |w_{j}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 99, 100, 101, 102, 103
# 97. in
#     core type: Literal
#     sub-expressions:
# 98. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 119, 104
# 99. 〈w_{j}|
#     core type: Operation
#     operator: 107
#     operand: 111
# 100. A
#      core type: Variable
#      sub-expressions:
# 101. |v_{i}〉
#      core type: Operation
#      operator: 105
#      operand: 112
# 102. |w_{j}〉
#      core type: Operation
#      operator: 105
#      operand: 111
# 103. 〈v_{i}|
#      core type: Operation
#      operator: 107
#      operand: 112
# 104. {1 .. n}
#      core type: Operation
#      operator: 109
#      operands: 110
# 105. KET
#      core type: Literal
#      sub-expressions:
# 106. (w_{j})
#      core type: ExprTuple
#      sub-expressions: 111
# 107. BRA
#      core type: Literal
#      sub-expressions:
# 108. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 112
# 109. Interval
#      core type: Literal
#      sub-expressions:
# 110. (1, n)
#      core type: ExprTuple
#      sub-expressions: 113, 114
# 111. w_{j}
#      core type: IndexedVar
# variable: 115
# index: 119
# 112. v_{i}
#      core type: IndexedVar
# variable: 117
# index: 120
# 113. 1
#      core type: Literal
#      sub-expressions:
# 114. n
#      core type: Variable
#      sub-expressions:
# 115. w
#      core type: Variable
#      sub-expressions:
# 116. (j)
#      core type: ExprTuple
#      sub-expressions: 119
# 117. v
#      core type: Variable
#      sub-expressions:
# 118. (i)
#      core type: ExprTuple
#      sub-expressions: 120
# 119. j
#      core type: Variable
#      sub-expressions:
# 120. i
#      core type: Variable
#      sub-expressions:
