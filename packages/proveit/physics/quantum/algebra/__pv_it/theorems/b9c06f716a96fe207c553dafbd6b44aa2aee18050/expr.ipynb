# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, i, n
from proveit.core_expr_types import v_i, w_i
from proveit.linear_algebra import OrthoNormBases, Unitary, VecSum
from proveit.logic import And, CartExp, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = OrthoNormBases(CartExp(Complex, n))
expr = Conditional(InSet(VecSum(index_or_indices = [i], summand = Qmult(Ket(v_i), Bra(w_i)), domain = Interval(one, n)), Unitary(n)), And(InSet(Set(v_1_to_n_kets), sub_expr1), InSet(Set(w_1_to_n_kets), sub_expr1)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\left(\sum_{i=1}^{n} \left(\lvert v_{i} \rangle \thinspace \langle w_{i} \rvert\right)\right) \in \textrm{U}\left(n\right) \textrm{ if } \left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right) ,  \left\{\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {(Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) in U(n)
#    core type: Operation
#    operator: 32
#    operands: 3
# 2. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})) and ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|), U(n))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)
#    core type: Operation
#    operator: 10
#    operand: 16
# 7. U(n)
#    core type: Operation
#    operator: 12
#    operand: 55
# 8. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#    core type: Operation
#    operator: 32
#    operands: 14
# 9. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})
#    core type: Operation
#    operator: 32
#    operands: 15
# 10. Sum
#     core type: Literal
#     sub-expressions:
# 11. (i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 16
# 12. U
#     core type: Literal
#     sub-expressions:
# 13. (n)
#     core type: ExprTuple
#     sub-expressions: 55
# 14. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 15. ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 62
#     body: 20
# 17. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 35
#     operand: 27
# 18. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}
#     core type: Operation
#     operator: 35
#     operand: 28
# 19. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 23
#     operand: 29
# 20. {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 25
#     condition: 26
# 21. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 27
# 22. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 28
# 23. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 24. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 29
# 25. |v_{i}〉 . 〈w_{i}|
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. i in {1 .. n}
#     core type: Operation
#     operator: 32
#     operands: 33
# 27. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 35
#     operands: 34
# 28. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 35
#     operands: 36
# 29. Complex^{n}
#     core type: Operation
#     operator: 37
#     operands: 38
# 30. .
#     core type: Literal
#     sub-expressions:
# 31. (|v_{i}〉, 〈w_{i}|)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 62, 41
# 34. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 42
# 35. Set
#     core type: Literal
#     sub-expressions:
# 36. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 43
# 37. CartExp
#     core type: Literal
#     sub-expressions:
# 38. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 44, 55
# 39. |v_{i}〉
#     core type: Operation
#     operator: 60
#     operand: 52
# 40. 〈w_{i}|
#     core type: Operation
#     operator: 46
#     operand: 53
# 41. {1 .. n}
#     core type: Operation
#     operator: 48
#     operands: 49
# 42. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 50
#     start_index: 54
#     end_index: 55
# 43. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 54
#     end_index: 55
# 44. Complex
#     core type: Literal
#     sub-expressions:
# 45. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 52
# 46. BRA
#     core type: Literal
#     sub-expressions:
# 47. (w_{i})
#     core type: ExprTuple
#     sub-expressions: 53
# 48. Interval
#     core type: Literal
#     sub-expressions:
# 49. (1, n)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 50. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 68
#     body: 56
# 51. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 68
#     body: 57
# 52. v_{i}
#     core type: IndexedVar
# variable: 65
# index: 62
# 53. w_{i}
#     core type: IndexedVar
# variable: 66
# index: 62
# 54. 1
#     core type: Literal
#     sub-expressions:
# 55. n
#     core type: Variable
#     sub-expressions:
# 56. |v_{_a}〉
#     core type: Operation
#     operator: 60
#     operand: 63
# 57. |w_{_a}〉
#     core type: Operation
#     operator: 60
#     operand: 64
# 58. (i)
#     core type: ExprTuple
#     sub-expressions: 62
# 59. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 63
# 60. KET
#     core type: Literal
#     sub-expressions:
# 61. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 64
# 62. i
#     core type: Variable
#     sub-expressions:
# 63. v_{_a}
#     core type: IndexedVar
# variable: 65
# index: 68
# 64. w_{_a}
#     core type: IndexedVar
# variable: 66
# index: 68
# 65. v
#     core type: Variable
#     sub-expressions:
# 66. w
#     core type: Variable
#     sub-expressions:
# 67. (_a)
#     core type: ExprTuple
#     sub-expressions: 68
# 68. _a
#     core type: Variable
#     sub-expressions:
