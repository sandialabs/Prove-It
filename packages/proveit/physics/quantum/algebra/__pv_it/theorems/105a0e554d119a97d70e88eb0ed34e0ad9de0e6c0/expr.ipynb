# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, i, n
from proveit.core_expr_types import x_1_to_n, x_i
from proveit.linear_algebra import HilbertSpaces, Hspace, Identity, OrthoNormBases, VecSum
from proveit.logic import Equals, Forall, InClass, InSet
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import x_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Lambda(Hspace, Conditional(Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(VecSum(index_or_indices = [i], summand = Qmult(Ket(x_i), Bra(x_i)), domain = Interval(one, n)), Identity(Hspace)), condition = InSet(x_1_to_n_kets, OrthoNormBases(Hspace))).with_wrapping(), domain = NaturalPos), InClass(Hspace, HilbertSpaces)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \mathcal{H} \mapsto \left\{\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{\lvert x_{1} \rangle, \lvert x_{2} \rangle, \ldots, \lvert x_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left(\left(\sum_{i=1}^{n} \left(\lvert x_{i} \rangle \thinspace \langle x_{i} \rvert\right)\right) = I_{\mathcal{H}}\right)\end{array}\right] \textrm{ if } \mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. H -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)] if H in_c HilbertSpaces.
#    core type: Lambda
#    parameter: 40
#    body: 1
# 1. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)] if H in_c HilbertSpaces.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)]
#    core type: Operation
#    operator: 13
#    operand: 7
# 3. H in_c HilbertSpaces
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. in_c
#    core type: Literal
#    sub-expressions:
# 6. (H, HilbertSpaces)
#    core type: ExprTuple
#    sub-expressions: 40, 8
# 7. n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H) if n in NaturalPos.
#    core type: Lambda
#    parameter: 63
#    body: 10
# 8. HilbertSpaces
#    core type: Literal
#    sub-expressions:
# 9. (n)
#    core type: ExprTuple
#    sub-expressions: 63
# 10. {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H) if n in NaturalPos.
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)
#     core type: Operation
#     operator: 13
#     operand: 16
# 12. n in NaturalPos
#     core type: Operation
#     operator: 48
#     operands: 15
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. ((x_{1}, x_{2}, ..., x_{n}) -> {(Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 63, 17
# 16. (x_{1}, x_{2}, ..., x_{n}) -> {(Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 18\n    body: 19
# 17. NaturalPos
#     core type: Literal
#     sub-expressions:
# 18. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 20
# 19. {(Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Conditional
#     value: 21
#     condition: 22
# 20. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 62
#     end_index: 63
# 21. (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)
#     core type: Operation
#     operator: 48
#     operands: 26
# 23. _a -> x_{_a}
#     core type: Lambda
#     parameter: 64
#     body: 54
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|), I_H)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. ({|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)
#     core type: Operation
#     operator: 31
#     operand: 38
# 28. I_H
#     core type: Operation
#     operator: 33
#     operand: 40
# 29. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. O.N.Bases(H)
#     core type: Operation
#     operator: 36
#     operand: 40
# 31. Sum
#     core type: Literal
#     sub-expressions:
# 32. (i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 38
# 33. I
#     core type: Literal
#     sub-expressions:
# 34. Set
#     core type: Literal
#     sub-expressions:
# 35. (|x_{1}〉, |x_{2}〉, ..., |x_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 39
# 36. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 37. (H)
#     core type: ExprTuple
#     sub-expressions: 40
# 38. i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 67
#     body: 41
# 39. |x_{1}〉, |x_{2}〉, ..., |x_{n}〉
#     core type: ExprRange
#     lambda_map: 42
#     start_index: 62
#     end_index: 63
# 40. H
#     core type: Variable
#     sub-expressions:
# 41. {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 43
#     condition: 44
# 42. _a -> |x_{_a}〉
#     core type: Lambda
#     parameter: 64
#     body: 45
# 43. |x_{i}〉 . 〈x_{i}|
#     core type: Operation
#     operator: 46
#     operands: 47
# 44. i in {1 .. n}
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. |x_{_a}〉
#     core type: Operation
#     operator: 55
#     operand: 54
# 46. .
#     core type: Literal
#     sub-expressions:
# 47. (|x_{i}〉, 〈x_{i}|)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 67, 53
# 50. (x_{_a})
#     core type: ExprTuple
#     sub-expressions: 54
# 51. |x_{i}〉
#     core type: Operation
#     operator: 55
#     operand: 61
# 52. 〈x_{i}|
#     core type: Operation
#     operator: 56
#     operand: 61
# 53. {1 .. n}
#     core type: Operation
#     operator: 58
#     operands: 59
# 54. x_{_a}
#     core type: IndexedVar
# variable: 65
# index: 64
# 55. KET
#     core type: Literal
#     sub-expressions:
# 56. BRA
#     core type: Literal
#     sub-expressions:
# 57. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 61
# 58. Interval
#     core type: Literal
#     sub-expressions:
# 59. (1, n)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 60. (_a)
#     core type: ExprTuple
#     sub-expressions: 64
# 61. x_{i}
#     core type: IndexedVar
# variable: 65
# index: 67
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. n
#     core type: Variable
#     sub-expressions:
# 64. _a
#     core type: Variable
#     sub-expressions:
# 65. x
#     core type: Variable
#     sub-expressions:
# 66. (i)
#     core type: ExprTuple
#     sub-expressions: 67
# 67. i
#     core type: Variable
#     sub-expressions:
