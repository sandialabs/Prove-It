# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, V, W, i, j, m, n
from proveit.core_expr_types import v_1_to_m, v_i, w_1_to_n, w_j
from proveit.linear_algebra import LinMap, OrthoNormBases, VecSum
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_m_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall(instance_param_or_params = [m, n], instance_expr = Forall(instance_param_or_params = [v_1_to_m], instance_expr = Forall(instance_param_or_params = [w_1_to_n], instance_expr = Equals(A, VecSum(index_or_indices = [i], summand = VecSum(index_or_indices = [j], summand = Qmult(Bra(w_j), A, Ket(v_i), Ket(w_j), Bra(v_i)), domain = Interval(one, n)), domain = Interval(one, m))), condition = InSet(w_1_to_n_kets, OrthoNormBases(W))).with_wrapping(), condition = InSet(v_1_to_m_kets, OrthoNormBases(V))).with_wrapping(), domain = NaturalPos), InSet(A, LinMap(V, W)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{m, n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{v_{1}, v_{2}, \ldots, v_{m}~|~\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{m} \rangle\right\} \in \textrm{O.N.Bases}\left(V\right)}~\\
# \left[\begin{array}{l}\forall_{w_{1}, w_{2}, \ldots, w_{n}~|~\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(W\right)}~\\
# \left(A = \left(\sum_{i=1}^{m} \left(\sum_{j=1}^{n} \left(\langle w_{j} \rvert \thinspace A \thinspace \lvert v_{i} \rangle \thinspace \lvert w_{j} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}\right]\end{array}\right] \textrm{ if } A \in \mathcal{L}\left(V, W\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]] if A in LINMAP(V, W).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]]
#    core type: Operation
#    operator: 28
#    operand: 5
# 2. A in LINMAP(V, W)
#    core type: Operation
#    operator: 83
#    operands: 4
# 3. ((m, n) -> {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (A, LINMAP(V, W))
#    core type: ExprTuple
#    sub-expressions: 86, 6
# 5. (m, n) -> {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. LINMAP(V, W)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (m, n)
#    core type: ExprTuple
#    sub-expressions: 79, 100
# 8. {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. LINMAP
#    core type: Literal
#    sub-expressions:
# 10. (V, W)
#     core type: ExprTuple
#     sub-expressions: 42, 60
# 11. forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]
#     core type: Operation
#     operator: 28
#     operand: 16
# 12. (m in NaturalPos) and (n in NaturalPos)
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. ((v_{1}, v_{2}, ..., v_{m}) -> {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (m in NaturalPos, n in NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. (v_{1}, v_{2}, ..., v_{m}) -> {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).
#     core type: Lambda
#     parameters: 19\n    body: 20
# 17. m in NaturalPos
#     core type: Operation
#     operator: 83
#     operands: 21
# 18. n in NaturalPos
#     core type: Operation
#     operator: 83
#     operands: 22
# 19. (v_{1}, v_{2}, ..., v_{m})
#     core type: ExprTuple
#     sub-expressions: 23
# 20. {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).
#     core type: Conditional
#     value: 24
#     condition: 25
# 21. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 79, 26
# 22. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 100, 26
# 23. v_{1}, v_{2}, ..., v_{m}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 99
#     end_index: 79
# 24. forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 28
#     operand: 31
# 25. {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)
#     core type: Operation
#     operator: 83
#     operands: 30
# 26. NaturalPos
#     core type: Literal
#     sub-expressions:
# 27. _a -> v_{_a}
#     core type: Lambda
#     parameter: 80
#     body: 61
# 28. forall
#     core type: Literal
#     sub-expressions:
# 29. ((w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).)
#     core type: ExprTuple
#     sub-expressions: 31
# 30. ({|v_{1}〉, |v_{2}〉, ..., |v_{m}〉}, O.N.Bases(V))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 31. (w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#     core type: Lambda
#     parameters: 34\n    body: 35
# 32. {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉}
#     core type: Operation
#     operator: 53
#     operands: 36
# 33. O.N.Bases(V)
#     core type: Operation
#     operator: 55
#     operand: 42
# 34. (w_{1}, w_{2}, ..., w_{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 35. {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#     core type: Conditional
#     value: 39
#     condition: 40
# 36. (|v_{1}〉, |v_{2}〉, ..., |v_{m}〉)
#     core type: ExprTuple
#     sub-expressions: 41
# 37. (V)
#     core type: ExprTuple
#     sub-expressions: 42
# 38. w_{1}, w_{2}, ..., w_{n}
#     core type: ExprRange
#     lambda_map: 43
#     start_index: 99
#     end_index: 100
# 39. A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)
#     core type: Operation
#     operator: 83
#     operands: 46
# 41. |v_{1}〉, |v_{2}〉, ..., |v_{m}〉
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 99
#     end_index: 79
# 42. V
#     core type: Variable
#     sub-expressions:
# 43. _a -> w_{_a}
#     core type: Lambda
#     parameter: 80
#     body: 73
# 44. =
#     core type: Literal
#     sub-expressions:
# 45. (A, Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 86, 48
# 46. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}, O.N.Bases(W))
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 47. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 80
#     body: 51
# 48. Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 67
#     operand: 58
# 49. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 53
#     operands: 54
# 50. O.N.Bases(W)
#     core type: Operation
#     operator: 55
#     operand: 60
# 51. |v_{_a}〉
#     core type: Operation
#     operator: 91
#     operand: 61
# 52. (i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 58
# 53. Set
#     core type: Literal
#     sub-expressions:
# 54. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 59
# 55. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 56. (W)
#     core type: ExprTuple
#     sub-expressions: 60
# 57. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 61
# 58. i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Lambda
#     parameter: 106
#     body: 62
# 59. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 63
#     start_index: 99
#     end_index: 100
# 60. W
#     core type: Variable
#     sub-expressions:
# 61. v_{_a}
#     core type: IndexedVar
# variable: 103
# index: 80
# 62. {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Conditional
#     value: 64
#     condition: 65
# 63. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 80
#     body: 66
# 64. Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 67
#     operand: 71
# 65. i in {1 .. m}
#     core type: Operation
#     operator: 83
#     operands: 69
# 66. |w_{_a}〉
#     core type: Operation
#     operator: 91
#     operand: 73
# 67. Sum
#     core type: Literal
#     sub-expressions:
# 68. (j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 71
# 69. (i, {1 .. m})
#     core type: ExprTuple
#     sub-expressions: 106, 72
# 70. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 73
# 71. j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Lambda
#     parameter: 105
#     body: 74
# 72. {1 .. m}
#     core type: Operation
#     operator: 95
#     operands: 75
# 73. w_{_a}
#     core type: IndexedVar
# variable: 101
# index: 80
# 74. {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Conditional
#     value: 77
#     condition: 78
# 75. (1, m)
#     core type: ExprTuple
#     sub-expressions: 99, 79
# 76. (_a)
#     core type: ExprTuple
#     sub-expressions: 80
# 77. 〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 81
#     operands: 82
# 78. j in {1 .. n}
#     core type: Operation
#     operator: 83
#     operands: 84
# 79. m
#     core type: Variable
#     sub-expressions:
# 80. _a
#     core type: Variable
#     sub-expressions:
# 81. .
#     core type: Literal
#     sub-expressions:
# 82. (〈w_{j}|, A, |v_{i}〉, |w_{j}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 85, 86, 87, 88, 89
# 83. in
#     core type: Literal
#     sub-expressions:
# 84. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 105, 90
# 85. 〈w_{j}|
#     core type: Operation
#     operator: 93
#     operand: 97
# 86. A
#     core type: Variable
#     sub-expressions:
# 87. |v_{i}〉
#     core type: Operation
#     operator: 91
#     operand: 98
# 88. |w_{j}〉
#     core type: Operation
#     operator: 91
#     operand: 97
# 89. 〈v_{i}|
#     core type: Operation
#     operator: 93
#     operand: 98
# 90. {1 .. n}
#     core type: Operation
#     operator: 95
#     operands: 96
# 91. KET
#     core type: Literal
#     sub-expressions:
# 92. (w_{j})
#     core type: ExprTuple
#     sub-expressions: 97
# 93. BRA
#     core type: Literal
#     sub-expressions:
# 94. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 98
# 95. Interval
#     core type: Literal
#     sub-expressions:
# 96. (1, n)
#     core type: ExprTuple
#     sub-expressions: 99, 100
# 97. w_{j}
#     core type: IndexedVar
# variable: 101
# index: 105
# 98. v_{i}
#     core type: IndexedVar
# variable: 103
# index: 106
# 99. 1
#     core type: Literal
#     sub-expressions:
# 100. n
#      core type: Variable
#      sub-expressions:
# 101. w
#      core type: Variable
#      sub-expressions:
# 102. (j)
#      core type: ExprTuple
#      sub-expressions: 105
# 103. v
#      core type: Variable
#      sub-expressions:
# 104. (i)
#      core type: ExprTuple
#      sub-expressions: 106
# 105. j
#      core type: Variable
#      sub-expressions:
# 106. i
#      core type: Variable
#      sub-expressions:
