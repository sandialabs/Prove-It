# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprRange, IndexedVar, Variable, a, b, i, n
from proveit.core_expr_types import a_i, b_i, v_i
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [i]
sub_expr3 = Interval(one, n)
sub_expr4 = Qmult(Ket(v_i), Bra(v_i))
expr = Conditional(And(Equals(A, VecSum(index_or_indices = sub_expr2, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)), Equals(B, VecSum(index_or_indices = sub_expr2, summand = ScalarMult(b_i, sub_expr4), domain = sub_expr3))).with_wrapping_at(2), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, n), ExprRange(sub_expr1, InSet(IndexedVar(b, sub_expr1), Complex), one, n)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array} \textrm{ if } \left(a_{1} \in \mathbb{C}\right) ,  \left(a_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(a_{n} \in \mathbb{C}\right), \left(b_{1} \in \mathbb{C}\right) ,  \left(b_{2} \in \mathbb{C}\right) ,  \ldots ,  \left(b_{n} \in \mathbb{C}\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 55
#    end_index: 56
# 9. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 55
#    end_index: 56
# 10. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 13. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 37
#     body: 19
# 14. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 37
#     body: 20
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 22
#     operand: 26
# 17. B
#     core type: Variable
#     sub-expressions:
# 18. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 22
#     operand: 27
# 19. a_{_a} in Complex
#     core type: Operation
#     operator: 41
#     operands: 24
# 20. b_{_a} in Complex
#     core type: Operation
#     operator: 41
#     operands: 25
# 21. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 26
# 22. Sum
#     core type: Literal
#     sub-expressions:
# 23. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 27
# 24. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 28, 30
# 25. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 63
#     body: 31
# 27. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 63
#     body: 32
# 28. a_{_a}
#     core type: IndexedVar
# variable: 47
# index: 37
# 29. b_{_a}
#     core type: IndexedVar
# variable: 48
# index: 37
# 30. Complex
#     core type: Literal
#     sub-expressions:
# 31. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 34
#     condition: 36
# 32. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 35
#     condition: 36
# 33. (_a)
#     core type: ExprTuple
#     sub-expressions: 37
# 34. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 39
#     operands: 38
# 35. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 39
#     operands: 40
# 36. i in {1 .. n}
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. _a
#     core type: Variable
#     sub-expressions:
# 38. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 43, 45
# 39. *
#     core type: Literal
#     sub-expressions:
# 40. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 41. in
#     core type: Literal
#     sub-expressions:
# 42. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 63, 46
# 43. a_{i}
#     core type: IndexedVar
# variable: 47
# index: 63
# 44. b_{i}
#     core type: IndexedVar
# variable: 48
# index: 63
# 45. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 49
#     operands: 50
# 46. {1 .. n}
#     core type: Operation
#     operator: 51
#     operands: 52
# 47. a
#     core type: Variable
#     sub-expressions:
# 48. b
#     core type: Variable
#     sub-expressions:
# 49. .
#     core type: Literal
#     sub-expressions:
# 50. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. Interval
#     core type: Literal
#     sub-expressions:
# 52. (1, n)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. |v_{i}〉
#     core type: Operation
#     operator: 57
#     operand: 60
# 54. 〈v_{i}|
#     core type: Operation
#     operator: 58
#     operand: 60
# 55. 1
#     core type: Literal
#     sub-expressions:
# 56. n
#     core type: Variable
#     sub-expressions:
# 57. KET
#     core type: Literal
#     sub-expressions:
# 58. BRA
#     core type: Literal
#     sub-expressions:
# 59. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 60
# 60. v_{i}
#     core type: IndexedVar
# variable: 61
# index: 63
# 61. v
#     core type: Variable
#     sub-expressions:
# 62. (i)
#     core type: ExprTuple
#     sub-expressions: 63
# 63. i
#     core type: Variable
#     sub-expressions:
