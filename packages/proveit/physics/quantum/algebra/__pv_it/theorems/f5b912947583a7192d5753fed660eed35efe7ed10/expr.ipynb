# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, Lambda, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, v_1_to_n, v_i
from proveit.linear_algebra import Hspace, OrthoNormBases, ScalarMult, VecSum
from proveit.logic import And, Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Interval(one, n)
sub_expr3 = Qmult(Ket(v_i), Bra(v_i))
expr = Lambda([v_1_to_n], Conditional(Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr3), domain = sub_expr2)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr3), domain = sub_expr2))).with_wrapping_at(2), domain = Complex).with_wrapping(), InSet(Set(v_1_to_n), OrthoNormBases(Hspace))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(v_{1}, v_{2}, \ldots, v_{n}\right) \mapsto \left\{\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array}\right)\end{array} \textrm{ if } \left\{v_{1}, v_{2}, \ldots, v_{n}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).
#    core type: Lambda
#    parameters: 13\n   body: 1
# 1. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(H)
#    core type: Operation
#    operator: 64
#    operands: 6
# 4. exists
#    core type: Literal
#    sub-expressions:
# 5. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. ({v_{1}, v_{2}, ..., v_{n}}, O.N.Bases(H))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 8. {v_{1}, v_{2}, ..., v_{n}}
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. O.N.Bases(H)
#    core type: Operation
#    operator: 14
#    operand: 21
# 10. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 11. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 18
#     condition: 19
# 12. Set
#     core type: Literal
#     sub-expressions:
# 13. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 20
# 14. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 15. (H)
#     core type: ExprTuple
#     sub-expressions: 21
# 16. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 78
#     end_index: 79
# 17. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 78
#     end_index: 79
# 18. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 25
#     operands: 24
# 19. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 25
#     operands: 26
# 20. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 78
#     end_index: 79
# 21. H
#     core type: Variable
#     sub-expressions:
# 22. _a -> a_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 51
# 23. _a -> b_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 52
# 24. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. and
#     core type: Literal
#     sub-expressions:
# 26. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 27. _a -> v_{_a}
#     core type: Lambda
#     parameter: 60
#     body: 32
# 28. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 34
#     operands: 33
# 29. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 78
#     end_index: 79
# 31. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 78
#     end_index: 79
# 32. v_{_a}
#     core type: IndexedVar
# variable: 84
# index: 60
# 33. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 34. =
#     core type: Literal
#     sub-expressions:
# 35. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 36. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 60
#     body: 42
# 37. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 60
#     body: 43
# 38. A
#     core type: Variable
#     sub-expressions:
# 39. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 45
#     operand: 49
# 40. B
#     core type: Variable
#     sub-expressions:
# 41. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 45
#     operand: 50
# 42. a_{_a} in Complex
#     core type: Operation
#     operator: 64
#     operands: 47
# 43. b_{_a} in Complex
#     core type: Operation
#     operator: 64
#     operands: 48
# 44. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 49
# 45. Sum
#     core type: Literal
#     sub-expressions:
# 46. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 50
# 47. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 51, 53
# 48. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 49. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 86
#     body: 54
# 50. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 86
#     body: 55
# 51. a_{_a}
#     core type: IndexedVar
# variable: 70
# index: 60
# 52. b_{_a}
#     core type: IndexedVar
# variable: 71
# index: 60
# 53. Complex
#     core type: Literal
#     sub-expressions:
# 54. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 57
#     condition: 59
# 55. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 58
#     condition: 59
# 56. (_a)
#     core type: ExprTuple
#     sub-expressions: 60
# 57. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 62
#     operands: 61
# 58. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 62
#     operands: 63
# 59. i in {1 .. n}
#     core type: Operation
#     operator: 64
#     operands: 65
# 60. _a
#     core type: Variable
#     sub-expressions:
# 61. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 66, 68
# 62. *
#     core type: Literal
#     sub-expressions:
# 63. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 64. in
#     core type: Literal
#     sub-expressions:
# 65. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 86, 69
# 66. a_{i}
#     core type: IndexedVar
# variable: 70
# index: 86
# 67. b_{i}
#     core type: IndexedVar
# variable: 71
# index: 86
# 68. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 72
#     operands: 73
# 69. {1 .. n}
#     core type: Operation
#     operator: 74
#     operands: 75
# 70. a
#     core type: Variable
#     sub-expressions:
# 71. b
#     core type: Variable
#     sub-expressions:
# 72. .
#     core type: Literal
#     sub-expressions:
# 73. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 76, 77
# 74. Interval
#     core type: Literal
#     sub-expressions:
# 75. (1, n)
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 76. |v_{i}〉
#     core type: Operation
#     operator: 80
#     operand: 83
# 77. 〈v_{i}|
#     core type: Operation
#     operator: 81
#     operand: 83
# 78. 1
#     core type: Literal
#     sub-expressions:
# 79. n
#     core type: Variable
#     sub-expressions:
# 80. KET
#     core type: Literal
#     sub-expressions:
# 81. BRA
#     core type: Literal
#     sub-expressions:
# 82. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 83
# 83. v_{i}
#     core type: IndexedVar
# variable: 84
# index: 86
# 84. v
#     core type: Variable
#     sub-expressions:
# 85. (i)
#     core type: ExprTuple
#     sub-expressions: 86
# 86. i
#     core type: Variable
#     sub-expressions:
