# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Iff.html">Iff</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, v_1_to_n, v_i
from proveit.linear_algebra import Adj, OrthoNormBases, ScalarMult, VecSum
from proveit.logic import CartExp, Equals, Exists, Iff, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = Iff(Equals(Qmult(sub_expr1, M), Qmult(M, sub_expr1)), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, Qmult(Ket(v_i), Bra(v_i))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n_kets), OrthoNormBases(CartExp(Complex, n)))).with_wrapping()).with_wrapping_at(2)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \thinspace M\right) = \left(M \thinspace M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array}

# %%
stored_expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: (2)
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'without_wrapping', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=>
#    core type: Literal
#    sub-expressions:
# 2. ((M* . M) = (M . M*), exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (M* . M) = (M . M*)
#    core type: Operation
#    operator: 38
#    operands: 5
# 4. exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]
#    core type: Operation
#    operator: 21
#    operand: 9
# 5. (M* . M, M . M*)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. M* . M
#    core type: Operation
#    operator: 75
#    operands: 10
# 8. M . M*
#    core type: Operation
#    operator: 75
#    operands: 11
# 9. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 12\n   body: 13
# 10. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 14, 46
# 11. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 46, 14
# 12. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 13. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. M*
#     core type: Operation
#     operator: 18
#     operand: 46
# 15. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 81
#     end_index: 82
# 16. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 21
#     operand: 24
# 17. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 67
#     operands: 23
# 18. Adj
#     core type: Literal
#     sub-expressions:
# 19. (M)
#     core type: ExprTuple
#     sub-expressions: 46
# 20. _a -> v_{_a}
#     core type: Lambda
#     parameter: 73
#     body: 64
# 21. exists
#     core type: Literal
#     sub-expressions:
# 22. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 27\n    body: 28
# 25. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 42
#     operand: 35
# 26. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 30
#     operand: 36
# 27. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 32
# 28. {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 33
#     condition: 34
# 29. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 35
# 30. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 31. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 36
# 32. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 81
#     end_index: 82
# 33. M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 40
#     operands: 41
# 35. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 42
#     operands: 43
# 36. Complex^{n}
#     core type: Operation
#     operator: 44
#     operands: 45
# 37. _a -> a_{_a}
#     core type: Lambda
#     parameter: 73
#     body: 62
# 38. =
#     core type: Literal
#     sub-expressions:
# 39. (M, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 40. and
#     core type: Literal
#     sub-expressions:
# 41. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 48
# 42. Set
#     core type: Literal
#     sub-expressions:
# 43. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 49
# 44. CartExp
#     core type: Literal
#     sub-expressions:
# 45. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 63, 82
# 46. M
#     core type: Variable
#     sub-expressions:
# 47. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 50
#     operand: 54
# 48. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 52
#     start_index: 81
#     end_index: 82
# 49. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 53
#     start_index: 81
#     end_index: 82
# 50. Sum
#     core type: Literal
#     sub-expressions:
# 51. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 54
# 52. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 73
#     body: 55
# 53. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 73
#     body: 56
# 54. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 89
#     body: 57
# 55. a_{_a} in Complex
#     core type: Operation
#     operator: 67
#     operands: 58
# 56. |v_{_a}〉
#     core type: Operation
#     operator: 83
#     operand: 64
# 57. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 60
#     condition: 61
# 58. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 59. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 64
# 60. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. i in {1 .. n}
#     core type: Operation
#     operator: 67
#     operands: 68
# 62. a_{_a}
#     core type: IndexedVar
# variable: 74
# index: 73
# 63. Complex
#     core type: Literal
#     sub-expressions:
# 64. v_{_a}
#     core type: IndexedVar
# variable: 87
# index: 73
# 65. *
#     core type: Literal
#     sub-expressions:
# 66. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 67. in
#     core type: Literal
#     sub-expressions:
# 68. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 89, 72
# 69. (_a)
#     core type: ExprTuple
#     sub-expressions: 73
# 70. a_{i}
#     core type: IndexedVar
# variable: 74
# index: 89
# 71. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 75
#     operands: 76
# 72. {1 .. n}
#     core type: Operation
#     operator: 77
#     operands: 78
# 73. _a
#     core type: Variable
#     sub-expressions:
# 74. a
#     core type: Variable
#     sub-expressions:
# 75. .
#     core type: Literal
#     sub-expressions:
# 76. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 77. Interval
#     core type: Literal
#     sub-expressions:
# 78. (1, n)
#     core type: ExprTuple
#     sub-expressions: 81, 82
# 79. |v_{i}〉
#     core type: Operation
#     operator: 83
#     operand: 86
# 80. 〈v_{i}|
#     core type: Operation
#     operator: 84
#     operand: 86
# 81. 1
#     core type: Literal
#     sub-expressions:
# 82. n
#     core type: Variable
#     sub-expressions:
# 83. KET
#     core type: Literal
#     sub-expressions:
# 84. BRA
#     core type: Literal
#     sub-expressions:
# 85. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 86
# 86. v_{i}
#     core type: IndexedVar
# variable: 87
# index: 89
# 87. v
#     core type: Variable
#     sub-expressions:
# 88. (i)
#     core type: ExprTuple
#     sub-expressions: 89
# 89. i
#     core type: Variable
#     sub-expressions:
