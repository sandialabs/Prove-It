# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, D, U, V, n
from proveit.linear_algebra import Diagonal, MatrixSpace, Unitary
from proveit.logic import Equals, Exists, Forall
from proveit.numbers import Complex, NaturalPos
from proveit.physics.quantum import Qmult

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [A], instance_expr = Exists(instance_param_or_params = [D], instance_expr = Exists(instance_param_or_params = [U, V], instance_expr = Equals(A, Qmult(U, D, V)), domain = Unitary(n)), domain = Diagonal(n)), domain = MatrixSpace(field = Complex, rows = n, columns = n)), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{A \in \mathbb{C}^{n \times n}}~\left[\exists_{D \in \textrm{D}\left(n\right)}~\left[\exists_{U, V \in \textrm{U}\left(n\right)}~\left(A = \left(U \thinspace D \thinspace V\right)\right)\right]\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{A in Complex^{n x n}} [exists_{D in D(n)} [exists_{U, V in U(n)} (A = (U . D . V))]]]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{A in Complex^{n x n}} [exists_{D in D(n)} [exists_{U, V in U(n)} (A = (U . D . V))]] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{A in Complex^{n x n}} [exists_{D in D(n)} [exists_{U, V in U(n)} (A = (U . D . V))]] if n in NaturalPos.
#    core type: Lambda
#    parameter: 55
#    body: 3
# 3. {forall_{A in Complex^{n x n}} [exists_{D in D(n)} [exists_{U, V in U(n)} (A = (U . D . V))]] if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A in Complex^{n x n}} [exists_{D in D(n)} [exists_{U, V in U(n)} (A = (U . D . V))]]
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in NaturalPos
#    core type: Operation
#    operator: 47
#    operands: 8
# 6. forall
#    core type: Literal
# ...
