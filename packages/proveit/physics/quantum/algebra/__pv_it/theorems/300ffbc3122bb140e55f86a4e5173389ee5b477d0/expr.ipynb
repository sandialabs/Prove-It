# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprTuple, Lambda, W, i, j, m, n
from proveit.core_expr_types import v_i, w_1_to_n, w_j
from proveit.linear_algebra import OrthoNormBases, VecSum
from proveit.logic import Equals, InSet
from proveit.numbers import Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import w_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([w_1_to_n], Conditional(Equals(A, VecSum(index_or_indices = [i], summand = VecSum(index_or_indices = [j], summand = Qmult(Bra(w_j), A, Ket(v_i), Ket(w_j), Bra(v_i)), domain = Interval(one, n)), domain = Interval(one, m))), InSet(w_1_to_n_kets, OrthoNormBases(W)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(w_{1}, w_{2}, \ldots, w_{n}\right) \mapsto \left\{A = \left(\sum_{i=1}^{m} \left(\sum_{j=1}^{n} \left(\langle w_{j} \rvert \thinspace A \thinspace \lvert v_{i} \rangle \thinspace \lvert w_{j} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right) \textrm{ if } \left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(W\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (w_{1}, w_{2}, ..., w_{n})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#    core type: Conditional
#    value: 5
#    condition: 6
# 4. w_{1}, w_{2}, ..., w_{n}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 59
#    end_index: 60
# 5. A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)
#    core type: Operation
#    operator: 43
#    operands: 10
# 7. _a -> w_{_a}
#    core type: Lambda
#    parameter: 40
#    body: 33
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (A, Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#    core type: ExprTuple
#    sub-expressions: 46, 11
# 10. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}, O.N.Bases(W))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 27
#     operand: 19
# 12. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. O.N.Bases(W)
#     core type: Operation
#     operator: 17
#     operand: 21
# 14. (i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 19
# 15. Set
#     core type: Literal
#     sub-expressions:
# 16. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 20
# 17. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 18. (W)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Lambda
#     parameter: 66
#     body: 22
# 20. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 59
#     end_index: 60
# 21. W
#     core type: Variable
#     sub-expressions:
# 22. {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Conditional
#     value: 24
#     condition: 25
# 23. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 40
#     body: 26
# 24. Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 27
#     operand: 31
# 25. i in {1 .. m}
#     core type: Operation
#     operator: 43
#     operands: 29
# 26. |w_{_a}〉
#     core type: Operation
#     operator: 51
#     operand: 33
# 27. Sum
#     core type: Literal
#     sub-expressions:
# 28. (j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 31
# 29. (i, {1 .. m})
#     core type: ExprTuple
#     sub-expressions: 66, 32
# 30. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 33
# 31. j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Lambda
#     parameter: 65
#     body: 34
# 32. {1 .. m}
#     core type: Operation
#     operator: 55
#     operands: 35
# 33. w_{_a}
#     core type: IndexedVar
# variable: 61
# index: 40
# 34. {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Conditional
#     value: 37
#     condition: 38
# 35. (1, m)
#     core type: ExprTuple
#     sub-expressions: 59, 39
# 36. (_a)
#     core type: ExprTuple
#     sub-expressions: 40
# 37. 〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. j in {1 .. n}
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. m
#     core type: Variable
#     sub-expressions:
# 40. _a
#     core type: Variable
#     sub-expressions:
# 41. .
#     core type: Literal
#     sub-expressions:
# 42. (〈w_{j}|, A, |v_{i}〉, |w_{j}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 45, 46, 47, 48, 49
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 65, 50
# 45. 〈w_{j}|
#     core type: Operation
#     operator: 53
#     operand: 57
# 46. A
#     core type: Variable
#     sub-expressions:
# 47. |v_{i}〉
#     core type: Operation
#     operator: 51
#     operand: 58
# 48. |w_{j}〉
#     core type: Operation
#     operator: 51
#     operand: 57
# 49. 〈v_{i}|
#     core type: Operation
#     operator: 53
#     operand: 58
# 50. {1 .. n}
#     core type: Operation
#     operator: 55
#     operands: 56
# 51. KET
#     core type: Literal
#     sub-expressions:
# 52. (w_{j})
#     core type: ExprTuple
#     sub-expressions: 57
# 53. BRA
#     core type: Literal
#     sub-expressions:
# 54. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 58
# 55. Interval
#     core type: Literal
#     sub-expressions:
# 56. (1, n)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 57. w_{j}
#     core type: IndexedVar
# variable: 61
# index: 65
# 58. v_{i}
#     core type: IndexedVar
# variable: 63
# index: 66
# 59. 1
#     core type: Literal
#     sub-expressions:
# 60. n
#     core type: Variable
#     sub-expressions:
# 61. w
#     core type: Variable
#     sub-expressions:
# 62. (j)
#     core type: ExprTuple
#     sub-expressions: 65
# 63. v
#     core type: Variable
#     sub-expressions:
# 64. (i)
#     core type: ExprTuple
#     sub-expressions: 66
# 65. j
#     core type: Variable
#     sub-expressions:
# 66. i
#     core type: Variable
#     sub-expressions:
