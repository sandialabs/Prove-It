# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, B, Conditional, ExprTuple, Lambda, i, n
from proveit.core_expr_types import a_1_to_n, a_i, b_1_to_n, b_i, v_1_to_n, v_i
from proveit.linear_algebra import Adj, Commutator, MatrixSpace, OrthoNormBases, ScalarMult, VecSum, VecZero
from proveit.logic import And, CartExp, Equals, Exists, Forall, Iff, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = MatrixSpace(field = Complex, rows = n, columns = n)
sub_expr3 = Interval(one, n)
sub_expr4 = Qmult(Ket(v_i), Bra(v_i))
expr = ExprTuple(Lambda(n, Conditional(Forall(instance_param_or_params = [A, B], instance_expr = Iff(Equals(Commutator(A, B), VecZero(sub_expr2)), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n, b_1_to_n], instance_expr = And(Equals(A, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr4), domain = sub_expr3)), Equals(B, VecSum(index_or_indices = sub_expr1, summand = ScalarMult(b_i, sub_expr4), domain = sub_expr3))).with_wrapping_at(2), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n), OrthoNormBases(CartExp(Complex, n)))).with_wrapping()).with_wrapping_at(2), domain = sub_expr2, conditions = [Equals(Adj(A), A), Equals(Adj(B), B)]).with_wrapping(), InSet(n, NaturalPos))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(n \mapsto \left\{\begin{array}{l}\forall_{A, B \in \mathbb{C}^{n \times n}~|~A^{\dagger} = A, B^{\dagger} = B}~\\
# \left(\begin{array}{c} \begin{array}{l} \left(\left[A, B\right] = \vec{0}\left(\mathbb{C}^{n \times n}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{v_{1}, v_{2}, \ldots, v_{n}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n}, b_{1}, b_{2}, \ldots, b_{n} \in \mathbb{C}}~\\
# \left(\begin{array}{c} \left(A = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \land  \\ \left(B = \left(\sum_{i=1}^{n} \left(b_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right) \end{array}\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right)\end{array} \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (n -> {forall_{A, B in Complex^{n x n} | A* = A, B* = B} (([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{A, B in Complex^{n x n} | A* = A, B* = B} (([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]) if n in NaturalPos.
#    core type: Lambda
#    parameter: 124
#    body: 3
# 2. (n)
#    core type: ExprTuple
#    sub-expressions: 124
# 3. {forall_{A, B in Complex^{n x n} | A* = A, B* = B} (([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]) if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A, B in Complex^{n x n} | A* = A, B* = B} (([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]])
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in NaturalPos
#    core type: Operation
#    operator: 109
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((A, B) -> {([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in Complex^{n x n} ,  B in Complex^{n x n} ,  A* = A ,  B* = B.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 124, 10
# 9. (A, B) -> {([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in Complex^{n x n} ,  B in Complex^{n x n} ,  A* = A ,  B* = B.
#    core type: Lambda
#    parameters: 35\n   body: 11
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. {([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]] if A in Complex^{n x n} ,  B in Complex^{n x n} ,  A* = A ,  B* = B.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. ([A, B] = 0(Complex^{n x n})) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]]
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (A in Complex^{n x n}) and (B in Complex^{n x n}) and (A* = A) and (B* = B)
#     core type: Operation
#     operator: 68
#     operands: 16
# 14. <=>
#     core type: Literal
#     sub-expressions:
# 15. ([A, B] = 0(Complex^{n x n}), exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))])
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. (A in Complex^{n x n}, B in Complex^{n x n}, A* = A, B* = B)
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21, 22
# 17. [A, B] = 0(Complex^{n x n})
#     core type: Operation
#     operator: 79
#     operands: 23
# 18. exists_{v_{1}, v_{2}, ..., v_{n} | {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})} [exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))]
#     core type: Operation
#     operator: 47
#     operand: 31
# 19. A in Complex^{n x n}
#     core type: Operation
#     operator: 109
#     operands: 25
# 20. B in Complex^{n x n}
#     core type: Operation
#     operator: 109
#     operands: 26
# 21. A* = A
#     core type: Operation
#     operator: 79
#     operands: 27
# 22. B* = B
#     core type: Operation
#     operator: 79
#     operands: 28
# 23. ([A, B], 0(Complex^{n x n}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 24. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).)
#     core type: ExprTuple
#     sub-expressions: 31
# 25. (A, Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 83, 42
# 26. (B, Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 85, 42
# 27. (A*, A)
#     core type: ExprTuple
#     sub-expressions: 32, 83
# 28. (B*, B)
#     core type: ExprTuple
#     sub-expressions: 33, 85
# 29. [A, B]
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. 0(Complex^{n x n})
#     core type: Operation
#     operator: 36
#     operand: 42
# 31. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).
#     core type: Lambda
#     parameters: 56\n    body: 38
# 32. A*
#     core type: Operation
#     operator: 40
#     operand: 83
# 33. B*
#     core type: Operation
#     operator: 40
#     operand: 85
# 34. commutator
#     core type: Literal
#     sub-expressions:
# 35. (A, B)
#     core type: ExprTuple
#     sub-expressions: 83, 85
# 36. 0
#     core type: Literal
#     sub-expressions:
# 37. (Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 42
# 38. {exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))) if {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 43
#     condition: 44
# 39. (A)
#     core type: ExprTuple
#     sub-expressions: 83
# 40. Adj
#     core type: Literal
#     sub-expressions:
# 41. (B)
#     core type: ExprTuple
#     sub-expressions: 85
# 42. Complex^{n x n}
#     core type: Operation
#     operator: 45
#     operands: 46
# 43. exists_{a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n} in Complex} ((A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))))
#     core type: Operation
#     operator: 47
#     operand: 50
# 44. {v_{1}, v_{2}, ..., v_{n}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 109
#     operands: 49
# 45. MSpace
#     core type: Literal
#     sub-expressions:
# 46. {field:Complex, rows:n, columns:n}
#     core type: NamedExprs
#     field: 98
#     rows: 124
#     columns: 124
# 47. exists
#     core type: Literal
#     sub-expressions:
# 48. ((a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 50
# 49. ({v_{1}, v_{2}, ..., v_{n}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 50. (a_{1}, a_{2}, ..., a_{n}, b_{1}, b_{2}, ..., b_{n}) -> {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Lambda
#     parameters: 53\n    body: 54
# 51. {v_{1}, v_{2}, ..., v_{n}}
#     core type: Operation
#     operator: 55
#     operands: 56
# 52. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 57
#     operand: 64
# 53. (a_{1}, a_{2}, ..., a_{n},b_{1}, b_{2}, ..., b_{n})
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 54. {(A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) ,  (a_{2} in Complex) ,  ... ,  (a_{n} in Complex), (b_{1} in Complex) ,  (b_{2} in Complex) ,  ... ,  (b_{n} in Complex).
#     core type: Conditional
#     value: 61
#     condition: 62
# 55. Set
#     core type: Literal
#     sub-expressions:
# 56. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 63
# 57. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 58. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 64
# 59. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 65
#     start_index: 123
#     end_index: 124
# 60. b_{1}, b_{2}, ..., b_{n}
#     core type: ExprRange
#     lambda_map: 66
#     start_index: 123
#     end_index: 124
# 61. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) and  \\ (B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 68
#     operands: 67
# 62. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)and (b_{1} in Complex) and  (b_{2} in Complex) and  ... and  (b_{n} in Complex)
#     core type: Operation
#     operator: 68
#     operands: 69
# 63. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 123
#     end_index: 124
# 64. Complex^{n}
#     core type: Operation
#     operator: 71
#     operands: 72
# 65. _a -> a_{_a}
#     core type: Lambda
#     parameter: 105
#     body: 96
# 66. _a -> b_{_a}
#     core type: Lambda
#     parameter: 105
#     body: 97
# 67. (A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 68. and
#     core type: Literal
#     sub-expressions:
# 69. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex),(b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 70. _a -> v_{_a}
#     core type: Lambda
#     parameter: 105
#     body: 77
# 71. CartExp
#     core type: Literal
#     sub-expressions:
# 72. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 98, 124
# 73. A = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 79
#     operands: 78
# 74. B = (Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 79
#     operands: 80
# 75. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 81
#     start_index: 123
#     end_index: 124
# 76. (b_{1} in Complex), (b_{2} in Complex), ..., (b_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 82
#     start_index: 123
#     end_index: 124
# 77. v_{_a}
#     core type: IndexedVar
# variable: 129
# index: 105
# 78. (A, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 79. =
#     core type: Literal
#     sub-expressions:
# 80. (B, Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 85, 86
# 81. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 105
#     body: 87
# 82. _a -> (b_{_a} in Complex)
#     core type: Lambda
#     parameter: 105
#     body: 88
# 83. A
#     core type: Variable
#     sub-expressions:
# 84. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 90
#     operand: 94
# 85. B
#     core type: Variable
#     sub-expressions:
# 86. Sum_{i=1}^{n} (b_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 90
#     operand: 95
# 87. a_{_a} in Complex
#     core type: Operation
#     operator: 109
#     operands: 92
# 88. b_{_a} in Complex
#     core type: Operation
#     operator: 109
#     operands: 93
# 89. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 94
# 90. Sum
#     core type: Literal
#     sub-expressions:
# 91. (i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 95
# 92. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 96, 98
# 93. (b_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 97, 98
# 94. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 131
#     body: 99
# 95. i -> {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 131
#     body: 100
# 96. a_{_a}
#     core type: IndexedVar
# variable: 115
# index: 105
# 97. b_{_a}
#     core type: IndexedVar
# variable: 116
# index: 105
# 98. Complex
#     core type: Literal
#     sub-expressions:
# 99. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 102
#     condition: 104
# 100. {b_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#      core type: Conditional
#      value: 103
#      condition: 104
# 101. (_a)
#      core type: ExprTuple
#      sub-expressions: 105
# 102. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#      core type: Operation
#      operator: 107
#      operands: 106
# 103. b_{i} * (|v_{i}〉 . 〈v_{i}|)
#      core type: Operation
#      operator: 107
#      operands: 108
# 104. i in {1 .. n}
#      core type: Operation
#      operator: 109
#      operands: 110
# 105. _a
#      core type: Variable
#      sub-expressions:
# 106. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 111, 113
# 107. *
#      core type: Literal
#      sub-expressions:
# 108. (b_{i}, |v_{i}〉 . 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 112, 113
# 109. in
#      core type: Literal
#      sub-expressions:
# 110. (i, {1 .. n})
#      core type: ExprTuple
#      sub-expressions: 131, 114
# 111. a_{i}
#      core type: IndexedVar
# variable: 115
# index: 131
# 112. b_{i}
#      core type: IndexedVar
# variable: 116
# index: 131
# 113. |v_{i}〉 . 〈v_{i}|
#      core type: Operation
#      operator: 117
#      operands: 118
# 114. {1 .. n}
#      core type: Operation
#      operator: 119
#      operands: 120
# 115. a
#      core type: Variable
#      sub-expressions:
# 116. b
#      core type: Variable
#      sub-expressions:
# 117. .
#      core type: Literal
#      sub-expressions:
# 118. (|v_{i}〉, 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 121, 122
# 119. Interval
#      core type: Literal
#      sub-expressions:
# 120. (1, n)
#      core type: ExprTuple
#      sub-expressions: 123, 124
# 121. |v_{i}〉
#      core type: Operation
#      operator: 125
#      operand: 128
# 122. 〈v_{i}|
#      core type: Operation
#      operator: 126
#      operand: 128
# 123. 1
#      core type: Literal
#      sub-expressions:
# 124. n
#      core type: Variable
#      sub-expressions:
# 125. KET
#      core type: Literal
#      sub-expressions:
# 126. BRA
#      core type: Literal
#      sub-expressions:
# 127. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 128
# 128. v_{i}
#      core type: IndexedVar
# variable: 129
# index: 131
# 129. v
#      core type: Variable
#      sub-expressions:
# 130. (i)
#      core type: ExprTuple
#      sub-expressions: 131
# 131. i
#      core type: Variable
#      sub-expressions:
