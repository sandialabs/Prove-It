# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, V, W, i, j, m, n
from proveit.core_expr_types import v_1_to_m, v_i, w_1_to_n, w_j
from proveit.linear_algebra import LinMap, OrthoNormBases, VecSum
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_m_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [A], instance_expr = Forall(instance_param_or_params = [m, n], instance_expr = Forall(instance_param_or_params = [v_1_to_m], instance_expr = Forall(instance_param_or_params = [w_1_to_n], instance_expr = Equals(A, VecSum(index_or_indices = [i], summand = VecSum(index_or_indices = [j], summand = Qmult(Bra(w_j), A, Ket(v_i), Ket(w_j), Bra(v_i)), domain = Interval(one, n)), domain = Interval(one, m))), condition = InSet(w_1_to_n_kets, OrthoNormBases(W))).with_wrapping(), condition = InSet(v_1_to_m_kets, OrthoNormBases(V))).with_wrapping(), domain = NaturalPos), domain = LinMap(V, W))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{A \in \mathcal{L}\left(V, W\right)}~\left[\forall_{m, n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{v_{1}, v_{2}, \ldots, v_{m}~|~\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{m} \rangle\right\} \in \textrm{O.N.Bases}\left(V\right)}~\\
# \left[\begin{array}{l}\forall_{w_{1}, w_{2}, \ldots, w_{n}~|~\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(W\right)}~\\
# \left(A = \left(\sum_{i=1}^{m} \left(\sum_{j=1}^{n} \left(\langle w_{j} \rvert \thinspace A \thinspace \lvert v_{i} \rangle \thinspace \lvert w_{j} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}\right]\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{A in LINMAP(V, W)} [forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]]]
#    core type: Operation
#    operator: 32
#    operand: 2
# 1. (A -> {forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]] if A in LINMAP(V, W).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. A -> {forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]] if A in LINMAP(V, W).
#    core type: Lambda
#    parameter: 90
#    body: 4
# 3. (A)
#    core type: ExprTuple
#    sub-expressions: 90
# 4. {forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]] if A in LINMAP(V, W).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{m, n in NaturalPos} [forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]]
#    core type: Operation
#    operator: 32
#    operand: 9
# 6. A in LINMAP(V, W)
#    core type: Operation
#    operator: 87
#    operands: 8
# 7. ((m, n) -> {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (A, LINMAP(V, W))
#    core type: ExprTuple
#    sub-expressions: 90, 10
# 9. (m, n) -> {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. LINMAP(V, W)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. (m, n)
#     core type: ExprTuple
#     sub-expressions: 83, 104
# 12. {forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))] if m in NaturalPos ,  n in NaturalPos.
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. LINMAP
#     core type: Literal
#     sub-expressions:
# 14. (V, W)
#     core type: ExprTuple
#     sub-expressions: 46, 64
# 15. forall_{v_{1}, v_{2}, ..., v_{m} | {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)} [forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))]
#     core type: Operation
#     operator: 32
#     operand: 20
# 16. (m in NaturalPos) and (n in NaturalPos)
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. ((v_{1}, v_{2}, ..., v_{m}) -> {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. (m in NaturalPos, n in NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. (v_{1}, v_{2}, ..., v_{m}) -> {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).
#     core type: Lambda
#     parameters: 23\n    body: 24
# 21. m in NaturalPos
#     core type: Operation
#     operator: 87
#     operands: 25
# 22. n in NaturalPos
#     core type: Operation
#     operator: 87
#     operands: 26
# 23. (v_{1}, v_{2}, ..., v_{m})
#     core type: ExprTuple
#     sub-expressions: 27
# 24. {forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))) if {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V).
#     core type: Conditional
#     value: 28
#     condition: 29
# 25. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 83, 30
# 26. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 104, 30
# 27. v_{1}, v_{2}, ..., v_{m}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 103
#     end_index: 83
# 28. forall_{w_{1}, w_{2}, ..., w_{n} | {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)} (A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 32
#     operand: 35
# 29. {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉} in O.N.Bases(V)
#     core type: Operation
#     operator: 87
#     operands: 34
# 30. NaturalPos
#     core type: Literal
#     sub-expressions:
# 31. _a -> v_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 65
# 32. forall
#     core type: Literal
#     sub-expressions:
# 33. ((w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).)
#     core type: ExprTuple
#     sub-expressions: 35
# 34. ({|v_{1}〉, |v_{2}〉, ..., |v_{m}〉}, O.N.Bases(V))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 35. (w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#     core type: Lambda
#     parameters: 38\n    body: 39
# 36. {|v_{1}〉, |v_{2}〉, ..., |v_{m}〉}
#     core type: Operation
#     operator: 57
#     operands: 40
# 37. O.N.Bases(V)
#     core type: Operation
#     operator: 59
#     operand: 46
# 38. (w_{1}, w_{2}, ..., w_{n})
#     core type: ExprTuple
#     sub-expressions: 42
# 39. {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#     core type: Conditional
#     value: 43
#     condition: 44
# 40. (|v_{1}〉, |v_{2}〉, ..., |v_{m}〉)
#     core type: ExprTuple
#     sub-expressions: 45
# 41. (V)
#     core type: ExprTuple
#     sub-expressions: 46
# 42. w_{1}, w_{2}, ..., w_{n}
#     core type: ExprRange
#     lambda_map: 47
#     start_index: 103
#     end_index: 104
# 43. A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 48
#     operands: 49
# 44. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)
#     core type: Operation
#     operator: 87
#     operands: 50
# 45. |v_{1}〉, |v_{2}〉, ..., |v_{m}〉
#     core type: ExprRange
#     lambda_map: 51
#     start_index: 103
#     end_index: 83
# 46. V
#     core type: Variable
#     sub-expressions:
# 47. _a -> w_{_a}
#     core type: Lambda
#     parameter: 84
#     body: 77
# 48. =
#     core type: Literal
#     sub-expressions:
# 49. (A, Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 90, 52
# 50. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}, O.N.Bases(W))
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 84
#     body: 55
# 52. Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 71
#     operand: 62
# 53. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 57
#     operands: 58
# 54. O.N.Bases(W)
#     core type: Operation
#     operator: 59
#     operand: 64
# 55. |v_{_a}〉
#     core type: Operation
#     operator: 95
#     operand: 65
# 56. (i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 62
# 57. Set
#     core type: Literal
#     sub-expressions:
# 58. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 63
# 59. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 60. (W)
#     core type: ExprTuple
#     sub-expressions: 64
# 61. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 65
# 62. i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Lambda
#     parameter: 110
#     body: 66
# 63. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 67
#     start_index: 103
#     end_index: 104
# 64. W
#     core type: Variable
#     sub-expressions:
# 65. v_{_a}
#     core type: IndexedVar
# variable: 107
# index: 84
# 66. {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Conditional
#     value: 68
#     condition: 69
# 67. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 84
#     body: 70
# 68. Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 71
#     operand: 75
# 69. i in {1 .. m}
#     core type: Operation
#     operator: 87
#     operands: 73
# 70. |w_{_a}〉
#     core type: Operation
#     operator: 95
#     operand: 77
# 71. Sum
#     core type: Literal
#     sub-expressions:
# 72. (j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 75
# 73. (i, {1 .. m})
#     core type: ExprTuple
#     sub-expressions: 110, 76
# 74. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 77
# 75. j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Lambda
#     parameter: 109
#     body: 78
# 76. {1 .. m}
#     core type: Operation
#     operator: 99
#     operands: 79
# 77. w_{_a}
#     core type: IndexedVar
# variable: 105
# index: 84
# 78. {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Conditional
#     value: 81
#     condition: 82
# 79. (1, m)
#     core type: ExprTuple
#     sub-expressions: 103, 83
# 80. (_a)
#     core type: ExprTuple
#     sub-expressions: 84
# 81. 〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 85
#     operands: 86
# 82. j in {1 .. n}
#     core type: Operation
#     operator: 87
#     operands: 88
# 83. m
#     core type: Variable
#     sub-expressions:
# 84. _a
#     core type: Variable
#     sub-expressions:
# 85. .
#     core type: Literal
#     sub-expressions:
# 86. (〈w_{j}|, A, |v_{i}〉, |w_{j}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 89, 90, 91, 92, 93
# 87. in
#     core type: Literal
#     sub-expressions:
# 88. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 109, 94
# 89. 〈w_{j}|
#     core type: Operation
#     operator: 97
#     operand: 101
# 90. A
#     core type: Variable
#     sub-expressions:
# 91. |v_{i}〉
#     core type: Operation
#     operator: 95
#     operand: 102
# 92. |w_{j}〉
#     core type: Operation
#     operator: 95
#     operand: 101
# 93. 〈v_{i}|
#     core type: Operation
#     operator: 97
#     operand: 102
# 94. {1 .. n}
#     core type: Operation
#     operator: 99
#     operands: 100
# 95. KET
#     core type: Literal
#     sub-expressions:
# 96. (w_{j})
#     core type: ExprTuple
#     sub-expressions: 101
# 97. BRA
#     core type: Literal
#     sub-expressions:
# 98. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 102
# 99. Interval
#     core type: Literal
#     sub-expressions:
# 100. (1, n)
#      core type: ExprTuple
#      sub-expressions: 103, 104
# 101. w_{j}
#      core type: IndexedVar
# variable: 105
# index: 109
# 102. v_{i}
#      core type: IndexedVar
# variable: 107
# index: 110
# 103. 1
#      core type: Literal
#      sub-expressions:
# 104. n
#      core type: Variable
#      sub-expressions:
# 105. w
#      core type: Variable
#      sub-expressions:
# 106. (j)
#      core type: ExprTuple
#      sub-expressions: 109
# 107. v
#      core type: Variable
#      sub-expressions:
# 108. (i)
#      core type: ExprTuple
#      sub-expressions: 110
# 109. j
#      core type: Variable
#      sub-expressions:
# 110. i
#      core type: Variable
#      sub-expressions:
