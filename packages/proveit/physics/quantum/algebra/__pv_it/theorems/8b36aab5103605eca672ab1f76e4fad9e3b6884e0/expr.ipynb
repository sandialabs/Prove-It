# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, U, i, n
from proveit.core_expr_types import v_1_to_n, v_i, w_1_to_n, w_i
from proveit.linear_algebra import OrthoNormBases, Unitary, VecSum
from proveit.logic import CartExp, Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = OrthoNormBases(CartExp(Complex, n))
expr = ExprTuple(Lambda(U, Conditional(Exists(instance_param_or_params = [v_1_to_n, w_1_to_n], instance_expr = Equals(U, VecSum(index_or_indices = [i], summand = Qmult(Ket(v_i), Bra(w_i)), domain = Interval(one, n))), conditions = [InSet(Set(v_1_to_n_kets), sub_expr1), InSet(Set(w_1_to_n_kets), sub_expr1)]).with_wrapping(), InSet(U, Unitary(n)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(U \mapsto \left\{\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}, w_{1}, w_{2}, \ldots, w_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right), \left\{\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left(U = \left(\sum_{i=1}^{n} \left(\lvert v_{i} \rangle \thinspace \langle w_{i} \rvert\right)\right)\right)\end{array} \textrm{ if } U \in \textrm{U}\left(n\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (U -> {exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))) if U in U(n).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. U -> {exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))) if U in U(n).
#    core type: Lambda
#    parameter: 25
#    body: 3
# 2. (U)
#    core type: ExprTuple
#    sub-expressions: 25
# 3. {exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))) if U in U(n).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. U in U(n)
#    core type: Operation
#    operator: 49
#    operands: 8
# 6. exists
#    core type: Literal
#    sub-expressions:
# 7. ((v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (U, U(n))
#    core type: ExprTuple
#    sub-expressions: 25, 10
# 9. (v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. U(n)
#     core type: Operation
#     operator: 13
#     operand: 72
# 11. (v_{1}, v_{2}, ..., v_{n},w_{1}, w_{2}, ..., w_{n})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 17
#     condition: 18
# 13. U
#     core type: Literal
#     sub-expressions:
# 14. (n)
#     core type: ExprTuple
#     sub-expressions: 72
# 15. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 71
#     end_index: 72
# 16. w_{1}, w_{2}, ..., w_{n}
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 71
#     end_index: 72
# 17. U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})) and ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. _a -> v_{_a}
#     core type: Lambda
#     parameter: 85
#     body: 80
# 20. _a -> w_{_a}
#     core type: Lambda
#     parameter: 85
#     body: 81
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (U, Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. U
#     core type: Variable
#     sub-expressions:
# 26. Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)
#     core type: Operation
#     operator: 29
#     operand: 33
# 27. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 49
#     operands: 31
# 28. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 49
#     operands: 32
# 29. Sum
#     core type: Literal
#     sub-expressions:
# 30. (i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 33
# 31. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 34, 36
# 32. ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 79
#     body: 37
# 34. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 52
#     operand: 44
# 35. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}
#     core type: Operation
#     operator: 52
#     operand: 45
# 36. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 40
#     operand: 46
# 37. {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 42
#     condition: 43
# 38. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 44
# 39. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 45
# 40. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 41. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 46
# 42. |v_{i}〉 . 〈w_{i}|
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. i in {1 .. n}
#     core type: Operation
#     operator: 49
#     operands: 50
# 44. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 52
#     operands: 51
# 45. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 52
#     operands: 53
# 46. Complex^{n}
#     core type: Operation
#     operator: 54
#     operands: 55
# 47. .
#     core type: Literal
#     sub-expressions:
# 48. (|v_{i}〉, 〈w_{i}|)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 79, 58
# 51. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 59
# 52. Set
#     core type: Literal
#     sub-expressions:
# 53. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 60
# 54. CartExp
#     core type: Literal
#     sub-expressions:
# 55. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 61, 72
# 56. |v_{i}〉
#     core type: Operation
#     operator: 77
#     operand: 69
# 57. 〈w_{i}|
#     core type: Operation
#     operator: 63
#     operand: 70
# 58. {1 .. n}
#     core type: Operation
#     operator: 65
#     operands: 66
# 59. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 67
#     start_index: 71
#     end_index: 72
# 60. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 68
#     start_index: 71
#     end_index: 72
# 61. Complex
#     core type: Literal
#     sub-expressions:
# 62. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 69
# 63. BRA
#     core type: Literal
#     sub-expressions:
# 64. (w_{i})
#     core type: ExprTuple
#     sub-expressions: 70
# 65. Interval
#     core type: Literal
#     sub-expressions:
# 66. (1, n)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 67. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 85
#     body: 73
# 68. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 85
#     body: 74
# 69. v_{i}
#     core type: IndexedVar
# variable: 82
# index: 79
# 70. w_{i}
#     core type: IndexedVar
# variable: 83
# index: 79
# 71. 1
#     core type: Literal
#     sub-expressions:
# 72. n
#     core type: Variable
#     sub-expressions:
# 73. |v_{_a}〉
#     core type: Operation
#     operator: 77
#     operand: 80
# 74. |w_{_a}〉
#     core type: Operation
#     operator: 77
#     operand: 81
# 75. (i)
#     core type: ExprTuple
#     sub-expressions: 79
# 76. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 80
# 77. KET
#     core type: Literal
#     sub-expressions:
# 78. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 81
# 79. i
#     core type: Variable
#     sub-expressions:
# 80. v_{_a}
#     core type: IndexedVar
# variable: 82
# index: 85
# 81. w_{_a}
#     core type: IndexedVar
# variable: 83
# index: 85
# 82. v
#     core type: Variable
#     sub-expressions:
# 83. w
#     core type: Variable
#     sub-expressions:
# 84. (_a)
#     core type: ExprTuple
#     sub-expressions: 85
# 85. _a
#     core type: Variable
#     sub-expressions:
