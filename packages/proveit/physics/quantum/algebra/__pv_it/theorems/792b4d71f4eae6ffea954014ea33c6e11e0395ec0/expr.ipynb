# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Function, f, i, n
from proveit.core_expr_types import a_1_to_n, a_i, v_i
from proveit.linear_algebra import Hspace, OrthoNormBases, ScalarMult, VecSum
from proveit.logic import Equals, Forall, Functions, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Interval(one, n)
sub_expr3 = Qmult(Ket(v_i), Bra(v_i))
expr = Conditional(Forall(instance_param_or_params = [a_1_to_n], instance_expr = Forall(instance_param_or_params = [f], instance_expr = Equals(Function(f, [VecSum(index_or_indices = sub_expr1, summand = ScalarMult(a_i, sub_expr3), domain = sub_expr2)]), VecSum(index_or_indices = sub_expr1, summand = ScalarMult(Function(f, [a_i]), sub_expr3), domain = sub_expr2)), domain = Functions(Complex, Complex)), domain = Complex), InSet(Set(v_1_to_n_kets), OrthoNormBases(Hspace)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\forall_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\left[\forall_{f \in \left[\mathbb{C} \rightarrow \mathbb{C}\right]}~\left(f\left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right) = \left(\sum_{i=1}^{n} \left(f\left(a_{i}\right) \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\right] \textrm{ if } \left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))] if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, a_{2}, ..., a_{n} in Complex} [forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))]
#    core type: Operation
#    operator: 19
#    operand: 5
# 2. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)
#    core type: Operation
#    operator: 67
#    operands: 4
# 3. ((a_{1}, a_{2}, ..., a_{n}) -> {forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(H))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (a_{1}, a_{2}, ..., a_{n}) -> {forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#    core type: Lambda
#    parameters: 8\n   body: 9
# 6. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#    core type: Operation
#    operator: 23
#    operand: 16
# 7. O.N.Bases(H)
#    core type: Operation
#    operator: 11
#    operand: 17
# 8. (a_{1}, a_{2}, ..., a_{n})
#    core type: ExprTuple
#    sub-expressions: 13
# 9. {forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#    core type: Conditional
#    value: 14
#    condition: 15
# 10. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 16
# 11. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 12. (H)
#     core type: ExprTuple
#     sub-expressions: 17
# 13. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 81
#     end_index: 82
# 14. forall_{f in [Complex -> Complex]} (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 19
#     operand: 25
# 15. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 23
#     operands: 24
# 17. H
#     core type: Variable
#     sub-expressions:
# 18. _a -> a_{_a}
#     core type: Lambda
#     parameter: 54
#     body: 44
# 19. forall
#     core type: Literal
#     sub-expressions:
# 20. (f -> {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].)
#     core type: ExprTuple
#     sub-expressions: 25
# 21. and
#     core type: Literal
#     sub-expressions:
# 22. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 26
# 23. Set
#     core type: Literal
#     sub-expressions:
# 24. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 27
# 25. f -> {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].
#     core type: Lambda
#     parameter: 69
#     body: 29
# 26. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 81
#     end_index: 82
# 27. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 81
#     end_index: 82
# 28. (f)
#     core type: ExprTuple
#     sub-expressions: 69
# 29. {f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))) if f in [Complex -> Complex].
#     core type: Conditional
#     value: 32
#     condition: 33
# 30. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 54
#     body: 34
# 31. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 54
#     body: 35
# 32. f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) = (Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. f in [Complex -> Complex]
#     core type: Operation
#     operator: 67
#     operands: 38
# 34. a_{_a} in Complex
#     core type: Operation
#     operator: 67
#     operands: 39
# 35. |v_{_a}〉
#     core type: Operation
#     operator: 83
#     operand: 45
# 36. =
#     core type: Literal
#     sub-expressions:
# 37. (f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))), Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 38. (f, [Complex -> Complex])
#     core type: ExprTuple
#     sub-expressions: 69, 43
# 39. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 44, 53
# 40. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 45
# 41. f(Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 69
#     operand: 51
# 42. Sum_{i=1}^{n} (f(a_{i}) * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 55
#     operand: 52
# 43. [Complex -> Complex]
#     core type: Operation
#     operator: 48
#     operands: 49
# 44. a_{_a}
#     core type: IndexedVar
# variable: 78
# index: 54
# 45. v_{_a}
#     core type: IndexedVar
# variable: 87
# index: 54
# 46. (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 51
# 47. (i -> {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 52
# 48. Functions
#     core type: Literal
#     sub-expressions:
# 49. (Complex, Complex)
#     core type: ExprTuple
#     sub-expressions: 53, 53
# 50. (_a)
#     core type: ExprTuple
#     sub-expressions: 54
# 51. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 55
#     operand: 58
# 52. i -> {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 89
#     body: 57
# 53. Complex
#     core type: Literal
#     sub-expressions:
# 54. _a
#     core type: Variable
#     sub-expressions:
# 55. Sum
#     core type: Literal
#     sub-expressions:
# 56. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 58
# 57. {f(a_{i}) * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 59
#     condition: 63
# 58. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 89
#     body: 60
# 59. f(a_{i}) * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 65
#     operands: 61
# 60. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 62
#     condition: 63
# 61. (f(a_{i}), |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 64, 71
# 62. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 65
#     operands: 66
# 63. i in {1 .. n}
#     core type: Operation
#     operator: 67
#     operands: 68
# 64. f(a_{i})
#     core type: Operation
#     operator: 69
#     operand: 73
# 65. *
#     core type: Literal
#     sub-expressions:
# 66. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 73, 71
# 67. in
#     core type: Literal
#     sub-expressions:
# 68. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 89, 72
# 69. f
#     core type: Variable
#     sub-expressions:
# 70. (a_{i})
#     core type: ExprTuple
#     sub-expressions: 73
# 71. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 74
#     operands: 75
# 72. {1 .. n}
#     core type: Operation
#     operator: 76
#     operands: 77
# 73. a_{i}
#     core type: IndexedVar
# variable: 78
# index: 89
# 74. .
#     core type: Literal
#     sub-expressions:
# 75. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 76. Interval
#     core type: Literal
#     sub-expressions:
# 77. (1, n)
#     core type: ExprTuple
#     sub-expressions: 81, 82
# 78. a
#     core type: Variable
#     sub-expressions:
# 79. |v_{i}〉
#     core type: Operation
#     operator: 83
#     operand: 86
# 80. 〈v_{i}|
#     core type: Operation
#     operator: 84
#     operand: 86
# 81. 1
#     core type: Literal
#     sub-expressions:
# 82. n
#     core type: Variable
#     sub-expressions:
# 83. KET
#     core type: Literal
#     sub-expressions:
# 84. BRA
#     core type: Literal
#     sub-expressions:
# 85. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 86
# 86. v_{i}
#     core type: IndexedVar
# variable: 87
# index: 89
# 87. v
#     core type: Variable
#     sub-expressions:
# 88. (i)
#     core type: ExprTuple
#     sub-expressions: 89
# 89. i
#     core type: Variable
#     sub-expressions:
