# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, v_1_to_n, v_i
from proveit.linear_algebra import Hspace, OrthoNormBases, ScalarMult, VecSum
from proveit.logic import Equals, Exists, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([v_1_to_n], Conditional(Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, Qmult(Ket(v_i), Bra(v_i))), domain = Interval(one, n))), domain = Complex).with_wrapping(), InSet(Set(v_1_to_n_kets), OrthoNormBases(Hspace)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(v_{1}, v_{2}, \ldots, v_{n}\right) \mapsto \left\{\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array} \textrm{ if } \left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (v_{1}, v_{2}, ..., v_{n})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#    core type: Conditional
#    value: 5
#    condition: 6
# 4. v_{1}, v_{2}, ..., v_{n}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 66
#    end_index: 67
# 5. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))
#    core type: Operation
#    operator: 8
#    operand: 11
# 6. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)
#    core type: Operation
#    operator: 52
#    operands: 10
# 7. _a -> v_{_a}
#    core type: Lambda
#    parameter: 58
#    body: 49
# 8. exists
#    core type: Literal
#    sub-expressions:
# 9. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 14\n    body: 15
# 12. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 29
#     operand: 22
# 13. O.N.Bases(H)
#     core type: Operation
#     operator: 17
#     operand: 23
# 14. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 19
# 15. {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 20
#     condition: 21
# 16. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 22
# 17. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 18. (H)
#     core type: ExprTuple
#     sub-expressions: 23
# 19. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 66
#     end_index: 67
# 20. M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 27
#     operands: 28
# 22. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 29
#     operands: 30
# 23. H
#     core type: Variable
#     sub-expressions:
# 24. _a -> a_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 47
# 25. =
#     core type: Literal
#     sub-expressions:
# 26. (M, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 33
# 29. Set
#     core type: Literal
#     sub-expressions:
# 30. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 34
# 31. M
#     core type: Variable
#     sub-expressions:
# 32. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 35
#     operand: 39
# 33. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 37
#     start_index: 66
#     end_index: 67
# 34. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 66
#     end_index: 67
# 35. Sum
#     core type: Literal
#     sub-expressions:
# 36. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 39
# 37. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 58
#     body: 40
# 38. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 58
#     body: 41
# 39. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 74
#     body: 42
# 40. a_{_a} in Complex
#     core type: Operation
#     operator: 52
#     operands: 43
# 41. |v_{_a}〉
#     core type: Operation
#     operator: 68
#     operand: 49
# 42. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 45
#     condition: 46
# 43. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 44. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 49
# 45. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. i in {1 .. n}
#     core type: Operation
#     operator: 52
#     operands: 53
# 47. a_{_a}
#     core type: IndexedVar
# variable: 59
# index: 58
# 48. Complex
#     core type: Literal
#     sub-expressions:
# 49. v_{_a}
#     core type: IndexedVar
# variable: 72
# index: 58
# 50. *
#     core type: Literal
#     sub-expressions:
# 51. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 74, 57
# 54. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 55. a_{i}
#     core type: IndexedVar
# variable: 59
# index: 74
# 56. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 60
#     operands: 61
# 57. {1 .. n}
#     core type: Operation
#     operator: 62
#     operands: 63
# 58. _a
#     core type: Variable
#     sub-expressions:
# 59. a
#     core type: Variable
#     sub-expressions:
# 60. .
#     core type: Literal
#     sub-expressions:
# 61. (|v_{i}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 62. Interval
#     core type: Literal
#     sub-expressions:
# 63. (1, n)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 64. |v_{i}〉
#     core type: Operation
#     operator: 68
#     operand: 71
# 65. 〈v_{i}|
#     core type: Operation
#     operator: 69
#     operand: 71
# 66. 1
#     core type: Literal
#     sub-expressions:
# 67. n
#     core type: Variable
#     sub-expressions:
# 68. KET
#     core type: Literal
#     sub-expressions:
# 69. BRA
#     core type: Literal
#     sub-expressions:
# 70. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 71
# 71. v_{i}
#     core type: IndexedVar
# variable: 72
# index: 74
# 72. v
#     core type: Variable
#     sub-expressions:
# 73. (i)
#     core type: ExprTuple
#     sub-expressions: 74
# 74. i
#     core type: Variable
#     sub-expressions:
