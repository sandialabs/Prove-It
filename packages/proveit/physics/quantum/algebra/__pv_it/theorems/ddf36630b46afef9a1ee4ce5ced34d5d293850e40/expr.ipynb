# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, X, i, n
from proveit.core_expr_types import x_1_to_n, x_i
from proveit.linear_algebra import Hspace, OrthoNormBases, OrthoProj, VecSum
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import x_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(OrthoProj(Hspace, X), VecSum(index_or_indices = [i], summand = Qmult(Ket(x_i), Bra(x_i)), domain = Interval(one, n))), condition = InSet(x_1_to_n_kets, OrthoNormBases(Hspace))).with_wrapping(), InSet(n, NaturalPos)))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# n \mapsto \left\{\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{\lvert x_{1} \rangle, \lvert x_{2} \rangle, \ldots, \lvert x_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left(\textrm{OrthoProj}\left(\mathcal{H}, X\right) = \left(\sum_{i=1}^{n} \left(\lvert x_{i} \rangle \thinspace \langle x_{i} \rvert\right)\right)\right)\end{array} \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#    core type: Lambda
#    parameter: 57
#    body: 2
# 1. (n)
#    core type: ExprTuple
#    sub-expressions: 57
# 2. {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} (OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. n in NaturalPos
#    core type: Operation
#    operator: 42
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 57, 9
# 8. (x_{1}, x_{2}, ..., x_{n}) -> {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#    core type: Lambda
#    parameters: 10\n   body: 11
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 12
# 11. {OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Conditional
#     value: 13
#     condition: 14
# 12. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 56
#     end_index: 57
# 13. OrthoProj(H, X) = (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)
#     core type: Operation
#     operator: 42
#     operands: 18
# 15. _a -> x_{_a}
#     core type: Lambda
#     parameter: 58
#     body: 48
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (OrthoProj(H, X), Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. ({|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. OrthoProj(H, X)
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)
#     core type: Operation
#     operator: 25
#     operand: 32
# 21. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}
#     core type: Operation
#     operator: 27
#     operands: 28
# 22. O.N.Bases(H)
#     core type: Operation
#     operator: 29
#     operand: 34
# 23. OrthoProj
#     core type: Literal
#     sub-expressions:
# 24. (H, X)
#     core type: ExprTuple
#     sub-expressions: 34, 31
# 25. Sum
#     core type: Literal
#     sub-expressions:
# 26. (i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 32
# 27. Set
#     core type: Literal
#     sub-expressions:
# 28. (|x_{1}〉, |x_{2}〉, ..., |x_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 33
# 29. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 30. (H)
#     core type: ExprTuple
#     sub-expressions: 34
# 31. X
#     core type: Variable
#     sub-expressions:
# 32. i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 61
#     body: 35
# 33. |x_{1}〉, |x_{2}〉, ..., |x_{n}〉
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 56
#     end_index: 57
# 34. H
#     core type: Variable
#     sub-expressions:
# 35. {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 37
#     condition: 38
# 36. _a -> |x_{_a}〉
#     core type: Lambda
#     parameter: 58
#     body: 39
# 37. |x_{i}〉 . 〈x_{i}|
#     core type: Operation
#     operator: 40
#     operands: 41
# 38. i in {1 .. n}
#     core type: Operation
#     operator: 42
#     operands: 43
# 39. |x_{_a}〉
#     core type: Operation
#     operator: 49
#     operand: 48
# 40. .
#     core type: Literal
#     sub-expressions:
# 41. (|x_{i}〉, 〈x_{i}|)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 42. in
#     core type: Literal
#     sub-expressions:
# 43. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 61, 47
# 44. (x_{_a})
#     core type: ExprTuple
#     sub-expressions: 48
# 45. |x_{i}〉
#     core type: Operation
#     operator: 49
#     operand: 55
# 46. 〈x_{i}|
#     core type: Operation
#     operator: 50
#     operand: 55
# 47. {1 .. n}
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. x_{_a}
#     core type: IndexedVar
# variable: 59
# index: 58
# 49. KET
#     core type: Literal
#     sub-expressions:
# 50. BRA
#     core type: Literal
#     sub-expressions:
# 51. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 55
# 52. Interval
#     core type: Literal
#     sub-expressions:
# 53. (1, n)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 54. (_a)
#     core type: ExprTuple
#     sub-expressions: 58
# 55. x_{i}
#     core type: IndexedVar
# variable: 59
# index: 61
# 56. 1
#     core type: Literal
#     sub-expressions:
# 57. n
#     core type: Variable
#     sub-expressions:
# 58. _a
#     core type: Variable
#     sub-expressions:
# 59. x
#     core type: Variable
#     sub-expressions:
# 60. (i)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. i
#     core type: Variable
#     sub-expressions:
