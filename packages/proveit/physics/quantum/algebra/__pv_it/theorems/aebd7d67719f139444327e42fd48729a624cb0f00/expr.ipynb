# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import U, i, j, n
from proveit.core_expr_types import v_1_to_n, v_i, v_j
from proveit.linear_algebra import Adj, MatrixSpace, OrthoNormBases, Unitary
from proveit.logic import CartExp, Equals, Forall, Implies, InSet, Set
from proveit.numbers import Complex, Interval, KroneckerDelta, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [U], instance_expr = Forall(instance_param_or_params = [v_1_to_n], instance_expr = Implies(Forall(instance_param_or_params = [i, j], instance_expr = Equals(Qmult(Bra(v_i), Adj(U), U, Ket(v_j)), KroneckerDelta(i, j)), domain = Interval(one, n)), InSet(U, Unitary(n))), condition = InSet(Set(v_1_to_n_kets), OrthoNormBases(CartExp(Complex, n)))).with_wrapping(), domain = MatrixSpace(field = Complex, rows = n, columns = n)), domain = NaturalPos)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{U \in \mathbb{C}^{n \times n}}~\left[\begin{array}{l}\forall_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left(\left[\forall_{i, j \in \{1~\ldotp \ldotp~n\}}~\left(\left(\langle v_{i} \rvert \thinspace U^{\dagger} \thinspace U \thinspace \lvert v_{j} \rangle\right) = \delta_{i, j}\right)\right] \Rightarrow \left(U \in \textrm{U}\left(n\right)\right)\right)\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{U in Complex^{n x n}} [forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)))]]
#    core type: Operation
#    operator: 32
#    operand: 2
# 1. (n -> {forall_{U in Complex^{n x n}} [forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)))] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{U in Complex^{n x n}} [forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)))] if n in NaturalPos.
#    core type: Lambda
#    parameter: 89
#    body: 3
# 3. {forall_{U in Complex^{n x n}} [forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)))] if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{U in Complex^{n x n}} [forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)))]
#    core type: Operation
#    operator: 32
#    operand: 8
# 5. n in NaturalPos
#    core type: Operation
#    operator: 68
#    operands: 7
# 6. (U -> {forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n))) if U in Complex^{n x n}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 89, 9
# 8. U -> {forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n))) if U in Complex^{n x n}.
#    core type: Lambda
#    parameter: 86
#    body: 10
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. {forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n))) if U in Complex^{n x n}.
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. forall_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})} ([forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)))
#     core type: Operation
#     operator: 32
#     operand: 15
# 12. U in Complex^{n x n}
#     core type: Operation
#     operator: 68
#     operands: 14
# 13. ((v_{1}, v_{2}, ..., v_{n}) -> {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. (U, Complex^{n x n})
#     core type: ExprTuple
#     sub-expressions: 86, 16
# 15. (v_{1}, v_{2}, ..., v_{n}) -> {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Lambda
#     parameters: 17\n    body: 18
# 16. Complex^{n x n}
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 21
# 18. {[forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 22
#     condition: 23
# 19. MSpace
#     core type: Literal
#     sub-expressions:
# 20. {field:Complex, rows:n, columns:n}
#     core type: NamedExprs
#     field: 52
#     rows: 89
#     columns: 89
# 21. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 88
#     end_index: 89
# 22. [forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})] => (U in U(n))
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 68
#     operands: 27
# 24. _a -> v_{_a}
#     core type: Lambda
#     parameter: 90
#     body: 75
# 25. =>
#     core type: Literal
#     sub-expressions:
# 26. (forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j}), U in U(n))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. forall_{i, j in {1 .. n}} ((〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j})
#     core type: Operation
#     operator: 32
#     operand: 38
# 29. U in U(n)
#     core type: Operation
#     operator: 68
#     operands: 34
# 30. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 45
#     operand: 40
# 31. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 36
#     operand: 41
# 32. forall
#     core type: Literal
#     sub-expressions:
# 33. ((i, j) -> {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 38
# 34. (U, U(n))
#     core type: ExprTuple
#     sub-expressions: 86, 39
# 35. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 40
# 36. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 37. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 41
# 38. (i, j) -> {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.
#     core type: Lambda
#     parameters: 66\n    body: 42
# 39. U(n)
#     core type: Operation
#     operator: 43
#     operand: 89
# 40. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 45
#     operands: 46
# 41. Complex^{n}
#     core type: Operation
#     operator: 47
#     operands: 48
# 42. {(〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j} if i in {1 .. n} ,  j in {1 .. n}.
#     core type: Conditional
#     value: 49
#     condition: 50
# 43. U
#     core type: Literal
#     sub-expressions:
# 44. (n)
#     core type: ExprTuple
#     sub-expressions: 89
# 45. Set
#     core type: Literal
#     sub-expressions:
# 46. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 51
# 47. CartExp
#     core type: Literal
#     sub-expressions:
# 48. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 52, 89
# 49. (〈v_{i}| . U* . U . |v_{j}〉) = delta_{i, j}
#     core type: Operation
#     operator: 53
#     operands: 54
# 50. (i in {1 .. n}) and (j in {1 .. n})
#     core type: Operation
#     operator: 55
#     operands: 56
# 51. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 57
#     start_index: 88
#     end_index: 89
# 52. Complex
#     core type: Literal
#     sub-expressions:
# 53. =
#     core type: Literal
#     sub-expressions:
# 54. (〈v_{i}| . U* . U . |v_{j}〉, delta_{i, j})
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 55. and
#     core type: Literal
#     sub-expressions:
# 56. (i in {1 .. n}, j in {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 57. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 90
#     body: 62
# 58. 〈v_{i}| . U* . U . |v_{j}〉
#     core type: Operation
#     operator: 63
#     operands: 64
# 59. delta_{i, j}
#     core type: Operation
#     operator: 65
#     operands: 66
# 60. i in {1 .. n}
#     core type: Operation
#     operator: 68
#     operands: 67
# 61. j in {1 .. n}
#     core type: Operation
#     operator: 68
#     operands: 69
# 62. |v_{_a}〉
#     core type: Operation
#     operator: 80
#     operand: 75
# 63. .
#     core type: Literal
#     sub-expressions:
# 64. (〈v_{i}|, U*, U, |v_{j}〉)
#     core type: ExprTuple
#     sub-expressions: 71, 72, 86, 73
# 65. Kdelta
#     core type: Literal
#     sub-expressions:
# 66. (i, j)
#     core type: ExprTuple
#     sub-expressions: 94, 95
# 67. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 94, 74
# 68. in
#     core type: Literal
#     sub-expressions:
# 69. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 95, 74
# 70. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 75
# 71. 〈v_{i}|
#     core type: Operation
#     operator: 76
#     operand: 85
# 72. U*
#     core type: Operation
#     operator: 78
#     operand: 86
# 73. |v_{j}〉
#     core type: Operation
#     operator: 80
#     operand: 87
# 74. {1 .. n}
#     core type: Operation
#     operator: 82
#     operands: 83
# 75. v_{_a}
#     core type: IndexedVar
# variable: 92
# index: 90
# 76. BRA
#     core type: Literal
#     sub-expressions:
# 77. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 85
# 78. Adj
#     core type: Literal
#     sub-expressions:
# 79. (U)
#     core type: ExprTuple
#     sub-expressions: 86
# 80. KET
#     core type: Literal
#     sub-expressions:
# 81. (v_{j})
#     core type: ExprTuple
#     sub-expressions: 87
# 82. Interval
#     core type: Literal
#     sub-expressions:
# 83. (1, n)
#     core type: ExprTuple
#     sub-expressions: 88, 89
# 84. (_a)
#     core type: ExprTuple
#     sub-expressions: 90
# 85. v_{i}
#     core type: IndexedVar
# variable: 92
# index: 94
# 86. U
#     core type: Variable
#     sub-expressions:
# 87. v_{j}
#     core type: IndexedVar
# variable: 92
# index: 95
# 88. 1
#     core type: Literal
#     sub-expressions:
# 89. n
#     core type: Variable
#     sub-expressions:
# 90. _a
#     core type: Variable
#     sub-expressions:
# 91. (i)
#     core type: ExprTuple
#     sub-expressions: 94
# 92. v
#     core type: Variable
#     sub-expressions:
# 93. (j)
#     core type: ExprTuple
#     sub-expressions: 95
# 94. i
#     core type: Variable
#     sub-expressions:
# 95. j
#     core type: Variable
#     sub-expressions:
