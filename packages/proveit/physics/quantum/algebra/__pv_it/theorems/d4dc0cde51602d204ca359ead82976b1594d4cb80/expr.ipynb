# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import U, i, n
from proveit.core_expr_types import v_1_to_n, v_i, w_1_to_n, w_i
from proveit.linear_algebra import OrthoNormBases, Unitary, VecSum
from proveit.logic import CartExp, Equals, Exists, Forall, InSet, Set
from proveit.numbers import Complex, Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets, w_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = OrthoNormBases(CartExp(Complex, n))
expr = Forall(instance_param_or_params = [U], instance_expr = Exists(instance_param_or_params = [v_1_to_n, w_1_to_n], instance_expr = Equals(U, VecSum(index_or_indices = [i], summand = Qmult(Ket(v_i), Bra(w_i)), domain = Interval(one, n))), conditions = [InSet(Set(v_1_to_n_kets), sub_expr1), InSet(Set(w_1_to_n_kets), sub_expr1)]).with_wrapping(), domain = Unitary(n))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{U \in \textrm{U}\left(n\right)}~\left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}, w_{1}, w_{2}, \ldots, w_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right), \left\{\left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathbb{C}^{n}\right)}~\\
# \left(U = \left(\sum_{i=1}^{n} \left(\lvert v_{i} \rangle \thinspace \langle w_{i} \rvert\right)\right)\right)\end{array}\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{U in U(n)} [exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)))]
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (U -> {exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))) if U in U(n).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. U -> {exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))) if U in U(n).
#    core type: Lambda
#    parameter: 27
#    body: 5
# 4. (U)
#    core type: ExprTuple
#    sub-expressions: 27
# 5. {exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))) if U in U(n).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. exists_{v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})} (U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)))
#    core type: Operation
#    operator: 8
#    operand: 11
# 7. U in U(n)
#    core type: Operation
#    operator: 51
#    operands: 10
# 8. exists
#    core type: Literal
#    sub-expressions:
# 9. ((v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (U, U(n))
#     core type: ExprTuple
#     sub-expressions: 27, 12
# 11. (v_{1}, v_{2}, ..., v_{n}, w_{1}, w_{2}, ..., w_{n}) -> {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Lambda
#     parameters: 13\n    body: 14
# 12. U(n)
#     core type: Operation
#     operator: 15
#     operand: 74
# 13. (v_{1}, v_{2}, ..., v_{n},w_{1}, w_{2}, ..., w_{n})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. {U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}) ,  {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}).
#     core type: Conditional
#     value: 19
#     condition: 20
# 15. U
#     core type: Literal
#     sub-expressions:
# 16. (n)
#     core type: ExprTuple
#     sub-expressions: 74
# 17. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 73
#     end_index: 74
# 18. w_{1}, w_{2}, ..., w_{n}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 73
#     end_index: 74
# 19. U = (Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})) and ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. _a -> v_{_a}
#     core type: Lambda
#     parameter: 87
#     body: 82
# 22. _a -> w_{_a}
#     core type: Lambda
#     parameter: 87
#     body: 83
# 23. =
#     core type: Literal
#     sub-expressions:
# 24. (U, Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. and
#     core type: Literal
#     sub-expressions:
# 26. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n}), {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. U
#     core type: Variable
#     sub-expressions:
# 28. Sum_{i=1}^{n} (|v_{i}〉 . 〈w_{i}|)
#     core type: Operation
#     operator: 31
#     operand: 35
# 29. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 51
#     operands: 33
# 30. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}} in O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 51
#     operands: 34
# 31. Sum
#     core type: Literal
#     sub-expressions:
# 32. (i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 35
# 33. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 36, 38
# 34. ({{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}, O.N.Bases(Complex^{n}))
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. i -> {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 81
#     body: 39
# 36. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 54
#     operand: 46
# 37. {{|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}}
#     core type: Operation
#     operator: 54
#     operand: 47
# 38. O.N.Bases(Complex^{n})
#     core type: Operation
#     operator: 42
#     operand: 48
# 39. {|v_{i}〉 . 〈w_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 44
#     condition: 45
# 40. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 46
# 41. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 47
# 42. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 43. (Complex^{n})
#     core type: ExprTuple
#     sub-expressions: 48
# 44. |v_{i}〉 . 〈w_{i}|
#     core type: Operation
#     operator: 49
#     operands: 50
# 45. i in {1 .. n}
#     core type: Operation
#     operator: 51
#     operands: 52
# 46. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 54
#     operands: 53
# 47. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 54
#     operands: 55
# 48. Complex^{n}
#     core type: Operation
#     operator: 56
#     operands: 57
# 49. .
#     core type: Literal
#     sub-expressions:
# 50. (|v_{i}〉, 〈w_{i}|)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 81, 60
# 53. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 61
# 54. Set
#     core type: Literal
#     sub-expressions:
# 55. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 62
# 56. CartExp
#     core type: Literal
#     sub-expressions:
# 57. (Complex, n)
#     core type: ExprTuple
#     sub-expressions: 63, 74
# 58. |v_{i}〉
#     core type: Operation
#     operator: 79
#     operand: 71
# 59. 〈w_{i}|
#     core type: Operation
#     operator: 65
#     operand: 72
# 60. {1 .. n}
#     core type: Operation
#     operator: 67
#     operands: 68
# 61. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 69
#     start_index: 73
#     end_index: 74
# 62. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 70
#     start_index: 73
#     end_index: 74
# 63. Complex
#     core type: Literal
#     sub-expressions:
# 64. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 71
# 65. BRA
#     core type: Literal
#     sub-expressions:
# 66. (w_{i})
#     core type: ExprTuple
#     sub-expressions: 72
# 67. Interval
#     core type: Literal
#     sub-expressions:
# 68. (1, n)
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 69. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 87
#     body: 75
# 70. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 87
#     body: 76
# 71. v_{i}
#     core type: IndexedVar
# variable: 84
# index: 81
# 72. w_{i}
#     core type: IndexedVar
# variable: 85
# index: 81
# 73. 1
#     core type: Literal
#     sub-expressions:
# 74. n
#     core type: Variable
#     sub-expressions:
# 75. |v_{_a}〉
#     core type: Operation
#     operator: 79
#     operand: 82
# 76. |w_{_a}〉
#     core type: Operation
#     operator: 79
#     operand: 83
# 77. (i)
#     core type: ExprTuple
#     sub-expressions: 81
# 78. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 82
# 79. KET
#     core type: Literal
#     sub-expressions:
# 80. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 83
# 81. i
#     core type: Variable
#     sub-expressions:
# 82. v_{_a}
#     core type: IndexedVar
# variable: 84
# index: 87
# 83. w_{_a}
#     core type: IndexedVar
# variable: 85
# index: 87
# 84. v
#     core type: Variable
#     sub-expressions:
# 85. w
#     core type: Variable
#     sub-expressions:
# 86. (_a)
#     core type: ExprTuple
#     sub-expressions: 87
# 87. _a
#     core type: Variable
#     sub-expressions:
