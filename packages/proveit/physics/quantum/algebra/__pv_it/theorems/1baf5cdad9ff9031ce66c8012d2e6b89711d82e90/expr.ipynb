# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, n
from proveit.core_expr_types import x_1_to_n, x_i
from proveit.linear_algebra import HilbertSpaces, Hspace, Identity, OrthoNormBases, VecSum
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import x_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Forall(instance_param_or_params = [Hspace], instance_expr = Forall(instance_param_or_params = [n], instance_expr = Forall(instance_param_or_params = [x_1_to_n], instance_expr = Equals(VecSum(index_or_indices = [i], summand = Qmult(Ket(x_i), Bra(x_i)), domain = Interval(one, n)), Identity(Hspace)), condition = InSet(x_1_to_n_kets, OrthoNormBases(Hspace))).with_wrapping(), domain = NaturalPos), domain = HilbertSpaces)
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{\mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}}~\left[\forall_{n \in \mathbb{N}^+}~\left[\begin{array}{l}\forall_{x_{1}, x_{2}, \ldots, x_{n}~|~\left\{\lvert x_{1} \rangle, \lvert x_{2} \rangle, \ldots, \lvert x_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left(\left(\sum_{i=1}^{n} \left(\lvert x_{i} \rangle \thinspace \langle x_{i} \rvert\right)\right) = I_{\mathcal{H}}\right)\end{array}\right]\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{H in_c HilbertSpaces} [forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)]]
#    core type: Operation
#    operator: 15
#    operand: 2
# 1. (H -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)] if H in_c HilbertSpaces.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. H -> {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)] if H in_c HilbertSpaces.
#    core type: Lambda
#    parameter: 42
#    body: 3
# 3. {forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)] if H in_c HilbertSpaces.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)]
#    core type: Operation
#    operator: 15
#    operand: 9
# 5. H in_c HilbertSpaces
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in_c
#    core type: Literal
#    sub-expressions:
# 8. (H, HilbertSpaces)
#    core type: ExprTuple
#    sub-expressions: 42, 10
# 9. n -> {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H) if n in NaturalPos.
#    core type: Lambda
#    parameter: 65
#    body: 12
# 10. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 11. (n)
#     core type: ExprTuple
#     sub-expressions: 65
# 12. {forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H) if n in NaturalPos.
#     core type: Conditional
#     value: 13
#     condition: 14
# 13. forall_{x_{1}, x_{2}, ..., x_{n} | {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)} ((Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H)
#     core type: Operation
#     operator: 15
#     operand: 18
# 14. n in NaturalPos
#     core type: Operation
#     operator: 50
#     operands: 17
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. ((x_{1}, x_{2}, ..., x_{n}) -> {(Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 65, 19
# 18. (x_{1}, x_{2}, ..., x_{n}) -> {(Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 20\n    body: 21
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. (x_{1}, x_{2}, ..., x_{n})
#     core type: ExprTuple
#     sub-expressions: 22
# 21. {(Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H if {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H).
#     core type: Conditional
#     value: 23
#     condition: 24
# 22. x_{1}, x_{2}, ..., x_{n}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 64
#     end_index: 65
# 23. (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)) = I_H
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉} in O.N.Bases(H)
#     core type: Operation
#     operator: 50
#     operands: 28
# 25. _a -> x_{_a}
#     core type: Lambda
#     parameter: 66
#     body: 56
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. (Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|), I_H)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. ({|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. Sum_{i=1}^{n} (|x_{i}〉 . 〈x_{i}|)
#     core type: Operation
#     operator: 33
#     operand: 40
# 30. I_H
#     core type: Operation
#     operator: 35
#     operand: 42
# 31. {|x_{1}〉, |x_{2}〉, ..., |x_{n}〉}
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. O.N.Bases(H)
#     core type: Operation
#     operator: 38
#     operand: 42
# 33. Sum
#     core type: Literal
#     sub-expressions:
# 34. (i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 40
# 35. I
#     core type: Literal
#     sub-expressions:
# 36. Set
#     core type: Literal
#     sub-expressions:
# 37. (|x_{1}〉, |x_{2}〉, ..., |x_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 41
# 38. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 39. (H)
#     core type: ExprTuple
#     sub-expressions: 42
# 40. i -> {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Lambda
#     parameter: 69
#     body: 43
# 41. |x_{1}〉, |x_{2}〉, ..., |x_{n}〉
#     core type: ExprRange
#     lambda_map: 44
#     start_index: 64
#     end_index: 65
# 42. H
#     core type: Variable
#     sub-expressions:
# 43. {|x_{i}〉 . 〈x_{i}| if i in {1 .. n}.
#     core type: Conditional
#     value: 45
#     condition: 46
# 44. _a -> |x_{_a}〉
#     core type: Lambda
#     parameter: 66
#     body: 47
# 45. |x_{i}〉 . 〈x_{i}|
#     core type: Operation
#     operator: 48
#     operands: 49
# 46. i in {1 .. n}
#     core type: Operation
#     operator: 50
#     operands: 51
# 47. |x_{_a}〉
#     core type: Operation
#     operator: 57
#     operand: 56
# 48. .
#     core type: Literal
#     sub-expressions:
# 49. (|x_{i}〉, 〈x_{i}|)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 69, 55
# 52. (x_{_a})
#     core type: ExprTuple
#     sub-expressions: 56
# 53. |x_{i}〉
#     core type: Operation
#     operator: 57
#     operand: 63
# 54. 〈x_{i}|
#     core type: Operation
#     operator: 58
#     operand: 63
# 55. {1 .. n}
#     core type: Operation
#     operator: 60
#     operands: 61
# 56. x_{_a}
#     core type: IndexedVar
# variable: 67
# index: 66
# 57. KET
#     core type: Literal
#     sub-expressions:
# 58. BRA
#     core type: Literal
#     sub-expressions:
# 59. (x_{i})
#     core type: ExprTuple
#     sub-expressions: 63
# 60. Interval
#     core type: Literal
#     sub-expressions:
# 61. (1, n)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 62. (_a)
#     core type: ExprTuple
#     sub-expressions: 66
# 63. x_{i}
#     core type: IndexedVar
# variable: 67
# index: 69
# 64. 1
#     core type: Literal
#     sub-expressions:
# 65. n
#     core type: Variable
#     sub-expressions:
# 66. _a
#     core type: Variable
#     sub-expressions:
# 67. x
#     core type: Variable
#     sub-expressions:
# 68. (i)
#     core type: ExprTuple
#     sub-expressions: 69
# 69. i
#     core type: Variable
#     sub-expressions:
