# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l, m, n
from proveit.core_expr_types import A_1_to_l, B_1_to_m, C_1_to_n
from proveit.logic import Equals, Forall, InClass
from proveit.numbers import Natural, NaturalPos
from proveit.physics.quantum import Qmult, QmultCodomain

# %%
# build up the expression from sub-expressions
sub_expr1 = Qmult(A_1_to_l, B_1_to_m, C_1_to_n)
expr = Forall(instance_param_or_params = [l, m, n], instance_expr = Forall(instance_param_or_params = [A_1_to_l, B_1_to_m, C_1_to_n], instance_expr = Equals(sub_expr1, Qmult(A_1_to_l, Qmult(B_1_to_m), C_1_to_n)).with_wrapping_at(2), condition = InClass(sub_expr1, QmultCodomain)), domains = [Natural, NaturalPos, Natural])
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \forall_{l \in \mathbb{N}, m \in \mathbb{N}^+, n \in \mathbb{N}}~\left[\forall_{A_{1}, A_{2}, \ldots, A_{l}, B_{1}, B_{2}, \ldots, B_{m}, C_{1}, C_{2}, \ldots, C_{n}~|~\left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\thinspace B_{1} \thinspace  B_{2} \thinspace  \ldots \thinspace  B_{m}\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) \underset{{\scriptscriptstyle c}}{\in} \mathcal{Q^*}}~\left(\begin{array}{c} \begin{array}{l} \left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l}\thinspace B_{1} \thinspace  B_{2} \thinspace  \ldots \thinspace  B_{m}\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) =  \\ \left(A_{1} \thinspace  A_{2} \thinspace  \ldots \thinspace  A_{l} \thinspace \left(B_{1} \thinspace  B_{2} \thinspace  \ldots \thinspace  B_{m}\right)\thinspace C_{1} \thinspace  C_{2} \thinspace  \ldots \thinspace  C_{n}\right) \end{array} \end{array}\right)\right]

# %%
stored_expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: condition_wrapping
# description: Wrap 'before' or 'after' the condition (or None).
# default: None
# current value: None/False
# related methods: ('with_wrap_after_condition', 'with_wrap_before_condition')
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. forall_{l in Natural, m in NaturalPos, n in Natural} [forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (A_{1} .  A_{2} .  ... .  A_{l} . (B_{1} .  B_{2} .  ... .  B_{m}). C_{1} .  C_{2} .  ... .  C_{n}))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (A_{1} .  A_{2} .  ... .  A_{l} . (B_{1} .  B_{2} .  ... .  B_{m}). C_{1} .  C_{2} .  ... .  C_{n})) if l in Natural ,  m in NaturalPos ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (l, m, n) -> {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (A_{1} .  A_{2} .  ... .  A_{l} . (B_{1} .  B_{2} .  ... .  B_{m}). C_{1} .  C_{2} .  ... .  C_{n})) if l in Natural ,  m in NaturalPos ,  n in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (l, m, n)
#    core type: ExprTuple
#    sub-expressions: 39, 47, 41
# 4. {forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (A_{1} .  A_{2} .  ... .  A_{l} . (B_{1} .  B_{2} .  ... .  B_{m}). C_{1} .  C_{2} .  ... .  C_{n})) if l in Natural ,  m in NaturalPos ,  n in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} | (A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*} ((A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (A_{1} .  A_{2} .  ... .  A_{l} . (B_{1} .  B_{2} .  ... .  B_{m}). C_{1} .  C_{2} .  ... .  C_{n}))
#    core type: Operation
#    operator: 7
#    operand: 11
# 6. (l in Natural) and (m in NaturalPos) and (n in Natural)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n}) -> {(A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (A_{1} .  A_{2} .  ... .  A_{l} . (B_{1} .  B_{2} .  ... .  B_{m}). C_{1} .  C_{2} .  ... .  C_{n}) if (A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*.)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (l in Natural, m in NaturalPos, n in Natural)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14
# 11. (A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n}) -> {(A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (A_{1} .  A_{2} .  ... .  A_{l} . (B_{1} .  B_{2} .  ... .  B_{m}). C_{1} .  C_{2} .  ... .  C_{n}) if (A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*.
#     core type: Lambda
#     parameters: 32\n    body: 15
# 12. l in Natural
#     core type: Operation
#     operator: 18
#     operands: 16
# 13. m in NaturalPos
#     core type: Operation
#     operator: 18
#     operands: 17
# 14. n in Natural
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. {(A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (A_{1} .  A_{2} .  ... .  A_{l} . (B_{1} .  B_{2} .  ... .  B_{m}). C_{1} .  C_{2} .  ... .  C_{n}) if (A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*.
#     core type: Conditional
#     value: 20
#     condition: 21
# 16. (l, Natural)
#     core type: ExprTuple
#     sub-expressions: 39, 23
# 17. (m, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 47, 22
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 41, 23
# 20. (A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) =  \\ (A_{1} .  A_{2} .  ... .  A_{l} . (B_{1} .  B_{2} .  ... .  B_{m}). C_{1} .  C_{2} .  ... .  C_{n})
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. (A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. NaturalPos
#     core type: Literal
#     sub-expressions:
# 23. Natural
#     core type: Literal
#     sub-expressions:
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}, A_{1} .  A_{2} .  ... .  A_{l} . (B_{1} .  B_{2} .  ... .  B_{m}). C_{1} .  C_{2} .  ... .  C_{n})
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 26. in_c
#     core type: Literal
#     sub-expressions:
# 27. (A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}, Q*)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. A_{1} .  A_{2} .  ... .  A_{l} . (B_{1} .  B_{2} .  ... .  B_{m}). C_{1} .  C_{2} .  ... .  C_{n}
#     core type: Operation
#     operator: 36
#     operands: 31
# 29. A_{1} .  A_{2} .  ... .  A_{l}. B_{1} .  B_{2} .  ... .  B_{m}. C_{1} .  C_{2} .  ... .  C_{n}
#     core type: Operation
#     operator: 36
#     operands: 32
# 30. Q*
#     core type: Literal
#     sub-expressions:
# 31. (A_{1}, A_{2}, ..., A_{l}, B_{1} .  B_{2} .  ... .  B_{m},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 34, 33, 35
# 32. (A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m},C_{1}, C_{2}, ..., C_{n})
#     core type: ExprTuple
#     sub-expressions: 34, 42, 35
# 33. B_{1} .  B_{2} .  ... .  B_{m}
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. A_{1}, A_{2}, ..., A_{l}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 46
#     end_index: 39
# 35. C_{1}, C_{2}, ..., C_{n}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 46
#     end_index: 41
# 36. .
#     core type: Literal
#     sub-expressions:
# 37. (B_{1}, B_{2}, ..., B_{m})
#     core type: ExprTuple
#     sub-expressions: 42
# 38. _a -> A_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 43
# 39. l
#     core type: Variable
#     sub-expressions:
# 40. _a -> C_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 44
# 41. n
#     core type: Variable
#     sub-expressions:
# 42. B_{1}, B_{2}, ..., B_{m}
#     core type: ExprRange
#     lambda_map: 45
#     start_index: 46
#     end_index: 47
# 43. A_{_a}
#     core type: IndexedVar
# variable: 48
# index: 53
# 44. C_{_a}
#     core type: IndexedVar
# variable: 49
# index: 53
# 45. _a -> B_{_a}
#     core type: Lambda
#     parameter: 53
#     body: 50
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. m
#     core type: Variable
#     sub-expressions:
# 48. A
#     core type: Variable
#     sub-expressions:
# 49. C
#     core type: Variable
#     sub-expressions:
# 50. B_{_a}
#     core type: IndexedVar
# variable: 51
# index: 53
# 51. B
#     core type: Variable
#     sub-expressions:
# 52. (_a)
#     core type: ExprTuple
#     sub-expressions: 53
# 53. _a
#     core type: Variable
#     sub-expressions:
