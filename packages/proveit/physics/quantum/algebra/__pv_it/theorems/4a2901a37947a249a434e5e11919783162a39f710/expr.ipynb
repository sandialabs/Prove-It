# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, M, i, n
from proveit.core_expr_types import a_1_to_n, a_i, v_1_to_n, v_i
from proveit.linear_algebra import Adj, Dim, HilbertSpaces, Hspace, LinMap, OrthoNormBases, ScalarMult, VecSum
from proveit.logic import Equals, Exists, Forall, Iff, InSet, Set
from proveit.numbers import Complex, Interval, NaturalPos, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import v_1_to_n_kets

# %%
# build up the expression from sub-expressions
sub_expr1 = Adj(M)
expr = Conditional(Forall(instance_param_or_params = [Hspace], instance_expr = Forall(instance_param_or_params = [M], instance_expr = Iff(Equals(Qmult(sub_expr1, M), Qmult(M, sub_expr1)), Exists(instance_param_or_params = [v_1_to_n], instance_expr = Exists(instance_param_or_params = [a_1_to_n], instance_expr = Equals(M, VecSum(index_or_indices = [i], summand = ScalarMult(a_i, Qmult(Ket(v_i), Bra(v_i))), domain = Interval(one, n))), domain = Complex).with_wrapping(), condition = InSet(Set(v_1_to_n_kets), OrthoNormBases(Hspace))).with_wrapping()).with_wrapping_at(2), domain = LinMap(Hspace, Hspace)), domain = HilbertSpaces, condition = Equals(Dim(Hspace), n)).with_wrapping(), InSet(n, NaturalPos))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left\{\begin{array}{l}\forall_{\mathcal{H} \underset{{\scriptscriptstyle c}}{\in} \textrm{HilbertSpaces}~|~\textrm{Dim}\left(\mathcal{H}\right) = n}~\\
# \left[\forall_{M \in \mathcal{L}\left(\mathcal{H}, \mathcal{H}\right)}~\left(\begin{array}{c} \begin{array}{l} \left(\left(M^{\dagger} \thinspace M\right) = \left(M \thinspace M^{\dagger}\right)\right) \Leftrightarrow  \\ \left[\begin{array}{l}\exists_{v_{1}, v_{2}, \ldots, v_{n}~|~\left\{\left\{\lvert v_{1} \rangle, \lvert v_{2} \rangle, \ldots, \lvert v_{n} \rangle\right\}\right\} \in \textrm{O.N.Bases}\left(\mathcal{H}\right)}~\\
# \left[\begin{array}{l}\exists_{a_{1}, a_{2}, \ldots, a_{n} \in \mathbb{C}}~\\
# \left(M = \left(\sum_{i=1}^{n} \left(a_{i} \cdot \left(\lvert v_{i} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right)\right)\end{array}\right]\end{array}\right] \end{array} \end{array}\right)\right]\end{array} \textrm{ if } n \in \mathbb{N}^+\right..

# %%
stored_expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. {forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]])] if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{H in_c HilbertSpaces | Dim(H) = n} [forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]])]
#    core type: Operation
#    operator: 10
#    operand: 5
# 2. n in NaturalPos
#    core type: Operation
#    operator: 93
#    operands: 4
# 3. (H -> {forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 108, 6
# 5. H -> {forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Lambda
#    parameter: 64
#    body: 7
# 6. NaturalPos
#    core type: Literal
#    sub-expressions:
# 7. {forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]) if H in_c HilbertSpaces ,  Dim(H) = n.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{M in LINMAP(H, H)} (((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]])
#    core type: Operation
#    operator: 10
#    operand: 13
# 9. (H in_c HilbertSpaces) and (Dim(H) = n)
#    core type: Operation
#    operator: 68
#    operands: 12
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. (M -> {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in LINMAP(H, H).)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (H in_c HilbertSpaces, Dim(H) = n)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. M -> {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in LINMAP(H, H).
#     core type: Lambda
#     parameter: 72
#     body: 16
# 14. H in_c HilbertSpaces
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. Dim(H) = n
#     core type: Operation
#     operator: 66
#     operands: 19
# 16. {((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]] if M in LINMAP(H, H).
#     core type: Conditional
#     value: 20
#     condition: 21
# 17. in_c
#     core type: Literal
#     sub-expressions:
# 18. (H, HilbertSpaces)
#     core type: ExprTuple
#     sub-expressions: 64, 22
# 19. (Dim(H), n)
#     core type: ExprTuple
#     sub-expressions: 23, 108
# 20. ((M* . M) = (M . M*)) <=>  \\ [exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]]
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. M in LINMAP(H, H)
#     core type: Operation
#     operator: 93
#     operands: 26
# 22. HilbertSpaces
#     core type: Literal
#     sub-expressions:
# 23. Dim(H)
#     core type: Operation
#     operator: 27
#     operand: 64
# 24. <=>
#     core type: Literal
#     sub-expressions:
# 25. ((M* . M) = (M . M*), exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))])
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. (M, LINMAP(H, H))
#     core type: ExprTuple
#     sub-expressions: 72, 30
# 27. Dim
#     core type: Literal
#     sub-expressions:
# 28. (M* . M) = (M . M*)
#     core type: Operation
#     operator: 66
#     operands: 31
# 29. exists_{v_{1}, v_{2}, ..., v_{n} | {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)} [exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))]
#     core type: Operation
#     operator: 49
#     operand: 37
# 30. LINMAP(H, H)
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. (M* . M, M . M*)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 32. ((v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).)
#     core type: ExprTuple
#     sub-expressions: 37
# 33. LINMAP
#     core type: Literal
#     sub-expressions:
# 34. (H, H)
#     core type: ExprTuple
#     sub-expressions: 64, 64
# 35. M* . M
#     core type: Operation
#     operator: 101
#     operands: 38
# 36. M . M*
#     core type: Operation
#     operator: 101
#     operands: 39
# 37. (v_{1}, v_{2}, ..., v_{n}) -> {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#     core type: Lambda
#     parameters: 40\n    body: 41
# 38. (M*, M)
#     core type: ExprTuple
#     sub-expressions: 42, 72
# 39. (M, M*)
#     core type: ExprTuple
#     sub-expressions: 72, 42
# 40. (v_{1}, v_{2}, ..., v_{n})
#     core type: ExprTuple
#     sub-expressions: 43
# 41. {exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))) if {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H).
#     core type: Conditional
#     value: 44
#     condition: 45
# 42. M*
#     core type: Operation
#     operator: 46
#     operand: 72
# 43. v_{1}, v_{2}, ..., v_{n}
#     core type: ExprRange
#     lambda_map: 48
#     start_index: 107
#     end_index: 108
# 44. exists_{a_{1}, a_{2}, ..., a_{n} in Complex} (M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))))
#     core type: Operation
#     operator: 49
#     operand: 52
# 45. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}} in O.N.Bases(H)
#     core type: Operation
#     operator: 93
#     operands: 51
# 46. Adj
#     core type: Literal
#     sub-expressions:
# 47. (M)
#     core type: ExprTuple
#     sub-expressions: 72
# 48. _a -> v_{_a}
#     core type: Lambda
#     parameter: 99
#     body: 90
# 49. exists
#     core type: Literal
#     sub-expressions:
# 50. ((a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).)
#     core type: ExprTuple
#     sub-expressions: 52
# 51. ({{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}, O.N.Bases(H))
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 52. (a_{1}, a_{2}, ..., a_{n}) -> {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Lambda
#     parameters: 55\n    body: 56
# 53. {{|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}}
#     core type: Operation
#     operator: 70
#     operand: 63
# 54. O.N.Bases(H)
#     core type: Operation
#     operator: 58
#     operand: 64
# 55. (a_{1}, a_{2}, ..., a_{n})
#     core type: ExprTuple
#     sub-expressions: 60
# 56. {M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))) if (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex).
#     core type: Conditional
#     value: 61
#     condition: 62
# 57. ({|v_{1}〉, |v_{2}〉, ..., |v_{n}〉})
#     core type: ExprTuple
#     sub-expressions: 63
# 58. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 59. (H)
#     core type: ExprTuple
#     sub-expressions: 64
# 60. a_{1}, a_{2}, ..., a_{n}
#     core type: ExprRange
#     lambda_map: 65
#     start_index: 107
#     end_index: 108
# 61. M = (Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: Operation
#     operator: 66
#     operands: 67
# 62. (a_{1} in Complex) and  (a_{2} in Complex) and  ... and  (a_{n} in Complex)
#     core type: Operation
#     operator: 68
#     operands: 69
# 63. {|v_{1}〉, |v_{2}〉, ..., |v_{n}〉}
#     core type: Operation
#     operator: 70
#     operands: 71
# 64. H
#     core type: Variable
#     sub-expressions:
# 65. _a -> a_{_a}
#     core type: Lambda
#     parameter: 99
#     body: 88
# 66. =
#     core type: Literal
#     sub-expressions:
# 67. (M, Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|)))
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 68. and
#     core type: Literal
#     sub-expressions:
# 69. ((a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex))
#     core type: ExprTuple
#     sub-expressions: 74
# 70. Set
#     core type: Literal
#     sub-expressions:
# 71. (|v_{1}〉, |v_{2}〉, ..., |v_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 75
# 72. M
#     core type: Variable
#     sub-expressions:
# 73. Sum_{i=1}^{n} (a_{i} * (|v_{i}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 76
#     operand: 80
# 74. (a_{1} in Complex), (a_{2} in Complex), ..., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 78
#     start_index: 107
#     end_index: 108
# 75. |v_{1}〉, |v_{2}〉, ..., |v_{n}〉
#     core type: ExprRange
#     lambda_map: 79
#     start_index: 107
#     end_index: 108
# 76. Sum
#     core type: Literal
#     sub-expressions:
# 77. (i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 80
# 78. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 99
#     body: 81
# 79. _a -> |v_{_a}〉
#     core type: Lambda
#     parameter: 99
#     body: 82
# 80. i -> {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Lambda
#     parameter: 115
#     body: 83
# 81. a_{_a} in Complex
#     core type: Operation
#     operator: 93
#     operands: 84
# 82. |v_{_a}〉
#     core type: Operation
#     operator: 109
#     operand: 90
# 83. {a_{i} * (|v_{i}〉 . 〈v_{i}|) if i in {1 .. n}.
#     core type: Conditional
#     value: 86
#     condition: 87
# 84. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 88, 89
# 85. (v_{_a})
#     core type: ExprTuple
#     sub-expressions: 90
# 86. a_{i} * (|v_{i}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 91
#     operands: 92
# 87. i in {1 .. n}
#     core type: Operation
#     operator: 93
#     operands: 94
# 88. a_{_a}
#     core type: IndexedVar
# variable: 100
# index: 99
# 89. Complex
#     core type: Literal
#     sub-expressions:
# 90. v_{_a}
#     core type: IndexedVar
# variable: 113
# index: 99
# 91. *
#     core type: Literal
#     sub-expressions:
# 92. (a_{i}, |v_{i}〉 . 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 96, 97
# 93. in
#     core type: Literal
#     sub-expressions:
# 94. (i, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 115, 98
# 95. (_a)
#     core type: ExprTuple
#     sub-expressions: 99
# 96. a_{i}
#     core type: IndexedVar
# variable: 100
# index: 115
# 97. |v_{i}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 101
#     operands: 102
# 98. {1 .. n}
#     core type: Operation
#     operator: 103
#     operands: 104
# 99. _a
#     core type: Variable
#     sub-expressions:
# 100. a
#      core type: Variable
#      sub-expressions:
# 101. .
#      core type: Literal
#      sub-expressions:
# 102. (|v_{i}〉, 〈v_{i}|)
#      core type: ExprTuple
#      sub-expressions: 105, 106
# 103. Interval
#      core type: Literal
#      sub-expressions:
# 104. (1, n)
#      core type: ExprTuple
#      sub-expressions: 107, 108
# 105. |v_{i}〉
#      core type: Operation
#      operator: 109
#      operand: 112
# 106. 〈v_{i}|
#      core type: Operation
#      operator: 110
#      operand: 112
# 107. 1
#      core type: Literal
#      sub-expressions:
# 108. n
#      core type: Variable
#      sub-expressions:
# 109. KET
#      core type: Literal
#      sub-expressions:
# 110. BRA
#      core type: Literal
#      sub-expressions:
# 111. (v_{i})
#      core type: ExprTuple
#      sub-expressions: 112
# 112. v_{i}
#      core type: IndexedVar
# variable: 113
# index: 115
# 113. v
#      core type: Variable
#      sub-expressions:
# 114. (i)
#      core type: ExprTuple
#      sub-expressions: 115
# 115. i
#      core type: Variable
#      sub-expressions:
