# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, Lambda, W, i, j, m, n
from proveit.core_expr_types import v_i, w_1_to_n, w_j
from proveit.linear_algebra import OrthoNormBases, VecSum
from proveit.logic import Equals, InSet
from proveit.numbers import Interval, one
from proveit.physics.quantum import Bra, Ket, Qmult
from proveit.physics.quantum.algebra import w_1_to_n_kets

# %%
# build up the expression from sub-expressions
expr = Lambda([w_1_to_n], Conditional(Equals(A, VecSum(index_or_indices = [i], summand = VecSum(index_or_indices = [j], summand = Qmult(Bra(w_j), A, Ket(v_i), Ket(w_j), Bra(v_i)), domain = Interval(one, n)), domain = Interval(one, m))), InSet(w_1_to_n_kets, OrthoNormBases(W))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(w_{1}, w_{2}, \ldots, w_{n}\right) \mapsto \left\{A = \left(\sum_{i=1}^{m} \left(\sum_{j=1}^{n} \left(\langle w_{j} \rvert \thinspace A \thinspace \lvert v_{i} \rangle \thinspace \lvert w_{j} \rangle \thinspace \langle v_{i} \rvert\right)\right)\right) \textrm{ if } \left\{\lvert w_{1} \rangle, \lvert w_{2} \rangle, \ldots, \lvert w_{n} \rangle\right\} \in \textrm{O.N.Bases}\left(W\right)\right..

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. (w_{1}, w_{2}, ..., w_{n}) -> {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (w_{1}, w_{2}, ..., w_{n})
#    core type: ExprTuple
#    sub-expressions: 3
# 2. {A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))) if {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W).
#    core type: Conditional
#    value: 4
#    condition: 5
# 3. w_{1}, w_{2}, ..., w_{n}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 58
#    end_index: 59
# 4. A = (Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉} in O.N.Bases(W)
#    core type: Operation
#    operator: 42
#    operands: 9
# 6. _a -> w_{_a}
#    core type: Lambda
#    parameter: 39
#    body: 32
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (A, Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)))
#    core type: ExprTuple
#    sub-expressions: 45, 10
# 9. ({|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}, O.N.Bases(W))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. Sum_{i=1}^{m} (Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|))
#     core type: Operation
#     operator: 26
#     operand: 18
# 11. {|w_{1}〉, |w_{2}〉, ..., |w_{n}〉}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. O.N.Bases(W)
#     core type: Operation
#     operator: 16
#     operand: 20
# 13. (i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.)
#     core type: ExprTuple
#     sub-expressions: 18
# 14. Set
#     core type: Literal
#     sub-expressions:
# 15. (|w_{1}〉, |w_{2}〉, ..., |w_{n}〉)
#     core type: ExprTuple
#     sub-expressions: 19
# 16. O.N.Bases
#     core type: Literal
#     sub-expressions:
# 17. (W)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. i -> {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Lambda
#     parameter: 65
#     body: 21
# 19. |w_{1}〉, |w_{2}〉, ..., |w_{n}〉
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 58
#     end_index: 59
# 20. W
#     core type: Variable
#     sub-expressions:
# 21. {Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|) if i in {1 .. m}.
#     core type: Conditional
#     value: 23
#     condition: 24
# 22. _a -> |w_{_a}〉
#     core type: Lambda
#     parameter: 39
#     body: 25
# 23. Sum_{j=1}^{n} (〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|)
#     core type: Operation
#     operator: 26
#     operand: 30
# 24. i in {1 .. m}
#     core type: Operation
#     operator: 42
#     operands: 28
# 25. |w_{_a}〉
#     core type: Operation
#     operator: 50
#     operand: 32
# 26. Sum
#     core type: Literal
#     sub-expressions:
# 27. (j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 30
# 28. (i, {1 .. m})
#     core type: ExprTuple
#     sub-expressions: 65, 31
# 29. (w_{_a})
#     core type: ExprTuple
#     sub-expressions: 32
# 30. j -> {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Lambda
#     parameter: 64
#     body: 33
# 31. {1 .. m}
#     core type: Operation
#     operator: 54
#     operands: 34
# 32. w_{_a}
#     core type: IndexedVar
# variable: 60
# index: 39
# 33. {〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}| if j in {1 .. n}.
#     core type: Conditional
#     value: 36
#     condition: 37
# 34. (1, m)
#     core type: ExprTuple
#     sub-expressions: 58, 38
# 35. (_a)
#     core type: ExprTuple
#     sub-expressions: 39
# 36. 〈w_{j}| . A . |v_{i}〉 . |w_{j}〉 . 〈v_{i}|
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. j in {1 .. n}
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. m
#     core type: Variable
#     sub-expressions:
# 39. _a
#     core type: Variable
#     sub-expressions:
# 40. .
#     core type: Literal
#     sub-expressions:
# 41. (〈w_{j}|, A, |v_{i}〉, |w_{j}〉, 〈v_{i}|)
#     core type: ExprTuple
#     sub-expressions: 44, 45, 46, 47, 48
# 42. in
#     core type: Literal
#     sub-expressions:
# 43. (j, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 64, 49
# 44. 〈w_{j}|
#     core type: Operation
#     operator: 52
#     operand: 56
# 45. A
#     core type: Variable
#     sub-expressions:
# 46. |v_{i}〉
#     core type: Operation
#     operator: 50
#     operand: 57
# 47. |w_{j}〉
#     core type: Operation
#     operator: 50
#     operand: 56
# 48. 〈v_{i}|
#     core type: Operation
#     operator: 52
#     operand: 57
# 49. {1 .. n}
#     core type: Operation
#     operator: 54
#     operands: 55
# 50. KET
#     core type: Literal
#     sub-expressions:
# 51. (w_{j})
#     core type: ExprTuple
#     sub-expressions: 56
# 52. BRA
#     core type: Literal
#     sub-expressions:
# 53. (v_{i})
#     core type: ExprTuple
#     sub-expressions: 57
# 54. Interval
#     core type: Literal
#     sub-expressions:
# 55. (1, n)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 56. w_{j}
#     core type: IndexedVar
# variable: 60
# index: 64
# 57. v_{i}
#     core type: IndexedVar
# variable: 62
# index: 65
# 58. 1
#     core type: Literal
#     sub-expressions:
# 59. n
#     core type: Variable
#     sub-expressions:
# 60. w
#     core type: Variable
#     sub-expressions:
# 61. (j)
#     core type: ExprTuple
#     sub-expressions: 64
# 62. v
#     core type: Variable
#     sub-expressions:
# 63. (i)
#     core type: ExprTuple
#     sub-expressions: 65
# 64. j
#     core type: Variable
#     sub-expressions:
# 65. i
#     core type: Variable
#     sub-expressions:
