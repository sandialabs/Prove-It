# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, i, lambda_, m, n
from proveit.core_expr_types import a_i, b_i, lambda_i
from proveit.linear_algebra import ScalarMult, VecSum
from proveit.logic import And, Equals, InSet
from proveit.numbers import Interval, Min, RealNonNeg, one
from proveit.physics.quantum import Ket, Qmult, var_ket_psi

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = IndexedVar(lambda_, sub_expr1)
sub_expr3 = Min(m, n)
expr = ExprTuple(Lambda([ExprRange(sub_expr1, sub_expr2, one, sub_expr3)], Conditional(Equals(var_ket_psi, VecSum(index_or_indices = [i], summand = ScalarMult(lambda_i, Qmult(Ket(a_i), Ket(b_i))), domain = Interval(one, sub_expr3))), And(ExprRange(sub_expr1, InSet(sub_expr2, RealNonNeg), one, sub_expr3)))))
# Out:
# <strong id="expr">expr:</strong> <a class="ProveItLink" href="expr.ipynb"><img src="expr.png" style="display:inline;vertical-align:middle;" /></a><br>

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(stored_expr.latex())
# Out:
# \left(\left(\lambda_{1}, \lambda_{2}, \ldots, \lambda_{{\rm Min}\left(m, n\right)}\right) \mapsto \left\{\lvert \psi \rangle = \left(\sum_{i=1}^{{\rm Min}\left(m, n\right)} \left(\lambda_{i} \cdot \left(\lvert a_{i} \rangle \thinspace \lvert b_{i} \rangle\right)\right)\right) \textrm{ if } \left(\lambda_{1} \in \mathbb{R}^{\ge 0}\right) \land  \left(\lambda_{2} \in \mathbb{R}^{\ge 0}\right) \land  \ldots \land  \left(\lambda_{{\rm Min}\left(m, n\right)} \in \mathbb{R}^{\ge 0}\right)\right..\right)

# %%
stored_expr.style_options()
# Out:
# no style options

# %%
# display the expression information
stored_expr.expr_info()
# Out:
# 0. ((lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}) -> {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. {|psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))) if (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg).
#    core type: Conditional
#    value: 5
#    condition: 6
# 4. lambda_{1}, lambda_{2}, ..., lambda_{Min(m, n)}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 42
#    end_index: 43
# 5. |psi> = (Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. (lambda_{1} in RealNonNeg) and  (lambda_{2} in RealNonNeg) and  ... and  (lambda_{Min(m, n)} in RealNonNeg)
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. _a -> lambda_{_a}
#    core type: Lambda
#    parameter: 34
#    body: 24
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (|psi>, Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉)))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. ((lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg))
#     core type: ExprTuple
#     sub-expressions: 14
# 12. |psi>
#     core type: Variable
#     sub-expressions:
# 13. Sum_{i=1}^{Min(m, n)} (lambda_{i} * (|a_{i}〉 . |b_{i}〉))
#     core type: Operation
#     operator: 15
#     operand: 18
# 14. (lambda_{1} in RealNonNeg), (lambda_{2} in RealNonNeg), ..., (lambda_{Min(m, n)} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 42
#     end_index: 43
# 15. Sum
#     core type: Literal
#     sub-expressions:
# 16. (i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. _a -> (lambda_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 34
#     body: 19
# 18. i -> {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Lambda
#     parameter: 56
#     body: 20
# 19. lambda_{_a} in RealNonNeg
#     core type: Operation
#     operator: 28
#     operands: 21
# 20. {lambda_{i} * (|a_{i}〉 . |b_{i}〉) if i in {1 .. Min(m, n)}.
#     core type: Conditional
#     value: 22
#     condition: 23
# 21. (lambda_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. lambda_{i} * (|a_{i}〉 . |b_{i}〉)
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. i in {1 .. Min(m, n)}
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. lambda_{_a}
#     core type: IndexedVar
# variable: 35
# index: 34
# 25. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 26. *
#     core type: Literal
#     sub-expressions:
# 27. (lambda_{i}, |a_{i}〉 . |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. (i, {1 .. Min(m, n)})
#     core type: ExprTuple
#     sub-expressions: 56, 33
# 30. (_a)
#     core type: ExprTuple
#     sub-expressions: 34
# 31. lambda_{i}
#     core type: IndexedVar
# variable: 35
# index: 56
# 32. |a_{i}〉 . |b_{i}〉
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. {1 .. Min(m, n)}
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. _a
#     core type: Variable
#     sub-expressions:
# 35. lambda
#     core type: Variable
#     sub-expressions:
# 36. .
#     core type: Literal
#     sub-expressions:
# 37. (|a_{i}〉, |b_{i}〉)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. Interval
#     core type: Literal
#     sub-expressions:
# 39. (1, Min(m, n))
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 40. |a_{i}〉
#     core type: Operation
#     operator: 45
#     operand: 49
# 41. |b_{i}〉
#     core type: Operation
#     operator: 45
#     operand: 50
# 42. 1
#     core type: Literal
#     sub-expressions:
# 43. Min(m, n)
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. (a_{i})
#     core type: ExprTuple
#     sub-expressions: 49
# 45. KET
#     core type: Literal
#     sub-expressions:
# 46. (b_{i})
#     core type: ExprTuple
#     sub-expressions: 50
# 47. Min
#     core type: Literal
#     sub-expressions:
# 48. (m, n)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. a_{i}
#     core type: IndexedVar
# variable: 53
# index: 56
# 50. b_{i}
#     core type: IndexedVar
# variable: 54
# index: 56
# 51. m
#     core type: Variable
#     sub-expressions:
# 52. n
#     core type: Variable
#     sub-expressions:
# 53. a
#     core type: Variable
#     sub-expressions:
# 54. b
#     core type: Variable
#     sub-expressions:
# 55. (i)
#     core type: ExprTuple
#     sub-expressions: 56
# 56. i
#     core type: Variable
#     sub-expressions:
