# %% [markdown]
# Proof of <a class="ProveItLink" href="..\_theory_.ipynb">socks_demo</a>.<a href="../_theorems_.ipynb#sufficient_subsets" class="ProveItLink">sufficient_subsets</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory('..') # the theorem's theory is in the parent directory

# %%
# %begin_proof sufficient_subsets presuming [proveit.logic]

# %%
antecedent = sufficient_subsets.antecedent
