# %% [markdown]
# Context: socks_demo
# ========
#
# The socks_demo context in the tutorial.  This context provides a demonstration of **Prove-It** by solving a simple riddle.
#
# There are 10 black socks and 10 white socks in a dresser.  It is pitch black.  What is the minimum number of socks that must be randomly pulled from the dresser in order to guarantee that you have a matching pair?

# %%
import proveit
# %context # toggles between interactive and static modes
# Out:
# <table>
# <th><a class="ProveItLink" href="_common_.ipynb">common expressions</a></th>
# <th><a class="ProveItLink" href="_axioms_.ipynb">axioms</a></th>
# <th><a class="ProveItLink" href="_theorems_.ipynb">theorems</a></th>
# </table>
