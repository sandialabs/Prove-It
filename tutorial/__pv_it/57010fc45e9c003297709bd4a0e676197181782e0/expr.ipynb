# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import j, k
from proveit.logic import Equals
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(one)
expr = Equals(Add(Add(j, subExpr1, one), Add(k, subExpr1, one)), Add(j, k))
# Out:
# expr: ((j - 1 + 1) + (k - 1 + 1)) = (j + k)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(j - 1 + 1\right) + \left(k - 1 + 1\right)\right) = \left(j + k\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((j - 1 + 1) + (k - 1 + 1)) = (j + k)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((j - 1 + 1) + (k - 1 + 1), j + k)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (j - 1 + 1) + (k - 1 + 1)
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. j + k
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (j - 1 + 1, k - 1 + 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (j, k)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 7. j - 1 + 1
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. k - 1 + 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (j, -1, 1)
#    core type: ExprTuple
#    sub-expressions: 12, 14, 16
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (k, -1, 1)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 16
# 12. j
#     core type: Variable
#     sub-expressions:
# 13. k
#     core type: Variable
#     sub-expressions:
# 14. -1
#     core type: Operation
#     operator: 15
#     operand: 16
# 15. -
#     core type: Literal
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
