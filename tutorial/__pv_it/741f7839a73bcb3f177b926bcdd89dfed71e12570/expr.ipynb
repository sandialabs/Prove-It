# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit.core_expr_types._common_ import A_i_to_j
from proveit.logic import Or

# %%
# build up the expression from sub-expressions
expr = Lambda(A_i_to_j, Or(A_i_to_j))
# Out:
# expr: (A_{i}, ..A_{_a}.., A_{j}) -> (A_{i} or ..A_{_a}.. or A_{j})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{i}, \ldots, A_{j}\right) \mapsto \left(A_{i} \lor \ldots \lor A_{j}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{i}, ..A_{_a}.., A_{j}) -> (A_{i} or ..A_{_a}.. or A_{j})
#    core type: Lambda
#    parameter: 4
#    body: 1
# 1. A_{i} or ..A_{_a}.. or A_{j}
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. or
#    core type: Literal
#    sub-expressions:
# 3. (A_{i}, ..A_{_a}.., A_{j})
#    core type: ExprTuple
#    sub-expressions: 4
# 4. A_{i}, ..A_{_a}.., A_{j}
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 5. _a -> A_{_a}
#    core type: Lambda
#    parameter: 10
#    body: 8
# 6. i
#    core type: Variable
#    sub-expressions:
# 7. j
#    core type: Variable
#    sub-expressions:
# 8. A_{_a}
#    core type: IndexedVar
# variable: 9
# index: 10
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. _a
#     core type: Variable
#     sub-expressions:
