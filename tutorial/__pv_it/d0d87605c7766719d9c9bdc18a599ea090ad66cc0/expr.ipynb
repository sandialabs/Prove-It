# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import i, j, k, n
from proveit.number import Mult, one

# %%
# build up the expression from sub-expressions
expr = ExprRange(i, ExprRange(j, ExprRange(k, Mult(i, j, k), one, n), one, n), one, n)
# Out:
# expr: (1 * 1 * 1), ..(1 * 1 * k).., (1 * 1 * n), ....(1 * j * 1), ..(1 * j * k).., (1 * j * n)...., (1 * n * 1), ..(1 * n * k).., (1 * n * n), ......(i * 1 * 1), ..(i * 1 * k).., (i * 1 * n), ....(i * j * 1), ..(i * j * k).., (i * j * n)...., (i * n * 1), ..(i * n * k).., (i * n * n)......, (n * 1 * 1), ..(n * 1 * k).., (n * 1 * n), ....(n * j * 1), ..(n * j * k).., (n * j * n)...., (n * n * 1), ..(n * n * k).., (n * n * n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1 \cdot 1 \cdot 1\right), \ldots, \left(1 \cdot 1 \cdot n\right), \ldots\ldots, \left(1 \cdot n \cdot 1\right), \ldots, \left(1 \cdot n \cdot n\right), \ldots\ldots\ldots, \left(n \cdot 1 \cdot 1\right), \ldots, \left(n \cdot 1 \cdot n\right), \ldots\ldots, \left(n \cdot n \cdot 1\right), \ldots, \left(n \cdot n \cdot n\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (1 * 1 * 1), ..(1 * 1 * k).., (1 * 1 * n), ....(1 * j * 1), ..(1 * j * k).., (1 * j * n)...., (1 * n * 1), ..(1 * n * k).., (1 * n * n), ......(i * 1 * 1), ..(i * 1 * k).., (i * 1 * n), ....(i * j * 1), ..(i * j * k).., (i * j * n)...., (i * n * 1), ..(i * n * k).., (i * n * n)......, (n * 1 * 1), ..(n * 1 * k).., (n * 1 * n), ....(n * j * 1), ..(n * j * k).., (n * j * n)...., (n * n * 1), ..(n * n * k).., (n * n * n)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 6
#    end_index: 7
# 1. i -> (i * 1 * 1), ..(i * 1 * k).., (i * 1 * n), ....(i * j * 1), ..(i * j * k).., (i * j * n)...., (i * n * 1), ..(i * n * k).., (i * n * n)
#    core type: Lambda
#    parameter: 11
#    body: 2
# 2. (i * 1 * 1), ..(i * 1 * k).., (i * 1 * n), ....(i * j * 1), ..(i * j * k).., (i * j * n)...., (i * n * 1), ..(i * n * k).., (i * n * n)
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 6
#    end_index: 7
# 3. j -> (i * j * 1), ..(i * j * k).., (i * j * n)
#    core type: Lambda
#    parameter: 12
#    body: 4
# 4. (i * j * 1), ..(i * j * k).., (i * j * n)
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 5. k -> (i * j * k)
#    core type: Lambda
#    parameter: 13
#    body: 8
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. n
#    core type: Variable
#    sub-expressions:
# 8. i * j * k
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (i, j, k)
#     core type: ExprTuple
#     sub-expressions: 11, 12, 13
# 11. i
#     core type: Variable
#     sub-expressions:
# 12. j
#     core type: Variable
#     sub-expressions:
# 13. k
#     core type: Variable
#     sub-expressions:
