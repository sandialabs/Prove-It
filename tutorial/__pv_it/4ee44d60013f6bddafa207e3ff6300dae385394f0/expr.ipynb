# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Not.html">Not</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar
from proveit._common_ import A, i, m
from proveit.logic import And, Not
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Not(And(ExprRange(i, Not(IndexedVar(A, i)), one, m)))
# Out:
# expr: [not]([not](A_{1}) and ..[not](A_{i}).. and [not](A_{m}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \lnot \left((\lnot A_{1}) \land \ldots \land (\lnot A_{m})\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [not]([not](A_{1}) and ..[not](A_{i}).. and [not](A_{m}))
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. [not](A_{1}) and ..[not](A_{i}).. and [not](A_{m})
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. and
#    core type: Literal
#    sub-expressions:
# 3. ([not](A_{1}), ..[not](A_{i}).., [not](A_{m}))
#    core type: ExprTuple
#    sub-expressions: 4
# 4. [not](A_{1}), ..[not](A_{i}).., [not](A_{m})
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 5. i -> [not](A_{i})
#    core type: Lambda
#    parameter: 12
#    body: 8
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. m
#    core type: Variable
#    sub-expressions:
# 8. [not](A_{i})
#    core type: Operation
#    operator: 9
#    operand: 10
# 9. not
#    core type: Literal
#    sub-expressions:
# 10. A_{i}
#     core type: IndexedVar
# variable: 11
# index: 12
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. i
#     core type: Variable
#     sub-expressions:
