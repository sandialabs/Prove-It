# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar
from proveit._common_ import C, a, i, j
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Equals(Len([ExprRange(a, IndexedVar(C, a), one, i)]), Len([ExprRange(a, a, i, j)]))
# Out:
# expr: |(C_{1}, ..C_{a}.., C_{i})| = |(i, ..a.., j)|

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(C_{1}, \ldots, C_{i}\right)| = |\left(i, \ldots, j\right)|

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |(C_{1}, ..C_{a}.., C_{i})| = |(i, ..a.., j)|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(C_{1}, ..C_{a}.., C_{i})|, |(i, ..a.., j)|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(C_{1}, ..C_{a}.., C_{i})|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |(i, ..a.., j)|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((C_{1}, ..C_{a}.., C_{i}))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((i, ..a.., j))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (C_{1}, ..C_{a}.., C_{i})
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (i, ..a.., j)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. C_{1}, ..C_{a}.., C_{i}
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 13
#     end_index: 15
# 11. i, ..a.., j
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 12. a -> C_{a}
#     core type: Lambda
#     parameter: 19
#     body: 17
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. a -> a
#     core type: Lambda
#     parameter: 19
#     body: 19
# 15. i
#     core type: Variable
#     sub-expressions:
# 16. j
#     core type: Variable
#     sub-expressions:
# 17. C_{a}
#     core type: IndexedVar
# variable: 18
# index: 19
# 18. C
#     core type: Variable
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
