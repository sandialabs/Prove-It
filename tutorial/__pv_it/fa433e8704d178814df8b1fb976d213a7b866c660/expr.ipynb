# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable
from proveit._common_ import i, j
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = ExprTuple(ExprRange(subExpr1, subExpr1, one, Add(i, Neg(one)).withSubtractionAt()), ExprRange(subExpr1, subExpr1, i, j))
# Out:
# expr: (1, .._a.., i + (-1), i, .._a.., j)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1, \ldots, i + \left(-1\right), i, \ldots, j\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (1, .._a.., i + (-1), i, .._a.., j)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 1, .._a.., (i + (-1))
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 12
#    end_index: 3
# 2. i, .._a.., j
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 9
#    end_index: 5
# 3. i + (-1)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. _a -> _a
#    core type: Lambda
#    parameter: 8
#    body: 8
# 5. j
#    core type: Variable
#    sub-expressions:
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (i, -1)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. _a
#    core type: Variable
#    sub-expressions:
# 9. i
#    core type: Variable
#    sub-expressions:
# 10. -1
#     core type: Operation
#     operator: 11
#     operand: 12
# 11. -
#     core type: Literal
#     sub-expressions:
# 12. 1
#     core type: Literal
#     sub-expressions:
