# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.number.Add.html">Add</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar
from proveit._common_ import k, n, x
from proveit.number import Add, Mult, one

# %%
# build up the expression from sub-expressions
expr = Add(ExprRange(k, Mult(k, IndexedVar(x, k)), one, n))
# Out:
# expr: (1 * x_{1}) + ..(k * x_{k}).. + (n * x_{n})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1 \cdot x_{1}\right) + \ldots + \left(n \cdot x_{n}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (1 * x_{1}) + ..(k * x_{k}).. + (n * x_{n})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. +
#    core type: Literal
#    sub-expressions:
# 2. (1 * x_{1}, ..k * x_{k}.., n * x_{n})
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (1 * x_{1}), ..(k * x_{k}).., (n * x_{n})
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. k -> (k * x_{k})
#    core type: Lambda
#    parameter: 12
#    body: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. n
#    core type: Variable
#    sub-expressions:
# 7. k * x_{k}
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. *
#    core type: Literal
#    sub-expressions:
# 9. (k, x_{k})
#    core type: ExprTuple
#    sub-expressions: 12, 10
# 10. x_{k}
#     core type: IndexedVar
# variable: 11
# index: 12
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. k
#     core type: Variable
#     sub-expressions:
