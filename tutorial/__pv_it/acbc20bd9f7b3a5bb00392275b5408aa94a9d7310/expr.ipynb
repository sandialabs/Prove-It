# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar
from proveit._common_ import a, b, j, k, x
from proveit.core_expr_types import Len
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(one)
expr = ExprTuple(Len([ExprRange(x, IndexedVar(b, x), one, k), ExprRange(x, IndexedVar(a, x), one, j)]), Add(Add(k, subExpr1, one), Add(j, subExpr1, one)))
# Out:
# expr: (|(b_{1}, ..b_{x}.., b_{k}, a_{1}, ..a_{x}.., a_{j})|, (k - 1 + 1) + (j - 1 + 1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(b_{1}, \ldots, b_{k}, a_{1}, \ldots, a_{j}\right)|, \left(k - 1 + 1\right) + \left(j - 1 + 1\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(b_{1}, ..b_{x}.., b_{k}, a_{1}, ..a_{x}.., a_{j})|, (k - 1 + 1) + (j - 1 + 1))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(b_{1}, ..b_{x}.., b_{k}, a_{1}, ..a_{x}.., a_{j})|
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (k - 1 + 1) + (j - 1 + 1)
#    core type: Operation
#    operator: 12
#    operands: 5
# 3. length
#    core type: Literal
#    sub-expressions:
# 4. ((b_{1}, ..b_{x}.., b_{k}, a_{1}, ..a_{x}.., a_{j}))
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (k - 1 + 1, j - 1 + 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (b_{1}, ..b_{x}.., b_{k}, a_{1}, ..a_{x}.., a_{j})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. k - 1 + 1
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. j - 1 + 1
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. b_{1}, ..b_{x}.., b_{k}
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 22
#    end_index: 16
# 10. a_{1}, ..a_{x}.., a_{j}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 22
#     end_index: 17
# 11. (k, -1, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 18, 22
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (j, -1, 1)
#     core type: ExprTuple
#     sub-expressions: 17, 18, 22
# 14. x -> b_{x}
#     core type: Lambda
#     parameter: 25
#     body: 19
# 15. x -> a_{x}
#     core type: Lambda
#     parameter: 25
#     body: 20
# 16. k
#     core type: Variable
#     sub-expressions:
# 17. j
#     core type: Variable
#     sub-expressions:
# 18. -1
#     core type: Operation
#     operator: 21
#     operand: 22
# 19. b_{x}
#     core type: IndexedVar
# variable: 23
# index: 25
# 20. a_{x}
#     core type: IndexedVar
# variable: 24
# index: 25
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
# 24. a
#     core type: Variable
#     sub-expressions:
# 25. x
#     core type: Variable
#     sub-expressions:
