# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, Lambda, Variable
from proveit._common_ import m
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = Variable("_b", latexFormat = r"{_{-}b}")
expr = ExprRange(subExpr1, Lambda(subExpr2, [subExpr1, subExpr2]), one, m)
# Out:
# expr: [_b -> (1, _b)], ..[_b -> (_a, _b)].., [_b -> (m, _b)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[{_{-}b} \mapsto \left(1, {_{-}b}\right)\right], \ldots, \left[{_{-}b} \mapsto \left(m, {_{-}b}\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [_b -> (1, _b)], ..[_b -> (_a, _b)].., [_b -> (m, _b)]
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. _a -> [_b -> (_a, _b)]
#    core type: Lambda
#    parameter: 6
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. m
#    core type: Variable
#    sub-expressions:
# 4. _b -> (_a, _b)
#    core type: Lambda
#    parameter: 7
#    body: 5
# 5. (_a, _b)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. _a
#    core type: Variable
#    sub-expressions:
# 7. _b
#    core type: Variable
#    sub-expressions:
