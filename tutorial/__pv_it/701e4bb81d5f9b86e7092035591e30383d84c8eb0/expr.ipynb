# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import k, m, n
from proveit.logic import And, InSet
from proveit.number import Add, Complexes, Neg, one

# %%
# build up the expression from sub-expressions
expr = And(ExprRange(k, InSet(n, Complexes), one, Add(m, Neg(one))))
# Out:
# expr: (n in Complexes) and ..m - 1 repeats.. and (n in Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \in \mathbb{C}\right) \land ..m - 1 \textrm{ repeats}.. \land \left(n \in \mathbb{C}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (n in Complexes) and ..m - 1 repeats.. and (n in Complexes)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (n in Complexes, ..m - 1 repeats.., n in Complexes)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (n in Complexes), ..m - 1 repeats.., (n in Complexes)
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 17
#    end_index: 5
# 4. k -> (n in Complexes)
#    core type: Lambda
#    parameter: 6
#    body: 7
# 5. m - 1
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. k
#    core type: Variable
#    sub-expressions:
# 7. n in Complexes
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (m, -1)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (n, Complexes)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. m
#     core type: Variable
#     sub-expressions:
# 13. -1
#     core type: Operation
#     operator: 16
#     operand: 17
# 14. n
#     core type: Variable
#     sub-expressions:
# 15. Complexes
#     core type: Literal
#     sub-expressions:
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
