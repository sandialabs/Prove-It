# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import i
from proveit.core_expr_types._common_ import i_to_j_len
from proveit.logic import Equals, InSet, Set
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Set(InSet(i, NaturalsPos), Equals(i_to_j_len, i))
# Out:
# expr: {i in NaturalsPos, (j - i + 1) = i}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{i \in \mathbb{N}^+, \left(j - i + 1\right) = i\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {i in NaturalsPos, (j - i + 1) = i}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (i in NaturalsPos, (j - i + 1) = i)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. i in NaturalsPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (j - i + 1) = i
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (i, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 17, 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (j - i + 1, i)
#    core type: ExprTuple
#    sub-expressions: 10, 17
# 9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. j - i + 1
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (j, -i, 1)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 13. j
#     core type: Variable
#     sub-expressions:
# 14. -i
#     core type: Operation
#     operator: 16
#     operand: 17
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. i
#     core type: Variable
#     sub-expressions:
