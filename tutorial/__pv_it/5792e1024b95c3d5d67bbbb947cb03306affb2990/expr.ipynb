# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import i
from proveit.logic import Equals
from proveit.number import Add, Mult, Neg, one, two

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(one)
expr = Equals(Add(Add(Add(i, subExpr1).withSubtractionAt(), subExpr1, one), Add(i, subExpr1, one)), Add(Mult(two, i), subExpr1).withSubtractionAt())
# Out:
# expr: (((i + (-1)) - 1 + 1) + (i - 1 + 1)) = ((2 * i) + (-1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\left(i + \left(-1\right)\right) - 1 + 1\right) + \left(i - 1 + 1\right)\right) = \left(\left(2 \cdot i\right) + \left(-1\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (((i + (-1)) - 1 + 1) + (i - 1 + 1)) = ((2 * i) + (-1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (((i + (-1)) - 1 + 1) + (i - 1 + 1), (2 * i) + (-1))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. ((i + (-1)) - 1 + 1) + (i - 1 + 1)
#    core type: Operation
#    operator: 16
#    operands: 5
# 4. (2 * i) + (-1)
#    core type: Operation
#    operator: 16
#    operands: 6
# 5. ((i + (-1)) - 1 + 1, i - 1 + 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (2 * i, -1)
#    core type: ExprTuple
#    sub-expressions: 9, 19
# 7. (i + (-1)) - 1 + 1
#    core type: Operation
#    operator: 16
#    operands: 10
# 8. i - 1 + 1
#    core type: Operation
#    operator: 16
#    operands: 11
# 9. 2 * i
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. (i + (-1), -1, 1)
#     core type: ExprTuple
#     sub-expressions: 14, 19, 21
# 11. (i, -1, 1)
#     core type: ExprTuple
# ...
