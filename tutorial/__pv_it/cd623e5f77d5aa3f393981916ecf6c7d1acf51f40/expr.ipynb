# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Function, Lambda
from proveit._common_ import P, a, b, c, d
from proveit.logic import Forall

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Forall([c], Forall([d], Function(P, [a, b, c, d]))))
# Out:
# expr: b -> [forall_{c} [forall_{d} P(a, b, c, d)]]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# b \mapsto \left[\forall_{c}~\left[\forall_{d}~P(a, b, c, d)\right]\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> [forall_{c} [forall_{d} P(a, b, c, d)]]
#    core type: Lambda
#    parameter: 10
#    body: 1
# 1. forall_{c} [forall_{d} P(a, b, c, d)]
#    core type: Operation
#    operator: 4
#    operand: 2
# 2. c -> [forall_{d} P(a, b, c, d)]
#    core type: Lambda
#    parameter: 11
#    body: 3
# 3. forall_{d} P(a, b, c, d)
#    core type: Operation
#    operator: 4
#    operand: 5
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. d -> P(a, b, c, d)
#    core type: Lambda
#    parameter: 12
#    body: 6
# 6. P(a, b, c, d)
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. P
#    core type: Variable
#    sub-expressions:
# 8. (a, b, c, d)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. d
#     core type: Variable
#     sub-expressions:
