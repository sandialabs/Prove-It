# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C
from proveit.logic import Booleans, Forall, Implies, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], C, domains = [Booleans, Booleans], conditions = [Or(A, B), Implies(A, C), Implies(B, C)])
# Out:
# expr: forall_{A in BOOLEANS, B in BOOLEANS | A or B, A => C, B => C} C

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A \in \mathbb{B}, B \in \mathbb{B}~|~A \lor B, A \Rightarrow C, B \Rightarrow C}~C

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A in BOOLEANS, B in BOOLEANS | A or B, A => C, B => C} C
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A, B) -> {C if A in BOOLEANS ,  B in BOOLEANS ,  A or B ,  A => C ,  B => C.
#    core type: Lambda
#    parameters: 16\n   body: 3
# 3. {C if A in BOOLEANS ,  B in BOOLEANS ,  A or B ,  A => C ,  B => C.
#    core type: Conditional
#    value: 23
#    condition: 4
# 4. (A in BOOLEANS) and (B in BOOLEANS) and (A or B) and (A => C) and (B => C)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A in BOOLEANS, B in BOOLEANS, A or B, A => C, B => C)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10, 11
# 7. A in BOOLEANS
#    core type: Operation
#    operator: 13
#    operands: 12
# 8. B in BOOLEANS
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. A or B
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. A => C
#     core type: Operation
#     operator: 18
#     operands: 17
# 11. B => C
#     core type: Operation
#     operator: 18
#     operands: 19
# 12. (A, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (B, BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 22, 20
# 15. or
#     core type: Literal
#     sub-expressions:
# 16. (A, B)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 17. (A, C)
#     core type: ExprTuple
#     sub-expressions: 21, 23
# 18. =>
#     core type: Literal
#     sub-expressions:
# 19. (B, C)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 21. A
#     core type: Variable
#     sub-expressions:
# 22. B
#     core type: Variable
#     sub-expressions:
# 23. C
#     core type: Variable
#     sub-expressions:
