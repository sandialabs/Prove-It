# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import b, j
from proveit.logic import InSet
from proveit.number import Complexes, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = ExprRange(subExpr1, InSet(IndexedVar(b, subExpr1), Complexes), one, j)
# Out:
# expr: (b_{1} in Complexes), ..(b_{_a} in Complexes).., (b_{j} in Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(b_{1} \in \mathbb{C}\right), \ldots, \left(b_{j} \in \mathbb{C}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (b_{1} in Complexes), ..(b_{_a} in Complexes).., (b_{j} in Complexes)
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. _a -> (b_{_a} in Complexes)
#    core type: Lambda
#    parameter: 10
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. j
#    core type: Variable
#    sub-expressions:
# 4. b_{_a} in Complexes
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (b_{_a}, Complexes)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. b_{_a}
#    core type: IndexedVar
# variable: 9
# index: 10
# 8. Complexes
#    core type: Literal
#    sub-expressions:
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. _a
#     core type: Variable
#     sub-expressions:
