# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Lambda
from proveit._common_ import k, n, x
from proveit.logic import And, Equals, InSet
from proveit.number import Add, Complexes, Mult, Naturals, one

# %%
# build up the expression from sub-expressions
expr = Lambda([n, x], Conditional(Equals(Add(ExprRange(k, x, one, n)), Mult(n, x)), And(InSet(n, Naturals), InSet(x, Complexes))))
# Out:
# expr: (n, x) -> {(x + ..n repeats.. + x) = (n * x) if n in Naturals ,  x in Complexes.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n, x\right) \mapsto \left\{\left(x + ..n \textrm{ repeats}.. + x\right) = \left(n \cdot x\right) \textrm{ if } n \in \mathbb{N} ,  x \in \mathbb{C}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (n, x) -> {(x + ..n repeats.. + x) = (n * x) if n in Naturals ,  x in Complexes.
#    core type: Lambda
#    parameters: 15\n   body: 1
# 1. {(x + ..n repeats.. + x) = (n * x) if n in Naturals ,  x in Complexes.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (x + ..n repeats.. + x) = (n * x)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (n in Naturals) and (x in Complexes)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (x + ..n repeats.. + x, n * x)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (n in Naturals, x in Complexes)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. x + ..n repeats.. + x
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. n * x
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. n in Naturals
#     core type: Operation
#     operator: 17
# ...
