# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, Function, IndexedVar, Lambda
from proveit._common_ import a, f, n, x
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = ExprRange(a, Lambda(x, Function(IndexedVar(f, a), x)), one, n)
# Out:
# expr: [x -> f_{1}(x)], ..[x -> f_{a}(x)].., [x -> f_{n}(x)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[x \mapsto f_{1}(x)\right], \ldots, \left[x \mapsto f_{n}(x)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [x -> f_{1}(x)], ..[x -> f_{a}(x)].., [x -> f_{n}(x)]
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. a -> [x -> f_{a}(x)]
#    core type: Lambda
#    parameter: 9
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. n
#    core type: Variable
#    sub-expressions:
# 4. x -> f_{a}(x)
#    core type: Lambda
#    parameter: 7
#    body: 5
# 5. f_{a}(x)
#    core type: Operation
#    operator: 6
#    operand: 7
# 6. f_{a}
#    core type: IndexedVar
# variable: 8
# index: 9
# 7. x
#    core type: Variable
#    sub-expressions:
# 8. f
#    core type: Variable
#    sub-expressions:
# 9. a
#    core type: Variable
#    sub-expressions:
