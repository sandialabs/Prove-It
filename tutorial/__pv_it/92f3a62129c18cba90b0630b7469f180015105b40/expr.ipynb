# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import a, n
from proveit.number import Mult, one, two

# %%
# build up the expression from sub-expressions
expr = ExprRange(a, Mult(a, a), one, Mult(two, n))
# Out:
# expr: (1 * 1), ..(a * a).., ((2 * n) * (2 * n))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1 \cdot 1\right), \ldots, \left(\left(2 \cdot n\right) \cdot \left(2 \cdot n\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (1 * 1), ..(a * a).., ((2 * n) * (2 * n))
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. a -> (a * a)
#    core type: Lambda
#    parameter: 10
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. 2 * n
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. a * a
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (2, n)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. *
#    core type: Literal
#    sub-expressions:
# 7. (a, a)
#    core type: ExprTuple
#    sub-expressions: 10, 10
# 8. 2
#    core type: Literal
#    sub-expressions:
# 9. n
#    core type: Variable
#    sub-expressions:
# 10. a
#     core type: Variable
#     sub-expressions:
