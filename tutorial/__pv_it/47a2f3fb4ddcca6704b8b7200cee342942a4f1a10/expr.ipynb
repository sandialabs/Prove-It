# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import a, i, j
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple([ExprRange(a, a, one, Add(i, Neg(one)).withSubtractionAt()), ExprRange(a, a, i, j)], [ExprRange(a, a, one, j)])
# Out:
# expr: ((1, ..a.., i + (-1), i, ..a.., j), (1, ..a.., j))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(1, \ldots, i + \left(-1\right), i, \ldots, j\right), \left(1, \ldots, j\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((1, ..a.., i + (-1), i, ..a.., j), (1, ..a.., j))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (1, ..a.., i + (-1), i, ..a.., j)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 2. (1, ..a.., j)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. 1, ..a.., (i + (-1))
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 15
#    end_index: 6
# 4. i, ..a.., j
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 12
#    end_index: 8
# 5. 1, ..a.., j
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 15
#    end_index: 8
# 6. i + (-1)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. a -> a
#    core type: Lambda
#    parameter: 11
#    body: 11
# 8. j
#    core type: Variable
#    sub-expressions:
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (i, -1)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. i
#     core type: Variable
#     sub-expressions:
# 13. -1
#     core type: Operation
#     operator: 14
#     operand: 15
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
