# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Variable
from proveit._common_ import k, m, n, x
from proveit.number import Add, Mult, one, zero

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = ExprTuple(ExprRange(subExpr1, Mult(subExpr1, subExpr1), zero, k), x, ExprRange(subExpr1, subExpr1, one, m), ExprRange(subExpr1, Add(subExpr1, subExpr1), one, n))
# Out:
# expr: (0 * 0, .._a * _a.., k * k, x, 1, .._a.., m, 1 + 1, .._a + _a.., n + n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(0 \cdot 0, \ldots, k \cdot k, x, 1, \ldots, m, 1 + 1, \ldots, n + n\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (0 * 0, .._a * _a.., k * k, x, 1, .._a.., m, 1 + 1, .._a + _a.., n + n)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. (0 * 0), ..(_a * _a).., (k * k)
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 2. x
#    core type: Variable
#    sub-expressions:
# 3. 1, .._a.., m
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 11
#    end_index: 9
# 4. (1 + 1), ..(_a + _a).., (n + n)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 5. _a -> (_a * _a)
#    core type: Lambda
#    parameter: 18
#    body: 13
# 6. 0
#    core type: Literal
#    sub-expressions:
# 7. k
#    core type: Variable
#    sub-expressions:
# 8. _a -> _a
#    core type: Lambda
#    parameter: 18
#    body: 18
# 9. m
#    core type: Variable
#    sub-expressions:
# 10. _a -> (_a + _a)
#     core type: Lambda
#     parameter: 18
#     body: 14
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. n
# ...
