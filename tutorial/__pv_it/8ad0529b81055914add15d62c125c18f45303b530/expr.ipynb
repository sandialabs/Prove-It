# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import m, n
from proveit.logic import InSet, Set
from proveit.number import Naturals, NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Set(InSet(n, Naturals), InSet(m, NaturalsPos))
# Out:
# expr: {n in Naturals, m in NaturalsPos}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{n \in \mathbb{N}, m \in \mathbb{N}^+\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {n in Naturals, m in NaturalsPos}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (n in Naturals, m in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. n in Naturals
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. m in NaturalsPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (m, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. n
#    core type: Variable
#    sub-expressions:
# 9. Naturals
#    core type: Literal
#    sub-expressions:
# 10. m
#     core type: Variable
#     sub-expressions:
# 11. NaturalsPos
#     core type: Literal
#     sub-expressions:
