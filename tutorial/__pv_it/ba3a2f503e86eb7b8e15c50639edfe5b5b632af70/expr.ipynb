# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import R, a, k, m, x
from proveit.logic import Implies
from proveit.number import Add, Mult, one, zero

# %%
# build up the expression from sub-expressions
expr = Implies(Add(ExprRange(a, Mult(a, a), zero, k), x, ExprRange(a, a, one, m)), R)
# Out:
# expr: ((0 * 0) + ..(a * a).. + (k * k) + x + 1 + ..a.. + m) => R

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(0 \cdot 0\right) + \ldots + \left(k \cdot k\right) + x + 1 + \ldots + m\right) \Rightarrow R

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((0 * 0) + ..(a * a).. + (k * k) + x + 1 + ..a.. + m) => R
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. ((0 * 0) + ..(a * a).. + (k * k) + x + 1 + ..a.. + m, R)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (0 * 0) + ..(a * a).. + (k * k) + x + 1 + ..a.. + m
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. R
#    core type: Variable
#    sub-expressions:
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (0 * 0, ..a * a.., k * k, x, 1, ..a.., m)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. (0 * 0), ..(a * a).., (k * k)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. 1, ..a.., m
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 14
#    end_index: 15
# 10. a -> (a * a)
#     core type: Lambda
#     parameter: 19
#     body: 16
# 11. 0
#     core type: Literal
#     sub-expressions:
# 12. k
#     core type: Variable
#     sub-expressions:
# 13. a -> a
#     core type: Lambda
#     parameter: 19
#     body: 19
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. m
#     core type: Variable
#     sub-expressions:
# 16. a * a
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. *
#     core type: Literal
#     sub-expressions:
# 18. (a, a)
#     core type: ExprTuple
#     sub-expressions: 19, 19
# 19. a
#     core type: Variable
#     sub-expressions:
