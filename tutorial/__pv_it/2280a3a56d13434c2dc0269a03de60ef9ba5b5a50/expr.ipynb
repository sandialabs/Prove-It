# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar
from proveit._common_ import a, b, j, k, x
from proveit.core_expr_types import Len
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([ExprRange(x, IndexedVar(b, x), one, k), ExprRange(x, IndexedVar(a, x), one, j)]), Add(j, k))
# Out:
# expr: (|(b_{1}, ..b_{x}.., b_{k}, a_{1}, ..a_{x}.., a_{j})|, j + k)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(b_{1}, \ldots, b_{k}, a_{1}, \ldots, a_{j}\right)|, j + k\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(b_{1}, ..b_{x}.., b_{k}, a_{1}, ..a_{x}.., a_{j})|, j + k)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(b_{1}, ..b_{x}.., b_{k}, a_{1}, ..a_{x}.., a_{j})|
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. j + k
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. length
#    core type: Literal
#    sub-expressions:
# 4. ((b_{1}, ..b_{x}.., b_{k}, a_{1}, ..a_{x}.., a_{j}))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (j, k)
#    core type: ExprTuple
#    sub-expressions: 14, 11
# 7. (b_{1}, ..b_{x}.., b_{k}, a_{1}, ..a_{x}.., a_{j})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. b_{1}, ..b_{x}.., b_{k}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 13
#    end_index: 11
# 9. a_{1}, ..a_{x}.., a_{j}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 13
#    end_index: 14
# 10. x -> b_{x}
#     core type: Lambda
#     parameter: 19
#     body: 15
# 11. k
#     core type: Variable
#     sub-expressions:
# 12. x -> a_{x}
#     core type: Lambda
#     parameter: 19
#     body: 16
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. j
#     core type: Variable
#     sub-expressions:
# 15. b_{x}
#     core type: IndexedVar
# variable: 17
# index: 19
# 16. a_{x}
#     core type: IndexedVar
# variable: 18
# index: 19
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. x
#     core type: Variable
#     sub-expressions:
