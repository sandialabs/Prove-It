# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple, IndexedVar, Lambda, Variable
from proveit._common_ import B, C, k
from proveit.logic import Not

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = ExprTuple([Lambda(k, Not(IndexedVar(B, k))), Lambda(subExpr1, IndexedVar(C, subExpr1))])
# Out:
# expr: ((k -> [not](B_{k}), _a -> C_{_a}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(k \mapsto (\lnot B_{k}), {_{-}a} \mapsto C_{{_{-}a}}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((k -> [not](B_{k}), _a -> C_{_a}))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (k -> [not](B_{k}), _a -> C_{_a})
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. k -> [not](B_{k})
#    core type: Lambda
#    parameter: 11
#    body: 4
# 3. _a -> C_{_a}
#    core type: Lambda
#    parameter: 9
#    body: 5
# 4. [not](B_{k})
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. C_{_a}
#    core type: IndexedVar
# variable: 8
# index: 9
# 6. not
#    core type: Literal
#    sub-expressions:
# 7. B_{k}
#    core type: IndexedVar
# variable: 10
# index: 11
# 8. C
#    core type: Variable
#    sub-expressions:
# 9. _a
#    core type: Variable
#    sub-expressions:
# 10. B
#     core type: Variable
#     sub-expressions:
# 11. k
#     core type: Variable
#     sub-expressions:
