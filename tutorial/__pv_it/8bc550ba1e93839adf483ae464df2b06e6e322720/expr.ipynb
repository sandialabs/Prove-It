# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import IndexedVar
from proveit._common_ import A, B, C
from proveit.logic import Forall
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = IndexedVar(B, one)
subExpr2 = [IndexedVar(A, one), subExpr1, IndexedVar(C, one)]
expr = Forall(subExpr2, subExpr1, conditions = subExpr2)
# Out:
# expr: forall_{A_{1}, B_{1}, C_{1} | A_{1}, B_{1}, C_{1}} B_{1}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A_{1}, B_{1}, C_{1}~|~A_{1}, B_{1}, C_{1}}~B_{1}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A_{1}, B_{1}, C_{1} | A_{1}, B_{1}, C_{1}} B_{1}
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A_{1}, B_{1}, C_{1}) -> {B_{1} if A_{1} ,  B_{1} ,  C_{1}.
#    core type: Lambda
#    parameters: 6\n   body: 3
# 3. {B_{1} if A_{1} ,  B_{1} ,  C_{1}.
#    core type: Conditional
#    value: 8
#    condition: 4
# 4. A_{1} and B_{1} and C_{1}
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A_{1}, B_{1}, C_{1})
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. A_{1}
#    core type: IndexedVar
# variable: 10
# index: 13
# 8. B_{1}
#    core type: IndexedVar
# variable: 11
# index: 13
# 9. C_{1}
#    core type: IndexedVar
# variable: 12
# index: 13
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
# 12. C
#     core type: Variable
#     sub-expressions:
# 13. 1
#     core type: Literal
#     sub-expressions:
