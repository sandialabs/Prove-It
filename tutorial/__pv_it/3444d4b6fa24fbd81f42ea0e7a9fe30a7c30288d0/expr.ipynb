# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.number.Add.html">Add</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import i, j, k, n
from proveit.number import Add, Mult, one

# %%
# build up the expression from sub-expressions
expr = Add(ExprRange(i, ExprRange(j, ExprRange(k, Mult(i, j, k), one, n), one, n), one, n))
# Out:
# expr: (1 * 1 * 1)+..(1 * 1 * k)..+(1 * 1 * n)+....(1 * j * 1)+..(1 * j * k)..+(1 * j * n)....+(1 * n * 1)+..(1 * n * k)..+(1 * n * n) + ......(i * 1 * 1)+..(i * 1 * k)..+(i * 1 * n)+....(i * j * 1)+..(i * j * k)..+(i * j * n)....+(i * n * 1)+..(i * n * k)..+(i * n * n)...... + (n * 1 * 1)+..(n * 1 * k)..+(n * 1 * n)+....(n * j * 1)+..(n * j * k)..+(n * j * n)....+(n * n * 1)+..(n * n * k)..+(n * n * n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1 \cdot 1 \cdot 1\right)+\ldots+\left(1 \cdot 1 \cdot n\right)+\ldots\ldots+\left(1 \cdot n \cdot 1\right)+\ldots+\left(1 \cdot n \cdot n\right) + \ldots\ldots\ldots + \left(n \cdot 1 \cdot 1\right)+\ldots+\left(n \cdot 1 \cdot n\right)+\ldots\ldots+\left(n \cdot n \cdot 1\right)+\ldots+\left(n \cdot n \cdot n\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (1 * 1 * 1)+..(1 * 1 * k)..+(1 * 1 * n)+....(1 * j * 1)+..(1 * j * k)..+(1 * j * n)....+(1 * n * 1)+..(1 * n * k)..+(1 * n * n) + ......(i * 1 * 1)+..(i * 1 * k)..+(i * 1 * n)+....(i * j * 1)+..(i * j * k)..+(i * j * n)....+(i * n * 1)+..(i * n * k)..+(i * n * n)...... + (n * 1 * 1)+..(n * 1 * k)..+(n * 1 * n)+....(n * j * 1)+..(n * j * k)..+(n * j * n)....+(n * n * 1)+..(n * n * k)..+(n * n * n)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. +
#    core type: Literal
#    sub-expressions:
# 2. ((1 * 1 * 1), ..(1 * 1 * k).., (1 * 1 * n), ....(1 * j * 1), ..(1 * j * k).., (1 * j * n)...., (1 * n * 1), ..(1 * n * k).., (1 * n * n), ......(i * 1 * 1), ..(i * 1 * k).., (i * 1 * n), ....(i * j * 1), ..(i * j * k).., (i * j * n)...., (i * n * 1), ..(i * n * k).., (i * n * n)......, (n * 1 * 1), ..(n * 1 * k).., (n * 1 * n), ....(n * j * 1), ..(n * j * k).., (n * j * n)...., (n * n * 1), ..(n * n * k).., (n * n * n))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (1 * 1 * 1), ..(1 * 1 * k).., (1 * 1 * n), ....(1 * j * 1), ..(1 * j * k).., (1 * j * n)...., (1 * n * 1), ..(1 * n * k).., (1 * n * n), ......(i * 1 * 1), ..(i * 1 * k).., (i * 1 * n), ....(i * j * 1), ..(i * j * k).., (i * j * n)...., (i * n * 1), ..(i * n * k).., (i * n * n)......, (n * 1 * 1), ..(n * 1 * k).., (n * 1 * n), ....(n * j * 1), ..(n * j * k).., (n * j * n)...., (n * n * 1), ..(n * n * k).., (n * n * n)
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 9
#    end_index: 10
# 4. i -> (i * 1 * 1), ..(i * 1 * k).., (i * 1 * n), ....(i * j * 1), ..(i * j * k).., (i * j * n)...., (i * n * 1), ..(i * n * k).., (i * n * n)
#    core type: Lambda
#    parameter: 14
#    body: 5
# 5. (i * 1 * 1), ..(i * 1 * k).., (i * 1 * n), ....(i * j * 1), ..(i * j * k).., (i * j * n)...., (i * n * 1), ..(i * n * k).., (i * n * n)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 9
#    end_index: 10
# 6. j -> (i * j * 1), ..(i * j * k).., (i * j * n)
#    core type: Lambda
#    parameter: 15
#    body: 7
# 7. (i * j * 1), ..(i * j * k).., (i * j * n)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 8. k -> (i * j * k)
#    core type: Lambda
#    parameter: 16
#    body: 11
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. n
#     core type: Variable
#     sub-expressions:
# 11. i * j * k
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (i, j, k)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. j
#     core type: Variable
#     sub-expressions:
# 16. k
#     core type: Variable
#     sub-expressions:
