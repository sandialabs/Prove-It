# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import k, m, n, x
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.number import Add, Mult, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = Neg(one)
subExpr3 = Add(m, subExpr2)
subExpr4 = Add(n, subExpr2, one)
expr = Equals(Len([ExprRange(k, ExprRange(subExpr1, IndexedVar(IndexedVar(x, k), subExpr1), one, n), one, subExpr3), ExprRange(x, Mult(x, x), one, n)]), Add(ExprRange(k, subExpr4, one, subExpr3), subExpr4))
# Out:
# expr: |(x_{1,1}, ..x_{1,_a}.., x_{1,n}, ....x_{k,1}, ..x_{k,_a}.., x_{k,n}...., x_{m - 1,1}, ..x_{m - 1,_a}.., x_{m - 1,n}, 1 * 1, ..x * x.., n * n)| = ((n - 1 + 1) + ..m - 1 repeats.. + (n - 1 + 1) + (n - 1 + 1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(x_{1,1}, \ldots, x_{1,n}, \ldots\ldots, x_{m - 1,1}, \ldots, x_{m - 1,n}, 1 \cdot 1, \ldots, n \cdot n\right)| = \left(\left(n - 1 + 1\right) + ..m - 1 \textrm{ repeats}.. + \left(n - 1 + 1\right) + \left(n - 1 + 1\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |(x_{1,1}, ..x_{1,_a}.., x_{1,n}, ....x_{k,1}, ..x_{k,_a}.., x_{k,n}...., x_{m - 1,1}, ..x_{m - 1,_a}.., x_{m - 1,n}, 1 * 1, ..x * x.., n * n)| = ((n - 1 + 1) + ..m - 1 repeats.. + (n - 1 + 1) + (n - 1 + 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(x_{1,1}, ..x_{1,_a}.., x_{1,n}, ....x_{k,1}, ..x_{k,_a}.., x_{k,n}...., x_{m - 1,1}, ..x_{m - 1,_a}.., x_{m - 1,n}, 1 * 1, ..x * x.., n * n)|, (n - 1 + 1) + ..m - 1 repeats.. + (n - 1 + 1) + (n - 1 + 1))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(x_{1,1}, ..x_{1,_a}.., x_{1,n}, ....x_{k,1}, ..x_{k,_a}.., x_{k,n}...., x_{m - 1,1}, ..x_{m - 1,_a}.., x_{m - 1,n}, 1 * 1, ..x * x.., n * n)|
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (n - 1 + 1) + ..m - 1 repeats.. + (n - 1 + 1) + (n - 1 + 1)
#    core type: Operation
#    operator: 20
#    operands: 7
# 5. length
#    core type: Literal
#    sub-expressions:
# ...
