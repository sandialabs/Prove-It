# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar
from proveit._common_ import a, m, x, y
from proveit.number import Mult, one

# %%
# build up the expression from sub-expressions
expr = ExprRange(a, Mult(IndexedVar(x, a), IndexedVar(y, a)), one, m)
# Out:
# expr: (x_{1} * y_{1}), ..(x_{a} * y_{a}).., (x_{m} * y_{m})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1} \cdot y_{1}\right), \ldots, \left(x_{m} \cdot y_{m}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_{1} * y_{1}), ..(x_{a} * y_{a}).., (x_{m} * y_{m})
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. a -> (x_{a} * y_{a})
#    core type: Lambda
#    parameter: 11
#    body: 4
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. m
#    core type: Variable
#    sub-expressions:
# 4. x_{a} * y_{a}
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (x_{a}, y_{a})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. x_{a}
#    core type: IndexedVar
# variable: 9
# index: 11
# 8. y_{a}
#    core type: IndexedVar
# variable: 10
# index: 11
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. y
#     core type: Variable
#     sub-expressions:
# 11. a
#     core type: Variable
#     sub-expressions:
