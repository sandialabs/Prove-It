# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.core_expr_types.Len.html">Len</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import k, m, n, x
from proveit.core_expr_types import Len
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Len([ExprRange(k, ExprRange(x, [k, x], one, n), one, m)])
# Out:
# expr: |((1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n))|

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(\left(1, 1\right), \ldots, \left(1, n\right), \ldots\ldots, \left(m, 1\right), \ldots, \left(m, n\right)\right)|

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |((1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n))|
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. length
#    core type: Literal
#    sub-expressions:
# 2. (((1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n)))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. ((1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n))
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n)
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 9
#    end_index: 6
# 5. k -> (k, 1), ..(k, x).., (k, n)
#    core type: Lambda
#    parameter: 12
#    body: 7
# 6. m
#    core type: Variable
#    sub-expressions:
# 7. (k, 1), ..(k, x).., (k, n)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 8. x -> (k, x)
#    core type: Lambda
#    parameter: 13
#    body: 11
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. n
#     core type: Variable
#     sub-expressions:
# 11. (k, x)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. k
#     core type: Variable
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
