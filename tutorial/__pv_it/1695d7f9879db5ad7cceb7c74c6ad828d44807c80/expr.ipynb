# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import j, k
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(one)
expr = ExprTuple(Add(Add(k, subExpr1, one), Add(j, subExpr1, one)), Add(k, j))
# Out:
# expr: ((k - 1 + 1) + (j - 1 + 1), k + j)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(k - 1 + 1\right) + \left(j - 1 + 1\right), k + j\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((k - 1 + 1) + (j - 1 + 1), k + j)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (k - 1 + 1) + (j - 1 + 1)
#    core type: Operation
#    operator: 8
#    operands: 3
# 2. k + j
#    core type: Operation
#    operator: 8
#    operands: 4
# 3. (k - 1 + 1, j - 1 + 1)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (k, j)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 5. k - 1 + 1
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. j - 1 + 1
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (k, -1, 1)
#    core type: ExprTuple
#    sub-expressions: 10, 12, 14
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (j, -1, 1)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 14
# 10. k
#     core type: Variable
#     sub-expressions:
# 11. j
#     core type: Variable
#     sub-expressions:
# 12. -1
#     core type: Operation
#     operator: 13
#     operand: 14
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. 1
#     core type: Literal
#     sub-expressions:
