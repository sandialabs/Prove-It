# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import Q, R, a, k, m, n, x
from proveit.core_expr_types import Len
from proveit.logic import Equals, Implies
from proveit.number import Add, Mult, one, zero

# %%
# build up the expression from sub-expressions
subExpr1 = ExprRange(a, a, one, m)
subExpr2 = ExprRange(a, Mult(a, a), zero, k)
expr = ExprTuple(Implies(Add(subExpr2, x, subExpr1), Q), Implies(Q, R), Equals(Len([subExpr2, x, subExpr1]), Len([ExprRange(a, a, one, n)])))
# Out:
# expr: (((0 * 0) + ..(a * a).. + (k * k) + x + 1 + ..a.. + m) => Q, Q => R, |(0 * 0, ..a * a.., k * k, x, 1, ..a.., m)| = |(1, ..a.., n)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\left(0 \cdot 0\right) + \ldots + \left(k \cdot k\right) + x + 1 + \ldots + m\right) \Rightarrow Q, Q \Rightarrow R, |\left(0 \cdot 0, \ldots, k \cdot k, x, 1, \ldots, m\right)| = |\left(1, \ldots, n\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (((0 * 0) + ..(a * a).. + (k * k) + x + 1 + ..a.. + m) => Q, Q => R, |(0 * 0, ..a * a.., k * k, x, 1, ..a.., m)| = |(1, ..a.., n)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. ((0 * 0) + ..(a * a).. + (k * k) + x + 1 + ..a.. + m) => Q
#    core type: Operation
#    operator: 5
#    operands: 4
# 2. Q => R
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. |(0 * 0, ..a * a.., k * k, x, 1, ..a.., m)| = |(1, ..a.., n)|
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. ((0 * 0) + ..(a * a).. + (k * k) + x + 1 + ..a.. + m, Q)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (Q, R)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (|(0 * 0, ..a * a.., k * k, x, 1, ..a.., m)|, |(1, ..a.., n)|)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. (0 * 0) + ..(a * a).. + (k * k) + x + 1 + ..a.. + m
# ...
