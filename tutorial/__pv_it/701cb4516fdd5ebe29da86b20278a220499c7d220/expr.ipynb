# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import n, x
from proveit.logic import And, InSet
from proveit.number import Complexes, Naturals

# %%
# build up the expression from sub-expressions
expr = And(InSet(n, Naturals), InSet(x, Complexes))
# Out:
# expr: (n in Naturals) and (x in Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \in \mathbb{N}\right) \land \left(x \in \mathbb{C}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (n in Naturals) and (x in Complexes)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (n in Naturals, x in Complexes)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. n in Naturals
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. x in Complexes
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (n, Naturals)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, Complexes)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. n
#    core type: Variable
#    sub-expressions:
# 9. Naturals
#    core type: Literal
#    sub-expressions:
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. Complexes
#     core type: Literal
#     sub-expressions:
