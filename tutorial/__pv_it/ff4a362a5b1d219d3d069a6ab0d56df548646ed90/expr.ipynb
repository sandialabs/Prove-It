# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import m, n, x
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = Variable("_b", latexFormat = r"{_{-}b}")
expr = ExprRange(subExpr1, ExprRange(subExpr2, IndexedVar(IndexedVar(x, subExpr1), subExpr2), one, n), one, m)
# Out:
# expr: x_{1,1}, ..x_{1,_b}.., x_{1,n}, ....x_{_a,1}, ..x_{_a,_b}.., x_{_a,n}...., x_{m,1}, ..x_{m,_b}.., x_{m,n}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x_{1,1}, \ldots, x_{1,n}, \ldots\ldots, x_{m,1}, \ldots, x_{m,n}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x_{1,1}, ..x_{1,_b}.., x_{1,n}, ....x_{_a,1}, ..x_{_a,_b}.., x_{_a,n}...., x_{m,1}, ..x_{m,_b}.., x_{m,n}
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 5
#    end_index: 2
# 1. _a -> x_{_a,1}, ..x_{_a,_b}.., x_{_a,n}
#    core type: Lambda
#    parameter: 11
#    body: 3
# 2. m
#    core type: Variable
#    sub-expressions:
# 3. x_{_a,1}, ..x_{_a,_b}.., x_{_a,n}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. _b -> x_{_a,_b}
#    core type: Lambda
#    parameter: 9
#    body: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. n
#    core type: Variable
#    sub-expressions:
# 7. x_{_a,_b}
#    core type: IndexedVar
# variable: 8
# index: 9
# 8. x_{_a}
#    core type: IndexedVar
# variable: 10
# index: 11
# 9. _b
#    core type: Variable
#    sub-expressions:
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. _a
#     core type: Variable
#     sub-expressions:
