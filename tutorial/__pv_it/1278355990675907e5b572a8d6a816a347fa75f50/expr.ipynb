# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Lambda
from proveit._common_ import a, n, x, y
from proveit.core_expr_types._common_ import x_1_to_n, y_1_to_n
from proveit.number import Add, Mult, one

# %%
# build up the expression from sub-expressions
expr = Lambda([x_1_to_n, y_1_to_n], Add(ExprRange(a, Mult(IndexedVar(x, a), IndexedVar(y, a)), one, n)))
# Out:
# expr: (x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> ((x_{1} * y_{1}) + ..(x_{a} * y_{a}).. + (x_{n} * y_{n}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1}, \ldots, x_{n}, y_{1}, \ldots, y_{n}\right) \mapsto \left(\left(x_{1} \cdot y_{1}\right) + \ldots + \left(x_{n} \cdot y_{n}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n}) -> ((x_{1} * y_{1}) + ..(x_{a} * y_{a}).. + (x_{n} * y_{n}))
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 2. (x_{1} * y_{1}) + ..(x_{a} * y_{a}).. + (x_{n} * y_{n})
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. x_{1}, ..x_{_a}.., x_{n}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 13
#    end_index: 14
# 4. y_{1}, ..y_{_a}.., y_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 13
#    end_index: 14
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (x_{1} * y_{1}, ..x_{a} * y_{a}.., x_{n} * y_{n})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. _a -> x_{_a}
#    core type: Lambda
#    parameter: 15
#    body: 10
# 8. _a -> y_{_a}
#    core type: Lambda
#    parameter: 15
#    body: 11
# 9. (x_{1} * y_{1}), ..(x_{a} * y_{a}).., (x_{n} * y_{n})
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 13
#    end_index: 14
# 10. x_{_a}
#     core type: IndexedVar
# variable: 21
# index: 15
# 11. y_{_a}
#     core type: IndexedVar
# variable: 22
# index: 15
# 12. a -> (x_{a} * y_{a})
#     core type: Lambda
#     parameter: 23
#     body: 16
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. n
#     core type: Variable
#     sub-expressions:
# 15. _a
#     core type: Variable
#     sub-expressions:
# 16. x_{a} * y_{a}
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. *
#     core type: Literal
#     sub-expressions:
# 18. (x_{a}, y_{a})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. x_{a}
#     core type: IndexedVar
# variable: 21
# index: 23
# 20. y_{a}
#     core type: IndexedVar
# variable: 22
# index: 23
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. y
#     core type: Variable
#     sub-expressions:
# 23. a
#     core type: Variable
#     sub-expressions:
