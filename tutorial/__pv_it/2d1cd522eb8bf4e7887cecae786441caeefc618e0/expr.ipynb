# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import k, m, n
from proveit.logic import Equals
from proveit.number import Add, Mult, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Add(m, Neg(one))
expr = Equals(Add(ExprRange(k, n, one, subExpr1)), Mult(subExpr1, n))
# Out:
# expr: (n + ..m - 1 repeats.. + n) = ((m - 1) * n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n + ..m - 1 \textrm{ repeats}.. + n\right) = \left(\left(m - 1\right) \cdot n\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (n + ..m - 1 repeats.. + n) = ((m - 1) * n)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (n + ..m - 1 repeats.. + n, (m - 1) * n)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. n + ..m - 1 repeats.. + n
#    core type: Operation
#    operator: 13
#    operands: 5
# 4. (m - 1) * n
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (n, ..m - 1 repeats.., n)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. *
#    core type: Literal
#    sub-expressions:
# 7. (m - 1, n)
#    core type: ExprTuple
#    sub-expressions: 10, 12
# 8. n, ..m - 1 repeats.., n
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 18
#    end_index: 10
# 9. k -> n
#    core type: Lambda
#    parameter: 11
#    body: 12
# 10. m - 1
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. k
#     core type: Variable
#     sub-expressions:
# 12. n
#     core type: Variable
#     sub-expressions:
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (m, -1)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. m
#     core type: Variable
#     sub-expressions:
# 16. -1
#     core type: Operation
#     operator: 17
#     operand: 18
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. 1
#     core type: Literal
#     sub-expressions:
