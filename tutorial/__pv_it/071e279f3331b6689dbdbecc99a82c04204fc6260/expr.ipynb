# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import A, B, C, D, i
from proveit.core_expr_types._common_ import A_i_to_j
from proveit.logic import And, Forall, Not, Or
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = And(ExprRange(subExpr1, Not(IndexedVar(B, subExpr1)), one, Add(i, Neg(one)).withSubtractionAt()), ExprRange(subExpr1, IndexedVar(C, subExpr1), one, i), Forall([A_i_to_j], Or(A_i_to_j)), Or(A, D))
# Out:
# expr: [not](B_{1}) and ..[not](B_{_a}).. and [not](B_{i + (-1)}) and C_{1} and ..C_{_a}.. and C_{i} and [forall_{A_{i}, ..A_{_a}.., A_{j}} (A_{i} or ..A_{_a}.. or A_{j})] and (A or D)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# (\lnot B_{1}) \land \ldots \land (\lnot B_{i + \left(-1\right)}) \land C_{1} \land \ldots \land C_{i} \land \left[\forall_{A_{i}, \ldots, A_{j}}~\left(A_{i} \lor \ldots \lor A_{j}\right)\right] \land \left(A \lor D\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [not](B_{1}) and ..[not](B_{_a}).. and [not](B_{i + (-1)}) and C_{1} and ..C_{_a}.. and C_{i} and [forall_{A_{i}, ..A_{_a}.., A_{j}} (A_{i} or ..A_{_a}.. or A_{j})] and (A or D)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. ([not](B_{1}), ..[not](B_{_a}).., [not](B_{i + (-1)}), C_{1}, ..C_{_a}.., C_{i}, forall_{A_{i}, ..A_{_a}.., A_{j}} (A_{i} or ..A_{_a}.. or A_{j}), A or D)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. [not](B_{1}), ..[not](B_{_a}).., [not](B_{i + (-1)})
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 27
#    end_index: 8
# 4. C_{1}, ..C_{_a}.., C_{i}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 27
#    end_index: 30
# 5. forall_{A_{i}, ..A_{_a}.., A_{j}} (A_{i} or ..A_{_a}.. or A_{j})
#    core type: Operation
#    operator: 10
#    operand: 11
# 6. A or D
#    core type: Operation
#    operator: 23
#    operands: 12
# ...
