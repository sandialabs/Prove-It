# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import B
from proveit.core_expr_types._common_ import A_1_to_m, C_1_to_n
from proveit.logic import And, Booleans, InSet

# %%
# build up the expression from sub-expressions
expr = InSet(And(A_1_to_m, B, C_1_to_n), Booleans)
# Out:
# expr: (A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}) in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1} \land \ldots \land A_{m} \land B \land C_{1} \land \ldots \land C_{n}\right) \in \mathbb{B}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}) in BOOLEANS
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}, BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A_{1} and ..A_{_a}.. and A_{m} and B and C_{1} and ..C_{_a}.. and C_{n}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A_{1}, ..A_{_a}.., A_{m}, B, C_{1}, ..C_{_a}.., C_{n})
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. A_{1}, ..A_{_a}.., A_{m}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 13
#    end_index: 11
# 8. B
#    core type: Variable
#    sub-expressions:
# 9. C_{1}, ..C_{_a}.., C_{n}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 13
#    end_index: 14
# 10. _a -> A_{_a}
#     core type: Lambda
#     parameter: 19
#     body: 15
# 11. m
#     core type: Variable
#     sub-expressions:
# 12. _a -> C_{_a}
#     core type: Lambda
#     parameter: 19
#     body: 16
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. n
#     core type: Variable
#     sub-expressions:
# 15. A_{_a}
#     core type: IndexedVar
# variable: 17
# index: 19
# 16. C_{_a}
#     core type: IndexedVar
# variable: 18
# index: 19
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. C
#     core type: Variable
#     sub-expressions:
# 19. _a
#     core type: Variable
#     sub-expressions:
