# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Function
from proveit._common_ import Q, a, f, k, m, x
from proveit.number import Mult, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Function(f, [ExprRange(a, Mult(a, a), zero, k), x, ExprRange(a, a, one, m)]), Q)
# Out:
# expr: (f(0 * 0, ..a * a.., k * k, x, 1, ..a.., m), Q)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f(0 \cdot 0, \ldots, k \cdot k, x, 1, \ldots, m), Q\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (f(0 * 0, ..a * a.., k * k, x, 1, ..a.., m), Q)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. f(0 * 0, ..a * a.., k * k, x, 1, ..a.., m)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. Q
#    core type: Variable
#    sub-expressions:
# 3. f
#    core type: Variable
#    sub-expressions:
# 4. (0 * 0, ..a * a.., k * k, x, 1, ..a.., m)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7
# 5. (0 * 0), ..(a * a).., (k * k)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 6. x
#    core type: Variable
#    sub-expressions:
# 7. 1, ..a.., m
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 12
#    end_index: 13
# 8. a -> (a * a)
#    core type: Lambda
#    parameter: 17
#    body: 14
# 9. 0
#    core type: Literal
#    sub-expressions:
# 10. k
#     core type: Variable
#     sub-expressions:
# 11. a -> a
#     core type: Lambda
#     parameter: 17
#     body: 17
# 12. 1
#     core type: Literal
# ...
