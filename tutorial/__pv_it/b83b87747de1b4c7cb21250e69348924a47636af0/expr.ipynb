# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import i, j
from proveit.logic import Equals
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(one)
subExpr2 = Neg(i)
expr = Equals(Add(i, subExpr1, Add(j, subExpr2, one)).withSubtractionAt(), Add(i, subExpr1, j, subExpr2, one).withSubtractionAt())
# Out:
# expr: (i + (-1) + (j - i + 1)) = (i + (-1) + j + (-i) + 1)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i + \left(-1\right) + \left(j - i + 1\right)\right) = \left(i + \left(-1\right) + j + \left(-i\right) + 1\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (i + (-1) + (j - i + 1)) = (i + (-1) + j + (-i) + 1)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (i + (-1) + (j - i + 1), i + (-1) + j + (-i) + 1)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. i + (-1) + (j - i + 1)
#    core type: Operation
#    operator: 9
#    operands: 5
# 4. i + (-1) + j + (-i) + 1
#    core type: Operation
#    operator: 9
#    operands: 6
# 5. (i, -1, j - i + 1)
#    core type: ExprTuple
#    sub-expressions: 15, 8, 7
# 6. (i, -1, j, -i, 1)
#    core type: ExprTuple
#    sub-expressions: 15, 8, 11, 12, 13
# 7. j - i + 1
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. -1
#    core type: Operation
#    operator: 14
#    operand: 13
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (j, -i, 1)
#     core type: ExprTuple
#     sub-expressions: 11, 12, 13
# 11. j
#     core type: Variable
#     sub-expressions:
# 12. -i
#     core type: Operation
#     operator: 14
#     operand: 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. i
#     core type: Variable
#     sub-expressions:
