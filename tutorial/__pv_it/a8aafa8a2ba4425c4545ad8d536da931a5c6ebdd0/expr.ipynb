# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Lambda, Variable
from proveit._common_ import m, x
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = Variable("_b", latexFormat = r"{_{-}b}")
expr = ExprRange(subExpr1, Lambda(subExpr2, IndexedVar(IndexedVar(x, subExpr1), subExpr2)), one, Add(m, Neg(one)))
# Out:
# expr: [_b -> x_{1,_b}], ..[_b -> x_{_a,_b}].., [_b -> x_{m - 1,_b}]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[{_{-}b} \mapsto x_{1,{_{-}b}}\right], \ldots, \left[{_{-}b} \mapsto x_{m - 1,{_{-}b}}\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [_b -> x_{1,_b}], ..[_b -> x_{_a,_b}].., [_b -> x_{m - 1,_b}]
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 12
#    end_index: 2
# 1. _a -> [_b -> x_{_a,_b}]
#    core type: Lambda
#    parameter: 14
#    body: 3
# 2. m - 1
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. _b -> x_{_a,_b}
#    core type: Lambda
#    parameter: 10
#    body: 6
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (m, -1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. x_{_a,_b}
#    core type: IndexedVar
# variable: 9
# index: 10
# 7. m
#    core type: Variable
#    sub-expressions:
# 8. -1
#    core type: Operation
#    operator: 11
#    operand: 12
# 9. x_{_a}
#    core type: IndexedVar
# variable: 13
# index: 14
# 10. _b
#     core type: Variable
#     sub-expressions:
# 11. -
#     core type: Literal
#     sub-expressions:
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. _a
# ...
