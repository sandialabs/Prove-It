# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import a, m
from proveit.logic import Equals
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
expr = Equals([ExprRange(a, a, one, m)], [ExprRange(a, a, one, Add(m, Neg(one))), m])
# Out:
# expr: (1, ..a.., m) = (1, ..a.., m - 1, m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1, \ldots, m\right) = \left(1, \ldots, m - 1, m\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (1, ..a.., m) = (1, ..a.., m - 1, m)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1, ..a.., m), (1, ..a.., m - 1, m))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1, ..a.., m)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (1, ..a.., m - 1, m)
#    core type: ExprTuple
#    sub-expressions: 6, 12
# 5. 1, ..a.., m
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 15
#    end_index: 12
# 6. 1, ..a.., (m - 1)
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 15
#    end_index: 8
# 7. a -> a
#    core type: Lambda
#    parameter: 9
#    body: 9
# 8. m - 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (m, -1)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. m
#     core type: Variable
#     sub-expressions:
# 13. -1
#     core type: Operation
#     operator: 14
#     operand: 15
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
