# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar
from proveit._common_ import A, a, i, j
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = IndexedVar(A, a)
expr = ExprTuple(ExprRange(a, subExpr1, one, Add(i, Neg(one))), ExprRange(a, subExpr1, i, j))
# Out:
# expr: (A_{1}, ..A_{a}.., A_{i - 1}, A_{i}, ..A_{a}.., A_{j})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1}, \ldots, A_{i - 1}, A_{i}, \ldots, A_{j}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1}, ..A_{a}.., A_{i - 1}, A_{i}, ..A_{a}.., A_{j})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. A_{1}, ..A_{a}.., A_{i - 1}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 14
#    end_index: 3
# 2. A_{i}, ..A_{a}.., A_{j}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 9
#    end_index: 5
# 3. i - 1
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. a -> A_{a}
#    core type: Lambda
#    parameter: 12
#    body: 8
# 5. j
#    core type: Variable
#    sub-expressions:
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (i, -1)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. A_{a}
#    core type: IndexedVar
# variable: 11
# index: 12
# 9. i
#    core type: Variable
#    sub-expressions:
# 10. -1
#     core type: Operation
#     operator: 13
#     operand: 14
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. 1
#     core type: Literal
#     sub-expressions:
