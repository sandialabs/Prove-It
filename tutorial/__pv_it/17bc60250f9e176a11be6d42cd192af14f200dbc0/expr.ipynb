# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, IndexedVar
from proveit._common_ import B
from proveit.logic import And
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = IndexedVar(B, one)
expr = ExprTuple(Conditional(subExpr1, And(subExpr1)), Conditional(subExpr1, subExpr1))
# Out:
# expr: (B_{1} if [and](B_{1}), B_{1} if B_{1})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(B_{1} \textrm{ if } \left[\land\right]\left(B_{1}\right), B_{1} \textrm{ if } B_{1}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (B_{1} if [and](B_{1}), B_{1} if B_{1})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. {B_{1} if [and](B_{1}).
#    core type: Conditional
#    value: 5
#    condition: 3
# 2. {B_{1} if B_{1}.
#    core type: Conditional
#    value: 5
#    condition: 5
# 3. [and](B_{1})
#    core type: Operation
#    operator: 4
#    operand: 5
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. B_{1}
#    core type: IndexedVar
# variable: 6
# index: 7
# 6. B
#    core type: Variable
#    sub-expressions:
# 7. 1
#    core type: Literal
#    sub-expressions:
