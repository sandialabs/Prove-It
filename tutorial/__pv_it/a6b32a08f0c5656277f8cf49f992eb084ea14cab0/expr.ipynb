# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Lambda, Variable
from proveit._common_ import n, x
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_b", latexFormat = r"{_{-}b}")
subExpr2 = Variable("_c", latexFormat = r"{_{-}c}")
expr = Lambda(subExpr1, ExprRange(subExpr2, IndexedVar(IndexedVar(IndexedVar(x, Variable("_a", latexFormat = r"{_{-}a}")), subExpr1), subExpr2), one, n))
# Out:
# expr: _b -> x_{_a,_b,1}, ..x_{_a,_b,_c}.., x_{_a,_b,n}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# {_{-}b} \mapsto x_{{_{-}a},{_{-}b},1}, \ldots, x_{{_{-}a},{_{-}b},n}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. _b -> x_{_a,_b,1}, ..x_{_a,_b,_c}.., x_{_a,_b,n}
#    core type: Lambda
#    parameter: 9
#    body: 1
# 1. x_{_a,_b,1}, ..x_{_a,_b,_c}.., x_{_a,_b,n}
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 3
#    end_index: 4
# 2. _c -> x_{_a,_b,_c}
#    core type: Lambda
#    parameter: 7
#    body: 5
# 3. 1
#    core type: Literal
#    sub-expressions:
# 4. n
#    core type: Variable
#    sub-expressions:
# 5. x_{_a,_b,_c}
#    core type: IndexedVar
# variable: 6
# index: 7
# 6. x_{_a,_b}
#    core type: IndexedVar
# variable: 8
# index: 9
# 7. _c
#    core type: Variable
#    sub-expressions:
# 8. x_{_a}
#    core type: IndexedVar
# variable: 10
# index: 11
# 9. _b
#    core type: Variable
#    sub-expressions:
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. _a
#     core type: Variable
#     sub-expressions:
