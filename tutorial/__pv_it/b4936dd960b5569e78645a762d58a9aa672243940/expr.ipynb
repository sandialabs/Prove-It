# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import i, j
from proveit.core_expr_types._common_ import i_to_j_len
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(one)
expr = ExprTuple(Add(Add(Add(i, subExpr1), subExpr1, one), i_to_j_len), j)
# Out:
# expr: (((i - 1) - 1 + 1) + (j - i + 1), j)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\left(i - 1\right) - 1 + 1\right) + \left(j - i + 1\right), j\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (((i - 1) - 1 + 1) + (j - i + 1), j)
#    core type: ExprTuple
#    sub-expressions: 1, 8
# 1. ((i - 1) - 1 + 1) + (j - i + 1)
#    core type: Operation
#    operator: 10
#    operands: 2
# 2. ((i - 1) - 1 + 1, j - i + 1)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (i - 1) - 1 + 1
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. j - i + 1
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (i - 1, -1, 1)
#    core type: ExprTuple
#    sub-expressions: 7, 13, 15
# 6. (j, -i, 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 15
# 7. i - 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. j
#    core type: Variable
#    sub-expressions:
# 9. -i
#    core type: Operation
#    operator: 14
#    operand: 12
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (i, -1)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. i
#     core type: Variable
#     sub-expressions:
# 13. -1
#     core type: Operation
#     operator: 14
#     operand: 15
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
