# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import a, b, c, d, k, m, n, x
from proveit.core_expr_types import Len
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([a, b, c, d]), Len([ExprRange(k, ExprRange(x, [k, x], one, n), one, m)]))
# Out:
# expr: (|(a, b, c, d)|, |((1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n))|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(a, b, c, d\right)|, |\left(\left(1, 1\right), \ldots, \left(1, n\right), \ldots\ldots, \left(m, 1\right), \ldots, \left(m, n\right)\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(a, b, c, d)|, |((1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n))|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(a, b, c, d)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |((1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n))|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((a, b, c, d))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. (((1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n)))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (a, b, c, d)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. ((1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n))
#    core type: ExprTuple
#    sub-expressions: 12
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. c
#     core type: Variable
#     sub-expressions:
# 11. d
#     core type: Variable
#     sub-expressions:
# 12. (1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n)
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 17
#     end_index: 14
# 13. k -> (k, 1), ..(k, x).., (k, n)
#     core type: Lambda
#     parameter: 20
#     body: 15
# 14. m
#     core type: Variable
#     sub-expressions:
# 15. (k, 1), ..(k, x).., (k, n)
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 16. x -> (k, x)
#     core type: Lambda
#     parameter: 21
#     body: 19
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. n
#     core type: Variable
#     sub-expressions:
# 19. (k, x)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. k
#     core type: Variable
#     sub-expressions:
# 21. x
#     core type: Variable
#     sub-expressions:
