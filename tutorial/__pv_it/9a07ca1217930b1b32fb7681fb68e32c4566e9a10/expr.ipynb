# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import f, i, j
from proveit.core_expr_types import Len
from proveit.core_expr_types._common_ import f_i_to_j, i_to_j_len, range_i_to_j
from proveit.logic import Equals, Forall, InSet
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Forall([f, i, j], Equals(Len([f_i_to_j]), Len([range_i_to_j])), condition = InSet(i_to_j_len, Naturals))
# Out:
# expr: forall_{f, i, j | (j - i + 1) in Naturals} (|(f(i), ..f(a).., f(j))| = |(i, ..k.., j)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{f, i, j~|~\left(j - i + 1\right) \in \mathbb{N}}~\left(|\left(f(i), \ldots, f(j)\right)| = |\left(i, \ldots, j\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{f, i, j | (j - i + 1) in Naturals} (|(f(i), ..f(a).., f(j))| = |(i, ..k.., j)|)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (f, i, j) -> {|(f(i), ..f(a).., f(j))| = |(i, ..k.., j)| if (j - i + 1) in Naturals.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f, i, j)
#    core type: ExprTuple
#    sub-expressions: 33, 29, 30
# 4. {|(f(i), ..f(a).., f(j))| = |(i, ..k.., j)| if (j - i + 1) in Naturals.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. |(f(i), ..f(a).., f(j))| = |(i, ..k.., j)|
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (j - i + 1) in Naturals
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (|(f(i), ..f(a).., f(j))|, |(i, ..k.., j)|)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (j - i + 1, Naturals)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. |(f(i), ..f(a).., f(j))|
#     core type: Operation
#     operator: 16
#     operand: 20
# 12. |(i, ..k.., j)|
#     core type: Operation
#     operator: 16
#     operand: 21
# 13. j - i + 1
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. Naturals
#     core type: Literal
#     sub-expressions:
# 15. ((f(i), ..f(a).., f(j)))
#     core type: ExprTuple
#     sub-expressions: 20
# 16. length
#     core type: Literal
#     sub-expressions:
# 17. ((i, ..k.., j))
#     core type: ExprTuple
#     sub-expressions: 21
# 18. +
#     core type: Literal
#     sub-expressions:
# 19. (j, -i, 1)
#     core type: ExprTuple
#     sub-expressions: 30, 22, 23
# 20. (f(i), ..f(a).., f(j))
#     core type: ExprTuple
#     sub-expressions: 24
# 21. (i, ..k.., j)
#     core type: ExprTuple
#     sub-expressions: 25
# 22. -i
#     core type: Operation
#     operator: 26
#     operand: 29
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. f(i), ..f(a).., f(j)
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 29
#     end_index: 30
# 25. i, ..k.., j
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 29
#     end_index: 30
# 26. -
#     core type: Literal
#     sub-expressions:
# 27. a -> f(a)
#     core type: Lambda
#     parameter: 34
#     body: 31
# 28. k -> k
#     core type: Lambda
#     parameter: 32
#     body: 32
# 29. i
#     core type: Variable
#     sub-expressions:
# 30. j
#     core type: Variable
#     sub-expressions:
# 31. f(a)
#     core type: Operation
#     operator: 33
#     operand: 34
# 32. k
#     core type: Variable
#     sub-expressions:
# 33. f
#     core type: Variable
#     sub-expressions:
# 34. a
#     core type: Variable
#     sub-expressions:
