# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import j, k, n
from proveit.core_expr_types import Len
from proveit.number import Neg, one, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([n, Neg(j)]), Len([ExprRange(k, k, one, two)]))
# Out:
# expr: (|(n, -j)|, |(1, ..k.., 2)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(n, -j\right)|, |\left(1, \ldots, 2\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(n, -j)|, |(1, ..k.., 2)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(n, -j)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 2)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((n, -j))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 2))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (n, -j)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (1, ..k.., 2)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. n
#    core type: Variable
#    sub-expressions:
# 9. -j
#    core type: Operation
#    operator: 11
#    operand: 12
# 10. 1, ..k.., 2
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 11. -
#     core type: Literal
#     sub-expressions:
# 12. j
#     core type: Variable
#     sub-expressions:
# 13. k -> k
#     core type: Lambda
#     parameter: 16
#     body: 16
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. k
#     core type: Variable
#     sub-expressions:
