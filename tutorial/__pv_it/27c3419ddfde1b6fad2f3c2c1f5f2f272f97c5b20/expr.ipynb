# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import j, n
from proveit.logic import InSet, Set
from proveit.number import Add, Naturals, Neg

# %%
# build up the expression from sub-expressions
expr = Set(InSet(j, Naturals), InSet(Add(n, Neg(j)), Naturals))
# Out:
# expr: {j in Naturals, (n - j) in Naturals}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{j \in \mathbb{N}, \left(n - j\right) \in \mathbb{N}\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {j in Naturals, (n - j) in Naturals}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (j in Naturals, (n - j) in Naturals)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. j in Naturals
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (n - j) in Naturals
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (j, Naturals)
#    core type: ExprTuple
#    sub-expressions: 15, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (n - j, Naturals)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. n - j
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. Naturals
#    core type: Literal
#    sub-expressions:
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (n, -j)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. n
#     core type: Variable
#     sub-expressions:
# 13. -j
#     core type: Operation
#     operator: 14
#     operand: 15
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. j
#     core type: Variable
#     sub-expressions:
