# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Function, Lambda
from proveit._common_ import k, n, x
from proveit.core_expr_types import Len
from proveit.core_expr_types._common_ import f_1_to_n, f_k, i_1_to_n, i_k, j_1_to_n, j_k
from proveit.logic import And, Equals, InSet
from proveit.number import Add, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Add(j_k, Neg(i_k), one)
expr = Lambda([f_1_to_n, i_1_to_n, j_1_to_n], Conditional(Equals(Len([ExprRange(k, ExprRange(x, Function(f_k, x), i_k, j_k), one, n)]), Add(ExprRange(k, subExpr1, one, n))), And(ExprRange(k, InSet(subExpr1, Naturals), one, n))))
# Out:
# expr: (f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n}) -> {|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)) if ((j_{1} - i_{1} + 1) in Naturals) and ..((j_{k} - i_{k} + 1) in Naturals).. and ((j_{n} - i_{n} + 1) in Naturals).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f_{1}, \ldots, f_{n}, i_{1}, \ldots, i_{n}, j_{1}, \ldots, j_{n}\right) \mapsto \left\{|\left(f_{1}(i_{1}), \ldots, f_{1}(j_{1}), \ldots\ldots, f_{n}(i_{n}), \ldots, f_{n}(j_{n})\right)| = \left(\left(j_{1} - i_{1} + 1\right) + \ldots + \left(j_{n} - i_{n} + 1\right)\right) \textrm{ if } \left(\left(j_{1} - i_{1} + 1\right) \in \mathbb{N}\right) \land \ldots \land \left(\left(j_{n} - i_{n} + 1\right) \in \mathbb{N}\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n}) -> {|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)) if ((j_{1} - i_{1} + 1) in Naturals) and ..((j_{k} - i_{k} + 1) in Naturals).. and ((j_{n} - i_{n} + 1) in Naturals).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (f_{1}, ..f_{_a}.., f_{n}, i_{1}, ..i_{_a}.., i_{n}, j_{1}, ..j_{_a}.., j_{n})
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 2. {|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)) if ((j_{1} - i_{1} + 1) in Naturals) and ..((j_{k} - i_{k} + 1) in Naturals).. and ((j_{n} - i_{n} + 1) in Naturals).
#    core type: Conditional
#    value: 6
#    condition: 7
# 3. f_{1}, ..f_{_a}.., f_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 43
#    end_index: 34
# 4. i_{1}, ..i_{_a}.., i_{n}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 43
#    end_index: 34
# 5. j_{1}, ..j_{_a}.., j_{n}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 43
#    end_index: 34
# 6. |(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))| = ((j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1))
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. ((j_{1} - i_{1} + 1) in Naturals) and ..((j_{k} - i_{k} + 1) in Naturals).. and ((j_{n} - i_{n} + 1) in Naturals)
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. _a -> f_{_a}
#    core type: Lambda
#    parameter: 21
#    body: 15
# 9. _a -> i_{_a}
#    core type: Lambda
#    parameter: 21
#    body: 16
# 10. _a -> j_{_a}
#     core type: Lambda
#     parameter: 21
#     body: 17
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (|(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))|, (j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. ((j_{1} - i_{1} + 1) in Naturals, ..(j_{k} - i_{k} + 1) in Naturals.., (j_{n} - i_{n} + 1) in Naturals)
#     core type: ExprTuple
#     sub-expressions: 20
# 15. f_{_a}
#     core type: IndexedVar
# variable: 51
# index: 21
# 16. i_{_a}
#     core type: IndexedVar
# variable: 50
# index: 21
# 17. j_{_a}
#     core type: IndexedVar
# variable: 45
# index: 21
# 18. |(f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))|
#     core type: Operation
#     operator: 22
#     operand: 26
# 19. (j_{1} - i_{1} + 1) + ..(j_{k} - i_{k} + 1).. + (j_{n} - i_{n} + 1)
#     core type: Operation
#     operator: 38
#     operands: 24
# 20. ((j_{1} - i_{1} + 1) in Naturals), ..((j_{k} - i_{k} + 1) in Naturals).., ((j_{n} - i_{n} + 1) in Naturals)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 43
#     end_index: 34
# 21. _a
#     core type: Variable
#     sub-expressions:
# 22. length
#     core type: Literal
#     sub-expressions:
# 23. ((f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n})))
#     core type: ExprTuple
#     sub-expressions: 26
# 24. (j_{1} - i_{1} + 1, ..j_{k} - i_{k} + 1.., j_{n} - i_{n} + 1)
#     core type: ExprTuple
#     sub-expressions: 27
# 25. k -> ((j_{k} - i_{k} + 1) in Naturals)
#     core type: Lambda
#     parameter: 52
#     body: 28
# 26. (f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n}))
#     core type: ExprTuple
#     sub-expressions: 29
# 27. (j_{1} - i_{1} + 1), ..(j_{k} - i_{k} + 1).., (j_{n} - i_{n} + 1)
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 43
#     end_index: 34
# 28. (j_{k} - i_{k} + 1) in Naturals
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. f_{1}(i_{1}), ..f_{1}(x).., f_{1}(j_{1}), ....f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})...., f_{n}(i_{n}), ..f_{n}(x).., f_{n}(j_{n})
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 43
#     end_index: 34
# 30. k -> (j_{k} - i_{k} + 1)
#     core type: Lambda
#     parameter: 52
#     body: 35
# 31. in
#     core type: Literal
#     sub-expressions:
# 32. (j_{k} - i_{k} + 1, Naturals)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. k -> f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})
#     core type: Lambda
#     parameter: 52
#     body: 37
# 34. n
#     core type: Variable
#     sub-expressions:
# 35. j_{k} - i_{k} + 1
#     core type: Operation
#     operator: 38
#     operands: 39
# 36. Naturals
#     core type: Literal
#     sub-expressions:
# 37. f_{k}(i_{k}), ..f_{k}(x).., f_{k}(j_{k})
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 47
#     end_index: 41
# 38. +
#     core type: Literal
#     sub-expressions:
# 39. (j_{k}, -i_{k}, 1)
#     core type: ExprTuple
#     sub-expressions: 41, 42, 43
# 40. x -> f_{k}(x)
#     core type: Lambda
#     parameter: 49
#     body: 44
# 41. j_{k}
#     core type: IndexedVar
# variable: 45
# index: 52
# 42. -i_{k}
#     core type: Operation
#     operator: 46
#     operand: 47
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. f_{k}(x)
#     core type: Operation
#     operator: 48
#     operand: 49
# 45. j
#     core type: Variable
#     sub-expressions:
# 46. -
#     core type: Literal
#     sub-expressions:
# 47. i_{k}
#     core type: IndexedVar
# variable: 50
# index: 52
# 48. f_{k}
#     core type: IndexedVar
# variable: 51
# index: 52
# 49. x
#     core type: Variable
#     sub-expressions:
# 50. i
#     core type: Variable
#     sub-expressions:
# 51. f
#     core type: Variable
#     sub-expressions:
# 52. k
#     core type: Variable
#     sub-expressions:
