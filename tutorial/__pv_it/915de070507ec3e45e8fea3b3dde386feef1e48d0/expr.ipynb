# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit._common_ import a, j, n
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = IndexedVar(a, subExpr1)
expr = ExprTuple([ExprRange(subExpr1, subExpr2, one, j), ExprRange(subExpr1, subExpr2, Add(j, one), n)])
# Out:
# expr: ((a_{1}, ..a_{_a}.., a_{j}, a_{j + 1}, ..a_{_a}.., a_{n}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1}, \ldots, a_{j}, a_{j + 1}, \ldots, a_{n}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((a_{1}, ..a_{_a}.., a_{j}, a_{j + 1}, ..a_{_a}.., a_{n}))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1}, ..a_{_a}.., a_{j}, a_{j + 1}, ..a_{_a}.., a_{n})
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. a_{1}, ..a_{_a}.., a_{j}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 13
#    end_index: 12
# 3. a_{j + 1}, ..a_{_a}.., a_{n}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 4. _a -> a_{_a}
#    core type: Lambda
#    parameter: 11
#    body: 7
# 5. j + 1
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. n
#    core type: Variable
#    sub-expressions:
# 7. a_{_a}
#    core type: IndexedVar
# variable: 10
# index: 11
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (j, 1)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. _a
#     core type: Variable
#     sub-expressions:
# 12. j
#     core type: Variable
#     sub-expressions:
# 13. 1
#     core type: Literal
#     sub-expressions:
