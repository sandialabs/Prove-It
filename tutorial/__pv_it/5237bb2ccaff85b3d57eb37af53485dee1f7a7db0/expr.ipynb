# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import k, n
from proveit.core_expr_types._common_ import i_k, j_k
from proveit.logic import InSet, Set
from proveit.number import Add, Naturals, NaturalsPos, Neg, one

# %%
# build up the expression from sub-expressions
expr = Set(InSet(n, NaturalsPos), ExprRange(k, InSet(Add(j_k, Neg(i_k), one), Naturals), one, n))
# Out:
# expr: {n in NaturalsPos, (j_{1} - i_{1} + 1) in Naturals, ..(j_{k} - i_{k} + 1) in Naturals.., (j_{n} - i_{n} + 1) in Naturals}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{n \in \mathbb{N}^+, \left(j_{1} - i_{1} + 1\right) \in \mathbb{N}, \ldots, \left(j_{n} - i_{n} + 1\right) \in \mathbb{N}\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {n in NaturalsPos, (j_{1} - i_{1} + 1) in Naturals, ..(j_{k} - i_{k} + 1) in Naturals.., (j_{n} - i_{n} + 1) in Naturals}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (n in NaturalsPos, (j_{1} - i_{1} + 1) in Naturals, ..(j_{k} - i_{k} + 1) in Naturals.., (j_{n} - i_{n} + 1) in Naturals)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. n in NaturalsPos
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. ((j_{1} - i_{1} + 1) in Naturals), ..((j_{k} - i_{k} + 1) in Naturals).., ((j_{n} - i_{n} + 1) in Naturals)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 18
#    end_index: 7
# 5. (n, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. k -> ((j_{k} - i_{k} + 1) in Naturals)
#    core type: Lambda
#    parameter: 23
#    body: 9
# 7. n
#    core type: Variable
#    sub-expressions:
# 8. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 9. (j_{k} - i_{k} + 1) in Naturals
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (j_{k} - i_{k} + 1, Naturals)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. j_{k} - i_{k} + 1
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. Naturals
#     core type: Literal
#     sub-expressions:
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (j_{k}, -i_{k}, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18
# 16. j_{k}
#     core type: IndexedVar
# variable: 19
# index: 23
# 17. -i_{k}
#     core type: Operation
#     operator: 20
#     operand: 21
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. j
#     core type: Variable
#     sub-expressions:
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. i_{k}
#     core type: IndexedVar
# variable: 22
# index: 23
# 22. i
#     core type: Variable
#     sub-expressions:
# 23. k
#     core type: Variable
#     sub-expressions:
