# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import m
from proveit.logic import InSet
from proveit.number import Add, NaturalsPos, Neg, one

# %%
# build up the expression from sub-expressions
expr = InSet(Add(Add(m, Neg(one)), one), NaturalsPos)
# Out:
# expr: ((m - 1) + 1) in NaturalsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(m - 1\right) + 1\right) \in \mathbb{N}^+

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((m - 1) + 1) in NaturalsPos
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. ((m - 1) + 1, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (m - 1) + 1
#    core type: Operation
#    operator: 7
#    operands: 5
# 4. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 5. (m - 1, 1)
#    core type: ExprTuple
#    sub-expressions: 6, 12
# 6. m - 1
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (m, -1)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. m
#    core type: Variable
#    sub-expressions:
# 10. -1
#     core type: Operation
#     operator: 11
#     operand: 12
# 11. -
#     core type: Literal
#     sub-expressions:
# 12. 1
#     core type: Literal
#     sub-expressions:
