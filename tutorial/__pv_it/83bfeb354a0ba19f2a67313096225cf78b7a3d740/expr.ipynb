# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional
from proveit._common_ import a
from proveit.logic import InSet
from proveit.number import Add, Naturals, NaturalsPos, Neg, one

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Add(a, Neg(one)), Naturals), InSet(a, NaturalsPos))
# Out:
# expr: {(a - 1) in Naturals if a in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a - 1\right) \in \mathbb{N} \textrm{ if } a \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a - 1) in Naturals if a in NaturalsPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a - 1) in Naturals
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. a in NaturalsPos
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a - 1, Naturals)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (a, NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 11, 8
# 6. a - 1
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. Naturals
#    core type: Literal
#    sub-expressions:
# 8. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (a, -1)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. -1
#     core type: Operation
#     operator: 13
#     operand: 14
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. 1
#     core type: Literal
#     sub-expressions:
