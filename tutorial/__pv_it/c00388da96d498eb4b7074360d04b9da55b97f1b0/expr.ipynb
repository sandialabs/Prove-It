# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import k, m, n, x
from proveit.core_expr_types import Len
from proveit.number import four, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(four, Len([ExprRange(k, ExprRange(x, [k, x], one, n), one, m)]))
# Out:
# expr: (4, |((1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n))|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(4, |\left(\left(1, 1\right), \ldots, \left(1, n\right), \ldots\ldots, \left(m, 1\right), \ldots, \left(m, n\right)\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (4, |((1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n))|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 4
#    core type: Literal
#    sub-expressions:
# 2. |((1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n))|
#    core type: Operation
#    operator: 3
#    operand: 5
# 3. length
#    core type: Literal
#    sub-expressions:
# 4. (((1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n)))
#    core type: ExprTuple
#    sub-expressions: 5
# 5. ((1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n))
#    core type: ExprTuple
#    sub-expressions: 6
# 6. (1, 1), ..(1, x).., (1, n), ....(k, 1), ..(k, x).., (k, n)...., (m, 1), ..(m, x).., (m, n)
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 11
#    end_index: 8
# 7. k -> (k, 1), ..(k, x).., (k, n)
#    core type: Lambda
#    parameter: 14
#    body: 9
# 8. m
#    core type: Variable
#    sub-expressions:
# 9. (k, 1), ..(k, x).., (k, n)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 10. x -> (k, x)
#     core type: Lambda
#     parameter: 15
#     body: 13
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. n
#     core type: Variable
#     sub-expressions:
# 13. (k, x)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. k
#     core type: Variable
#     sub-expressions:
# 15. x
#     core type: Variable
#     sub-expressions:
