# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import i
from proveit.logic import Equals
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(one)
subExpr2 = Add(i, subExpr1).withSubtractionAt()
subExpr3 = Add(i, subExpr1, one)
expr = Equals(Add(Add(subExpr2, subExpr1, one), subExpr3), Add(subExpr2, subExpr3))
# Out:
# expr: (((i + (-1)) - 1 + 1) + (i - 1 + 1)) = ((i + (-1)) + (i - 1 + 1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\left(i + \left(-1\right)\right) - 1 + 1\right) + \left(i - 1 + 1\right)\right) = \left(\left(i + \left(-1\right)\right) + \left(i - 1 + 1\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (((i + (-1)) - 1 + 1) + (i - 1 + 1)) = ((i + (-1)) + (i - 1 + 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (((i + (-1)) - 1 + 1) + (i - 1 + 1), (i + (-1)) + (i - 1 + 1))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. ((i + (-1)) - 1 + 1) + (i - 1 + 1)
#    core type: Operation
#    operator: 12
#    operands: 5
# 4. (i + (-1)) + (i - 1 + 1)
#    core type: Operation
#    operator: 12
#    operands: 6
# 5. ((i + (-1)) - 1 + 1, i - 1 + 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (i + (-1), i - 1 + 1)
#    core type: ExprTuple
#    sub-expressions: 11, 8
# 7. (i + (-1)) - 1 + 1
#    core type: Operation
#    operator: 12
#    operands: 9
# 8. i - 1 + 1
#    core type: Operation
#    operator: 12
#    operands: 10
# 9. (i + (-1), -1, 1)
#    core type: ExprTuple
#    sub-expressions: 11, 15, 17
# 10. (i, -1, 1)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 17
# 11. i + (-1)
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (i, -1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. -1
#     core type: Operation
#     operator: 16
#     operand: 17
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
