# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar
from proveit._common_ import a, j, k, n
from proveit.number import Add, Mult, one

# %%
# build up the expression from sub-expressions
expr = ExprRange(k, Mult(k, IndexedVar(a, k)), Add(j, one), n)
# Out:
# expr: ((j + 1) * a_{j + 1}), ..(k * a_{k}).., (n * a_{n})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(j + 1\right) \cdot a_{j + 1}\right), \ldots, \left(n \cdot a_{n}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((j + 1) * a_{j + 1}), ..(k * a_{k}).., (n * a_{n})
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. k -> (k * a_{k})
#    core type: Lambda
#    parameter: 13
#    body: 4
# 2. j + 1
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. n
#    core type: Variable
#    sub-expressions:
# 4. k * a_{k}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (j, 1)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. *
#    core type: Literal
#    sub-expressions:
# 8. (k, a_{k})
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 9. j
#    core type: Variable
#    sub-expressions:
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. a_{k}
#     core type: IndexedVar
# variable: 12
# index: 13
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. k
#     core type: Variable
#     sub-expressions:
