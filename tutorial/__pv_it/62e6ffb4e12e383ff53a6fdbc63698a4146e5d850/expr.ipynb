# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar
from proveit._common_ import B, a, i, k
from proveit.core_expr_types import Len
from proveit.logic import Not
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Add(i, Neg(one)).withSubtractionAt()
expr = ExprTuple(Len([ExprRange(a, Not(IndexedVar(B, a)), one, subExpr1)]), Len([ExprRange(k, k, one, subExpr1)]))
# Out:
# expr: (|([not](B_{1}), ..[not](B_{a}).., [not](B_{i + (-1)}))|, |(1, ..k.., i + (-1))|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(\lnot B_{1}, \ldots, \lnot B_{i + \left(-1\right)}\right)|, |\left(1, \ldots, i + \left(-1\right)\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|([not](B_{1}), ..[not](B_{a}).., [not](B_{i + (-1)}))|, |(1, ..k.., i + (-1))|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |([not](B_{1}), ..[not](B_{a}).., [not](B_{i + (-1)}))|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., i + (-1))|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (([not](B_{1}), ..[not](B_{a}).., [not](B_{i + (-1)})))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., i + (-1)))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. ([not](B_{1}), ..[not](B_{a}).., [not](B_{i + (-1)}))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (1, ..k.., i + (-1))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. [not](B_{1}), ..[not](B_{a}).., [not](B_{i + (-1)})
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 24
#    end_index: 12
# 9. 1, ..k.., (i + (-1))
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 24
#    end_index: 12
# 10. a -> [not](B_{a})
#     core type: Lambda
#     parameter: 22
#     body: 13
# 11. k -> k
#     core type: Lambda
#     parameter: 14
#     body: 14
# 12. i + (-1)
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. [not](B_{a})
#     core type: Operation
#     operator: 17
#     operand: 18
# 14. k
#     core type: Variable
#     sub-expressions:
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (i, -1)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. not
#     core type: Literal
#     sub-expressions:
# 18. B_{a}
#     core type: IndexedVar
# variable: 21
# index: 22
# 19. i
#     core type: Variable
#     sub-expressions:
# 20. -1
#     core type: Operation
#     operator: 23
#     operand: 24
# 21. B
#     core type: Variable
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. -
#     core type: Literal
#     sub-expressions:
# 24. 1
#     core type: Literal
#     sub-expressions:
