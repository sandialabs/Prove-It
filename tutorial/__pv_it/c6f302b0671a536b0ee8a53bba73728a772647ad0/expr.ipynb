# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable
from proveit._common_ import A, i
from proveit.logic import And, Not, Or
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = ExprRange(subExpr1, IndexedVar(A, subExpr1), one, one)
expr = Lambda(subExpr2, Conditional(Or(subExpr2), Not(And(ExprRange(i, Not(IndexedVar(A, i)), one, one)))))
# Out:
# expr: (A_{1}, ..A_{_a}.., A_{1}) -> {A_{1} or ..A_{_a}.. or A_{1} if [not]([not](A_{1}) and ..[not](A_{i}).. and [not](A_{1})).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1}, \ldots, A_{1}\right) \mapsto \left\{A_{1} \lor \ldots \lor A_{1} \textrm{ if } \lnot \left((\lnot A_{1}) \land \ldots \land (\lnot A_{1})\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1}, ..A_{_a}.., A_{1}) -> {A_{1} or ..A_{_a}.. or A_{1} if [not]([not](A_{1}) and ..[not](A_{i}).. and [not](A_{1})).
#    core type: Lambda
#    parameter: 7
#    body: 1
# 1. {A_{1} or ..A_{_a}.. or A_{1} if [not]([not](A_{1}) and ..[not](A_{i}).. and [not](A_{1})).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. A_{1} or ..A_{_a}.. or A_{1}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. [not]([not](A_{1}) and ..[not](A_{i}).. and [not](A_{1}))
#    core type: Operation
#    operator: 17
#    operand: 6
# 4. or
#    core type: Literal
#    sub-expressions:
# 5. (A_{1}, ..A_{_a}.., A_{1})
#    core type: ExprTuple
#    sub-expressions: 7
# 6. [not](A_{1}) and ..[not](A_{i}).. and [not](A_{1})
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. A_{1}, ..A_{_a}.., A_{1}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 14
#    end_index: 14
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. ([not](A_{1}), ..[not](A_{i}).., [not](A_{1}))
#    core type: ExprTuple
#    sub-expressions: 11
# 10. _a -> A_{_a}
#     core type: Lambda
#     parameter: 15
#     body: 12
# 11. [not](A_{1}), ..[not](A_{i}).., [not](A_{1})
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 14
# 12. A_{_a}
#     core type: IndexedVar
# variable: 19
# index: 15
# 13. i -> [not](A_{i})
#     core type: Lambda
#     parameter: 20
#     body: 16
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. _a
#     core type: Variable
#     sub-expressions:
# 16. [not](A_{i})
#     core type: Operation
#     operator: 17
#     operand: 18
# 17. not
#     core type: Literal
#     sub-expressions:
# 18. A_{i}
#     core type: IndexedVar
# variable: 19
# index: 20
# 19. A
#     core type: Variable
#     sub-expressions:
# 20. i
#     core type: Variable
#     sub-expressions:
