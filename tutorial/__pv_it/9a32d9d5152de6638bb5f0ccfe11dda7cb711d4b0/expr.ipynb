# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Lambda, Variable
from proveit._common_ import a, b, n
from proveit.number import Add, Mult, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = IndexedVar(a, subExpr1)
subExpr3 = IndexedVar(b, subExpr1)
expr = Lambda([ExprRange(subExpr1, subExpr2, one, n), ExprRange(subExpr1, subExpr3, one, n)], Add(ExprRange(subExpr1, Mult(subExpr2, subExpr3), one, n)))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n}) -> ((a_{1} * b_{1}) + ..(a_{_a} * b_{_a}).. + (a_{n} * b_{n}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{n}, b_{1}, \ldots, b_{n}\right) \mapsto \left(\left(a_{1} \cdot b_{1}\right) + \ldots + \left(a_{n} \cdot b_{n}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n}) -> ((a_{1} * b_{1}) + ..(a_{_a} * b_{_a}).. + (a_{n} * b_{n}))
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a_{1}, ..a_{_a}.., a_{n}, b_{1}, ..b_{_a}.., b_{n})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 2. (a_{1} * b_{1}) + ..(a_{_a} * b_{_a}).. + (a_{n} * b_{n})
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. a_{1}, ..a_{_a}.., a_{n}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 11
#    end_index: 12
# 4. b_{1}, ..b_{_a}.., b_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 11
#    end_index: 12
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} * b_{1}, ..a_{_a} * b_{_a}.., a_{n} * b_{n})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. _a -> a_{_a}
#    core type: Lambda
#    parameter: 20
#    body: 16
# 8. _a -> b_{_a}
#    core type: Lambda
#    parameter: 20
#    body: 17
# ...
