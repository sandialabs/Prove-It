# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar
from proveit._common_ import B, a, i, j
from proveit.core_expr_types import Len
from proveit.core_expr_types._common_ import range_i_to_j
from proveit.logic import Equals

# %%
# build up the expression from sub-expressions
expr = Equals(Len([ExprRange(a, IndexedVar(B, a), i, j)]), Len([range_i_to_j]))
# Out:
# expr: |(B_{i}, ..B_{a}.., B_{j})| = |(i, ..k.., j)|

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(B_{i}, \ldots, B_{j}\right)| = |\left(i, \ldots, j\right)|

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |(B_{i}, ..B_{a}.., B_{j})| = |(i, ..k.., j)|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(B_{i}, ..B_{a}.., B_{j})|, |(i, ..k.., j)|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(B_{i}, ..B_{a}.., B_{j})|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |(i, ..k.., j)|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((B_{i}, ..B_{a}.., B_{j}))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((i, ..k.., j))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (B_{i}, ..B_{a}.., B_{j})
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (i, ..k.., j)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. B_{i}, ..B_{a}.., B_{j}
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 14
#     end_index: 15
# 11. i, ..k.., j
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 12. a -> B_{a}
#     core type: Lambda
#     parameter: 19
#     body: 16
# 13. k -> k
#     core type: Lambda
#     parameter: 17
#     body: 17
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. j
#     core type: Variable
#     sub-expressions:
# 16. B_{a}
#     core type: IndexedVar
# variable: 18
# index: 19
# 17. k
#     core type: Variable
#     sub-expressions:
# 18. B
#     core type: Variable
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
