# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import k, n
from proveit.core_expr_types import Len
from proveit.core_expr_types._common_ import a_1_to_n
from proveit.logic import Equals
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Equals(Len([a_1_to_n]), Len([ExprRange(k, k, one, n)]))
# Out:
# expr: |(a_{1}, ..a_{_a}.., a_{n})| = |(1, ..k.., n)|

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(a_{1}, \ldots, a_{n}\right)| = |\left(1, \ldots, n\right)|

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |(a_{1}, ..a_{_a}.., a_{n})| = |(1, ..k.., n)|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(a_{1}, ..a_{_a}.., a_{n})|, |(1, ..k.., n)|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(a_{1}, ..a_{_a}.., a_{n})|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |(1, ..k.., n)|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((a_{1}, ..a_{_a}.., a_{n}))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((1, ..k.., n))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (a_{1}, ..a_{_a}.., a_{n})
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (1, ..k.., n)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 14
#     end_index: 15
# 11. 1, ..k.., n
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 12. _a -> a_{_a}
#     core type: Lambda
#     parameter: 19
#     body: 16
# 13. k -> k
#     core type: Lambda
#     parameter: 17
#     body: 17
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. n
#     core type: Variable
#     sub-expressions:
# 16. a_{_a}
#     core type: IndexedVar
# variable: 18
# index: 19
# 17. k
#     core type: Variable
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. _a
#     core type: Variable
#     sub-expressions:
