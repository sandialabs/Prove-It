# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Function, Lambda
from proveit._common_ import P, a, b, c, d
from proveit.logic import Forall

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([b], Forall([c], Forall([d], Function(P, [a, b, c, d])))))
# Out:
# expr: a -> [forall_{b} [forall_{c} [forall_{d} P(a, b, c, d)]]]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# a \mapsto \left[\forall_{b}~\left[\forall_{c}~\left[\forall_{d}~P(a, b, c, d)\right]\right]\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b} [forall_{c} [forall_{d} P(a, b, c, d)]]]
#    core type: Lambda
#    parameter: 11
#    body: 1
# 1. forall_{b} [forall_{c} [forall_{d} P(a, b, c, d)]]
#    core type: Operation
#    operator: 6
#    operand: 2
# 2. b -> [forall_{c} [forall_{d} P(a, b, c, d)]]
#    core type: Lambda
#    parameter: 12
#    body: 3
# 3. forall_{c} [forall_{d} P(a, b, c, d)]
#    core type: Operation
#    operator: 6
#    operand: 4
# 4. c -> [forall_{d} P(a, b, c, d)]
#    core type: Lambda
#    parameter: 13
#    body: 5
# 5. forall_{d} P(a, b, c, d)
#    core type: Operation
#    operator: 6
#    operand: 7
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. d -> P(a, b, c, d)
#    core type: Lambda
#    parameter: 14
#    body: 8
# 8. P(a, b, c, d)
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. P
#    core type: Variable
#    sub-expressions:
# 10. (a, b, c, d)
#     core type: ExprTuple
#     sub-expressions: 11, 12, 13, 14
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. d
#     core type: Variable
#     sub-expressions:
