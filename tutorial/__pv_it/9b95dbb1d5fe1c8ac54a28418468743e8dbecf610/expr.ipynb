# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import k, n
from proveit.core_expr_types import Len
from proveit.core_expr_types._common_ import a_1_to_n
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([a_1_to_n]), Len([ExprRange(k, k, one, n)]))
# Out:
# expr: (|(a_{1}, ..a_{_a}.., a_{n})|, |(1, ..k.., n)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(a_{1}, \ldots, a_{n}\right)|, |\left(1, \ldots, n\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(a_{1}, ..a_{_a}.., a_{n})|, |(1, ..k.., n)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(a_{1}, ..a_{_a}.., a_{n})|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., n)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((a_{1}, ..a_{_a}.., a_{n}))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., n))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (a_{1}, ..a_{_a}.., a_{n})
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (1, ..k.., n)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. a_{1}, ..a_{_a}.., a_{n}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 12
#    end_index: 13
# 9. 1, ..k.., n
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 12
#    end_index: 13
# 10. _a -> a_{_a}
#     core type: Lambda
#     parameter: 17
#     body: 14
# 11. k -> k
#     core type: Lambda
#     parameter: 15
#     body: 15
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. n
#     core type: Variable
#     sub-expressions:
# 14. a_{_a}
#     core type: IndexedVar
# variable: 16
# index: 17
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. _a
#     core type: Variable
#     sub-expressions:
