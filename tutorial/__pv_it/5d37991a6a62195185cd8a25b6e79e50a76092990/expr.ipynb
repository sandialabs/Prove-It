# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import j, k
from proveit.logic import Equals
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(one)
expr = Equals(Add(Add(k, subExpr1, one), Add(j, subExpr1, one)), Add(k, j))
# Out:
# expr: ((k - 1 + 1) + (j - 1 + 1)) = (k + j)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(k - 1 + 1\right) + \left(j - 1 + 1\right)\right) = \left(k + j\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((k - 1 + 1) + (j - 1 + 1)) = (k + j)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((k - 1 + 1) + (j - 1 + 1), k + j)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (k - 1 + 1) + (j - 1 + 1)
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. k + j
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (k - 1 + 1, j - 1 + 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (k, j)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 7. k - 1 + 1
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. j - 1 + 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (k, -1, 1)
#    core type: ExprTuple
#    sub-expressions: 12, 14, 16
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (j, -1, 1)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 16
# 12. k
#     core type: Variable
#     sub-expressions:
# 13. j
#     core type: Variable
#     sub-expressions:
# 14. -1
#     core type: Operation
#     operator: 15
#     operand: 16
# 15. -
#     core type: Literal
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
