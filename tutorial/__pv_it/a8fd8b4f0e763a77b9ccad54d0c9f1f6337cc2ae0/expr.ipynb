# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import k, m, n
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(one)
subExpr2 = Add(n, subExpr1, one)
expr = ExprTuple(ExprRange(k, subExpr2, one, Add(m, subExpr1)), subExpr2)
# Out:
# expr: (n - 1 + 1, ..m - 1 repeats.., n - 1 + 1, n - 1 + 1)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n - 1 + 1, ..m - 1 \textrm{ repeats}.., n - 1 + 1, n - 1 + 1\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (n - 1 + 1, ..m - 1 repeats.., n - 1 + 1, n - 1 + 1)
#    core type: ExprTuple
#    sub-expressions: 1, 5
# 1. (n - 1 + 1), ..m - 1 repeats.., (n - 1 + 1)
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 13
#    end_index: 3
# 2. k -> (n - 1 + 1)
#    core type: Lambda
#    parameter: 4
#    body: 5
# 3. m - 1
#    core type: Operation
#    operator: 7
#    operands: 6
# 4. k
#    core type: Variable
#    sub-expressions:
# 5. n - 1 + 1
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (m, -1)
#    core type: ExprTuple
#    sub-expressions: 9, 11
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (n, -1, 1)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 13
# 9. m
#    core type: Variable
#    sub-expressions:
# 10. n
#     core type: Variable
#     sub-expressions:
# 11. -1
#     core type: Operation
#     operator: 12
#     operand: 13
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. 1
#     core type: Literal
#     sub-expressions:
