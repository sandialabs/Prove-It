# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import B, i, j, x
from proveit.core_expr_types import Len
from proveit.logic import Equals, Not
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Not(IndexedVar(B, x))
expr = Equals(Len([ExprRange(x, subExpr1, one, Add(i, Neg(one))), ExprRange(x, subExpr1, i, j)]), Variable("_a", latexFormat = r"{_{-}a}"))
# Out:
# expr: |([not](B_{1}), ..[not](B_{x}).., [not](B_{i - 1}), [not](B_{i}), ..[not](B_{x}).., [not](B_{j}))| = _a

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(\lnot B_{1}, \ldots, \lnot B_{i - 1}, \lnot B_{i}, \ldots, \lnot B_{j}\right)| = {_{-}a}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |([not](B_{1}), ..[not](B_{x}).., [not](B_{i - 1}), [not](B_{i}), ..[not](B_{x}).., [not](B_{j}))| = _a
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|([not](B_{1}), ..[not](B_{x}).., [not](B_{i - 1}), [not](B_{i}), ..[not](B_{x}).., [not](B_{j}))|, _a)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |([not](B_{1}), ..[not](B_{x}).., [not](B_{i - 1}), [not](B_{i}), ..[not](B_{x}).., [not](B_{j}))|
#    core type: Operation
#    operator: 5
#    operand: 7
# 4. _a
#    core type: Variable
#    sub-expressions:
# 5. length
#    core type: Literal
#    sub-expressions:
# 6. (([not](B_{1}), ..[not](B_{x}).., [not](B_{i - 1}), [not](B_{i}), ..[not](B_{x}).., [not](B_{j})))
#    core type: ExprTuple
#    sub-expressions: 7
# 7. ([not](B_{1}), ..[not](B_{x}).., [not](B_{i - 1}), [not](B_{i}), ..[not](B_{x}).., [not](B_{j}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# ...
