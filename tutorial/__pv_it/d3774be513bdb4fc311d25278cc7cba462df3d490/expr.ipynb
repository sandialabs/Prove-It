# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import A, j, m
from proveit.core_expr_types._common_ import A_i_to_j
from proveit.logic import And, Forall, Or
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = And(ExprRange(subExpr1, IndexedVar(A, subExpr1), one, j), Forall([A_i_to_j], Or(A_i_to_j)), IndexedVar(A, m))
# Out:
# expr: A_{1} and ..A_{_a}.. and A_{j} and [forall_{A_{i}, ..A_{_a}.., A_{j}} (A_{i} or ..A_{_a}.. or A_{j})] and A_{m}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# A_{1} \land \ldots \land A_{j} \land \left[\forall_{A_{i}, \ldots, A_{j}}~\left(A_{i} \lor \ldots \lor A_{j}\right)\right] \land A_{m}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A_{1} and ..A_{_a}.. and A_{j} and [forall_{A_{i}, ..A_{_a}.., A_{j}} (A_{i} or ..A_{_a}.. or A_{j})] and A_{m}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (A_{1}, ..A_{_a}.., A_{j}, forall_{A_{i}, ..A_{_a}.., A_{j}} (A_{i} or ..A_{_a}.. or A_{j}), A_{m})
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. A_{1}, ..A_{_a}.., A_{j}
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 6
#    end_index: 16
# 4. forall_{A_{i}, ..A_{_a}.., A_{j}} (A_{i} or ..A_{_a}.. or A_{j})
#    core type: Operation
#    operator: 7
#    operand: 8
# 5. A_{m}
#    core type: IndexedVar
# variable: 18
# index: 9
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. (A_{i}, ..A_{_a}.., A_{j}) -> (A_{i} or ..A_{_a}.. or A_{j})
#    core type: Lambda
#    parameter: 13
#    body: 10
# 9. m
#    core type: Variable
#    sub-expressions:
# ...
