# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar
from proveit._common_ import B, C, i, j, x
from proveit.core_expr_types import Len
from proveit.logic import Not
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([ExprRange(x, Not(IndexedVar(B, x)), one, Add(i, Neg(one)).withSubtractionAt()), ExprRange(x, IndexedVar(C, x), one, i)]), j)
# Out:
# expr: (|([not](B_{1}), ..[not](B_{x}).., [not](B_{i + (-1)}), C_{1}, ..C_{x}.., C_{i})|, j)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(\lnot B_{1}, \ldots, \lnot B_{i + \left(-1\right)}, C_{1}, \ldots, C_{i}\right)|, j\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|([not](B_{1}), ..[not](B_{x}).., [not](B_{i + (-1)}), C_{1}, ..C_{x}.., C_{i})|, j)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |([not](B_{1}), ..[not](B_{x}).., [not](B_{i + (-1)}), C_{1}, ..C_{x}.., C_{i})|
#    core type: Operation
#    operator: 3
#    operand: 5
# 2. j
#    core type: Variable
#    sub-expressions:
# 3. length
#    core type: Literal
#    sub-expressions:
# 4. (([not](B_{1}), ..[not](B_{x}).., [not](B_{i + (-1)}), C_{1}, ..C_{x}.., C_{i}))
#    core type: ExprTuple
#    sub-expressions: 5
# 5. ([not](B_{1}), ..[not](B_{x}).., [not](B_{i + (-1)}), C_{1}, ..C_{x}.., C_{i})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. [not](B_{1}), ..[not](B_{x}).., [not](B_{i + (-1)})
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 23
#    end_index: 9
# 7. C_{1}, ..C_{x}.., C_{i}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 23
#    end_index: 17
# 8. x -> [not](B_{x})
#    core type: Lambda
#    parameter: 21
#    body: 11
# 9. i + (-1)
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. x -> C_{x}
#     core type: Lambda
#     parameter: 21
#     body: 14
# 11. [not](B_{x})
#     core type: Operation
#     operator: 15
#     operand: 16
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (i, -1)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. C_{x}
#     core type: IndexedVar
# variable: 19
# index: 21
# 15. not
#     core type: Literal
#     sub-expressions:
# 16. B_{x}
#     core type: IndexedVar
# variable: 20
# index: 21
# 17. i
#     core type: Variable
#     sub-expressions:
# 18. -1
#     core type: Operation
#     operator: 22
#     operand: 23
# 19. C
#     core type: Variable
#     sub-expressions:
# 20. B
#     core type: Variable
#     sub-expressions:
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. -
#     core type: Literal
#     sub-expressions:
# 23. 1
#     core type: Literal
#     sub-expressions:
