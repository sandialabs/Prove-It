# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import a, k, m, n, x
from proveit.core_expr_types import Len
from proveit.logic import Equals, Set
from proveit.number import Mult, one, zero

# %%
# build up the expression from sub-expressions
expr = Set(Equals(Len([ExprRange(a, Mult(a, a), zero, k), x, ExprRange(a, a, one, m)]), Len([ExprRange(a, a, one, n)])))
# Out:
# expr: {|(0 * 0, ..a * a.., k * k, x, 1, ..a.., m)| = |(1, ..a.., n)|}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{|\left(0 \cdot 0, \ldots, k \cdot k, x, 1, \ldots, m\right)| = |\left(1, \ldots, n\right)|\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {|(0 * 0, ..a * a.., k * k, x, 1, ..a.., m)| = |(1, ..a.., n)|}
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. |(0 * 0, ..a * a.., k * k, x, 1, ..a.., m)| = |(1, ..a.., n)|
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (|(0 * 0, ..a * a.., k * k, x, 1, ..a.., m)|, |(1, ..a.., n)|)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. |(0 * 0, ..a * a.., k * k, x, 1, ..a.., m)|
#    core type: Operation
#    operator: 8
#    operand: 10
# 6. |(1, ..a.., n)|
#    core type: Operation
#    operator: 8
#    operand: 11
# 7. ((0 * 0, ..a * a.., k * k, x, 1, ..a.., m))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. length
#    core type: Literal
#    sub-expressions:
# 9. ((1, ..a.., n))
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (0 * 0, ..a * a.., k * k, x, 1, ..a.., m)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14
# 11. (1, ..a.., n)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. (0 * 0), ..(a * a).., (k * k)
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. 1, ..a.., m
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 19
# 15. 1, ..a.., n
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 16. a -> (a * a)
#     core type: Lambda
#     parameter: 26
#     body: 23
# 17. 0
#     core type: Literal
#     sub-expressions:
# 18. k
#     core type: Variable
#     sub-expressions:
# 19. m
#     core type: Variable
#     sub-expressions:
# 20. a -> a
#     core type: Lambda
#     parameter: 26
#     body: 26
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. n
#     core type: Variable
#     sub-expressions:
# 23. a * a
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. *
#     core type: Literal
#     sub-expressions:
# 25. (a, a)
#     core type: ExprTuple
#     sub-expressions: 26, 26
# 26. a
#     core type: Variable
#     sub-expressions:
