# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import m, n
from proveit.logic import Equals
from proveit.number import Add, Mult, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Add(m, Neg(one))
expr = Equals(Mult(Add(subExpr1, one), n), Add(Mult(subExpr1, n), Mult(one, n)))
# Out:
# expr: (((m - 1) + 1) * n) = (((m - 1) * n) + (1 * n))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\left(m - 1\right) + 1\right) \cdot n\right) = \left(\left(\left(m - 1\right) \cdot n\right) + \left(1 \cdot n\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (((m - 1) + 1) * n) = (((m - 1) * n) + (1 * n))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (((m - 1) + 1) * n, ((m - 1) * n) + (1 * n))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. ((m - 1) + 1) * n
#    core type: Operation
#    operator: 12
#    operands: 5
# 4. ((m - 1) * n) + (1 * n)
#    core type: Operation
#    operator: 16
#    operands: 6
# 5. ((m - 1) + 1, n)
#    core type: ExprTuple
#    sub-expressions: 7, 15
# 6. ((m - 1) * n, 1 * n)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (m - 1) + 1
#    core type: Operation
#    operator: 16
#    operands: 10
# 8. (m - 1) * n
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. 1 * n
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. (m - 1, 1)
#     core type: ExprTuple
#     sub-expressions: 14, 21
# 11. (m - 1, n)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (1, n)
#     core type: ExprTuple
#     sub-expressions: 21, 15
# 14. m - 1
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. n
#     core type: Variable
#     sub-expressions:
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (m, -1)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. m
#     core type: Variable
#     sub-expressions:
# 19. -1
#     core type: Operation
#     operator: 20
#     operand: 21
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. 1
#     core type: Literal
#     sub-expressions:
