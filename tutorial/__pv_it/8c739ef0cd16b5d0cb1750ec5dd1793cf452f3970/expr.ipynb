# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import i, j
from proveit.logic import Equals
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(one)
expr = Equals(Add(Add(Add(i, subExpr1), subExpr1, one), Add(j, Neg(i), one)), j)
# Out:
# expr: (((i - 1) - 1 + 1) + (j - i + 1)) = j

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\left(i - 1\right) - 1 + 1\right) + \left(j - i + 1\right)\right) = j

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (((i - 1) - 1 + 1) + (j - i + 1)) = j
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (((i - 1) - 1 + 1) + (j - i + 1), j)
#    core type: ExprTuple
#    sub-expressions: 3, 10
# 3. ((i - 1) - 1 + 1) + (j - i + 1)
#    core type: Operation
#    operator: 12
#    operands: 4
# 4. ((i - 1) - 1 + 1, j - i + 1)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. (i - 1) - 1 + 1
#    core type: Operation
#    operator: 12
#    operands: 7
# 6. j - i + 1
#    core type: Operation
#    operator: 12
#    operands: 8
# 7. (i - 1, -1, 1)
#    core type: ExprTuple
#    sub-expressions: 9, 15, 17
# 8. (j, -i, 1)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 17
# 9. i - 1
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. j
#     core type: Variable
#     sub-expressions:
# 11. -i
#     core type: Operation
#     operator: 16
#     operand: 14
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (i, -1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. -1
#     core type: Operation
#     operator: 16
#     operand: 17
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
