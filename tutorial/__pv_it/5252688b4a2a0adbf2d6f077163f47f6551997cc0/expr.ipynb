# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import i
from proveit.core_expr_types._common_ import i_to_j_len
from proveit.logic import Equals
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(one)
expr = Equals(Add(Add(Add(i, subExpr1), subExpr1, one), i_to_j_len), Add(Add(i, subExpr1).withSubtractionAt(), i_to_j_len))
# Out:
# expr: (((i - 1) - 1 + 1) + (j - i + 1)) = ((i + (-1)) + (j - i + 1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\left(i - 1\right) - 1 + 1\right) + \left(j - i + 1\right)\right) = \left(\left(i + \left(-1\right)\right) + \left(j - i + 1\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (((i - 1) - 1 + 1) + (j - i + 1)) = ((i + (-1)) + (j - i + 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (((i - 1) - 1 + 1) + (j - i + 1), (i + (-1)) + (j - i + 1))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. ((i - 1) - 1 + 1) + (j - i + 1)
#    core type: Operation
#    operator: 14
#    operands: 5
# 4. (i + (-1)) + (j - i + 1)
#    core type: Operation
#    operator: 14
#    operands: 6
# 5. ((i - 1) - 1 + 1, j - i + 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (i + (-1), j - i + 1)
#    core type: ExprTuple
#    sub-expressions: 11, 8
# 7. (i - 1) - 1 + 1
#    core type: Operation
#    operator: 14
#    operands: 9
# 8. j - i + 1
#    core type: Operation
#    operator: 14
#    operands: 10
# 9. (i - 1, -1, 1)
#    core type: ExprTuple
#    sub-expressions: 11, 17, 19
# 10. (j, -i, 1)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 19
# 11. i - 1
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. j
#     core type: Variable
#     sub-expressions:
# 13. -i
#     core type: Operation
#     operator: 18
#     operand: 16
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (i, -1)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. i
#     core type: Variable
#     sub-expressions:
# 17. -1
#     core type: Operation
#     operator: 18
#     operand: 19
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. 1
#     core type: Literal
#     sub-expressions:
