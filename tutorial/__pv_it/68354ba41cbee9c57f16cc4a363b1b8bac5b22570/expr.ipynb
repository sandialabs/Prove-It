# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import k, m
from proveit.core_expr_types import Len
from proveit.number import Add, Neg, one, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([Add(m, Neg(one)), one]), Len([ExprRange(k, k, one, two)]))
# Out:
# expr: (|(m - 1, 1)|, |(1, ..k.., 2)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(m - 1, 1\right)|, |\left(1, \ldots, 2\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(m - 1, 1)|, |(1, ..k.., 2)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(m - 1, 1)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 2)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((m - 1, 1))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 2))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (m - 1, 1)
#    core type: ExprTuple
#    sub-expressions: 8, 18
# 7. (1, ..k.., 2)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. m - 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. 1, ..k.., 2
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 18
#    end_index: 13
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (m, -1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. k -> k
#     core type: Lambda
#     parameter: 16
#     body: 16
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. m
#     core type: Variable
#     sub-expressions:
# 15. -1
#     core type: Operation
#     operator: 17
#     operand: 18
# 16. k
#     core type: Variable
#     sub-expressions:
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. 1
#     core type: Literal
#     sub-expressions:
