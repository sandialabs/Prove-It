# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import j, n
from proveit.logic import Equals
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Add(n, Neg(Add(j, one)), one)
expr = Equals(Add(Add(j, Neg(one), one), subExpr1), Add(j, subExpr1))
# Out:
# expr: ((j - 1 + 1) + (n - (j + 1) + 1)) = (j + (n - (j + 1) + 1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(j - 1 + 1\right) + \left(n - \left(j + 1\right) + 1\right)\right) = \left(j + \left(n - \left(j + 1\right) + 1\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((j - 1 + 1) + (n - (j + 1) + 1)) = (j + (n - (j + 1) + 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((j - 1 + 1) + (n - (j + 1) + 1), j + (n - (j + 1) + 1))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (j - 1 + 1) + (n - (j + 1) + 1)
#    core type: Operation
#    operator: 16
#    operands: 5
# 4. j + (n - (j + 1) + 1)
#    core type: Operation
#    operator: 16
#    operands: 6
# 5. (j - 1 + 1, n - (j + 1) + 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (j, n - (j + 1) + 1)
#    core type: ExprTuple
#    sub-expressions: 18, 8
# 7. j - 1 + 1
#    core type: Operation
#    operator: 16
#    operands: 9
# 8. n - (j + 1) + 1
#    core type: Operation
#    operator: 16
#    operands: 10
# 9. (j, -1, 1)
#    core type: ExprTuple
#    sub-expressions: 18, 11, 19
# 10. (n, -(j + 1), 1)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 19
# 11. -1
#     core type: Operation
#     operator: 14
#     operand: 19
# 12. n
#     core type: Variable
#     sub-expressions:
# 13. -(j + 1)
#     core type: Operation
#     operator: 14
#     operand: 15
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. j + 1
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. j
#     core type: Variable
#     sub-expressions:
# 19. 1
#     core type: Literal
#     sub-expressions:
