# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import a, k
from proveit.number import Add, Mult, zero

# %%
# build up the expression from sub-expressions
expr = ExprRange(a, Mult(Mult(a, a), Add(a, a)), zero, k)
# Out:
# expr: ((0 * 0) * (0 + 0)), ..((a * a) * (a + a)).., ((k * k) * (k + k))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(0 \cdot 0\right) \cdot \left(0 + 0\right)\right), \ldots, \left(\left(k \cdot k\right) \cdot \left(k + k\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((0 * 0) * (0 + 0)), ..((a * a) * (a + a)).., ((k * k) * (k + k))
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. a -> ((a * a) * (a + a))
#    core type: Lambda
#    parameter: 11
#    body: 4
# 2. 0
#    core type: Literal
#    sub-expressions:
# 3. k
#    core type: Variable
#    sub-expressions:
# 4. (a * a) * (a + a)
#    core type: Operation
#    operator: 8
#    operands: 5
# 5. (a * a, a + a)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. a * a
#    core type: Operation
#    operator: 8
#    operands: 10
# 7. a + a
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. *
#    core type: Literal
#    sub-expressions:
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (a, a)
#     core type: ExprTuple
#     sub-expressions: 11, 11
# 11. a
#     core type: Variable
#     sub-expressions:
