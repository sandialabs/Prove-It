# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.core_expr_types._common_ import a_1_to_j, b_1_to_k

# %%
# build up the expression from sub-expressions
expr = ExprTuple(a_1_to_j, b_1_to_k)
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{j}, b_{1}, ..b_{_a}.., b_{k})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{j}, b_{1}, \ldots, b_{k}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{j}, b_{1}, ..b_{_a}.., b_{k})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a_{1}, ..a_{_a}.., a_{j}
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 6
#    end_index: 4
# 2. b_{1}, ..b_{_a}.., b_{k}
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 3. _a -> a_{_a}
#    core type: Lambda
#    parameter: 12
#    body: 8
# 4. j
#    core type: Variable
#    sub-expressions:
# 5. _a -> b_{_a}
#    core type: Lambda
#    parameter: 12
#    body: 9
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. k
#    core type: Variable
#    sub-expressions:
# 8. a_{_a}
#    core type: IndexedVar
# variable: 10
# index: 12
# 9. b_{_a}
#    core type: IndexedVar
# variable: 11
# index: 12
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. b
#     core type: Variable
#     sub-expressions:
# 12. _a
#     core type: Variable
#     sub-expressions:
