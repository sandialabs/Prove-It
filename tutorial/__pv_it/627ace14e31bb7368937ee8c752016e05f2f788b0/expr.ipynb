# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable
from proveit._common_ import a, b, c, d, i, j, k
from proveit.core_expr_types._common_ import a_1_to_i, c_1_to_j, d_1_to_k
from proveit.logic import And, Equals, InSet
from proveit.number import Add, Complexes, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
expr = Conditional(Equals(Add(a_1_to_i, b, c_1_to_j, Neg(b), d_1_to_k), Add(a_1_to_i, c_1_to_j, d_1_to_k)), And(ExprRange(subExpr1, InSet(IndexedVar(a, subExpr1), Complexes), one, i), InSet(b, Complexes), ExprRange(subExpr1, InSet(IndexedVar(c, subExpr1), Complexes), one, j), ExprRange(subExpr1, InSet(IndexedVar(d, subExpr1), Complexes), one, k)))
# Out:
# expr: {(a_{1} i repeats ..a_{_a}.. + a_{i} + b + c_{1} j repeats ..c_{_a}.. + c_{j} - b + d_{1} k repeats ..d_{_a}.. + d_{k}) = (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k}) if a_{1} in Complexes ,  ..a_{_a} in Complexes.. ,  a_{i} in Complexes ,  b in Complexes ,  c_{1} in Complexes ,  ..c_{_a} in Complexes.. ,  c_{j} in Complexes ,  d_{1} in Complexes ,  ..d_{_a} in Complexes.. ,  d_{k} in Complexes.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a_{1} i \textrm{ repeats} \ldots + a_{i} + b + c_{1} j \textrm{ repeats} \ldots + c_{j} - b + d_{1} k \textrm{ repeats} \ldots + d_{k}\right) = \left(a_{1} + \ldots + a_{i} + c_{1} + \ldots + c_{j} + d_{1} + \ldots + d_{k}\right) \textrm{ if } a_{1} \in \mathbb{C} ,  \ldots ,  a_{i} \in \mathbb{C} ,  b \in \mathbb{C} ,  c_{1} \in \mathbb{C} ,  \ldots ,  c_{j} \in \mathbb{C} ,  d_{1} \in \mathbb{C} ,  \ldots ,  d_{k} \in \mathbb{C}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a_{1} i repeats ..a_{_a}.. + a_{i} + b + c_{1} j repeats ..c_{_a}.. + c_{j} - b + d_{1} k repeats ..d_{_a}.. + d_{k}) = (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k}) if a_{1} in Complexes ,  ..a_{_a} in Complexes.. ,  a_{i} in Complexes ,  b in Complexes ,  c_{1} in Complexes ,  ..c_{_a} in Complexes.. ,  c_{j} in Complexes ,  d_{1} in Complexes ,  ..d_{_a} in Complexes.. ,  d_{k} in Complexes.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a_{1} i repeats ..a_{_a}.. + a_{i} + b + c_{1} j repeats ..c_{_a}.. + c_{j} - b + d_{1} k repeats ..d_{_a}.. + d_{k}) = (a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a_{1} in Complexes) and ..(a_{_a} in Complexes).. and (a_{i} in Complexes) and (b in Complexes) and (c_{1} in Complexes) and ..(c_{_a} in Complexes).. and (c_{j} in Complexes) and (d_{1} in Complexes) and ..(d_{_a} in Complexes).. and (d_{k} in Complexes)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a_{1} i repeats ..a_{_a}.. + a_{i} + b + c_{1} j repeats ..c_{_a}.. + c_{j} - b + d_{1} k repeats ..d_{_a}.. + d_{k}, a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} in Complexes, ..a_{_a} in Complexes.., a_{i} in Complexes, b in Complexes, c_{1} in Complexes, ..c_{_a} in Complexes.., c_{j} in Complexes, d_{1} in Complexes, ..d_{_a} in Complexes.., d_{k} in Complexes)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 7. a_{1} i repeats ..a_{_a}.. + a_{i} + b + c_{1} j repeats ..c_{_a}.. + c_{j} - b + d_{1} k repeats ..d_{_a}.. + d_{k}
#    core type: Operation
#    operator: 14
#    operands: 13
# 8. a_{1} + ..a_{_a}.. + a_{i} + c_{1} + ..c_{_a}.. + c_{j} + d_{1} + ..d_{_a}.. + d_{k}
#    core type: Operation
#    operator: 14
#    operands: 15
# 9. (a_{1} in Complexes), ..(a_{_a} in Complexes).., (a_{i} in Complexes)
#    core type: ExprRange
#    lambda_map: 16
#    start_index: 34
#    end_index: 30
# 10. b in Complexes
#     core type: Operation
#     operator: 38
#     operands: 17
# 11. (c_{1} in Complexes), ..(c_{_a} in Complexes).., (c_{j} in Complexes)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 34
#     end_index: 32
# 12. (d_{1} in Complexes), ..(d_{_a} in Complexes).., (d_{k} in Complexes)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 34
#     end_index: 35
# 13. (a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, -b, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 21, 28, 22, 20, 23
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k})
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23
# 16. _a -> (a_{_a} in Complexes)
#     core type: Lambda
#     parameter: 47
#     body: 24
# 17. (b, Complexes)
#     core type: ExprTuple
#     sub-expressions: 28, 43
# 18. _a -> (c_{_a} in Complexes)
#     core type: Lambda
#     parameter: 47
#     body: 25
# 19. _a -> (d_{_a} in Complexes)
#     core type: Lambda
#     parameter: 47
#     body: 26
# 20. -b
#     core type: Operation
#     operator: 27
#     operand: 28
# 21. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 34
#     end_index: 30
# 22. c_{1}, ..c_{_a}.., c_{j}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 34
#     end_index: 32
# 23. d_{1}, ..d_{_a}.., d_{k}
#     core type: ExprRange
#     lambda_map: 33
#     start_index: 34
#     end_index: 35
# 24. a_{_a} in Complexes
#     core type: Operation
#     operator: 38
#     operands: 36
# 25. c_{_a} in Complexes
#     core type: Operation
#     operator: 38
#     operands: 37
# 26. d_{_a} in Complexes
#     core type: Operation
#     operator: 38
#     operands: 39
# 27. -
#     core type: Literal
#     sub-expressions:
# 28. b
#     core type: Variable
#     sub-expressions:
# 29. _a -> a_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 40
# 30. i
#     core type: Variable
#     sub-expressions:
# 31. _a -> c_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 41
# 32. j
#     core type: Variable
#     sub-expressions:
# 33. _a -> d_{_a}
#     core type: Lambda
#     parameter: 47
#     body: 42
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. k
#     core type: Variable
#     sub-expressions:
# 36. (a_{_a}, Complexes)
#     core type: ExprTuple
#     sub-expressions: 40, 43
# 37. (c_{_a}, Complexes)
#     core type: ExprTuple
#     sub-expressions: 41, 43
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (d_{_a}, Complexes)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 40. a_{_a}
#     core type: IndexedVar
# variable: 44
# index: 47
# 41. c_{_a}
#     core type: IndexedVar
# variable: 45
# index: 47
# 42. d_{_a}
#     core type: IndexedVar
# variable: 46
# index: 47
# 43. Complexes
#     core type: Literal
#     sub-expressions:
# 44. a
#     core type: Variable
#     sub-expressions:
# 45. c
#     core type: Variable
#     sub-expressions:
# 46. d
#     core type: Variable
#     sub-expressions:
# 47. _a
#     core type: Variable
#     sub-expressions:
