# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar
from proveit._common_ import B, i, j, x
from proveit.core_expr_types import Len
from proveit.logic import Not
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(one)
subExpr2 = Not(IndexedVar(B, x))
subExpr3 = Add(i, subExpr1)
expr = ExprTuple(Len([ExprRange(x, subExpr2, one, subExpr3), ExprRange(x, subExpr2, i, j)]), Add(Add(subExpr3, subExpr1, one), Add(j, Neg(i), one)))
# Out:
# expr: (|([not](B_{1}), ..[not](B_{x}).., [not](B_{i - 1}), [not](B_{i}), ..[not](B_{x}).., [not](B_{j}))|, ((i - 1) - 1 + 1) + (j - i + 1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(\lnot B_{1}, \ldots, \lnot B_{i - 1}, \lnot B_{i}, \ldots, \lnot B_{j}\right)|, \left(\left(i - 1\right) - 1 + 1\right) + \left(j - i + 1\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|([not](B_{1}), ..[not](B_{x}).., [not](B_{i - 1}), [not](B_{i}), ..[not](B_{x}).., [not](B_{j}))|, ((i - 1) - 1 + 1) + (j - i + 1))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |([not](B_{1}), ..[not](B_{x}).., [not](B_{i - 1}), [not](B_{i}), ..[not](B_{x}).., [not](B_{j}))|
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. ((i - 1) - 1 + 1) + (j - i + 1)
#    core type: Operation
#    operator: 18
#    operands: 5
# 3. length
#    core type: Literal
#    sub-expressions:
# 4. (([not](B_{1}), ..[not](B_{x}).., [not](B_{i - 1}), [not](B_{i}), ..[not](B_{x}).., [not](B_{j})))
#    core type: ExprTuple
#    sub-expressions: 6
# 5. ((i - 1) - 1 + 1, j - i + 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. ([not](B_{1}), ..[not](B_{x}).., [not](B_{i - 1}), [not](B_{i}), ..[not](B_{x}).., [not](B_{j}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (i - 1) - 1 + 1
#    core type: Operation
#    operator: 18
#    operands: 11
# ...
