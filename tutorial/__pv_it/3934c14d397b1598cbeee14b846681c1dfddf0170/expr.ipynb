# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import m, n
from proveit.number import Add, Mult, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(Add(m, Neg(one)), n)
expr = ExprTuple(Add(subExpr1, n), Add(subExpr1, Mult(one, n)))
# Out:
# expr: (((m - 1) * n) + n, ((m - 1) * n) + (1 * n))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\left(m - 1\right) \cdot n\right) + n, \left(\left(m - 1\right) \cdot n\right) + \left(1 \cdot n\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (((m - 1) * n) + n, ((m - 1) * n) + (1 * n))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. ((m - 1) * n) + n
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. ((m - 1) * n) + (1 * n)
#    core type: Operation
#    operator: 12
#    operands: 4
# 3. ((m - 1) * n, n)
#    core type: ExprTuple
#    sub-expressions: 5, 11
# 4. ((m - 1) * n, 1 * n)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. (m - 1) * n
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. 1 * n
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (m - 1, n)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. *
#    core type: Literal
#    sub-expressions:
# 9. (1, n)
#    core type: ExprTuple
#    sub-expressions: 17, 11
# 10. m - 1
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. n
#     core type: Variable
#     sub-expressions:
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (m, -1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. m
#     core type: Variable
#     sub-expressions:
# 15. -1
#     core type: Operation
#     operator: 16
#     operand: 17
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
