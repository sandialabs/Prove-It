# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import j, k, n
from proveit.logic import Equals, InSet
from proveit.number import Add, Naturals

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(k, Naturals), InSet(j, Naturals), Equals(Add(j, k), n))
# Out:
# expr: (k in Naturals, j in Naturals, (j + k) = n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(k \in \mathbb{N}, j \in \mathbb{N}, \left(j + k\right) = n\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (k in Naturals, j in Naturals, (j + k) = n)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. k in Naturals
#    core type: Operation
#    operator: 5
#    operands: 4
# 2. j in Naturals
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. (j + k) = n
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. (k, Naturals)
#    core type: ExprTuple
#    sub-expressions: 15, 9
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (j, Naturals)
#    core type: ExprTuple
#    sub-expressions: 14, 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (j + k, n)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. Naturals
#    core type: Literal
#    sub-expressions:
# 10. j + k
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. n
#     core type: Variable
#     sub-expressions:
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (j, k)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. j
#     core type: Variable
#     sub-expressions:
# 15. k
#     core type: Variable
#     sub-expressions:
