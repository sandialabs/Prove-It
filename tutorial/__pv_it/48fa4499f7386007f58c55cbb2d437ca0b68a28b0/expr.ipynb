# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Lambda, Variable
from proveit._common_ import A, C, i, j
from proveit.logic import And, Or
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_a", latexFormat = r"{_{-}a}")
subExpr2 = ExprRange(subExpr1, IndexedVar(C, subExpr1), i, j)
expr = And(ExprRange(subExpr1, IndexedVar(A, subExpr1), one, j), Lambda(subExpr2, Or(subExpr2)))
# Out:
# expr: A_{1} and ..A_{_a}.. and A_{j} and [(C_{i}, ..C_{_a}.., C_{j}) -> (C_{i} or ..C_{_a}.. or C_{j})]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# A_{1} \land \ldots \land A_{j} \land \left[\left(C_{i}, \ldots, C_{j}\right) \mapsto \left(C_{i} \lor \ldots \lor C_{j}\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A_{1} and ..A_{_a}.. and A_{j} and [(C_{i}, ..C_{_a}.., C_{j}) -> (C_{i} or ..C_{_a}.. or C_{j})]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (A_{1}, ..A_{_a}.., A_{j}, (C_{i}, ..C_{_a}.., C_{j}) -> (C_{i} or ..C_{_a}.. or C_{j}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A_{1}, ..A_{_a}.., A_{j}
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 15
# 4. (C_{i}, ..C_{_a}.., C_{j}) -> (C_{i} or ..C_{_a}.. or C_{j})
#    core type: Lambda
#    parameter: 12
#    body: 7
# 5. _a -> A_{_a}
#    core type: Lambda
#    parameter: 18
#    body: 8
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. C_{i} or ..C_{_a}.. or C_{j}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. A_{_a}
#    core type: IndexedVar
# variable: 11
# index: 18
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (C_{i}, ..C_{_a}.., C_{j})
#     core type: ExprTuple
#     sub-expressions: 12
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. C_{i}, ..C_{_a}.., C_{j}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 13. _a -> C_{_a}
#     core type: Lambda
#     parameter: 18
#     body: 16
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. j
#     core type: Variable
#     sub-expressions:
# 16. C_{_a}
#     core type: IndexedVar
# variable: 17
# index: 18
# 17. C
#     core type: Variable
#     sub-expressions:
# 18. _a
#     core type: Variable
#     sub-expressions:
