# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.IndexedVar.html">IndexedVar</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import IndexedVar, Variable
from proveit._common_ import x

# %%
# build up the expression from sub-expressions
expr = IndexedVar(IndexedVar(IndexedVar(x, Variable("_a", latexFormat = r"{_{-}a}")), Variable("_b", latexFormat = r"{_{-}b}")), Variable("_c", latexFormat = r"{_{-}c}"))
# Out:
# expr: x_{_a,_b,_c}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x_{{_{-}a},{_{-}b},{_{-}c}}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x_{_a,_b,_c}
#    core type: IndexedVar
# variable: 1
# index: 2
# 1. x_{_a,_b}
#    core type: IndexedVar
# variable: 3
# index: 4
# 2. _c
#    core type: Variable
#    sub-expressions:
# 3. x_{_a}
#    core type: IndexedVar
# variable: 5
# index: 6
# 4. _b
#    core type: Variable
#    sub-expressions:
# 5. x
#    core type: Variable
#    sub-expressions:
# 6. _a
#    core type: Variable
#    sub-expressions:
