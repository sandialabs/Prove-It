# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit._common_ import j, n
from proveit.logic import InSet
from proveit.number import Add, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
expr = InSet(Add(n, Neg(Add(j, one)), one), Naturals)
# Out:
# expr: (n - (j + 1) + 1) in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n - \left(j + 1\right) + 1\right) \in \mathbb{N}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (n - (j + 1) + 1) in Naturals
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (n - (j + 1) + 1, Naturals)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. n - (j + 1) + 1
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. Naturals
#    core type: Literal
#    sub-expressions:
# 5. (n, -(j + 1), 1)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 13
# 6. n
#    core type: Variable
#    sub-expressions:
# 7. -(j + 1)
#    core type: Operation
#    operator: 8
#    operand: 9
# 8. -
#    core type: Literal
#    sub-expressions:
# 9. j + 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (j, 1)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. j
#     core type: Variable
#     sub-expressions:
# 13. 1
#     core type: Literal
#     sub-expressions:
