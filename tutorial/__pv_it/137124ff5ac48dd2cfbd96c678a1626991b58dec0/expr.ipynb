# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple
from proveit._common_ import a, k, m, x, y
from proveit.number import Add, Mult, one, zero

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(a, a)
expr = ExprTuple(ExprRange(a, Mult(subExpr1, Add(a, a)), zero, k), Mult(x, y), ExprRange(a, subExpr1, one, m))
# Out:
# expr: ((0 * 0) * (0 + 0), ..(a * a) * (a + a).., (k * k) * (k + k), x * y, 1 * 1, ..a * a.., m * m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(0 \cdot 0\right) \cdot \left(0 + 0\right), \ldots, \left(k \cdot k\right) \cdot \left(k + k\right), x \cdot y, 1 \cdot 1, \ldots, m \cdot m\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((0 * 0) * (0 + 0), ..(a * a) * (a + a).., (k * k) * (k + k), x * y, 1 * 1, ..a * a.., m * m)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. ((0 * 0) * (0 + 0)), ..((a * a) * (a + a)).., ((k * k) * (k + k))
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 5
#    end_index: 6
# 2. x * y
#    core type: Operation
#    operator: 17
#    operands: 7
# 3. (1 * 1), ..(a * a).., (m * m)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 4. a -> ((a * a) * (a + a))
#    core type: Lambda
#    parameter: 20
#    body: 11
# 5. 0
#    core type: Literal
#    sub-expressions:
# 6. k
#    core type: Variable
#    sub-expressions:
# 7. (x, y)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 8. a -> (a * a)
#    core type: Lambda
#    parameter: 20
#    body: 15
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. m
#     core type: Variable
#     sub-expressions:
# 11. (a * a) * (a + a)
#     core type: Operation
#     operator: 17
#     operands: 14
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. y
#     core type: Variable
#     sub-expressions:
# 14. (a * a, a + a)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. a * a
#     core type: Operation
#     operator: 17
#     operands: 19
# 16. a + a
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. *
#     core type: Literal
#     sub-expressions:
# 18. +
#     core type: Literal
#     sub-expressions:
# 19. (a, a)
#     core type: ExprTuple
#     sub-expressions: 20, 20
# 20. a
#     core type: Variable
#     sub-expressions:
